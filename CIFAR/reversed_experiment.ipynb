# %% [markdown]
# # Example for:
# Transfer Learning Empirical Experiment from Animals (pretraining) to Vehicles (finetuning) classes of CIFAR

# %% [markdown]
# ### Setup and Hyperparams

# %%
# Specify which gpu
import os
gpu_id = 4
# os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

import sys
sys.path.append('/home/arnisaf/mp-tl-study')
from functions.utils import *

# device = torch.device("cuda" if torch.cuda.is_available() else "mps")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.cuda.manual_seed_all(0)  # if using multi-GPU

# %%
# cuts=0 means: end-to-end model if we are reinitializing
cuts = [0,1,2,3,4,5,6]

# %%
# Changes Here for the experiments
params = {
      # MODEL ARCHITECTURE PARAMS
      'depth': 6,
      'num_channels': 64, # num channels for CNN
      # 'hidden_dim_lin': 128,
      'activation_function': nn.ReLU,
      'kernel_size': 3,
      # TRAINING PARAMS
      'device': device,
      'lr_pretrain': 0.001,   
      'lr_fine_tune': 0.001,  # CHANGE: if no layer-wise lr
      # 'lr_fine_tune_reinit': 0.001,         # CHANGE: if no layer-wise lr
      # 'lr_fine_tune_no_reinit': 0.0001,     # CHANGE: if layer-wise lr
      'num_train': 10,
      'early_stop_patience': 5,
      'save_best': False,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': False,
      'classification_report_flag': False,
      'batch_size':64,
      # DATASET PARAMS
      'pre_train_classes': [2, 3, 4, 5, 6, 7],
      'fine_tune_classes': [0, 1, 8, 9],
        'val_split': 0.1,
      'num_workers': 0,
      'generate_dataset_seed': 42,
      # EXPERIMENT SETTING PARAMS
      'use_pooling': True,   # CHANGE
      'pooling_every_n_layers': 2, # add pooling after every n layers specified here. For only one pooling after all the CNN layers, this equals params['depth']
      'pooling_stride': 2,
      'freeze': True,         # CHANGE: freeze the conv layers before the cut
      'reinit': True,         # CHANGE: reinit the conv lyers only after the cut
      'reinit_both_dense': True   # CHANGE: True for reinitialize both dense layers, False for reinit only the last dense layer
    }

# %%
root_dir = './data'  # Specify your data directory here
transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            ])
dataloader_wrapped = TransferLearningWrapper(params, datasets.CIFAR10, datasets.CIFAR10, root_dir, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Pretraining

# %%
pretrained_model = CustomCNN(params, dataloader_wrapped.output_dim, tuple(dataloader_wrapped.finetune_test_loader.dataset[0][0].shape))
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=1024, out_features=6, bias=True)
# )

# %%
# # Train and evaluate
# trainer = Trainer(pretrained_model, dataloader_wrapped, params["lr_pretrain"], params)
# train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

# print(f"Final Training Accuracy: {train_acc:.4f}")
# print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 47.07%
# Validation Accuracy: 45.83%
# Epoch: 1 	Training Accuracy: 56.01%
# Validation Accuracy: 53.77%
# Epoch: 2 	Training Accuracy: 63.18%
# Validation Accuracy: 59.60%
# Epoch: 3 	Training Accuracy: 67.62%
# Validation Accuracy: 63.63%
# Epoch: 4 	Training Accuracy: 72.28%
# Validation Accuracy: 68.77%
# Epoch: 5 	Training Accuracy: 75.13%
# Validation Accuracy: 70.07%
# Epoch: 6 	Training Accuracy: 77.28%
# Validation Accuracy: 70.47%
# Epoch: 7 	Training Accuracy: 80.19%
# Validation Accuracy: 73.23%
# Epoch: 8 	Training Accuracy: 82.81%
# Validation Accuracy: 72.90%
# Epoch: 9 	Training Accuracy: 84.17%
# Validation Accuracy: 73.70%
# Final Training Accuracy: 0.8417
# Final Test Accuracy: 0.7305

# %%
pretrained_model.load_state_dict(torch.load('pretrained_models/pretrained_model_animals/modelcifar10_animals.pth'))
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=1024, out_features=6, bias=True)
# )

# %%
eval(pretrained_model, device, dataloader_wrapped.val_loader, debug=True, classification_report_flag=True, is_cnn=True)
# Out:
# Average loss: 0.7561, Accuracy: 2211.0/3000 (74%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.79      0.67      0.73       465
#      Class 1       0.58      0.67      0.62       530
#      Class 2       0.71      0.80      0.75       492
#      Class 3       0.67      0.71      0.69       504
#      Class 4       0.88      0.78      0.83       489
#      Class 5       0.88      0.78      0.83       520
#
#     accuracy                           0.74      3000
#    macro avg       0.75      0.74      0.74      3000
# weighted avg       0.75      0.74      0.74      3000
# 0.737

# %%
# save model for later use
torch.save(pretrained_model.state_dict(), 'pretrained_models/pretrained_0.001/pretrained_model_89percent.pth')

params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
#save params as well
with open('pretrained_models/pretrained_0.001/params.json', 'w') as fp:
    json.dump(params_tmp, fp)

# %% [markdown]
# ## Fine-tuning Experiments

# %% [markdown]
# ### Baselines (End-to-end models trained on subsets of fine-tuning dataset)
# We also reuse the baselines a lot! so skip if we already have the jsons

# %%
baselines_results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:      
    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
    
    for repeat in range(repeats):
        # Print or log the sampled values for transparency
        print(f"\nSampled Percentage: {sampled_percentage}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

        # Reduce the dataset
        train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        torch.manual_seed(repeat)
        #train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)

        # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
        params_tmp = copy.deepcopy(params)
        params_tmp["reinit"] = True
        model_new = cut_custom_cnn_model(pretrained_model, cut_point=0, params=params_tmp, output_dim=dataloader_wrapped.output_dim)
        model_new.to(device)

        # Train and evaluate
        trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
        train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
        print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

        # Store the results
        baselines_results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":-1, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc}) # -1 for the cut point means it's baseline
# Out:
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.7500, Test Accuracy: 0.4143
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.7500, Test Accuracy: 0.3735
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.6875, Test Accuracy: 0.4083
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.3125, Test Accuracy: 0.2978
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.3125, Test Accuracy: 0.2855
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.6875, Test Accuracy: 0.2945
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9375, Test Accuracy: 0.4093
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.6875, Test Accuracy: 0.3840
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.7500, Test Accuracy: 0.3695
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.6875, Test Accuracy: 0.3177
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.6250, Test Accuracy: 0.3262
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.6875, Test Accuracy: 0.3762
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.6250, Test Accuracy: 0.3063
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.6875, Test Accuracy: 0.3123
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.6875, Test Accuracy: 0.3865
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.6250, Test Accuracy: 0.3628
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.2500, Test Accuracy: 0.2385
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.6250, Test Accuracy: 0.3837
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.4375, Test Accuracy: 0.3723
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.8125, Test Accuracy: 0.3837
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 0.2500, Test Accuracy: 0.2500
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 21
# Training Accuracy: 0.8125, Test Accuracy: 0.4070
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 22
# Training Accuracy: 0.6250, Test Accuracy: 0.3645
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 23
# Training Accuracy: 0.6875, Test Accuracy: 0.2875
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.7500, Test Accuracy: 0.3885
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.5333, Test Accuracy: 0.4923
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.5778, Test Accuracy: 0.4540
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.5333, Test Accuracy: 0.4715
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.5889, Test Accuracy: 0.4595
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.5222, Test Accuracy: 0.4537
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.5111, Test Accuracy: 0.3992
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.4833, Test Accuracy: 0.4585
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.4944, Test Accuracy: 0.4647
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.5722, Test Accuracy: 0.4502
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.5222, Test Accuracy: 0.4595
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.5389, Test Accuracy: 0.4407
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.5167, Test Accuracy: 0.4387
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.5556, Test Accuracy: 0.4785
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.5333, Test Accuracy: 0.4885
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.5333, Test Accuracy: 0.4768
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.5222, Test Accuracy: 0.4720
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.5444, Test Accuracy: 0.4835
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.5222, Test Accuracy: 0.4778
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.5722, Test Accuracy: 0.4655
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.5889, Test Accuracy: 0.4597
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 20
# Training Accuracy: 0.5556, Test Accuracy: 0.4788
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 21
# Training Accuracy: 0.5500, Test Accuracy: 0.4728
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 22
# Training Accuracy: 0.5722, Test Accuracy: 0.4770
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 23
# Training Accuracy: 0.5778, Test Accuracy: 0.4983
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.5778, Test Accuracy: 0.4750
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.7139, Test Accuracy: 0.6408
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.7394, Test Accuracy: 0.6442
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.6728, Test Accuracy: 0.5893
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.6900, Test Accuracy: 0.6352
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.7383, Test Accuracy: 0.6560
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.7194, Test Accuracy: 0.6400
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.6939, Test Accuracy: 0.6525
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.6750, Test Accuracy: 0.6162
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.6828, Test Accuracy: 0.5950
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.7094, Test Accuracy: 0.6145
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.6517, Test Accuracy: 0.5985
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.7428, Test Accuracy: 0.6415
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.7006, Test Accuracy: 0.6428
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.7428, Test Accuracy: 0.6645
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.7156, Test Accuracy: 0.6272
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.7039, Test Accuracy: 0.6358
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.6894, Test Accuracy: 0.6382
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.7333, Test Accuracy: 0.6757
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.6789, Test Accuracy: 0.5958
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.7317, Test Accuracy: 0.6522
#
# Sampled Percentage: 0.5, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9132, Test Accuracy: 0.8407
#
# Sampled Percentage: 0.5, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9223, Test Accuracy: 0.8427
#
# Sampled Percentage: 0.5, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9162, Test Accuracy: 0.8498
#
# Sampled Percentage: 0.5, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8893, Test Accuracy: 0.8340
#
# Sampled Percentage: 0.5, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9087, Test Accuracy: 0.8455
#
# Sampled Percentage: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9565, Test Accuracy: 0.8832
#
# Sampled Percentage: 1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9386, Test Accuracy: 0.8790
#
# Sampled Percentage: 1, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9447, Test Accuracy: 0.8828
#
# Sampled Percentage: 1, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9556, Test Accuracy: 0.8818
#
# Sampled Percentage: 1, Lr: 0.001, Repeat: 4

# %%
# save baseline results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + baselines_results

with open(f'results_jsons/baselines_freeze_{params["freeze"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)

# %% [markdown]
# ### Fine-tuning

# %%
results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9565, Test Accuracy: 0.8832
#
# Sampled Percentage: 1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9386, Test Accuracy: 0.8790
#
# Sampled Percentage: 1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9447, Test Accuracy: 0.8828
#
# Sampled Percentage: 1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9556, Test Accuracy: 0.8818
#
# Sampled Percentage: 1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9424, Test Accuracy: 0.8788
#
# Sampled Percentage: 1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9495, Test Accuracy: 0.8858
#
# Sampled Percentage: 1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9568, Test Accuracy: 0.8990
#
# Sampled Percentage: 1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9479, Test Accuracy: 0.8928
#
# Sampled Percentage: 1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9585, Test Accuracy: 0.8960
#
# Sampled Percentage: 1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9588, Test Accuracy: 0.9055
#
# Sampled Percentage: 1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9526, Test Accuracy: 0.8922
#
# Sampled Percentage: 1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9629, Test Accuracy: 0.9000
#
# Sampled Percentage: 1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9549, Test Accuracy: 0.8938
#
# Sampled Percentage: 1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9456, Test Accuracy: 0.8752
#
# Sampled Percentage: 1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9507, Test Accuracy: 0.8865
#
# Sampled Percentage: 1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9534, Test Accuracy: 0.8878
#
# Sampled Percentage: 1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9576, Test Accuracy: 0.8878
#
# Sampled Percentage: 1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9529, Test Accuracy: 0.8918
#
# Sampled Percentage: 1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9396, Test Accuracy: 0.8690
#
# Sampled Percentage: 1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9531, Test Accuracy: 0.8810
#
# Sampled Percentage: 1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9463, Test Accuracy: 0.8645
#
# Sampled Percentage: 1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9510, Test Accuracy: 0.8710
#
# Sampled Percentage: 1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9586, Test Accuracy: 0.8740
#
# Sampled Percentage: 1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9548, Test Accuracy: 0.8712
#
# Sampled Percentage: 1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9600, Test Accuracy: 0.8775
#
# Sampled Percentage: 1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9335, Test Accuracy: 0.8417
#
# Sampled Percentage: 1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9275, Test Accuracy: 0.8367
#
# Sampled Percentage: 1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9362, Test Accuracy: 0.8367
#
# Sampled Percentage: 1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9389, Test Accuracy: 0.8470
#
# Sampled Percentage: 1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9387, Test Accuracy: 0.8425
#
# Sampled Percentage: 1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8280, Test Accuracy: 0.7865
#
# Sampled Percentage: 1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8318, Test Accuracy: 0.7873
#
# Sampled Percentage: 1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.8161, Test Accuracy: 0.7850
#
# Sampled Percentage: 1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8302, Test Accuracy: 0.7855
#
# Sampled Percentage: 1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.8306, Test Accuracy: 0.7880

# %%
# save fine-tuning results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/results_freeze_{params["freeze"]}_reinit_{params["reinit"]}_pool_{params["use_pooling"]}_lr_{params["lr_fine_tune"]}_nice_curve.json', 'w') as f:
    json.dump(results, f)
results = results[1:]

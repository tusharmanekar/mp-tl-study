# %% [markdown]
# # Example for:
# Transfer Learning Empirical Experiment from all other classes of FashionMNIST to shoes (Sandal, Sneaker, Ankle boot) classes in FashionMNIST

# %% [markdown]
# ### Setup and Hyperparams

# %%
# Specify which gpu
import os
gpu_id = 6
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

import sys
sys.path.append('/home/arnisaf/mp-tl-study')
from functions.utils import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.cuda.manual_seed_all(0)  # if using multi-GPU

# %%
# cuts=0 means: end-to-end model if we are reinitializing
cuts = [0,1,2,3,4,5,6]

# %%
# Changes Here for the experiments
params = {
      # MODEL ARCHITECTURE PARAMS
      'depth': 6,
      'num_channels': 64, # num channels for CNN
      'two_linear_layers': False,
      'hidden_dim_lin': 128,  # if two_linear_layers == True
      'activation_function': nn.ReLU,
      'kernel_size': 3,
      # TRAINING PARAMS
      'device': device,
      'lr_pretrain': 0.001,   
      'lr_fine_tune': 0.001,  # CHANGE: if no layer-wise lr
      'num_train': 40,
      'early_stop_patience': 6,
      'save_best': False,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': False,
      'classification_report_flag': False,
      'batch_size':4096,
      # DATASET PARAMS
      'pre_train_classes': [0, 1, 2, 3, 4],
      'fine_tune_classes': [5, 6, 7, 8, 9],
      'val_split': 0.1,
      'num_workers': 0,
      'generate_dataset_seed': 42,
      # EXPERIMENT SETTING PARAMS
      'use_pooling': True,   # CHANGE
      'pooling_every_n_layers': 2, # add pooling after every n layers specified here. For only one pooling after all the CNN layers, this equals params['depth']
      # default value for pooling_every_n_layers is 1 (after each cnn layer)
      'pooling_stride': 2,
      'freeze': True,         # CHANGE: freeze the conv layers before the cut
      'reinit': True,         # CHANGE: reinit the conv lyers only after the cut
      'reinit_both_dense': True   # CHANGE: True for reinitialize both dense layers, False for reinit only the last dense layer
    }

# %%
root_dir = './data'  # Specify your data directory here
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
dataloader_wrapped = TransferLearningWrapper(params, datasets.FashionMNIST, datasets.FashionMNIST, root_dir, transform=transform)## Pretraining

# %%
dataloader_wrapped.pretrain_train_loader.dataset.__len__()
# Out:
# 27000

# %% [markdown]
# ## Pretraining

# %%
#Create DNN model
pretrained_model = CustomCNN(params, dataloader_wrapped.output_dim)
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=5, bias=True)
# )

# %%
# Train and evaluate - Skip if loading saved model!
trainer = Trainer(pretrained_model, dataloader_wrapped, params["lr_pretrain"], params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 35.97%
# Validation Accuracy: 36.63%
# Epoch: 1 	Training Accuracy: 59.17%
# Validation Accuracy: 59.93%
# Epoch: 2 	Training Accuracy: 69.57%
# Validation Accuracy: 69.97%
# Epoch: 3 	Training Accuracy: 76.40%
# Validation Accuracy: 76.27%
# Epoch: 4 	Training Accuracy: 79.24%
# Validation Accuracy: 79.20%
# Epoch: 5 	Training Accuracy: 79.97%
# Validation Accuracy: 79.83%
# Epoch: 6 	Training Accuracy: 78.35%
# Validation Accuracy: 78.00%
# Epoch: 7 	Training Accuracy: 82.17%
# Validation Accuracy: 82.20%
# Epoch: 8 	Training Accuracy: 83.48%
# Validation Accuracy: 83.03%
# Epoch: 9 	Training Accuracy: 83.65%
# Validation Accuracy: 82.93%
# Epoch: 10 	Training Accuracy: 84.15%
# Validation Accuracy: 83.87%
# Epoch: 11 	Training Accuracy: 84.84%
# Validation Accuracy: 84.03%
# Epoch: 12 	Training Accuracy: 85.16%
# Validation Accuracy: 84.83%
# Epoch: 13 	Training Accuracy: 85.78%
# Validation Accuracy: 85.33%
# Epoch: 14 	Training Accuracy: 86.27%
# Validation Accuracy: 85.90%
# Epoch: 15 	Training Accuracy: 86.53%
# Validation Accuracy: 86.17%
# Epoch: 16 	Training Accuracy: 86.79%
# Validation Accuracy: 86.60%
# Epoch: 17 	Training Accuracy: 87.10%
# Validation Accuracy: 86.63%
# Epoch: 18 	Training Accuracy: 87.24%
# Validation Accuracy: 86.70%
# Epoch: 19 	Training Accuracy: 87.77%
# Validation Accuracy: 87.63%
# Epoch: 20 	Training Accuracy: 87.26%
# Validation Accuracy: 87.63%
# Epoch: 21 	Training Accuracy: 88.08%
# Validation Accuracy: 87.80%
# Epoch: 22 	Training Accuracy: 87.80%
# Validation Accuracy: 87.77%
# Epoch: 23 	Training Accuracy: 88.02%
# Validation Accuracy: 88.20%
# Epoch: 24 	Training Accuracy: 88.96%
# Validation Accuracy: 88.97%
# Epoch: 25 	Training Accuracy: 88.87%
# Validation Accuracy: 88.53%
# Epoch: 26 	Training Accuracy: 88.94%
# Validation Accuracy: 88.77%
# Epoch: 27 	Training Accuracy: 89.42%
# Validation Accuracy: 89.87%
# Epoch: 28 	Training Accuracy: 89.82%
# Validation Accuracy: 89.87%
# Epoch: 29 	Training Accuracy: 90.07%
# Validation Accuracy: 89.77%
# Epoch: 30 	Training Accuracy: 89.88%
# Validation Accuracy: 90.07%
# Epoch: 31 	Training Accuracy: 89.55%
# Validation Accuracy: 88.90%
# Epoch: 32 	Training Accuracy: 90.00%
# Validation Accuracy: 90.10%
# Epoch: 33 	Training Accuracy: 90.83%
# Validation Accuracy: 90.37%
# Epoch: 34 	Training Accuracy: 91.00%
# Validation Accuracy: 90.63%
# Epoch: 35 	Training Accuracy: 91.24%
# Validation Accuracy: 90.97%
# Epoch: 36 	Training Accuracy: 91.13%
# Validation Accuracy: 90.80%
# Epoch: 37 	Training Accuracy: 91.55%
# Validation Accuracy: 91.07%
# Epoch: 38 	Training Accuracy: 91.48%
# Validation Accuracy: 91.40%
# Epoch: 39 	Training Accuracy: 91.56%
# Validation Accuracy: 90.97%
# Final Training Accuracy: 0.9156
# Final Test Accuracy: 0.9150

# %%
torch.save(pretrained_model.state_dict(), 'pretrained_models/pretrained_cifar_arc/pretrained_model_new.pth')

# %%
pretrained_model.load_state_dict(torch.load('pretrained_models/pretrained_cifar_arc/pretrained_model_new.pth'))
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=5, bias=True)
# )

# %%
eval(pretrained_model, device, dataloader_wrapped.val_loader, debug=True, classification_report_flag=True, is_cnn=True)
# Out:
# Average loss: 0.2344, Accuracy: 2729.0/3000 (91%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.94      0.92      0.93       604
#      Class 1       0.98      0.98      0.98       629
#      Class 2       0.86      0.92      0.89       583
#      Class 3       0.88      0.87      0.88       583
#      Class 4       0.88      0.86      0.87       601
#
#     accuracy                           0.91      3000
#    macro avg       0.91      0.91      0.91      3000
# weighted avg       0.91      0.91      0.91      3000
# 0.9096666666666666

# %%
# save model for later use
foldername = "pretrained_models/pretrained_normal_classes_new"
os.mkdir(foldername)
torch.save(pretrained_model.state_dict(), os.path.join(foldername, 'pretrained_model.pth'))

params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
#save params as well
with open(os.path.join(foldername, 'params.json'), 'w') as fp:
    json.dump(params_tmp, fp)

# %% [markdown]
# ## Fine-tuning Experiments

# %% [markdown]
# ### Baselines (End-to-end models trained on subsets of fine-tuning dataset)
# We also reuse the baselines a lot! so skip if we already have the jsons

# %%
baselines_results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:      
    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
    
    for repeat in range(repeats):
        # Print or log the sampled values for transparency
        print(f"\nSampled Percentage: {sampled_percentage}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

        # Reduce the dataset
        train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        torch.manual_seed(repeat)
        #train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)

        # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
        params_tmp = copy.deepcopy(params)
        params_tmp["reinit"] = True
        model_new = cut_custom_cnn_model(pretrained_model, cut_point=0, params=params_tmp, output_dim=dataloader_wrapped.output_dim)
        model_new.to(device)

        # Train and evaluate
        trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
        train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
        print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

        # Store the results
        baselines_results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":-1, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc}) # -1 for the cut point means it's baseline
# Out:
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8400, Test Accuracy: 0.7093
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.7712
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.8400, Test Accuracy: 0.7833
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.7268
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.7448
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.8400, Test Accuracy: 0.6792
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.7600, Test Accuracy: 0.8136
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.7200, Test Accuracy: 0.6660
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 8
# Training Accuracy: 1.0000, Test Accuracy: 0.8056
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.8003
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.7600, Test Accuracy: 0.6798
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.6917
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.9600, Test Accuracy: 0.7715
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.7138
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.7702
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.7760
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.7398
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.8046
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.7866
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.7201
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.7848
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.9600, Test Accuracy: 0.7947
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.7531
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.6800, Test Accuracy: 0.7886
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.7819
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9370, Test Accuracy: 0.8603
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.8630, Test Accuracy: 0.8554
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.7481, Test Accuracy: 0.7485
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8815, Test Accuracy: 0.8557
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.7868
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.8481, Test Accuracy: 0.8335
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.8815, Test Accuracy: 0.8767
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8852, Test Accuracy: 0.8525
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.8852, Test Accuracy: 0.8496
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.8963, Test Accuracy: 0.8687
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.8481, Test Accuracy: 0.8494
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.8704, Test Accuracy: 0.8474
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.8889, Test Accuracy: 0.8648
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.8778, Test Accuracy: 0.8633
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.8185, Test Accuracy: 0.8162
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9148, Test Accuracy: 0.8748
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9148, Test Accuracy: 0.8679
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.8778, Test Accuracy: 0.8743
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.7481, Test Accuracy: 0.7416
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.8481, Test Accuracy: 0.8191
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 0.8407, Test Accuracy: 0.8061
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.8370, Test Accuracy: 0.8447
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 22
# Training Accuracy: 0.9111, Test Accuracy: 0.8608
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 23
# Training Accuracy: 0.8741, Test Accuracy: 0.8673
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.8926, Test Accuracy: 0.8789
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8822, Test Accuracy: 0.8817
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8952, Test Accuracy: 0.8853
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.7567, Test Accuracy: 0.7513
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8041, Test Accuracy: 0.8046
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.8778, Test Accuracy: 0.8721
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.8578, Test Accuracy: 0.8479
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.8578, Test Accuracy: 0.8761
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8689, Test Accuracy: 0.8727
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.8770, Test Accuracy: 0.8608
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.8530, Test Accuracy: 0.8506
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.8633, Test Accuracy: 0.8737
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8693, Test Accuracy: 0.8625
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.8781, Test Accuracy: 0.8744
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.8770, Test Accuracy: 0.8747
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.8726, Test Accuracy: 0.8709
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.8863, Test Accuracy: 0.8759
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.8759, Test Accuracy: 0.8731
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.8789, Test Accuracy: 0.8753
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.8133, Test Accuracy: 0.8035
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.8507, Test Accuracy: 0.8491
#
# Sampled Percentage: 0.5, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9489, Test Accuracy: 0.9469
#
# Sampled Percentage: 0.5, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9506, Test Accuracy: 0.9469
#
# Sampled Percentage: 0.5, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9417, Test Accuracy: 0.9428
#
# Sampled Percentage: 0.5, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9439, Test Accuracy: 0.9411
#
# Sampled Percentage: 0.5, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9019, Test Accuracy: 0.9020
#
# Sampled Percentage: 1.0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9665, Test Accuracy: 0.9660
#
# Sampled Percentage: 1.0, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9702, Test Accuracy: 0.9694
#
# Sampled Percentage: 1.0, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9671, Test Accuracy: 0.9666
#
# Sampled Percentage: 1.0, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9661, Test Accuracy: 0.9656
#
# Sampled Percentage: 1.0, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9550, Test Accuracy: 0.9551

# %%
print(baselines_results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 0, 'train_acc': 0.84, 'test_acc': 0.7092666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 1, 'train_acc': 0.88, 'test_acc': 0.7712333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 2, 'train_acc': 0.84, 'test_acc': 0.7833}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 3, 'train_acc': 0.88, 'test_acc': 0.7267666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 4, 'train_acc': 0.8, 'test_acc': 0.7448333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 5, 'train_acc': 0.84, 'test_acc': 0.6792}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 6, 'train_acc': 0.76, 'test_acc': 0.8136}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 7, 'train_acc': 0.72, 'test_acc': 0.6659666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 8, 'train_acc': 1.0, 'test_acc': 0.8055666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 9, 'train_acc': 0.92, 'test_acc': 0.8003}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 10, 'train_acc': 0.76, 'test_acc': 0.6798}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 11, 'train_acc': 0.88, 'test_acc': 0.6917}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 12, 'train_acc': 0.96, 'test_acc': 0.7715333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 13, 'train_acc': 0.88, 'test_acc': 0.7138}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 14, 'train_acc': 1.0, 'test_acc': 0.7702}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 15, 'train_acc': 1.0, 'test_acc': 0.7759666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 16, 'train_acc': 0.92, 'test_acc': 0.7398}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 17, 'train_acc': 0.92, 'test_acc': 0.8046}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 18, 'train_acc': 1.0, 'test_acc': 0.7866}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 19, 'train_acc': 1.0, 'test_acc': 0.7200666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 20, 'train_acc': 0.88, 'test_acc': 0.7848}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 21, 'train_acc': 0.96, 'test_acc': 0.7947333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 22, 'train_acc': 1.0, 'test_acc': 0.7530666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 23, 'train_acc': 0.68, 'test_acc': 0.7886333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 24, 'train_acc': 1.0, 'test_acc': 0.7819333333333334}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 0, 'train_acc': 0.937037037037037, 'test_acc': 0.8602666666666666}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 1, 'train_acc': 0.8629629629629629, 'test_acc': 0.8554}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 2, 'train_acc': 0.7481481481481481, 'test_acc': 0.7484666666666666}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 3, 'train_acc': 0.8814814814814815, 'test_acc': 0.8557}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 4, 'train_acc': 0.8, 'test_acc': 0.7868}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 5, 'train_acc': 0.8481481481481481, 'test_acc': 0.833466 ...

# %%
# save baseline results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + baselines_results

with open(f'results_jsons/baselines_freeze_{params["freeze"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)

# %% [markdown]
# ### Fine-tuning

# %%
results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})

# %%
# save fine-tuning results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/results_freeze_{params["freeze"]}_reinit_{params["reinit"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)
results = results[1:]

# %% [markdown]
# # Example for:
# Transfer Learning Empirical Experiment from all other classes of FashionMNIST to shoes (Sandal, Sneaker, Ankle boot) classes in FashionMNIST

# %% [markdown]
# ### Setup and Hyperparams

# %%
# Specify which gpu
import os
gpu_id = 4
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

import sys
sys.path.append('/home/arnisaf/mp-tl-study')
from functions.utils import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.cuda.manual_seed_all(0)  # if using multi-GPU

# %%
# cuts=0 means: end-to-end model if we are reinitializing
cuts = [0,1,2,3,4,5,6]

# %%
# Changes Here for the experiments
params = {
      # MODEL ARCHITECTURE PARAMS
      'depth': 6,
      'num_channels': 64, # num channels for CNN
      'two_linear_layers': False,
      'hidden_dim_lin': 128,  # if two_linear_layers == True
      'activation_function': nn.ReLU,
      'kernel_size': 3,
      # TRAINING PARAMS
      'device': device,
      'lr_pretrain': 0.001,   
      'lr_fine_tune': 0.001,  # CHANGE: if no layer-wise lr
      'num_train': 40,
      'early_stop_patience': 6,
      'save_best': False,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': False,
      'classification_report_flag': False,
      'batch_size':4096,
      # DATASET PARAMS
      'pre_train_classes': [0, 1, 2, 3, 4, 6, 8],
      'fine_tune_classes': [5, 7, 9],
      'val_split': 0.1,
      'num_workers': 0,
      'generate_dataset_seed': 42,
      # EXPERIMENT SETTING PARAMS
      'use_pooling': True,   # CHANGE
      'pooling_every_n_layers': 2, # add pooling after every n layers specified here. For only one pooling after all the CNN layers, this equals params['depth']
      # default value for pooling_every_n_layers is 1 (after each cnn layer)
      'pooling_stride': 2,
      'freeze': True,         # CHANGE: freeze the conv layers before the cut
      'reinit': True,         # CHANGE: reinit the conv lyers only after the cut
      'reinit_both_dense': True   # CHANGE: True for reinitialize both dense layers, False for reinit only the last dense layer
    }

# %%
root_dir = './data'  # Specify your data directory here
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
dataloader_wrapped = TransferLearningWrapper(params, datasets.FashionMNIST, datasets.FashionMNIST, root_dir, transform=transform)## Pretraining

# %%
dataloader_wrapped.pretrain_train_loader.dataset.__len__()
# Out:
# 37800

# %% [markdown]
# ## Pretraining

# %%
#Create DNN model
pretrained_model = CustomCNN(params, dataloader_wrapped.output_dim)
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=7, bias=True)
# )

# %%
# Train and evaluate - Skip if loading saved model!
trainer = Trainer(pretrained_model, dataloader_wrapped, params["lr_pretrain"], params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 52.15%
# Validation Accuracy: 51.71%
# Epoch: 1 	Training Accuracy: 59.28%
# Validation Accuracy: 59.00%
# Epoch: 2 	Training Accuracy: 64.52%
# Validation Accuracy: 63.98%
# Epoch: 3 	Training Accuracy: 69.87%
# Validation Accuracy: 69.69%
# Epoch: 4 	Training Accuracy: 74.66%
# Validation Accuracy: 74.33%
# Epoch: 5 	Training Accuracy: 74.02%
# Validation Accuracy: 73.71%
# Epoch: 6 	Training Accuracy: 74.74%
# Validation Accuracy: 75.00%
# Epoch: 7 	Training Accuracy: 77.03%
# Validation Accuracy: 77.19%
# Epoch: 8 	Training Accuracy: 77.91%
# Validation Accuracy: 78.31%
# Epoch: 9 	Training Accuracy: 78.17%
# Validation Accuracy: 78.14%
# Epoch: 10 	Training Accuracy: 79.04%
# Validation Accuracy: 78.81%
# Epoch: 11 	Training Accuracy: 80.21%
# Validation Accuracy: 80.33%
# Epoch: 12 	Training Accuracy: 81.06%
# Validation Accuracy: 80.88%
# Epoch: 13 	Training Accuracy: 80.10%
# Validation Accuracy: 79.45%
# Epoch: 14 	Training Accuracy: 80.54%
# Validation Accuracy: 80.69%
# Epoch: 15 	Training Accuracy: 82.26%
# Validation Accuracy: 81.95%
# Epoch: 16 	Training Accuracy: 82.04%
# Validation Accuracy: 81.52%
# Epoch: 17 	Training Accuracy: 82.95%
# Validation Accuracy: 82.19%
# Epoch: 18 	Training Accuracy: 82.95%
# Validation Accuracy: 82.79%
# Epoch: 19 	Training Accuracy: 84.07%
# Validation Accuracy: 83.62%
# Epoch: 20 	Training Accuracy: 81.02%
# Validation Accuracy: 80.88%
# Epoch: 21 	Training Accuracy: 84.55%
# Validation Accuracy: 83.45%
# Epoch: 22 	Training Accuracy: 85.10%
# Validation Accuracy: 84.67%
# Epoch: 23 	Training Accuracy: 84.55%
# Validation Accuracy: 84.33%
# Epoch: 24 	Training Accuracy: 85.46%
# Validation Accuracy: 84.81%
# Epoch: 25 	Training Accuracy: 85.23%
# Validation Accuracy: 84.31%
# Epoch: 26 	Training Accuracy: 85.42%
# Validation Accuracy: 85.17%
# Epoch: 27 	Training Accuracy: 84.67%
# Validation Accuracy: 84.31%
# Epoch: 28 	Training Accuracy: 86.17%
# Validation Accuracy: 85.21%
# Epoch: 29 	Training Accuracy: 86.01%
# Validation Accuracy: 86.12%
# Epoch: 30 	Training Accuracy: 85.08%
# Validation Accuracy: 84.67%
# Epoch: 31 	Training Accuracy: 85.37%
# Validation Accuracy: 84.62%
# Epoch: 32 	Training Accuracy: 86.10%
# Validation Accuracy: 85.79%
# Epoch: 33 	Training Accuracy: 86.65%
# Validation Accuracy: 85.45%
# Epoch: 34 	Training Accuracy: 87.47%
# Validation Accuracy: 86.38%
# Epoch: 35 	Training Accuracy: 87.51%
# Validation Accuracy: 86.52%
# Epoch: 36 	Training Accuracy: 87.30%
# Validation Accuracy: 86.83%
# Epoch: 37 	Training Accuracy: 87.61%
# Validation Accuracy: 86.64%
# Epoch: 38 	Training Accuracy: 87.70%
# Validation Accuracy: 86.64%
# Epoch: 39 	Training Accuracy: 88.07%
# Validation Accuracy: 87.60%
# Final Training Accuracy: 0.8807
# Final Test Accuracy: 0.8802

# %%
torch.save(pretrained_model.state_dict(), 'pretrained_models/pretrained_cifar_arc/pretrained_model_toshoes.pth')

# %%
pretrained_model.load_state_dict(torch.load('pretrained_models/pretrained_cifar_arc/pretrained_model_toshoes.pth'))
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=7, bias=True)
# )

# %%
eval(pretrained_model, device, dataloader_wrapped.val_loader, debug=True, classification_report_flag=True, is_cnn=True)
# Out:
# Average loss: 0.3543, Accuracy: 3679.0/4200 (88%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.86      0.85       560
#      Class 1       0.99      0.97      0.98       638
#      Class 2       0.85      0.86      0.86       595
#      Class 3       0.86      0.94      0.90       615
#      Class 4       0.82      0.83      0.82       579
#      Class 5       0.80      0.69      0.74       626
#      Class 6       0.98      0.98      0.98       587
#
#     accuracy                           0.88      4200
#    macro avg       0.87      0.88      0.87      4200
# weighted avg       0.88      0.88      0.87      4200
# 0.8759523809523809

# %%
# save model for later use
foldername = "pretrained_models/pretrained_normal_classes_new"
os.mkdir(foldername)
torch.save(pretrained_model.state_dict(), os.path.join(foldername, 'pretrained_model.pth'))

params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
#save params as well
with open(os.path.join(foldername, 'params.json'), 'w') as fp:
    json.dump(params_tmp, fp)

# %% [markdown]
# ## Fine-tuning Experiments

# %% [markdown]
# ### Baselines (End-to-end models trained on subsets of fine-tuning dataset)
# We also reuse the baselines a lot! so skip if we already have the jsons

# %%
baselines_results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:      
    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
    
    for repeat in range(repeats):
        # Print or log the sampled values for transparency
        print(f"\nSampled Percentage: {sampled_percentage}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

        # Reduce the dataset
        train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        torch.manual_seed(repeat)
        #train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)

        # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
        params_tmp = copy.deepcopy(params)
        params_tmp["reinit"] = True
        model_new = cut_custom_cnn_model(pretrained_model, cut_point=0, params=params_tmp, output_dim=dataloader_wrapped.output_dim)
        model_new.to(device)

        # Train and evaluate
        trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
        train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
        print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

        # Store the results
        baselines_results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":-1, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc}) # -1 for the cut point means it's baseline
# Out:
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 0

# %%
print(baselines_results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 0, 'train_acc': 0.84, 'test_acc': 0.7092666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 1, 'train_acc': 0.88, 'test_acc': 0.7712333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 2, 'train_acc': 0.84, 'test_acc': 0.7833}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 3, 'train_acc': 0.88, 'test_acc': 0.7267666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 4, 'train_acc': 0.8, 'test_acc': 0.7448333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 5, 'train_acc': 0.84, 'test_acc': 0.6792}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 6, 'train_acc': 0.76, 'test_acc': 0.8136}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 7, 'train_acc': 0.72, 'test_acc': 0.6659666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 8, 'train_acc': 1.0, 'test_acc': 0.8055666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 9, 'train_acc': 0.92, 'test_acc': 0.8003}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 10, 'train_acc': 0.76, 'test_acc': 0.6798}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 11, 'train_acc': 0.88, 'test_acc': 0.6917}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 12, 'train_acc': 0.96, 'test_acc': 0.7715333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 13, 'train_acc': 0.88, 'test_acc': 0.7138}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 14, 'train_acc': 1.0, 'test_acc': 0.7702}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 15, 'train_acc': 1.0, 'test_acc': 0.7759666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 16, 'train_acc': 0.92, 'test_acc': 0.7398}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 17, 'train_acc': 0.92, 'test_acc': 0.8046}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 18, 'train_acc': 1.0, 'test_acc': 0.7866}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 19, 'train_acc': 1.0, 'test_acc': 0.7200666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 20, 'train_acc': 0.88, 'test_acc': 0.7848}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 21, 'train_acc': 0.96, 'test_acc': 0.7947333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 22, 'train_acc': 1.0, 'test_acc': 0.7530666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 23, 'train_acc': 0.68, 'test_acc': 0.7886333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 24, 'train_acc': 1.0, 'test_acc': 0.7819333333333334}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 0, 'train_acc': 0.937037037037037, 'test_acc': 0.8602666666666666}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 1, 'train_acc': 0.8629629629629629, 'test_acc': 0.8554}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 2, 'train_acc': 0.7481481481481481, 'test_acc': 0.7484666666666666}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 3, 'train_acc': 0.8814814814814815, 'test_acc': 0.8557}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 4, 'train_acc': 0.8, 'test_acc': 0.7868}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 5, 'train_acc': 0.8481481481481481, 'test_acc': 0.833466 ...

# %%
# save baseline results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + baselines_results

with open(f'results_jsons/baselines_freeze_{params["freeze"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)

# %% [markdown]
# ### Fine-tuning

# %%
results = []
#percentages = [0.001, 0.01, 0.1, 0.5, 1.0]
percentages = [0.01]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.7840, Test Accuracy: 0.7858
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.7901, Test Accuracy: 0.7963
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.8086, Test Accuracy: 0.7832
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8025, Test Accuracy: 0.7898
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.7593, Test Accuracy: 0.7721
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.8457, Test Accuracy: 0.8469
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.7840, Test Accuracy: 0.7595
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8519, Test Accuracy: 0.8443
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8272, Test Accuracy: 0.8089
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.8333, Test Accuracy: 0.7780
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8580, Test Accuracy: 0.8252
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.7901, Test Accuracy: 0.7702
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.7716, Test Accuracy: 0.7820
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8272, Test Accuracy: 0.7667
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.7654, Test Accuracy: 0.7632
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.8272, Test Accuracy: 0.8294
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.8704, Test Accuracy: 0.8538
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.7963, Test Accuracy: 0.7881
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.7593, Test Accuracy: 0.8167
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.8395, Test Accuracy: 0.8372
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 0.8086, Test Accuracy: 0.8075
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.8704, Test Accuracy: 0.8308
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.8580, Test Accuracy: 0.8182
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 23
# Training Accuracy: 0.8457, Test Accuracy: 0.8308
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.9074, Test Accuracy: 0.8415
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.7346, Test Accuracy: 0.7612
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8642, Test Accuracy: 0.8248
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.8025, Test Accuracy: 0.8011
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8519, Test Accuracy: 0.8213
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.7778, Test Accuracy: 0.7626
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.8395, Test Accuracy: 0.8367
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.7901, Test Accuracy: 0.7687
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.7840, Test Accuracy: 0.7762
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8321
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.8333, Test Accuracy: 0.7813
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8025, Test Accuracy: 0.8081
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8339
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.7654, Test Accuracy: 0.7517
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8210, Test Accuracy: 0.8102
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.7963, Test Accuracy: 0.8007
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.8148, Test Accuracy: 0.8105
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.7778, Test Accuracy: 0.7707
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.8272, Test Accuracy: 0.7973
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.7840, Test Accuracy: 0.8336
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.8086, Test Accuracy: 0.8364
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 20
# Training Accuracy: 0.8642, Test Accuracy: 0.8406
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.8086, Test Accuracy: 0.7805
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.8148, Test Accuracy: 0.7935
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.7716, Test Accuracy: 0.7892
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.9012, Test Accuracy: 0.8445
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9321, Test Accuracy: 0.8613
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8889, Test Accuracy: 0.8724
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.8827, Test Accuracy: 0.8504
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8519, Test Accuracy: 0.8552
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.7840, Test Accuracy: 0.8040
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.8333, Test Accuracy: 0.8276
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.9444, Test Accuracy: 0.8594
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.8827, Test Accuracy: 0.8436
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8420
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.8086, Test Accuracy: 0.7940
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8333, Test Accuracy: 0.8403
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8210, Test Accuracy: 0.8441
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.8210, Test Accuracy: 0.8404
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9074, Test Accuracy: 0.8667
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.8086, Test Accuracy: 0.8304
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.8765, Test Accuracy: 0.8768
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.8519, Test Accuracy: 0.8246
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.8333, Test Accuracy: 0.8082
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.7716, Test Accuracy: 0.7947
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.8086, Test Accuracy: 0.8244
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 20
# Training Accuracy: 0.9012, Test Accuracy: 0.8761
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.8519, Test Accuracy: 0.8324
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.8889, Test Accuracy: 0.8544
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.8148, Test Accuracy: 0.8507
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 0.8889, Test Accuracy: 0.8541
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8272, Test Accuracy: 0.8338
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8726
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9383, Test Accuracy: 0.8893
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8765, Test Accuracy: 0.8643
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9259, Test Accuracy: 0.8859
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.8272, Test Accuracy: 0.8587
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.9321, Test Accuracy: 0.8669
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.8395, Test Accuracy: 0.8197
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8704, Test Accuracy: 0.8438
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8571
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.9321, Test Accuracy: 0.8976
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9198, Test Accuracy: 0.8843
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.8765, Test Accuracy: 0.8768
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8704, Test Accuracy: 0.8643
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.8210, Test Accuracy: 0.8473
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9012, Test Accuracy: 0.8848
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9383, Test Accuracy: 0.8867
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.9074, Test Accuracy: 0.8622
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8676
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.7901, Test Accuracy: 0.8311
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 0.8580, Test Accuracy: 0.8515
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 21
# Training Accuracy: 0.9321, Test Accuracy: 0.8721
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 22
# Training Accuracy: 0.9321, Test Accuracy: 0.8818
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 23
# Training Accuracy: 0.9136, Test Accuracy: 0.8788
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 0.8889, Test Accuracy: 0.8549
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9383, Test Accuracy: 0.8758
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9074, Test Accuracy: 0.8736
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8701
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9444, Test Accuracy: 0.8911
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8457, Test Accuracy: 0.8605
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9568, Test Accuracy: 0.9007
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.8889, Test Accuracy: 0.8552
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.9074, Test Accuracy: 0.8722
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8765, Test Accuracy: 0.8333
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8712
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8565
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8889, Test Accuracy: 0.8924
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.9321, Test Accuracy: 0.8777
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9568, Test Accuracy: 0.8982
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.8889, Test Accuracy: 0.8605
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8677
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9506, Test Accuracy: 0.8884
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9383, Test Accuracy: 0.8838
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9506, Test Accuracy: 0.8969
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.8765, Test Accuracy: 0.8862
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 0.8519, Test Accuracy: 0.8544
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8626
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 22
# Training Accuracy: 0.9506, Test Accuracy: 0.8761
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 23
# Training Accuracy: 0.9383, Test Accuracy: 0.8824
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 0.9198, Test Accuracy: 0.8802
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8629
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9136, Test Accuracy: 0.8914
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8653
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8567
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8333, Test Accuracy: 0.8496
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9630, Test Accuracy: 0.8994
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.8704, Test Accuracy: 0.8510
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.8827, Test Accuracy: 0.8510
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8654
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8665
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8765, Test Accuracy: 0.8652
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.9259, Test Accuracy: 0.9038
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.8704, Test Accuracy: 0.8562
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8759
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.8457, Test Accuracy: 0.8511
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.8272, Test Accuracy: 0.8487
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9568, Test Accuracy: 0.8981
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9691, Test Accuracy: 0.8876
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.8827, Test Accuracy: 0.8692
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.8395, Test Accuracy: 0.8571
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 20
# Training Accuracy: 0.9259, Test Accuracy: 0.9027
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.9506, Test Accuracy: 0.8907
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8696
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.8580, Test Accuracy: 0.8692
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 0.9259, Test Accuracy: 0.8621
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9074, Test Accuracy: 0.8552
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.8457, Test Accuracy: 0.8522
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9383, Test Accuracy: 0.8861
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8519, Test Accuracy: 0.8229
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.8704, Test Accuracy: 0.8712
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.8580, Test Accuracy: 0.8547
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8588
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.8765, Test Accuracy: 0.8588
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8503
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8627
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8765, Test Accuracy: 0.8531
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8517
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8454
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8827, Test Accuracy: 0.8523
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.8025, Test Accuracy: 0.8425
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.8765, Test Accuracy: 0.8643
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9198, Test Accuracy: 0.8704
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.9074, Test Accuracy: 0.8592
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.8519, Test Accuracy: 0.8515
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.8519, Test Accuracy: 0.8484
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8660
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.8580, Test Accuracy: 0.8324
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.8827, Test Accuracy: 0.8513
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.8272, Test Accuracy: 0.8633
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8578

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.7839506172839507, 'test_acc': 0.7858333333333334}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.7901234567901234, 'test_acc': 0.7962777777777778}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.808641975308642, 'test_acc': 0.7831666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.8024691358024691, 'test_acc': 0.7898333333333334}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.7592592592592593, 'test_acc': 0.7720555555555556}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.845679012345679, 'test_acc': 0.8468888888888889}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.7839506172839507, 'test_acc': 0.7595}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.8518518518518519, 'test_acc': 0.8443333333333334}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.8271604938271605, 'test_acc': 0.8089444444444445}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.8333333333333334, 'test_acc': 0.778}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.8580246913580247, 'test_acc': 0.8251666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.7901234567901234, 'test_acc': 0.7702222222222223}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.7716049382716049, 'test_acc': 0.782}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.8271604938271605, 'test_acc': 0.7667222222222222}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.7654320987654321, 'test_acc': 0.7632222222222222}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.8271604938271605, 'test_acc': 0.8294444444444444}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.8703703703703703, 'test_acc': 0.8538333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.7962962962962963, 'test_acc': 0.7880555555555555}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.7592592592592593, 'test_acc': 0.8167222222222222}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.8395061728395061, 'test_acc': 0.8371666666666666}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 20, 'train_acc': 0.808641975308642, 'test_acc': 0.8075}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 21, 'train_acc': 0.8703703703703703, 'test_acc': 0.8307777777777777}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 22, 'train_acc': 0.8580246913580247, 'test_acc': 0.8182222222222222}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 23, 'train_acc': 0.845679012345679, 'test_acc': 0.8308333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 24, 'train_acc': 0.9074074074074074, 'test_acc': 0.8415}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.7345679012345679, 'test_acc': 0.7611666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.8641975308641975, 'test_acc': 0.8248333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.8024691358024691, 'test_acc': 0.801055555 ...

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.7839506172839507, 'test_acc': 0.7858333333333334}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.7901234567901234, 'test_acc': 0.7962777777777778}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.808641975308642, 'test_acc': 0.7831666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.8024691358024691, 'test_acc': 0.7898333333333334}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.7592592592592593, 'test_acc': 0.7720555555555556}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.845679012345679, 'test_acc': 0.8468888888888889}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.7839506172839507, 'test_acc': 0.7595}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.8518518518518519, 'test_acc': 0.8443333333333334}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.8271604938271605, 'test_acc': 0.8089444444444445}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.8333333333333334, 'test_acc': 0.778}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.8580246913580247, 'test_acc': 0.8251666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.7901234567901234, 'test_acc': 0.7702222222222223}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.7716049382716049, 'test_acc': 0.782}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.8271604938271605, 'test_acc': 0.7667222222222222}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.7654320987654321, 'test_acc': 0.7632222222222222}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.8271604938271605, 'test_acc': 0.8294444444444444}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.8703703703703703, 'test_acc': 0.8538333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.7962962962962963, 'test_acc': 0.7880555555555555}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.7592592592592593, 'test_acc': 0.8167222222222222}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.8395061728395061, 'test_acc': 0.8371666666666666}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 20, 'train_acc': 0.808641975308642, 'test_acc': 0.8075}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 21, 'train_acc': 0.8703703703703703, 'test_acc': 0.8307777777777777}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 22, 'train_acc': 0.8580246913580247, 'test_acc': 0.8182222222222222}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 23, 'train_acc': 0.845679012345679, 'test_acc': 0.8308333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 24, 'train_acc': 0.9074074074074074, 'test_acc': 0.8415}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.7345679012345679, 'test_acc': 0.7611666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.8641975308641975, 'test_acc': 0.8248333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.8024691358024691, 'test_acc': 0.801055555 ...

# %%
# save fine-tuning results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/results_freeze_{params["freeze"]}_reinit_{params["reinit"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)
results = results[1:]

# %% [markdown]
# # Example for:
# Transfer Learning Empirical Experiment from all other classes of FashionMNIST to shoes (Sandal, Sneaker, Ankle boot) classes in FashionMNIST

# %% [markdown]
# ### Setup and Hyperparams

# %%
# Specify which gpu
import os
gpu_id = 5
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

import sys
sys.path.append('/home/arnisaf/mp-tl-study')
from functions.utils import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.cuda.manual_seed_all(0)  # if using multi-GPU

# %%
# cuts=0 means: end-to-end model if we are reinitializing
cuts = [0,1,2,3,4,5,6]

# %%
# Changes Here for the experiments
params = {
      # MODEL ARCHITECTURE PARAMS
      'depth': 6,
      'num_channels': 64, # num channels for CNN
      'two_linear_layers': False,
      'hidden_dim_lin': 128,  # if two_linear_layers == True
      'activation_function': nn.ReLU,
      'kernel_size': 3,
      # TRAINING PARAMS
      'device': device,
      'lr_pretrain': 0.001,   
      'lr_fine_tune': 0.001,  # CHANGE: if no layer-wise lr
      'num_train': 40,
      'early_stop_patience': 6,
      'save_best': False,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': False,
      'classification_report_flag': False,
      'batch_size':4096,
      # DATASET PARAMS
      'pre_train_classes': [0, 1, 2, 3, 4, 6, 8],
      'fine_tune_classes': [5, 7, 9],
      'val_split': 0.1,
      'num_workers': 0,
      'generate_dataset_seed': 42,
      # EXPERIMENT SETTING PARAMS
      'use_pooling': True,   # CHANGE
      'pooling_every_n_layers': 2, # add pooling after every n layers specified here. For only one pooling after all the CNN layers, this equals params['depth']
      # default value for pooling_every_n_layers is 1 (after each cnn layer)
      'pooling_stride': 2,
      'freeze': True,         # CHANGE: freeze the conv layers before the cut
      'reinit': True,         # CHANGE: reinit the conv lyers only after the cut
      'reinit_both_dense': True   # CHANGE: True for reinitialize both dense layers, False for reinit only the last dense layer
    }

# %%
root_dir = './data'  # Specify your data directory here
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
dataloader_wrapped = TransferLearningWrapper(params, datasets.FashionMNIST, datasets.FashionMNIST, root_dir, transform=transform)## Pretraining

# %%
dataloader_wrapped.pretrain_train_loader.dataset.__len__()
# Out:
# 37800

# %% [markdown]
# ## Pretraining

# %%
#Create DNN model
pretrained_model = CustomCNN(params, dataloader_wrapped.output_dim)
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=7, bias=True)
# )

# %%
# Train and evaluate - Skip if loading saved model!
trainer = Trainer(pretrained_model, dataloader_wrapped, params["lr_pretrain"], params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 52.15%
# Validation Accuracy: 51.71%
# Epoch: 1 	Training Accuracy: 59.28%
# Validation Accuracy: 59.00%
# Epoch: 2 	Training Accuracy: 64.52%
# Validation Accuracy: 63.98%
# Epoch: 3 	Training Accuracy: 69.87%
# Validation Accuracy: 69.69%
# Epoch: 4 	Training Accuracy: 74.66%
# Validation Accuracy: 74.33%
# Epoch: 5 	Training Accuracy: 74.02%
# Validation Accuracy: 73.71%
# Epoch: 6 	Training Accuracy: 74.74%
# Validation Accuracy: 75.00%
# Epoch: 7 	Training Accuracy: 77.03%
# Validation Accuracy: 77.19%
# Epoch: 8 	Training Accuracy: 77.91%
# Validation Accuracy: 78.31%
# Epoch: 9 	Training Accuracy: 78.17%
# Validation Accuracy: 78.14%
# Epoch: 10 	Training Accuracy: 79.04%
# Validation Accuracy: 78.81%
# Epoch: 11 	Training Accuracy: 80.21%
# Validation Accuracy: 80.33%
# Epoch: 12 	Training Accuracy: 81.06%
# Validation Accuracy: 80.88%
# Epoch: 13 	Training Accuracy: 80.10%
# Validation Accuracy: 79.45%
# Epoch: 14 	Training Accuracy: 80.54%
# Validation Accuracy: 80.69%
# Epoch: 15 	Training Accuracy: 82.26%
# Validation Accuracy: 81.95%
# Epoch: 16 	Training Accuracy: 82.04%
# Validation Accuracy: 81.52%
# Epoch: 17 	Training Accuracy: 82.95%
# Validation Accuracy: 82.19%
# Epoch: 18 	Training Accuracy: 82.95%
# Validation Accuracy: 82.79%
# Epoch: 19 	Training Accuracy: 84.07%
# Validation Accuracy: 83.62%
# Epoch: 20 	Training Accuracy: 81.02%
# Validation Accuracy: 80.88%
# Epoch: 21 	Training Accuracy: 84.55%
# Validation Accuracy: 83.45%
# Epoch: 22 	Training Accuracy: 85.10%
# Validation Accuracy: 84.67%
# Epoch: 23 	Training Accuracy: 84.55%
# Validation Accuracy: 84.33%
# Epoch: 24 	Training Accuracy: 85.46%
# Validation Accuracy: 84.81%
# Epoch: 25 	Training Accuracy: 85.23%
# Validation Accuracy: 84.31%
# Epoch: 26 	Training Accuracy: 85.42%
# Validation Accuracy: 85.17%
# Epoch: 27 	Training Accuracy: 84.67%
# Validation Accuracy: 84.31%
# Epoch: 28 	Training Accuracy: 86.17%
# Validation Accuracy: 85.21%
# Epoch: 29 	Training Accuracy: 86.01%
# Validation Accuracy: 86.12%
# Epoch: 30 	Training Accuracy: 85.08%
# Validation Accuracy: 84.67%
# Epoch: 31 	Training Accuracy: 85.37%
# Validation Accuracy: 84.62%
# Epoch: 32 	Training Accuracy: 86.10%
# Validation Accuracy: 85.79%
# Epoch: 33 	Training Accuracy: 86.65%
# Validation Accuracy: 85.45%
# Epoch: 34 	Training Accuracy: 87.47%
# Validation Accuracy: 86.38%
# Epoch: 35 	Training Accuracy: 87.51%
# Validation Accuracy: 86.52%
# Epoch: 36 	Training Accuracy: 87.30%
# Validation Accuracy: 86.83%
# Epoch: 37 	Training Accuracy: 87.61%
# Validation Accuracy: 86.64%
# Epoch: 38 	Training Accuracy: 87.70%
# Validation Accuracy: 86.64%
# Epoch: 39 	Training Accuracy: 88.07%
# Validation Accuracy: 87.60%
# Final Training Accuracy: 0.8807
# Final Test Accuracy: 0.8802

# %%
torch.save(pretrained_model.state_dict(), 'pretrained_models/pretrained_cifar_arc/pretrained_model_toshoes.pth')

# %%
pretrained_model.load_state_dict(torch.load('pretrained_models/pretrained_cifar_arc/pretrained_model_toshoes.pth'))
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=7, bias=True)
# )

# %%
eval(pretrained_model, device, dataloader_wrapped.val_loader, debug=True, classification_report_flag=True, is_cnn=True)
# Out:
# Average loss: 0.3543, Accuracy: 3679.0/4200 (88%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.86      0.85       560
#      Class 1       0.99      0.97      0.98       638
#      Class 2       0.85      0.86      0.86       595
#      Class 3       0.86      0.94      0.90       615
#      Class 4       0.82      0.83      0.82       579
#      Class 5       0.80      0.69      0.74       626
#      Class 6       0.98      0.98      0.98       587
#
#     accuracy                           0.88      4200
#    macro avg       0.87      0.88      0.87      4200
# weighted avg       0.88      0.88      0.87      4200
# 0.8759523809523809

# %%
# save model for later use
foldername = "pretrained_models/pretrained_normal_classes_new"
os.mkdir(foldername)
torch.save(pretrained_model.state_dict(), os.path.join(foldername, 'pretrained_model.pth'))

params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
#save params as well
with open(os.path.join(foldername, 'params.json'), 'w') as fp:
    json.dump(params_tmp, fp)

# %% [markdown]
# ## Fine-tuning Experiments

# %% [markdown]
# ### Baselines (End-to-end models trained on subsets of fine-tuning dataset)
# We also reuse the baselines a lot! so skip if we already have the jsons

# %%
baselines_results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:      
    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
    
    for repeat in range(repeats):
        # Print or log the sampled values for transparency
        print(f"\nSampled Percentage: {sampled_percentage}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

        # Reduce the dataset
        train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        torch.manual_seed(repeat)
        #train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)

        # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
        params_tmp = copy.deepcopy(params)
        params_tmp["reinit"] = True
        model_new = cut_custom_cnn_model(pretrained_model, cut_point=0, params=params_tmp, output_dim=dataloader_wrapped.output_dim)
        model_new.to(device)

        # Train and evaluate
        trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
        train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
        print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

        # Store the results
        baselines_results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":-1, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc}) # -1 for the cut point means it's baseline
# Out:
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 0

# %%
print(baselines_results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 0, 'train_acc': 0.84, 'test_acc': 0.7092666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 1, 'train_acc': 0.88, 'test_acc': 0.7712333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 2, 'train_acc': 0.84, 'test_acc': 0.7833}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 3, 'train_acc': 0.88, 'test_acc': 0.7267666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 4, 'train_acc': 0.8, 'test_acc': 0.7448333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 5, 'train_acc': 0.84, 'test_acc': 0.6792}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 6, 'train_acc': 0.76, 'test_acc': 0.8136}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 7, 'train_acc': 0.72, 'test_acc': 0.6659666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 8, 'train_acc': 1.0, 'test_acc': 0.8055666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 9, 'train_acc': 0.92, 'test_acc': 0.8003}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 10, 'train_acc': 0.76, 'test_acc': 0.6798}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 11, 'train_acc': 0.88, 'test_acc': 0.6917}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 12, 'train_acc': 0.96, 'test_acc': 0.7715333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 13, 'train_acc': 0.88, 'test_acc': 0.7138}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 14, 'train_acc': 1.0, 'test_acc': 0.7702}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 15, 'train_acc': 1.0, 'test_acc': 0.7759666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 16, 'train_acc': 0.92, 'test_acc': 0.7398}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 17, 'train_acc': 0.92, 'test_acc': 0.8046}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 18, 'train_acc': 1.0, 'test_acc': 0.7866}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 19, 'train_acc': 1.0, 'test_acc': 0.7200666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 20, 'train_acc': 0.88, 'test_acc': 0.7848}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 21, 'train_acc': 0.96, 'test_acc': 0.7947333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 22, 'train_acc': 1.0, 'test_acc': 0.7530666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 23, 'train_acc': 0.68, 'test_acc': 0.7886333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': -1, 'repeat': 24, 'train_acc': 1.0, 'test_acc': 0.7819333333333334}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 0, 'train_acc': 0.937037037037037, 'test_acc': 0.8602666666666666}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 1, 'train_acc': 0.8629629629629629, 'test_acc': 0.8554}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 2, 'train_acc': 0.7481481481481481, 'test_acc': 0.7484666666666666}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 3, 'train_acc': 0.8814814814814815, 'test_acc': 0.8557}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 4, 'train_acc': 0.8, 'test_acc': 0.7868}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': -1, 'repeat': 5, 'train_acc': 0.8481481481481481, 'test_acc': 0.833466 ...

# %%
# save baseline results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + baselines_results

with open(f'results_jsons/baselines_freeze_{params["freeze"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)

# %% [markdown]
# ### Fine-tuning

# %%
results = []
#percentages = [0.001, 0.01, 0.1, 0.5, 1.0]
percentages = [0.1]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8488, Test Accuracy: 0.8469
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8531, Test Accuracy: 0.8434
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.7722, Test Accuracy: 0.7763
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8327, Test Accuracy: 0.8272
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.7488, Test Accuracy: 0.7597
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.8438, Test Accuracy: 0.8553
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.7574, Test Accuracy: 0.7421
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8457, Test Accuracy: 0.8425
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.7451, Test Accuracy: 0.7429
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.8574, Test Accuracy: 0.8510
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.8568, Test Accuracy: 0.8387
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.7531, Test Accuracy: 0.7797
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.7722, Test Accuracy: 0.7839
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.7858, Test Accuracy: 0.7669
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.7617, Test Accuracy: 0.7718
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.8377, Test Accuracy: 0.8372
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.8728, Test Accuracy: 0.8603
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.7827, Test Accuracy: 0.7854
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.7654, Test Accuracy: 0.7621
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.8383, Test Accuracy: 0.8364
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.7420, Test Accuracy: 0.7575
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8691, Test Accuracy: 0.8639
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.8062, Test Accuracy: 0.8071
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8333, Test Accuracy: 0.8296
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.8309, Test Accuracy: 0.8441
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.8500, Test Accuracy: 0.8534
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.7772, Test Accuracy: 0.7647
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8494, Test Accuracy: 0.8514
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.8537, Test Accuracy: 0.8582
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.7840, Test Accuracy: 0.7866
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8438, Test Accuracy: 0.8306
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.8543, Test Accuracy: 0.8582
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.7488, Test Accuracy: 0.7586
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8191, Test Accuracy: 0.8057
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.8006, Test Accuracy: 0.8047
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.8512, Test Accuracy: 0.8457
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.7778, Test Accuracy: 0.7764
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.7926, Test Accuracy: 0.7881
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.8438, Test Accuracy: 0.8371
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.8519, Test Accuracy: 0.8526
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8802, Test Accuracy: 0.8732
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8722, Test Accuracy: 0.8682
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8698, Test Accuracy: 0.8663
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8735, Test Accuracy: 0.8725
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.7895, Test Accuracy: 0.8061
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.8160, Test Accuracy: 0.8113
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.8130, Test Accuracy: 0.7998
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8833, Test Accuracy: 0.8750
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8043, Test Accuracy: 0.8063
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.7957, Test Accuracy: 0.7962
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8401, Test Accuracy: 0.8277
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8117, Test Accuracy: 0.8326
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.8778, Test Accuracy: 0.8821
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8488, Test Accuracy: 0.8338
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.8660, Test Accuracy: 0.8596
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.8352, Test Accuracy: 0.8274
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.8389, Test Accuracy: 0.8357
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.7827, Test Accuracy: 0.7771
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.8667, Test Accuracy: 0.8624
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.7605, Test Accuracy: 0.7638
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8951, Test Accuracy: 0.8889
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8932, Test Accuracy: 0.8973
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9025, Test Accuracy: 0.8992
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8926, Test Accuracy: 0.8943
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.8802, Test Accuracy: 0.8767
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.8469, Test Accuracy: 0.8584
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.8586, Test Accuracy: 0.8522
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.8599, Test Accuracy: 0.8574
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.9012, Test Accuracy: 0.8957
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.8370, Test Accuracy: 0.8385
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8377, Test Accuracy: 0.8360
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.8944, Test Accuracy: 0.8928
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.8796, Test Accuracy: 0.8838
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9247, Test Accuracy: 0.9036
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.8198, Test Accuracy: 0.8196
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.8377, Test Accuracy: 0.8335
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9043, Test Accuracy: 0.8976
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9000, Test Accuracy: 0.9063
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.8512, Test Accuracy: 0.8424
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.9025, Test Accuracy: 0.8948
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9105, Test Accuracy: 0.9062
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9099, Test Accuracy: 0.9028
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9080, Test Accuracy: 0.9060
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9019, Test Accuracy: 0.8987
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8549, Test Accuracy: 0.8547
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9136, Test Accuracy: 0.9040
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9198, Test Accuracy: 0.9081
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.9123, Test Accuracy: 0.9086
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.9062, Test Accuracy: 0.9006
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9105, Test Accuracy: 0.9036
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8679, Test Accuracy: 0.8586
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8278, Test Accuracy: 0.8421
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.8340, Test Accuracy: 0.8362
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8636, Test Accuracy: 0.8524
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9012, Test Accuracy: 0.9080
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9167, Test Accuracy: 0.9109
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.8574, Test Accuracy: 0.8526
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9000, Test Accuracy: 0.9063
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.8556, Test Accuracy: 0.8515
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.8648, Test Accuracy: 0.8569
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8623, Test Accuracy: 0.8639
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.8802, Test Accuracy: 0.8758
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9117, Test Accuracy: 0.9081
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.8641
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8438, Test Accuracy: 0.8451
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.8636, Test Accuracy: 0.8707
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.8673, Test Accuracy: 0.8681
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.8543, Test Accuracy: 0.8558
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8796, Test Accuracy: 0.8743
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9019, Test Accuracy: 0.8967
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8685, Test Accuracy: 0.8603
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8500, Test Accuracy: 0.8645
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.8580, Test Accuracy: 0.8583
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8809, Test Accuracy: 0.8650
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.8858, Test Accuracy: 0.8852
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9049, Test Accuracy: 0.9022
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.8765, Test Accuracy: 0.8678
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9105, Test Accuracy: 0.9142
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.8691, Test Accuracy: 0.8707
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.8784, Test Accuracy: 0.8677
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8704, Test Accuracy: 0.8726
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.8444, Test Accuracy: 0.8526
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8914, Test Accuracy: 0.8897
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8321, Test Accuracy: 0.8324
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8494, Test Accuracy: 0.8536
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.8506, Test Accuracy: 0.8549
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.8654, Test Accuracy: 0.8599
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.8420, Test Accuracy: 0.8439
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8531, Test Accuracy: 0.8516
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.8877, Test Accuracy: 0.8754
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.8529
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8525, Test Accuracy: 0.8608
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.8623, Test Accuracy: 0.8632
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.8907, Test Accuracy: 0.8731
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.8432, Test Accuracy: 0.8422
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.8426, Test Accuracy: 0.8379
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.8501
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.8660, Test Accuracy: 0.8787
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.8383, Test Accuracy: 0.8451
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.8469, Test Accuracy: 0.8521

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.8487654320987654, 'test_acc': 0.8469444444444445}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.8530864197530864, 'test_acc': 0.8434444444444444}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.7722222222222223, 'test_acc': 0.7762777777777777}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.832716049382716, 'test_acc': 0.8271666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.7487654320987654, 'test_acc': 0.7597222222222222}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.8438271604938271, 'test_acc': 0.8552777777777778}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.7574074074074074, 'test_acc': 0.7420555555555556}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.845679012345679, 'test_acc': 0.8425}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.7450617283950617, 'test_acc': 0.7429444444444444}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.8574074074074074, 'test_acc': 0.851}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.8567901234567902, 'test_acc': 0.8386666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.7530864197530864, 'test_acc': 0.7797222222222222}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.7722222222222223, 'test_acc': 0.7838888888888889}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.7858024691358024, 'test_acc': 0.7668888888888888}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.7617283950617284, 'test_acc': 0.7717777777777778}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.8376543209876544, 'test_acc': 0.8371666666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.8728395061728395, 'test_acc': 0.8602777777777778}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.782716049382716, 'test_acc': 0.7853888888888889}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.7654320987654321, 'test_acc': 0.7621111111111111}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.8382716049382716, 'test_acc': 0.8364444444444444}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.7419753086419754, 'test_acc': 0.7575}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.8691358024691358, 'test_acc': 0.8639444444444444}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.8061728395061728, 'test_acc': 0.8070555555555555}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 3, 'train_acc': 0.8333333333333334, 'test_acc': 0.8296111111111111}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 4, 'train_acc': 0.8308641975308642, 'test_acc': 0.8441111111111111}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 5, 'train_acc': 0.85, 'test_acc': 0.8534444444444444}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 6, 'train_acc': 0.7771604938271605, 'test_acc': 0.7646666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 7, 'train_acc': 0.8493827160493828, 'test_acc': 0.8514444444444444}, {'lr': 0.00 ...

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.8487654320987654, 'test_acc': 0.8469444444444445}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.8530864197530864, 'test_acc': 0.8434444444444444}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.7722222222222223, 'test_acc': 0.7762777777777777}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.832716049382716, 'test_acc': 0.8271666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.7487654320987654, 'test_acc': 0.7597222222222222}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.8438271604938271, 'test_acc': 0.8552777777777778}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.7574074074074074, 'test_acc': 0.7420555555555556}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.845679012345679, 'test_acc': 0.8425}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.7450617283950617, 'test_acc': 0.7429444444444444}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.8574074074074074, 'test_acc': 0.851}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.8567901234567902, 'test_acc': 0.8386666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.7530864197530864, 'test_acc': 0.7797222222222222}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.7722222222222223, 'test_acc': 0.7838888888888889}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.7858024691358024, 'test_acc': 0.7668888888888888}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.7617283950617284, 'test_acc': 0.7717777777777778}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.8376543209876544, 'test_acc': 0.8371666666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.8728395061728395, 'test_acc': 0.8602777777777778}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.782716049382716, 'test_acc': 0.7853888888888889}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.7654320987654321, 'test_acc': 0.7621111111111111}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.8382716049382716, 'test_acc': 0.8364444444444444}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.7419753086419754, 'test_acc': 0.7575}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.8691358024691358, 'test_acc': 0.8639444444444444}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.8061728395061728, 'test_acc': 0.8070555555555555}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 3, 'train_acc': 0.8333333333333334, 'test_acc': 0.8296111111111111}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 4, 'train_acc': 0.8308641975308642, 'test_acc': 0.8441111111111111}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 5, 'train_acc': 0.85, 'test_acc': 0.8534444444444444}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 6, 'train_acc': 0.7771604938271605, 'test_acc': 0.7646666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 7, 'train_acc': 0.8493827160493828, 'test_acc': 0.8514444444444444}, {'lr': 0.00 ...

# %%
# save fine-tuning results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/results_freeze_{params["freeze"]}_reinit_{params["reinit"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)
results = results[1:]

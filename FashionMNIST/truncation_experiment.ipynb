# %% [markdown]
# # Example for:
# Transfer Learning Truncating Experiment from random classes of FashionMNIST ([0, 1, 2, 4, 6, 7, 9]) to rest of the classes ([3, 5, 8]) in FashionMNIST, where instead of reinitializing the CNN layers after the cut, we remove them.

# %% [markdown]
# ### Setup and Hyperparams

# %%
# Specify which gpu
import os
gpu_id = 1
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

import sys
sys.path.append('/home/arnisaf/mp-tl-study')
from functions.utils import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.cuda.manual_seed_all(0)  # if using multi-GPU
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 import sys
#       7 sys.path.append('/home/arnisaf/mp-tl-study')
# ----> 8 from functions.utils import *
#      10 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      12 np.random.seed(0)
#
# ModuleNotFoundError: No module named 'functions'

# %%
# cuts=0 means: end-to-end model if we are reinitializing
cuts = [0,1,2,3, 4, 5]

# %%
# Changes Here for the experiments
params = {
      # MODEL ARCHITECTURE PARAMS
      'depth': 5,
      'num_channels': 30, # num channels for CNN
      # 'hidden_dim_lin': 128,
      'activation_function': nn.ReLU,
      'kernel_size': 3,
      # TRAINING PARAMS
      'device': device,
      'lr_pretrain': 0.001,   
      'lr_fine_tune': 0.001,  # CHANGE: if no layer-wise lr
      # 'lr_fine_tune_reinit': 0.001,         # CHANGE: if no layer-wise lr
      # 'lr_fine_tune_no_reinit': 0.0001,     # CHANGE: if layer-wise lr
      'num_train': 40,
      'early_stop_patience': 6,
      'save_best': False,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': False,
      'classification_report_flag': False,
      'batch_size':4096,
      # DATASET PARAMS
      'pre_train_classes': [0, 1, 2, 4, 6, 7, 9],
      'fine_tune_classes': [3, 5, 8],
      'val_split': 0.1,
      'num_workers': 0,
      'generate_dataset_seed': 42,
      # EXPERIMENT SETTING PARAMS
      'use_pooling': False,   # CHANGE
      'pooling_every_n_layers': 5, # add pooling after every n layers specified here. For only one pooling after all the CNN layers, this equals params['depth']
      'pooling_stride': 2,
      'freeze': True,         # CHANGE: freeze the conv layers before the cut
      'reinit': True,         # CHANGE: reinit the conv lyers only after the cut
      'truncate': True,
      'reinit_both_dense': True   # CHANGE: True for reinitialize both dense layers, False for reinit only the last dense layer
    }

# %%
root_dir = './data'  # Specify your data directory here
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
dataloader_wrapped = TransferLearningWrapper(params, datasets.FashionMNIST, datasets.FashionMNIST, root_dir, transform=transform)## Pretraining

# %% [markdown]
# ## Pretraining

# %%
#Create DNN model
pretrained_model = CustomCNN(params, dataloader_wrapped.output_dim)
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (conv2): Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (conv4): Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (fc): Linear(in_features=23520, out_features=7, bias=True)
# )

# %%
# Train and evaluate - Skip if loading saved model!
trainer = Trainer(pretrained_model, dataloader_wrapped, params["lr_pretrain"], params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 73.09%
# Validation Accuracy: 72.52%
# Epoch: 1 	Training Accuracy: 78.11%
# Validation Accuracy: 78.24%
# Epoch: 2 	Training Accuracy: 82.51%
# Validation Accuracy: 82.45%
# Epoch: 3 	Training Accuracy: 84.25%
# Validation Accuracy: 83.74%
# Epoch: 4 	Training Accuracy: 85.15%
# Validation Accuracy: 84.57%
# Epoch: 5 	Training Accuracy: 86.51%
# Validation Accuracy: 86.02%
# Epoch: 6 	Training Accuracy: 86.73%
# Validation Accuracy: 86.10%
# Epoch: 7 	Training Accuracy: 87.59%
# Validation Accuracy: 87.48%
# Epoch: 8 	Training Accuracy: 88.53%
# Validation Accuracy: 87.90%
# Epoch: 9 	Training Accuracy: 88.05%
# Validation Accuracy: 87.19%
# Epoch: 10 	Training Accuracy: 88.95%
# Validation Accuracy: 88.74%
# Epoch: 11 	Training Accuracy: 89.33%
# Validation Accuracy: 88.83%
# Epoch: 12 	Training Accuracy: 89.19%
# Validation Accuracy: 88.50%
# Epoch: 13 	Training Accuracy: 89.33%
# Validation Accuracy: 88.90%
# Epoch: 14 	Training Accuracy: 89.04%
# Validation Accuracy: 88.52%
# Epoch: 15 	Training Accuracy: 88.69%
# Validation Accuracy: 88.45%
# Epoch: 16 	Training Accuracy: 90.16%
# Validation Accuracy: 89.21%
# Epoch: 17 	Training Accuracy: 90.65%
# Validation Accuracy: 89.76%
# Epoch: 18 	Training Accuracy: 90.66%
# Validation Accuracy: 90.19%
# Epoch: 19 	Training Accuracy: 90.80%
# Validation Accuracy: 89.71%
# Epoch: 20 	Training Accuracy: 91.00%
# Validation Accuracy: 89.88%
# Epoch: 21 	Training Accuracy: 91.08%
# Validation Accuracy: 89.88%
# Epoch: 22 	Training Accuracy: 90.39%
# Validation Accuracy: 89.52%
# Epoch: 23 	Training Accuracy: 91.09%
# Validation Accuracy: 89.76%
# Epoch: 24 	Training Accuracy: 91.35%
# Validation Accuracy: 90.45%
# Epoch: 25 	Training Accuracy: 91.34%
# Validation Accuracy: 89.88%
# Epoch: 26 	Training Accuracy: 91.98%
# Validation Accuracy: 90.19%
# Epoch: 27 	Training Accuracy: 91.83%
# Validation Accuracy: 89.98%
# Epoch: 28 	Training Accuracy: 91.99%
# Validation Accuracy: 90.19%
# Epoch: 29 	Training Accuracy: 91.43%
# Validation Accuracy: 89.71%
# Epoch: 30 	Training Accuracy: 92.62%
# Validation Accuracy: 90.67%
# Epoch: 31 	Training Accuracy: 92.48%
# Validation Accuracy: 90.17%
# Epoch: 32 	Training Accuracy: 92.57%
# Validation Accuracy: 90.26%
# Epoch: 33 	Training Accuracy: 92.90%
# Validation Accuracy: 90.81%
# Epoch: 34 	Training Accuracy: 92.54%
# Validation Accuracy: 90.19%
# Epoch: 35 	Training Accuracy: 93.08%
# Validation Accuracy: 90.74%
# Epoch: 36 	Training Accuracy: 93.44%
# Validation Accuracy: 90.74%
# Epoch: 37 	Training Accuracy: 93.37%
# Validation Accuracy: 90.93%
# Epoch: 38 	Training Accuracy: 93.56%
# Validation Accuracy: 90.83%
# Epoch: 39 	Training Accuracy: 93.15%
# Validation Accuracy: 90.64%
# Final Training Accuracy: 0.9315
# Final Test Accuracy: 0.9290

# %%
pretrained_model.load_state_dict(torch.load('pretrained_models/pretrained_random_classes_5_layers/pretrained_model.pth'))
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (conv2): Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (conv4): Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (fc): Linear(in_features=23520, out_features=7, bias=True)
# )

# %%
eval(pretrained_model, device, dataloader_wrapped.val_loader, debug=True, classification_report_flag=True, is_cnn=True)
# Out:
# Average loss: 0.2632, Accuracy: 3807.0/4200 (91%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.90      0.87      0.88       603
#      Class 1       1.00      0.98      0.99       645
#      Class 2       0.89      0.83      0.86       592
#      Class 3       0.83      0.94      0.89       600
#      Class 4       0.80      0.79      0.79       588
#      Class 5       0.95      0.98      0.96       581
#      Class 6       0.98      0.95      0.96       591
#
#     accuracy                           0.91      4200
#    macro avg       0.91      0.91      0.91      4200
# weighted avg       0.91      0.91      0.91      4200
# 0.9064285714285715

# %%
# save model for later use
foldername = "pretrained_models/pretrained_random_classes_5_layers"
os.mkdir(foldername)
torch.save(pretrained_model.state_dict(), os.path.join(foldername, 'pretrained_model.pth'))

params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
#save params as well
with open(os.path.join(foldername, 'params.json'), 'w') as fp:
    json.dump(params_tmp, fp)

# %% [markdown]
# ## Fine-tuning Experiments

# %% [markdown]
# ### Baselines (End-to-end models trained on subsets of fine-tuning dataset)
# We also reuse the baselines a lot! so skip if we already have the jsons

# %%
baselines_results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:      
    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
    
    for repeat in range(repeats):
        # Print or log the sampled values for transparency
        print(f"\nSampled Percentage: {sampled_percentage}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

        # Reduce the dataset
        train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        torch.manual_seed(repeat)
        #train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)

        # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
        params_tmp = copy.deepcopy(params)
        params_tmp["reinit"] = True
        model_new = cut_custom_cnn_model(pretrained_model, cut_point=0, params=params_tmp, output_dim=dataloader_wrapped.output_dim)
        model_new.to(device)

        # Train and evaluate
        trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
        train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
        print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

        # Store the results
        baselines_results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":-1, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc}) # -1 for the cut point means it's baseline
# Out:
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.8100
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.7890
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.8080
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.8120
#
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.8063
#
# Sampled Percentage: 0.002, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9667, Test Accuracy: 0.8487
#
# Sampled Percentage: 0.002, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.8003
#
# Sampled Percentage: 0.002, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.8033
#
# Sampled Percentage: 0.002, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.8470
#
# Sampled Percentage: 0.002, Lr: 0.001, Repeat: 4
# Training Accuracy: 1.0000, Test Accuracy: 0.8337
#
# Sampled Percentage: 0.005, Lr: 0.001, Repeat: 0
# Training Accuracy: 1.0000, Test Accuracy: 0.8680
#
# Sampled Percentage: 0.005, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8567
#
# Sampled Percentage: 0.005, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9877, Test Accuracy: 0.8653
#
# Sampled Percentage: 0.005, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8889, Test Accuracy: 0.8597
#
# Sampled Percentage: 0.005, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9383, Test Accuracy: 0.8503
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8380
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9198, Test Accuracy: 0.8613
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9691, Test Accuracy: 0.8927
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8573
#
# Sampled Percentage: 0.01, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8667
#
# Sampled Percentage: 0.05, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9235, Test Accuracy: 0.8980
#
# Sampled Percentage: 0.05, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9272, Test Accuracy: 0.9077
#
# Sampled Percentage: 0.05, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9284, Test Accuracy: 0.9160
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9148, Test Accuracy: 0.9143
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8728, Test Accuracy: 0.8713
#
# Sampled Percentage: 0.1, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8969, Test Accuracy: 0.9003
#
# Sampled Percentage: 0.3, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9531, Test Accuracy: 0.9447
#
# Sampled Percentage: 0.3, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9558, Test Accuracy: 0.9477
#
# Sampled Percentage: 0.3, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9444, Test Accuracy: 0.9440
#
# Sampled Percentage: 0.5, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9502, Test Accuracy: 0.9463
#
# Sampled Percentage: 0.8, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9624, Test Accuracy: 0.9567
#
# Sampled Percentage: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9714, Test Accuracy: 0.9647

# %%
# save baseline results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + baselines_results

with open(f'results_jsons/baselines_freeze_{params["freeze"]}_reinit_{params["reinit"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)

# %% [markdown]
# ### Fine-tuning

# %%
results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.8100
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.7890
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.8080
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.8120
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.8073
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.7803
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8127
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.7670
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.8157
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.8010
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.7733
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.8170
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.8457
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.8533
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8380
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8240
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.8573
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8237
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.8540
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8833
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.7563
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8143
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8113
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8063
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8417
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Training Accuracy: 1.0000, Test Accuracy: 0.7780
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.7280
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8310
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9333, Test Accuracy: 0.8043
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8387
#
# Sampled Percentage: 0.002, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9667, Test Accuracy: 0.8487
#
# Sampled Percentage: 0.002, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.8003
#
# Sampled Percentage: 0.002, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.8033
#
# Sampled Percentage: 0.002, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8597
#
# Sampled Percentage: 0.002, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9667, Test Accuracy: 0.8360
#
# Sampled Percentage: 0.002, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8643
#
# Sampled Percentage: 0.002, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.8667, Test Accuracy: 0.7943
#
# Sampled Percentage: 0.002, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.8000
#
# Sampled Percentage: 0.002, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.8617
#
# Sampled Percentage: 0.002, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Training Accuracy: 1.0000, Test Accuracy: 0.8460
#
# Sampled Percentage: 0.002, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9667, Test Accuracy: 0.8550
#
# Sampled Percentage: 0.002, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.8197
#
# Sampled Percentage: 0.002, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.8363
#
# Sampled Percentage: 0.002, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8833
#
# Sampled Percentage: 0.002, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9667, Test Accuracy: 0.8543
#
# Sampled Percentage: 0.002, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8683
#
# Sampled Percentage: 0.002, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.8663
#
# Sampled Percentage: 0.002, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9667, Test Accuracy: 0.8547
#
# Sampled Percentage: 0.002, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8927
#
# Sampled Percentage: 0.002, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8683
#
# Sampled Percentage: 0.002, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8723
#
# Sampled Percentage: 0.002, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8477
#
# Sampled Percentage: 0.002, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8087
#
# Sampled Percentage: 0.002, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8340
#
# Sampled Percentage: 0.002, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8500
#
# Sampled Percentage: 0.002, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8803
#
# Sampled Percentage: 0.002, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8640
#
# Sampled Percentage: 0.002, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9667, Test Accuracy: 0.8403
#
# Sampled Percentage: 0.002, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8703
#
# Sampled Percentage: 0.002, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8533
#
# Sampled Percentage: 0.005, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 1.0000, Test Accuracy: 0.8680
#
# Sampled Percentage: 0.005, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8567
#
# Sampled Percentage: 0.005, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9877, Test Accuracy: 0.8710
#
# Sampled Percentage: 0.005, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8889, Test Accuracy: 0.8593
#
# Sampled Percentage: 0.005, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9383, Test Accuracy: 0.8500
#
# Sampled Percentage: 0.005, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8343
#
# Sampled Percentage: 0.005, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8477
#
# Sampled Percentage: 0.005, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9877, Test Accuracy: 0.8657
#
# Sampled Percentage: 0.005, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9136, Test Accuracy: 0.8673
#
# Sampled Percentage: 0.005, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9630, Test Accuracy: 0.8443
#
# Sampled Percentage: 0.005, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9506, Test Accuracy: 0.8800
#
# Sampled Percentage: 0.005, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9259, Test Accuracy: 0.8713
#
# Sampled Percentage: 0.005, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9753, Test Accuracy: 0.8977
#
# Sampled Percentage: 0.005, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8642, Test Accuracy: 0.8443
#
# Sampled Percentage: 0.005, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9630, Test Accuracy: 0.8800
#
# Sampled Percentage: 0.005, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9877, Test Accuracy: 0.9023
#
# Sampled Percentage: 0.005, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9506, Test Accuracy: 0.8910
#
# Sampled Percentage: 0.005, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.9027
#
# Sampled Percentage: 0.005, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8953
#
# Sampled Percentage: 0.005, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.9100
#
# Sampled Percentage: 0.005, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9877, Test Accuracy: 0.8953
#
# Sampled Percentage: 0.005, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9630, Test Accuracy: 0.8810
#
# Sampled Percentage: 0.005, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8983
#
# Sampled Percentage: 0.005, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9877, Test Accuracy: 0.8753
#
# Sampled Percentage: 0.005, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.9120
#
# Sampled Percentage: 0.005, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8930
#
# Sampled Percentage: 0.005, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.8843
#
# Sampled Percentage: 0.005, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.9000
#
# Sampled Percentage: 0.005, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9877, Test Accuracy: 0.8877
#
# Sampled Percentage: 0.005, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.9103
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8377
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9198, Test Accuracy: 0.8607
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9568, Test Accuracy: 0.8910
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8580
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8951, Test Accuracy: 0.8673
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9444, Test Accuracy: 0.8673
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9198, Test Accuracy: 0.8577
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8610
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Training Accuracy: 1.0000, Test Accuracy: 0.8943
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9877, Test Accuracy: 0.8903
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9012, Test Accuracy: 0.8573
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.8519, Test Accuracy: 0.8507
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9630, Test Accuracy: 0.9010
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9753, Test Accuracy: 0.9080
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Training Accuracy: 1.0000, Test Accuracy: 0.9007
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9815, Test Accuracy: 0.9057
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.8889, Test Accuracy: 0.9053
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9938, Test Accuracy: 0.9183
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9938, Test Accuracy: 0.9117
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9630, Test Accuracy: 0.9167
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9877, Test Accuracy: 0.9143
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9506, Test Accuracy: 0.8990
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9506, Test Accuracy: 0.9127
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.9017
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9877, Test Accuracy: 0.9267
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9630, Test Accuracy: 0.9057
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9321, Test Accuracy: 0.9163
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9630, Test Accuracy: 0.9243
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.9140
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9938, Test Accuracy: 0.9283
#
# Sampled Percentage: 0.05, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9247, Test Accuracy: 0.8967
#
# Sampled Percentage: 0.05, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9296, Test Accuracy: 0.9113
#
# Sampled Percentage: 0.05, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8901, Test Accuracy: 0.8917
#
# Sampled Percentage: 0.05, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9358, Test Accuracy: 0.9143
#
# Sampled Percentage: 0.05, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9296, Test Accuracy: 0.9097
#
# Sampled Percentage: 0.05, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9506, Test Accuracy: 0.9217
#
# Sampled Percentage: 0.05, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8679, Test Accuracy: 0.8523
#
# Sampled Percentage: 0.05, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9481, Test Accuracy: 0.9257
#
# Sampled Percentage: 0.05, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9481, Test Accuracy: 0.9303
#
# Sampled Percentage: 0.05, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9802, Test Accuracy: 0.9427
#
# Sampled Percentage: 0.05, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9593, Test Accuracy: 0.9407
#
# Sampled Percentage: 0.05, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9704, Test Accuracy: 0.9403
#
# Sampled Percentage: 0.05, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9753, Test Accuracy: 0.9410
#
# Sampled Percentage: 0.05, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9506, Test Accuracy: 0.9327
#
# Sampled Percentage: 0.05, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9852, Test Accuracy: 0.9410
#
# Sampled Percentage: 0.05, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9580, Test Accuracy: 0.9387
#
# Sampled Percentage: 0.05, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9593, Test Accuracy: 0.9343
#
# Sampled Percentage: 0.05, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9556, Test Accuracy: 0.9380
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9093, Test Accuracy: 0.9057
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8778, Test Accuracy: 0.8777
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8963, Test Accuracy: 0.9003
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9142, Test Accuracy: 0.9173
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9049, Test Accuracy: 0.9033
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9204, Test Accuracy: 0.9213
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9444, Test Accuracy: 0.9273
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9358, Test Accuracy: 0.9303
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9432, Test Accuracy: 0.9357
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9691, Test Accuracy: 0.9443
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9642, Test Accuracy: 0.9453
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9611, Test Accuracy: 0.9447
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9457, Test Accuracy: 0.9397
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9401, Test Accuracy: 0.9313
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9605, Test Accuracy: 0.9460
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9821, Test Accuracy: 0.9503
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9821, Test Accuracy: 0.9520
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9549, Test Accuracy: 0.9393
#
# Sampled Percentage: 0.3, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9531, Test Accuracy: 0.9453
#
# Sampled Percentage: 0.3, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9543, Test Accuracy: 0.9453
#
# Sampled Percentage: 0.3, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9455, Test Accuracy: 0.9450
#
# Sampled Percentage: 0.3, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9607, Test Accuracy: 0.9507
#
# Sampled Percentage: 0.3, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9541, Test Accuracy: 0.9457
#
# Sampled Percentage: 0.3, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9432, Test Accuracy: 0.9470
#
# Sampled Percentage: 0.3, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9455, Test Accuracy: 0.9387
#
# Sampled Percentage: 0.3, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9558, Test Accuracy: 0.9503
#
# Sampled Percentage: 0.3, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9541, Test Accuracy: 0.9477
#
# Sampled Percentage: 0.3, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9677, Test Accuracy: 0.9577
#
# Sampled Percentage: 0.3, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9535, Test Accuracy: 0.9487
#
# Sampled Percentage: 0.3, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9621, Test Accuracy: 0.9543
#
# Sampled Percentage: 0.3, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9788, Test Accuracy: 0.9603
#
# Sampled Percentage: 0.3, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9807, Test Accuracy: 0.9580
#
# Sampled Percentage: 0.3, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9648, Test Accuracy: 0.9560
#
# Sampled Percentage: 0.3, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9842, Test Accuracy: 0.9620
#
# Sampled Percentage: 0.3, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9862, Test Accuracy: 0.9590
#
# Sampled Percentage: 0.3, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9615, Test Accuracy: 0.9537
#
# Sampled Percentage: 0.5, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9520, Test Accuracy: 0.9467
#
# Sampled Percentage: 0.5, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9602, Test Accuracy: 0.9540
#
# Sampled Percentage: 0.5, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9622, Test Accuracy: 0.9567
#
# Sampled Percentage: 0.5, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9699, Test Accuracy: 0.9613
#
# Sampled Percentage: 0.5, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9693, Test Accuracy: 0.9603
#
# Sampled Percentage: 0.5, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9688, Test Accuracy: 0.9607
#
# Sampled Percentage: 0.8, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9678, Test Accuracy: 0.9593
#
# Sampled Percentage: 0.8, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9685, Test Accuracy: 0.9657
#
# Sampled Percentage: 0.8, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9682, Test Accuracy: 0.9647
#
# Sampled Percentage: 0.8, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9670, Test Accuracy: 0.9620
#
# Sampled Percentage: 0.8, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9723, Test Accuracy: 0.9617
#
# Sampled Percentage: 0.8, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9822, Test Accuracy: 0.9680
#
# Sampled Percentage: 1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9701, Test Accuracy: 0.9620
#
# Sampled Percentage: 1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9735, Test Accuracy: 0.9713
#
# Sampled Percentage: 1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9676, Test Accuracy: 0.9630
#
# Sampled Percentage: 1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9758, Test Accuracy: 0.9687
#
# Sampled Percentage: 1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9783, Test Accuracy: 0.9687
#
# Sampled Percentage: 1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9758, Test Accuracy: 0.9660

# %%
cut_custom_cnn_model(pretrained_model, cut_point=2, params=params, output_dim=dataloader_wrapped.output_dim)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc): Linear(in_features=23520, out_features=7, bias=True)
# )

# %%
# save fine-tuning results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/results_freeze_{params["freeze"]}_reinit_{params["reinit"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)
results = results[1:]

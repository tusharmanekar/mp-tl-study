# %% [markdown]
# # Example for:
# Transfer Learning Empirical Experiment from all 10 classes of FashionMNIST into all 10 classes of MNIST

# %% [markdown]
# ### Setup and Hyperparams

# %%
# Specify which gpu
import os
gpu_id = 3
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

import sys
sys.path.append('/home/arnisaf/mp-tl-study')
from functions.utils import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.cuda.manual_seed_all(0)  # if using multi-GPU

# %%
# cuts=0 means: end-to-end model if we are reinitializing
cuts = [0,1,2,3,4,5,6]

# %%
# Changes Here for the experiments
params = {
      # MODEL ARCHITECTURE PARAMS
      'depth': 6,
      'num_channels': 64,
      'kernel_size': 3,
      'activation_function': nn.ReLU,
      # TRAINING PARAMS
      'device': device,
      'lr_pretrain': 0.001,   
      'lr_fine_tune': 0.001, 
      'num_train': 40,
      'early_stop_patience': 6,
      'batch_size':4096,
      # DATASET PARAMS
      'pre_train_classes': list(range(10)),
      'fine_tune_classes': list(range(10)),
      # EXPERIMENT SETTING PARAMS
      'use_pooling': True,   # CHANGE
      'pooling_every_n_layers': 2, # add pooling after every n layers specified here. For only one pooling after all the CNN layers, this equals params['depth']
      # default value for pooling_every_n_layers is 1 (after each cnn layer)
      'pooling_stride': 2,
      'freeze': True,         # CHANGE: freeze the conv layers before the cut
      'reinit': True         # CHANGE: reinit the conv lyers only after the cut
      }

# %%
root_dir = './data'  # Specify your data directory here
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
dataloader_wrapped = TransferLearningWrapper(params, datasets.FashionMNIST, datasets.MNIST, root_dir, transform=transform)

# %%
dataloader_wrapped.pretrain_train_loader.dataset.__len__()
# Out:
# 54000

# %%
train_loader_reduced = reduce_dataset(dataloader_wrapped.finetune_train_loader, 0.001, seed = 0)
train_loader_reduced.dataset.__len__()
# Out:
# 50

# %% [markdown]
# ## Pretraining

# %%
#Create DNN model
pretrained_model = CustomCNN(params, dataloader_wrapped.output_dim)
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=10, bias=True)
# )

# %%
# Train and evaluate - Skip if loading saved model!
trainer = Trainer(pretrained_model, dataloader_wrapped, params["lr_pretrain"], params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 50.89%
# Validation Accuracy: 50.18%
# Epoch: 1 	Training Accuracy: 66.44%
# Validation Accuracy: 65.82%
# Epoch: 2 	Training Accuracy: 73.80%
# Validation Accuracy: 73.12%
# Epoch: 3 	Training Accuracy: 74.74%
# Validation Accuracy: 74.50%
# Epoch: 4 	Training Accuracy: 74.98%
# Validation Accuracy: 74.92%
# Epoch: 5 	Training Accuracy: 76.63%
# Validation Accuracy: 76.57%
# Epoch: 6 	Training Accuracy: 77.45%
# Validation Accuracy: 77.40%
# Epoch: 7 	Training Accuracy: 78.08%
# Validation Accuracy: 77.83%
# Epoch: 8 	Training Accuracy: 78.84%
# Validation Accuracy: 78.67%
# Epoch: 9 	Training Accuracy: 79.90%
# Validation Accuracy: 79.78%
# Epoch: 10 	Training Accuracy: 81.09%
# Validation Accuracy: 80.85%
# Epoch: 11 	Training Accuracy: 82.20%
# Validation Accuracy: 81.83%
# Epoch: 12 	Training Accuracy: 82.57%
# Validation Accuracy: 82.25%
# Epoch: 13 	Training Accuracy: 82.78%
# Validation Accuracy: 82.53%
# Epoch: 14 	Training Accuracy: 79.65%
# Validation Accuracy: 79.30%
# Epoch: 15 	Training Accuracy: 83.08%
# Validation Accuracy: 82.82%
# Epoch: 16 	Training Accuracy: 83.87%
# Validation Accuracy: 83.80%
# Epoch: 17 	Training Accuracy: 84.86%
# Validation Accuracy: 84.55%
# Epoch: 18 	Training Accuracy: 84.62%
# Validation Accuracy: 84.32%
# Epoch: 19 	Training Accuracy: 86.26%
# Validation Accuracy: 85.90%
# Epoch: 20 	Training Accuracy: 85.68%
# Validation Accuracy: 85.37%
# Epoch: 21 	Training Accuracy: 86.66%
# Validation Accuracy: 86.25%
# Epoch: 22 	Training Accuracy: 84.68%
# Validation Accuracy: 84.28%
# Epoch: 23 	Training Accuracy: 87.23%
# Validation Accuracy: 86.58%
# Epoch: 24 	Training Accuracy: 87.71%
# Validation Accuracy: 87.08%
# Epoch: 25 	Training Accuracy: 87.54%
# Validation Accuracy: 87.07%
# Epoch: 26 	Training Accuracy: 87.40%
# Validation Accuracy: 86.60%
# Epoch: 27 	Training Accuracy: 87.83%
# Validation Accuracy: 87.55%
# Epoch: 28 	Training Accuracy: 87.69%
# Validation Accuracy: 87.30%
# Epoch: 29 	Training Accuracy: 88.17%
# Validation Accuracy: 87.55%
# Epoch: 30 	Training Accuracy: 88.20%
# Validation Accuracy: 87.55%
# Epoch: 31 	Training Accuracy: 88.24%
# Validation Accuracy: 87.68%
# Epoch: 32 	Training Accuracy: 88.71%
# Validation Accuracy: 87.83%
# Epoch: 33 	Training Accuracy: 88.46%
# Validation Accuracy: 87.72%
# Epoch: 34 	Training Accuracy: 88.18%
# Validation Accuracy: 87.97%
# Epoch: 35 	Training Accuracy: 89.24%
# Validation Accuracy: 88.52%
# Epoch: 36 	Training Accuracy: 89.14%
# Validation Accuracy: 88.05%
# Epoch: 37 	Training Accuracy: 89.42%
# Validation Accuracy: 88.45%
# Epoch: 38 	Training Accuracy: 89.71%
# Validation Accuracy: 88.92%
# Epoch: 39 	Training Accuracy: 89.94%
# Validation Accuracy: 89.17%
# Final Training Accuracy: 0.8994
# Final Test Accuracy: 0.8986

# %%
pretrained_model.load_state_dict(torch.load('pretrained_models/pretrained_model_only_fashion_new.pth'))
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=10, bias=True)
# )

# %%
eval(pretrained_model, device, dataloader_wrapped.val_loader, debug=True, classification_report_flag=True, is_cnn=True)
# Out:
# Average loss: 0.3068, Accuracy: 5350.0/6000 (89%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.81      0.83       658
#      Class 1       0.99      0.99      0.99       611
#      Class 2       0.83      0.88      0.86       612
#      Class 3       0.84      0.91      0.88       562
#      Class 4       0.86      0.81      0.83       607
#      Class 5       0.96      0.97      0.96       613
#      Class 6       0.74      0.70      0.72       600
#      Class 7       0.94      0.95      0.94       537
#      Class 8       0.96      0.96      0.96       598
#      Class 9       0.97      0.95      0.96       602
#
#     accuracy                           0.89      6000
#    macro avg       0.89      0.89      0.89      6000
# weighted avg       0.89      0.89      0.89      6000
# 0.8916666666666667

# %%
# save model for later use
foldername = "pretrained_models/pretrained_Fashion_all_classes"
os.mkdir(foldername)
torch.save(pretrained_model.state_dict(), os.path.join(foldername, 'pretrained_model.pth'))

params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
#save params as well
with open(os.path.join(foldername, 'params.json'), 'w') as fp:
    json.dump(params_tmp, fp)

# %% [markdown]
# ## Fine-tuning Experiments

# %% [markdown]
# ### Baselines (End-to-end models trained on subsets of fine-tuning dataset)
# We also reuse the baselines a lot! so skip if we already have the jsons

# %%
baselines_results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:      
    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
    
    for repeat in range(repeats):
        # Print or log the sampled values for transparency
        print(f"\nSampled Percentage: {sampled_percentage}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

        # Reduce the dataset
        train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        torch.manual_seed(repeat)
        #train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)

        # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
        params_tmp = copy.deepcopy(params)
        params_tmp["reinit"] = True
        model_new = cut_custom_cnn_model(pretrained_model, cut_point=0, params=params_tmp, output_dim=dataloader_wrapped.output_dim)
        model_new.to(device)

        # Train and evaluate
        trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
        train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
        print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

        # Store the results
        baselines_results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":-1, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc}) # -1 for the cut point means it's baseline
# Out:
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 0

# %%
print(baselines_results)

# %%
# save baseline results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + baselines_results

with open(f'results_jsons/baselines_freeze_{params["freeze"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)

# %% [markdown]
# ### Fine-tuning

# %%
results = []
#percentages = [0.001, 0.01, 0.1, 0.5, 1.0]
percentages = [0.1]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9376, Test Accuracy: 0.9319
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9372, Test Accuracy: 0.9289
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9383, Test Accuracy: 0.9273
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9348, Test Accuracy: 0.9293
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9320, Test Accuracy: 0.9252
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9359, Test Accuracy: 0.9249
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9248, Test Accuracy: 0.9219
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.9383, Test Accuracy: 0.9308
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.9219, Test Accuracy: 0.9146
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9424, Test Accuracy: 0.9306
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.9313, Test Accuracy: 0.9200
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9378, Test Accuracy: 0.9345
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.9417, Test Accuracy: 0.9315
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9343, Test Accuracy: 0.9265
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9283, Test Accuracy: 0.9225
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9281, Test Accuracy: 0.9224
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9283, Test Accuracy: 0.9205
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9339, Test Accuracy: 0.9210
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9448, Test Accuracy: 0.9363
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.9330, Test Accuracy: 0.9227
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9524, Test Accuracy: 0.9425
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9319, Test Accuracy: 0.9285
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8974, Test Accuracy: 0.8889
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9180, Test Accuracy: 0.9093
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9141, Test Accuracy: 0.9056
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9243, Test Accuracy: 0.9127
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9194, Test Accuracy: 0.9217
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.9187, Test Accuracy: 0.9147
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.9196, Test Accuracy: 0.9154
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9330, Test Accuracy: 0.9227
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.9169, Test Accuracy: 0.9052
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9437, Test Accuracy: 0.9364
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.9407, Test Accuracy: 0.9302
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9220, Test Accuracy: 0.9171
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9393, Test Accuracy: 0.9334
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9481, Test Accuracy: 0.9395
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9213, Test Accuracy: 0.9163
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9381, Test Accuracy: 0.9262
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9276, Test Accuracy: 0.9244
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.9230, Test Accuracy: 0.9141
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9437, Test Accuracy: 0.9395
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9370, Test Accuracy: 0.9295
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9413, Test Accuracy: 0.9344
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9402, Test Accuracy: 0.9299
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9381, Test Accuracy: 0.9291
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9348, Test Accuracy: 0.9271
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9413, Test Accuracy: 0.9419
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.9389, Test Accuracy: 0.9312
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.9330, Test Accuracy: 0.9347
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9444, Test Accuracy: 0.9388
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.9370, Test Accuracy: 0.9306
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9481, Test Accuracy: 0.9386
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.9485, Test Accuracy: 0.9383
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9344, Test Accuracy: 0.9303
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9372, Test Accuracy: 0.9320
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9331, Test Accuracy: 0.9299
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9394, Test Accuracy: 0.9363
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9343, Test Accuracy: 0.9202
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9241, Test Accuracy: 0.9221
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.9196, Test Accuracy: 0.9166
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9378, Test Accuracy: 0.9356
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9313, Test Accuracy: 0.9259
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9435, Test Accuracy: 0.9324
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9367, Test Accuracy: 0.9267
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9361, Test Accuracy: 0.9290
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9420, Test Accuracy: 0.9354
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9133, Test Accuracy: 0.9131
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.9339, Test Accuracy: 0.9268
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.9313, Test Accuracy: 0.9302
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9404, Test Accuracy: 0.9317
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.9339, Test Accuracy: 0.9279
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9383, Test Accuracy: 0.9281
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.9406, Test Accuracy: 0.9305
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9287, Test Accuracy: 0.9267
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9404, Test Accuracy: 0.9355
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9374, Test Accuracy: 0.9323
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9380, Test Accuracy: 0.9373
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9317, Test Accuracy: 0.9226
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9376, Test Accuracy: 0.9347
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.9315, Test Accuracy: 0.9257
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9131, Test Accuracy: 0.9137
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9281, Test Accuracy: 0.9201
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9070, Test Accuracy: 0.8946
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9326, Test Accuracy: 0.9217
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9200, Test Accuracy: 0.9129
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9131, Test Accuracy: 0.9104
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9215, Test Accuracy: 0.9180
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.9185, Test Accuracy: 0.9117
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.9117, Test Accuracy: 0.9138
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9102, Test Accuracy: 0.9052
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.9272, Test Accuracy: 0.9215
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9174, Test Accuracy: 0.9111
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.9183, Test Accuracy: 0.9103
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9261, Test Accuracy: 0.9223
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9307, Test Accuracy: 0.9220
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9265, Test Accuracy: 0.9231
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9320, Test Accuracy: 0.9284
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9239, Test Accuracy: 0.9118
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9274, Test Accuracy: 0.9213
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.9154, Test Accuracy: 0.9109
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9250, Test Accuracy: 0.9192
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9233, Test Accuracy: 0.9176
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9252, Test Accuracy: 0.9119
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9165, Test Accuracy: 0.9101
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9370, Test Accuracy: 0.9251
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9239, Test Accuracy: 0.9178
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9328, Test Accuracy: 0.9231
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.9335, Test Accuracy: 0.9223
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.9115, Test Accuracy: 0.9101
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9254, Test Accuracy: 0.9180
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.9231, Test Accuracy: 0.9153
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9211, Test Accuracy: 0.9138
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.9174, Test Accuracy: 0.9066
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9263, Test Accuracy: 0.9231
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9231, Test Accuracy: 0.9185
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9281, Test Accuracy: 0.9175
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9330, Test Accuracy: 0.9251
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9344, Test Accuracy: 0.9235
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9265, Test Accuracy: 0.9209
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.9259, Test Accuracy: 0.9158
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8485, Test Accuracy: 0.8502
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8457, Test Accuracy: 0.8441
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8596, Test Accuracy: 0.8511
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8750, Test Accuracy: 0.8671
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.8737, Test Accuracy: 0.8653
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.8543, Test Accuracy: 0.8484
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.8450, Test Accuracy: 0.8461
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8485, Test Accuracy: 0.8447
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.8546, Test Accuracy: 0.8570
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.8646, Test Accuracy: 0.8633
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.8731, Test Accuracy: 0.8670
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.8665, Test Accuracy: 0.8605
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.8506, Test Accuracy: 0.8428
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.8533, Test Accuracy: 0.8584
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.8583, Test Accuracy: 0.8555
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.8535, Test Accuracy: 0.8528
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.8539, Test Accuracy: 0.8482
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.8683, Test Accuracy: 0.8598
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.8493, Test Accuracy: 0.8495
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.8607, Test Accuracy: 0.8529

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.9375925925925926, 'test_acc': 0.9319}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.9372222222222222, 'test_acc': 0.9288666666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.9383333333333334, 'test_acc': 0.9273166666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.9348148148148148, 'test_acc': 0.9292666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.932037037037037, 'test_acc': 0.9251833333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.9359259259259259, 'test_acc': 0.9249}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.9248148148148149, 'test_acc': 0.9219}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.9383333333333334, 'test_acc': 0.93085}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.9218518518518518, 'test_acc': 0.9145666666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.9424074074074074, 'test_acc': 0.9306333333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.9312962962962963, 'test_acc': 0.9199666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.9377777777777778, 'test_acc': 0.93455}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.9416666666666667, 'test_acc': 0.9314833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.9342592592592592, 'test_acc': 0.9264833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.9283333333333333, 'test_acc': 0.9225166666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.9281481481481482, 'test_acc': 0.9223833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.9283333333333333, 'test_acc': 0.9205166666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.9338888888888889, 'test_acc': 0.9209666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.9448148148148148, 'test_acc': 0.9363}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.932962962962963, 'test_acc': 0.9227333333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.9524074074074074, 'test_acc': 0.94245}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.9318518518518518, 'test_acc': 0.9284833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.8974074074074074, 'test_acc': 0.8889333333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 3, 'train_acc': 0.917962962962963, 'test_acc': 0.9093333333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 4, 'train_acc': 0.914074074074074, 'test_acc': 0.90565}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 5, 'train_acc': 0.9242592592592592, 'test_acc': 0.9127333333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 6, 'train_acc': 0.9194444444444444, 'test_acc': 0.92175}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 7, 'train_acc': 0.9187037037037037, 'test_acc': 0.9147166666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, ...

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.9375925925925926, 'test_acc': 0.9319}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.9372222222222222, 'test_acc': 0.9288666666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.9383333333333334, 'test_acc': 0.9273166666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.9348148148148148, 'test_acc': 0.9292666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.932037037037037, 'test_acc': 0.9251833333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.9359259259259259, 'test_acc': 0.9249}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.9248148148148149, 'test_acc': 0.9219}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.9383333333333334, 'test_acc': 0.93085}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.9218518518518518, 'test_acc': 0.9145666666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.9424074074074074, 'test_acc': 0.9306333333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.9312962962962963, 'test_acc': 0.9199666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.9377777777777778, 'test_acc': 0.93455}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.9416666666666667, 'test_acc': 0.9314833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.9342592592592592, 'test_acc': 0.9264833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.9283333333333333, 'test_acc': 0.9225166666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.9281481481481482, 'test_acc': 0.9223833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.9283333333333333, 'test_acc': 0.9205166666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.9338888888888889, 'test_acc': 0.9209666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.9448148148148148, 'test_acc': 0.9363}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.932962962962963, 'test_acc': 0.9227333333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.9524074074074074, 'test_acc': 0.94245}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.9318518518518518, 'test_acc': 0.9284833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.8974074074074074, 'test_acc': 0.8889333333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 3, 'train_acc': 0.917962962962963, 'test_acc': 0.9093333333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 4, 'train_acc': 0.914074074074074, 'test_acc': 0.90565}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 5, 'train_acc': 0.9242592592592592, 'test_acc': 0.9127333333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 6, 'train_acc': 0.9194444444444444, 'test_acc': 0.92175}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 7, 'train_acc': 0.9187037037037037, 'test_acc': 0.9147166666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, ...

# %%
# save fine-tuning results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/results_freeze_{params["freeze"]}_reinit_{params["reinit"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)
results = results[1:]

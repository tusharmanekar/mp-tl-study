# %% [markdown]
# # Example for:
# Transfer Learning Empirical Experiment from first 5 classes of MNIST into final 5 classes of MNIST
# - Almost all the details about optimizers, training, lr, ... are in the params dict!
# - And all experiment design details too! reinit, freeze, ..

# %% [markdown]
# ### Setup and Hyperparams

# %%
# Specify which gpu
import os
gpu_id = 3
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

import sys
sys.path.append('/home/arnisaf/mp-tl-study')
from functions.utils import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.cuda.manual_seed_all(0)  # if using multi-GPU

# %%
# cuts=0 means: end-to-end model if we are reinitializing
cuts = [0,1,2,3,4,5,6]

# %%
# Changes Here for the experiments
params = {
      # MODEL ARCHITECTURE PARAMS
      'depth': 6,
      'num_channels': 64, # num channels for CNN
      'two_linear_layers': False,
      'hidden_dim_lin': 128,  # if two_linear_layers == True
      'activation_function': nn.ReLU,
      'kernel_size': 3,
      # TRAINING PARAMS
      'device': device,
      'lr_pretrain': 0.001,   
      'lr_fine_tune': 0.001,  # CHANGE: if no layer-wise lr
      'num_train': 40,
      'early_stop_patience': 6,
      'save_best': False,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': False,
      'classification_report_flag': False,
      'batch_size':4096,
      # DATASET PARAMS
      'pre_train_classes': [0, 1, 2, 3, 4],
      'fine_tune_classes': [5, 6, 7, 8, 9],
      'val_split': 0.1,
      'num_workers': 0,
      'generate_dataset_seed': 42,
      # EXPERIMENT SETTING PARAMS
      'use_pooling': True,   # CHANGE
      'pooling_every_n_layers': 2, # add pooling after every n layers specified here. For only one pooling after all the CNN layers, this equals params['depth']
      # default value for pooling_every_n_layers is 1 (after each cnn layer)
      'pooling_stride': 2,
      'freeze': True,         # CHANGE: freeze the conv layers before the cut
      'reinit': True,         # CHANGE: reinit the conv lyers only after the cut
      'reinit_both_dense': True   # CHANGE: True for reinitialize both dense layers, False for reinit only the last dense layer
    }

# %%
root_dir = './data'  # Specify your data directory here
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
dataloader_wrapped = TransferLearningWrapper(params, datasets.MNIST, datasets.MNIST, root_dir, transform=transform)

# %%
dataloader_wrapped.finetune_train_loader.dataset.__len__()
# Out:
# 26464

# %% [markdown]
# ## Pretraining

# %%
#Create DNN model
pretrained_model = CustomCNN(params, dataloader_wrapped.output_dim)
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=5, bias=True)
# )

# %%
# Train and evaluate
trainer = Trainer(pretrained_model, dataloader_wrapped, params["lr_pretrain"], params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 22.05%
# Validation Accuracy: 21.90%
# Epoch: 1 	Training Accuracy: 79.30%
# Validation Accuracy: 79.44%
# Epoch: 2 	Training Accuracy: 79.70%
# Validation Accuracy: 79.57%
# Epoch: 3 	Training Accuracy: 87.36%
# Validation Accuracy: 86.40%
# Epoch: 4 	Training Accuracy: 90.55%
# Validation Accuracy: 90.06%
# Epoch: 5 	Training Accuracy: 92.87%
# Validation Accuracy: 92.42%
# Epoch: 6 	Training Accuracy: 94.19%
# Validation Accuracy: 93.79%
# Epoch: 7 	Training Accuracy: 95.14%
# Validation Accuracy: 94.87%
# Epoch: 8 	Training Accuracy: 96.23%
# Validation Accuracy: 95.59%
# Epoch: 9 	Training Accuracy: 96.83%
# Validation Accuracy: 96.08%
# Epoch: 10 	Training Accuracy: 97.04%
# Validation Accuracy: 96.31%
# Epoch: 11 	Training Accuracy: 97.52%
# Validation Accuracy: 96.73%
# Epoch: 12 	Training Accuracy: 97.84%
# Validation Accuracy: 97.19%
# Epoch: 13 	Training Accuracy: 98.08%
# Validation Accuracy: 97.38%
# Epoch: 14 	Training Accuracy: 98.13%
# Validation Accuracy: 97.55%
# Epoch: 15 	Training Accuracy: 98.40%
# Validation Accuracy: 97.78%
# Epoch: 16 	Training Accuracy: 98.54%
# Validation Accuracy: 97.88%
# Epoch: 17 	Training Accuracy: 98.55%
# Validation Accuracy: 97.84%
# Epoch: 18 	Training Accuracy: 98.55%
# Validation Accuracy: 97.78%
# Epoch: 19 	Training Accuracy: 98.84%
# Validation Accuracy: 98.17%
# Epoch: 20 	Training Accuracy: 98.86%
# Validation Accuracy: 98.23%
# Epoch: 21 	Training Accuracy: 98.91%
# Validation Accuracy: 98.14%
# Epoch: 22 	Training Accuracy: 98.93%
# Validation Accuracy: 98.40%
# Epoch: 23 	Training Accuracy: 99.08%
# Validation Accuracy: 98.23%
# Epoch: 24 	Training Accuracy: 98.95%
# Validation Accuracy: 98.30%
# Epoch: 25 	Training Accuracy: 99.14%
# Validation Accuracy: 98.50%
# Epoch: 26 	Training Accuracy: 99.22%
# Validation Accuracy: 98.59%
# Epoch: 27 	Training Accuracy: 99.23%
# Validation Accuracy: 98.43%
# Epoch: 28 	Training Accuracy: 99.22%
# Validation Accuracy: 98.50%
# Epoch: 29 	Training Accuracy: 99.34%
# Validation Accuracy: 98.69%
# Epoch: 30 	Training Accuracy: 99.31%
# Validation Accuracy: 98.63%
# Epoch: 31 	Training Accuracy: 99.34%
# Validation Accuracy: 98.69%
# Epoch: 32 	Training Accuracy: 99.34%
# Validation Accuracy: 98.82%
# Epoch: 33 	Training Accuracy: 99.38%
# Validation Accuracy: 98.82%
# Epoch: 34 	Training Accuracy: 99.45%
# Validation Accuracy: 98.73%
# Epoch: 35 	Training Accuracy: 99.51%
# Validation Accuracy: 98.95%
# Epoch: 36 	Training Accuracy: 99.53%
# Validation Accuracy: 99.02%
# Epoch: 37 	Training Accuracy: 99.54%
# Validation Accuracy: 99.02%
# Epoch: 38 	Training Accuracy: 99.60%
# Validation Accuracy: 99.05%
# Epoch: 39 	Training Accuracy: 99.57%
# Validation Accuracy: 99.12%
# Final Training Accuracy: 0.9957
# Final Test Accuracy: 0.9952

# %%
torch.save(pretrained_model.state_dict(), 'pretrained_models/pretrained_mnist_final/pretrained_model_new.pth')

# %%
pretrained_model.load_state_dict(torch.load('pretrained_models/pretrained_mnist_final/pretrained_model_new.pth'))
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=5, bias=True)
# )

# %%
eval(pretrained_model, device, dataloader_wrapped.val_loader, debug=True, classification_report_flag=True, is_cnn=True)
# Out:
# Average loss: 0.0260, Accuracy: 3032.0/3059 (99%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.99      1.00       544
#      Class 1       0.99      0.99      0.99       670
#      Class 2       0.98      0.99      0.99       631
#      Class 3       1.00      0.98      0.99       613
#      Class 4       0.99      1.00      0.99       601
#
#     accuracy                           0.99      3059
#    macro avg       0.99      0.99      0.99      3059
# weighted avg       0.99      0.99      0.99      3059
# 0.9911735861392612

# %%
# save model for later use
foldername = "pretrained_models/pretrained_mnist_final"
os.mkdir(foldername)
torch.save(pretrained_model.state_dict(), os.path.join(foldername, 'pretrained_model.pth'))

params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp.get("activation_function", nn.ReLU))
#save params as well
with open(os.path.join(foldername, 'params.json'), 'w') as fp:
    json.dump(params_tmp, fp)

# %% [markdown]
# ## Fine-tuning Experiments

# %% [markdown]
# ### Baselines (End-to-end models trained on subsets of fine-tuning dataset)
# We also reuse the baselines a lot! so skip if we already have the jsons

# %%
baselines_results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:      
    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
    
    for repeat in range(repeats):
        # Print or log the sampled values for transparency
        print(f"\nSampled Percentage: {sampled_percentage}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

        # Reduce the dataset
        train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        torch.manual_seed(repeat)
        #train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)

        # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
        params_tmp = copy.deepcopy(params)
        params_tmp["reinit"] = True
        model_new = cut_custom_cnn_model(pretrained_model, cut_point=0, params=params_tmp, output_dim=dataloader_wrapped.output_dim)
        model_new.to(device)

        # Train and evaluate
        trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
        train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
        print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

        # Store the results
        baselines_results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":-1, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc}) # -1 for the cut point means it's baseline
# Out:
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 0

# %%
# save baseline results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
baselines_results = [params_tmp] + baselines_results

with open(f'results_jsons/baselines_freeze_{params["freeze"]}_pool_{params["use_pooling"]}.json', 'w') as f:
    json.dump(baselines_results, f)

# %% [markdown]
# ### Fine-tuning

# %%
results = []
#percentages = [0.001, 0.01, 0.1, 0.5, 1.0]
percentages = [0.1]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8805, Test Accuracy: 0.8723
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9130, Test Accuracy: 0.9094
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.7055, Test Accuracy: 0.7096
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.6843, Test Accuracy: 0.6799
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.5388, Test Accuracy: 0.5392
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.7161, Test Accuracy: 0.7216
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.6979, Test Accuracy: 0.6900
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.9146, Test Accuracy: 0.9030
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.6938, Test Accuracy: 0.6858
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9017, Test Accuracy: 0.9015
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.7198, Test Accuracy: 0.7274
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9134, Test Accuracy: 0.9145
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.7251, Test Accuracy: 0.7315
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9051, Test Accuracy: 0.9034
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.8972, Test Accuracy: 0.8892
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.7437, Test Accuracy: 0.7443
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.7093, Test Accuracy: 0.7076
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.8938, Test Accuracy: 0.8875
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9108, Test Accuracy: 0.9038
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.8824, Test Accuracy: 0.8837
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9221, Test Accuracy: 0.9145
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.7720, Test Accuracy: 0.7787
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9191, Test Accuracy: 0.9232
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.7459, Test Accuracy: 0.7382
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9081, Test Accuracy: 0.9094
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9210, Test Accuracy: 0.9152
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.7263, Test Accuracy: 0.7179
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.9130, Test Accuracy: 0.9077
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8469, Test Accuracy: 0.8406
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.7127, Test Accuracy: 0.7176
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.7618, Test Accuracy: 0.7650
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.7974, Test Accuracy: 0.7896
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.9070, Test Accuracy: 0.9081
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.7490, Test Accuracy: 0.7600
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9414, Test Accuracy: 0.9323
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9282, Test Accuracy: 0.9166
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9251, Test Accuracy: 0.9166
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9119, Test Accuracy: 0.9098
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.7259, Test Accuracy: 0.7207
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.7062, Test Accuracy: 0.7090
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8155, Test Accuracy: 0.8098
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.7467, Test Accuracy: 0.7472
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.7611, Test Accuracy: 0.7795
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9388, Test Accuracy: 0.9321
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9482, Test Accuracy: 0.9462
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.7422, Test Accuracy: 0.7451
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9448, Test Accuracy: 0.9344
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.7713, Test Accuracy: 0.7673
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.7380, Test Accuracy: 0.7304
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.7361, Test Accuracy: 0.7355
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.7788, Test Accuracy: 0.7787
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.7660, Test Accuracy: 0.7719
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.8151, Test Accuracy: 0.8208
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9244, Test Accuracy: 0.9201
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9161, Test Accuracy: 0.9089
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.7815, Test Accuracy: 0.7926
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.7811, Test Accuracy: 0.7759
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9342, Test Accuracy: 0.9274
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9183, Test Accuracy: 0.9194
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.7425, Test Accuracy: 0.7515
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8193, Test Accuracy: 0.8179
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9577, Test Accuracy: 0.9518
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9338, Test Accuracy: 0.9345
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9550, Test Accuracy: 0.9462
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9289, Test Accuracy: 0.9253
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9618, Test Accuracy: 0.9535
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9599, Test Accuracy: 0.9524
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.7826, Test Accuracy: 0.7926
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.9565, Test Accuracy: 0.9481
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9599, Test Accuracy: 0.9584
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.8144, Test Accuracy: 0.8242
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9580, Test Accuracy: 0.9524
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.8272, Test Accuracy: 0.8331
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8389, Test Accuracy: 0.8411
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9607, Test Accuracy: 0.9470
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9425, Test Accuracy: 0.9320
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.8159, Test Accuracy: 0.8183
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.8053, Test Accuracy: 0.8016
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9543, Test Accuracy: 0.9534
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.9505, Test Accuracy: 0.9504
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9675, Test Accuracy: 0.9597
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9660, Test Accuracy: 0.9601
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9652, Test Accuracy: 0.9625
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9645, Test Accuracy: 0.9618
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9724, Test Accuracy: 0.9645
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9698, Test Accuracy: 0.9605
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9716, Test Accuracy: 0.9610
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.9739, Test Accuracy: 0.9654
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.9648, Test Accuracy: 0.9597
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9603, Test Accuracy: 0.9544
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.9690, Test Accuracy: 0.9629
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9671, Test Accuracy: 0.9627
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.9554, Test Accuracy: 0.9547
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9660, Test Accuracy: 0.9662
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9773, Test Accuracy: 0.9667
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9720, Test Accuracy: 0.9645
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9667, Test Accuracy: 0.9614
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9637, Test Accuracy: 0.9601
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9660, Test Accuracy: 0.9599
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.9679, Test Accuracy: 0.9596
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9493, Test Accuracy: 0.9383
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.9448, Test Accuracy: 0.9426
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9384, Test Accuracy: 0.9393
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.9270, Test Accuracy: 0.9216
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9452, Test Accuracy: 0.9413
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9527, Test Accuracy: 0.9458
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9380, Test Accuracy: 0.9344
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.8707, Test Accuracy: 0.8646
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.9459, Test Accuracy: 0.9403
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.9452, Test Accuracy: 0.9429
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.9595, Test Accuracy: 0.9534
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9524, Test Accuracy: 0.9423
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.9282, Test Accuracy: 0.9233
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.9474, Test Accuracy: 0.9472
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9505, Test Accuracy: 0.9435
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9429, Test Accuracy: 0.9372
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9486, Test Accuracy: 0.9461
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9505, Test Accuracy: 0.9450
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.9452, Test Accuracy: 0.9370
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.9516, Test Accuracy: 0.9480
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9108, Test Accuracy: 0.9088
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8994, Test Accuracy: 0.8970
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.9089, Test Accuracy: 0.9058
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8953, Test Accuracy: 0.8832
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.9115, Test Accuracy: 0.9024
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.8896, Test Accuracy: 0.8822
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.8839, Test Accuracy: 0.8823
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.9146, Test Accuracy: 0.9134
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.8941, Test Accuracy: 0.8921
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.8934, Test Accuracy: 0.8984
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.9119, Test Accuracy: 0.9138
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.9146, Test Accuracy: 0.9078
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.8922, Test Accuracy: 0.9038
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.8987, Test Accuracy: 0.8975
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.9100, Test Accuracy: 0.8986
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.9115, Test Accuracy: 0.9023
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9036, Test Accuracy: 0.8963
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.9267, Test Accuracy: 0.9176
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.8964, Test Accuracy: 0.8950
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.9198, Test Accuracy: 0.9206

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.8805293005671078, 'test_acc': 0.8722622772411917}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.9130434782608695, 'test_acc': 0.9093660726431778}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.7054820415879017, 'test_acc': 0.7095973336960958}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.6843100189035917, 'test_acc': 0.6799415045572031}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.5387523629489603, 'test_acc': 0.5392123520609441}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.7160680529300567, 'test_acc': 0.7216365120391783}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.6979206049149338, 'test_acc': 0.6900081621548089}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.9145557655954631, 'test_acc': 0.9030063936879336}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.6937618147448015, 'test_acc': 0.6858250578152633}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.9017013232514177, 'test_acc': 0.9014759896612706}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.7198487712665407, 'test_acc': 0.727350020405387}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.913421550094518, 'test_acc': 0.9145354373554618}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.7251417769376182, 'test_acc': 0.7315331247449327}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.9051039697542533, 'test_acc': 0.9034485104067473}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.897164461247637, 'test_acc': 0.8892327574479663}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.7436672967863894, 'test_acc': 0.7442864916337913}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.7092627599243856, 'test_acc': 0.7075908039722487}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.8937618147448015, 'test_acc': 0.8875323085294518}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.9107750472589792, 'test_acc': 0.90375459121208}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.8824196597353497, 'test_acc': 0.8836892939736091}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.922117202268431, 'test_acc': 0.9145354373554618}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.7720226843100189, 'test_acc': 0.7787035777445246}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.9190926275992438, 'test_acc': 0.9231737178615155}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 3, 'train_acc': 0.7459357277882798, 'test_acc': 0.7381648755271392}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 4, 'train_acc': 0.9081285444234405, 'test_acc': 0.9093660726431778}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 5, 'train_acc': 0.9209829867674858, 'test_acc': 0.9151816079444973}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 6, 'train_acc': 0.7262759924385633, 'test_acc': 0.7178615154400761}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 7, 'train_acc': 0.91304347826086 ...

# %%
# save fine-tuning results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/results_freeze_{params["freeze"]}_reinit_{params["reinit"]}_pool_{params["use_pooling"]}_truncate_{params["truncate"]}.json', 'w') as f:
    json.dump(results, f)
results = results[1:]

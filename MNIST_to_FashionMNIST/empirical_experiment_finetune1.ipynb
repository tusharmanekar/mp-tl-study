# %% [markdown]
# # Example for:
# Transfer Learning Empirical Experiment from all 10 classes of MNIST into all 10 classes of FashionMNIST \
# Note that here we are using the same architecture we used in FashionMNIST folder, with 5 CNN layers and 1 linear layer

# %% [markdown]
# ### Setup and Hyperparams

# %%
# Specify which gpu
import os
gpu_id = 2
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

import sys
sys.path.append('/home/arnisaf/mp-tl-study')
from functions.utils import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.cuda.manual_seed_all(0)  # if using multi-GPU

# %%
# cuts=0 means: end-to-end model if we are reinitializing
cuts = [0,1,2,3,4,5.6]

# %%
# Changes Here for the experiments
params = {
      # MODEL ARCHITECTURE PARAMS
      'depth': 6,
      'num_channels': 64,
      'kernel_size': 3,
      'activation_function': nn.ReLU,
      # TRAINING PARAMS
      'device': device,
      'lr_pretrain': 0.001,   
      'lr_fine_tune': 0.001, 
      'num_train': 40,
      'early_stop_patience': 6,
      'batch_size':4096,
      # DATASET PARAMS
      'pre_train_classes': list(range(10)),
      'fine_tune_classes': list(range(10)),
      # EXPERIMENT SETTING PARAMS
      'use_pooling': True,   # CHANGE
      'pooling_every_n_layers': 2, # add pooling after every n layers specified here. For only one pooling after all the CNN layers, this equals params['depth']
      # default value for pooling_every_n_layers is 1 (after each cnn layer)
      'pooling_stride': 2,
      'freeze': True,         # CHANGE: freeze the conv layers before the cut
      'reinit': True         # CHANGE: reinit the conv lyers only after the cut
      }

# %%
root_dir = './data'  # Specify your data directory here
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
dataloader_wrapped = TransferLearningWrapper(params, datasets.MNIST, datasets.FashionMNIST, root_dir, transform=transform)

# %%
dataloader_wrapped.pretrain_train_loader.dataset.__len__()
# Out:
# 54000

# %%
train_loader_reduced = reduce_dataset(dataloader_wrapped.finetune_train_loader, 0.5, seed = 0)
train_loader_reduced.dataset.__len__()
# Out:
# 27000

# %% [markdown]
# ## Pretraining

# %%
#Create DNN model
pretrained_model = CustomCNN(params, dataloader_wrapped.output_dim)
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=10, bias=True)
# )

# %%
# Train and evaluate
trainer = Trainer(pretrained_model, dataloader_wrapped, params["lr_pretrain"], params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 47.74%
# Validation Accuracy: 47.67%
# Epoch: 1 	Training Accuracy: 75.33%
# Validation Accuracy: 74.87%
# Epoch: 2 	Training Accuracy: 82.54%
# Validation Accuracy: 81.30%
# Epoch: 3 	Training Accuracy: 87.35%
# Validation Accuracy: 86.38%
# Epoch: 4 	Training Accuracy: 89.96%
# Validation Accuracy: 89.22%
# Epoch: 5 	Training Accuracy: 92.27%
# Validation Accuracy: 91.60%
# Epoch: 6 	Training Accuracy: 93.92%
# Validation Accuracy: 93.58%
# Epoch: 7 	Training Accuracy: 95.48%
# Validation Accuracy: 95.22%
# Epoch: 8 	Training Accuracy: 95.81%
# Validation Accuracy: 95.62%
# Epoch: 9 	Training Accuracy: 94.51%
# Validation Accuracy: 94.42%
# Epoch: 10 	Training Accuracy: 96.38%
# Validation Accuracy: 96.10%
# Epoch: 11 	Training Accuracy: 97.17%
# Validation Accuracy: 96.97%
# Epoch: 12 	Training Accuracy: 97.34%
# Validation Accuracy: 97.03%
# Epoch: 13 	Training Accuracy: 97.67%
# Validation Accuracy: 97.30%
# Epoch: 14 	Training Accuracy: 97.27%
# Validation Accuracy: 97.13%
# Epoch: 15 	Training Accuracy: 97.97%
# Validation Accuracy: 97.60%
# Epoch: 16 	Training Accuracy: 98.11%
# Validation Accuracy: 97.85%
# Epoch: 17 	Training Accuracy: 97.84%
# Validation Accuracy: 97.38%
# Epoch: 18 	Training Accuracy: 98.31%
# Validation Accuracy: 97.95%
# Epoch: 19 	Training Accuracy: 98.27%
# Validation Accuracy: 97.85%
# Epoch: 20 	Training Accuracy: 98.30%
# Validation Accuracy: 98.02%
# Epoch: 21 	Training Accuracy: 98.37%
# Validation Accuracy: 97.93%
# Epoch: 22 	Training Accuracy: 98.14%
# Validation Accuracy: 97.83%
# Epoch: 23 	Training Accuracy: 98.53%
# Validation Accuracy: 98.10%
# Epoch: 24 	Training Accuracy: 98.67%
# Validation Accuracy: 98.17%
# Epoch: 25 	Training Accuracy: 98.60%
# Validation Accuracy: 98.18%
# Epoch: 26 	Training Accuracy: 98.47%
# Validation Accuracy: 97.95%
# Epoch: 27 	Training Accuracy: 98.92%
# Validation Accuracy: 98.37%
# Epoch: 28 	Training Accuracy: 98.87%
# Validation Accuracy: 98.38%
# Epoch: 29 	Training Accuracy: 98.91%
# Validation Accuracy: 98.50%
# Epoch: 30 	Training Accuracy: 98.82%
# Validation Accuracy: 98.33%
# Epoch: 31 	Training Accuracy: 99.00%
# Validation Accuracy: 98.45%
# Epoch: 32 	Training Accuracy: 98.90%
# Validation Accuracy: 98.40%
# Epoch: 33 	Training Accuracy: 99.10%
# Validation Accuracy: 98.70%
# Epoch: 34 	Training Accuracy: 99.06%
# Validation Accuracy: 98.57%
# Epoch: 35 	Training Accuracy: 99.12%
# Validation Accuracy: 98.58%
# Epoch: 36 	Training Accuracy: 98.85%
# Validation Accuracy: 98.23%
# Epoch: 37 	Training Accuracy: 98.85%
# Validation Accuracy: 98.33%
# Epoch: 38 	Training Accuracy: 99.21%
# Validation Accuracy: 98.70%
# Epoch: 39 	Training Accuracy: 98.33%
# Validation Accuracy: 97.85%
# Early stopping invoked.
# Final Training Accuracy: 0.9910
# Final Test Accuracy: 0.9906

# %%
#torch.save(pretrained_model.state_dict(), 'pretrained_models/pretrained_model_only_numbers_new.pth')

# %%
pretrained_model.load_state_dict(torch.load('pretrained_models/pretrained_model_only_numbers_new.pth'))
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=10, bias=True)
# )

# %%
eval(pretrained_model, device, dataloader_wrapped.test_loader, debug=True, classification_report_flag=True, is_cnn=True)
# Out:
# Average loss: 0.0307, Accuracy: 59436.0/60000 (99%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.99      1.00      1.00      5923
#      Class 1       0.99      1.00      0.99      6742
#      Class 2       0.99      0.99      0.99      5958
#      Class 3       0.99      0.99      0.99      6131
#      Class 4       0.99      0.99      0.99      5842
#      Class 5       0.99      0.99      0.99      5421
#      Class 6       0.99      0.99      0.99      5918
#      Class 7       0.99      1.00      0.99      6265
#      Class 8       0.99      0.98      0.99      5851
#      Class 9       0.98      0.99      0.98      5949
#
#     accuracy                           0.99     60000
#    macro avg       0.99      0.99      0.99     60000
# weighted avg       0.99      0.99      0.99     60000
# 0.9906

# %%
# save model for later use
foldername = "pretrained_models/pretrained_mnist_to_fashion_all_classes"
os.mkdir(foldername)
torch.save(pretrained_model.state_dict(), os.path.join(foldername, 'pretrained_model.pth'))

params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp.get("activation_function", nn.ReLU))
#save params as well
with open(os.path.join(foldername, 'params.json'), 'w') as fp:
    json.dump(params_tmp, fp)

# %% [markdown]
# ## Fine-tuning Experiments

# %%
# load results: to continue from a checkpoint (actually don't run)
with open('results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Baselines (End-to-end models trained on subsets of fine-tuning dataset)
# We also reuse the baselines a lot! so skip if we already have the jsons

# %%
baselines_results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:      
    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
    
    for repeat in range(repeats):
        # Print or log the sampled values for transparency
        print(f"\nSampled Percentage: {sampled_percentage}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

        # Reduce the dataset
        train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        torch.manual_seed(repeat)
        #train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)

        # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
        params_tmp = copy.deepcopy(params)
        params_tmp["reinit"] = True
        model_new = cut_custom_cnn_model(pretrained_model, cut_point=0, params=params_tmp, output_dim=dataloader_wrapped.output_dim)
        model_new.to(device)

        # Train and evaluate
        trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
        train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
        print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

        # Store the results
        baselines_results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":-1, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc}) # -1 for the cut point means it's baseline
# Out:
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 0

# %%
print(baselines_results)

# %%
# save baseline results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/baselines_freeze_{params["freeze"]}_pool_{params["use_pooling"]}_lr_{params["lr_fine_tune"]}_dummy_run.json', 'w') as f:
    json.dump(results, f)

# %% [markdown]
# ### Fine-tuning

# %%
results = []
#percentages = [0.001, 0.01, 0.1, 0.5, 1.0]
percentages = [0.001]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.5600, Test Accuracy: 0.4955
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.5880
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.7600, Test Accuracy: 0.5669
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.6600, Test Accuracy: 0.5566
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.6400, Test Accuracy: 0.5088
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.5800, Test Accuracy: 0.5023
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.8400, Test Accuracy: 0.6064
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.7600, Test Accuracy: 0.5174
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8200, Test Accuracy: 0.5829
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.6151
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.6114
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.7400, Test Accuracy: 0.6201
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.6800, Test Accuracy: 0.5493
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.6600, Test Accuracy: 0.5476
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.5934
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.7200, Test Accuracy: 0.5226
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9000, Test Accuracy: 0.5743
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.8600, Test Accuracy: 0.5807
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.8600, Test Accuracy: 0.5818
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.7200, Test Accuracy: 0.5783
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.6376
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 21
# Training Accuracy: 0.9400, Test Accuracy: 0.5611
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.4000, Test Accuracy: 0.3668
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.6216
#
# Sampled Percentage: 0.001, Sampled Cut Point: 0, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.6010
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.9800, Test Accuracy: 0.5824
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.6029
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.7800, Test Accuracy: 0.5413
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.5822
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.5307
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.8200, Test Accuracy: 0.5573
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.9600, Test Accuracy: 0.6027
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.8600, Test Accuracy: 0.5545
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.6102
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.7200, Test Accuracy: 0.5593
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.9600, Test Accuracy: 0.6325
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.9400, Test Accuracy: 0.6398
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.7600, Test Accuracy: 0.5182
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.7200, Test Accuracy: 0.5638
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.6147
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.7600, Test Accuracy: 0.5701
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.8200, Test Accuracy: 0.5665
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.5743
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.5503
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.7600, Test Accuracy: 0.5632
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 0.9600, Test Accuracy: 0.6617
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.7400, Test Accuracy: 0.5212
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.8400, Test Accuracy: 0.5845
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.5904
#
# Sampled Percentage: 0.001, Sampled Cut Point: 1, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.9000, Test Accuracy: 0.5920
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.7800, Test Accuracy: 0.5781
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Training Accuracy: 1.0000, Test Accuracy: 0.6000
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.7400, Test Accuracy: 0.5149
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8600, Test Accuracy: 0.5580
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.5400, Test Accuracy: 0.4842
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 5
# Training Accuracy: 1.0000, Test Accuracy: 0.5631
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.6070
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.8400, Test Accuracy: 0.5207
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.8400, Test Accuracy: 0.5857
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.7800, Test Accuracy: 0.6112
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.9400, Test Accuracy: 0.6017
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.6002
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.5345
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.6600, Test Accuracy: 0.5327
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.5627
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 15
# Training Accuracy: 1.0000, Test Accuracy: 0.5707
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.7800, Test Accuracy: 0.5406
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.5800, Test Accuracy: 0.5033
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.9600, Test Accuracy: 0.5385
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.8200, Test Accuracy: 0.5562
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.6287
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.5544
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.8400, Test Accuracy: 0.5846
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 23
# Training Accuracy: 0.9800, Test Accuracy: 0.6007
#
# Sampled Percentage: 0.001, Sampled Cut Point: 2, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 0.8200, Test Accuracy: 0.5897
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.7800, Test Accuracy: 0.5884
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.6058
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.5703
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.5840
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.5111
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.9600, Test Accuracy: 0.6023
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.6173
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.8200, Test Accuracy: 0.5310
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.5794
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.6325
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.6400, Test Accuracy: 0.5464
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.6295
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.7000, Test Accuracy: 0.5315
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.7800, Test Accuracy: 0.5231
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.5502
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.9400, Test Accuracy: 0.5872
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.8400, Test Accuracy: 0.5685
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.9600, Test Accuracy: 0.5705
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.5699
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.6400, Test Accuracy: 0.5589
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 20
# Training Accuracy: 1.0000, Test Accuracy: 0.6306
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.7400, Test Accuracy: 0.5490
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.5881
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.6130
#
# Sampled Percentage: 0.001, Sampled Cut Point: 3, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.5931
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.5813
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9600, Test Accuracy: 0.6033
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.8600, Test Accuracy: 0.5860
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.5996
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8400, Test Accuracy: 0.5441
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.6064
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.6089
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.9400, Test Accuracy: 0.5740
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.6278
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.6360
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.6051
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8600, Test Accuracy: 0.6110
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.9400, Test Accuracy: 0.5749
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.6800, Test Accuracy: 0.5347
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.5694
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.8400, Test Accuracy: 0.5908
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.8600, Test Accuracy: 0.5998
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.5614
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.8200, Test Accuracy: 0.5656
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.5744
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.6616
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.5737
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.7400, Test Accuracy: 0.5704
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.8000, Test Accuracy: 0.6054
#
# Sampled Percentage: 0.001, Sampled Cut Point: 4, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.6030
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5.6, Lr: 0.001, Repeat: 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-bf55f78cc5f7> in <module>
#      25
#      26             # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
# ---> 27             model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
#      28             model_new.to(device)
#      29
#
# ~/mp-tl-study/functions/utils.py in cut_custom_cnn_model(model, cut_point, params, output_dim)
#     315     # If freeze is True, set requires_grad to False for layers before cut_point
#     316     if params.get("freeze", None):
# --> 317         for idx in conv_indices[:cut_point]:
#     318             for param in getattr(new_model, layer_names[idx]).parameters():
#     319                 param.requires_grad = False
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.56, 'test_acc': 0.49546666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.9, 'test_acc': 0.5880333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.76, 'test_acc': 0.5669}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.66, 'test_acc': 0.5566333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.64, 'test_acc': 0.50875}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.58, 'test_acc': 0.5023166666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.84, 'test_acc': 0.6063833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.76, 'test_acc': 0.5173666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.82, 'test_acc': 0.5828833333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.8, 'test_acc': 0.6151166666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.92, 'test_acc': 0.6114333333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.74, 'test_acc': 0.6201}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.68, 'test_acc': 0.5493333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.66, 'test_acc': 0.5475666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.9, 'test_acc': 0.5934}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.72, 'test_acc': 0.5225666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.9, 'test_acc': 0.5742833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.86, 'test_acc': 0.5807333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.86, 'test_acc': 0.5818}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.72, 'test_acc': 0.5782833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 20, 'train_acc': 0.92, 'test_acc': 0.6376}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 21, 'train_acc': 0.94, 'test_acc': 0.5610833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 22, 'train_acc': 0.4, 'test_acc': 0.36678333333333335}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 23, 'train_acc': 0.9, 'test_acc': 0.6216333333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 24, 'train_acc': 0.88, 'test_acc': 0.601}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.98, 'test_acc': 0.5824333333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.92, 'test_acc': 0.6029166666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.78, 'test_acc': 0.5413}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 3, 'train_acc': 0.88, 'test_acc': 0.5822166666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 4, 'train_acc': 0.8, 'test_acc': 0.5307333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 5, 'train_acc': 0.82, 'test_acc': 0.557316666666 ...

# %%
cuts = [5, 6]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.6208
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.5961
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.7400, Test Accuracy: 0.5606
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.6250
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.5427
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.6087
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.8600, Test Accuracy: 0.6154
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.5967
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.6109
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.6217
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.5962
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.6153
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 12
# Training Accuracy: 1.0000, Test Accuracy: 0.6027
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 13
# Training Accuracy: 1.0000, Test Accuracy: 0.5726
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.5744
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.6065
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.9600, Test Accuracy: 0.5934
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.8800, Test Accuracy: 0.5620
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.5717
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.9400, Test Accuracy: 0.5657
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.6506
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 21
# Early stopping invoked.
# Training Accuracy: 0.9400, Test Accuracy: 0.5826
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.9400, Test Accuracy: 0.5932
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.6438
#
# Sampled Percentage: 0.001, Sampled Cut Point: 5, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 0.8200, Test Accuracy: 0.6083
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 0
# Early stopping invoked.
# Training Accuracy: 0.8600, Test Accuracy: 0.5628
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.9400, Test Accuracy: 0.5951
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.9600, Test Accuracy: 0.5536
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.5715
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 4
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.5108
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.9800, Test Accuracy: 0.5912
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 6
# Training Accuracy: 1.0000, Test Accuracy: 0.5777
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.5956
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 8
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.5744
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.6113
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 10
# Training Accuracy: 1.0000, Test Accuracy: 0.5928
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.8200, Test Accuracy: 0.5652
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.9800, Test Accuracy: 0.5938
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.8600, Test Accuracy: 0.5493
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.5804
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 15
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.5755
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.9600, Test Accuracy: 0.5738
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.9400, Test Accuracy: 0.5654
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.9600, Test Accuracy: 0.5512
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.5204
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 20
# Early stopping invoked.
# Training Accuracy: 1.0000, Test Accuracy: 0.6192
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 21
# Training Accuracy: 1.0000, Test Accuracy: 0.5858
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.8600, Test Accuracy: 0.5637
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.9000, Test Accuracy: 0.6183
#
# Sampled Percentage: 0.001, Sampled Cut Point: 6, Lr: 0.001, Repeat: 24
# Early stopping invoked.
# Training Accuracy: 0.9200, Test Accuracy: 0.5409

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.56, 'test_acc': 0.49546666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.9, 'test_acc': 0.5880333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.76, 'test_acc': 0.5669}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.66, 'test_acc': 0.5566333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.64, 'test_acc': 0.50875}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.58, 'test_acc': 0.5023166666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.84, 'test_acc': 0.6063833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.76, 'test_acc': 0.5173666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.82, 'test_acc': 0.5828833333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.8, 'test_acc': 0.6151166666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.92, 'test_acc': 0.6114333333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.74, 'test_acc': 0.6201}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.68, 'test_acc': 0.5493333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.66, 'test_acc': 0.5475666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.9, 'test_acc': 0.5934}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.72, 'test_acc': 0.5225666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.9, 'test_acc': 0.5742833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.86, 'test_acc': 0.5807333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.86, 'test_acc': 0.5818}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.72, 'test_acc': 0.5782833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 20, 'train_acc': 0.92, 'test_acc': 0.6376}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 21, 'train_acc': 0.94, 'test_acc': 0.5610833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 22, 'train_acc': 0.4, 'test_acc': 0.36678333333333335}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 23, 'train_acc': 0.9, 'test_acc': 0.6216333333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 24, 'train_acc': 0.88, 'test_acc': 0.601}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.98, 'test_acc': 0.5824333333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.92, 'test_acc': 0.6029166666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.78, 'test_acc': 0.5413}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 3, 'train_acc': 0.88, 'test_acc': 0.5822166666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 4, 'train_acc': 0.8, 'test_acc': 0.5307333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 5, 'train_acc': 0.82, 'test_acc': 0.557316666666 ...

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.56, 'test_acc': 0.49546666666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.9, 'test_acc': 0.5880333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.76, 'test_acc': 0.5669}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.66, 'test_acc': 0.5566333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.64, 'test_acc': 0.50875}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.58, 'test_acc': 0.5023166666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.84, 'test_acc': 0.6063833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.76, 'test_acc': 0.5173666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.82, 'test_acc': 0.5828833333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.8, 'test_acc': 0.6151166666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.92, 'test_acc': 0.6114333333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.74, 'test_acc': 0.6201}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.68, 'test_acc': 0.5493333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.66, 'test_acc': 0.5475666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.9, 'test_acc': 0.5934}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.72, 'test_acc': 0.5225666666666666}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.9, 'test_acc': 0.5742833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.86, 'test_acc': 0.5807333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.86, 'test_acc': 0.5818}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.72, 'test_acc': 0.5782833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 20, 'train_acc': 0.92, 'test_acc': 0.6376}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 21, 'train_acc': 0.94, 'test_acc': 0.5610833333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 22, 'train_acc': 0.4, 'test_acc': 0.36678333333333335}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 23, 'train_acc': 0.9, 'test_acc': 0.6216333333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 0, 'repeat': 24, 'train_acc': 0.88, 'test_acc': 0.601}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.98, 'test_acc': 0.5824333333333334}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.92, 'test_acc': 0.6029166666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.78, 'test_acc': 0.5413}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 3, 'train_acc': 0.88, 'test_acc': 0.5822166666666667}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 4, 'train_acc': 0.8, 'test_acc': 0.5307333333333333}, {'lr': 0.001, 'sampled_percentage': 0.001, 'sampled_cut_point': 1, 'repeat': 5, 'train_acc': 0.82, 'test_acc': 0.557316666666 ...

# %%
# save fine-tuning results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/results_freeze_{params["freeze"]}_reinit_{params["reinit"]}_pool_{params["use_pooling"]}_lr_{params["lr_fine_tune"]}_MNIST_to_Fashion_{percentages[0]}_to_{percentages[-1]}.json', 'w') as f:
    json.dump(results, f)
results = results[1:]

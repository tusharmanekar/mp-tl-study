# %% [markdown]
# # Example for:
# Transfer Learning Empirical Experiment from all 10 classes of MNIST into all 10 classes of FashionMNIST \
# Note that here we are using the same architecture we used in FashionMNIST folder, with 5 CNN layers and 1 linear layer

# %% [markdown]
# ### Setup and Hyperparams

# %%
# Specify which gpu
import os
gpu_id = 0
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

import sys
sys.path.append('/home/arnisaf/mp-tl-study')
from functions.utils import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.cuda.manual_seed_all(0)  # if using multi-GPU

# %%
# cuts=0 means: end-to-end model if we are reinitializing
cuts = [0,1,2,3,4,5.6]

# %%
# Changes Here for the experiments
params = {
      # MODEL ARCHITECTURE PARAMS
      'depth': 6,
      'num_channels': 64,
      'kernel_size': 3,
      'activation_function': nn.ReLU,
      # TRAINING PARAMS
      'device': device,
      'lr_pretrain': 0.001,   
      'lr_fine_tune': 0.001, 
      'num_train': 40,
      'early_stop_patience': 6,
      'batch_size':4096,
      # DATASET PARAMS
      'pre_train_classes': list(range(10)),
      'fine_tune_classes': list(range(10)),
      # EXPERIMENT SETTING PARAMS
      'use_pooling': True,   # CHANGE
      'pooling_every_n_layers': 2, # add pooling after every n layers specified here. For only one pooling after all the CNN layers, this equals params['depth']
      # default value for pooling_every_n_layers is 1 (after each cnn layer)
      'pooling_stride': 2,
      'freeze': True,         # CHANGE: freeze the conv layers before the cut
      'reinit': True         # CHANGE: reinit the conv lyers only after the cut
      }

# %%
root_dir = './data'  # Specify your data directory here
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
dataloader_wrapped = TransferLearningWrapper(params, datasets.MNIST, datasets.FashionMNIST, root_dir, transform=transform)

# %%
dataloader_wrapped.pretrain_train_loader.dataset.__len__()
# Out:
# 54000

# %%
train_loader_reduced = reduce_dataset(dataloader_wrapped.finetune_train_loader, 0.5, seed = 0)
train_loader_reduced.dataset.__len__()
# Out:
# 27000

# %% [markdown]
# ## Pretraining

# %%
#Create DNN model
pretrained_model = CustomCNN(params, dataloader_wrapped.output_dim)
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=10, bias=True)
# )

# %%
# Train and evaluate
trainer = Trainer(pretrained_model, dataloader_wrapped, params["lr_pretrain"], params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 47.74%
# Validation Accuracy: 47.67%
# Epoch: 1 	Training Accuracy: 75.33%
# Validation Accuracy: 74.87%
# Epoch: 2 	Training Accuracy: 82.54%
# Validation Accuracy: 81.30%
# Epoch: 3 	Training Accuracy: 87.35%
# Validation Accuracy: 86.38%
# Epoch: 4 	Training Accuracy: 89.96%
# Validation Accuracy: 89.22%
# Epoch: 5 	Training Accuracy: 92.27%
# Validation Accuracy: 91.60%
# Epoch: 6 	Training Accuracy: 93.92%
# Validation Accuracy: 93.58%
# Epoch: 7 	Training Accuracy: 95.48%
# Validation Accuracy: 95.22%
# Epoch: 8 	Training Accuracy: 95.81%
# Validation Accuracy: 95.62%
# Epoch: 9 	Training Accuracy: 94.51%
# Validation Accuracy: 94.42%
# Epoch: 10 	Training Accuracy: 96.38%
# Validation Accuracy: 96.10%
# Epoch: 11 	Training Accuracy: 97.17%
# Validation Accuracy: 96.97%
# Epoch: 12 	Training Accuracy: 97.34%
# Validation Accuracy: 97.03%
# Epoch: 13 	Training Accuracy: 97.67%
# Validation Accuracy: 97.30%
# Epoch: 14 	Training Accuracy: 97.27%
# Validation Accuracy: 97.13%
# Epoch: 15 	Training Accuracy: 97.97%
# Validation Accuracy: 97.60%
# Epoch: 16 	Training Accuracy: 98.11%
# Validation Accuracy: 97.85%
# Epoch: 17 	Training Accuracy: 97.84%
# Validation Accuracy: 97.38%
# Epoch: 18 	Training Accuracy: 98.31%
# Validation Accuracy: 97.95%
# Epoch: 19 	Training Accuracy: 98.27%
# Validation Accuracy: 97.85%
# Epoch: 20 	Training Accuracy: 98.30%
# Validation Accuracy: 98.02%
# Epoch: 21 	Training Accuracy: 98.37%
# Validation Accuracy: 97.93%
# Epoch: 22 	Training Accuracy: 98.14%
# Validation Accuracy: 97.83%
# Epoch: 23 	Training Accuracy: 98.53%
# Validation Accuracy: 98.10%
# Epoch: 24 	Training Accuracy: 98.67%
# Validation Accuracy: 98.17%
# Epoch: 25 	Training Accuracy: 98.60%
# Validation Accuracy: 98.18%
# Epoch: 26 	Training Accuracy: 98.47%
# Validation Accuracy: 97.95%
# Epoch: 27 	Training Accuracy: 98.92%
# Validation Accuracy: 98.37%
# Epoch: 28 	Training Accuracy: 98.87%
# Validation Accuracy: 98.38%
# Epoch: 29 	Training Accuracy: 98.91%
# Validation Accuracy: 98.50%
# Epoch: 30 	Training Accuracy: 98.82%
# Validation Accuracy: 98.33%
# Epoch: 31 	Training Accuracy: 99.00%
# Validation Accuracy: 98.45%
# Epoch: 32 	Training Accuracy: 98.90%
# Validation Accuracy: 98.40%
# Epoch: 33 	Training Accuracy: 99.10%
# Validation Accuracy: 98.70%
# Epoch: 34 	Training Accuracy: 99.06%
# Validation Accuracy: 98.57%
# Epoch: 35 	Training Accuracy: 99.12%
# Validation Accuracy: 98.58%
# Epoch: 36 	Training Accuracy: 98.85%
# Validation Accuracy: 98.23%
# Epoch: 37 	Training Accuracy: 98.85%
# Validation Accuracy: 98.33%
# Epoch: 38 	Training Accuracy: 99.21%
# Validation Accuracy: 98.70%
# Epoch: 39 	Training Accuracy: 98.33%
# Validation Accuracy: 97.85%
# Early stopping invoked.
# Final Training Accuracy: 0.9910
# Final Test Accuracy: 0.9906

# %%
#torch.save(pretrained_model.state_dict(), 'pretrained_models/pretrained_model_only_numbers_new.pth')

# %%
pretrained_model.load_state_dict(torch.load('pretrained_models/pretrained_model_only_numbers_new.pth'))
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=10, bias=True)
# )

# %%
eval(pretrained_model, device, dataloader_wrapped.test_loader, debug=True, classification_report_flag=True, is_cnn=True)
# Out:
# Average loss: 0.0307, Accuracy: 59436.0/60000 (99%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.99      1.00      1.00      5923
#      Class 1       0.99      1.00      0.99      6742
#      Class 2       0.99      0.99      0.99      5958
#      Class 3       0.99      0.99      0.99      6131
#      Class 4       0.99      0.99      0.99      5842
#      Class 5       0.99      0.99      0.99      5421
#      Class 6       0.99      0.99      0.99      5918
#      Class 7       0.99      1.00      0.99      6265
#      Class 8       0.99      0.98      0.99      5851
#      Class 9       0.98      0.99      0.98      5949
#
#     accuracy                           0.99     60000
#    macro avg       0.99      0.99      0.99     60000
# weighted avg       0.99      0.99      0.99     60000
# 0.9906

# %%
# save model for later use
foldername = "pretrained_models/pretrained_mnist_to_fashion_all_classes"
os.mkdir(foldername)
torch.save(pretrained_model.state_dict(), os.path.join(foldername, 'pretrained_model.pth'))

params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp.get("activation_function", nn.ReLU))
#save params as well
with open(os.path.join(foldername, 'params.json'), 'w') as fp:
    json.dump(params_tmp, fp)

# %% [markdown]
# ## Fine-tuning Experiments

# %%
# load results: to continue from a checkpoint (actually don't run)
with open('results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Baselines (End-to-end models trained on subsets of fine-tuning dataset)
# We also reuse the baselines a lot! so skip if we already have the jsons

# %%
baselines_results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:      
    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
    
    for repeat in range(repeats):
        # Print or log the sampled values for transparency
        print(f"\nSampled Percentage: {sampled_percentage}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

        # Reduce the dataset
        train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        torch.manual_seed(repeat)
        #train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)

        # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
        params_tmp = copy.deepcopy(params)
        params_tmp["reinit"] = True
        model_new = cut_custom_cnn_model(pretrained_model, cut_point=0, params=params_tmp, output_dim=dataloader_wrapped.output_dim)
        model_new.to(device)

        # Train and evaluate
        trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
        train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
        print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

        # Store the results
        baselines_results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":-1, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc}) # -1 for the cut point means it's baseline
# Out:
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 0

# %%
print(baselines_results)

# %%
# save baseline results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/baselines_freeze_{params["freeze"]}_pool_{params["use_pooling"]}_lr_{params["lr_fine_tune"]}_dummy_run.json', 'w') as f:
    json.dump(results, f)

# %% [markdown]
# ### Fine-tuning

# %%
results = []
#percentages = [0.001, 0.01, 0.1, 0.5, 1.0]
percentages = [0.01]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.7630, Test Accuracy: 0.7379
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Early stopping invoked.
# Training Accuracy: 0.5704, Test Accuracy: 0.5429
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.6870, Test Accuracy: 0.6838
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.7130, Test Accuracy: 0.6703
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.7167, Test Accuracy: 0.6886
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.7222, Test Accuracy: 0.7058
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.7667, Test Accuracy: 0.7047
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.7370, Test Accuracy: 0.6763
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.7352, Test Accuracy: 0.6878
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.5519, Test Accuracy: 0.5358
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.7667, Test Accuracy: 0.7022
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.5296, Test Accuracy: 0.5434
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.7148, Test Accuracy: 0.6945
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 13
# Early stopping invoked.
# Training Accuracy: 0.5315, Test Accuracy: 0.5412
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.6463, Test Accuracy: 0.6158
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.7685, Test Accuracy: 0.7105
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.7148, Test Accuracy: 0.6790
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.7944, Test Accuracy: 0.7027
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.7611, Test Accuracy: 0.7129
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.6944, Test Accuracy: 0.6864
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 20
# Training Accuracy: 0.7370, Test Accuracy: 0.6807
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 21
# Training Accuracy: 0.7574, Test Accuracy: 0.7052
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 22
# Early stopping invoked.
# Training Accuracy: 0.5722, Test Accuracy: 0.5656
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.5778, Test Accuracy: 0.5532
#
# Sampled Percentage: 0.01, Sampled Cut Point: 0, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.7370, Test Accuracy: 0.6950
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.7074, Test Accuracy: 0.7168
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.7704, Test Accuracy: 0.7098
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.7426, Test Accuracy: 0.7175
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Early stopping invoked.
# Training Accuracy: 0.5630, Test Accuracy: 0.5750
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.7111, Test Accuracy: 0.6827
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.7241, Test Accuracy: 0.6879
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 6
# Early stopping invoked.
# Training Accuracy: 0.6111, Test Accuracy: 0.6048
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 7
# Early stopping invoked.
# Training Accuracy: 0.7778, Test Accuracy: 0.7206
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.7537, Test Accuracy: 0.6994
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.7148, Test Accuracy: 0.6797
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.7556, Test Accuracy: 0.7230
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.5685, Test Accuracy: 0.5829
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.7019, Test Accuracy: 0.6829
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.7481, Test Accuracy: 0.7002
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.7407, Test Accuracy: 0.7006
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.7815, Test Accuracy: 0.7121
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.7778, Test Accuracy: 0.7264
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.7926, Test Accuracy: 0.7020
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.7556, Test Accuracy: 0.7004
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.6796, Test Accuracy: 0.6698
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 20
# Training Accuracy: 0.7778, Test Accuracy: 0.7288
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 21
# Training Accuracy: 0.7333, Test Accuracy: 0.6923
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 22
# Training Accuracy: 0.7556, Test Accuracy: 0.7165
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.5630, Test Accuracy: 0.5236
#
# Sampled Percentage: 0.01, Sampled Cut Point: 1, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.7204, Test Accuracy: 0.6865
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.7352, Test Accuracy: 0.6885
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.7519, Test Accuracy: 0.6870
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.7259, Test Accuracy: 0.6887
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.7519, Test Accuracy: 0.6825
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.7185, Test Accuracy: 0.6811
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.7148, Test Accuracy: 0.6885
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.7333, Test Accuracy: 0.6851
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.7481, Test Accuracy: 0.6796
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.7537, Test Accuracy: 0.6767
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.7444, Test Accuracy: 0.6802
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.7593, Test Accuracy: 0.7000
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.7056, Test Accuracy: 0.6663
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.7630, Test Accuracy: 0.7051
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.7315, Test Accuracy: 0.6686
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.7519, Test Accuracy: 0.6796
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.7407, Test Accuracy: 0.6695
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.7148, Test Accuracy: 0.6653
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.7685, Test Accuracy: 0.6835
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.7741, Test Accuracy: 0.6996
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 19
# Early stopping invoked.
# Training Accuracy: 0.6796, Test Accuracy: 0.6692
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 20
# Training Accuracy: 0.7667, Test Accuracy: 0.7076
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 21
# Training Accuracy: 0.7222, Test Accuracy: 0.6624
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 22
# Training Accuracy: 0.7685, Test Accuracy: 0.6970
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 23
# Training Accuracy: 0.7704, Test Accuracy: 0.7190
#
# Sampled Percentage: 0.01, Sampled Cut Point: 2, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.7500, Test Accuracy: 0.6813
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.7759, Test Accuracy: 0.7221
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.7889, Test Accuracy: 0.7063
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.7519, Test Accuracy: 0.7031
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.7685, Test Accuracy: 0.6924
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.7444, Test Accuracy: 0.7162
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.7537, Test Accuracy: 0.7119
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.7741, Test Accuracy: 0.7175
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8093, Test Accuracy: 0.7176
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.7519, Test Accuracy: 0.6892
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 9
# Early stopping invoked.
# Training Accuracy: 0.5444, Test Accuracy: 0.5588
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.7741, Test Accuracy: 0.7069
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.7926, Test Accuracy: 0.7152
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 12
# Early stopping invoked.
# Training Accuracy: 0.5500, Test Accuracy: 0.5569
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.7741, Test Accuracy: 0.7109
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.7704, Test Accuracy: 0.7083
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.7944, Test Accuracy: 0.7036
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 16
# Early stopping invoked.
# Training Accuracy: 0.5889, Test Accuracy: 0.5568
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 17
# Early stopping invoked.
# Training Accuracy: 0.5889, Test Accuracy: 0.5754
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 18
# Early stopping invoked.
# Training Accuracy: 0.5759, Test Accuracy: 0.5587
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.7722, Test Accuracy: 0.7123
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 20
# Training Accuracy: 0.7852, Test Accuracy: 0.7148
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 21
# Training Accuracy: 0.7741, Test Accuracy: 0.6934
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 22
# Training Accuracy: 0.7778, Test Accuracy: 0.7079
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 23
# Early stopping invoked.
# Training Accuracy: 0.5722, Test Accuracy: 0.5414
#
# Sampled Percentage: 0.01, Sampled Cut Point: 3, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.8000, Test Accuracy: 0.7306
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8352, Test Accuracy: 0.7313
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8352, Test Accuracy: 0.7377
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8241, Test Accuracy: 0.7352
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8296, Test Accuracy: 0.7323
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.8222, Test Accuracy: 0.7381
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.8407, Test Accuracy: 0.7432
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.8111, Test Accuracy: 0.7441
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8426, Test Accuracy: 0.7402
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.8241, Test Accuracy: 0.7387
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.7926, Test Accuracy: 0.7178
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.8259, Test Accuracy: 0.7309
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 11
# Early stopping invoked.
# Training Accuracy: 0.7481, Test Accuracy: 0.6944
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.8148, Test Accuracy: 0.7449
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.8093, Test Accuracy: 0.7265
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.8574, Test Accuracy: 0.7340
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.8333, Test Accuracy: 0.7252
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.8148, Test Accuracy: 0.7306
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.8463, Test Accuracy: 0.7352
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.8370, Test Accuracy: 0.7348
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.8352, Test Accuracy: 0.7292
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 20
# Training Accuracy: 0.8222, Test Accuracy: 0.7313
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 21
# Training Accuracy: 0.8407, Test Accuracy: 0.7308
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 22
# Training Accuracy: 0.8296, Test Accuracy: 0.7369
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 23
# Training Accuracy: 0.8148, Test Accuracy: 0.7451
#
# Sampled Percentage: 0.01, Sampled Cut Point: 4, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.8370, Test Accuracy: 0.7482
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5.6, Lr: 0.001, Repeat: 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-bf55f78cc5f7> in <module>
#      25
#      26             # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
# ---> 27             model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
#      28             model_new.to(device)
#      29
#
# ~/mp-tl-study/functions/utils.py in cut_custom_cnn_model(model, cut_point, params, output_dim)
#     315     # If freeze is True, set requires_grad to False for layers before cut_point
#     316     if params.get("freeze", None):
# --> 317         for idx in conv_indices[:cut_point]:
#     318             for param in getattr(new_model, layer_names[idx]).parameters():
#     319                 param.requires_grad = False
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.762962962962963, 'test_acc': 0.73785}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.5703703703703704, 'test_acc': 0.5428666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.687037037037037, 'test_acc': 0.6838333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.7129629629629629, 'test_acc': 0.6703}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.7166666666666667, 'test_acc': 0.6885666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.7222222222222222, 'test_acc': 0.7058}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.7666666666666667, 'test_acc': 0.7047}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.737037037037037, 'test_acc': 0.6762666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.7351851851851852, 'test_acc': 0.68785}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.5518518518518518, 'test_acc': 0.5358166666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.7666666666666667, 'test_acc': 0.7022166666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.5296296296296297, 'test_acc': 0.5434166666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.7148148148148148, 'test_acc': 0.6945}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.5314814814814814, 'test_acc': 0.5411666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.6462962962962963, 'test_acc': 0.6158333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.7685185185185185, 'test_acc': 0.7105}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.7148148148148148, 'test_acc': 0.6789666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.7944444444444444, 'test_acc': 0.7026833333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.7611111111111111, 'test_acc': 0.7129333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.6944444444444444, 'test_acc': 0.6863666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 20, 'train_acc': 0.737037037037037, 'test_acc': 0.6806666666666666}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 21, 'train_acc': 0.7574074074074074, 'test_acc': 0.7051666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 22, 'train_acc': 0.5722222222222222, 'test_acc': 0.5656166666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 23, 'train_acc': 0.5777777777777777, 'test_acc': 0.5531666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 24, 'train_acc': 0.737037037037037, 'test_acc': 0.6950333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.7074074074074074, 'test_acc': 0.7167833333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.7703703703703704, 'test_acc': 0.7097666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.7425925925925926, 'test_acc': 0.7175333333333334}, {'lr': 0.00 ...

# %%
cuts = [5,6]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8519, Test Accuracy: 0.7451
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8463, Test Accuracy: 0.7377
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.7981, Test Accuracy: 0.7270
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.7981, Test Accuracy: 0.7214
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.8278, Test Accuracy: 0.7417
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.8519, Test Accuracy: 0.7493
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.8093, Test Accuracy: 0.7254
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8648, Test Accuracy: 0.7503
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.8463, Test Accuracy: 0.7332
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.8407, Test Accuracy: 0.7323
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.8870, Test Accuracy: 0.7471
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.8556, Test Accuracy: 0.7355
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.8167, Test Accuracy: 0.7409
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.8204, Test Accuracy: 0.7189
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.8444, Test Accuracy: 0.7306
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.8352, Test Accuracy: 0.7212
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.8315, Test Accuracy: 0.7361
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.8648, Test Accuracy: 0.7376
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.8148, Test Accuracy: 0.7287
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.8704, Test Accuracy: 0.7419
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 20
# Training Accuracy: 0.8481, Test Accuracy: 0.7468
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 21
# Training Accuracy: 0.8019, Test Accuracy: 0.7310
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 22
# Training Accuracy: 0.8537, Test Accuracy: 0.7432
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 23
# Training Accuracy: 0.8315, Test Accuracy: 0.7485
#
# Sampled Percentage: 0.01, Sampled Cut Point: 5, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.8333, Test Accuracy: 0.7450
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.7907, Test Accuracy: 0.7161
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.7685, Test Accuracy: 0.6823
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.7907, Test Accuracy: 0.7225
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.7389, Test Accuracy: 0.6737
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.7778, Test Accuracy: 0.7055
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.7574, Test Accuracy: 0.7082
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.7352, Test Accuracy: 0.6717
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.7778, Test Accuracy: 0.7022
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.7722, Test Accuracy: 0.6901
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.7926, Test Accuracy: 0.6948
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.7889, Test Accuracy: 0.7029
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.7907, Test Accuracy: 0.6928
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.7722, Test Accuracy: 0.7019
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.7500, Test Accuracy: 0.6873
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.7685, Test Accuracy: 0.7042
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.7944, Test Accuracy: 0.6988
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.7944, Test Accuracy: 0.6874
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.8000, Test Accuracy: 0.6980
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.7778, Test Accuracy: 0.6955
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.7944, Test Accuracy: 0.6918
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 20
# Training Accuracy: 0.7667, Test Accuracy: 0.6993
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 21
# Training Accuracy: 0.7704, Test Accuracy: 0.7010
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 22
# Training Accuracy: 0.7741, Test Accuracy: 0.6942
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 23
# Training Accuracy: 0.7574, Test Accuracy: 0.7019
#
# Sampled Percentage: 0.01, Sampled Cut Point: 6, Lr: 0.001, Repeat: 24
# Training Accuracy: 0.7222, Test Accuracy: 0.6895

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.762962962962963, 'test_acc': 0.73785}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.5703703703703704, 'test_acc': 0.5428666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.687037037037037, 'test_acc': 0.6838333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.7129629629629629, 'test_acc': 0.6703}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.7166666666666667, 'test_acc': 0.6885666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.7222222222222222, 'test_acc': 0.7058}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.7666666666666667, 'test_acc': 0.7047}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.737037037037037, 'test_acc': 0.6762666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.7351851851851852, 'test_acc': 0.68785}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.5518518518518518, 'test_acc': 0.5358166666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.7666666666666667, 'test_acc': 0.7022166666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.5296296296296297, 'test_acc': 0.5434166666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.7148148148148148, 'test_acc': 0.6945}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.5314814814814814, 'test_acc': 0.5411666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.6462962962962963, 'test_acc': 0.6158333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.7685185185185185, 'test_acc': 0.7105}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.7148148148148148, 'test_acc': 0.6789666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.7944444444444444, 'test_acc': 0.7026833333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.7611111111111111, 'test_acc': 0.7129333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.6944444444444444, 'test_acc': 0.6863666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 20, 'train_acc': 0.737037037037037, 'test_acc': 0.6806666666666666}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 21, 'train_acc': 0.7574074074074074, 'test_acc': 0.7051666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 22, 'train_acc': 0.5722222222222222, 'test_acc': 0.5656166666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 23, 'train_acc': 0.5777777777777777, 'test_acc': 0.5531666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 0, 'repeat': 24, 'train_acc': 0.737037037037037, 'test_acc': 0.6950333333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.7074074074074074, 'test_acc': 0.7167833333333333}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.7703703703703704, 'test_acc': 0.7097666666666667}, {'lr': 0.001, 'sampled_percentage': 0.01, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.7425925925925926, 'test_acc': 0.7175333333333334}, {'lr': 0.00 ...

# %%
# save fine-tuning results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/results_freeze_{params["freeze"]}_reinit_{params["reinit"]}_pool_{params["use_pooling"]}_lr_{params["lr_fine_tune"]}_MNIST_to_Fashion_{percentages[0]}_to_{percentages[-1]}.json', 'w') as f:
    json.dump(results, f)
results = results[1:]

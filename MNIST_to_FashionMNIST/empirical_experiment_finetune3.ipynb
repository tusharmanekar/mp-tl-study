# %% [markdown]
# # Example for:
# Transfer Learning Empirical Experiment from all 10 classes of MNIST into all 10 classes of FashionMNIST \
# Note that here we are using the same architecture we used in FashionMNIST folder, with 5 CNN layers and 1 linear layer

# %% [markdown]
# ### Setup and Hyperparams

# %%
# Specify which gpu
import os
gpu_id = 2
os.environ["CUDA_VISIBLE_DEVICES"] = str(gpu_id)

import sys
sys.path.append('/home/arnisaf/mp-tl-study')
from functions.utils import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)
    torch.cuda.manual_seed_all(0)  # if using multi-GPU

# %%
# cuts=0 means: end-to-end model if we are reinitializing
cuts = [0,1,2,3,4,5.6]

# %%
# Changes Here for the experiments
params = {
      # MODEL ARCHITECTURE PARAMS
      'depth': 6,
      'num_channels': 64,
      'kernel_size': 3,
      'activation_function': nn.ReLU,
      # TRAINING PARAMS
      'device': device,
      'lr_pretrain': 0.001,   
      'lr_fine_tune': 0.001, 
      'num_train': 40,
      'early_stop_patience': 6,
      'batch_size':4096,
      # DATASET PARAMS
      'pre_train_classes': list(range(10)),
      'fine_tune_classes': list(range(10)),
      # EXPERIMENT SETTING PARAMS
      'use_pooling': True,   # CHANGE
      'pooling_every_n_layers': 2, # add pooling after every n layers specified here. For only one pooling after all the CNN layers, this equals params['depth']
      # default value for pooling_every_n_layers is 1 (after each cnn layer)
      'pooling_stride': 2,
      'freeze': True,         # CHANGE: freeze the conv layers before the cut
      'reinit': True         # CHANGE: reinit the conv lyers only after the cut
      }

# %%
root_dir = './data'  # Specify your data directory here
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
dataloader_wrapped = TransferLearningWrapper(params, datasets.MNIST, datasets.FashionMNIST, root_dir, transform=transform)

# %%
dataloader_wrapped.pretrain_train_loader.dataset.__len__()
# Out:
# 54000

# %% [markdown]
# ## Pretraining

# %%
#Create DNN model
pretrained_model = CustomCNN(params, dataloader_wrapped.output_dim)
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=10, bias=True)
# )

# %%
# Train and evaluate
trainer = Trainer(pretrained_model, dataloader_wrapped, params["lr_pretrain"], params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 47.74%
# Validation Accuracy: 47.67%
# Epoch: 1 	Training Accuracy: 75.33%
# Validation Accuracy: 74.87%
# Epoch: 2 	Training Accuracy: 82.54%
# Validation Accuracy: 81.30%
# Epoch: 3 	Training Accuracy: 87.35%
# Validation Accuracy: 86.38%
# Epoch: 4 	Training Accuracy: 89.96%
# Validation Accuracy: 89.22%
# Epoch: 5 	Training Accuracy: 92.27%
# Validation Accuracy: 91.60%
# Epoch: 6 	Training Accuracy: 93.92%
# Validation Accuracy: 93.58%
# Epoch: 7 	Training Accuracy: 95.48%
# Validation Accuracy: 95.22%
# Epoch: 8 	Training Accuracy: 95.81%
# Validation Accuracy: 95.62%
# Epoch: 9 	Training Accuracy: 94.51%
# Validation Accuracy: 94.42%
# Epoch: 10 	Training Accuracy: 96.38%
# Validation Accuracy: 96.10%
# Epoch: 11 	Training Accuracy: 97.17%
# Validation Accuracy: 96.97%
# Epoch: 12 	Training Accuracy: 97.34%
# Validation Accuracy: 97.03%
# Epoch: 13 	Training Accuracy: 97.67%
# Validation Accuracy: 97.30%
# Epoch: 14 	Training Accuracy: 97.27%
# Validation Accuracy: 97.13%
# Epoch: 15 	Training Accuracy: 97.97%
# Validation Accuracy: 97.60%
# Epoch: 16 	Training Accuracy: 98.11%
# Validation Accuracy: 97.85%
# Epoch: 17 	Training Accuracy: 97.84%
# Validation Accuracy: 97.38%
# Epoch: 18 	Training Accuracy: 98.31%
# Validation Accuracy: 97.95%
# Epoch: 19 	Training Accuracy: 98.27%
# Validation Accuracy: 97.85%
# Epoch: 20 	Training Accuracy: 98.30%
# Validation Accuracy: 98.02%
# Epoch: 21 	Training Accuracy: 98.37%
# Validation Accuracy: 97.93%
# Epoch: 22 	Training Accuracy: 98.14%
# Validation Accuracy: 97.83%
# Epoch: 23 	Training Accuracy: 98.53%
# Validation Accuracy: 98.10%
# Epoch: 24 	Training Accuracy: 98.67%
# Validation Accuracy: 98.17%
# Epoch: 25 	Training Accuracy: 98.60%
# Validation Accuracy: 98.18%
# Epoch: 26 	Training Accuracy: 98.47%
# Validation Accuracy: 97.95%
# Epoch: 27 	Training Accuracy: 98.92%
# Validation Accuracy: 98.37%
# Epoch: 28 	Training Accuracy: 98.87%
# Validation Accuracy: 98.38%
# Epoch: 29 	Training Accuracy: 98.91%
# Validation Accuracy: 98.50%
# Epoch: 30 	Training Accuracy: 98.82%
# Validation Accuracy: 98.33%
# Epoch: 31 	Training Accuracy: 99.00%
# Validation Accuracy: 98.45%
# Epoch: 32 	Training Accuracy: 98.90%
# Validation Accuracy: 98.40%
# Epoch: 33 	Training Accuracy: 99.10%
# Validation Accuracy: 98.70%
# Epoch: 34 	Training Accuracy: 99.06%
# Validation Accuracy: 98.57%
# Epoch: 35 	Training Accuracy: 99.12%
# Validation Accuracy: 98.58%
# Epoch: 36 	Training Accuracy: 98.85%
# Validation Accuracy: 98.23%
# Epoch: 37 	Training Accuracy: 98.85%
# Validation Accuracy: 98.33%
# Epoch: 38 	Training Accuracy: 99.21%
# Validation Accuracy: 98.70%
# Epoch: 39 	Training Accuracy: 98.33%
# Validation Accuracy: 97.85%
# Early stopping invoked.
# Final Training Accuracy: 0.9910
# Final Test Accuracy: 0.9906

# %%
#torch.save(pretrained_model.state_dict(), 'pretrained_models/pretrained_model_only_numbers_new.pth')

# %%
pretrained_model.load_state_dict(torch.load('pretrained_models/pretrained_model_only_numbers_new.pth'))
pretrained_model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act3): ReLU()
#   (pool3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act4): ReLU()
#   (conv5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act5): ReLU()
#   (pool5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc): Linear(in_features=576, out_features=10, bias=True)
# )

# %%
eval(pretrained_model, device, dataloader_wrapped.test_loader, debug=True, classification_report_flag=True, is_cnn=True)
# Out:
# Average loss: 0.0307, Accuracy: 59436.0/60000 (99%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.99      1.00      1.00      5923
#      Class 1       0.99      1.00      0.99      6742
#      Class 2       0.99      0.99      0.99      5958
#      Class 3       0.99      0.99      0.99      6131
#      Class 4       0.99      0.99      0.99      5842
#      Class 5       0.99      0.99      0.99      5421
#      Class 6       0.99      0.99      0.99      5918
#      Class 7       0.99      1.00      0.99      6265
#      Class 8       0.99      0.98      0.99      5851
#      Class 9       0.98      0.99      0.98      5949
#
#     accuracy                           0.99     60000
#    macro avg       0.99      0.99      0.99     60000
# weighted avg       0.99      0.99      0.99     60000
# 0.9906

# %%
# save model for later use
foldername = "pretrained_models/pretrained_mnist_to_fashion_all_classes"
os.mkdir(foldername)
torch.save(pretrained_model.state_dict(), os.path.join(foldername, 'pretrained_model.pth'))

params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp.get("activation_function", nn.ReLU))
#save params as well
with open(os.path.join(foldername, 'params.json'), 'w') as fp:
    json.dump(params_tmp, fp)

# %% [markdown]
# ## Fine-tuning Experiments

# %%
# load results: to continue from a checkpoint (actually don't run)
with open('results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Baselines (End-to-end models trained on subsets of fine-tuning dataset)
# We also reuse the baselines a lot! so skip if we already have the jsons

# %%
baselines_results = []
percentages = [0.001, 0.01, 0.1, 0.5, 1.0]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:      
    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
    
    for repeat in range(repeats):
        # Print or log the sampled values for transparency
        print(f"\nSampled Percentage: {sampled_percentage}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

        # Reduce the dataset
        train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        torch.manual_seed(repeat)
        #train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed = repeat)
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)

        # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
        params_tmp = copy.deepcopy(params)
        params_tmp["reinit"] = True
        model_new = cut_custom_cnn_model(pretrained_model, cut_point=0, params=params_tmp, output_dim=dataloader_wrapped.output_dim)
        model_new.to(device)

        # Train and evaluate
        trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
        train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
        print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

        # Store the results
        baselines_results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":-1, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc}) # -1 for the cut point means it's baseline
# Out:
# Sampled Percentage: 0.001, Lr: 0.001, Repeat: 0

# %%
print(baselines_results)

# %%
# save baseline results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/baselines_freeze_{params["freeze"]}_pool_{params["use_pooling"]}_lr_{params["lr_fine_tune"]}_dummy_run.json', 'w') as f:
    json.dump(results, f)

# %% [markdown]
# ### Fine-tuning

# %%
results = []
#percentages = [0.001, 0.01, 0.1, 0.5, 1.0]
percentages = [0.1]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8093, Test Accuracy: 0.7930
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.7906, Test Accuracy: 0.7855
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.7478, Test Accuracy: 0.7487
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.7702, Test Accuracy: 0.7667
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.7754, Test Accuracy: 0.7689
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.7856, Test Accuracy: 0.7838
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.7787, Test Accuracy: 0.7705
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.7735, Test Accuracy: 0.7638
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.7635, Test Accuracy: 0.7632
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.7670, Test Accuracy: 0.7599
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.7843, Test Accuracy: 0.7750
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.7737, Test Accuracy: 0.7612
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.7648, Test Accuracy: 0.7530
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.7798, Test Accuracy: 0.7744
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.7700, Test Accuracy: 0.7596
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.7796, Test Accuracy: 0.7742
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.7848, Test Accuracy: 0.7726
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.7869, Test Accuracy: 0.7809
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.7889, Test Accuracy: 0.7817
#
# Sampled Percentage: 0.1, Sampled Cut Point: 0, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.7587, Test Accuracy: 0.7624
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.7856, Test Accuracy: 0.7735
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.7850, Test Accuracy: 0.7805
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 2
# Early stopping invoked.
# Training Accuracy: 0.7735, Test Accuracy: 0.7669
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.7889, Test Accuracy: 0.7832
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.7800, Test Accuracy: 0.7726
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.7819, Test Accuracy: 0.7774
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.7589, Test Accuracy: 0.7511
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.7874, Test Accuracy: 0.7772
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.7626, Test Accuracy: 0.7586
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.7763, Test Accuracy: 0.7739
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.7889, Test Accuracy: 0.7779
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.7893, Test Accuracy: 0.7778
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.7800, Test Accuracy: 0.7692
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.7687, Test Accuracy: 0.7655
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.7593, Test Accuracy: 0.7496
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.7769, Test Accuracy: 0.7670
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.7931, Test Accuracy: 0.7788
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.7824, Test Accuracy: 0.7692
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.7900, Test Accuracy: 0.7817
#
# Sampled Percentage: 0.1, Sampled Cut Point: 1, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.7770, Test Accuracy: 0.7815
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.7880, Test Accuracy: 0.7811
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.7930, Test Accuracy: 0.7769
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.7798, Test Accuracy: 0.7724
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.7781, Test Accuracy: 0.7741
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.8013, Test Accuracy: 0.7909
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.7593, Test Accuracy: 0.7478
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.7578, Test Accuracy: 0.7497
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.7928, Test Accuracy: 0.7761
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.7831, Test Accuracy: 0.7761
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.7854, Test Accuracy: 0.7732
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 10
# Early stopping invoked.
# Training Accuracy: 0.7650, Test Accuracy: 0.7576
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.7659, Test Accuracy: 0.7566
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.7980, Test Accuracy: 0.7839
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.7570, Test Accuracy: 0.7489
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 14
# Early stopping invoked.
# Training Accuracy: 0.7648, Test Accuracy: 0.7556
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.7607, Test Accuracy: 0.7516
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.7889, Test Accuracy: 0.7754
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.7481, Test Accuracy: 0.7453
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.8000, Test Accuracy: 0.7880
#
# Sampled Percentage: 0.1, Sampled Cut Point: 2, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.7696, Test Accuracy: 0.7681
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8152, Test Accuracy: 0.7966
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.7993, Test Accuracy: 0.7879
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8030, Test Accuracy: 0.7886
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.7789, Test Accuracy: 0.7726
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.7806, Test Accuracy: 0.7672
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.7996, Test Accuracy: 0.7912
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.8017, Test Accuracy: 0.7873
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.7894, Test Accuracy: 0.7742
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.7980, Test Accuracy: 0.7861
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.8002, Test Accuracy: 0.7859
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.8111, Test Accuracy: 0.7941
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.8107, Test Accuracy: 0.7897
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.8007, Test Accuracy: 0.7809
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.8013, Test Accuracy: 0.7892
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.8061, Test Accuracy: 0.7917
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.7959, Test Accuracy: 0.7870
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.8009, Test Accuracy: 0.7848
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.7919, Test Accuracy: 0.7842
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.7991, Test Accuracy: 0.7877
#
# Sampled Percentage: 0.1, Sampled Cut Point: 3, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.7943, Test Accuracy: 0.7869
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8044, Test Accuracy: 0.7871
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8144, Test Accuracy: 0.8000
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8191, Test Accuracy: 0.8012
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8150, Test Accuracy: 0.8009
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.8235, Test Accuracy: 0.8086
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 5
# Early stopping invoked.
# Training Accuracy: 0.7869, Test Accuracy: 0.7819
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.8041, Test Accuracy: 0.7950
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8263, Test Accuracy: 0.8084
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.8269, Test Accuracy: 0.8073
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.8063, Test Accuracy: 0.7898
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.8254, Test Accuracy: 0.8043
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.8139, Test Accuracy: 0.7978
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.8167, Test Accuracy: 0.7966
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.8107, Test Accuracy: 0.7998
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.8272, Test Accuracy: 0.8106
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.8152, Test Accuracy: 0.8035
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.8174, Test Accuracy: 0.8058
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.8122, Test Accuracy: 0.7994
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.8100, Test Accuracy: 0.7949
#
# Sampled Percentage: 0.1, Sampled Cut Point: 4, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.8130, Test Accuracy: 0.7975
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5.6, Lr: 0.001, Repeat: 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-bf55f78cc5f7> in <module>
#      25
#      26             # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
# ---> 27             model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
#      28             model_new.to(device)
#      29
#
# ~/mp-tl-study/functions/utils.py in cut_custom_cnn_model(model, cut_point, params, output_dim)
#     315     # If freeze is True, set requires_grad to False for layers before cut_point
#     316     if params.get("freeze", None):
# --> 317         for idx in conv_indices[:cut_point]:
#     318             for param in getattr(new_model, layer_names[idx]).parameters():
#     319                 param.requires_grad = False
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.8092592592592592, 'test_acc': 0.79295}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.7905555555555556, 'test_acc': 0.7855}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.7477777777777778, 'test_acc': 0.7487333333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.7701851851851852, 'test_acc': 0.76665}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.7753703703703704, 'test_acc': 0.7688833333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.7855555555555556, 'test_acc': 0.7838333333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.7787037037037037, 'test_acc': 0.7705}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.7735185185185185, 'test_acc': 0.7637833333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.7635185185185185, 'test_acc': 0.7632333333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.7670370370370371, 'test_acc': 0.7599}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.7842592592592592, 'test_acc': 0.7750333333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.7737037037037037, 'test_acc': 0.7611833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.7648148148148148, 'test_acc': 0.7529666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.7798148148148148, 'test_acc': 0.77445}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.77, 'test_acc': 0.7596}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.7796296296296297, 'test_acc': 0.7742}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.7848148148148149, 'test_acc': 0.7725833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.7868518518518518, 'test_acc': 0.7808833333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.7888888888888889, 'test_acc': 0.7816666666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.7587037037037037, 'test_acc': 0.7624166666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.7855555555555556, 'test_acc': 0.7735166666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.785, 'test_acc': 0.7805}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.7735185185185185, 'test_acc': 0.7669166666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 3, 'train_acc': 0.7888888888888889, 'test_acc': 0.78315}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 4, 'train_acc': 0.78, 'test_acc': 0.7725833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 5, 'train_acc': 0.7818518518518518, 'test_acc': 0.7773833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 6, 'train_acc': 0.7588888888888888, 'test_acc': 0.7510833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 7, 'train_acc': 0.7874074074074074, 'test_acc': 0.7772166666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 8, 'train_acc': 0.7625925925925926, 'te ...

# %%
cuts = [5,6]

# %%
dataloader_wrapped.update_phase('finetune')

for sampled_percentage in percentages:

    if sampled_percentage <= 0.01:
        repeats = 25
    elif sampled_percentage < 0.5:
        repeats = 20
    else:
        repeats = 5
        
    for sampled_cut_point in cuts:

        for repeat in range(repeats):
            # Add the combination to the tested set
            # tested_combinations.add((sampled_percentage, sampled_cut_point))

            # Print or log the sampled values for transparency
            print(f"\nSampled Percentage: {sampled_percentage}, Sampled Cut Point: {sampled_cut_point}, Lr: {params['lr_fine_tune']}, Repeat: {repeat}")

            # Reduce the dataset
            train_loader_reduced = reduce_dataset(dataloader_wrapped.train_loader, sampled_percentage, seed=repeat)
            dataset_namespace_new = SimpleNamespace(train_loader=train_loader_reduced, test_loader=dataloader_wrapped.test_loader, val_loader=dataloader_wrapped.val_loader)
            torch.manual_seed(repeat) # because in the cut function we reinitialize some layers too (at least the dense layers)
            
            # Copy and then cut the model - we already deepcopy it in the function: pretrained_model
            model_new = cut_custom_cnn_model(pretrained_model, cut_point=sampled_cut_point, params=params, output_dim=dataloader_wrapped.output_dim)
            model_new.to(device)
            
            # Train and evaluate
            trainer = Trainer(model_new, dataset_namespace_new, params['lr_fine_tune'], params)
            train_acc, test_acc, effective_epochs, checkpoints = trainer.train(verbose=0)
            print(f"Training Accuracy: {train_acc:.4f}, Test Accuracy: {test_acc:.4f}")

            # Store the results
            results.append({"lr":params['lr_fine_tune'], "sampled_percentage":sampled_percentage, "sampled_cut_point":sampled_cut_point, "repeat":repeat, "train_acc":train_acc, "test_acc":test_acc})
# Out:
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.8322, Test Accuracy: 0.8104
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.8311, Test Accuracy: 0.8091
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8144, Test Accuracy: 0.7972
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.8006, Test Accuracy: 0.7908
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.8294, Test Accuracy: 0.8122
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.8291, Test Accuracy: 0.8110
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.8037, Test Accuracy: 0.7952
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.8294, Test Accuracy: 0.8098
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.8291, Test Accuracy: 0.8105
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.8315, Test Accuracy: 0.8116
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.8363, Test Accuracy: 0.8170
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.8315, Test Accuracy: 0.8083
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.8233, Test Accuracy: 0.8028
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.8187, Test Accuracy: 0.7996
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.8263, Test Accuracy: 0.8062
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.8172, Test Accuracy: 0.7985
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.8176, Test Accuracy: 0.7987
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.8206, Test Accuracy: 0.8095
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.8122, Test Accuracy: 0.7959
#
# Sampled Percentage: 0.1, Sampled Cut Point: 5, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.8269, Test Accuracy: 0.8125
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 0
# Training Accuracy: 0.7956, Test Accuracy: 0.7807
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 1
# Training Accuracy: 0.7846, Test Accuracy: 0.7671
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 2
# Training Accuracy: 0.8022, Test Accuracy: 0.7834
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 3
# Training Accuracy: 0.7713, Test Accuracy: 0.7651
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 4
# Training Accuracy: 0.7933, Test Accuracy: 0.7805
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 5
# Training Accuracy: 0.7813, Test Accuracy: 0.7748
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 6
# Training Accuracy: 0.7561, Test Accuracy: 0.7536
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 7
# Training Accuracy: 0.7859, Test Accuracy: 0.7710
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 8
# Training Accuracy: 0.7796, Test Accuracy: 0.7735
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 9
# Training Accuracy: 0.7920, Test Accuracy: 0.7782
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 10
# Training Accuracy: 0.7820, Test Accuracy: 0.7751
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 11
# Training Accuracy: 0.7780, Test Accuracy: 0.7667
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 12
# Training Accuracy: 0.7843, Test Accuracy: 0.7726
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 13
# Training Accuracy: 0.7848, Test Accuracy: 0.7716
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 14
# Training Accuracy: 0.7965, Test Accuracy: 0.7787
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 15
# Training Accuracy: 0.7956, Test Accuracy: 0.7810
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 16
# Training Accuracy: 0.7911, Test Accuracy: 0.7763
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 17
# Training Accuracy: 0.7900, Test Accuracy: 0.7791
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 18
# Training Accuracy: 0.7822, Test Accuracy: 0.7720
#
# Sampled Percentage: 0.1, Sampled Cut Point: 6, Lr: 0.001, Repeat: 19
# Training Accuracy: 0.7748, Test Accuracy: 0.7680

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.8092592592592592, 'test_acc': 0.79295}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.7905555555555556, 'test_acc': 0.7855}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.7477777777777778, 'test_acc': 0.7487333333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.7701851851851852, 'test_acc': 0.76665}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.7753703703703704, 'test_acc': 0.7688833333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.7855555555555556, 'test_acc': 0.7838333333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.7787037037037037, 'test_acc': 0.7705}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.7735185185185185, 'test_acc': 0.7637833333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.7635185185185185, 'test_acc': 0.7632333333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.7670370370370371, 'test_acc': 0.7599}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.7842592592592592, 'test_acc': 0.7750333333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.7737037037037037, 'test_acc': 0.7611833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.7648148148148148, 'test_acc': 0.7529666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.7798148148148148, 'test_acc': 0.77445}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.77, 'test_acc': 0.7596}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.7796296296296297, 'test_acc': 0.7742}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.7848148148148149, 'test_acc': 0.7725833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.7868518518518518, 'test_acc': 0.7808833333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.7888888888888889, 'test_acc': 0.7816666666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.7587037037037037, 'test_acc': 0.7624166666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.7855555555555556, 'test_acc': 0.7735166666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.785, 'test_acc': 0.7805}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.7735185185185185, 'test_acc': 0.7669166666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 3, 'train_acc': 0.7888888888888889, 'test_acc': 0.78315}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 4, 'train_acc': 0.78, 'test_acc': 0.7725833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 5, 'train_acc': 0.7818518518518518, 'test_acc': 0.7773833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 6, 'train_acc': 0.7588888888888888, 'test_acc': 0.7510833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 7, 'train_acc': 0.7874074074074074, 'test_acc': 0.7772166666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 8, 'train_acc': 0.7625925925925926, 'te ...

# %%
print(results)
# Out:
# [{'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 0, 'train_acc': 0.8092592592592592, 'test_acc': 0.79295}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 1, 'train_acc': 0.7905555555555556, 'test_acc': 0.7855}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 2, 'train_acc': 0.7477777777777778, 'test_acc': 0.7487333333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 3, 'train_acc': 0.7701851851851852, 'test_acc': 0.76665}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 4, 'train_acc': 0.7753703703703704, 'test_acc': 0.7688833333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 5, 'train_acc': 0.7855555555555556, 'test_acc': 0.7838333333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 6, 'train_acc': 0.7787037037037037, 'test_acc': 0.7705}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 7, 'train_acc': 0.7735185185185185, 'test_acc': 0.7637833333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 8, 'train_acc': 0.7635185185185185, 'test_acc': 0.7632333333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 9, 'train_acc': 0.7670370370370371, 'test_acc': 0.7599}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 10, 'train_acc': 0.7842592592592592, 'test_acc': 0.7750333333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 11, 'train_acc': 0.7737037037037037, 'test_acc': 0.7611833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 12, 'train_acc': 0.7648148148148148, 'test_acc': 0.7529666666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 13, 'train_acc': 0.7798148148148148, 'test_acc': 0.77445}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 14, 'train_acc': 0.77, 'test_acc': 0.7596}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 15, 'train_acc': 0.7796296296296297, 'test_acc': 0.7742}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 16, 'train_acc': 0.7848148148148149, 'test_acc': 0.7725833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 17, 'train_acc': 0.7868518518518518, 'test_acc': 0.7808833333333334}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 18, 'train_acc': 0.7888888888888889, 'test_acc': 0.7816666666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 0, 'repeat': 19, 'train_acc': 0.7587037037037037, 'test_acc': 0.7624166666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 0, 'train_acc': 0.7855555555555556, 'test_acc': 0.7735166666666666}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 1, 'train_acc': 0.785, 'test_acc': 0.7805}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 2, 'train_acc': 0.7735185185185185, 'test_acc': 0.7669166666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 3, 'train_acc': 0.7888888888888889, 'test_acc': 0.78315}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 4, 'train_acc': 0.78, 'test_acc': 0.7725833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 5, 'train_acc': 0.7818518518518518, 'test_acc': 0.7773833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 6, 'train_acc': 0.7588888888888888, 'test_acc': 0.7510833333333333}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 7, 'train_acc': 0.7874074074074074, 'test_acc': 0.7772166666666667}, {'lr': 0.001, 'sampled_percentage': 0.1, 'sampled_cut_point': 1, 'repeat': 8, 'train_acc': 0.7625925925925926, 'te ...

# %%
# save fine-tuning results
params_tmp = copy.deepcopy(params)
del params_tmp["device"]
params_tmp["activation_function"] = str(params_tmp["activation_function"])
results = [params_tmp] + results

with open(f'results_jsons/results_freeze_{params["freeze"]}_reinit_{params["reinit"]}_pool_{params["use_pooling"]}_lr_{params["lr_fine_tune"]}_MNIST_to_Fashion_{percentages[0]}_to_{percentages[-1]}.json', 'w') as f:
    json.dump(results, f)
results = results[1:]

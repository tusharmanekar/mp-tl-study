# %%
from utils import *
from data_utils import *
from metrics import *
from plots import *

from sklearn.datasets import make_blobs
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from numpy import where
from matplotlib import pyplot
from types import SimpleNamespace
from tqdm import tqdm

# %%
# ---------------------------------------- DATA GENERATION ------------------------------------
# generate samples for blobs problem with a given random seed
def samples_for_seed(seed, num_classes=3):
    # generate samples
    X, y = make_blobs(n_samples=1000, centers=num_classes, n_features=2, cluster_std=2, random_state=seed)
    return X, y

def prep_samples(X, y, n_train = 500):
    trainX, testX = X[:n_train, :], X[n_train:, :]
    trainy, testy = y[:n_train], y[n_train:]

    # Create DataLoaders
    train_dataset = TensorDataset(torch.FloatTensor(trainX), torch.LongTensor(trainy))
    test_dataset = TensorDataset(torch.FloatTensor(testX), torch.LongTensor(testy))
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)
    return train_loader, test_loader
 
# --------------------------------------------- PLOTS --------------------------------------------
# create a scatter plot of points colored by class value
def plot_samples(X, y, classes=3):
    # plot points for each class
    for i in range(classes):
        # select indices of points with each class label
        samples_ix = where(y == i)
        # plot points for this class with a given color
        pyplot.scatter(X[samples_ix, 0], X[samples_ix, 1])

def plot_decision_boundary(model, X, y, n_classes):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1))

    with torch.no_grad():
        model.eval()
        Z = model(torch.FloatTensor(np.c_[xx.ravel(), yy.ravel()])).numpy()
        Z = np.argmax(Z, axis=1)

    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, alpha=0.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o', linewidth=1)
    plt.title("Decision Boundary")
    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")

    for i in range(n_classes):
        plt.scatter([], [], c='k', alpha=0.8, s=20, label=f"Class {i}")
    plt.legend(loc='upper left')

    plt.show()

def plot_layer_ranks(model):
    ranks = []
    layer_names = []
    
    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            rank = np.linalg.matrix_rank(weight_matrix)
            ranks.append(rank)
            layer_names.append(name)
    
    # Plotting
    plt.figure(figsize=(15, 6))
    plt.bar(layer_names, ranks, color='blue')
    plt.xlabel('Layer')
    plt.ylabel('Rank')
    plt.title('Rank of Weight Matrices for Each Layer')
    plt.grid(True)
    
    y_max = np.max(ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(y_min, y_max, step=2))  # Set yticks

    plt.show()

def effective_rank(singular_values):
    normalized_singular_values = singular_values / np.sum(singular_values)
    entropy = -np.sum(normalized_singular_values * np.log(normalized_singular_values))
    eff_rank = np.exp(entropy)
    return eff_rank

def plot_layer_effective_ranks(model):
    effective_ranks = []
    layer_names = []
    
    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            singular_values = np.linalg.svd(weight_matrix, compute_uv=False)
            eff_rank = effective_rank(singular_values)
            effective_ranks.append(eff_rank)
            layer_names.append(name)
    
    # Plotting
    plt.figure(figsize=(35, 12))
    plt.bar(layer_names, effective_ranks, color='green')
    plt.xlabel('Layer')
    plt.ylabel('Effective Rank')
    plt.title('Effective Rank of Weight Matrices for Each Layer')
    plt.grid(True)
    
    y_max = np.max(effective_ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(effective_ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(0, int(y_max)+2, step=2))  # Set yticks

    plt.show()

# -------------------------------------- MODEL FUNCTIONS --------------------------------------------
# define and fit model on a training dataset
def fit_model(train_loader, test_loader, verbose=False):
    # define model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    params = dict(device=device,
        width=5, lr=0.005, num_train=100,
        sb=0.05, depth=3, sw=1.7346938775510203, early_stop_patience = None, activation_function='relu')
    # Create DNN model
    input_dim = 2  # 2D data points
    output_dim = 3  # Number of classes
    model = generate_fc_dnn(input_dim, output_dim, params, gaussian_init=False, activation_function=nn.ReLU)

    # train
    # Create a 'Namespace' to supply to the training function (to comply with your function's requirements)
    dataset_namespace = SimpleNamespace(train_loader=train_loader, test_loader=test_loader, val_loader=test_loader)
    train_acc, test_acc, model, _ = compute_training_acc_epochs(model, dataset_namespace, params, debug=verbose)

    if verbose:
        print(f"Final Training Accuracy: {train_acc:.4f}")
        print(f"Final Test Accuracy: {test_acc:.4f}")
    return model

def fine_tune_model(pretrained_model, train_loader, test_loader, verbose=False):
    model = copy.deepcopy(pretrained_model)
    # define model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    params = dict(device=device,
        width=5, lr=0.005, num_train=100,
        sb=0.05, depth=3, sw=1.7346938775510203, early_stop_patience = None, activation_function='relu')
    # train
    # Create a 'Namespace' to supply to the training function (to comply with your function's requirements)
    dataset_namespace = SimpleNamespace(train_loader=train_loader, test_loader=test_loader, val_loader=test_loader)
    train_acc, test_acc, model, _ = compute_training_acc_epochs(model, dataset_namespace, params, debug=verbose)

    if verbose:
        print(f"Final Training Accuracy: {train_acc:.4f}")
        print(f"Final Test Accuracy: {test_acc:.4f}")
    return model

def eval(model, device, dataset_loader, debug=False):
    model.eval()
    test_loss, correct = 0., 0.
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for data, target in dataset_loader:
            data, target = data.reshape([data.shape[0], -1]).to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(
                output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(
                dim=1,
                keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(target.cpu().numpy())

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data
    if debug:
        print('\nTrain set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.
              format(test_loss, correct, num_data, 100. * acc))
        print(classification_report(all_labels, all_preds, target_names=[f'Class {i}' for i in range(len(set(all_labels)))]))
    return acc

# --------------------------------------- EXPERIMENTS -----------------------------------------------------
# repeatedly train (or fine-tune) and evaluate the trained (or fine-tuned) model
# also if we are fine-tuning, freeze the first cut_point layers 
def eval_multiple_experiments(train_loader, test_loader, n_repeats, pretrained_model=None, cut_point=0, debug=False):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    scores = list()
    for _ in tqdm(range(n_repeats)):
		# define and fit a new model on the train dataset
        if pretrained_model:
            model = fine_tune_model(pretrained_model, train_loader, test_loader)
            layers = list(model.children())
            for i in range(cut_point):
                for param in layers[2*i].parameters():
                    param.requires_grad = False
        else:
            model = fit_model(train_loader, test_loader)
		# evaluate model on test dataset
        test_acc = eval(model, device, test_loader, debug)
        scores.append(test_acc)
    return scores

# %% [markdown]
# # Generate Data for Problems 1 and 2: Pretrain on 1 and Fine-tune on 2

# %%
# generate multiple problems
n_problems = 2
for i in range(1, n_problems+1):
    # specify subplot
    pyplot.subplot(210 + i)
    # generate samples
    X, y = samples_for_seed(i)
    # scatter plot of samples
    plot_samples(X, y)
# plot figure
pyplot.show()

# %% [markdown]
# # Pretrain a Model on Problem 1

# %%
X, y = samples_for_seed(1)
train_loader, test_loader = prep_samples(X, y)

# %%
pretrained_model = fit_model(train_loader, test_loader, verbose=True)
# Out:
# Epoch: 0 	Training Accuracy: 35.40%
# Validation Accuracy: 31.20%
# Epoch: 1 	Training Accuracy: 35.40%
# Validation Accuracy: 31.20%
# Epoch: 2 	Training Accuracy: 35.40%
# Validation Accuracy: 31.20%
# Epoch: 3 	Training Accuracy: 35.40%
# Validation Accuracy: 31.20%
# Epoch: 4 	Training Accuracy: 35.40%
# Validation Accuracy: 31.20%
# Epoch: 5 	Training Accuracy: 36.40%
# Validation Accuracy: 31.80%
# Epoch: 6 	Training Accuracy: 47.60%
# Validation Accuracy: 46.40%
# Epoch: 7 	Training Accuracy: 58.40%
# Validation Accuracy: 59.80%
# Epoch: 8 	Training Accuracy: 71.60%
# Validation Accuracy: 74.60%
# Epoch: 9 	Training Accuracy: 75.80%
# Validation Accuracy: 77.40%
# Epoch: 10 	Training Accuracy: 78.80%
# Validation Accuracy: 79.40%
# Epoch: 11 	Training Accuracy: 82.20%
# Validation Accuracy: 81.80%
# Epoch: 12 	Training Accuracy: 85.40%
# Validation Accuracy: 85.00%
# Epoch: 13 	Training Accuracy: 85.80%
# Validation Accuracy: 85.40%
# Epoch: 14 	Training Accuracy: 85.80%
# Validation Accuracy: 85.20%
# Epoch: 15 	Training Accuracy: 88.60%
# Validation Accuracy: 88.00%
# Epoch: 16 	Training Accuracy: 88.20%
# Validation Accuracy: 87.00%
# Epoch: 17 	Training Accuracy: 90.20%
# Validation Accuracy: 90.00%
# Epoch: 18 	Training Accuracy: 89.80%
# Validation Accuracy: 90.00%
# Epoch: 19 	Training Accuracy: 90.00%
# Validation Accuracy: 90.20%
# Epoch: 20 	Training Accuracy: 90.60%
# Validation Accuracy: 90.60%
# Epoch: 21 	Training Accuracy: 90.80%
# Validation Accuracy: 91.40%
# Epoch: 22 	Training Accuracy: 91.00%
# Validation Accuracy: 91.00%
# Epoch: 23 	Training Accuracy: 91.00%
# Validation Accuracy: 90.80%
# Epoch: 24 	Training Accuracy: 90.80%
# Validation Accuracy: 91.00%
# Epoch: 25 	Training Accuracy: 90.20%
# Validation Accuracy: 91.80%
# Epoch: 26 	Training Accuracy: 91.20%
# Validation Accuracy: 92.00%
# Epoch: 27 	Training Accuracy: 91.40%
# Validation Accuracy: 92.40%
# Epoch: 28 	Training Accuracy: 91.60%
# Validation Accuracy: 92.80%
# Epoch: 29 	Training Accuracy: 91.20%
# Validation Accuracy: 91.80%
# Epoch: 30 	Training Accuracy: 92.00%
# Validation Accuracy: 92.40%
# Epoch: 31 	Training Accuracy: 92.00%
# Validation Accuracy: 93.20%
# Epoch: 32 	Training Accuracy: 92.20%
# Validation Accuracy: 92.80%
# Epoch: 33 	Training Accuracy: 92.00%
# Validation Accuracy: 92.40%
# Epoch: 34 	Training Accuracy: 91.80%
# Validation Accuracy: 93.40%
# Epoch: 35 	Training Accuracy: 91.60%
# Validation Accuracy: 92.40%
# Epoch: 36 	Training Accuracy: 91.80%
# Validation Accuracy: 93.60%
# Epoch: 37 	Training Accuracy: 91.80%
# Validation Accuracy: 92.40%
# Epoch: 38 	Training Accuracy: 92.20%
# Validation Accuracy: 93.40%
# Epoch: 39 	Training Accuracy: 92.00%
# Validation Accuracy: 93.20%
# Epoch: 40 	Training Accuracy: 91.80%
# Validation Accuracy: 92.40%
# Epoch: 41 	Training Accuracy: 92.40%
# Validation Accuracy: 93.60%
# Epoch: 42 	Training Accuracy: 92.20%
# Validation Accuracy: 93.60%
# Epoch: 43 	Training Accuracy: 92.20%
# Validation Accuracy: 93.00%
# Epoch: 44 	Training Accuracy: 92.20%
# Validation Accuracy: 93.00%
# Epoch: 45 	Training Accuracy: 92.40%
# Validation Accuracy: 93.80%
# Epoch: 46 	Training Accuracy: 92.40%
# Validation Accuracy: 93.00%
# Epoch: 47 	Training Accuracy: 92.40%
# Validation Accuracy: 93.20%
# Epoch: 48 	Training Accuracy: 92.40%
# Validation Accuracy: 93.00%
# Epoch: 49 	Training Accuracy: 92.40%
# Validation Accuracy: 93.00%
# Epoch: 50 	Training Accuracy: 92.20%
# Validation Accuracy: 93.20%
# Epoch: 51 	Training Accuracy: 92.40%
# Validation Accuracy: 92.60%
# Epoch: 52 	Training Accuracy: 92.00%
# Validation Accuracy: 93.20%
# Epoch: 53 	Training Accuracy: 92.20%
# Validation Accuracy: 93.20%
# Epoch: 54 	Training Accuracy: 92.60%
# Validation Accuracy: 93.20%
# Epoch: 55 	Training Accuracy: 92.40%
# Validation Accuracy: 92.60%
# Epoch: 56 	Training Accuracy: 92.60%
# Validation Accuracy: 93.40%
# Epoch: 57 	Training Accuracy: 92.00%
# Validation Accuracy: 93.20%
# Epoch: 58 	Training Accuracy: 92.60%
# Validation Accuracy: 93.40%
# Epoch: 59 	Training Accuracy: 92.20%
# Validation Accuracy: 93.20%
# Epoch: 60 	Training Accuracy: 92.40%
# Validation Accuracy: 92.60%
# Epoch: 61 	Training Accuracy: 92.40%
# Validation Accuracy: 93.00%
# Epoch: 62 	Training Accuracy: 92.20%
# Validation Accuracy: 93.20%
# Epoch: 63 	Training Accuracy: 92.00%
# Validation Accuracy: 93.20%
# Epoch: 64 	Training Accuracy: 92.20%
# Validation Accuracy: 93.00%
# Epoch: 65 	Training Accuracy: 92.20%
# Validation Accuracy: 93.00%
# Epoch: 66 	Training Accuracy: 92.40%
# Validation Accuracy: 92.40%
# Epoch: 67 	Training Accuracy: 92.80%
# Validation Accuracy: 93.20%
# Epoch: 68 	Training Accuracy: 92.20%
# Validation Accuracy: 93.00%
# Epoch: 69 	Training Accuracy: 92.40%
# Validation Accuracy: 92.80%
# Epoch: 70 	Training Accuracy: 92.00%
# Validation Accuracy: 93.00%
# Epoch: 71 	Training Accuracy: 91.20%
# Validation Accuracy: 93.20%
# Epoch: 72 	Training Accuracy: 92.40%
# Validation Accuracy: 93.00%
# Epoch: 73 	Training Accuracy: 92.80%
# Validation Accuracy: 93.20%
# Epoch: 74 	Training Accuracy: 92.60%
# Validation Accuracy: 93.00%
# Epoch: 75 	Training Accuracy: 92.20%
# Validation Accuracy: 93.00%
# Epoch: 76 	Training Accuracy: 92.60%
# Validation Accuracy: 92.40%
# Epoch: 77 	Training Accuracy: 92.20%
# Validation Accuracy: 93.00%
# Epoch: 78 	Training Accuracy: 92.00%
# Validation Accuracy: 92.00%
# Epoch: 79 	Training Accuracy: 92.80%
# Validation Accuracy: 93.20%
# Epoch: 80 	Training Accuracy: 92.20%
# Validation Accuracy: 92.40%
# Epoch: 81 	Training Accuracy: 92.60%
# Validation Accuracy: 93.20%
# Epoch: 82 	Training Accuracy: 93.00%
# Validation Accuracy: 93.20%
# Epoch: 83 	Training Accuracy: 92.20%
# Validation Accuracy: 92.00%
# Epoch: 84 	Training Accuracy: 92.20%
# Validation Accuracy: 92.40%
# Epoch: 85 	Training Accuracy: 91.60%
# Validation Accuracy: 93.40%
# Epoch: 86 	Training Accuracy: 92.40%
# Validation Accuracy: 93.00%
# Epoch: 87 	Training Accuracy: 92.40%
# Validation Accuracy: 93.00%
# Epoch: 88 	Training Accuracy: 92.60%
# Validation Accuracy: 93.20%
# Epoch: 89 	Training Accuracy: 92.00%
# Validation Accuracy: 92.20%
# Epoch: 90 	Training Accuracy: 92.40%
# Validation Accuracy: 92.80%
# Epoch: 91 	Training Accuracy: 92.20%
# Validation Accuracy: 92.80%
# Epoch: 92 	Training Accuracy: 92.20%
# Validation Accuracy: 91.80%
# Epoch: 93 	Training Accuracy: 92.40%
# Validation Accuracy: 92.80%
# Epoch: 94 	Training Accuracy: 92.20%
# Validation Accuracy: 92.80%
# Epoch: 95 	Training Accuracy: 93.00%
# Validation Accuracy: 93.00%
# Epoch: 96 	Training Accuracy: 92.60%
# Validation Accuracy: 92.80%
# Epoch: 97 	Training Accuracy: 92.60%
# Validation Accuracy: 93.00%
# Epoch: 98 	Training Accuracy: 92.60%
# Validation Accuracy: 92.80%
# Epoch: 99 	Training Accuracy: 92.20%
# Validation Accuracy: 92.80%
# Final Training Accuracy: 0.9220
# Final Test Accuracy: 0.9280

# %%
plot_decision_boundary(pretrained_model, test_loader.dataset.tensors[0], test_loader.dataset.tensors[1], n_classes=3)

# %%
plot_layer_ranks(pretrained_model)

# %%
plot_layer_effective_ranks(pretrained_model)

# %%
results, variances = compute_layer_variances_dense(pretrained_model, test_loader, device = 'cpu',cnn=False)
plot_variances_by_layer_type(variances, results, cnn = False, ignore_final_layer=True, std_of_variance = True )
# Out:
# c:\Users\user\Desktop\MP\mp-tl-study\plots.py:103: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(conv_layer_names, rotation=90)
# c:\Users\user\Desktop\MP\mp-tl-study\plots.py:114: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels(activation_layer_names, rotation=90)

# %% [markdown]
# # Train a Model only on Problem 2 data
# What we aim is: The fine-tuned model (Problem 1 -> 2) should be better than the one trained only on 2

# %%
X, y = samples_for_seed(2)
train_loader, test_loader = prep_samples(X, y)
standalone_model = fit_model(train_loader, test_loader, verbose=True)
# Out:
# Epoch: 0 	Training Accuracy: 30.60%
# Validation Accuracy: 28.80%
# Epoch: 1 	Training Accuracy: 30.40%
# Validation Accuracy: 28.80%
# Epoch: 2 	Training Accuracy: 30.20%
# Validation Accuracy: 29.00%
# Epoch: 3 	Training Accuracy: 30.20%
# Validation Accuracy: 29.00%
# Epoch: 4 	Training Accuracy: 30.40%
# Validation Accuracy: 29.00%
# Epoch: 5 	Training Accuracy: 30.40%
# Validation Accuracy: 29.00%
# Epoch: 6 	Training Accuracy: 30.60%
# Validation Accuracy: 29.40%
# Epoch: 7 	Training Accuracy: 30.80%
# Validation Accuracy: 29.40%
# Epoch: 8 	Training Accuracy: 31.00%
# Validation Accuracy: 29.40%
# Epoch: 9 	Training Accuracy: 31.00%
# Validation Accuracy: 29.60%
# Epoch: 10 	Training Accuracy: 31.00%
# Validation Accuracy: 30.00%
# Epoch: 11 	Training Accuracy: 31.00%
# Validation Accuracy: 30.20%
# Epoch: 12 	Training Accuracy: 31.40%
# Validation Accuracy: 31.00%
# Epoch: 13 	Training Accuracy: 31.40%
# Validation Accuracy: 31.20%
# Epoch: 14 	Training Accuracy: 31.60%
# Validation Accuracy: 31.40%
# Epoch: 15 	Training Accuracy: 32.00%
# Validation Accuracy: 31.80%
# Epoch: 16 	Training Accuracy: 32.20%
# Validation Accuracy: 31.80%
# Epoch: 17 	Training Accuracy: 32.20%
# Validation Accuracy: 32.00%
# Epoch: 18 	Training Accuracy: 32.20%
# Validation Accuracy: 32.20%
# Epoch: 19 	Training Accuracy: 32.20%
# Validation Accuracy: 32.40%
# Epoch: 20 	Training Accuracy: 32.40%
# Validation Accuracy: 32.40%
# Epoch: 21 	Training Accuracy: 32.40%
# Validation Accuracy: 32.60%
# Epoch: 22 	Training Accuracy: 32.80%
# Validation Accuracy: 32.80%
# Epoch: 23 	Training Accuracy: 32.80%
# Validation Accuracy: 32.80%
# Epoch: 24 	Training Accuracy: 32.80%
# Validation Accuracy: 32.80%
# Epoch: 25 	Training Accuracy: 47.40%
# Validation Accuracy: 46.20%
# Epoch: 26 	Training Accuracy: 49.00%
# Validation Accuracy: 46.80%
# Epoch: 27 	Training Accuracy: 49.80%
# Validation Accuracy: 47.60%
# Epoch: 28 	Training Accuracy: 49.80%
# Validation Accuracy: 47.40%
# Epoch: 29 	Training Accuracy: 50.00%
# Validation Accuracy: 47.40%
# Epoch: 30 	Training Accuracy: 50.00%
# Validation Accuracy: 47.60%
# Epoch: 31 	Training Accuracy: 50.00%
# Validation Accuracy: 48.00%
# Epoch: 32 	Training Accuracy: 50.40%
# Validation Accuracy: 48.80%
# Epoch: 33 	Training Accuracy: 50.00%
# Validation Accuracy: 48.60%
# Epoch: 34 	Training Accuracy: 50.00%
# Validation Accuracy: 48.80%
# Epoch: 35 	Training Accuracy: 50.00%
# Validation Accuracy: 49.00%
# Epoch: 36 	Training Accuracy: 51.20%
# Validation Accuracy: 49.40%
# Epoch: 37 	Training Accuracy: 50.80%
# Validation Accuracy: 49.40%
# Epoch: 38 	Training Accuracy: 50.80%
# Validation Accuracy: 49.40%
# Epoch: 39 	Training Accuracy: 50.80%
# Validation Accuracy: 49.40%
# Epoch: 40 	Training Accuracy: 51.00%
# Validation Accuracy: 49.40%
# Epoch: 41 	Training Accuracy: 50.80%
# Validation Accuracy: 49.60%
# Epoch: 42 	Training Accuracy: 51.20%
# Validation Accuracy: 50.20%
# Epoch: 43 	Training Accuracy: 51.60%
# Validation Accuracy: 50.80%
# Epoch: 44 	Training Accuracy: 51.60%
# Validation Accuracy: 51.00%
# Epoch: 45 	Training Accuracy: 51.60%
# Validation Accuracy: 51.00%
# Epoch: 46 	Training Accuracy: 52.20%
# Validation Accuracy: 52.00%
# Epoch: 47 	Training Accuracy: 52.80%
# Validation Accuracy: 52.40%
# Epoch: 48 	Training Accuracy: 53.20%
# Validation Accuracy: 52.60%
# Epoch: 49 	Training Accuracy: 53.20%
# Validation Accuracy: 52.60%
# Epoch: 50 	Training Accuracy: 53.60%
# Validation Accuracy: 53.20%
# Epoch: 51 	Training Accuracy: 53.80%
# Validation Accuracy: 53.20%
# Epoch: 52 	Training Accuracy: 53.60%
# Validation Accuracy: 53.60%
# Epoch: 53 	Training Accuracy: 53.80%
# Validation Accuracy: 53.20%
# Epoch: 54 	Training Accuracy: 53.60%
# Validation Accuracy: 53.60%
# Epoch: 55 	Training Accuracy: 53.80%
# Validation Accuracy: 53.20%
# Epoch: 56 	Training Accuracy: 54.20%
# Validation Accuracy: 54.20%
# Epoch: 57 	Training Accuracy: 54.20%
# Validation Accuracy: 54.20%
# Epoch: 58 	Training Accuracy: 54.80%
# Validation Accuracy: 54.80%
# Epoch: 59 	Training Accuracy: 55.00%
# Validation Accuracy: 55.20%
# Epoch: 60 	Training Accuracy: 55.20%
# Validation Accuracy: 55.80%
# Epoch: 61 	Training Accuracy: 54.80%
# Validation Accuracy: 56.40%
# Epoch: 62 	Training Accuracy: 54.40%
# Validation Accuracy: 56.40%
# Epoch: 63 	Training Accuracy: 54.80%
# Validation Accuracy: 56.40%
# Epoch: 64 	Training Accuracy: 54.80%
# Validation Accuracy: 56.40%
# Epoch: 65 	Training Accuracy: 54.40%
# Validation Accuracy: 56.40%
# Epoch: 66 	Training Accuracy: 54.60%
# Validation Accuracy: 56.40%
# Epoch: 67 	Training Accuracy: 54.60%
# Validation Accuracy: 56.60%
# Epoch: 68 	Training Accuracy: 54.40%
# Validation Accuracy: 56.60%
# Epoch: 69 	Training Accuracy: 54.80%
# Validation Accuracy: 56.60%
# Epoch: 70 	Training Accuracy: 55.00%
# Validation Accuracy: 56.80%
# Epoch: 71 	Training Accuracy: 55.00%
# Validation Accuracy: 57.00%
# Epoch: 72 	Training Accuracy: 55.20%
# Validation Accuracy: 57.00%
# Epoch: 73 	Training Accuracy: 55.20%
# Validation Accuracy: 57.20%
# Epoch: 74 	Training Accuracy: 55.40%
# Validation Accuracy: 57.20%
# Epoch: 75 	Training Accuracy: 55.60%
# Validation Accuracy: 57.40%
# Epoch: 76 	Training Accuracy: 55.40%
# Validation Accuracy: 57.20%
# Epoch: 77 	Training Accuracy: 55.40%
# Validation Accuracy: 57.40%
# Epoch: 78 	Training Accuracy: 55.60%
# Validation Accuracy: 57.60%
# Epoch: 79 	Training Accuracy: 55.60%
# Validation Accuracy: 57.60%
# Epoch: 80 	Training Accuracy: 55.60%
# Validation Accuracy: 57.80%
# Epoch: 81 	Training Accuracy: 56.00%
# Validation Accuracy: 57.80%
# Epoch: 82 	Training Accuracy: 56.20%
# Validation Accuracy: 57.80%
# Epoch: 83 	Training Accuracy: 56.80%
# Validation Accuracy: 58.00%
# Epoch: 84 	Training Accuracy: 57.00%
# Validation Accuracy: 58.00%
# Epoch: 85 	Training Accuracy: 57.00%
# Validation Accuracy: 58.00%
# Epoch: 86 	Training Accuracy: 57.20%
# Validation Accuracy: 58.20%
# Epoch: 87 	Training Accuracy: 57.20%
# Validation Accuracy: 58.00%
# Epoch: 88 	Training Accuracy: 57.60%
# Validation Accuracy: 58.20%
# Epoch: 89 	Training Accuracy: 57.60%
# Validation Accuracy: 58.20%
# Epoch: 90 	Training Accuracy: 57.80%
# Validation Accuracy: 58.20%
# Epoch: 91 	Training Accuracy: 58.00%
# Validation Accuracy: 58.20%
# Epoch: 92 	Training Accuracy: 58.20%
# Validation Accuracy: 58.40%
# Epoch: 93 	Training Accuracy: 58.00%
# Validation Accuracy: 58.60%
# Epoch: 94 	Training Accuracy: 58.20%
# Validation Accuracy: 58.40%
# Epoch: 95 	Training Accuracy: 58.40%
# Validation Accuracy: 58.60%
# Epoch: 96 	Training Accuracy: 58.60%
# Validation Accuracy: 59.00%
# Epoch: 97 	Training Accuracy: 59.60%
# Validation Accuracy: 59.00%
# Epoch: 98 	Training Accuracy: 59.40%
# Validation Accuracy: 59.20%
# Epoch: 99 	Training Accuracy: 59.60%
# Validation Accuracy: 59.40%
# Final Training Accuracy: 0.5960
# Final Test Accuracy: 0.5940

# %%
plot_decision_boundary(standalone_model, test_loader.dataset.tensors[0], test_loader.dataset.tensors[1], n_classes=3)

# %% [markdown]
# # Now Fine-tune on Problem 2

# %%
fine_tuned_model = fine_tune_model(pretrained_model, train_loader, test_loader, verbose=True)
# Out:
# Epoch: 0 	Training Accuracy: 25.60%
# Validation Accuracy: 29.60%
# Epoch: 1 	Training Accuracy: 32.20%
# Validation Accuracy: 34.20%
# Epoch: 2 	Training Accuracy: 35.20%
# Validation Accuracy: 35.40%
# Epoch: 3 	Training Accuracy: 36.20%
# Validation Accuracy: 36.80%
# Epoch: 4 	Training Accuracy: 37.80%
# Validation Accuracy: 39.60%
# Epoch: 5 	Training Accuracy: 38.80%
# Validation Accuracy: 40.60%
# Epoch: 6 	Training Accuracy: 40.20%
# Validation Accuracy: 40.40%
# Epoch: 7 	Training Accuracy: 40.60%
# Validation Accuracy: 39.80%
# Epoch: 8 	Training Accuracy: 40.60%
# Validation Accuracy: 40.60%
# Epoch: 9 	Training Accuracy: 41.40%
# Validation Accuracy: 41.20%
# Epoch: 10 	Training Accuracy: 41.40%
# Validation Accuracy: 41.20%
# Epoch: 11 	Training Accuracy: 41.80%
# Validation Accuracy: 41.80%
# Epoch: 12 	Training Accuracy: 42.40%
# Validation Accuracy: 42.20%
# Epoch: 13 	Training Accuracy: 42.60%
# Validation Accuracy: 42.00%
# Epoch: 14 	Training Accuracy: 43.00%
# Validation Accuracy: 42.20%
# Epoch: 15 	Training Accuracy: 43.00%
# Validation Accuracy: 42.40%
# Epoch: 16 	Training Accuracy: 43.20%
# Validation Accuracy: 42.40%
# Epoch: 17 	Training Accuracy: 43.00%
# Validation Accuracy: 42.80%
# Epoch: 18 	Training Accuracy: 43.20%
# Validation Accuracy: 43.20%
# Epoch: 19 	Training Accuracy: 43.60%
# Validation Accuracy: 43.40%
# Epoch: 20 	Training Accuracy: 43.60%
# Validation Accuracy: 43.40%
# Epoch: 21 	Training Accuracy: 44.00%
# Validation Accuracy: 43.80%
# Epoch: 22 	Training Accuracy: 45.00%
# Validation Accuracy: 45.00%
# Epoch: 23 	Training Accuracy: 46.00%
# Validation Accuracy: 46.60%
# Epoch: 24 	Training Accuracy: 47.40%
# Validation Accuracy: 49.00%
# Epoch: 25 	Training Accuracy: 50.40%
# Validation Accuracy: 51.60%
# Epoch: 26 	Training Accuracy: 51.20%
# Validation Accuracy: 53.20%
# Epoch: 27 	Training Accuracy: 52.60%
# Validation Accuracy: 55.60%
# Epoch: 28 	Training Accuracy: 54.60%
# Validation Accuracy: 57.20%
# Epoch: 29 	Training Accuracy: 55.40%
# Validation Accuracy: 58.80%
# Epoch: 30 	Training Accuracy: 56.80%
# Validation Accuracy: 60.00%
# Epoch: 31 	Training Accuracy: 57.20%
# Validation Accuracy: 61.60%
# Epoch: 32 	Training Accuracy: 58.80%
# Validation Accuracy: 62.80%
# Epoch: 33 	Training Accuracy: 59.60%
# Validation Accuracy: 63.60%
# Epoch: 34 	Training Accuracy: 61.00%
# Validation Accuracy: 64.00%
# Epoch: 35 	Training Accuracy: 61.20%
# Validation Accuracy: 64.40%
# Epoch: 36 	Training Accuracy: 62.20%
# Validation Accuracy: 64.80%
# Epoch: 37 	Training Accuracy: 62.40%
# Validation Accuracy: 65.40%
# Epoch: 38 	Training Accuracy: 62.60%
# Validation Accuracy: 66.40%
# Epoch: 39 	Training Accuracy: 62.80%
# Validation Accuracy: 67.40%
# Epoch: 40 	Training Accuracy: 63.60%
# Validation Accuracy: 67.60%
# Epoch: 41 	Training Accuracy: 64.40%
# Validation Accuracy: 67.80%
# Epoch: 42 	Training Accuracy: 64.60%
# Validation Accuracy: 68.40%
# Epoch: 43 	Training Accuracy: 64.80%
# Validation Accuracy: 68.60%
# Epoch: 44 	Training Accuracy: 65.40%
# Validation Accuracy: 69.00%
# Epoch: 45 	Training Accuracy: 65.80%
# Validation Accuracy: 69.40%
# Epoch: 46 	Training Accuracy: 66.00%
# Validation Accuracy: 70.00%
# Epoch: 47 	Training Accuracy: 66.00%
# Validation Accuracy: 70.40%
# Epoch: 48 	Training Accuracy: 66.80%
# Validation Accuracy: 71.00%
# Epoch: 49 	Training Accuracy: 67.00%
# Validation Accuracy: 71.20%
# Epoch: 50 	Training Accuracy: 67.40%
# Validation Accuracy: 71.40%
# Epoch: 51 	Training Accuracy: 68.20%
# Validation Accuracy: 72.00%
# Epoch: 52 	Training Accuracy: 68.40%
# Validation Accuracy: 72.20%
# Epoch: 53 	Training Accuracy: 68.60%
# Validation Accuracy: 72.20%
# Epoch: 54 	Training Accuracy: 69.20%
# Validation Accuracy: 72.80%
# Epoch: 55 	Training Accuracy: 70.00%
# Validation Accuracy: 73.00%
# Epoch: 56 	Training Accuracy: 69.60%
# Validation Accuracy: 73.00%
# Epoch: 57 	Training Accuracy: 69.60%
# Validation Accuracy: 73.00%
# Epoch: 58 	Training Accuracy: 70.00%
# Validation Accuracy: 73.20%
# Epoch: 59 	Training Accuracy: 70.40%
# Validation Accuracy: 73.20%
# Epoch: 60 	Training Accuracy: 70.80%
# Validation Accuracy: 73.20%
# Epoch: 61 	Training Accuracy: 71.60%
# Validation Accuracy: 73.40%
# Epoch: 62 	Training Accuracy: 71.60%
# Validation Accuracy: 73.80%
# Epoch: 63 	Training Accuracy: 71.40%
# Validation Accuracy: 73.80%
# Epoch: 64 	Training Accuracy: 71.80%
# Validation Accuracy: 74.60%
# Epoch: 65 	Training Accuracy: 71.60%
# Validation Accuracy: 74.80%
# Epoch: 66 	Training Accuracy: 72.00%
# Validation Accuracy: 75.00%
# Epoch: 67 	Training Accuracy: 71.80%
# Validation Accuracy: 75.00%
# Epoch: 68 	Training Accuracy: 72.20%
# Validation Accuracy: 75.20%
# Epoch: 69 	Training Accuracy: 72.20%
# Validation Accuracy: 75.00%
# Epoch: 70 	Training Accuracy: 72.20%
# Validation Accuracy: 75.20%
# Epoch: 71 	Training Accuracy: 72.40%
# Validation Accuracy: 75.20%
# Epoch: 72 	Training Accuracy: 73.00%
# Validation Accuracy: 75.60%
# Epoch: 73 	Training Accuracy: 73.20%
# Validation Accuracy: 76.20%
# Epoch: 74 	Training Accuracy: 73.20%
# Validation Accuracy: 76.40%
# Epoch: 75 	Training Accuracy: 74.00%
# Validation Accuracy: 76.40%
# Epoch: 76 	Training Accuracy: 74.00%
# Validation Accuracy: 76.40%
# Epoch: 77 	Training Accuracy: 74.00%
# Validation Accuracy: 76.60%
# Epoch: 78 	Training Accuracy: 74.20%
# Validation Accuracy: 76.60%
# Epoch: 79 	Training Accuracy: 74.20%
# Validation Accuracy: 76.60%
# Epoch: 80 	Training Accuracy: 75.20%
# Validation Accuracy: 77.00%
# Epoch: 81 	Training Accuracy: 75.20%
# Validation Accuracy: 77.20%
# Epoch: 82 	Training Accuracy: 75.20%
# Validation Accuracy: 77.20%
# Epoch: 83 	Training Accuracy: 75.20%
# Validation Accuracy: 77.20%
# Epoch: 84 	Training Accuracy: 75.20%
# Validation Accuracy: 77.60%
# Epoch: 85 	Training Accuracy: 75.20%
# Validation Accuracy: 77.40%
# Epoch: 86 	Training Accuracy: 75.20%
# Validation Accuracy: 77.80%
# Epoch: 87 	Training Accuracy: 75.20%
# Validation Accuracy: 77.60%
# Epoch: 88 	Training Accuracy: 75.20%
# Validation Accuracy: 77.80%
# Epoch: 89 	Training Accuracy: 75.60%
# Validation Accuracy: 78.20%
# Epoch: 90 	Training Accuracy: 75.60%
# Validation Accuracy: 78.00%
# Epoch: 91 	Training Accuracy: 75.60%
# Validation Accuracy: 78.40%
# Epoch: 92 	Training Accuracy: 75.60%
# Validation Accuracy: 78.40%
# Epoch: 93 	Training Accuracy: 75.80%
# Validation Accuracy: 78.40%
# Epoch: 94 	Training Accuracy: 76.20%
# Validation Accuracy: 78.40%
# Epoch: 95 	Training Accuracy: 76.40%
# Validation Accuracy: 78.80%
# Epoch: 96 	Training Accuracy: 76.40%
# Validation Accuracy: 78.80%
# Epoch: 97 	Training Accuracy: 76.80%
# Validation Accuracy: 79.00%
# Epoch: 98 	Training Accuracy: 77.00%
# Validation Accuracy: 79.00%
# Epoch: 99 	Training Accuracy: 76.80%
# Validation Accuracy: 79.20%
# Final Training Accuracy: 0.7680
# Final Test Accuracy: 0.7920

# %%
plot_decision_boundary(fine_tuned_model, test_loader.dataset.tensors[0], test_loader.dataset.tensors[1], n_classes=3)

# %% [markdown]
# # Now Multiple Experiments to Test our Hypothesis
# What we aim is: The fine-tuned model (Problem 1 -> 2) should be better than the one trained only on 2

# %%
# prepare data for problem 2
X, y = samples_for_seed(2)
train_loader, test_loader = prep_samples(X, y)
n_repeats = 30
dists, dist_labels = list(), list()

# repeated evaluation of standalone model
standalone_scores = eval_multiple_experiments(train_loader, test_loader, n_repeats)
print('Standalone %.3f (%.3f)' % (np.mean(standalone_scores), np.std(standalone_scores)))
dists.append(standalone_scores)
dist_labels.append('standalone')

# repeated evaluation of transfer learning model, vary fixed layers
n_fixed = 3
for i in range(n_fixed):
	scores = eval_multiple_experiments(train_loader, test_loader, n_repeats, pretrained_model=pretrained_model, cut_point=i)
	print('Transfer (fixed=%d) %.3f (%.3f)' % (i, np.mean(scores), np.std(scores)))
	dists.append(scores)
	dist_labels.append('transfer f='+str(i))

# box and whisker plot of score distributions
pyplot.boxplot(dists, labels=dist_labels)
pyplot.show()
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# 100%|██████████| 30/30 [01:34<00:00,  3.13s/it]
# Standalone 0.800 (0.025)
# 100%|██████████| 30/30 [01:56<00:00,  3.88s/it]
#  33%|███▎      | 1/3 [01:56<03:52, 116.49s/it]
# Transfer (fixed=0) 0.791 (0.002)
# 100%|██████████| 30/30 [01:24<00:00,  2.82s/it]
#  67%|██████▋   | 2/3 [03:21<01:37, 97.69s/it]
# Transfer (fixed=1) 0.791 (0.002)
# 100%|██████████| 30/30 [01:22<00:00,  2.75s/it]
# 100%|██████████| 3/3 [04:43<00:00, 94.50s/it]
# Transfer (fixed=2) 0.791 (0.002)

# %% [markdown]
# # Result
# Transfer learning doesn't improve the accuracy much, but it makes the training more robust in a way. f = cut point. We can play with other params too (for example here there is no early stopping)

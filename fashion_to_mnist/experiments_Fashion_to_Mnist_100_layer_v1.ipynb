# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# data
import numpy as np
np.random.seed(42)

import torch
from torchvision import datasets, transforms

# (1, 28, 28) for CNN
# some people transform it to have 0 mean and 1 std?
class MNISTtrainer(object):
    def __init__(self, batch_size, input_dim=28*28,val_split=0.1):
        self.input_dim = input_dim
        self.output_dim = 10
        self.val_split = val_split

        train = datasets.MNIST(
                '../data',
                train=True,
                download=True,
                transform=transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
                ]))

        # split some part of train set to validation
        train_set, val_set = torch.utils.data.random_split(train, [1.-self.val_split, self.val_split])
        self.train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)
        self.val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=True)

        self.test_loader = torch.utils.data.DataLoader(
            datasets.MNIST(
                '../data',
                train=False,
                download=True,
                transform=transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
                ])),
            batch_size=batch_size,
            shuffle=True)

# (1, 28, 28) for CNN
class FashionMNISTtrainer(object):
    def __init__(self, batch_size, input_dim=28*28, val_split=0.1):
        self.input_dim = input_dim
        self.output_dim = 10
        self.val_split = val_split


        train = datasets.FashionMNIST(
            '../data',
            train=True,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        # split some part of train set to validation
        train_set, val_set = torch.utils.data.random_split(train, [1.-self.val_split, self.val_split])
        self.train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)
        self.val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=True)

        self.test_loader = torch.utils.data.DataLoader(
            datasets.FashionMNIST(
                '../data',
                train=False,
                download=True,
                transform=transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
                ])),
            batch_size=batch_size,
            shuffle=True)

# %%
import numpy as np
import torch, random
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
###############################random seed##############################################################################
# manualSeed = random.randint(1, 10000) # fix seed
manualSeed = 42
print("Random Seed: ",manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
np.random.seed(manualSeed)
#torch.cuda.manual_seed_all(manualSeed)
# cudnn.benchmark = True
########################################################################################################################


import copy

# init given linear layer m with given sw and sb
def init_weights(m, sw, sb):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, mean=0.0, std=(np.sqrt(sw / m.out_features)))
        nn.init.normal_(m.bias, mean=0.0, std=np.sqrt(sb))

# init new model
# TODO: activation function
# TODO: name the layers
def generate_fc_dnn(input_dim, output_dim, params):
    depth, width = params['depth'], params['width']
    def gen_linear_layer_dim(layer_index):
        return {
            0: (input_dim, width),
            depth - 1: (width, output_dim),
        }.get(layer_index, (width, width))

    fc_list = list()
    for i in range(depth):
        fc_list += [
            nn.Linear(*gen_linear_layer_dim(i)),
            nn.LogSoftmax(dim=1) if (depth - 1 == i) else nn.Tanh()
        ]
    model = nn.Sequential(*fc_list)
    model.apply(lambda m: init_weights(m, params['sw'], params['sb']))
    return model

'''def generate_cnn(input_dim, output_dim, depth, num_channels):
    layers = []
    in_channels = 1  # Assuming grayscale input images

    # Convolutional layers
    for i in range(depth):
        layers.append(nn.Conv2d(in_channels, num_channels, kernel_size=3, padding=1))
        layers.append(nn.Tanh())

        # Add MaxPool2d layer every 2 convolutional layers
        if i % 2 == 1:
            layers.append(nn.MaxPool2d(2))
            input_dim = input_dim // 2
            print("input_dim: ", input_dim)

        in_channels = num_channels
        #num_channels *= 2

    # Flatten the output from convolutional layers
    layers.append(nn.Flatten())

    # Fully connected layer for classification
    layers.append(nn.Linear(in_channels * input_dim * input_dim, output_dim))
    layers.append(nn.LogSoftmax(dim=1))

    model = nn.Sequential(*layers)
    return model
'''

class CustomCNN(nn.Module):
    def init(self, input_dim, output_dim, depth, num_channels, act_fn, use_pooling=True):
        super(CustomCNN, self).init()
        in_channels = 1  # Assuming grayscale input images
        conv_count = 0

        self.layers = nn.ModuleList()

        for i in range(depth):
            # Add convolutional layer
            self.layers.append(nn.Conv2d(in_channels, num_channels, kernel_size=3, padding=1))
            # Add activation layer
            self.layers.append(act_fn())
            conv_count += 1

            # Add MaxPool2d layer every 2 convolutional layers if use_pooling is set
            if use_pooling and i % 2 == 1:
                self.layers.append(nn.MaxPool2d(2))
                input_dim = input_dim // 2
                print("input_dim: ", input_dim)

            in_channels = num_channels
            # num_channels = 2

        # Add fully connected layer for classification
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(in_channels, input_dim * input_dim, output_dim)
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        x = self.flatten(x)
        x = self.fc(x)
        return self.logsoftmax(x)

def generate_cnn(input_dim, output_dim, depth, num_channels, act_fn=nn.ReLU, use_pooling=True):
    model = CustomCNN(input_dim, output_dim, depth, num_channels, act_fn, use_pooling)
    return model

# dataset_loader is fine-tuning dataset
def eval(model, device, dataset_loader, debug):
    model.eval()
    test_loss, correct = 0., 0.
    with torch.no_grad():
        for data, target in dataset_loader:
            data, target = data.reshape([data.shape[0], -1]).to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(
                output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(
                dim=1,
                keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data
    if debug:
        print('\nTrain set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.
              format(test_loss, correct, num_data, 100. * acc))

    return acc

# TODO: option to freeze some layers
# TODO: option to save the model?
def compute_training_acc(model, dataset, params, debug=False):
    device = torch.device(params['device'])
    optimizer = optim.SGD(model.parameters(), lr=params['lr'])
    # if debug: print(model, optimizer)

    # run training for few steps and return the accuracy
    train_acc = 0.0
    model.train()
    for batch_idx, (data, target) in enumerate(dataset.train_loader):
        data, target = data.reshape([data.shape[0],-1]).to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()

        # Evaluate after every 10 steps epoch
        if debug and batch_idx % 10 == 0:
            train_acc = eval(model, device, dataset.train_loader, debug=False)
            print('Step: {} \tTraining Accuracy: {:.2f}%'.format(batch_idx, train_acc*100))
            # if debug and (epoch+1) % 1 == 0:
            val_acc = eval(model, device, dataset.val_loader, debug=False)
            print('\t\tValidation Accuracy: {:.2f}%'.format(val_acc*100))

    train_acc = eval(model, device, dataset.train_loader, debug=False)
    test_acc = eval(model, device, dataset.test_loader, debug=False)
    return train_acc, test_acc, model

# like previous function, but run for given number of epochs determined by params['num_train']
def compute_training_acc_epochs(model, dataset, params, debug=False):
    device = torch.device(params['device'])
    optimizer = optim.SGD(model.parameters(), lr=params['lr'])
    # if debug: print(model, optimizer)

    if params['early_stop_patience']:
        no_improve_epochs = 0
        max_val_acc = 0.

    train_acc = 0.0
    model.train()

    # Loop over epochs
    for epoch in range(params['num_train']):
        for batch_idx, (data, target) in enumerate(dataset.train_loader):
            data, target = data.reshape([data.shape[0], -1]).to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = F.nll_loss(output, target)
            loss.backward()
            optimizer.step()

            if debug and batch_idx % 20 == 0:
                #print('Epoch: {} Train step: {} \tLoss: {:.6f}'.format(epoch, batch_idx, loss.item()))
                pass

        # Evaluate after each epoch
        if debug:
            train_acc = eval(model, device, dataset.train_loader, debug=False)
            print('Epoch: {} \tTraining Accuracy: {:.2f}%'.format(epoch, train_acc*100))
            # if debug and (epoch+1) % 1 == 0:
            val_acc = eval(model, device, dataset.val_loader, debug=False)
            print('Validation Accuracy: {:.2f}%'.format(val_acc*100))

            if params['early_stop_patience']:
                if val_acc > max_val_acc:
                    max_val_acc = val_acc
                    no_improve_epochs = 0
                else:
                    no_improve_epochs += 1
                    print("val_acc: {}, max_val_acc: {}, no_improve_epochs: {}".format(val_acc, max_val_acc, no_improve_epochs))
                    if no_improve_epochs >= params['early_stop_patience']:
                        print("Early stopping invoked.")
                        break

    # Final evaluation after all epochs are completed
    train_acc = eval(model, device, dataset.train_loader, debug=False)
    test_acc = eval(model, device, dataset.test_loader, debug=False)
    return train_acc, test_acc, model

def eval_cnn(model, device, dataset_loader, debug):
    model.eval()
    test_loss, correct = 0., 0.
    with torch.no_grad():
        for data, target in dataset_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data
    if debug:
        print('\nTrain set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(test_loss, correct, num_data, 100. * acc))

    return acc

def compute_training_acc_epochs_cnn(model, dataset, params, debug=False):
    device = torch.device(params['device'])
    optimizer = optim.SGD(model.parameters(), lr=params['lr'])

    if debug:
        print(model, optimizer)

    train_acc = 0.0
    model.train()

    # Loop over epochs
    for epoch in range(params['num_train']):
        for batch_idx, (data, target) in enumerate(dataset.train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = F.nll_loss(output, target)
            loss.backward()
            optimizer.step()

            if debug and batch_idx % 20 == 0:
                pass

        # Evaluate after each epoch
        if debug:
            train_acc = eval_cnn(model, device, dataset.train_loader, debug=False)
            print('Epoch: {} \tTraining Accuracy: {:.2f}%'.format(epoch, train_acc*100))
            if debug and (epoch+1) % 3 == 0:
                val_acc = eval_cnn(model, device, dataset.val_loader, debug=False)
                print('Validation Accuracy: {:.2f}%'.format(val_acc*100))

    # Final evaluation after all epochs are completed
    train_acc = eval_cnn(model, device, dataset.train_loader, debug=False)
    test_acc = eval_cnn(model, device, dataset.test_loader, debug=False)
    return train_acc, test_acc, model



# cut_point: no. of layers to keep in the model
# reinitialize after cutting point using init_weights function
def cut_model(model, sw = 1, sb = 1, cut_point=1, freeze=True):
    #deepcopy to avoid changing the original model
    model = copy.deepcopy(model)
    # Convert sequential model to list of layers
    layers = list(model.children())

    # Check if cut_point is out of range
    if cut_point < 0 or cut_point >= len(layers) // 2:
        raise ValueError("cut_point should be in range [0, number of layers - 1]")

    # If freeze is True, set requires_grad to False for layers before cut_point
    if freeze:
        for i in range(cut_point):
            for param in layers[2*i].parameters():
                param.requires_grad = False

    # Cut layers
    new_layers = layers[:2*cut_point]

    # Reinitialize layers after cut point
    for i in range(cut_point, len(layers) // 2):
        linear_layer = layers[2*i]
        activation = layers[2*i + 1]

        # Apply initialization
        init_weights(linear_layer, sw, sb)

        # Append to new layers
        new_layers.extend([linear_layer, activation])

    # Return new model
    return nn.Sequential(*new_layers)

def cut_cnn_model(model, cut_point=1, freeze=True):
    """
    Cut the CNN model at a specific layer and reinitialize the weights for layers after cut_point.

    Parameters:
    - model (nn.Module): Original model.
    - cut_point (int): Layer index at which to cut the model.
    - freeze (bool): If True, layers before cut_point will have their weights frozen.

    Returns:
    - new_model (nn.Sequential): Cut and potentially modified model.
    """

    # Deep copy to avoid changing the original model
    model = copy.deepcopy(model)

    # Convert sequential model to list of layers
    layers = list(model.children())

    # Check if cut_point is out of range
    if cut_point < 0 or cut_point >= len(layers):
        raise ValueError("cut_point should be in range [0, number of layers - 1]")

    # If freeze is True, set requires_grad to False for layers before cut_point
    if freeze:
        for i in range(cut_point):
            for param in layers[i].parameters():
                param.requires_grad = False

    # Cut layers
    new_layers = layers[:cut_point]

    # Reinitialize layers after cut point
    for i in range(cut_point, len(layers)):
        layer = layers[i]

        # Reinitialize weights if layer has parameters (like Conv2d)
        if hasattr(layer, 'weight'):
            nn.init.kaiming_uniform_(layer.weight, a=0, mode='fan_in', nonlinearity='relu')
            if layer.bias is not None:
                nn.init.constant_(layer.bias, 0)

        # Append to new layers
        new_layers.append(layer)

    # Return new model
    return nn.Sequential(*new_layers)
# Out:
# Random Seed:  42

# %% [markdown]
# ### Baseline, end to end trained model

# %%
batch_size = 256
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = 'mps'
depth = 100
width = 300

fashion_dataset = FashionMNISTtrainer(batch_size)

# early stopping? False if not needed, otherwise int
params = dict(device=device,
                width=width, lr=1e-3, num_train=60,
                sb=0.05, depth=depth, sw=1.7346938775510203, early_stop_patience=10)

fashion_model = generate_fc_dnn(fashion_dataset.input_dim, fashion_dataset.output_dim,
                params).to(device)

pretrain_acc, pretrain_test_acc, pre_trained_model = compute_training_acc_epochs(fashion_model, fashion_dataset, params, debug=True)
# pretrain_acc, pretrain_test_acc, pre_trained_model = compute_training_acc(fashion_model, fashion_dataset, params, debug=True)
# Out:
# Epoch: 0 	Training Accuracy: 67.34%
# Validation Accuracy: 67.67%
# Epoch: 1 	Training Accuracy: 68.75%
# Validation Accuracy: 68.72%
# Epoch: 2 	Training Accuracy: 79.19%
# Validation Accuracy: 78.58%
# Epoch: 3 	Training Accuracy: 74.99%
# Validation Accuracy: 75.52%
# val_acc: 0.7551666666666667, max_val_acc: 0.7858333333333334, no_improve_epochs: 1
# Epoch: 4 	Training Accuracy: 81.76%
# Validation Accuracy: 80.53%
# Epoch: 5 	Training Accuracy: 82.40%
# Validation Accuracy: 81.83%
# Epoch: 6 	Training Accuracy: 82.17%
# Validation Accuracy: 81.47%
# val_acc: 0.8146666666666667, max_val_acc: 0.8183333333333334, no_improve_epochs: 1
# Epoch: 7 	Training Accuracy: 81.67%
# Validation Accuracy: 81.17%
# val_acc: 0.8116666666666666, max_val_acc: 0.8183333333333334, no_improve_epochs: 2
# Epoch: 8 	Training Accuracy: 84.52%
# Validation Accuracy: 82.68%
# Epoch: 9 	Training Accuracy: 84.40%
# Validation Accuracy: 82.63%
# val_acc: 0.8263333333333334, max_val_acc: 0.8268333333333333, no_improve_epochs: 1
# Epoch: 10 	Training Accuracy: 84.82%
# Validation Accuracy: 82.82%
# Epoch: 11 	Training Accuracy: 85.70%
# Validation Accuracy: 83.25%
# Epoch: 12 	Training Accuracy: 85.84%
# Validation Accuracy: 83.77%
# Epoch: 13 	Training Accuracy: 86.29%
# Validation Accuracy: 83.50%
# val_acc: 0.835, max_val_acc: 0.8376666666666667, no_improve_epochs: 1
# Epoch: 14 	Training Accuracy: 86.08%
# Validation Accuracy: 82.97%
# val_acc: 0.8296666666666667, max_val_acc: 0.8376666666666667, no_improve_epochs: 2
# Epoch: 15 	Training Accuracy: 86.85%
# Validation Accuracy: 84.23%
# Epoch: 16 	Training Accuracy: 87.06%
# Validation Accuracy: 84.13%
# val_acc: 0.8413333333333334, max_val_acc: 0.8423333333333334, no_improve_epochs: 1
# Epoch: 17 	Training Accuracy: 87.97%
# Validation Accuracy: 84.65%
# Epoch: 18 	Training Accuracy: 85.60%
# Validation Accuracy: 83.07%
# val_acc: 0.8306666666666667, max_val_acc: 0.8465, no_improve_epochs: 1
# Epoch: 19 	Training Accuracy: 88.01%
# Validation Accuracy: 84.25%
# val_acc: 0.8425, max_val_acc: 0.8465, no_improve_epochs: 2
# Epoch: 20 	Training Accuracy: 87.78%
# Validation Accuracy: 83.97%
# val_acc: 0.8396666666666667, max_val_acc: 0.8465, no_improve_epochs: 3
# Epoch: 21 	Training Accuracy: 87.81%
# Validation Accuracy: 84.12%
# val_acc: 0.8411666666666666, max_val_acc: 0.8465, no_improve_epochs: 4
# Epoch: 22 	Training Accuracy: 89.04%
# Validation Accuracy: 84.97%
# Epoch: 23 	Training Accuracy: 88.72%
# Validation Accuracy: 84.57%
# val_acc: 0.8456666666666667, max_val_acc: 0.8496666666666667, no_improve_epochs: 1
# Epoch: 24 	Training Accuracy: 88.94%
# Validation Accuracy: 85.03%
# Epoch: 25 	Training Accuracy: 88.94%
# Validation Accuracy: 84.77%
# val_acc: 0.8476666666666667, max_val_acc: 0.8503333333333334, no_improve_epochs: 1
# Epoch: 26 	Training Accuracy: 89.63%
# Validation Accuracy: 85.23%
# Epoch: 27 	Training Accuracy: 88.86%
# Validation Accuracy: 84.03%
# val_acc: 0.8403333333333334, max_val_acc: 0.8523333333333334, no_improve_epochs: 1
# Epoch: 28 	Training Accuracy: 89.84%
# Validation Accuracy: 85.02%
# val_acc: 0.8501666666666666, max_val_acc: 0.8523333333333334, no_improve_epochs: 2
# Epoch: 29 	Training Accuracy: 89.07%
# Validation Accuracy: 84.20%
# val_acc: 0.842, max_val_acc: 0.8523333333333334, no_improve_epochs: 3
# Epoch: 30 	Training Accuracy: 88.44%
# Validation Accuracy: 84.05%
# val_acc: 0.8405, max_val_acc: 0.8523333333333334, no_improve_epochs: 4
# Epoch: 31 	Training Accuracy: 90.01%
# Validation Accuracy: 84.70%
# val_acc: 0.847, max_val_acc: 0.8523333333333334, no_improve_epochs: 5
# Epoch: 32 	Training Accuracy: 90.48%
# Validation Accuracy: 84.42%
# val_acc: 0.8441666666666666, max_val_acc: 0.8523333333333334, no_improve_epochs: 6
# Epoch: 33 	Training Accuracy: 90.51%
# Validation Accuracy: 84.73%
# val_acc: 0.8473333333333334, max_val_acc: 0.8523333333333334, no_improve_epochs: 7
# Epoch: 34 	Training Accuracy: 91.50%
# Validation Accuracy: 85.03%
# val_acc: 0.8503333333333334, max_val_acc: 0.8523333333333334, no_improve_epochs: 8
# Epoch: 35 	Training Accuracy: 90.56%
# Validation Accuracy: 84.30%
# val_acc: 0.843, max_val_acc: 0.8523333333333334, no_improve_epochs: 9
# Epoch: 36 	Training Accuracy: 91.80%
# Validation Accuracy: 85.75%
# Epoch: 37 	Training Accuracy: 91.46%
# Validation Accuracy: 84.88%
# val_acc: 0.8488333333333333, max_val_acc: 0.8575, no_improve_epochs: 1
# Epoch: 38 	Training Accuracy: 89.29%
# Validation Accuracy: 84.18%
# val_acc: 0.8418333333333333, max_val_acc: 0.8575, no_improve_epochs: 2
# Epoch: 39 	Training Accuracy: 92.16%
# Validation Accuracy: 85.18%
# val_acc: 0.8518333333333333, max_val_acc: 0.8575, no_improve_epochs: 3
# Epoch: 40 	Training Accuracy: 91.84%
# Validation Accuracy: 85.28%
# val_acc: 0.8528333333333333, max_val_acc: 0.8575, no_improve_epochs: 4
# Epoch: 41 	Training Accuracy: 93.10%
# Validation Accuracy: 85.53%
# val_acc: 0.8553333333333333, max_val_acc: 0.8575, no_improve_epochs: 5
# Epoch: 42 	Training Accuracy: 91.96%
# Validation Accuracy: 84.78%
# val_acc: 0.8478333333333333, max_val_acc: 0.8575, no_improve_epochs: 6
# Epoch: 43 	Training Accuracy: 92.80%
# Validation Accuracy: 85.03%
# val_acc: 0.8503333333333334, max_val_acc: 0.8575, no_improve_epochs: 7
# Epoch: 44 	Training Accuracy: 92.83%
# Validation Accuracy: 85.12%
# val_acc: 0.8511666666666666, max_val_acc: 0.8575, no_improve_epochs: 8
# Epoch: 45 	Training Accuracy: 93.26%
# Validation Accuracy: 85.45%
# val_acc: 0.8545, max_val_acc: 0.8575, no_improve_epochs: 9
# Epoch: 46 	Training Accuracy: 91.45%
# Validation Accuracy: 84.03%
# val_acc: 0.8403333333333334, max_val_acc: 0.8575, no_improve_epochs: 10
# Early stopping invoked.

# %%
# save the model with hyperparams
import json, os

models_path = "drive/MyDrive/MP/models"
if not os.path.exists(models_path):
    os.mkdir(models_path)

# below choose where you name the new directory
model_path = os.path.join(models_path, "fashion_to_mnist_1")
os.mkdir(model_path)
torch.save(fashion_model.state_dict(), os.path.join(model_path, "pretrained_model.pt"))

params['batch_size'] = batch_size
del params['device']
with open(os.path.join(model_path, "model_params.json"), "w+") as f:
      json.dump(params, f, indent=2, ensure_ascii=False)  # encode dict into JSON

# %%
# load the model
import json, os

batch_size = 256
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = 'mps'
depth = 100
width = 300

fashion_dataset = FashionMNISTtrainer(batch_size)

models_path = "drive/MyDrive/MP"
model_path = os.path.join(models_path, "fashion_to_mnist_1")

with open(os.path.join(model_path, "model_params.json"), "r") as f:
    params = json.load(f)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
params['device'] = device
fashion_model = generate_fc_dnn(fashion_dataset.input_dim, fashion_dataset.output_dim, params)
fashion_model.load_state_dict(torch.load(os.path.join(model_path, "pretrained_model.pt")))
fashion_model.to(device)
fashion_model.eval()
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ../data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:00<00:00, 115373216.48it/s]
# Extracting ../data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ../data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 5158335.04it/s]
# Extracting ../data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ../data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 63549349.03it/s]
# Extracting ../data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ../data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 18129535.68it/s]
# Extracting ../data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/FashionMNIST/raw
# Sequential(
#   (0): Linear(in_features=784, out_features=300, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=300, out_features=300, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=300, out_features=300, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=300, out_features=300, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=300, out_features=300, bias=True)
#   (9): Tanh()
#   (10): Linear(in_features=300, out_features=300, bias=True)
#   (11): Tanh()
#   (12): Linear(in_features=300, out_features=300, bias=True)
#   (13): Tanh()
#   (14): Linear(in_features=300, out_features=300, bias=True)
#   (15): Tanh()
#   (16): Linear(in_features=300, out_features=300, bias=True)
#   (17): Tanh()
#   (18): Linear(in_features=300, out_features=300, bias=True)
#   (19): Tanh()
#   (20): Linear(in_features=300, out_features=300, bias=True)
#   (21): Tanh()
#   (22): Linear(in_features=300, out_features=300, bias=True)
#   (23): Tanh()
#   (24): Linear(in_features=300, out_features=300, bias=True)
#   (25): Tanh()
#   (26): Linear(in_features=300, out_features=300, bias=True)
#   (27): Tanh()
#   (28): Linear(in_features=300, out_features=300, bias=True)
#   (29): Tanh()
#   (30): Linear(in_features=300, out_features=300, bias=True)
#   (31): Tanh()
#   (32): Linear(in_features=300, out_features=300, bias=True)
#   (33): Tanh()
#   (34): Linear(in_features=300, out_features=300, bias=True)
#   (35): Tanh()
#   (36): Linear(in_features=300, out_features=300, bias=True)
#   (37): Tanh()
#   (38): Linear(in_features=300, out_features=300, bias=True)
#   (39): Tanh()
#   (40): Linear(in_features=300, out_features=300, bias=True)
#   (41): Tanh()
#   (42): Linear(in_features=300, out_features=300, bias=True)
#   (43): Tanh()
#   (44): Linear(in_features=300, out_features=300, bias=True)
#   (45): Tanh()
#   (46): Linear(in_features=300, out_features=300, bias=True)
#   (47): Tanh()
#   (48): Linear(in_features=300, out_features=300, bias=True)
#   (49): Tanh()
#   (50): Linear(in_features=300, out_features=300, bias=True)
#   (51): Tanh()
#   (52): Linear(in_features=300, out_features=300, bias=True)
#   (53): Tanh()
#   (54): Linear(in_features=300, out_features=300, bias=True)
#   (55): Tanh()
#   (56): Linear(in_features=300, out_features=300, bias=True)
#   (57): Tanh()
#   (58): Linear(in_features=300, out_features=300, bias=True)
#   (59): Tanh()
#   (60): Linear(in_features=300, out_features=300, bias=True)
#   (61): Tanh()
#   (62): Linear(in_features=300, out_features=300, bias=True)
#   (63): Tanh()
#   (64): Linear(in_features=300, out_features=300, bias=True)
#   (65): Tanh()
#   (66): Linear(in_features=300, out_features=300, bias=True)
#   (67): Tanh()
#   (68): Linear(in_features=300, out_features=300, bias=True)
#   (69): Tanh()
#   (70): Linear(in_features=300, out_features=300, bias=True)
#   (71): Tanh()
#   (72): Linear(in_features=300, out_features=300, bias=True)
#   (73): Tanh()
#   (74): Linear(in_features=300, out_features=300, bias=True)
#   (75): Tanh()
#   (76): Linear(in_features=300, out_features=300, bias=True)
#   (77): Tanh()
#   (78): Linear(in_features=300, out_features=300, bias=True)
#   (79): Tanh()
#   (80): Linear(in_features=300, out_features=300, bias=True)
#   (81): Tanh()
#   (82): Linear(in_features=300, out_features=300, bias=True)
#   (83): Tanh()
#   (84): Linear(in_features=300, out_features=300, bias=True)
#   (85): Tanh()
#   (86): Linear(in_features=300, out_features=300, bias=True)
#   (87): Tanh()
#   (88): Linear(in_features=300, out_features=300, bias=True)
#   (89): Tanh()
#   (90): Linear(in_features=300, out_features=300, bias=True)
#   (91): Tanh()
#   (92): Linear(in_features=300, out_features=300, bias=True)
#   (93): Tanh()
#   (94): Linear(in_features=300, out_features=300, bias=True)
#   (95): Tanh()
#   (96): Linear(in_features=300, out_features=300, bias=True)
#   (97): Tanh()
#   (98): Linear(in_features=300, out_features=300, bias=True)
#   (99): Tanh()
#   (100): Linear(in_features=300, out_features=300, bias=True)
#   (101): Tanh()
#   (102): Linear(in_features=300, out_features=300, bias=True)
#   (103): Tanh()
#   (104): Linear(in_features=300, out_features=300, bias=True)
#   (105): Tanh()
#   (106): Linear(in_features=300, out_features=300, bias=True)
#   (107): Tanh()
#   (108): Linear(in_features=300, out_features=300, bias=True)
#   (109): Tanh()
#   (110): Linear(in_features=300, out_features=300, bias=True)
#   (111): Tanh()
#   (112): Linear(in_features=300, out_features=300, bias=True)
#   (113): Tanh()
#   (114): Linear(in_features=300, out_features=300, bias=True)
#   (115): Tanh()
#   (116): Linear(in_features=300, out_features=300, bias=True)
#   (117): Tanh()
#   (118): Linear(in_features=300, out_features=300, bias=True)
#   (119): Tanh()
#   (120): Linear(in_features=300, out_features=300, bias=True)
#   (121): Tanh()
#   (122): Linear(in_features=300, out_features=300, bias=True)
#   (123): Tanh()
#   (124): Linear(in_features=300, out_features=300, bias=True)
#   (125): Tanh()
#   (126): Linear(in_features=300, out_features=300, bias=True)
#   (127): Tanh()
#   (128): Linear(in_features=300, out_features=300, bias=True)
#   (129): Tanh()
#   (130): Linear(in_features=300, out_features=300, bias=True)
#   (131): Tanh()
#   (132): Linear(in_features=300, out_features=300, bias=True)
#   (133): Tanh()
#   (134): Linear(in_features=300, out_features=300, bias=True)
#   (135): Tanh()
#   (136): Linear(in_features=300, out_features=300, bias=True)
#   (137): Tanh()
#   (138): Linear(in_features=300, out_features=300, bias=True)
#   (139): Tanh()
#   (140): Linear(in_features=300, out_features=300, bias=True)
#   (141): Tanh()
#   (142): Linear(in_features=300, out_features=300, bias=True)
#   (143): Tanh()
#   (144): Linear(in_features=300, out_features=300, bias=True)
#   (145): Tanh()
#   (146): Linear(in_features=300, out_features=300, bias=True)
#   (147): Tanh()
#   (148): Linear(in_features=300, out_features=300, bias=True)
#   (149): Tanh()
#   (150): Linear(in_features=300, out_features=300, bias=True)
#   (151): Tanh()
#   (152): Linear(in_features=300, out_features=300, bias=True)
#   (153): Tanh()
#   (154): Linear(in_features=300, out_features=300, bias=True)
#   (155): Tanh()
#   (156): Linear(in_features=300, out_features=300, bias=True)
#   (157): Tanh()
#   (158): Linear(in_features=300, out_features=300, bias=True)
#   (159): Tanh()
#   (160): Linear(in_features=300, out_features=300, bias=True)
#   (161): Tanh()
#   (162): Linear(in_features=300, out_features=300, bias=True)
#   (163): Tanh()
#   (164): Linear(in_features=300, out_features=300, bias=True)
#   (165): Tanh()
#   (166): Linear(in_features=300, out_features=300, bias=True)
#   (167): Tanh()
#   (168): Linear(in_features=300, out_features=300, bias=True)
#   (169): Tanh()
#   (170): Linear(in_features=300, out_features=300, bias=True)
#   (171): Tanh()
#   (172): Linear(in_features=300, out_features=300, bias=True)
#   (173): Tanh()
#   (174): Linear(in_features=300, out_features=300, bias=True)
#   (175): Tanh()
#   (176): Linear(in_features=300, out_features=300, bias=True)
#   (177): Tanh()
#   (178): Linear(in_features=300, out_features=300, bias=True)
#   (179): Tanh()
#   (180): Linear(in_features=300, out_features=300, bias=True)
#   (181): Tanh()
#   (182): Linear(in_features=300, out_features=300, bias=True)
#   (183): Tanh()
#   (184): Linear(in_features=300, out_features=300, bias=True)
#   (185): Tanh()
#   (186): Linear(in_features=300, out_features=300, bias=True)
#   (187): Tanh()
#   (188): Linear(in_features=300, out_features=300, bias=True)
#   (189): Tanh()
#   (190): Linear(in_features=300, out_features=300, bias=True)
#   (191): Tanh()
#   (192): Linear(in_features=300, out_features=300, bias=True)
#   (193): Tanh()
#   (194): Linear(in_features=300, out_features=300, bias=True)
#   (195): Tanh()
#   (196): Linear(in_features=300, out_features=300, bias=True)
#   (197): Tanh()
#   (198): Linear(in_features=300, out_features=10, bias=True)
#   (199): LogSoftmax(dim=1)
# )

# %%
eval(fashion_model, device, fashion_dataset.train_loader, debug=False)
# Out:
# 0.9078888888888889

# %% [markdown]
# ### finetuned staring from regular mnist

# %%
params
# Out:
# {'width': 300,
#  'lr': 0.001,
#  'num_train': 60,
#  'sb': 0.05,
#  'depth': 100,
#  'sw': 1.7346938775510203,
#  'early_stop_patience': 10,
#  'batch_size': 256,
#  'device': device(type='cuda')}

# %%
#luckily, the number of classes is the same, so we don't need to change the last layer.
from tqdm import tqdm

number_dataset = MNISTtrainer(batch_size)

cut_models = []

# epochs fro fine tuning
params['num_train'] = 10
params['early_stop_patience'] = False

for cut in tqdm(range(0, depth, 10)):
    temp = {}
    temp['cut_model'] = cut_model(fashion_model, sw = params['sw'], sb = params['sb'], cut_point = cut, freeze=False)
    finetuned_acc, finetuned_test_acc, finetuned_model = compute_training_acc_epochs(temp['cut_model'], number_dataset, params, debug=False)
    temp['finetuned_acc'] = finetuned_acc
    temp['finetuned_test_acc'] = finetuned_test_acc
    temp['finetuned_model'] = finetuned_model
    cut_models.append(temp)
    # save everything - ?
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 181050494.02it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 45832649.95it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 83220718.83it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 1829319.07it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw
# 100%|██████████| 10/10 [23:22<00:00, 140.22s/it]

# %% [markdown]
# # Froze the Layers

# %%
from pprint import pprint

for i, mod in enumerate(cut_models):
    print(f"Cut {i*10}:")
    pprint(mod['finetuned_acc'])
# Out:
# Cut 0:
# 0.9467037037037037
# Cut 10:
# 0.884962962962963
# Cut 20:
# 0.7794074074074074
# Cut 30:
# 0.680074074074074
# Cut 40:
# 0.6113703703703703
# Cut 50:
# 0.5469074074074074
# Cut 60:
# 0.4998148148148148
# Cut 70:
# 0.4489444444444444
# Cut 80:
# 0.39825925925925926
# Cut 90:
# 0.37275925925925923

# %%
import matplotlib.pyplot as plt

finetuned_accs = [model['finetuned_acc'] for model in cut_models]
cuts = range(0,len(finetuned_accs)*10,10)
plt.plot(cuts, finetuned_accs)
plt.xlabel('Cut')
plt.ylabel('Finetuned Accuracy')
plt.title('Finetuned Accuracy vs Cut')
plt.show()

# %%
import matplotlib.pyplot as plt

finetuned_test_accs = [model['finetuned_test_acc'] for model in cut_models]
cuts = range(len(finetuned_test_accs))
plt.plot(cuts, finetuned_test_accs)
plt.xlabel('Cut')
plt.ylabel('Finetuned Test Accuracy')
plt.title('Finetuned Test Accuracy vs Cut')
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# # Variances

# %%
def compute_layer_variances(model, test_loader, device='cpu'):
    # Define a hook to collect activations
    activations = {}

    def create_hook(name):
        def hook(module, input, output):
            activations[name] = output
        return hook

    for i, layer in enumerate(linear_layers):
        layer.register_forward_hook(create_hook("linear_{}".format(i)))

    for i, layer in enumerate(activation_layers):
        layer.register_forward_hook(create_hook("tanh_{}".format(i)))

    # Run inference on the test set
    with torch.no_grad():
        for images, _ in test_loader:
            images = images.reshape([images.shape[0], -1]).to(device)
            outputs = model(images)

    # Calculate and print variance for each layer's activations
    variances = {key: torch.var(act, dim=0) for key, act in activations.items()}

    result = {}
    for layer_name, variance in variances.items():
        result[layer_name] = variance.mean().item()

    return result, variances

# Usage:
linear_layers = []
activation_layers = []
for i, layer in enumerate(fashion_model.modules()):
  if i % 2 == 1:
    linear_layers.append(layer)
  else:
    activation_layers.append(layer)
activation_layers = activation_layers[1:]

results, variances = compute_layer_variances(fashion_model, fashion_dataset.test_loader, device = 'cuda')
for layer_name, variance in results.items():
    print(f"Layer {layer_name} - Variance: {variance}")

import matplotlib.pyplot as plt

# Create a list of layer names and variances
layer_names = list(variances.keys())
variance_values = [variance.mean().item() for variance in variances.values()]

# Plot the variances
plt.plot(layer_names[:-2], variance_values[:-2])
plt.xticks(rotation=90)
plt.xlabel('Layer Name')
plt.ylabel('Variance')
plt.title('Activation Variances')
plt.show()
# Out:
# Layer linear_0 - Variance: 0.31452760100364685
# Layer tanh_0 - Variance: 0.14261914789676666
# Layer linear_1 - Variance: 0.24732615053653717
# Layer tanh_1 - Variance: 0.12973791360855103
# Layer linear_2 - Variance: 0.23917338252067566
# Layer tanh_2 - Variance: 0.1279456913471222
# Layer linear_3 - Variance: 0.21903987228870392
# Layer tanh_3 - Variance: 0.12167692929506302
# Layer linear_4 - Variance: 0.21989098191261292
# Layer tanh_4 - Variance: 0.12018883228302002
# Layer linear_5 - Variance: 0.22180484235286713
# Layer tanh_5 - Variance: 0.1231466680765152
# Layer linear_6 - Variance: 0.22994598746299744
# Layer tanh_6 - Variance: 0.12301275879144669
# Layer linear_7 - Variance: 0.22340093553066254
# Layer tanh_7 - Variance: 0.12016244232654572
# Layer linear_8 - Variance: 0.22513630986213684
# Layer tanh_8 - Variance: 0.11776024103164673
# Layer linear_9 - Variance: 0.21309299767017365
# Layer tanh_9 - Variance: 0.11389541625976562
# Layer linear_10 - Variance: 0.21464188396930695
# Layer tanh_10 - Variance: 0.11404630541801453
# Layer linear_11 - Variance: 0.19589027762413025
# Layer tanh_11 - Variance: 0.10293030738830566
# Layer linear_12 - Variance: 0.19046726822853088
# Layer tanh_12 - Variance: 0.10323355346918106
# Layer linear_13 - Variance: 0.19006693363189697
# Layer tanh_13 - Variance: 0.10175281763076782
# Layer linear_14 - Variance: 0.19337940216064453
# Layer tanh_14 - Variance: 0.10664837807416916
# Layer linear_15 - Variance: 0.19443392753601074
# Layer tanh_15 - Variance: 0.10720590502023697
# Layer linear_16 - Variance: 0.19635796546936035
# Layer tanh_16 - Variance: 0.11072975397109985
# Layer linear_17 - Variance: 0.19971629977226257
# Layer tanh_17 - Variance: 0.11033498495817184
# Layer linear_18 - Variance: 0.21226324141025543
# Layer tanh_18 - Variance: 0.11974824219942093
# Layer linear_19 - Variance: 0.23352114856243134
# Layer tanh_19 - Variance: 0.1248217523097992
# Layer linear_20 - Variance: 0.23238983750343323
# Layer tanh_20 - Variance: 0.12391991168260574
# Layer linear_21 - Variance: 0.21168754994869232
# Layer tanh_21 - Variance: 0.11929059773683548
# Layer linear_22 - Variance: 0.22068116068840027
# Layer tanh_22 - Variance: 0.12852013111114502
# Layer linear_23 - Variance: 0.23575443029403687
# Layer tanh_23 - Variance: 0.12954148650169373
# Layer linear_24 - Variance: 0.23684047162532806
# Layer tanh_24 - Variance: 0.12921977043151855
# Layer linear_25 - Variance: 0.24278518557548523
# Layer tanh_25 - Variance: 0.13313056528568268
# Layer linear_26 - Variance: 0.25091493129730225
# Layer tanh_26 - Variance: 0.14044685661792755
# Layer linear_27 - Variance: 0.2713121175765991
# Layer tanh_27 - Variance: 0.14442701637744904
# Layer linear_28 - Variance: 0.25549209117889404
# Layer tanh_28 - Variance: 0.13685888051986694
# Layer linear_29 - Variance: 0.24429215490818024
# Layer tanh_29 - Variance: 0.13718290627002716
# Layer linear_30 - Variance: 0.24205951392650604
# Layer tanh_30 - Variance: 0.1314712017774582
# Layer linear_31 - Variance: 0.23374156653881073
# Layer tanh_31 - Variance: 0.12986354529857635
# Layer linear_32 - Variance: 0.21870364248752594
# Layer tanh_32 - Variance: 0.12416092306375504
# Layer linear_33 - Variance: 0.22639013826847076
# Layer tanh_33 - Variance: 0.12912483513355255
# Layer linear_34 - Variance: 0.22643181681632996
# Layer tanh_34 - Variance: 0.1269860565662384
# Layer linear_35 - Variance: 0.2268373668193817
# Layer tanh_35 - Variance: 0.12359614670276642
# Layer linear_36 - Variance: 0.2260478287935257
# Layer tanh_36 - Variance: 0.12037519365549088
# Layer linear_37 - Variance: 0.2143113762140274
# Layer tanh_37 - Variance: 0.11620746552944183
# Layer linear_38 - Variance: 0.1984957456588745
# Layer tanh_38 - Variance: 0.11368938535451889
# Layer linear_39 - Variance: 0.2161678671836853
# Layer tanh_39 - Variance: 0.11768952757120132
# Layer linear_40 - Variance: 0.21688835322856903
# Layer tanh_40 - Variance: 0.11771886795759201
# Layer linear_41 - Variance: 0.2269165813922882
# Layer tanh_41 - Variance: 0.12123077362775803
# Layer linear_42 - Variance: 0.22363431751728058
# Layer tanh_42 - Variance: 0.1206464171409607
# Layer linear_43 - Variance: 0.20485082268714905
# Layer tanh_43 - Variance: 0.11427939683198929
# Layer linear_44 - Variance: 0.20076148211956024
# Layer tanh_44 - Variance: 0.10987311601638794
# Layer linear_45 - Variance: 0.18835662305355072
# Layer tanh_45 - Variance: 0.1034320518374443
# Layer linear_46 - Variance: 0.19012406468391418
# Layer tanh_46 - Variance: 0.10761459916830063
# Layer linear_47 - Variance: 0.19387008249759674
# Layer tanh_47 - Variance: 0.10381955653429031
# Layer linear_48 - Variance: 0.18595795333385468
# Layer tanh_48 - Variance: 0.1009507030248642
# Layer linear_49 - Variance: 0.1821352243423462
# Layer tanh_49 - Variance: 0.09932571649551392
# Layer linear_50 - Variance: 0.17969277501106262
# Layer tanh_50 - Variance: 0.10131531953811646
# Layer linear_51 - Variance: 0.182709202170372
# Layer tanh_51 - Variance: 0.10075205564498901
# Layer linear_52 - Variance: 0.18086786568164825
# Layer tanh_52 - Variance: 0.0991630032658577
# Layer linear_53 - Variance: 0.18800325691699982
# Layer tanh_53 - Variance: 0.0999530702829361
# Layer linear_54 - Variance: 0.1830018162727356
# Layer tanh_54 - Variance: 0.10407085716724396
# Layer linear_55 - Variance: 0.19081619381904602
# Layer tanh_55 - Variance: 0.10892222076654434
# Layer linear_56 - Variance: 0.2100520133972168
# Layer tanh_56 - Variance: 0.117435522377491
# Layer linear_57 - Variance: 0.2254718542098999
# Layer tanh_57 - Variance: 0.12380623072385788
# Layer linear_58 - Variance: 0.2181847244501114
# Layer tanh_58 - Variance: 0.11858120560646057
# Layer linear_59 - Variance: 0.21024566888809204
# Layer tanh_59 - Variance: 0.11416231840848923
# Layer linear_60 - Variance: 0.19914011657238007
# Layer tanh_60 - Variance: 0.10900828242301941
# Layer linear_61 - Variance: 0.18585576117038727
# Layer tanh_61 - Variance: 0.1028396263718605
# Layer linear_62 - Variance: 0.19651877880096436
# Layer tanh_62 - Variance: 0.11165241152048111
# Layer linear_63 - Variance: 0.2023443877696991
# Layer tanh_63 - Variance: 0.11423533409833908
# Layer linear_64 - Variance: 0.20655466616153717
# Layer tanh_64 - Variance: 0.11418238282203674
# Layer linear_65 - Variance: 0.21893206238746643
# Layer tanh_65 - Variance: 0.11854784935712814
# Layer linear_66 - Variance: 0.22597478330135345
# Layer tanh_66 - Variance: 0.12314974516630173
# Layer linear_67 - Variance: 0.22174204885959625
# Layer tanh_67 - Variance: 0.1198723092675209
# Layer linear_68 - Variance: 0.21613577008247375
# Layer tanh_68 - Variance: 0.11727595329284668
# Layer linear_69 - Variance: 0.20858868956565857
# Layer tanh_69 - Variance: 0.11332706362009048
# Layer linear_70 - Variance: 0.2045479118824005
# Layer tanh_70 - Variance: 0.11194505542516708
# Layer linear_71 - Variance: 0.20606820285320282
# Layer tanh_71 - Variance: 0.11351995170116425
# Layer linear_72 - Variance: 0.2074984610080719
# Layer tanh_72 - Variance: 0.1128532662987709
# Layer linear_73 - Variance: 0.20612160861492157
# Layer tanh_73 - Variance: 0.11009807884693146
# Layer linear_74 - Variance: 0.2071315497159958
# Layer tanh_74 - Variance: 0.11172925680875778
# Layer linear_75 - Variance: 0.20593132078647614
# Layer tanh_75 - Variance: 0.1152946725487709
# Layer linear_76 - Variance: 0.2148134708404541
# Layer tanh_76 - Variance: 0.11667091399431229
# Layer linear_77 - Variance: 0.21432210505008698
# Layer tanh_77 - Variance: 0.11706492304801941
# Layer linear_78 - Variance: 0.21989242732524872
# Layer tanh_78 - Variance: 0.119659423828125
# Layer linear_79 - Variance: 0.21605803072452545
# Layer tanh_79 - Variance: 0.12182751297950745
# Layer linear_80 - Variance: 0.22187884151935577
# Layer tanh_80 - Variance: 0.12299789488315582
# Layer linear_81 - Variance: 0.22534798085689545
# Layer tanh_81 - Variance: 0.12174202501773834
# Layer linear_82 - Variance: 0.2250610888004303
# Layer tanh_82 - Variance: 0.1200188472867012
# Layer linear_83 - Variance: 0.22844921052455902
# Layer tanh_83 - Variance: 0.12195025384426117
# Layer linear_84 - Variance: 0.22301585972309113
# Layer tanh_84 - Variance: 0.12170308828353882
# Layer linear_85 - Variance: 0.2339433878660202
# Layer tanh_85 - Variance: 0.12782832980155945
# Layer linear_86 - Variance: 0.22717590630054474
# Layer tanh_86 - Variance: 0.12609821557998657
# Layer linear_87 - Variance: 0.23590098321437836
# Layer tanh_87 - Variance: 0.12609560787677765
# Layer linear_88 - Variance: 0.2237814962863922
# Layer tanh_88 - Variance: 0.11948862671852112
# Layer linear_89 - Variance: 0.22465424239635468
# Layer tanh_89 - Variance: 0.12100033462047577
# Layer linear_90 - Variance: 0.22475281357765198
# Layer tanh_90 - Variance: 0.12065428495407104
# Layer linear_91 - Variance: 0.2133571356534958
# Layer tanh_91 - Variance: 0.11620776355266571
# Layer linear_92 - Variance: 0.21717850863933563
# Layer tanh_92 - Variance: 0.11386574059724808
# Layer linear_93 - Variance: 0.2035626769065857
# Layer tanh_93 - Variance: 0.10968567430973053
# Layer linear_94 - Variance: 0.20260821282863617
# Layer tanh_94 - Variance: 0.10697714984416962
# Layer linear_95 - Variance: 0.19794099032878876
# Layer tanh_95 - Variance: 0.10433504730463028
# Layer linear_96 - Variance: 0.19210152328014374
# Layer tanh_96 - Variance: 0.09769241511821747
# Layer linear_97 - Variance: 0.17796507477760315
# Layer tanh_97 - Variance: 0.09376485645771027
# Layer linear_98 - Variance: 0.18677249550819397
# Layer tanh_98 - Variance: 0.09562373906373978
# Layer linear_99 - Variance: 13.13116455078125
# Layer tanh_99 - Variance: 16.292749404907227

# %%
# Same on the train set:
results, variances = compute_layer_variances(fashion_model, fashion_dataset.train_loader, device = 'cuda')
for layer_name, variance in results.items():
    print(f"Layer {layer_name} - Variance: {variance}")

import matplotlib.pyplot as plt

# Create a list of layer names and variances
layer_names = list(variances.keys())
variance_values = [variance.mean().item() for variance in variances.values()]

# Plot the variances
plt.plot(layer_names[:-2], variance_values[:-2])
plt.xticks(rotation=90)
plt.xlabel('Layer Name')
plt.ylabel('Variance')
plt.title('Activation Variances')
plt.show()
# Out:
# Layer linear_0 - Variance: 0.3893282413482666
# Layer tanh_0 - Variance: 0.17486345767974854
# Layer linear_1 - Variance: 0.3105175197124481
# Layer tanh_1 - Variance: 0.1572810411453247
# Layer linear_2 - Variance: 0.29265663027763367
# Layer tanh_2 - Variance: 0.1542920172214508
# Layer linear_3 - Variance: 0.26932260394096375
# Layer tanh_3 - Variance: 0.14528626203536987
# Layer linear_4 - Variance: 0.2635204792022705
# Layer tanh_4 - Variance: 0.14160476624965668
# Layer linear_5 - Variance: 0.26112350821495056
# Layer tanh_5 - Variance: 0.143144428730011
# Layer linear_6 - Variance: 0.2690756022930145
# Layer tanh_6 - Variance: 0.14462265372276306
# Layer linear_7 - Variance: 0.26512572169303894
# Layer tanh_7 - Variance: 0.14238594472408295
# Layer linear_8 - Variance: 0.26500046253204346
# Layer tanh_8 - Variance: 0.13741470873355865
# Layer linear_9 - Variance: 0.24606192111968994
# Layer tanh_9 - Variance: 0.13110089302062988
# Layer linear_10 - Variance: 0.2416406273841858
# Layer tanh_10 - Variance: 0.12919339537620544
# Layer linear_11 - Variance: 0.21980105340480804
# Layer tanh_11 - Variance: 0.11611247062683105
# Layer linear_12 - Variance: 0.21077105402946472
# Layer tanh_12 - Variance: 0.11334636807441711
# Layer linear_13 - Variance: 0.21504728496074677
# Layer tanh_13 - Variance: 0.11354085803031921
# Layer linear_14 - Variance: 0.21157008409500122
# Layer tanh_14 - Variance: 0.11628591269254684
# Layer linear_15 - Variance: 0.2138734757900238
# Layer tanh_15 - Variance: 0.11579713225364685
# Layer linear_16 - Variance: 0.21204185485839844
# Layer tanh_16 - Variance: 0.11938492208719254
# Layer linear_17 - Variance: 0.20705482363700867
# Layer tanh_17 - Variance: 0.11493097990751266
# Layer linear_18 - Variance: 0.21700599789619446
# Layer tanh_18 - Variance: 0.12275578081607819
# Layer linear_19 - Variance: 0.2339051365852356
# Layer tanh_19 - Variance: 0.1273939609527588
# Layer linear_20 - Variance: 0.22833473980426788
# Layer tanh_20 - Variance: 0.12379857897758484
# Layer linear_21 - Variance: 0.214654341340065
# Layer tanh_21 - Variance: 0.11979861557483673
# Layer linear_22 - Variance: 0.22090739011764526
# Layer tanh_22 - Variance: 0.12911829352378845
# Layer linear_23 - Variance: 0.2419901341199875
# Layer tanh_23 - Variance: 0.13641566038131714
# Layer linear_24 - Variance: 0.25156423449516296
# Layer tanh_24 - Variance: 0.13886184990406036
# Layer linear_25 - Variance: 0.2625792622566223
# Layer tanh_25 - Variance: 0.14469009637832642
# Layer linear_26 - Variance: 0.2696519196033478
# Layer tanh_26 - Variance: 0.1497986614704132
# Layer linear_27 - Variance: 0.29321372509002686
# Layer tanh_27 - Variance: 0.1562802791595459
# Layer linear_28 - Variance: 0.27385401725769043
# Layer tanh_28 - Variance: 0.148804172873497
# Layer linear_29 - Variance: 0.268287718296051
# Layer tanh_29 - Variance: 0.1472989171743393
# Layer linear_30 - Variance: 0.2573924660682678
# Layer tanh_30 - Variance: 0.14127136766910553
# Layer linear_31 - Variance: 0.24603737890720367
# Layer tanh_31 - Variance: 0.13794434070587158
# Layer linear_32 - Variance: 0.23216718435287476
# Layer tanh_32 - Variance: 0.13063205778598785
# Layer linear_33 - Variance: 0.23882588744163513
# Layer tanh_33 - Variance: 0.13462504744529724
# Layer linear_34 - Variance: 0.24112343788146973
# Layer tanh_34 - Variance: 0.13618849217891693
# Layer linear_35 - Variance: 0.23915192484855652
# Layer tanh_35 - Variance: 0.12918929755687714
# Layer linear_36 - Variance: 0.2400340884923935
# Layer tanh_36 - Variance: 0.12689171731472015
# Layer linear_37 - Variance: 0.22787761688232422
# Layer tanh_37 - Variance: 0.12474986165761948
# Layer linear_38 - Variance: 0.2191493809223175
# Layer tanh_38 - Variance: 0.12442360073328018
# Layer linear_39 - Variance: 0.23224620521068573
# Layer tanh_39 - Variance: 0.12686055898666382
# Layer linear_40 - Variance: 0.23137646913528442
# Layer tanh_40 - Variance: 0.12437177449464798
# Layer linear_41 - Variance: 0.2384650707244873
# Layer tanh_41 - Variance: 0.12913364171981812
# Layer linear_42 - Variance: 0.24585551023483276
# Layer tanh_42 - Variance: 0.13226576149463654
# Layer linear_43 - Variance: 0.2247384637594223
# Layer tanh_43 - Variance: 0.12431741505861282
# Layer linear_44 - Variance: 0.22696904838085175
# Layer tanh_44 - Variance: 0.12199651449918747
# Layer linear_45 - Variance: 0.21199876070022583
# Layer tanh_45 - Variance: 0.1134297177195549
# Layer linear_46 - Variance: 0.21343407034873962
# Layer tanh_46 - Variance: 0.11881259083747864
# Layer linear_47 - Variance: 0.21274752914905548
# Layer tanh_47 - Variance: 0.11430341005325317
# Layer linear_48 - Variance: 0.2088225930929184
# Layer tanh_48 - Variance: 0.11366453766822815
# Layer linear_49 - Variance: 0.20904067158699036
# Layer tanh_49 - Variance: 0.11466512084007263
# Layer linear_50 - Variance: 0.20990288257598877
# Layer tanh_50 - Variance: 0.11697886139154434
# Layer linear_51 - Variance: 0.20826563239097595
# Layer tanh_51 - Variance: 0.11509880423545837
# Layer linear_52 - Variance: 0.20577600598335266
# Layer tanh_52 - Variance: 0.11363853514194489
# Layer linear_53 - Variance: 0.2130475640296936
# Layer tanh_53 - Variance: 0.11510661989450455
# Layer linear_54 - Variance: 0.2130020707845688
# Layer tanh_54 - Variance: 0.1198548898100853
# Layer linear_55 - Variance: 0.2227461338043213
# Layer tanh_55 - Variance: 0.12515948712825775
# Layer linear_56 - Variance: 0.2269795536994934
# Layer tanh_56 - Variance: 0.12754641473293304
# Layer linear_57 - Variance: 0.24663294851779938
# Layer tanh_57 - Variance: 0.13388793170452118
# Layer linear_58 - Variance: 0.24791792035102844
# Layer tanh_58 - Variance: 0.13266108930110931
# Layer linear_59 - Variance: 0.23607325553894043
# Layer tanh_59 - Variance: 0.126951664686203
# Layer linear_60 - Variance: 0.21998530626296997
# Layer tanh_60 - Variance: 0.11939733475446701
# Layer linear_61 - Variance: 0.20481647551059723
# Layer tanh_61 - Variance: 0.11193527281284332
# Layer linear_62 - Variance: 0.21024440228939056
# Layer tanh_62 - Variance: 0.1182878389954567
# Layer linear_63 - Variance: 0.21825271844863892
# Layer tanh_63 - Variance: 0.12022451311349869
# Layer linear_64 - Variance: 0.21332375705242157
# Layer tanh_64 - Variance: 0.118486687541008
# Layer linear_65 - Variance: 0.22201918065547943
# Layer tanh_65 - Variance: 0.12095071375370026
# Layer linear_66 - Variance: 0.231011301279068
# Layer tanh_66 - Variance: 0.1273701786994934
# Layer linear_67 - Variance: 0.2302245944738388
# Layer tanh_67 - Variance: 0.12584775686264038
# Layer linear_68 - Variance: 0.22917461395263672
# Layer tanh_68 - Variance: 0.1248510554432869
# Layer linear_69 - Variance: 0.22347629070281982
# Layer tanh_69 - Variance: 0.11996948719024658
# Layer linear_70 - Variance: 0.2170202136039734
# Layer tanh_70 - Variance: 0.11740397661924362
# Layer linear_71 - Variance: 0.21802571415901184
# Layer tanh_71 - Variance: 0.12051821500062943
# Layer linear_72 - Variance: 0.22595179080963135
# Layer tanh_72 - Variance: 0.12243885546922684
# Layer linear_73 - Variance: 0.223985493183136
# Layer tanh_73 - Variance: 0.11976311355829239
# Layer linear_74 - Variance: 0.21434570848941803
# Layer tanh_74 - Variance: 0.11632697284221649
# Layer linear_75 - Variance: 0.2154010534286499
# Layer tanh_75 - Variance: 0.12046651542186737
# Layer linear_76 - Variance: 0.23008780181407928
# Layer tanh_76 - Variance: 0.12281881272792816
# Layer linear_77 - Variance: 0.22529327869415283
# Layer tanh_77 - Variance: 0.12122821062803268
# Layer linear_78 - Variance: 0.22690466046333313
# Layer tanh_78 - Variance: 0.12492933124303818
# Layer linear_79 - Variance: 0.22546055912971497
# Layer tanh_79 - Variance: 0.1266508251428604
# Layer linear_80 - Variance: 0.2360188364982605
# Layer tanh_80 - Variance: 0.13123129308223724
# Layer linear_81 - Variance: 0.24053025245666504
# Layer tanh_81 - Variance: 0.12950566411018372
# Layer linear_82 - Variance: 0.23942774534225464
# Layer tanh_82 - Variance: 0.12726375460624695
# Layer linear_83 - Variance: 0.2420310527086258
# Layer tanh_83 - Variance: 0.12796969711780548
# Layer linear_84 - Variance: 0.2324478179216385
# Layer tanh_84 - Variance: 0.12686192989349365
# Layer linear_85 - Variance: 0.23979614675045013
# Layer tanh_85 - Variance: 0.13080592453479767
# Layer linear_86 - Variance: 0.23366639018058777
# Layer tanh_86 - Variance: 0.12848025560379028
# Layer linear_87 - Variance: 0.24376465380191803
# Layer tanh_87 - Variance: 0.12966525554656982
# Layer linear_88 - Variance: 0.22675074636936188
# Layer tanh_88 - Variance: 0.1215704157948494
# Layer linear_89 - Variance: 0.22983984649181366
# Layer tanh_89 - Variance: 0.12271178513765335
# Layer linear_90 - Variance: 0.2272631824016571
# Layer tanh_90 - Variance: 0.12108200043439865
# Layer linear_91 - Variance: 0.22155645489692688
# Layer tanh_91 - Variance: 0.12026716023683548
# Layer linear_92 - Variance: 0.22614003717899323
# Layer tanh_92 - Variance: 0.1191215068101883
# Layer linear_93 - Variance: 0.2108745127916336
# Layer tanh_93 - Variance: 0.11326950043439865
# Layer linear_94 - Variance: 0.20949794352054596
# Layer tanh_94 - Variance: 0.11063150316476822
# Layer linear_95 - Variance: 0.20810526609420776
# Layer tanh_95 - Variance: 0.10928811877965927
# Layer linear_96 - Variance: 0.20409058034420013
# Layer tanh_96 - Variance: 0.1048763319849968
# Layer linear_97 - Variance: 0.19601504504680634
# Layer tanh_97 - Variance: 0.10274318605661392
# Layer linear_98 - Variance: 0.2031533420085907
# Layer tanh_98 - Variance: 0.10529213398694992
# Layer linear_99 - Variance: 16.04482650756836
# Layer tanh_99 - Variance: 17.43848419189453

# %%
for idx, mod in enumerate(cut_models):
    # Same for all fine-tuned:
    mod['cut_model'].eval()
    linear_layers = []
    activation_layers = []
    for i, layer in enumerate(mod['cut_model'].modules()):
      if i % 2 == 1:
        linear_layers.append(layer)
      else:
        activation_layers.append(layer)
    activation_layers = activation_layers[1:]
    results, variances = compute_layer_variances(mod['cut_model'], fashion_dataset.test_loader, device = 'cuda')
    # for layer_name, variance in results.items():
    #    print(f"Layer {layer_name} - Variance: {variance}")

    # Create a list of layer names and variances
    layer_names = list(variances.keys())
    variance_values = [variance.mean().item() for variance in variances.values()]

    # Plot the variances
    plt.plot(layer_names[:-2], variance_values[:-2])
    plt.xticks(rotation=90)
    plt.xlabel('Layer Name')
    plt.ylabel('Variance')
    plt.title('Activation Variances Cut: {}'.format(idx*10))
    plt.show()

# %% [markdown]
# # Without Freezing the Layers

# %%
from pprint import pprint

for i, mod in enumerate(cut_models):
    print(f"Cut {i*10}:")
    pprint(mod['finetuned_acc'])
# Out:
# Cut 0:
# 0.9408703703703704
# Cut 10:
# 0.9471296296296297
# Cut 20:
# 0.9413888888888889
# Cut 30:
# 0.9380185185185185
# Cut 40:
# 0.9528518518518518
# Cut 50:
# 0.9414814814814815
# Cut 60:
# 0.9527777777777777
# Cut 70:
# 0.9461296296296297
# Cut 80:
# 0.9537592592592593
# Cut 90:
# 0.9564444444444444

# %%
import matplotlib.pyplot as plt

finetuned_accs = [model['finetuned_acc'] for model in cut_models]
cuts = range(0,len(finetuned_accs)*10,10)
plt.plot(cuts, finetuned_accs)
plt.xlabel('Cut')
plt.ylabel('Finetuned Accuracy')
plt.title('Finetuned Accuracy vs Cut')
plt.show()

# %%
import matplotlib.pyplot as plt

finetuned_accs = [model['finetuned_test_acc'] for model in cut_models]
cuts = range(0,len(finetuned_accs)*10,10)
plt.plot(cuts, finetuned_accs)
plt.xlabel('Cut')
plt.ylabel('Finetuned Test Accuracy')
plt.title('Finetuned Accuracy vs Cut')
plt.show()

# %% [markdown]
# # Variances

# %%
def compute_layer_variances(model, test_loader, device='cpu'):
    # Define a hook to collect activations
    activations = {}

    def create_hook(name):
        def hook(module, input, output):
            activations[name] = output
        return hook

    for i, layer in enumerate(linear_layers):
        layer.register_forward_hook(create_hook("linear_{}".format(i)))

    for i, layer in enumerate(activation_layers):
        layer.register_forward_hook(create_hook("tanh_{}".format(i)))

    # Run inference on the test set
    with torch.no_grad():
        for images, _ in test_loader:
            images = images.reshape([images.shape[0], -1]).to(device)
            outputs = model(images)

    # Calculate and print variance for each layer's activations
    variances = {key: torch.var(act, dim=0) for key, act in activations.items()}

    result = {}
    for layer_name, variance in variances.items():
        result[layer_name] = variance.mean().item()

    return result, variances

# Usage:
linear_layers = []
activation_layers = []
for i, layer in enumerate(fashion_model.modules()):
  if i % 2 == 1:
    linear_layers.append(layer)
  else:
    activation_layers.append(layer)
activation_layers = activation_layers[1:]

results, variances = compute_layer_variances(fashion_model, fashion_dataset.test_loader, device = 'cuda')
for layer_name, variance in results.items():
    print(f"Layer {layer_name} - Variance: {variance}")

import matplotlib.pyplot as plt

# Create a list of layer names and variances
layer_names = list(variances.keys())
variance_values = [variance.mean().item() for variance in variances.values()]

# Plot the variances
plt.plot(layer_names[:-2], variance_values[:-2])
plt.xticks(rotation=90)
plt.xlabel('Layer Name')
plt.ylabel('Variance')
plt.title('Activation Variances')
plt.show()
# Out:
# Layer linear_0 - Variance: 0.38292399048805237
# Layer tanh_0 - Variance: 0.1755739003419876
# Layer linear_1 - Variance: 0.31816259026527405
# Layer tanh_1 - Variance: 0.16353172063827515
# Layer linear_2 - Variance: 0.2958187460899353
# Layer tanh_2 - Variance: 0.15719062089920044
# Layer linear_3 - Variance: 0.2816946804523468
# Layer tanh_3 - Variance: 0.15091222524642944
# Layer linear_4 - Variance: 0.2551898956298828
# Layer tanh_4 - Variance: 0.1383443921804428
# Layer linear_5 - Variance: 0.25151869654655457
# Layer tanh_5 - Variance: 0.1381296068429947
# Layer linear_6 - Variance: 0.259805291891098
# Layer tanh_6 - Variance: 0.13816030323505402
# Layer linear_7 - Variance: 0.24199102818965912
# Layer tanh_7 - Variance: 0.13177314400672913
# Layer linear_8 - Variance: 0.24843163788318634
# Layer tanh_8 - Variance: 0.12934578955173492
# Layer linear_9 - Variance: 0.23673956096172333
# Layer tanh_9 - Variance: 0.125845268368721
# Layer linear_10 - Variance: 0.2318820208311081
# Layer tanh_10 - Variance: 0.12421777099370956
# Layer linear_11 - Variance: 0.21791093051433563
# Layer tanh_11 - Variance: 0.11434738337993622
# Layer linear_12 - Variance: 0.20952509343624115
# Layer tanh_12 - Variance: 0.1129670962691307
# Layer linear_13 - Variance: 0.21079491078853607
# Layer tanh_13 - Variance: 0.11027473956346512
# Layer linear_14 - Variance: 0.1996035873889923
# Layer tanh_14 - Variance: 0.1118282750248909
# Layer linear_15 - Variance: 0.20787635445594788
# Layer tanh_15 - Variance: 0.11326362937688828
# Layer linear_16 - Variance: 0.20047731697559357
# Layer tanh_16 - Variance: 0.11366544663906097
# Layer linear_17 - Variance: 0.19826863706111908
# Layer tanh_17 - Variance: 0.10842718929052353
# Layer linear_18 - Variance: 0.20567284524440765
# Layer tanh_18 - Variance: 0.11882977932691574
# Layer linear_19 - Variance: 0.22062750160694122
# Layer tanh_19 - Variance: 0.12049690634012222
# Layer linear_20 - Variance: 0.21308693289756775
# Layer tanh_20 - Variance: 0.11647920310497284
# Layer linear_21 - Variance: 0.20405612885951996
# Layer tanh_21 - Variance: 0.11357451230287552
# Layer linear_22 - Variance: 0.19803674519062042
# Layer tanh_22 - Variance: 0.1178806871175766
# Layer linear_23 - Variance: 0.21578346192836761
# Layer tanh_23 - Variance: 0.12251905351877213
# Layer linear_24 - Variance: 0.2201218158006668
# Layer tanh_24 - Variance: 0.12350787222385406
# Layer linear_25 - Variance: 0.23638299107551575
# Layer tanh_25 - Variance: 0.13196329772472382
# Layer linear_26 - Variance: 0.24633093178272247
# Layer tanh_26 - Variance: 0.13812264800071716
# Layer linear_27 - Variance: 0.2735544443130493
# Layer tanh_27 - Variance: 0.14419591426849365
# Layer linear_28 - Variance: 0.25804468989372253
# Layer tanh_28 - Variance: 0.13904717564582825
# Layer linear_29 - Variance: 0.2555707097053528
# Layer tanh_29 - Variance: 0.14101000130176544
# Layer linear_30 - Variance: 0.24052715301513672
# Layer tanh_30 - Variance: 0.1347423493862152
# Layer linear_31 - Variance: 0.23317760229110718
# Layer tanh_31 - Variance: 0.13170205056667328
# Layer linear_32 - Variance: 0.22697685658931732
# Layer tanh_32 - Variance: 0.12776869535446167
# Layer linear_33 - Variance: 0.22968889772891998
# Layer tanh_33 - Variance: 0.13123422861099243
# Layer linear_34 - Variance: 0.23216915130615234
# Layer tanh_34 - Variance: 0.13103686273097992
# Layer linear_35 - Variance: 0.2295251339673996
# Layer tanh_35 - Variance: 0.12342781573534012
# Layer linear_36 - Variance: 0.23323796689510345
# Layer tanh_36 - Variance: 0.12207512557506561
# Layer linear_37 - Variance: 0.21517400443553925
# Layer tanh_37 - Variance: 0.11778973042964935
# Layer linear_38 - Variance: 0.2113281935453415
# Layer tanh_38 - Variance: 0.11961988359689713
# Layer linear_39 - Variance: 0.22347427904605865
# Layer tanh_39 - Variance: 0.12231305986642838
# Layer linear_40 - Variance: 0.2278481125831604
# Layer tanh_40 - Variance: 0.12236707657575607
# Layer linear_41 - Variance: 0.2326270043849945
# Layer tanh_41 - Variance: 0.12543651461601257
# Layer linear_42 - Variance: 0.23786605894565582
# Layer tanh_42 - Variance: 0.12718315422534943
# Layer linear_43 - Variance: 0.22892872989177704
# Layer tanh_43 - Variance: 0.12386393547058105
# Layer linear_44 - Variance: 0.2305121123790741
# Layer tanh_44 - Variance: 0.12239581346511841
# Layer linear_45 - Variance: 0.2110362946987152
# Layer tanh_45 - Variance: 0.11232686787843704
# Layer linear_46 - Variance: 0.21300974488258362
# Layer tanh_46 - Variance: 0.11697281152009964
# Layer linear_47 - Variance: 0.2053728997707367
# Layer tanh_47 - Variance: 0.11226196587085724
# Layer linear_48 - Variance: 0.203848734498024
# Layer tanh_48 - Variance: 0.11057057976722717
# Layer linear_49 - Variance: 0.19822055101394653
# Layer tanh_49 - Variance: 0.10950968414545059
# Layer linear_50 - Variance: 0.1991857886314392
# Layer tanh_50 - Variance: 0.10987386107444763
# Layer linear_51 - Variance: 0.1959892064332962
# Layer tanh_51 - Variance: 0.10787506401538849
# Layer linear_52 - Variance: 0.1949331909418106
# Layer tanh_52 - Variance: 0.10747548937797546
# Layer linear_53 - Variance: 0.19453799724578857
# Layer tanh_53 - Variance: 0.10692192614078522
# Layer linear_54 - Variance: 0.1966707706451416
# Layer tanh_54 - Variance: 0.11123225092887878
# Layer linear_55 - Variance: 0.2135881930589676
# Layer tanh_55 - Variance: 0.1199098452925682
# Layer linear_56 - Variance: 0.21847371757030487
# Layer tanh_56 - Variance: 0.12356158345937729
# Layer linear_57 - Variance: 0.23935328423976898
# Layer tanh_57 - Variance: 0.13205641508102417
# Layer linear_58 - Variance: 0.24683693051338196
# Layer tanh_58 - Variance: 0.1329096555709839
# Layer linear_59 - Variance: 0.23221969604492188
# Layer tanh_59 - Variance: 0.12340879440307617
# Layer linear_60 - Variance: 0.21204397082328796
# Layer tanh_60 - Variance: 0.11673574149608612
# Layer linear_61 - Variance: 0.20146729052066803
# Layer tanh_61 - Variance: 0.11002984642982483
# Layer linear_62 - Variance: 0.20134486258029938
# Layer tanh_62 - Variance: 0.11208240687847137
# Layer linear_63 - Variance: 0.21290579438209534
# Layer tanh_63 - Variance: 0.1158733144402504
# Layer linear_64 - Variance: 0.20068055391311646
# Layer tanh_64 - Variance: 0.11138471215963364
# Layer linear_65 - Variance: 0.2150830328464508
# Layer tanh_65 - Variance: 0.11787562072277069
# Layer linear_66 - Variance: 0.2233198583126068
# Layer tanh_66 - Variance: 0.12277505546808243
# Layer linear_67 - Variance: 0.21707195043563843
# Layer tanh_67 - Variance: 0.11908838897943497
# Layer linear_68 - Variance: 0.21251839399337769
# Layer tanh_68 - Variance: 0.11784308403730392
# Layer linear_69 - Variance: 0.21189601719379425
# Layer tanh_69 - Variance: 0.11581289023160934
# Layer linear_70 - Variance: 0.20693397521972656
# Layer tanh_70 - Variance: 0.1145666241645813
# Layer linear_71 - Variance: 0.21262887120246887
# Layer tanh_71 - Variance: 0.11756829917430878
# Layer linear_72 - Variance: 0.21527095139026642
# Layer tanh_72 - Variance: 0.11786850541830063
# Layer linear_73 - Variance: 0.21383413672447205
# Layer tanh_73 - Variance: 0.1128007248044014
# Layer linear_74 - Variance: 0.20090465247631073
# Layer tanh_74 - Variance: 0.10708542168140411
# Layer linear_75 - Variance: 0.1986405849456787
# Layer tanh_75 - Variance: 0.11009707301855087
# Layer linear_76 - Variance: 0.20745092630386353
# Layer tanh_76 - Variance: 0.11045705527067184
# Layer linear_77 - Variance: 0.1982349455356598
# Layer tanh_77 - Variance: 0.10627197474241257
# Layer linear_78 - Variance: 0.19648303091526031
# Layer tanh_78 - Variance: 0.1073259487748146
# Layer linear_79 - Variance: 0.2008468359708786
# Layer tanh_79 - Variance: 0.11126287281513214
# Layer linear_80 - Variance: 0.2048211395740509
# Layer tanh_80 - Variance: 0.11504624783992767
# Layer linear_81 - Variance: 0.20087575912475586
# Layer tanh_81 - Variance: 0.10708893090486526
# Layer linear_82 - Variance: 0.20146231353282928
# Layer tanh_82 - Variance: 0.10867772996425629
# Layer linear_83 - Variance: 0.20438694953918457
# Layer tanh_83 - Variance: 0.1086825579404831
# Layer linear_84 - Variance: 0.19408883154392242
# Layer tanh_84 - Variance: 0.10721076279878616
# Layer linear_85 - Variance: 0.20732958614826202
# Layer tanh_85 - Variance: 0.11204535514116287
# Layer linear_86 - Variance: 0.20440895855426788
# Layer tanh_86 - Variance: 0.11506225913763046
# Layer linear_87 - Variance: 0.22160866856575012
# Layer tanh_87 - Variance: 0.11998222768306732
# Layer linear_88 - Variance: 0.2126854509115219
# Layer tanh_88 - Variance: 0.11650664359331131
# Layer linear_89 - Variance: 0.22137589752674103
# Layer tanh_89 - Variance: 0.11730173975229263
# Layer linear_90 - Variance: 0.21141313016414642
# Layer tanh_90 - Variance: 0.11487133055925369
# Layer linear_91 - Variance: 0.2070339322090149
# Layer tanh_91 - Variance: 0.11396494507789612
# Layer linear_92 - Variance: 0.21415241062641144
# Layer tanh_92 - Variance: 0.1136372908949852
# Layer linear_93 - Variance: 0.2086554914712906
# Layer tanh_93 - Variance: 0.11023259907960892
# Layer linear_94 - Variance: 0.2089027464389801
# Layer tanh_94 - Variance: 0.1073438823223114
# Layer linear_95 - Variance: 0.2063310593366623
# Layer tanh_95 - Variance: 0.10839317739009857
# Layer linear_96 - Variance: 0.2001127153635025
# Layer tanh_96 - Variance: 0.10177386552095413
# Layer linear_97 - Variance: 0.1847766637802124
# Layer tanh_97 - Variance: 0.09404987841844559
# Layer linear_98 - Variance: 0.18532432615756989
# Layer tanh_98 - Variance: 0.09714457392692566
# Layer linear_99 - Variance: 16.421876907348633
# Layer tanh_99 - Variance: 17.498401641845703

# %%
# Same on the train set:
results, variances = compute_layer_variances(fashion_model, fashion_dataset.train_loader, device = 'cuda')
for layer_name, variance in results.items():
    print(f"Layer {layer_name} - Variance: {variance}")

import matplotlib.pyplot as plt

# Create a list of layer names and variances
layer_names = list(variances.keys())
variance_values = [variance.mean().item() for variance in variances.values()]

# Plot the variances
plt.plot(layer_names[:-2], variance_values[:-2])
plt.xticks(rotation=90)
plt.xlabel('Layer Name')
plt.ylabel('Variance')
plt.title('Activation Variances')
plt.show()
# Out:
# Layer linear_0 - Variance: 0.38761627674102783
# Layer tanh_0 - Variance: 0.17336665093898773
# Layer linear_1 - Variance: 0.3105985224246979
# Layer tanh_1 - Variance: 0.15676555037498474
# Layer linear_2 - Variance: 0.2887900471687317
# Layer tanh_2 - Variance: 0.15302343666553497
# Layer linear_3 - Variance: 0.2677745521068573
# Layer tanh_3 - Variance: 0.14530663192272186
# Layer linear_4 - Variance: 0.2598607838153839
# Layer tanh_4 - Variance: 0.13975319266319275
# Layer linear_5 - Variance: 0.25769588351249695
# Layer tanh_5 - Variance: 0.14184337854385376
# Layer linear_6 - Variance: 0.26337072253227234
# Layer tanh_6 - Variance: 0.1421659290790558
# Layer linear_7 - Variance: 0.2605423629283905
# Layer tanh_7 - Variance: 0.1406419575214386
# Layer linear_8 - Variance: 0.2638050615787506
# Layer tanh_8 - Variance: 0.13669006526470184
# Layer linear_9 - Variance: 0.24463745951652527
# Layer tanh_9 - Variance: 0.13008403778076172
# Layer linear_10 - Variance: 0.23935888707637787
# Layer tanh_10 - Variance: 0.12733067572116852
# Layer linear_11 - Variance: 0.21796423196792603
# Layer tanh_11 - Variance: 0.11535728722810745
# Layer linear_12 - Variance: 0.21099023520946503
# Layer tanh_12 - Variance: 0.11367664486169815
# Layer linear_13 - Variance: 0.21632687747478485
# Layer tanh_13 - Variance: 0.1136481910943985
# Layer linear_14 - Variance: 0.21415717899799347
# Layer tanh_14 - Variance: 0.11778979003429413
# Layer linear_15 - Variance: 0.21444158256053925
# Layer tanh_15 - Variance: 0.11635760217905045
# Layer linear_16 - Variance: 0.21292008459568024
# Layer tanh_16 - Variance: 0.11953900754451752
# Layer linear_17 - Variance: 0.20789821445941925
# Layer tanh_17 - Variance: 0.11516746878623962
# Layer linear_18 - Variance: 0.2192499339580536
# Layer tanh_18 - Variance: 0.12379642575979233
# Layer linear_19 - Variance: 0.2345343828201294
# Layer tanh_19 - Variance: 0.12764796614646912
# Layer linear_20 - Variance: 0.232636496424675
# Layer tanh_20 - Variance: 0.12579356133937836
# Layer linear_21 - Variance: 0.21742162108421326
# Layer tanh_21 - Variance: 0.12154978513717651
# Layer linear_22 - Variance: 0.2250153124332428
# Layer tanh_22 - Variance: 0.13087669014930725
# Layer linear_23 - Variance: 0.24539004266262054
# Layer tanh_23 - Variance: 0.13765515387058258
# Layer linear_24 - Variance: 0.2519523799419403
# Layer tanh_24 - Variance: 0.13904331624507904
# Layer linear_25 - Variance: 0.26201310753822327
# Layer tanh_25 - Variance: 0.14407557249069214
# Layer linear_26 - Variance: 0.26995187997817993
# Layer tanh_26 - Variance: 0.1498785763978958
# Layer linear_27 - Variance: 0.29327714443206787
# Layer tanh_27 - Variance: 0.15582513809204102
# Layer linear_28 - Variance: 0.27560514211654663
# Layer tanh_28 - Variance: 0.14903518557548523
# Layer linear_29 - Variance: 0.26777470111846924
# Layer tanh_29 - Variance: 0.14667686820030212
# Layer linear_30 - Variance: 0.25403088331222534
# Layer tanh_30 - Variance: 0.1393776535987854
# Layer linear_31 - Variance: 0.24452754855155945
# Layer tanh_31 - Variance: 0.13686391711235046
# Layer linear_32 - Variance: 0.23159338533878326
# Layer tanh_32 - Variance: 0.13068220019340515
# Layer linear_33 - Variance: 0.23443534970283508
# Layer tanh_33 - Variance: 0.13249251246452332
# Layer linear_34 - Variance: 0.2397487908601761
# Layer tanh_34 - Variance: 0.13524176180362701
# Layer linear_35 - Variance: 0.2402506023645401
# Layer tanh_35 - Variance: 0.13011881709098816
# Layer linear_36 - Variance: 0.2420385777950287
# Layer tanh_36 - Variance: 0.12786616384983063
# Layer linear_37 - Variance: 0.22798971831798553
# Layer tanh_37 - Variance: 0.12372086197137833
# Layer linear_38 - Variance: 0.21665573120117188
# Layer tanh_38 - Variance: 0.12316194176673889
# Layer linear_39 - Variance: 0.22690078616142273
# Layer tanh_39 - Variance: 0.1236538216471672
# Layer linear_40 - Variance: 0.22782552242279053
# Layer tanh_40 - Variance: 0.121799036860466
# Layer linear_41 - Variance: 0.2321217954158783
# Layer tanh_41 - Variance: 0.12579047679901123
# Layer linear_42 - Variance: 0.23737488687038422
# Layer tanh_42 - Variance: 0.12778235971927643
# Layer linear_43 - Variance: 0.21672490239143372
# Layer tanh_43 - Variance: 0.11968203634023666
# Layer linear_44 - Variance: 0.2157772332429886
# Layer tanh_44 - Variance: 0.11658667773008347
# Layer linear_45 - Variance: 0.2029331624507904
# Layer tanh_45 - Variance: 0.10908732563257217
# Layer linear_46 - Variance: 0.20719778537750244
# Layer tanh_46 - Variance: 0.11607465147972107
# Layer linear_47 - Variance: 0.2113420069217682
# Layer tanh_47 - Variance: 0.11327428370714188
# Layer linear_48 - Variance: 0.2072736620903015
# Layer tanh_48 - Variance: 0.11271701008081436
# Layer linear_49 - Variance: 0.20687927305698395
# Layer tanh_49 - Variance: 0.11330307275056839
# Layer linear_50 - Variance: 0.20679908990859985
# Layer tanh_50 - Variance: 0.115634486079216
# Layer linear_51 - Variance: 0.2071685642004013
# Layer tanh_51 - Variance: 0.11460983753204346
# Layer linear_52 - Variance: 0.2047252655029297
# Layer tanh_52 - Variance: 0.11283574998378754
# Layer linear_53 - Variance: 0.21170182526111603
# Layer tanh_53 - Variance: 0.11394108086824417
# Layer linear_54 - Variance: 0.20978568494319916
# Layer tanh_54 - Variance: 0.11812014877796173
# Layer linear_55 - Variance: 0.22180278599262238
# Layer tanh_55 - Variance: 0.1244766041636467
# Layer linear_56 - Variance: 0.22882695496082306
# Layer tanh_56 - Variance: 0.12814989686012268
# Layer linear_57 - Variance: 0.24719370901584625
# Layer tanh_57 - Variance: 0.13452006876468658
# Layer linear_58 - Variance: 0.24861964583396912
# Layer tanh_58 - Variance: 0.13340690732002258
# Layer linear_59 - Variance: 0.23516927659511566
# Layer tanh_59 - Variance: 0.1264536827802658
# Layer linear_60 - Variance: 0.22148028016090393
# Layer tanh_60 - Variance: 0.12024091184139252
# Layer linear_61 - Variance: 0.20557333528995514
# Layer tanh_61 - Variance: 0.11227380484342575
# Layer linear_62 - Variance: 0.21156659722328186
# Layer tanh_62 - Variance: 0.11932327598333359
# Layer linear_63 - Variance: 0.21999423205852509
# Layer tanh_63 - Variance: 0.12152711302042007
# Layer linear_64 - Variance: 0.21588116884231567
# Layer tanh_64 - Variance: 0.11970839649438858
# Layer linear_65 - Variance: 0.22204959392547607
# Layer tanh_65 - Variance: 0.12151320278644562
# Layer linear_66 - Variance: 0.2297508865594864
# Layer tanh_66 - Variance: 0.12727178633213043
# Layer linear_67 - Variance: 0.22935330867767334
# Layer tanh_67 - Variance: 0.12570375204086304
# Layer linear_68 - Variance: 0.22865687310695648
# Layer tanh_68 - Variance: 0.12443471699953079
# Layer linear_69 - Variance: 0.22305268049240112
# Layer tanh_69 - Variance: 0.11947709321975708
# Layer linear_70 - Variance: 0.21700718998908997
# Layer tanh_70 - Variance: 0.11696108430624008
# Layer linear_71 - Variance: 0.2174777090549469
# Layer tanh_71 - Variance: 0.1199045181274414
# Layer linear_72 - Variance: 0.2207762897014618
# Layer tanh_72 - Variance: 0.11940360069274902
# Layer linear_73 - Variance: 0.21839313209056854
# Layer tanh_73 - Variance: 0.11703263968229294
# Layer linear_74 - Variance: 0.20996566116809845
# Layer tanh_74 - Variance: 0.1131322979927063
# Layer linear_75 - Variance: 0.2097824662923813
# Layer tanh_75 - Variance: 0.11817721277475357
# Layer linear_76 - Variance: 0.22303763031959534
# Layer tanh_76 - Variance: 0.1194242388010025
# Layer linear_77 - Variance: 0.2189934402704239
# Layer tanh_77 - Variance: 0.11838403344154358
# Layer linear_78 - Variance: 0.2191862016916275
# Layer tanh_78 - Variance: 0.1215023323893547
# Layer linear_79 - Variance: 0.21889503300189972
# Layer tanh_79 - Variance: 0.12308433651924133
# Layer linear_80 - Variance: 0.2289024442434311
# Layer tanh_80 - Variance: 0.12731677293777466
# Layer linear_81 - Variance: 0.2331189215183258
# Layer tanh_81 - Variance: 0.12527906894683838
# Layer linear_82 - Variance: 0.23143760859966278
# Layer tanh_82 - Variance: 0.12334801256656647
# Layer linear_83 - Variance: 0.23456111550331116
# Layer tanh_83 - Variance: 0.12384738028049469
# Layer linear_84 - Variance: 0.2247876524925232
# Layer tanh_84 - Variance: 0.12280798703432083
# Layer linear_85 - Variance: 0.2328951507806778
# Layer tanh_85 - Variance: 0.12736846506595612
# Layer linear_86 - Variance: 0.22688084840774536
# Layer tanh_86 - Variance: 0.1250709593296051
# Layer linear_87 - Variance: 0.23763568699359894
# Layer tanh_87 - Variance: 0.126980721950531
# Layer linear_88 - Variance: 0.22166708111763
# Layer tanh_88 - Variance: 0.11920148134231567
# Layer linear_89 - Variance: 0.22596721351146698
# Layer tanh_89 - Variance: 0.12140429764986038
# Layer linear_90 - Variance: 0.22319748997688293
# Layer tanh_90 - Variance: 0.11847252398729324
# Layer linear_91 - Variance: 0.21506622433662415
# Layer tanh_91 - Variance: 0.11673145741224289
# Layer linear_92 - Variance: 0.22034841775894165
# Layer tanh_92 - Variance: 0.11616645008325577
# Layer linear_93 - Variance: 0.20711728930473328
# Layer tanh_93 - Variance: 0.11200326681137085
# Layer linear_94 - Variance: 0.20776811242103577
# Layer tanh_94 - Variance: 0.11029421538114548
# Layer linear_95 - Variance: 0.20833076536655426
# Layer tanh_95 - Variance: 0.1098613291978836
# Layer linear_96 - Variance: 0.2047228217124939
# Layer tanh_96 - Variance: 0.10573091357946396
# Layer linear_97 - Variance: 0.19689950346946716
# Layer tanh_97 - Variance: 0.10388872027397156
# Layer linear_98 - Variance: 0.20397251844406128
# Layer tanh_98 - Variance: 0.10590458661317825
# Layer linear_99 - Variance: 15.667739868164062
# Layer tanh_99 - Variance: 16.895601272583008

# %%
for idx, mod in enumerate(cut_models):
    # Same for all fine-tuned:
    mod['cut_model'].eval()
    linear_layers = []
    activation_layers = []
    for i, layer in enumerate(mod['cut_model'].modules()):
      if i % 2 == 1:
        linear_layers.append(layer)
      else:
        activation_layers.append(layer)
    activation_layers = activation_layers[1:]
    results, variances = compute_layer_variances(mod['cut_model'], fashion_dataset.test_loader, device = 'cuda')
    # for layer_name, variance in results.items():
    #    print(f"Layer {layer_name} - Variance: {variance}")

    # Create a list of layer names and variances
    layer_names = list(variances.keys())
    variance_values = [variance.mean().item() for variance in variances.values()]

    # Plot the variances
    plt.plot(layer_names[:-2], variance_values[:-2])
    plt.xticks(rotation=90)
    plt.xlabel('Layer Name')
    plt.ylabel('Variance')
    plt.title('Activation Variances Cut: {}'.format(idx*10))
    plt.show()

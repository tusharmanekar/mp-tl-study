# %% [markdown]
# ***EXPERIMENT SETUP***

# %% [markdown]
# - percentages_set_1 = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
# - dataset: same as before MNIST 5 to 5
#
# - lr pretraining = 0.001
# - lr finetuning = 0.0001
#
# - architecture:
#     - Conv 1 (5,5), channels=1
#     - Relu
#     - Conv 2 (5,5,), channels=1
#     - Relu
#     - Pooling: False
#     - dense( x, x) x=output shape of prev layer (128?)
#     - Relu
#     - dense(x, 5)
#     - softmax
#
#
# - Freezing: NO
#
# - Reinitializing CNN layers: No
# - Reinitializing CNN layers: Only last
# - Reinitializing softmax layers: Yes
#
# - If we don’t save the best model, ES=6
#
# - num train = 20

# %% [markdown]
# ***IMPORTS***

# %%
import numpy as np
import random
import copy
import matplotlib.pyplot as plt
import json
from tqdm.auto import tqdm

# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from torchvision import datasets, transforms

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from types import SimpleNamespace
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ***UTILS***

# %%
def eval(model, device, dataset_loader, debug=False, classification_report_flag=False, is_cnn=True, logger=print):

    """
    Evaluates the model on the given dataset loader.

    Parameters:
    - model: the PyTorch model to evaluate.
    - device: the device to which tensors should be moved before computation.
    - dataset_loader: DataLoader for evaluation.
    - debug: whether to print debug info like loss and accuracy.
    - classification_report_flag: whether to print a classification report.
    - is_cnn: a flag indicating if the model is a CNN. If it's not, the input data will be reshaped.
    - logger: logging function for printing messages.

    Returns:
    - Accuracy of the model on the provided dataset loader.

    Usage:
    - accuracy = eval(model, device, dataset_loader, debug=False, is_cnn=False, classification_report_flag=False)
    """

    model.eval()
    test_loss, correct = 0., 0.
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data, target in dataset_loader:
            if is_cnn:
              data = data.view(data.size(0), 1, 28, 28)
            else:
              data = data.reshape([data.shape[0], -1])
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(target.cpu().numpy())

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data

    if debug:
        logger('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(test_loss, correct, num_data, 100. * acc))

    if classification_report_flag:
        unique_labels = np.unique(all_labels).tolist()
        logger(classification_report(all_labels, all_preds, labels=unique_labels, target_names=[f'Class {i}' for i in unique_labels]))

    return acc

# %%
class Trainer:

    """
    A class for training and evaluating a model with early stopping and best model saving functionalities.

    Attributes:
    - model: PyTorch model to be trained and evaluated.
    - dataloader: Contains data loaders (train, validation, test) for training and evaluation.
    - params: Dictionary containing various hyperparameters and settings.
    - device: the device to which tensors should be moved before computation.
    - optimizer: The optimizer for training.
    - best_model_state: State dictionary of the best model.
    - max_val_acc: The highest validation accuracy encountered during training.
    - no_improve_epochs: Number of epochs without improvement in validation accuracy.
    - is_cnn: Flag indicating if the model is a CNN.
    - is_debug: Flag indicating if debug information should be printed.
    - classification_report_flag: Flag indicating if a classification report should be generated.

    Methods:
    - train_epoch(): Runs a single epoch of training.
    - evaluate(loader): Evaluates the model on a given data loader.
    - save_best_model(): Saves the current state of the model as the best model.
    - save_checkpoint(epoch, train_acc, val_acc): Saves the current state of the model and other information as a checkpoint.
    - early_stopping_check(val_acc): Checks the stopping criterion and performs actions based on it.
    - train(): Runs the training process for a number of epochs, with early stopping functionality.

    Usage:
    params = {
      'device': 'cuda',
      'lr': 0.001,
      'num_train': 10,
      'early_stop_patience': 3,
      'save_best': True,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': True
    }

    trainer = Trainer(model, dataloader, params)
    train_acc, test_acc, effective_epochs, checkpoints = trainer.train()
    """


    def __init__(self, model, dataloader, params):
        self.model = model
        self.dataloader = dataloader
        self.params = params

        self.device = torch.device(params['device'])
        self.optimizer = optim.Adam(model.parameters(), lr=params['lr'])

        # Initialize best_model_state with the current model state
        self.best_model_state = copy.deepcopy(self.model.state_dict())
        self.max_val_acc = 0.
        self.no_improve_epochs = 0

        self.is_cnn = params.get('is_cnn', False)
        self.is_debug = params.get('is_debug', False)
        self.classification_report_flag = params.get('classification_report_flag', False)
        self.logger = params.get('logger', print)
        
    def train_epoch(self):
      self.model.train()
      for batch_idx, (data, target) in enumerate(self.dataloader.train_loader):

          # Print the size of the current batch
          if self.is_cnn:
            data = data.view(data.size(0), 1, 28, 28)
          else:
            data = data.reshape([data.shape[0], -1])

          data, target = data.to(self.device), target.to(self.device)
          self.optimizer.zero_grad()
          output = self.model(data)
          loss = F.nll_loss(output, target)
          loss.backward()
          self.optimizer.step()

          if self.is_debug and batch_idx % 20 == 0:
              self.logger(f"Batch: {batch_idx}, Loss: {loss.item()}")

    def evaluate(self, loader):
        return eval(self.model, self.device, loader, self.is_debug, self.classification_report_flag, self.is_cnn)

    def save_best_model(self):
        torch.save(self.model.state_dict(), 'best_model.pth')

    def save_checkpoint(self, epoch, train_acc, val_acc):
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'train_acc': train_acc,
            'val_acc': val_acc
        }
        torch.save(checkpoint, f'checkpoint_epoch_{epoch}.pth')
        return checkpoint

    def early_stopping_check(self, val_acc):
        if val_acc > self.max_val_acc:
            self.max_val_acc = val_acc
            self.no_improve_epochs = 0
            # Deep copy the model's state
            self.best_model_state = copy.deepcopy(self.model.state_dict())
            if self.params.get('save_best', False):
                self.save_best_model()
        else:
            self.no_improve_epochs += 1
            if self.no_improve_epochs >= self.params['early_stop_patience']:
                self.logger("Early stopping invoked.")
                # Only load if best_model_state has been set
                if self.best_model_state is not None:
                    self.model.load_state_dict(self.best_model_state)
                return True
        return False

    def train(self):
        effective_epochs = 0
        checkpoints = []

        for epoch in range(self.params['num_train']):
            effective_epochs += 1
            self.train_epoch()

            train_acc = self.evaluate(self.dataloader.train_loader)
            val_acc = self.evaluate(self.dataloader.val_loader)
            self.logger(f'Epoch: {epoch} \tTraining Accuracy: {train_acc*100:.2f}%')
            self.logger(f'Validation Accuracy: {val_acc*100:.2f}%')

            if self.params.get('early_stop_patience', None):
                if self.early_stopping_check(val_acc):
                    self.model.load_state_dict(self.best_model_state)
                    break

            if self.params.get('save_checkpoints', False):
                checkpoint = self.save_checkpoint(epoch, train_acc, val_acc)
                checkpoints.append(checkpoint)

        # Final evaluations
        train_acc = self.evaluate(self.dataloader.train_loader)
        test_acc = self.evaluate(self.dataloader.test_loader)

        return train_acc, test_acc, effective_epochs, checkpoints

# %%
def reduce_dataset(dataloader, percentage, balanced=True, seed=42):

    """
    Reduces the dataset to the given percentage. Can ensure class balance if needed.

    Parameters:
    - dataloader: PyTorch DataLoader object.
    - percentage: Desired percentage of the original dataset.
    - balanced: If True, ensures class balance. If False, reduces randomly.
    - seed: Seed for reproducibility.

    Returns:
    - reduced_dataloader: DataLoader with the reduced dataset.
    """
    # Extract the dataset from the dataloader
    dataset = dataloader.dataset

    # Extract all data and labels from the dataset
    X = [dataset[i][0] for i in range(len(dataset))]
    y = [dataset[i][1] for i in range(len(dataset))]

    # Set the seed for reproducibility
    torch.manual_seed(seed)

    if not balanced:
        # Determine the number of samples to keep
        num_samples = int(len(dataset) * percentage)

        # Randomly select indices without replacement
        indices = torch.randperm(len(dataset))[:num_samples].tolist()

    else:
        # Get unique classes and their counts
        classes, class_counts = torch.unique(torch.tensor(y), return_counts=True)

        # Determine the number of samples per class to keep
        num_samples_per_class = int(len(dataset) * percentage / len(classes))
        indices = []

        for class_label in classes:
            class_indices = [i for i, label in enumerate(y) if label == class_label]

            # Randomly select indices without replacement for each class
            class_selected_indices = torch.randperm(len(class_indices))[:num_samples_per_class].tolist()
            indices.extend([class_indices[i] for i in class_selected_indices])

    # Use a Subset of the original dataset to create a reduced dataset
    reduced_dataset = data.Subset(dataset, indices)

    # Create a DataLoader with the reduced dataset.
    reduced_dataloader = data.DataLoader(reduced_dataset, batch_size=dataloader.batch_size, shuffle=True)

    return reduced_dataloader

# %%
class RelabeledSubset(torch.utils.data.Dataset):
    def __init__(self, dataset, offset):
        self.dataset = dataset
        self.offset = offset

    def __getitem__(self, idx):
        data, label = self.dataset[idx]
        # Offset the label to start from 0
        label = label - self.offset
        return data, label

    def __len__(self):
        return len(self.dataset)

# %%
class TransferLearningMNIST(object):
    def __init__(self, batch_size, input_dim=28*28, val_split=0.1, num_workers=4):
        self.input_dim = input_dim
        self.output_dim = 10
        self.val_split = val_split

        def filter_dataset(dataset, classes):
            indices = [i for i, t in enumerate(dataset.targets) if t in classes]
            return torch.utils.data.Subset(dataset, indices)

        mnist_train_data = datasets.MNIST(
            '../data',
            train=True,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_train_data = filter_dataset(mnist_train_data, list(range(5)))
        finetune_train_data = filter_dataset(mnist_train_data, list(range(5, 10)))

        pretrain_len = len(pretrain_train_data)
        finetune_len = len(finetune_train_data)
        pretrain_val_len = int(val_split * pretrain_len)
        finetune_val_len = int(val_split * finetune_len)
        SEED = 42
        pretrain_train_set, pretrain_val_set = torch.utils.data.random_split(
            pretrain_train_data, [pretrain_len - pretrain_val_len, pretrain_val_len], generator=torch.Generator().manual_seed(SEED))
        finetune_train_set, finetune_val_set = torch.utils.data.random_split(
            finetune_train_data, [finetune_len - finetune_val_len, finetune_val_len], generator=torch.Generator().manual_seed(SEED))

        self.pretrain_train_loader = torch.utils.data.DataLoader(pretrain_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.pretrain_val_loader = torch.utils.data.DataLoader(pretrain_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning datasets
        finetune_train_set = RelabeledSubset(finetune_train_set, 5)
        finetune_val_set = RelabeledSubset(finetune_val_set, 5)

        self.finetune_train_loader = torch.utils.data.DataLoader(finetune_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.finetune_val_loader = torch.utils.data.DataLoader(finetune_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        mnist_test_data = datasets.MNIST(
            '../data',
            train=False,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_test_data = filter_dataset(mnist_test_data, list(range(5)))
        finetune_test_data = filter_dataset(mnist_test_data, list(range(5, 10)))

        self.pretrain_test_loader = torch.utils.data.DataLoader(pretrain_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning test datasets
        finetune_test_data = RelabeledSubset(finetune_test_data, 5)
        self.finetune_test_loader = torch.utils.data.DataLoader(finetune_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        # Complete test loader contains all test examples.
        self.complete_test_loader = torch.utils.data.DataLoader(mnist_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
class TransferLearningMNISTWrapper:
    """
    This wrapper class provides a convenient way to switch between pretraining and fine-tuning phases.

    It allows for changing the phase and accordingly updating the data loaders (train, val, test)
    to either pretraining or fine-tuning sets.
    """
    def __init__(self, transferLearningMNISTObj, phase):
        """
        Initializes the TransferLearningMNISTWrapper object.

        Parameters:
        - transferLearningMNISTObj: An instance of the TransferLearningMNIST class.
        - phase: String indicating the current phase ("pretrain" or "finetune").
        """
        self.transferLearningMNISTObj = transferLearningMNISTObj
        self.phase = phase
        self.input_dim = self.transferLearningMNISTObj.input_dim
        self.output_dim = self.transferLearningMNISTObj.output_dim
        self.update_phase(phase)

    def update_phase(self, phase):
        """
        Updates the phase and the corresponding data loaders.

        Parameters:
        - phase: String indicating the desired phase ("pretrain" or "finetune").

        Throws:
        - ValueError: If the phase is neither "pretrain" nor "finetune".
        """
        self.phase = phase
        if phase == 'pretrain':
            self.train_loader = self.transferLearningMNISTObj.pretrain_train_loader
            self.val_loader = self.transferLearningMNISTObj.pretrain_val_loader
            self.test_loader = self.transferLearningMNISTObj.pretrain_test_loader
        elif phase == 'finetune':
            self.train_loader = self.transferLearningMNISTObj.finetune_train_loader
            self.val_loader = self.transferLearningMNISTObj.finetune_val_loader
            self.test_loader = self.transferLearningMNISTObj.finetune_test_loader
        else:
            raise ValueError('Phase must be either "pretrain" or "finetune".')

    def get_current_phase(self):
      return self.phase

# %%
class CustomCNN(nn.Module):
    def __init__(self, input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling=True):
        super(CustomCNN, self).__init__()

        # Initial number of input channels, assuming grayscale images
        in_channels = 1

        # Dynamically add convolutional and activation layers based on the specified depth
        for i in range(depth):
            # Create a convolutional layer and add it to the model
            setattr(self, f"conv{i}", nn.Conv2d(in_channels, num_channels, kernel_size=kernel_size, padding=1))

            # Create an activation layer (e.g., ReLU) and add it to the model
            setattr(self, f"act{i}", activation_function())

            # Update the input dimensions after convolution
            input_dim = (input_dim - kernel_size + 2 * 1) + 1

            # Optionally add pooling layers to reduce spatial dimensions
            if use_pooling and i % 2 == 1:
                setattr(self, f"pool{i}", nn.MaxPool2d(2))
                input_dim = input_dim // 2

            # Update the input channels for the next convolutional layer
            in_channels = num_channels

        # Compute the size of the flattened features for the fully connected layer
        flattened_size = in_channels * input_dim * input_dim

        # Add two fully connected layers for classification
        self.fc_1 = nn.Linear(flattened_size, hidden_dim_lin)
        self.fc_2 = nn.Linear(hidden_dim_lin, output_dim)

        # Add log softmax layer for multi-class classification output
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
      # Iterate over each module in the CustomCNN class
      for layer_name, layer in self.named_children():
          # Process the input tensor through convolutional and activation layers
          if "conv" in layer_name or "act" in layer_name:
              x = layer(x)
          # Process the input tensor through pooling layers if they exist
          elif "pool" in layer_name:
              x = layer(x)
          # If reached fully connected layers, break the loop
          elif isinstance(layer, nn.Linear):
              break

      # Flatten the tensor to fit the input shape of the fully connected layers
      x = x.view(x.size(0), -1)
        
      # Save the flattened size for reinitializing layers later
      self.flattened_size = x.shape[1]

      # Pass the tensor through the fully connected layers
      x = self.fc_1(x)
      x = self.fc_2(x)

      # Return log softmax activated output
      return self.logsoftmax(x)

# %%
def generate_cnn(input_dim, output_dim, depth, num_channels, hidden_dim_lin, kernel_size, activation_function=nn.ReLU, use_pooling=True):
    model = CustomCNN(input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling)
    return model

# %% [markdown]
# ***PRE-TRAINING***

# %%
batch_size = 128

dataloader = TransferLearningMNIST(batch_size)
dataloader_wrapped = TransferLearningMNISTWrapper(dataloader, phase = 'pretrain')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 146925696.43it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 46323401.08it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 36249850.07it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 7381065.00it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw

# %%
a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        break

# %%
params = {
      'depth': 2,
      'width': 1,
      'hidden_dim_lin': 128,
      'activation_function': nn.ReLU,
      'kernel_size': 5,
      'device': device,
      'lr': 0.001,
      'num_train': 20,
      'early_stop_patience': 6,
      'save_best': True,
      'save_checkpoints': True,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': False
    }

# Create DNN model
model = generate_cnn(input_dim = 28, output_dim = 10, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
model
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
# Train and evaluate
trainer = Trainer(model, dataloader_wrapped, params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Batch: 0, Loss: 2.252068042755127
# Batch: 20, Loss: 1.5382814407348633
# Batch: 40, Loss: 1.1264406442642212
# Batch: 60, Loss: 0.663777768611908
# Batch: 80, Loss: 0.46668240427970886
# Batch: 100, Loss: 0.31548014283180237
# Batch: 120, Loss: 0.2728981673717499
# Batch: 140, Loss: 0.22731254994869232
# Batch: 160, Loss: 0.2661399841308594
# Batch: 180, Loss: 0.19541701674461365
# Batch: 200, Loss: 0.177613765001297
#
# Average loss: 0.1694, Accuracy: 26102.0/27537 (95%)
#
#
# Average loss: 0.1940, Accuracy: 2883.0/3059 (94%)
#
# Epoch: 0 	Training Accuracy: 94.79%
# Validation Accuracy: 94.25%
# Batch: 0, Loss: 0.2083708494901657
# Batch: 20, Loss: 0.13925418257713318
# Batch: 40, Loss: 0.11019642651081085
# Batch: 60, Loss: 0.11581018567085266
# Batch: 80, Loss: 0.12861022353172302
# Batch: 100, Loss: 0.15408572554588318
# Batch: 120, Loss: 0.14619159698486328
# Batch: 140, Loss: 0.10776446759700775
# Batch: 160, Loss: 0.13944819569587708
# Batch: 180, Loss: 0.07220103591680527
# Batch: 200, Loss: 0.176319420337677
#
# Average loss: 0.1266, Accuracy: 26522.0/27537 (96%)
#
#
# Average loss: 0.1547, Accuracy: 2921.0/3059 (95%)
#
# Epoch: 1 	Training Accuracy: 96.31%
# Validation Accuracy: 95.49%
# Batch: 0, Loss: 0.17478470504283905
# Batch: 20, Loss: 0.11627426743507385
# Batch: 40, Loss: 0.13514170050621033
# Batch: 60, Loss: 0.2014850229024887
# Batch: 80, Loss: 0.14797602593898773
# Batch: 100, Loss: 0.11074851453304291
# Batch: 120, Loss: 0.11348969489336014
# Batch: 140, Loss: 0.19567906856536865
# Batch: 160, Loss: 0.09842033684253693
# Batch: 180, Loss: 0.10231628268957138
# Batch: 200, Loss: 0.24882610142230988
#
# Average loss: 0.1170, Accuracy: 26578.0/27537 (97%)
#
#
# Average loss: 0.1422, Accuracy: 2933.0/3059 (96%)
#
# Epoch: 2 	Training Accuracy: 96.52%
# Validation Accuracy: 95.88%
# Batch: 0, Loss: 0.13942737877368927
# Batch: 20, Loss: 0.1615048050880432
# Batch: 40, Loss: 0.11347535997629166
# Batch: 60, Loss: 0.10092955082654953
# Batch: 80, Loss: 0.14401952922344208
# Batch: 100, Loss: 0.3735804557800293
# Batch: 120, Loss: 0.10088881850242615
# Batch: 140, Loss: 0.138961523771286
# Batch: 160, Loss: 0.13352744281291962
# Batch: 180, Loss: 0.10849753767251968
# Batch: 200, Loss: 0.0632154792547226
#
# Average loss: 0.1096, Accuracy: 26654.0/27537 (97%)
#
#
# Average loss: 0.1322, Accuracy: 2938.0/3059 (96%)
#
# Epoch: 3 	Training Accuracy: 96.79%
# Validation Accuracy: 96.04%
# Batch: 0, Loss: 0.14035466313362122
# Batch: 20, Loss: 0.046767354011535645
# Batch: 40, Loss: 0.06337730586528778
# Batch: 60, Loss: 0.19033479690551758
# Batch: 80, Loss: 0.1554260551929474
# Batch: 100, Loss: 0.08693777024745941
# Batch: 120, Loss: 0.07825008034706116
# Batch: 140, Loss: 0.0824410691857338
# Batch: 160, Loss: 0.12162451446056366
# Batch: 180, Loss: 0.07181822508573532
# Batch: 200, Loss: 0.09157181531190872
#
# Average loss: 0.1073, Accuracy: 26645.0/27537 (97%)
#
#
# Average loss: 0.1290, Accuracy: 2935.0/3059 (96%)
#
# Epoch: 4 	Training Accuracy: 96.76%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.04984351247549057
# Batch: 20, Loss: 0.09852927178144455
# Batch: 40, Loss: 0.06258311122655869
# Batch: 60, Loss: 0.09458814561367035
# Batch: 80, Loss: 0.0427732840180397
# Batch: 100, Loss: 0.1728028655052185
# Batch: 120, Loss: 0.057123612612485886
# Batch: 140, Loss: 0.06913018971681595
# Batch: 160, Loss: 0.09153033047914505
# Batch: 180, Loss: 0.09854686260223389
# Batch: 200, Loss: 0.07431194931268692
#
# Average loss: 0.1094, Accuracy: 26599.0/27537 (97%)
#
#
# Average loss: 0.1316, Accuracy: 2936.0/3059 (96%)
#
# Epoch: 5 	Training Accuracy: 96.59%
# Validation Accuracy: 95.98%
# Batch: 0, Loss: 0.0690416470170021
# Batch: 20, Loss: 0.12133567780256271
# Batch: 40, Loss: 0.11523985862731934
# Batch: 60, Loss: 0.1296260505914688
# Batch: 80, Loss: 0.12655118107795715
# Batch: 100, Loss: 0.10829214006662369
# Batch: 120, Loss: 0.12056553363800049
# Batch: 140, Loss: 0.057709187269210815
# Batch: 160, Loss: 0.10354691743850708
# Batch: 180, Loss: 0.20733219385147095
# Batch: 200, Loss: 0.08562657982110977
#
# Average loss: 0.1055, Accuracy: 26664.0/27537 (97%)
#
#
# Average loss: 0.1278, Accuracy: 2943.0/3059 (96%)
#
# Epoch: 6 	Training Accuracy: 96.83%
# Validation Accuracy: 96.21%
# Batch: 0, Loss: 0.03324184566736221
# Batch: 20, Loss: 0.10983530431985855
# Batch: 40, Loss: 0.11677522212266922
# Batch: 60, Loss: 0.06727101653814316
# Batch: 80, Loss: 0.06689659506082535
# Batch: 100, Loss: 0.05160849541425705
# Batch: 120, Loss: 0.12442120909690857
# Batch: 140, Loss: 0.10627985000610352
# Batch: 160, Loss: 0.04138914868235588
# Batch: 180, Loss: 0.065098837018013
# Batch: 200, Loss: 0.055697228759527206
#
# Average loss: 0.1018, Accuracy: 26703.0/27537 (97%)
#
#
# Average loss: 0.1231, Accuracy: 2950.0/3059 (96%)
#
# Epoch: 7 	Training Accuracy: 96.97%
# Validation Accuracy: 96.44%
# Batch: 0, Loss: 0.12848295271396637
# Batch: 20, Loss: 0.1120145246386528
# Batch: 40, Loss: 0.08327622711658478
# Batch: 60, Loss: 0.06751253455877304
# Batch: 80, Loss: 0.12981776893138885
# Batch: 100, Loss: 0.03229231387376785
# Batch: 120, Loss: 0.050107136368751526
# Batch: 140, Loss: 0.09470750391483307
# Batch: 160, Loss: 0.07355557382106781
# Batch: 180, Loss: 0.10206057876348495
# Batch: 200, Loss: 0.08464892208576202
#
# Average loss: 0.1012, Accuracy: 26735.0/27537 (97%)
#
#
# Average loss: 0.1249, Accuracy: 2950.0/3059 (96%)
#
# Epoch: 8 	Training Accuracy: 97.09%
# Validation Accuracy: 96.44%
# Batch: 0, Loss: 0.03589542955160141
# Batch: 20, Loss: 0.08120311051607132
# Batch: 40, Loss: 0.07330632209777832
# Batch: 60, Loss: 0.13723543286323547
# Batch: 80, Loss: 0.09258612990379333
# Batch: 100, Loss: 0.11355920881032944
# Batch: 120, Loss: 0.09277024865150452
# Batch: 140, Loss: 0.06977446377277374
# Batch: 160, Loss: 0.13986235857009888
# Batch: 180, Loss: 0.07067468017339706
# Batch: 200, Loss: 0.06770896166563034
#
# Average loss: 0.0972, Accuracy: 26729.0/27537 (97%)
#
#
# Average loss: 0.1201, Accuracy: 2943.0/3059 (96%)
#
# Epoch: 9 	Training Accuracy: 97.07%
# Validation Accuracy: 96.21%
# Batch: 0, Loss: 0.09362617880105972
# Batch: 20, Loss: 0.0531032532453537
# Batch: 40, Loss: 0.04826362058520317
# Batch: 60, Loss: 0.03210887685418129
# Batch: 80, Loss: 0.08384325355291367
# Batch: 100, Loss: 0.0871971994638443
# Batch: 120, Loss: 0.08710440248250961
# Batch: 140, Loss: 0.09709866344928741
# Batch: 160, Loss: 0.06335318088531494
# Batch: 180, Loss: 0.10493167489767075
# Batch: 200, Loss: 0.13300365209579468
#
# Average loss: 0.0964, Accuracy: 26762.0/27537 (97%)
#
#
# Average loss: 0.1190, Accuracy: 2947.0/3059 (96%)
#
# Epoch: 10 	Training Accuracy: 97.19%
# Validation Accuracy: 96.34%
# Batch: 0, Loss: 0.08704540133476257
# Batch: 20, Loss: 0.07316336035728455
# Batch: 40, Loss: 0.07063259184360504
# Batch: 60, Loss: 0.08871889859437943
# Batch: 80, Loss: 0.03106580674648285
# Batch: 100, Loss: 0.12686675786972046
# Batch: 120, Loss: 0.1014825701713562
# Batch: 140, Loss: 0.05781719088554382
# Batch: 160, Loss: 0.16497747600078583
# Batch: 180, Loss: 0.09708314388990402
# Batch: 200, Loss: 0.11772878468036652
#
# Average loss: 0.0965, Accuracy: 26726.0/27537 (97%)
#
#
# Average loss: 0.1183, Accuracy: 2943.0/3059 (96%)
#
# Epoch: 11 	Training Accuracy: 97.05%
# Validation Accuracy: 96.21%
# Batch: 0, Loss: 0.14694704115390778
# Batch: 20, Loss: 0.04838750883936882
# Batch: 40, Loss: 0.07234496623277664
# Batch: 60, Loss: 0.16421112418174744
# Batch: 80, Loss: 0.06902658194303513
# Batch: 100, Loss: 0.09113648533821106
# Batch: 120, Loss: 0.05951421707868576
# Batch: 140, Loss: 0.09224814176559448
# Batch: 160, Loss: 0.18391479551792145
# Batch: 180, Loss: 0.03638353571295738
# Batch: 200, Loss: 0.07690343260765076
#
# Average loss: 0.0927, Accuracy: 26806.0/27537 (97%)
#
#
# Average loss: 0.1142, Accuracy: 2951.0/3059 (96%)
#
# Epoch: 12 	Training Accuracy: 97.35%
# Validation Accuracy: 96.47%
# Batch: 0, Loss: 0.06654193997383118
# Batch: 20, Loss: 0.05586825683712959
# Batch: 40, Loss: 0.07630537450313568
# Batch: 60, Loss: 0.21812640130519867
# Batch: 80, Loss: 0.09180442988872528
# Batch: 100, Loss: 0.1220005452632904
# Batch: 120, Loss: 0.09541711956262589
# Batch: 140, Loss: 0.12356871366500854
# Batch: 160, Loss: 0.1358349770307541
# Batch: 180, Loss: 0.08139806985855103
# Batch: 200, Loss: 0.05138152092695236
#
# Average loss: 0.0941, Accuracy: 26756.0/27537 (97%)
#
#
# Average loss: 0.1156, Accuracy: 2944.0/3059 (96%)
#
# Epoch: 13 	Training Accuracy: 97.16%
# Validation Accuracy: 96.24%
# Batch: 0, Loss: 0.08960019052028656
# Batch: 20, Loss: 0.04241049289703369
# Batch: 40, Loss: 0.15319174528121948
# Batch: 60, Loss: 0.10138513892889023
# Batch: 80, Loss: 0.0997757613658905
# Batch: 100, Loss: 0.04695596173405647
# Batch: 120, Loss: 0.1889752596616745
# Batch: 140, Loss: 0.06833384186029434
# Batch: 160, Loss: 0.08862698078155518
# Batch: 180, Loss: 0.06088794022798538
# Batch: 200, Loss: 0.09251895546913147
#
# Average loss: 0.0948, Accuracy: 26714.0/27537 (97%)
#
#
# Average loss: 0.1177, Accuracy: 2944.0/3059 (96%)
#
# Epoch: 14 	Training Accuracy: 97.01%
# Validation Accuracy: 96.24%
# Batch: 0, Loss: 0.10287581384181976
# Batch: 20, Loss: 0.13089120388031006
# Batch: 40, Loss: 0.14106003940105438
# Batch: 60, Loss: 0.07261419296264648
# Batch: 80, Loss: 0.07856858521699905
# Batch: 100, Loss: 0.07486379146575928
# Batch: 120, Loss: 0.06955306977033615
# Batch: 140, Loss: 0.10794426500797272
# Batch: 160, Loss: 0.12126313894987106
# Batch: 180, Loss: 0.13864022493362427
# Batch: 200, Loss: 0.059743352234363556
#
# Average loss: 0.0899, Accuracy: 26807.0/27537 (97%)
#
#
# Average loss: 0.1100, Accuracy: 2954.0/3059 (97%)
#
# Epoch: 15 	Training Accuracy: 97.35%
# Validation Accuracy: 96.57%
# Batch: 0, Loss: 0.0800536498427391
# Batch: 20, Loss: 0.09581723809242249
# Batch: 40, Loss: 0.09232142567634583
# Batch: 60, Loss: 0.05087510123848915
# Batch: 80, Loss: 0.08292663097381592
# Batch: 100, Loss: 0.10103948414325714
# Batch: 120, Loss: 0.14273391664028168
# Batch: 140, Loss: 0.15325462818145752
# Batch: 160, Loss: 0.08011825382709503
# Batch: 180, Loss: 0.07404766231775284
# Batch: 200, Loss: 0.06816457211971283
#
# Average loss: 0.0899, Accuracy: 26819.0/27537 (97%)
#
#
# Average loss: 0.1136, Accuracy: 2955.0/3059 (97%)
#
# Epoch: 16 	Training Accuracy: 97.39%
# Validation Accuracy: 96.60%
# Batch: 0, Loss: 0.025317706167697906
# Batch: 20, Loss: 0.09555011987686157
# Batch: 40, Loss: 0.02942950837314129
# Batch: 60, Loss: 0.036505185067653656
# Batch: 80, Loss: 0.15366172790527344
# Batch: 100, Loss: 0.04797738045454025
# Batch: 120, Loss: 0.09241983294487
# Batch: 140, Loss: 0.20252163708209991
# Batch: 160, Loss: 0.05756163224577904
# Batch: 180, Loss: 0.11537323892116547
# Batch: 200, Loss: 0.03205268830060959
#
# Average loss: 0.0961, Accuracy: 26775.0/27537 (97%)
#
#
# Average loss: 0.1170, Accuracy: 2964.0/3059 (97%)
#
# Epoch: 17 	Training Accuracy: 97.23%
# Validation Accuracy: 96.89%
# Batch: 0, Loss: 0.07393345236778259
# Batch: 20, Loss: 0.04662803187966347
# Batch: 40, Loss: 0.08055146038532257
# Batch: 60, Loss: 0.19665394723415375
# Batch: 80, Loss: 0.14119544625282288
# Batch: 100, Loss: 0.08386465162038803
# Batch: 120, Loss: 0.054877735674381256
# Batch: 140, Loss: 0.023033352568745613
# Batch: 160, Loss: 0.07232287526130676
# Batch: 180, Loss: 0.06601821631193161
# Batch: 200, Loss: 0.11756573617458344
#
# Average loss: 0.0869, Accuracy: 26835.0/27537 (97%)
#
#
# Average loss: 0.1133, Accuracy: 2961.0/3059 (97%)
#
# Epoch: 18 	Training Accuracy: 97.45%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.04197335243225098
# Batch: 20, Loss: 0.07308311015367508
# Batch: 40, Loss: 0.096781425178051
# Batch: 60, Loss: 0.04597463458776474
# Batch: 80, Loss: 0.045486003160476685
# Batch: 100, Loss: 0.0474083386361599
# Batch: 120, Loss: 0.08507683873176575
# Batch: 140, Loss: 0.1172526404261589
# Batch: 160, Loss: 0.10560335963964462
# Batch: 180, Loss: 0.07185586541891098
# Batch: 200, Loss: 0.0748838484287262
#
# Average loss: 0.0881, Accuracy: 26797.0/27537 (97%)
#
#
# Average loss: 0.1137, Accuracy: 2954.0/3059 (97%)
#
# Epoch: 19 	Training Accuracy: 97.31%
# Validation Accuracy: 96.57%
#
# Average loss: 0.0881, Accuracy: 26797.0/27537 (97%)
#
#
# Average loss: 0.0801, Accuracy: 5010.0/5139 (97%)
#
# Final Training Accuracy: 0.9731
# Final Test Accuracy: 0.9749

# %%
accuracy = eval(model, device, dataloader_wrapped.test_loader, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
# Out:
# Average loss: 0.0801, Accuracy: 5010.0/5139 (97%)

# %%
def effective_rank(singular_values):
    normalized_singular_values = singular_values / np.sum(singular_values)
    entropy = -np.sum(normalized_singular_values * np.log(normalized_singular_values))
    eff_rank = np.exp(entropy)
    return eff_rank

def plot_layer_effective_ranks(model, print_ranks=True):
    effective_ranks = []
    layer_names = []

    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            singular_values = np.linalg.svd(weight_matrix, compute_uv=False)
            eff_rank = effective_rank(singular_values)
            effective_ranks.append(eff_rank)
            layer_names.append(name)

    if print_ranks:
        for layer_name, eff_rank in zip(layer_names, effective_ranks):
            print(f'{layer_name}: {eff_rank:.4f}')

    # Plotting
    plt.figure(figsize=(15, 5))
    plt.bar(layer_names, effective_ranks, color='green')
    plt.xlabel('Layer')
    plt.ylabel('Effective Rank')
    plt.title('Effective Rank of Weight Matrices for Each Layer')
    plt.grid(True)

    y_max = np.max(effective_ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(effective_ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(0, int(y_max)+2, step=2))  # Set yticks

    plt.show()

# Example usage
plot_layer_effective_ranks(model)  # Note: You'll need to define or load 'model' before calling this function
# Out:
# conv0.weight: 3.9730
# conv1.weight: 4.1044
# fc_1.weight: 80.4868
# fc_2.weight: 8.5678

# %% [markdown]
# ----

# %% [markdown]
# # Finetuning experiments

# %%
dataloader_wrapped.update_phase('finetune')

a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        print('-------------')
        break
# Out:
# -------------

# %% [markdown]
# ## Baseline model: end2end with the same architecture as the preatining model

# %%
# 2. Create a new model and copy weights from the original model, then adjust the final layer
print("Current dataloader phase: ", dataloader_wrapped.get_current_phase())

model_finetuning_baseline = generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
model_finetuning_baseline.to(device)

# dataloader_wrapped.update_phase('finetune')
# Train and evaluate the new model on the new data
# train_acc_new, test_acc_new, model_finetuning_baseline, _,_ = compute_training_acc_epochs_cnn(model_finetuning_baseline, dataloader_wrapped, params, debug=True)

trainer = Trainer(model, dataloader_wrapped, params)
train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
print(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")
# Out:
# Current dataloader phase:  finetune
# Batch: 0, Loss: 5.619503498077393
# Batch: 20, Loss: 1.9578052759170532
# Batch: 40, Loss: 1.0553290843963623
# Batch: 60, Loss: 0.8612099289894104
# Batch: 80, Loss: 0.6780183911323547
# Batch: 100, Loss: 0.6043002605438232
# Batch: 120, Loss: 0.4688805639743805
# Batch: 140, Loss: 0.46040108799934387
# Batch: 160, Loss: 0.39083027839660645
# Batch: 180, Loss: 0.38763487339019775
# Batch: 200, Loss: 0.42238378524780273
#
# Average loss: 0.3120, Accuracy: 23805.0/26464 (90%)
#
#
# Average loss: 0.3431, Accuracy: 2630.0/2940 (89%)
#
# Epoch: 0 	Training Accuracy: 89.95%
# Validation Accuracy: 89.46%
# Batch: 0, Loss: 0.32947269082069397
# Batch: 20, Loss: 0.283253937959671
# Batch: 40, Loss: 0.3625904321670532
# Batch: 60, Loss: 0.3279014527797699
# Batch: 80, Loss: 0.26623544096946716
# Batch: 100, Loss: 0.31295129656791687
# Batch: 120, Loss: 0.3303050994873047
# Batch: 140, Loss: 0.28956785798072815
# Batch: 160, Loss: 0.30200475454330444
# Batch: 180, Loss: 0.3752863109111786
# Batch: 200, Loss: 0.1670600026845932
#
# Average loss: 0.2195, Accuracy: 24650.0/26464 (93%)
#
#
# Average loss: 0.2424, Accuracy: 2717.0/2940 (92%)
#
# Epoch: 1 	Training Accuracy: 93.15%
# Validation Accuracy: 92.41%
# Batch: 0, Loss: 0.19575470685958862
# Batch: 20, Loss: 0.18978506326675415
# Batch: 40, Loss: 0.2591736316680908
# Batch: 60, Loss: 0.16711129248142242
# Batch: 80, Loss: 0.1782090812921524
# Batch: 100, Loss: 0.16214025020599365
# Batch: 120, Loss: 0.15489158034324646
# Batch: 140, Loss: 0.2591099441051483
# Batch: 160, Loss: 0.19028066098690033
# Batch: 180, Loss: 0.18878449499607086
# Batch: 200, Loss: 0.1519884318113327
#
# Average loss: 0.1847, Accuracy: 24901.0/26464 (94%)
#
#
# Average loss: 0.2093, Accuracy: 2745.0/2940 (93%)
#
# Epoch: 2 	Training Accuracy: 94.09%
# Validation Accuracy: 93.37%
# Batch: 0, Loss: 0.22985664010047913
# Batch: 20, Loss: 0.12948796153068542
# Batch: 40, Loss: 0.1561591476202011
# Batch: 60, Loss: 0.20356038212776184
# Batch: 80, Loss: 0.11137064546346664
# Batch: 100, Loss: 0.14242210984230042
# Batch: 120, Loss: 0.14771349728107452
# Batch: 140, Loss: 0.1331290453672409
# Batch: 160, Loss: 0.10985127091407776
# Batch: 180, Loss: 0.10334409028291702
# Batch: 200, Loss: 0.25683286786079407
#
# Average loss: 0.1731, Accuracy: 25013.0/26464 (95%)
#
#
# Average loss: 0.1959, Accuracy: 2760.0/2940 (94%)
#
# Epoch: 3 	Training Accuracy: 94.52%
# Validation Accuracy: 93.88%
# Batch: 0, Loss: 0.2959228754043579
# Batch: 20, Loss: 0.209359809756279
# Batch: 40, Loss: 0.11938653886318207
# Batch: 60, Loss: 0.19349974393844604
# Batch: 80, Loss: 0.1442512720823288
# Batch: 100, Loss: 0.1878957599401474
# Batch: 120, Loss: 0.11859937757253647
# Batch: 140, Loss: 0.1917470246553421
# Batch: 160, Loss: 0.16780707240104675
# Batch: 180, Loss: 0.2585849165916443
# Batch: 200, Loss: 0.171698197722435
#
# Average loss: 0.1601, Accuracy: 25102.0/26464 (95%)
#
#
# Average loss: 0.1835, Accuracy: 2782.0/2940 (95%)
#
# Epoch: 4 	Training Accuracy: 94.85%
# Validation Accuracy: 94.63%
# Batch: 0, Loss: 0.05703315883874893
# Batch: 20, Loss: 0.13169948756694794
# Batch: 40, Loss: 0.1348906010389328
# Batch: 60, Loss: 0.1247907429933548
# Batch: 80, Loss: 0.12615491449832916
# Batch: 100, Loss: 0.11180039495229721
# Batch: 120, Loss: 0.1440075933933258
# Batch: 140, Loss: 0.08387874066829681
# Batch: 160, Loss: 0.1163659393787384
# Batch: 180, Loss: 0.18313749134540558
# Batch: 200, Loss: 0.07527303695678711
#
# Average loss: 0.1514, Accuracy: 25197.0/26464 (95%)
#
#
# Average loss: 0.1734, Accuracy: 2783.0/2940 (95%)
#
# Epoch: 5 	Training Accuracy: 95.21%
# Validation Accuracy: 94.66%
# Batch: 0, Loss: 0.17160214483737946
# Batch: 20, Loss: 0.11605960875749588
# Batch: 40, Loss: 0.2195570170879364
# Batch: 60, Loss: 0.1789567768573761
# Batch: 80, Loss: 0.1231890469789505
# Batch: 100, Loss: 0.17555372416973114
# Batch: 120, Loss: 0.10454672574996948
# Batch: 140, Loss: 0.11050150543451309
# Batch: 160, Loss: 0.19252890348434448
# Batch: 180, Loss: 0.08383210003376007
# Batch: 200, Loss: 0.15289539098739624
#
# Average loss: 0.1472, Accuracy: 25213.0/26464 (95%)
#
#
# Average loss: 0.1741, Accuracy: 2785.0/2940 (95%)
#
# Epoch: 6 	Training Accuracy: 95.27%
# Validation Accuracy: 94.73%
# Batch: 0, Loss: 0.09666242450475693
# Batch: 20, Loss: 0.07556697726249695
# Batch: 40, Loss: 0.2666180729866028
# Batch: 60, Loss: 0.1862274706363678
# Batch: 80, Loss: 0.11763659119606018
# Batch: 100, Loss: 0.14247070252895355
# Batch: 120, Loss: 0.05142172425985336
# Batch: 140, Loss: 0.20939061045646667
# Batch: 160, Loss: 0.23895716667175293
# Batch: 180, Loss: 0.09498091042041779
# Batch: 200, Loss: 0.12179271131753922
#
# Average loss: 0.1526, Accuracy: 25216.0/26464 (95%)
#
#
# Average loss: 0.1792, Accuracy: 2792.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 95.28%
# Validation Accuracy: 94.97%
# Batch: 0, Loss: 0.1670774221420288
# Batch: 20, Loss: 0.11047956347465515
# Batch: 40, Loss: 0.1857987940311432
# Batch: 60, Loss: 0.16903404891490936
# Batch: 80, Loss: 0.08777028322219849
# Batch: 100, Loss: 0.12116122990846634
# Batch: 120, Loss: 0.11959512531757355
# Batch: 140, Loss: 0.17157050967216492
# Batch: 160, Loss: 0.09785313904285431
# Batch: 180, Loss: 0.1967160403728485
# Batch: 200, Loss: 0.14131319522857666
#
# Average loss: 0.1396, Accuracy: 25364.0/26464 (96%)
#
#
# Average loss: 0.1675, Accuracy: 2803.0/2940 (95%)
#
# Epoch: 8 	Training Accuracy: 95.84%
# Validation Accuracy: 95.34%
# Batch: 0, Loss: 0.15504194796085358
# Batch: 20, Loss: 0.26010966300964355
# Batch: 40, Loss: 0.1758819818496704
# Batch: 60, Loss: 0.1544511765241623
# Batch: 80, Loss: 0.12756650149822235
# Batch: 100, Loss: 0.17774371802806854
# Batch: 120, Loss: 0.17270252108573914
# Batch: 140, Loss: 0.1567063182592392
# Batch: 160, Loss: 0.14892445504665375
# Batch: 180, Loss: 0.3303559720516205
# Batch: 200, Loss: 0.12641549110412598
#
# Average loss: 0.1376, Accuracy: 25334.0/26464 (96%)
#
#
# Average loss: 0.1666, Accuracy: 2797.0/2940 (95%)
#
# Epoch: 9 	Training Accuracy: 95.73%
# Validation Accuracy: 95.14%
# Batch: 0, Loss: 0.12184219807386398
# Batch: 20, Loss: 0.14467231929302216
# Batch: 40, Loss: 0.08174984902143478
# Batch: 60, Loss: 0.19994914531707764
# Batch: 80, Loss: 0.1381702423095703
# Batch: 100, Loss: 0.18442010879516602
# Batch: 120, Loss: 0.09770188480615616
# Batch: 140, Loss: 0.12875999510288239
# Batch: 160, Loss: 0.16341476142406464
# Batch: 180, Loss: 0.12034941464662552
# Batch: 200, Loss: 0.13784734904766083
#
# Average loss: 0.1351, Accuracy: 25382.0/26464 (96%)
#
#
# Average loss: 0.1634, Accuracy: 2799.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 95.91%
# Validation Accuracy: 95.20%
# Batch: 0, Loss: 0.12685661017894745
# Batch: 20, Loss: 0.20728793740272522
# Batch: 40, Loss: 0.0815262570977211
# Batch: 60, Loss: 0.16338877379894257
# Batch: 80, Loss: 0.1285448670387268
# Batch: 100, Loss: 0.1000460535287857
# Batch: 120, Loss: 0.12941205501556396
# Batch: 140, Loss: 0.1028943881392479
# Batch: 160, Loss: 0.08599507063627243
# Batch: 180, Loss: 0.23193317651748657
# Batch: 200, Loss: 0.13081909716129303
#
# Average loss: 0.1324, Accuracy: 25403.0/26464 (96%)
#
#
# Average loss: 0.1666, Accuracy: 2804.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 95.99%
# Validation Accuracy: 95.37%
# Batch: 0, Loss: 0.06225946173071861
# Batch: 20, Loss: 0.08404067158699036
# Batch: 40, Loss: 0.29635000228881836
# Batch: 60, Loss: 0.20859843492507935
# Batch: 80, Loss: 0.07694581896066666
# Batch: 100, Loss: 0.06625720113515854
# Batch: 120, Loss: 0.15648096799850464
# Batch: 140, Loss: 0.14843516051769257
# Batch: 160, Loss: 0.117665596306324
# Batch: 180, Loss: 0.06203112751245499
# Batch: 200, Loss: 0.12130529433488846
#
# Average loss: 0.1310, Accuracy: 25423.0/26464 (96%)
#
#
# Average loss: 0.1638, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 96.07%
# Validation Accuracy: 95.85%
# Batch: 0, Loss: 0.22642172873020172
# Batch: 20, Loss: 0.11601079255342484
# Batch: 40, Loss: 0.057407133281230927
# Batch: 60, Loss: 0.13887926936149597
# Batch: 80, Loss: 0.19184602797031403
# Batch: 100, Loss: 0.1684097945690155
# Batch: 120, Loss: 0.18255500495433807
# Batch: 140, Loss: 0.09660094231367111
# Batch: 160, Loss: 0.15757456421852112
# Batch: 180, Loss: 0.09440034627914429
# Batch: 200, Loss: 0.13098764419555664
#
# Average loss: 0.1350, Accuracy: 25361.0/26464 (96%)
#
#
# Average loss: 0.1655, Accuracy: 2810.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 95.83%
# Validation Accuracy: 95.58%
# Batch: 0, Loss: 0.11696866899728775
# Batch: 20, Loss: 0.25678345561027527
# Batch: 40, Loss: 0.13863249123096466
# Batch: 60, Loss: 0.16290324926376343
# Batch: 80, Loss: 0.22849483788013458
# Batch: 100, Loss: 0.1548282653093338
# Batch: 120, Loss: 0.10808665305376053
# Batch: 140, Loss: 0.05259905382990837
# Batch: 160, Loss: 0.1263056844472885
# Batch: 180, Loss: 0.10202450305223465
# Batch: 200, Loss: 0.14853151142597198
#
# Average loss: 0.1267, Accuracy: 25430.0/26464 (96%)
#
#
# Average loss: 0.1572, Accuracy: 2809.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 96.09%
# Validation Accuracy: 95.54%
# Batch: 0, Loss: 0.06547144800424576
# Batch: 20, Loss: 0.10248759388923645
# Batch: 40, Loss: 0.11044248193502426
# Batch: 60, Loss: 0.11826305091381073
# Batch: 80, Loss: 0.09747328609228134
# Batch: 100, Loss: 0.12014058977365494
# Batch: 120, Loss: 0.06235111504793167
# Batch: 140, Loss: 0.18178504705429077
# Batch: 160, Loss: 0.09732573479413986
# Batch: 180, Loss: 0.11526123434305191
# Batch: 200, Loss: 0.12906880676746368
#
# Average loss: 0.1275, Accuracy: 25463.0/26464 (96%)
#
#
# Average loss: 0.1592, Accuracy: 2812.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 96.22%
# Validation Accuracy: 95.65%
# Batch: 0, Loss: 0.06138850376009941
# Batch: 20, Loss: 0.13752517104148865
# Batch: 40, Loss: 0.16875393688678741
# Batch: 60, Loss: 0.1471308469772339
# Batch: 80, Loss: 0.08234947174787521
# Batch: 100, Loss: 0.11922170221805573
# Batch: 120, Loss: 0.16735844314098358
# Batch: 140, Loss: 0.13723348081111908
# Batch: 160, Loss: 0.06715477257966995
# Batch: 180, Loss: 0.09434451162815094
# Batch: 200, Loss: 0.15997961163520813
#
# Average loss: 0.1303, Accuracy: 25392.0/26464 (96%)
#
#
# Average loss: 0.1657, Accuracy: 2802.0/2940 (95%)
#
# Epoch: 16 	Training Accuracy: 95.95%
# Validation Accuracy: 95.31%
# Batch: 0, Loss: 0.1843463033437729
# Batch: 20, Loss: 0.07151399552822113
# Batch: 40, Loss: 0.13955995440483093
# Batch: 60, Loss: 0.06912519037723541
# Batch: 80, Loss: 0.14737004041671753
# Batch: 100, Loss: 0.07542546093463898
# Batch: 120, Loss: 0.10544521361589432
# Batch: 140, Loss: 0.1752142310142517
# Batch: 160, Loss: 0.1077631339430809
# Batch: 180, Loss: 0.12580697238445282
# Batch: 200, Loss: 0.10561243444681168
#
# Average loss: 0.1252, Accuracy: 25442.0/26464 (96%)
#
#
# Average loss: 0.1601, Accuracy: 2813.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 96.14%
# Validation Accuracy: 95.68%
# Batch: 0, Loss: 0.16712814569473267
# Batch: 20, Loss: 0.22365346550941467
# Batch: 40, Loss: 0.07473700493574142
# Batch: 60, Loss: 0.2012113779783249
# Batch: 80, Loss: 0.04505176842212677
# Batch: 100, Loss: 0.0718049630522728
# Batch: 120, Loss: 0.09929412603378296
# Batch: 140, Loss: 0.13630206882953644
# Batch: 160, Loss: 0.06759905070066452
# Batch: 180, Loss: 0.11935631185770035
# Batch: 200, Loss: 0.08453547954559326
#
# Average loss: 0.1247, Accuracy: 25442.0/26464 (96%)
#
#
# Average loss: 0.1583, Accuracy: 2804.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 96.14%
# Validation Accuracy: 95.37%
# Early stopping invoked.
#
# Average loss: 0.1310, Accuracy: 25423.0/26464 (96%)
#
#
# Average loss: 0.1389, Accuracy: 4652.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9607
# Final Test Accuracy (New Data): 0.9570

# %%
plot_layer_effective_ranks(model_finetuning_baseline)
# Out:
# conv0.weight: 3.8695
# conv1.weight: 3.3434
# fc_1.weight: 108.0013
# fc_2.weight: 4.9708

# %% [markdown]
# ***WITH BALANCED CLASSES***

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01]
percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]

seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test = {}
results_train = {}
best_models = {}
data_loaders = {}
epochs_taken = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Training with different data percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []

    for seed in tqdm(seed_set, desc=f'Training for data percentage: {perc}', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")
        
        model_new =  generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
        model_new.to(device)

        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)

        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        # Train and evaluate the new model on the new data
        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        # Add tqdm write method to prevent progress bar overlap
        tqdm.write(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
        tqdm.write(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test[perc] = test_accuracies
    results_train[perc] = train_accuracies
    epochs_taken[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Training with different data percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Training for data percentage: 0.01:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 74 =========================
# Batch: 0, Loss: 1.6154248714447021
#
# Average loss: 1.6094, Accuracy: 67.0/260 (26%)
#
#
# Average loss: 1.6092, Accuracy: 619.0/2940 (21%)
#
# Epoch: 0 	Training Accuracy: 25.77%
# Validation Accuracy: 21.05%
# Batch: 0, Loss: 1.6097102165222168
#
# Average loss: 1.6091, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6076, Accuracy: 655.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6123515367507935
#
# Average loss: 1.6111, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6079, Accuracy: 655.0/2940 (22%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.619430422782898
#
# Average loss: 1.6113, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6087, Accuracy: 655.0/2940 (22%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.5906250476837158
#
# Average loss: 1.6108, Accuracy: 86.0/260 (33%)
#
#
# Average loss: 1.6099, Accuracy: 917.0/2940 (31%)
#
# Epoch: 4 	Training Accuracy: 33.08%
# Validation Accuracy: 31.19%
# Batch: 0, Loss: 1.6227540969848633
#
# Average loss: 1.6084, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6089, Accuracy: 552.0/2940 (19%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 18.78%
# Batch: 0, Loss: 1.6064528226852417
#
# Average loss: 1.6044, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6057, Accuracy: 551.0/2940 (19%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6084545850753784
#
# Average loss: 1.5982, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5999, Accuracy: 551.0/2940 (19%)
#
# Epoch: 7 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6013809442520142
#
# Average loss: 1.5933, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5958, Accuracy: 551.0/2940 (19%)
#
# Epoch: 8 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6072498559951782
#
# Average loss: 1.5886, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5917, Accuracy: 551.0/2940 (19%)
#
# Epoch: 9 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.5868442058563232
#
# Average loss: 1.5840, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5877, Accuracy: 552.0/2940 (19%)
#
# Epoch: 10 	Training Accuracy: 20.00%
# Validation Accuracy: 18.78%
# Early stopping invoked.
#
# Average loss: 1.6108, Accuracy: 86.0/260 (33%)
#
#
# Average loss: 1.6124, Accuracy: 1479.0/4861 (30%)
#
# Final Training Accuracy (New Data): 0.3308
# Final Test Accuracy (New Data): 0.3043
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 19 =========================
# Batch: 0, Loss: 1.6119766235351562
#
# Average loss: 1.6053, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6052, Accuracy: 599.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6049262285232544
#
# Average loss: 1.5980, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5990, Accuracy: 600.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 20.41%
# Batch: 0, Loss: 1.5936434268951416
#
# Average loss: 1.5875, Accuracy: 93.0/260 (36%)
#
#
# Average loss: 1.5894, Accuracy: 976.0/2940 (33%)
#
# Epoch: 2 	Training Accuracy: 35.77%
# Validation Accuracy: 33.20%
# Batch: 0, Loss: 1.5843620300292969
#
# Average loss: 1.5755, Accuracy: 131.0/260 (50%)
#
#
# Average loss: 1.5788, Accuracy: 1329.0/2940 (45%)
#
# Epoch: 3 	Training Accuracy: 50.38%
# Validation Accuracy: 45.20%
# Batch: 0, Loss: 1.566880702972412
#
# Average loss: 1.5620, Accuracy: 120.0/260 (46%)
#
#
# Average loss: 1.5672, Accuracy: 1227.0/2940 (42%)
#
# Epoch: 4 	Training Accuracy: 46.15%
# Validation Accuracy: 41.73%
# Batch: 0, Loss: 1.5697160959243774
#
# Average loss: 1.5456, Accuracy: 114.0/260 (44%)
#
#
# Average loss: 1.5517, Accuracy: 1180.0/2940 (40%)
#
# Epoch: 5 	Training Accuracy: 43.85%
# Validation Accuracy: 40.14%
# Batch: 0, Loss: 1.548050880432129
#
# Average loss: 1.5275, Accuracy: 94.0/260 (36%)
#
#
# Average loss: 1.5342, Accuracy: 988.0/2940 (34%)
#
# Epoch: 6 	Training Accuracy: 36.15%
# Validation Accuracy: 33.61%
# Batch: 0, Loss: 1.5283576250076294
#
# Average loss: 1.5067, Accuracy: 85.0/260 (33%)
#
#
# Average loss: 1.5127, Accuracy: 920.0/2940 (31%)
#
# Epoch: 7 	Training Accuracy: 32.69%
# Validation Accuracy: 31.29%
# Batch: 0, Loss: 1.5176857709884644
#
# Average loss: 1.4822, Accuracy: 133.0/260 (51%)
#
#
# Average loss: 1.4858, Accuracy: 1330.0/2940 (45%)
#
# Epoch: 8 	Training Accuracy: 51.15%
# Validation Accuracy: 45.24%
# Batch: 0, Loss: 1.4759395122528076
#
# Average loss: 1.4520, Accuracy: 168.0/260 (65%)
#
#
# Average loss: 1.4535, Accuracy: 1817.0/2940 (62%)
#
# Epoch: 9 	Training Accuracy: 64.62%
# Validation Accuracy: 61.80%
# Batch: 0, Loss: 1.4580259323120117
#
# Average loss: 1.4148, Accuracy: 155.0/260 (60%)
#
#
# Average loss: 1.4150, Accuracy: 1817.0/2940 (62%)
#
# Epoch: 10 	Training Accuracy: 59.62%
# Validation Accuracy: 61.80%
# Batch: 0, Loss: 1.402498483657837
#
# Average loss: 1.3702, Accuracy: 148.0/260 (57%)
#
#
# Average loss: 1.3708, Accuracy: 1735.0/2940 (59%)
#
# Epoch: 11 	Training Accuracy: 56.92%
# Validation Accuracy: 59.01%
# Batch: 0, Loss: 1.3852072954177856
#
# Average loss: 1.3145, Accuracy: 152.0/260 (58%)
#
#
# Average loss: 1.3189, Accuracy: 1819.0/2940 (62%)
#
# Epoch: 12 	Training Accuracy: 58.46%
# Validation Accuracy: 61.87%
# Batch: 0, Loss: 1.3072161674499512
#
# Average loss: 1.2473, Accuracy: 171.0/260 (66%)
#
#
# Average loss: 1.2577, Accuracy: 2030.0/2940 (69%)
#
# Epoch: 13 	Training Accuracy: 65.77%
# Validation Accuracy: 69.05%
# Batch: 0, Loss: 1.2412210702896118
#
# Average loss: 1.1758, Accuracy: 194.0/260 (75%)
#
#
# Average loss: 1.1938, Accuracy: 2168.0/2940 (74%)
#
# Epoch: 14 	Training Accuracy: 74.62%
# Validation Accuracy: 73.74%
# Batch: 0, Loss: 1.1750937700271606
#
# Average loss: 1.0977, Accuracy: 207.0/260 (80%)
#
#
# Average loss: 1.1213, Accuracy: 2246.0/2940 (76%)
#
# Epoch: 15 	Training Accuracy: 79.62%
# Validation Accuracy: 76.39%
# Batch: 0, Loss: 1.1086170673370361
#
# Average loss: 1.0174, Accuracy: 207.0/260 (80%)
#
#
# Average loss: 1.0449, Accuracy: 2257.0/2940 (77%)
#
# Epoch: 16 	Training Accuracy: 79.62%
# Validation Accuracy: 76.77%
# Batch: 0, Loss: 1.0227421522140503
#
# Average loss: 0.9387, Accuracy: 212.0/260 (82%)
#
#
# Average loss: 0.9699, Accuracy: 2277.0/2940 (77%)
#
# Epoch: 17 	Training Accuracy: 81.54%
# Validation Accuracy: 77.45%
# Batch: 0, Loss: 0.8914777040481567
#
# Average loss: 0.8565, Accuracy: 212.0/260 (82%)
#
#
# Average loss: 0.8938, Accuracy: 2313.0/2940 (79%)
#
# Epoch: 18 	Training Accuracy: 81.54%
# Validation Accuracy: 78.67%
# Batch: 0, Loss: 0.8585199117660522
#
# Average loss: 0.7719, Accuracy: 222.0/260 (85%)
#
#
# Average loss: 0.8148, Accuracy: 2351.0/2940 (80%)
#
# Epoch: 19 	Training Accuracy: 85.38%
# Validation Accuracy: 79.97%
#
# Average loss: 0.7719, Accuracy: 222.0/260 (85%)
#
#
# Average loss: 0.7945, Accuracy: 3944.0/4861 (81%)
#
# Final Training Accuracy (New Data): 0.8538
# Final Test Accuracy (New Data): 0.8114
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 33 =========================
# Batch: 0, Loss: 1.6075658798217773
#
# Average loss: 1.6095, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6080, Accuracy: 599.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6107052564620972
#
# Average loss: 1.6078, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6071, Accuracy: 599.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6065881252288818
#
# Average loss: 1.6054, Accuracy: 54.0/260 (21%)
#
#
# Average loss: 1.6054, Accuracy: 641.0/2940 (22%)
#
# Epoch: 2 	Training Accuracy: 20.77%
# Validation Accuracy: 21.80%
# Batch: 0, Loss: 1.6040924787521362
#
# Average loss: 1.6013, Accuracy: 82.0/260 (32%)
#
#
# Average loss: 1.6019, Accuracy: 972.0/2940 (33%)
#
# Epoch: 3 	Training Accuracy: 31.54%
# Validation Accuracy: 33.06%
# Batch: 0, Loss: 1.6040260791778564
#
# Average loss: 1.5948, Accuracy: 80.0/260 (31%)
#
#
# Average loss: 1.5961, Accuracy: 939.0/2940 (32%)
#
# Epoch: 4 	Training Accuracy: 30.77%
# Validation Accuracy: 31.94%
# Batch: 0, Loss: 1.5947680473327637
#
# Average loss: 1.5847, Accuracy: 105.0/260 (40%)
#
#
# Average loss: 1.5870, Accuracy: 1154.0/2940 (39%)
#
# Epoch: 5 	Training Accuracy: 40.38%
# Validation Accuracy: 39.25%
# Batch: 0, Loss: 1.583409309387207
#
# Average loss: 1.5694, Accuracy: 122.0/260 (47%)
#
#
# Average loss: 1.5732, Accuracy: 1238.0/2940 (42%)
#
# Epoch: 6 	Training Accuracy: 46.92%
# Validation Accuracy: 42.11%
# Batch: 0, Loss: 1.5726473331451416
#
# Average loss: 1.5476, Accuracy: 134.0/260 (52%)
#
#
# Average loss: 1.5535, Accuracy: 1395.0/2940 (47%)
#
# Epoch: 7 	Training Accuracy: 51.54%
# Validation Accuracy: 47.45%
# Batch: 0, Loss: 1.5441970825195312
#
# Average loss: 1.5177, Accuracy: 144.0/260 (55%)
#
#
# Average loss: 1.5267, Accuracy: 1543.0/2940 (52%)
#
# Epoch: 8 	Training Accuracy: 55.38%
# Validation Accuracy: 52.48%
# Batch: 0, Loss: 1.5241918563842773
#
# Average loss: 1.4791, Accuracy: 154.0/260 (59%)
#
#
# Average loss: 1.4924, Accuracy: 1596.0/2940 (54%)
#
# Epoch: 9 	Training Accuracy: 59.23%
# Validation Accuracy: 54.29%
# Batch: 0, Loss: 1.4757826328277588
#
# Average loss: 1.4312, Accuracy: 156.0/260 (60%)
#
#
# Average loss: 1.4501, Accuracy: 1563.0/2940 (53%)
#
# Epoch: 10 	Training Accuracy: 60.00%
# Validation Accuracy: 53.16%
# Batch: 0, Loss: 1.4466934204101562
#
# Average loss: 1.3750, Accuracy: 148.0/260 (57%)
#
#
# Average loss: 1.4015, Accuracy: 1481.0/2940 (50%)
#
# Epoch: 11 	Training Accuracy: 56.92%
# Validation Accuracy: 50.37%
# Batch: 0, Loss: 1.3658075332641602
#
# Average loss: 1.3152, Accuracy: 141.0/260 (54%)
#
#
# Average loss: 1.3502, Accuracy: 1379.0/2940 (47%)
#
# Epoch: 12 	Training Accuracy: 54.23%
# Validation Accuracy: 46.90%
# Batch: 0, Loss: 1.318228006362915
#
# Average loss: 1.2530, Accuracy: 140.0/260 (54%)
#
#
# Average loss: 1.2959, Accuracy: 1372.0/2940 (47%)
#
# Epoch: 13 	Training Accuracy: 53.85%
# Validation Accuracy: 46.67%
# Batch: 0, Loss: 1.2794684171676636
#
# Average loss: 1.1880, Accuracy: 144.0/260 (55%)
#
#
# Average loss: 1.2379, Accuracy: 1430.0/2940 (49%)
#
# Epoch: 14 	Training Accuracy: 55.38%
# Validation Accuracy: 48.64%
# Batch: 0, Loss: 1.2033591270446777
#
# Average loss: 1.1136, Accuracy: 153.0/260 (59%)
#
#
# Average loss: 1.1696, Accuracy: 1535.0/2940 (52%)
#
# Epoch: 15 	Training Accuracy: 58.85%
# Validation Accuracy: 52.21%
# Early stopping invoked.
#
# Average loss: 1.4791, Accuracy: 154.0/260 (59%)
#
#
# Average loss: 1.4860, Accuracy: 2736.0/4861 (56%)
#
# Final Training Accuracy (New Data): 0.5923
# Final Test Accuracy (New Data): 0.5628
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 72 =========================
# Batch: 0, Loss: 1.613410234451294
#
# Average loss: 1.6020, Accuracy: 104.0/260 (40%)
#
#
# Average loss: 1.6037, Accuracy: 1135.0/2940 (39%)
#
# Epoch: 0 	Training Accuracy: 40.00%
# Validation Accuracy: 38.61%
# Batch: 0, Loss: 1.6048873662948608
#
# Average loss: 1.5929, Accuracy: 130.0/260 (50%)
#
#
# Average loss: 1.5959, Accuracy: 1355.0/2940 (46%)
#
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 46.09%
# Batch: 0, Loss: 1.5883140563964844
#
# Average loss: 1.5820, Accuracy: 113.0/260 (43%)
#
#
# Average loss: 1.5864, Accuracy: 1199.0/2940 (41%)
#
# Epoch: 2 	Training Accuracy: 43.46%
# Validation Accuracy: 40.78%
# Batch: 0, Loss: 1.5813333988189697
#
# Average loss: 1.5687, Accuracy: 107.0/260 (41%)
#
#
# Average loss: 1.5746, Accuracy: 1103.0/2940 (38%)
#
# Epoch: 3 	Training Accuracy: 41.15%
# Validation Accuracy: 37.52%
# Batch: 0, Loss: 1.5764824151992798
#
# Average loss: 1.5524, Accuracy: 109.0/260 (42%)
#
#
# Average loss: 1.5602, Accuracy: 1107.0/2940 (38%)
#
# Epoch: 4 	Training Accuracy: 41.92%
# Validation Accuracy: 37.65%
# Batch: 0, Loss: 1.552013874053955
#
# Average loss: 1.5324, Accuracy: 120.0/260 (46%)
#
#
# Average loss: 1.5425, Accuracy: 1203.0/2940 (41%)
#
# Epoch: 5 	Training Accuracy: 46.15%
# Validation Accuracy: 40.92%
# Batch: 0, Loss: 1.5423920154571533
#
# Average loss: 1.5078, Accuracy: 128.0/260 (49%)
#
#
# Average loss: 1.5203, Accuracy: 1354.0/2940 (46%)
#
# Epoch: 6 	Training Accuracy: 49.23%
# Validation Accuracy: 46.05%
# Batch: 0, Loss: 1.514168620109558
#
# Average loss: 1.4779, Accuracy: 134.0/260 (52%)
#
#
# Average loss: 1.4929, Accuracy: 1422.0/2940 (48%)
#
# Epoch: 7 	Training Accuracy: 51.54%
# Validation Accuracy: 48.37%
# Batch: 0, Loss: 1.4990378618240356
#
# Average loss: 1.4439, Accuracy: 136.0/260 (52%)
#
#
# Average loss: 1.4619, Accuracy: 1440.0/2940 (49%)
#
# Epoch: 8 	Training Accuracy: 52.31%
# Validation Accuracy: 48.98%
# Batch: 0, Loss: 1.4342824220657349
#
# Average loss: 1.4055, Accuracy: 141.0/260 (54%)
#
#
# Average loss: 1.4265, Accuracy: 1483.0/2940 (50%)
#
# Epoch: 9 	Training Accuracy: 54.23%
# Validation Accuracy: 50.44%
# Batch: 0, Loss: 1.4033845663070679
#
# Average loss: 1.3604, Accuracy: 149.0/260 (57%)
#
#
# Average loss: 1.3844, Accuracy: 1580.0/2940 (54%)
#
# Epoch: 10 	Training Accuracy: 57.31%
# Validation Accuracy: 53.74%
# Batch: 0, Loss: 1.3643999099731445
#
# Average loss: 1.3074, Accuracy: 167.0/260 (64%)
#
#
# Average loss: 1.3348, Accuracy: 1760.0/2940 (60%)
#
# Epoch: 11 	Training Accuracy: 64.23%
# Validation Accuracy: 59.86%
# Batch: 0, Loss: 1.31440269947052
#
# Average loss: 1.2508, Accuracy: 168.0/260 (65%)
#
#
# Average loss: 1.2827, Accuracy: 1760.0/2940 (60%)
#
# Epoch: 12 	Training Accuracy: 64.62%
# Validation Accuracy: 59.86%
# Batch: 0, Loss: 1.2413358688354492
#
# Average loss: 1.1908, Accuracy: 162.0/260 (62%)
#
#
# Average loss: 1.2285, Accuracy: 1757.0/2940 (60%)
#
# Epoch: 13 	Training Accuracy: 62.31%
# Validation Accuracy: 59.76%
# Batch: 0, Loss: 1.2120640277862549
#
# Average loss: 1.1277, Accuracy: 160.0/260 (62%)
#
#
# Average loss: 1.1703, Accuracy: 1786.0/2940 (61%)
#
# Epoch: 14 	Training Accuracy: 61.54%
# Validation Accuracy: 60.75%
# Batch: 0, Loss: 1.1107102632522583
#
# Average loss: 1.0633, Accuracy: 162.0/260 (62%)
#
#
# Average loss: 1.1101, Accuracy: 1796.0/2940 (61%)
#
# Epoch: 15 	Training Accuracy: 62.31%
# Validation Accuracy: 61.09%
# Batch: 0, Loss: 1.0553373098373413
#
# Average loss: 0.9977, Accuracy: 171.0/260 (66%)
#
#
# Average loss: 1.0480, Accuracy: 1840.0/2940 (63%)
#
# Epoch: 16 	Training Accuracy: 65.77%
# Validation Accuracy: 62.59%
# Batch: 0, Loss: 0.9820938110351562
#
# Average loss: 0.9375, Accuracy: 177.0/260 (68%)
#
#
# Average loss: 0.9888, Accuracy: 1891.0/2940 (64%)
#
# Epoch: 17 	Training Accuracy: 68.08%
# Validation Accuracy: 64.32%
# Batch: 0, Loss: 0.9414152503013611
#
# Average loss: 0.8822, Accuracy: 179.0/260 (69%)
#
#
# Average loss: 0.9371, Accuracy: 1911.0/2940 (65%)
#
# Epoch: 18 	Training Accuracy: 68.85%
# Validation Accuracy: 65.00%
# Batch: 0, Loss: 0.825003445148468
#
# Average loss: 0.8197, Accuracy: 191.0/260 (73%)
#
#
# Average loss: 0.8794, Accuracy: 1997.0/2940 (68%)
#
# Epoch: 19 	Training Accuracy: 73.46%
# Validation Accuracy: 67.93%
#
# Average loss: 0.8197, Accuracy: 191.0/260 (73%)
#
#
# Average loss: 0.8775, Accuracy: 3344.0/4861 (69%)
#
# Final Training Accuracy (New Data): 0.7346
# Final Test Accuracy (New Data): 0.6879
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 62 =========================
# Batch: 0, Loss: 1.6079639196395874
#
# Average loss: 1.6083, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6098, Accuracy: 550.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6052820682525635
#
# Average loss: 1.6060, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6079, Accuracy: 550.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6060210466384888
#
# Average loss: 1.6018, Accuracy: 67.0/260 (26%)
#
#
# Average loss: 1.6044, Accuracy: 660.0/2940 (22%)
#
# Epoch: 2 	Training Accuracy: 25.77%
# Validation Accuracy: 22.45%
# Batch: 0, Loss: 1.6057549715042114
#
# Average loss: 1.5953, Accuracy: 102.0/260 (39%)
#
#
# Average loss: 1.5988, Accuracy: 1075.0/2940 (37%)
#
# Epoch: 3 	Training Accuracy: 39.23%
# Validation Accuracy: 36.56%
# Batch: 0, Loss: 1.5924713611602783
#
# Average loss: 1.5871, Accuracy: 140.0/260 (54%)
#
#
# Average loss: 1.5905, Accuracy: 1414.0/2940 (48%)
#
# Epoch: 4 	Training Accuracy: 53.85%
# Validation Accuracy: 48.10%
# Batch: 0, Loss: 1.5881048440933228
#
# Average loss: 1.5756, Accuracy: 83.0/260 (32%)
#
#
# Average loss: 1.5781, Accuracy: 893.0/2940 (30%)
#
# Epoch: 5 	Training Accuracy: 31.92%
# Validation Accuracy: 30.37%
# Batch: 0, Loss: 1.5736165046691895
#
# Average loss: 1.5648, Accuracy: 88.0/260 (34%)
#
#
# Average loss: 1.5669, Accuracy: 974.0/2940 (33%)
#
# Epoch: 6 	Training Accuracy: 33.85%
# Validation Accuracy: 33.13%
# Batch: 0, Loss: 1.5635572671890259
#
# Average loss: 1.5517, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.5547, Accuracy: 1034.0/2940 (35%)
#
# Epoch: 7 	Training Accuracy: 35.00%
# Validation Accuracy: 35.17%
# Batch: 0, Loss: 1.542519211769104
#
# Average loss: 1.5348, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.5384, Accuracy: 1027.0/2940 (35%)
#
# Epoch: 8 	Training Accuracy: 35.00%
# Validation Accuracy: 34.93%
# Batch: 0, Loss: 1.5262144804000854
#
# Average loss: 1.5167, Accuracy: 85.0/260 (33%)
#
#
# Average loss: 1.5197, Accuracy: 955.0/2940 (32%)
#
# Epoch: 9 	Training Accuracy: 32.69%
# Validation Accuracy: 32.48%
# Batch: 0, Loss: 1.5215189456939697
#
# Average loss: 1.4994, Accuracy: 98.0/260 (38%)
#
#
# Average loss: 1.4977, Accuracy: 1096.0/2940 (37%)
#
# Epoch: 10 	Training Accuracy: 37.69%
# Validation Accuracy: 37.28%
# Early stopping invoked.
#
# Average loss: 1.5871, Accuracy: 140.0/260 (54%)
#
#
# Average loss: 1.5897, Accuracy: 2547.0/4861 (52%)
#
# Final Training Accuracy (New Data): 0.5385
# Final Test Accuracy (New Data): 0.5240
# Training for data percentage: 0.03:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 83 =========================
# Batch: 0, Loss: 1.602069616317749
#
# Average loss: 1.6036, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6045, Accuracy: 550.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6076217889785767
#
# Average loss: 1.5959, Accuracy: 174.0/790 (22%)
#
#
# Average loss: 1.5962, Accuracy: 620.0/2940 (21%)
#
# Epoch: 1 	Training Accuracy: 22.03%
# Validation Accuracy: 21.09%
# Batch: 0, Loss: 1.6027201414108276
#
# Average loss: 1.5777, Accuracy: 366.0/790 (46%)
#
#
# Average loss: 1.5788, Accuracy: 1323.0/2940 (45%)
#
# Epoch: 2 	Training Accuracy: 46.33%
# Validation Accuracy: 45.00%
# Batch: 0, Loss: 1.5773648023605347
#
# Average loss: 1.5374, Accuracy: 353.0/790 (45%)
#
#
# Average loss: 1.5385, Accuracy: 1324.0/2940 (45%)
#
# Epoch: 3 	Training Accuracy: 44.68%
# Validation Accuracy: 45.03%
# Batch: 0, Loss: 1.5462349653244019
#
# Average loss: 1.4530, Accuracy: 442.0/790 (56%)
#
#
# Average loss: 1.4495, Accuracy: 1662.0/2940 (57%)
#
# Epoch: 4 	Training Accuracy: 55.95%
# Validation Accuracy: 56.53%
# Batch: 0, Loss: 1.4664100408554077
#
# Average loss: 1.3029, Accuracy: 502.0/790 (64%)
#
#
# Average loss: 1.2883, Accuracy: 1840.0/2940 (63%)
#
# Epoch: 5 	Training Accuracy: 63.54%
# Validation Accuracy: 62.59%
# Batch: 0, Loss: 1.2756701707839966
#
# Average loss: 1.1040, Accuracy: 519.0/790 (66%)
#
#
# Average loss: 1.0785, Accuracy: 1918.0/2940 (65%)
#
# Epoch: 6 	Training Accuracy: 65.70%
# Validation Accuracy: 65.24%
# Batch: 0, Loss: 1.1144051551818848
#
# Average loss: 0.9055, Accuracy: 578.0/790 (73%)
#
#
# Average loss: 0.8839, Accuracy: 2125.0/2940 (72%)
#
# Epoch: 7 	Training Accuracy: 73.16%
# Validation Accuracy: 72.28%
# Batch: 0, Loss: 0.8885884881019592
#
# Average loss: 0.7550, Accuracy: 603.0/790 (76%)
#
#
# Average loss: 0.7511, Accuracy: 2180.0/2940 (74%)
#
# Epoch: 8 	Training Accuracy: 76.33%
# Validation Accuracy: 74.15%
# Batch: 0, Loss: 0.7712517380714417
#
# Average loss: 0.6391, Accuracy: 630.0/790 (80%)
#
#
# Average loss: 0.6413, Accuracy: 2291.0/2940 (78%)
#
# Epoch: 9 	Training Accuracy: 79.75%
# Validation Accuracy: 77.93%
# Batch: 0, Loss: 0.6515526175498962
#
# Average loss: 0.5586, Accuracy: 654.0/790 (83%)
#
#
# Average loss: 0.5703, Accuracy: 2330.0/2940 (79%)
#
# Epoch: 10 	Training Accuracy: 82.78%
# Validation Accuracy: 79.25%
# Batch: 0, Loss: 0.6314785480499268
#
# Average loss: 0.5051, Accuracy: 662.0/790 (84%)
#
#
# Average loss: 0.5289, Accuracy: 2376.0/2940 (81%)
#
# Epoch: 11 	Training Accuracy: 83.80%
# Validation Accuracy: 80.82%
# Batch: 0, Loss: 0.5322598218917847
#
# Average loss: 0.4688, Accuracy: 669.0/790 (85%)
#
#
# Average loss: 0.5036, Accuracy: 2419.0/2940 (82%)
#
# Epoch: 12 	Training Accuracy: 84.68%
# Validation Accuracy: 82.28%
# Batch: 0, Loss: 0.4576229751110077
#
# Average loss: 0.4353, Accuracy: 677.0/790 (86%)
#
#
# Average loss: 0.4662, Accuracy: 2455.0/2940 (84%)
#
# Epoch: 13 	Training Accuracy: 85.70%
# Validation Accuracy: 83.50%
# Batch: 0, Loss: 0.46766382455825806
#
# Average loss: 0.4107, Accuracy: 680.0/790 (86%)
#
#
# Average loss: 0.4460, Accuracy: 2467.0/2940 (84%)
#
# Epoch: 14 	Training Accuracy: 86.08%
# Validation Accuracy: 83.91%
# Batch: 0, Loss: 0.41941145062446594
#
# Average loss: 0.3980, Accuracy: 679.0/790 (86%)
#
#
# Average loss: 0.4476, Accuracy: 2449.0/2940 (83%)
#
# Epoch: 15 	Training Accuracy: 85.95%
# Validation Accuracy: 83.30%
# Batch: 0, Loss: 0.4509643018245697
#
# Average loss: 0.3723, Accuracy: 686.0/790 (87%)
#
#
# Average loss: 0.4210, Accuracy: 2488.0/2940 (85%)
#
# Epoch: 16 	Training Accuracy: 86.84%
# Validation Accuracy: 84.63%
# Batch: 0, Loss: 0.3480117917060852
#
# Average loss: 0.3586, Accuracy: 688.0/790 (87%)
#
#
# Average loss: 0.4072, Accuracy: 2508.0/2940 (85%)
#
# Epoch: 17 	Training Accuracy: 87.09%
# Validation Accuracy: 85.31%
# Batch: 0, Loss: 0.28626570105552673
#
# Average loss: 0.3451, Accuracy: 692.0/790 (88%)
#
#
# Average loss: 0.4061, Accuracy: 2499.0/2940 (85%)
#
# Epoch: 18 	Training Accuracy: 87.59%
# Validation Accuracy: 85.00%
# Batch: 0, Loss: 0.3347877860069275
#
# Average loss: 0.3349, Accuracy: 692.0/790 (88%)
#
#
# Average loss: 0.3959, Accuracy: 2512.0/2940 (85%)
#
# Epoch: 19 	Training Accuracy: 87.59%
# Validation Accuracy: 85.44%
#
# Average loss: 0.3349, Accuracy: 692.0/790 (88%)
#
#
# Average loss: 0.3751, Accuracy: 4203.0/4861 (86%)
#
# Final Training Accuracy (New Data): 0.8759
# Final Test Accuracy (New Data): 0.8646
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 48 =========================
# Batch: 0, Loss: 1.6137385368347168
#
# Average loss: 1.6104, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6096, Accuracy: 599.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.612055778503418
#
# Average loss: 1.6085, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6083, Accuracy: 599.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6061433553695679
#
# Average loss: 1.5984, Accuracy: 191.0/790 (24%)
#
#
# Average loss: 1.5989, Accuracy: 702.0/2940 (24%)
#
# Epoch: 2 	Training Accuracy: 24.18%
# Validation Accuracy: 23.88%
# Batch: 0, Loss: 1.5949479341506958
#
# Average loss: 1.5612, Accuracy: 309.0/790 (39%)
#
#
# Average loss: 1.5624, Accuracy: 1182.0/2940 (40%)
#
# Epoch: 3 	Training Accuracy: 39.11%
# Validation Accuracy: 40.20%
# Batch: 0, Loss: 1.565171241760254
#
# Average loss: 1.4685, Accuracy: 404.0/790 (51%)
#
#
# Average loss: 1.4704, Accuracy: 1446.0/2940 (49%)
#
# Epoch: 4 	Training Accuracy: 51.14%
# Validation Accuracy: 49.18%
# Batch: 0, Loss: 1.4571468830108643
#
# Average loss: 1.3102, Accuracy: 468.0/790 (59%)
#
#
# Average loss: 1.3162, Accuracy: 1660.0/2940 (56%)
#
# Epoch: 5 	Training Accuracy: 59.24%
# Validation Accuracy: 56.46%
# Batch: 0, Loss: 1.3143161535263062
#
# Average loss: 1.0691, Accuracy: 548.0/790 (69%)
#
#
# Average loss: 1.0806, Accuracy: 1996.0/2940 (68%)
#
# Epoch: 6 	Training Accuracy: 69.37%
# Validation Accuracy: 67.89%
# Batch: 0, Loss: 1.0883080959320068
#
# Average loss: 0.8339, Accuracy: 631.0/790 (80%)
#
#
# Average loss: 0.8568, Accuracy: 2278.0/2940 (77%)
#
# Epoch: 7 	Training Accuracy: 79.87%
# Validation Accuracy: 77.48%
# Batch: 0, Loss: 0.8847009539604187
#
# Average loss: 0.6383, Accuracy: 654.0/790 (83%)
#
#
# Average loss: 0.6768, Accuracy: 2353.0/2940 (80%)
#
# Epoch: 8 	Training Accuracy: 82.78%
# Validation Accuracy: 80.03%
# Batch: 0, Loss: 0.6598678231239319
#
# Average loss: 0.5027, Accuracy: 667.0/790 (84%)
#
#
# Average loss: 0.5506, Accuracy: 2407.0/2940 (82%)
#
# Epoch: 9 	Training Accuracy: 84.43%
# Validation Accuracy: 81.87%
# Batch: 0, Loss: 0.45628151297569275
#
# Average loss: 0.4195, Accuracy: 684.0/790 (87%)
#
#
# Average loss: 0.4819, Accuracy: 2450.0/2940 (83%)
#
# Epoch: 10 	Training Accuracy: 86.58%
# Validation Accuracy: 83.33%
# Batch: 0, Loss: 0.4731893241405487
#
# Average loss: 0.3703, Accuracy: 689.0/790 (87%)
#
#
# Average loss: 0.4480, Accuracy: 2469.0/2940 (84%)
#
# Epoch: 11 	Training Accuracy: 87.22%
# Validation Accuracy: 83.98%
# Batch: 0, Loss: 0.3576110601425171
#
# Average loss: 0.3264, Accuracy: 701.0/790 (89%)
#
#
# Average loss: 0.4118, Accuracy: 2492.0/2940 (85%)
#
# Epoch: 12 	Training Accuracy: 88.73%
# Validation Accuracy: 84.76%
# Batch: 0, Loss: 0.38726356625556946
#
# Average loss: 0.3009, Accuracy: 706.0/790 (89%)
#
#
# Average loss: 0.3917, Accuracy: 2530.0/2940 (86%)
#
# Epoch: 13 	Training Accuracy: 89.37%
# Validation Accuracy: 86.05%
# Batch: 0, Loss: 0.30941689014434814
#
# Average loss: 0.2852, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.3830, Accuracy: 2537.0/2940 (86%)
#
# Epoch: 14 	Training Accuracy: 90.38%
# Validation Accuracy: 86.29%
# Batch: 0, Loss: 0.31091728806495667
#
# Average loss: 0.2590, Accuracy: 718.0/790 (91%)
#
#
# Average loss: 0.3507, Accuracy: 2559.0/2940 (87%)
#
# Epoch: 15 	Training Accuracy: 90.89%
# Validation Accuracy: 87.04%
# Batch: 0, Loss: 0.2190650999546051
#
# Average loss: 0.2414, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.3429, Accuracy: 2576.0/2940 (88%)
#
# Epoch: 16 	Training Accuracy: 92.15%
# Validation Accuracy: 87.62%
# Batch: 0, Loss: 0.23846761882305145
#
# Average loss: 0.2225, Accuracy: 737.0/790 (93%)
#
#
# Average loss: 0.3295, Accuracy: 2598.0/2940 (88%)
#
# Epoch: 17 	Training Accuracy: 93.29%
# Validation Accuracy: 88.37%
# Batch: 0, Loss: 0.2696393132209778
#
# Average loss: 0.2100, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.3153, Accuracy: 2609.0/2940 (89%)
#
# Epoch: 18 	Training Accuracy: 93.16%
# Validation Accuracy: 88.74%
# Batch: 0, Loss: 0.20684844255447388
#
# Average loss: 0.1953, Accuracy: 743.0/790 (94%)
#
#
# Average loss: 0.3096, Accuracy: 2625.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 94.05%
# Validation Accuracy: 89.29%
#
# Average loss: 0.1953, Accuracy: 743.0/790 (94%)
#
#
# Average loss: 0.2765, Accuracy: 4386.0/4861 (90%)
#
# Final Training Accuracy (New Data): 0.9405
# Final Test Accuracy (New Data): 0.9023
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 97 =========================
# Batch: 0, Loss: 1.6059268712997437
#
# Average loss: 1.6075, Accuracy: 159.0/790 (20%)
#
#
# Average loss: 1.6115, Accuracy: 551.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.13%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.596319317817688
#
# Average loss: 1.5951, Accuracy: 207.0/790 (26%)
#
#
# Average loss: 1.5995, Accuracy: 712.0/2940 (24%)
#
# Epoch: 1 	Training Accuracy: 26.20%
# Validation Accuracy: 24.22%
# Batch: 0, Loss: 1.5949814319610596
#
# Average loss: 1.5639, Accuracy: 390.0/790 (49%)
#
#
# Average loss: 1.5684, Accuracy: 1433.0/2940 (49%)
#
# Epoch: 2 	Training Accuracy: 49.37%
# Validation Accuracy: 48.74%
# Batch: 0, Loss: 1.5595393180847168
#
# Average loss: 1.4983, Accuracy: 440.0/790 (56%)
#
#
# Average loss: 1.5040, Accuracy: 1616.0/2940 (55%)
#
# Epoch: 3 	Training Accuracy: 55.70%
# Validation Accuracy: 54.97%
# Batch: 0, Loss: 1.5111923217773438
#
# Average loss: 1.3718, Accuracy: 499.0/790 (63%)
#
#
# Average loss: 1.3793, Accuracy: 1844.0/2940 (63%)
#
# Epoch: 4 	Training Accuracy: 63.16%
# Validation Accuracy: 62.72%
# Batch: 0, Loss: 1.406477689743042
#
# Average loss: 1.1626, Accuracy: 580.0/790 (73%)
#
#
# Average loss: 1.1720, Accuracy: 2134.0/2940 (73%)
#
# Epoch: 5 	Training Accuracy: 73.42%
# Validation Accuracy: 72.59%
# Batch: 0, Loss: 1.1879448890686035
#
# Average loss: 0.8864, Accuracy: 654.0/790 (83%)
#
#
# Average loss: 0.8997, Accuracy: 2377.0/2940 (81%)
#
# Epoch: 6 	Training Accuracy: 82.78%
# Validation Accuracy: 80.85%
# Batch: 0, Loss: 0.8663268089294434
#
# Average loss: 0.6388, Accuracy: 670.0/790 (85%)
#
#
# Average loss: 0.6705, Accuracy: 2435.0/2940 (83%)
#
# Epoch: 7 	Training Accuracy: 84.81%
# Validation Accuracy: 82.82%
# Batch: 0, Loss: 0.6027916669845581
#
# Average loss: 0.4853, Accuracy: 680.0/790 (86%)
#
#
# Average loss: 0.5402, Accuracy: 2460.0/2940 (84%)
#
# Epoch: 8 	Training Accuracy: 86.08%
# Validation Accuracy: 83.67%
# Batch: 0, Loss: 0.5070320963859558
#
# Average loss: 0.4045, Accuracy: 688.0/790 (87%)
#
#
# Average loss: 0.4769, Accuracy: 2488.0/2940 (85%)
#
# Epoch: 9 	Training Accuracy: 87.09%
# Validation Accuracy: 84.63%
# Batch: 0, Loss: 0.35011526942253113
#
# Average loss: 0.3644, Accuracy: 696.0/790 (88%)
#
#
# Average loss: 0.4477, Accuracy: 2507.0/2940 (85%)
#
# Epoch: 10 	Training Accuracy: 88.10%
# Validation Accuracy: 85.27%
# Batch: 0, Loss: 0.3999093770980835
#
# Average loss: 0.3410, Accuracy: 700.0/790 (89%)
#
#
# Average loss: 0.4284, Accuracy: 2535.0/2940 (86%)
#
# Epoch: 11 	Training Accuracy: 88.61%
# Validation Accuracy: 86.22%
# Batch: 0, Loss: 0.285868376493454
#
# Average loss: 0.3199, Accuracy: 707.0/790 (89%)
#
#
# Average loss: 0.4206, Accuracy: 2545.0/2940 (87%)
#
# Epoch: 12 	Training Accuracy: 89.49%
# Validation Accuracy: 86.56%
# Batch: 0, Loss: 0.24008621275424957
#
# Average loss: 0.3019, Accuracy: 711.0/790 (90%)
#
#
# Average loss: 0.3997, Accuracy: 2567.0/2940 (87%)
#
# Epoch: 13 	Training Accuracy: 90.00%
# Validation Accuracy: 87.31%
# Batch: 0, Loss: 0.35713785886764526
#
# Average loss: 0.2923, Accuracy: 711.0/790 (90%)
#
#
# Average loss: 0.3897, Accuracy: 2585.0/2940 (88%)
#
# Epoch: 14 	Training Accuracy: 90.00%
# Validation Accuracy: 87.93%
# Batch: 0, Loss: 0.33487364649772644
#
# Average loss: 0.2788, Accuracy: 715.0/790 (91%)
#
#
# Average loss: 0.3798, Accuracy: 2593.0/2940 (88%)
#
# Epoch: 15 	Training Accuracy: 90.51%
# Validation Accuracy: 88.20%
# Batch: 0, Loss: 0.241496279835701
#
# Average loss: 0.2704, Accuracy: 720.0/790 (91%)
#
#
# Average loss: 0.3728, Accuracy: 2589.0/2940 (88%)
#
# Epoch: 16 	Training Accuracy: 91.14%
# Validation Accuracy: 88.06%
# Batch: 0, Loss: 0.2739306390285492
#
# Average loss: 0.2677, Accuracy: 725.0/790 (92%)
#
#
# Average loss: 0.3723, Accuracy: 2586.0/2940 (88%)
#
# Epoch: 17 	Training Accuracy: 91.77%
# Validation Accuracy: 87.96%
# Batch: 0, Loss: 0.2596530616283417
#
# Average loss: 0.2518, Accuracy: 730.0/790 (92%)
#
#
# Average loss: 0.3601, Accuracy: 2595.0/2940 (88%)
#
# Epoch: 18 	Training Accuracy: 92.41%
# Validation Accuracy: 88.27%
# Batch: 0, Loss: 0.30998462438583374
#
# Average loss: 0.2477, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.3558, Accuracy: 2595.0/2940 (88%)
#
# Epoch: 19 	Training Accuracy: 92.15%
# Validation Accuracy: 88.27%
#
# Average loss: 0.2477, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.3497, Accuracy: 4318.0/4861 (89%)
#
# Final Training Accuracy (New Data): 0.9215
# Final Test Accuracy (New Data): 0.8883
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 43 =========================
# Batch: 0, Loss: 1.6100854873657227
#
# Average loss: 1.6016, Accuracy: 160.0/790 (20%)
#
#
# Average loss: 1.6021, Accuracy: 588.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.25%
# Validation Accuracy: 20.00%
# Batch: 0, Loss: 1.6024032831192017
#
# Average loss: 1.5824, Accuracy: 479.0/790 (61%)
#
#
# Average loss: 1.5845, Accuracy: 1709.0/2940 (58%)
#
# Epoch: 1 	Training Accuracy: 60.63%
# Validation Accuracy: 58.13%
# Batch: 0, Loss: 1.582168698310852
#
# Average loss: 1.5407, Accuracy: 343.0/790 (43%)
#
#
# Average loss: 1.5461, Accuracy: 1189.0/2940 (40%)
#
# Epoch: 2 	Training Accuracy: 43.42%
# Validation Accuracy: 40.44%
# Batch: 0, Loss: 1.542593002319336
#
# Average loss: 1.4590, Accuracy: 376.0/790 (48%)
#
#
# Average loss: 1.4687, Accuracy: 1284.0/2940 (44%)
#
# Epoch: 3 	Training Accuracy: 47.59%
# Validation Accuracy: 43.67%
# Batch: 0, Loss: 1.4631882905960083
#
# Average loss: 1.3250, Accuracy: 437.0/790 (55%)
#
#
# Average loss: 1.3408, Accuracy: 1632.0/2940 (56%)
#
# Epoch: 4 	Training Accuracy: 55.32%
# Validation Accuracy: 55.51%
# Batch: 0, Loss: 1.349690318107605
#
# Average loss: 1.1519, Accuracy: 515.0/790 (65%)
#
#
# Average loss: 1.1763, Accuracy: 1853.0/2940 (63%)
#
# Epoch: 5 	Training Accuracy: 65.19%
# Validation Accuracy: 63.03%
# Batch: 0, Loss: 1.184295892715454
#
# Average loss: 0.9801, Accuracy: 528.0/790 (67%)
#
#
# Average loss: 1.0104, Accuracy: 1955.0/2940 (66%)
#
# Epoch: 6 	Training Accuracy: 66.84%
# Validation Accuracy: 66.50%
# Batch: 0, Loss: 0.9595719575881958
#
# Average loss: 0.8263, Accuracy: 560.0/790 (71%)
#
#
# Average loss: 0.8694, Accuracy: 2039.0/2940 (69%)
#
# Epoch: 7 	Training Accuracy: 70.89%
# Validation Accuracy: 69.35%
# Batch: 0, Loss: 0.760276198387146
#
# Average loss: 0.6999, Accuracy: 597.0/790 (76%)
#
#
# Average loss: 0.7501, Accuracy: 2132.0/2940 (73%)
#
# Epoch: 8 	Training Accuracy: 75.57%
# Validation Accuracy: 72.52%
# Batch: 0, Loss: 0.729792058467865
#
# Average loss: 0.5934, Accuracy: 618.0/790 (78%)
#
#
# Average loss: 0.6479, Accuracy: 2232.0/2940 (76%)
#
# Epoch: 9 	Training Accuracy: 78.23%
# Validation Accuracy: 75.92%
# Batch: 0, Loss: 0.6266489624977112
#
# Average loss: 0.5151, Accuracy: 647.0/790 (82%)
#
#
# Average loss: 0.5780, Accuracy: 2332.0/2940 (79%)
#
# Epoch: 10 	Training Accuracy: 81.90%
# Validation Accuracy: 79.32%
# Batch: 0, Loss: 0.5675487518310547
#
# Average loss: 0.4530, Accuracy: 659.0/790 (83%)
#
#
# Average loss: 0.5132, Accuracy: 2388.0/2940 (81%)
#
# Epoch: 11 	Training Accuracy: 83.42%
# Validation Accuracy: 81.22%
# Batch: 0, Loss: 0.4662629961967468
#
# Average loss: 0.4037, Accuracy: 682.0/790 (86%)
#
#
# Average loss: 0.4647, Accuracy: 2468.0/2940 (84%)
#
# Epoch: 12 	Training Accuracy: 86.33%
# Validation Accuracy: 83.95%
# Batch: 0, Loss: 0.46007177233695984
#
# Average loss: 0.3678, Accuracy: 695.0/790 (88%)
#
#
# Average loss: 0.4341, Accuracy: 2501.0/2940 (85%)
#
# Epoch: 13 	Training Accuracy: 87.97%
# Validation Accuracy: 85.07%
# Batch: 0, Loss: 0.37416088581085205
#
# Average loss: 0.3390, Accuracy: 706.0/790 (89%)
#
#
# Average loss: 0.4063, Accuracy: 2525.0/2940 (86%)
#
# Epoch: 14 	Training Accuracy: 89.37%
# Validation Accuracy: 85.88%
# Batch: 0, Loss: 0.33655473589897156
#
# Average loss: 0.3163, Accuracy: 709.0/790 (90%)
#
#
# Average loss: 0.3847, Accuracy: 2544.0/2940 (87%)
#
# Epoch: 15 	Training Accuracy: 89.75%
# Validation Accuracy: 86.53%
# Batch: 0, Loss: 0.36895057559013367
#
# Average loss: 0.2987, Accuracy: 710.0/790 (90%)
#
#
# Average loss: 0.3737, Accuracy: 2551.0/2940 (87%)
#
# Epoch: 16 	Training Accuracy: 89.87%
# Validation Accuracy: 86.77%
# Batch: 0, Loss: 0.33793219923973083
#
# Average loss: 0.2815, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.3532, Accuracy: 2581.0/2940 (88%)
#
# Epoch: 17 	Training Accuracy: 91.01%
# Validation Accuracy: 87.79%
# Batch: 0, Loss: 0.22780558466911316
#
# Average loss: 0.2670, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.3435, Accuracy: 2594.0/2940 (88%)
#
# Epoch: 18 	Training Accuracy: 91.01%
# Validation Accuracy: 88.23%
# Batch: 0, Loss: 0.28536686301231384
#
# Average loss: 0.2610, Accuracy: 715.0/790 (91%)
#
#
# Average loss: 0.3450, Accuracy: 2605.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 90.51%
# Validation Accuracy: 88.61%
#
# Average loss: 0.2610, Accuracy: 715.0/790 (91%)
#
#
# Average loss: 0.3516, Accuracy: 4262.0/4861 (88%)
#
# Final Training Accuracy (New Data): 0.9051
# Final Test Accuracy (New Data): 0.8768
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 23 =========================
# Batch: 0, Loss: 1.6195330619812012
#
# Average loss: 1.6098, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6116, Accuracy: 551.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6113131046295166
#
# Average loss: 1.6094, Accuracy: 159.0/790 (20%)
#
#
# Average loss: 1.6104, Accuracy: 552.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.13%
# Validation Accuracy: 18.78%
# Batch: 0, Loss: 1.6083993911743164
#
# Average loss: 1.6084, Accuracy: 196.0/790 (25%)
#
#
# Average loss: 1.6090, Accuracy: 659.0/2940 (22%)
#
# Epoch: 2 	Training Accuracy: 24.81%
# Validation Accuracy: 22.41%
# Batch: 0, Loss: 1.6083240509033203
#
# Average loss: 1.6044, Accuracy: 243.0/790 (31%)
#
#
# Average loss: 1.6047, Accuracy: 831.0/2940 (28%)
#
# Epoch: 3 	Training Accuracy: 30.76%
# Validation Accuracy: 28.27%
# Batch: 0, Loss: 1.6030113697052002
#
# Average loss: 1.5890, Accuracy: 403.0/790 (51%)
#
#
# Average loss: 1.5897, Accuracy: 1446.0/2940 (49%)
#
# Epoch: 4 	Training Accuracy: 51.01%
# Validation Accuracy: 49.18%
# Batch: 0, Loss: 1.5881720781326294
#
# Average loss: 1.5398, Accuracy: 446.0/790 (56%)
#
#
# Average loss: 1.5436, Accuracy: 1569.0/2940 (53%)
#
# Epoch: 5 	Training Accuracy: 56.46%
# Validation Accuracy: 53.37%
# Batch: 0, Loss: 1.542777419090271
#
# Average loss: 1.4413, Accuracy: 401.0/790 (51%)
#
#
# Average loss: 1.4544, Accuracy: 1403.0/2940 (48%)
#
# Epoch: 6 	Training Accuracy: 50.76%
# Validation Accuracy: 47.72%
# Batch: 0, Loss: 1.4510387182235718
#
# Average loss: 1.2910, Accuracy: 457.0/790 (58%)
#
#
# Average loss: 1.3153, Accuracy: 1662.0/2940 (57%)
#
# Epoch: 7 	Training Accuracy: 57.85%
# Validation Accuracy: 56.53%
# Batch: 0, Loss: 1.2969752550125122
#
# Average loss: 1.0693, Accuracy: 585.0/790 (74%)
#
#
# Average loss: 1.0992, Accuracy: 2145.0/2940 (73%)
#
# Epoch: 8 	Training Accuracy: 74.05%
# Validation Accuracy: 72.96%
# Batch: 0, Loss: 1.0570759773254395
#
# Average loss: 0.8186, Accuracy: 647.0/790 (82%)
#
#
# Average loss: 0.8511, Accuracy: 2340.0/2940 (80%)
#
# Epoch: 9 	Training Accuracy: 81.90%
# Validation Accuracy: 79.59%
# Batch: 0, Loss: 0.8207938075065613
#
# Average loss: 0.6289, Accuracy: 657.0/790 (83%)
#
#
# Average loss: 0.6691, Accuracy: 2380.0/2940 (81%)
#
# Epoch: 10 	Training Accuracy: 83.16%
# Validation Accuracy: 80.95%
# Batch: 0, Loss: 0.5196897983551025
#
# Average loss: 0.5129, Accuracy: 663.0/790 (84%)
#
#
# Average loss: 0.5567, Accuracy: 2460.0/2940 (84%)
#
# Epoch: 11 	Training Accuracy: 83.92%
# Validation Accuracy: 83.67%
# Batch: 0, Loss: 0.47933658957481384
#
# Average loss: 0.4413, Accuracy: 675.0/790 (85%)
#
#
# Average loss: 0.4961, Accuracy: 2488.0/2940 (85%)
#
# Epoch: 12 	Training Accuracy: 85.44%
# Validation Accuracy: 84.63%
# Batch: 0, Loss: 0.39652219414711
#
# Average loss: 0.3979, Accuracy: 685.0/790 (87%)
#
#
# Average loss: 0.4624, Accuracy: 2528.0/2940 (86%)
#
# Epoch: 13 	Training Accuracy: 86.71%
# Validation Accuracy: 85.99%
# Batch: 0, Loss: 0.38730373978614807
#
# Average loss: 0.3686, Accuracy: 685.0/790 (87%)
#
#
# Average loss: 0.4379, Accuracy: 2531.0/2940 (86%)
#
# Epoch: 14 	Training Accuracy: 86.71%
# Validation Accuracy: 86.09%
# Batch: 0, Loss: 0.3176009953022003
#
# Average loss: 0.3395, Accuracy: 695.0/790 (88%)
#
#
# Average loss: 0.4199, Accuracy: 2557.0/2940 (87%)
#
# Epoch: 15 	Training Accuracy: 87.97%
# Validation Accuracy: 86.97%
# Batch: 0, Loss: 0.3835751712322235
#
# Average loss: 0.3192, Accuracy: 700.0/790 (89%)
#
#
# Average loss: 0.4077, Accuracy: 2556.0/2940 (87%)
#
# Epoch: 16 	Training Accuracy: 88.61%
# Validation Accuracy: 86.94%
# Batch: 0, Loss: 0.3684588074684143
#
# Average loss: 0.2987, Accuracy: 707.0/790 (89%)
#
#
# Average loss: 0.3957, Accuracy: 2578.0/2940 (88%)
#
# Epoch: 17 	Training Accuracy: 89.49%
# Validation Accuracy: 87.69%
# Batch: 0, Loss: 0.19503124058246613
#
# Average loss: 0.2805, Accuracy: 715.0/790 (91%)
#
#
# Average loss: 0.3882, Accuracy: 2576.0/2940 (88%)
#
# Epoch: 18 	Training Accuracy: 90.51%
# Validation Accuracy: 87.62%
# Batch: 0, Loss: 0.29744261503219604
#
# Average loss: 0.2636, Accuracy: 718.0/790 (91%)
#
#
# Average loss: 0.3771, Accuracy: 2589.0/2940 (88%)
#
# Epoch: 19 	Training Accuracy: 90.89%
# Validation Accuracy: 88.06%
#
# Average loss: 0.2636, Accuracy: 718.0/790 (91%)
#
#
# Average loss: 0.3589, Accuracy: 4288.0/4861 (88%)
#
# Final Training Accuracy (New Data): 0.9089
# Final Test Accuracy (New Data): 0.8821
# Training for data percentage: 0.05:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 6 =========================
# Batch: 0, Loss: 1.6117595434188843
#
# Average loss: 1.6095, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6090, Accuracy: 655.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.60931396484375
#
# Average loss: 1.6096, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6086, Accuracy: 655.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6103156805038452
#
# Average loss: 1.6040, Accuracy: 455.0/1320 (34%)
#
#
# Average loss: 1.6037, Accuracy: 1028.0/2940 (35%)
#
# Epoch: 2 	Training Accuracy: 34.47%
# Validation Accuracy: 34.97%
# Batch: 0, Loss: 1.6034879684448242
#
# Average loss: 1.5052, Accuracy: 495.0/1320 (38%)
#
#
# Average loss: 1.5034, Accuracy: 1154.0/2940 (39%)
#
# Epoch: 3 	Training Accuracy: 37.50%
# Validation Accuracy: 39.25%
# Batch: 0, Loss: 1.5107890367507935
#
# Average loss: 1.1643, Accuracy: 935.0/1320 (71%)
#
#
# Average loss: 1.1600, Accuracy: 2067.0/2940 (70%)
#
# Epoch: 4 	Training Accuracy: 70.83%
# Validation Accuracy: 70.31%
# Batch: 0, Loss: 1.1534810066223145
#
# Average loss: 0.7364, Accuracy: 1058.0/1320 (80%)
#
#
# Average loss: 0.7566, Accuracy: 2312.0/2940 (79%)
#
# Epoch: 5 	Training Accuracy: 80.15%
# Validation Accuracy: 78.64%
# Batch: 0, Loss: 0.6916645765304565
#
# Average loss: 0.5125, Accuracy: 1082.0/1320 (82%)
#
#
# Average loss: 0.5555, Accuracy: 2363.0/2940 (80%)
#
# Epoch: 6 	Training Accuracy: 81.97%
# Validation Accuracy: 80.37%
# Batch: 0, Loss: 0.5377072691917419
#
# Average loss: 0.4027, Accuracy: 1132.0/1320 (86%)
#
#
# Average loss: 0.4500, Accuracy: 2466.0/2940 (84%)
#
# Epoch: 7 	Training Accuracy: 85.76%
# Validation Accuracy: 83.88%
# Batch: 0, Loss: 0.3533908426761627
#
# Average loss: 0.3366, Accuracy: 1162.0/1320 (88%)
#
#
# Average loss: 0.4003, Accuracy: 2522.0/2940 (86%)
#
# Epoch: 8 	Training Accuracy: 88.03%
# Validation Accuracy: 85.78%
# Batch: 0, Loss: 0.42095670104026794
#
# Average loss: 0.2978, Accuracy: 1176.0/1320 (89%)
#
#
# Average loss: 0.3657, Accuracy: 2560.0/2940 (87%)
#
# Epoch: 9 	Training Accuracy: 89.09%
# Validation Accuracy: 87.07%
# Batch: 0, Loss: 0.32133162021636963
#
# Average loss: 0.2802, Accuracy: 1184.0/1320 (90%)
#
#
# Average loss: 0.3445, Accuracy: 2597.0/2940 (88%)
#
# Epoch: 10 	Training Accuracy: 89.70%
# Validation Accuracy: 88.33%
# Batch: 0, Loss: 0.30129262804985046
#
# Average loss: 0.2904, Accuracy: 1182.0/1320 (90%)
#
#
# Average loss: 0.3632, Accuracy: 2590.0/2940 (88%)
#
# Epoch: 11 	Training Accuracy: 89.55%
# Validation Accuracy: 88.10%
# Batch: 0, Loss: 0.3180849552154541
#
# Average loss: 0.2560, Accuracy: 1190.0/1320 (90%)
#
#
# Average loss: 0.3300, Accuracy: 2599.0/2940 (88%)
#
# Epoch: 12 	Training Accuracy: 90.15%
# Validation Accuracy: 88.40%
# Batch: 0, Loss: 0.2683962285518646
#
# Average loss: 0.2316, Accuracy: 1216.0/1320 (92%)
#
#
# Average loss: 0.3055, Accuracy: 2645.0/2940 (90%)
#
# Epoch: 13 	Training Accuracy: 92.12%
# Validation Accuracy: 89.97%
# Batch: 0, Loss: 0.25219547748565674
#
# Average loss: 0.2275, Accuracy: 1210.0/1320 (92%)
#
#
# Average loss: 0.3056, Accuracy: 2649.0/2940 (90%)
#
# Epoch: 14 	Training Accuracy: 91.67%
# Validation Accuracy: 90.10%
# Batch: 0, Loss: 0.23661677539348602
#
# Average loss: 0.2313, Accuracy: 1216.0/1320 (92%)
#
#
# Average loss: 0.2993, Accuracy: 2647.0/2940 (90%)
#
# Epoch: 15 	Training Accuracy: 92.12%
# Validation Accuracy: 90.03%
# Batch: 0, Loss: 0.2448088675737381
#
# Average loss: 0.2239, Accuracy: 1214.0/1320 (92%)
#
#
# Average loss: 0.3107, Accuracy: 2640.0/2940 (90%)
#
# Epoch: 16 	Training Accuracy: 91.97%
# Validation Accuracy: 89.80%
# Batch: 0, Loss: 0.1401699334383011
#
# Average loss: 0.2100, Accuracy: 1226.0/1320 (93%)
#
#
# Average loss: 0.2906, Accuracy: 2660.0/2940 (90%)
#
# Epoch: 17 	Training Accuracy: 92.88%
# Validation Accuracy: 90.48%
# Batch: 0, Loss: 0.32098108530044556
#
# Average loss: 0.2044, Accuracy: 1223.0/1320 (93%)
#
#
# Average loss: 0.2959, Accuracy: 2658.0/2940 (90%)
#
# Epoch: 18 	Training Accuracy: 92.65%
# Validation Accuracy: 90.41%
# Batch: 0, Loss: 0.18004338443279266
#
# Average loss: 0.2020, Accuracy: 1227.0/1320 (93%)
#
#
# Average loss: 0.2935, Accuracy: 2659.0/2940 (90%)
#
# Epoch: 19 	Training Accuracy: 92.95%
# Validation Accuracy: 90.44%
#
# Average loss: 0.2020, Accuracy: 1227.0/1320 (93%)
#
#
# Average loss: 0.2750, Accuracy: 4432.0/4861 (91%)
#
# Final Training Accuracy (New Data): 0.9295
# Final Test Accuracy (New Data): 0.9117
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
# ...
#
#
# Average loss: 0.1033, Accuracy: 2838.0/2940 (97%)
#
# Epoch: 14 	Training Accuracy: 97.25%
# Validation Accuracy: 96.53%
# Batch: 0, Loss: 0.09690464287996292
# Batch: 20, Loss: 0.10130207985639572
# Batch: 40, Loss: 0.038601867854595184
# Batch: 60, Loss: 0.11217617988586426
# Batch: 80, Loss: 0.1286395639181137
# Batch: 100, Loss: 0.08095794171094894
# Batch: 120, Loss: 0.06499285995960236
# Batch: 140, Loss: 0.017585057765245438
# Batch: 160, Loss: 0.11558154970407486
# Batch: 180, Loss: 0.05704526603221893
# Batch: 200, Loss: 0.0828564241528511
#
# Average loss: 0.0808, Accuracy: 25340.0/26038 (97%)
#
#
# Average loss: 0.1048, Accuracy: 2839.0/2940 (97%)
#
# Epoch: 15 	Training Accuracy: 97.32%
# Validation Accuracy: 96.56%
# Batch: 0, Loss: 0.05131005123257637
# Batch: 20, Loss: 0.05829501897096634
# Batch: 40, Loss: 0.16559839248657227
# Batch: 60, Loss: 0.1594102382659912
# Batch: 80, Loss: 0.06855995208024979
# Batch: 100, Loss: 0.0428774431347847
# Batch: 120, Loss: 0.11744839698076248
# Batch: 140, Loss: 0.06767035275697708
# Batch: 160, Loss: 0.04014471918344498
# Batch: 180, Loss: 0.1268201768398285
# Batch: 200, Loss: 0.1457001119852066
#
# Average loss: 0.0751, Accuracy: 25403.0/26038 (98%)
#
#
# Average loss: 0.0986, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 16 	Training Accuracy: 97.56%
# Validation Accuracy: 96.97%
# Early stopping invoked.
#
# Average loss: 0.0807, Accuracy: 25366.0/26038 (97%)
#
#
# Average loss: 0.0807, Accuracy: 4731.0/4861 (97%)
#
# Final Training Accuracy (New Data): 0.9742
# Final Test Accuracy (New Data): 0.9733
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 51 =========================
# Batch: 0, Loss: 1.6012206077575684
# Batch: 20, Loss: 1.558289885520935
# Batch: 40, Loss: 1.3170615434646606
# Batch: 60, Loss: 0.7826000452041626
# Batch: 80, Loss: 0.5060900449752808
# Batch: 100, Loss: 0.3877299427986145
# Batch: 120, Loss: 0.3128651976585388
# Batch: 140, Loss: 0.31100526452064514
# Batch: 160, Loss: 0.25003430247306824
# Batch: 180, Loss: 0.33845579624176025
# Batch: 200, Loss: 0.26249006390571594
#
# Average loss: 0.2942, Accuracy: 23325.0/26038 (90%)
#
#
# Average loss: 0.3083, Accuracy: 2635.0/2940 (90%)
#
# Epoch: 0 	Training Accuracy: 89.58%
# Validation Accuracy: 89.63%
# Batch: 0, Loss: 0.3004676401615143
# Batch: 20, Loss: 0.2741208076477051
# Batch: 40, Loss: 0.21770010888576508
# Batch: 60, Loss: 0.19003212451934814
# Batch: 80, Loss: 0.22800272703170776
# Batch: 100, Loss: 0.2539409399032593
# Batch: 120, Loss: 0.3477827310562134
# Batch: 140, Loss: 0.2343519777059555
# Batch: 160, Loss: 0.15081673860549927
# Batch: 180, Loss: 0.18553239107131958
# Batch: 200, Loss: 0.22215503454208374
#
# Average loss: 0.2000, Accuracy: 24299.0/26038 (93%)
#
#
# Average loss: 0.2227, Accuracy: 2723.0/2940 (93%)
#
# Epoch: 1 	Training Accuracy: 93.32%
# Validation Accuracy: 92.62%
# Batch: 0, Loss: 0.263408899307251
# Batch: 20, Loss: 0.2183675765991211
# Batch: 40, Loss: 0.2913549542427063
# Batch: 60, Loss: 0.12382225692272186
# Batch: 80, Loss: 0.15149527788162231
# Batch: 100, Loss: 0.25679367780685425
# Batch: 120, Loss: 0.16574913263320923
# Batch: 140, Loss: 0.13944630324840546
# Batch: 160, Loss: 0.18979795277118683
# Batch: 180, Loss: 0.27534714341163635
# Batch: 200, Loss: 0.17972707748413086
#
# Average loss: 0.1640, Accuracy: 24627.0/26038 (95%)
#
#
# Average loss: 0.1916, Accuracy: 2759.0/2940 (94%)
#
# Epoch: 2 	Training Accuracy: 94.58%
# Validation Accuracy: 93.84%
# Batch: 0, Loss: 0.14855176210403442
# Batch: 20, Loss: 0.18412776291370392
# Batch: 40, Loss: 0.19337259232997894
# Batch: 60, Loss: 0.19895194470882416
# Batch: 80, Loss: 0.19314128160476685
# Batch: 100, Loss: 0.1203877180814743
# Batch: 120, Loss: 0.04857577383518219
# Batch: 140, Loss: 0.0867968201637268
# Batch: 160, Loss: 0.08913547545671463
# Batch: 180, Loss: 0.1748613566160202
# Batch: 200, Loss: 0.12317958474159241
#
# Average loss: 0.1766, Accuracy: 24490.0/26038 (94%)
#
#
# Average loss: 0.2047, Accuracy: 2738.0/2940 (93%)
#
# Epoch: 3 	Training Accuracy: 94.05%
# Validation Accuracy: 93.13%
# Batch: 0, Loss: 0.07821907103061676
# Batch: 20, Loss: 0.08468141406774521
# Batch: 40, Loss: 0.08941000699996948
# Batch: 60, Loss: 0.14035184681415558
# Batch: 80, Loss: 0.17793957889080048
# Batch: 100, Loss: 0.07852619141340256
# Batch: 120, Loss: 0.164911150932312
# Batch: 140, Loss: 0.15820248425006866
# Batch: 160, Loss: 0.18615087866783142
# Batch: 180, Loss: 0.10280823707580566
# Batch: 200, Loss: 0.12690088152885437
#
# Average loss: 0.1435, Accuracy: 24817.0/26038 (95%)
#
#
# Average loss: 0.1704, Accuracy: 2788.0/2940 (95%)
#
# Epoch: 4 	Training Accuracy: 95.31%
# Validation Accuracy: 94.83%
# Batch: 0, Loss: 0.11062222719192505
# Batch: 20, Loss: 0.10904537886381149
# Batch: 40, Loss: 0.0839461013674736
# Batch: 60, Loss: 0.07342426478862762
# Batch: 80, Loss: 0.12634634971618652
# Batch: 100, Loss: 0.2992737889289856
# Batch: 120, Loss: 0.06948798894882202
# Batch: 140, Loss: 0.14216579496860504
# Batch: 160, Loss: 0.12573154270648956
# Batch: 180, Loss: 0.10424838960170746
# Batch: 200, Loss: 0.10108057409524918
#
# Average loss: 0.1257, Accuracy: 24998.0/26038 (96%)
#
#
# Average loss: 0.1519, Accuracy: 2794.0/2940 (95%)
#
# Epoch: 5 	Training Accuracy: 96.01%
# Validation Accuracy: 95.03%
# Batch: 0, Loss: 0.11355243623256683
# Batch: 20, Loss: 0.12011068314313889
# Batch: 40, Loss: 0.2447899580001831
# Batch: 60, Loss: 0.1588810384273529
# Batch: 80, Loss: 0.16247349977493286
# Batch: 100, Loss: 0.06997054815292358
# Batch: 120, Loss: 0.10763832181692123
# Batch: 140, Loss: 0.08827460557222366
# Batch: 160, Loss: 0.1017213761806488
# Batch: 180, Loss: 0.13752485811710358
# Batch: 200, Loss: 0.2116144299507141
#
# Average loss: 0.1271, Accuracy: 24947.0/26038 (96%)
#
#
# Average loss: 0.1482, Accuracy: 2794.0/2940 (95%)
#
# Epoch: 6 	Training Accuracy: 95.81%
# Validation Accuracy: 95.03%
# Batch: 0, Loss: 0.08657819777727127
# Batch: 20, Loss: 0.09751629829406738
# Batch: 40, Loss: 0.15311740338802338
# Batch: 60, Loss: 0.095569908618927
# Batch: 80, Loss: 0.1970605105161667
# Batch: 100, Loss: 0.11401783674955368
# Batch: 120, Loss: 0.10631299763917923
# Batch: 140, Loss: 0.06547054648399353
# Batch: 160, Loss: 0.10603784769773483
# Batch: 180, Loss: 0.040554843842983246
# Batch: 200, Loss: 0.19135986268520355
#
# Average loss: 0.1180, Accuracy: 25008.0/26038 (96%)
#
#
# Average loss: 0.1428, Accuracy: 2802.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 96.04%
# Validation Accuracy: 95.31%
# Batch: 0, Loss: 0.14089198410511017
# Batch: 20, Loss: 0.1889156997203827
# Batch: 40, Loss: 0.1542588174343109
# Batch: 60, Loss: 0.170818492770195
# Batch: 80, Loss: 0.14968690276145935
# Batch: 100, Loss: 0.13750696182250977
# Batch: 120, Loss: 0.12598544359207153
# Batch: 140, Loss: 0.1282513290643692
# Batch: 160, Loss: 0.09678097814321518
# Batch: 180, Loss: 0.15118761360645294
# Batch: 200, Loss: 0.1328486204147339
#
# Average loss: 0.1187, Accuracy: 25002.0/26038 (96%)
#
#
# Average loss: 0.1472, Accuracy: 2805.0/2940 (95%)
#
# Epoch: 8 	Training Accuracy: 96.02%
# Validation Accuracy: 95.41%
# Batch: 0, Loss: 0.07133231312036514
# Batch: 20, Loss: 0.11672497540712357
# Batch: 40, Loss: 0.11124559491872787
# Batch: 60, Loss: 0.12870337069034576
# Batch: 80, Loss: 0.11940363049507141
# Batch: 100, Loss: 0.07706703245639801
# Batch: 120, Loss: 0.06688553094863892
# Batch: 140, Loss: 0.17068366706371307
# Batch: 160, Loss: 0.12357592582702637
# Batch: 180, Loss: 0.06751149147748947
# Batch: 200, Loss: 0.13405771553516388
#
# Average loss: 0.1118, Accuracy: 25064.0/26038 (96%)
#
#
# Average loss: 0.1375, Accuracy: 2809.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 96.26%
# Validation Accuracy: 95.54%
# Batch: 0, Loss: 0.138376384973526
# Batch: 20, Loss: 0.08468231558799744
# Batch: 40, Loss: 0.18328911066055298
# Batch: 60, Loss: 0.12244649231433868
# Batch: 80, Loss: 0.108816958963871
# Batch: 100, Loss: 0.08568091690540314
# Batch: 120, Loss: 0.22375965118408203
# Batch: 140, Loss: 0.06168399006128311
# Batch: 160, Loss: 0.07854235172271729
# Batch: 180, Loss: 0.07027634978294373
# Batch: 200, Loss: 0.05614820867776871
#
# Average loss: 0.1190, Accuracy: 24998.0/26038 (96%)
#
#
# Average loss: 0.1470, Accuracy: 2798.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 96.01%
# Validation Accuracy: 95.17%
# Batch: 0, Loss: 0.12136437743902206
# Batch: 20, Loss: 0.09250408411026001
# Batch: 40, Loss: 0.10869037359952927
# Batch: 60, Loss: 0.13282205164432526
# Batch: 80, Loss: 0.061437979340553284
# Batch: 100, Loss: 0.12320266664028168
# Batch: 120, Loss: 0.10211805254220963
# Batch: 140, Loss: 0.08036978542804718
# Batch: 160, Loss: 0.19071123003959656
# Batch: 180, Loss: 0.14196281135082245
# Batch: 200, Loss: 0.12209303677082062
#
# Average loss: 0.1126, Accuracy: 25100.0/26038 (96%)
#
#
# Average loss: 0.1409, Accuracy: 2810.0/2940 (96%)
#
# Epoch: 11 	Training Accuracy: 96.40%
# Validation Accuracy: 95.58%
# Batch: 0, Loss: 0.07039234042167664
# Batch: 20, Loss: 0.10128547996282578
# Batch: 40, Loss: 0.10240983963012695
# Batch: 60, Loss: 0.1258891373872757
# Batch: 80, Loss: 0.045135725289583206
# Batch: 100, Loss: 0.11230108141899109
# Batch: 120, Loss: 0.11783204227685928
# Batch: 140, Loss: 0.12046900391578674
# Batch: 160, Loss: 0.06340903043746948
# Batch: 180, Loss: 0.11664196848869324
# Batch: 200, Loss: 0.12477631121873856
#
# Average loss: 0.1081, Accuracy: 25100.0/26038 (96%)
#
#
# Average loss: 0.1338, Accuracy: 2812.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 96.40%
# Validation Accuracy: 95.65%
# Batch: 0, Loss: 0.1652926653623581
# Batch: 20, Loss: 0.15958784520626068
# Batch: 40, Loss: 0.23156170547008514
# Batch: 60, Loss: 0.21447429060935974
# Batch: 80, Loss: 0.04745769128203392
# Batch: 100, Loss: 0.09174199402332306
# Batch: 120, Loss: 0.13678336143493652
# Batch: 140, Loss: 0.13173861801624298
# Batch: 160, Loss: 0.07347958534955978
# Batch: 180, Loss: 0.15325839817523956
# Batch: 200, Loss: 0.193752720952034
#
# Average loss: 0.1066, Accuracy: 25160.0/26038 (97%)
#
#
# Average loss: 0.1344, Accuracy: 2814.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 96.63%
# Validation Accuracy: 95.71%
# Batch: 0, Loss: 0.059956878423690796
# Batch: 20, Loss: 0.16444340348243713
# Batch: 40, Loss: 0.0513538233935833
# Batch: 60, Loss: 0.10538731515407562
# Batch: 80, Loss: 0.07608529180288315
# Batch: 100, Loss: 0.10891454666852951
# Batch: 120, Loss: 0.08734554052352905
# Batch: 140, Loss: 0.06890957057476044
# Batch: 160, Loss: 0.17614737153053284
# Batch: 180, Loss: 0.12824556231498718
# Batch: 200, Loss: 0.09863433986902237
#
# Average loss: 0.1078, Accuracy: 25131.0/26038 (97%)
#
#
# Average loss: 0.1366, Accuracy: 2812.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 96.52%
# Validation Accuracy: 95.65%
# Batch: 0, Loss: 0.1284334510564804
# Batch: 20, Loss: 0.059347737580537796
# Batch: 40, Loss: 0.07500480115413666
# Batch: 60, Loss: 0.03483494371175766
# Batch: 80, Loss: 0.07579974830150604
# Batch: 100, Loss: 0.13903233408927917
# Batch: 120, Loss: 0.12453266233205795
# Batch: 140, Loss: 0.07690062373876572
# Batch: 160, Loss: 0.07863679528236389
# Batch: 180, Loss: 0.07510019838809967
# Batch: 200, Loss: 0.02834615856409073
#
# Average loss: 0.1122, Accuracy: 25110.0/26038 (96%)
#
#
# Average loss: 0.1472, Accuracy: 2810.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 96.44%
# Validation Accuracy: 95.58%
# Batch: 0, Loss: 0.15845772624015808
# Batch: 20, Loss: 0.0897819772362709
# Batch: 40, Loss: 0.11293414980173111
# Batch: 60, Loss: 0.1398802548646927
# Batch: 80, Loss: 0.0756821408867836
# Batch: 100, Loss: 0.12241823971271515
# Batch: 120, Loss: 0.04962603375315666
# Batch: 140, Loss: 0.07177525013685226
# Batch: 160, Loss: 0.10704242438077927
# Batch: 180, Loss: 0.08428853005170822
# Batch: 200, Loss: 0.10642088949680328
#
# Average loss: 0.1073, Accuracy: 25104.0/26038 (96%)
#
#
# Average loss: 0.1335, Accuracy: 2805.0/2940 (95%)
#
# Epoch: 16 	Training Accuracy: 96.41%
# Validation Accuracy: 95.41%
# Batch: 0, Loss: 0.08302629739046097
# Batch: 20, Loss: 0.07987197488546371
# Batch: 40, Loss: 0.12336717545986176
# Batch: 60, Loss: 0.1252528727054596
# Batch: 80, Loss: 0.16410160064697266
# Batch: 100, Loss: 0.17279207706451416
# Batch: 120, Loss: 0.0866725817322731
# Batch: 140, Loss: 0.09304603189229965
# Batch: 160, Loss: 0.08382099121809006
# Batch: 180, Loss: 0.05863017961382866
# Batch: 200, Loss: 0.0908743143081665
#
# Average loss: 0.1031, Accuracy: 25152.0/26038 (97%)
#
#
# Average loss: 0.1322, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 96.60%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.04485301673412323
# Batch: 20, Loss: 0.17743828892707825
# Batch: 40, Loss: 0.07909885793924332
# Batch: 60, Loss: 0.14635232090950012
# Batch: 80, Loss: 0.11736692488193512
# Batch: 100, Loss: 0.055582884699106216
# Batch: 120, Loss: 0.03948087617754936
# Batch: 140, Loss: 0.10930709540843964
# Batch: 160, Loss: 0.11575503647327423
# Batch: 180, Loss: 0.10486240684986115
# Batch: 200, Loss: 0.18599049746990204
#
# Average loss: 0.1001, Accuracy: 25175.0/26038 (97%)
#
#
# Average loss: 0.1322, Accuracy: 2814.0/2940 (96%)
#
# Epoch: 18 	Training Accuracy: 96.69%
# Validation Accuracy: 95.71%
# Batch: 0, Loss: 0.06665153801441193
# Batch: 20, Loss: 0.09741047024726868
# Batch: 40, Loss: 0.11261739581823349
# Batch: 60, Loss: 0.05881602689623833
# Batch: 80, Loss: 0.09336906671524048
# Batch: 100, Loss: 0.14503081142902374
# Batch: 120, Loss: 0.13020843267440796
# Batch: 140, Loss: 0.15297167003154755
# Batch: 160, Loss: 0.08519993722438812
# Batch: 180, Loss: 0.12673310935497284
# Batch: 200, Loss: 0.08689048141241074
#
# Average loss: 0.0985, Accuracy: 25203.0/26038 (97%)
#
#
# Average loss: 0.1290, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 19 	Training Accuracy: 96.79%
# Validation Accuracy: 95.85%
#
# Average loss: 0.0985, Accuracy: 25203.0/26038 (97%)
#
#
# Average loss: 0.1123, Accuracy: 4678.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9679
# Final Test Accuracy (New Data): 0.9624
# Percentage: 0.01, Seed: 10, Epochs taken: 11
# Percentage: 0.01, Seed: 20, Epochs taken: 20
# Percentage: 0.01, Seed: 30, Epochs taken: 16
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 11
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 20
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 7
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 9
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 19
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 20
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 14
# Percentage: 1, Seed: 20, Epochs taken: 16
# Percentage: 1, Seed: 30, Epochs taken: 20
# Percentage: 1, Seed: 40, Epochs taken: 17
# Percentage: 1, Seed: 50, Epochs taken: 20

# %% [markdown]
# ## Only heads and data for new classes

# %% [markdown]
# now with balanced classes

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.0001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test_finetune = {}
results_train_finetune = {}
best_models = {}
data_loaders = {}
epochs_taken_finetune = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Processing percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []
    
    for seed in tqdm(seed_set, desc=f'Running seeds for {perc} data', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")

                # Copying model
        model_new = copy.deepcopy(model)

        # Calculate the output size from the pool layer dynamically
        # You would replace this with the actual size based on your model's architecture
        # model_new.fc_1 = nn.Linear(576, 128)
    
        # Reinitialize the second fully connected layer
        model_new.fc_2 = nn.Linear(128, 5)
        
        # Ensure the softmax layer matches the number of classes (if used)
        model_new.softmax = nn.Softmax(dim=1)
        
        model_new.to(device)
        
        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)
        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test_finetune[perc] = test_accuracies
    results_train_finetune[perc] = train_accuracies
    epochs_taken_finetune[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken_finetune[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Running seeds for 0.01 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 70 =========================
# Batch: 0, Loss: 1.7290277481079102
#
# Average loss: 1.7285, Accuracy: 38.0/260 (15%)
#
#
# Average loss: 1.7388, Accuracy: 327.0/2940 (11%)
#
# Epoch: 0 	Training Accuracy: 14.62%
# Validation Accuracy: 11.12%
# Batch: 0, Loss: 1.7123712301254272
#
# Average loss: 1.7049, Accuracy: 43.0/260 (17%)
#
#
# Average loss: 1.7167, Accuracy: 393.0/2940 (13%)
#
# Epoch: 1 	Training Accuracy: 16.54%
# Validation Accuracy: 13.37%
# Batch: 0, Loss: 1.6955991983413696
#
# Average loss: 1.6832, Accuracy: 46.0/260 (18%)
#
#
# Average loss: 1.6960, Accuracy: 465.0/2940 (16%)
#
# Epoch: 2 	Training Accuracy: 17.69%
# Validation Accuracy: 15.82%
# Batch: 0, Loss: 1.661901593208313
#
# Average loss: 1.6619, Accuracy: 55.0/260 (21%)
#
#
# Average loss: 1.6753, Accuracy: 534.0/2940 (18%)
#
# Epoch: 3 	Training Accuracy: 21.15%
# Validation Accuracy: 18.16%
# Batch: 0, Loss: 1.646164894104004
#
# Average loss: 1.6410, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.6543, Accuracy: 586.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 22.31%
# Validation Accuracy: 19.93%
# Batch: 0, Loss: 1.6088498830795288
#
# Average loss: 1.6204, Accuracy: 62.0/260 (24%)
#
#
# Average loss: 1.6337, Accuracy: 640.0/2940 (22%)
#
# Epoch: 5 	Training Accuracy: 23.85%
# Validation Accuracy: 21.77%
# Batch: 0, Loss: 1.6126314401626587
#
# Average loss: 1.6002, Accuracy: 65.0/260 (25%)
#
#
# Average loss: 1.6137, Accuracy: 687.0/2940 (23%)
#
# Epoch: 6 	Training Accuracy: 25.00%
# Validation Accuracy: 23.37%
# Batch: 0, Loss: 1.6116114854812622
#
# Average loss: 1.5802, Accuracy: 70.0/260 (27%)
#
#
# Average loss: 1.5940, Accuracy: 731.0/2940 (25%)
#
# Epoch: 7 	Training Accuracy: 26.92%
# Validation Accuracy: 24.86%
# Batch: 0, Loss: 1.597875714302063
#
# Average loss: 1.5607, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.5744, Accuracy: 782.0/2940 (27%)
#
# Epoch: 8 	Training Accuracy: 28.46%
# Validation Accuracy: 26.60%
# Batch: 0, Loss: 1.575993537902832
#
# Average loss: 1.5420, Accuracy: 78.0/260 (30%)
#
#
# Average loss: 1.5557, Accuracy: 823.0/2940 (28%)
#
# Epoch: 9 	Training Accuracy: 30.00%
# Validation Accuracy: 27.99%
# Batch: 0, Loss: 1.5472288131713867
#
# Average loss: 1.5239, Accuracy: 82.0/260 (32%)
#
#
# Average loss: 1.5376, Accuracy: 874.0/2940 (30%)
#
# Epoch: 10 	Training Accuracy: 31.54%
# Validation Accuracy: 29.73%
# Batch: 0, Loss: 1.5269849300384521
#
# Average loss: 1.5054, Accuracy: 88.0/260 (34%)
#
#
# Average loss: 1.5190, Accuracy: 924.0/2940 (31%)
#
# Epoch: 11 	Training Accuracy: 33.85%
# Validation Accuracy: 31.43%
# Batch: 0, Loss: 1.502976417541504
#
# Average loss: 1.4870, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.5004, Accuracy: 968.0/2940 (33%)
#
# Epoch: 12 	Training Accuracy: 35.00%
# Validation Accuracy: 32.93%
# Batch: 0, Loss: 1.507403016090393
#
# Average loss: 1.4687, Accuracy: 94.0/260 (36%)
#
#
# Average loss: 1.4820, Accuracy: 1019.0/2940 (35%)
#
# Epoch: 13 	Training Accuracy: 36.15%
# Validation Accuracy: 34.66%
# Batch: 0, Loss: 1.4557929039001465
#
# Average loss: 1.4506, Accuracy: 102.0/260 (39%)
#
#
# Average loss: 1.4638, Accuracy: 1065.0/2940 (36%)
#
# Epoch: 14 	Training Accuracy: 39.23%
# Validation Accuracy: 36.22%
# Batch: 0, Loss: 1.4534692764282227
#
# Average loss: 1.4329, Accuracy: 105.0/260 (40%)
#
#
# Average loss: 1.4461, Accuracy: 1106.0/2940 (38%)
#
# Epoch: 15 	Training Accuracy: 40.38%
# Validation Accuracy: 37.62%
# Batch: 0, Loss: 1.4264177083969116
#
# Average loss: 1.4159, Accuracy: 109.0/260 (42%)
#
#
# Average loss: 1.4292, Accuracy: 1147.0/2940 (39%)
#
# Epoch: 16 	Training Accuracy: 41.92%
# Validation Accuracy: 39.01%
# Batch: 0, Loss: 1.3989139795303345
#
# Average loss: 1.3989, Accuracy: 115.0/260 (44%)
#
#
# Average loss: 1.4122, Accuracy: 1183.0/2940 (40%)
#
# Epoch: 17 	Training Accuracy: 44.23%
# Validation Accuracy: 40.24%
# Batch: 0, Loss: 1.4082385301589966
#
# Average loss: 1.3824, Accuracy: 119.0/260 (46%)
#
#
# Average loss: 1.3957, Accuracy: 1227.0/2940 (42%)
#
# Epoch: 18 	Training Accuracy: 45.77%
# Validation Accuracy: 41.73%
# Batch: 0, Loss: 1.3784314393997192
#
# Average loss: 1.3663, Accuracy: 120.0/260 (46%)
#
#
# Average loss: 1.3796, Accuracy: 1279.0/2940 (44%)
#
# Epoch: 19 	Training Accuracy: 46.15%
# Validation Accuracy: 43.50%
#
# Average loss: 1.3663, Accuracy: 120.0/260 (46%)
#
#
# Average loss: 1.3760, Accuracy: 2237.0/4861 (46%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 75 =========================
# Batch: 0, Loss: 1.4034972190856934
#
# Average loss: 1.3875, Accuracy: 128.0/260 (49%)
#
#
# Average loss: 1.3846, Accuracy: 1393.0/2940 (47%)
#
# Epoch: 0 	Training Accuracy: 49.23%
# Validation Accuracy: 47.38%
# Batch: 0, Loss: 1.4137049913406372
#
# Average loss: 1.3651, Accuracy: 138.0/260 (53%)
#
#
# Average loss: 1.3627, Accuracy: 1496.0/2940 (51%)
#
# Epoch: 1 	Training Accuracy: 53.08%
# Validation Accuracy: 50.88%
# Batch: 0, Loss: 1.3915750980377197
#
# Average loss: 1.3443, Accuracy: 145.0/260 (56%)
#
#
# Average loss: 1.3427, Accuracy: 1607.0/2940 (55%)
#
# Epoch: 2 	Training Accuracy: 55.77%
# Validation Accuracy: 54.66%
# Batch: 0, Loss: 1.3184974193572998
#
# Average loss: 1.3235, Accuracy: 153.0/260 (59%)
#
#
# Average loss: 1.3232, Accuracy: 1690.0/2940 (57%)
#
# Epoch: 3 	Training Accuracy: 58.85%
# Validation Accuracy: 57.48%
# Batch: 0, Loss: 1.3147304058074951
#
# Average loss: 1.3022, Accuracy: 156.0/260 (60%)
#
#
# Average loss: 1.3028, Accuracy: 1734.0/2940 (59%)
#
# Epoch: 4 	Training Accuracy: 60.00%
# Validation Accuracy: 58.98%
# Batch: 0, Loss: 1.2858506441116333
#
# Average loss: 1.2814, Accuracy: 159.0/260 (61%)
#
#
# Average loss: 1.2828, Accuracy: 1777.0/2940 (60%)
#
# Epoch: 5 	Training Accuracy: 61.15%
# Validation Accuracy: 60.44%
# Batch: 0, Loss: 1.2591543197631836
#
# Average loss: 1.2607, Accuracy: 166.0/260 (64%)
#
#
# Average loss: 1.2636, Accuracy: 1813.0/2940 (62%)
#
# Epoch: 6 	Training Accuracy: 63.85%
# Validation Accuracy: 61.67%
# Batch: 0, Loss: 1.2552968263626099
#
# Average loss: 1.2407, Accuracy: 166.0/260 (64%)
#
#
# Average loss: 1.2453, Accuracy: 1838.0/2940 (63%)
#
# Epoch: 7 	Training Accuracy: 63.85%
# Validation Accuracy: 62.52%
# Batch: 0, Loss: 1.2094781398773193
#
# Average loss: 1.2215, Accuracy: 173.0/260 (67%)
#
#
# Average loss: 1.2277, Accuracy: 1879.0/2940 (64%)
#
# Epoch: 8 	Training Accuracy: 66.54%
# Validation Accuracy: 63.91%
# Batch: 0, Loss: 1.2377468347549438
#
# Average loss: 1.2030, Accuracy: 173.0/260 (67%)
#
#
# Average loss: 1.2109, Accuracy: 1912.0/2940 (65%)
#
# Epoch: 9 	Training Accuracy: 66.54%
# Validation Accuracy: 65.03%
# Batch: 0, Loss: 1.1739593744277954
#
# Average loss: 1.1849, Accuracy: 178.0/260 (68%)
#
#
# Average loss: 1.1941, Accuracy: 1958.0/2940 (67%)
#
# Epoch: 10 	Training Accuracy: 68.46%
# Validation Accuracy: 66.60%
# Batch: 0, Loss: 1.2210618257522583
#
# Average loss: 1.1674, Accuracy: 181.0/260 (70%)
#
#
# Average loss: 1.1778, Accuracy: 1979.0/2940 (67%)
#
# Epoch: 11 	Training Accuracy: 69.62%
# Validation Accuracy: 67.31%
# Batch: 0, Loss: 1.1981029510498047
#
# Average loss: 1.1502, Accuracy: 183.0/260 (70%)
#
#
# Average loss: 1.1621, Accuracy: 2009.0/2940 (68%)
#
# Epoch: 12 	Training Accuracy: 70.38%
# Validation Accuracy: 68.33%
# Batch: 0, Loss: 1.1144908666610718
#
# Average loss: 1.1331, Accuracy: 186.0/260 (72%)
#
#
# Average loss: 1.1466, Accuracy: 2034.0/2940 (69%)
#
# Epoch: 13 	Training Accuracy: 71.54%
# Validation Accuracy: 69.18%
# Batch: 0, Loss: 1.151673436164856
#
# Average loss: 1.1159, Accuracy: 190.0/260 (73%)
#
#
# Average loss: 1.1311, Accuracy: 2067.0/2940 (70%)
#
# Epoch: 14 	Training Accuracy: 73.08%
# Validation Accuracy: 70.31%
# Batch: 0, Loss: 1.1180585622787476
#
# Average loss: 1.0991, Accuracy: 190.0/260 (73%)
#
#
# Average loss: 1.1157, Accuracy: 2090.0/2940 (71%)
#
# Epoch: 15 	Training Accuracy: 73.08%
# Validation Accuracy: 71.09%
# Batch: 0, Loss: 1.087285041809082
#
# Average loss: 1.0822, Accuracy: 193.0/260 (74%)
#
#
# Average loss: 1.0998, Accuracy: 2118.0/2940 (72%)
#
# Epoch: 16 	Training Accuracy: 74.23%
# Validation Accuracy: 72.04%
# Batch: 0, Loss: 1.1022218465805054
#
# Average loss: 1.0658, Accuracy: 192.0/260 (74%)
#
#
# Average loss: 1.0841, Accuracy: 2144.0/2940 (73%)
#
# Epoch: 17 	Training Accuracy: 73.85%
# Validation Accuracy: 72.93%
# Batch: 0, Loss: 1.0560803413391113
#
# Average loss: 1.0492, Accuracy: 196.0/260 (75%)
#
#
# Average loss: 1.0685, Accuracy: 2178.0/2940 (74%)
#
# Epoch: 18 	Training Accuracy: 75.38%
# Validation Accuracy: 74.08%
# Batch: 0, Loss: 1.018470048904419
#
# Average loss: 1.0330, Accuracy: 199.0/260 (77%)
#
#
# Average loss: 1.0533, Accuracy: 2213.0/2940 (75%)
#
# Epoch: 19 	Training Accuracy: 76.54%
# Validation Accuracy: 75.27%
#
# Average loss: 1.0330, Accuracy: 199.0/260 (77%)
#
#
# Average loss: 1.0562, Accuracy: 3621.0/4861 (74%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 36 =========================
# Batch: 0, Loss: 1.7739523649215698
#
# Average loss: 1.7685, Accuracy: 26.0/260 (10%)
#
#
# Average loss: 1.7759, Accuracy: 315.0/2940 (11%)
#
# Epoch: 0 	Training Accuracy: 10.00%
# Validation Accuracy: 10.71%
# Batch: 0, Loss: 1.7597551345825195
#
# Average loss: 1.7404, Accuracy: 23.0/260 (9%)
#
#
# Average loss: 1.7492, Accuracy: 302.0/2940 (10%)
#
# Epoch: 1 	Training Accuracy: 8.85%
# Validation Accuracy: 10.27%
# Batch: 0, Loss: 1.7543872594833374
#
# Average loss: 1.7136, Accuracy: 22.0/260 (8%)
#
#
# Average loss: 1.7238, Accuracy: 305.0/2940 (10%)
#
# Epoch: 2 	Training Accuracy: 8.46%
# Validation Accuracy: 10.37%
# Batch: 0, Loss: 1.7012710571289062
#
# Average loss: 1.6879, Accuracy: 21.0/260 (8%)
#
#
# Average loss: 1.6994, Accuracy: 309.0/2940 (11%)
#
# Epoch: 3 	Training Accuracy: 8.08%
# Validation Accuracy: 10.51%
# Batch: 0, Loss: 1.6915892362594604
#
# Average loss: 1.6633, Accuracy: 20.0/260 (8%)
#
#
# Average loss: 1.6763, Accuracy: 322.0/2940 (11%)
#
# Epoch: 4 	Training Accuracy: 7.69%
# Validation Accuracy: 10.95%
# Batch: 0, Loss: 1.6758397817611694
#
# Average loss: 1.6405, Accuracy: 22.0/260 (8%)
#
#
# Average loss: 1.6550, Accuracy: 343.0/2940 (12%)
#
# Epoch: 5 	Training Accuracy: 8.46%
# Validation Accuracy: 11.67%
# Batch: 0, Loss: 1.6300987005233765
#
# Average loss: 1.6189, Accuracy: 23.0/260 (9%)
#
#
# Average loss: 1.6350, Accuracy: 370.0/2940 (13%)
#
# Epoch: 6 	Training Accuracy: 8.85%
# Validation Accuracy: 12.59%
# Batch: 0, Loss: 1.6221033334732056
#
# Average loss: 1.5980, Accuracy: 25.0/260 (10%)
#
#
# Average loss: 1.6158, Accuracy: 402.0/2940 (14%)
#
# Epoch: 7 	Training Accuracy: 9.62%
# Validation Accuracy: 13.67%
# Batch: 0, Loss: 1.612225890159607
#
# Average loss: 1.5774, Accuracy: 26.0/260 (10%)
#
#
# Average loss: 1.5966, Accuracy: 430.0/2940 (15%)
#
# Epoch: 8 	Training Accuracy: 10.00%
# Validation Accuracy: 14.63%
# Batch: 0, Loss: 1.5774825811386108
#
# Average loss: 1.5569, Accuracy: 32.0/260 (12%)
#
#
# Average loss: 1.5771, Accuracy: 471.0/2940 (16%)
#
# Epoch: 9 	Training Accuracy: 12.31%
# Validation Accuracy: 16.02%
# Batch: 0, Loss: 1.5824923515319824
#
# Average loss: 1.5370, Accuracy: 33.0/260 (13%)
#
#
# Average loss: 1.5581, Accuracy: 508.0/2940 (17%)
#
# Epoch: 10 	Training Accuracy: 12.69%
# Validation Accuracy: 17.28%
# Batch: 0, Loss: 1.4989979267120361
#
# Average loss: 1.5171, Accuracy: 41.0/260 (16%)
#
#
# Average loss: 1.5390, Accuracy: 554.0/2940 (19%)
#
# Epoch: 11 	Training Accuracy: 15.77%
# Validation Accuracy: 18.84%
# Batch: 0, Loss: 1.4958406686782837
#
# Average loss: 1.4975, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.5199, Accuracy: 601.0/2940 (20%)
#
# Epoch: 12 	Training Accuracy: 20.38%
# Validation Accuracy: 20.44%
# Batch: 0, Loss: 1.5105634927749634
#
# Average loss: 1.4782, Accuracy: 59.0/260 (23%)
#
#
# Average loss: 1.5012, Accuracy: 664.0/2940 (23%)
#
# Epoch: 13 	Training Accuracy: 22.69%
# Validation Accuracy: 22.59%
# Batch: 0, Loss: 1.4982186555862427
#
# Average loss: 1.4595, Accuracy: 65.0/260 (25%)
#
#
# Average loss: 1.4833, Accuracy: 719.0/2940 (24%)
#
# Epoch: 14 	Training Accuracy: 25.00%
# Validation Accuracy: 24.46%
# Batch: 0, Loss: 1.4750694036483765
#
# Average loss: 1.4413, Accuracy: 75.0/260 (29%)
#
#
# Average loss: 1.4658, Accuracy: 774.0/2940 (26%)
#
# Epoch: 15 	Training Accuracy: 28.85%
# Validation Accuracy: 26.33%
# Batch: 0, Loss: 1.456109881401062
#
# Average loss: 1.4231, Accuracy: 80.0/260 (31%)
#
#
# Average loss: 1.4487, Accuracy: 830.0/2940 (28%)
#
# Epoch: 16 	Training Accuracy: 30.77%
# Validation Accuracy: 28.23%
# Batch: 0, Loss: 1.3965787887573242
#
# Average loss: 1.4049, Accuracy: 88.0/260 (34%)
#
#
# Average loss: 1.4314, Accuracy: 887.0/2940 (30%)
#
# Epoch: 17 	Training Accuracy: 33.85%
# Validation Accuracy: 30.17%
# Batch: 0, Loss: 1.4010382890701294
#
# Average loss: 1.3872, Accuracy: 95.0/260 (37%)
#
#
# Average loss: 1.4148, Accuracy: 948.0/2940 (32%)
#
# Epoch: 18 	Training Accuracy: 36.54%
# Validation Accuracy: 32.24%
# Batch: 0, Loss: 1.379837989807129
#
# Average loss: 1.3697, Accuracy: 102.0/260 (39%)
#
#
# Average loss: 1.3982, Accuracy: 1016.0/2940 (35%)
#
# Epoch: 19 	Training Accuracy: 39.23%
# Validation Accuracy: 34.56%
#
# Average loss: 1.3697, Accuracy: 102.0/260 (39%)
#
#
# Average loss: 1.4081, Accuracy: 1638.0/4861 (34%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 84 =========================
# Batch: 0, Loss: 1.6646642684936523
#
# Average loss: 1.6394, Accuracy: 44.0/260 (17%)
#
#
# Average loss: 1.6195, Accuracy: 437.0/2940 (15%)
#
# Epoch: 0 	Training Accuracy: 16.92%
# Validation Accuracy: 14.86%
# Batch: 0, Loss: 1.6310882568359375
#
# Average loss: 1.6151, Accuracy: 48.0/260 (18%)
#
#
# Average loss: 1.5956, Accuracy: 514.0/2940 (17%)
#
# Epoch: 1 	Training Accuracy: 18.46%
# Validation Accuracy: 17.48%
# Batch: 0, Loss: 1.6584171056747437
#
# Average loss: 1.5933, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5736, Accuracy: 592.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 20.14%
# Batch: 0, Loss: 1.5874468088150024
#
# Average loss: 1.5723, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.5523, Accuracy: 675.0/2940 (23%)
#
# Epoch: 3 	Training Accuracy: 22.31%
# Validation Accuracy: 22.96%
# Batch: 0, Loss: 1.5708311796188354
#
# Average loss: 1.5521, Accuracy: 63.0/260 (24%)
#
#
# Average loss: 1.5325, Accuracy: 758.0/2940 (26%)
#
# Epoch: 4 	Training Accuracy: 24.23%
# Validation Accuracy: 25.78%
# Batch: 0, Loss: 1.5489296913146973
#
# Average loss: 1.5325, Accuracy: 69.0/260 (27%)
#
#
# Average loss: 1.5137, Accuracy: 807.0/2940 (27%)
#
# Epoch: 5 	Training Accuracy: 26.54%
# Validation Accuracy: 27.45%
# Batch: 0, Loss: 1.5380268096923828
#
# Average loss: 1.5122, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.4940, Accuracy: 893.0/2940 (30%)
#
# Epoch: 6 	Training Accuracy: 28.46%
# Validation Accuracy: 30.37%
# Batch: 0, Loss: 1.5673843622207642
#
# Average loss: 1.4920, Accuracy: 78.0/260 (30%)
#
#
# Average loss: 1.4744, Accuracy: 967.0/2940 (33%)
#
# Epoch: 7 	Training Accuracy: 30.00%
# Validation Accuracy: 32.89%
# Batch: 0, Loss: 1.472528100013733
#
# Average loss: 1.4718, Accuracy: 83.0/260 (32%)
#
#
# Average loss: 1.4548, Accuracy: 1043.0/2940 (35%)
#
# Epoch: 8 	Training Accuracy: 31.92%
# Validation Accuracy: 35.48%
# Batch: 0, Loss: 1.4839853048324585
#
# Average loss: 1.4520, Accuracy: 90.0/260 (35%)
#
#
# Average loss: 1.4355, Accuracy: 1121.0/2940 (38%)
#
# Epoch: 9 	Training Accuracy: 34.62%
# Validation Accuracy: 38.13%
# Batch: 0, Loss: 1.427344799041748
#
# Average loss: 1.4323, Accuracy: 95.0/260 (37%)
#
#
# Average loss: 1.4163, Accuracy: 1204.0/2940 (41%)
#
# Epoch: 10 	Training Accuracy: 36.54%
# Validation Accuracy: 40.95%
# Batch: 0, Loss: 1.442991852760315
#
# Average loss: 1.4128, Accuracy: 101.0/260 (39%)
#
#
# Average loss: 1.3973, Accuracy: 1271.0/2940 (43%)
#
# Epoch: 11 	Training Accuracy: 38.85%
# Validation Accuracy: 43.23%
# Batch: 0, Loss: 1.3954014778137207
#
# Average loss: 1.3937, Accuracy: 111.0/260 (43%)
#
#
# Average loss: 1.3783, Accuracy: 1340.0/2940 (46%)
#
# Epoch: 12 	Training Accuracy: 42.69%
# Validation Accuracy: 45.58%
# Batch: 0, Loss: 1.40214204788208
#
# Average loss: 1.3744, Accuracy: 121.0/260 (47%)
#
#
# Average loss: 1.3594, Accuracy: 1408.0/2940 (48%)
#
# Epoch: 13 	Training Accuracy: 46.54%
# Validation Accuracy: 47.89%
# Batch: 0, Loss: 1.3846176862716675
#
# Average loss: 1.3556, Accuracy: 125.0/260 (48%)
#
#
# Average loss: 1.3411, Accuracy: 1462.0/2940 (50%)
#
# Epoch: 14 	Training Accuracy: 48.08%
# Validation Accuracy: 49.73%
# Batch: 0, Loss: 1.3676111698150635
#
# Average loss: 1.3378, Accuracy: 127.0/260 (49%)
#
#
# Average loss: 1.3236, Accuracy: 1499.0/2940 (51%)
#
# Epoch: 15 	Training Accuracy: 48.85%
# Validation Accuracy: 50.99%
# Batch: 0, Loss: 1.311257004737854
#
# Average loss: 1.3201, Accuracy: 133.0/260 (51%)
#
#
# Average loss: 1.3064, Accuracy: 1542.0/2940 (52%)
#
# Epoch: 16 	Training Accuracy: 51.15%
# Validation Accuracy: 52.45%
# Batch: 0, Loss: 1.3280029296875
#
# Average loss: 1.3025, Accuracy: 136.0/260 (52%)
#
#
# Average loss: 1.2892, Accuracy: 1587.0/2940 (54%)
#
# Epoch: 17 	Training Accuracy: 52.31%
# Validation Accuracy: 53.98%
# Batch: 0, Loss: 1.3181401491165161
#
# Average loss: 1.2853, Accuracy: 142.0/260 (55%)
#
#
# Average loss: 1.2723, Accuracy: 1615.0/2940 (55%)
#
# Epoch: 18 	Training Accuracy: 54.62%
# Validation Accuracy: 54.93%
# Batch: 0, Loss: 1.2727793455123901
#
# Average loss: 1.2685, Accuracy: 144.0/260 (55%)
#
#
# Average loss: 1.2557, Accuracy: 1654.0/2940 (56%)
#
# Epoch: 19 	Training Accuracy: 55.38%
# Validation Accuracy: 56.26%
#
# Average loss: 1.2685, Accuracy: 144.0/260 (55%)
#
#
# Average loss: 1.2619, Accuracy: 2697.0/4861 (55%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 28 =========================
# Batch: 0, Loss: 1.7696819305419922
#
# Average loss: 1.7383, Accuracy: 50.0/260 (19%)
#
#
# Average loss: 1.7463, Accuracy: 545.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 19.23%
# Validation Accuracy: 18.54%
# Batch: 0, Loss: 1.7598098516464233
#
# Average loss: 1.7052, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.7146, Accuracy: 566.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.38%
# Validation Accuracy: 19.25%
# Batch: 0, Loss: 1.6615841388702393
#
# Average loss: 1.6761, Accuracy: 55.0/260 (21%)
#
#
# Average loss: 1.6865, Accuracy: 582.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 21.15%
# Validation Accuracy: 19.80%
# Batch: 0, Loss: 1.7143714427947998
#
# Average loss: 1.6492, Accuracy: 54.0/260 (21%)
#
#
# Average loss: 1.6605, Accuracy: 599.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.77%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6546229124069214
#
# Average loss: 1.6229, Accuracy: 51.0/260 (20%)
#
#
# Average loss: 1.6353, Accuracy: 632.0/2940 (21%)
#
# Epoch: 4 	Training Accuracy: 19.62%
# Validation Accuracy: 21.50%
# Batch: 0, Loss: 1.591018795967102
#
# Average loss: 1.5972, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.6109, Accuracy: 664.0/2940 (23%)
#
# Epoch: 5 	Training Accuracy: 20.38%
# Validation Accuracy: 22.59%
# Batch: 0, Loss: 1.6007955074310303
#
# Average loss: 1.5720, Accuracy: 60.0/260 (23%)
#
#
# Average loss: 1.5870, Accuracy: 708.0/2940 (24%)
#
# Epoch: 6 	Training Accuracy: 23.08%
# Validation Accuracy: 24.08%
# Batch: 0, Loss: 1.5633201599121094
#
# Average loss: 1.5479, Accuracy: 65.0/260 (25%)
#
#
# Average loss: 1.5637, Accuracy: 750.0/2940 (26%)
#
# Epoch: 7 	Training Accuracy: 25.00%
# Validation Accuracy: 25.51%
# Batch: 0, Loss: 1.5001444816589355
#
# Average loss: 1.5246, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.5412, Accuracy: 824.0/2940 (28%)
#
# Epoch: 8 	Training Accuracy: 28.46%
# Validation Accuracy: 28.03%
# Batch: 0, Loss: 1.4966086149215698
#
# Average loss: 1.5018, Accuracy: 83.0/260 (32%)
#
#
# Average loss: 1.5192, Accuracy: 886.0/2940 (30%)
#
# Epoch: 9 	Training Accuracy: 31.92%
# Validation Accuracy: 30.14%
# Batch: 0, Loss: 1.5016676187515259
#
# Average loss: 1.4792, Accuracy: 89.0/260 (34%)
#
#
# Average loss: 1.4978, Accuracy: 975.0/2940 (33%)
#
# Epoch: 10 	Training Accuracy: 34.23%
# Validation Accuracy: 33.16%
# Batch: 0, Loss: 1.4582089185714722
#
# Average loss: 1.4572, Accuracy: 92.0/260 (35%)
#
#
# Average loss: 1.4769, Accuracy: 1077.0/2940 (37%)
#
# Epoch: 11 	Training Accuracy: 35.38%
# Validation Accuracy: 36.63%
# Batch: 0, Loss: 1.4616596698760986
#
# Average loss: 1.4359, Accuracy: 100.0/260 (38%)
#
#
# Average loss: 1.4564, Accuracy: 1170.0/2940 (40%)
#
# Epoch: 12 	Training Accuracy: 38.46%
# Validation Accuracy: 39.80%
# Batch: 0, Loss: 1.4038900136947632
#
# Average loss: 1.4152, Accuracy: 107.0/260 (41%)
#
#
# Average loss: 1.4362, Accuracy: 1256.0/2940 (43%)
#
# Epoch: 13 	Training Accuracy: 41.15%
# Validation Accuracy: 42.72%
# Batch: 0, Loss: 1.4081047773361206
#
# Average loss: 1.3951, Accuracy: 116.0/260 (45%)
#
#
# Average loss: 1.4167, Accuracy: 1349.0/2940 (46%)
#
# Epoch: 14 	Training Accuracy: 44.62%
# Validation Accuracy: 45.88%
# Batch: 0, Loss: 1.414615511894226
#
# Average loss: 1.3757, Accuracy: 122.0/260 (47%)
#
#
# Average loss: 1.3975, Accuracy: 1422.0/2940 (48%)
#
# Epoch: 15 	Training Accuracy: 46.92%
# Validation Accuracy: 48.37%
# Batch: 0, Loss: 1.4034794569015503
#
# Average loss: 1.3565, Accuracy: 131.0/260 (50%)
#
#
# Average loss: 1.3788, Accuracy: 1519.0/2940 (52%)
#
# Epoch: 16 	Training Accuracy: 50.38%
# Validation Accuracy: 51.67%
# Batch: 0, Loss: 1.3427497148513794
#
# Average loss: 1.3378, Accuracy: 143.0/260 (55%)
#
#
# Average loss: 1.3607, Accuracy: 1602.0/2940 (54%)
#
# Epoch: 17 	Training Accuracy: 55.00%
# Validation Accuracy: 54.49%
# Batch: 0, Loss: 1.3502532243728638
#
# Average loss: 1.3192, Accuracy: 152.0/260 (58%)
#
#
# Average loss: 1.3427, Accuracy: 1708.0/2940 (58%)
#
# Epoch: 18 	Training Accuracy: 58.46%
# Validation Accuracy: 58.10%
# Batch: 0, Loss: 1.3173754215240479
#
# Average loss: 1.3012, Accuracy: 160.0/260 (62%)
#
#
# Average loss: 1.3254, Accuracy: 1758.0/2940 (60%)
#
# Epoch: 19 	Training Accuracy: 61.54%
# Validation Accuracy: 59.80%
#
# Average loss: 1.3012, Accuracy: 160.0/260 (62%)
#
#
# Average loss: 1.3127, Accuracy: 2954.0/4861 (61%)
# Running seeds for 0.03 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 61 =========================
# Batch: 0, Loss: 1.387245535850525
#
# Average loss: 1.2821, Accuracy: 409.0/790 (52%)
#
#
# Average loss: 1.2639, Accuracy: 1586.0/2940 (54%)
#
# Epoch: 0 	Training Accuracy: 51.77%
# Validation Accuracy: 53.95%
# Batch: 0, Loss: 1.3260695934295654
#
# Average loss: 1.2235, Accuracy: 435.0/790 (55%)
#
#
# Average loss: 1.2081, Accuracy: 1695.0/2940 (58%)
#
# Epoch: 1 	Training Accuracy: 55.06%
# Validation Accuracy: 57.65%
# Batch: 0, Loss: 1.2587727308273315
#
# Average loss: 1.1681, Accuracy: 456.0/790 (58%)
#
#
# Average loss: 1.1557, Accuracy: 1768.0/2940 (60%)
#
# Epoch: 2 	Training Accuracy: 57.72%
# Validation Accuracy: 60.14%
# Batch: 0, Loss: 1.165724277496338
#
# Average loss: 1.1153, Accuracy: 484.0/790 (61%)
#
#
# Average loss: 1.1055, Accuracy: 1897.0/2940 (65%)
#
# Epoch: 3 	Training Accuracy: 61.27%
# Validation Accuracy: 64.52%
# Batch: 0, Loss: 1.079811930656433
#
# Average loss: 1.0643, Accuracy: 515.0/790 (65%)
#
#
# Average loss: 1.0567, Accuracy: 2005.0/2940 (68%)
#
# Epoch: 4 	Training Accuracy: 65.19%
# Validation Accuracy: 68.20%
# Batch: 0, Loss: 1.0481486320495605
#
# Average loss: 1.0158, Accuracy: 550.0/790 (70%)
#
#
# Average loss: 1.0103, Accuracy: 2119.0/2940 (72%)
#
# Epoch: 5 	Training Accuracy: 69.62%
# Validation Accuracy: 72.07%
# Batch: 0, Loss: 0.9996405839920044
#
# Average loss: 0.9685, Accuracy: 597.0/790 (76%)
#
#
# Average loss: 0.9657, Accuracy: 2245.0/2940 (76%)
#
# Epoch: 6 	Training Accuracy: 75.57%
# Validation Accuracy: 76.36%
# Batch: 0, Loss: 0.9526280164718628
#
# Average loss: 0.9233, Accuracy: 636.0/790 (81%)
#
#
# Average loss: 0.9231, Accuracy: 2346.0/2940 (80%)
#
# Epoch: 7 	Training Accuracy: 80.51%
# Validation Accuracy: 79.80%
# Batch: 0, Loss: 0.9629818797111511
#
# Average loss: 0.8801, Accuracy: 658.0/790 (83%)
#
#
# Average loss: 0.8822, Accuracy: 2426.0/2940 (83%)
#
# Epoch: 8 	Training Accuracy: 83.29%
# Validation Accuracy: 82.52%
# Batch: 0, Loss: 0.8487964272499084
#
# Average loss: 0.8389, Accuracy: 682.0/790 (86%)
#
#
# Average loss: 0.8433, Accuracy: 2480.0/2940 (84%)
#
# Epoch: 9 	Training Accuracy: 86.33%
# Validation Accuracy: 84.35%
# Batch: 0, Loss: 0.8526546955108643
#
# Average loss: 0.8001, Accuracy: 693.0/790 (88%)
#
#
# Average loss: 0.8063, Accuracy: 2516.0/2940 (86%)
#
# Epoch: 10 	Training Accuracy: 87.72%
# Validation Accuracy: 85.58%
# Batch: 0, Loss: 0.7482540607452393
#
# Average loss: 0.7630, Accuracy: 694.0/790 (88%)
#
#
# Average loss: 0.7714, Accuracy: 2538.0/2940 (86%)
#
# Epoch: 11 	Training Accuracy: 87.85%
# Validation Accuracy: 86.33%
# Batch: 0, Loss: 0.8015169501304626
#
# Average loss: 0.7281, Accuracy: 702.0/790 (89%)
#
#
# Average loss: 0.7387, Accuracy: 2576.0/2940 (88%)
#
# Epoch: 12 	Training Accuracy: 88.86%
# Validation Accuracy: 87.62%
# Batch: 0, Loss: 0.6717150211334229
#
# Average loss: 0.6952, Accuracy: 706.0/790 (89%)
#
#
# Average loss: 0.7079, Accuracy: 2585.0/2940 (88%)
#
# Epoch: 13 	Training Accuracy: 89.37%
# Validation Accuracy: 87.93%
# Batch: 0, Loss: 0.7116780877113342
#
# Average loss: 0.6643, Accuracy: 709.0/790 (90%)
#
#
# Average loss: 0.6791, Accuracy: 2604.0/2940 (89%)
#
# Epoch: 14 	Training Accuracy: 89.75%
# Validation Accuracy: 88.57%
# Batch: 0, Loss: 0.6973884105682373
#
# Average loss: 0.6354, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.6515, Accuracy: 2620.0/2940 (89%)
#
# Epoch: 15 	Training Accuracy: 90.38%
# Validation Accuracy: 89.12%
# Batch: 0, Loss: 0.666917085647583
#
# Average loss: 0.6077, Accuracy: 713.0/790 (90%)
#
#
# Average loss: 0.6256, Accuracy: 2629.0/2940 (89%)
#
# Epoch: 16 	Training Accuracy: 90.25%
# Validation Accuracy: 89.42%
# Batch: 0, Loss: 0.5705127120018005
#
# Average loss: 0.5822, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.6015, Accuracy: 2640.0/2940 (90%)
#
# Epoch: 17 	Training Accuracy: 91.01%
# Validation Accuracy: 89.80%
# Batch: 0, Loss: 0.5660548806190491
#
# Average loss: 0.5585, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.5799, Accuracy: 2650.0/2940 (90%)
#
# Epoch: 18 	Training Accuracy: 90.76%
# Validation Accuracy: 90.14%
# Batch: 0, Loss: 0.532890796661377
#
# Average loss: 0.5360, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.5590, Accuracy: 2654.0/2940 (90%)
#
# Epoch: 19 	Training Accuracy: 91.01%
# Validation Accuracy: 90.27%
#
# Average loss: 0.5360, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.5506, Accuracy: 4421.0/4861 (91%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 84 =========================
# Batch: 0, Loss: 1.6010981798171997
#
# Average loss: 1.5412, Accuracy: 227.0/790 (29%)
#
#
# Average loss: 1.5525, Accuracy: 802.0/2940 (27%)
#
# Epoch: 0 	Training Accuracy: 28.73%
# Validation Accuracy: 27.28%
# Batch: 0, Loss: 1.4784518480300903
#
# Average loss: 1.4749, Accuracy: 278.0/790 (35%)
#
#
# Average loss: 1.4871, Accuracy: 972.0/2940 (33%)
#
# Epoch: 1 	Training Accuracy: 35.19%
# Validation Accuracy: 33.06%
# Batch: 0, Loss: 1.4825022220611572
#
# Average loss: 1.4122, Accuracy: 332.0/790 (42%)
#
#
# Average loss: 1.4256, Accuracy: 1153.0/2940 (39%)
#
# Epoch: 2 	Training Accuracy: 42.03%
# Validation Accuracy: 39.22%
# Batch: 0, Loss: 1.4062731266021729
#
# Average loss: 1.3534, Accuracy: 381.0/790 (48%)
#
#
# Average loss: 1.3674, Accuracy: 1350.0/2940 (46%)
#
# Epoch: 3 	Training Accuracy: 48.23%
# Validation Accuracy: 45.92%
# Batch: 0, Loss: 1.3235114812850952
#
# Average loss: 1.2961, Accuracy: 440.0/790 (56%)
#
#
# Average loss: 1.3107, Accuracy: 1581.0/2940 (54%)
#
# Epoch: 4 	Training Accuracy: 55.70%
# Validation Accuracy: 53.78%
# Batch: 0, Loss: 1.2822716236114502
#
# Average loss: 1.2402, Accuracy: 487.0/790 (62%)
#
#
# Average loss: 1.2557, Accuracy: 1809.0/2940 (62%)
#
# Epoch: 5 	Training Accuracy: 61.65%
# Validation Accuracy: 61.53%
# Batch: 0, Loss: 1.2155239582061768
#
# Average loss: 1.1859, Accuracy: 536.0/790 (68%)
#
#
# Average loss: 1.2025, Accuracy: 1973.0/2940 (67%)
#
# Epoch: 6 	Training Accuracy: 67.85%
# Validation Accuracy: 67.11%
# Batch: 0, Loss: 1.2026842832565308
#
# Average loss: 1.1330, Accuracy: 574.0/790 (73%)
#
#
# Average loss: 1.1511, Accuracy: 2113.0/2940 (72%)
#
# Epoch: 7 	Training Accuracy: 72.66%
# Validation Accuracy: 71.87%
# Batch: 0, Loss: 1.132017970085144
#
# Average loss: 1.0809, Accuracy: 603.0/790 (76%)
#
#
# Average loss: 1.0999, Accuracy: 2230.0/2940 (76%)
#
# Epoch: 8 	Training Accuracy: 76.33%
# Validation Accuracy: 75.85%
# Batch: 0, Loss: 1.0765740871429443
#
# Average loss: 1.0303, Accuracy: 636.0/790 (81%)
#
#
# Average loss: 1.0491, Accuracy: 2332.0/2940 (79%)
#
# Epoch: 9 	Training Accuracy: 80.51%
# Validation Accuracy: 79.32%
# Batch: 0, Loss: 1.0345109701156616
#
# Average loss: 0.9822, Accuracy: 655.0/790 (83%)
#
#
# Average loss: 1.0014, Accuracy: 2418.0/2940 (82%)
#
# Epoch: 10 	Training Accuracy: 82.91%
# Validation Accuracy: 82.24%
# Batch: 0, Loss: 0.9771386981010437
#
# Average loss: 0.9363, Accuracy: 669.0/790 (85%)
#
#
# Average loss: 0.9564, Accuracy: 2457.0/2940 (84%)
#
# Epoch: 11 	Training Accuracy: 84.68%
# Validation Accuracy: 83.57%
# Batch: 0, Loss: 0.9256028532981873
#
# Average loss: 0.8923, Accuracy: 677.0/790 (86%)
#
#
# Average loss: 0.9132, Accuracy: 2505.0/2940 (85%)
#
# Epoch: 12 	Training Accuracy: 85.70%
# Validation Accuracy: 85.20%
# Batch: 0, Loss: 0.9139190912246704
#
# Average loss: 0.8503, Accuracy: 688.0/790 (87%)
#
#
# Average loss: 0.8721, Accuracy: 2544.0/2940 (87%)
#
# Epoch: 13 	Training Accuracy: 87.09%
# Validation Accuracy: 86.53%
# Batch: 0, Loss: 0.8720895051956177
#
# Average loss: 0.8100, Accuracy: 699.0/790 (88%)
#
#
# Average loss: 0.8329, Accuracy: 2566.0/2940 (87%)
#
# Epoch: 14 	Training Accuracy: 88.48%
# Validation Accuracy: 87.28%
# Batch: 0, Loss: 0.8115487098693848
#
# Average loss: 0.7724, Accuracy: 705.0/790 (89%)
#
#
# Average loss: 0.7962, Accuracy: 2577.0/2940 (88%)
#
# Epoch: 15 	Training Accuracy: 89.24%
# Validation Accuracy: 87.65%
# Batch: 0, Loss: 0.8098471164703369
#
# Average loss: 0.7368, Accuracy: 711.0/790 (90%)
#
#
# Average loss: 0.7622, Accuracy: 2601.0/2940 (88%)
#
# Epoch: 16 	Training Accuracy: 90.00%
# Validation Accuracy: 88.47%
# Batch: 0, Loss: 0.7597571015357971
#
# Average loss: 0.7036, Accuracy: 716.0/790 (91%)
#
#
# Average loss: 0.7304, Accuracy: 2613.0/2940 (89%)
#
# Epoch: 17 	Training Accuracy: 90.63%
# Validation Accuracy: 88.88%
# Batch: 0, Loss: 0.6840264797210693
#
# Average loss: 0.6725, Accuracy: 718.0/790 (91%)
#
#
# Average loss: 0.7003, Accuracy: 2625.0/2940 (89%)
#
# Epoch: 18 	Training Accuracy: 90.89%
# Validation Accuracy: 89.29%
# Batch: 0, Loss: 0.6472653150558472
#
# Average loss: 0.6431, Accuracy: 721.0/790 (91%)
#
#
# Average loss: 0.6723, Accuracy: 2630.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 91.27%
# Validation Accuracy: 89.46%
#
# Average loss: 0.6431, Accuracy: 721.0/790 (91%)
#
#
# Average loss: 0.6522, Accuracy: 4386.0/4861 (90%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 72 =========================
# Batch: 0, Loss: 1.7633016109466553
#
# Average loss: 1.7105, Accuracy: 149.0/790 (19%)
#
#
# Average loss: 1.6981, Accuracy: 578.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 18.86%
# Validation Accuracy: 19.66%
# Batch: 0, Loss: 1.7479960918426514
#
# Average loss: 1.6312, Accuracy: 176.0/790 (22%)
#
#
# Average loss: 1.6218, Accuracy: 658.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 22.28%
# Validation Accuracy: 22.38%
# Batch: 0, Loss: 1.5923529863357544
#
# Average loss: 1.5597, Accuracy: 213.0/790 (27%)
#
#
# Average loss: 1.5537, Accuracy: 818.0/2940 (28%)
#
# Epoch: 2 	Training Accuracy: 26.96%
# Validation Accuracy: 27.82%
# Batch: 0, Loss: 1.5761784315109253
#
# Average loss: 1.4938, Accuracy: 280.0/790 (35%)
#
#
# Average loss: 1.4903, Accuracy: 1018.0/2940 (35%)
#
# Epoch: 3 	Training Accuracy: 35.44%
# Validation Accuracy: 34.63%
# Batch: 0, Loss: 1.4937312602996826
#
# Average loss: 1.4326, Accuracy: 346.0/790 (44%)
#
#
# Average loss: 1.4307, Accuracy: 1302.0/2940 (44%)
#
# Epoch: 4 	Training Accuracy: 43.80%
# Validation Accuracy: 44.29%
# Batch: 0, Loss: 1.4187575578689575
#
# Average loss: 1.3744, Accuracy: 408.0/790 (52%)
#
#
# Average loss: 1.3737, Accuracy: 1545.0/2940 (53%)
#
# Epoch: 5 	Training Accuracy: 51.65%
# Validation Accuracy: 52.55%
# Batch: 0, Loss: 1.3991214036941528
#
# Average loss: 1.3188, Accuracy: 478.0/790 (61%)
#
#
# Average loss: 1.3201, Accuracy: 1775.0/2940 (60%)
#
# Epoch: 6 	Training Accuracy: 60.51%
# Validation Accuracy: 60.37%
# Batch: 0, Loss: 1.3570119142532349
#
# Average loss: 1.2659, Accuracy: 520.0/790 (66%)
#
#
# Average loss: 1.2693, Accuracy: 1963.0/2940 (67%)
#
# Epoch: 7 	Training Accuracy: 65.82%
# Validation Accuracy: 66.77%
# Batch: 0, Loss: 1.2888035774230957
#
# Average loss: 1.2148, Accuracy: 553.0/790 (70%)
#
#
# Average loss: 1.2194, Accuracy: 2092.0/2940 (71%)
#
# Epoch: 8 	Training Accuracy: 70.00%
# Validation Accuracy: 71.16%
# Batch: 0, Loss: 1.2015336751937866
#
# Average loss: 1.1651, Accuracy: 577.0/790 (73%)
#
#
# Average loss: 1.1712, Accuracy: 2174.0/2940 (74%)
#
# Epoch: 9 	Training Accuracy: 73.04%
# Validation Accuracy: 73.95%
# Batch: 0, Loss: 1.1493360996246338
#
# Average loss: 1.1167, Accuracy: 603.0/790 (76%)
#
#
# Average loss: 1.1233, Accuracy: 2260.0/2940 (77%)
#
# Epoch: 10 	Training Accuracy: 76.33%
# Validation Accuracy: 76.87%
# Batch: 0, Loss: 1.0901844501495361
#
# Average loss: 1.0697, Accuracy: 619.0/790 (78%)
#
#
# Average loss: 1.0770, Accuracy: 2331.0/2940 (79%)
#
# Epoch: 11 	Training Accuracy: 78.35%
# Validation Accuracy: 79.29%
# Batch: 0, Loss: 1.1078360080718994
#
# Average loss: 1.0243, Accuracy: 638.0/790 (81%)
#
#
# Average loss: 1.0328, Accuracy: 2392.0/2940 (81%)
#
# Epoch: 12 	Training Accuracy: 80.76%
# Validation Accuracy: 81.36%
# Batch: 0, Loss: 1.017902135848999
#
# Average loss: 0.9804, Accuracy: 650.0/790 (82%)
#
#
# Average loss: 0.9904, Accuracy: 2443.0/2940 (83%)
#
# Epoch: 13 	Training Accuracy: 82.28%
# Validation Accuracy: 83.10%
# Batch: 0, Loss: 0.9959837794303894
#
# Average loss: 0.9382, Accuracy: 665.0/790 (84%)
#
#
# Average loss: 0.9499, Accuracy: 2474.0/2940 (84%)
#
# Epoch: 14 	Training Accuracy: 84.18%
# Validation Accuracy: 84.15%
# Batch: 0, Loss: 0.9246935844421387
#
# Average loss: 0.8976, Accuracy: 682.0/790 (86%)
#
#
# Average loss: 0.9105, Accuracy: 2499.0/2940 (85%)
#
# Epoch: 15 	Training Accuracy: 86.33%
# Validation Accuracy: 85.00%
# Batch: 0, Loss: 0.9190701246261597
#
# Average loss: 0.8590, Accuracy: 690.0/790 (87%)
#
#
# Average loss: 0.8727, Accuracy: 2533.0/2940 (86%)
#
# Epoch: 16 	Training Accuracy: 87.34%
# Validation Accuracy: 86.16%
# Batch: 0, Loss: 0.8851176500320435
#
# Average loss: 0.8222, Accuracy: 694.0/790 (88%)
#
#
# Average loss: 0.8370, Accuracy: 2543.0/2940 (86%)
#
# Epoch: 17 	Training Accuracy: 87.85%
# Validation Accuracy: 86.50%
# Batch: 0, Loss: 0.7859299182891846
#
# Average loss: 0.7868, Accuracy: 707.0/790 (89%)
#
#
# Average loss: 0.8022, Accuracy: 2560.0/2940 (87%)
#
# Epoch: 18 	Training Accuracy: 89.49%
# Validation Accuracy: 87.07%
# Batch: 0, Loss: 0.7799434661865234
#
# Average loss: 0.7531, Accuracy: 708.0/790 (90%)
#
#
# Average loss: 0.7691, Accuracy: 2558.0/2940 (87%)
#
# Epoch: 19 	Training Accuracy: 89.62%
# Validation Accuracy: 87.01%
#
# Average loss: 0.7531, Accuracy: 708.0/790 (90%)
#
#
# Average loss: 0.7536, Accuracy: 4307.0/4861 (89%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 42 =========================
# Batch: 0, Loss: 1.9263666868209839
#
# Average loss: 1.8884, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.9264, Accuracy: 601.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.44%
# Batch: 0, Loss: 1.8843278884887695
#
# Average loss: 1.8101, Accuracy: 186.0/790 (24%)
#
#
# Average loss: 1.8440, Accuracy: 724.0/2940 (25%)
#
# Epoch: 1 	Training Accuracy: 23.54%
# Validation Accuracy: 24.63%
# Batch: 0, Loss: 1.8430334329605103
#
# Average loss: 1.7360, Accuracy: 230.0/790 (29%)
#
#
# Average loss: 1.7662, Accuracy: 889.0/2940 (30%)
#
# Epoch: 2 	Training Accuracy: 29.11%
# Validation Accuracy: 30.24%
# Batch: 0, Loss: 1.7204959392547607
#
# Average loss: 1.6667, Accuracy: 290.0/790 (37%)
#
#
# Average loss: 1.6932, Accuracy: 1044.0/2940 (36%)
#
# Epoch: 3 	Training Accuracy: 36.71%
# Validation Accuracy: 35.51%
# Batch: 0, Loss: 1.7028224468231201
#
# Average loss: 1.6026, Accuracy: 332.0/790 (42%)
#
#
# Average loss: 1.6260, Accuracy: 1163.0/2940 (40%)
#
# Epoch: 4 	Training Accuracy: 42.03%
# Validation Accuracy: 39.56%
# Batch: 0, Loss: 1.5761908292770386
#
# Average loss: 1.5419, Accuracy: 367.0/790 (46%)
#
#
# Average loss: 1.5621, Accuracy: 1279.0/2940 (44%)
#
# Epoch: 5 	Training Accuracy: 46.46%
# Validation Accuracy: 43.50%
# Batch: 0, Loss: 1.538165807723999
#
# Average loss: 1.4858, Accuracy: 388.0/790 (49%)
#
#
# Average loss: 1.5044, Accuracy: 1403.0/2940 (48%)
#
# Epoch: 6 	Training Accuracy: 49.11%
# Validation Accuracy: 47.72%
# Batch: 0, Loss: 1.5047197341918945
#
# Average loss: 1.4316, Accuracy: 412.0/790 (52%)
#
#
# Average loss: 1.4484, Accuracy: 1493.0/2940 (51%)
#
# Epoch: 7 	Training Accuracy: 52.15%
# Validation Accuracy: 50.78%
# Batch: 0, Loss: 1.4639891386032104
#
# Average loss: 1.3793, Accuracy: 430.0/790 (54%)
#
#
# Average loss: 1.3949, Accuracy: 1580.0/2940 (54%)
#
# Epoch: 8 	Training Accuracy: 54.43%
# Validation Accuracy: 53.74%
# Batch: 0, Loss: 1.3790785074234009
#
# Average loss: 1.3287, Accuracy: 455.0/790 (58%)
#
#
# Average loss: 1.3427, Accuracy: 1650.0/2940 (56%)
#
# Epoch: 9 	Training Accuracy: 57.59%
# Validation Accuracy: 56.12%
# Batch: 0, Loss: 1.3434712886810303
#
# Average loss: 1.2796, Accuracy: 464.0/790 (59%)
#
#
# Average loss: 1.2926, Accuracy: 1700.0/2940 (58%)
#
# Epoch: 10 	Training Accuracy: 58.73%
# Validation Accuracy: 57.82%
# Batch: 0, Loss: 1.256582498550415
#
# Average loss: 1.2315, Accuracy: 491.0/790 (62%)
#
#
# Average loss: 1.2432, Accuracy: 1790.0/2940 (61%)
#
# Epoch: 11 	Training Accuracy: 62.15%
# Validation Accuracy: 60.88%
# Batch: 0, Loss: 1.2047641277313232
#
# Average loss: 1.1841, Accuracy: 530.0/790 (67%)
#
#
# Average loss: 1.1951, Accuracy: 1903.0/2940 (65%)
#
# Epoch: 12 	Training Accuracy: 67.09%
# Validation Accuracy: 64.73%
# Batch: 0, Loss: 1.2431821823120117
#
# Average loss: 1.1376, Accuracy: 551.0/790 (70%)
#
#
# Average loss: 1.1483, Accuracy: 2028.0/2940 (69%)
#
# Epoch: 13 	Training Accuracy: 69.75%
# Validation Accuracy: 68.98%
# Batch: 0, Loss: 1.152337908744812
#
# Average loss: 1.0921, Accuracy: 579.0/790 (73%)
#
#
# Average loss: 1.1026, Accuracy: 2156.0/2940 (73%)
#
# Epoch: 14 	Training Accuracy: 73.29%
# Validation Accuracy: 73.33%
# Batch: 0, Loss: 1.0916959047317505
#
# Average loss: 1.0470, Accuracy: 606.0/790 (77%)
#
#
# Average loss: 1.0572, Accuracy: 2245.0/2940 (76%)
#
# Epoch: 15 	Training Accuracy: 76.71%
# Validation Accuracy: 76.36%
# Batch: 0, Loss: 1.0492281913757324
#
# Average loss: 1.0033, Accuracy: 628.0/790 (79%)
#
#
# Average loss: 1.0134, Accuracy: 2309.0/2940 (79%)
#
# Epoch: 16 	Training Accuracy: 79.49%
# Validation Accuracy: 78.54%
# Batch: 0, Loss: 0.951728343963623
#
# Average loss: 0.9609, Accuracy: 641.0/790 (81%)
#
#
# Average loss: 0.9715, Accuracy: 2361.0/2940 (80%)
#
# Epoch: 17 	Training Accuracy: 81.14%
# Validation Accuracy: 80.31%
# Batch: 0, Loss: 0.960962176322937
#
# Average loss: 0.9201, Accuracy: 655.0/790 (83%)
#
#
# Average loss: 0.9305, Accuracy: 2399.0/2940 (82%)
#
# Epoch: 18 	Training Accuracy: 82.91%
# Validation Accuracy: 81.60%
# Batch: 0, Loss: 0.8809458017349243
#
# Average loss: 0.8802, Accuracy: 661.0/790 (84%)
#
#
# Average loss: 0.8902, Accuracy: 2439.0/2940 (83%)
#
# Epoch: 19 	Training Accuracy: 83.67%
# Validation Accuracy: 82.96%
#
# Average loss: 0.8802, Accuracy: 661.0/790 (84%)
#
#
# Average loss: 0.8682, Accuracy: 4109.0/4861 (85%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 17 =========================
# Batch: 0, Loss: 1.8440217971801758
#
# Average loss: 1.7409, Accuracy: 82.0/790 (10%)
#
#
# Average loss: 1.7282, Accuracy: 308.0/2940 (10%)
#
# Epoch: 0 	Training Accuracy: 10.38%
# Validation Accuracy: 10.48%
# Batch: 0, Loss: 1.7627016305923462
#
# Average loss: 1.6680, Accuracy: 111.0/790 (14%)
#
#
# Average loss: 1.6571, Accuracy: 423.0/2940 (14%)
#
# Epoch: 1 	Training Accuracy: 14.05%
# Validation Accuracy: 14.39%
# Batch: 0, Loss: 1.6409831047058105
#
# Average loss: 1.6006, Accuracy: 139.0/790 (18%)
#
#
# Average loss: 1.5915, Accuracy: 574.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 17.59%
# Validation Accuracy: 19.52%
# Batch: 0, Loss: 1.5959696769714355
#
# Average loss: 1.5367, Accuracy: 180.0/790 (23%)
#
#
# Average loss: 1.5297, Accuracy: 731.0/2940 (25%)
#
# Epoch: 3 	Training Accuracy: 22.78%
# Validation Accuracy: 24.86%
# Batch: 0, Loss: 1.533793330192566
#
# Average loss: 1.4760, Accuracy: 230.0/790 (29%)
#
#
# Average loss: 1.4708, Accuracy: 881.0/2940 (30%)
#
# Epoch: 4 	Training Accuracy: 29.11%
# Validation Accuracy: 29.97%
# Batch: 0, Loss: 1.457521915435791
#
# Average loss: 1.4177, Accuracy: 292.0/790 (37%)
#
#
# Average loss: 1.4142, Accuracy: 1095.0/2940 (37%)
#
# Epoch: 5 	Training Accuracy: 36.96%
# Validation Accuracy: 37.24%
# Batch: 0, Loss: 1.4001522064208984
#
# Average loss: 1.3610, Accuracy: 353.0/790 (45%)
#
#
# Average loss: 1.3593, Accuracy: 1351.0/2940 (46%)
#
# Epoch: 6 	Training Accuracy: 44.68%
# Validation Accuracy: 45.95%
# Batch: 0, Loss: 1.3520963191986084
#
# Average loss: 1.3066, Accuracy: 430.0/790 (54%)
#
#
# Average loss: 1.3072, Accuracy: 1585.0/2940 (54%)
#
# Epoch: 7 	Training Accuracy: 54.43%
# Validation Accuracy: 53.91%
# Batch: 0, Loss: 1.301071286201477
#
# Average loss: 1.2538, Accuracy: 485.0/790 (61%)
#
#
# Average loss: 1.2564, Accuracy: 1769.0/2940 (60%)
#
# Epoch: 8 	Training Accuracy: 61.39%
# Validation Accuracy: 60.17%
# Batch: 0, Loss: 1.2357141971588135
#
# Average loss: 1.2022, Accuracy: 523.0/790 (66%)
#
#
# Average loss: 1.2068, Accuracy: 1926.0/2940 (66%)
#
# Epoch: 9 	Training Accuracy: 66.20%
# Validation Accuracy: 65.51%
# Batch: 0, Loss: 1.1953606605529785
#
# Average loss: 1.1518, Accuracy: 564.0/790 (71%)
#
#
# Average loss: 1.1582, Accuracy: 2072.0/2940 (70%)
#
# Epoch: 10 	Training Accuracy: 71.39%
# Validation Accuracy: 70.48%
# Batch: 0, Loss: 1.212997317314148
#
# Average loss: 1.1027, Accuracy: 596.0/790 (75%)
#
#
# Average loss: 1.1108, Accuracy: 2192.0/2940 (75%)
#
# Epoch: 11 	Training Accuracy: 75.44%
# Validation Accuracy: 74.56%
# Batch: 0, Loss: 1.1180448532104492
#
# Average loss: 1.0554, Accuracy: 617.0/790 (78%)
#
#
# Average loss: 1.0653, Accuracy: 2284.0/2940 (78%)
#
# Epoch: 12 	Training Accuracy: 78.10%
# Validation Accuracy: 77.69%
# Batch: 0, Loss: 1.0991541147232056
#
# Average loss: 1.0094, Accuracy: 637.0/790 (81%)
#
#
# Average loss: 1.0209, Accuracy: 2351.0/2940 (80%)
#
# Epoch: 13 	Training Accuracy: 80.63%
# Validation Accuracy: 79.97%
# Batch: 0, Loss: 1.0075783729553223
#
# Average loss: 0.9650, Accuracy: 652.0/790 (83%)
#
#
# Average loss: 0.9786, Accuracy: 2404.0/2940 (82%)
#
# Epoch: 14 	Training Accuracy: 82.53%
# Validation Accuracy: 81.77%
# Batch: 0, Loss: 0.9983102083206177
#
# Average loss: 0.9221, Accuracy: 664.0/790 (84%)
#
#
# Average loss: 0.9381, Accuracy: 2446.0/2940 (83%)
#
# Epoch: 15 	Training Accuracy: 84.05%
# Validation Accuracy: 83.20%
# Batch: 0, Loss: 0.9540217518806458
#
# Average loss: 0.8808, Accuracy: 674.0/790 (85%)
#
#
# Average loss: 0.8993, Accuracy: 2474.0/2940 (84%)
#
# Epoch: 16 	Training Accuracy: 85.32%
# Validation Accuracy: 84.15%
# Batch: 0, Loss: 0.8613572120666504
#
# Average loss: 0.8414, Accuracy: 681.0/790 (86%)
#
#
# Average loss: 0.8620, Accuracy: 2496.0/2940 (85%)
#
# Epoch: 17 	Training Accuracy: 86.20%
# Validation Accuracy: 84.90%
# Batch: 0, Loss: 0.7809295058250427
#
# Average loss: 0.8037, Accuracy: 686.0/790 (87%)
#
#
# Average loss: 0.8265, Accuracy: 2512.0/2940 (85%)
#
# Epoch: 18 	Training Accuracy: 86.84%
# Validation Accuracy: 85.44%
# Batch: 0, Loss: 0.8240309953689575
#
# Average loss: 0.7676, Accuracy: 699.0/790 (88%)
#
#
# Average loss: 0.7928, Accuracy: 2543.0/2940 (86%)
#
# Epoch: 19 	Training Accuracy: 88.48%
# Validation Accuracy: 86.50%
#
# Average loss: 0.7676, Accuracy: 699.0/790 (88%)
#
#
# Average loss: 0.7848, Accuracy: 4234.0/4861 (87%)
# Running seeds for 0.05 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 52 =========================
# Batch: 0, Loss: 1.6642683744430542
#
# Average loss: 1.5530, Accuracy: 415.0/1320 (31%)
#
#
# Average loss: 1.5521, Accuracy: 978.0/2940 (33%)
#
# Epoch: 0 	Training Accuracy: 31.44%
# Validation Accuracy: 33.27%
# Batch: 0, Loss: 1.5592541694641113
#
# Average loss: 1.4557, Accuracy: 570.0/1320 (43%)
#
#
# Average loss: 1.4556, Accuracy: 1274.0/2940 (43%)
#
# Epoch: 1 	Training Accuracy: 43.18%
# Validation Accuracy: 43.33%
# Batch: 0, Loss: 1.4458646774291992
#
# Average loss: 1.3633, Accuracy: 687.0/1320 (52%)
#
#
# Average loss: 1.3643, Accuracy: 1516.0/2940 (52%)
#
# Epoch: 2 	Training Accuracy: 52.05%
# Validation Accuracy: 51.56%
# Batch: 0, Loss: 1.3551061153411865
#
# Average loss: 1.2744, Accuracy: 783.0/1320 (59%)
#
#
# Average loss: 1.2753, Accuracy: 1752.0/2940 (60%)
#
# Epoch: 3 	Training Accuracy: 59.32%
# Validation Accuracy: 59.59%
# Batch: 0, Loss: 1.2966926097869873
#
# Average loss: 1.1894, Accuracy: 878.0/1320 (67%)
#
#
# Average loss: 1.1898, Accuracy: 1981.0/2940 (67%)
#
# Epoch: 4 	Training Accuracy: 66.52%
# Validation Accuracy: 67.38%
# Batch: 0, Loss: 1.1682809591293335
#
# Average loss: 1.1071, Accuracy: 983.0/1320 (74%)
#
#
# Average loss: 1.1074, Accuracy: 2152.0/2940 (73%)
#
# Epoch: 5 	Training Accuracy: 74.47%
# ...
# Batch: 140, Loss: 0.10393565148115158
# Batch: 160, Loss: 0.2495153844356537
# Batch: 180, Loss: 0.11368274688720703
# Batch: 200, Loss: 0.16971825063228607
#
# Average loss: 0.1386, Accuracy: 24962.0/26038 (96%)
#
#
# Average loss: 0.1658, Accuracy: 2799.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 95.87%
# Validation Accuracy: 95.20%
# Batch: 0, Loss: 0.13558520376682281
# Batch: 20, Loss: 0.18232837319374084
# Batch: 40, Loss: 0.08886221796274185
# Batch: 60, Loss: 0.17552727460861206
# Batch: 80, Loss: 0.14360715448856354
# Batch: 100, Loss: 0.11516100913286209
# Batch: 120, Loss: 0.09448515623807907
# Batch: 140, Loss: 0.1567438393831253
# Batch: 160, Loss: 0.0981094166636467
# Batch: 180, Loss: 0.1658945083618164
# Batch: 200, Loss: 0.11745870113372803
#
# Average loss: 0.1377, Accuracy: 24941.0/26038 (96%)
#
#
# Average loss: 0.1649, Accuracy: 2801.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 95.79%
# Validation Accuracy: 95.27%
# Batch: 0, Loss: 0.14629772305488586
# Batch: 20, Loss: 0.17615771293640137
# Batch: 40, Loss: 0.07026802748441696
# Batch: 60, Loss: 0.12295900285243988
# Batch: 80, Loss: 0.10553152114152908
# Batch: 100, Loss: 0.2252454161643982
# Batch: 120, Loss: 0.11046738922595978
# Batch: 140, Loss: 0.16575174033641815
# Batch: 160, Loss: 0.1550230085849762
# Batch: 180, Loss: 0.0842534527182579
# Batch: 200, Loss: 0.1529831886291504
#
# Average loss: 0.1363, Accuracy: 24955.0/26038 (96%)
#
#
# Average loss: 0.1637, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 19 	Training Accuracy: 95.84%
# Validation Accuracy: 95.10%
#
# Average loss: 0.1363, Accuracy: 24955.0/26038 (96%)
#
#
# Average loss: 0.1465, Accuracy: 4638.0/4861 (95%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 61 =========================
# Batch: 0, Loss: 1.6970601081848145
# Batch: 20, Loss: 1.4626412391662598
# Batch: 40, Loss: 1.2725454568862915
# Batch: 60, Loss: 1.1327654123306274
# Batch: 80, Loss: 0.9876765012741089
# Batch: 100, Loss: 0.8334990739822388
# Batch: 120, Loss: 0.7479472756385803
# Batch: 140, Loss: 0.681422233581543
# Batch: 160, Loss: 0.5864613056182861
# Batch: 180, Loss: 0.5290484428405762
# Batch: 200, Loss: 0.4868808686733246
#
# Average loss: 0.4689, Accuracy: 23806.0/26038 (91%)
#
#
# Average loss: 0.4792, Accuracy: 2653.0/2940 (90%)
#
# Epoch: 0 	Training Accuracy: 91.43%
# Validation Accuracy: 90.24%
# Batch: 0, Loss: 0.45759227871894836
# Batch: 20, Loss: 0.4265066981315613
# Batch: 40, Loss: 0.3847595155239105
# Batch: 60, Loss: 0.400399386882782
# Batch: 80, Loss: 0.3991367518901825
# Batch: 100, Loss: 0.37535372376441956
# Batch: 120, Loss: 0.317329078912735
# Batch: 140, Loss: 0.2885206341743469
# Batch: 160, Loss: 0.2773696780204773
# Batch: 180, Loss: 0.23827038705348969
# Batch: 200, Loss: 0.3490813672542572
#
# Average loss: 0.2659, Accuracy: 24261.0/26038 (93%)
#
#
# Average loss: 0.2838, Accuracy: 2724.0/2940 (93%)
#
# Epoch: 1 	Training Accuracy: 93.18%
# Validation Accuracy: 92.65%
# Batch: 0, Loss: 0.33445999026298523
# Batch: 20, Loss: 0.25035619735717773
# Batch: 40, Loss: 0.26143041253089905
# Batch: 60, Loss: 0.20095151662826538
# Batch: 80, Loss: 0.24385207891464233
# Batch: 100, Loss: 0.18057972192764282
# Batch: 120, Loss: 0.2499542385339737
# Batch: 140, Loss: 0.25304052233695984
# Batch: 160, Loss: 0.24520759284496307
# Batch: 180, Loss: 0.19128063321113586
# Batch: 200, Loss: 0.26242199540138245
#
# Average loss: 0.2127, Accuracy: 24416.0/26038 (94%)
#
#
# Average loss: 0.2341, Accuracy: 2737.0/2940 (93%)
#
# Epoch: 2 	Training Accuracy: 93.77%
# Validation Accuracy: 93.10%
# Batch: 0, Loss: 0.20135720074176788
# Batch: 20, Loss: 0.20331032574176788
# Batch: 40, Loss: 0.20689350366592407
# Batch: 60, Loss: 0.19808441400527954
# Batch: 80, Loss: 0.16035105288028717
# Batch: 100, Loss: 0.21883752942085266
# Batch: 120, Loss: 0.16600309312343597
# Batch: 140, Loss: 0.21380089223384857
# Batch: 160, Loss: 0.2986566126346588
# Batch: 180, Loss: 0.26265209913253784
# Batch: 200, Loss: 0.2464579939842224
#
# Average loss: 0.1895, Accuracy: 24522.0/26038 (94%)
#
#
# Average loss: 0.2126, Accuracy: 2748.0/2940 (93%)
#
# Epoch: 3 	Training Accuracy: 94.18%
# Validation Accuracy: 93.47%
# Batch: 0, Loss: 0.1432664394378662
# Batch: 20, Loss: 0.13524973392486572
# Batch: 40, Loss: 0.15577462315559387
# Batch: 60, Loss: 0.2738574147224426
# Batch: 80, Loss: 0.13480672240257263
# Batch: 100, Loss: 0.18222831189632416
# Batch: 120, Loss: 0.19034931063652039
# Batch: 140, Loss: 0.13990682363510132
# Batch: 160, Loss: 0.21320249140262604
# Batch: 180, Loss: 0.16703316569328308
# Batch: 200, Loss: 0.1613544076681137
#
# Average loss: 0.1770, Accuracy: 24624.0/26038 (95%)
#
#
# Average loss: 0.2008, Accuracy: 2765.0/2940 (94%)
#
# Epoch: 4 	Training Accuracy: 94.57%
# Validation Accuracy: 94.05%
# Batch: 0, Loss: 0.222847118973732
# Batch: 20, Loss: 0.1507686823606491
# Batch: 40, Loss: 0.17039553821086884
# Batch: 60, Loss: 0.14998702704906464
# Batch: 80, Loss: 0.19120462238788605
# Batch: 100, Loss: 0.19072403013706207
# Batch: 120, Loss: 0.19351854920387268
# Batch: 140, Loss: 0.2971630394458771
# Batch: 160, Loss: 0.21258853375911713
# Batch: 180, Loss: 0.14118674397468567
# Batch: 200, Loss: 0.12303753942251205
#
# Average loss: 0.1682, Accuracy: 24686.0/26038 (95%)
#
#
# Average loss: 0.1939, Accuracy: 2768.0/2940 (94%)
#
# Epoch: 5 	Training Accuracy: 94.81%
# Validation Accuracy: 94.15%
# Batch: 0, Loss: 0.28344830870628357
# Batch: 20, Loss: 0.08331801742315292
# Batch: 40, Loss: 0.18808232247829437
# Batch: 60, Loss: 0.12847119569778442
# Batch: 80, Loss: 0.1537061333656311
# Batch: 100, Loss: 0.2850954532623291
# Batch: 120, Loss: 0.16850726306438446
# Batch: 140, Loss: 0.16225585341453552
# Batch: 160, Loss: 0.2708836793899536
# Batch: 180, Loss: 0.13714483380317688
# Batch: 200, Loss: 0.17819388210773468
#
# Average loss: 0.1617, Accuracy: 24712.0/26038 (95%)
#
#
# Average loss: 0.1887, Accuracy: 2771.0/2940 (94%)
#
# Epoch: 6 	Training Accuracy: 94.91%
# Validation Accuracy: 94.25%
# Batch: 0, Loss: 0.1424177885055542
# Batch: 20, Loss: 0.15389655530452728
# Batch: 40, Loss: 0.15741127729415894
# Batch: 60, Loss: 0.11729209870100021
# Batch: 80, Loss: 0.1639932245016098
# Batch: 100, Loss: 0.15113481879234314
# Batch: 120, Loss: 0.10916423797607422
# Batch: 140, Loss: 0.2726324200630188
# Batch: 160, Loss: 0.08780132234096527
# Batch: 180, Loss: 0.13975849747657776
# Batch: 200, Loss: 0.16967561841011047
#
# Average loss: 0.1576, Accuracy: 24729.0/26038 (95%)
#
#
# Average loss: 0.1859, Accuracy: 2781.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 94.97%
# Validation Accuracy: 94.59%
# Batch: 0, Loss: 0.33258044719696045
# Batch: 20, Loss: 0.2117030918598175
# Batch: 40, Loss: 0.16823634505271912
# Batch: 60, Loss: 0.19600912928581238
# Batch: 80, Loss: 0.12438739836215973
# Batch: 100, Loss: 0.08037719875574112
# Batch: 120, Loss: 0.174240380525589
# Batch: 140, Loss: 0.1998101770877838
# Batch: 160, Loss: 0.19148221611976624
# Batch: 180, Loss: 0.11856657266616821
# Batch: 200, Loss: 0.0991770550608635
#
# Average loss: 0.1536, Accuracy: 24768.0/26038 (95%)
#
#
# Average loss: 0.1809, Accuracy: 2786.0/2940 (95%)
#
# Epoch: 8 	Training Accuracy: 95.12%
# Validation Accuracy: 94.76%
# Batch: 0, Loss: 0.21574042737483978
# Batch: 20, Loss: 0.17007343471050262
# Batch: 40, Loss: 0.2510755956172943
# Batch: 60, Loss: 0.12395203858613968
# Batch: 80, Loss: 0.11562761664390564
# Batch: 100, Loss: 0.1484491378068924
# Batch: 120, Loss: 0.11270508915185928
# Batch: 140, Loss: 0.14461900293827057
# Batch: 160, Loss: 0.12136327475309372
# Batch: 180, Loss: 0.2818860113620758
# Batch: 200, Loss: 0.19980388879776
#
# Average loss: 0.1498, Accuracy: 24816.0/26038 (95%)
#
#
# Average loss: 0.1784, Accuracy: 2786.0/2940 (95%)
#
# Epoch: 9 	Training Accuracy: 95.31%
# Validation Accuracy: 94.76%
# Batch: 0, Loss: 0.1395929604768753
# Batch: 20, Loss: 0.1707598716020584
# Batch: 40, Loss: 0.12008435279130936
# Batch: 60, Loss: 0.11707787960767746
# Batch: 80, Loss: 0.12431789189577103
# Batch: 100, Loss: 0.23427405953407288
# Batch: 120, Loss: 0.21361736953258514
# Batch: 140, Loss: 0.09144645929336548
# Batch: 160, Loss: 0.09438283741474152
# Batch: 180, Loss: 0.18043479323387146
# Batch: 200, Loss: 0.1100812554359436
#
# Average loss: 0.1474, Accuracy: 24864.0/26038 (95%)
#
#
# Average loss: 0.1755, Accuracy: 2791.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 95.49%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.0772247314453125
# Batch: 20, Loss: 0.12196911871433258
# Batch: 40, Loss: 0.11102921515703201
# Batch: 60, Loss: 0.14144575595855713
# Batch: 80, Loss: 0.21857471764087677
# Batch: 100, Loss: 0.1036216989159584
# Batch: 120, Loss: 0.20130468904972076
# Batch: 140, Loss: 0.14122281968593597
# Batch: 160, Loss: 0.11921811103820801
# Batch: 180, Loss: 0.1279798001050949
# Batch: 200, Loss: 0.0749533399939537
#
# Average loss: 0.1460, Accuracy: 24857.0/26038 (95%)
#
#
# Average loss: 0.1746, Accuracy: 2790.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 95.46%
# Validation Accuracy: 94.90%
# Batch: 0, Loss: 0.13897156715393066
# Batch: 20, Loss: 0.17233383655548096
# Batch: 40, Loss: 0.10297564417123795
# Batch: 60, Loss: 0.15213921666145325
# Batch: 80, Loss: 0.12832210958003998
# Batch: 100, Loss: 0.14470809698104858
# Batch: 120, Loss: 0.14469848573207855
# Batch: 140, Loss: 0.25375524163246155
# Batch: 160, Loss: 0.1867622584104538
# Batch: 180, Loss: 0.0958760678768158
# Batch: 200, Loss: 0.26243826746940613
#
# Average loss: 0.1437, Accuracy: 24880.0/26038 (96%)
#
#
# Average loss: 0.1732, Accuracy: 2795.0/2940 (95%)
#
# Epoch: 12 	Training Accuracy: 95.55%
# Validation Accuracy: 95.07%
# Batch: 0, Loss: 0.11891059577465057
# Batch: 20, Loss: 0.16482007503509521
# Batch: 40, Loss: 0.19260522723197937
# Batch: 60, Loss: 0.19404612481594086
# Batch: 80, Loss: 0.08256803452968597
# Batch: 100, Loss: 0.18058788776397705
# Batch: 120, Loss: 0.22552785277366638
# Batch: 140, Loss: 0.08356466889381409
# Batch: 160, Loss: 0.17217300832271576
# Batch: 180, Loss: 0.15613378584384918
# Batch: 200, Loss: 0.1163652092218399
#
# Average loss: 0.1422, Accuracy: 24917.0/26038 (96%)
#
#
# Average loss: 0.1716, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 13 	Training Accuracy: 95.69%
# Validation Accuracy: 95.10%
# Batch: 0, Loss: 0.1508573740720749
# Batch: 20, Loss: 0.12400319427251816
# Batch: 40, Loss: 0.143284410238266
# Batch: 60, Loss: 0.06807523965835571
# Batch: 80, Loss: 0.06598680466413498
# Batch: 100, Loss: 0.13384203612804413
# Batch: 120, Loss: 0.0880744680762291
# Batch: 140, Loss: 0.09884493798017502
# Batch: 160, Loss: 0.1468489021062851
# Batch: 180, Loss: 0.164559006690979
# Batch: 200, Loss: 0.08245367556810379
#
# Average loss: 0.1417, Accuracy: 24929.0/26038 (96%)
#
#
# Average loss: 0.1718, Accuracy: 2794.0/2940 (95%)
#
# Epoch: 14 	Training Accuracy: 95.74%
# Validation Accuracy: 95.03%
# Batch: 0, Loss: 0.18810465931892395
# Batch: 20, Loss: 0.16663852334022522
# Batch: 40, Loss: 0.19478338956832886
# Batch: 60, Loss: 0.04904751852154732
# Batch: 80, Loss: 0.1424700915813446
# Batch: 100, Loss: 0.13309408724308014
# Batch: 120, Loss: 0.12624035775661469
# Batch: 140, Loss: 0.07522720098495483
# Batch: 160, Loss: 0.07722561061382294
# Batch: 180, Loss: 0.07505015283823013
# Batch: 200, Loss: 0.28465357422828674
#
# Average loss: 0.1397, Accuracy: 24948.0/26038 (96%)
#
#
# Average loss: 0.1692, Accuracy: 2795.0/2940 (95%)
#
# Epoch: 15 	Training Accuracy: 95.81%
# Validation Accuracy: 95.07%
# Batch: 0, Loss: 0.14397995173931122
# Batch: 20, Loss: 0.12059877067804337
# Batch: 40, Loss: 0.06737376004457474
# Batch: 60, Loss: 0.1326814740896225
# Batch: 80, Loss: 0.09198884665966034
# Batch: 100, Loss: 0.14459240436553955
# Batch: 120, Loss: 0.11787336319684982
# Batch: 140, Loss: 0.12410997599363327
# Batch: 160, Loss: 0.08264684677124023
# Batch: 180, Loss: 0.11792448163032532
# Batch: 200, Loss: 0.12731894850730896
#
# Average loss: 0.1384, Accuracy: 24942.0/26038 (96%)
#
#
# Average loss: 0.1680, Accuracy: 2795.0/2940 (95%)
#
# Epoch: 16 	Training Accuracy: 95.79%
# Validation Accuracy: 95.07%
# Batch: 0, Loss: 0.18912404775619507
# Batch: 20, Loss: 0.10343489795923233
# Batch: 40, Loss: 0.16009093821048737
# Batch: 60, Loss: 0.17917442321777344
# Batch: 80, Loss: 0.19043399393558502
# Batch: 100, Loss: 0.18636643886566162
# Batch: 120, Loss: 0.18535180389881134
# Batch: 140, Loss: 0.1782379001379013
# Batch: 160, Loss: 0.0887470468878746
# Batch: 180, Loss: 0.12949241697788239
# Batch: 200, Loss: 0.12416020035743713
#
# Average loss: 0.1375, Accuracy: 24962.0/26038 (96%)
#
#
# Average loss: 0.1676, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 95.87%
# Validation Accuracy: 95.10%
# Batch: 0, Loss: 0.19831568002700806
# Batch: 20, Loss: 0.11809103935956955
# Batch: 40, Loss: 0.12007669359445572
# Batch: 60, Loss: 0.12724335491657257
# Batch: 80, Loss: 0.09591600298881531
# Batch: 100, Loss: 0.12078945338726044
# Batch: 120, Loss: 0.09229933470487595
# Batch: 140, Loss: 0.1347062587738037
# Batch: 160, Loss: 0.12191443890333176
# Batch: 180, Loss: 0.19333668053150177
# Batch: 200, Loss: 0.07866501808166504
#
# Average loss: 0.1383, Accuracy: 24913.0/26038 (96%)
#
#
# Average loss: 0.1665, Accuracy: 2797.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 95.68%
# Validation Accuracy: 95.14%
# Batch: 0, Loss: 0.07837823778390884
# Batch: 20, Loss: 0.09779134392738342
# Batch: 40, Loss: 0.1455625295639038
# Batch: 60, Loss: 0.21561789512634277
# Batch: 80, Loss: 0.0976003110408783
# Batch: 100, Loss: 0.08258871734142303
# Batch: 120, Loss: 0.11566860228776932
# Batch: 140, Loss: 0.07113146781921387
# Batch: 160, Loss: 0.15196076035499573
# Batch: 180, Loss: 0.12474602460861206
# Batch: 200, Loss: 0.11299095302820206
#
# Average loss: 0.1369, Accuracy: 24962.0/26038 (96%)
#
#
# Average loss: 0.1682, Accuracy: 2800.0/2940 (95%)
#
# Epoch: 19 	Training Accuracy: 95.87%
# Validation Accuracy: 95.24%
#
# Average loss: 0.1369, Accuracy: 24962.0/26038 (96%)
#
#
# Average loss: 0.1465, Accuracy: 4640.0/4861 (95%)
#
# Percentage: 0.01, Seed: 10, Epochs taken: 20
# Percentage: 0.01, Seed: 20, Epochs taken: 20
# Percentage: 0.01, Seed: 30, Epochs taken: 20
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 20
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 20
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 20
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 20
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 20
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 20
# Percentage: 1, Seed: 40, Epochs taken: 20
# Percentage: 1, Seed: 50, Epochs taken: 20

# %%
# End to End - Train Accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Train Accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Train Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Train Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
# End to End - Test Accuracies
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]

plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Test Accuracies
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Test Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Test Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
data_to_save = {
    "results_test_finetune": results_test_finetune,
    "results_train_finetune": results_train_finetune,
    "epochs_taken_finetune": epochs_taken_finetune,
    
    "results_test": results_test,
    "results_train": results_train,
    "epochs_taken": epochs_taken
}

# Assuming data_to_save from the previous code
with open("data.json", "w") as file:
    json.dump(data_to_save, file)

# %%
plt.figure(figsize=(10, 6))

for perc in percentages:
    plt.scatter(epochs_taken[perc], epochs_taken_finetune[perc], label=f'{perc} data')
plt.xlabel('Epochs (End to End)')
plt.ylabel('Epochs (Finetune)')
plt.title('Scatter Plot Comparing Epochs Taken for Convergence')
plt.legend()
plt.show()

# %%
# Given data
percentages = list(epochs_taken.keys())

all_epochs = []
labels = []

for perc in percentages:
    all_epochs.extend([epochs_taken[perc], epochs_taken_finetune[perc]])
    labels.extend([f'{perc} End to End', f'{perc} Finetune'])

# Plotting
plt.figure(figsize=(10, 6))
box = plt.boxplot(all_epochs, labels=labels, patch_artist=True)

# Coloring
colors = ['skyblue', 'lightgreen'] * len(percentages)
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

plt.ylabel('Epochs Taken')
plt.title('Box Plot of Epochs Taken for Each Percentage')
plt.xticks(rotation=90)
plt.show()

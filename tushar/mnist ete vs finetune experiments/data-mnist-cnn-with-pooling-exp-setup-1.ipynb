# %% [markdown]
# ***EXPERIMENT SETUP***

# %% [markdown]
# - percentages_set_1 = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
# - dataset: same as before MNIST 5 to 5
#
# - lr pretraining = 0.001
# - lr finetuning = 0.0001
#
# - architecture:
#     - Conv 1 (5,5), channels = 1
#     - Relu
#     - Conv 2 (5,5,), channels = 1
#     - Relu
#     - Pooling: TRUE
#     - dense( x, x) x=output shape of prev layer (128?)
#     - Relu
#     - dense(x, 5)
#     - softmax
#
# - Freezing: NO
# - Reinitializing: NO for CNN layers. For dense, reinit last dense and softmax, but also try BOTH (time permitting)
#
# - If we don’t save the best model, ES=6
#
# - num train = 20

# %% [markdown]
# ***IMPORTS***

# %%
import numpy as np
import random
import copy
import matplotlib.pyplot as plt
import json

# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from torchvision import datasets, transforms

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from types import SimpleNamespace
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ***UTILS***

# %%
def eval(model, device, dataset_loader, debug=False, classification_report_flag=False, is_cnn=True, logger=print):

    """
    Evaluates the model on the given dataset loader.

    Parameters:
    - model: the PyTorch model to evaluate.
    - device: the device to which tensors should be moved before computation.
    - dataset_loader: DataLoader for evaluation.
    - debug: whether to print debug info like loss and accuracy.
    - classification_report_flag: whether to print a classification report.
    - is_cnn: a flag indicating if the model is a CNN. If it's not, the input data will be reshaped.
    - logger: logging function for printing messages.

    Returns:
    - Accuracy of the model on the provided dataset loader.

    Usage:
    - accuracy = eval(model, device, dataset_loader, debug=False, is_cnn=False, classification_report_flag=False)
    """

    model.eval()
    test_loss, correct = 0., 0.
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data, target in dataset_loader:
            if is_cnn:
              data = data.view(data.size(0), 1, 28, 28)
            else:
              data = data.reshape([data.shape[0], -1])
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(target.cpu().numpy())

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data

    if debug:
        logger('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(test_loss, correct, num_data, 100. * acc))

    if classification_report_flag:
        unique_labels = np.unique(all_labels).tolist()
        logger(classification_report(all_labels, all_preds, labels=unique_labels, target_names=[f'Class {i}' for i in unique_labels]))

    return acc

# %%
class Trainer:

    """
    A class for training and evaluating a model with early stopping and best model saving functionalities.

    Attributes:
    - model: PyTorch model to be trained and evaluated.
    - dataloader: Contains data loaders (train, validation, test) for training and evaluation.
    - params: Dictionary containing various hyperparameters and settings.
    - device: the device to which tensors should be moved before computation.
    - optimizer: The optimizer for training.
    - best_model_state: State dictionary of the best model.
    - max_val_acc: The highest validation accuracy encountered during training.
    - no_improve_epochs: Number of epochs without improvement in validation accuracy.
    - is_cnn: Flag indicating if the model is a CNN.
    - is_debug: Flag indicating if debug information should be printed.
    - classification_report_flag: Flag indicating if a classification report should be generated.

    Methods:
    - train_epoch(): Runs a single epoch of training.
    - evaluate(loader): Evaluates the model on a given data loader.
    - save_best_model(): Saves the current state of the model as the best model.
    - save_checkpoint(epoch, train_acc, val_acc): Saves the current state of the model and other information as a checkpoint.
    - early_stopping_check(val_acc): Checks the stopping criterion and performs actions based on it.
    - train(): Runs the training process for a number of epochs, with early stopping functionality.

    Usage:
    params = {
      'device': 'cuda',
      'lr': 0.001,
      'num_train': 10,
      'early_stop_patience': 3,
      'save_best': True,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': True
    }

    trainer = Trainer(model, dataloader, params)
    train_acc, test_acc, effective_epochs, checkpoints = trainer.train()
    """


    def __init__(self, model, dataloader, params):
        self.model = model
        self.dataloader = dataloader
        self.params = params

        self.device = torch.device(params['device'])
        self.optimizer = optim.Adam(model.parameters(), lr=params['lr'])

        # Initialize best_model_state with the current model state
        self.best_model_state = copy.deepcopy(self.model.state_dict())
        self.max_val_acc = 0.
        self.no_improve_epochs = 0

        self.is_cnn = params.get('is_cnn', False)
        self.is_debug = params.get('is_debug', False)
        self.classification_report_flag = params.get('classification_report_flag', False)
        self.logger = params.get('logger', print)
        
    def train_epoch(self):
      self.model.train()
      for batch_idx, (data, target) in enumerate(self.dataloader.train_loader):

          # Print the size of the current batch
          if self.is_cnn:
            data = data.view(data.size(0), 1, 28, 28)
          else:
            data = data.reshape([data.shape[0], -1])

          data, target = data.to(self.device), target.to(self.device)
          self.optimizer.zero_grad()
          output = self.model(data)
          loss = F.nll_loss(output, target)
          loss.backward()
          self.optimizer.step()

          if self.is_debug and batch_idx % 20 == 0:
              self.logger(f"Batch: {batch_idx}, Loss: {loss.item()}")

    def evaluate(self, loader):
        return eval(self.model, self.device, loader, self.is_debug, self.classification_report_flag, self.is_cnn)

    def save_best_model(self):
        torch.save(self.model.state_dict(), 'best_model.pth')

    def save_checkpoint(self, epoch, train_acc, val_acc):
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'train_acc': train_acc,
            'val_acc': val_acc
        }
        torch.save(checkpoint, f'checkpoint_epoch_{epoch}.pth')
        return checkpoint

    def early_stopping_check(self, val_acc):
        if val_acc > self.max_val_acc:
            self.max_val_acc = val_acc
            self.no_improve_epochs = 0
            # Deep copy the model's state
            self.best_model_state = copy.deepcopy(self.model.state_dict())
            if self.params.get('save_best', False):
                self.save_best_model()
        else:
            self.no_improve_epochs += 1
            if self.no_improve_epochs >= self.params['early_stop_patience']:
                self.logger("Early stopping invoked.")
                # Only load if best_model_state has been set
                if self.best_model_state is not None:
                    self.model.load_state_dict(self.best_model_state)
                return True
        return False

    def train(self):
        effective_epochs = 0
        checkpoints = []

        for epoch in range(self.params['num_train']):
            effective_epochs += 1
            self.train_epoch()

            train_acc = self.evaluate(self.dataloader.train_loader)
            val_acc = self.evaluate(self.dataloader.val_loader)
            self.logger(f'Epoch: {epoch} \tTraining Accuracy: {train_acc*100:.2f}%')
            self.logger(f'Validation Accuracy: {val_acc*100:.2f}%')

            if self.params.get('early_stop_patience', None):
                if self.early_stopping_check(val_acc):
                    self.model.load_state_dict(self.best_model_state)
                    break

            if self.params.get('save_checkpoints', False):
                checkpoint = self.save_checkpoint(epoch, train_acc, val_acc)
                checkpoints.append(checkpoint)

        # Final evaluations
        train_acc = self.evaluate(self.dataloader.train_loader)
        test_acc = self.evaluate(self.dataloader.test_loader)

        return train_acc, test_acc, effective_epochs, checkpoints

# %%
def reduce_dataset(dataloader, percentage, balanced=True, seed=42):

    """
    Reduces the dataset to the given percentage. Can ensure class balance if needed.

    Parameters:
    - dataloader: PyTorch DataLoader object.
    - percentage: Desired percentage of the original dataset.
    - balanced: If True, ensures class balance. If False, reduces randomly.
    - seed: Seed for reproducibility.

    Returns:
    - reduced_dataloader: DataLoader with the reduced dataset.
    """
    # Extract the dataset from the dataloader
    dataset = dataloader.dataset

    # Extract all data and labels from the dataset
    X = [dataset[i][0] for i in range(len(dataset))]
    y = [dataset[i][1] for i in range(len(dataset))]

    # Set the seed for reproducibility
    torch.manual_seed(seed)

    if not balanced:
        # Determine the number of samples to keep
        num_samples = int(len(dataset) * percentage)

        # Randomly select indices without replacement
        indices = torch.randperm(len(dataset))[:num_samples].tolist()

    else:
        # Get unique classes and their counts
        classes, class_counts = torch.unique(torch.tensor(y), return_counts=True)

        # Determine the number of samples per class to keep
        num_samples_per_class = int(len(dataset) * percentage / len(classes))
        indices = []

        for class_label in classes:
            class_indices = [i for i, label in enumerate(y) if label == class_label]

            # Randomly select indices without replacement for each class
            class_selected_indices = torch.randperm(len(class_indices))[:num_samples_per_class].tolist()
            indices.extend([class_indices[i] for i in class_selected_indices])

    # Use a Subset of the original dataset to create a reduced dataset
    reduced_dataset = data.Subset(dataset, indices)

    # Create a DataLoader with the reduced dataset.
    reduced_dataloader = data.DataLoader(reduced_dataset, batch_size=dataloader.batch_size, shuffle=True)

    return reduced_dataloader

# %%
class RelabeledSubset(torch.utils.data.Dataset):
    def __init__(self, dataset, offset):
        self.dataset = dataset
        self.offset = offset

    def __getitem__(self, idx):
        data, label = self.dataset[idx]
        # Offset the label to start from 0
        label = label - self.offset
        return data, label

    def __len__(self):
        return len(self.dataset)

# %%
class TransferLearningMNIST(object):
    def __init__(self, batch_size, input_dim=28*28, val_split=0.1, num_workers=4):
        self.input_dim = input_dim
        self.output_dim = 10
        self.val_split = val_split

        def filter_dataset(dataset, classes):
            indices = [i for i, t in enumerate(dataset.targets) if t in classes]
            return torch.utils.data.Subset(dataset, indices)

        mnist_train_data = datasets.MNIST(
            '../data',
            train=True,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_train_data = filter_dataset(mnist_train_data, list(range(5)))
        finetune_train_data = filter_dataset(mnist_train_data, list(range(5, 10)))

        pretrain_len = len(pretrain_train_data)
        finetune_len = len(finetune_train_data)
        pretrain_val_len = int(val_split * pretrain_len)
        finetune_val_len = int(val_split * finetune_len)
        SEED = 42
        pretrain_train_set, pretrain_val_set = torch.utils.data.random_split(
            pretrain_train_data, [pretrain_len - pretrain_val_len, pretrain_val_len], generator=torch.Generator().manual_seed(SEED))
        finetune_train_set, finetune_val_set = torch.utils.data.random_split(
            finetune_train_data, [finetune_len - finetune_val_len, finetune_val_len], generator=torch.Generator().manual_seed(SEED))

        self.pretrain_train_loader = torch.utils.data.DataLoader(pretrain_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.pretrain_val_loader = torch.utils.data.DataLoader(pretrain_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning datasets
        finetune_train_set = RelabeledSubset(finetune_train_set, 5)
        finetune_val_set = RelabeledSubset(finetune_val_set, 5)

        self.finetune_train_loader = torch.utils.data.DataLoader(finetune_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.finetune_val_loader = torch.utils.data.DataLoader(finetune_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        mnist_test_data = datasets.MNIST(
            '../data',
            train=False,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_test_data = filter_dataset(mnist_test_data, list(range(5)))
        finetune_test_data = filter_dataset(mnist_test_data, list(range(5, 10)))

        self.pretrain_test_loader = torch.utils.data.DataLoader(pretrain_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning test datasets
        finetune_test_data = RelabeledSubset(finetune_test_data, 5)
        self.finetune_test_loader = torch.utils.data.DataLoader(finetune_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        # Complete test loader contains all test examples.
        self.complete_test_loader = torch.utils.data.DataLoader(mnist_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
class TransferLearningMNISTWrapper:
    """
    This wrapper class provides a convenient way to switch between pretraining and fine-tuning phases.

    It allows for changing the phase and accordingly updating the data loaders (train, val, test)
    to either pretraining or fine-tuning sets.
    """
    def __init__(self, transferLearningMNISTObj, phase):
        """
        Initializes the TransferLearningMNISTWrapper object.

        Parameters:
        - transferLearningMNISTObj: An instance of the TransferLearningMNIST class.
        - phase: String indicating the current phase ("pretrain" or "finetune").
        """
        self.transferLearningMNISTObj = transferLearningMNISTObj
        self.phase = phase
        self.input_dim = self.transferLearningMNISTObj.input_dim
        self.output_dim = self.transferLearningMNISTObj.output_dim
        self.update_phase(phase)

    def update_phase(self, phase):
        """
        Updates the phase and the corresponding data loaders.

        Parameters:
        - phase: String indicating the desired phase ("pretrain" or "finetune").

        Throws:
        - ValueError: If the phase is neither "pretrain" nor "finetune".
        """
        self.phase = phase
        if phase == 'pretrain':
            self.train_loader = self.transferLearningMNISTObj.pretrain_train_loader
            self.val_loader = self.transferLearningMNISTObj.pretrain_val_loader
            self.test_loader = self.transferLearningMNISTObj.pretrain_test_loader
        elif phase == 'finetune':
            self.train_loader = self.transferLearningMNISTObj.finetune_train_loader
            self.val_loader = self.transferLearningMNISTObj.finetune_val_loader
            self.test_loader = self.transferLearningMNISTObj.finetune_test_loader
        else:
            raise ValueError('Phase must be either "pretrain" or "finetune".')

    def get_current_phase(self):
      return self.phase

# %%
class CustomCNN(nn.Module):
    def __init__(self, input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling=True):
        super(CustomCNN, self).__init__()

        # Initial number of input channels, assuming grayscale images
        in_channels = 1

        # Dynamically add convolutional and activation layers based on the specified depth
        for i in range(depth):
            # Create a convolutional layer and add it to the model
            setattr(self, f"conv{i}", nn.Conv2d(in_channels, num_channels, kernel_size=kernel_size, padding=1))

            # Create an activation layer (e.g., ReLU) and add it to the model
            setattr(self, f"act{i}", activation_function())

            # Update the input dimensions after convolution
            input_dim = (input_dim - kernel_size + 2 * 1) + 1

            # Optionally add pooling layers to reduce spatial dimensions
            if use_pooling and i % 2 == 1:
                setattr(self, f"pool{i}", nn.MaxPool2d(2))
                input_dim = input_dim // 2

            # Update the input channels for the next convolutional layer
            in_channels = num_channels

        # Compute the size of the flattened features for the fully connected layer
        flattened_size = in_channels * input_dim * input_dim

        # Add two fully connected layers for classification
        self.fc_1 = nn.Linear(flattened_size, hidden_dim_lin)
        self.fc_2 = nn.Linear(hidden_dim_lin, output_dim)

        # Add log softmax layer for multi-class classification output
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
      # Iterate over each module in the CustomCNN class
      for layer_name, layer in self.named_children():
          # Process the input tensor through convolutional and activation layers
          if "conv" in layer_name or "act" in layer_name:
              x = layer(x)
          # Process the input tensor through pooling layers if they exist
          elif "pool" in layer_name:
              x = layer(x)
          # If reached fully connected layers, break the loop
          elif isinstance(layer, nn.Linear):
              break

      # Flatten the tensor to fit the input shape of the fully connected layers
      x = x.view(x.size(0), -1)

      # Pass the tensor through the fully connected layers
      x = self.fc_1(x)
      x = self.fc_2(x)

      # Return log softmax activated output
      return self.logsoftmax(x)

# %%
def generate_cnn(input_dim, output_dim, depth, num_channels, hidden_dim_lin, kernel_size, activation_function=nn.ReLU, use_pooling=True):
    model = CustomCNN(input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling)
    return model

# %% [markdown]
# ***PRE-TRAINING***

# %%
batch_size = 128

dataloader = TransferLearningMNIST(batch_size)
dataloader_wrapped = TransferLearningMNISTWrapper(dataloader, phase = 'pretrain')

# %%
a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        break

# %%
params = {
      'depth': 2,
      'width': 1,
      'hidden_dim_lin': 128,
      'activation_function': nn.ReLU,
      'kernel_size': 5,
      'device': device,
      'lr': 0.001,
      'num_train': 20,
      'early_stop_patience': 6,
      'save_best': True,
      'save_checkpoints': True,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': False
    }

# Create DNN model
model = generate_cnn(input_dim = 28, output_dim = 10, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
model
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
# Train and evaluate
trainer = Trainer(model, dataloader_wrapped, params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Batch: 0, Loss: 2.3095815181732178
# Batch: 20, Loss: 1.72598397731781
# Batch: 40, Loss: 1.615909457206726
# Batch: 60, Loss: 1.4308514595031738
# Batch: 80, Loss: 0.7935433983802795
# Batch: 100, Loss: 0.3157154619693756
# Batch: 120, Loss: 0.14666739106178284
# Batch: 140, Loss: 0.2401275634765625
# Batch: 160, Loss: 0.08310997486114502
# Batch: 180, Loss: 0.1749996542930603
# Batch: 200, Loss: 0.11625810712575912
#
# Average loss: 0.1543, Accuracy: 26235.0/27537 (95%)
#
#
# Average loss: 0.1776, Accuracy: 2892.0/3059 (95%)
#
# Epoch: 0 	Training Accuracy: 95.27%
# Validation Accuracy: 94.54%
# Batch: 0, Loss: 0.23274321854114532
# Batch: 20, Loss: 0.2530253827571869
# Batch: 40, Loss: 0.11001688241958618
# Batch: 60, Loss: 0.11883228272199631
# Batch: 80, Loss: 0.17653609812259674
# Batch: 100, Loss: 0.19826404750347137
# Batch: 120, Loss: 0.14518329501152039
# Batch: 140, Loss: 0.07072363793849945
# Batch: 160, Loss: 0.1281173974275589
# Batch: 180, Loss: 0.11690007895231247
# Batch: 200, Loss: 0.16385044157505035
#
# Average loss: 0.1288, Accuracy: 26414.0/27537 (96%)
#
#
# Average loss: 0.1491, Accuracy: 2915.0/3059 (95%)
#
# Epoch: 1 	Training Accuracy: 95.92%
# Validation Accuracy: 95.29%
# Batch: 0, Loss: 0.10537014901638031
# Batch: 20, Loss: 0.16208869218826294
# Batch: 40, Loss: 0.06023840978741646
# Batch: 60, Loss: 0.10800457745790482
# Batch: 80, Loss: 0.07415676862001419
# Batch: 100, Loss: 0.16632603108882904
# Batch: 120, Loss: 0.16034208238124847
# Batch: 140, Loss: 0.10058853775262833
# Batch: 160, Loss: 0.11908268183469772
# Batch: 180, Loss: 0.07156683504581451
# Batch: 200, Loss: 0.1628979593515396
#
# Average loss: 0.1173, Accuracy: 26512.0/27537 (96%)
#
#
# Average loss: 0.1352, Accuracy: 2921.0/3059 (95%)
#
# Epoch: 2 	Training Accuracy: 96.28%
# Validation Accuracy: 95.49%
# Batch: 0, Loss: 0.1693098545074463
# Batch: 20, Loss: 0.14984259009361267
# Batch: 40, Loss: 0.06146978959441185
# Batch: 60, Loss: 0.04833091050386429
# Batch: 80, Loss: 0.302796334028244
# Batch: 100, Loss: 0.07475923001766205
# Batch: 120, Loss: 0.1003069207072258
# Batch: 140, Loss: 0.10918272286653519
# Batch: 160, Loss: 0.11593333631753922
# Batch: 180, Loss: 0.10506117343902588
# Batch: 200, Loss: 0.1537790596485138
#
# Average loss: 0.1062, Accuracy: 26629.0/27537 (97%)
#
#
# Average loss: 0.1241, Accuracy: 2936.0/3059 (96%)
#
# Epoch: 3 	Training Accuracy: 96.70%
# Validation Accuracy: 95.98%
# Batch: 0, Loss: 0.12017035484313965
# Batch: 20, Loss: 0.042752835899591446
# Batch: 40, Loss: 0.04265773668885231
# Batch: 60, Loss: 0.09035325050354004
# Batch: 80, Loss: 0.09046974033117294
# Batch: 100, Loss: 0.11222878098487854
# Batch: 120, Loss: 0.13587686419487
# Batch: 140, Loss: 0.12691541016101837
# Batch: 160, Loss: 0.11977031826972961
# Batch: 180, Loss: 0.14454777538776398
# Batch: 200, Loss: 0.13454380631446838
#
# Average loss: 0.1024, Accuracy: 26673.0/27537 (97%)
#
#
# Average loss: 0.1187, Accuracy: 2943.0/3059 (96%)
#
# Epoch: 4 	Training Accuracy: 96.86%
# Validation Accuracy: 96.21%
# Batch: 0, Loss: 0.12477243691682816
# Batch: 20, Loss: 0.09565789252519608
# Batch: 40, Loss: 0.12832511961460114
# Batch: 60, Loss: 0.20294007658958435
# Batch: 80, Loss: 0.036143168807029724
# Batch: 100, Loss: 0.143599271774292
# Batch: 120, Loss: 0.18806685507297516
# Batch: 140, Loss: 0.07582926005125046
# Batch: 160, Loss: 0.1419803649187088
# Batch: 180, Loss: 0.07675310224294662
# Batch: 200, Loss: 0.0970456451177597
#
# Average loss: 0.1091, Accuracy: 26562.0/27537 (96%)
#
#
# Average loss: 0.1249, Accuracy: 2931.0/3059 (96%)
#
# Epoch: 5 	Training Accuracy: 96.46%
# Validation Accuracy: 95.82%
# Batch: 0, Loss: 0.17389719188213348
# Batch: 20, Loss: 0.060643021017313004
# Batch: 40, Loss: 0.17883093655109406
# Batch: 60, Loss: 0.17316482961177826
# Batch: 80, Loss: 0.13116267323493958
# Batch: 100, Loss: 0.07547213137149811
# Batch: 120, Loss: 0.10438543558120728
# Batch: 140, Loss: 0.07421845197677612
# Batch: 160, Loss: 0.09346966445446014
# Batch: 180, Loss: 0.1527729481458664
# Batch: 200, Loss: 0.10755494982004166
#
# Average loss: 0.0966, Accuracy: 26694.0/27537 (97%)
#
#
# Average loss: 0.1122, Accuracy: 2942.0/3059 (96%)
#
# Epoch: 6 	Training Accuracy: 96.94%
# Validation Accuracy: 96.18%
# Batch: 0, Loss: 0.053619347512722015
# Batch: 20, Loss: 0.06724561750888824
# Batch: 40, Loss: 0.10666411370038986
# Batch: 60, Loss: 0.07815511524677277
# Batch: 80, Loss: 0.11550287157297134
# Batch: 100, Loss: 0.06319020688533783
# Batch: 120, Loss: 0.10417478531599045
# Batch: 140, Loss: 0.07351221889257431
# Batch: 160, Loss: 0.0831143781542778
# Batch: 180, Loss: 0.08216999471187592
# Batch: 200, Loss: 0.13983310759067535
#
# Average loss: 0.0931, Accuracy: 26746.0/27537 (97%)
#
#
# Average loss: 0.1066, Accuracy: 2958.0/3059 (97%)
#
# Epoch: 7 	Training Accuracy: 97.13%
# Validation Accuracy: 96.70%
# Batch: 0, Loss: 0.09096435457468033
# Batch: 20, Loss: 0.09273830056190491
# Batch: 40, Loss: 0.16539433598518372
# Batch: 60, Loss: 0.03823632374405861
# Batch: 80, Loss: 0.1263267546892166
# Batch: 100, Loss: 0.03199787065386772
# Batch: 120, Loss: 0.07487978041172028
# Batch: 140, Loss: 0.059161946177482605
# Batch: 160, Loss: 0.18372391164302826
# Batch: 180, Loss: 0.060898009687662125
# Batch: 200, Loss: 0.08191720396280289
#
# Average loss: 0.0911, Accuracy: 26776.0/27537 (97%)
#
#
# Average loss: 0.1075, Accuracy: 2954.0/3059 (97%)
#
# Epoch: 8 	Training Accuracy: 97.24%
# Validation Accuracy: 96.57%
# Batch: 0, Loss: 0.05856506898999214
# Batch: 20, Loss: 0.10934248566627502
# Batch: 40, Loss: 0.10779162496328354
# Batch: 60, Loss: 0.10350026190280914
# Batch: 80, Loss: 0.19389420747756958
# Batch: 100, Loss: 0.1095634251832962
# Batch: 120, Loss: 0.05212908238172531
# Batch: 140, Loss: 0.12796375155448914
# Batch: 160, Loss: 0.03918564319610596
# Batch: 180, Loss: 0.16503632068634033
# Batch: 200, Loss: 0.2026556432247162
#
# Average loss: 0.0909, Accuracy: 26775.0/27537 (97%)
#
#
# Average loss: 0.1074, Accuracy: 2955.0/3059 (97%)
#
# Epoch: 9 	Training Accuracy: 97.23%
# Validation Accuracy: 96.60%
# Batch: 0, Loss: 0.06057348474860191
# Batch: 20, Loss: 0.18923881649971008
# Batch: 40, Loss: 0.14861243963241577
# Batch: 60, Loss: 0.07792655378580093
# Batch: 80, Loss: 0.17566122114658356
# Batch: 100, Loss: 0.10285545140504837
# Batch: 120, Loss: 0.15457884967327118
# Batch: 140, Loss: 0.11968191713094711
# Batch: 160, Loss: 0.029263891279697418
# Batch: 180, Loss: 0.1373094618320465
# Batch: 200, Loss: 0.07469300925731659
#
# Average loss: 0.0969, Accuracy: 26712.0/27537 (97%)
#
#
# Average loss: 0.1169, Accuracy: 2959.0/3059 (97%)
#
# Epoch: 10 	Training Accuracy: 97.00%
# Validation Accuracy: 96.73%
# Batch: 0, Loss: 0.1355222463607788
# Batch: 20, Loss: 0.0990012064576149
# Batch: 40, Loss: 0.07813311368227005
# Batch: 60, Loss: 0.038148995488882065
# Batch: 80, Loss: 0.12533625960350037
# Batch: 100, Loss: 0.11086906492710114
# Batch: 120, Loss: 0.0551588237285614
# Batch: 140, Loss: 0.1041228398680687
# Batch: 160, Loss: 0.09540969133377075
# Batch: 180, Loss: 0.11132671684026718
# Batch: 200, Loss: 0.0868707001209259
#
# Average loss: 0.0894, Accuracy: 26802.0/27537 (97%)
#
#
# Average loss: 0.1102, Accuracy: 2956.0/3059 (97%)
#
# Epoch: 11 	Training Accuracy: 97.33%
# Validation Accuracy: 96.63%
# Batch: 0, Loss: 0.06518610566854477
# Batch: 20, Loss: 0.059321071952581406
# Batch: 40, Loss: 0.138634592294693
# Batch: 60, Loss: 0.10340612381696701
# Batch: 80, Loss: 0.09972352534532547
# Batch: 100, Loss: 0.04743648320436478
# Batch: 120, Loss: 0.0677986666560173
# Batch: 140, Loss: 0.045452870428562164
# Batch: 160, Loss: 0.04093829542398453
# Batch: 180, Loss: 0.06720248609781265
# Batch: 200, Loss: 0.03048756718635559
#
# Average loss: 0.0859, Accuracy: 26801.0/27537 (97%)
#
#
# Average loss: 0.1031, Accuracy: 2964.0/3059 (97%)
#
# Epoch: 12 	Training Accuracy: 97.33%
# Validation Accuracy: 96.89%
# Batch: 0, Loss: 0.07879568636417389
# Batch: 20, Loss: 0.07467614859342575
# Batch: 40, Loss: 0.06373631209135056
# Batch: 60, Loss: 0.04080813750624657
# Batch: 80, Loss: 0.0364631824195385
# Batch: 100, Loss: 0.05182299017906189
# Batch: 120, Loss: 0.07174129039049149
# Batch: 140, Loss: 0.11825550347566605
# Batch: 160, Loss: 0.1474493443965912
# Batch: 180, Loss: 0.056716591119766235
# Batch: 200, Loss: 0.05264004319906235
#
# Average loss: 0.0860, Accuracy: 26807.0/27537 (97%)
#
#
# Average loss: 0.1055, Accuracy: 2963.0/3059 (97%)
#
# Epoch: 13 	Training Accuracy: 97.35%
# Validation Accuracy: 96.86%
# Batch: 0, Loss: 0.06057140976190567
# Batch: 20, Loss: 0.07849899679422379
# Batch: 40, Loss: 0.07257521152496338
# Batch: 60, Loss: 0.1288243979215622
# Batch: 80, Loss: 0.060577865689992905
# Batch: 100, Loss: 0.0797063410282135
# Batch: 120, Loss: 0.11654403060674667
# Batch: 140, Loss: 0.11166665703058243
# Batch: 160, Loss: 0.03928862139582634
# Batch: 180, Loss: 0.04402552545070648
# Batch: 200, Loss: 0.08423732966184616
#
# Average loss: 0.0871, Accuracy: 26807.0/27537 (97%)
#
#
# Average loss: 0.1090, Accuracy: 2966.0/3059 (97%)
#
# Epoch: 14 	Training Accuracy: 97.35%
# Validation Accuracy: 96.96%
# Batch: 0, Loss: 0.058548152446746826
# Batch: 20, Loss: 0.03625532239675522
# Batch: 40, Loss: 0.16413328051567078
# Batch: 60, Loss: 0.06402919441461563
# Batch: 80, Loss: 0.0949888750910759
# Batch: 100, Loss: 0.16158609092235565
# Batch: 120, Loss: 0.07413679361343384
# Batch: 140, Loss: 0.06617781519889832
# Batch: 160, Loss: 0.07203589379787445
# Batch: 180, Loss: 0.09662722051143646
# Batch: 200, Loss: 0.08465825021266937
#
# Average loss: 0.0890, Accuracy: 26795.0/27537 (97%)
#
#
# Average loss: 0.1144, Accuracy: 2963.0/3059 (97%)
#
# Epoch: 15 	Training Accuracy: 97.31%
# Validation Accuracy: 96.86%
# Batch: 0, Loss: 0.07368993014097214
# Batch: 20, Loss: 0.06027369201183319
# Batch: 40, Loss: 0.07303072512149811
# Batch: 60, Loss: 0.07873891294002533
# Batch: 80, Loss: 0.10854531824588776
# Batch: 100, Loss: 0.13404622673988342
# Batch: 120, Loss: 0.08291466534137726
# Batch: 140, Loss: 0.03849063813686371
# Batch: 160, Loss: 0.06374252587556839
# Batch: 180, Loss: 0.09568426758050919
# Batch: 200, Loss: 0.04063540697097778
#
# Average loss: 0.0872, Accuracy: 26784.0/27537 (97%)
#
#
# Average loss: 0.1046, Accuracy: 2971.0/3059 (97%)
#
# Epoch: 16 	Training Accuracy: 97.27%
# Validation Accuracy: 97.12%
# Batch: 0, Loss: 0.07510153204202652
# Batch: 20, Loss: 0.10544723272323608
# Batch: 40, Loss: 0.14784428477287292
# Batch: 60, Loss: 0.11784558743238449
# Batch: 80, Loss: 0.041910216212272644
# Batch: 100, Loss: 0.05367645248770714
# Batch: 120, Loss: 0.0513441301882267
# Batch: 140, Loss: 0.07086677104234695
# Batch: 160, Loss: 0.0910332128405571
# Batch: 180, Loss: 0.0847029760479927
# Batch: 200, Loss: 0.016532808542251587
#
# Average loss: 0.0841, Accuracy: 26828.0/27537 (97%)
#
#
# Average loss: 0.1071, Accuracy: 2969.0/3059 (97%)
#
# Epoch: 17 	Training Accuracy: 97.43%
# Validation Accuracy: 97.06%
# Batch: 0, Loss: 0.061216119676828384
# Batch: 20, Loss: 0.08883167803287506
# Batch: 40, Loss: 0.03367811441421509
# Batch: 60, Loss: 0.042581409215927124
# Batch: 80, Loss: 0.0507056899368763
# Batch: 100, Loss: 0.13160814344882965
# Batch: 120, Loss: 0.023743445053696632
# Batch: 140, Loss: 0.07071461528539658
# Batch: 160, Loss: 0.046354204416275024
# Batch: 180, Loss: 0.06081420183181763
# Batch: 200, Loss: 0.08732730150222778
#
# Average loss: 0.0823, Accuracy: 26846.0/27537 (97%)
#
#
# Average loss: 0.1030, Accuracy: 2967.0/3059 (97%)
#
# Epoch: 18 	Training Accuracy: 97.49%
# Validation Accuracy: 96.99%
# Batch: 0, Loss: 0.08320822566747665
# Batch: 20, Loss: 0.11943599581718445
# Batch: 40, Loss: 0.022554930299520493
# Batch: 60, Loss: 0.08481250703334808
# Batch: 80, Loss: 0.10068856179714203
# Batch: 100, Loss: 0.19677618145942688
# Batch: 120, Loss: 0.1685076206922531
# Batch: 140, Loss: 0.04613449051976204
# Batch: 160, Loss: 0.12002778798341751
# Batch: 180, Loss: 0.1322730928659439
# Batch: 200, Loss: 0.050446346402168274
#
# Average loss: 0.0854, Accuracy: 26833.0/27537 (97%)
#
#
# Average loss: 0.1074, Accuracy: 2967.0/3059 (97%)
#
# Epoch: 19 	Training Accuracy: 97.44%
# Validation Accuracy: 96.99%
#
# Average loss: 0.0854, Accuracy: 26833.0/27537 (97%)
#
#
# Average loss: 0.0838, Accuracy: 5009.0/5139 (97%)
#
# Final Training Accuracy: 0.9744
# Final Test Accuracy: 0.9747

# %%
accuracy = eval(model, device, dataloader_wrapped.test_loader, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
# Out:
# Average loss: 0.0838, Accuracy: 5009.0/5139 (97%)

# %%
def effective_rank(singular_values):
    normalized_singular_values = singular_values / np.sum(singular_values)
    entropy = -np.sum(normalized_singular_values * np.log(normalized_singular_values))
    eff_rank = np.exp(entropy)
    return eff_rank

def plot_layer_effective_ranks(model, print_ranks=True):
    effective_ranks = []
    layer_names = []

    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            singular_values = np.linalg.svd(weight_matrix, compute_uv=False)
            eff_rank = effective_rank(singular_values)
            effective_ranks.append(eff_rank)
            layer_names.append(name)

    if print_ranks:
        for layer_name, eff_rank in zip(layer_names, effective_ranks):
            print(f'{layer_name}: {eff_rank:.4f}')

    # Plotting
    plt.figure(figsize=(15, 5))
    plt.bar(layer_names, effective_ranks, color='green')
    plt.xlabel('Layer')
    plt.ylabel('Effective Rank')
    plt.title('Effective Rank of Weight Matrices for Each Layer')
    plt.grid(True)

    y_max = np.max(effective_ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(effective_ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(0, int(y_max)+2, step=2))  # Set yticks

    plt.show()

# Example usage
plot_layer_effective_ranks(model)  # Note: You'll need to define or load 'model' before calling this function
# Out:
# conv0.weight: 3.9384
# conv1.weight: 3.9429
# fc_1.weight: 77.6022
# fc_2.weight: 8.7448

# %% [markdown]
# ----

# %% [markdown]
# # Finetuning experiments

# %%
dataloader_wrapped.update_phase('finetune')

a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        print('-------------')
        break
# Out:
# -------------

# %% [markdown]
# ## Baseline model: end2end with the same architecture as the preatining model

# %%
# 2. Create a new model and copy weights from the original model, then adjust the final layer
print("Current dataloader phase: ", dataloader_wrapped.get_current_phase())

model_finetuning_baseline = generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
model_finetuning_baseline.to(device)

# dataloader_wrapped.update_phase('finetune')
# Train and evaluate the new model on the new data
# train_acc_new, test_acc_new, model_finetuning_baseline, _,_ = compute_training_acc_epochs_cnn(model_finetuning_baseline, dataloader_wrapped, params, debug=True)

trainer = Trainer(model, dataloader_wrapped, params)
train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
print(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")
# Out:
# Current dataloader phase:  finetune
# Batch: 0, Loss: 4.909561634063721
# Batch: 20, Loss: 1.9372434616088867
# Batch: 40, Loss: 1.3672746419906616
# Batch: 60, Loss: 0.9021041989326477
# Batch: 80, Loss: 0.7144639492034912
# Batch: 100, Loss: 0.7088696956634521
# Batch: 120, Loss: 0.5753801465034485
# Batch: 140, Loss: 0.571607232093811
# Batch: 160, Loss: 0.5827432870864868
# Batch: 180, Loss: 0.45191797614097595
# Batch: 200, Loss: 0.297166109085083
#
# Average loss: 0.3837, Accuracy: 23024.0/26464 (87%)
#
#
# Average loss: 0.4050, Accuracy: 2552.0/2940 (87%)
#
# Epoch: 0 	Training Accuracy: 87.00%
# Validation Accuracy: 86.80%
# Batch: 0, Loss: 0.6330706477165222
# Batch: 20, Loss: 0.29970991611480713
# Batch: 40, Loss: 0.24686872959136963
# Batch: 60, Loss: 0.27742913365364075
# Batch: 80, Loss: 0.3233950436115265
# Batch: 100, Loss: 0.4786728620529175
# Batch: 120, Loss: 0.3566199839115143
# Batch: 140, Loss: 0.1961079239845276
# Batch: 160, Loss: 0.22643636167049408
# Batch: 180, Loss: 0.13489915430545807
# Batch: 200, Loss: 0.274050235748291
#
# Average loss: 0.2386, Accuracy: 24420.0/26464 (92%)
#
#
# Average loss: 0.2557, Accuracy: 2695.0/2940 (92%)
#
# Epoch: 1 	Training Accuracy: 92.28%
# Validation Accuracy: 91.67%
# Batch: 0, Loss: 0.24076230823993683
# Batch: 20, Loss: 0.17620494961738586
# Batch: 40, Loss: 0.25199028849601746
# Batch: 60, Loss: 0.18723011016845703
# Batch: 80, Loss: 0.204702690243721
# Batch: 100, Loss: 0.21471765637397766
# Batch: 120, Loss: 0.3061979115009308
# Batch: 140, Loss: 0.19612763822078705
# Batch: 160, Loss: 0.15998134016990662
# Batch: 180, Loss: 0.29620420932769775
# Batch: 200, Loss: 0.1642305701971054
#
# Average loss: 0.1908, Accuracy: 24846.0/26464 (94%)
#
#
# Average loss: 0.2064, Accuracy: 2754.0/2940 (94%)
#
# Epoch: 2 	Training Accuracy: 93.89%
# Validation Accuracy: 93.67%
# Batch: 0, Loss: 0.16814304888248444
# Batch: 20, Loss: 0.18015071749687195
# Batch: 40, Loss: 0.19840791821479797
# Batch: 60, Loss: 0.3594362735748291
# Batch: 80, Loss: 0.2001642882823944
# Batch: 100, Loss: 0.19931194186210632
# Batch: 120, Loss: 0.21896502375602722
# Batch: 140, Loss: 0.16953687369823456
# Batch: 160, Loss: 0.19052204489707947
# Batch: 180, Loss: 0.21262557804584503
# Batch: 200, Loss: 0.20494547486305237
#
# Average loss: 0.1738, Accuracy: 24922.0/26464 (94%)
#
#
# Average loss: 0.1866, Accuracy: 2761.0/2940 (94%)
#
# Epoch: 3 	Training Accuracy: 94.17%
# Validation Accuracy: 93.91%
# Batch: 0, Loss: 0.22914531826972961
# Batch: 20, Loss: 0.1672622114419937
# Batch: 40, Loss: 0.15462838113307953
# Batch: 60, Loss: 0.12396280467510223
# Batch: 80, Loss: 0.16695232689380646
# Batch: 100, Loss: 0.1726820021867752
# Batch: 120, Loss: 0.13644565641880035
# Batch: 140, Loss: 0.16898208856582642
# Batch: 160, Loss: 0.23345667123794556
# Batch: 180, Loss: 0.09531182795763016
# Batch: 200, Loss: 0.2748483717441559
#
# Average loss: 0.1667, Accuracy: 25003.0/26464 (94%)
#
#
# Average loss: 0.1845, Accuracy: 2771.0/2940 (94%)
#
# Epoch: 4 	Training Accuracy: 94.48%
# Validation Accuracy: 94.25%
# Batch: 0, Loss: 0.28641530871391296
# Batch: 20, Loss: 0.16247648000717163
# Batch: 40, Loss: 0.2418171763420105
# Batch: 60, Loss: 0.16973502933979034
# Batch: 80, Loss: 0.06346743553876877
# Batch: 100, Loss: 0.1485460102558136
# Batch: 120, Loss: 0.17295797169208527
# Batch: 140, Loss: 0.07471190392971039
# Batch: 160, Loss: 0.14688028395175934
# Batch: 180, Loss: 0.13197287917137146
# Batch: 200, Loss: 0.3013174831867218
#
# Average loss: 0.1539, Accuracy: 25140.0/26464 (95%)
#
#
# Average loss: 0.1757, Accuracy: 2778.0/2940 (94%)
#
# Epoch: 5 	Training Accuracy: 95.00%
# Validation Accuracy: 94.49%
# Batch: 0, Loss: 0.27833622694015503
# Batch: 20, Loss: 0.134866863489151
# Batch: 40, Loss: 0.1534215658903122
# Batch: 60, Loss: 0.1970265507698059
# Batch: 80, Loss: 0.11365924775600433
# Batch: 100, Loss: 0.18450376391410828
# Batch: 120, Loss: 0.10277459025382996
# Batch: 140, Loss: 0.08841978013515472
# Batch: 160, Loss: 0.19104702770709991
# Batch: 180, Loss: 0.10818617045879364
# Batch: 200, Loss: 0.12452870607376099
#
# Average loss: 0.1459, Accuracy: 25182.0/26464 (95%)
#
#
# Average loss: 0.1629, Accuracy: 2783.0/2940 (95%)
#
# Epoch: 6 	Training Accuracy: 95.16%
# Validation Accuracy: 94.66%
# Batch: 0, Loss: 0.20851309597492218
# Batch: 20, Loss: 0.16344234347343445
# Batch: 40, Loss: 0.21129611134529114
# Batch: 60, Loss: 0.1492367535829544
# Batch: 80, Loss: 0.18336552381515503
# Batch: 100, Loss: 0.09264238178730011
# Batch: 120, Loss: 0.1194324642419815
# Batch: 140, Loss: 0.1699979305267334
# Batch: 160, Loss: 0.20349670946598053
# Batch: 180, Loss: 0.3057398498058319
# Batch: 200, Loss: 0.09970634430646896
#
# Average loss: 0.1566, Accuracy: 25049.0/26464 (95%)
#
#
# Average loss: 0.1748, Accuracy: 2780.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 94.65%
# Validation Accuracy: 94.56%
# Batch: 0, Loss: 0.1532919704914093
# Batch: 20, Loss: 0.16254939138889313
# Batch: 40, Loss: 0.13581854104995728
# Batch: 60, Loss: 0.16088998317718506
# Batch: 80, Loss: 0.17676635086536407
# Batch: 100, Loss: 0.22407178580760956
# Batch: 120, Loss: 0.13248670101165771
# Batch: 140, Loss: 0.24007943272590637
# Batch: 160, Loss: 0.1855868101119995
# Batch: 180, Loss: 0.08805675059556961
# Batch: 200, Loss: 0.17978225648403168
#
# Average loss: 0.1351, Accuracy: 25297.0/26464 (96%)
#
#
# Average loss: 0.1563, Accuracy: 2790.0/2940 (95%)
#
# Epoch: 8 	Training Accuracy: 95.59%
# Validation Accuracy: 94.90%
# Batch: 0, Loss: 0.21165715157985687
# Batch: 20, Loss: 0.15502481162548065
# Batch: 40, Loss: 0.057009123265743256
# Batch: 60, Loss: 0.12907977402210236
# Batch: 80, Loss: 0.09957575798034668
# Batch: 100, Loss: 0.07384806871414185
# Batch: 120, Loss: 0.17930543422698975
# Batch: 140, Loss: 0.18387067317962646
# Batch: 160, Loss: 0.21812108159065247
# Batch: 180, Loss: 0.0648886039853096
# Batch: 200, Loss: 0.07990504056215286
#
# Average loss: 0.1338, Accuracy: 25279.0/26464 (96%)
#
#
# Average loss: 0.1544, Accuracy: 2791.0/2940 (95%)
#
# Epoch: 9 	Training Accuracy: 95.52%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.13218869268894196
# Batch: 20, Loss: 0.14598338305950165
# Batch: 40, Loss: 0.15057265758514404
# Batch: 60, Loss: 0.16582322120666504
# Batch: 80, Loss: 0.08245393633842468
# Batch: 100, Loss: 0.1471520960330963
# Batch: 120, Loss: 0.09428564459085464
# Batch: 140, Loss: 0.15135139226913452
# Batch: 160, Loss: 0.11497492343187332
# Batch: 180, Loss: 0.19695842266082764
# Batch: 200, Loss: 0.1252962201833725
#
# Average loss: 0.1376, Accuracy: 25248.0/26464 (95%)
#
#
# Average loss: 0.1597, Accuracy: 2789.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 95.41%
# Validation Accuracy: 94.86%
# Batch: 0, Loss: 0.12659677863121033
# Batch: 20, Loss: 0.15918183326721191
# Batch: 40, Loss: 0.11115022003650665
# Batch: 60, Loss: 0.2767484188079834
# Batch: 80, Loss: 0.1926083117723465
# Batch: 100, Loss: 0.10924829542636871
# Batch: 120, Loss: 0.18638122081756592
# Batch: 140, Loss: 0.14127975702285767
# Batch: 160, Loss: 0.17685794830322266
# Batch: 180, Loss: 0.11716242879629135
# Batch: 200, Loss: 0.17563483119010925
#
# Average loss: 0.1291, Accuracy: 25334.0/26464 (96%)
#
#
# Average loss: 0.1506, Accuracy: 2797.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 95.73%
# Validation Accuracy: 95.14%
# Batch: 0, Loss: 0.12038935720920563
# Batch: 20, Loss: 0.12813133001327515
# Batch: 40, Loss: 0.12045077234506607
# Batch: 60, Loss: 0.10292869061231613
# Batch: 80, Loss: 0.08640046417713165
# Batch: 100, Loss: 0.12664012610912323
# Batch: 120, Loss: 0.1986423283815384
# Batch: 140, Loss: 0.09502696245908737
# Batch: 160, Loss: 0.17618869245052338
# Batch: 180, Loss: 0.0960875153541565
# Batch: 200, Loss: 0.07287711650133133
#
# Average loss: 0.1278, Accuracy: 25338.0/26464 (96%)
#
#
# Average loss: 0.1515, Accuracy: 2793.0/2940 (95%)
#
# Epoch: 12 	Training Accuracy: 95.75%
# Validation Accuracy: 95.00%
# Batch: 0, Loss: 0.13815616071224213
# Batch: 20, Loss: 0.14950710535049438
# Batch: 40, Loss: 0.15146444737911224
# Batch: 60, Loss: 0.060753583908081055
# Batch: 80, Loss: 0.03563662990927696
# Batch: 100, Loss: 0.17213495075702667
# Batch: 120, Loss: 0.18114934861660004
# Batch: 140, Loss: 0.08399020880460739
# Batch: 160, Loss: 0.12618505954742432
# Batch: 180, Loss: 0.10971210151910782
# Batch: 200, Loss: 0.10597866028547287
#
# Average loss: 0.1256, Accuracy: 25376.0/26464 (96%)
#
#
# Average loss: 0.1514, Accuracy: 2803.0/2940 (95%)
#
# Epoch: 13 	Training Accuracy: 95.89%
# Validation Accuracy: 95.34%
# Batch: 0, Loss: 0.22501327097415924
# Batch: 20, Loss: 0.14849072694778442
# Batch: 40, Loss: 0.07645653188228607
# Batch: 60, Loss: 0.19494464993476868
# Batch: 80, Loss: 0.11905350536108017
# Batch: 100, Loss: 0.07346320897340775
# Batch: 120, Loss: 0.16014419496059418
# Batch: 140, Loss: 0.11179253458976746
# Batch: 160, Loss: 0.14849862456321716
# Batch: 180, Loss: 0.10972290486097336
# Batch: 200, Loss: 0.14646917581558228
#
# Average loss: 0.1222, Accuracy: 25415.0/26464 (96%)
#
#
# Average loss: 0.1506, Accuracy: 2805.0/2940 (95%)
#
# Epoch: 14 	Training Accuracy: 96.04%
# Validation Accuracy: 95.41%
# Batch: 0, Loss: 0.12874433398246765
# Batch: 20, Loss: 0.11585863679647446
# Batch: 40, Loss: 0.13568522036075592
# Batch: 60, Loss: 0.20340536534786224
# Batch: 80, Loss: 0.1035483330488205
# Batch: 100, Loss: 0.0752444714307785
# Batch: 120, Loss: 0.27697932720184326
# Batch: 140, Loss: 0.11533471196889877
# Batch: 160, Loss: 0.09995903074741364
# Batch: 180, Loss: 0.09292798489332199
# Batch: 200, Loss: 0.05013514310121536
#
# Average loss: 0.1258, Accuracy: 25332.0/26464 (96%)
#
#
# Average loss: 0.1526, Accuracy: 2798.0/2940 (95%)
#
# Epoch: 15 	Training Accuracy: 95.72%
# Validation Accuracy: 95.17%
# Batch: 0, Loss: 0.09743961691856384
# Batch: 20, Loss: 0.08224926888942719
# Batch: 40, Loss: 0.11601414531469345
# Batch: 60, Loss: 0.13378621637821198
# Batch: 80, Loss: 0.055605098605155945
# Batch: 100, Loss: 0.09526459127664566
# Batch: 120, Loss: 0.03930966556072235
# Batch: 140, Loss: 0.11892767995595932
# Batch: 160, Loss: 0.26127034425735474
# Batch: 180, Loss: 0.08001948148012161
# Batch: 200, Loss: 0.17124946415424347
#
# Average loss: 0.1204, Accuracy: 25395.0/26464 (96%)
#
#
# Average loss: 0.1494, Accuracy: 2799.0/2940 (95%)
#
# Epoch: 16 	Training Accuracy: 95.96%
# Validation Accuracy: 95.20%
# Batch: 0, Loss: 0.12840893864631653
# Batch: 20, Loss: 0.08046377450227737
# Batch: 40, Loss: 0.13880133628845215
# Batch: 60, Loss: 0.12890776991844177
# Batch: 80, Loss: 0.12644712626934052
# Batch: 100, Loss: 0.24811168015003204
# Batch: 120, Loss: 0.06910873204469681
# Batch: 140, Loss: 0.15520839393138885
# Batch: 160, Loss: 0.13018813729286194
# Batch: 180, Loss: 0.060202471911907196
# Batch: 200, Loss: 0.08804366737604141
#
# Average loss: 0.1204, Accuracy: 25404.0/26464 (96%)
#
#
# Average loss: 0.1475, Accuracy: 2801.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 95.99%
# Validation Accuracy: 95.27%
# Batch: 0, Loss: 0.08901355415582657
# Batch: 20, Loss: 0.1247907429933548
# Batch: 40, Loss: 0.11126018315553665
# Batch: 60, Loss: 0.09410834312438965
# Batch: 80, Loss: 0.1548466831445694
# Batch: 100, Loss: 0.24554866552352905
# Batch: 120, Loss: 0.10320982336997986
# Batch: 140, Loss: 0.11201459169387817
# Batch: 160, Loss: 0.16345863044261932
# Batch: 180, Loss: 0.20374450087547302
# Batch: 200, Loss: 0.12895065546035767
#
# Average loss: 0.1187, Accuracy: 25414.0/26464 (96%)
#
#
# Average loss: 0.1487, Accuracy: 2798.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 96.03%
# Validation Accuracy: 95.17%
# Batch: 0, Loss: 0.06358108669519424
# Batch: 20, Loss: 0.08580861240625381
# Batch: 40, Loss: 0.10504663735628128
# Batch: 60, Loss: 0.1844356209039688
# Batch: 80, Loss: 0.17401720583438873
# Batch: 100, Loss: 0.22138473391532898
# Batch: 120, Loss: 0.10687362402677536
# Batch: 140, Loss: 0.10344833880662918
# Batch: 160, Loss: 0.10889177024364471
# Batch: 180, Loss: 0.1699220836162567
# Batch: 200, Loss: 0.22471961379051208
#
# Average loss: 0.1170, Accuracy: 25431.0/26464 (96%)
#
#
# Average loss: 0.1473, Accuracy: 2805.0/2940 (95%)
#
# Epoch: 19 	Training Accuracy: 96.10%
# Validation Accuracy: 95.41%
#
# Average loss: 0.1170, Accuracy: 25431.0/26464 (96%)
#
#
# Average loss: 0.1314, Accuracy: 4644.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9610
# Final Test Accuracy (New Data): 0.9554

# %%
plot_layer_effective_ranks(model_finetuning_baseline)
# Out:
# conv0.weight: 3.6157
# conv1.weight: 3.9917
# fc_1.weight: 108.0027
# fc_2.weight: 4.9787

# %% [markdown]
# ***WITH BALANCED CLASSES***

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01]
percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]

seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.0001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test = {}
results_train = {}
best_models = {}
data_loaders = {}
epochs_taken = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in percentages:
    print(f"Percentage: {perc}")
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []  # Store epochs for this percentage

    for _, temp_seed in enumerate(seed_set):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")
        model_new =  generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
        model_new.to(device)

        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)

        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        # Train and evaluate the new model on the new data
        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        print(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
        print(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test[perc] = test_accuracies
    results_train[perc] = train_accuracies
    epochs_taken[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Percentage: 0.01
# Repeat: 0, with seed 10 =========================
# Batch: 0, Loss: 1.627357840538025
#
# Average loss: 1.6182, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6203, Accuracy: 555.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.88%
# Batch: 0, Loss: 1.6187101602554321
#
# Average loss: 1.6154, Accuracy: 50.0/260 (19%)
#
#
# Average loss: 1.6175, Accuracy: 547.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 19.23%
# Validation Accuracy: 18.61%
# Batch: 0, Loss: 1.6138081550598145
#
# Average loss: 1.6131, Accuracy: 41.0/260 (16%)
#
#
# Average loss: 1.6148, Accuracy: 463.0/2940 (16%)
#
# Epoch: 2 	Training Accuracy: 15.77%
# Validation Accuracy: 15.75%
# Batch: 0, Loss: 1.6192138195037842
#
# Average loss: 1.6108, Accuracy: 40.0/260 (15%)
#
#
# Average loss: 1.6123, Accuracy: 470.0/2940 (16%)
#
# Epoch: 3 	Training Accuracy: 15.38%
# Validation Accuracy: 15.99%
# Batch: 0, Loss: 1.6063207387924194
#
# Average loss: 1.6089, Accuracy: 48.0/260 (18%)
#
#
# Average loss: 1.6102, Accuracy: 537.0/2940 (18%)
#
# Epoch: 4 	Training Accuracy: 18.46%
# Validation Accuracy: 18.27%
# Batch: 0, Loss: 1.6136749982833862
#
# Average loss: 1.6071, Accuracy: 51.0/260 (20%)
#
#
# Average loss: 1.6082, Accuracy: 619.0/2940 (21%)
#
# Epoch: 5 	Training Accuracy: 19.62%
# Validation Accuracy: 21.05%
# Batch: 0, Loss: 1.609161376953125
#
# Average loss: 1.6056, Accuracy: 59.0/260 (23%)
#
#
# Average loss: 1.6067, Accuracy: 746.0/2940 (25%)
#
# Epoch: 6 	Training Accuracy: 22.69%
# Validation Accuracy: 25.37%
# Batch: 0, Loss: 1.6018753051757812
#
# Average loss: 1.6041, Accuracy: 79.0/260 (30%)
#
#
# Average loss: 1.6049, Accuracy: 935.0/2940 (32%)
#
# Epoch: 7 	Training Accuracy: 30.38%
# Validation Accuracy: 31.80%
# Batch: 0, Loss: 1.6021353006362915
#
# Average loss: 1.6025, Accuracy: 85.0/260 (33%)
#
#
# Average loss: 1.6032, Accuracy: 1013.0/2940 (34%)
#
# Epoch: 8 	Training Accuracy: 32.69%
# Validation Accuracy: 34.46%
# Batch: 0, Loss: 1.6049492359161377
#
# Average loss: 1.6009, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.6013, Accuracy: 1016.0/2940 (35%)
#
# Epoch: 9 	Training Accuracy: 35.00%
# Validation Accuracy: 34.56%
# Batch: 0, Loss: 1.5998902320861816
#
# Average loss: 1.5994, Accuracy: 85.0/260 (33%)
#
#
# Average loss: 1.5993, Accuracy: 1028.0/2940 (35%)
#
# Epoch: 10 	Training Accuracy: 32.69%
# Validation Accuracy: 34.97%
# Batch: 0, Loss: 1.5983998775482178
#
# Average loss: 1.5979, Accuracy: 89.0/260 (34%)
#
#
# Average loss: 1.5973, Accuracy: 1010.0/2940 (34%)
#
# Epoch: 11 	Training Accuracy: 34.23%
# Validation Accuracy: 34.35%
# Batch: 0, Loss: 1.6000521183013916
#
# Average loss: 1.5965, Accuracy: 86.0/260 (33%)
#
#
# Average loss: 1.5955, Accuracy: 916.0/2940 (31%)
#
# Epoch: 12 	Training Accuracy: 33.08%
# Validation Accuracy: 31.16%
# Batch: 0, Loss: 1.597283959388733
#
# Average loss: 1.5952, Accuracy: 73.0/260 (28%)
#
#
# Average loss: 1.5940, Accuracy: 768.0/2940 (26%)
#
# Epoch: 13 	Training Accuracy: 28.08%
# Validation Accuracy: 26.12%
# Batch: 0, Loss: 1.599022388458252
#
# Average loss: 1.5938, Accuracy: 64.0/260 (25%)
#
#
# Average loss: 1.5928, Accuracy: 721.0/2940 (25%)
#
# Epoch: 14 	Training Accuracy: 24.62%
# Validation Accuracy: 24.52%
# Batch: 0, Loss: 1.5963926315307617
#
# Average loss: 1.5924, Accuracy: 65.0/260 (25%)
#
#
# Average loss: 1.5917, Accuracy: 728.0/2940 (25%)
#
# Epoch: 15 	Training Accuracy: 25.00%
# Validation Accuracy: 24.76%
# Batch: 0, Loss: 1.596036672592163
#
# Average loss: 1.5911, Accuracy: 59.0/260 (23%)
#
#
# Average loss: 1.5907, Accuracy: 693.0/2940 (24%)
#
# Epoch: 16 	Training Accuracy: 22.69%
# Validation Accuracy: 23.57%
# Early stopping invoked.
#
# Average loss: 1.5994, Accuracy: 85.0/260 (33%)
#
#
# Average loss: 1.5990, Accuracy: 1748.0/4861 (36%)
#
# Final Training Accuracy (New Data): 0.3269
# Final Test Accuracy (New Data): 0.3596
# Repeat: 1, with seed 59 =========================
# Batch: 0, Loss: 1.613946795463562
#
# Average loss: 1.6103, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6108, Accuracy: 598.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.34%
# Batch: 0, Loss: 1.610015869140625
#
# Average loss: 1.6102, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6107, Accuracy: 597.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 20.31%
# Batch: 0, Loss: 1.6070481538772583
#
# Average loss: 1.6101, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6106, Accuracy: 598.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 20.34%
# Batch: 0, Loss: 1.604367733001709
#
# Average loss: 1.6100, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6105, Accuracy: 598.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 20.34%
# Batch: 0, Loss: 1.6077663898468018
#
# Average loss: 1.6099, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6104, Accuracy: 598.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 20.34%
# Batch: 0, Loss: 1.6138843297958374
#
# Average loss: 1.6098, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6103, Accuracy: 599.0/2940 (20%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6128557920455933
#
# Average loss: 1.6097, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6102, Accuracy: 599.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6123138666152954
#
# Average loss: 1.6097, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6102, Accuracy: 599.0/2940 (20%)
#
# Epoch: 7 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6095359325408936
#
# Average loss: 1.6096, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6101, Accuracy: 599.0/2940 (20%)
#
# Epoch: 8 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6103317737579346
#
# Average loss: 1.6095, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6100, Accuracy: 599.0/2940 (20%)
#
# Epoch: 9 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6131994724273682
#
# Average loss: 1.6095, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6100, Accuracy: 599.0/2940 (20%)
#
# Epoch: 10 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6061593294143677
#
# Average loss: 1.6094, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6099, Accuracy: 599.0/2940 (20%)
#
# Epoch: 11 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Early stopping invoked.
#
# Average loss: 1.6098, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6094, Accuracy: 957.0/4861 (20%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.1969
# Repeat: 2, with seed 30 =========================
# Batch: 0, Loss: 1.6096311807632446
#
# Average loss: 1.6085, Accuracy: 55.0/260 (21%)
#
#
# Average loss: 1.6081, Accuracy: 615.0/2940 (21%)
#
# Epoch: 0 	Training Accuracy: 21.15%
# Validation Accuracy: 20.92%
# Batch: 0, Loss: 1.6077138185501099
#
# Average loss: 1.6083, Accuracy: 62.0/260 (24%)
#
#
# Average loss: 1.6080, Accuracy: 637.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 23.85%
# Validation Accuracy: 21.67%
# Batch: 0, Loss: 1.6080090999603271
#
# Average loss: 1.6081, Accuracy: 56.0/260 (22%)
#
#
# Average loss: 1.6078, Accuracy: 729.0/2940 (25%)
#
# Epoch: 2 	Training Accuracy: 21.54%
# Validation Accuracy: 24.80%
# Batch: 0, Loss: 1.6082979440689087
#
# Average loss: 1.6080, Accuracy: 70.0/260 (27%)
#
#
# Average loss: 1.6076, Accuracy: 799.0/2940 (27%)
#
# Epoch: 3 	Training Accuracy: 26.92%
# Validation Accuracy: 27.18%
# Batch: 0, Loss: 1.6080554723739624
#
# Average loss: 1.6078, Accuracy: 68.0/260 (26%)
#
#
# Average loss: 1.6074, Accuracy: 795.0/2940 (27%)
#
# Epoch: 4 	Training Accuracy: 26.15%
# Validation Accuracy: 27.04%
# Batch: 0, Loss: 1.6077858209609985
#
# Average loss: 1.6077, Accuracy: 64.0/260 (25%)
#
#
# Average loss: 1.6073, Accuracy: 799.0/2940 (27%)
#
# Epoch: 5 	Training Accuracy: 24.62%
# Validation Accuracy: 27.18%
# Batch: 0, Loss: 1.6077526807785034
#
# Average loss: 1.6076, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.6071, Accuracy: 760.0/2940 (26%)
#
# Epoch: 6 	Training Accuracy: 22.31%
# Validation Accuracy: 25.85%
# Batch: 0, Loss: 1.607550859451294
#
# Average loss: 1.6075, Accuracy: 57.0/260 (22%)
#
#
# Average loss: 1.6070, Accuracy: 749.0/2940 (25%)
#
# Epoch: 7 	Training Accuracy: 21.92%
# Validation Accuracy: 25.48%
# Batch: 0, Loss: 1.6085190773010254
#
# Average loss: 1.6074, Accuracy: 56.0/260 (22%)
#
#
# Average loss: 1.6070, Accuracy: 765.0/2940 (26%)
#
# Epoch: 8 	Training Accuracy: 21.54%
# Validation Accuracy: 26.02%
# Batch: 0, Loss: 1.6078534126281738
#
# Average loss: 1.6073, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.6068, Accuracy: 745.0/2940 (25%)
#
# Epoch: 9 	Training Accuracy: 22.31%
# Validation Accuracy: 25.34%
# Early stopping invoked.
#
# Average loss: 1.6080, Accuracy: 70.0/260 (27%)
#
#
# Average loss: 1.6074, Accuracy: 1301.0/4861 (27%)
#
# Final Training Accuracy (New Data): 0.2692
# Final Test Accuracy (New Data): 0.2676
# Repeat: 3, with seed 25 =========================
# Batch: 0, Loss: 1.60835862159729
#
# Average loss: 1.6081, Accuracy: 64.0/260 (25%)
#
#
# Average loss: 1.6121, Accuracy: 633.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 24.62%
# Validation Accuracy: 21.53%
# Batch: 0, Loss: 1.5995159149169922
#
# Average loss: 1.6060, Accuracy: 69.0/260 (27%)
#
#
# Average loss: 1.6103, Accuracy: 653.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 26.54%
# Validation Accuracy: 22.21%
# Batch: 0, Loss: 1.6050963401794434
#
# Average loss: 1.6041, Accuracy: 72.0/260 (28%)
#
#
# Average loss: 1.6087, Accuracy: 673.0/2940 (23%)
#
# Epoch: 2 	Training Accuracy: 27.69%
# Validation Accuracy: 22.89%
# Batch: 0, Loss: 1.6050723791122437
#
# Average loss: 1.6024, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.6071, Accuracy: 700.0/2940 (24%)
#
# Epoch: 3 	Training Accuracy: 28.46%
# Validation Accuracy: 23.81%
# Batch: 0, Loss: 1.5951193571090698
#
# Average loss: 1.6005, Accuracy: 78.0/260 (30%)
#
#
# Average loss: 1.6055, Accuracy: 728.0/2940 (25%)
#
# Epoch: 4 	Training Accuracy: 30.00%
# Validation Accuracy: 24.76%
# Batch: 0, Loss: 1.6018526554107666
#
# Average loss: 1.5986, Accuracy: 78.0/260 (30%)
#
#
# Average loss: 1.6038, Accuracy: 749.0/2940 (25%)
#
# Epoch: 5 	Training Accuracy: 30.00%
# Validation Accuracy: 25.48%
# Batch: 0, Loss: 1.5992767810821533
#
# Average loss: 1.5967, Accuracy: 79.0/260 (30%)
#
#
# Average loss: 1.6021, Accuracy: 767.0/2940 (26%)
#
# Epoch: 6 	Training Accuracy: 30.38%
# Validation Accuracy: 26.09%
# Batch: 0, Loss: 1.5990062952041626
#
# Average loss: 1.5949, Accuracy: 81.0/260 (31%)
#
#
# Average loss: 1.6004, Accuracy: 795.0/2940 (27%)
#
# Epoch: 7 	Training Accuracy: 31.15%
# Validation Accuracy: 27.04%
# Batch: 0, Loss: 1.591027855873108
#
# Average loss: 1.5932, Accuracy: 83.0/260 (32%)
#
#
# Average loss: 1.5987, Accuracy: 825.0/2940 (28%)
#
# Epoch: 8 	Training Accuracy: 31.92%
# Validation Accuracy: 28.06%
# Batch: 0, Loss: 1.5930538177490234
#
# Average loss: 1.5915, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5970, Accuracy: 854.0/2940 (29%)
#
# Epoch: 9 	Training Accuracy: 32.31%
# Validation Accuracy: 29.05%
# Batch: 0, Loss: 1.5917203426361084
#
# Average loss: 1.5897, Accuracy: 85.0/260 (33%)
#
#
# Average loss: 1.5954, Accuracy: 883.0/2940 (30%)
#
# Epoch: 10 	Training Accuracy: 32.69%
# Validation Accuracy: 30.03%
# Batch: 0, Loss: 1.5862654447555542
#
# Average loss: 1.5878, Accuracy: 86.0/260 (33%)
#
#
# Average loss: 1.5937, Accuracy: 907.0/2940 (31%)
#
# Epoch: 11 	Training Accuracy: 33.08%
# Validation Accuracy: 30.85%
# Batch: 0, Loss: 1.5871593952178955
#
# Average loss: 1.5859, Accuracy: 90.0/260 (35%)
#
#
# Average loss: 1.5919, Accuracy: 934.0/2940 (32%)
#
# Epoch: 12 	Training Accuracy: 34.62%
# Validation Accuracy: 31.77%
# Batch: 0, Loss: 1.5892502069473267
#
# Average loss: 1.5838, Accuracy: 94.0/260 (36%)
#
#
# Average loss: 1.5900, Accuracy: 964.0/2940 (33%)
#
# Epoch: 13 	Training Accuracy: 36.15%
# Validation Accuracy: 32.79%
# Batch: 0, Loss: 1.5913052558898926
#
# Average loss: 1.5817, Accuracy: 98.0/260 (38%)
#
#
# Average loss: 1.5881, Accuracy: 1008.0/2940 (34%)
#
# Epoch: 14 	Training Accuracy: 37.69%
# Validation Accuracy: 34.29%
# Batch: 0, Loss: 1.5784419775009155
#
# Average loss: 1.5796, Accuracy: 107.0/260 (41%)
#
#
# Average loss: 1.5863, Accuracy: 1052.0/2940 (36%)
#
# Epoch: 15 	Training Accuracy: 41.15%
# Validation Accuracy: 35.78%
# Batch: 0, Loss: 1.5805244445800781
#
# Average loss: 1.5775, Accuracy: 110.0/260 (42%)
#
#
# Average loss: 1.5845, Accuracy: 1100.0/2940 (37%)
#
# Epoch: 16 	Training Accuracy: 42.31%
# Validation Accuracy: 37.41%
# Batch: 0, Loss: 1.5787745714187622
#
# Average loss: 1.5753, Accuracy: 116.0/260 (45%)
#
#
# Average loss: 1.5826, Accuracy: 1125.0/2940 (38%)
#
# Epoch: 17 	Training Accuracy: 44.62%
# Validation Accuracy: 38.27%
# Batch: 0, Loss: 1.5774447917938232
#
# Average loss: 1.5732, Accuracy: 118.0/260 (45%)
#
#
# Average loss: 1.5808, Accuracy: 1137.0/2940 (39%)
#
# Epoch: 18 	Training Accuracy: 45.38%
# Validation Accuracy: 38.67%
# Batch: 0, Loss: 1.5721584558486938
#
# Average loss: 1.5711, Accuracy: 123.0/260 (47%)
#
#
# Average loss: 1.5789, Accuracy: 1179.0/2940 (40%)
#
# Epoch: 19 	Training Accuracy: 47.31%
# Validation Accuracy: 40.10%
#
# Average loss: 1.5711, Accuracy: 123.0/260 (47%)
#
#
# Average loss: 1.5775, Accuracy: 1948.0/4861 (40%)
#
# Final Training Accuracy (New Data): 0.4731
# Final Test Accuracy (New Data): 0.4007
# Repeat: 4, with seed 8 =========================
# Batch: 0, Loss: 1.6117064952850342
#
# Average loss: 1.6093, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6076, Accuracy: 655.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6122052669525146
#
# Average loss: 1.6090, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6074, Accuracy: 655.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6069090366363525
#
# Average loss: 1.6088, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6072, Accuracy: 655.0/2940 (22%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.606601357460022
#
# Average loss: 1.6085, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6070, Accuracy: 655.0/2940 (22%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6090106964111328
#
# Average loss: 1.6083, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6067, Accuracy: 655.0/2940 (22%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6053744554519653
#
# Average loss: 1.6080, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6065, Accuracy: 655.0/2940 (22%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6073880195617676
#
# Average loss: 1.6077, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6062, Accuracy: 655.0/2940 (22%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Early stopping invoked.
#
# Average loss: 1.6093, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6080, Accuracy: 1028.0/4861 (21%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.2115
# Percentage: 0.03
# Repeat: 0, with seed 62 =========================
# Batch: 0, Loss: 1.6145459413528442
#
# Average loss: 1.6100, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6097, Accuracy: 584.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.86%
# Batch: 0, Loss: 1.612109899520874
#
# Average loss: 1.6099, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6096, Accuracy: 599.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6073262691497803
#
# Average loss: 1.6099, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6096, Accuracy: 579.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 19.69%
# Batch: 0, Loss: 1.613930344581604
#
# Average loss: 1.6099, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6096, Accuracy: 599.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6137924194335938
#
# Average loss: 1.6099, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6096, Accuracy: 599.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6061142683029175
#
# Average loss: 1.6098, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6095, Accuracy: 599.0/2940 (20%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6095848083496094
#
# Average loss: 1.6098, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6095, Accuracy: 599.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6111180782318115
#
# Average loss: 1.6098, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6094, Accuracy: 599.0/2940 (20%)
#
# Epoch: 7 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Early stopping invoked.
#
# Average loss: 1.6099, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6092, Accuracy: 956.0/4861 (20%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.1967
# Repeat: 1, with seed 41 =========================
# Batch: 0, Loss: 1.6063934564590454
#
# Average loss: 1.6085, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6110, Accuracy: 585.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6282342672348022
#
# Average loss: 1.6031, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6055, Accuracy: 585.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6035997867584229
#
# Average loss: 1.5979, Accuracy: 160.0/790 (20%)
#
#
# Average loss: 1.6002, Accuracy: 596.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.25%
# Validation Accuracy: 20.27%
# Batch: 0, Loss: 1.593214750289917
#
# Average loss: 1.5929, Accuracy: 213.0/790 (27%)
#
#
# Average loss: 1.5952, Accuracy: 797.0/2940 (27%)
#
# Epoch: 3 	Training Accuracy: 26.96%
# Validation Accuracy: 27.11%
# Batch: 0, Loss: 1.594979166984558
#
# Average loss: 1.5879, Accuracy: 311.0/790 (39%)
#
#
# Average loss: 1.5902, Accuracy: 1087.0/2940 (37%)
#
# Epoch: 4 	Training Accuracy: 39.37%
# Validation Accuracy: 36.97%
# Batch: 0, Loss: 1.5873984098434448
#
# Average loss: 1.5824, Accuracy: 321.0/790 (41%)
#
#
# Average loss: 1.5844, Accuracy: 1114.0/2940 (38%)
#
# Epoch: 5 	Training Accuracy: 40.63%
# Validation Accuracy: 37.89%
# Batch: 0, Loss: 1.5809375047683716
#
# Average loss: 1.5765, Accuracy: 353.0/790 (45%)
#
#
# Average loss: 1.5784, Accuracy: 1238.0/2940 (42%)
#
# Epoch: 6 	Training Accuracy: 44.68%
# Validation Accuracy: 42.11%
# Batch: 0, Loss: 1.5804716348648071
#
# Average loss: 1.5701, Accuracy: 402.0/790 (51%)
#
#
# Average loss: 1.5719, Accuracy: 1422.0/2940 (48%)
#
# Epoch: 7 	Training Accuracy: 50.89%
# Validation Accuracy: 48.37%
# Batch: 0, Loss: 1.5739705562591553
#
# Average loss: 1.5631, Accuracy: 440.0/790 (56%)
#
#
# Average loss: 1.5648, Accuracy: 1537.0/2940 (52%)
#
# Epoch: 8 	Training Accuracy: 55.70%
# Validation Accuracy: 52.28%
# Batch: 0, Loss: 1.5635207891464233
#
# Average loss: 1.5555, Accuracy: 497.0/790 (63%)
#
#
# Average loss: 1.5570, Accuracy: 1787.0/2940 (61%)
#
# Epoch: 9 	Training Accuracy: 62.91%
# Validation Accuracy: 60.78%
# Batch: 0, Loss: 1.5566850900650024
#
# Average loss: 1.5474, Accuracy: 536.0/790 (68%)
#
#
# Average loss: 1.5488, Accuracy: 1926.0/2940 (66%)
#
# Epoch: 10 	Training Accuracy: 67.85%
# Validation Accuracy: 65.51%
# Batch: 0, Loss: 1.549792766571045
#
# Average loss: 1.5388, Accuracy: 535.0/790 (68%)
#
#
# Average loss: 1.5404, Accuracy: 1910.0/2940 (65%)
#
# Epoch: 11 	Training Accuracy: 67.72%
# Validation Accuracy: 64.97%
# Batch: 0, Loss: 1.5451924800872803
#
# Average loss: 1.5295, Accuracy: 546.0/790 (69%)
#
#
# Average loss: 1.5308, Accuracy: 1966.0/2940 (67%)
#
# Epoch: 12 	Training Accuracy: 69.11%
# Validation Accuracy: 66.87%
# Batch: 0, Loss: 1.5302326679229736
#
# Average loss: 1.5195, Accuracy: 537.0/790 (68%)
#
#
# Average loss: 1.5208, Accuracy: 1963.0/2940 (67%)
#
# Epoch: 13 	Training Accuracy: 67.97%
# Validation Accuracy: 66.77%
# Batch: 0, Loss: 1.526839256286621
#
# Average loss: 1.5088, Accuracy: 543.0/790 (69%)
#
#
# Average loss: 1.5101, Accuracy: 1961.0/2940 (67%)
#
# Epoch: 14 	Training Accuracy: 68.73%
# Validation Accuracy: 66.70%
# Batch: 0, Loss: 1.5096142292022705
#
# Average loss: 1.4973, Accuracy: 549.0/790 (69%)
#
#
# Average loss: 1.4985, Accuracy: 1961.0/2940 (67%)
#
# Epoch: 15 	Training Accuracy: 69.49%
# Validation Accuracy: 66.70%
# Batch: 0, Loss: 1.495787501335144
#
# Average loss: 1.4852, Accuracy: 560.0/790 (71%)
#
#
# Average loss: 1.4866, Accuracy: 1999.0/2940 (68%)
#
# Epoch: 16 	Training Accuracy: 70.89%
# Validation Accuracy: 67.99%
# Batch: 0, Loss: 1.4792587757110596
#
# Average loss: 1.4724, Accuracy: 595.0/790 (75%)
#
#
# Average loss: 1.4742, Accuracy: 2099.0/2940 (71%)
#
# Epoch: 17 	Training Accuracy: 75.32%
# Validation Accuracy: 71.39%
# Batch: 0, Loss: 1.467936635017395
#
# Average loss: 1.4585, Accuracy: 606.0/790 (77%)
#
#
# Average loss: 1.4601, Accuracy: 2151.0/2940 (73%)
#
# Epoch: 18 	Training Accuracy: 76.71%
# Validation Accuracy: 73.16%
# Batch: 0, Loss: 1.4613852500915527
#
# Average loss: 1.4436, Accuracy: 613.0/790 (78%)
#
#
# Average loss: 1.4455, Accuracy: 2198.0/2940 (75%)
#
# Epoch: 19 	Training Accuracy: 77.59%
# Validation Accuracy: 74.76%
#
# Average loss: 1.4436, Accuracy: 613.0/790 (78%)
#
#
# Average loss: 1.4432, Accuracy: 3680.0/4861 (76%)
#
# Final Training Accuracy (New Data): 0.7759
# Final Test Accuracy (New Data): 0.7570
# Repeat: 2, with seed 86 =========================
# Batch: 0, Loss: 1.6169871091842651
#
# Average loss: 1.6122, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6145, Accuracy: 585.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6145251989364624
#
# Average loss: 1.6105, Accuracy: 133.0/790 (17%)
#
#
# Average loss: 1.6121, Accuracy: 555.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 16.84%
# Validation Accuracy: 18.88%
# Batch: 0, Loss: 1.6106889247894287
#
# Average loss: 1.6094, Accuracy: 144.0/790 (18%)
#
#
# Average loss: 1.6105, Accuracy: 492.0/2940 (17%)
#
# Epoch: 2 	Training Accuracy: 18.23%
# Validation Accuracy: 16.73%
# Batch: 0, Loss: 1.6095656156539917
#
# Average loss: 1.6086, Accuracy: 148.0/790 (19%)
#
#
# Average loss: 1.6094, Accuracy: 515.0/2940 (18%)
#
# Epoch: 3 	Training Accuracy: 18.73%
# Validation Accuracy: 17.52%
# Batch: 0, Loss: 1.608215093612671
#
# Average loss: 1.6082, Accuracy: 135.0/790 (17%)
#
#
# Average loss: 1.6090, Accuracy: 547.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 17.09%
# Validation Accuracy: 18.61%
# Batch: 0, Loss: 1.6116646528244019
#
# Average loss: 1.6077, Accuracy: 150.0/790 (19%)
#
#
# Average loss: 1.6084, Accuracy: 516.0/2940 (18%)
#
# Epoch: 5 	Training Accuracy: 18.99%
# Validation Accuracy: 17.55%
# Batch: 0, Loss: 1.6076680421829224
#
# Average loss: 1.6073, Accuracy: 157.0/790 (20%)
#
#
# Average loss: 1.6079, Accuracy: 548.0/2940 (19%)
#
# Epoch: 6 	Training Accuracy: 19.87%
# Validation Accuracy: 18.64%
# Early stopping invoked.
#
# Average loss: 1.6122, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6110, Accuracy: 1010.0/4861 (21%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.2078
# Repeat: 3, with seed 97 =========================
# Batch: 0, Loss: 1.610261082649231
#
# Average loss: 1.6081, Accuracy: 178.0/790 (23%)
#
#
# Average loss: 1.6052, Accuracy: 707.0/2940 (24%)
#
# Epoch: 0 	Training Accuracy: 22.53%
# Validation Accuracy: 24.05%
# Batch: 0, Loss: 1.6170049905776978
#
# Average loss: 1.6059, Accuracy: 214.0/790 (27%)
#
#
# Average loss: 1.6032, Accuracy: 855.0/2940 (29%)
#
# Epoch: 1 	Training Accuracy: 27.09%
# Validation Accuracy: 29.08%
# Batch: 0, Loss: 1.6080185174942017
#
# Average loss: 1.6036, Accuracy: 256.0/790 (32%)
#
#
# Average loss: 1.6009, Accuracy: 972.0/2940 (33%)
#
# Epoch: 2 	Training Accuracy: 32.41%
# Validation Accuracy: 33.06%
# Batch: 0, Loss: 1.6081442832946777
#
# Average loss: 1.6012, Accuracy: 272.0/790 (34%)
#
#
# Average loss: 1.5986, Accuracy: 1074.0/2940 (37%)
#
# Epoch: 3 	Training Accuracy: 34.43%
# Validation Accuracy: 36.53%
# Batch: 0, Loss: 1.5999722480773926
#
# Average loss: 1.5987, Accuracy: 288.0/790 (36%)
#
#
# Average loss: 1.5961, Accuracy: 1137.0/2940 (39%)
#
# Epoch: 4 	Training Accuracy: 36.46%
# Validation Accuracy: 38.67%
# Batch: 0, Loss: 1.5997910499572754
#
# Average loss: 1.5960, Accuracy: 293.0/790 (37%)
#
#
# Average loss: 1.5934, Accuracy: 1161.0/2940 (39%)
#
# Epoch: 5 	Training Accuracy: 37.09%
# Validation Accuracy: 39.49%
# Batch: 0, Loss: 1.5939404964447021
#
# Average loss: 1.5930, Accuracy: 301.0/790 (38%)
#
#
# Average loss: 1.5906, Accuracy: 1176.0/2940 (40%)
#
# Epoch: 6 	Training Accuracy: 38.10%
# Validation Accuracy: 40.00%
# Batch: 0, Loss: 1.583397388458252
#
# Average loss: 1.5899, Accuracy: 308.0/790 (39%)
#
#
# Average loss: 1.5875, Accuracy: 1191.0/2940 (41%)
#
# Epoch: 7 	Training Accuracy: 38.99%
# Validation Accuracy: 40.51%
# Batch: 0, Loss: 1.5872851610183716
#
# Average loss: 1.5865, Accuracy: 317.0/790 (40%)
#
#
# Average loss: 1.5842, Accuracy: 1211.0/2940 (41%)
#
# Epoch: 8 	Training Accuracy: 40.13%
# Validation Accuracy: 41.19%
# Batch: 0, Loss: 1.5875416994094849
#
# Average loss: 1.5828, Accuracy: 323.0/790 (41%)
#
#
# Average loss: 1.5806, Accuracy: 1246.0/2940 (42%)
#
# Epoch: 9 	Training Accuracy: 40.89%
# Validation Accuracy: 42.38%
# Batch: 0, Loss: 1.574477195739746
#
# Average loss: 1.5786, Accuracy: 346.0/790 (44%)
#
#
# Average loss: 1.5767, Accuracy: 1320.0/2940 (45%)
#
# Epoch: 10 	Training Accuracy: 43.80%
# Validation Accuracy: 44.90%
# Batch: 0, Loss: 1.5760670900344849
#
# Average loss: 1.5741, Accuracy: 370.0/790 (47%)
#
#
# Average loss: 1.5723, Accuracy: 1391.0/2940 (47%)
#
# Epoch: 11 	Training Accuracy: 46.84%
# Validation Accuracy: 47.31%
# Batch: 0, Loss: 1.5679672956466675
#
# Average loss: 1.5692, Accuracy: 378.0/790 (48%)
#
#
# Average loss: 1.5675, Accuracy: 1443.0/2940 (49%)
#
# Epoch: 12 	Training Accuracy: 47.85%
# Validation Accuracy: 49.08%
# Batch: 0, Loss: 1.5686687231063843
#
# Average loss: 1.5638, Accuracy: 394.0/790 (50%)
#
#
# Average loss: 1.5622, Accuracy: 1470.0/2940 (50%)
#
# Epoch: 13 	Training Accuracy: 49.87%
# Validation Accuracy: 50.00%
# Batch: 0, Loss: 1.5631139278411865
#
# Average loss: 1.5580, Accuracy: 400.0/790 (51%)
#
#
# Average loss: 1.5565, Accuracy: 1490.0/2940 (51%)
#
# Epoch: 14 	Training Accuracy: 50.63%
# Validation Accuracy: 50.68%
# Batch: 0, Loss: 1.5548832416534424
#
# Average loss: 1.5516, Accuracy: 409.0/790 (52%)
#
#
# Average loss: 1.5503, Accuracy: 1539.0/2940 (52%)
#
# Epoch: 15 	Training Accuracy: 51.77%
# Validation Accuracy: 52.35%
# Batch: 0, Loss: 1.5447547435760498
#
# Average loss: 1.5447, Accuracy: 422.0/790 (53%)
#
#
# Average loss: 1.5436, Accuracy: 1578.0/2940 (54%)
#
# Epoch: 16 	Training Accuracy: 53.42%
# Validation Accuracy: 53.67%
# Batch: 0, Loss: 1.537550926208496
#
# Average loss: 1.5372, Accuracy: 428.0/790 (54%)
#
#
# Average loss: 1.5363, Accuracy: 1600.0/2940 (54%)
#
# Epoch: 17 	Training Accuracy: 54.18%
# Validation Accuracy: 54.42%
# Batch: 0, Loss: 1.5311329364776611
#
# Average loss: 1.5293, Accuracy: 437.0/790 (55%)
#
#
# Average loss: 1.5286, Accuracy: 1636.0/2940 (56%)
#
# Epoch: 18 	Training Accuracy: 55.32%
# Validation Accuracy: 55.65%
# Batch: 0, Loss: 1.5346804857254028
#
# Average loss: 1.5208, Accuracy: 451.0/790 (57%)
#
#
# Average loss: 1.5202, Accuracy: 1670.0/2940 (57%)
#
# Epoch: 19 	Training Accuracy: 57.09%
# Validation Accuracy: 56.80%
#
# Average loss: 1.5208, Accuracy: 451.0/790 (57%)
#
#
# Average loss: 1.5183, Accuracy: 2812.0/4861 (58%)
#
# Final Training Accuracy (New Data): 0.5709
# Final Test Accuracy (New Data): 0.5785
# Repeat: 4, with seed 67 =========================
# Batch: 0, Loss: 1.6112767457962036
#
# Average loss: 1.6101, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6098, Accuracy: 585.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6060848236083984
#
# Average loss: 1.6095, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6092, Accuracy: 585.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.608371615409851
#
# Average loss: 1.6090, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6088, Accuracy: 585.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6127889156341553
#
# Average loss: 1.6084, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6082, Accuracy: 585.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6077864170074463
#
# Average loss: 1.6077, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6075, Accuracy: 585.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6075187921524048
#
# Average loss: 1.6069, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6067, Accuracy: 585.0/2940 (20%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6089084148406982
#
# Average loss: 1.6059, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6059, Accuracy: 585.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Early stopping invoked.
#
# Average loss: 1.6101, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6092, Accuracy: 1009.0/4861 (21%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.2076
# Percentage: 0.05
# Repeat: 0, with seed 9 =========================
# Batch: 0, Loss: 1.6142691373825073
#
# Average loss: 1.6081, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6093, Accuracy: 585.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6050859689712524
#
# Average loss: 1.6039, Accuracy: 267.0/1320 (20%)
#
#
# Average loss: 1.6044, Accuracy: 591.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.23%
# Validation Accuracy: 20.10%
# Batch: 0, Loss: 1.5997532606124878
#
# Average loss: 1.5994, Accuracy: 268.0/1320 (20%)
#
#
# Average loss: 1.5992, Accuracy: 592.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.30%
# Validation Accuracy: 20.14%
# Batch: 0, Loss: 1.6027286052703857
#
# Average loss: 1.5940, Accuracy: 342.0/1320 (26%)
#
#
# Average loss: 1.5927, Accuracy: 810.0/2940 (28%)
#
# Epoch: 3 	Training Accuracy: 25.91%
# Validation Accuracy: 27.55%
# Batch: 0, Loss: 1.5954209566116333
#
# Average loss: 1.5877, Accuracy: 445.0/1320 (34%)
#
#
# Average loss: 1.5855, Accuracy: 1010.0/2940 (34%)
#
# Epoch: 4 	Training Accuracy: 33.71%
# Validation Accuracy: 34.35%
# Batch: 0, Loss: 1.5855847597122192
#
# Average loss: 1.5802, Accuracy: 516.0/1320 (39%)
#
#
# Average loss: 1.5773, Accuracy: 1131.0/2940 (38%)
#
# Epoch: 5 	Training Accuracy: 39.09%
# Validation Accuracy: 38.47%
# Batch: 0, Loss: 1.573781132698059
#
# Average loss: 1.5711, Accuracy: 520.0/1320 (39%)
#
#
# Average loss: 1.5676, Accuracy: 1134.0/2940 (39%)
#
# Epoch: 6 	Training Accuracy: 39.39%
# Validation Accuracy: 38.57%
# Batch: 0, Loss: 1.5711275339126587
#
# Average loss: 1.5596, Accuracy: 688.0/1320 (52%)
#
#
# Average loss: 1.5562, Accuracy: 1548.0/2940 (53%)
#
# Epoch: 7 	Training Accuracy: 52.12%
# Validation Accuracy: 52.65%
# Batch: 0, Loss: 1.5554242134094238
#
# Average loss: 1.5455, Accuracy: 754.0/1320 (57%)
#
#
# Average loss: 1.5418, Accuracy: 1707.0/2940 (58%)
#
# Epoch: 8 	Training Accuracy: 57.12%
# Validation Accuracy: 58.06%
# Batch: 0, Loss: 1.5315982103347778
#
# Average loss: 1.5285, Accuracy: 754.0/1320 (57%)
#
#
# Average loss: 1.5244, Accuracy: 1693.0/2940 (58%)
#
# Epoch: 9 	Training Accuracy: 57.12%
# Validation Accuracy: 57.59%
# Batch: 0, Loss: 1.539099097251892
#
# Average loss: 1.5082, Accuracy: 866.0/1320 (66%)
#
#
# Average loss: 1.5045, Accuracy: 1954.0/2940 (66%)
#
# Epoch: 10 	Training Accuracy: 65.61%
# Validation Accuracy: 66.46%
# Batch: 0, Loss: 1.507147192955017
#
# Average loss: 1.4843, Accuracy: 1004.0/1320 (76%)
#
#
# Average loss: 1.4814, Accuracy: 2207.0/2940 (75%)
#
# Epoch: 11 	Training Accuracy: 76.06%
# Validation Accuracy: 75.07%
# Batch: 0, Loss: 1.4891116619110107
#
# Average loss: 1.4557, Accuracy: 951.0/1320 (72%)
#
#
# Average loss: 1.4512, Accuracy: 2120.0/2940 (72%)
#
# Epoch: 12 	Training Accuracy: 72.05%
# Validation Accuracy: 72.11%
# Batch: 0, Loss: 1.4528988599777222
#
# Average loss: 1.4225, Accuracy: 983.0/1320 (74%)
#
#
# Average loss: 1.4184, Accuracy: 2205.0/2940 (75%)
#
# Epoch: 13 	Training Accuracy: 74.47%
# Validation Accuracy: 75.00%
# Batch: 0, Loss: 1.421837568283081
#
# Average loss: 1.3847, Accuracy: 1005.0/1320 (76%)
#
#
# Average loss: 1.3803, Accuracy: 2262.0/2940 (77%)
#
# Epoch: 14 	Training Accuracy: 76.14%
# Validation Accuracy: 76.94%
# Batch: 0, Loss: 1.3878974914550781
#
# Average loss: 1.3420, Accuracy: 1014.0/1320 (77%)
#
#
# Average loss: 1.3382, Accuracy: 2260.0/2940 (77%)
#
# Epoch: 15 	Training Accuracy: 76.82%
# Validation Accuracy: 76.87%
# Batch: 0, Loss: 1.3200780153274536
#
# Average loss: 1.2936, Accuracy: 992.0/1320 (75%)
#
#
# Average loss: 1.2876, Accuracy: 2212.0/2940 (75%)
#
# Epoch: 16 	Training Accuracy: 75.15%
# Validation Accuracy: 75.24%
# Batch: 0, Loss: 1.2740970849990845
#
# Average loss: 1.2416, Accuracy: 1011.0/1320 (77%)
#
#
# Average loss: 1.2355, Accuracy: 2231.0/2940 (76%)
#
# Epoch: 17 	Training Accuracy: 76.59%
# Validation Accuracy: 75.88%
# Batch: 0, Loss: 1.2431325912475586
#
# Average loss: 1.1861, Accuracy: 1022.0/1320 (77%)
#
#
# Average loss: 1.1811, Accuracy: 2268.0/2940 (77%)
#
# Epoch: 18 	Training Accuracy: 77.42%
# Validation Accuracy: 77.14%
# Batch: 0, Loss: 1.1497188806533813
#
# Average loss: 1.1301, Accuracy: 1020.0/1320 (77%)
#
#
# Average loss: 1.1254, Accuracy: 2251.0/2940 (77%)
#
# Epoch: 19 	Training Accuracy: 77.27%
# Validation Accuracy: 76.56%
#
# Average loss: 1.1301, Accuracy: 1020.0/1320 (77%)
#
#
# Average loss: 1.1164, Accuracy: 3878.0/4861 (80%)
#
# Final Training Accuracy (New Data): 0.7727
# Final Test Accuracy (New Data): 0.7978
# Repeat: 1, with seed 43 =========================
# Batch: 0, Loss: 1.6160365343093872
#
# Average loss: 1.6107, Accuracy: 266.0/1320 (20%)
#
#
# Average loss: 1.6101, Accuracy: 601.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.15%
# Validation Accuracy: 20.44%
# Batch: 0, Loss: 1.6081573963165283
#
# Average loss: 1.6086, Accuracy: 269.0/1320 (20%)
#
#
# Average loss: 1.6082, Accuracy: 613.0/2940 (21%)
#
# Epoch: 1 	Training Accuracy: 20.38%
# Validation Accuracy: 20.85%
# Batch: 0, Loss: 1.611262321472168
#
# Average loss: 1.6064, Accuracy: 286.0/1320 (22%)
#
#
# Average loss: 1.6062, Accuracy: 635.0/2940 (22%)
#
# Epoch: 2 	Training Accuracy: 21.67%
# Validation Accuracy: 21.60%
# Batch: 0, Loss: 1.6095411777496338
#
# Average loss: 1.6039, Accuracy: 314.0/1320 (24%)
#
#
# Average loss: 1.6040, Accuracy: 683.0/2940 (23%)
#
# Epoch: 3 	Training Accuracy: 23.79%
# Validation Accuracy: 23.23%
# Batch: 0, Loss: 1.5938477516174316
#
# Average loss: 1.6009, Accuracy: 348.0/1320 (26%)
#
#
# Average loss: 1.6011, Accuracy: 736.0/2940 (25%)
#
# Epoch: 4 	Training Accuracy: 26.36%
# Validation Accuracy: 25.03%
# Batch: 0, Loss: 1.6003037691116333
#
# Average loss: 1.5970, Accuracy: 375.0/1320 (28%)
#
#
# Average loss: 1.5976, Accuracy: 814.0/2940 (28%)
#
# Epoch: 5 	Training Accuracy: 28.41%
# Validation Accuracy: 27.69%
# Batch: 0, Loss: 1.6053825616836548
#
# Average loss: 1.5922, Accuracy: 419.0/1320 (32%)
#
#
# Average loss: 1.5931, Accuracy: 895.0/2940 (30%)
#
# Epoch: 6 	Training Accuracy: 31.74%
# Validation Accuracy: 30.44%
# Batch: 0, Loss: 1.5915520191192627
#
# Average loss: 1.5859, Accuracy: 456.0/1320 (35%)
#
#
# Average loss: 1.5872, Accuracy: 972.0/2940 (33%)
#
# Epoch: 7 	Training Accuracy: 34.55%
# Validation Accuracy: 33.06%
# Batch: 0, Loss: 1.590585470199585
#
# Average loss: 1.5776, Accuracy: 484.0/1320 (37%)
#
#
# Average loss: 1.5795, Accuracy: 1047.0/2940 (36%)
#
# Epoch: 8 	Training Accuracy: 36.67%
# Validation Accuracy: 35.61%
# Batch: 0, Loss: 1.5728189945220947
#
# Average loss: 1.5674, Accuracy: 511.0/1320 (39%)
#
#
# Average loss: 1.5702, Accuracy: 1098.0/2940 (37%)
#
# Epoch: 9 	Training Accuracy: 38.71%
# Validation Accuracy: 37.35%
# Batch: 0, Loss: 1.5694533586502075
#
# Average loss: 1.5551, Accuracy: 545.0/1320 (41%)
#
#
# Average loss: 1.5585, Accuracy: 1165.0/2940 (40%)
#
# Epoch: 10 	Training Accuracy: 41.29%
# Validation Accuracy: 39.63%
# Batch: 0, Loss: 1.5498898029327393
#
# Average loss: 1.5400, Accuracy: 627.0/1320 (48%)
#
#
# Average loss: 1.5439, Accuracy: 1310.0/2940 (45%)
#
# Epoch: 11 	Training Accuracy: 47.50%
# Validation Accuracy: 44.56%
# Batch: 0, Loss: 1.5525659322738647
#
# Average loss: 1.5220, Accuracy: 715.0/1320 (54%)
#
#
# Average loss: 1.5263, Accuracy: 1494.0/2940 (51%)
#
# Epoch: 12 	Training Accuracy: 54.17%
# Validation Accuracy: 50.82%
# Batch: 0, Loss: 1.522497534751892
#
# Average loss: 1.5007, Accuracy: 750.0/1320 (57%)
#
#
# Average loss: 1.5058, Accuracy: 1576.0/2940 (54%)
#
# Epoch: 13 	Training Accuracy: 56.82%
# Validation Accuracy: 53.61%
# Batch: 0, Loss: 1.4965897798538208
#
# Average loss: 1.4763, Accuracy: 846.0/1320 (64%)
#
#
# Average loss: 1.4817, Accuracy: 1847.0/2940 (63%)
#
# Epoch: 14 	Training Accuracy: 64.09%
# Validation Accuracy: 62.82%
# Batch: 0, Loss: 1.4880095720291138
#
# Average loss: 1.4500, Accuracy: 925.0/1320 (70%)
#
#
# Average loss: 1.4555, Accuracy: 2032.0/2940 (69%)
#
# Epoch: 15 	Training Accuracy: 70.08%
# Validation Accuracy: 69.12%
# Batch: 0, Loss: 1.4503413438796997
#
# Average loss: 1.4233, Accuracy: 971.0/1320 (74%)
#
#
# Average loss: 1.4288, Accuracy: 2140.0/2940 (73%)
#
# Epoch: 16 	Training Accuracy: 73.56%
# Validation Accuracy: 72.79%
# Batch: 0, Loss: 1.4069339036941528
#
# Average loss: 1.3944, Accuracy: 1025.0/1320 (78%)
#
#
# Average loss: 1.3993, Accuracy: 2248.0/2940 (76%)
#
# Epoch: 17 	Training Accuracy: 77.65%
# Validation Accuracy: 76.46%
# Batch: 0, Loss: 1.405725359916687
#
# Average loss: 1.3631, Accuracy: 1057.0/1320 (80%)
#
#
# Average loss: 1.3679, Accuracy: 2315.0/2940 (79%)
#
# Epoch: 18 	Training Accuracy: 80.08%
# Validation Accuracy: 78.74%
# Batch: 0, Loss: 1.3722318410873413
#
# Average loss: 1.3290, Accuracy: 1071.0/1320 (81%)
#
#
# Average loss: 1.3335, Accuracy: 2326.0/2940 (79%)
#
# Epoch: 19 	Training Accuracy: 81.14%
# Validation Accuracy: 79.12%
#
# Average loss: 1.3290, Accuracy: 1071.0/1320 (81%)
#
#
# Average loss: 1.3277, Accuracy: 3979.0/4861 (82%)
#
# Final Training Accuracy (New Data): 0.8114
# Final Test Accuracy (New Data): 0.8186
# Repeat: 2, with seed 71 =========================
# Batch: 0, Loss: 1.6105124950408936
#
# Average loss: 1.6103, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6127, Accuracy: 551.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6162039041519165
#
# Average loss: 1.6102, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6124, Accuracy: 551.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6083910465240479
#
# Average loss: 1.6101, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6122, Accuracy: 551.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6136704683303833
#
# Average loss: 1.6100, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6120, Accuracy: 551.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6046851873397827
#
# Average loss: 1.6100, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6119, Accuracy: 551.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6096367835998535
#
# Average loss: 1.6099, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6116, Accuracy: 551.0/2940 (19%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6143611669540405
#
# Average loss: 1.6098, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6114, Accuracy: 551.0/2940 (19%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Early stopping invoked.
#
# Average loss: 1.6103, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6121, Accuracy: 892.0/4861 (18%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.1835
# Repeat: 3, with seed 3 =========================
# Batch: 0, Loss: 1.6261576414108276
#
# Average loss: 1.6121, Accuracy: 237.0/1320 (18%)
#
#
# Average loss: 1.6153, Accuracy: 512.0/2940 (17%)
#
# Epoch: 0 	Training Accuracy: 17.95%
# Validation Accuracy: 17.41%
# Batch: 0, Loss: 1.6119943857192993
#
# Average loss: 1.6051, Accuracy: 262.0/1320 (20%)
#
#
# Average loss: 1.6077, Accuracy: 541.0/2940 (18%)
#
# Epoch: 1 	Training Accuracy: 19.85%
# Validation Accuracy: 18.40%
# Batch: 0, Loss: 1.6068148612976074
#
# Average loss: 1.5982, Accuracy: 276.0/1320 (21%)
#
#
# Average loss: 1.6003, Accuracy: 570.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 20.91%
# Validation Accuracy: 19.39%
# Batch: 0, Loss: 1.5989677906036377
#
# Average loss: 1.5904, Accuracy: 334.0/1320 (25%)
#
#
# Average loss: 1.5920, Accuracy: 708.0/2940 (24%)
#
# Epoch: 3 	Training Accuracy: 25.30%
# Validation Accuracy: 24.08%
# Batch: 0, Loss: 1.5873852968215942
#
# Average loss: 1.5816, Accuracy: 440.0/1320 (33%)
#
#
# Average loss: 1.5832, Accuracy: 955.0/2940 (32%)
#
# Epoch: 4 	Training Accuracy: 33.33%
# Validation Accuracy: 32.48%
# Batch: 0, Loss: 1.5828145742416382
#
# Average loss: 1.5714, Accuracy: 667.0/1320 (51%)
#
#
# Average loss: 1.5729, Accuracy: 1414.0/2940 (48%)
#
# Epoch: 5 	Training Accuracy: 50.53%
# Validation Accuracy: 48.10%
# Batch: 0, Loss: 1.5752477645874023
#
# Average loss: 1.5597, Accuracy: 765.0/1320 (58%)
#
#
# Average loss: 1.5611, Accuracy: 1722.0/2940 (59%)
#
# Epoch: 6 	Training Accuracy: 57.95%
# Validation Accuracy: 58.57%
# Batch: 0, Loss: 1.5569032430648804
#
# Average loss: 1.5461, Accuracy: 863.0/1320 (65%)
#
#
# Average loss: 1.5475, Accuracy: 1953.0/2940 (66%)
#
# Epoch: 7 	Training Accuracy: 65.38%
# Validation Accuracy: 66.43%
# Batch: 0, Loss: 1.5451064109802246
#
# Average loss: 1.5306, Accuracy: 929.0/1320 (70%)
#
#
# Average loss: 1.5322, Accuracy: 2113.0/2940 (72%)
#
# Epoch: 8 	Training Accuracy: 70.38%
# Validation Accuracy: 71.87%
# Batch: 0, Loss: 1.5379453897476196
#
# Average loss: 1.5129, Accuracy: 973.0/1320 (74%)
#
#
# Average loss: 1.5143, Accuracy: 2218.0/2940 (75%)
#
# Epoch: 9 	Training Accuracy: 73.71%
# Validation Accuracy: 75.44%
# Batch: 0, Loss: 1.5173802375793457
#
# Average loss: 1.4925, Accuracy: 967.0/1320 (73%)
#
#
# Average loss: 1.4943, Accuracy: 2200.0/2940 (75%)
#
# Epoch: 10 	Training Accuracy: 73.26%
# Validation Accuracy: 74.83%
# Batch: 0, Loss: 1.4825536012649536
#
# Average loss: 1.4694, Accuracy: 987.0/1320 (75%)
#
#
# Average loss: 1.4716, Accuracy: 2247.0/2940 (76%)
#
# Epoch: 11 	Training Accuracy: 74.77%
# Validation Accuracy: 76.43%
# Batch: 0, Loss: 1.4630513191223145
#
# Average loss: 1.4433, Accuracy: 1017.0/1320 (77%)
#
#
# Average loss: 1.4453, Accuracy: 2310.0/2940 (79%)
#
# Epoch: 12 	Training Accuracy: 77.05%
# Validation Accuracy: 78.57%
# Batch: 0, Loss: 1.443655252456665
#
# Average loss: 1.4143, Accuracy: 1031.0/1320 (78%)
#
#
# Average loss: 1.4161, Accuracy: 2333.0/2940 (79%)
#
# Epoch: 13 	Training Accuracy: 78.11%
# Validation Accuracy: 79.35%
# Batch: 0, Loss: 1.4056384563446045
#
# Average loss: 1.3821, Accuracy: 1036.0/1320 (78%)
#
#
# Average loss: 1.3836, Accuracy: 2337.0/2940 (79%)
#
# Epoch: 14 	Training Accuracy: 78.48%
# Validation Accuracy: 79.49%
# Batch: 0, Loss: 1.3966974020004272
#
# Average loss: 1.3469, Accuracy: 1050.0/1320 (80%)
#
#
# Average loss: 1.3484, Accuracy: 2360.0/2940 (80%)
#
# Epoch: 15 	Training Accuracy: 79.55%
# Validation Accuracy: 80.27%
# Batch: 0, Loss: 1.3388010263442993
#
# Average loss: 1.3082, Accuracy: 1055.0/1320 (80%)
#
#
# Average loss: 1.3096, Accuracy: 2359.0/2940 (80%)
#
# Epoch: 16 	Training Accuracy: 79.92%
# Validation Accuracy: 80.24%
# Batch: 0, Loss: 1.29405677318573
#
# Average loss: 1.2665, Accuracy: 1059.0/1320 (80%)
#
#
# Average loss: 1.2676, Accuracy: 2377.0/2940 (81%)
#
# Epoch: 17 	Training Accuracy: 80.23%
# Validation Accuracy: 80.85%
# Batch: 0, Loss: 1.2789188623428345
#
# Average loss: 1.2223, Accuracy: 1060.0/1320 (80%)
#
#
# Average loss: 1.2228, Accuracy: 2370.0/2940 (81%)
#
# Epoch: 18 	Training Accuracy: 80.30%
# Validation Accuracy: 80.61%
# Batch: 0, Loss: 1.2301137447357178
#
# Average loss: 1.1767, Accuracy: 1059.0/1320 (80%)
#
#
# Average loss: 1.1771, Accuracy: 2370.0/2940 (81%)
#
# Epoch: 19 	Training Accuracy: 80.23%
# Validation Accuracy: 80.61%
#
# Average loss: 1.1767, Accuracy: 1059.0/1320 (80%)
#
#
# Average loss: 1.1742, Accuracy: 3900.0/4861 (80%)
#
# Final Training Accuracy (New Data): 0.8023
# Final Test Accuracy (New Data): 0.8023
# Repeat: 4, with seed 7 =========================
# Batch: 0, Loss: 1.6009628772735596
#
# Average loss: 1.6079, Accuracy: 418.0/1320 (32%)
#
#
# Average loss: 1.6072, Accuracy: 938.0/2940 (32%)
#
# Epoch: 0 	Training Accuracy: 31.67%
# Validation Accuracy: 31.90%
# Batch: 0, Loss: 1.6084694862365723
#
# Average loss: 1.6054, Accuracy: 410.0/1320 (31%)
#
#
# Average loss: 1.6050, Accuracy: 927.0/2940 (32%)
#
# Epoch: 1 	Training Accuracy: 31.06%
# Validation Accuracy: 31.53%
# Batch: 0, Loss: 1.607612133026123
#
# Average loss: 1.6031, Accuracy: 452.0/1320 (34%)
#
#
# Average loss: 1.6031, Accuracy: 1024.0/2940 (35%)
#
# Epoch: 2 	Training Accuracy: 34.24%
# Validation Accuracy: 34.83%
# Batch: 0, Loss: 1.6009588241577148
#
# Average loss: 1.6005, Accuracy: 450.0/1320 (34%)
#
#
# Average loss: 1.6007, Accuracy: 1010.0/2940 (34%)
#
# Epoch: 3 	Training Accuracy: 34.09%
# Validation Accuracy: 34.35%
# Batch: 0, Loss: 1.6015855073928833
#
# Average loss: 1.5976, Accuracy: 563.0/1320 (43%)
#
#
# Average loss: 1.5978, Accuracy: 1267.0/2940 (43%)
#
# Epoch: 4 	Training Accuracy: 42.65%
# Validation Accuracy: 43.10%
# Batch: 0, Loss: 1.5944023132324219
#
# Average loss: 1.5941, Accuracy: 658.0/1320 (50%)
#
#
# Average loss: 1.5943, Accuracy: 1539.0/2940 (52%)
#
# Epoch: 5 	Training Accuracy: 49.85%
# Validation Accuracy: 52.35%
# Batch: 0, Loss: 1.5953974723815918
#
# Average loss: 1.5900, Accuracy: 775.0/1320 (59%)
#
#
# Average loss: 1.5902, Accuracy: 1755.0/2940 (60%)
#
# Epoch: 6 	Training Accuracy: 58.71%
# Validation Accuracy: 59.69%
# Batch: 0, Loss: 1.5911180973052979
#
# Average loss: 1.5853, Accuracy: 781.0/1320 (59%)
#
#
# Average loss: 1.5855, Accuracy: 1785.0/2940 (61%)
#
# Epoch: 7 	Training Accuracy: 59.17%
# Validation Accuracy: 60.71%
# Batch: 0, Loss: 1.5822163820266724
#
# Average loss: 1.5797, Accuracy: 785.0/1320 (59%)
#
#
# Average loss: 1.5801, Accuracy: 1785.0/2940 (61%)
#
# Epoch: 8 	Training Accuracy: 59.47%
# Validation Accuracy: 60.71%
# Batch: 0, Loss: 1.5753637552261353
#
# Average loss: 1.5732, Accuracy: 837.0/1320 (63%)
#
#
# Average loss: 1.5737, Accuracy: 1861.0/2940 (63%)
#
# Epoch: 9 	Training Accuracy: 63.41%
# Validation Accuracy: 63.30%
# Batch: 0, Loss: 1.5699230432510376
#
# Average loss: 1.5655, Accuracy: 827.0/1320 (63%)
#
#
# Average loss: 1.5660, Accuracy: 1849.0/2940 (63%)
#
# Epoch: 10 	Training Accuracy: 62.65%
# Validation Accuracy: 62.89%
# Batch: 0, Loss: 1.5667352676391602
#
# Average loss: 1.5565, Accuracy: 818.0/1320 (62%)
#
#
# Average loss: 1.5573, Accuracy: 1864.0/2940 (63%)
#
# Epoch: 11 	Training Accuracy: 61.97%
# Validation Accuracy: 63.40%
# Batch: 0, Loss: 1.5589317083358765
#
# Average loss: 1.5462, Accuracy: 910.0/1320 (69%)
#
#
# Average loss: 1.5474, Accuracy: 2010.0/2940 (68%)
#
# Epoch: 12 	Training Accuracy: 68.94%
# Validation Accuracy: 68.37%
# Batch: 0, Loss: 1.5407077074050903
#
# Average loss: 1.5342, Accuracy: 879.0/1320 (67%)
#
#
# Average loss: 1.5359, Accuracy: 1963.0/2940 (67%)
#
# Epoch: 13 	Training Accuracy: 66.59%
# Validation Accuracy: 66.77%
# Batch: 0, Loss: 1.5238635540008545
#
# Average loss: 1.5204, Accuracy: 891.0/1320 (68%)
#
#
# Average loss: 1.5218, Accuracy: 1995.0/2940 (68%)
#
# Epoch: 14 	Training Accuracy: 67.50%
# Validation Accuracy: 67.86%
# Batch: 0, Loss: 1.5211461782455444
#
# Average loss: 1.5045, Accuracy: 885.0/1320 (67%)
#
#
# Average loss: 1.5060, Accuracy: 1982.0/2940 (67%)
#
# Epoch: 15 	Training Accuracy: 67.05%
# Validation Accuracy: 67.41%
# Batch: 0, Loss: 1.493760585784912
#
# Average loss: 1.4865, Accuracy: 914.0/1320 (69%)
#
#
# Average loss: 1.4885, Accuracy: 2032.0/2940 (69%)
#
# Epoch: 16 	Training Accuracy: 69.24%
# Validation Accuracy: 69.12%
# Batch: 0, Loss: 1.4797821044921875
#
# Average loss: 1.4659, Accuracy: 971.0/1320 (74%)
#
#
# Average loss: 1.4682, Accuracy: 2120.0/2940 (72%)
#
# Epoch: 17 	Training Accuracy: 73.56%
# Validation Accuracy: 72.11%
# Batch: 0, Loss: 1.474214792251587
#
# Average loss: 1.4422, Accuracy: 965.0/1320 (73%)
#
#
# Average loss: 1.4441, Accuracy: 2116.0/2940 (72%)
#
# Epoch: 18 	Training Accuracy: 73.11%
# Validation Accuracy: 71.97%
# Batch: 0, Loss: 1.4681001901626587
#
# Average loss: 1.4157, Accuracy: 970.0/1320 (73%)
#
#
# Average loss: 1.4177, Accuracy: 2129.0/2940 (72%)
#
# Epoch: 19 	Training Accuracy: 73.48%
# Validation Accuracy: 72.41%
#
# Average loss: 1.4157, Accuracy: 970.0/1320 (73%)
#
#
# Average loss: 1.4171, Accuracy: 3506.0/4861 (72%)
#
# Final Training Accuracy (New Data): 0.7348
# Final Test Accuracy (New Data): 0.7213
# Percentage: 0.1
# Repeat: 0, with seed 70 =========================
# Batch: 0, Loss: 1.6103800535202026
# Batch: 20, Loss: 1.6198595762252808
#
# Average loss: 1.6080, Accuracy: 746.0/2645 (28%)
#
#
# Average loss: 1.6047, Accuracy: 848.0/2940 (29%)
#
# Epoch: 0 	Training Accuracy: 28.20%
# Validation Accuracy: 28.84%
# Batch: 0, Loss: 1.6044243574142456
# Batch: 20, Loss: 1.5904285907745361
#
# Average loss: 1.5978, Accuracy: 961.0/2645 (36%)
#
#
# Average loss: 1.5950, Accuracy: 1140.0/2940 (39%)
#
# Epoch: 1 	Training Accuracy: 36.33%
# Validation Accuracy: 38.78%
# Batch: 0, Loss: 1.5941004753112793
# Batch: 20, Loss: 1.5823776721954346
#
# Average loss: 1.5807, Accuracy: 1021.0/2645 (39%)
#
#
# Average loss: 1.5785, Accuracy: 1201.0/2940 (41%)
#
# Epoch: 2 	Training Accuracy: 38.60%
# Validation Accuracy: 40.85%
# Batch: 0, Loss: 1.5790519714355469
# Batch: 20, Loss: 1.5602357387542725
#
# Average loss: 1.5560, Accuracy: 1361.0/2645 (51%)
#
#
# Average loss: 1.5543, Accuracy: 1539.0/2940 (52%)
#
# Epoch: 3 	Training Accuracy: 51.46%
# Validation Accuracy: 52.35%
# Batch: 0, Loss: 1.5619451999664307
# ...
#
# Epoch: 16 	Training Accuracy: 93.28%
# Validation Accuracy: 93.37%
# Batch: 0, Loss: 0.2033211886882782
# Batch: 20, Loss: 0.1734342873096466
# Batch: 40, Loss: 0.295931875705719
# Batch: 60, Loss: 0.20056240260601044
# Batch: 80, Loss: 0.12689584493637085
# Batch: 100, Loss: 0.2972828447818756
# Batch: 120, Loss: 0.25741663575172424
# Batch: 140, Loss: 0.2813898026943207
# Batch: 160, Loss: 0.1863943487405777
# Batch: 180, Loss: 0.19304923713207245
# Batch: 200, Loss: 0.24634823203086853
#
# Average loss: 0.1934, Accuracy: 24325.0/26038 (93%)
#
#
# Average loss: 0.2015, Accuracy: 2747.0/2940 (93%)
#
# Epoch: 17 	Training Accuracy: 93.42%
# Validation Accuracy: 93.44%
# Batch: 0, Loss: 0.25875604152679443
# Batch: 20, Loss: 0.17164123058319092
# Batch: 40, Loss: 0.1990615576505661
# Batch: 60, Loss: 0.17777058482170105
# Batch: 80, Loss: 0.19114336371421814
# Batch: 100, Loss: 0.19081786274909973
# Batch: 120, Loss: 0.22177164256572723
# Batch: 140, Loss: 0.1515333205461502
# Batch: 160, Loss: 0.193645641207695
# Batch: 180, Loss: 0.11419408768415451
# Batch: 200, Loss: 0.17971201241016388
#
# Average loss: 0.1898, Accuracy: 24360.0/26038 (94%)
#
#
# Average loss: 0.1980, Accuracy: 2752.0/2940 (94%)
#
# Epoch: 18 	Training Accuracy: 93.56%
# Validation Accuracy: 93.61%
# Batch: 0, Loss: 0.2339363545179367
# Batch: 20, Loss: 0.1421326994895935
# Batch: 40, Loss: 0.23704437911510468
# Batch: 60, Loss: 0.19055457413196564
# Batch: 80, Loss: 0.1926611065864563
# Batch: 100, Loss: 0.14792418479919434
# Batch: 120, Loss: 0.19787536561489105
# Batch: 140, Loss: 0.31273967027664185
# Batch: 160, Loss: 0.22484104335308075
# Batch: 180, Loss: 0.21251407265663147
# Batch: 200, Loss: 0.19485916197299957
#
# Average loss: 0.1858, Accuracy: 24399.0/26038 (94%)
#
#
# Average loss: 0.1949, Accuracy: 2761.0/2940 (94%)
#
# Epoch: 19 	Training Accuracy: 93.71%
# Validation Accuracy: 93.91%
#
# Average loss: 0.1858, Accuracy: 24399.0/26038 (94%)
#
#
# Average loss: 0.1968, Accuracy: 4525.0/4861 (93%)
#
# Final Training Accuracy (New Data): 0.9371
# Final Test Accuracy (New Data): 0.9309
# Repeat: 4, with seed 53 =========================
# Batch: 0, Loss: 1.6135848760604858
# Batch: 20, Loss: 1.603271484375
# Batch: 40, Loss: 1.6080330610275269
# Batch: 60, Loss: 1.5959417819976807
# Batch: 80, Loss: 1.5886776447296143
# Batch: 100, Loss: 1.577027440071106
# Batch: 120, Loss: 1.565664291381836
# Batch: 140, Loss: 1.558685541152954
# Batch: 160, Loss: 1.5318512916564941
# Batch: 180, Loss: 1.5178954601287842
# Batch: 200, Loss: 1.5086228847503662
#
# Average loss: 1.4846, Accuracy: 15199.0/26038 (58%)
#
#
# Average loss: 1.4875, Accuracy: 1675.0/2940 (57%)
#
# Epoch: 0 	Training Accuracy: 58.37%
# Validation Accuracy: 56.97%
# Batch: 0, Loss: 1.4702301025390625
# Batch: 20, Loss: 1.4540077447891235
# Batch: 40, Loss: 1.4051625728607178
# Batch: 60, Loss: 1.3615992069244385
# Batch: 80, Loss: 1.3122817277908325
# Batch: 100, Loss: 1.228435754776001
# Batch: 120, Loss: 1.1942780017852783
# Batch: 140, Loss: 1.0691776275634766
# Batch: 160, Loss: 1.007375717163086
# Batch: 180, Loss: 0.9233033657073975
# Batch: 200, Loss: 0.8171830177307129
#
# Average loss: 0.8155, Accuracy: 21322.0/26038 (82%)
#
#
# Average loss: 0.8162, Accuracy: 2401.0/2940 (82%)
#
# Epoch: 1 	Training Accuracy: 81.89%
# Validation Accuracy: 81.67%
# Batch: 0, Loss: 0.872047483921051
# Batch: 20, Loss: 0.7271157503128052
# Batch: 40, Loss: 0.6139839291572571
# Batch: 60, Loss: 0.6150034666061401
# Batch: 80, Loss: 0.5622409582138062
# Batch: 100, Loss: 0.5178529620170593
# Batch: 120, Loss: 0.5439544916152954
# Batch: 140, Loss: 0.4507768154144287
# Batch: 160, Loss: 0.4109446406364441
# Batch: 180, Loss: 0.5039568543434143
# Batch: 200, Loss: 0.4040360152721405
#
# Average loss: 0.4018, Accuracy: 23141.0/26038 (89%)
#
#
# Average loss: 0.4181, Accuracy: 2595.0/2940 (88%)
#
# Epoch: 2 	Training Accuracy: 88.87%
# Validation Accuracy: 88.27%
# Batch: 0, Loss: 0.3702182471752167
# Batch: 20, Loss: 0.4464191496372223
# Batch: 40, Loss: 0.3237733840942383
# Batch: 60, Loss: 0.3319072425365448
# Batch: 80, Loss: 0.2532513737678528
# Batch: 100, Loss: 0.29959672689437866
# Batch: 120, Loss: 0.4279061257839203
# Batch: 140, Loss: 0.24878698587417603
# Batch: 160, Loss: 0.34403377771377563
# Batch: 180, Loss: 0.3580878973007202
# Batch: 200, Loss: 0.30633413791656494
#
# Average loss: 0.3016, Accuracy: 23637.0/26038 (91%)
#
#
# Average loss: 0.3234, Accuracy: 2646.0/2940 (90%)
#
# Epoch: 3 	Training Accuracy: 90.78%
# Validation Accuracy: 90.00%
# Batch: 0, Loss: 0.3055184781551361
# Batch: 20, Loss: 0.25165075063705444
# Batch: 40, Loss: 0.2616998851299286
# Batch: 60, Loss: 0.1705494374036789
# Batch: 80, Loss: 0.22805878520011902
# Batch: 100, Loss: 0.20257675647735596
# Batch: 120, Loss: 0.29755130410194397
# Batch: 140, Loss: 0.2231350839138031
# Batch: 160, Loss: 0.3926943838596344
# Batch: 180, Loss: 0.19693554937839508
# Batch: 200, Loss: 0.3063868284225464
#
# Average loss: 0.2588, Accuracy: 23956.0/26038 (92%)
#
#
# Average loss: 0.2803, Accuracy: 2686.0/2940 (91%)
#
# Epoch: 4 	Training Accuracy: 92.00%
# Validation Accuracy: 91.36%
# Batch: 0, Loss: 0.25197699666023254
# Batch: 20, Loss: 0.22715404629707336
# Batch: 40, Loss: 0.2637235224246979
# Batch: 60, Loss: 0.23871320486068726
# Batch: 80, Loss: 0.17530083656311035
# Batch: 100, Loss: 0.17837797105312347
# Batch: 120, Loss: 0.15112711489200592
# Batch: 140, Loss: 0.26723217964172363
# Batch: 160, Loss: 0.26483353972435
# Batch: 180, Loss: 0.2289929986000061
# Batch: 200, Loss: 0.2813045084476471
#
# Average loss: 0.2319, Accuracy: 24189.0/26038 (93%)
#
#
# Average loss: 0.2525, Accuracy: 2713.0/2940 (92%)
#
# Epoch: 5 	Training Accuracy: 92.90%
# Validation Accuracy: 92.28%
# Batch: 0, Loss: 0.25249773263931274
# Batch: 20, Loss: 0.3042493760585785
# Batch: 40, Loss: 0.27326685190200806
# Batch: 60, Loss: 0.3025341033935547
# Batch: 80, Loss: 0.13363337516784668
# Batch: 100, Loss: 0.20932258665561676
# Batch: 120, Loss: 0.19565017521381378
# Batch: 140, Loss: 0.21155434846878052
# Batch: 160, Loss: 0.12219230085611343
# Batch: 180, Loss: 0.11934377998113632
# Batch: 200, Loss: 0.1729552447795868
#
# Average loss: 0.2133, Accuracy: 24272.0/26038 (93%)
#
#
# Average loss: 0.2335, Accuracy: 2729.0/2940 (93%)
#
# Epoch: 6 	Training Accuracy: 93.22%
# Validation Accuracy: 92.82%
# Batch: 0, Loss: 0.26876100897789
# Batch: 20, Loss: 0.2186809480190277
# Batch: 40, Loss: 0.11677784472703934
# Batch: 60, Loss: 0.16614708304405212
# Batch: 80, Loss: 0.31923407316207886
# Batch: 100, Loss: 0.20570440590381622
# Batch: 120, Loss: 0.24363555014133453
# Batch: 140, Loss: 0.26122695207595825
# Batch: 160, Loss: 0.15416058897972107
# Batch: 180, Loss: 0.17862996459007263
# Batch: 200, Loss: 0.20339606702327728
#
# Average loss: 0.1981, Accuracy: 24418.0/26038 (94%)
#
#
# Average loss: 0.2168, Accuracy: 2752.0/2940 (94%)
#
# Epoch: 7 	Training Accuracy: 93.78%
# Validation Accuracy: 93.61%
# Batch: 0, Loss: 0.14619271457195282
# Batch: 20, Loss: 0.15867550671100616
# Batch: 40, Loss: 0.14423944056034088
# Batch: 60, Loss: 0.2148425430059433
# Batch: 80, Loss: 0.13142167031764984
# Batch: 100, Loss: 0.15100900828838348
# Batch: 120, Loss: 0.21895554661750793
# Batch: 140, Loss: 0.352289080619812
# Batch: 160, Loss: 0.24701108038425446
# Batch: 180, Loss: 0.22901026904582977
# Batch: 200, Loss: 0.15314367413520813
#
# Average loss: 0.1854, Accuracy: 24547.0/26038 (94%)
#
#
# Average loss: 0.2032, Accuracy: 2768.0/2940 (94%)
#
# Epoch: 8 	Training Accuracy: 94.27%
# Validation Accuracy: 94.15%
# Batch: 0, Loss: 0.17910736799240112
# Batch: 20, Loss: 0.38086894154548645
# Batch: 40, Loss: 0.26075437664985657
# Batch: 60, Loss: 0.2076517790555954
# Batch: 80, Loss: 0.18800923228263855
# Batch: 100, Loss: 0.27887651324272156
# Batch: 120, Loss: 0.2347394973039627
# Batch: 140, Loss: 0.08388792723417282
# Batch: 160, Loss: 0.23248574137687683
# Batch: 180, Loss: 0.13196194171905518
# Batch: 200, Loss: 0.23192711174488068
#
# Average loss: 0.1760, Accuracy: 24627.0/26038 (95%)
#
#
# Average loss: 0.1934, Accuracy: 2780.0/2940 (95%)
#
# Epoch: 9 	Training Accuracy: 94.58%
# Validation Accuracy: 94.56%
# Batch: 0, Loss: 0.19624587893486023
# Batch: 20, Loss: 0.141929492354393
# Batch: 40, Loss: 0.09813454002141953
# Batch: 60, Loss: 0.10153482854366302
# Batch: 80, Loss: 0.19644461572170258
# Batch: 100, Loss: 0.07049649208784103
# Batch: 120, Loss: 0.15514186024665833
# Batch: 140, Loss: 0.19335784018039703
# Batch: 160, Loss: 0.2514864504337311
# Batch: 180, Loss: 0.13642337918281555
# Batch: 200, Loss: 0.15334057807922363
#
# Average loss: 0.1685, Accuracy: 24685.0/26038 (95%)
#
#
# Average loss: 0.1845, Accuracy: 2783.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 94.80%
# Validation Accuracy: 94.66%
# Batch: 0, Loss: 0.19316691160202026
# Batch: 20, Loss: 0.09564118087291718
# Batch: 40, Loss: 0.19241438806056976
# Batch: 60, Loss: 0.16263428330421448
# Batch: 80, Loss: 0.16932106018066406
# Batch: 100, Loss: 0.10831263661384583
# Batch: 120, Loss: 0.21497754752635956
# Batch: 140, Loss: 0.22555314004421234
# Batch: 160, Loss: 0.09701287746429443
# Batch: 180, Loss: 0.16061849892139435
# Batch: 200, Loss: 0.10848990082740784
#
# Average loss: 0.1620, Accuracy: 24761.0/26038 (95%)
#
#
# Average loss: 0.1788, Accuracy: 2782.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 95.10%
# Validation Accuracy: 94.63%
# Batch: 0, Loss: 0.20653319358825684
# Batch: 20, Loss: 0.1371266394853592
# Batch: 40, Loss: 0.1434851437807083
# Batch: 60, Loss: 0.13100680708885193
# Batch: 80, Loss: 0.11125179380178452
# Batch: 100, Loss: 0.17179830372333527
# Batch: 120, Loss: 0.09390656650066376
# Batch: 140, Loss: 0.16681301593780518
# Batch: 160, Loss: 0.14392204582691193
# Batch: 180, Loss: 0.2261451780796051
# Batch: 200, Loss: 0.15793828666210175
#
# Average loss: 0.1570, Accuracy: 24754.0/26038 (95%)
#
#
# Average loss: 0.1735, Accuracy: 2791.0/2940 (95%)
#
# Epoch: 12 	Training Accuracy: 95.07%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.17539948225021362
# Batch: 20, Loss: 0.17289069294929504
# Batch: 40, Loss: 0.1629478484392166
# Batch: 60, Loss: 0.22125335037708282
# Batch: 80, Loss: 0.14354795217514038
# Batch: 100, Loss: 0.10626660287380219
# Batch: 120, Loss: 0.22137294709682465
# Batch: 140, Loss: 0.23533685505390167
# Batch: 160, Loss: 0.3066391348838806
# Batch: 180, Loss: 0.11476703733205795
# Batch: 200, Loss: 0.1215958371758461
#
# Average loss: 0.1529, Accuracy: 24779.0/26038 (95%)
#
#
# Average loss: 0.1677, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 13 	Training Accuracy: 95.16%
# Validation Accuracy: 95.10%
# Batch: 0, Loss: 0.1359819918870926
# Batch: 20, Loss: 0.09918148815631866
# Batch: 40, Loss: 0.11058036237955093
# Batch: 60, Loss: 0.16495507955551147
# Batch: 80, Loss: 0.12768663465976715
# Batch: 100, Loss: 0.15772002935409546
# Batch: 120, Loss: 0.16562840342521667
# Batch: 140, Loss: 0.21031317114830017
# Batch: 160, Loss: 0.1211651861667633
# Batch: 180, Loss: 0.13553917407989502
# Batch: 200, Loss: 0.12494999915361404
#
# Average loss: 0.1473, Accuracy: 24838.0/26038 (95%)
#
#
# Average loss: 0.1622, Accuracy: 2800.0/2940 (95%)
#
# Epoch: 14 	Training Accuracy: 95.39%
# Validation Accuracy: 95.24%
# Batch: 0, Loss: 0.09371312707662582
# Batch: 20, Loss: 0.13945625722408295
# Batch: 40, Loss: 0.18426626920700073
# Batch: 60, Loss: 0.11566682159900665
# Batch: 80, Loss: 0.14087249338626862
# Batch: 100, Loss: 0.19595955312252045
# Batch: 120, Loss: 0.11454688757658005
# Batch: 140, Loss: 0.08038701117038727
# Batch: 160, Loss: 0.13546447455883026
# Batch: 180, Loss: 0.16363365948200226
# Batch: 200, Loss: 0.08280415832996368
#
# Average loss: 0.1439, Accuracy: 24921.0/26038 (96%)
#
#
# Average loss: 0.1585, Accuracy: 2807.0/2940 (95%)
#
# Epoch: 15 	Training Accuracy: 95.71%
# Validation Accuracy: 95.48%
# Batch: 0, Loss: 0.1894877701997757
# Batch: 20, Loss: 0.25982916355133057
# Batch: 40, Loss: 0.1084345206618309
# Batch: 60, Loss: 0.18112246692180634
# Batch: 80, Loss: 0.20287862420082092
# Batch: 100, Loss: 0.12009142339229584
# Batch: 120, Loss: 0.05881847068667412
# Batch: 140, Loss: 0.1447421759366989
# Batch: 160, Loss: 0.05371273681521416
# Batch: 180, Loss: 0.12793169915676117
# Batch: 200, Loss: 0.08731255680322647
#
# Average loss: 0.1402, Accuracy: 24939.0/26038 (96%)
#
#
# Average loss: 0.1558, Accuracy: 2806.0/2940 (95%)
#
# Epoch: 16 	Training Accuracy: 95.78%
# Validation Accuracy: 95.44%
# Batch: 0, Loss: 0.09853653609752655
# Batch: 20, Loss: 0.09459228813648224
# Batch: 40, Loss: 0.16759124398231506
# Batch: 60, Loss: 0.1038619726896286
# Batch: 80, Loss: 0.1336359977722168
# Batch: 100, Loss: 0.09118664264678955
# Batch: 120, Loss: 0.1252184957265854
# Batch: 140, Loss: 0.13888005912303925
# Batch: 160, Loss: 0.11346245557069778
# Batch: 180, Loss: 0.13587883114814758
# Batch: 200, Loss: 0.1810671091079712
#
# Average loss: 0.1376, Accuracy: 24953.0/26038 (96%)
#
#
# Average loss: 0.1531, Accuracy: 2807.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 95.83%
# Validation Accuracy: 95.48%
# Batch: 0, Loss: 0.17081938683986664
# Batch: 20, Loss: 0.15014822781085968
# Batch: 40, Loss: 0.10035920143127441
# Batch: 60, Loss: 0.0931694507598877
# Batch: 80, Loss: 0.19249525666236877
# Batch: 100, Loss: 0.1419592648744583
# Batch: 120, Loss: 0.10889050364494324
# Batch: 140, Loss: 0.2312222421169281
# Batch: 160, Loss: 0.11144469678401947
# Batch: 180, Loss: 0.1250983327627182
# Batch: 200, Loss: 0.18484129011631012
#
# Average loss: 0.1344, Accuracy: 24989.0/26038 (96%)
#
#
# Average loss: 0.1503, Accuracy: 2812.0/2940 (96%)
#
# Epoch: 18 	Training Accuracy: 95.97%
# Validation Accuracy: 95.65%
# Batch: 0, Loss: 0.11443817615509033
# Batch: 20, Loss: 0.13181272149085999
# Batch: 40, Loss: 0.08081728219985962
# Batch: 60, Loss: 0.12477277219295502
# Batch: 80, Loss: 0.13981124758720398
# Batch: 100, Loss: 0.09875360876321793
# Batch: 120, Loss: 0.0767262801527977
# Batch: 140, Loss: 0.1394866555929184
# Batch: 160, Loss: 0.08835087716579437
# Batch: 180, Loss: 0.17440557479858398
# Batch: 200, Loss: 0.09955813735723495
#
# Average loss: 0.1318, Accuracy: 25004.0/26038 (96%)
#
#
# Average loss: 0.1471, Accuracy: 2815.0/2940 (96%)
#
# Epoch: 19 	Training Accuracy: 96.03%
# Validation Accuracy: 95.75%
#
# Average loss: 0.1318, Accuracy: 25004.0/26038 (96%)
#
#
# Average loss: 0.1307, Accuracy: 4656.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9603
# Final Test Accuracy (New Data): 0.9578
# Percentage: 0.01, Seed: 10, Epochs taken: 17
# Percentage: 0.01, Seed: 20, Epochs taken: 12
# Percentage: 0.01, Seed: 30, Epochs taken: 10
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 7
# Percentage: 0.03, Seed: 10, Epochs taken: 8
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 7
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 7
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 7
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 11
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 20
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 20
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 20
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 20
# Percentage: 1, Seed: 40, Epochs taken: 20
# Percentage: 1, Seed: 50, Epochs taken: 20

# %% [markdown]
# ## Only heads and data for new classes

# %% [markdown]
# now with balanced classes

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.0001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test_finetune = {}
results_train_finetune = {}
best_models = {}
data_loaders = {}
epochs_taken_finetune = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in percentages:
    print(f"Percentage: {perc}")
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []  # Store epochs for this percentage

    for _, temp_seed in enumerate(seed_set):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")

        # Copying model
        model_new = copy.deepcopy(model)

        in_features = model.fc_2.in_features
        out_features = 5

        # Reinitializing the second fcnn layer and softmax layer
        model_new.fc_2 = nn.Linear(in_features, out_features)  # Reinitialize with the same shape
        model_new.softmax = nn.Softmax(dim=1)
        
        model_new.to(device)

        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)
        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test_finetune[perc] = test_accuracies
    results_train_finetune[perc] = train_accuracies
    epochs_taken_finetune[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken_finetune[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Percentage: 0.01
# Repeat: 0, with seed 76 =========================
# Batch: 0, Loss: 1.624597430229187
#
# Average loss: 1.6050, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.6229, Accuracy: 850.0/2940 (29%)
#
# Epoch: 0 	Training Accuracy: 28.46%
# Validation Accuracy: 28.91%
# Batch: 0, Loss: 1.6353321075439453
#
# Average loss: 1.5816, Accuracy: 85.0/260 (33%)
#
#
# Average loss: 1.5995, Accuracy: 936.0/2940 (32%)
#
# Epoch: 1 	Training Accuracy: 32.69%
# Validation Accuracy: 31.84%
# Batch: 0, Loss: 1.6022166013717651
#
# Average loss: 1.5596, Accuracy: 94.0/260 (36%)
#
#
# Average loss: 1.5769, Accuracy: 1014.0/2940 (34%)
#
# Epoch: 2 	Training Accuracy: 36.15%
# Validation Accuracy: 34.49%
# Batch: 0, Loss: 1.5305908918380737
#
# Average loss: 1.5388, Accuracy: 102.0/260 (39%)
#
#
# Average loss: 1.5555, Accuracy: 1100.0/2940 (37%)
#
# Epoch: 3 	Training Accuracy: 39.23%
# Validation Accuracy: 37.41%
# Batch: 0, Loss: 1.5144720077514648
#
# Average loss: 1.5175, Accuracy: 114.0/260 (44%)
#
#
# Average loss: 1.5336, Accuracy: 1202.0/2940 (41%)
#
# Epoch: 4 	Training Accuracy: 43.85%
# Validation Accuracy: 40.88%
# Batch: 0, Loss: 1.5136240720748901
#
# Average loss: 1.4967, Accuracy: 119.0/260 (46%)
#
#
# Average loss: 1.5120, Accuracy: 1301.0/2940 (44%)
#
# Epoch: 5 	Training Accuracy: 45.77%
# Validation Accuracy: 44.25%
# Batch: 0, Loss: 1.4699362516403198
#
# Average loss: 1.4762, Accuracy: 127.0/260 (49%)
#
#
# Average loss: 1.4910, Accuracy: 1373.0/2940 (47%)
#
# Epoch: 6 	Training Accuracy: 48.85%
# Validation Accuracy: 46.70%
# Batch: 0, Loss: 1.4661720991134644
#
# Average loss: 1.4558, Accuracy: 134.0/260 (52%)
#
#
# Average loss: 1.4699, Accuracy: 1452.0/2940 (49%)
#
# Epoch: 7 	Training Accuracy: 51.54%
# Validation Accuracy: 49.39%
# Batch: 0, Loss: 1.4737757444381714
#
# Average loss: 1.4360, Accuracy: 141.0/260 (54%)
#
#
# Average loss: 1.4497, Accuracy: 1547.0/2940 (53%)
#
# Epoch: 8 	Training Accuracy: 54.23%
# Validation Accuracy: 52.62%
# Batch: 0, Loss: 1.4176043272018433
#
# Average loss: 1.4169, Accuracy: 148.0/260 (57%)
#
#
# Average loss: 1.4307, Accuracy: 1626.0/2940 (55%)
#
# Epoch: 9 	Training Accuracy: 56.92%
# Validation Accuracy: 55.31%
# Batch: 0, Loss: 1.4466934204101562
#
# Average loss: 1.3985, Accuracy: 154.0/260 (59%)
#
#
# Average loss: 1.4124, Accuracy: 1674.0/2940 (57%)
#
# Epoch: 10 	Training Accuracy: 59.23%
# Validation Accuracy: 56.94%
# Batch: 0, Loss: 1.4008865356445312
#
# Average loss: 1.3811, Accuracy: 160.0/260 (62%)
#
#
# Average loss: 1.3952, Accuracy: 1714.0/2940 (58%)
#
# Epoch: 11 	Training Accuracy: 61.54%
# Validation Accuracy: 58.30%
# Batch: 0, Loss: 1.3602888584136963
#
# Average loss: 1.3641, Accuracy: 160.0/260 (62%)
#
#
# Average loss: 1.3784, Accuracy: 1759.0/2940 (60%)
#
# Epoch: 12 	Training Accuracy: 61.54%
# Validation Accuracy: 59.83%
# Batch: 0, Loss: 1.3772342205047607
#
# Average loss: 1.3471, Accuracy: 161.0/260 (62%)
#
#
# Average loss: 1.3617, Accuracy: 1766.0/2940 (60%)
#
# Epoch: 13 	Training Accuracy: 61.92%
# Validation Accuracy: 60.07%
# Batch: 0, Loss: 1.3500365018844604
#
# Average loss: 1.3301, Accuracy: 161.0/260 (62%)
#
#
# Average loss: 1.3451, Accuracy: 1774.0/2940 (60%)
#
# Epoch: 14 	Training Accuracy: 61.92%
# Validation Accuracy: 60.34%
# Batch: 0, Loss: 1.3287593126296997
#
# Average loss: 1.3133, Accuracy: 163.0/260 (63%)
#
#
# Average loss: 1.3287, Accuracy: 1790.0/2940 (61%)
#
# Epoch: 15 	Training Accuracy: 62.69%
# Validation Accuracy: 60.88%
# Batch: 0, Loss: 1.2952669858932495
#
# Average loss: 1.2963, Accuracy: 165.0/260 (63%)
#
#
# Average loss: 1.3120, Accuracy: 1821.0/2940 (62%)
#
# Epoch: 16 	Training Accuracy: 63.46%
# Validation Accuracy: 61.94%
# Batch: 0, Loss: 1.318366289138794
#
# Average loss: 1.2793, Accuracy: 171.0/260 (66%)
#
#
# Average loss: 1.2949, Accuracy: 1847.0/2940 (63%)
#
# Epoch: 17 	Training Accuracy: 65.77%
# Validation Accuracy: 62.82%
# Batch: 0, Loss: 1.2814809083938599
#
# Average loss: 1.2624, Accuracy: 175.0/260 (67%)
#
#
# Average loss: 1.2777, Accuracy: 1889.0/2940 (64%)
#
# Epoch: 18 	Training Accuracy: 67.31%
# Validation Accuracy: 64.25%
# Batch: 0, Loss: 1.2582197189331055
#
# Average loss: 1.2454, Accuracy: 183.0/260 (70%)
#
#
# Average loss: 1.2603, Accuracy: 1926.0/2940 (66%)
#
# Epoch: 19 	Training Accuracy: 70.38%
# Validation Accuracy: 65.51%
#
# Average loss: 1.2454, Accuracy: 183.0/260 (70%)
#
#
# Average loss: 1.2577, Accuracy: 3207.0/4861 (66%)
#
# Repeat: 1, with seed 31 =========================
# Batch: 0, Loss: 1.7799043655395508
#
# Average loss: 1.7773, Accuracy: 47.0/260 (18%)
#
#
# Average loss: 1.7864, Accuracy: 502.0/2940 (17%)
#
# Epoch: 0 	Training Accuracy: 18.08%
# Validation Accuracy: 17.07%
# Batch: 0, Loss: 1.7987509965896606
#
# Average loss: 1.7503, Accuracy: 49.0/260 (19%)
#
#
# Average loss: 1.7585, Accuracy: 542.0/2940 (18%)
#
# Epoch: 1 	Training Accuracy: 18.85%
# Validation Accuracy: 18.44%
# Batch: 0, Loss: 1.7698466777801514
#
# Average loss: 1.7246, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.7319, Accuracy: 590.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.38%
# Validation Accuracy: 20.07%
# Batch: 0, Loss: 1.7040958404541016
#
# Average loss: 1.7008, Accuracy: 61.0/260 (23%)
#
#
# Average loss: 1.7074, Accuracy: 641.0/2940 (22%)
#
# Epoch: 3 	Training Accuracy: 23.46%
# Validation Accuracy: 21.80%
# Batch: 0, Loss: 1.7011082172393799
#
# Average loss: 1.6790, Accuracy: 67.0/260 (26%)
#
#
# Average loss: 1.6853, Accuracy: 703.0/2940 (24%)
#
# Epoch: 4 	Training Accuracy: 25.77%
# Validation Accuracy: 23.91%
# Batch: 0, Loss: 1.6933579444885254
#
# Average loss: 1.6580, Accuracy: 70.0/260 (27%)
#
#
# Average loss: 1.6640, Accuracy: 795.0/2940 (27%)
#
# Epoch: 5 	Training Accuracy: 26.92%
# Validation Accuracy: 27.04%
# Batch: 0, Loss: 1.6548950672149658
#
# Average loss: 1.6375, Accuracy: 75.0/260 (29%)
#
#
# Average loss: 1.6432, Accuracy: 834.0/2940 (28%)
#
# Epoch: 6 	Training Accuracy: 28.85%
# Validation Accuracy: 28.37%
# Batch: 0, Loss: 1.6280889511108398
#
# Average loss: 1.6175, Accuracy: 86.0/260 (33%)
#
#
# Average loss: 1.6230, Accuracy: 920.0/2940 (31%)
#
# Epoch: 7 	Training Accuracy: 33.08%
# Validation Accuracy: 31.29%
# Batch: 0, Loss: 1.6103664636611938
#
# Average loss: 1.5980, Accuracy: 92.0/260 (35%)
#
#
# Average loss: 1.6032, Accuracy: 996.0/2940 (34%)
#
# Epoch: 8 	Training Accuracy: 35.38%
# Validation Accuracy: 33.88%
# Batch: 0, Loss: 1.5238474607467651
#
# Average loss: 1.5790, Accuracy: 101.0/260 (39%)
#
#
# Average loss: 1.5837, Accuracy: 1072.0/2940 (36%)
#
# Epoch: 9 	Training Accuracy: 38.85%
# Validation Accuracy: 36.46%
# Batch: 0, Loss: 1.555457353591919
#
# Average loss: 1.5603, Accuracy: 105.0/260 (40%)
#
#
# Average loss: 1.5643, Accuracy: 1147.0/2940 (39%)
#
# Epoch: 10 	Training Accuracy: 40.38%
# Validation Accuracy: 39.01%
# Batch: 0, Loss: 1.5952637195587158
#
# Average loss: 1.5427, Accuracy: 114.0/260 (44%)
#
#
# Average loss: 1.5459, Accuracy: 1225.0/2940 (42%)
#
# Epoch: 11 	Training Accuracy: 43.85%
# Validation Accuracy: 41.67%
# Batch: 0, Loss: 1.5361043214797974
#
# Average loss: 1.5259, Accuracy: 123.0/260 (47%)
#
#
# Average loss: 1.5285, Accuracy: 1287.0/2940 (44%)
#
# Epoch: 12 	Training Accuracy: 47.31%
# Validation Accuracy: 43.78%
# Batch: 0, Loss: 1.493648648262024
#
# Average loss: 1.5092, Accuracy: 128.0/260 (49%)
#
#
# Average loss: 1.5111, Accuracy: 1347.0/2940 (46%)
#
# Epoch: 13 	Training Accuracy: 49.23%
# Validation Accuracy: 45.82%
# Batch: 0, Loss: 1.4706902503967285
#
# Average loss: 1.4929, Accuracy: 131.0/260 (50%)
#
#
# Average loss: 1.4942, Accuracy: 1405.0/2940 (48%)
#
# Epoch: 14 	Training Accuracy: 50.38%
# Validation Accuracy: 47.79%
# Batch: 0, Loss: 1.4566645622253418
#
# Average loss: 1.4768, Accuracy: 133.0/260 (51%)
#
#
# Average loss: 1.4778, Accuracy: 1453.0/2940 (49%)
#
# Epoch: 15 	Training Accuracy: 51.15%
# Validation Accuracy: 49.42%
# Batch: 0, Loss: 1.4793072938919067
#
# Average loss: 1.4609, Accuracy: 137.0/260 (53%)
#
#
# Average loss: 1.4617, Accuracy: 1496.0/2940 (51%)
#
# Epoch: 16 	Training Accuracy: 52.69%
# Validation Accuracy: 50.88%
# Batch: 0, Loss: 1.4683536291122437
#
# Average loss: 1.4456, Accuracy: 139.0/260 (53%)
#
#
# Average loss: 1.4463, Accuracy: 1531.0/2940 (52%)
#
# Epoch: 17 	Training Accuracy: 53.46%
# Validation Accuracy: 52.07%
# Batch: 0, Loss: 1.4587880373001099
#
# Average loss: 1.4300, Accuracy: 140.0/260 (54%)
#
#
# Average loss: 1.4305, Accuracy: 1568.0/2940 (53%)
#
# Epoch: 18 	Training Accuracy: 53.85%
# Validation Accuracy: 53.33%
# Batch: 0, Loss: 1.4921494722366333
#
# Average loss: 1.4143, Accuracy: 142.0/260 (55%)
#
#
# Average loss: 1.4143, Accuracy: 1596.0/2940 (54%)
#
# Epoch: 19 	Training Accuracy: 54.62%
# Validation Accuracy: 54.29%
#
# Average loss: 1.4143, Accuracy: 142.0/260 (55%)
#
#
# Average loss: 1.4088, Accuracy: 2657.0/4861 (55%)
#
# Repeat: 2, with seed 77 =========================
# Batch: 0, Loss: 1.673317551612854
#
# Average loss: 1.6732, Accuracy: 49.0/260 (19%)
#
#
# Average loss: 1.6439, Accuracy: 593.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 18.85%
# Validation Accuracy: 20.17%
# Batch: 0, Loss: 1.6990201473236084
#
# Average loss: 1.6475, Accuracy: 54.0/260 (21%)
#
#
# Average loss: 1.6196, Accuracy: 657.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 20.77%
# Validation Accuracy: 22.35%
# Batch: 0, Loss: 1.6248480081558228
#
# Average loss: 1.6241, Accuracy: 59.0/260 (23%)
#
#
# Average loss: 1.5972, Accuracy: 722.0/2940 (25%)
#
# Epoch: 2 	Training Accuracy: 22.69%
# Validation Accuracy: 24.56%
# Batch: 0, Loss: 1.5856858491897583
#
# Average loss: 1.6019, Accuracy: 61.0/260 (23%)
#
#
# Average loss: 1.5758, Accuracy: 795.0/2940 (27%)
#
# Epoch: 3 	Training Accuracy: 23.46%
# Validation Accuracy: 27.04%
# Batch: 0, Loss: 1.6214087009429932
#
# Average loss: 1.5808, Accuracy: 66.0/260 (25%)
#
#
# Average loss: 1.5555, Accuracy: 845.0/2940 (29%)
#
# Epoch: 4 	Training Accuracy: 25.38%
# Validation Accuracy: 28.74%
# Batch: 0, Loss: 1.553763747215271
#
# Average loss: 1.5603, Accuracy: 71.0/260 (27%)
#
#
# Average loss: 1.5358, Accuracy: 904.0/2940 (31%)
#
# Epoch: 5 	Training Accuracy: 27.31%
# Validation Accuracy: 30.75%
# Batch: 0, Loss: 1.564740777015686
#
# Average loss: 1.5406, Accuracy: 77.0/260 (30%)
#
#
# Average loss: 1.5169, Accuracy: 960.0/2940 (33%)
#
# Epoch: 6 	Training Accuracy: 29.62%
# Validation Accuracy: 32.65%
# Batch: 0, Loss: 1.4727083444595337
#
# Average loss: 1.5219, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.4990, Accuracy: 1005.0/2940 (34%)
#
# Epoch: 7 	Training Accuracy: 32.31%
# Validation Accuracy: 34.18%
# Batch: 0, Loss: 1.5156667232513428
#
# Average loss: 1.5033, Accuracy: 88.0/260 (34%)
#
#
# Average loss: 1.4811, Accuracy: 1057.0/2940 (36%)
#
# Epoch: 8 	Training Accuracy: 33.85%
# Validation Accuracy: 35.95%
# Batch: 0, Loss: 1.5274454355239868
#
# Average loss: 1.4849, Accuracy: 92.0/260 (35%)
#
#
# Average loss: 1.4634, Accuracy: 1111.0/2940 (38%)
#
# Epoch: 9 	Training Accuracy: 35.38%
# Validation Accuracy: 37.79%
# Batch: 0, Loss: 1.4574636220932007
#
# Average loss: 1.4669, Accuracy: 96.0/260 (37%)
#
#
# Average loss: 1.4458, Accuracy: 1164.0/2940 (40%)
#
# Epoch: 10 	Training Accuracy: 36.92%
# Validation Accuracy: 39.59%
# Batch: 0, Loss: 1.4574713706970215
#
# Average loss: 1.4491, Accuracy: 100.0/260 (38%)
#
#
# Average loss: 1.4284, Accuracy: 1234.0/2940 (42%)
#
# Epoch: 11 	Training Accuracy: 38.46%
# Validation Accuracy: 41.97%
# Batch: 0, Loss: 1.5001612901687622
#
# Average loss: 1.4316, Accuracy: 106.0/260 (41%)
#
#
# Average loss: 1.4114, Accuracy: 1314.0/2940 (45%)
#
# Epoch: 12 	Training Accuracy: 40.77%
# Validation Accuracy: 44.69%
# Batch: 0, Loss: 1.4365664720535278
#
# Average loss: 1.4143, Accuracy: 113.0/260 (43%)
#
#
# Average loss: 1.3944, Accuracy: 1382.0/2940 (47%)
#
# Epoch: 13 	Training Accuracy: 43.46%
# Validation Accuracy: 47.01%
# Batch: 0, Loss: 1.3674447536468506
#
# Average loss: 1.3972, Accuracy: 127.0/260 (49%)
#
#
# Average loss: 1.3778, Accuracy: 1450.0/2940 (49%)
#
# Epoch: 14 	Training Accuracy: 48.85%
# Validation Accuracy: 49.32%
# Batch: 0, Loss: 1.34920072555542
#
# Average loss: 1.3803, Accuracy: 131.0/260 (50%)
#
#
# Average loss: 1.3614, Accuracy: 1495.0/2940 (51%)
#
# Epoch: 15 	Training Accuracy: 50.38%
# Validation Accuracy: 50.85%
# Batch: 0, Loss: 1.386334776878357
#
# Average loss: 1.3635, Accuracy: 137.0/260 (53%)
#
#
# Average loss: 1.3453, Accuracy: 1562.0/2940 (53%)
#
# Epoch: 16 	Training Accuracy: 52.69%
# Validation Accuracy: 53.13%
# Batch: 0, Loss: 1.3378435373306274
#
# Average loss: 1.3471, Accuracy: 141.0/260 (54%)
#
#
# Average loss: 1.3296, Accuracy: 1622.0/2940 (55%)
#
# Epoch: 17 	Training Accuracy: 54.23%
# Validation Accuracy: 55.17%
# Batch: 0, Loss: 1.3265776634216309
#
# Average loss: 1.3310, Accuracy: 150.0/260 (58%)
#
#
# Average loss: 1.3143, Accuracy: 1684.0/2940 (57%)
#
# Epoch: 18 	Training Accuracy: 57.69%
# Validation Accuracy: 57.28%
# Batch: 0, Loss: 1.316933512687683
#
# Average loss: 1.3153, Accuracy: 156.0/260 (60%)
#
#
# Average loss: 1.2995, Accuracy: 1728.0/2940 (59%)
#
# Epoch: 19 	Training Accuracy: 60.00%
# Validation Accuracy: 58.78%
#
# Average loss: 1.3153, Accuracy: 156.0/260 (60%)
#
#
# Average loss: 1.3124, Accuracy: 2844.0/4861 (59%)
#
# Repeat: 3, with seed 12 =========================
# Batch: 0, Loss: 1.7404820919036865
#
# Average loss: 1.7154, Accuracy: 36.0/260 (14%)
#
#
# Average loss: 1.6980, Accuracy: 418.0/2940 (14%)
#
# Epoch: 0 	Training Accuracy: 13.85%
# Validation Accuracy: 14.22%
# Batch: 0, Loss: 1.7320456504821777
#
# Average loss: 1.6927, Accuracy: 44.0/260 (17%)
#
#
# Average loss: 1.6759, Accuracy: 481.0/2940 (16%)
#
# Epoch: 1 	Training Accuracy: 16.92%
# Validation Accuracy: 16.36%
# Batch: 0, Loss: 1.6848348379135132
#
# Average loss: 1.6710, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.6548, Accuracy: 538.0/2940 (18%)
#
# Epoch: 2 	Training Accuracy: 20.38%
# Validation Accuracy: 18.30%
# Batch: 0, Loss: 1.6638965606689453
#
# Average loss: 1.6500, Accuracy: 55.0/260 (21%)
#
#
# Average loss: 1.6343, Accuracy: 600.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 21.15%
# Validation Accuracy: 20.41%
# Batch: 0, Loss: 1.635735034942627
#
# Average loss: 1.6295, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.6138, Accuracy: 670.0/2940 (23%)
#
# Epoch: 4 	Training Accuracy: 22.31%
# Validation Accuracy: 22.79%
# Batch: 0, Loss: 1.6056970357894897
#
# Average loss: 1.6096, Accuracy: 64.0/260 (25%)
#
#
# Average loss: 1.5939, Accuracy: 756.0/2940 (26%)
#
# Epoch: 5 	Training Accuracy: 24.62%
# Validation Accuracy: 25.71%
# Batch: 0, Loss: 1.6034554243087769
#
# Average loss: 1.5905, Accuracy: 67.0/260 (26%)
#
#
# Average loss: 1.5751, Accuracy: 841.0/2940 (29%)
#
# Epoch: 6 	Training Accuracy: 25.77%
# Validation Accuracy: 28.61%
# Batch: 0, Loss: 1.5662808418273926
#
# Average loss: 1.5721, Accuracy: 75.0/260 (29%)
#
#
# Average loss: 1.5568, Accuracy: 914.0/2940 (31%)
#
# Epoch: 7 	Training Accuracy: 28.85%
# Validation Accuracy: 31.09%
# Batch: 0, Loss: 1.548516869544983
#
# Average loss: 1.5537, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5384, Accuracy: 974.0/2940 (33%)
#
# Epoch: 8 	Training Accuracy: 32.31%
# Validation Accuracy: 33.13%
# Batch: 0, Loss: 1.606493592262268
#
# Average loss: 1.5358, Accuracy: 87.0/260 (33%)
#
#
# Average loss: 1.5205, Accuracy: 1033.0/2940 (35%)
#
# Epoch: 9 	Training Accuracy: 33.46%
# Validation Accuracy: 35.14%
# Batch: 0, Loss: 1.5680233240127563
#
# Average loss: 1.5187, Accuracy: 99.0/260 (38%)
#
#
# Average loss: 1.5036, Accuracy: 1094.0/2940 (37%)
#
# Epoch: 10 	Training Accuracy: 38.08%
# Validation Accuracy: 37.21%
# Batch: 0, Loss: 1.54987370967865
#
# Average loss: 1.5019, Accuracy: 102.0/260 (39%)
#
#
# Average loss: 1.4869, Accuracy: 1169.0/2940 (40%)
#
# Epoch: 11 	Training Accuracy: 39.23%
# Validation Accuracy: 39.76%
# Batch: 0, Loss: 1.4678218364715576
#
# Average loss: 1.4850, Accuracy: 104.0/260 (40%)
#
#
# Average loss: 1.4697, Accuracy: 1233.0/2940 (42%)
#
# Epoch: 12 	Training Accuracy: 40.00%
# Validation Accuracy: 41.94%
# Batch: 0, Loss: 1.4594571590423584
#
# Average loss: 1.4682, Accuracy: 109.0/260 (42%)
#
#
# Average loss: 1.4527, Accuracy: 1291.0/2940 (44%)
#
# Epoch: 13 	Training Accuracy: 41.92%
# Validation Accuracy: 43.91%
# Batch: 0, Loss: 1.4686368703842163
#
# Average loss: 1.4515, Accuracy: 115.0/260 (44%)
#
#
# Average loss: 1.4359, Accuracy: 1354.0/2940 (46%)
#
# Epoch: 14 	Training Accuracy: 44.23%
# Validation Accuracy: 46.05%
# Batch: 0, Loss: 1.4155505895614624
#
# Average loss: 1.4347, Accuracy: 120.0/260 (46%)
#
#
# Average loss: 1.4189, Accuracy: 1404.0/2940 (48%)
#
# Epoch: 15 	Training Accuracy: 46.15%
# Validation Accuracy: 47.76%
# Batch: 0, Loss: 1.4637749195098877
#
# Average loss: 1.4181, Accuracy: 124.0/260 (48%)
#
#
# Average loss: 1.4020, Accuracy: 1451.0/2940 (49%)
#
# Epoch: 16 	Training Accuracy: 47.69%
# Validation Accuracy: 49.35%
# Batch: 0, Loss: 1.3866530656814575
#
# Average loss: 1.4017, Accuracy: 129.0/260 (50%)
#
#
# Average loss: 1.3854, Accuracy: 1491.0/2940 (51%)
#
# Epoch: 17 	Training Accuracy: 49.62%
# Validation Accuracy: 50.71%
# Batch: 0, Loss: 1.395914077758789
#
# Average loss: 1.3856, Accuracy: 135.0/260 (52%)
#
#
# Average loss: 1.3692, Accuracy: 1533.0/2940 (52%)
#
# Epoch: 18 	Training Accuracy: 51.92%
# Validation Accuracy: 52.14%
# Batch: 0, Loss: 1.4041881561279297
#
# Average loss: 1.3698, Accuracy: 138.0/260 (53%)
#
#
# Average loss: 1.3534, Accuracy: 1597.0/2940 (54%)
#
# Epoch: 19 	Training Accuracy: 53.08%
# Validation Accuracy: 54.32%
#
# Average loss: 1.3698, Accuracy: 138.0/260 (53%)
#
#
# Average loss: 1.3576, Accuracy: 2711.0/4861 (56%)
#
# Repeat: 4, with seed 17 =========================
# Batch: 0, Loss: 1.583112359046936
#
# Average loss: 1.5501, Accuracy: 47.0/260 (18%)
#
#
# Average loss: 1.5128, Accuracy: 580.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 18.08%
# Validation Accuracy: 19.73%
# Batch: 0, Loss: 1.5531023740768433
#
# Average loss: 1.5252, Accuracy: 51.0/260 (20%)
#
#
# Average loss: 1.4891, Accuracy: 694.0/2940 (24%)
#
# Epoch: 1 	Training Accuracy: 19.62%
# Validation Accuracy: 23.61%
# Batch: 0, Loss: 1.5258893966674805
#
# Average loss: 1.5021, Accuracy: 63.0/260 (24%)
#
#
# Average loss: 1.4671, Accuracy: 792.0/2940 (27%)
#
# Epoch: 2 	Training Accuracy: 24.23%
# Validation Accuracy: 26.94%
# Batch: 0, Loss: 1.5204448699951172
#
# Average loss: 1.4794, Accuracy: 70.0/260 (27%)
#
#
# Average loss: 1.4456, Accuracy: 895.0/2940 (30%)
#
# Epoch: 3 	Training Accuracy: 26.92%
# Validation Accuracy: 30.44%
# Batch: 0, Loss: 1.4940751791000366
#
# Average loss: 1.4574, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.4249, Accuracy: 999.0/2940 (34%)
#
# Epoch: 4 	Training Accuracy: 28.46%
# Validation Accuracy: 33.98%
# Batch: 0, Loss: 1.4526035785675049
#
# Average loss: 1.4359, Accuracy: 79.0/260 (30%)
#
#
# Average loss: 1.4051, Accuracy: 1116.0/2940 (38%)
#
# Epoch: 5 	Training Accuracy: 30.38%
# Validation Accuracy: 37.96%
# Batch: 0, Loss: 1.449286937713623
#
# Average loss: 1.4152, Accuracy: 88.0/260 (34%)
#
#
# Average loss: 1.3859, Accuracy: 1237.0/2940 (42%)
#
# Epoch: 6 	Training Accuracy: 33.85%
# Validation Accuracy: 42.07%
# Batch: 0, Loss: 1.4121668338775635
#
# Average loss: 1.3949, Accuracy: 97.0/260 (37%)
#
#
# Average loss: 1.3668, Accuracy: 1351.0/2940 (46%)
#
# Epoch: 7 	Training Accuracy: 37.31%
# Validation Accuracy: 45.95%
# Batch: 0, Loss: 1.401249885559082
#
# Average loss: 1.3747, Accuracy: 109.0/260 (42%)
#
#
# Average loss: 1.3478, Accuracy: 1434.0/2940 (49%)
#
# Epoch: 8 	Training Accuracy: 41.92%
# Validation Accuracy: 48.78%
# Batch: 0, Loss: 1.3565571308135986
#
# Average loss: 1.3547, Accuracy: 111.0/260 (43%)
#
#
# Average loss: 1.3290, Accuracy: 1529.0/2940 (52%)
#
# Epoch: 9 	Training Accuracy: 42.69%
# Validation Accuracy: 52.01%
# Batch: 0, Loss: 1.3388392925262451
#
# Average loss: 1.3351, Accuracy: 125.0/260 (48%)
#
#
# Average loss: 1.3109, Accuracy: 1605.0/2940 (55%)
#
# Epoch: 10 	Training Accuracy: 48.08%
# Validation Accuracy: 54.59%
# Batch: 0, Loss: 1.3408693075180054
#
# Average loss: 1.3158, Accuracy: 132.0/260 (51%)
#
#
# Average loss: 1.2928, Accuracy: 1675.0/2940 (57%)
#
# Epoch: 11 	Training Accuracy: 50.77%
# Validation Accuracy: 56.97%
# Batch: 0, Loss: 1.31102454662323
#
# Average loss: 1.2965, Accuracy: 141.0/260 (54%)
#
#
# Average loss: 1.2746, Accuracy: 1757.0/2940 (60%)
#
# Epoch: 12 	Training Accuracy: 54.23%
# Validation Accuracy: 59.76%
# Batch: 0, Loss: 1.3007242679595947
#
# Average loss: 1.2772, Accuracy: 147.0/260 (57%)
#
#
# Average loss: 1.2564, Accuracy: 1849.0/2940 (63%)
#
# Epoch: 13 	Training Accuracy: 56.54%
# Validation Accuracy: 62.89%
# Batch: 0, Loss: 1.2872867584228516
#
# Average loss: 1.2581, Accuracy: 159.0/260 (61%)
#
#
# Average loss: 1.2384, Accuracy: 1912.0/2940 (65%)
#
# Epoch: 14 	Training Accuracy: 61.15%
# Validation Accuracy: 65.03%
# Batch: 0, Loss: 1.277031421661377
#
# Average loss: 1.2392, Accuracy: 169.0/260 (65%)
#
#
# Average loss: 1.2206, Accuracy: 1968.0/2940 (67%)
#
# Epoch: 15 	Training Accuracy: 65.00%
# Validation Accuracy: 66.94%
# Batch: 0, Loss: 1.231041431427002
#
# Average loss: 1.2208, Accuracy: 173.0/260 (67%)
#
#
# Average loss: 1.2033, Accuracy: 2014.0/2940 (69%)
#
# Epoch: 16 	Training Accuracy: 66.54%
# Validation Accuracy: 68.50%
# Batch: 0, Loss: 1.1921466588974
#
# Average loss: 1.2027, Accuracy: 176.0/260 (68%)
#
#
# Average loss: 1.1861, Accuracy: 2067.0/2940 (70%)
#
# Epoch: 17 	Training Accuracy: 67.69%
# Validation Accuracy: 70.31%
# Batch: 0, Loss: 1.2372177839279175
#
# Average loss: 1.1844, Accuracy: 184.0/260 (71%)
#
#
# Average loss: 1.1688, Accuracy: 2113.0/2940 (72%)
#
# Epoch: 18 	Training Accuracy: 70.77%
# Validation Accuracy: 71.87%
# Batch: 0, Loss: 1.1602962017059326
#
# Average loss: 1.1667, Accuracy: 190.0/260 (73%)
#
#
# Average loss: 1.1521, Accuracy: 2169.0/2940 (74%)
#
# Epoch: 19 	Training Accuracy: 73.08%
# Validation Accuracy: 73.78%
#
# Average loss: 1.1667, Accuracy: 190.0/260 (73%)
#
#
# Average loss: 1.1410, Accuracy: 3691.0/4861 (76%)
#
# Percentage: 0.03
# Repeat: 0, with seed 28 =========================
# Batch: 0, Loss: 1.443602204322815
#
# Average loss: 1.3857, Accuracy: 329.0/790 (42%)
#
#
# Average loss: 1.3730, Accuracy: 1301.0/2940 (44%)
#
# Epoch: 0 	Training Accuracy: 41.65%
# Validation Accuracy: 44.25%
# Batch: 0, Loss: 1.360701322555542
#
# Average loss: 1.3295, Accuracy: 393.0/790 (50%)
#
#
# Average loss: 1.3192, Accuracy: 1500.0/2940 (51%)
#
# Epoch: 1 	Training Accuracy: 49.75%
# Validation Accuracy: 51.02%
# Batch: 0, Loss: 1.3297406435012817
#
# Average loss: 1.2754, Accuracy: 453.0/790 (57%)
#
#
# Average loss: 1.2677, Accuracy: 1695.0/2940 (58%)
#
# Epoch: 2 	Training Accuracy: 57.34%
# Validation Accuracy: 57.65%
# Batch: 0, Loss: 1.298473834991455
#
# Average loss: 1.2229, Accuracy: 529.0/790 (67%)
#
#
# Average loss: 1.2173, Accuracy: 1903.0/2940 (65%)
#
# Epoch: 3 	Training Accuracy: 66.96%
# Validation Accuracy: 64.73%
# Batch: 0, Loss: 1.2374255657196045
#
# Average loss: 1.1717, Accuracy: 584.0/790 (74%)
#
#
# Average loss: 1.1678, Accuracy: 2120.0/2940 (72%)
#
# Epoch: 4 	Training Accuracy: 73.92%
# Validation Accuracy: 72.11%
# Batch: 0, Loss: 1.1531176567077637
#
# Average loss: 1.1217, Accuracy: 615.0/790 (78%)
#
#
# Average loss: 1.1193, Accuracy: 2297.0/2940 (78%)
#
# Epoch: 5 	Training Accuracy: 77.85%
# Validation Accuracy: 78.13%
# Batch: 0, Loss: 1.1295098066329956
#
# Average loss: 1.0724, Accuracy: 655.0/790 (83%)
#
#
# Average loss: 1.0717, Accuracy: 2415.0/2940 (82%)
#
# Epoch: 6 	Training Accuracy: 82.91%
# Validation Accuracy: 82.14%
# Batch: 0, Loss: 1.0681434869766235
#
# Average loss: 1.0247, Accuracy: 678.0/790 (86%)
#
#
# Average loss: 1.0255, Accuracy: 2503.0/2940 (85%)
#
# Epoch: 7 	Training Accuracy: 85.82%
# Validation Accuracy: 85.14%
# Batch: 0, Loss: 0.9952284097671509
#
# Average loss: 0.9787, Accuracy: 700.0/790 (89%)
#
#
# Average loss: 0.9808, Accuracy: 2564.0/2940 (87%)
#
# Epoch: 8 	Training Accuracy: 88.61%
# Validation Accuracy: 87.21%
# Batch: 0, Loss: 1.0248825550079346
#
# Average loss: 0.9345, Accuracy: 704.0/790 (89%)
#
#
# Average loss: 0.9378, Accuracy: 2603.0/2940 (89%)
#
# Epoch: 9 	Training Accuracy: 89.11%
# Validation Accuracy: 88.54%
# Batch: 0, Loss: 0.9366227388381958
#
# Average loss: 0.8917, Accuracy: 710.0/790 (90%)
#
#
# Average loss: 0.8962, Accuracy: 2624.0/2940 (89%)
#
# Epoch: 10 	Training Accuracy: 89.87%
# Validation Accuracy: 89.25%
# Batch: 0, Loss: 0.861004114151001
#
# Average loss: 0.8506, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.8563, Accuracy: 2643.0/2940 (90%)
#
# Epoch: 11 	Training Accuracy: 91.01%
# Validation Accuracy: 89.90%
# Batch: 0, Loss: 0.8335309624671936
#
# Average loss: 0.8119, Accuracy: 725.0/790 (92%)
#
#
# Average loss: 0.8190, Accuracy: 2658.0/2940 (90%)
#
# Epoch: 12 	Training Accuracy: 91.77%
# Validation Accuracy: 90.41%
# Batch: 0, Loss: 0.8480566143989563
#
# Average loss: 0.7746, Accuracy: 727.0/790 (92%)
#
#
# Average loss: 0.7831, Accuracy: 2671.0/2940 (91%)
#
# Epoch: 13 	Training Accuracy: 92.03%
# Validation Accuracy: 90.85%
# Batch: 0, Loss: 0.7866312265396118
#
# Average loss: 0.7393, Accuracy: 731.0/790 (93%)
#
#
# Average loss: 0.7495, Accuracy: 2685.0/2940 (91%)
#
# Epoch: 14 	Training Accuracy: 92.53%
# Validation Accuracy: 91.33%
# Batch: 0, Loss: 0.7096284031867981
#
# Average loss: 0.7062, Accuracy: 735.0/790 (93%)
#
#
# Average loss: 0.7174, Accuracy: 2687.0/2940 (91%)
#
# Epoch: 15 	Training Accuracy: 93.04%
# Validation Accuracy: 91.39%
# Batch: 0, Loss: 0.7229029536247253
#
# Average loss: 0.6751, Accuracy: 735.0/790 (93%)
#
#
# Average loss: 0.6873, Accuracy: 2691.0/2940 (92%)
#
# Epoch: 16 	Training Accuracy: 93.04%
# Validation Accuracy: 91.53%
# Batch: 0, Loss: 0.6711913347244263
#
# Average loss: 0.6459, Accuracy: 733.0/790 (93%)
#
#
# Average loss: 0.6593, Accuracy: 2693.0/2940 (92%)
#
# Epoch: 17 	Training Accuracy: 92.78%
# Validation Accuracy: 91.60%
# Batch: 0, Loss: 0.617735743522644
#
# Average loss: 0.6183, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.6327, Accuracy: 2700.0/2940 (92%)
#
# Epoch: 18 	Training Accuracy: 93.16%
# Validation Accuracy: 91.84%
# Batch: 0, Loss: 0.5733011960983276
#
# Average loss: 0.5925, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.6079, Accuracy: 2698.0/2940 (92%)
#
# Epoch: 19 	Training Accuracy: 93.42%
# Validation Accuracy: 91.77%
#
# Average loss: 0.5925, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.5973, Accuracy: 4486.0/4861 (92%)
#
# Repeat: 1, with seed 80 =========================
# Batch: 0, Loss: 1.676870584487915
#
# Average loss: 1.6024, Accuracy: 169.0/790 (21%)
#
#
# Average loss: 1.6145, Accuracy: 628.0/2940 (21%)
#
# Epoch: 0 	Training Accuracy: 21.39%
# Validation Accuracy: 21.36%
# Batch: 0, Loss: 1.6004773378372192
#
# Average loss: 1.5403, Accuracy: 192.0/790 (24%)
#
#
# Average loss: 1.5517, Accuracy: 769.0/2940 (26%)
#
# Epoch: 1 	Training Accuracy: 24.30%
# Validation Accuracy: 26.16%
# Batch: 0, Loss: 1.5613354444503784
#
# Average loss: 1.4820, Accuracy: 251.0/790 (32%)
#
#
# Average loss: 1.4930, Accuracy: 952.0/2940 (32%)
#
# Epoch: 2 	Training Accuracy: 31.77%
# Validation Accuracy: 32.38%
# Batch: 0, Loss: 1.5191843509674072
#
# Average loss: 1.4270, Accuracy: 320.0/790 (41%)
#
#
# Average loss: 1.4373, Accuracy: 1168.0/2940 (40%)
#
# Epoch: 3 	Training Accuracy: 40.51%
# Validation Accuracy: 39.73%
# Batch: 0, Loss: 1.4197700023651123
#
# Average loss: 1.3735, Accuracy: 388.0/790 (49%)
#
#
# Average loss: 1.3835, Accuracy: 1395.0/2940 (47%)
#
# Epoch: 4 	Training Accuracy: 49.11%
# Validation Accuracy: 47.45%
# Batch: 0, Loss: 1.4095897674560547
#
# Average loss: 1.3219, Accuracy: 446.0/790 (56%)
#
#
# Average loss: 1.3316, Accuracy: 1617.0/2940 (55%)
#
# Epoch: 5 	Training Accuracy: 56.46%
# Validation Accuracy: 55.00%
# Batch: 0, Loss: 1.3081378936767578
#
# Average loss: 1.2712, Accuracy: 499.0/790 (63%)
#
#
# Average loss: 1.2804, Accuracy: 1790.0/2940 (61%)
#
# Epoch: 6 	Training Accuracy: 63.16%
# Validation Accuracy: 60.88%
# Batch: 0, Loss: 1.2580316066741943
#
# Average loss: 1.2222, Accuracy: 530.0/790 (67%)
#
#
# Average loss: 1.2310, Accuracy: 1897.0/2940 (65%)
#
# Epoch: 7 	Training Accuracy: 67.09%
# Validation Accuracy: 64.52%
# Batch: 0, Loss: 1.2102655172348022
#
# Average loss: 1.1741, Accuracy: 564.0/790 (71%)
#
#
# Average loss: 1.1831, Accuracy: 1995.0/2940 (68%)
#
# Epoch: 8 	Training Accuracy: 71.39%
# Validation Accuracy: 67.86%
# Batch: 0, Loss: 1.2338560819625854
#
# Average loss: 1.1270, Accuracy: 587.0/790 (74%)
#
#
# Average loss: 1.1355, Accuracy: 2117.0/2940 (72%)
#
# Epoch: 9 	Training Accuracy: 74.30%
# Validation Accuracy: 72.01%
# Batch: 0, Loss: 1.1427685022354126
#
# Average loss: 1.0810, Accuracy: 627.0/790 (79%)
#
#
# Average loss: 1.0890, Accuracy: 2240.0/2940 (76%)
#
# Epoch: 10 	Training Accuracy: 79.37%
# Validation Accuracy: 76.19%
# Batch: 0, Loss: 1.0799241065979004
#
# Average loss: 1.0363, Accuracy: 646.0/790 (82%)
#
#
# Average loss: 1.0444, Accuracy: 2313.0/2940 (79%)
#
# Epoch: 11 	Training Accuracy: 81.77%
# Validation Accuracy: 78.67%
# Batch: 0, Loss: 1.0498756170272827
#
# Average loss: 0.9927, Accuracy: 660.0/790 (84%)
#
#
# Average loss: 1.0015, Accuracy: 2361.0/2940 (80%)
#
# Epoch: 12 	Training Accuracy: 83.54%
# Validation Accuracy: 80.31%
# Batch: 0, Loss: 0.9603511691093445
#
# Average loss: 0.9507, Accuracy: 672.0/790 (85%)
#
#
# Average loss: 0.9602, Accuracy: 2394.0/2940 (81%)
#
# Epoch: 13 	Training Accuracy: 85.06%
# Validation Accuracy: 81.43%
# Batch: 0, Loss: 0.9257582426071167
#
# Average loss: 0.9106, Accuracy: 679.0/790 (86%)
#
#
# Average loss: 0.9213, Accuracy: 2414.0/2940 (82%)
#
# Epoch: 14 	Training Accuracy: 85.95%
# Validation Accuracy: 82.11%
# Batch: 0, Loss: 0.9265968799591064
#
# Average loss: 0.8714, Accuracy: 690.0/790 (87%)
#
#
# Average loss: 0.8823, Accuracy: 2458.0/2940 (84%)
#
# Epoch: 15 	Training Accuracy: 87.34%
# Validation Accuracy: 83.61%
# Batch: 0, Loss: 0.9200890064239502
#
# Average loss: 0.8340, Accuracy: 697.0/790 (88%)
#
#
# Average loss: 0.8451, Accuracy: 2483.0/2940 (84%)
#
# Epoch: 16 	Training Accuracy: 88.23%
# Validation Accuracy: 84.46%
# Batch: 0, Loss: 0.7765488028526306
#
# Average loss: 0.7985, Accuracy: 704.0/790 (89%)
#
#
# Average loss: 0.8096, Accuracy: 2517.0/2940 (86%)
#
# Epoch: 17 	Training Accuracy: 89.11%
# Validation Accuracy: 85.61%
# Batch: 0, Loss: 0.8418480157852173
#
# Average loss: 0.7646, Accuracy: 713.0/790 (90%)
#
#
# Average loss: 0.7756, Accuracy: 2547.0/2940 (87%)
#
# Epoch: 18 	Training Accuracy: 90.25%
# Validation Accuracy: 86.63%
# Batch: 0, Loss: 0.7124482989311218
#
# Average loss: 0.7326, Accuracy: 715.0/790 (91%)
#
#
# Average loss: 0.7443, Accuracy: 2565.0/2940 (87%)
#
# Epoch: 19 	Training Accuracy: 90.51%
# Validation Accuracy: 87.24%
#
# Average loss: 0.7326, Accuracy: 715.0/790 (91%)
#
#
# Average loss: 0.7451, Accuracy: 4280.0/4861 (88%)
#
# Repeat: 2, with seed 78 =========================
# Batch: 0, Loss: 2.1438980102539062
#
# Average loss: 2.0676, Accuracy: 32.0/790 (4%)
#
#
# Average loss: 2.1067, Accuracy: 95.0/2940 (3%)
#
# Epoch: 0 	Training Accuracy: 4.05%
# Validation Accuracy: 3.23%
# Batch: 0, Loss: 2.0327956676483154
#
# Average loss: 1.9914, Accuracy: 47.0/790 (6%)
#
#
# Average loss: 2.0296, Accuracy: 156.0/2940 (5%)
#
# Epoch: 1 	Training Accuracy: 5.95%
# Validation Accuracy: 5.31%
# Batch: 0, Loss: 1.988114356994629
#
# Average loss: 1.9213, Accuracy: 77.0/790 (10%)
#
#
# Average loss: 1.9586, Accuracy: 267.0/2940 (9%)
#
# Epoch: 2 	Training Accuracy: 9.75%
# Validation Accuracy: 9.08%
# Batch: 0, Loss: 1.9031867980957031
#
# Average loss: 1.8559, Accuracy: 120.0/790 (15%)
#
#
# Average loss: 1.8922, Accuracy: 410.0/2940 (14%)
#
# Epoch: 3 	Training Accuracy: 15.19%
# Validation Accuracy: 13.95%
# Batch: 0, Loss: 1.9009342193603516
#
# Average loss: 1.7949, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.8300, Accuracy: 570.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 19.39%
# Batch: 0, Loss: 1.7350517511367798
#
# Average loss: 1.7372, Accuracy: 182.0/790 (23%)
#
#
# Average loss: 1.7715, Accuracy: 671.0/2940 (23%)
#
# Epoch: 5 	Training Accuracy: 23.04%
# Validation Accuracy: 22.82%
# Batch: 0, Loss: 1.773177146911621
#
# Average loss: 1.6816, Accuracy: 205.0/790 (26%)
#
#
# Average loss: 1.7144, Accuracy: 768.0/2940 (26%)
#
# Epoch: 6 	Training Accuracy: 25.95%
# Validation Accuracy: 26.12%
# Batch: 0, Loss: 1.6931202411651611
#
# Average loss: 1.6288, Accuracy: 241.0/790 (31%)
#
#
# Average loss: 1.6601, Accuracy: 885.0/2940 (30%)
#
# Epoch: 7 	Training Accuracy: 30.51%
# Validation Accuracy: 30.10%
# Batch: 0, Loss: 1.6534397602081299
#
# Average loss: 1.5779, Accuracy: 265.0/790 (34%)
#
#
# Average loss: 1.6075, Accuracy: 962.0/2940 (33%)
#
# Epoch: 8 	Training Accuracy: 33.54%
# Validation Accuracy: 32.72%
# Batch: 0, Loss: 1.572407603263855
#
# Average loss: 1.5296, Accuracy: 290.0/790 (37%)
#
#
# Average loss: 1.5582, Accuracy: 1044.0/2940 (36%)
#
# Epoch: 9 	Training Accuracy: 36.71%
# Validation Accuracy: 35.51%
# Batch: 0, Loss: 1.54510498046875
#
# Average loss: 1.4827, Accuracy: 328.0/790 (42%)
#
#
# Average loss: 1.5102, Accuracy: 1139.0/2940 (39%)
#
# Epoch: 10 	Training Accuracy: 41.52%
# Validation Accuracy: 38.74%
# Batch: 0, Loss: 1.543653964996338
#
# Average loss: 1.4373, Accuracy: 365.0/790 (46%)
#
#
# Average loss: 1.4638, Accuracy: 1264.0/2940 (43%)
#
# Epoch: 11 	Training Accuracy: 46.20%
# Validation Accuracy: 42.99%
# Batch: 0, Loss: 1.438201904296875
#
# Average loss: 1.3927, Accuracy: 409.0/790 (52%)
#
#
# Average loss: 1.4185, Accuracy: 1406.0/2940 (48%)
#
# Epoch: 12 	Training Accuracy: 51.77%
# Validation Accuracy: 47.82%
# Batch: 0, Loss: 1.3777443170547485
#
# Average loss: 1.3494, Accuracy: 436.0/790 (55%)
#
#
# Average loss: 1.3748, Accuracy: 1523.0/2940 (52%)
#
# Epoch: 13 	Training Accuracy: 55.19%
# Validation Accuracy: 51.80%
# Batch: 0, Loss: 1.377299427986145
#
# Average loss: 1.3063, Accuracy: 484.0/790 (61%)
#
#
# Average loss: 1.3317, Accuracy: 1654.0/2940 (56%)
#
# Epoch: 14 	Training Accuracy: 61.27%
# Validation Accuracy: 56.26%
# Batch: 0, Loss: 1.2789138555526733
#
# Average loss: 1.2640, Accuracy: 506.0/790 (64%)
#
#
# Average loss: 1.2893, Accuracy: 1764.0/2940 (60%)
#
# Epoch: 15 	Training Accuracy: 64.05%
# Validation Accuracy: 60.00%
# Batch: 0, Loss: 1.2703874111175537
#
# Average loss: 1.2222, Accuracy: 525.0/790 (66%)
#
#
# Average loss: 1.2472, Accuracy: 1855.0/2940 (63%)
#
# Epoch: 16 	Training Accuracy: 66.46%
# Validation Accuracy: 63.10%
# Batch: 0, Loss: 1.2199394702911377
#
# Average loss: 1.1809, Accuracy: 551.0/790 (70%)
#
#
# Average loss: 1.2056, Accuracy: 1949.0/2940 (66%)
#
# Epoch: 17 	Training Accuracy: 69.75%
# Validation Accuracy: 66.29%
# Batch: 0, Loss: 1.1843559741973877
#
# Average loss: 1.1398, Accuracy: 566.0/790 (72%)
#
#
# Average loss: 1.1643, Accuracy: 2023.0/2940 (69%)
#
# Epoch: 18 	Training Accuracy: 71.65%
# Validation Accuracy: 68.81%
# Batch: 0, Loss: 1.1521081924438477
#
# Average loss: 1.0995, Accuracy: 574.0/790 (73%)
#
#
# Average loss: 1.1240, Accuracy: 2096.0/2940 (71%)
#
# Epoch: 19 	Training Accuracy: 72.66%
# Validation Accuracy: 71.29%
#
# Average loss: 1.0995, Accuracy: 574.0/790 (73%)
#
#
# Average loss: 1.1206, Accuracy: 3544.0/4861 (73%)
#
# Repeat: 3, with seed 86 =========================
# Batch: 0, Loss: 1.444082498550415
#
# Average loss: 1.4461, Accuracy: 275.0/790 (35%)
#
#
# Average loss: 1.4408, Accuracy: 1037.0/2940 (35%)
#
# Epoch: 0 	Training Accuracy: 34.81%
# Validation Accuracy: 35.27%
# Batch: 0, Loss: 1.4557193517684937
#
# Average loss: 1.3877, Accuracy: 323.0/790 (41%)
#
#
# Average loss: 1.3828, Accuracy: 1232.0/2940 (42%)
#
# Epoch: 1 	Training Accuracy: 40.89%
# Validation Accuracy: 41.90%
# Batch: 0, Loss: 1.3649693727493286
#
# Average loss: 1.3325, Accuracy: 360.0/790 (46%)
#
#
# Average loss: 1.3285, Accuracy: 1399.0/2940 (48%)
#
# Epoch: 2 	Training Accuracy: 45.57%
# Validation Accuracy: 47.59%
# Batch: 0, Loss: 1.314221978187561
#
# Average loss: 1.2791, Accuracy: 398.0/790 (50%)
#
#
# Average loss: 1.2760, Accuracy: 1540.0/2940 (52%)
#
# Epoch: 3 	Training Accuracy: 50.38%
# Validation Accuracy: 52.38%
# Batch: 0, Loss: 1.2815624475479126
#
# Average loss: 1.2279, Accuracy: 433.0/790 (55%)
#
#
# Average loss: 1.2261, Accuracy: 1659.0/2940 (56%)
#
# Epoch: 4 	Training Accuracy: 54.81%
# Validation Accuracy: 56.43%
# Batch: 0, Loss: 1.2322598695755005
#
# Average loss: 1.1789, Accuracy: 492.0/790 (62%)
#
#
# Average loss: 1.1779, Accuracy: 1830.0/2940 (62%)
#
# Epoch: 5 	Training Accuracy: 62.28%
# Validation Accuracy: 62.24%
# Batch: 0, Loss: 1.2102071046829224
#
# Average loss: 1.1316, Accuracy: 536.0/790 (68%)
#
#
# Average loss: 1.1315, Accuracy: 1972.0/2940 (67%)
#
# Epoch: 6 	Training Accuracy: 67.85%
# Validation Accuracy: 67.07%
# Batch: 0, Loss: 1.11503005027771
#
# Average loss: 1.0862, Accuracy: 576.0/790 (73%)
#
#
# Average loss: 1.0867, Accuracy: 2094.0/2940 (71%)
#
# Epoch: 7 	Training Accuracy: 72.91%
# Validation Accuracy: 71.22%
# Batch: 0, Loss: 1.1000250577926636
#
# Average loss: 1.0422, Accuracy: 599.0/790 (76%)
#
#
# Average loss: 1.0433, Accuracy: 2174.0/2940 (74%)
#
# Epoch: 8 	Training Accuracy: 75.82%
# Validation Accuracy: 73.95%
# Batch: 0, Loss: 1.022456407546997
#
# Average loss: 0.9992, Accuracy: 626.0/790 (79%)
#
#
# Average loss: 1.0015, Accuracy: 2269.0/2940 (77%)
#
# Epoch: 9 	Training Accuracy: 79.24%
# Validation Accuracy: 77.18%
# Batch: 0, Loss: 1.0219424962997437
#
# Average loss: 0.9574, Accuracy: 646.0/790 (82%)
#
#
# Average loss: 0.9612, Accuracy: 2341.0/2940 (80%)
#
# Epoch: 10 	Training Accuracy: 81.77%
# Validation Accuracy: 79.63%
# Batch: 0, Loss: 0.9650928974151611
#
# Average loss: 0.9173, Accuracy: 664.0/790 (84%)
#
#
# Average loss: 0.9232, Accuracy: 2408.0/2940 (82%)
#
# Epoch: 11 	Training Accuracy: 84.05%
# Validation Accuracy: 81.90%
# Batch: 0, Loss: 0.9480311274528503
#
# Average loss: 0.8792, Accuracy: 677.0/790 (86%)
#
#
# Average loss: 0.8865, Accuracy: 2444.0/2940 (83%)
#
# Epoch: 12 	Training Accuracy: 85.70%
# Validation Accuracy: 83.13%
# Batch: 0, Loss: 0.8470517992973328
#
# Average loss: 0.8423, Accuracy: 686.0/790 (87%)
#
#
# Average loss: 0.8511, Accuracy: 2479.0/2940 (84%)
#
# Epoch: 13 	Training Accuracy: 86.84%
# Validation Accuracy: 84.32%
# Batch: 0, Loss: 0.8546116352081299
#
# Average loss: 0.8066, Accuracy: 696.0/790 (88%)
#
#
# Average loss: 0.8167, Accuracy: 2502.0/2940 (85%)
#
# Epoch: 14 	Training Accuracy: 88.10%
# Validation Accuracy: 85.10%
# Batch: 0, Loss: 0.7983442544937134
#
# Average loss: 0.7725, Accuracy: 699.0/790 (88%)
#
#
# Average loss: 0.7839, Accuracy: 2522.0/2940 (86%)
#
# Epoch: 15 	Training Accuracy: 88.48%
# Validation Accuracy: 85.78%
# Batch: 0, Loss: 0.7796941995620728
#
# Average loss: 0.7402, Accuracy: 705.0/790 (89%)
#
#
# Average loss: 0.7530, Accuracy: 2553.0/2940 (87%)
#
# Epoch: 16 	Training Accuracy: 89.24%
# Validation Accuracy: 86.84%
# Batch: 0, Loss: 0.7881590127944946
#
# Average loss: 0.7094, Accuracy: 710.0/790 (90%)
#
#
# Average loss: 0.7234, Accuracy: 2567.0/2940 (87%)
#
# Epoch: 17 	Training Accuracy: 89.87%
# Validation Accuracy: 87.31%
# Batch: 0, Loss: 0.7350605130195618
#
# Average loss: 0.6797, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.6949, Accuracy: 2583.0/2940 (88%)
#
# Epoch: 18 	Training Accuracy: 90.76%
# Validation Accuracy: 87.86%
# Batch: 0, Loss: 0.697813093662262
#
# Average loss: 0.6522, Accuracy: 724.0/790 (92%)
#
#
# Average loss: 0.6684, Accuracy: 2592.0/2940 (88%)
#
# Epoch: 19 	Training Accuracy: 91.65%
# Validation Accuracy: 88.16%
#
# Average loss: 0.6522, Accuracy: 724.0/790 (92%)
#
#
# Average loss: 0.6578, Accuracy: 4346.0/4861 (89%)
#
# Repeat: 4, with seed 57 =========================
# Batch: 0, Loss: 1.5738228559494019
#
# Average loss: 1.5097, Accuracy: 247.0/790 (31%)
#
#
# Average loss: 1.4986, Accuracy: 914.0/2940 (31%)
#
# Epoch: 0 	Training Accuracy: 31.27%
# Validation Accuracy: 31.09%
# Batch: 0, Loss: 1.5247578620910645
#
# Average loss: 1.4538, Accuracy: 278.0/790 (35%)
#
#
# Average loss: 1.4421, Accuracy: 1029.0/2940 (35%)
#
# Epoch: 1 	Training Accuracy: 35.19%
# Validation Accuracy: 35.00%
# Batch: 0, Loss: 1.4567310810089111
#
# Average loss: 1.3999, Accuracy: 314.0/790 (40%)
#
#
# Average loss: 1.3877, Accuracy: 1179.0/2940 (40%)
#
# Epoch: 2 	Training Accuracy: 39.75%
# Validation Accuracy: 40.10%
# Batch: 0, Loss: 1.3565033674240112
#
# Average loss: 1.3477, Accuracy: 354.0/790 (45%)
#
#
# Average loss: 1.3350, Accuracy: 1327.0/2940 (45%)
#
# Epoch: 3 	Training Accuracy: 44.81%
# Validation Accuracy: 45.14%
# Batch: 0, Loss: 1.3487497568130493
#
# Average loss: 1.2970, Accuracy: 401.0/790 (51%)
#
#
# Average loss: 1.2844, Accuracy: 1464.0/2940 (50%)
#
# Epoch: 4 	Training Accuracy: 50.76%
# Validation Accuracy: 49.80%
# Batch: 0, Loss: 1.2891113758087158
#
# Average loss: 1.2478, Accuracy: 439.0/790 (56%)
#
#
# Average loss: 1.2347, Accuracy: 1616.0/2940 (55%)
#
# Epoch: 5 	Training Accuracy: 55.57%
# Validation Accuracy: 54.97%
# Batch: 0, Loss: 1.2726553678512573
#
# Average loss: 1.2006, Accuracy: 469.0/790 (59%)
#
#
# Average loss: 1.1872, Accuracy: 1758.0/2940 (60%)
#
# Epoch: 6 	Training Accuracy: 59.37%
# Validation Accuracy: 59.80%
# Batch: 0, Loss: 1.2201144695281982
#
# Average loss: 1.1545, Accuracy: 503.0/790 (64%)
#
#
# Average loss: 1.1413, Accuracy: 1883.0/2940 (64%)
#
# Epoch: 7 	Training Accuracy: 63.67%
# Validation Accuracy: 64.05%
# Batch: 0, Loss: 1.1893390417099
#
# Average loss: 1.1096, Accuracy: 519.0/790 (66%)
#
#
# Average loss: 1.0969, Accuracy: 2003.0/2940 (68%)
#
# Epoch: 8 	Training Accuracy: 65.70%
# Validation Accuracy: 68.13%
# Batch: 0, Loss: 1.0713536739349365
#
# Average loss: 1.0661, Accuracy: 554.0/790 (70%)
#
#
# Average loss: 1.0530, Accuracy: 2082.0/2940 (71%)
#
# Epoch: 9 	Training Accuracy: 70.13%
# Validation Accuracy: 70.82%
# Batch: 0, Loss: 1.1101919412612915
#
# Average loss: 1.0239, Accuracy: 571.0/790 (72%)
#
#
# Average loss: 1.0111, Accuracy: 2156.0/2940 (73%)
#
# Epoch: 10 	Training Accuracy: 72.28%
# Validation Accuracy: 73.33%
# Batch: 0, Loss: 1.0522263050079346
#
# Average loss: 0.9829, Accuracy: 598.0/790 (76%)
#
#
# Average loss: 0.9706, Accuracy: 2209.0/2940 (75%)
#
# Epoch: 11 	Training Accuracy: 75.70%
# Validation Accuracy: 75.14%
# Batch: 0, Loss: 0.9975082874298096
#
# Average loss: 0.9431, Accuracy: 611.0/790 (77%)
#
#
# Average loss: 0.9316, Accuracy: 2265.0/2940 (77%)
#
# Epoch: 12 	Training Accuracy: 77.34%
# Validation Accuracy: 77.04%
# Batch: 0, Loss: 0.9702406525611877
#
# Average loss: 0.9044, Accuracy: 629.0/790 (80%)
#
#
# Average loss: 0.8936, Accuracy: 2315.0/2940 (79%)
#
# Epoch: 13 	Training Accuracy: 79.62%
# Validation Accuracy: 78.74%
# Batch: 0, Loss: 0.8645960092544556
#
# Average loss: 0.8676, Accuracy: 640.0/790 (81%)
#
#
# Average loss: 0.8576, Accuracy: 2369.0/2940 (81%)
#
# Epoch: 14 	Training Accuracy: 81.01%
# Validation Accuracy: 80.58%
# Batch: 0, Loss: 0.8888335227966309
#
# Average loss: 0.8319, Accuracy: 655.0/790 (83%)
#
#
# Average loss: 0.8228, Accuracy: 2423.0/2940 (82%)
#
# Epoch: 15 	Training Accuracy: 82.91%
# Validation Accuracy: 82.41%
# Batch: 0, Loss: 0.812501072883606
#
# Average loss: 0.7982, Accuracy: 665.0/790 (84%)
#
#
# Average loss: 0.7901, Accuracy: 2454.0/2940 (83%)
#
# Epoch: 16 	Training Accuracy: 84.18%
# Validation Accuracy: 83.47%
# Batch: 0, Loss: 0.806921124458313
#
# Average loss: 0.7653, Accuracy: 675.0/790 (85%)
#
#
# Average loss: 0.7582, Accuracy: 2504.0/2940 (85%)
#
# Epoch: 17 	Training Accuracy: 85.44%
# Validation Accuracy: 85.17%
# Batch: 0, Loss: 0.7783070206642151
#
# Average loss: 0.7341, Accuracy: 680.0/790 (86%)
#
#
# Average loss: 0.7277, Accuracy: 2560.0/2940 (87%)
#
# Epoch: 18 	Training Accuracy: 86.08%
# Validation Accuracy: 87.07%
# Batch: 0, Loss: 0.770010769367218
#
# Average loss: 0.7045, Accuracy: 691.0/790 (87%)
#
#
# Average loss: 0.6988, Accuracy: 2598.0/2940 (88%)
#
# Epoch: 19 	Training Accuracy: 87.47%
# Validation Accuracy: 88.37%
#
# Average loss: 0.7045, Accuracy: 691.0/790 (87%)
#
#
# Average loss: 0.6970, Accuracy: 4267.0/4861 (88%)
#
# Percentage: 0.05
# Repeat: 0, with seed 18 =========================
# Batch: 0, Loss: 1.7126858234405518
#
# Average loss: 1.6374, Accuracy: 275.0/1320 (21%)
#
#
# Average loss: 1.6525, Accuracy: 551.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.83%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.615492343902588
#
# Average loss: 1.5399, Accuracy: 375.0/1320 (28%)
#
#
# Average loss: 1.5522, Accuracy: 741.0/2940 (25%)
#
# Epoch: 1 	Training Accuracy: 28.41%
# Validation Accuracy: 25.20%
# Batch: 0, Loss: 1.5845472812652588
#
# Average loss: 1.4496, Accuracy: 524.0/1320 (40%)
#
#
# Average loss: 1.4599, Accuracy: 1087.0/2940 (37%)
#
# Epoch: 2 	Training Accuracy: 39.70%
# Validation Accuracy: 36.97%
# Batch: 0, Loss: 1.4681789875030518
#
# Average loss: 1.3646, Accuracy: 713.0/1320 (54%)
#
#
# Average loss: 1.3734, Accuracy: 1536.0/2940 (52%)
#
# Epoch: 3 	Training Accuracy: 54.02%
# Validation Accuracy: 52.24%
# Batch: 0, Loss: 1.3707456588745117
#
# Average loss: 1.2814, Accuracy: 854.0/1320 (65%)
#
#
# Average loss: 1.2887, Accuracy: 1894.0/2940 (64%)
#
# Epoch: 4 	Training Accuracy: 64.70%
# Validation Accuracy: 64.42%
# Batch: 0, Loss: 1.2569293975830078
#
# Average loss: 1.1999, Accuracy: 983.0/1320 (74%)
#
#
# Average loss: 1.2061, Accuracy: 2166.0/2940 (74%)
#
# Epoch: 5 	Training Accuracy: 74.47%
# Validation Accuracy: 73.67%
# Batch: 0, Loss: 1.1958369016647339
#
# Average loss: 1.1209, Accuracy: 1057.0/1320 (80%)
#
#
# Average loss: 1.1266, Accuracy: 2330.0/2940 (79%)
#
# Epoch: 6 	Training Accuracy: 80.08%
# Validation Accuracy: 79.25%
# Batch: 0, Loss: 1.1358373165130615
#
# Average loss: 1.0446, Accuracy: 1101.0/1320 (83%)
#
#
# Average loss: 1.0494, Accuracy: 2444.0/2940 (83%)
#
# Epoch: 7 	Training Accuracy: 83.41%
# Validation Accuracy: 83.13%
# Batch: 0, Loss: 1.0444071292877197
#
# Average loss: 0.9724, Accuracy: 1123.0/1320 (85%)
#
#
# Average loss: 0.9772, Accuracy: 2506.0/2940 (85%)
#
# Epoch: 8 	Training Accuracy: 85.08%
# Validation Accuracy: 85.24%
# Batch: 0, Loss: 0.959213376045227
#
# Average loss: 0.9040, Accuracy: 1142.0/1320 (87%)
#
#
# Average loss: 0.9090, Accuracy: 2548.0/2940 (87%)
#
# Epoch: 9 	Training Accuracy: 86.52%
# Validation Accuracy: 86.67%
# Batch: 0, Loss: 0.9039648175239563
#
# Average loss: 0.8408, Accuracy: 1162.0/1320 (88%)
#
#
# Average loss: 0.8459, Accuracy: 2576.0/2940 (88%)
#
# Epoch: 10 	Training Accuracy: 88.03%
# Validation Accuracy: 87.62%
# Batch: 0, Loss: 0.8675278425216675
#
# Average loss: 0.7827, Accuracy: 1173.0/1320 (89%)
#
#
# Average loss: 0.7886, Accuracy: 2598.0/2940 (88%)
#
# Epoch: 11 	Training Accuracy: 88.86%
# Validation Accuracy: 88.37%
# Batch: 0, Loss: 0.7829626798629761
#
# Average loss: 0.7293, Accuracy: 1178.0/1320 (89%)
#
#
# Average loss: 0.7356, Accuracy: 2613.0/2940 (89%)
#
# Epoch: 12 	Training Accuracy: 89.24%
# Validation Accuracy: 88.88%
# Batch: 0, Loss: 0.6723803877830505
#
# Average loss: 0.6807, Accuracy: 1190.0/1320 (90%)
#
#
# Average loss: 0.6867, Accuracy: 2634.0/2940 (90%)
#
# Epoch: 13 	Training Accuracy: 90.15%
# Validation Accuracy: 89.59%
# Batch: 0, Loss: 0.7637597322463989
#
# Average loss: 0.6365, Accuracy: 1195.0/1320 (91%)
#
#
# Average loss: 0.6435, Accuracy: 2636.0/2940 (90%)
#
# Epoch: 14 	Training Accuracy: 90.53%
# Validation Accuracy: 89.66%
# Batch: 0, Loss: 0.6464102864265442
#
# Average loss: 0.5966, Accuracy: 1199.0/1320 (91%)
#
#
# Average loss: 0.6042, Accuracy: 2651.0/2940 (90%)
#
# Epoch: 15 	Training Accuracy: 90.83%
# Validation Accuracy: 90.17%
# Batch: 0, Loss: 0.5754454731941223
#
# Average loss: 0.5606, Accuracy: 1201.0/1320 (91%)
#
#
# Average loss: 0.5688, Accuracy: 2658.0/2940 (90%)
#
# Epoch: 16 	Training Accuracy: 90.98%
# Validation Accuracy: 90.41%
# Batch: 0, Loss: 0.5760073065757751
#
# Average loss: 0.5281, Accuracy: 1205.0/1320 (91%)
#
#
# Average loss: 0.5369, Accuracy: 2669.0/2940 (91%)
#
# Epoch: 17 	Training Accuracy: 91.29%
# Validation Accuracy: 90.78%
# Batch: 0, Loss: 0.521333634853363
#
# Average loss: 0.4987, Accuracy: 1213.0/1320 (92%)
#
#
# Average loss: 0.5078, Accuracy: 2675.0/2940 (91%)
#
# Epoch: 18 	Training Accuracy: 91.89%
# Validation Accuracy: 90.99%
# Batch: 0, Loss: 0.45967957377433777
#
# Average loss: 0.4724, Accuracy: 1215.0/1320 (92%)
#
#
# Average loss: 0.4819, Accuracy: 2678.0/2940 (91%)
#
# Epoch: 19 	Training Accuracy: 92.05%
# Validation Accuracy: 91.09%
#
# Average loss: 0.4724, Accuracy: 1215.0/1320 (92%)
#
#
# Average loss: 0.4711, Accuracy: 4458.0/4861 (92%)
#
# Repeat: 1, with seed 63 =========================
# Batch: 0, Loss: 1.5802249908447266
#
# Average loss: 1.4981, Accuracy: 381.0/1320 (29%)
#
#
# Average loss: 1.5026, Accuracy: 859.0/2940 (29%)
#
# Epoch: 0 	Training Accuracy: 28.86%
# Validation Accuracy: 29.22%
# Batch: 0, Loss: 1.5201904773712158
#
# Average loss: 1.4052, Accuracy: 577.0/1320 (44%)
#
#
# Average loss: 1.4121, Accuracy: 1291.0/2940 (44%)
#
# Epoch: 1 	Training Accuracy: 43.71%
# Validation Accuracy: 43.91%
# Batch: 0, Loss: 1.4315166473388672
#
# Average loss: 1.3165, Accuracy: 731.0/1320 (55%)
#
#
# Average loss: 1.3249, Accuracy: 1652.0/2940 (56%)
#
# Epoch: 2 	Training Accuracy: 55.38%
# Validation Accuracy: 56.19%
# Batch: 0, Loss: 1.3055896759033203
#
# Average loss: 1.2301, Accuracy: 867.0/1320 (66%)
#
#
# Average loss: 1.2399, Accuracy: 1928.0/2940 (66%)
#
# Epoch: 3 	Training Accuracy: 65.68%
# Validation Accuracy: 65.58%
# Batch: 0, Loss: 1.2507576942443848
#
# Average loss: 1.1475, Accuracy: 967.0/1320 (73%)
#
#
# Average loss: 1.1580, Accuracy: 2155.0/2940 (73%)
#
# Epoch: 4 	Training Accuracy: 73.26%
# Validation Accuracy: 73.30%
# Batch: 0, Loss: 1.1492576599121094
#
# Average loss: 1.0678, Accuracy: 1051.0/1320 (80%)
#
#
# Average loss: 1.0792, Accuracy: 2303.0/2940 (78%)
#
# Epoch: 5 	Training Accuracy: 79.62%
# Validation Accuracy: 78.33%
# Batch: 0, Loss: 1.0843957662582397
#
# Average loss: 0.9923, Accuracy: 1104.0/1320 (84%)
#
#
# Average loss: 1.0046, Accuracy: 2384.0/2940 (81%)
#
# Epoch: 6 	Training Accuracy: 83.64%
# Validation Accuracy: 81.09%
# Batch: 0, Loss: 0.9726336598396301
#
# Average loss: 0.9212, Accuracy: 1130.0/1320 (86%)
#
#
# Average loss: 0.9348, Accuracy: 2462.0/2940 (84%)
#
# Epoch: 7 	Training Accuracy: 85.61%
# Validation Accuracy: 83.74%
# Batch: 0, Loss: 0.8720759153366089
#
# Average loss: 0.8550, Accuracy: 1159.0/1320 (88%)
#
#
# Average loss: 0.8701, Accuracy: 2511.0/2940 (85%)
#
# Epoch: 8 	Training Accuracy: 87.80%
# Validation Accuracy: 85.41%
# Batch: 0, Loss: 0.8240690231323242
#
# Average loss: 0.7937, Accuracy: 1170.0/1320 (89%)
#
#
# Average loss: 0.8091, Accuracy: 2556.0/2940 (87%)
#
# Epoch: 9 	Training Accuracy: 88.64%
# ...
# Batch: 20, Loss: 0.12186959385871887
# Batch: 40, Loss: 0.08168449252843857
# Batch: 60, Loss: 0.09322208911180496
# Batch: 80, Loss: 0.2209099680185318
# Batch: 100, Loss: 0.1825684905052185
# Batch: 120, Loss: 0.17357242107391357
# Batch: 140, Loss: 0.16738353669643402
# Batch: 160, Loss: 0.17340558767318726
# Batch: 180, Loss: 0.21880188584327698
# Batch: 200, Loss: 0.22916419804096222
#
# Average loss: 0.1376, Accuracy: 24871.0/26038 (96%)
#
#
# Average loss: 0.1537, Accuracy: 2798.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 95.52%
# Validation Accuracy: 95.17%
# Batch: 0, Loss: 0.1055099293589592
# Batch: 20, Loss: 0.1313794106245041
# Batch: 40, Loss: 0.13056427240371704
# Batch: 60, Loss: 0.15043549239635468
# Batch: 80, Loss: 0.14930714666843414
# Batch: 100, Loss: 0.08271888643503189
# Batch: 120, Loss: 0.11615945398807526
# Batch: 140, Loss: 0.14545759558677673
# Batch: 160, Loss: 0.0608099028468132
# Batch: 180, Loss: 0.08814273774623871
# Batch: 200, Loss: 0.07611268758773804
#
# Average loss: 0.1356, Accuracy: 24873.0/26038 (96%)
#
#
# Average loss: 0.1527, Accuracy: 2801.0/2940 (95%)
#
# Epoch: 8 	Training Accuracy: 95.53%
# Validation Accuracy: 95.27%
# Batch: 0, Loss: 0.13231363892555237
# Batch: 20, Loss: 0.16346386075019836
# Batch: 40, Loss: 0.09020812064409256
# Batch: 60, Loss: 0.11889021843671799
# Batch: 80, Loss: 0.10380519926548004
# Batch: 100, Loss: 0.13131187856197357
# Batch: 120, Loss: 0.10835197567939758
# Batch: 140, Loss: 0.10579438507556915
# Batch: 160, Loss: 0.16940417885780334
# Batch: 180, Loss: 0.15456373989582062
# Batch: 200, Loss: 0.19864511489868164
#
# Average loss: 0.1327, Accuracy: 24903.0/26038 (96%)
#
#
# Average loss: 0.1497, Accuracy: 2799.0/2940 (95%)
#
# Epoch: 9 	Training Accuracy: 95.64%
# Validation Accuracy: 95.20%
# Batch: 0, Loss: 0.2132890671491623
# Batch: 20, Loss: 0.13601553440093994
# Batch: 40, Loss: 0.09927473217248917
# Batch: 60, Loss: 0.20755180716514587
# Batch: 80, Loss: 0.1487072855234146
# Batch: 100, Loss: 0.12233304232358932
# Batch: 120, Loss: 0.09601493179798126
# Batch: 140, Loss: 0.1434791088104248
# Batch: 160, Loss: 0.08364919573068619
# Batch: 180, Loss: 0.18248170614242554
# Batch: 200, Loss: 0.11396535485982895
#
# Average loss: 0.1320, Accuracy: 24905.0/26038 (96%)
#
#
# Average loss: 0.1502, Accuracy: 2797.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 95.65%
# Validation Accuracy: 95.14%
# Batch: 0, Loss: 0.11919646710157394
# Batch: 20, Loss: 0.07767689973115921
# Batch: 40, Loss: 0.201940655708313
# Batch: 60, Loss: 0.1085650846362114
# Batch: 80, Loss: 0.14857088029384613
# Batch: 100, Loss: 0.17636464536190033
# Batch: 120, Loss: 0.1830122470855713
# Batch: 140, Loss: 0.06354192644357681
# Batch: 160, Loss: 0.12654216587543488
# Batch: 180, Loss: 0.0889810249209404
# Batch: 200, Loss: 0.08823966234922409
#
# Average loss: 0.1310, Accuracy: 24891.0/26038 (96%)
#
#
# Average loss: 0.1480, Accuracy: 2794.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 95.59%
# Validation Accuracy: 95.03%
# Batch: 0, Loss: 0.10288746654987335
# Batch: 20, Loss: 0.10168614238500595
# Batch: 40, Loss: 0.1291675567626953
# Batch: 60, Loss: 0.2030419409275055
# Batch: 80, Loss: 0.2796419858932495
# Batch: 100, Loss: 0.1658073365688324
# Batch: 120, Loss: 0.1583307832479477
# Batch: 140, Loss: 0.1608695685863495
# Batch: 160, Loss: 0.11164827644824982
# Batch: 180, Loss: 0.11007112264633179
# Batch: 200, Loss: 0.09727326035499573
#
# Average loss: 0.1293, Accuracy: 24942.0/26038 (96%)
#
#
# Average loss: 0.1494, Accuracy: 2807.0/2940 (95%)
#
# Epoch: 12 	Training Accuracy: 95.79%
# Validation Accuracy: 95.48%
# Batch: 0, Loss: 0.08989972621202469
# Batch: 20, Loss: 0.1637800931930542
# Batch: 40, Loss: 0.16813021898269653
# Batch: 60, Loss: 0.13447880744934082
# Batch: 80, Loss: 0.1531975120306015
# Batch: 100, Loss: 0.21558544039726257
# Batch: 120, Loss: 0.12124825268983841
# Batch: 140, Loss: 0.2111753672361374
# Batch: 160, Loss: 0.0672612115740776
# Batch: 180, Loss: 0.10981902480125427
# Batch: 200, Loss: 0.11334394663572311
#
# Average loss: 0.1274, Accuracy: 24938.0/26038 (96%)
#
#
# Average loss: 0.1462, Accuracy: 2808.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 95.78%
# Validation Accuracy: 95.51%
# Batch: 0, Loss: 0.12699320912361145
# Batch: 20, Loss: 0.07841508835554123
# Batch: 40, Loss: 0.14986374974250793
# Batch: 60, Loss: 0.1354760229587555
# Batch: 80, Loss: 0.052636176347732544
# Batch: 100, Loss: 0.15078319609165192
# Batch: 120, Loss: 0.1382138580083847
# Batch: 140, Loss: 0.1288103610277176
# Batch: 160, Loss: 0.07094720005989075
# Batch: 180, Loss: 0.2700643241405487
# Batch: 200, Loss: 0.06677570939064026
#
# Average loss: 0.1270, Accuracy: 24944.0/26038 (96%)
#
#
# Average loss: 0.1454, Accuracy: 2802.0/2940 (95%)
#
# Epoch: 14 	Training Accuracy: 95.80%
# Validation Accuracy: 95.31%
# Batch: 0, Loss: 0.15725617110729218
# Batch: 20, Loss: 0.07259581983089447
# Batch: 40, Loss: 0.12327339500188828
# Batch: 60, Loss: 0.10456141829490662
# Batch: 80, Loss: 0.06266195327043533
# Batch: 100, Loss: 0.17108073830604553
# Batch: 120, Loss: 0.1588592231273651
# Batch: 140, Loss: 0.08745986968278885
# Batch: 160, Loss: 0.10893429070711136
# Batch: 180, Loss: 0.19864316284656525
# Batch: 200, Loss: 0.06700122356414795
#
# Average loss: 0.1276, Accuracy: 24928.0/26038 (96%)
#
#
# Average loss: 0.1478, Accuracy: 2795.0/2940 (95%)
#
# Epoch: 15 	Training Accuracy: 95.74%
# Validation Accuracy: 95.07%
# Batch: 0, Loss: 0.15141300857067108
# Batch: 20, Loss: 0.18660596013069153
# Batch: 40, Loss: 0.17350715398788452
# Batch: 60, Loss: 0.09307089447975159
# Batch: 80, Loss: 0.14081645011901855
# Batch: 100, Loss: 0.13778086006641388
# Batch: 120, Loss: 0.13267073035240173
# Batch: 140, Loss: 0.2042587846517563
# Batch: 160, Loss: 0.11497799307107925
# Batch: 180, Loss: 0.12469962239265442
# Batch: 200, Loss: 0.07761349529027939
#
# Average loss: 0.1243, Accuracy: 24959.0/26038 (96%)
#
#
# Average loss: 0.1443, Accuracy: 2812.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 95.86%
# Validation Accuracy: 95.65%
# Batch: 0, Loss: 0.10132858902215958
# Batch: 140, Loss: 0.24415864050388336
# Batch: 160, Loss: 0.12254652380943298
# Batch: 180, Loss: 0.3280029892921448
# Batch: 200, Loss: 0.2236580103635788
#
# Average loss: 0.1461, Accuracy: 24789.0/26038 (95%)
#
#
# Average loss: 0.1616, Accuracy: 2778.0/2940 (94%)
#
# Epoch: 6 	Training Accuracy: 95.20%
# Validation Accuracy: 94.49%
# Batch: 0, Loss: 0.18609663844108582
# Batch: 20, Loss: 0.14143730700016022
# Batch: 40, Loss: 0.10403496772050858
# Batch: 60, Loss: 0.0974840298295021
# Batch: 80, Loss: 0.1170860156416893
# Batch: 100, Loss: 0.06327212601900101
# Batch: 120, Loss: 0.10954630374908447
# Batch: 140, Loss: 0.1758657693862915
# Batch: 160, Loss: 0.09255894273519516
# Batch: 180, Loss: 0.10814764350652695
# Batch: 200, Loss: 0.12517432868480682
#
# Average loss: 0.1406, Accuracy: 24837.0/26038 (95%)
#
#
# Average loss: 0.1560, Accuracy: 2787.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 95.39%
# Validation Accuracy: 94.80%
# Batch: 0, Loss: 0.15153385698795319
# Batch: 20, Loss: 0.2296469658613205
# Batch: 40, Loss: 0.14203961193561554
# Batch: 60, Loss: 0.22258323431015015
# Batch: 80, Loss: 0.197366401553154
# Batch: 100, Loss: 0.16866888105869293
# Batch: 120, Loss: 0.14140585064888
# Batch: 140, Loss: 0.1247812882065773
# Batch: 160, Loss: 0.06851540505886078
# Batch: 180, Loss: 0.2536107301712036
# Batch: 200, Loss: 0.17625804245471954
#
# Average loss: 0.1377, Accuracy: 24854.0/26038 (95%)
#
#
# Average loss: 0.1540, Accuracy: 2788.0/2940 (95%)
#
# Epoch: 8 	Training Accuracy: 95.45%
# Validation Accuracy: 94.83%
# Batch: 0, Loss: 0.08453734219074249
# Batch: 20, Loss: 0.0946977287530899
# Batch: 40, Loss: 0.08879243582487106
# Batch: 60, Loss: 0.10423465818166733
# Batch: 80, Loss: 0.07235401123762131
# Batch: 100, Loss: 0.07994740456342697
# Batch: 120, Loss: 0.08259806036949158
# Batch: 140, Loss: 0.14247603714466095
# Batch: 160, Loss: 0.1723783016204834
# Batch: 180, Loss: 0.1345299333333969
# Batch: 200, Loss: 0.18935754895210266
#
# Average loss: 0.1353, Accuracy: 24879.0/26038 (96%)
#
#
# Average loss: 0.1524, Accuracy: 2794.0/2940 (95%)
#
# Epoch: 9 	Training Accuracy: 95.55%
# Validation Accuracy: 95.03%
# Batch: 0, Loss: 0.21380756795406342
# Batch: 20, Loss: 0.11282449960708618
# Batch: 40, Loss: 0.14338889718055725
# Batch: 60, Loss: 0.09942131489515305
# Batch: 80, Loss: 0.13462086021900177
# Batch: 100, Loss: 0.14298154413700104
# Batch: 120, Loss: 0.10696665942668915
# Batch: 140, Loss: 0.11603138595819473
# Batch: 160, Loss: 0.06561031192541122
# Batch: 180, Loss: 0.1273544728755951
# Batch: 200, Loss: 0.10959362983703613
#
# Average loss: 0.1332, Accuracy: 24889.0/26038 (96%)
#
#
# Average loss: 0.1501, Accuracy: 2791.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 95.59%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.12661530077457428
# Batch: 20, Loss: 0.14254191517829895
# Batch: 40, Loss: 0.11830312013626099
# Batch: 60, Loss: 0.12038388103246689
# Batch: 80, Loss: 0.11252278089523315
# Batch: 100, Loss: 0.13911262154579163
# Batch: 120, Loss: 0.08626912534236908
# Batch: 140, Loss: 0.09417194128036499
# Batch: 160, Loss: 0.15077300369739532
# Batch: 180, Loss: 0.09701954573392868
# Batch: 200, Loss: 0.1253204196691513
#
# Average loss: 0.1316, Accuracy: 24911.0/26038 (96%)
#
#
# Average loss: 0.1486, Accuracy: 2792.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 95.67%
# Validation Accuracy: 94.97%
# Batch: 0, Loss: 0.1280655711889267
# Batch: 20, Loss: 0.16610953211784363
# Batch: 40, Loss: 0.1560382843017578
# Batch: 60, Loss: 0.10836365818977356
# Batch: 80, Loss: 0.14286957681179047
# Batch: 100, Loss: 0.10775037854909897
# Batch: 120, Loss: 0.10567715764045715
# Batch: 140, Loss: 0.2212982177734375
# Batch: 160, Loss: 0.11192639917135239
# Batch: 180, Loss: 0.13430558145046234
# Batch: 200, Loss: 0.1018749326467514
#
# Average loss: 0.1308, Accuracy: 24912.0/26038 (96%)
#
#
# Average loss: 0.1496, Accuracy: 2790.0/2940 (95%)
#
# Epoch: 12 	Training Accuracy: 95.68%
# Validation Accuracy: 94.90%
# Batch: 0, Loss: 0.13596783578395844
# Batch: 20, Loss: 0.09388042241334915
# Batch: 40, Loss: 0.14366638660430908
# Batch: 60, Loss: 0.06021350994706154
# Batch: 80, Loss: 0.14072659611701965
# Batch: 100, Loss: 0.13040092587471008
# Batch: 120, Loss: 0.18359141051769257
# Batch: 140, Loss: 0.13598117232322693
# Batch: 160, Loss: 0.15164272487163544
# Batch: 180, Loss: 0.1586814969778061
# Batch: 200, Loss: 0.10799621790647507
#
# Average loss: 0.1294, Accuracy: 24926.0/26038 (96%)
#
#
# Average loss: 0.1484, Accuracy: 2793.0/2940 (95%)
#
# Epoch: 13 	Training Accuracy: 95.73%
# Validation Accuracy: 95.00%
# Batch: 0, Loss: 0.05962667614221573
# Batch: 20, Loss: 0.17236515879631042
# Batch: 40, Loss: 0.1344841867685318
# Batch: 60, Loss: 0.15986323356628418
# Batch: 80, Loss: 0.12535591423511505
# Batch: 100, Loss: 0.14845062792301178
# Batch: 120, Loss: 0.1982664316892624
# Batch: 140, Loss: 0.11787014454603195
# Batch: 160, Loss: 0.09618722647428513
# Batch: 180, Loss: 0.08108307421207428
# Batch: 200, Loss: 0.08782577514648438
#
# Average loss: 0.1279, Accuracy: 24923.0/26038 (96%)
#
#
# Average loss: 0.1468, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 14 	Training Accuracy: 95.72%
# Validation Accuracy: 95.10%
# Batch: 0, Loss: 0.03810872882604599
# Batch: 20, Loss: 0.2048758864402771
# Batch: 40, Loss: 0.1708294004201889
# Batch: 60, Loss: 0.19915790855884552
# Batch: 80, Loss: 0.19336391985416412
# Batch: 100, Loss: 0.087872214615345
# Batch: 120, Loss: 0.11528360098600388
# Batch: 140, Loss: 0.10757250338792801
# Batch: 160, Loss: 0.15983407199382782
# Batch: 180, Loss: 0.2399151474237442
# Batch: 200, Loss: 0.1130443811416626
#
# Average loss: 0.1272, Accuracy: 24933.0/26038 (96%)
#
#
# Average loss: 0.1460, Accuracy: 2802.0/2940 (95%)
#
# Epoch: 15 	Training Accuracy: 95.76%
# Validation Accuracy: 95.31%
# Batch: 0, Loss: 0.19191892445087433
# Batch: 20, Loss: 0.1254543960094452
# Batch: 40, Loss: 0.1025000661611557
# Batch: 60, Loss: 0.17223519086837769
# Batch: 80, Loss: 0.18236811459064484
# Batch: 100, Loss: 0.10361506789922714
# Batch: 120, Loss: 0.21923714876174927
# Batch: 140, Loss: 0.07879863679409027
# Batch: 160, Loss: 0.1881323605775833
# Batch: 180, Loss: 0.13697662949562073
# Batch: 200, Loss: 0.12189401686191559
#
# Average loss: 0.1256, Accuracy: 24958.0/26038 (96%)
#
#
# Average loss: 0.1453, Accuracy: 2801.0/2940 (95%)
#
# Epoch: 16 	Training Accuracy: 95.85%
# Validation Accuracy: 95.27%
# Batch: 0, Loss: 0.09680800139904022
# Batch: 20, Loss: 0.18472860753536224
# Batch: 40, Loss: 0.12464575469493866
# Batch: 60, Loss: 0.19592444598674774
# Batch: 80, Loss: 0.14288732409477234
# Batch: 100, Loss: 0.1244744136929512
# Batch: 120, Loss: 0.10890240967273712
# Batch: 140, Loss: 0.15023063123226166
# Batch: 160, Loss: 0.057061441242694855
# Batch: 180, Loss: 0.15969115495681763
# Batch: 200, Loss: 0.10833223164081573
#
# Average loss: 0.1251, Accuracy: 24961.0/26038 (96%)
#
#
# Average loss: 0.1446, Accuracy: 2804.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 95.86%
# Validation Accuracy: 95.37%
# Batch: 0, Loss: 0.14682063460350037
# Batch: 20, Loss: 0.1320638507604599
# Batch: 40, Loss: 0.13673418760299683
# Batch: 60, Loss: 0.09850197285413742
# Batch: 80, Loss: 0.15139822661876678
# Batch: 100, Loss: 0.22179321944713593
# Batch: 120, Loss: 0.12250348925590515
# Batch: 140, Loss: 0.09230132400989532
# Batch: 160, Loss: 0.09518665075302124
# Batch: 180, Loss: 0.13143594563007355
# Batch: 200, Loss: 0.18013422191143036
#
# Average loss: 0.1240, Accuracy: 24964.0/26038 (96%)
#
#
# Average loss: 0.1443, Accuracy: 2804.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 95.88%
# Validation Accuracy: 95.37%
# Batch: 0, Loss: 0.19728513062000275
# Batch: 20, Loss: 0.11208115518093109
# Batch: 40, Loss: 0.18006035685539246
# Batch: 60, Loss: 0.09446831792593002
# Batch: 80, Loss: 0.13603715598583221
# Batch: 100, Loss: 0.14759515225887299
# Batch: 120, Loss: 0.10650058090686798
# Batch: 140, Loss: 0.09306583553552628
# Batch: 160, Loss: 0.1321796327829361
# Batch: 180, Loss: 0.05191979184746742
# Batch: 200, Loss: 0.14912022650241852
#
# Average loss: 0.1240, Accuracy: 24962.0/26038 (96%)
#
#
# Average loss: 0.1436, Accuracy: 2801.0/2940 (95%)
#
# Epoch: 19 	Training Accuracy: 95.87%
# Validation Accuracy: 95.27%
#
# Average loss: 0.1240, Accuracy: 24962.0/26038 (96%)
#
#
# Average loss: 0.1345, Accuracy: 4636.0/4861 (95%)
#
# Percentage: 0.01, Seed: 10, Epochs taken: 20
# Percentage: 0.01, Seed: 20, Epochs taken: 20
# Percentage: 0.01, Seed: 30, Epochs taken: 20
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 20
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 20
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 19
# Percentage: 0.4, Seed: 30, Epochs taken: 20
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 20
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 20
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 20
# Percentage: 1, Seed: 40, Epochs taken: 20
# Percentage: 1, Seed: 50, Epochs taken: 20

# %%
# End to End - Train Accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Train Accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Train Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Train Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
# End to End - Test Accuracies
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]

plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Test Accuracies
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Test Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Test Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
data_to_save = {
    "results_test_finetune": results_test_finetune,
    "results_train_finetune": results_train_finetune,
    "epochs_taken_finetune": epochs_taken_finetune,
    
    "results_test": results_test,
    "results_train": results_train,
    "epochs_taken": epochs_taken
}

# Assuming data_to_save from the previous code
with open("data.json", "w") as file:
    json.dump(data_to_save, file)

# %%
plt.figure(figsize=(10, 6))

for perc in percentages:
    plt.scatter(epochs_taken[perc], epochs_taken_finetune[perc], label=f'{perc} data')
plt.xlabel('Epochs (End to End)')
plt.ylabel('Epochs (Finetune)')
plt.title('Scatter Plot Comparing Epochs Taken for Convergence')
plt.legend()
plt.show()

# %%
# Given data
percentages = list(epochs_taken.keys())

all_epochs = []
labels = []

for perc in percentages:
    all_epochs.extend([epochs_taken[perc], epochs_taken_finetune[perc]])
    labels.extend([f'{perc} End to End', f'{perc} Finetune'])

# Plotting
plt.figure(figsize=(10, 6))
box = plt.boxplot(all_epochs, labels=labels, patch_artist=True)

# Coloring
colors = ['skyblue', 'lightgreen'] * len(percentages)
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

plt.ylabel('Epochs Taken')
plt.title('Box Plot of Epochs Taken for Each Percentage')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ***EXPERIMENT SETUP***

# %% [markdown]
# - percentages_set_1 = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
# - dataset: same as before MNIST 5 to 5
#
# - lr pretraining = 0.001
# - lr finetuning = 0.0001
#
# - architecture:
#     - Conv 1 (5,5), channels=1
#     - Relu
#     - Conv 2 (5,5,), channels=1
#     - Relu
#     - Pooling: TRUE
#     - dense( x, x) x=output shape of prev layer (128?)
#     - Relu
#     - dense(x, 5)
#     - softmax
#
# - Freezing: NO
#
# - Reinitializing CNN layers: No
# - Reinitializing CNN layers: No
# - Reinitializing softmax layers: Yes
#
# - If we don’t save the best model, ES=6
#
# - num train = 20

# %% [markdown]
# ***IMPORTS***

# %%
import numpy as np
import random
import copy
import matplotlib.pyplot as plt
import json
from tqdm.auto import tqdm

# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from torchvision import datasets, transforms

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from types import SimpleNamespace
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ***UTILS***

# %%
def eval(model, device, dataset_loader, debug=False, classification_report_flag=False, is_cnn=True, logger=print):

    """
    Evaluates the model on the given dataset loader.

    Parameters:
    - model: the PyTorch model to evaluate.
    - device: the device to which tensors should be moved before computation.
    - dataset_loader: DataLoader for evaluation.
    - debug: whether to print debug info like loss and accuracy.
    - classification_report_flag: whether to print a classification report.
    - is_cnn: a flag indicating if the model is a CNN. If it's not, the input data will be reshaped.
    - logger: logging function for printing messages.

    Returns:
    - Accuracy of the model on the provided dataset loader.

    Usage:
    - accuracy = eval(model, device, dataset_loader, debug=False, is_cnn=False, classification_report_flag=False)
    """

    model.eval()
    test_loss, correct = 0., 0.
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data, target in dataset_loader:
            if is_cnn:
              data = data.view(data.size(0), 1, 28, 28)
            else:
              data = data.reshape([data.shape[0], -1])
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(target.cpu().numpy())

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data

    if debug:
        logger('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(test_loss, correct, num_data, 100. * acc))

    if classification_report_flag:
        unique_labels = np.unique(all_labels).tolist()
        logger(classification_report(all_labels, all_preds, labels=unique_labels, target_names=[f'Class {i}' for i in unique_labels]))

    return acc

# %%
class Trainer:

    """
    A class for training and evaluating a model with early stopping and best model saving functionalities.

    Attributes:
    - model: PyTorch model to be trained and evaluated.
    - dataloader: Contains data loaders (train, validation, test) for training and evaluation.
    - params: Dictionary containing various hyperparameters and settings.
    - device: the device to which tensors should be moved before computation.
    - optimizer: The optimizer for training.
    - best_model_state: State dictionary of the best model.
    - max_val_acc: The highest validation accuracy encountered during training.
    - no_improve_epochs: Number of epochs without improvement in validation accuracy.
    - is_cnn: Flag indicating if the model is a CNN.
    - is_debug: Flag indicating if debug information should be printed.
    - classification_report_flag: Flag indicating if a classification report should be generated.

    Methods:
    - train_epoch(): Runs a single epoch of training.
    - evaluate(loader): Evaluates the model on a given data loader.
    - save_best_model(): Saves the current state of the model as the best model.
    - save_checkpoint(epoch, train_acc, val_acc): Saves the current state of the model and other information as a checkpoint.
    - early_stopping_check(val_acc): Checks the stopping criterion and performs actions based on it.
    - train(): Runs the training process for a number of epochs, with early stopping functionality.

    Usage:
    params = {
      'device': 'cuda',
      'lr': 0.001,
      'num_train': 10,
      'early_stop_patience': 3,
      'save_best': True,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': True
    }

    trainer = Trainer(model, dataloader, params)
    train_acc, test_acc, effective_epochs, checkpoints = trainer.train()
    """


    def __init__(self, model, dataloader, params):
        self.model = model
        self.dataloader = dataloader
        self.params = params

        self.device = torch.device(params['device'])
        self.optimizer = optim.Adam(model.parameters(), lr=params['lr'])

        # Initialize best_model_state with the current model state
        self.best_model_state = copy.deepcopy(self.model.state_dict())
        self.max_val_acc = 0.
        self.no_improve_epochs = 0

        self.is_cnn = params.get('is_cnn', False)
        self.is_debug = params.get('is_debug', False)
        self.classification_report_flag = params.get('classification_report_flag', False)
        self.logger = params.get('logger', print)
        
    def train_epoch(self):
      self.model.train()
      for batch_idx, (data, target) in enumerate(self.dataloader.train_loader):

          # Print the size of the current batch
          if self.is_cnn:
            data = data.view(data.size(0), 1, 28, 28)
          else:
            data = data.reshape([data.shape[0], -1])

          data, target = data.to(self.device), target.to(self.device)
          self.optimizer.zero_grad()
          output = self.model(data)
          loss = F.nll_loss(output, target)
          loss.backward()
          self.optimizer.step()

          if self.is_debug and batch_idx % 20 == 0:
              self.logger(f"Batch: {batch_idx}, Loss: {loss.item()}")

    def evaluate(self, loader):
        return eval(self.model, self.device, loader, self.is_debug, self.classification_report_flag, self.is_cnn)

    def save_best_model(self):
        torch.save(self.model.state_dict(), 'best_model.pth')

    def save_checkpoint(self, epoch, train_acc, val_acc):
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'train_acc': train_acc,
            'val_acc': val_acc
        }
        torch.save(checkpoint, f'checkpoint_epoch_{epoch}.pth')
        return checkpoint

    def early_stopping_check(self, val_acc):
        if val_acc > self.max_val_acc:
            self.max_val_acc = val_acc
            self.no_improve_epochs = 0
            # Deep copy the model's state
            self.best_model_state = copy.deepcopy(self.model.state_dict())
            if self.params.get('save_best', False):
                self.save_best_model()
        else:
            self.no_improve_epochs += 1
            if self.no_improve_epochs >= self.params['early_stop_patience']:
                self.logger("Early stopping invoked.")
                # Only load if best_model_state has been set
                if self.best_model_state is not None:
                    self.model.load_state_dict(self.best_model_state)
                return True
        return False

    def train(self):
        effective_epochs = 0
        checkpoints = []

        for epoch in range(self.params['num_train']):
            effective_epochs += 1
            self.train_epoch()

            train_acc = self.evaluate(self.dataloader.train_loader)
            val_acc = self.evaluate(self.dataloader.val_loader)
            self.logger(f'Epoch: {epoch} \tTraining Accuracy: {train_acc*100:.2f}%')
            self.logger(f'Validation Accuracy: {val_acc*100:.2f}%')

            if self.params.get('early_stop_patience', None):
                if self.early_stopping_check(val_acc):
                    self.model.load_state_dict(self.best_model_state)
                    break

            if self.params.get('save_checkpoints', False):
                checkpoint = self.save_checkpoint(epoch, train_acc, val_acc)
                checkpoints.append(checkpoint)

        # Final evaluations
        train_acc = self.evaluate(self.dataloader.train_loader)
        test_acc = self.evaluate(self.dataloader.test_loader)

        return train_acc, test_acc, effective_epochs, checkpoints

# %%
def reduce_dataset(dataloader, percentage, balanced=True, seed=42):

    """
    Reduces the dataset to the given percentage. Can ensure class balance if needed.

    Parameters:
    - dataloader: PyTorch DataLoader object.
    - percentage: Desired percentage of the original dataset.
    - balanced: If True, ensures class balance. If False, reduces randomly.
    - seed: Seed for reproducibility.

    Returns:
    - reduced_dataloader: DataLoader with the reduced dataset.
    """
    # Extract the dataset from the dataloader
    dataset = dataloader.dataset

    # Extract all data and labels from the dataset
    X = [dataset[i][0] for i in range(len(dataset))]
    y = [dataset[i][1] for i in range(len(dataset))]

    # Set the seed for reproducibility
    torch.manual_seed(seed)

    if not balanced:
        # Determine the number of samples to keep
        num_samples = int(len(dataset) * percentage)

        # Randomly select indices without replacement
        indices = torch.randperm(len(dataset))[:num_samples].tolist()

    else:
        # Get unique classes and their counts
        classes, class_counts = torch.unique(torch.tensor(y), return_counts=True)

        # Determine the number of samples per class to keep
        num_samples_per_class = int(len(dataset) * percentage / len(classes))
        indices = []

        for class_label in classes:
            class_indices = [i for i, label in enumerate(y) if label == class_label]

            # Randomly select indices without replacement for each class
            class_selected_indices = torch.randperm(len(class_indices))[:num_samples_per_class].tolist()
            indices.extend([class_indices[i] for i in class_selected_indices])

    # Use a Subset of the original dataset to create a reduced dataset
    reduced_dataset = data.Subset(dataset, indices)

    # Create a DataLoader with the reduced dataset.
    reduced_dataloader = data.DataLoader(reduced_dataset, batch_size=dataloader.batch_size, shuffle=True)

    return reduced_dataloader

# %%
class RelabeledSubset(torch.utils.data.Dataset):
    def __init__(self, dataset, offset):
        self.dataset = dataset
        self.offset = offset

    def __getitem__(self, idx):
        data, label = self.dataset[idx]
        # Offset the label to start from 0
        label = label - self.offset
        return data, label

    def __len__(self):
        return len(self.dataset)

# %%
class TransferLearningMNIST(object):
    def __init__(self, batch_size, input_dim=28*28, val_split=0.1, num_workers=4):
        self.input_dim = input_dim
        self.output_dim = 10
        self.val_split = val_split

        def filter_dataset(dataset, classes):
            indices = [i for i, t in enumerate(dataset.targets) if t in classes]
            return torch.utils.data.Subset(dataset, indices)

        mnist_train_data = datasets.MNIST(
            '../data',
            train=True,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_train_data = filter_dataset(mnist_train_data, list(range(5)))
        finetune_train_data = filter_dataset(mnist_train_data, list(range(5, 10)))

        pretrain_len = len(pretrain_train_data)
        finetune_len = len(finetune_train_data)
        pretrain_val_len = int(val_split * pretrain_len)
        finetune_val_len = int(val_split * finetune_len)
        SEED = 42
        pretrain_train_set, pretrain_val_set = torch.utils.data.random_split(
            pretrain_train_data, [pretrain_len - pretrain_val_len, pretrain_val_len], generator=torch.Generator().manual_seed(SEED))
        finetune_train_set, finetune_val_set = torch.utils.data.random_split(
            finetune_train_data, [finetune_len - finetune_val_len, finetune_val_len], generator=torch.Generator().manual_seed(SEED))

        self.pretrain_train_loader = torch.utils.data.DataLoader(pretrain_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.pretrain_val_loader = torch.utils.data.DataLoader(pretrain_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning datasets
        finetune_train_set = RelabeledSubset(finetune_train_set, 5)
        finetune_val_set = RelabeledSubset(finetune_val_set, 5)

        self.finetune_train_loader = torch.utils.data.DataLoader(finetune_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.finetune_val_loader = torch.utils.data.DataLoader(finetune_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        mnist_test_data = datasets.MNIST(
            '../data',
            train=False,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_test_data = filter_dataset(mnist_test_data, list(range(5)))
        finetune_test_data = filter_dataset(mnist_test_data, list(range(5, 10)))

        self.pretrain_test_loader = torch.utils.data.DataLoader(pretrain_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning test datasets
        finetune_test_data = RelabeledSubset(finetune_test_data, 5)
        self.finetune_test_loader = torch.utils.data.DataLoader(finetune_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        # Complete test loader contains all test examples.
        self.complete_test_loader = torch.utils.data.DataLoader(mnist_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
class TransferLearningMNISTWrapper:
    """
    This wrapper class provides a convenient way to switch between pretraining and fine-tuning phases.

    It allows for changing the phase and accordingly updating the data loaders (train, val, test)
    to either pretraining or fine-tuning sets.
    """
    def __init__(self, transferLearningMNISTObj, phase):
        """
        Initializes the TransferLearningMNISTWrapper object.

        Parameters:
        - transferLearningMNISTObj: An instance of the TransferLearningMNIST class.
        - phase: String indicating the current phase ("pretrain" or "finetune").
        """
        self.transferLearningMNISTObj = transferLearningMNISTObj
        self.phase = phase
        self.input_dim = self.transferLearningMNISTObj.input_dim
        self.output_dim = self.transferLearningMNISTObj.output_dim
        self.update_phase(phase)

    def update_phase(self, phase):
        """
        Updates the phase and the corresponding data loaders.

        Parameters:
        - phase: String indicating the desired phase ("pretrain" or "finetune").

        Throws:
        - ValueError: If the phase is neither "pretrain" nor "finetune".
        """
        self.phase = phase
        if phase == 'pretrain':
            self.train_loader = self.transferLearningMNISTObj.pretrain_train_loader
            self.val_loader = self.transferLearningMNISTObj.pretrain_val_loader
            self.test_loader = self.transferLearningMNISTObj.pretrain_test_loader
        elif phase == 'finetune':
            self.train_loader = self.transferLearningMNISTObj.finetune_train_loader
            self.val_loader = self.transferLearningMNISTObj.finetune_val_loader
            self.test_loader = self.transferLearningMNISTObj.finetune_test_loader
        else:
            raise ValueError('Phase must be either "pretrain" or "finetune".')

    def get_current_phase(self):
      return self.phase

# %%
class CustomCNN(nn.Module):
    def __init__(self, input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling=True):
        super(CustomCNN, self).__init__()

        # Initial number of input channels, assuming grayscale images
        in_channels = 1

        # Dynamically add convolutional and activation layers based on the specified depth
        for i in range(depth):
            # Create a convolutional layer and add it to the model
            setattr(self, f"conv{i}", nn.Conv2d(in_channels, num_channels, kernel_size=kernel_size, padding=1))

            # Create an activation layer (e.g., ReLU) and add it to the model
            setattr(self, f"act{i}", activation_function())

            # Update the input dimensions after convolution
            input_dim = (input_dim - kernel_size + 2 * 1) + 1

            # Optionally add pooling layers to reduce spatial dimensions
            if use_pooling and i % 2 == 1:
                setattr(self, f"pool{i}", nn.MaxPool2d(2))
                input_dim = input_dim // 2

            # Update the input channels for the next convolutional layer
            in_channels = num_channels

        # Compute the size of the flattened features for the fully connected layer
        flattened_size = in_channels * input_dim * input_dim

        # Add two fully connected layers for classification
        self.fc_1 = nn.Linear(flattened_size, hidden_dim_lin)
        self.fc_2 = nn.Linear(hidden_dim_lin, output_dim)

        # Add log softmax layer for multi-class classification output
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
      # Iterate over each module in the CustomCNN class
      for layer_name, layer in self.named_children():
          # Process the input tensor through convolutional and activation layers
          if "conv" in layer_name or "act" in layer_name:
              x = layer(x)
          # Process the input tensor through pooling layers if they exist
          elif "pool" in layer_name:
              x = layer(x)
          # If reached fully connected layers, break the loop
          elif isinstance(layer, nn.Linear):
              break

      # Flatten the tensor to fit the input shape of the fully connected layers
      x = x.view(x.size(0), -1)
        
      # Save the flattened size for reinitializing layers later
      self.flattened_size = x.shape[1]

      # Pass the tensor through the fully connected layers
      x = self.fc_1(x)
      x = self.fc_2(x)

      # Return log softmax activated output
      return self.logsoftmax(x)

# %%
def generate_cnn(input_dim, output_dim, depth, num_channels, hidden_dim_lin, kernel_size, activation_function=nn.ReLU, use_pooling=True):
    model = CustomCNN(input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling)
    return model

# %% [markdown]
# ***PRE-TRAINING***

# %%
batch_size = 128

dataloader = TransferLearningMNIST(batch_size)
dataloader_wrapped = TransferLearningMNISTWrapper(dataloader, phase = 'pretrain')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 155894691.78it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 46572738.88it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 35983908.95it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 8190253.12it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw

# %%
a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        break

# %%
params = {
      'depth': 2,
      'width': 1,
      'hidden_dim_lin': 128,
      'activation_function': nn.ReLU,
      'kernel_size': 5,
      'device': device,
      'lr': 0.001,
      'num_train': 20,
      'early_stop_patience': 6,
      'save_best': True,
      'save_checkpoints': True,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': False
    }

# Create DNN model
model = generate_cnn(input_dim = 28, output_dim = 10, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
model
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
# Train and evaluate
trainer = Trainer(model, dataloader_wrapped, params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Batch: 0, Loss: 2.3093087673187256
# Batch: 20, Loss: 2.1257894039154053
# Batch: 40, Loss: 1.585206389427185
# Batch: 60, Loss: 0.9015859365463257
# Batch: 80, Loss: 0.49514707922935486
# Batch: 100, Loss: 0.31713882088661194
# Batch: 120, Loss: 0.21635983884334564
# Batch: 140, Loss: 0.22622746229171753
# Batch: 160, Loss: 0.17020750045776367
# Batch: 180, Loss: 0.16841590404510498
# Batch: 200, Loss: 0.21021749079227448
#
# Average loss: 0.1562, Accuracy: 26389.0/27537 (96%)
#
#
# Average loss: 0.1862, Accuracy: 2912.0/3059 (95%)
#
# Epoch: 0 	Training Accuracy: 95.83%
# Validation Accuracy: 95.19%
# Batch: 0, Loss: 0.13679426908493042
# Batch: 20, Loss: 0.19767343997955322
# Batch: 40, Loss: 0.1861766278743744
# Batch: 60, Loss: 0.2116478830575943
# Batch: 80, Loss: 0.1074298545718193
# Batch: 100, Loss: 0.08496075868606567
# Batch: 120, Loss: 0.1913529932498932
# Batch: 140, Loss: 0.08937941491603851
# Batch: 160, Loss: 0.22256295382976532
# Batch: 180, Loss: 0.268809050321579
# Batch: 200, Loss: 0.15333999693393707
#
# Average loss: 0.1176, Accuracy: 26544.0/27537 (96%)
#
#
# Average loss: 0.1494, Accuracy: 2921.0/3059 (95%)
#
# Epoch: 1 	Training Accuracy: 96.39%
# Validation Accuracy: 95.49%
# Batch: 0, Loss: 0.17846855521202087
# Batch: 20, Loss: 0.07161926478147507
# Batch: 40, Loss: 0.06338882446289062
# Batch: 60, Loss: 0.10084047168493271
# Batch: 80, Loss: 0.1460830271244049
# Batch: 100, Loss: 0.07852058857679367
# Batch: 120, Loss: 0.04739784821867943
# Batch: 140, Loss: 0.06548777222633362
# Batch: 160, Loss: 0.15466520190238953
# Batch: 180, Loss: 0.10060934722423553
# Batch: 200, Loss: 0.08507466316223145
#
# Average loss: 0.0933, Accuracy: 26772.0/27537 (97%)
#
#
# Average loss: 0.1205, Accuracy: 2952.0/3059 (97%)
#
# Epoch: 2 	Training Accuracy: 97.22%
# Validation Accuracy: 96.50%
# Batch: 0, Loss: 0.061493512243032455
# Batch: 20, Loss: 0.07473484426736832
# Batch: 40, Loss: 0.1420014202594757
# Batch: 60, Loss: 0.08889994025230408
# Batch: 80, Loss: 0.09299106150865555
# Batch: 100, Loss: 0.05758226662874222
# Batch: 120, Loss: 0.12928560376167297
# Batch: 140, Loss: 0.095217265188694
# Batch: 160, Loss: 0.04430677369236946
# Batch: 180, Loss: 0.08008725196123123
# Batch: 200, Loss: 0.16137292981147766
#
# Average loss: 0.0850, Accuracy: 26853.0/27537 (98%)
#
#
# Average loss: 0.1122, Accuracy: 2956.0/3059 (97%)
#
# Epoch: 3 	Training Accuracy: 97.52%
# Validation Accuracy: 96.63%
# Batch: 0, Loss: 0.07552801817655563
# Batch: 20, Loss: 0.10367488116025925
# Batch: 40, Loss: 0.15836121141910553
# Batch: 60, Loss: 0.16706858575344086
# Batch: 80, Loss: 0.09965373575687408
# Batch: 100, Loss: 0.02863006480038166
# Batch: 120, Loss: 0.13088761270046234
# Batch: 140, Loss: 0.04067134112119675
# Batch: 160, Loss: 0.09411995857954025
# Batch: 180, Loss: 0.14107836782932281
# Batch: 200, Loss: 0.08979175984859467
#
# Average loss: 0.0882, Accuracy: 26830.0/27537 (97%)
#
#
# Average loss: 0.1163, Accuracy: 2952.0/3059 (97%)
#
# Epoch: 4 	Training Accuracy: 97.43%
# Validation Accuracy: 96.50%
# Batch: 0, Loss: 0.07287602126598358
# Batch: 20, Loss: 0.17622166872024536
# Batch: 40, Loss: 0.02256488800048828
# Batch: 60, Loss: 0.04471484199166298
# Batch: 80, Loss: 0.02476600371301174
# Batch: 100, Loss: 0.10715185105800629
# Batch: 120, Loss: 0.10782122611999512
# Batch: 140, Loss: 0.10995282977819443
# Batch: 160, Loss: 0.052461303770542145
# Batch: 180, Loss: 0.02350112609565258
# Batch: 200, Loss: 0.045030802488327026
#
# Average loss: 0.0739, Accuracy: 26930.0/27537 (98%)
#
#
# Average loss: 0.1017, Accuracy: 2961.0/3059 (97%)
#
# Epoch: 5 	Training Accuracy: 97.80%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.19859622418880463
# Batch: 20, Loss: 0.051251113414764404
# Batch: 40, Loss: 0.055583979934453964
# Batch: 60, Loss: 0.06566385179758072
# Batch: 80, Loss: 0.0532015785574913
# Batch: 100, Loss: 0.0657583475112915
# Batch: 120, Loss: 0.024994291365146637
# Batch: 140, Loss: 0.03690700605511665
# Batch: 160, Loss: 0.16860820353031158
# Batch: 180, Loss: 0.07382868975400925
# Batch: 200, Loss: 0.18368738889694214
#
# Average loss: 0.0732, Accuracy: 26904.0/27537 (98%)
#
#
# Average loss: 0.0945, Accuracy: 2963.0/3059 (97%)
#
# Epoch: 6 	Training Accuracy: 97.70%
# Validation Accuracy: 96.86%
# Batch: 0, Loss: 0.05189002677798271
# Batch: 20, Loss: 0.055884938687086105
# Batch: 40, Loss: 0.061464883387088776
# Batch: 60, Loss: 0.019322946667671204
# Batch: 80, Loss: 0.09596926718950272
# Batch: 100, Loss: 0.17627376317977905
# Batch: 120, Loss: 0.10755910724401474
# Batch: 140, Loss: 0.053966209292411804
# Batch: 160, Loss: 0.022262422367930412
# Batch: 180, Loss: 0.06080230325460434
# Batch: 200, Loss: 0.024327853694558144
#
# Average loss: 0.0734, Accuracy: 26917.0/27537 (98%)
#
#
# Average loss: 0.0942, Accuracy: 2963.0/3059 (97%)
#
# Epoch: 7 	Training Accuracy: 97.75%
# Validation Accuracy: 96.86%
# Batch: 0, Loss: 0.07448970526456833
# Batch: 20, Loss: 0.07500414550304413
# Batch: 40, Loss: 0.10480684787034988
# Batch: 60, Loss: 0.024812109768390656
# Batch: 80, Loss: 0.027017846703529358
# Batch: 100, Loss: 0.12373355031013489
# Batch: 120, Loss: 0.05621762573719025
# Batch: 140, Loss: 0.03227328509092331
# Batch: 160, Loss: 0.0571560338139534
# Batch: 180, Loss: 0.08733521401882172
# Batch: 200, Loss: 0.029516493901610374
#
# Average loss: 0.0665, Accuracy: 27001.0/27537 (98%)
#
#
# Average loss: 0.0891, Accuracy: 2974.0/3059 (97%)
#
# Epoch: 8 	Training Accuracy: 98.05%
# Validation Accuracy: 97.22%
# Batch: 0, Loss: 0.04520725831389427
# Batch: 20, Loss: 0.04205405339598656
# Batch: 40, Loss: 0.07012462615966797
# Batch: 60, Loss: 0.06016151234507561
# Batch: 80, Loss: 0.05127717927098274
# Batch: 100, Loss: 0.1734464168548584
# Batch: 120, Loss: 0.18707698583602905
# Batch: 140, Loss: 0.07865695655345917
# Batch: 160, Loss: 0.11576822400093079
# Batch: 180, Loss: 0.041650306433439255
# Batch: 200, Loss: 0.15178367495536804
#
# Average loss: 0.0655, Accuracy: 27001.0/27537 (98%)
#
#
# Average loss: 0.0938, Accuracy: 2966.0/3059 (97%)
#
# Epoch: 9 	Training Accuracy: 98.05%
# Validation Accuracy: 96.96%
# Batch: 0, Loss: 0.11799876391887665
# Batch: 20, Loss: 0.05798931047320366
# Batch: 40, Loss: 0.09132649004459381
# Batch: 60, Loss: 0.0760323703289032
# Batch: 80, Loss: 0.08635714650154114
# Batch: 100, Loss: 0.07302892208099365
# Batch: 120, Loss: 0.11872504651546478
# Batch: 140, Loss: 0.14742964506149292
# Batch: 160, Loss: 0.02125844731926918
# Batch: 180, Loss: 0.020581087097525597
# Batch: 200, Loss: 0.04558677598834038
#
# Average loss: 0.0673, Accuracy: 26995.0/27537 (98%)
#
#
# Average loss: 0.0890, Accuracy: 2972.0/3059 (97%)
#
# Epoch: 10 	Training Accuracy: 98.03%
# Validation Accuracy: 97.16%
# Batch: 0, Loss: 0.04241123050451279
# Batch: 20, Loss: 0.10373862087726593
# Batch: 40, Loss: 0.13998806476593018
# Batch: 60, Loss: 0.08582992851734161
# Batch: 80, Loss: 0.08517920225858688
# Batch: 100, Loss: 0.155828595161438
# Batch: 120, Loss: 0.03340849280357361
# Batch: 140, Loss: 0.035993970930576324
# Batch: 160, Loss: 0.10182414948940277
# Batch: 180, Loss: 0.0835605189204216
# Batch: 200, Loss: 0.05317820981144905
#
# Average loss: 0.0639, Accuracy: 27015.0/27537 (98%)
#
# Batch: 0, Loss: 0.03263075649738312
# Batch: 20, Loss: 0.09100959450006485
# Batch: 40, Loss: 0.16164082288742065
# Batch: 60, Loss: 0.09582304209470749
# Batch: 80, Loss: 0.073440782725811
# Batch: 100, Loss: 0.030962925404310226
# Batch: 120, Loss: 0.03934939578175545
# Batch: 140, Loss: 0.08553764224052429
# Batch: 160, Loss: 0.037221260368824005
# Batch: 180, Loss: 0.030704686418175697
# Batch: 200, Loss: 0.04814869537949562
#
# Average loss: 0.0629, Accuracy: 26986.0/27537 (98%)
#
#
# Average loss: 0.0864, Accuracy: 2974.0/3059 (97%)
#
# Epoch: 12 	Training Accuracy: 98.00%
# Validation Accuracy: 97.22%
# Batch: 0, Loss: 0.050869621336460114
# Batch: 20, Loss: 0.0305541530251503
# Batch: 40, Loss: 0.05687801539897919
# Batch: 60, Loss: 0.0355689711868763
# Batch: 80, Loss: 0.09065377712249756
# Batch: 100, Loss: 0.035198625177145004
# Batch: 120, Loss: 0.021580226719379425
# Batch: 140, Loss: 0.035356555134058
# Batch: 160, Loss: 0.06652453541755676
# Batch: 180, Loss: 0.10965517163276672
# Batch: 200, Loss: 0.07229625433683395
#
# Average loss: 0.0607, Accuracy: 27052.0/27537 (98%)
#
#
# Average loss: 0.0845, Accuracy: 2979.0/3059 (97%)
#
# Epoch: 13 	Training Accuracy: 98.24%
# Validation Accuracy: 97.38%
# Batch: 0, Loss: 0.051849327981472015
# Batch: 20, Loss: 0.02685488387942314
# Batch: 40, Loss: 0.08283144235610962
# Batch: 60, Loss: 0.06101764366030693
# Batch: 80, Loss: 0.08208108693361282
# Batch: 100, Loss: 0.0296662375330925
# Batch: 120, Loss: 0.07411059737205505
# Batch: 140, Loss: 0.05239617079496384
# Batch: 160, Loss: 0.07184598594903946
# Batch: 180, Loss: 0.03261255472898483
# Batch: 200, Loss: 0.1296328902244568
#
# Average loss: 0.0578, Accuracy: 27049.0/27537 (98%)
#
#
# Average loss: 0.0827, Accuracy: 2972.0/3059 (97%)
#
# Epoch: 14 	Training Accuracy: 98.23%
# Validation Accuracy: 97.16%
# Batch: 0, Loss: 0.0467643067240715
# Batch: 20, Loss: 0.09455715119838715
# Batch: 40, Loss: 0.18144658207893372
# Batch: 60, Loss: 0.12910974025726318
# Batch: 80, Loss: 0.017243102192878723
# Batch: 100, Loss: 0.12624609470367432
# Batch: 120, Loss: 0.0101392837241292
# Batch: 140, Loss: 0.05593721196055412
# Batch: 160, Loss: 0.032921917736530304
# Batch: 180, Loss: 0.07276427000761032
# Batch: 200, Loss: 0.14431968331336975
#
# Average loss: 0.0585, Accuracy: 27054.0/27537 (98%)
#
#
# Average loss: 0.0847, Accuracy: 2966.0/3059 (97%)
#
# Epoch: 15 	Training Accuracy: 98.25%
# Validation Accuracy: 96.96%
# Batch: 0, Loss: 0.023889858275651932
# Batch: 20, Loss: 0.057084500789642334
# Batch: 40, Loss: 0.032150737941265106
# Batch: 60, Loss: 0.06658510118722916
# Batch: 80, Loss: 0.04508766904473305
# Batch: 100, Loss: 0.02459392324090004
# Batch: 120, Loss: 0.07594811916351318
# Batch: 140, Loss: 0.10293029248714447
# Batch: 160, Loss: 0.04109003767371178
# Batch: 180, Loss: 0.05375789478421211
# Batch: 200, Loss: 0.015116011723876
#
# Average loss: 0.0588, Accuracy: 27039.0/27537 (98%)
#
#
# Average loss: 0.0828, Accuracy: 2971.0/3059 (97%)
#
# Epoch: 16 	Training Accuracy: 98.19%
# Validation Accuracy: 97.12%
# Batch: 0, Loss: 0.03295755386352539
# Batch: 20, Loss: 0.06227635219693184
# Batch: 40, Loss: 0.07909353822469711
# Batch: 60, Loss: 0.07270973175764084
# Batch: 80, Loss: 0.013834544457495213
# Batch: 100, Loss: 0.05009995773434639
# Batch: 120, Loss: 0.02610987052321434
# Batch: 140, Loss: 0.049210306257009506
# Batch: 160, Loss: 0.011664524674415588
# Batch: 180, Loss: 0.10950122028589249
# Batch: 200, Loss: 0.036462362855672836
#
# Average loss: 0.0572, Accuracy: 27053.0/27537 (98%)
#
#
# Average loss: 0.0807, Accuracy: 2972.0/3059 (97%)
#
# Epoch: 17 	Training Accuracy: 98.24%
# Validation Accuracy: 97.16%
# Batch: 0, Loss: 0.041837237775325775
# Batch: 20, Loss: 0.04247941076755524
# Batch: 40, Loss: 0.07267633080482483
# Batch: 60, Loss: 0.035113897174596786
# Batch: 80, Loss: 0.0280743520706892
# Batch: 100, Loss: 0.03473590314388275
# Batch: 120, Loss: 0.04568886756896973
# Batch: 140, Loss: 0.029601505026221275
# Batch: 160, Loss: 0.07631106674671173
# Batch: 180, Loss: 0.18919259309768677
# Batch: 200, Loss: 0.10336804389953613
#
# Average loss: 0.0614, Accuracy: 27008.0/27537 (98%)
#
#
# Average loss: 0.0866, Accuracy: 2974.0/3059 (97%)
#
# Epoch: 18 	Training Accuracy: 98.08%
# Validation Accuracy: 97.22%
# Batch: 0, Loss: 0.11379125714302063
# Batch: 20, Loss: 0.02539851702749729
# Batch: 40, Loss: 0.024117697030305862
# Batch: 60, Loss: 0.05112838000059128
# Batch: 80, Loss: 0.023500535637140274
# Batch: 100, Loss: 0.047702234238386154
# Batch: 120, Loss: 0.06973790377378464
# Batch: 140, Loss: 0.03903327137231827
# Batch: 160, Loss: 0.03236328810453415
# Batch: 180, Loss: 0.012360351160168648
# Batch: 200, Loss: 0.034688208252191544
#
# Average loss: 0.0549, Accuracy: 27080.0/27537 (98%)
#
#
# Average loss: 0.0786, Accuracy: 2975.0/3059 (97%)
#
# Epoch: 19 	Training Accuracy: 98.34%
# Validation Accuracy: 97.25%
# Early stopping invoked.
#
# Average loss: 0.0607, Accuracy: 27052.0/27537 (98%)
#
#
# Average loss: 0.0512, Accuracy: 5059.0/5139 (98%)
#
# Final Training Accuracy: 0.9824
# Final Test Accuracy: 0.9844

# %%
accuracy = eval(model, device, dataloader_wrapped.test_loader, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
# Out:
# Average loss: 0.0512, Accuracy: 5059.0/5139 (98%)

# %%
def effective_rank(singular_values):
    normalized_singular_values = singular_values / np.sum(singular_values)
    entropy = -np.sum(normalized_singular_values * np.log(normalized_singular_values))
    eff_rank = np.exp(entropy)
    return eff_rank

def plot_layer_effective_ranks(model, print_ranks=True):
    effective_ranks = []
    layer_names = []

    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            singular_values = np.linalg.svd(weight_matrix, compute_uv=False)
            eff_rank = effective_rank(singular_values)
            effective_ranks.append(eff_rank)
            layer_names.append(name)

    if print_ranks:
        for layer_name, eff_rank in zip(layer_names, effective_ranks):
            print(f'{layer_name}: {eff_rank:.4f}')

    # Plotting
    plt.figure(figsize=(15, 5))
    plt.bar(layer_names, effective_ranks, color='green')
    plt.xlabel('Layer')
    plt.ylabel('Effective Rank')
    plt.title('Effective Rank of Weight Matrices for Each Layer')
    plt.grid(True)

    y_max = np.max(effective_ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(effective_ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(0, int(y_max)+2, step=2))  # Set yticks

    plt.show()

# Example usage
plot_layer_effective_ranks(model)  # Note: You'll need to define or load 'model' before calling this function
# Out:
# conv0.weight: 3.5123
# conv1.weight: 4.0340
# fc_1.weight: 74.8117
# fc_2.weight: 8.7122

# %% [markdown]
# ----

# %% [markdown]
# # Finetuning experiments

# %%
dataloader_wrapped.update_phase('finetune')

a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        print('-------------')
        break
# Out:
# -------------

# %% [markdown]
# ## Baseline model: end2end with the same architecture as the preatining model

# %%
# 2. Create a new model and copy weights from the original model, then adjust the final layer
print("Current dataloader phase: ", dataloader_wrapped.get_current_phase())

model_finetuning_baseline = generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
model_finetuning_baseline.to(device)

# dataloader_wrapped.update_phase('finetune')
# Train and evaluate the new model on the new data
# train_acc_new, test_acc_new, model_finetuning_baseline, _,_ = compute_training_acc_epochs_cnn(model_finetuning_baseline, dataloader_wrapped, params, debug=True)

trainer = Trainer(model, dataloader_wrapped, params)
train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
print(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")
# Out:
# Current dataloader phase:  finetune
# Batch: 0, Loss: 4.773896217346191
# Batch: 20, Loss: 1.5008550882339478
# Batch: 40, Loss: 0.9438675045967102
# Batch: 60, Loss: 0.6265371441841125
# Batch: 80, Loss: 0.6172699332237244
# Batch: 100, Loss: 0.5302684903144836
# Batch: 120, Loss: 0.5171888470649719
# Batch: 140, Loss: 0.36827340722084045
# Batch: 160, Loss: 0.2759491205215454
# Batch: 180, Loss: 0.3228133022785187
# Batch: 200, Loss: 0.14829464256763458
#
# Average loss: 0.2691, Accuracy: 24188.0/26464 (91%)
#
#
# Average loss: 0.2898, Accuracy: 2671.0/2940 (91%)
#
# Epoch: 0 	Training Accuracy: 91.40%
# Validation Accuracy: 90.85%
# Batch: 0, Loss: 0.31559517979621887
# Batch: 20, Loss: 0.2782391607761383
# Batch: 40, Loss: 0.1992025226354599
# Batch: 60, Loss: 0.21339298784732819
# Batch: 80, Loss: 0.2348383069038391
# Batch: 100, Loss: 0.13507692515850067
# Batch: 120, Loss: 0.14524613320827484
# Batch: 140, Loss: 0.3818294405937195
# Batch: 160, Loss: 0.1993166208267212
# Batch: 180, Loss: 0.24308833479881287
# Batch: 200, Loss: 0.16150841116905212
#
# Average loss: 0.1744, Accuracy: 25006.0/26464 (94%)
#
#
# Average loss: 0.1971, Accuracy: 2766.0/2940 (94%)
#
# Epoch: 1 	Training Accuracy: 94.49%
# Validation Accuracy: 94.08%
# Batch: 0, Loss: 0.26169416308403015
# Batch: 20, Loss: 0.13032780587673187
# Batch: 40, Loss: 0.3236261010169983
# Batch: 60, Loss: 0.09677983075380325
# Batch: 80, Loss: 0.227134108543396
# Batch: 100, Loss: 0.16668495535850525
# Batch: 120, Loss: 0.15168242156505585
# Batch: 140, Loss: 0.21074353158473969
# Batch: 160, Loss: 0.11309721320867538
# Batch: 180, Loss: 0.1561465859413147
# Batch: 200, Loss: 0.1784822791814804
#
# Average loss: 0.1418, Accuracy: 25282.0/26464 (96%)
#
#
# Average loss: 0.1636, Accuracy: 2803.0/2940 (95%)
#
# Epoch: 2 	Training Accuracy: 95.53%
# Validation Accuracy: 95.34%
# Batch: 0, Loss: 0.13527701795101166
# Batch: 20, Loss: 0.1729796975851059
# Batch: 40, Loss: 0.09467526525259018
# Batch: 60, Loss: 0.13501495122909546
# Batch: 80, Loss: 0.08551710844039917
# Batch: 100, Loss: 0.0901593342423439
# Batch: 120, Loss: 0.12451022118330002
# Batch: 140, Loss: 0.14369402825832367
# Batch: 160, Loss: 0.14854028820991516
# Batch: 180, Loss: 0.0939900279045105
# Batch: 200, Loss: 0.0673137679696083
#
# Average loss: 0.1254, Accuracy: 25395.0/26464 (96%)
#
#
# Average loss: 0.1477, Accuracy: 2815.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 95.96%
# Validation Accuracy: 95.75%
# Batch: 0, Loss: 0.24850833415985107
# Batch: 20, Loss: 0.1732948273420334
# Batch: 40, Loss: 0.08201964944601059
# Batch: 60, Loss: 0.04587868973612785
# Batch: 80, Loss: 0.14941973984241486
# Batch: 100, Loss: 0.10294719785451889
# Batch: 120, Loss: 0.04934243485331535
# Batch: 140, Loss: 0.15932543575763702
# Batch: 160, Loss: 0.190892294049263
# Batch: 180, Loss: 0.14745838940143585
# Batch: 200, Loss: 0.14238566160202026
#
# Average loss: 0.1247, Accuracy: 25452.0/26464 (96%)
#
#
# Average loss: 0.1490, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 96.18%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.20065367221832275
# Batch: 20, Loss: 0.12395723909139633
# Batch: 40, Loss: 0.18616466224193573
# Batch: 60, Loss: 0.12173830717802048
# Batch: 80, Loss: 0.08283701539039612
# Batch: 100, Loss: 0.11475473642349243
# Batch: 120, Loss: 0.06346209347248077
# Batch: 140, Loss: 0.07293973863124847
# Batch: 160, Loss: 0.09199350327253342
# Batch: 180, Loss: 0.07620056718587875
# Batch: 200, Loss: 0.0586840957403183
#
# Average loss: 0.1107, Accuracy: 25542.0/26464 (97%)
#
#
# Average loss: 0.1313, Accuracy: 2835.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 96.52%
# Validation Accuracy: 96.43%
# Batch: 0, Loss: 0.06621710956096649
# Batch: 20, Loss: 0.1920640468597412
# Batch: 40, Loss: 0.07887040823698044
# Batch: 60, Loss: 0.1192447692155838
# Batch: 80, Loss: 0.20553700625896454
# Batch: 100, Loss: 0.06464745849370956
# Batch: 120, Loss: 0.10643075406551361
# Batch: 140, Loss: 0.10173054039478302
# Batch: 160, Loss: 0.14533106982707977
# Batch: 180, Loss: 0.08675277233123779
# Batch: 200, Loss: 0.07351915538311005
#
# Average loss: 0.1097, Accuracy: 25534.0/26464 (96%)
#
#
# Average loss: 0.1327, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 96.49%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.09192729741334915
# Batch: 20, Loss: 0.14894258975982666
# Batch: 40, Loss: 0.08716103434562683
# Batch: 60, Loss: 0.18347373604774475
# Batch: 80, Loss: 0.09988603740930557
# Batch: 100, Loss: 0.040319327265024185
# Batch: 120, Loss: 0.11602644622325897
# Batch: 140, Loss: 0.06969107687473297
# Batch: 160, Loss: 0.15566937625408173
# Batch: 180, Loss: 0.14137807488441467
# Batch: 200, Loss: 0.03300164267420769
#
# Average loss: 0.1029, Accuracy: 25608.0/26464 (97%)
#
#
# Average loss: 0.1261, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 96.77%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.061346959322690964
# Batch: 20, Loss: 0.06866399198770523
# Batch: 40, Loss: 0.10567750781774521
# Batch: 60, Loss: 0.10070671141147614
# Batch: 80, Loss: 0.21591752767562866
# Batch: 100, Loss: 0.09193892031908035
# Batch: 120, Loss: 0.07122538983821869
# Batch: 140, Loss: 0.09594671428203583
# Batch: 160, Loss: 0.06112847477197647
# Batch: 180, Loss: 0.09229467809200287
# Batch: 200, Loss: 0.09151900559663773
#
# Average loss: 0.0977, Accuracy: 25660.0/26464 (97%)
#
#
# Average loss: 0.1234, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 8 	Training Accuracy: 96.96%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.12571650743484497
# Batch: 20, Loss: 0.08458302915096283
# Batch: 40, Loss: 0.09239552915096283
# Batch: 60, Loss: 0.10082946717739105
# Batch: 80, Loss: 0.17835134267807007
# Batch: 100, Loss: 0.07716640830039978
# Batch: 120, Loss: 0.10109703242778778
# Batch: 140, Loss: 0.05061858519911766
# Batch: 160, Loss: 0.1306036114692688
# Batch: 180, Loss: 0.112357959151268
# Batch: 200, Loss: 0.03233599290251732
#
# Average loss: 0.0994, Accuracy: 25659.0/26464 (97%)
#
#
# Average loss: 0.1256, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 9 	Training Accuracy: 96.96%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.05051155760884285
# Batch: 20, Loss: 0.1268738955259323
# Batch: 40, Loss: 0.13401025533676147
# Batch: 60, Loss: 0.06109532713890076
# Batch: 80, Loss: 0.10521493852138519
# Batch: 100, Loss: 0.0703640729188919
# Batch: 120, Loss: 0.09041880816221237
# Batch: 140, Loss: 0.044426318258047104
# Batch: 160, Loss: 0.15867500007152557
# Batch: 180, Loss: 0.08554253727197647
# Batch: 200, Loss: 0.1456359475851059
#
# Average loss: 0.0928, Accuracy: 25685.0/26464 (97%)
#
#
# Average loss: 0.1146, Accuracy: 2844.0/2940 (97%)
#
# Epoch: 10 	Training Accuracy: 97.06%
# Validation Accuracy: 96.73%
# Batch: 0, Loss: 0.08302770555019379
# Batch: 20, Loss: 0.13968494534492493
# Batch: 40, Loss: 0.07569148391485214
# Batch: 60, Loss: 0.09481263160705566
# Batch: 80, Loss: 0.028056273236870766
# Batch: 100, Loss: 0.07345519959926605
# Batch: 120, Loss: 0.08075077086687088
# Batch: 140, Loss: 0.06005971506237984
# Batch: 160, Loss: 0.20102517306804657
# Batch: 180, Loss: 0.09516177326440811
# Batch: 200, Loss: 0.1480512022972107
#
# Average loss: 0.0948, Accuracy: 25686.0/26464 (97%)
#
#
# Average loss: 0.1205, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 11 	Training Accuracy: 97.06%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.11951175332069397
# Batch: 20, Loss: 0.06582016497850418
# Batch: 40, Loss: 0.056776247918605804
# Batch: 60, Loss: 0.06474831700325012
# Batch: 80, Loss: 0.2045442759990692
# Batch: 100, Loss: 0.0890272855758667
# Batch: 120, Loss: 0.08818674087524414
# Batch: 140, Loss: 0.09661060571670532
# Batch: 160, Loss: 0.04465363174676895
# Batch: 180, Loss: 0.0687953308224678
# Batch: 200, Loss: 0.09971489012241364
#
# Average loss: 0.0907, Accuracy: 25705.0/26464 (97%)
#
#
# Average loss: 0.1178, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 12 	Training Accuracy: 97.13%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.06050876900553703
# Batch: 20, Loss: 0.03670269995927811
# Batch: 40, Loss: 0.08310399949550629
# Batch: 60, Loss: 0.04690713435411453
# Batch: 80, Loss: 0.10703101009130478
# Batch: 100, Loss: 0.05647793412208557
# Batch: 120, Loss: 0.08500176668167114
# Batch: 140, Loss: 0.08319856226444244
# Batch: 160, Loss: 0.026179702952504158
# Batch: 180, Loss: 0.08575869351625443
# Batch: 200, Loss: 0.15412099659442902
#
# Average loss: 0.0896, Accuracy: 25730.0/26464 (97%)
#
#
# Average loss: 0.1126, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 13 	Training Accuracy: 97.23%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.033639032393693924
# Batch: 20, Loss: 0.0586128793656826
# Batch: 40, Loss: 0.05332105606794357
# Batch: 60, Loss: 0.03028564527630806
# Batch: 80, Loss: 0.08253493160009384
# Batch: 100, Loss: 0.09019628167152405
# Batch: 120, Loss: 0.08141857385635376
# Batch: 140, Loss: 0.05571083724498749
# Batch: 160, Loss: 0.11388351768255234
# Batch: 180, Loss: 0.05873316526412964
# Batch: 200, Loss: 0.16698434948921204
#
# Average loss: 0.0900, Accuracy: 25689.0/26464 (97%)
#
#
# Average loss: 0.1117, Accuracy: 2840.0/2940 (97%)
#
# Epoch: 14 	Training Accuracy: 97.07%
# Validation Accuracy: 96.60%
# Early stopping invoked.
#
# Average loss: 0.0977, Accuracy: 25660.0/26464 (97%)
#
#
# Average loss: 0.0933, Accuracy: 4712.0/4861 (97%)
#
# Final Training Accuracy (New Data): 0.9696
# Final Test Accuracy (New Data): 0.9693

# %%
plot_layer_effective_ranks(model_finetuning_baseline)
# Out:
# conv0.weight: 4.3392
# conv1.weight: 4.5006
# fc_1.weight: 107.8648
# fc_2.weight: 4.9857

# %% [markdown]
# ***WITH BALANCED CLASSES***

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01]
percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]

seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test = {}
results_train = {}
best_models = {}
data_loaders = {}
epochs_taken = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Training with different data percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []

    for seed in tqdm(seed_set, desc=f'Training for data percentage: {perc}', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")
        
        model_new =  generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
        model_new.to(device)

        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)

        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        # Train and evaluate the new model on the new data
        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        # Add tqdm write method to prevent progress bar overlap
        tqdm.write(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
        tqdm.write(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test[perc] = test_accuracies
    results_train[perc] = train_accuracies
    epochs_taken[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Training with different data percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Training for data percentage: 0.01:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 71 =========================
# Batch: 0, Loss: 1.6116575002670288
#
# Average loss: 1.6099, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6110, Accuracy: 550.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6070932149887085
#
# Average loss: 1.6099, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.6106, Accuracy: 639.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 22.31%
# Validation Accuracy: 21.73%
# Batch: 0, Loss: 1.608989953994751
#
# Average loss: 1.6099, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6102, Accuracy: 599.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6097266674041748
#
# Average loss: 1.6096, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6098, Accuracy: 599.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6088855266571045
#
# Average loss: 1.6091, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.6094, Accuracy: 601.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.38%
# Validation Accuracy: 20.44%
# Batch: 0, Loss: 1.6077256202697754
#
# Average loss: 1.6081, Accuracy: 61.0/260 (23%)
#
#
# Average loss: 1.6087, Accuracy: 622.0/2940 (21%)
#
# Epoch: 5 	Training Accuracy: 23.46%
# Validation Accuracy: 21.16%
# Batch: 0, Loss: 1.6089632511138916
#
# Average loss: 1.6065, Accuracy: 78.0/260 (30%)
#
#
# Average loss: 1.6075, Accuracy: 770.0/2940 (26%)
#
# Epoch: 6 	Training Accuracy: 30.00%
# Validation Accuracy: 26.19%
# Batch: 0, Loss: 1.606827735900879
#
# Average loss: 1.6037, Accuracy: 100.0/260 (38%)
#
#
# Average loss: 1.6050, Accuracy: 1107.0/2940 (38%)
#
# Epoch: 7 	Training Accuracy: 38.46%
# Validation Accuracy: 37.65%
# Batch: 0, Loss: 1.5969130992889404
#
# Average loss: 1.5984, Accuracy: 100.0/260 (38%)
#
#
# Average loss: 1.6003, Accuracy: 1123.0/2940 (38%)
#
# Epoch: 8 	Training Accuracy: 38.46%
# Validation Accuracy: 38.20%
# Batch: 0, Loss: 1.6004343032836914
#
# Average loss: 1.5896, Accuracy: 82.0/260 (32%)
#
#
# Average loss: 1.5926, Accuracy: 921.0/2940 (31%)
#
# Epoch: 9 	Training Accuracy: 31.54%
# Validation Accuracy: 31.33%
# Batch: 0, Loss: 1.5859243869781494
#
# Average loss: 1.5763, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.5809, Accuracy: 819.0/2940 (28%)
#
# Epoch: 10 	Training Accuracy: 28.46%
# Validation Accuracy: 27.86%
# Batch: 0, Loss: 1.573325276374817
#
# Average loss: 1.5590, Accuracy: 81.0/260 (31%)
#
#
# Average loss: 1.5660, Accuracy: 841.0/2940 (29%)
#
# Epoch: 11 	Training Accuracy: 31.15%
# Validation Accuracy: 28.61%
# Batch: 0, Loss: 1.5546170473098755
#
# Average loss: 1.5381, Accuracy: 76.0/260 (29%)
#
#
# Average loss: 1.5492, Accuracy: 791.0/2940 (27%)
#
# Epoch: 12 	Training Accuracy: 29.23%
# Validation Accuracy: 26.90%
# Batch: 0, Loss: 1.544529676437378
#
# Average loss: 1.5139, Accuracy: 99.0/260 (38%)
#
#
# Average loss: 1.5283, Accuracy: 935.0/2940 (32%)
#
# Epoch: 13 	Training Accuracy: 38.08%
# Validation Accuracy: 31.80%
# Batch: 0, Loss: 1.514512062072754
#
# Average loss: 1.4804, Accuracy: 117.0/260 (45%)
#
#
# Average loss: 1.4953, Accuracy: 1164.0/2940 (40%)
#
# Epoch: 14 	Training Accuracy: 45.00%
# Validation Accuracy: 39.59%
# Batch: 0, Loss: 1.492220401763916
#
# Average loss: 1.4411, Accuracy: 144.0/260 (55%)
#
#
# Average loss: 1.4571, Accuracy: 1504.0/2940 (51%)
#
# Epoch: 15 	Training Accuracy: 55.38%
# Validation Accuracy: 51.16%
# Batch: 0, Loss: 1.4447349309921265
#
# Average loss: 1.3954, Accuracy: 155.0/260 (60%)
#
#
# Average loss: 1.4151, Accuracy: 1641.0/2940 (56%)
#
# Epoch: 16 	Training Accuracy: 59.62%
# Validation Accuracy: 55.82%
# Batch: 0, Loss: 1.4028289318084717
#
# Average loss: 1.3442, Accuracy: 150.0/260 (58%)
#
#
# Average loss: 1.3696, Accuracy: 1582.0/2940 (54%)
#
# Epoch: 17 	Training Accuracy: 57.69%
# Validation Accuracy: 53.81%
# Batch: 0, Loss: 1.3472508192062378
#
# Average loss: 1.2862, Accuracy: 138.0/260 (53%)
#
#
# Average loss: 1.3168, Accuracy: 1508.0/2940 (51%)
#
# Epoch: 18 	Training Accuracy: 53.08%
# Validation Accuracy: 51.29%
# Batch: 0, Loss: 1.3095015287399292
#
# Average loss: 1.2026, Accuracy: 169.0/260 (65%)
#
#
# Average loss: 1.2354, Accuracy: 1795.0/2940 (61%)
#
# Epoch: 19 	Training Accuracy: 65.00%
# Validation Accuracy: 61.05%
#
# Average loss: 1.2026, Accuracy: 169.0/260 (65%)
#
#
# Average loss: 1.2364, Accuracy: 3000.0/4861 (62%)
#
# Final Training Accuracy (New Data): 0.6500
# Final Test Accuracy (New Data): 0.6172
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 47 =========================
# Batch: 0, Loss: 1.6303492784500122
#
# Average loss: 1.6088, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6086, Accuracy: 551.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.611464023590088
#
# Average loss: 1.6118, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6115, Accuracy: 551.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6030243635177612
#
# Average loss: 1.6085, Accuracy: 59.0/260 (23%)
#
#
# Average loss: 1.6063, Accuracy: 632.0/2940 (21%)
#
# Epoch: 2 	Training Accuracy: 22.69%
# Validation Accuracy: 21.50%
# Batch: 0, Loss: 1.6043633222579956
#
# Average loss: 1.6041, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6016, Accuracy: 655.0/2940 (22%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6031849384307861
#
# Average loss: 1.6033, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6028, Accuracy: 585.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.599137306213379
#
# Average loss: 1.6037, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6034, Accuracy: 585.0/2940 (20%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.597890853881836
#
# Average loss: 1.6007, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6019, Accuracy: 585.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.5917052030563354
#
# Average loss: 1.5993, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6036, Accuracy: 585.0/2940 (20%)
#
# Epoch: 7 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.5967708826065063
#
# Average loss: 1.6027, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6098, Accuracy: 585.0/2940 (20%)
#
# Epoch: 8 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6144649982452393
#
# Average loss: 1.6066, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6169, Accuracy: 585.0/2940 (20%)
#
# Epoch: 9 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Early stopping invoked.
#
# Average loss: 1.6041, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6034, Accuracy: 1028.0/4861 (21%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.2115
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 0 =========================
# Batch: 0, Loss: 1.6135847568511963
#
# Average loss: 1.6027, Accuracy: 82.0/260 (32%)
#
#
# Average loss: 1.6045, Accuracy: 910.0/2940 (31%)
#
# Epoch: 0 	Training Accuracy: 31.54%
# Validation Accuracy: 30.95%
# Batch: 0, Loss: 1.6023187637329102
#
# Average loss: 1.5967, Accuracy: 76.0/260 (29%)
#
#
# Average loss: 1.5996, Accuracy: 837.0/2940 (28%)
#
# Epoch: 1 	Training Accuracy: 29.23%
# Validation Accuracy: 28.47%
# Batch: 0, Loss: 1.600473403930664
#
# Average loss: 1.5899, Accuracy: 67.0/260 (26%)
#
#
# Average loss: 1.5945, Accuracy: 731.0/2940 (25%)
#
# Epoch: 2 	Training Accuracy: 25.77%
# Validation Accuracy: 24.86%
# Batch: 0, Loss: 1.5827722549438477
#
# Average loss: 1.5821, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.5877, Accuracy: 551.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 20.38%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.5812872648239136
#
# Average loss: 1.5731, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5793, Accuracy: 551.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.5716984272003174
#
# Average loss: 1.5604, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5672, Accuracy: 551.0/2940 (19%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.561964511871338
#
# Average loss: 1.5460, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5541, Accuracy: 551.0/2940 (19%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Early stopping invoked.
#
# Average loss: 1.6027, Accuracy: 82.0/260 (32%)
#
#
# Average loss: 1.6031, Accuracy: 1606.0/4861 (33%)
#
# Final Training Accuracy (New Data): 0.3154
# Final Test Accuracy (New Data): 0.3304
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 51 =========================
# Batch: 0, Loss: 1.6052663326263428
#
# Average loss: 1.6074, Accuracy: 76.0/260 (29%)
#
#
# Average loss: 1.6083, Accuracy: 851.0/2940 (29%)
#
# Epoch: 0 	Training Accuracy: 29.23%
# Validation Accuracy: 28.95%
# Batch: 0, Loss: 1.601563811302185
#
# Average loss: 1.6007, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.6024, Accuracy: 987.0/2940 (34%)
#
# Epoch: 1 	Training Accuracy: 35.00%
# Validation Accuracy: 33.57%
# Batch: 0, Loss: 1.6043535470962524
#
# Average loss: 1.5892, Accuracy: 98.0/260 (38%)
#
#
# Average loss: 1.5923, Accuracy: 1060.0/2940 (36%)
#
# Epoch: 2 	Training Accuracy: 37.69%
# Validation Accuracy: 36.05%
# Batch: 0, Loss: 1.5887134075164795
#
# Average loss: 1.5711, Accuracy: 111.0/260 (43%)
#
#
# Average loss: 1.5765, Accuracy: 1149.0/2940 (39%)
#
# Epoch: 3 	Training Accuracy: 42.69%
# Validation Accuracy: 39.08%
# Batch: 0, Loss: 1.569501519203186
#
# Average loss: 1.5505, Accuracy: 151.0/260 (58%)
#
#
# Average loss: 1.5582, Accuracy: 1558.0/2940 (53%)
#
# Epoch: 4 	Training Accuracy: 58.08%
# Validation Accuracy: 52.99%
# Batch: 0, Loss: 1.5548914670944214
#
# Average loss: 1.5272, Accuracy: 193.0/260 (74%)
#
#
# Average loss: 1.5380, Accuracy: 1948.0/2940 (66%)
#
# Epoch: 5 	Training Accuracy: 74.23%
# Validation Accuracy: 66.26%
# Batch: 0, Loss: 1.5303493738174438
#
# Average loss: 1.4977, Accuracy: 177.0/260 (68%)
#
#
# Average loss: 1.5102, Accuracy: 1963.0/2940 (67%)
#
# Epoch: 6 	Training Accuracy: 68.08%
# Validation Accuracy: 66.77%
# Batch: 0, Loss: 1.5004159212112427
#
# Average loss: 1.4610, Accuracy: 178.0/260 (68%)
#
#
# Average loss: 1.4729, Accuracy: 1971.0/2940 (67%)
#
# Epoch: 7 	Training Accuracy: 68.46%
# Validation Accuracy: 67.04%
# Batch: 0, Loss: 1.4628032445907593
#
# Average loss: 1.4161, Accuracy: 179.0/260 (69%)
#
#
# Average loss: 1.4279, Accuracy: 1908.0/2940 (65%)
#
# Epoch: 8 	Training Accuracy: 68.85%
# Validation Accuracy: 64.90%
# Batch: 0, Loss: 1.4080910682678223
#
# Average loss: 1.3608, Accuracy: 188.0/260 (72%)
#
#
# Average loss: 1.3735, Accuracy: 1962.0/2940 (67%)
#
# Epoch: 9 	Training Accuracy: 72.31%
# Validation Accuracy: 66.73%
# Batch: 0, Loss: 1.3595552444458008
#
# Average loss: 1.2974, Accuracy: 183.0/260 (70%)
#
#
# Average loss: 1.3105, Accuracy: 1893.0/2940 (64%)
#
# Epoch: 10 	Training Accuracy: 70.38%
# Validation Accuracy: 64.39%
# Batch: 0, Loss: 1.313387155532837
#
# Average loss: 1.2180, Accuracy: 190.0/260 (73%)
#
#
# Average loss: 1.2340, Accuracy: 1999.0/2940 (68%)
#
# Epoch: 11 	Training Accuracy: 73.08%
# Validation Accuracy: 67.99%
# Batch: 0, Loss: 1.208033561706543
#
# Average loss: 1.1234, Accuracy: 225.0/260 (87%)
#
#
# Average loss: 1.1459, Accuracy: 2316.0/2940 (79%)
#
# Epoch: 12 	Training Accuracy: 86.54%
# Validation Accuracy: 78.78%
# Batch: 0, Loss: 1.1412690877914429
#
# Average loss: 1.0352, Accuracy: 232.0/260 (89%)
#
#
# Average loss: 1.0651, Accuracy: 2474.0/2940 (84%)
#
# Epoch: 13 	Training Accuracy: 89.23%
# Validation Accuracy: 84.15%
# Batch: 0, Loss: 1.0442527532577515
#
# Average loss: 0.9497, Accuracy: 226.0/260 (87%)
#
#
# Average loss: 0.9820, Accuracy: 2426.0/2940 (83%)
#
# Epoch: 14 	Training Accuracy: 86.92%
# Validation Accuracy: 82.52%
# Batch: 0, Loss: 0.9563674926757812
#
# Average loss: 0.8562, Accuracy: 216.0/260 (83%)
#
#
# Average loss: 0.8914, Accuracy: 2292.0/2940 (78%)
#
# Epoch: 15 	Training Accuracy: 83.08%
# Validation Accuracy: 77.96%
# Batch: 0, Loss: 0.8952038288116455
#
# Average loss: 0.7656, Accuracy: 218.0/260 (84%)
#
#
# Average loss: 0.8052, Accuracy: 2270.0/2940 (77%)
#
# Epoch: 16 	Training Accuracy: 83.85%
# Validation Accuracy: 77.21%
# Batch: 0, Loss: 0.7744672298431396
#
# Average loss: 0.6662, Accuracy: 229.0/260 (88%)
#
#
# Average loss: 0.7120, Accuracy: 2436.0/2940 (83%)
#
# Epoch: 17 	Training Accuracy: 88.08%
# Validation Accuracy: 82.86%
# Batch: 0, Loss: 0.631499171257019
#
# Average loss: 0.5848, Accuracy: 232.0/260 (89%)
#
#
# Average loss: 0.6366, Accuracy: 2468.0/2940 (84%)
#
# Epoch: 18 	Training Accuracy: 89.23%
# Validation Accuracy: 83.95%
# Batch: 0, Loss: 0.5215432643890381
#
# Average loss: 0.5301, Accuracy: 228.0/260 (88%)
#
#
# Average loss: 0.5884, Accuracy: 2449.0/2940 (83%)
#
# Epoch: 19 	Training Accuracy: 87.69%
# Validation Accuracy: 83.30%
# Early stopping invoked.
#
# Average loss: 1.0352, Accuracy: 232.0/260 (89%)
#
#
# Average loss: 1.0564, Accuracy: 4093.0/4861 (84%)
#
# Final Training Accuracy (New Data): 0.8923
# Final Test Accuracy (New Data): 0.8420
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 84 =========================
# Batch: 0, Loss: 1.611106038093567
#
# Average loss: 1.6096, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6108, Accuracy: 550.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6107182502746582
#
# Average loss: 1.6096, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6104, Accuracy: 585.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6076650619506836
#
# Average loss: 1.6096, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6100, Accuracy: 585.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6107120513916016
#
# Average loss: 1.6095, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6096, Accuracy: 585.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6094666719436646
#
# Average loss: 1.6096, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6094, Accuracy: 585.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6090880632400513
#
# Average loss: 1.6097, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6094, Accuracy: 585.0/2940 (20%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6114922761917114
#
# Average loss: 1.6097, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6093, Accuracy: 585.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6088299751281738
#
# Average loss: 1.6098, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6093, Accuracy: 585.0/2940 (20%)
#
# Epoch: 7 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Early stopping invoked.
#
# Average loss: 1.6096, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6098, Accuracy: 1009.0/4861 (21%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.2076
# Training for data percentage: 0.03:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 89 =========================
# Batch: 0, Loss: 1.6187553405761719
#
# Average loss: 1.5894, Accuracy: 185.0/790 (23%)
#
#
# Average loss: 1.5903, Accuracy: 674.0/2940 (23%)
#
# Epoch: 0 	Training Accuracy: 23.42%
# Validation Accuracy: 22.93%
# Batch: 0, Loss: 1.5934116840362549
#
# Average loss: 1.5631, Accuracy: 415.0/790 (53%)
#
#
# Average loss: 1.5655, Accuracy: 1434.0/2940 (49%)
#
# Epoch: 1 	Training Accuracy: 52.53%
# Validation Accuracy: 48.78%
# Batch: 0, Loss: 1.558828353881836
#
# Average loss: 1.5249, Accuracy: 349.0/790 (44%)
#
#
# Average loss: 1.5274, Accuracy: 1236.0/2940 (42%)
#
# Epoch: 2 	Training Accuracy: 44.18%
# Validation Accuracy: 42.04%
# Batch: 0, Loss: 1.5193806886672974
#
# Average loss: 1.4544, Accuracy: 515.0/790 (65%)
#
#
# Average loss: 1.4565, Accuracy: 1899.0/2940 (65%)
#
# Epoch: 3 	Training Accuracy: 65.19%
# Validation Accuracy: 64.59%
# Batch: 0, Loss: 1.451431393623352
#
# Average loss: 1.3472, Accuracy: 613.0/790 (78%)
#
#
# Average loss: 1.3481, Accuracy: 2253.0/2940 (77%)
#
# Epoch: 4 	Training Accuracy: 77.59%
# Validation Accuracy: 76.63%
# Batch: 0, Loss: 1.35576593875885
#
# Average loss: 1.1887, Accuracy: 617.0/790 (78%)
#
#
# Average loss: 1.1885, Accuracy: 2273.0/2940 (77%)
#
# Epoch: 5 	Training Accuracy: 78.10%
# Validation Accuracy: 77.31%
# Batch: 0, Loss: 1.159984827041626
#
# Average loss: 0.9994, Accuracy: 620.0/790 (78%)
#
#
# Average loss: 1.0002, Accuracy: 2244.0/2940 (76%)
#
# Epoch: 6 	Training Accuracy: 78.48%
# Validation Accuracy: 76.33%
# Batch: 0, Loss: 1.0527126789093018
#
# Average loss: 0.8090, Accuracy: 641.0/790 (81%)
#
#
# Average loss: 0.8174, Accuracy: 2343.0/2940 (80%)
#
# Epoch: 7 	Training Accuracy: 81.14%
# Validation Accuracy: 79.69%
# Batch: 0, Loss: 0.8152502179145813
#
# Average loss: 0.6458, Accuracy: 653.0/790 (83%)
#
#
# Average loss: 0.6665, Accuracy: 2399.0/2940 (82%)
#
# Epoch: 8 	Training Accuracy: 82.66%
# Validation Accuracy: 81.60%
# Batch: 0, Loss: 0.6637009382247925
#
# Average loss: 0.5221, Accuracy: 684.0/790 (87%)
#
#
# Average loss: 0.5523, Accuracy: 2457.0/2940 (84%)
#
# Epoch: 9 	Training Accuracy: 86.58%
# Validation Accuracy: 83.57%
# Batch: 0, Loss: 0.5805463194847107
#
# Average loss: 0.4382, Accuracy: 695.0/790 (88%)
#
#
# Average loss: 0.4798, Accuracy: 2500.0/2940 (85%)
#
# Epoch: 10 	Training Accuracy: 87.97%
# Validation Accuracy: 85.03%
# Batch: 0, Loss: 0.4282453954219818
#
# Average loss: 0.3812, Accuracy: 699.0/790 (88%)
#
#
# Average loss: 0.4275, Accuracy: 2536.0/2940 (86%)
#
# Epoch: 11 	Training Accuracy: 88.48%
# Validation Accuracy: 86.26%
# Batch: 0, Loss: 0.4078112840652466
#
# Average loss: 0.3384, Accuracy: 712.0/790 (90%)
#
#
# Average loss: 0.3915, Accuracy: 2586.0/2940 (88%)
#
# Epoch: 12 	Training Accuracy: 90.13%
# Validation Accuracy: 87.96%
# Batch: 0, Loss: 0.37431806325912476
#
# Average loss: 0.3097, Accuracy: 720.0/790 (91%)
#
#
# Average loss: 0.3691, Accuracy: 2605.0/2940 (89%)
#
# Epoch: 13 	Training Accuracy: 91.14%
# Validation Accuracy: 88.61%
# Batch: 0, Loss: 0.3232995867729187
#
# Average loss: 0.2870, Accuracy: 720.0/790 (91%)
#
#
# Average loss: 0.3536, Accuracy: 2614.0/2940 (89%)
#
# Epoch: 14 	Training Accuracy: 91.14%
# Validation Accuracy: 88.91%
# Batch: 0, Loss: 0.3602425456047058
#
# Average loss: 0.2736, Accuracy: 724.0/790 (92%)
#
#
# Average loss: 0.3383, Accuracy: 2633.0/2940 (90%)
#
# Epoch: 15 	Training Accuracy: 91.65%
# Validation Accuracy: 89.56%
# Batch: 0, Loss: 0.2630317211151123
#
# Average loss: 0.2618, Accuracy: 729.0/790 (92%)
#
#
# Average loss: 0.3348, Accuracy: 2641.0/2940 (90%)
#
# Epoch: 16 	Training Accuracy: 92.28%
# Validation Accuracy: 89.83%
# Batch: 0, Loss: 0.24710974097251892
#
# Average loss: 0.2488, Accuracy: 730.0/790 (92%)
#
#
# Average loss: 0.3306, Accuracy: 2640.0/2940 (90%)
#
# Epoch: 17 	Training Accuracy: 92.41%
# Validation Accuracy: 89.80%
# Batch: 0, Loss: 0.27091652154922485
#
# Average loss: 0.2392, Accuracy: 731.0/790 (93%)
#
#
# Average loss: 0.3146, Accuracy: 2662.0/2940 (91%)
#
# Epoch: 18 	Training Accuracy: 92.53%
# Validation Accuracy: 90.54%
# Batch: 0, Loss: 0.25896692276000977
#
# Average loss: 0.2327, Accuracy: 735.0/790 (93%)
#
#
# Average loss: 0.3094, Accuracy: 2658.0/2940 (90%)
#
# Epoch: 19 	Training Accuracy: 93.04%
# Validation Accuracy: 90.41%
#
# Average loss: 0.2327, Accuracy: 735.0/790 (93%)
#
#
# Average loss: 0.2758, Accuracy: 4426.0/4861 (91%)
#
# Final Training Accuracy (New Data): 0.9304
# Final Test Accuracy (New Data): 0.9105
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 100 =========================
# Batch: 0, Loss: 1.6120821237564087
#
# Average loss: 1.5849, Accuracy: 330.0/790 (42%)
#
#
# Average loss: 1.5855, Accuracy: 1196.0/2940 (41%)
#
# Epoch: 0 	Training Accuracy: 41.77%
# Validation Accuracy: 40.68%
# Batch: 0, Loss: 1.5854417085647583
#
# Average loss: 1.5465, Accuracy: 329.0/790 (42%)
#
#
# Average loss: 1.5489, Accuracy: 1162.0/2940 (40%)
#
# Epoch: 1 	Training Accuracy: 41.65%
# Validation Accuracy: 39.52%
# Batch: 0, Loss: 1.542086124420166
#
# Average loss: 1.4793, Accuracy: 564.0/790 (71%)
#
#
# Average loss: 1.4826, Accuracy: 2053.0/2940 (70%)
#
# Epoch: 2 	Training Accuracy: 71.39%
# Validation Accuracy: 69.83%
# Batch: 0, Loss: 1.483146071434021
#
# Average loss: 1.3778, Accuracy: 621.0/790 (79%)
#
#
# Average loss: 1.3771, Accuracy: 2395.0/2940 (81%)
#
# Epoch: 3 	Training Accuracy: 78.61%
# Validation Accuracy: 81.46%
# Batch: 0, Loss: 1.3660311698913574
#
# Average loss: 1.2223, Accuracy: 623.0/790 (79%)
#
#
# Average loss: 1.2196, Accuracy: 2392.0/2940 (81%)
#
# Epoch: 4 	Training Accuracy: 78.86%
# Validation Accuracy: 81.36%
# Batch: 0, Loss: 1.1894532442092896
#
# Average loss: 1.0120, Accuracy: 642.0/790 (81%)
#
#
# Average loss: 1.0081, Accuracy: 2442.0/2940 (83%)
#
# Epoch: 5 	Training Accuracy: 81.27%
# Validation Accuracy: 83.06%
# Batch: 0, Loss: 1.0216364860534668
#
# Average loss: 0.7900, Accuracy: 655.0/790 (83%)
#
#
# Average loss: 0.7818, Accuracy: 2477.0/2940 (84%)
#
# Epoch: 6 	Training Accuracy: 82.91%
# Validation Accuracy: 84.25%
# Batch: 0, Loss: 0.796238899230957
#
# Average loss: 0.6179, Accuracy: 667.0/790 (84%)
#
#
# Average loss: 0.6102, Accuracy: 2545.0/2940 (87%)
#
# Epoch: 7 	Training Accuracy: 84.43%
# Validation Accuracy: 86.56%
# Batch: 0, Loss: 0.6266849637031555
#
# Average loss: 0.5097, Accuracy: 680.0/790 (86%)
#
#
# Average loss: 0.5065, Accuracy: 2571.0/2940 (87%)
#
# Epoch: 8 	Training Accuracy: 86.08%
# Validation Accuracy: 87.45%
# Batch: 0, Loss: 0.5275688171386719
#
# Average loss: 0.4462, Accuracy: 687.0/790 (87%)
#
#
# Average loss: 0.4431, Accuracy: 2570.0/2940 (87%)
#
# Epoch: 9 	Training Accuracy: 86.96%
# Validation Accuracy: 87.41%
# Batch: 0, Loss: 0.5123882293701172
#
# Average loss: 0.4004, Accuracy: 689.0/790 (87%)
#
#
# Average loss: 0.4024, Accuracy: 2606.0/2940 (89%)
#
# Epoch: 10 	Training Accuracy: 87.22%
# Validation Accuracy: 88.64%
# Batch: 0, Loss: 0.392406702041626
#
# Average loss: 0.3699, Accuracy: 690.0/790 (87%)
#
#
# Average loss: 0.3770, Accuracy: 2609.0/2940 (89%)
#
# Epoch: 11 	Training Accuracy: 87.34%
# Validation Accuracy: 88.74%
# Batch: 0, Loss: 0.4491376578807831
#
# Average loss: 0.3447, Accuracy: 693.0/790 (88%)
#
#
# Average loss: 0.3519, Accuracy: 2642.0/2940 (90%)
#
# Epoch: 12 	Training Accuracy: 87.72%
# Validation Accuracy: 89.86%
# Batch: 0, Loss: 0.36845195293426514
#
# Average loss: 0.3199, Accuracy: 707.0/790 (89%)
#
#
# Average loss: 0.3339, Accuracy: 2644.0/2940 (90%)
#
# Epoch: 13 	Training Accuracy: 89.49%
# Validation Accuracy: 89.93%
# Batch: 0, Loss: 0.30133065581321716
#
# Average loss: 0.3050, Accuracy: 718.0/790 (91%)
#
#
# Average loss: 0.3205, Accuracy: 2648.0/2940 (90%)
#
# Epoch: 14 	Training Accuracy: 90.89%
# Validation Accuracy: 90.07%
# Batch: 0, Loss: 0.3529413044452667
#
# Average loss: 0.2876, Accuracy: 730.0/790 (92%)
#
#
# Average loss: 0.3139, Accuracy: 2674.0/2940 (91%)
#
# Epoch: 15 	Training Accuracy: 92.41%
# Validation Accuracy: 90.95%
# Batch: 0, Loss: 0.2957839071750641
#
# Average loss: 0.2699, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.3005, Accuracy: 2677.0/2940 (91%)
#
# Epoch: 16 	Training Accuracy: 92.15%
# Validation Accuracy: 91.05%
# Batch: 0, Loss: 0.300075501203537
#
# Average loss: 0.2605, Accuracy: 725.0/790 (92%)
#
#
# Average loss: 0.2922, Accuracy: 2682.0/2940 (91%)
#
# Epoch: 17 	Training Accuracy: 91.77%
# Validation Accuracy: 91.22%
# Batch: 0, Loss: 0.225674107670784
#
# Average loss: 0.2448, Accuracy: 733.0/790 (93%)
#
#
# Average loss: 0.2863, Accuracy: 2686.0/2940 (91%)
#
# Epoch: 18 	Training Accuracy: 92.78%
# Validation Accuracy: 91.36%
# Batch: 0, Loss: 0.21968138217926025
#
# Average loss: 0.2377, Accuracy: 733.0/790 (93%)
#
#
# Average loss: 0.2846, Accuracy: 2689.0/2940 (91%)
#
# Epoch: 19 	Training Accuracy: 92.78%
# Validation Accuracy: 91.46%
#
# Average loss: 0.2377, Accuracy: 733.0/790 (93%)
#
#
# Average loss: 0.2904, Accuracy: 4409.0/4861 (91%)
#
# Final Training Accuracy (New Data): 0.9278
# Final Test Accuracy (New Data): 0.9070
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 43 =========================
# Batch: 0, Loss: 1.60883629322052
#
# Average loss: 1.6035, Accuracy: 159.0/790 (20%)
#
#
# Average loss: 1.6038, Accuracy: 592.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.13%
# Validation Accuracy: 20.14%
# Batch: 0, Loss: 1.6047401428222656
#
# Average loss: 1.5871, Accuracy: 423.0/790 (54%)
#
#
# Average loss: 1.5879, Accuracy: 1520.0/2940 (52%)
#
# Epoch: 1 	Training Accuracy: 53.54%
# Validation Accuracy: 51.70%
# Batch: 0, Loss: 1.584233283996582
#
# Average loss: 1.5479, Accuracy: 445.0/790 (56%)
#
#
# Average loss: 1.5504, Accuracy: 1691.0/2940 (58%)
#
# Epoch: 2 	Training Accuracy: 56.33%
# Validation Accuracy: 57.52%
# Batch: 0, Loss: 1.5436115264892578
#
# Average loss: 1.4644, Accuracy: 475.0/790 (60%)
#
#
# Average loss: 1.4695, Accuracy: 1723.0/2940 (59%)
#
# Epoch: 3 	Training Accuracy: 60.13%
# Validation Accuracy: 58.61%
# Batch: 0, Loss: 1.470409631729126
#
# Average loss: 1.3111, Accuracy: 515.0/790 (65%)
#
#
# Average loss: 1.3194, Accuracy: 1919.0/2940 (65%)
#
# Epoch: 4 	Training Accuracy: 65.19%
# Validation Accuracy: 65.27%
# Batch: 0, Loss: 1.3078453540802002
#
# Average loss: 1.0676, Accuracy: 630.0/790 (80%)
#
#
# Average loss: 1.0763, Accuracy: 2342.0/2940 (80%)
#
# Epoch: 5 	Training Accuracy: 79.75%
# Validation Accuracy: 79.66%
# Batch: 0, Loss: 1.0671474933624268
#
# Average loss: 0.7824, Accuracy: 673.0/790 (85%)
#
#
# Average loss: 0.7881, Accuracy: 2489.0/2940 (85%)
#
# Epoch: 6 	Training Accuracy: 85.19%
# Validation Accuracy: 84.66%
# Batch: 0, Loss: 0.8261869549751282
#
# Average loss: 0.5767, Accuracy: 683.0/790 (86%)
#
#
# Average loss: 0.5894, Accuracy: 2507.0/2940 (85%)
#
# Epoch: 7 	Training Accuracy: 86.46%
# Validation Accuracy: 85.27%
# Batch: 0, Loss: 0.5524288415908813
#
# Average loss: 0.4527, Accuracy: 693.0/790 (88%)
#
#
# Average loss: 0.4760, Accuracy: 2562.0/2940 (87%)
#
# Epoch: 8 	Training Accuracy: 87.72%
# Validation Accuracy: 87.14%
# Batch: 0, Loss: 0.45486846566200256
#
# Average loss: 0.3942, Accuracy: 696.0/790 (88%)
#
#
# Average loss: 0.4262, Accuracy: 2580.0/2940 (88%)
#
# Epoch: 9 	Training Accuracy: 88.10%
# Validation Accuracy: 87.76%
# Batch: 0, Loss: 0.38603752851486206
#
# Average loss: 0.3573, Accuracy: 705.0/790 (89%)
#
#
# Average loss: 0.4030, Accuracy: 2589.0/2940 (88%)
#
# Epoch: 10 	Training Accuracy: 89.24%
# Validation Accuracy: 88.06%
# Batch: 0, Loss: 0.43256521224975586
#
# Average loss: 0.3324, Accuracy: 718.0/790 (91%)
#
#
# Average loss: 0.3926, Accuracy: 2604.0/2940 (89%)
#
# Epoch: 11 	Training Accuracy: 90.89%
# Validation Accuracy: 88.57%
# Batch: 0, Loss: 0.37792477011680603
#
# Average loss: 0.3130, Accuracy: 716.0/790 (91%)
#
#
# Average loss: 0.3848, Accuracy: 2619.0/2940 (89%)
#
# Epoch: 12 	Training Accuracy: 90.63%
# Validation Accuracy: 89.08%
# Batch: 0, Loss: 0.39849960803985596
#
# Average loss: 0.2979, Accuracy: 724.0/790 (92%)
#
#
# Average loss: 0.3823, Accuracy: 2619.0/2940 (89%)
#
# Epoch: 13 	Training Accuracy: 91.65%
# Validation Accuracy: 89.08%
# Batch: 0, Loss: 0.24168996512889862
#
# Average loss: 0.2868, Accuracy: 721.0/790 (91%)
#
#
# Average loss: 0.3829, Accuracy: 2621.0/2940 (89%)
#
# Epoch: 14 	Training Accuracy: 91.27%
# Validation Accuracy: 89.15%
# Batch: 0, Loss: 0.28292831778526306
#
# Average loss: 0.2810, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.3842, Accuracy: 2604.0/2940 (89%)
#
# Epoch: 15 	Training Accuracy: 91.01%
# Validation Accuracy: 88.57%
# Batch: 0, Loss: 0.31656360626220703
#
# Average loss: 0.2670, Accuracy: 724.0/790 (92%)
#
#
# Average loss: 0.3695, Accuracy: 2625.0/2940 (89%)
#
# Epoch: 16 	Training Accuracy: 91.65%
# Validation Accuracy: 89.29%
# Batch: 0, Loss: 0.3367205262184143
#
# Average loss: 0.2555, Accuracy: 734.0/790 (93%)
#
#
# Average loss: 0.3637, Accuracy: 2633.0/2940 (90%)
#
# Epoch: 17 	Training Accuracy: 92.91%
# Validation Accuracy: 89.56%
# Batch: 0, Loss: 0.192649707198143
#
# Average loss: 0.2474, Accuracy: 737.0/790 (93%)
#
#
# Average loss: 0.3626, Accuracy: 2628.0/2940 (89%)
#
# Epoch: 18 	Training Accuracy: 93.29%
# Validation Accuracy: 89.39%
# Batch: 0, Loss: 0.21323616802692413
#
# Average loss: 0.2387, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.3576, Accuracy: 2639.0/2940 (90%)
#
# Epoch: 19 	Training Accuracy: 93.16%
# Validation Accuracy: 89.76%
#
# Average loss: 0.2387, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.3455, Accuracy: 4349.0/4861 (89%)
#
# Final Training Accuracy (New Data): 0.9316
# Final Test Accuracy (New Data): 0.8947
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 89 =========================
# Batch: 0, Loss: 1.6091768741607666
#
# Average loss: 1.6100, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6113, Accuracy: 599.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6123123168945312
#
# Average loss: 1.6096, Accuracy: 166.0/790 (21%)
#
#
# Average loss: 1.6108, Accuracy: 617.0/2940 (21%)
#
# Epoch: 1 	Training Accuracy: 21.01%
# Validation Accuracy: 20.99%
# Batch: 0, Loss: 1.6092040538787842
#
# Average loss: 1.6087, Accuracy: 226.0/790 (29%)
#
#
# Average loss: 1.6098, Accuracy: 784.0/2940 (27%)
#
# Epoch: 2 	Training Accuracy: 28.61%
# Validation Accuracy: 26.67%
# Batch: 0, Loss: 1.6080931425094604
#
# Average loss: 1.6048, Accuracy: 212.0/790 (27%)
#
#
# Average loss: 1.6062, Accuracy: 763.0/2940 (26%)
#
# Epoch: 3 	Training Accuracy: 26.84%
# Validation Accuracy: 25.95%
# Batch: 0, Loss: 1.6050761938095093
#
# Average loss: 1.5906, Accuracy: 317.0/790 (40%)
#
#
# Average loss: 1.5929, Accuracy: 1081.0/2940 (37%)
#
# Epoch: 4 	Training Accuracy: 40.13%
# Validation Accuracy: 36.77%
# Batch: 0, Loss: 1.5879616737365723
#
# Average loss: 1.5468, Accuracy: 451.0/790 (57%)
#
#
# Average loss: 1.5522, Accuracy: 1551.0/2940 (53%)
#
# Epoch: 5 	Training Accuracy: 57.09%
# Validation Accuracy: 52.76%
# Batch: 0, Loss: 1.5444320440292358
#
# Average loss: 1.4521, Accuracy: 431.0/790 (55%)
#
#
# Average loss: 1.4641, Accuracy: 1461.0/2940 (50%)
#
# Epoch: 6 	Training Accuracy: 54.56%
# Validation Accuracy: 49.69%
# Batch: 0, Loss: 1.4779704809188843
#
# Average loss: 1.3060, Accuracy: 438.0/790 (55%)
#
#
# Average loss: 1.3286, Accuracy: 1540.0/2940 (52%)
#
# Epoch: 7 	Training Accuracy: 55.44%
# Validation Accuracy: 52.38%
# Batch: 0, Loss: 1.312355875968933
#
# Average loss: 1.0935, Accuracy: 550.0/790 (70%)
#
#
# Average loss: 1.1235, Accuracy: 2014.0/2940 (69%)
#
# Epoch: 8 	Training Accuracy: 69.62%
# Validation Accuracy: 68.50%
# Batch: 0, Loss: 1.0882400274276733
#
# Average loss: 0.8408, Accuracy: 648.0/790 (82%)
#
#
# Average loss: 0.8743, Accuracy: 2391.0/2940 (81%)
#
# Epoch: 9 	Training Accuracy: 82.03%
# Validation Accuracy: 81.33%
# Batch: 0, Loss: 0.9119827747344971
#
# Average loss: 0.6312, Accuracy: 663.0/790 (84%)
#
#
# Average loss: 0.6733, Accuracy: 2416.0/2940 (82%)
#
# Epoch: 10 	Training Accuracy: 83.92%
# Validation Accuracy: 82.18%
# Batch: 0, Loss: 0.6650044918060303
#
# Average loss: 0.4986, Accuracy: 673.0/790 (85%)
#
#
# Average loss: 0.5552, Accuracy: 2448.0/2940 (83%)
#
# Epoch: 11 	Training Accuracy: 85.19%
# Validation Accuracy: 83.27%
# Batch: 0, Loss: 0.5129312872886658
#
# Average loss: 0.4267, Accuracy: 679.0/790 (86%)
#
#
# Average loss: 0.4873, Accuracy: 2490.0/2940 (85%)
#
# Epoch: 12 	Training Accuracy: 85.95%
# Validation Accuracy: 84.69%
# Batch: 0, Loss: 0.4493666887283325
#
# Average loss: 0.3779, Accuracy: 693.0/790 (88%)
#
#
# Average loss: 0.4520, Accuracy: 2522.0/2940 (86%)
#
# Epoch: 13 	Training Accuracy: 87.72%
# Validation Accuracy: 85.78%
# Batch: 0, Loss: 0.41310545802116394
#
# Average loss: 0.3422, Accuracy: 701.0/790 (89%)
#
#
# Average loss: 0.4239, Accuracy: 2565.0/2940 (87%)
#
# Epoch: 14 	Training Accuracy: 88.73%
# Validation Accuracy: 87.24%
# Batch: 0, Loss: 0.38460761308670044
#
# Average loss: 0.3182, Accuracy: 702.0/790 (89%)
#
#
# Average loss: 0.4061, Accuracy: 2585.0/2940 (88%)
#
# Epoch: 15 	Training Accuracy: 88.86%
# Validation Accuracy: 87.93%
# Batch: 0, Loss: 0.3322222828865051
#
# Average loss: 0.3017, Accuracy: 708.0/790 (90%)
#
#
# Average loss: 0.4095, Accuracy: 2562.0/2940 (87%)
#
# Epoch: 16 	Training Accuracy: 89.62%
# Validation Accuracy: 87.14%
# Batch: 0, Loss: 0.30244746804237366
#
# Average loss: 0.2799, Accuracy: 711.0/790 (90%)
#
#
# Average loss: 0.3927, Accuracy: 2582.0/2940 (88%)
#
# Epoch: 17 	Training Accuracy: 90.00%
# Validation Accuracy: 87.82%
# Batch: 0, Loss: 0.24926069378852844
#
# Average loss: 0.2742, Accuracy: 713.0/790 (90%)
#
#
# Average loss: 0.3800, Accuracy: 2590.0/2940 (88%)
#
# Epoch: 18 	Training Accuracy: 90.25%
# Validation Accuracy: 88.10%
# Batch: 0, Loss: 0.33839571475982666
#
# Average loss: 0.2550, Accuracy: 716.0/790 (91%)
#
#
# Average loss: 0.3748, Accuracy: 2606.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 90.63%
# Validation Accuracy: 88.64%
#
# Average loss: 0.2550, Accuracy: 716.0/790 (91%)
#
#
# Average loss: 0.3552, Accuracy: 4292.0/4861 (88%)
#
# Final Training Accuracy (New Data): 0.9063
# Final Test Accuracy (New Data): 0.8829
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 48 =========================
# Batch: 0, Loss: 1.6166073083877563
#
# Average loss: 1.5856, Accuracy: 291.0/790 (37%)
#
#
# Average loss: 1.5859, Accuracy: 1015.0/2940 (35%)
#
# Epoch: 0 	Training Accuracy: 36.84%
# Validation Accuracy: 34.52%
# Batch: 0, Loss: 1.5859373807907104
#
# Average loss: 1.5473, Accuracy: 336.0/790 (43%)
#
#
# Average loss: 1.5520, Accuracy: 1107.0/2940 (38%)
#
# Epoch: 1 	Training Accuracy: 42.53%
# Validation Accuracy: 37.65%
# Batch: 0, Loss: 1.5475140810012817
#
# Average loss: 1.4808, Accuracy: 526.0/790 (67%)
#
#
# Average loss: 1.4856, Accuracy: 1946.0/2940 (66%)
#
# Epoch: 2 	Training Accuracy: 66.58%
# Validation Accuracy: 66.19%
# Batch: 0, Loss: 1.4831925630569458
#
# Average loss: 1.3768, Accuracy: 626.0/790 (79%)
#
#
# Average loss: 1.3819, Accuracy: 2308.0/2940 (79%)
#
# Epoch: 3 	Training Accuracy: 79.24%
# Validation Accuracy: 78.50%
# Batch: 0, Loss: 1.3750661611557007
#
# Average loss: 1.2111, Accuracy: 640.0/790 (81%)
#
#
# Average loss: 1.2170, Accuracy: 2363.0/2940 (80%)
#
# Epoch: 4 	Training Accuracy: 81.01%
# Validation Accuracy: 80.37%
# Batch: 0, Loss: 1.2037644386291504
#
# Average loss: 0.9878, Accuracy: 653.0/790 (83%)
#
#
# Average loss: 0.9961, Accuracy: 2437.0/2940 (83%)
#
# Epoch: 5 	Training Accuracy: 82.66%
# Validation Accuracy: 82.89%
# Batch: 0, Loss: 0.9667258858680725
#
# Average loss: 0.7517, Accuracy: 657.0/790 (83%)
#
#
# Average loss: 0.7638, Accuracy: 2473.0/2940 (84%)
#
# Epoch: 6 	Training Accuracy: 83.16%
# Validation Accuracy: 84.12%
# Batch: 0, Loss: 0.763092577457428
#
# Average loss: 0.5745, Accuracy: 673.0/790 (85%)
#
#
# Average loss: 0.5946, Accuracy: 2518.0/2940 (86%)
#
# Epoch: 7 	Training Accuracy: 85.19%
# Validation Accuracy: 85.65%
# Batch: 0, Loss: 0.5838907361030579
#
# Average loss: 0.4627, Accuracy: 684.0/790 (87%)
#
#
# Average loss: 0.4878, Accuracy: 2540.0/2940 (86%)
#
# Epoch: 8 	Training Accuracy: 86.58%
# Validation Accuracy: 86.39%
# Batch: 0, Loss: 0.4174884557723999
#
# Average loss: 0.3976, Accuracy: 685.0/790 (87%)
#
#
# Average loss: 0.4274, Accuracy: 2561.0/2940 (87%)
#
# Epoch: 9 	Training Accuracy: 86.71%
# Validation Accuracy: 87.11%
# Batch: 0, Loss: 0.4044797420501709
#
# Average loss: 0.3560, Accuracy: 692.0/790 (88%)
#
#
# Average loss: 0.3958, Accuracy: 2562.0/2940 (87%)
#
# Epoch: 10 	Training Accuracy: 87.59%
# Validation Accuracy: 87.14%
# Batch: 0, Loss: 0.32155558466911316
#
# Average loss: 0.3258, Accuracy: 700.0/790 (89%)
#
#
# Average loss: 0.3681, Accuracy: 2595.0/2940 (88%)
#
# Epoch: 11 	Training Accuracy: 88.61%
# Validation Accuracy: 88.27%
# Batch: 0, Loss: 0.38358235359191895
#
# Average loss: 0.3088, Accuracy: 701.0/790 (89%)
#
#
# Average loss: 0.3542, Accuracy: 2590.0/2940 (88%)
#
# Epoch: 12 	Training Accuracy: 88.73%
# Validation Accuracy: 88.10%
# Batch: 0, Loss: 0.3681204915046692
#
# Average loss: 0.2843, Accuracy: 709.0/790 (90%)
#
#
# Average loss: 0.3383, Accuracy: 2617.0/2940 (89%)
#
# Epoch: 13 	Training Accuracy: 89.75%
# Validation Accuracy: 89.01%
# Batch: 0, Loss: 0.32488349080085754
#
# Average loss: 0.2720, Accuracy: 710.0/790 (90%)
#
#
# Average loss: 0.3229, Accuracy: 2634.0/2940 (90%)
#
# Epoch: 14 	Training Accuracy: 89.87%
# Validation Accuracy: 89.59%
# Batch: 0, Loss: 0.3572266101837158
#
# Average loss: 0.2616, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.3269, Accuracy: 2622.0/2940 (89%)
#
# Epoch: 15 	Training Accuracy: 91.39%
# Validation Accuracy: 89.18%
# Batch: 0, Loss: 0.2517215609550476
#
# Average loss: 0.2423, Accuracy: 725.0/790 (92%)
#
#
# Average loss: 0.3082, Accuracy: 2651.0/2940 (90%)
#
# Epoch: 16 	Training Accuracy: 91.77%
# Validation Accuracy: 90.17%
# Batch: 0, Loss: 0.2218351811170578
#
# Average loss: 0.2303, Accuracy: 727.0/790 (92%)
#
#
# Average loss: 0.3017, Accuracy: 2659.0/2940 (90%)
#
# Epoch: 17 	Training Accuracy: 92.03%
# Validation Accuracy: 90.44%
# Batch: 0, Loss: 0.22374649345874786
#
# Average loss: 0.2187, Accuracy: 731.0/790 (93%)
#
#
# Average loss: 0.2954, Accuracy: 2665.0/2940 (91%)
#
# Epoch: 18 	Training Accuracy: 92.53%
# Validation Accuracy: 90.65%
# Batch: 0, Loss: 0.18226145207881927
#
# Average loss: 0.2099, Accuracy: 733.0/790 (93%)
#
#
# Average loss: 0.2901, Accuracy: 2665.0/2940 (91%)
#
# Epoch: 19 	Training Accuracy: 92.78%
# Validation Accuracy: 90.65%
#
# Average loss: 0.2099, Accuracy: 733.0/790 (93%)
#
#
# Average loss: 0.2752, Accuracy: 4436.0/4861 (91%)
#
# Final Training Accuracy (New Data): 0.9278
# Final Test Accuracy (New Data): 0.9126
# Training for data percentage: 0.05:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 62 =========================
# Batch: 0, Loss: 1.621057152748108
#
# Average loss: 1.5974, Accuracy: 448.0/1320 (34%)
#
#
# Average loss: 1.6009, Accuracy: 932.0/2940 (32%)
#
# Epoch: 0 	Training Accuracy: 33.94%
# Validation Accuracy: 31.70%
# Batch: 0, Loss: 1.5955111980438232
#
# Average loss: 1.5406, Accuracy: 702.0/1320 (53%)
#
#
# Average loss: 1.5446, Accuracy: 1515.0/2940 (52%)
#
# Epoch: 1 	Training Accuracy: 53.18%
# Validation Accuracy: 51.53%
# Batch: 0, Loss: 1.5433132648468018
#
# Average loss: 1.3678, Accuracy: 834.0/1320 (63%)
#
#
# Average loss: 1.3744, Accuracy: 1845.0/2940 (63%)
#
# Epoch: 2 	Training Accuracy: 63.18%
# Validation Accuracy: 62.76%
# Batch: 0, Loss: 1.3764135837554932
#
# Average loss: 1.0099, Accuracy: 1012.0/1320 (77%)
#
#
# Average loss: 1.0140, Accuracy: 2257.0/2940 (77%)
#
# Epoch: 3 	Training Accuracy: 76.67%
# Validation Accuracy: 76.77%
# Batch: 0, Loss: 1.042859673500061
#
# Average loss: 0.6305, Accuracy: 1116.0/1320 (85%)
#
#
# Average loss: 0.6354, Accuracy: 2466.0/2940 (84%)
#
# Epoch: 4 	Training Accuracy: 84.55%
# Validation Accuracy: 83.88%
# Batch: 0, Loss: 0.6105294227600098
#
# Average loss: 0.4482, Accuracy: 1136.0/1320 (86%)
#
#
# Average loss: 0.4702, Accuracy: 2503.0/2940 (85%)
#
# Epoch: 5 	Training Accuracy: 86.06%
# Validation Accuracy: 85.14%
# Batch: 0, Loss: 0.4821288287639618
#
# Average loss: 0.3844, Accuracy: 1152.0/1320 (87%)
#
#
# Average loss: 0.4218, Accuracy: 2539.0/2940 (86%)
#
# Epoch: 6 	Training Accuracy: 87.27%
# Validation Accuracy: 86.36%
# Batch: 0, Loss: 0.33902987837791443
#
# Average loss: 0.3513, Accuracy: 1161.0/1320 (88%)
#
#
# Average loss: 0.3916, Accuracy: 2571.0/2940 (87%)
#
# Epoch: 7 	Training Accuracy: 87.95%
# Validation Accuracy: 87.45%
# Batch: 0, Loss: 0.34844887256622314
#
# Average loss: 0.3267, Accuracy: 1180.0/1320 (89%)
#
#
# Average loss: 0.3723, Accuracy: 2593.0/2940 (88%)
#
# Epoch: 8 	Training Accuracy: 89.39%
# Validation Accuracy: 88.20%
# Batch: 0, Loss: 0.3491531014442444
#
# Average loss: 0.3063, Accuracy: 1185.0/1320 (90%)
#
#
# Average loss: 0.3554, Accuracy: 2602.0/2940 (89%)
#
# Epoch: 9 	Training Accuracy: 89.77%
# Validation Accuracy: 88.50%
# Batch: 0, Loss: 0.2549148201942444
#
# Average loss: 0.3053, Accuracy: 1191.0/1320 (90%)
#
#
# Average loss: 0.3583, Accuracy: 2618.0/2940 (89%)
#
# Epoch: 10 	Training Accuracy: 90.23%
# Validation Accuracy: 89.05%
# Batch: 0, Loss: 0.33881649374961853
#
# Average loss: 0.2780, Accuracy: 1197.0/1320 (91%)
#
#
# Average loss: 0.3334, Accuracy: 2623.0/2940 (89%)
#
# Epoch: 11 	Training Accuracy: 90.68%
# Validation Accuracy: 89.22%
# Batch: 0, Loss: 0.30167728662490845
#
# Average loss: 0.2642, Accuracy: 1209.0/1320 (92%)
#
#
# Average loss: 0.3250, Accuracy: 2634.0/2940 (90%)
#
# Epoch: 12 	Training Accuracy: 91.59%
# Validation Accuracy: 89.59%
# Batch: 0, Loss: 0.30627530813217163
#
# Average loss: 0.2537, Accuracy: 1212.0/1320 (92%)
#
#
# Average loss: 0.3159, Accuracy: 2641.0/2940 (90%)
#
# Epoch: 13 	Training Accuracy: 91.82%
# Validation Accuracy: 89.83%
# Batch: 0, Loss: 0.2269105166196823
#
# Average loss: 0.2436, Accuracy: 1214.0/1320 (92%)
#
#
# Average loss: 0.3089, Accuracy: 2644.0/2940 (90%)
#
# Epoch: 14 	Training Accuracy: 91.97%
# Validation Accuracy: 89.93%
# Batch: 0, Loss: 0.24925659596920013
#
# Average loss: 0.2355, Accuracy: 1219.0/1320 (92%)
#
#
# Average loss: 0.3022, Accuracy: 2648.0/2940 (90%)
#
# Epoch: 15 	Training Accuracy: 92.35%
# Validation Accuracy: 90.07%
# Batch: 0, Loss: 0.21038182079792023
#
# Average loss: 0.2283, Accuracy: 1221.0/1320 (92%)
#
#
# Average loss: 0.2971, Accuracy: 2665.0/2940 (91%)
#
# Epoch: 16 	Training Accuracy: 92.50%
# Validation Accuracy: 90.65%
# Batch: 0, Loss: 0.23122018575668335
#
# Average loss: 0.2236, Accuracy: 1217.0/1320 (92%)
#
#
# Average loss: 0.2954, Accuracy: 2659.0/2940 (90%)
#
# Epoch: 17 	Training Accuracy: 92.20%
# Validation Accuracy: 90.44%
# Batch: 0, Loss: 0.19296380877494812
#
# Average loss: 0.2161, Accuracy: 1223.0/1320 (93%)
#
#
# Average loss: 0.2914, Accuracy: 2672.0/2940 (91%)
#
# Epoch: 18 	Training Accuracy: 92.65%
# Validation Accuracy: 90.88%
# Batch: 0, Loss: 0.3758254647254944
#
# Average loss: 0.2085, Accuracy: 1224.0/1320 (93%)
#
#
# Average loss: 0.2870, Accuracy: 2656.0/2940 (90%)
#
# Epoch: 19 	Training Accuracy: 92.73%
# Validation Accuracy: 90.34%
#
# Average loss: 0.2085, Accuracy: 1224.0/1320 (93%)
#
#
# Average loss: 0.2922, Accuracy: 4421.0/4861 (91%)
#
# Final Training Accuracy (New Data): 0.9273
# Final Test Accuracy (New Data): 0.9095
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 63 =========================
# Batch: 0, Loss: 1.6073778867721558
#
# Average loss: 1.5949, Accuracy: 504.0/1320 (38%)
#
#
# Average loss: 1.5953, Accuracy: 1141.0/2940 (39%)
#
# Epoch: 0 	Training Accuracy: 38.18%
# Validation Accuracy: 38.81%
# Batch: 0, Loss: 1.5992891788482666
#
# Average loss: 1.5628, Accuracy: 384.0/1320 (29%)
#
#
# Average loss: 1.5645, Accuracy: 809.0/2940 (28%)
#
# Epoch: 1 	Training Accuracy: 29.09%
# Validation Accuracy: 27.52%
# Batch: 0, Loss: 1.57270348072052
#
# Average loss: 1.4738, Accuracy: 961.0/1320 (73%)
#
#
# Average loss: 1.4724, Accuracy: 2155.0/2940 (73%)
#
# Epoch: 2 	Training Accuracy: 72.80%
# Validation Accuracy: 73.30%
# Batch: 0, Loss: 1.4846223592758179
#
# Average loss: 1.2692, Accuracy: 987.0/1320 (75%)
#
#
# Average loss: 1.2643, Accuracy: 2160.0/2940 (73%)
#
# Epoch: 3 	Training Accuracy: 74.77%
# Validation Accuracy: 73.47%
# Batch: 0, Loss: 1.302692174911499
#
# Average loss: 0.9471, Accuracy: 1020.0/1320 (77%)
#
#
# Average loss: 0.9413, Accuracy: 2244.0/2940 (76%)
#
# Epoch: 4 	Training Accuracy: 77.27%
# Validation Accuracy: 76.33%
# Batch: 0, Loss: 0.9177437424659729
#
# Average loss: 0.6663, Accuracy: 1056.0/1320 (80%)
#
#
# Average loss: 0.6662, Accuracy: 2328.0/2940 (79%)
#
# Epoch: 5 	Training Accuracy: 80.00%
# Validation Accuracy: 79.18%
# Batch: 0, Loss: 0.6729794144630432
#
# Average loss: 0.5027, Accuracy: 1083.0/1320 (82%)
#
#
# Average loss: 0.5209, Accuracy: 2396.0/2940 (81%)
#
# Epoch: 6 	Training Accuracy: 82.05%
# Validation Accuracy: 81.50%
# Batch: 0, Loss: 0.5764474868774414
#
# Average loss: 0.4151, Accuracy: 1127.0/1320 (85%)
#
#
# Average loss: 0.4341, Accuracy: 2494.0/2940 (85%)
#
# Epoch: 7 	Training Accuracy: 85.38%
# Validation Accuracy: 84.83%
# Batch: 0, Loss: 0.4287886917591095
#
# Average loss: 0.3644, Accuracy: 1147.0/1320 (87%)
#
#
# Average loss: 0.3980, Accuracy: 2535.0/2940 (86%)
#
# Epoch: 8 	Training Accuracy: 86.89%
# Validation Accuracy: 86.22%
# Batch: 0, Loss: 0.3482852578163147
#
# Average loss: 0.3363, Accuracy: 1159.0/1320 (88%)
#
#
# Average loss: 0.3774, Accuracy: 2542.0/2940 (86%)
#
# Epoch: 9 	Training Accuracy: 87.80%
# Validation Accuracy: 86.46%
# Batch: 0, Loss: 0.3712855577468872
#
# Average loss: 0.3023, Accuracy: 1184.0/1320 (90%)
#
#
# Average loss: 0.3548, Accuracy: 2597.0/2940 (88%)
#
# Epoch: 10 	Training Accuracy: 89.70%
# Validation Accuracy: 88.33%
# Batch: 0, Loss: 0.3593745231628418
#
# Average loss: 0.2792, Accuracy: 1185.0/1320 (90%)
#
#
# Average loss: 0.3373, Accuracy: 2591.0/2940 (88%)
#
# Epoch: 11 	Training Accuracy: 89.77%
# Validation Accuracy: 88.13%
# Batch: 0, Loss: 0.33364102244377136
#
# ...
#
#
# Average loss: 0.1482, Accuracy: 2795.0/2940 (95%)
#
# Epoch: 15 	Training Accuracy: 95.97%
# Validation Accuracy: 95.07%
# Batch: 0, Loss: 0.1866985708475113
# Batch: 20, Loss: 0.17396007478237152
# Batch: 40, Loss: 0.12403760850429535
# Batch: 60, Loss: 0.1023283302783966
# Batch: 80, Loss: 0.11358919739723206
# Batch: 100, Loss: 0.13243359327316284
# Batch: 120, Loss: 0.10674969106912613
# Batch: 140, Loss: 0.16379958391189575
# Batch: 160, Loss: 0.0585201159119606
# Batch: 180, Loss: 0.1472032070159912
# Batch: 200, Loss: 0.1257031261920929
#
# Average loss: 0.1171, Accuracy: 25022.0/26038 (96%)
#
#
# Average loss: 0.1468, Accuracy: 2793.0/2940 (95%)
#
# Epoch: 16 	Training Accuracy: 96.10%
# Validation Accuracy: 95.00%
# Batch: 0, Loss: 0.11534392833709717
# Batch: 20, Loss: 0.14162634313106537
# Batch: 40, Loss: 0.11513809859752655
# Batch: 60, Loss: 0.12982061505317688
# Batch: 80, Loss: 0.21552255749702454
# Batch: 100, Loss: 0.038657091557979584
# Batch: 120, Loss: 0.08117637783288956
# Batch: 140, Loss: 0.08685315400362015
# Batch: 160, Loss: 0.29977190494537354
# Batch: 180, Loss: 0.05793413519859314
# Batch: 200, Loss: 0.07117460668087006
#
# Average loss: 0.1159, Accuracy: 25017.0/26038 (96%)
#
#
# Average loss: 0.1477, Accuracy: 2798.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 96.08%
# Validation Accuracy: 95.17%
# Early stopping invoked.
#
# Average loss: 0.1230, Accuracy: 24955.0/26038 (96%)
#
#
# Average loss: 0.1298, Accuracy: 4648.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9584
# Final Test Accuracy (New Data): 0.9562
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 43 =========================
# Batch: 0, Loss: 1.6083078384399414
# Batch: 20, Loss: 1.3763058185577393
# Batch: 40, Loss: 0.688502311706543
# Batch: 60, Loss: 0.40379413962364197
# Batch: 80, Loss: 0.26834046840667725
# Batch: 100, Loss: 0.28358545899391174
# Batch: 120, Loss: 0.23769883811473846
# Batch: 140, Loss: 0.26811453700065613
# Batch: 160, Loss: 0.3459084928035736
# Batch: 180, Loss: 0.24883635342121124
# Batch: 200, Loss: 0.20066261291503906
#
# Average loss: 0.2354, Accuracy: 23970.0/26038 (92%)
#
#
# Average loss: 0.2490, Accuracy: 2701.0/2940 (92%)
#
# Epoch: 0 	Training Accuracy: 92.06%
# Validation Accuracy: 91.87%
# Batch: 0, Loss: 0.17436988651752472
# Batch: 20, Loss: 0.19005493819713593
# Batch: 40, Loss: 0.10108853876590729
# Batch: 60, Loss: 0.21393173933029175
# Batch: 80, Loss: 0.14812636375427246
# Batch: 100, Loss: 0.2442624866962433
# Batch: 120, Loss: 0.17614659667015076
# Batch: 140, Loss: 0.14740656316280365
# Batch: 160, Loss: 0.18199047446250916
# Batch: 180, Loss: 0.28464242815971375
# Batch: 200, Loss: 0.18581603467464447
#
# Average loss: 0.1891, Accuracy: 24420.0/26038 (94%)
#
#
# Average loss: 0.2090, Accuracy: 2739.0/2940 (93%)
#
# Epoch: 1 	Training Accuracy: 93.79%
# Validation Accuracy: 93.16%
# Batch: 0, Loss: 0.21127663552761078
# Batch: 20, Loss: 0.18980345129966736
# Batch: 40, Loss: 0.1123044565320015
# Batch: 60, Loss: 0.19759808480739594
# Batch: 80, Loss: 0.17765462398529053
# Batch: 100, Loss: 0.15142406523227692
# Batch: 120, Loss: 0.07005894929170609
# Batch: 140, Loss: 0.17107492685317993
# Batch: 160, Loss: 0.1739545464515686
# Batch: 180, Loss: 0.09328746795654297
# Batch: 200, Loss: 0.14561505615711212
#
# Average loss: 0.1800, Accuracy: 24475.0/26038 (94%)
#
#
# Average loss: 0.2053, Accuracy: 2741.0/2940 (93%)
#
# Epoch: 2 	Training Accuracy: 94.00%
# Validation Accuracy: 93.23%
# Batch: 0, Loss: 0.19187672436237335
# Batch: 20, Loss: 0.23577208817005157
# Batch: 40, Loss: 0.20573219656944275
# Batch: 60, Loss: 0.11113065481185913
# Batch: 80, Loss: 0.17880657315254211
# Batch: 100, Loss: 0.1791553795337677
# Batch: 120, Loss: 0.14790481328964233
# Batch: 140, Loss: 0.18768210709095
# Batch: 160, Loss: 0.1780516803264618
# Batch: 180, Loss: 0.203107088804245
# Batch: 200, Loss: 0.14231042563915253
#
# Average loss: 0.1746, Accuracy: 24569.0/26038 (94%)
#
#
# Average loss: 0.1968, Accuracy: 2748.0/2940 (93%)
#
# Epoch: 3 	Training Accuracy: 94.36%
# Validation Accuracy: 93.47%
# Batch: 0, Loss: 0.20234322547912598
# Batch: 20, Loss: 0.13612164556980133
# Batch: 40, Loss: 0.16284890472888947
# Batch: 60, Loss: 0.16256198287010193
# Batch: 80, Loss: 0.12079758197069168
# Batch: 100, Loss: 0.21380746364593506
# Batch: 120, Loss: 0.1297672539949417
# Batch: 140, Loss: 0.16295605897903442
# Batch: 160, Loss: 0.3032626509666443
# Batch: 180, Loss: 0.23125213384628296
# Batch: 200, Loss: 0.16626490652561188
#
# Average loss: 0.1763, Accuracy: 24508.0/26038 (94%)
#
#
# Average loss: 0.1996, Accuracy: 2762.0/2940 (94%)
#
# Epoch: 4 	Training Accuracy: 94.12%
# Validation Accuracy: 93.95%
# Batch: 0, Loss: 0.28930944204330444
# Batch: 20, Loss: 0.1311851590871811
# Batch: 40, Loss: 0.2592319846153259
# Batch: 60, Loss: 0.10028392821550369
# Batch: 80, Loss: 0.1509178727865219
# Batch: 100, Loss: 0.1267905831336975
# Batch: 120, Loss: 0.19591757655143738
# Batch: 140, Loss: 0.13186264038085938
# Batch: 160, Loss: 0.07025894522666931
# Batch: 180, Loss: 0.18549665808677673
# Batch: 200, Loss: 0.08079634606838226
#
# Average loss: 0.1535, Accuracy: 24757.0/26038 (95%)
#
#
# Average loss: 0.1776, Accuracy: 2770.0/2940 (94%)
#
# Epoch: 5 	Training Accuracy: 95.08%
# Validation Accuracy: 94.22%
# Batch: 0, Loss: 0.1287335604429245
# Batch: 20, Loss: 0.14064140617847443
# Batch: 40, Loss: 0.115858294069767
# Batch: 60, Loss: 0.14431549608707428
# Batch: 80, Loss: 0.13405176997184753
# Batch: 100, Loss: 0.13878393173217773
# Batch: 120, Loss: 0.2135883867740631
# Batch: 140, Loss: 0.2521294057369232
# Batch: 160, Loss: 0.1501537263393402
# Batch: 180, Loss: 0.16326913237571716
# Batch: 200, Loss: 0.1369456946849823
#
# Average loss: 0.1714, Accuracy: 24532.0/26038 (94%)
#
#
# Average loss: 0.1964, Accuracy: 2761.0/2940 (94%)
#
# Epoch: 6 	Training Accuracy: 94.22%
# Validation Accuracy: 93.91%
# Batch: 0, Loss: 0.20733022689819336
# Batch: 20, Loss: 0.16931983828544617
# Batch: 40, Loss: 0.132234588265419
# Batch: 60, Loss: 0.1480971872806549
# Batch: 80, Loss: 0.08246208727359772
# Batch: 100, Loss: 0.14089904725551605
# Batch: 120, Loss: 0.1141924038529396
# Batch: 140, Loss: 0.25083833932876587
# Batch: 160, Loss: 0.07564783096313477
# Batch: 180, Loss: 0.1987535059452057
# Batch: 200, Loss: 0.1721421629190445
#
# Average loss: 0.1417, Accuracy: 24851.0/26038 (95%)
#
#
# Average loss: 0.1653, Accuracy: 2781.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 95.44%
# Validation Accuracy: 94.59%
# Batch: 0, Loss: 0.1176176369190216
# Batch: 20, Loss: 0.14978890120983124
# Batch: 40, Loss: 0.1351020783185959
# Batch: 60, Loss: 0.15625958144664764
# Batch: 80, Loss: 0.08078523725271225
# Batch: 100, Loss: 0.1462782919406891
# Batch: 120, Loss: 0.07625391334295273
# Batch: 140, Loss: 0.09799695760011673
# Batch: 160, Loss: 0.09787635505199432
# Batch: 180, Loss: 0.11142969876527786
# Batch: 200, Loss: 0.1596001386642456
#
# Average loss: 0.1435, Accuracy: 24818.0/26038 (95%)
#
#
# Average loss: 0.1646, Accuracy: 2777.0/2940 (94%)
#
# Epoch: 8 	Training Accuracy: 95.31%
# Validation Accuracy: 94.46%
# Batch: 0, Loss: 0.07188444584608078
# Batch: 20, Loss: 0.194428488612175
# Batch: 40, Loss: 0.20756734907627106
# Batch: 60, Loss: 0.1123371347784996
# Batch: 80, Loss: 0.09061526507139206
# Batch: 100, Loss: 0.09061480313539505
# Batch: 120, Loss: 0.13024628162384033
# Batch: 140, Loss: 0.1060684323310852
# Batch: 160, Loss: 0.18453389406204224
# Batch: 180, Loss: 0.16580767929553986
# Batch: 200, Loss: 0.08332276344299316
#
# Average loss: 0.1410, Accuracy: 24821.0/26038 (95%)
#
#
# Average loss: 0.1662, Accuracy: 2785.0/2940 (95%)
#
# Epoch: 9 	Training Accuracy: 95.33%
# Validation Accuracy: 94.73%
# Batch: 0, Loss: 0.1913667470216751
# Batch: 20, Loss: 0.20962168276309967
# Batch: 40, Loss: 0.18835172057151794
# Batch: 60, Loss: 0.19890937209129333
# Batch: 80, Loss: 0.1547321379184723
# Batch: 100, Loss: 0.04921294376254082
# Batch: 120, Loss: 0.20552116632461548
# Batch: 140, Loss: 0.13157372176647186
# Batch: 160, Loss: 0.16546639800071716
# Batch: 180, Loss: 0.18483774363994598
# Batch: 200, Loss: 0.09199147671461105
#
# Average loss: 0.1361, Accuracy: 24912.0/26038 (96%)
#
#
# Average loss: 0.1550, Accuracy: 2803.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 95.68%
# Validation Accuracy: 95.34%
# Batch: 0, Loss: 0.12567760050296783
# Batch: 20, Loss: 0.15410417318344116
# Batch: 40, Loss: 0.1878126561641693
# Batch: 60, Loss: 0.1613735556602478
# Batch: 80, Loss: 0.1554815173149109
# Batch: 100, Loss: 0.16186068952083588
# Batch: 120, Loss: 0.14533662796020508
# Batch: 140, Loss: 0.21336348354816437
# Batch: 160, Loss: 0.20315276086330414
# Batch: 180, Loss: 0.09539438039064407
# Batch: 200, Loss: 0.1320374757051468
#
# Average loss: 0.1357, Accuracy: 24896.0/26038 (96%)
#
#
# Average loss: 0.1543, Accuracy: 2792.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 95.61%
# Validation Accuracy: 94.97%
# Batch: 0, Loss: 0.10234341770410538
# Batch: 20, Loss: 0.16022047400474548
# Batch: 40, Loss: 0.10845114290714264
# Batch: 60, Loss: 0.1348353922367096
# Batch: 80, Loss: 0.1403180956840515
# Batch: 100, Loss: 0.05904405564069748
# Batch: 120, Loss: 0.14457443356513977
# Batch: 140, Loss: 0.22655366361141205
# Batch: 160, Loss: 0.1404702216386795
# Batch: 180, Loss: 0.11629296839237213
# Batch: 200, Loss: 0.13224563002586365
#
# Average loss: 0.1514, Accuracy: 24718.0/26038 (95%)
#
#
# Average loss: 0.1688, Accuracy: 2774.0/2940 (94%)
#
# Epoch: 12 	Training Accuracy: 94.93%
# Validation Accuracy: 94.35%
# Batch: 0, Loss: 0.19180232286453247
# Batch: 20, Loss: 0.23900842666625977
# Batch: 40, Loss: 0.14671611785888672
# Batch: 60, Loss: 0.07980294525623322
# Batch: 80, Loss: 0.17928795516490936
# Batch: 100, Loss: 0.1081555038690567
# Batch: 120, Loss: 0.06583280861377716
# Batch: 140, Loss: 0.14068959653377533
# Batch: 160, Loss: 0.10310875624418259
# Batch: 180, Loss: 0.08737754076719284
# Batch: 200, Loss: 0.1596601903438568
#
# Average loss: 0.1293, Accuracy: 24941.0/26038 (96%)
#
#
# Average loss: 0.1506, Accuracy: 2789.0/2940 (95%)
#
# Epoch: 13 	Training Accuracy: 95.79%
# Validation Accuracy: 94.86%
# Batch: 0, Loss: 0.20342522859573364
# Batch: 20, Loss: 0.13976135849952698
# Batch: 40, Loss: 0.1081915870308876
# Batch: 60, Loss: 0.044355444610118866
# Batch: 80, Loss: 0.0834372416138649
# Batch: 100, Loss: 0.16687853634357452
# Batch: 120, Loss: 0.1781357377767563
# Batch: 140, Loss: 0.11283967643976212
# Batch: 160, Loss: 0.11327143013477325
# Batch: 180, Loss: 0.11895345896482468
# Batch: 200, Loss: 0.16020460426807404
#
# Average loss: 0.1199, Accuracy: 25042.0/26038 (96%)
#
#
# Average loss: 0.1421, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 96.17%
# Validation Accuracy: 95.85%
# Batch: 0, Loss: 0.10885575413703918
# Batch: 20, Loss: 0.17217789590358734
# Batch: 40, Loss: 0.06279133260250092
# Batch: 60, Loss: 0.16091687977313995
# Batch: 80, Loss: 0.23442016541957855
# Batch: 100, Loss: 0.14204582571983337
# Batch: 120, Loss: 0.12532085180282593
# Batch: 140, Loss: 0.06698191910982132
# Batch: 160, Loss: 0.11097357422113419
# Batch: 180, Loss: 0.13319116830825806
# Batch: 200, Loss: 0.11066913604736328
#
# Average loss: 0.1250, Accuracy: 24991.0/26038 (96%)
#
#
# Average loss: 0.1459, Accuracy: 2810.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 95.98%
# Validation Accuracy: 95.58%
# Batch: 0, Loss: 0.24467983841896057
# Batch: 20, Loss: 0.21474608778953552
# Batch: 40, Loss: 0.10593417286872864
# Batch: 60, Loss: 0.12440817058086395
# Batch: 80, Loss: 0.14236262440681458
# Batch: 100, Loss: 0.10244221985340118
# Batch: 120, Loss: 0.13726966083049774
# Batch: 140, Loss: 0.04691138118505478
# Batch: 160, Loss: 0.16052067279815674
# Batch: 180, Loss: 0.06449276953935623
# Batch: 200, Loss: 0.08324483782052994
#
# Average loss: 0.1124, Accuracy: 25116.0/26038 (96%)
#
#
# Average loss: 0.1316, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 96.46%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.11423404514789581
# Batch: 20, Loss: 0.15461868047714233
# Batch: 40, Loss: 0.16334886848926544
# Batch: 60, Loss: 0.11709465831518173
# Batch: 80, Loss: 0.1094210296869278
# Batch: 100, Loss: 0.10753835737705231
# Batch: 120, Loss: 0.20321035385131836
# Batch: 140, Loss: 0.13397184014320374
# Batch: 160, Loss: 0.06950106471776962
# Batch: 180, Loss: 0.1598508358001709
# Batch: 200, Loss: 0.09783177822828293
#
# Average loss: 0.1140, Accuracy: 25119.0/26038 (96%)
#
#
# Average loss: 0.1340, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 96.47%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.07950512319803238
# Batch: 20, Loss: 0.0825609564781189
# Batch: 40, Loss: 0.14012479782104492
# Batch: 60, Loss: 0.08114707469940186
# Batch: 80, Loss: 0.1855611503124237
# Batch: 100, Loss: 0.08208663016557693
# Batch: 120, Loss: 0.10092784464359283
# Batch: 140, Loss: 0.105720154941082
# Batch: 160, Loss: 0.27083736658096313
# Batch: 180, Loss: 0.1295730322599411
# Batch: 200, Loss: 0.1490880697965622
#
# Average loss: 0.1088, Accuracy: 25162.0/26038 (97%)
#
#
# Average loss: 0.1275, Accuracy: 2827.0/2940 (96%)
#
# Epoch: 18 	Training Accuracy: 96.64%
# Validation Accuracy: 96.16%
# Batch: 0, Loss: 0.05936286970973015
# Batch: 20, Loss: 0.06618760526180267
# Batch: 40, Loss: 0.06113172695040703
# Batch: 60, Loss: 0.18399958312511444
# Batch: 80, Loss: 0.11871227622032166
# Batch: 100, Loss: 0.0730428695678711
# Batch: 120, Loss: 0.08099181205034256
# Batch: 140, Loss: 0.056344304233789444
# Batch: 160, Loss: 0.11988837271928787
# Batch: 180, Loss: 0.07627461105585098
# Batch: 200, Loss: 0.054338596761226654
#
# Average loss: 0.1178, Accuracy: 25067.0/26038 (96%)
#
#
# Average loss: 0.1413, Accuracy: 2809.0/2940 (96%)
#
# Epoch: 19 	Training Accuracy: 96.27%
# Validation Accuracy: 95.54%
#
# Average loss: 0.1178, Accuracy: 25067.0/26038 (96%)
#
#
# Average loss: 0.1225, Accuracy: 4663.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9627
# Final Test Accuracy (New Data): 0.9593
# Percentage: 0.01, Seed: 10, Epochs taken: 20
# Percentage: 0.01, Seed: 20, Epochs taken: 10
# Percentage: 0.01, Seed: 30, Epochs taken: 7
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 8
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 20
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 10
# Percentage: 0.4, Seed: 30, Epochs taken: 19
# Percentage: 0.4, Seed: 40, Epochs taken: 7
# Percentage: 0.4, Seed: 50, Epochs taken: 19
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 18
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 15
# Percentage: 1, Seed: 40, Epochs taken: 18
# Percentage: 1, Seed: 50, Epochs taken: 20

# %% [markdown]
# ## Only heads and data for new classes

# %% [markdown]
# now with balanced classes

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.0001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test_finetune = {}
results_train_finetune = {}
best_models = {}
data_loaders = {}
epochs_taken_finetune = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Processing percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []
    
    for seed in tqdm(seed_set, desc=f'Running seeds for {perc} data', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")

                # Copying model
        model_new = copy.deepcopy(model)

        # Calculate the output size from the pool layer dynamically
        # You would replace this with the actual size based on your model's architecture
        # model_new.fc_1 = nn.Linear(576, 128)
    
        # Reinitialize the second fully connected layer
        # model_new.fc_2 = nn.Linear(128, 5)
        
        # Ensure the softmax layer matches the number of classes (if used)
        model_new.softmax = nn.Softmax(dim=1)
        
        model_new.to(device)
        
        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)
        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test_finetune[perc] = test_accuracies
    results_train_finetune[perc] = train_accuracies
    epochs_taken_finetune[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken_finetune[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Running seeds for 0.01 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 18 =========================
# Batch: 0, Loss: 0.09205556660890579
#
# Average loss: 0.0824, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1209, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 96.54%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.09937179833650589
#
# Average loss: 0.0798, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1197, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 96.92%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.08839455246925354
#
# Average loss: 0.0778, Accuracy: 253.0/260 (97%)
#
#
# Average loss: 0.1188, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.31%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.08920962363481522
#
# Average loss: 0.0765, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1179, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 96.92%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.0720272958278656
#
# Average loss: 0.0753, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1177, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 96.92%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.05829805135726929
#
# Average loss: 0.0741, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1177, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 96.92%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.0644378811120987
#
# Average loss: 0.0730, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1178, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 96.92%
# Validation Accuracy: 96.80%
# Early stopping invoked.
#
# Average loss: 0.0824, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.0917, Accuracy: 4723.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 60 =========================
# Batch: 0, Loss: 0.1328664869070053
#
# Average loss: 0.1385, Accuracy: 247.0/260 (95%)
#
#
# Average loss: 0.1229, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 95.00%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.1748068779706955
#
# Average loss: 0.1357, Accuracy: 248.0/260 (95%)
#
#
# Average loss: 0.1224, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 95.38%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.1109381765127182
#
# Average loss: 0.1335, Accuracy: 247.0/260 (95%)
#
#
# Average loss: 0.1225, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 95.00%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.12282019108533859
#
# Average loss: 0.1321, Accuracy: 248.0/260 (95%)
#
#
# Average loss: 0.1233, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 95.38%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.11777529120445251
#
# Average loss: 0.1311, Accuracy: 248.0/260 (95%)
#
#
# Average loss: 0.1240, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 95.38%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.1358918696641922
#
# Average loss: 0.1302, Accuracy: 247.0/260 (95%)
#
#
# Average loss: 0.1245, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 95.00%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.17871980369091034
#
# Average loss: 0.1294, Accuracy: 247.0/260 (95%)
#
#
# Average loss: 0.1248, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 95.00%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.10959254205226898
#
# Average loss: 0.1286, Accuracy: 247.0/260 (95%)
#
#
# Average loss: 0.1247, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 95.00%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.1542142629623413
#
# Average loss: 0.1279, Accuracy: 247.0/260 (95%)
#
#
# Average loss: 0.1242, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 8 	Training Accuracy: 95.00%
# Validation Accuracy: 96.80%
# Early stopping invoked.
#
# Average loss: 0.1335, Accuracy: 247.0/260 (95%)
#
#
# Average loss: 0.0927, Accuracy: 4714.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 36 =========================
# Batch: 0, Loss: 0.06035624444484711
#
# Average loss: 0.0570, Accuracy: 255.0/260 (98%)
#
#
# Average loss: 0.1204, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 98.08%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.027868198230862617
#
# Average loss: 0.0555, Accuracy: 256.0/260 (98%)
#
#
# Average loss: 0.1190, Accuracy: 2844.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 98.46%
# Validation Accuracy: 96.73%
# Batch: 0, Loss: 0.048950374126434326
#
# Average loss: 0.0544, Accuracy: 256.0/260 (98%)
#
#
# Average loss: 0.1185, Accuracy: 2843.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 98.46%
# Validation Accuracy: 96.70%
# Batch: 0, Loss: 0.06249302625656128
#
# Average loss: 0.0533, Accuracy: 256.0/260 (98%)
#
#
# Average loss: 0.1184, Accuracy: 2837.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 98.46%
# Validation Accuracy: 96.50%
# Batch: 0, Loss: 0.029301593080163002
#
# Average loss: 0.0522, Accuracy: 256.0/260 (98%)
#
#
# Average loss: 0.1184, Accuracy: 2837.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 98.46%
# Validation Accuracy: 96.50%
# Batch: 0, Loss: 0.06566695123910904
#
# Average loss: 0.0513, Accuracy: 255.0/260 (98%)
#
#
# Average loss: 0.1187, Accuracy: 2837.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 98.08%
# Validation Accuracy: 96.50%
# Batch: 0, Loss: 0.06470464169979095
#
# Average loss: 0.0507, Accuracy: 255.0/260 (98%)
#
#
# Average loss: 0.1195, Accuracy: 2834.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 98.08%
# Validation Accuracy: 96.39%
# Early stopping invoked.
#
# Average loss: 0.0570, Accuracy: 255.0/260 (98%)
#
#
# Average loss: 0.0918, Accuracy: 4717.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 65 =========================
# Batch: 0, Loss: 0.05599689856171608
#
# Average loss: 0.0420, Accuracy: 257.0/260 (99%)
#
#
# Average loss: 0.1210, Accuracy: 2853.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 98.85%
# Validation Accuracy: 97.04%
# Batch: 0, Loss: 0.045056525617837906
#
# Average loss: 0.0402, Accuracy: 258.0/260 (99%)
#
#
# Average loss: 0.1202, Accuracy: 2853.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 99.23%
# Validation Accuracy: 97.04%
# Batch: 0, Loss: 0.052497997879981995
#
# Average loss: 0.0388, Accuracy: 259.0/260 (100%)
#
#
# Average loss: 0.1199, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 99.62%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.037478622049093246
#
# Average loss: 0.0378, Accuracy: 259.0/260 (100%)
#
#
# Average loss: 0.1197, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 99.62%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.03485654667019844
#
# Average loss: 0.0371, Accuracy: 259.0/260 (100%)
#
#
# Average loss: 0.1196, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 99.62%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.03560195490717888
#
# Average loss: 0.0366, Accuracy: 259.0/260 (100%)
#
#
# Average loss: 0.1203, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 99.62%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.02624557353556156
#
# Average loss: 0.0362, Accuracy: 259.0/260 (100%)
#
#
# Average loss: 0.1211, Accuracy: 2853.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 99.62%
# Validation Accuracy: 97.04%
# Early stopping invoked.
#
# Average loss: 0.0420, Accuracy: 257.0/260 (99%)
#
#
# Average loss: 0.0915, Accuracy: 4722.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 18 =========================
# Batch: 0, Loss: 0.09205556660890579
#
# Average loss: 0.0824, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1209, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 96.54%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.09937179833650589
#
# Average loss: 0.0798, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1197, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 96.92%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.08839453756809235
#
# Average loss: 0.0778, Accuracy: 253.0/260 (97%)
#
#
# Average loss: 0.1188, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.31%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.08920963853597641
#
# Average loss: 0.0765, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1179, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 96.92%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.07202727347612381
#
# Average loss: 0.0753, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1177, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 96.92%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.05829806253314018
#
# Average loss: 0.0741, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1177, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 96.92%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.0644378587603569
#
# Average loss: 0.0730, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1178, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 96.92%
# Validation Accuracy: 96.80%
# Early stopping invoked.
#
# Average loss: 0.0824, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.0917, Accuracy: 4723.0/4861 (97%)
# Running seeds for 0.03 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 14 =========================
# Batch: 0, Loss: 0.08881711214780807
#
# Average loss: 0.0846, Accuracy: 767.0/790 (97%)
#
#
# Average loss: 0.1183, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 97.09%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.08221980929374695
#
# Average loss: 0.0804, Accuracy: 770.0/790 (97%)
#
#
# Average loss: 0.1171, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 97.47%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.07423531264066696
#
# Average loss: 0.0782, Accuracy: 770.0/790 (97%)
#
#
# Average loss: 0.1185, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.47%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.061007216572761536
#
# Average loss: 0.0765, Accuracy: 771.0/790 (98%)
#
#
# Average loss: 0.1192, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 97.59%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.10720138251781464
#
# Average loss: 0.0749, Accuracy: 771.0/790 (98%)
#
#
# Average loss: 0.1190, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.59%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.0608883872628212
#
# Average loss: 0.0736, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1192, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.72%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.1042952761054039
#
# Average loss: 0.0725, Accuracy: 774.0/790 (98%)
#
#
# Average loss: 0.1201, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.97%
# Validation Accuracy: 96.77%
# Early stopping invoked.
#
# Average loss: 0.0846, Accuracy: 767.0/790 (97%)
#
#
# Average loss: 0.0902, Accuracy: 4723.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 84 =========================
# Batch: 0, Loss: 0.023757491260766983
#
# Average loss: 0.0818, Accuracy: 767.0/790 (97%)
#
#
# Average loss: 0.1180, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 97.09%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.032743845134973526
#
# Average loss: 0.0760, Accuracy: 769.0/790 (97%)
#
#
# Average loss: 0.1180, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 97.34%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.07464209198951721
#
# Average loss: 0.0735, Accuracy: 771.0/790 (98%)
#
#
# Average loss: 0.1205, Accuracy: 2843.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.59%
# Validation Accuracy: 96.70%
# Batch: 0, Loss: 0.0639185905456543
#
# Average loss: 0.0728, Accuracy: 770.0/790 (97%)
#
#
# Average loss: 0.1223, Accuracy: 2837.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 97.47%
# Validation Accuracy: 96.50%
# Batch: 0, Loss: 0.0830027237534523
#
# Average loss: 0.0718, Accuracy: 770.0/790 (97%)
#
#
# Average loss: 0.1228, Accuracy: 2839.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.47%
# Validation Accuracy: 96.56%
# Batch: 0, Loss: 0.07023399323225021
#
# Average loss: 0.0711, Accuracy: 770.0/790 (97%)
#
#
# Average loss: 0.1240, Accuracy: 2838.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.47%
# Validation Accuracy: 96.53%
# Batch: 0, Loss: 0.10426139831542969
#
# Average loss: 0.0703, Accuracy: 770.0/790 (97%)
#
#
# Average loss: 0.1246, Accuracy: 2837.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.47%
# Validation Accuracy: 96.50%
# Early stopping invoked.
#
# Average loss: 0.0818, Accuracy: 767.0/790 (97%)
#
#
# Average loss: 0.0904, Accuracy: 4726.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 33 =========================
# Batch: 0, Loss: 0.11806103587150574
#
# Average loss: 0.1002, Accuracy: 762.0/790 (96%)
#
#
# Average loss: 0.1194, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 96.46%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.05642583966255188
#
# Average loss: 0.0986, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.1206, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 96.33%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.09687857329845428
#
# Average loss: 0.0971, Accuracy: 762.0/790 (96%)
#
#
# Average loss: 0.1200, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 96.46%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.07726395130157471
#
# Average loss: 0.0963, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.1208, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 96.33%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.09321863204240799
#
# Average loss: 0.0953, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.1199, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 96.33%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.12214931845664978
#
# Average loss: 0.0946, Accuracy: 762.0/790 (96%)
#
#
# Average loss: 0.1191, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 96.46%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.15054358541965485
#
# Average loss: 0.0937, Accuracy: 763.0/790 (97%)
#
#
# Average loss: 0.1190, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 96.58%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.08851257711648941
#
# Average loss: 0.0929, Accuracy: 763.0/790 (97%)
#
#
# Average loss: 0.1196, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 96.58%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.11079831421375275
#
# Average loss: 0.0922, Accuracy: 762.0/790 (96%)
#
#
# Average loss: 0.1195, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 8 	Training Accuracy: 96.46%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.13676269352436066
#
# Average loss: 0.0914, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.1196, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 9 	Training Accuracy: 96.33%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.12880516052246094
#
# Average loss: 0.0907, Accuracy: 763.0/790 (97%)
#
#
# Average loss: 0.1197, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 10 	Training Accuracy: 96.58%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.06531742960214615
#
# Average loss: 0.0900, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.1201, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 11 	Training Accuracy: 96.33%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.13655301928520203
#
# Average loss: 0.0893, Accuracy: 763.0/790 (97%)
#
#
# Average loss: 0.1198, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 12 	Training Accuracy: 96.58%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.05657785385847092
#
# Average loss: 0.0887, Accuracy: 764.0/790 (97%)
#
#
# Average loss: 0.1196, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 13 	Training Accuracy: 96.71%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.09369973093271255
#
# Average loss: 0.0884, Accuracy: 764.0/790 (97%)
#
#
# Average loss: 0.1193, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 14 	Training Accuracy: 96.71%
# Validation Accuracy: 96.94%
# Early stopping invoked.
#
# Average loss: 0.0922, Accuracy: 762.0/790 (96%)
#
#
# Average loss: 0.0918, Accuracy: 4717.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 22 =========================
# Batch: 0, Loss: 0.11491260677576065
#
# Average loss: 0.1145, Accuracy: 764.0/790 (97%)
#
#
# Average loss: 0.1187, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 96.71%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.14707699418067932
#
# Average loss: 0.1113, Accuracy: 765.0/790 (97%)
#
#
# Average loss: 0.1178, Accuracy: 2837.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 96.84%
# Validation Accuracy: 96.50%
# Batch: 0, Loss: 0.14601978659629822
#
# Average loss: 0.1098, Accuracy: 764.0/790 (97%)
#
#
# Average loss: 0.1185, Accuracy: 2836.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 96.71%
# Validation Accuracy: 96.46%
# Batch: 0, Loss: 0.06079522520303726
#
# Average loss: 0.1083, Accuracy: 765.0/790 (97%)
#
#
# Average loss: 0.1184, Accuracy: 2836.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 96.84%
# Validation Accuracy: 96.46%
# Batch: 0, Loss: 0.12266287952661514
#
# Average loss: 0.1070, Accuracy: 766.0/790 (97%)
#
#
# Average loss: 0.1182, Accuracy: 2837.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 96.96%
# Validation Accuracy: 96.50%
# Batch: 0, Loss: 0.10492239892482758
#
# Average loss: 0.1060, Accuracy: 766.0/790 (97%)
#
#
# Average loss: 0.1185, Accuracy: 2837.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 96.96%
# Validation Accuracy: 96.50%
# Batch: 0, Loss: 0.09163734316825867
#
# Average loss: 0.1045, Accuracy: 766.0/790 (97%)
#
#
# Average loss: 0.1178, Accuracy: 2837.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 96.96%
# Validation Accuracy: 96.50%
# Early stopping invoked.
#
# Average loss: 0.1145, Accuracy: 764.0/790 (97%)
#
#
# Average loss: 0.0914, Accuracy: 4714.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 57 =========================
# Batch: 0, Loss: 0.10429093986749649
#
# Average loss: 0.0906, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1219, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 97.72%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.06405656784772873
#
# Average loss: 0.0884, Accuracy: 774.0/790 (98%)
#
#
# Average loss: 0.1214, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 97.97%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.1338627189397812
#
# Average loss: 0.0868, Accuracy: 774.0/790 (98%)
#
#
# Average loss: 0.1218, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.97%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.04630588740110397
#
# Average loss: 0.0857, Accuracy: 773.0/790 (98%)
#
#
# Average loss: 0.1221, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 97.85%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.09473538398742676
#
# Average loss: 0.0846, Accuracy: 773.0/790 (98%)
#
#
# Average loss: 0.1218, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.85%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.10112325847148895
#
# Average loss: 0.0834, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1218, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.72%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.10557570308446884
#
# Average loss: 0.0822, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1225, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.72%
# Validation Accuracy: 96.97%
# Early stopping invoked.
#
# Average loss: 0.0906, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.0918, Accuracy: 4720.0/4861 (97%)
# Running seeds for 0.05 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 43 =========================
# Batch: 0, Loss: 0.16175709664821625
#
# Average loss: 0.1137, Accuracy: 1275.0/1320 (97%)
#
#
# Average loss: 0.1171, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 96.59%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.10168905556201935
#
# Average loss: 0.1116, Accuracy: 1276.0/1320 (97%)
#
#
# Average loss: 0.1170, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 96.67%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.0753435268998146
#
# Average loss: 0.1096, Accuracy: 1279.0/1320 (97%)
#
#
# Average loss: 0.1171, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 96.89%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.03605442866683006
#
# Average loss: 0.1082, Accuracy: 1279.0/1320 (97%)
#
#
# Average loss: 0.1177, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 96.89%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.1837719976902008
#
# Average loss: 0.1069, Accuracy: 1281.0/1320 (97%)
#
#
# Average loss: 0.1170, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.05%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.14224529266357422
#
# Average loss: 0.1058, Accuracy: 1284.0/1320 (97%)
#
#
# Average loss: 0.1174, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.27%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.13553056120872498
#
# Average loss: 0.1047, Accuracy: 1284.0/1320 (97%)
#
#
# Average loss: 0.1171, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.27%
# Validation Accuracy: 96.80%
# Early stopping invoked.
#
# Average loss: 0.1137, Accuracy: 1275.0/1320 (97%)
#
#
# Average loss: 0.0905, Accuracy: 4719.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 28 =========================
# Batch: 0, Loss: 0.12853248417377472
#
# Average loss: 0.0840, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.1211, Accuracy: 2854.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 97.42%
# Validation Accuracy: 97.07%
# Batch: 0, Loss: 0.06367027759552002
#
# Average loss: 0.0825, Accuracy: 1283.0/1320 (97%)
#
#
# Average loss: 0.1185, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 97.20%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.09615276753902435
#
# Average loss: 0.0809, Accuracy: 1283.0/1320 (97%)
#
#
# Average loss: 0.1190, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.20%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.07472745329141617
#
# Average loss: 0.0798, Accuracy: 1283.0/1320 (97%)
#
#
# Average loss: 0.1181, Accuracy: 2853.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 97.20%
# Validation Accuracy: 97.04%
# Batch: 0, Loss: 0.10042218118906021
#
# Average loss: 0.0785, Accuracy: 1287.0/1320 (98%)
#
#
# Average loss: 0.1192, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.50%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.13042229413986206
#
# Average loss: 0.0774, Accuracy: 1288.0/1320 (98%)
#
#
# Average loss: 0.1193, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.58%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.05934074521064758
#
# Average loss: 0.0767, Accuracy: 1288.0/1320 (98%)
#
#
# Average loss: 0.1177, Accuracy: 2854.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.58%
# Validation Accuracy: 97.07%
# Early stopping invoked.
#
# Average loss: 0.0840, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.0916, Accuracy: 4719.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 20 =========================
# Batch: 0, Loss: 0.09547571837902069
#
# Average loss: 0.0937, Accuracy: 1277.0/1320 (97%)
#
#
# Average loss: 0.1180, Accuracy: 2844.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 96.74%
# Validation Accuracy: 96.73%
# Batch: 0, Loss: 0.06579778343439102
#
# Average loss: 0.0913, Accuracy: 1279.0/1320 (97%)
#
#
# Average loss: 0.1183, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 96.89%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.12984761595726013
#
# Average loss: 0.0898, Accuracy: 1277.0/1320 (97%)
#
#
# Average loss: 0.1178, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 96.74%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.09478338062763214
#
# Average loss: 0.0888, Accuracy: 1279.0/1320 (97%)
#
#
# Average loss: 0.1184, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 96.89%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.07417896389961243
#
# Average loss: 0.0876, Accuracy: 1279.0/1320 (97%)
#
#
# Average loss: 0.1174, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 96.89%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.0784633606672287
#
# Average loss: 0.0864, Accuracy: 1280.0/1320 (97%)
#
#
# Average loss: 0.1178, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 96.97%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.09824559837579727
#
# Average loss: 0.0854, Accuracy: 1280.0/1320 (97%)
#
#
# Average loss: 0.1183, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 96.97%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.10422911494970322
#
# Average loss: 0.0846, Accuracy: 1281.0/1320 (97%)
#
#
# Average loss: 0.1182, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 97.05%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.07533595710992813
#
# Average loss: 0.0836, Accuracy: 1281.0/1320 (97%)
#
#
# Average loss: 0.1188, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 8 	Training Accuracy: 97.05%
# Validation Accuracy: 96.90%
# Early stopping invoked.
#
# Average loss: 0.0898, Accuracy: 1277.0/1320 (97%)
#
#
# Average loss: 0.0908, Accuracy: 4723.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 34 =========================
# Batch: 0, Loss: 0.15656207501888275
#
# Average loss: 0.1005, Accuracy: 1281.0/1320 (97%)
#
#
# Average loss: 0.1189, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 97.05%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.09999928623437881
#
# Average loss: 0.0976, Accuracy: 1282.0/1320 (97%)
#
#
# Average loss: 0.1170, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 97.12%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.15425710380077362
#
# Average loss: 0.0963, Accuracy: 1282.0/1320 (97%)
#
#
# Average loss: 0.1171, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.12%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.13731664419174194
#
# Average loss: 0.0951, Accuracy: 1282.0/1320 (97%)
#
#
# Average loss: 0.1173, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 97.12%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.15393686294555664
#
# Average loss: 0.0940, Accuracy: 1282.0/1320 (97%)
#
#
# Average loss: 0.1175, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.12%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.06908807158470154
#
# Average loss: 0.0930, Accuracy: 1283.0/1320 (97%)
#
#
# Average loss: 0.1173, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.20%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.05820508301258087
#
# Average loss: 0.0920, Accuracy: 1283.0/1320 (97%)
#
#
# Average loss: 0.1173, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.20%
# Validation Accuracy: 96.80%
# Early stopping invoked.
#
# Average loss: 0.1005, Accuracy: 1281.0/1320 (97%)
#
#
# Average loss: 0.0909, Accuracy: 4725.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 74 =========================
# Batch: 0, Loss: 0.07361814379692078
#
# Average loss: 0.0934, Accuracy: 1284.0/1320 (97%)
#
#
# Average loss: 0.1221, Accuracy: 2856.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 97.27%
# Validation Accuracy: 97.14%
# Batch: 0, Loss: 0.051012713462114334
#
# Average loss: 0.0923, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.1197, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 97.42%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.06438543647527695
#
# Average loss: 0.0914, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.1214, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.42%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.052411891520023346
#
# Average loss: 0.0906, Accuracy: 1287.0/1320 (98%)
#
#
# Average loss: 0.1210, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 97.50%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.09258250147104263
#
# Average loss: 0.0899, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.1209, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.42%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.053333405405282974
#
# Average loss: 0.0892, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.1201, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.42%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.10412515699863434
#
# Average loss: 0.0886, Accuracy: 1288.0/1320 (98%)
#
#
# Average loss: 0.1196, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.58%
# Validation Accuracy: 96.80%
# Early stopping invoked.
#
# Average loss: 0.0934, Accuracy: 1284.0/1320 (97%)
#
#
# Average loss: 0.0921, Accuracy: 4716.0/4861 (97%)
# Running seeds for 0.1 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 35 =========================
# Batch: 0, Loss: 0.0998430997133255
# Batch: 20, Loss: 0.14858666062355042
#
# Average loss: 0.1060, Accuracy: 2558.0/2645 (97%)
#
#
# Average loss: 0.1170, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 96.71%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.13177408277988434
# Batch: 20, Loss: 0.08675596117973328
#
# Average loss: 0.1046, Accuracy: 2559.0/2645 (97%)
#
#
# Average loss: 0.1163, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 96.75%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.11709688603878021
# Batch: 20, Loss: 0.190388023853302
#
# Average loss: 0.1033, Accuracy: 2560.0/2645 (97%)
#
#
# Average loss: 0.1165, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 96.79%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.11001162230968475
# Batch: 20, Loss: 0.04484397917985916
#
# Average loss: 0.1024, Accuracy: 2558.0/2645 (97%)
#
#
# Average loss: 0.1166, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 96.71%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.07228927314281464
# Batch: 20, Loss: 0.06135166808962822
#
# Average loss: 0.1013, Accuracy: 2562.0/2645 (97%)
#
#
# Average loss: 0.1162, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 96.86%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.10862789303064346
# Batch: 20, Loss: 0.0813635066151619
#
# Average loss: 0.1005, Accuracy: 2563.0/2645 (97%)
#
#
# Average loss: 0.1163, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 96.90%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.11944307386875153
# Batch: 20, Loss: 0.09528497606515884
#
# Average loss: 0.0995, Accuracy: 2562.0/2645 (97%)
#
#
# Average loss: 0.1159, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 96.86%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.0849481150507927
# Batch: 20, Loss: 0.14232556521892548
#
# Average loss: 0.0988, Accuracy: 2559.0/2645 (97%)
#
#
# Average loss: 0.1163, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 96.75%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.09395395219326019
# Batch: 20, Loss: 0.10192234069108963
#
# Average loss: 0.0981, Accuracy: 2561.0/2645 (97%)
#
#
# Average loss: 0.1156, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 8 	Training Accuracy: 96.82%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.15207846462726593
# Batch: 20, Loss: 0.10119511932134628
#
# Average loss: 0.0973, Accuracy: 2564.0/2645 (97%)
#
#
# Average loss: 0.1158, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 9 	Training Accuracy: 96.94%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.1147245317697525
# Batch: 20, Loss: 0.041783593595027924
#
# Average loss: 0.0965, Accuracy: 2564.0/2645 (97%)
#
#
# Average loss: 0.1159, Accuracy: 2854.0/2940 (97%)
#
# Epoch: 10 	Training Accuracy: 96.94%
# Validation Accuracy: 97.07%
# Batch: 0, Loss: 0.08590308576822281
# Batch: 20, Loss: 0.045037806034088135
#
# Average loss: 0.0962, Accuracy: 2564.0/2645 (97%)
#
#
# Average loss: 0.1159, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 11 	Training Accuracy: 96.94%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.07250381261110306
# Batch: 20, Loss: 0.0815180242061615
#
# Average loss: 0.0954, Accuracy: 2563.0/2645 (97%)
#
#
# Average loss: 0.1160, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 12 	Training Accuracy: 96.90%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.09961020946502686
# Batch: 20, Loss: 0.08600745350122452
#
# Average loss: 0.0948, Accuracy: 2563.0/2645 (97%)
#
#
# Average loss: 0.1160, Accuracy: 2853.0/2940 (97%)
#
# Epoch: 13 	Training Accuracy: 96.90%
# Validation Accuracy: 97.04%
# Batch: 0, Loss: 0.09050071984529495
# Batch: 20, Loss: 0.11649532616138458
#
# Average loss: 0.0943, Accuracy: 2563.0/2645 (97%)
#
#
# Average loss: 0.1164, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 14 	Training Accuracy: 96.90%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.09741374850273132
# Batch: 20, Loss: 0.11346976459026337
#
# Average loss: 0.0937, Accuracy: 2564.0/2645 (97%)
#
#
# Average loss: 0.1158, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 15 	Training Accuracy: 96.94%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.06425103545188904
# Batch: 20, Loss: 0.15500974655151367
#
# Average loss: 0.0932, Accuracy: 2563.0/2645 (97%)
#
#
# Average loss: 0.1163, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 16 	Training Accuracy: 96.90%
# Validation Accuracy: 97.01%
# Early stopping invoked.
#
# Average loss: 0.0965, Accuracy: 2564.0/2645 (97%)
#
#
# Average loss: 0.0896, Accuracy: 4727.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 93 =========================
# Batch: 0, Loss: 0.09011924266815186
# Batch: 20, Loss: 0.12383110076189041
#
# Average loss: 0.0954, Accuracy: 2567.0/2645 (97%)
#
#
# Average loss: 0.1171, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 97.05%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.05264229699969292
# Batch: 20, Loss: 0.05970464646816254
#
# Average loss: 0.0943, Accuracy: 2567.0/2645 (97%)
#
#
# Average loss: 0.1173, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 97.05%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.08336714655160904
# Batch: 20, Loss: 0.0798904225230217
#
# Average loss: 0.0935, Accuracy: 2568.0/2645 (97%)
#
#
# Average loss: 0.1173, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.09%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.03911421820521355
# Batch: 20, Loss: 0.03884868323802948
#
# Average loss: 0.0927, Accuracy: 2570.0/2645 (97%)
#
#
# Average loss: 0.1173, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 97.16%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.035141825675964355
# Batch: 20, Loss: 0.053812261670827866
#
# Average loss: 0.0920, Accuracy: 2568.0/2645 (97%)
#
#
# Average loss: 0.1175, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.09%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.1432156264781952
# Batch: 20, Loss: 0.07907477021217346
#
# Average loss: 0.0914, Accuracy: 2570.0/2645 (97%)
#
#
# Average loss: 0.1169, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.16%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.15773600339889526
# Batch: 20, Loss: 0.07308115810155869
#
# Average loss: 0.0907, Accuracy: 2569.0/2645 (97%)
#
#
# Average loss: 0.1176, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.13%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.08471251279115677
# Batch: 20, Loss: 0.2052052915096283
#
# Average loss: 0.0902, Accuracy: 2572.0/2645 (97%)
#
#
# Average loss: 0.1172, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 97.24%
# Validation Accuracy: 96.84%
# Early stopping invoked.
#
# Average loss: 0.0943, Accuracy: 2567.0/2645 (97%)
#
#
# Average loss: 0.0899, Accuracy: 4727.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 12 =========================
# Batch: 0, Loss: 0.15360461175441742
# Batch: 20, Loss: 0.048438213765621185
#
# Average loss: 0.0987, Accuracy: 2562.0/2645 (97%)
#
#
# Average loss: 0.1175, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 96.86%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.07438018172979355
# Batch: 20, Loss: 0.034988436847925186
#
# Average loss: 0.0975, Accuracy: 2564.0/2645 (97%)
#
#
# Average loss: 0.1180, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 96.94%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.035177700221538544
# Batch: 20, Loss: 0.14705969393253326
#
# Average loss: 0.0965, Accuracy: 2565.0/2645 (97%)
#
#
# Average loss: 0.1181, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 96.98%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.13230690360069275
# Batch: 20, Loss: 0.04134540632367134
#
# Average loss: 0.0956, Accuracy: 2566.0/2645 (97%)
#
#
# Average loss: 0.1187, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 97.01%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.13747204840183258
# Batch: 20, Loss: 0.053455788642168045
#
# Average loss: 0.0948, Accuracy: 2566.0/2645 (97%)
#
#
# Average loss: 0.1192, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.01%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.12345553189516068
# Batch: 20, Loss: 0.07104705274105072
#
# Average loss: 0.0941, Accuracy: 2565.0/2645 (97%)
#
#
# Average loss: 0.1188, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 96.98%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.09268345683813095
# Batch: 20, Loss: 0.12081911414861679
#
# Average loss: 0.0933, Accuracy: 2568.0/2645 (97%)
#
#
# Average loss: 0.1191, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.09%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.08384488523006439
# Batch: 20, Loss: 0.16462372243404388
#
# Average loss: 0.0925, Accuracy: 2568.0/2645 (97%)
#
#
# Average loss: 0.1199, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 97.09%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.11634891480207443
# Batch: 20, Loss: 0.10703177750110626
#
# Average loss: 0.0918, Accuracy: 2568.0/2645 (97%)
#
#
# Average loss: 0.1197, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 8 	Training Accuracy: 97.09%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.09733778983354568
# Batch: 20, Loss: 0.040480609983205795
#
# Average loss: 0.0911, Accuracy: 2569.0/2645 (97%)
#
#
# Average loss: 0.1204, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 9 	Training Accuracy: 97.13%
# Validation Accuracy: 96.87%
# Early stopping invoked.
#
# Average loss: 0.0956, Accuracy: 2566.0/2645 (97%)
#
#
# Average loss: 0.0911, Accuracy: 4723.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 32 =========================
# Batch: 0, Loss: 0.10311441123485565
# Batch: 20, Loss: 0.07670709490776062
#
# Average loss: 0.0773, Accuracy: 2575.0/2645 (97%)
#
#
# Average loss: 0.1172, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 97.35%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.03461536392569542
# Batch: 20, Loss: 0.0963008850812912
#
# Average loss: 0.0762, Accuracy: 2574.0/2645 (97%)
#
#
# Average loss: 0.1175, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 97.32%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.1086379811167717
# Batch: 20, Loss: 0.03261560574173927
#
# Average loss: 0.0752, Accuracy: 2577.0/2645 (97%)
#
#
# Average loss: 0.1180, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.43%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.0341208316385746
# Batch: 20, Loss: 0.10296998918056488
#
# Average loss: 0.0745, Accuracy: 2579.0/2645 (98%)
#
#
# Average loss: 0.1181, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 97.50%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.1371835619211197
# Batch: 20, Loss: 0.09025737643241882
#
# Average loss: 0.0738, Accuracy: 2580.0/2645 (98%)
#
#
# Average loss: 0.1184, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.54%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.11253403127193451
# Batch: 20, Loss: 0.13567586243152618
#
# Average loss: 0.0730, Accuracy: 2581.0/2645 (98%)
#
#
# Average loss: 0.1187, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.58%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.06900335103273392
# Batch: 20, Loss: 0.047003213316202164
#
# Average loss: 0.0723, Accuracy: 2580.0/2645 (98%)
#
#
# Average loss: 0.1189, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.54%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.07408992946147919
# Batch: 20, Loss: 0.030062898993492126
#
# Average loss: 0.0717, Accuracy: 2584.0/2645 (98%)
#
#
# Average loss: 0.1191, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 97.69%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.07272136956453323
# Batch: 20, Loss: 0.09172625839710236
#
# Average loss: 0.0712, Accuracy: 2582.0/2645 (98%)
#
#
# Average loss: 0.1189, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 8 	Training Accuracy: 97.62%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.06775808334350586
# Batch: 20, Loss: 0.06883322447538376
#
# Average loss: 0.0705, Accuracy: 2581.0/2645 (98%)
#
#
# Average loss: 0.1194, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 9 	Training Accuracy: 97.58%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.06561204791069031
# Batch: 20, Loss: 0.04087885469198227
#
# Average loss: 0.0700, Accuracy: 2582.0/2645 (98%)
#
#
# Average loss: 0.1199, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 10 	Training Accuracy: 97.62%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.06396506726741791
# Batch: 20, Loss: 0.028363438323140144
#
# Average loss: 0.0695, Accuracy: 2583.0/2645 (98%)
#
#
# Average loss: 0.1195, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 11 	Training Accuracy: 97.66%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.021174777299165726
# Batch: 20, Loss: 0.016776273027062416
#
# Average loss: 0.0690, Accuracy: 2583.0/2645 (98%)
#
#
# Average loss: 0.1199, Accuracy: 2843.0/2940 (97%)
#
# Epoch: 12 	Training Accuracy: 97.66%
# Validation Accuracy: 96.70%
# Batch: 0, Loss: 0.08408068120479584
# Batch: 20, Loss: 0.07941615581512451
#
# Average loss: 0.0685, Accuracy: 2582.0/2645 (98%)
#
#
# Average loss: 0.1201, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 13 	Training Accuracy: 97.62%
# Validation Accuracy: 96.80%
# Early stopping invoked.
#
# Average loss: 0.0717, Accuracy: 2584.0/2645 (98%)
#
#
# Average loss: 0.0920, Accuracy: 4721.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
# ...
# Batch: 180, Loss: 0.10473213344812393
# Batch: 200, Loss: 0.1073397621512413
#
# Average loss: 0.0912, Accuracy: 25307.0/26038 (97%)
#
#
# Average loss: 0.1149, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.19%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.10920372605323792
# Batch: 20, Loss: 0.05891576409339905
# Batch: 40, Loss: 0.07017155736684799
# Batch: 60, Loss: 0.09742093831300735
# Batch: 80, Loss: 0.05369260907173157
# Batch: 100, Loss: 0.0933881476521492
# Batch: 120, Loss: 0.13346250355243683
# Batch: 140, Loss: 0.10355111956596375
# Batch: 160, Loss: 0.02969900704920292
# Batch: 180, Loss: 0.1609896570444107
# Batch: 200, Loss: 0.13904204964637756
#
# Average loss: 0.0923, Accuracy: 25284.0/26038 (97%)
#
#
# Average loss: 0.1183, Accuracy: 2855.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 97.10%
# Validation Accuracy: 97.11%
# Batch: 0, Loss: 0.1764434576034546
# Batch: 20, Loss: 0.0541987307369709
# Batch: 40, Loss: 0.04737871140241623
# Batch: 60, Loss: 0.10493607819080353
# Batch: 80, Loss: 0.10731563717126846
# Batch: 100, Loss: 0.0447235107421875
# Batch: 120, Loss: 0.1376141607761383
# Batch: 140, Loss: 0.07296367734670639
# Batch: 160, Loss: 0.07064583897590637
# Batch: 180, Loss: 0.073011115193367
# Batch: 200, Loss: 0.09387226402759552
#
# Average loss: 0.0903, Accuracy: 25312.0/26038 (97%)
#
#
# Average loss: 0.1156, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.21%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.11271040141582489
# Batch: 20, Loss: 0.08426930010318756
# Batch: 40, Loss: 0.02667059749364853
# Batch: 60, Loss: 0.09878992289304733
# Batch: 80, Loss: 0.0773535966873169
# Batch: 100, Loss: 0.09671594202518463
# Batch: 120, Loss: 0.06475551426410675
# Batch: 140, Loss: 0.0876716896891594
# Batch: 160, Loss: 0.029142193496227264
# Batch: 180, Loss: 0.12432876974344254
# Batch: 200, Loss: 0.11128371208906174
#
# Average loss: 0.0897, Accuracy: 25321.0/26038 (97%)
#
#
# Average loss: 0.1145, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.25%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.05410356819629669
# Batch: 20, Loss: 0.0946003720164299
# Batch: 40, Loss: 0.08362974226474762
# Batch: 60, Loss: 0.07026752084493637
# Batch: 80, Loss: 0.12438176572322845
# Batch: 100, Loss: 0.06412376463413239
# Batch: 120, Loss: 0.10510829091072083
# Batch: 140, Loss: 0.06308570504188538
# Batch: 160, Loss: 0.11141827702522278
# Batch: 180, Loss: 0.04884616285562515
# Batch: 200, Loss: 0.11864064633846283
#
# Average loss: 0.0895, Accuracy: 25318.0/26038 (97%)
#
#
# Average loss: 0.1146, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.23%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.052749406546354294
# Batch: 20, Loss: 0.10719417035579681
# Batch: 40, Loss: 0.09354828298091888
# Batch: 60, Loss: 0.12142182141542435
# Batch: 80, Loss: 0.11685492098331451
# Batch: 100, Loss: 0.15052135288715363
# Batch: 120, Loss: 0.06488557159900665
# Batch: 140, Loss: 0.10504739731550217
# Batch: 160, Loss: 0.03560406714677811
# Batch: 180, Loss: 0.05845958739519119
# Batch: 200, Loss: 0.09732471406459808
#
# Average loss: 0.0891, Accuracy: 25334.0/26038 (97%)
#
#
# Average loss: 0.1144, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 97.30%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.07163698971271515
# Batch: 20, Loss: 0.19880153238773346
# Batch: 40, Loss: 0.04655525088310242
# Batch: 60, Loss: 0.056289564818143845
# Batch: 80, Loss: 0.033904120326042175
# Batch: 100, Loss: 0.10129044204950333
# Batch: 120, Loss: 0.07343051582574844
# Batch: 140, Loss: 0.10684779286384583
# Batch: 160, Loss: 0.11544004082679749
# Batch: 180, Loss: 0.08694465458393097
# Batch: 200, Loss: 0.10724972188472748
#
# Average loss: 0.0896, Accuracy: 25309.0/26038 (97%)
#
#
# Average loss: 0.1162, Accuracy: 2854.0/2940 (97%)
#
# Epoch: 8 	Training Accuracy: 97.20%
# Validation Accuracy: 97.07%
# Batch: 0, Loss: 0.09317392855882645
# Batch: 20, Loss: 0.1331232190132141
# Batch: 40, Loss: 0.14525273442268372
# Batch: 60, Loss: 0.11036200076341629
# Batch: 80, Loss: 0.13676878809928894
# Batch: 100, Loss: 0.12396994233131409
# Batch: 120, Loss: 0.11165022850036621
# Batch: 140, Loss: 0.11585769057273865
# Batch: 160, Loss: 0.044804640114307404
# Batch: 180, Loss: 0.060174793004989624
# Batch: 200, Loss: 0.031943172216415405
#
# Average loss: 0.0885, Accuracy: 25331.0/26038 (97%)
#
#
# Average loss: 0.1149, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 9 	Training Accuracy: 97.28%
# Validation Accuracy: 97.01%
# Early stopping invoked.
#
# Average loss: 0.0923, Accuracy: 25284.0/26038 (97%)
#
#
# Average loss: 0.0901, Accuracy: 4715.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 96 =========================
# Batch: 0, Loss: 0.0993097797036171
# Batch: 20, Loss: 0.07110687345266342
# Batch: 40, Loss: 0.14216040074825287
# Batch: 60, Loss: 0.05871374532580376
# Batch: 80, Loss: 0.11037535220384598
# Batch: 100, Loss: 0.09446602314710617
# Batch: 120, Loss: 0.06955203413963318
# Batch: 140, Loss: 0.16238552331924438
# Batch: 160, Loss: 0.0757259950041771
# Batch: 180, Loss: 0.07601533830165863
# Batch: 200, Loss: 0.058112967759370804
#
# Average loss: 0.0927, Accuracy: 25294.0/26038 (97%)
#
#
# Average loss: 0.1160, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 0 	Training Accuracy: 97.14%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.0529976412653923
# Batch: 20, Loss: 0.09975320845842361
# Batch: 40, Loss: 0.12808726727962494
# Batch: 60, Loss: 0.04862863942980766
# Batch: 80, Loss: 0.11367589235305786
# Batch: 100, Loss: 0.07708428800106049
# Batch: 120, Loss: 0.04528336971998215
# Batch: 140, Loss: 0.09030714631080627
# Batch: 160, Loss: 0.0926080271601677
# Batch: 180, Loss: 0.1231154054403305
# Batch: 200, Loss: 0.14300569891929626
#
# Average loss: 0.0921, Accuracy: 25301.0/26038 (97%)
#
#
# Average loss: 0.1156, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 1 	Training Accuracy: 97.17%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.10274630039930344
# Batch: 20, Loss: 0.0876307487487793
# Batch: 40, Loss: 0.044399768114089966
# Batch: 60, Loss: 0.06732512265443802
# Batch: 80, Loss: 0.20131677389144897
# Batch: 100, Loss: 0.140959233045578
# Batch: 120, Loss: 0.11415328085422516
# Batch: 140, Loss: 0.08385995775461197
# Batch: 160, Loss: 0.0950932651758194
# Batch: 180, Loss: 0.06545033305883408
# Batch: 200, Loss: 0.1146431714296341
#
# Average loss: 0.0916, Accuracy: 25297.0/26038 (97%)
#
#
# Average loss: 0.1152, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 2 	Training Accuracy: 97.15%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.12605786323547363
# Batch: 20, Loss: 0.07186614722013474
# Batch: 40, Loss: 0.13615921139717102
# Batch: 60, Loss: 0.06999635696411133
# Batch: 80, Loss: 0.1855040192604065
# Batch: 100, Loss: 0.04169046878814697
# Batch: 120, Loss: 0.03929702192544937
# Batch: 140, Loss: 0.12108483165502548
# Batch: 160, Loss: 0.06679554283618927
# Batch: 180, Loss: 0.07469379901885986
# Batch: 200, Loss: 0.100594162940979
#
# Average loss: 0.0910, Accuracy: 25297.0/26038 (97%)
#
#
# Average loss: 0.1151, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 97.15%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.04268272593617439
# Batch: 20, Loss: 0.12643857300281525
# Batch: 40, Loss: 0.06469852477312088
# Batch: 60, Loss: 0.03792453184723854
# Batch: 80, Loss: 0.12099182605743408
# Batch: 100, Loss: 0.08092676103115082
# Batch: 120, Loss: 0.028475377708673477
# Batch: 140, Loss: 0.1273297816514969
# Batch: 160, Loss: 0.08178718388080597
# Batch: 180, Loss: 0.11752043664455414
# Batch: 200, Loss: 0.06953281909227371
#
# Average loss: 0.0913, Accuracy: 25300.0/26038 (97%)
#
#
# Average loss: 0.1161, Accuracy: 2853.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.17%
# Validation Accuracy: 97.04%
# Batch: 0, Loss: 0.10922318696975708
# Batch: 20, Loss: 0.11832505464553833
# Batch: 40, Loss: 0.18397998809814453
# Batch: 60, Loss: 0.06502462178468704
# Batch: 80, Loss: 0.17456987500190735
# Batch: 100, Loss: 0.04239166900515556
# Batch: 120, Loss: 0.09082330018281937
# Batch: 140, Loss: 0.1791614294052124
# Batch: 160, Loss: 0.04549524933099747
# Batch: 180, Loss: 0.05389675125479698
# Batch: 200, Loss: 0.0966181755065918
#
# Average loss: 0.0903, Accuracy: 25318.0/26038 (97%)
#
#
# Average loss: 0.1141, Accuracy: 2850.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.23%
# Validation Accuracy: 96.94%
# Batch: 0, Loss: 0.07630480080842972
# Batch: 20, Loss: 0.1431434005498886
# Batch: 40, Loss: 0.06900155544281006
# Batch: 60, Loss: 0.1118844673037529
# Batch: 80, Loss: 0.12430084496736526
# Batch: 100, Loss: 0.1689320206642151
# Batch: 120, Loss: 0.040982116013765335
# Batch: 140, Loss: 0.07899818569421768
# Batch: 160, Loss: 0.06068573519587517
# Batch: 180, Loss: 0.09206817299127579
# Batch: 200, Loss: 0.05887986347079277
#
# Average loss: 0.0903, Accuracy: 25323.0/26038 (97%)
#
#
# Average loss: 0.1151, Accuracy: 2854.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.25%
# Validation Accuracy: 97.07%
# Batch: 0, Loss: 0.12843675911426544
# Batch: 20, Loss: 0.06724648177623749
# Batch: 40, Loss: 0.05054671689867973
# Batch: 60, Loss: 0.09007672220468521
# Batch: 80, Loss: 0.06629417091608047
# Batch: 100, Loss: 0.1276555061340332
# Batch: 120, Loss: 0.05646246299147606
# Batch: 140, Loss: 0.0402766652405262
# Batch: 160, Loss: 0.09773847460746765
# Batch: 180, Loss: 0.08614106476306915
# Batch: 200, Loss: 0.06752685457468033
#
# Average loss: 0.0896, Accuracy: 25320.0/26038 (97%)
#
#
# Average loss: 0.1136, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 97.24%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.10841956734657288
# Batch: 20, Loss: 0.08628984540700912
# Batch: 40, Loss: 0.09995484352111816
# Batch: 60, Loss: 0.10026387870311737
# Batch: 80, Loss: 0.06825948506593704
# Batch: 100, Loss: 0.048665374517440796
# Batch: 120, Loss: 0.18284599483013153
# Batch: 140, Loss: 0.10083799809217453
# Batch: 160, Loss: 0.0653252899646759
# Batch: 180, Loss: 0.08211199939250946
# Batch: 200, Loss: 0.12541000545024872
#
# Average loss: 0.0894, Accuracy: 25310.0/26038 (97%)
#
#
# Average loss: 0.1143, Accuracy: 2855.0/2940 (97%)
#
# Epoch: 8 	Training Accuracy: 97.20%
# Validation Accuracy: 97.11%
# Batch: 0, Loss: 0.1092803031206131
# Batch: 20, Loss: 0.06005924195051193
# Batch: 40, Loss: 0.09680712223052979
# Batch: 60, Loss: 0.05269233509898186
# Batch: 80, Loss: 0.14417198300361633
# Batch: 100, Loss: 0.04386414587497711
# Batch: 120, Loss: 0.155223548412323
# Batch: 140, Loss: 0.04666636884212494
# Batch: 160, Loss: 0.09453065693378448
# Batch: 180, Loss: 0.0641656368970871
# Batch: 200, Loss: 0.053468234837055206
#
# Average loss: 0.0904, Accuracy: 25311.0/26038 (97%)
#
#
# Average loss: 0.1143, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 9 	Training Accuracy: 97.21%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.05842307582497597
# Batch: 20, Loss: 0.06881514936685562
# Batch: 40, Loss: 0.11342204362154007
# Batch: 60, Loss: 0.06602847576141357
# Batch: 80, Loss: 0.12019014358520508
# Batch: 100, Loss: 0.04760916158556938
# Batch: 120, Loss: 0.09132292866706848
# Batch: 140, Loss: 0.05539093539118767
# Batch: 160, Loss: 0.11955174803733826
# Batch: 180, Loss: 0.06842783093452454
# Batch: 200, Loss: 0.11474841833114624
#
# Average loss: 0.0893, Accuracy: 25318.0/26038 (97%)
#
#
# Average loss: 0.1140, Accuracy: 2855.0/2940 (97%)
#
# Epoch: 10 	Training Accuracy: 97.23%
# Validation Accuracy: 97.11%
# Batch: 0, Loss: 0.027652371674776077
# Batch: 20, Loss: 0.05475808307528496
# Batch: 40, Loss: 0.08140170574188232
# Batch: 60, Loss: 0.08696223050355911
# Batch: 80, Loss: 0.043118469417095184
# Batch: 100, Loss: 0.07586312294006348
# Batch: 120, Loss: 0.08127804845571518
# Batch: 140, Loss: 0.055332913994789124
# Batch: 160, Loss: 0.09244024008512497
# Batch: 180, Loss: 0.06392989307641983
# Batch: 200, Loss: 0.09354974329471588
#
# Average loss: 0.0885, Accuracy: 25329.0/26038 (97%)
#
#
# Average loss: 0.1136, Accuracy: 2853.0/2940 (97%)
#
# Epoch: 11 	Training Accuracy: 97.28%
# Validation Accuracy: 97.04%
# Batch: 0, Loss: 0.14039397239685059
# Batch: 20, Loss: 0.0987299457192421
# Batch: 40, Loss: 0.1060936376452446
# Batch: 60, Loss: 0.12933173775672913
# Batch: 80, Loss: 0.14124435186386108
# Batch: 100, Loss: 0.10842202603816986
# Batch: 120, Loss: 0.03555026650428772
# Batch: 140, Loss: 0.03562501072883606
# Batch: 160, Loss: 0.06886442750692368
# Batch: 180, Loss: 0.031317006796598434
# Batch: 200, Loss: 0.12044237554073334
#
# Average loss: 0.0883, Accuracy: 25330.0/26038 (97%)
#
#
# Average loss: 0.1136, Accuracy: 2853.0/2940 (97%)
#
# Epoch: 12 	Training Accuracy: 97.28%
# Validation Accuracy: 97.04%
# Batch: 0, Loss: 0.04515594616532326
# Batch: 20, Loss: 0.12606026232242584
# Batch: 40, Loss: 0.04764179512858391
# Batch: 60, Loss: 0.052664414048194885
# Batch: 80, Loss: 0.07050653547048569
# Batch: 100, Loss: 0.09792885929346085
# Batch: 120, Loss: 0.06325804442167282
# Batch: 140, Loss: 0.09499713033437729
# Batch: 160, Loss: 0.08426608890295029
# Batch: 180, Loss: 0.09361070394515991
# Batch: 200, Loss: 0.1283784657716751
#
# Average loss: 0.0878, Accuracy: 25324.0/26038 (97%)
#
#
# Average loss: 0.1131, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 13 	Training Accuracy: 97.26%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.06911386549472809
# Batch: 20, Loss: 0.13718220591545105
# Batch: 40, Loss: 0.03136027976870537
# Batch: 60, Loss: 0.020741133019328117
# Batch: 80, Loss: 0.12742304801940918
# Batch: 100, Loss: 0.14787203073501587
# Batch: 120, Loss: 0.05287233367562294
# Batch: 140, Loss: 0.11203743517398834
# Batch: 160, Loss: 0.045895546674728394
# Batch: 180, Loss: 0.07218004763126373
# Batch: 200, Loss: 0.09348687529563904
#
# Average loss: 0.0876, Accuracy: 25341.0/26038 (97%)
#
#
# Average loss: 0.1138, Accuracy: 2855.0/2940 (97%)
#
# Epoch: 14 	Training Accuracy: 97.32%
# Validation Accuracy: 97.11%
# Early stopping invoked.
#
# Average loss: 0.0894, Accuracy: 25310.0/26038 (97%)
#
#
# Average loss: 0.0870, Accuracy: 4728.0/4861 (97%)
#
# Percentage: 0.01, Seed: 10, Epochs taken: 7
# Percentage: 0.01, Seed: 20, Epochs taken: 9
# Percentage: 0.01, Seed: 30, Epochs taken: 7
# Percentage: 0.01, Seed: 40, Epochs taken: 7
# Percentage: 0.01, Seed: 50, Epochs taken: 7
# Percentage: 0.03, Seed: 10, Epochs taken: 7
# Percentage: 0.03, Seed: 20, Epochs taken: 7
# Percentage: 0.03, Seed: 30, Epochs taken: 15
# Percentage: 0.03, Seed: 40, Epochs taken: 7
# Percentage: 0.03, Seed: 50, Epochs taken: 7
# Percentage: 0.05, Seed: 10, Epochs taken: 7
# Percentage: 0.05, Seed: 20, Epochs taken: 7
# Percentage: 0.05, Seed: 30, Epochs taken: 9
# Percentage: 0.05, Seed: 40, Epochs taken: 7
# Percentage: 0.05, Seed: 50, Epochs taken: 7
# Percentage: 0.1, Seed: 10, Epochs taken: 17
# Percentage: 0.1, Seed: 20, Epochs taken: 8
# Percentage: 0.1, Seed: 30, Epochs taken: 10
# Percentage: 0.1, Seed: 40, Epochs taken: 14
# Percentage: 0.1, Seed: 50, Epochs taken: 7
# Percentage: 0.15, Seed: 10, Epochs taken: 18
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 8
# Percentage: 0.15, Seed: 40, Epochs taken: 10
# Percentage: 0.15, Seed: 50, Epochs taken: 11
# Percentage: 0.2, Seed: 10, Epochs taken: 9
# Percentage: 0.2, Seed: 20, Epochs taken: 16
# Percentage: 0.2, Seed: 30, Epochs taken: 13
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 12
# Percentage: 0.4, Seed: 10, Epochs taken: 15
# Percentage: 0.4, Seed: 20, Epochs taken: 7
# Percentage: 0.4, Seed: 30, Epochs taken: 11
# Percentage: 0.4, Seed: 40, Epochs taken: 9
# Percentage: 0.4, Seed: 50, Epochs taken: 7
# Percentage: 0.6, Seed: 10, Epochs taken: 9
# Percentage: 0.6, Seed: 20, Epochs taken: 8
# Percentage: 0.6, Seed: 30, Epochs taken: 13
# Percentage: 0.6, Seed: 40, Epochs taken: 8
# Percentage: 0.6, Seed: 50, Epochs taken: 9
# Percentage: 0.8, Seed: 10, Epochs taken: 8
# Percentage: 0.8, Seed: 20, Epochs taken: 10
# Percentage: 0.8, Seed: 30, Epochs taken: 17
# Percentage: 0.8, Seed: 40, Epochs taken: 11
# Percentage: 0.8, Seed: 50, Epochs taken: 13
# Percentage: 1, Seed: 10, Epochs taken: 13
# Percentage: 1, Seed: 20, Epochs taken: 18
# Percentage: 1, Seed: 30, Epochs taken: 13
# Percentage: 1, Seed: 40, Epochs taken: 10
# Percentage: 1, Seed: 50, Epochs taken: 15

# %%
# End to End - Train Accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Train Accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Train Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Train Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
# End to End - Test Accuracies
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]

plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Test Accuracies
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Test Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Test Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
data_to_save = {
    "results_test_finetune": results_test_finetune,
    "results_train_finetune": results_train_finetune,
    "epochs_taken_finetune": epochs_taken_finetune,
    
    "results_test": results_test,
    "results_train": results_train,
    "epochs_taken": epochs_taken
}

# Assuming data_to_save from the previous code
with open("data.json", "w") as file:
    json.dump(data_to_save, file)

# %%
plt.figure(figsize=(10, 6))

for perc in percentages:
    plt.scatter(epochs_taken[perc], epochs_taken_finetune[perc], label=f'{perc} data')
plt.xlabel('Epochs (End to End)')
plt.ylabel('Epochs (Finetune)')
plt.title('Scatter Plot Comparing Epochs Taken for Convergence')
plt.legend()
plt.show()

# %%
# Given data
percentages = list(epochs_taken.keys())

all_epochs = []
labels = []

for perc in percentages:
    all_epochs.extend([epochs_taken[perc], epochs_taken_finetune[perc]])
    labels.extend([f'{perc} End to End', f'{perc} Finetune'])

# Plotting
plt.figure(figsize=(10, 6))
box = plt.boxplot(all_epochs, labels=labels, patch_artist=True)

# Coloring
colors = ['skyblue', 'lightgreen'] * len(percentages)
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

plt.ylabel('Epochs Taken')
plt.title('Box Plot of Epochs Taken for Each Percentage')
plt.xticks(rotation=90)
plt.show()

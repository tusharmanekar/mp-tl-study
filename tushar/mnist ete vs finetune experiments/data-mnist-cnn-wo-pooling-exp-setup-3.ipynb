# %% [markdown]
# ***EXPERIMENT SETUP***

# %% [markdown]
# - percentages_set_1 = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
# - dataset: same as before MNIST 5 to 5
#
# - lr pretraining = 0.001
# - lr finetuning = 0.0001
#
# - architecture:
#     - Conv 1 (5,5), channels=1
#     - Relu
#     - Conv 2 (5,5,), channels=1
#     - Relu
#     - Pooling: TRUE
#     - dense( x, x) x=output shape of prev layer (128?)
#     - Relu
#     - dense(x, 5)
#     - softmax
#
# - Freezing: NO
#
# - Reinitializing CNN layers: No
# - Reinitializing CNN layers: No
# - Reinitializing softmax layers: Yes
#
# - If we don’t save the best model, ES=6
#
# - num train = 20

# %% [markdown]
# ***IMPORTS***

# %%
import numpy as np
import random
import copy
import matplotlib.pyplot as plt
import json
from tqdm.auto import tqdm

# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from torchvision import datasets, transforms

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from types import SimpleNamespace
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ***UTILS***

# %%
def eval(model, device, dataset_loader, debug=False, classification_report_flag=False, is_cnn=True, logger=print):

    """
    Evaluates the model on the given dataset loader.

    Parameters:
    - model: the PyTorch model to evaluate.
    - device: the device to which tensors should be moved before computation.
    - dataset_loader: DataLoader for evaluation.
    - debug: whether to print debug info like loss and accuracy.
    - classification_report_flag: whether to print a classification report.
    - is_cnn: a flag indicating if the model is a CNN. If it's not, the input data will be reshaped.
    - logger: logging function for printing messages.

    Returns:
    - Accuracy of the model on the provided dataset loader.

    Usage:
    - accuracy = eval(model, device, dataset_loader, debug=False, is_cnn=False, classification_report_flag=False)
    """

    model.eval()
    test_loss, correct = 0., 0.
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data, target in dataset_loader:
            if is_cnn:
              data = data.view(data.size(0), 1, 28, 28)
            else:
              data = data.reshape([data.shape[0], -1])
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(target.cpu().numpy())

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data

    if debug:
        logger('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(test_loss, correct, num_data, 100. * acc))

    if classification_report_flag:
        unique_labels = np.unique(all_labels).tolist()
        logger(classification_report(all_labels, all_preds, labels=unique_labels, target_names=[f'Class {i}' for i in unique_labels]))

    return acc

# %%
class Trainer:

    """
    A class for training and evaluating a model with early stopping and best model saving functionalities.

    Attributes:
    - model: PyTorch model to be trained and evaluated.
    - dataloader: Contains data loaders (train, validation, test) for training and evaluation.
    - params: Dictionary containing various hyperparameters and settings.
    - device: the device to which tensors should be moved before computation.
    - optimizer: The optimizer for training.
    - best_model_state: State dictionary of the best model.
    - max_val_acc: The highest validation accuracy encountered during training.
    - no_improve_epochs: Number of epochs without improvement in validation accuracy.
    - is_cnn: Flag indicating if the model is a CNN.
    - is_debug: Flag indicating if debug information should be printed.
    - classification_report_flag: Flag indicating if a classification report should be generated.

    Methods:
    - train_epoch(): Runs a single epoch of training.
    - evaluate(loader): Evaluates the model on a given data loader.
    - save_best_model(): Saves the current state of the model as the best model.
    - save_checkpoint(epoch, train_acc, val_acc): Saves the current state of the model and other information as a checkpoint.
    - early_stopping_check(val_acc): Checks the stopping criterion and performs actions based on it.
    - train(): Runs the training process for a number of epochs, with early stopping functionality.

    Usage:
    params = {
      'device': 'cuda',
      'lr': 0.001,
      'num_train': 10,
      'early_stop_patience': 3,
      'save_best': True,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': True
    }

    trainer = Trainer(model, dataloader, params)
    train_acc, test_acc, effective_epochs, checkpoints = trainer.train()
    """


    def __init__(self, model, dataloader, params):
        self.model = model
        self.dataloader = dataloader
        self.params = params

        self.device = torch.device(params['device'])
        self.optimizer = optim.Adam(model.parameters(), lr=params['lr'])

        # Initialize best_model_state with the current model state
        self.best_model_state = copy.deepcopy(self.model.state_dict())
        self.max_val_acc = 0.
        self.no_improve_epochs = 0

        self.is_cnn = params.get('is_cnn', False)
        self.is_debug = params.get('is_debug', False)
        self.classification_report_flag = params.get('classification_report_flag', False)
        self.logger = params.get('logger', print)
        
    def train_epoch(self):
      self.model.train()
      for batch_idx, (data, target) in enumerate(self.dataloader.train_loader):

          # Print the size of the current batch
          if self.is_cnn:
            data = data.view(data.size(0), 1, 28, 28)
          else:
            data = data.reshape([data.shape[0], -1])

          data, target = data.to(self.device), target.to(self.device)
          self.optimizer.zero_grad()
          output = self.model(data)
          loss = F.nll_loss(output, target)
          loss.backward()
          self.optimizer.step()

          if self.is_debug and batch_idx % 20 == 0:
              self.logger(f"Batch: {batch_idx}, Loss: {loss.item()}")

    def evaluate(self, loader):
        return eval(self.model, self.device, loader, self.is_debug, self.classification_report_flag, self.is_cnn)

    def save_best_model(self):
        torch.save(self.model.state_dict(), 'best_model.pth')

    def save_checkpoint(self, epoch, train_acc, val_acc):
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'train_acc': train_acc,
            'val_acc': val_acc
        }
        torch.save(checkpoint, f'checkpoint_epoch_{epoch}.pth')
        return checkpoint

    def early_stopping_check(self, val_acc):
        if val_acc > self.max_val_acc:
            self.max_val_acc = val_acc
            self.no_improve_epochs = 0
            # Deep copy the model's state
            self.best_model_state = copy.deepcopy(self.model.state_dict())
            if self.params.get('save_best', False):
                self.save_best_model()
        else:
            self.no_improve_epochs += 1
            if self.no_improve_epochs >= self.params['early_stop_patience']:
                self.logger("Early stopping invoked.")
                # Only load if best_model_state has been set
                if self.best_model_state is not None:
                    self.model.load_state_dict(self.best_model_state)
                return True
        return False

    def train(self):
        effective_epochs = 0
        checkpoints = []

        for epoch in range(self.params['num_train']):
            effective_epochs += 1
            self.train_epoch()

            train_acc = self.evaluate(self.dataloader.train_loader)
            val_acc = self.evaluate(self.dataloader.val_loader)
            self.logger(f'Epoch: {epoch} \tTraining Accuracy: {train_acc*100:.2f}%')
            self.logger(f'Validation Accuracy: {val_acc*100:.2f}%')

            if self.params.get('early_stop_patience', None):
                if self.early_stopping_check(val_acc):
                    self.model.load_state_dict(self.best_model_state)
                    break

            if self.params.get('save_checkpoints', False):
                checkpoint = self.save_checkpoint(epoch, train_acc, val_acc)
                checkpoints.append(checkpoint)

        # Final evaluations
        train_acc = self.evaluate(self.dataloader.train_loader)
        test_acc = self.evaluate(self.dataloader.test_loader)

        return train_acc, test_acc, effective_epochs, checkpoints

# %%
def reduce_dataset(dataloader, percentage, balanced=True, seed=42):

    """
    Reduces the dataset to the given percentage. Can ensure class balance if needed.

    Parameters:
    - dataloader: PyTorch DataLoader object.
    - percentage: Desired percentage of the original dataset.
    - balanced: If True, ensures class balance. If False, reduces randomly.
    - seed: Seed for reproducibility.

    Returns:
    - reduced_dataloader: DataLoader with the reduced dataset.
    """
    # Extract the dataset from the dataloader
    dataset = dataloader.dataset

    # Extract all data and labels from the dataset
    X = [dataset[i][0] for i in range(len(dataset))]
    y = [dataset[i][1] for i in range(len(dataset))]

    # Set the seed for reproducibility
    torch.manual_seed(seed)

    if not balanced:
        # Determine the number of samples to keep
        num_samples = int(len(dataset) * percentage)

        # Randomly select indices without replacement
        indices = torch.randperm(len(dataset))[:num_samples].tolist()

    else:
        # Get unique classes and their counts
        classes, class_counts = torch.unique(torch.tensor(y), return_counts=True)

        # Determine the number of samples per class to keep
        num_samples_per_class = int(len(dataset) * percentage / len(classes))
        indices = []

        for class_label in classes:
            class_indices = [i for i, label in enumerate(y) if label == class_label]

            # Randomly select indices without replacement for each class
            class_selected_indices = torch.randperm(len(class_indices))[:num_samples_per_class].tolist()
            indices.extend([class_indices[i] for i in class_selected_indices])

    # Use a Subset of the original dataset to create a reduced dataset
    reduced_dataset = data.Subset(dataset, indices)

    # Create a DataLoader with the reduced dataset.
    reduced_dataloader = data.DataLoader(reduced_dataset, batch_size=dataloader.batch_size, shuffle=True)

    return reduced_dataloader

# %%
class RelabeledSubset(torch.utils.data.Dataset):
    def __init__(self, dataset, offset):
        self.dataset = dataset
        self.offset = offset

    def __getitem__(self, idx):
        data, label = self.dataset[idx]
        # Offset the label to start from 0
        label = label - self.offset
        return data, label

    def __len__(self):
        return len(self.dataset)

# %%
class TransferLearningMNIST(object):
    def __init__(self, batch_size, input_dim=28*28, val_split=0.1, num_workers=4):
        self.input_dim = input_dim
        self.output_dim = 10
        self.val_split = val_split

        def filter_dataset(dataset, classes):
            indices = [i for i, t in enumerate(dataset.targets) if t in classes]
            return torch.utils.data.Subset(dataset, indices)

        mnist_train_data = datasets.MNIST(
            '../data',
            train=True,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_train_data = filter_dataset(mnist_train_data, list(range(5)))
        finetune_train_data = filter_dataset(mnist_train_data, list(range(5, 10)))

        pretrain_len = len(pretrain_train_data)
        finetune_len = len(finetune_train_data)
        pretrain_val_len = int(val_split * pretrain_len)
        finetune_val_len = int(val_split * finetune_len)
        SEED = 42
        pretrain_train_set, pretrain_val_set = torch.utils.data.random_split(
            pretrain_train_data, [pretrain_len - pretrain_val_len, pretrain_val_len], generator=torch.Generator().manual_seed(SEED))
        finetune_train_set, finetune_val_set = torch.utils.data.random_split(
            finetune_train_data, [finetune_len - finetune_val_len, finetune_val_len], generator=torch.Generator().manual_seed(SEED))

        self.pretrain_train_loader = torch.utils.data.DataLoader(pretrain_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.pretrain_val_loader = torch.utils.data.DataLoader(pretrain_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning datasets
        finetune_train_set = RelabeledSubset(finetune_train_set, 5)
        finetune_val_set = RelabeledSubset(finetune_val_set, 5)

        self.finetune_train_loader = torch.utils.data.DataLoader(finetune_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.finetune_val_loader = torch.utils.data.DataLoader(finetune_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        mnist_test_data = datasets.MNIST(
            '../data',
            train=False,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_test_data = filter_dataset(mnist_test_data, list(range(5)))
        finetune_test_data = filter_dataset(mnist_test_data, list(range(5, 10)))

        self.pretrain_test_loader = torch.utils.data.DataLoader(pretrain_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning test datasets
        finetune_test_data = RelabeledSubset(finetune_test_data, 5)
        self.finetune_test_loader = torch.utils.data.DataLoader(finetune_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        # Complete test loader contains all test examples.
        self.complete_test_loader = torch.utils.data.DataLoader(mnist_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
class TransferLearningMNISTWrapper:
    """
    This wrapper class provides a convenient way to switch between pretraining and fine-tuning phases.

    It allows for changing the phase and accordingly updating the data loaders (train, val, test)
    to either pretraining or fine-tuning sets.
    """
    def __init__(self, transferLearningMNISTObj, phase):
        """
        Initializes the TransferLearningMNISTWrapper object.

        Parameters:
        - transferLearningMNISTObj: An instance of the TransferLearningMNIST class.
        - phase: String indicating the current phase ("pretrain" or "finetune").
        """
        self.transferLearningMNISTObj = transferLearningMNISTObj
        self.phase = phase
        self.input_dim = self.transferLearningMNISTObj.input_dim
        self.output_dim = self.transferLearningMNISTObj.output_dim
        self.update_phase(phase)

    def update_phase(self, phase):
        """
        Updates the phase and the corresponding data loaders.

        Parameters:
        - phase: String indicating the desired phase ("pretrain" or "finetune").

        Throws:
        - ValueError: If the phase is neither "pretrain" nor "finetune".
        """
        self.phase = phase
        if phase == 'pretrain':
            self.train_loader = self.transferLearningMNISTObj.pretrain_train_loader
            self.val_loader = self.transferLearningMNISTObj.pretrain_val_loader
            self.test_loader = self.transferLearningMNISTObj.pretrain_test_loader
        elif phase == 'finetune':
            self.train_loader = self.transferLearningMNISTObj.finetune_train_loader
            self.val_loader = self.transferLearningMNISTObj.finetune_val_loader
            self.test_loader = self.transferLearningMNISTObj.finetune_test_loader
        else:
            raise ValueError('Phase must be either "pretrain" or "finetune".')

    def get_current_phase(self):
      return self.phase

# %%
class CustomCNN(nn.Module):
    def __init__(self, input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling=False):
        super(CustomCNN, self).__init__()

        # Initial number of input channels, assuming grayscale images
        in_channels = 1

        # Dynamically add convolutional and activation layers based on the specified depth
        for i in range(depth):
            # Create a convolutional layer and add it to the model
            setattr(self, f"conv{i}", nn.Conv2d(in_channels, num_channels, kernel_size=kernel_size, padding=1))

            # Create an activation layer (e.g., ReLU) and add it to the model
            setattr(self, f"act{i}", activation_function())

            # Update the input dimensions after convolution
            input_dim = (input_dim - kernel_size + 2 * 1) + 1

            # Optionally add pooling layers to reduce spatial dimensions
            if use_pooling and i % 2 == 1:
                setattr(self, f"pool{i}", nn.MaxPool2d(2))
                input_dim = input_dim // 2

            # Update the input channels for the next convolutional layer
            in_channels = num_channels

        # Compute the size of the flattened features for the fully connected layer
        flattened_size = in_channels * input_dim * input_dim

        # Add two fully connected layers for classification
        self.fc_1 = nn.Linear(flattened_size, hidden_dim_lin)
        self.fc_2 = nn.Linear(hidden_dim_lin, output_dim)

        # Add log softmax layer for multi-class classification output
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
      # Iterate over each module in the CustomCNN class
      for layer_name, layer in self.named_children():
          # Process the input tensor through convolutional and activation layers
          if "conv" in layer_name or "act" in layer_name:
              x = layer(x)
          # Process the input tensor through pooling layers if they exist
          elif "pool" in layer_name:
              x = layer(x)
          # If reached fully connected layers, break the loop
          elif isinstance(layer, nn.Linear):
              break

      # Flatten the tensor to fit the input shape of the fully connected layers
      x = x.view(x.size(0), -1)
        
      # Save the flattened size for reinitializing layers later
      self.flattened_size = x.shape[1]

      # Pass the tensor through the fully connected layers
      x = self.fc_1(x)
      x = self.fc_2(x)

      # Return log softmax activated output
      return self.logsoftmax(x)

# %%
def generate_cnn(input_dim, output_dim, depth, num_channels, hidden_dim_lin, kernel_size, activation_function=nn.ReLU, use_pooling=False):
    model = CustomCNN(input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling)
    return model

# %% [markdown]
# ***PRE-TRAINING***

# %%
batch_size = 128

dataloader = TransferLearningMNIST(batch_size)
dataloader_wrapped = TransferLearningMNISTWrapper(dataloader, phase = 'pretrain')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 88255409.32it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 46358857.18it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 26503862.58it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 13865013.66it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw

# %%
a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        break

# %%
params = {
      'depth': 2,
      'width': 1,
      'hidden_dim_lin': 128,
      'activation_function': nn.ReLU,
      'kernel_size': 5,
      'device': device,
      'lr': 0.001,
      'num_train': 20,
      'early_stop_patience': 6,
      'save_best': True,
      'save_checkpoints': True,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': False
    }

# Create DNN model
model = generate_cnn(input_dim = 28, output_dim = 10, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=False)
model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
model
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
# Train and evaluate
trainer = Trainer(model, dataloader_wrapped, params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Batch: 0, Loss: 2.2946743965148926
# Batch: 20, Loss: 1.3385170698165894
# Batch: 40, Loss: 0.4751957058906555
# Batch: 60, Loss: 0.1860802322626114
# Batch: 80, Loss: 0.15321165323257446
# Batch: 100, Loss: 0.12721547484397888
# Batch: 120, Loss: 0.13916543126106262
# Batch: 140, Loss: 0.24418886005878448
# Batch: 160, Loss: 0.1439710110425949
# Batch: 180, Loss: 0.11715759336948395
# Batch: 200, Loss: 0.1659645289182663
#
# Average loss: 0.1312, Accuracy: 26420.0/27537 (96%)
#
#
# Average loss: 0.1535, Accuracy: 2903.0/3059 (95%)
#
# Epoch: 0 	Training Accuracy: 95.94%
# Validation Accuracy: 94.90%
# Batch: 0, Loss: 0.1366705596446991
# Batch: 20, Loss: 0.10133597999811172
# Batch: 40, Loss: 0.10755718499422073
# Batch: 60, Loss: 0.2564704418182373
# Batch: 80, Loss: 0.0705508440732956
# Batch: 100, Loss: 0.05803706869482994
# Batch: 120, Loss: 0.05429243668913841
# Batch: 140, Loss: 0.15856555104255676
# Batch: 160, Loss: 0.10078997164964676
# Batch: 180, Loss: 0.047261931002140045
# Batch: 200, Loss: 0.1690939962863922
#
# Average loss: 0.1145, Accuracy: 26580.0/27537 (97%)
#
#
# Average loss: 0.1375, Accuracy: 2928.0/3059 (96%)
#
# Epoch: 1 	Training Accuracy: 96.52%
# Validation Accuracy: 95.72%
# Batch: 0, Loss: 0.09428050369024277
# Batch: 20, Loss: 0.07151994109153748
# Batch: 40, Loss: 0.11698447912931442
# Batch: 60, Loss: 0.11774887889623642
# Batch: 80, Loss: 0.09532766044139862
# Batch: 100, Loss: 0.09025000780820847
# Batch: 120, Loss: 0.14614197611808777
# Batch: 140, Loss: 0.03395438194274902
# Batch: 160, Loss: 0.039159923791885376
# Batch: 180, Loss: 0.12709656357765198
# Batch: 200, Loss: 0.1102241575717926
#
# Average loss: 0.1028, Accuracy: 26727.0/27537 (97%)
#
#
# Average loss: 0.1235, Accuracy: 2952.0/3059 (97%)
#
# Epoch: 2 	Training Accuracy: 97.06%
# Validation Accuracy: 96.50%
# Batch: 0, Loss: 0.10125367343425751
# Batch: 20, Loss: 0.06262297183275223
# Batch: 40, Loss: 0.06844273954629898
# Batch: 60, Loss: 0.09095659106969833
# Batch: 80, Loss: 0.09237545728683472
# Batch: 100, Loss: 0.07879412174224854
# Batch: 120, Loss: 0.11281024664640427
# Batch: 140, Loss: 0.1634424328804016
# Batch: 160, Loss: 0.07089772075414658
# Batch: 180, Loss: 0.07443694025278091
# Batch: 200, Loss: 0.07519213855266571
#
# Average loss: 0.0934, Accuracy: 26774.0/27537 (97%)
#
#
# Average loss: 0.1181, Accuracy: 2949.0/3059 (96%)
#
# Epoch: 3 	Training Accuracy: 97.23%
# Validation Accuracy: 96.40%
# Batch: 0, Loss: 0.0257035493850708
# Batch: 20, Loss: 0.14321717619895935
# Batch: 40, Loss: 0.09048700332641602
# Batch: 60, Loss: 0.1069837212562561
# Batch: 80, Loss: 0.0343933179974556
# Batch: 100, Loss: 0.13893398642539978
# Batch: 120, Loss: 0.1433502733707428
# Batch: 140, Loss: 0.10256902873516083
# Batch: 160, Loss: 0.08724924176931381
# Batch: 180, Loss: 0.08731018006801605
# Batch: 200, Loss: 0.08323841542005539
#
# Average loss: 0.0962, Accuracy: 26741.0/27537 (97%)
#
#
# Average loss: 0.1242, Accuracy: 2949.0/3059 (96%)
#
# Epoch: 4 	Training Accuracy: 97.11%
# Validation Accuracy: 96.40%
# Batch: 0, Loss: 0.12738077342510223
# Batch: 20, Loss: 0.097256138920784
# Batch: 40, Loss: 0.06218152865767479
# Batch: 60, Loss: 0.04357073828577995
# Batch: 80, Loss: 0.08931291848421097
# Batch: 100, Loss: 0.049363888800144196
# Batch: 120, Loss: 0.17179611325263977
# Batch: 140, Loss: 0.06411688774824142
# Batch: 160, Loss: 0.04752437397837639
# Batch: 180, Loss: 0.08313316851854324
# Batch: 200, Loss: 0.06683151423931122
#
# Average loss: 0.0851, Accuracy: 26839.0/27537 (97%)
#
#
# Average loss: 0.1129, Accuracy: 2956.0/3059 (97%)
#
# Epoch: 5 	Training Accuracy: 97.47%
# Validation Accuracy: 96.63%
# Batch: 0, Loss: 0.07924409210681915
# Batch: 20, Loss: 0.06344495713710785
# Batch: 40, Loss: 0.09978538006544113
# Batch: 60, Loss: 0.09692876785993576
# Batch: 80, Loss: 0.0685204491019249
# Batch: 100, Loss: 0.07615061104297638
# Batch: 120, Loss: 0.15118072926998138
# Batch: 140, Loss: 0.11355216801166534
# Batch: 160, Loss: 0.06232775002717972
# Batch: 180, Loss: 0.0598144605755806
# Batch: 200, Loss: 0.0945587307214737
#
# Average loss: 0.0842, Accuracy: 26841.0/27537 (97%)
#
#
# Average loss: 0.1112, Accuracy: 2953.0/3059 (97%)
#
# Epoch: 6 	Training Accuracy: 97.47%
# Validation Accuracy: 96.53%
# Batch: 0, Loss: 0.04010479152202606
# Batch: 20, Loss: 0.04605817422270775
# Batch: 40, Loss: 0.17674273252487183
# Batch: 60, Loss: 0.15391844511032104
# Batch: 80, Loss: 0.09589537233114243
# Batch: 100, Loss: 0.03522230684757233
# Batch: 120, Loss: 0.06771153211593628
# Batch: 140, Loss: 0.0884474664926529
# Batch: 160, Loss: 0.07702057808637619
# Batch: 180, Loss: 0.055723316967487335
# Batch: 200, Loss: 0.10581956058740616
#
# Average loss: 0.0792, Accuracy: 26901.0/27537 (98%)
#
#
# Average loss: 0.1069, Accuracy: 2962.0/3059 (97%)
#
# Epoch: 7 	Training Accuracy: 97.69%
# Validation Accuracy: 96.83%
# Batch: 0, Loss: 0.08343397825956345
# Batch: 20, Loss: 0.10806926339864731
# Batch: 40, Loss: 0.09823982417583466
# Batch: 60, Loss: 0.05029445141553879
# Batch: 80, Loss: 0.12614741921424866
# Batch: 100, Loss: 0.09992443025112152
# Batch: 120, Loss: 0.08110558241605759
# Batch: 140, Loss: 0.12628738582134247
# Batch: 160, Loss: 0.13091282546520233
# Batch: 180, Loss: 0.14596284925937653
# Batch: 200, Loss: 0.054925259202718735
#
# Average loss: 0.0939, Accuracy: 26748.0/27537 (97%)
#
#
# Average loss: 0.1200, Accuracy: 2953.0/3059 (97%)
#
# Epoch: 8 	Training Accuracy: 97.13%
# Validation Accuracy: 96.53%
# Batch: 0, Loss: 0.031628310680389404
# Batch: 20, Loss: 0.04732106253504753
# Batch: 40, Loss: 0.07685551792383194
# Batch: 60, Loss: 0.08739735931158066
# Batch: 80, Loss: 0.11342887580394745
# Batch: 100, Loss: 0.08450968563556671
# Batch: 120, Loss: 0.0671035572886467
# Batch: 140, Loss: 0.06399410963058472
# Batch: 160, Loss: 0.13076142966747284
# Batch: 180, Loss: 0.09671629965305328
# Batch: 200, Loss: 0.04258203133940697
#
# Average loss: 0.0752, Accuracy: 26938.0/27537 (98%)
#
#
# Average loss: 0.1058, Accuracy: 2969.0/3059 (97%)
#
# Epoch: 9 	Training Accuracy: 97.82%
# Validation Accuracy: 97.06%
# Batch: 0, Loss: 0.10770488530397415
# Batch: 20, Loss: 0.047324370592832565
# Batch: 40, Loss: 0.04315750673413277
# Batch: 60, Loss: 0.06410488486289978
# Batch: 80, Loss: 0.042981989681720734
# Batch: 100, Loss: 0.05133576691150665
# Batch: 120, Loss: 0.12929649651050568
# Batch: 140, Loss: 0.0740547925233841
# Batch: 160, Loss: 0.05488738790154457
# Batch: 180, Loss: 0.12196195125579834
# Batch: 200, Loss: 0.01624472439289093
#
# Average loss: 0.0793, Accuracy: 26893.0/27537 (98%)
#
#
# Average loss: 0.1161, Accuracy: 2955.0/3059 (97%)
#
# Epoch: 10 	Training Accuracy: 97.66%
# Validation Accuracy: 96.60%
# Batch: 0, Loss: 0.03422050178050995
# Batch: 20, Loss: 0.05636075139045715
# Batch: 40, Loss: 0.06844686716794968
# Batch: 60, Loss: 0.061444178223609924
# Batch: 80, Loss: 0.03402816876769066
# Batch: 100, Loss: 0.08593109250068665
# Batch: 120, Loss: 0.029615595936775208
# Batch: 140, Loss: 0.0766853466629982
# Batch: 160, Loss: 0.0643993392586708
# Batch: 180, Loss: 0.047883499413728714
# Batch: 200, Loss: 0.05867011472582817
#
# Average loss: 0.0743, Accuracy: 26918.0/27537 (98%)
#
#
# Average loss: 0.1080, Accuracy: 2964.0/3059 (97%)
#
# Epoch: 11 	Training Accuracy: 97.75%
# Validation Accuracy: 96.89%
# Batch: 0, Loss: 0.08279227465391159
# Batch: 20, Loss: 0.08613517135381699
# Batch: 40, Loss: 0.03803535923361778
# Batch: 60, Loss: 0.12553922832012177
# Batch: 80, Loss: 0.019715040922164917
# Batch: 100, Loss: 0.07283971458673477
# Batch: 120, Loss: 0.12606824934482574
# Batch: 140, Loss: 0.08833926916122437
# Batch: 160, Loss: 0.12565962970256805
# Batch: 180, Loss: 0.08103018254041672
# Batch: 200, Loss: 0.03381624445319176
#
# Average loss: 0.0723, Accuracy: 26919.0/27537 (98%)
#
#
# Average loss: 0.1072, Accuracy: 2962.0/3059 (97%)
#
# Epoch: 12 	Training Accuracy: 97.76%
# Validation Accuracy: 96.83%
# Batch: 0, Loss: 0.11058837175369263
# Batch: 20, Loss: 0.09184303134679794
# Batch: 40, Loss: 0.03945654630661011
# Batch: 60, Loss: 0.13275183737277985
# Batch: 80, Loss: 0.05256113409996033
# Batch: 100, Loss: 0.03565245866775513
# Batch: 120, Loss: 0.032837510108947754
# Batch: 140, Loss: 0.1107063964009285
# Batch: 160, Loss: 0.11321212351322174
# Batch: 180, Loss: 0.10229604691267014
# Batch: 200, Loss: 0.06694207340478897
#
# Average loss: 0.0712, Accuracy: 26929.0/27537 (98%)
#
#
# Average loss: 0.1015, Accuracy: 2967.0/3059 (97%)
#
# Epoch: 13 	Training Accuracy: 97.79%
# Validation Accuracy: 96.99%
# Batch: 0, Loss: 0.04322526976466179
# Batch: 20, Loss: 0.06660924851894379
# Batch: 40, Loss: 0.055524736642837524
# Batch: 60, Loss: 0.10802030563354492
# Batch: 80, Loss: 0.024496333673596382
# Batch: 100, Loss: 0.025843938812613487
# Batch: 120, Loss: 0.06123558059334755
# Batch: 140, Loss: 0.08599567413330078
# Batch: 160, Loss: 0.16050609946250916
# Batch: 180, Loss: 0.07035992294549942
# Batch: 200, Loss: 0.06271927058696747
#
# Average loss: 0.0680, Accuracy: 26958.0/27537 (98%)
#
#
# Average loss: 0.1001, Accuracy: 2971.0/3059 (97%)
#
# Epoch: 14 	Training Accuracy: 97.90%
# Validation Accuracy: 97.12%
# Batch: 0, Loss: 0.09767614305019379
# Batch: 20, Loss: 0.15141358971595764
# Batch: 40, Loss: 0.06358702480792999
# Batch: 60, Loss: 0.09815312922000885
# Batch: 80, Loss: 0.05255812779068947
# Batch: 100, Loss: 0.0464976467192173
# Batch: 120, Loss: 0.09518846869468689
# Batch: 140, Loss: 0.08375659584999084
# Batch: 160, Loss: 0.10102502256631851
# Batch: 180, Loss: 0.07229398936033249
# Batch: 200, Loss: 0.07747599482536316
#
# Average loss: 0.0653, Accuracy: 26979.0/27537 (98%)
#
#
# Average loss: 0.0965, Accuracy: 2976.0/3059 (97%)
#
# Epoch: 15 	Training Accuracy: 97.97%
# Validation Accuracy: 97.29%
# Batch: 0, Loss: 0.06780869513750076
# Batch: 20, Loss: 0.1162760928273201
# Batch: 40, Loss: 0.06012027710676193
# Batch: 60, Loss: 0.04089243337512016
# Batch: 80, Loss: 0.10391011089086533
# Batch: 100, Loss: 0.024482417851686478
# Batch: 120, Loss: 0.10238340497016907
# Batch: 140, Loss: 0.051699258387088776
# Batch: 160, Loss: 0.05374496802687645
# Batch: 180, Loss: 0.04842597618699074
# Batch: 200, Loss: 0.15158779919147491
#
# Average loss: 0.0687, Accuracy: 26960.0/27537 (98%)
#
#
# Average loss: 0.1005, Accuracy: 2963.0/3059 (97%)
#
# Epoch: 16 	Training Accuracy: 97.90%
# Validation Accuracy: 96.86%
# Batch: 0, Loss: 0.07267116010189056
# Batch: 20, Loss: 0.014696232974529266
# Batch: 40, Loss: 0.056479524821043015
# Batch: 60, Loss: 0.053464725613594055
# Batch: 80, Loss: 0.049259867519140244
# Batch: 100, Loss: 0.13426293432712555
# Batch: 120, Loss: 0.0345294363796711
# Batch: 140, Loss: 0.02229723148047924
# Batch: 160, Loss: 0.167537122964859
# Batch: 180, Loss: 0.03854788839817047
# Batch: 200, Loss: 0.04240294545888901
#
# Average loss: 0.0623, Accuracy: 27032.0/27537 (98%)
#
#
# Average loss: 0.0990, Accuracy: 2964.0/3059 (97%)
#
# Epoch: 17 	Training Accuracy: 98.17%
# Validation Accuracy: 96.89%
# Batch: 0, Loss: 0.08538641780614853
# Batch: 20, Loss: 0.06117226928472519
# Batch: 40, Loss: 0.034525781869888306
# Batch: 60, Loss: 0.13049259781837463
# Batch: 80, Loss: 0.03275362774729729
# Batch: 100, Loss: 0.05167936906218529
# Batch: 120, Loss: 0.051155880093574524
# Batch: 140, Loss: 0.04755701124668121
# Batch: 160, Loss: 0.1605038046836853
# Batch: 180, Loss: 0.10005643218755722
# Batch: 200, Loss: 0.10259167850017548
#
# Average loss: 0.0589, Accuracy: 27069.0/27537 (98%)
#
#
# Average loss: 0.0930, Accuracy: 2972.0/3059 (97%)
#
# Epoch: 18 	Training Accuracy: 98.30%
# Validation Accuracy: 97.16%
# Batch: 0, Loss: 0.04520993307232857
# Batch: 20, Loss: 0.07315493375062943
# Batch: 40, Loss: 0.08285167068243027
# Batch: 60, Loss: 0.08798766881227493
# Batch: 80, Loss: 0.09923725575208664
# Batch: 100, Loss: 0.11438708752393723
# Batch: 120, Loss: 0.035930611193180084
# Batch: 140, Loss: 0.06768178194761276
# Batch: 160, Loss: 0.02802485227584839
# Batch: 180, Loss: 0.16031336784362793
# Batch: 200, Loss: 0.07419058680534363
#
# Average loss: 0.0562, Accuracy: 27070.0/27537 (98%)
#
#
# Average loss: 0.0880, Accuracy: 2981.0/3059 (97%)
#
# Epoch: 19 	Training Accuracy: 98.30%
# Validation Accuracy: 97.45%
#
# Average loss: 0.0562, Accuracy: 27070.0/27537 (98%)
#
#
# Average loss: 0.0695, Accuracy: 5040.0/5139 (98%)
#
# Final Training Accuracy: 0.9830
# Final Test Accuracy: 0.9807

# %%
accuracy = eval(model, device, dataloader_wrapped.test_loader, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
# Out:
# Average loss: 0.0695, Accuracy: 5040.0/5139 (98%)

# %%
def effective_rank(singular_values):
    normalized_singular_values = singular_values / np.sum(singular_values)
    entropy = -np.sum(normalized_singular_values * np.log(normalized_singular_values))
    eff_rank = np.exp(entropy)
    return eff_rank

def plot_layer_effective_ranks(model, print_ranks=True):
    effective_ranks = []
    layer_names = []

    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            singular_values = np.linalg.svd(weight_matrix, compute_uv=False)
            eff_rank = effective_rank(singular_values)
            effective_ranks.append(eff_rank)
            layer_names.append(name)

    if print_ranks:
        for layer_name, eff_rank in zip(layer_names, effective_ranks):
            print(f'{layer_name}: {eff_rank:.4f}')

    # Plotting
    plt.figure(figsize=(15, 5))
    plt.bar(layer_names, effective_ranks, color='green')
    plt.xlabel('Layer')
    plt.ylabel('Effective Rank')
    plt.title('Effective Rank of Weight Matrices for Each Layer')
    plt.grid(True)

    y_max = np.max(effective_ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(effective_ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(0, int(y_max)+2, step=2))  # Set yticks

    plt.show()

# Example usage
plot_layer_effective_ranks(model)  # Note: You'll need to define or load 'model' before calling this function
# Out:
# conv0.weight: 4.0413
# conv1.weight: 3.2287
# fc_1.weight: 59.7336
# fc_2.weight: 8.4843

# %% [markdown]
# ----

# %% [markdown]
# # Finetuning experiments

# %%
dataloader_wrapped.update_phase('finetune')

a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        print('-------------')
        break
# Out:
# -------------

# %% [markdown]
# ## Baseline model: end2end with the same architecture as the preatining model

# %%
# 2. Create a new model and copy weights from the original model, then adjust the final layer
print("Current dataloader phase: ", dataloader_wrapped.get_current_phase())

model_finetuning_baseline = generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=False)
model_finetuning_baseline.to(device)

# dataloader_wrapped.update_phase('finetune')
# Train and evaluate the new model on the new data
# train_acc_new, test_acc_new, model_finetuning_baseline, _,_ = compute_training_acc_epochs_cnn(model_finetuning_baseline, dataloader_wrapped, params, debug=True)

trainer = Trainer(model, dataloader_wrapped, params)
train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
print(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")
# Out:
# Current dataloader phase:  finetune
# Batch: 0, Loss: 5.620834827423096
# Batch: 20, Loss: 1.4673172235488892
# Batch: 40, Loss: 1.0676904916763306
# Batch: 60, Loss: 0.8198676109313965
# Batch: 80, Loss: 0.5864421725273132
# Batch: 100, Loss: 0.5524859428405762
# Batch: 120, Loss: 0.4833773970603943
# Batch: 140, Loss: 0.38788285851478577
# Batch: 160, Loss: 0.4650513529777527
# Batch: 180, Loss: 0.2700682580471039
# Batch: 200, Loss: 0.4383014142513275
#
# Average loss: 0.3400, Accuracy: 23420.0/26464 (88%)
#
#
# Average loss: 0.3477, Accuracy: 2590.0/2940 (88%)
#
# Epoch: 0 	Training Accuracy: 88.50%
# Validation Accuracy: 88.10%
# Batch: 0, Loss: 0.29712235927581787
# Batch: 20, Loss: 0.3448997437953949
# Batch: 40, Loss: 0.30209168791770935
# Batch: 60, Loss: 0.22298786044120789
# Batch: 80, Loss: 0.30897191166877747
# Batch: 100, Loss: 0.20854678750038147
# Batch: 120, Loss: 0.2126522809267044
# Batch: 140, Loss: 0.3285782039165497
# Batch: 160, Loss: 0.3588930368423462
# Batch: 180, Loss: 0.1416746824979782
# Batch: 200, Loss: 0.21177373826503754
#
# Average loss: 0.2275, Accuracy: 24416.0/26464 (92%)
#
#
# Average loss: 0.2324, Accuracy: 2712.0/2940 (92%)
#
# Epoch: 1 	Training Accuracy: 92.26%
# Validation Accuracy: 92.24%
# Batch: 0, Loss: 0.3938457667827606
# Batch: 20, Loss: 0.29207736253738403
# Batch: 40, Loss: 0.13169151544570923
# Batch: 60, Loss: 0.1919979751110077
# Batch: 80, Loss: 0.15503188967704773
# Batch: 100, Loss: 0.34373217821121216
# Batch: 120, Loss: 0.18554486334323883
# Batch: 140, Loss: 0.2328791320323944
# Batch: 160, Loss: 0.23367321491241455
# Batch: 180, Loss: 0.13713885843753815
# Batch: 200, Loss: 0.1984705626964569
#
# Average loss: 0.1846, Accuracy: 24843.0/26464 (94%)
#
#
# Average loss: 0.1906, Accuracy: 2749.0/2940 (94%)
#
# Epoch: 2 	Training Accuracy: 93.87%
# Validation Accuracy: 93.50%
# Batch: 0, Loss: 0.35612809658050537
# Batch: 20, Loss: 0.09009400010108948
# Batch: 40, Loss: 0.19615958631038666
# Batch: 60, Loss: 0.20957301557064056
# Batch: 80, Loss: 0.15681548416614532
# Batch: 100, Loss: 0.19398033618927002
# Batch: 120, Loss: 0.16075660288333893
# Batch: 140, Loss: 0.21356606483459473
# Batch: 160, Loss: 0.16432321071624756
# Batch: 180, Loss: 0.11230326443910599
# Batch: 200, Loss: 0.15059414505958557
#
# Average loss: 0.1629, Accuracy: 25049.0/26464 (95%)
#
#
# Average loss: 0.1710, Accuracy: 2766.0/2940 (94%)
#
# Epoch: 3 	Training Accuracy: 94.65%
# Validation Accuracy: 94.08%
# Batch: 0, Loss: 0.17183879017829895
# Batch: 20, Loss: 0.17290657758712769
# Batch: 40, Loss: 0.18198154866695404
# Batch: 60, Loss: 0.11192692816257477
# Batch: 80, Loss: 0.0816875621676445
# Batch: 100, Loss: 0.08193088322877884
# Batch: 120, Loss: 0.1619330644607544
# Batch: 140, Loss: 0.14028696715831757
# Batch: 160, Loss: 0.267177939414978
# Batch: 180, Loss: 0.06922709941864014
# Batch: 200, Loss: 0.1941419541835785
#
# Average loss: 0.1466, Accuracy: 25150.0/26464 (95%)
#
#
# Average loss: 0.1517, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 4 	Training Accuracy: 95.03%
# Validation Accuracy: 95.10%
# Batch: 0, Loss: 0.1709812879562378
# Batch: 20, Loss: 0.11296466737985611
# Batch: 40, Loss: 0.092442587018013
# Batch: 60, Loss: 0.124945268034935
# Batch: 80, Loss: 0.13255487382411957
# Batch: 100, Loss: 0.07219944149255753
# Batch: 120, Loss: 0.11159996688365936
# Batch: 140, Loss: 0.08661631494760513
# Batch: 160, Loss: 0.18818387389183044
# Batch: 180, Loss: 0.10952272266149521
# Batch: 200, Loss: 0.10275021195411682
#
# Average loss: 0.1354, Accuracy: 25243.0/26464 (95%)
#
#
# Average loss: 0.1436, Accuracy: 2809.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 95.39%
# Validation Accuracy: 95.54%
# Batch: 0, Loss: 0.15652918815612793
# Batch: 20, Loss: 0.09976353496313095
# Batch: 40, Loss: 0.17903675138950348
# Batch: 60, Loss: 0.13670220971107483
# Batch: 80, Loss: 0.13787724077701569
# Batch: 100, Loss: 0.13760371506214142
# Batch: 120, Loss: 0.1113540530204773
# Batch: 140, Loss: 0.06649234890937805
# Batch: 160, Loss: 0.08547577261924744
# Batch: 180, Loss: 0.12718753516674042
# Batch: 200, Loss: 0.1304287314414978
#
# Average loss: 0.1299, Accuracy: 25283.0/26464 (96%)
#
#
# Average loss: 0.1431, Accuracy: 2803.0/2940 (95%)
#
# Epoch: 6 	Training Accuracy: 95.54%
# Validation Accuracy: 95.34%
# Batch: 0, Loss: 0.08368267118930817
# Batch: 20, Loss: 0.14175552129745483
# Batch: 40, Loss: 0.07911008596420288
# Batch: 60, Loss: 0.13772228360176086
# Batch: 80, Loss: 0.17280930280685425
# Batch: 100, Loss: 0.10104037821292877
# Batch: 120, Loss: 0.07420340925455093
# Batch: 140, Loss: 0.11160527914762497
# Batch: 160, Loss: 0.11809159070253372
# Batch: 180, Loss: 0.06378286331892014
# Batch: 200, Loss: 0.14471620321273804
#
# Average loss: 0.1224, Accuracy: 25382.0/26464 (96%)
#
#
# Average loss: 0.1358, Accuracy: 2805.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 95.91%
# Validation Accuracy: 95.41%
# Batch: 0, Loss: 0.18340805172920227
# Batch: 20, Loss: 0.1262047290802002
# Batch: 40, Loss: 0.10254275798797607
# Batch: 60, Loss: 0.10325302928686142
# Batch: 80, Loss: 0.18293216824531555
# Batch: 100, Loss: 0.07343389093875885
# Batch: 120, Loss: 0.12807965278625488
# Batch: 140, Loss: 0.12216858565807343
# Batch: 160, Loss: 0.17991875112056732
# Batch: 180, Loss: 0.12118575721979141
# Batch: 200, Loss: 0.11476738750934601
#
# Average loss: 0.1168, Accuracy: 25426.0/26464 (96%)
#
#
# Average loss: 0.1319, Accuracy: 2819.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 96.08%
# Validation Accuracy: 95.88%
# Batch: 0, Loss: 0.09388227015733719
# Batch: 20, Loss: 0.2409156709909439
# Batch: 40, Loss: 0.11585194617509842
# Batch: 60, Loss: 0.10021793097257614
# Batch: 80, Loss: 0.14666201174259186
# Batch: 100, Loss: 0.16323712468147278
# Batch: 120, Loss: 0.15259163081645966
# Batch: 140, Loss: 0.09751326590776443
# Batch: 160, Loss: 0.09803734719753265
# Batch: 180, Loss: 0.24919772148132324
# Batch: 200, Loss: 0.21745382249355316
#
# Average loss: 0.1228, Accuracy: 25393.0/26464 (96%)
#
#
# Average loss: 0.1388, Accuracy: 2809.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 95.95%
# Validation Accuracy: 95.54%
# Batch: 0, Loss: 0.11298175901174545
# Batch: 20, Loss: 0.10336461663246155
# Batch: 40, Loss: 0.05416516959667206
# Batch: 60, Loss: 0.07686606794595718
# Batch: 80, Loss: 0.1393781453371048
# Batch: 100, Loss: 0.18655389547348022
# Batch: 120, Loss: 0.10135063529014587
# Batch: 140, Loss: 0.11878673732280731
# Batch: 160, Loss: 0.11606726050376892
# Batch: 180, Loss: 0.08512956649065018
# Batch: 200, Loss: 0.07528272271156311
#
# Average loss: 0.1149, Accuracy: 25451.0/26464 (96%)
#
#
# Average loss: 0.1361, Accuracy: 2813.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 96.17%
# Validation Accuracy: 95.68%
# Batch: 0, Loss: 0.09087960422039032
# Batch: 20, Loss: 0.07693275809288025
# Batch: 40, Loss: 0.10338913649320602
# Batch: 60, Loss: 0.0514845997095108
# Batch: 80, Loss: 0.11445256322622299
# Batch: 100, Loss: 0.06936049461364746
# Batch: 120, Loss: 0.07284988462924957
# Batch: 140, Loss: 0.11115971207618713
# Batch: 160, Loss: 0.19378529489040375
# Batch: 180, Loss: 0.10647318512201309
# Batch: 200, Loss: 0.06859157234430313
#
# Average loss: 0.1185, Accuracy: 25405.0/26464 (96%)
#
#
# Average loss: 0.1347, Accuracy: 2816.0/2940 (96%)
#
# Epoch: 11 	Training Accuracy: 96.00%
# Validation Accuracy: 95.78%
# Batch: 0, Loss: 0.04913213476538658
# Batch: 20, Loss: 0.1110084131360054
# Batch: 40, Loss: 0.030763428658246994
# Batch: 60, Loss: 0.18398088216781616
# Batch: 80, Loss: 0.06386646628379822
# Batch: 100, Loss: 0.06813202798366547
# Batch: 120, Loss: 0.14898914098739624
# Batch: 140, Loss: 0.15012720227241516
# Batch: 160, Loss: 0.07665590196847916
# Batch: 180, Loss: 0.13759925961494446
# Batch: 200, Loss: 0.13220013678073883
#
# Average loss: 0.1079, Accuracy: 25501.0/26464 (96%)
#
#
# Average loss: 0.1246, Accuracy: 2817.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 96.36%
# Validation Accuracy: 95.82%
# Batch: 0, Loss: 0.07489994913339615
# Batch: 20, Loss: 0.1137707307934761
# Batch: 40, Loss: 0.07819955796003342
# Batch: 60, Loss: 0.13726912438869476
# Batch: 80, Loss: 0.1171933189034462
# Batch: 100, Loss: 0.11417311429977417
# Batch: 120, Loss: 0.11067850142717361
# Batch: 140, Loss: 0.08731752634048462
# Batch: 160, Loss: 0.10507667064666748
# Batch: 180, Loss: 0.10860412567853928
# Batch: 200, Loss: 0.137639582157135
#
# Average loss: 0.1087, Accuracy: 25488.0/26464 (96%)
#
#
# Average loss: 0.1271, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 96.31%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.0843776986002922
# Batch: 20, Loss: 0.08499003201723099
# Batch: 40, Loss: 0.19787880778312683
# Batch: 60, Loss: 0.1217595562338829
# Batch: 80, Loss: 0.05710572749376297
# Batch: 100, Loss: 0.19537675380706787
# Batch: 120, Loss: 0.08143965154886246
# Batch: 140, Loss: 0.12102089822292328
# Batch: 160, Loss: 0.14774513244628906
# Batch: 180, Loss: 0.08644797652959824
# Batch: 200, Loss: 0.12630490958690643
#
# Average loss: 0.1056, Accuracy: 25534.0/26464 (96%)
#
#
# Average loss: 0.1266, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 96.49%
# Validation Accuracy: 95.85%
# Batch: 0, Loss: 0.09916074573993683
# Batch: 20, Loss: 0.10971872508525848
# Batch: 40, Loss: 0.1411072164773941
# Batch: 60, Loss: 0.08606784045696259
# Batch: 80, Loss: 0.21926341950893402
# Batch: 100, Loss: 0.12662364542484283
# Batch: 120, Loss: 0.169401615858078
# Batch: 140, Loss: 0.08071921020746231
# Batch: 160, Loss: 0.0811442881822586
# Batch: 180, Loss: 0.11260973662137985
# Batch: 200, Loss: 0.09252171963453293
#
# Average loss: 0.1078, Accuracy: 25509.0/26464 (96%)
#
#
# Average loss: 0.1373, Accuracy: 2813.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 96.39%
# Validation Accuracy: 95.68%
# Batch: 0, Loss: 0.05376143380999565
# Batch: 20, Loss: 0.07584002614021301
# Batch: 40, Loss: 0.0897536501288414
# Batch: 60, Loss: 0.08255341649055481
# Batch: 80, Loss: 0.1274600774049759
# Batch: 100, Loss: 0.16188254952430725
# Batch: 120, Loss: 0.07752345502376556
# Batch: 140, Loss: 0.12302348762750626
# Batch: 160, Loss: 0.04920877888798714
# Batch: 180, Loss: 0.12137159705162048
# Batch: 200, Loss: 0.15411007404327393
#
# Average loss: 0.1053, Accuracy: 25527.0/26464 (96%)
#
#
# Average loss: 0.1299, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 96.46%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.1542515754699707
# Batch: 20, Loss: 0.08563360571861267
# Batch: 40, Loss: 0.0889059454202652
# Batch: 60, Loss: 0.18235322833061218
# Batch: 80, Loss: 0.09799475967884064
# Batch: 100, Loss: 0.12403779476881027
# Batch: 120, Loss: 0.210109144449234
# Batch: 140, Loss: 0.15900158882141113
# Batch: 160, Loss: 0.12181121855974197
# Batch: 180, Loss: 0.09129101783037186
# Batch: 200, Loss: 0.1270942986011505
#
# Average loss: 0.0989, Accuracy: 25586.0/26464 (97%)
#
#
# Average loss: 0.1274, Accuracy: 2819.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 96.68%
# Validation Accuracy: 95.88%
# Batch: 0, Loss: 0.04496221989393234
# Batch: 20, Loss: 0.04250173270702362
# Batch: 40, Loss: 0.09783516824245453
# Batch: 60, Loss: 0.0608329102396965
# Batch: 80, Loss: 0.09899840503931046
# Batch: 100, Loss: 0.10142520070075989
# Batch: 120, Loss: 0.07649610936641693
# Batch: 140, Loss: 0.05448625981807709
# Batch: 160, Loss: 0.14445075392723083
# Batch: 180, Loss: 0.22341474890708923
# Batch: 200, Loss: 0.10438765585422516
#
# Average loss: 0.0981, Accuracy: 25611.0/26464 (97%)
#
#
# Average loss: 0.1231, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 18 	Training Accuracy: 96.78%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.09662465751171112
# Batch: 20, Loss: 0.08358074724674225
# Batch: 40, Loss: 0.05434880778193474
# Batch: 60, Loss: 0.045889340341091156
# Batch: 80, Loss: 0.112865149974823
# Batch: 100, Loss: 0.03043174371123314
# Batch: 120, Loss: 0.10925489664077759
# Batch: 140, Loss: 0.10201187431812286
# Batch: 160, Loss: 0.07930506765842438
# Batch: 180, Loss: 0.08654377609491348
# Batch: 200, Loss: 0.044569067656993866
#
# Average loss: 0.0979, Accuracy: 25605.0/26464 (97%)
#
#
# Average loss: 0.1286, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 19 	Training Accuracy: 96.75%
# Validation Accuracy: 95.85%
#
# Average loss: 0.0979, Accuracy: 25605.0/26464 (97%)
#
#
# Average loss: 0.1256, Accuracy: 4658.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9675
# Final Test Accuracy (New Data): 0.9582

# %%
plot_layer_effective_ranks(model_finetuning_baseline)
# Out:
# conv0.weight: 3.8735
# conv1.weight: 4.2903
# fc_1.weight: 124.1394
# fc_2.weight: 4.9787

# %% [markdown]
# ***WITH BALANCED CLASSES***

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01]
percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]

seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test = {}
results_train = {}
best_models = {}
data_loaders = {}
epochs_taken = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Training with different data percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []

    for seed in tqdm(seed_set, desc=f'Training for data percentage: {perc}', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")
        
        model_new =  generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=False)
        model_new.to(device)

        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)

        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        # Train and evaluate the new model on the new data
        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        # Add tqdm write method to prevent progress bar overlap
        tqdm.write(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
        tqdm.write(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test[perc] = test_accuracies
    results_train[perc] = train_accuracies
    epochs_taken[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Training with different data percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Training for data percentage: 0.01:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 29 =========================
# Batch: 0, Loss: 1.6062769889831543
#
# Average loss: 1.5751, Accuracy: 76.0/260 (29%)
#
#
# Average loss: 1.5812, Accuracy: 792.0/2940 (27%)
#
# Epoch: 0 	Training Accuracy: 29.23%
# Validation Accuracy: 26.94%
# Batch: 0, Loss: 1.5752042531967163
#
# Average loss: 1.5431, Accuracy: 151.0/260 (58%)
#
#
# Average loss: 1.5534, Accuracy: 1563.0/2940 (53%)
#
# Epoch: 1 	Training Accuracy: 58.08%
# Validation Accuracy: 53.16%
# Batch: 0, Loss: 1.5437633991241455
#
# Average loss: 1.5073, Accuracy: 166.0/260 (64%)
#
#
# Average loss: 1.5228, Accuracy: 1645.0/2940 (56%)
#
# Epoch: 2 	Training Accuracy: 63.85%
# Validation Accuracy: 55.95%
# Batch: 0, Loss: 1.5123202800750732
#
# Average loss: 1.4636, Accuracy: 159.0/260 (61%)
#
#
# Average loss: 1.4857, Accuracy: 1654.0/2940 (56%)
#
# Epoch: 3 	Training Accuracy: 61.15%
# Validation Accuracy: 56.26%
# Batch: 0, Loss: 1.466019868850708
#
# Average loss: 1.4164, Accuracy: 157.0/260 (60%)
#
#
# Average loss: 1.4459, Accuracy: 1555.0/2940 (53%)
#
# Epoch: 4 	Training Accuracy: 60.38%
# Validation Accuracy: 52.89%
# Batch: 0, Loss: 1.4284154176712036
#
# Average loss: 1.3643, Accuracy: 163.0/260 (63%)
#
#
# Average loss: 1.4009, Accuracy: 1615.0/2940 (55%)
#
# Epoch: 5 	Training Accuracy: 62.69%
# Validation Accuracy: 54.93%
# Batch: 0, Loss: 1.3629215955734253
#
# Average loss: 1.3060, Accuracy: 165.0/260 (63%)
#
#
# Average loss: 1.3494, Accuracy: 1586.0/2940 (54%)
#
# Epoch: 6 	Training Accuracy: 63.46%
# Validation Accuracy: 53.95%
# Batch: 0, Loss: 1.3111766576766968
#
# Average loss: 1.2396, Accuracy: 163.0/260 (63%)
#
#
# Average loss: 1.2901, Accuracy: 1602.0/2940 (54%)
#
# Epoch: 7 	Training Accuracy: 62.69%
# Validation Accuracy: 54.49%
# Batch: 0, Loss: 1.2730858325958252
#
# Average loss: 1.1637, Accuracy: 165.0/260 (63%)
#
#
# Average loss: 1.2207, Accuracy: 1677.0/2940 (57%)
#
# Epoch: 8 	Training Accuracy: 63.46%
# Validation Accuracy: 57.04%
# Batch: 0, Loss: 1.144514799118042
#
# Average loss: 1.0740, Accuracy: 177.0/260 (68%)
#
#
# Average loss: 1.1351, Accuracy: 1889.0/2940 (64%)
#
# Epoch: 9 	Training Accuracy: 68.08%
# Validation Accuracy: 64.25%
# Batch: 0, Loss: 1.0781556367874146
#
# Average loss: 0.9735, Accuracy: 199.0/260 (77%)
#
#
# Average loss: 1.0378, Accuracy: 2093.0/2940 (71%)
#
# Epoch: 10 	Training Accuracy: 76.54%
# Validation Accuracy: 71.19%
# Batch: 0, Loss: 0.9841676354408264
#
# Average loss: 0.8736, Accuracy: 211.0/260 (81%)
#
#
# Average loss: 0.9431, Accuracy: 2241.0/2940 (76%)
#
# Epoch: 11 	Training Accuracy: 81.15%
# Validation Accuracy: 76.22%
# Batch: 0, Loss: 0.8645979762077332
#
# Average loss: 0.7831, Accuracy: 215.0/260 (83%)
#
#
# Average loss: 0.8623, Accuracy: 2333.0/2940 (79%)
#
# Epoch: 12 	Training Accuracy: 82.69%
# Validation Accuracy: 79.35%
# Batch: 0, Loss: 0.7609414458274841
#
# Average loss: 0.7032, Accuracy: 221.0/260 (85%)
#
#
# Average loss: 0.7966, Accuracy: 2338.0/2940 (80%)
#
# Epoch: 13 	Training Accuracy: 85.00%
# Validation Accuracy: 79.52%
# Batch: 0, Loss: 0.6964913010597229
#
# Average loss: 0.6369, Accuracy: 221.0/260 (85%)
#
#
# Average loss: 0.7462, Accuracy: 2296.0/2940 (78%)
#
# Epoch: 14 	Training Accuracy: 85.00%
# Validation Accuracy: 78.10%
# Batch: 0, Loss: 0.6411852836608887
#
# Average loss: 0.5780, Accuracy: 219.0/260 (84%)
#
#
# Average loss: 0.7002, Accuracy: 2291.0/2940 (78%)
#
# Epoch: 15 	Training Accuracy: 84.23%
# Validation Accuracy: 77.93%
# Batch: 0, Loss: 0.582342267036438
#
# Average loss: 0.5123, Accuracy: 224.0/260 (86%)
#
#
# Average loss: 0.6448, Accuracy: 2331.0/2940 (79%)
#
# Epoch: 16 	Training Accuracy: 86.15%
# Validation Accuracy: 79.29%
# Batch: 0, Loss: 0.48655420541763306
#
# Average loss: 0.4584, Accuracy: 229.0/260 (88%)
#
#
# Average loss: 0.6049, Accuracy: 2366.0/2940 (80%)
#
# Epoch: 17 	Training Accuracy: 88.08%
# Validation Accuracy: 80.48%
# Batch: 0, Loss: 0.4219006597995758
#
# Average loss: 0.4234, Accuracy: 227.0/260 (87%)
#
#
# Average loss: 0.5863, Accuracy: 2375.0/2940 (81%)
#
# Epoch: 18 	Training Accuracy: 87.31%
# Validation Accuracy: 80.78%
# Batch: 0, Loss: 0.4628435969352722
#
# Average loss: 0.4017, Accuracy: 227.0/260 (87%)
#
#
# Average loss: 0.5787, Accuracy: 2364.0/2940 (80%)
#
# Epoch: 19 	Training Accuracy: 87.31%
# Validation Accuracy: 80.41%
#
# Average loss: 0.4017, Accuracy: 227.0/260 (87%)
#
#
# Average loss: 0.5677, Accuracy: 3961.0/4861 (81%)
#
# Final Training Accuracy (New Data): 0.8731
# Final Test Accuracy (New Data): 0.8149
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 63 =========================
# Batch: 0, Loss: 1.6096687316894531
#
# Average loss: 1.5970, Accuracy: 112.0/260 (43%)
#
#
# Average loss: 1.5999, Accuracy: 1098.0/2940 (37%)
#
# Epoch: 0 	Training Accuracy: 43.08%
# Validation Accuracy: 37.35%
# Batch: 0, Loss: 1.5982425212860107
#
# Average loss: 1.5879, Accuracy: 69.0/260 (27%)
#
#
# Average loss: 1.5915, Accuracy: 824.0/2940 (28%)
#
# Epoch: 1 	Training Accuracy: 26.54%
# Validation Accuracy: 28.03%
# Batch: 0, Loss: 1.5901637077331543
#
# Average loss: 1.5777, Accuracy: 68.0/260 (26%)
#
#
# Average loss: 1.5836, Accuracy: 741.0/2940 (25%)
#
# Epoch: 2 	Training Accuracy: 26.15%
# Validation Accuracy: 25.20%
# Batch: 0, Loss: 1.5803579092025757
#
# Average loss: 1.5702, Accuracy: 86.0/260 (33%)
#
#
# Average loss: 1.5794, Accuracy: 910.0/2940 (31%)
#
# Epoch: 3 	Training Accuracy: 33.08%
# Validation Accuracy: 30.95%
# Batch: 0, Loss: 1.5650557279586792
#
# Average loss: 1.5615, Accuracy: 132.0/260 (51%)
#
#
# Average loss: 1.5750, Accuracy: 1326.0/2940 (45%)
#
# Epoch: 4 	Training Accuracy: 50.77%
# Validation Accuracy: 45.10%
# Batch: 0, Loss: 1.576169490814209
#
# Average loss: 1.5492, Accuracy: 130.0/260 (50%)
#
#
# Average loss: 1.5650, Accuracy: 1169.0/2940 (40%)
#
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 39.76%
# Batch: 0, Loss: 1.5544583797454834
#
# Average loss: 1.5421, Accuracy: 98.0/260 (38%)
#
#
# Average loss: 1.5593, Accuracy: 879.0/2940 (30%)
#
# Epoch: 6 	Training Accuracy: 37.69%
# Validation Accuracy: 29.90%
# Batch: 0, Loss: 1.5436562299728394
#
# Average loss: 1.5371, Accuracy: 129.0/260 (50%)
#
#
# Average loss: 1.5550, Accuracy: 1090.0/2940 (37%)
#
# Epoch: 7 	Training Accuracy: 49.62%
# Validation Accuracy: 37.07%
# Batch: 0, Loss: 1.531762719154358
#
# Average loss: 1.5257, Accuracy: 176.0/260 (68%)
#
#
# Average loss: 1.5457, Accuracy: 1504.0/2940 (51%)
#
# Epoch: 8 	Training Accuracy: 67.69%
# Validation Accuracy: 51.16%
# Batch: 0, Loss: 1.526495337486267
#
# Average loss: 1.5028, Accuracy: 184.0/260 (71%)
#
#
# Average loss: 1.5275, Accuracy: 1681.0/2940 (57%)
#
# Epoch: 9 	Training Accuracy: 70.77%
# Validation Accuracy: 57.18%
# Batch: 0, Loss: 1.4988538026809692
#
# Average loss: 1.4757, Accuracy: 170.0/260 (65%)
#
#
# Average loss: 1.5060, Accuracy: 1604.0/2940 (55%)
#
# Epoch: 10 	Training Accuracy: 65.38%
# Validation Accuracy: 54.56%
# Batch: 0, Loss: 1.4752564430236816
#
# Average loss: 1.4501, Accuracy: 183.0/260 (70%)
#
#
# Average loss: 1.4833, Accuracy: 1718.0/2940 (58%)
#
# Epoch: 11 	Training Accuracy: 70.38%
# Validation Accuracy: 58.44%
# Batch: 0, Loss: 1.4368242025375366
#
# Average loss: 1.4245, Accuracy: 182.0/260 (70%)
#
#
# Average loss: 1.4585, Accuracy: 1850.0/2940 (63%)
#
# Epoch: 12 	Training Accuracy: 70.00%
# Validation Accuracy: 62.93%
# Batch: 0, Loss: 1.4373393058776855
#
# Average loss: 1.3979, Accuracy: 170.0/260 (65%)
#
#
# Average loss: 1.4336, Accuracy: 1787.0/2940 (61%)
#
# Epoch: 13 	Training Accuracy: 65.38%
# Validation Accuracy: 60.78%
# Batch: 0, Loss: 1.4121298789978027
#
# Average loss: 1.3669, Accuracy: 168.0/260 (65%)
#
#
# Average loss: 1.4073, Accuracy: 1779.0/2940 (61%)
#
# Epoch: 14 	Training Accuracy: 64.62%
# Validation Accuracy: 60.51%
# Batch: 0, Loss: 1.3812528848648071
#
# Average loss: 1.3336, Accuracy: 169.0/260 (65%)
#
#
# Average loss: 1.3832, Accuracy: 1765.0/2940 (60%)
#
# Epoch: 15 	Training Accuracy: 65.00%
# Validation Accuracy: 60.03%
# Batch: 0, Loss: 1.3214365243911743
#
# Average loss: 1.2986, Accuracy: 159.0/260 (61%)
#
#
# Average loss: 1.3601, Accuracy: 1622.0/2940 (55%)
#
# Epoch: 16 	Training Accuracy: 61.15%
# Validation Accuracy: 55.17%
# Batch: 0, Loss: 1.2742317914962769
#
# Average loss: 1.2507, Accuracy: 183.0/260 (70%)
#
#
# Average loss: 1.3199, Accuracy: 1814.0/2940 (62%)
#
# Epoch: 17 	Training Accuracy: 70.38%
# Validation Accuracy: 61.70%
# Batch: 0, Loss: 1.2427855730056763
#
# Average loss: 1.2054, Accuracy: 193.0/260 (74%)
#
#
# Average loss: 1.2770, Accuracy: 1883.0/2940 (64%)
#
# Epoch: 18 	Training Accuracy: 74.23%
# Validation Accuracy: 64.05%
# Batch: 0, Loss: 1.2154595851898193
#
# Average loss: 1.1633, Accuracy: 183.0/260 (70%)
#
#
# Average loss: 1.2367, Accuracy: 1865.0/2940 (63%)
#
# Epoch: 19 	Training Accuracy: 70.38%
# Validation Accuracy: 63.44%
#
# Average loss: 1.1633, Accuracy: 183.0/260 (70%)
#
#
# Average loss: 1.2391, Accuracy: 3021.0/4861 (62%)
#
# Final Training Accuracy (New Data): 0.7038
# Final Test Accuracy (New Data): 0.6215
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 84 =========================
# Batch: 0, Loss: 1.6139065027236938
#
# Average loss: 1.5723, Accuracy: 66.0/260 (25%)
#
#
# Average loss: 1.5716, Accuracy: 780.0/2940 (27%)
#
# Epoch: 0 	Training Accuracy: 25.38%
# Validation Accuracy: 26.53%
# Batch: 0, Loss: 1.562358021736145
#
# Average loss: 1.5527, Accuracy: 131.0/260 (50%)
#
#
# Average loss: 1.5540, Accuracy: 1461.0/2940 (50%)
#
# Epoch: 1 	Training Accuracy: 50.38%
# Validation Accuracy: 49.69%
# Batch: 0, Loss: 1.5877000093460083
#
# Average loss: 1.5155, Accuracy: 94.0/260 (36%)
#
#
# Average loss: 1.5118, Accuracy: 1090.0/2940 (37%)
#
# Epoch: 2 	Training Accuracy: 36.15%
# Validation Accuracy: 37.07%
# Batch: 0, Loss: 1.5034772157669067
#
# Average loss: 1.4645, Accuracy: 81.0/260 (31%)
#
#
# Average loss: 1.4541, Accuracy: 1000.0/2940 (34%)
#
# Epoch: 3 	Training Accuracy: 31.15%
# Validation Accuracy: 34.01%
# Batch: 0, Loss: 1.45867919921875
#
# Average loss: 1.4118, Accuracy: 131.0/260 (50%)
#
#
# Average loss: 1.4050, Accuracy: 1541.0/2940 (52%)
#
# Epoch: 4 	Training Accuracy: 50.38%
# Validation Accuracy: 52.41%
# Batch: 0, Loss: 1.4104094505310059
#
# Average loss: 1.3735, Accuracy: 170.0/260 (65%)
#
#
# Average loss: 1.3731, Accuracy: 1894.0/2940 (64%)
#
# Epoch: 5 	Training Accuracy: 65.38%
# Validation Accuracy: 64.42%
# Batch: 0, Loss: 1.3974322080612183
#
# Average loss: 1.3008, Accuracy: 156.0/260 (60%)
#
#
# Average loss: 1.3052, Accuracy: 1741.0/2940 (59%)
#
# Epoch: 6 	Training Accuracy: 60.00%
# Validation Accuracy: 59.22%
# Batch: 0, Loss: 1.3504689931869507
#
# Average loss: 1.1765, Accuracy: 176.0/260 (68%)
#
#
# Average loss: 1.1848, Accuracy: 1963.0/2940 (67%)
#
# Epoch: 7 	Training Accuracy: 67.69%
# Validation Accuracy: 66.77%
# Batch: 0, Loss: 1.1266698837280273
#
# Average loss: 1.0599, Accuracy: 189.0/260 (73%)
#
#
# Average loss: 1.0738, Accuracy: 2104.0/2940 (72%)
#
# Epoch: 8 	Training Accuracy: 72.69%
# Validation Accuracy: 71.56%
# Batch: 0, Loss: 1.0723623037338257
#
# Average loss: 0.9828, Accuracy: 189.0/260 (73%)
#
#
# Average loss: 0.9969, Accuracy: 2086.0/2940 (71%)
#
# Epoch: 9 	Training Accuracy: 72.69%
# Validation Accuracy: 70.95%
# Batch: 0, Loss: 0.9903527498245239
#
# Average loss: 0.8375, Accuracy: 202.0/260 (78%)
#
#
# Average loss: 0.8624, Accuracy: 2210.0/2940 (75%)
#
# Epoch: 10 	Training Accuracy: 77.69%
# Validation Accuracy: 75.17%
# Batch: 0, Loss: 0.8665340542793274
#
# Average loss: 0.7048, Accuracy: 201.0/260 (77%)
#
#
# Average loss: 0.7480, Accuracy: 2224.0/2940 (76%)
#
# Epoch: 11 	Training Accuracy: 77.31%
# Validation Accuracy: 75.65%
# Batch: 0, Loss: 0.7302005290985107
#
# Average loss: 0.6138, Accuracy: 211.0/260 (81%)
#
#
# Average loss: 0.6786, Accuracy: 2245.0/2940 (76%)
#
# Epoch: 12 	Training Accuracy: 81.15%
# Validation Accuracy: 76.36%
# Batch: 0, Loss: 0.6354836225509644
#
# Average loss: 0.6135, Accuracy: 195.0/260 (75%)
#
#
# Average loss: 0.6990, Accuracy: 2155.0/2940 (73%)
#
# Epoch: 13 	Training Accuracy: 75.00%
# Validation Accuracy: 73.30%
# Batch: 0, Loss: 0.6433284878730774
#
# Average loss: 0.6094, Accuracy: 194.0/260 (75%)
#
#
# Average loss: 0.7075, Accuracy: 2118.0/2940 (72%)
#
# Epoch: 14 	Training Accuracy: 74.62%
# Validation Accuracy: 72.04%
# Batch: 0, Loss: 0.5771777033805847
#
# Average loss: 0.4375, Accuracy: 225.0/260 (87%)
#
#
# Average loss: 0.5405, Accuracy: 2344.0/2940 (80%)
#
# Epoch: 15 	Training Accuracy: 86.54%
# Validation Accuracy: 79.73%
# Batch: 0, Loss: 0.41505810618400574
#
# Average loss: 0.5888, Accuracy: 197.0/260 (76%)
#
#
# Average loss: 0.6877, Accuracy: 2153.0/2940 (73%)
#
# Epoch: 16 	Training Accuracy: 75.77%
# Validation Accuracy: 73.23%
# Batch: 0, Loss: 0.5745908617973328
#
# Average loss: 0.6251, Accuracy: 192.0/260 (74%)
#
#
# Average loss: 0.7949, Accuracy: 2072.0/2940 (70%)
#
# Epoch: 17 	Training Accuracy: 73.85%
# Validation Accuracy: 70.48%
# Batch: 0, Loss: 0.5955296754837036
#
# Average loss: 0.6490, Accuracy: 198.0/260 (76%)
#
#
# Average loss: 0.7870, Accuracy: 2137.0/2940 (73%)
#
# Epoch: 18 	Training Accuracy: 76.15%
# Validation Accuracy: 72.69%
# Batch: 0, Loss: 0.6474165916442871
#
# Average loss: 0.5228, Accuracy: 206.0/260 (79%)
#
#
# Average loss: 0.6503, Accuracy: 2217.0/2940 (75%)
#
# Epoch: 19 	Training Accuracy: 79.23%
# Validation Accuracy: 75.41%
#
# Average loss: 0.5228, Accuracy: 206.0/260 (79%)
#
#
# Average loss: 0.6330, Accuracy: 3680.0/4861 (76%)
#
# Final Training Accuracy (New Data): 0.7923
# Final Test Accuracy (New Data): 0.7570
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 30 =========================
# Batch: 0, Loss: 1.6144566535949707
#
# Average loss: 1.6103, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6088, Accuracy: 655.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6062654256820679
#
# Average loss: 1.6104, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6090, Accuracy: 655.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6110634803771973
#
# Average loss: 1.6103, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6090, Accuracy: 655.0/2940 (22%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6099474430084229
#
# Average loss: 1.6101, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6088, Accuracy: 655.0/2940 (22%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.609755516052246
#
# Average loss: 1.6094, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6085, Accuracy: 655.0/2940 (22%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6092700958251953
#
# Average loss: 1.6081, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6078, Accuracy: 655.0/2940 (22%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6100056171417236
#
# Average loss: 1.6053, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6060, Accuracy: 655.0/2940 (22%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Early stopping invoked.
#
# Average loss: 1.6103, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6090, Accuracy: 1028.0/4861 (21%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.2115
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 27 =========================
# Batch: 0, Loss: 1.6101553440093994
#
# Average loss: 1.5796, Accuracy: 64.0/260 (25%)
#
#
# Average loss: 1.5796, Accuracy: 789.0/2940 (27%)
#
# Epoch: 0 	Training Accuracy: 24.62%
# Validation Accuracy: 26.84%
# Batch: 0, Loss: 1.5769391059875488
#
# Average loss: 1.5598, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.5618, Accuracy: 621.0/2940 (21%)
#
# Epoch: 1 	Training Accuracy: 20.38%
# Validation Accuracy: 21.12%
# Batch: 0, Loss: 1.5543707609176636
#
# Average loss: 1.5384, Accuracy: 59.0/260 (23%)
#
#
# Average loss: 1.5435, Accuracy: 717.0/2940 (24%)
#
# Epoch: 2 	Training Accuracy: 22.69%
# Validation Accuracy: 24.39%
# Batch: 0, Loss: 1.5227655172348022
#
# Average loss: 1.5137, Accuracy: 82.0/260 (32%)
#
#
# Average loss: 1.5229, Accuracy: 916.0/2940 (31%)
#
# Epoch: 3 	Training Accuracy: 31.54%
# Validation Accuracy: 31.16%
# Batch: 0, Loss: 1.527817726135254
#
# Average loss: 1.4839, Accuracy: 104.0/260 (40%)
#
#
# Average loss: 1.4973, Accuracy: 1081.0/2940 (37%)
#
# Epoch: 4 	Training Accuracy: 40.00%
# Validation Accuracy: 36.77%
# Batch: 0, Loss: 1.483245611190796
#
# Average loss: 1.4461, Accuracy: 121.0/260 (47%)
#
#
# Average loss: 1.4633, Accuracy: 1246.0/2940 (42%)
#
# Epoch: 5 	Training Accuracy: 46.54%
# Validation Accuracy: 42.38%
# Batch: 0, Loss: 1.4712042808532715
#
# Average loss: 1.3946, Accuracy: 139.0/260 (53%)
#
#
# Average loss: 1.4144, Accuracy: 1391.0/2940 (47%)
#
# Epoch: 6 	Training Accuracy: 53.46%
# Validation Accuracy: 47.31%
# Batch: 0, Loss: 1.3928579092025757
#
# Average loss: 1.3279, Accuracy: 150.0/260 (58%)
#
#
# Average loss: 1.3501, Accuracy: 1567.0/2940 (53%)
#
# Epoch: 7 	Training Accuracy: 57.69%
# Validation Accuracy: 53.30%
# Batch: 0, Loss: 1.3288699388504028
#
# Average loss: 1.2432, Accuracy: 184.0/260 (71%)
#
#
# Average loss: 1.2653, Accuracy: 2002.0/2940 (68%)
#
# Epoch: 8 	Training Accuracy: 70.77%
# Validation Accuracy: 68.10%
# Batch: 0, Loss: 1.2426329851150513
#
# Average loss: 1.1515, Accuracy: 219.0/260 (84%)
#
#
# Average loss: 1.1748, Accuracy: 2341.0/2940 (80%)
#
# Epoch: 9 	Training Accuracy: 84.23%
# Validation Accuracy: 79.63%
# Batch: 0, Loss: 1.1553175449371338
#
# Average loss: 1.0649, Accuracy: 211.0/260 (81%)
#
#
# Average loss: 1.0913, Accuracy: 2301.0/2940 (78%)
#
# Epoch: 10 	Training Accuracy: 81.15%
# Validation Accuracy: 78.27%
# Batch: 0, Loss: 1.0353683233261108
#
# Average loss: 0.9811, Accuracy: 204.0/260 (78%)
#
#
# Average loss: 1.0095, Accuracy: 2244.0/2940 (76%)
#
# Epoch: 11 	Training Accuracy: 78.46%
# Validation Accuracy: 76.33%
# Batch: 0, Loss: 0.8931939601898193
#
# Average loss: 0.9033, Accuracy: 202.0/260 (78%)
#
#
# Average loss: 0.9324, Accuracy: 2233.0/2940 (76%)
#
# Epoch: 12 	Training Accuracy: 77.69%
# Validation Accuracy: 75.95%
# Batch: 0, Loss: 0.8958154320716858
#
# Average loss: 0.8178, Accuracy: 204.0/260 (78%)
#
#
# Average loss: 0.8496, Accuracy: 2273.0/2940 (77%)
#
# Epoch: 13 	Training Accuracy: 78.46%
# Validation Accuracy: 77.31%
# Batch: 0, Loss: 0.8354120254516602
#
# Average loss: 0.7360, Accuracy: 210.0/260 (81%)
#
#
# Average loss: 0.7757, Accuracy: 2281.0/2940 (78%)
#
# Epoch: 14 	Training Accuracy: 80.77%
# Validation Accuracy: 77.59%
# Batch: 0, Loss: 0.7086644768714905
#
# Average loss: 0.6858, Accuracy: 205.0/260 (79%)
#
#
# Average loss: 0.7441, Accuracy: 2219.0/2940 (75%)
#
# Epoch: 15 	Training Accuracy: 78.85%
# Validation Accuracy: 75.48%
# Early stopping invoked.
#
# Average loss: 1.1515, Accuracy: 219.0/260 (84%)
#
#
# Average loss: 1.1741, Accuracy: 3839.0/4861 (79%)
#
# Final Training Accuracy (New Data): 0.8423
# Final Test Accuracy (New Data): 0.7898
# Training for data percentage: 0.03:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 16 =========================
# Batch: 0, Loss: 1.613884687423706
#
# Average loss: 1.5611, Accuracy: 357.0/790 (45%)
#
#
# Average loss: 1.5635, Accuracy: 1391.0/2940 (47%)
#
# Epoch: 0 	Training Accuracy: 45.19%
# Validation Accuracy: 47.31%
# Batch: 0, Loss: 1.5604032278060913
#
# Average loss: 1.4381, Accuracy: 504.0/790 (64%)
#
#
# Average loss: 1.4487, Accuracy: 1922.0/2940 (65%)
#
# Epoch: 1 	Training Accuracy: 63.80%
# Validation Accuracy: 65.37%
# Batch: 0, Loss: 1.4266177415847778
#
# Average loss: 1.2059, Accuracy: 555.0/790 (70%)
#
#
# Average loss: 1.2293, Accuracy: 2075.0/2940 (71%)
#
# Epoch: 2 	Training Accuracy: 70.25%
# Validation Accuracy: 70.58%
# Batch: 0, Loss: 1.209936261177063
#
# Average loss: 0.9035, Accuracy: 596.0/790 (75%)
#
#
# Average loss: 0.9384, Accuracy: 2217.0/2940 (75%)
#
# Epoch: 3 	Training Accuracy: 75.44%
# Validation Accuracy: 75.41%
# Batch: 0, Loss: 0.9116894006729126
#
# Average loss: 0.6378, Accuracy: 653.0/790 (83%)
#
#
# Average loss: 0.6892, Accuracy: 2368.0/2940 (81%)
#
# Epoch: 4 	Training Accuracy: 82.66%
# Validation Accuracy: 80.54%
# Batch: 0, Loss: 0.6950037479400635
#
# Average loss: 0.4741, Accuracy: 672.0/790 (85%)
#
#
# Average loss: 0.5363, Accuracy: 2437.0/2940 (83%)
#
# Epoch: 5 	Training Accuracy: 85.06%
# Validation Accuracy: 82.89%
# Batch: 0, Loss: 0.5429650545120239
#
# Average loss: 0.3776, Accuracy: 689.0/790 (87%)
#
#
# Average loss: 0.4537, Accuracy: 2475.0/2940 (84%)
#
# Epoch: 6 	Training Accuracy: 87.22%
# Validation Accuracy: 84.18%
# Batch: 0, Loss: 0.3628751337528229
#
# Average loss: 0.3201, Accuracy: 708.0/790 (90%)
#
#
# Average loss: 0.4100, Accuracy: 2521.0/2940 (86%)
#
# Epoch: 7 	Training Accuracy: 89.62%
# Validation Accuracy: 85.75%
# Batch: 0, Loss: 0.36542585492134094
#
# Average loss: 0.2803, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.3874, Accuracy: 2543.0/2940 (86%)
#
# Epoch: 8 	Training Accuracy: 91.39%
# Validation Accuracy: 86.50%
# Batch: 0, Loss: 0.28168022632598877
#
# Average loss: 0.2478, Accuracy: 729.0/790 (92%)
#
#
# Average loss: 0.3671, Accuracy: 2574.0/2940 (88%)
#
# Epoch: 9 	Training Accuracy: 92.28%
# Validation Accuracy: 87.55%
# Batch: 0, Loss: 0.21172769367694855
#
# Average loss: 0.2217, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.3618, Accuracy: 2594.0/2940 (88%)
#
# Epoch: 10 	Training Accuracy: 93.42%
# Validation Accuracy: 88.23%
# Batch: 0, Loss: 0.170381560921669
#
# Average loss: 0.2019, Accuracy: 739.0/790 (94%)
#
#
# Average loss: 0.3571, Accuracy: 2592.0/2940 (88%)
#
# Epoch: 11 	Training Accuracy: 93.54%
# Validation Accuracy: 88.16%
# Batch: 0, Loss: 0.2226414978504181
#
# Average loss: 0.1880, Accuracy: 744.0/790 (94%)
#
#
# Average loss: 0.3518, Accuracy: 2595.0/2940 (88%)
#
# Epoch: 12 	Training Accuracy: 94.18%
# Validation Accuracy: 88.27%
# Batch: 0, Loss: 0.14559270441532135
#
# Average loss: 0.1741, Accuracy: 744.0/790 (94%)
#
#
# Average loss: 0.3400, Accuracy: 2614.0/2940 (89%)
#
# Epoch: 13 	Training Accuracy: 94.18%
# Validation Accuracy: 88.91%
# Batch: 0, Loss: 0.13250024616718292
#
# Average loss: 0.1640, Accuracy: 752.0/790 (95%)
#
#
# Average loss: 0.3511, Accuracy: 2607.0/2940 (89%)
#
# Epoch: 14 	Training Accuracy: 95.19%
# Validation Accuracy: 88.67%
# Batch: 0, Loss: 0.15569794178009033
#
# Average loss: 0.1467, Accuracy: 749.0/790 (95%)
#
#
# Average loss: 0.3411, Accuracy: 2623.0/2940 (89%)
#
# Epoch: 15 	Training Accuracy: 94.81%
# Validation Accuracy: 89.22%
# Batch: 0, Loss: 0.11859550327062607
#
# Average loss: 0.1395, Accuracy: 757.0/790 (96%)
#
#
# Average loss: 0.3431, Accuracy: 2618.0/2940 (89%)
#
# Epoch: 16 	Training Accuracy: 95.82%
# Validation Accuracy: 89.05%
# Batch: 0, Loss: 0.13722993433475494
#
# Average loss: 0.1266, Accuracy: 762.0/790 (96%)
#
#
# Average loss: 0.3464, Accuracy: 2617.0/2940 (89%)
#
# Epoch: 17 	Training Accuracy: 96.46%
# Validation Accuracy: 89.01%
# Batch: 0, Loss: 0.14538255333900452
#
# Average loss: 0.1161, Accuracy: 762.0/790 (96%)
#
#
# Average loss: 0.3411, Accuracy: 2629.0/2940 (89%)
#
# Epoch: 18 	Training Accuracy: 96.46%
# Validation Accuracy: 89.42%
# Batch: 0, Loss: 0.11808834969997406
#
# Average loss: 0.1108, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.3443, Accuracy: 2635.0/2940 (90%)
#
# Epoch: 19 	Training Accuracy: 96.33%
# Validation Accuracy: 89.63%
#
# Average loss: 0.1108, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.3367, Accuracy: 4364.0/4861 (90%)
#
# Final Training Accuracy (New Data): 0.9633
# Final Test Accuracy (New Data): 0.8978
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 46 =========================
# Batch: 0, Loss: 1.607835292816162
#
# Average loss: 1.5776, Accuracy: 396.0/790 (50%)
#
#
# Average loss: 1.5819, Accuracy: 1335.0/2940 (45%)
#
# Epoch: 0 	Training Accuracy: 50.13%
# Validation Accuracy: 45.41%
# Batch: 0, Loss: 1.5725913047790527
#
# Average loss: 1.5078, Accuracy: 561.0/790 (71%)
#
#
# Average loss: 1.5142, Accuracy: 1991.0/2940 (68%)
#
# Epoch: 1 	Training Accuracy: 71.01%
# Validation Accuracy: 67.72%
# Batch: 0, Loss: 1.5045361518859863
#
# Average loss: 1.3631, Accuracy: 558.0/790 (71%)
#
#
# Average loss: 1.3721, Accuracy: 2034.0/2940 (69%)
#
# Epoch: 2 	Training Accuracy: 70.63%
# Validation Accuracy: 69.18%
# Batch: 0, Loss: 1.3736516237258911
#
# Average loss: 1.1227, Accuracy: 562.0/790 (71%)
#
#
# Average loss: 1.1309, Accuracy: 2075.0/2940 (71%)
#
# Epoch: 3 	Training Accuracy: 71.14%
# Validation Accuracy: 70.58%
# Batch: 0, Loss: 1.1443582773208618
#
# Average loss: 0.8393, Accuracy: 607.0/790 (77%)
#
#
# Average loss: 0.8448, Accuracy: 2223.0/2940 (76%)
#
# Epoch: 4 	Training Accuracy: 76.84%
# Validation Accuracy: 75.61%
# Batch: 0, Loss: 0.8975925445556641
#
# Average loss: 0.6236, Accuracy: 647.0/790 (82%)
#
#
# Average loss: 0.6338, Accuracy: 2331.0/2940 (79%)
#
# Epoch: 5 	Training Accuracy: 81.90%
# Validation Accuracy: 79.29%
# Batch: 0, Loss: 0.568518877029419
#
# Average loss: 0.4884, Accuracy: 668.0/790 (85%)
#
#
# Average loss: 0.5064, Accuracy: 2446.0/2940 (83%)
#
# Epoch: 6 	Training Accuracy: 84.56%
# Validation Accuracy: 83.20%
# Batch: 0, Loss: 0.47489967942237854
#
# Average loss: 0.3950, Accuracy: 695.0/790 (88%)
#
#
# Average loss: 0.4206, Accuracy: 2526.0/2940 (86%)
#
# Epoch: 7 	Training Accuracy: 87.97%
# Validation Accuracy: 85.92%
# Batch: 0, Loss: 0.3168899416923523
#
# Average loss: 0.3389, Accuracy: 706.0/790 (89%)
#
#
# Average loss: 0.3705, Accuracy: 2577.0/2940 (88%)
#
# Epoch: 8 	Training Accuracy: 89.37%
# Validation Accuracy: 87.65%
# Batch: 0, Loss: 0.34487268328666687
#
# Average loss: 0.2970, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.3325, Accuracy: 2609.0/2940 (89%)
#
# Epoch: 9 	Training Accuracy: 91.39%
# Validation Accuracy: 88.74%
# Batch: 0, Loss: 0.32263144850730896
#
# Average loss: 0.2679, Accuracy: 723.0/790 (92%)
#
#
# Average loss: 0.3104, Accuracy: 2632.0/2940 (90%)
#
# Epoch: 10 	Training Accuracy: 91.52%
# Validation Accuracy: 89.52%
# Batch: 0, Loss: 0.24094797670841217
#
# Average loss: 0.2441, Accuracy: 734.0/790 (93%)
#
#
# Average loss: 0.2947, Accuracy: 2638.0/2940 (90%)
#
# Epoch: 11 	Training Accuracy: 92.91%
# Validation Accuracy: 89.73%
# Batch: 0, Loss: 0.2019842565059662
#
# Average loss: 0.2246, Accuracy: 739.0/790 (94%)
#
#
# Average loss: 0.2821, Accuracy: 2667.0/2940 (91%)
#
# Epoch: 12 	Training Accuracy: 93.54%
# Validation Accuracy: 90.71%
# Batch: 0, Loss: 0.22268860042095184
#
# Average loss: 0.2122, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.2745, Accuracy: 2677.0/2940 (91%)
#
# Epoch: 13 	Training Accuracy: 93.42%
# Validation Accuracy: 91.05%
# Batch: 0, Loss: 0.216653510928154
#
# Average loss: 0.1994, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.2734, Accuracy: 2674.0/2940 (91%)
#
# Epoch: 14 	Training Accuracy: 93.16%
# Validation Accuracy: 90.95%
# Batch: 0, Loss: 0.1554204523563385
#
# Average loss: 0.1853, Accuracy: 741.0/790 (94%)
#
#
# Average loss: 0.2655, Accuracy: 2680.0/2940 (91%)
#
# Epoch: 15 	Training Accuracy: 93.80%
# Validation Accuracy: 91.16%
# Batch: 0, Loss: 0.14645837247371674
#
# Average loss: 0.1786, Accuracy: 744.0/790 (94%)
#
#
# Average loss: 0.2651, Accuracy: 2676.0/2940 (91%)
#
# Epoch: 16 	Training Accuracy: 94.18%
# Validation Accuracy: 91.02%
# Batch: 0, Loss: 0.1746167689561844
#
# Average loss: 0.1689, Accuracy: 746.0/790 (94%)
#
#
# Average loss: 0.2629, Accuracy: 2691.0/2940 (92%)
#
# Epoch: 17 	Training Accuracy: 94.43%
# Validation Accuracy: 91.53%
# Batch: 0, Loss: 0.17923180758953094
#
# Average loss: 0.1579, Accuracy: 751.0/790 (95%)
#
#
# Average loss: 0.2582, Accuracy: 2693.0/2940 (92%)
#
# Epoch: 18 	Training Accuracy: 95.06%
# Validation Accuracy: 91.60%
# Batch: 0, Loss: 0.2065030038356781
#
# Average loss: 0.1484, Accuracy: 751.0/790 (95%)
#
#
# Average loss: 0.2552, Accuracy: 2701.0/2940 (92%)
#
# Epoch: 19 	Training Accuracy: 95.06%
# Validation Accuracy: 91.87%
#
# Average loss: 0.1484, Accuracy: 751.0/790 (95%)
#
#
# Average loss: 0.2461, Accuracy: 4460.0/4861 (92%)
#
# Final Training Accuracy (New Data): 0.9506
# Final Test Accuracy (New Data): 0.9175
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 79 =========================
# Batch: 0, Loss: 1.610357403755188
#
# Average loss: 1.5918, Accuracy: 272.0/790 (34%)
#
#
# Average loss: 1.5927, Accuracy: 974.0/2940 (33%)
#
# Epoch: 0 	Training Accuracy: 34.43%
# Validation Accuracy: 33.13%
# Batch: 0, Loss: 1.5941771268844604
#
# Average loss: 1.5265, Accuracy: 467.0/790 (59%)
#
#
# Average loss: 1.5265, Accuracy: 1682.0/2940 (57%)
#
# Epoch: 1 	Training Accuracy: 59.11%
# Validation Accuracy: 57.21%
# Batch: 0, Loss: 1.5224186182022095
#
# Average loss: 1.3570, Accuracy: 572.0/790 (72%)
#
#
# Average loss: 1.3537, Accuracy: 2076.0/2940 (71%)
#
# Epoch: 2 	Training Accuracy: 72.41%
# Validation Accuracy: 70.61%
# Batch: 0, Loss: 1.3562889099121094
#
# Average loss: 1.0536, Accuracy: 623.0/790 (79%)
#
#
# Average loss: 1.0480, Accuracy: 2259.0/2940 (77%)
#
# Epoch: 3 	Training Accuracy: 78.86%
# Validation Accuracy: 76.84%
# Batch: 0, Loss: 1.0461784601211548
#
# Average loss: 0.7269, Accuracy: 657.0/790 (83%)
#
#
# Average loss: 0.7273, Accuracy: 2417.0/2940 (82%)
#
# Epoch: 4 	Training Accuracy: 83.16%
# Validation Accuracy: 82.21%
# Batch: 0, Loss: 0.7921685576438904
#
# Average loss: 0.5115, Accuracy: 676.0/790 (86%)
#
#
# Average loss: 0.5302, Accuracy: 2497.0/2940 (85%)
#
# Epoch: 5 	Training Accuracy: 85.57%
# Validation Accuracy: 84.93%
# Batch: 0, Loss: 0.5676694512367249
#
# Average loss: 0.3989, Accuracy: 689.0/790 (87%)
#
#
# Average loss: 0.4449, Accuracy: 2541.0/2940 (86%)
#
# Epoch: 6 	Training Accuracy: 87.22%
# Validation Accuracy: 86.43%
# Batch: 0, Loss: 0.4516618251800537
#
# Average loss: 0.3331, Accuracy: 698.0/790 (88%)
#
#
# Average loss: 0.4074, Accuracy: 2580.0/2940 (88%)
#
# Epoch: 7 	Training Accuracy: 88.35%
# Validation Accuracy: 87.76%
# Batch: 0, Loss: 0.23279449343681335
#
# Average loss: 0.2877, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.3777, Accuracy: 2622.0/2940 (89%)
#
# Epoch: 8 	Training Accuracy: 90.38%
# Validation Accuracy: 89.18%
# Batch: 0, Loss: 0.28308531641960144
#
# Average loss: 0.2579, Accuracy: 723.0/790 (92%)
#
#
# Average loss: 0.3651, Accuracy: 2633.0/2940 (90%)
#
# Epoch: 9 	Training Accuracy: 91.52%
# Validation Accuracy: 89.56%
# Batch: 0, Loss: 0.2955563962459564
#
# Average loss: 0.2329, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.3525, Accuracy: 2643.0/2940 (90%)
#
# Epoch: 10 	Training Accuracy: 92.15%
# Validation Accuracy: 89.90%
# Batch: 0, Loss: 0.2585957646369934
#
# Average loss: 0.2101, Accuracy: 737.0/790 (93%)
#
#
# Average loss: 0.3396, Accuracy: 2655.0/2940 (90%)
#
# Epoch: 11 	Training Accuracy: 93.29%
# Validation Accuracy: 90.31%
# Batch: 0, Loss: 0.29524773359298706
#
# Average loss: 0.1968, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.3395, Accuracy: 2650.0/2940 (90%)
#
# Epoch: 12 	Training Accuracy: 93.42%
# Validation Accuracy: 90.14%
# Batch: 0, Loss: 0.14441408216953278
#
# Average loss: 0.2099, Accuracy: 732.0/790 (93%)
#
#
# Average loss: 0.3586, Accuracy: 2630.0/2940 (89%)
#
# Epoch: 13 	Training Accuracy: 92.66%
# Validation Accuracy: 89.46%
# Batch: 0, Loss: 0.279913067817688
#
# Average loss: 0.1662, Accuracy: 748.0/790 (95%)
#
#
# Average loss: 0.3262, Accuracy: 2678.0/2940 (91%)
#
# Epoch: 14 	Training Accuracy: 94.68%
# Validation Accuracy: 91.09%
# Batch: 0, Loss: 0.17529799044132233
#
# Average loss: 0.1549, Accuracy: 757.0/790 (96%)
#
#
# Average loss: 0.3217, Accuracy: 2683.0/2940 (91%)
#
# Epoch: 15 	Training Accuracy: 95.82%
# Validation Accuracy: 91.26%
# Batch: 0, Loss: 0.15581399202346802
#
# Average loss: 0.1562, Accuracy: 753.0/790 (95%)
#
#
# Average loss: 0.3309, Accuracy: 2679.0/2940 (91%)
#
# Epoch: 16 	Training Accuracy: 95.32%
# Validation Accuracy: 91.12%
# Batch: 0, Loss: 0.12916798889636993
#
# Average loss: 0.1431, Accuracy: 758.0/790 (96%)
#
#
# Average loss: 0.3193, Accuracy: 2667.0/2940 (91%)
#
# Epoch: 17 	Training Accuracy: 95.95%
# Validation Accuracy: 90.71%
# Batch: 0, Loss: 0.11034832149744034
#
# Average loss: 0.1333, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.3155, Accuracy: 2678.0/2940 (91%)
#
# Epoch: 18 	Training Accuracy: 96.33%
# Validation Accuracy: 91.09%
# Batch: 0, Loss: 0.16820688545703888
#
# Average loss: 0.1219, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.3107, Accuracy: 2693.0/2940 (92%)
#
# Epoch: 19 	Training Accuracy: 96.33%
# Validation Accuracy: 91.60%
#
# Average loss: 0.1219, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.2997, Accuracy: 4429.0/4861 (91%)
#
# Final Training Accuracy (New Data): 0.9633
# Final Test Accuracy (New Data): 0.9111
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 59 =========================
# Batch: 0, Loss: 1.6075531244277954
#
# Average loss: 1.6091, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6087, Accuracy: 655.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6130467653274536
#
# Average loss: 1.6022, Accuracy: 189.0/790 (24%)
#
#
# Average loss: 1.6026, Accuracy: 735.0/2940 (25%)
#
# Epoch: 1 	Training Accuracy: 23.92%
# Validation Accuracy: 25.00%
# Batch: 0, Loss: 1.6006131172180176
#
# Average loss: 1.5803, Accuracy: 333.0/790 (42%)
#
#
# Average loss: 1.5817, Accuracy: 1251.0/2940 (43%)
#
# Epoch: 2 	Training Accuracy: 42.15%
# Validation Accuracy: 42.55%
# Batch: 0, Loss: 1.574660062789917
#
# Average loss: 1.5219, Accuracy: 417.0/790 (53%)
#
#
# Average loss: 1.5265, Accuracy: 1571.0/2940 (53%)
#
# Epoch: 3 	Training Accuracy: 52.78%
# Validation Accuracy: 53.44%
# Batch: 0, Loss: 1.5141732692718506
#
# Average loss: 1.4004, Accuracy: 462.0/790 (58%)
#
#
# Average loss: 1.4107, Accuracy: 1695.0/2940 (58%)
#
# Epoch: 4 	Training Accuracy: 58.48%
# Validation Accuracy: 57.65%
# Batch: 0, Loss: 1.3539921045303345
#
# Average loss: 1.2355, Accuracy: 470.0/790 (59%)
#
#
# Average loss: 1.2478, Accuracy: 1749.0/2940 (59%)
#
# Epoch: 5 	Training Accuracy: 59.49%
# Validation Accuracy: 59.49%
# Batch: 0, Loss: 1.1592049598693848
#
# Average loss: 1.0836, Accuracy: 495.0/790 (63%)
#
#
# Average loss: 1.0907, Accuracy: 1815.0/2940 (62%)
#
# Epoch: 6 	Training Accuracy: 62.66%
# Validation Accuracy: 61.73%
# Batch: 0, Loss: 1.0449742078781128
#
# Average loss: 0.9241, Accuracy: 514.0/790 (65%)
#
#
# Average loss: 0.9328, Accuracy: 1921.0/2940 (65%)
#
# Epoch: 7 	Training Accuracy: 65.06%
# Validation Accuracy: 65.34%
# Batch: 0, Loss: 0.8558031320571899
#
# Average loss: 0.7616, Accuracy: 569.0/790 (72%)
#
#
# Average loss: 0.7948, Accuracy: 2096.0/2940 (71%)
#
# Epoch: 8 	Training Accuracy: 72.03%
# Validation Accuracy: 71.29%
# Batch: 0, Loss: 0.7577766180038452
#
# Average loss: 0.6297, Accuracy: 616.0/790 (78%)
#
#
# Average loss: 0.6900, Accuracy: 2209.0/2940 (75%)
#
# Epoch: 9 	Training Accuracy: 77.97%
# Validation Accuracy: 75.14%
# Batch: 0, Loss: 0.5815147757530212
#
# Average loss: 0.4977, Accuracy: 647.0/790 (82%)
#
#
# Average loss: 0.5707, Accuracy: 2329.0/2940 (79%)
#
# Epoch: 10 	Training Accuracy: 81.90%
# Validation Accuracy: 79.22%
# Batch: 0, Loss: 0.4998100697994232
#
# Average loss: 0.4006, Accuracy: 671.0/790 (85%)
#
#
# Average loss: 0.5002, Accuracy: 2412.0/2940 (82%)
#
# Epoch: 11 	Training Accuracy: 84.94%
# Validation Accuracy: 82.04%
# Batch: 0, Loss: 0.4279767870903015
#
# Average loss: 0.3373, Accuracy: 689.0/790 (87%)
#
#
# Average loss: 0.4562, Accuracy: 2465.0/2940 (84%)
#
# Epoch: 12 	Training Accuracy: 87.22%
# Validation Accuracy: 83.84%
# Batch: 0, Loss: 0.43310514092445374
#
# Average loss: 0.2947, Accuracy: 705.0/790 (89%)
#
#
# Average loss: 0.4368, Accuracy: 2485.0/2940 (85%)
#
# Epoch: 13 	Training Accuracy: 89.24%
# Validation Accuracy: 84.52%
# Batch: 0, Loss: 0.2644592225551605
#
# Average loss: 0.2580, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.4054, Accuracy: 2553.0/2940 (87%)
#
# Epoch: 14 	Training Accuracy: 90.76%
# Validation Accuracy: 86.84%
# Batch: 0, Loss: 0.26005151867866516
#
# Average loss: 0.2319, Accuracy: 729.0/790 (92%)
#
#
# Average loss: 0.3940, Accuracy: 2565.0/2940 (87%)
#
# Epoch: 15 	Training Accuracy: 92.28%
# Validation Accuracy: 87.24%
# Batch: 0, Loss: 0.16893070936203003
#
# Average loss: 0.2105, Accuracy: 731.0/790 (93%)
#
#
# Average loss: 0.3864, Accuracy: 2561.0/2940 (87%)
#
# Epoch: 16 	Training Accuracy: 92.53%
# Validation Accuracy: 87.11%
# Batch: 0, Loss: 0.20301644504070282
#
# Average loss: 0.1973, Accuracy: 737.0/790 (93%)
#
#
# Average loss: 0.3777, Accuracy: 2582.0/2940 (88%)
#
# Epoch: 17 	Training Accuracy: 93.29%
# Validation Accuracy: 87.82%
# Batch: 0, Loss: 0.1344555765390396
#
# Average loss: 0.1812, Accuracy: 746.0/790 (94%)
#
#
# Average loss: 0.3748, Accuracy: 2588.0/2940 (88%)
#
# Epoch: 18 	Training Accuracy: 94.43%
# Validation Accuracy: 88.03%
# Batch: 0, Loss: 0.15266002714633942
#
# Average loss: 0.1643, Accuracy: 746.0/790 (94%)
#
#
# Average loss: 0.3639, Accuracy: 2606.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 94.43%
# Validation Accuracy: 88.64%
#
# Average loss: 0.1643, Accuracy: 746.0/790 (94%)
#
#
# Average loss: 0.3364, Accuracy: 4348.0/4861 (89%)
#
# Final Training Accuracy (New Data): 0.9443
# Final Test Accuracy (New Data): 0.8945
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 79 =========================
# Batch: 0, Loss: 1.613580584526062
#
# Average loss: 1.5868, Accuracy: 400.0/790 (51%)
#
#
# Average loss: 1.5862, Accuracy: 1532.0/2940 (52%)
#
# Epoch: 0 	Training Accuracy: 50.63%
# Validation Accuracy: 52.11%
# Batch: 0, Loss: 1.592681646347046
#
# Average loss: 1.4622, Accuracy: 451.0/790 (57%)
#
#
# Average loss: 1.4633, Accuracy: 1660.0/2940 (56%)
#
# Epoch: 1 	Training Accuracy: 57.09%
# Validation Accuracy: 56.46%
# Batch: 0, Loss: 1.4554013013839722
#
# Average loss: 1.1500, Accuracy: 559.0/790 (71%)
#
#
# Average loss: 1.1500, Accuracy: 2093.0/2940 (71%)
#
# Epoch: 2 	Training Accuracy: 70.76%
# Validation Accuracy: 71.19%
# Batch: 0, Loss: 1.1696128845214844
#
# Average loss: 0.7197, Accuracy: 677.0/790 (86%)
#
#
# Average loss: 0.7173, Accuracy: 2523.0/2940 (86%)
#
# Epoch: 3 	Training Accuracy: 85.70%
# Validation Accuracy: 85.82%
# Batch: 0, Loss: 0.729709804058075
#
# Average loss: 0.4426, Accuracy: 690.0/790 (87%)
#
#
# Average loss: 0.4728, Accuracy: 2491.0/2940 (85%)
#
# Epoch: 4 	Training Accuracy: 87.34%
# Validation Accuracy: 84.73%
# Batch: 0, Loss: 0.4725160002708435
#
# Average loss: 0.2825, Accuracy: 726.0/790 (92%)
#
#
# Average loss: 0.3314, Accuracy: 2647.0/2940 (90%)
#
# Epoch: 5 	Training Accuracy: 91.90%
# Validation Accuracy: 90.03%
# Batch: 0, Loss: 0.3099249005317688
#
# Average loss: 0.2464, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.3069, Accuracy: 2654.0/2940 (90%)
#
# Epoch: 6 	Training Accuracy: 91.39%
# Validation Accuracy: 90.27%
# Batch: 0, Loss: 0.2605299651622772
#
# Average loss: 0.2050, Accuracy: 733.0/790 (93%)
#
#
# Average loss: 0.2808, Accuracy: 2694.0/2940 (92%)
#
# Epoch: 7 	Training Accuracy: 92.78%
# Validation Accuracy: 91.63%
# Batch: 0, Loss: 0.16277773678302765
#
# Average loss: 0.1832, Accuracy: 737.0/790 (93%)
#
#
# Average loss: 0.2631, Accuracy: 2696.0/2940 (92%)
#
# Epoch: 8 	Training Accuracy: 93.29%
# Validation Accuracy: 91.70%
# Batch: 0, Loss: 0.1940557360649109
#
# Average loss: 0.1807, Accuracy: 737.0/790 (93%)
#
#
# Average loss: 0.2798, Accuracy: 2683.0/2940 (91%)
#
# Epoch: 9 	Training Accuracy: 93.29%
# Validation Accuracy: 91.26%
# Batch: 0, Loss: 0.22392188012599945
#
# Average loss: 0.1728, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.2629, Accuracy: 2696.0/2940 (92%)
#
# Epoch: 10 	Training Accuracy: 93.42%
# Validation Accuracy: 91.70%
# Batch: 0, Loss: 0.21621516346931458
#
# Average loss: 0.1726, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.2794, Accuracy: 2669.0/2940 (91%)
#
# Epoch: 11 	Training Accuracy: 93.42%
# Validation Accuracy: 90.78%
# Batch: 0, Loss: 0.20191892981529236
#
# Average loss: 0.1397, Accuracy: 755.0/790 (96%)
#
#
# Average loss: 0.2361, Accuracy: 2731.0/2940 (93%)
#
# Epoch: 12 	Training Accuracy: 95.57%
# Validation Accuracy: 92.89%
# Batch: 0, Loss: 0.09813699126243591
#
# Average loss: 0.1602, Accuracy: 742.0/790 (94%)
#
#
# Average loss: 0.2605, Accuracy: 2700.0/2940 (92%)
#
# Epoch: 13 	Training Accuracy: 93.92%
# Validation Accuracy: 91.84%
# Batch: 0, Loss: 0.1905217468738556
#
# Average loss: 0.1370, Accuracy: 756.0/790 (96%)
#
#
# Average loss: 0.2342, Accuracy: 2732.0/2940 (93%)
#
# Epoch: 14 	Training Accuracy: 95.70%
# Validation Accuracy: 92.93%
# Batch: 0, Loss: 0.12738169729709625
#
# Average loss: 0.1377, Accuracy: 746.0/790 (94%)
#
#
# Average loss: 0.2410, Accuracy: 2712.0/2940 (92%)
#
# Epoch: 15 	Training Accuracy: 94.43%
# Validation Accuracy: 92.24%
# Batch: 0, Loss: 0.12826311588287354
#
# Average loss: 0.1277, Accuracy: 757.0/790 (96%)
#
#
# Average loss: 0.2265, Accuracy: 2742.0/2940 (93%)
#
# Epoch: 16 	Training Accuracy: 95.82%
# Validation Accuracy: 93.27%
# Batch: 0, Loss: 0.13270588219165802
#
# Average loss: 0.1138, Accuracy: 756.0/790 (96%)
#
#
# Average loss: 0.2173, Accuracy: 2748.0/2940 (93%)
#
# Epoch: 17 	Training Accuracy: 95.70%
# Validation Accuracy: 93.47%
# Batch: 0, Loss: 0.08842205256223679
#
# Average loss: 0.1100, Accuracy: 764.0/790 (97%)
#
#
# Average loss: 0.2176, Accuracy: 2738.0/2940 (93%)
#
# Epoch: 18 	Training Accuracy: 96.71%
# Validation Accuracy: 93.13%
# Batch: 0, Loss: 0.121616892516613
#
# Average loss: 0.1064, Accuracy: 754.0/790 (95%)
#
#
# Average loss: 0.2110, Accuracy: 2758.0/2940 (94%)
#
# Epoch: 19 	Training Accuracy: 95.44%
# Validation Accuracy: 93.81%
#
# Average loss: 0.1064, Accuracy: 754.0/790 (95%)
#
#
# Average loss: 0.1889, Accuracy: 4570.0/4861 (94%)
#
# Final Training Accuracy (New Data): 0.9544
# Final Test Accuracy (New Data): 0.9401
# Training for data percentage: 0.05:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 92 =========================
# Batch: 0, Loss: 1.6009979248046875
#
# Average loss: 1.6077, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6072, Accuracy: 656.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 22.31%
# Batch: 0, Loss: 1.6076853275299072
#
# Average loss: 1.5855, Accuracy: 592.0/1320 (45%)
#
#
# Average loss: 1.5855, Accuracy: 1359.0/2940 (46%)
#
# Epoch: 1 	Training Accuracy: 44.85%
# Validation Accuracy: 46.22%
# Batch: 0, Loss: 1.5826796293258667
#
# Average loss: 1.4765, Accuracy: 716.0/1320 (54%)
#
#
# Average loss: 1.4797, Accuracy: 1579.0/2940 (54%)
#
# Epoch: 2 	Training Accuracy: 54.24%
# Validation Accuracy: 53.71%
# Batch: 0, Loss: 1.4571502208709717
#
# Average loss: 1.2388, Accuracy: 751.0/1320 (57%)
#
#
# Average loss: 1.2544, Accuracy: 1678.0/2940 (57%)
#
# Epoch: 3 	Training Accuracy: 56.89%
# Validation Accuracy: 57.07%
# Batch: 0, Loss: 1.233805537223816
#
# Average loss: 1.0039, Accuracy: 842.0/1320 (64%)
#
#
# Average loss: 1.0170, Accuracy: 1860.0/2940 (63%)
#
# Epoch: 4 	Training Accuracy: 63.79%
# Validation Accuracy: 63.27%
# Batch: 0, Loss: 0.9938839077949524
#
# Average loss: 0.7381, Accuracy: 971.0/1320 (74%)
#
#
# Average loss: 0.7690, Accuracy: 2107.0/2940 (72%)
#
# Epoch: 5 	Training Accuracy: 73.56%
# Validation Accuracy: 71.67%
# Batch: 0, Loss: 0.7966817021369934
#
# Average loss: 0.5154, Accuracy: 1086.0/1320 (82%)
#
#
# Average loss: 0.5912, Accuracy: 2332.0/2940 (79%)
#
# Epoch: 6 	Training Accuracy: 82.27%
# Validation Accuracy: 79.32%
# Batch: 0, Loss: 0.51492840051651
#
# Average loss: 0.3744, Accuracy: 1155.0/1320 (88%)
#
#
# Average loss: 0.4856, Accuracy: 2453.0/2940 (83%)
#
# Epoch: 7 	Training Accuracy: 87.50%
# Validation Accuracy: 83.44%
# Batch: 0, Loss: 0.30850252509117126
#
# Average loss: 0.2981, Accuracy: 1194.0/1320 (90%)
#
#
# Average loss: 0.4254, Accuracy: 2533.0/2940 (86%)
#
# Epoch: 8 	Training Accuracy: 90.45%
# Validation Accuracy: 86.16%
# Batch: 0, Loss: 0.36024630069732666
#
# Average loss: 0.2585, Accuracy: 1213.0/1320 (92%)
#
#
# Average loss: 0.3901, Accuracy: 2574.0/2940 (88%)
#
# Epoch: 9 	Training Accuracy: 91.89%
# Validation Accuracy: 87.55%
# Batch: 0, Loss: 0.2528584599494934
#
# Average loss: 0.2294, Accuracy: 1223.0/1320 (93%)
#
#
# Average loss: 0.3719, Accuracy: 2598.0/2940 (88%)
#
# Epoch: 10 	Training Accuracy: 92.65%
# Validation Accuracy: 88.37%
# Batch: 0, Loss: 0.28848105669021606
#
# Average loss: 0.2098, Accuracy: 1232.0/1320 (93%)
#
#
# Average loss: 0.3578, Accuracy: 2615.0/2940 (89%)
#
# Epoch: 11 	Training Accuracy: 93.33%
# Validation Accuracy: 88.95%
# Batch: 0, Loss: 0.18848475813865662
#
# Average loss: 0.1984, Accuracy: 1232.0/1320 (93%)
#
#
# Average loss: 0.3534, Accuracy: 2632.0/2940 (90%)
#
# Epoch: 12 	Training Accuracy: 93.33%
# Validation Accuracy: 89.52%
# Batch: 0, Loss: 0.2791028916835785
#
# Average loss: 0.1760, Accuracy: 1239.0/1320 (94%)
#
#
# Average loss: 0.3336, Accuracy: 2633.0/2940 (90%)
#
# Epoch: 13 	Training Accuracy: 93.86%
# Validation Accuracy: 89.56%
# Batch: 0, Loss: 0.21152129769325256
#
# Average loss: 0.1619, Accuracy: 1248.0/1320 (95%)
#
#
# Average loss: 0.3317, Accuracy: 2653.0/2940 (90%)
#
# Epoch: 14 	Training Accuracy: 94.55%
# Validation Accuracy: 90.24%
# Batch: 0, Loss: 0.11491217464208603
#
# Average loss: 0.1508, Accuracy: 1252.0/1320 (95%)
#
#
# Average loss: 0.3270, Accuracy: 2654.0/2940 (90%)
#
# Epoch: 15 	Training Accuracy: 94.85%
# Validation Accuracy: 90.27%
# Batch: 0, Loss: 0.10138603299856186
#
# Average loss: 0.1520, Accuracy: 1253.0/1320 (95%)
#
#
# Average loss: 0.3369, Accuracy: 2639.0/2940 (90%)
#
# Epoch: 16 	Training Accuracy: 94.92%
# Validation Accuracy: 89.76%
# Batch: 0, Loss: 0.1858859807252884
#
# Average loss: 0.1294, Accuracy: 1258.0/1320 (95%)
#
#
# Average loss: 0.3193, Accuracy: 2663.0/2940 (91%)
#
# Epoch: 17 	Training Accuracy: 95.30%
# Validation Accuracy: 90.58%
# Batch: 0, Loss: 0.10995841771364212
#
# Average loss: 0.1200, Accuracy: 1265.0/1320 (96%)
#
#
# Average loss: 0.3172, Accuracy: 2670.0/2940 (91%)
#
# Epoch: 18 	Training Accuracy: 95.83%
# Validation Accuracy: 90.82%
# Batch: 0, Loss: 0.11441294848918915
#
# Average loss: 0.1172, Accuracy: 1264.0/1320 (96%)
#
#
# Average loss: 0.3299, Accuracy: 2664.0/2940 (91%)
#
# Epoch: 19 	Training Accuracy: 95.76%
# Validation Accuracy: 90.61%
#
# Average loss: 0.1172, Accuracy: 1264.0/1320 (96%)
#
#
# Average loss: 0.3104, Accuracy: 4427.0/4861 (91%)
#
# Final Training Accuracy (New Data): 0.9576
# Final Test Accuracy (New Data): 0.9107
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
# ...
# Batch: 200, Loss: 0.11189893633127213
#
# Average loss: 0.0938, Accuracy: 25231.0/26038 (97%)
#
#
# Average loss: 0.1341, Accuracy: 2813.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 96.90%
# Validation Accuracy: 95.68%
# Batch: 0, Loss: 0.11209437251091003
# Batch: 20, Loss: 0.1536768078804016
# Batch: 40, Loss: 0.1434832066297531
# Batch: 60, Loss: 0.09840516000986099
# Batch: 80, Loss: 0.04043039306998253
# Batch: 100, Loss: 0.09601537883281708
# Batch: 120, Loss: 0.08947651088237762
# Batch: 140, Loss: 0.1658628284931183
# Batch: 160, Loss: 0.0849258229136467
# Batch: 180, Loss: 0.08592944592237473
# Batch: 200, Loss: 0.13087987899780273
#
# Average loss: 0.0933, Accuracy: 25224.0/26038 (97%)
#
#
# Average loss: 0.1292, Accuracy: 2809.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 96.87%
# Validation Accuracy: 95.54%
# Batch: 0, Loss: 0.03891068696975708
# Batch: 20, Loss: 0.12691207230091095
# Batch: 40, Loss: 0.1269402652978897
# Batch: 60, Loss: 0.051693063229322433
# Batch: 80, Loss: 0.06121810898184776
# Batch: 100, Loss: 0.07502464950084686
# Batch: 120, Loss: 0.12993912398815155
# Batch: 140, Loss: 0.17201438546180725
# Batch: 160, Loss: 0.0400206558406353
# Batch: 180, Loss: 0.16274550557136536
# Batch: 200, Loss: 0.06591836363077164
#
# Average loss: 0.0941, Accuracy: 25252.0/26038 (97%)
#
#
# Average loss: 0.1385, Accuracy: 2816.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 96.98%
# Validation Accuracy: 95.78%
# Early stopping invoked.
#
# Average loss: 0.0993, Accuracy: 25206.0/26038 (97%)
#
#
# Average loss: 0.1325, Accuracy: 4656.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9680
# Final Test Accuracy (New Data): 0.9578
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 36 =========================
# Batch: 0, Loss: 1.6053155660629272
# Batch: 20, Loss: 0.8000212907791138
# Batch: 40, Loss: 0.3331699073314667
# Batch: 60, Loss: 0.23371116816997528
# Batch: 80, Loss: 0.20483990013599396
# Batch: 100, Loss: 0.22991633415222168
# Batch: 120, Loss: 0.2590424716472626
# Batch: 140, Loss: 0.24494875967502594
# Batch: 160, Loss: 0.3655410706996918
# Batch: 180, Loss: 0.19759966433048248
# Batch: 200, Loss: 0.23417073488235474
#
# Average loss: 0.2071, Accuracy: 24271.0/26038 (93%)
#
#
# Average loss: 0.2210, Accuracy: 2719.0/2940 (92%)
#
# Epoch: 0 	Training Accuracy: 93.21%
# Validation Accuracy: 92.48%
# Batch: 0, Loss: 0.13140152394771576
# Batch: 20, Loss: 0.2627784013748169
# Batch: 40, Loss: 0.10826154798269272
# Batch: 60, Loss: 0.12407952547073364
# Batch: 80, Loss: 0.24009914696216583
# Batch: 100, Loss: 0.18611393868923187
# Batch: 120, Loss: 0.2125205546617508
# Batch: 140, Loss: 0.18049901723861694
# Batch: 160, Loss: 0.19456812739372253
# Batch: 180, Loss: 0.10673718899488449
# Batch: 200, Loss: 0.08654657006263733
#
# Average loss: 0.1772, Accuracy: 24528.0/26038 (94%)
#
#
# Average loss: 0.1962, Accuracy: 2752.0/2940 (94%)
#
# Epoch: 1 	Training Accuracy: 94.20%
# Validation Accuracy: 93.61%
# Batch: 0, Loss: 0.13490818440914154
# Batch: 20, Loss: 0.09703459590673447
# Batch: 40, Loss: 0.3582347333431244
# Batch: 60, Loss: 0.19364377856254578
# Batch: 80, Loss: 0.14166299998760223
# Batch: 100, Loss: 0.0990336686372757
# Batch: 120, Loss: 0.17038999497890472
# Batch: 140, Loss: 0.2625328004360199
# Batch: 160, Loss: 0.13824431598186493
# Batch: 180, Loss: 0.13042022287845612
# Batch: 200, Loss: 0.12140918523073196
#
# Average loss: 0.1436, Accuracy: 24848.0/26038 (95%)
#
#
# Average loss: 0.1672, Accuracy: 2777.0/2940 (94%)
#
# Epoch: 2 	Training Accuracy: 95.43%
# Validation Accuracy: 94.46%
# Batch: 0, Loss: 0.22727544605731964
# Batch: 20, Loss: 0.13338400423526764
# Batch: 40, Loss: 0.07623975723981857
# Batch: 60, Loss: 0.08020401000976562
# Batch: 80, Loss: 0.15546931326389313
# Batch: 100, Loss: 0.17361992597579956
# Batch: 120, Loss: 0.09888904541730881
# Batch: 140, Loss: 0.12542302906513214
# Batch: 160, Loss: 0.05657880753278732
# Batch: 180, Loss: 0.16575118899345398
# Batch: 200, Loss: 0.19870321452617645
#
# Average loss: 0.1337, Accuracy: 24919.0/26038 (96%)
#
#
# Average loss: 0.1575, Accuracy: 2805.0/2940 (95%)
#
# Epoch: 3 	Training Accuracy: 95.70%
# Validation Accuracy: 95.41%
# Batch: 0, Loss: 0.13003574311733246
# Batch: 20, Loss: 0.1513829231262207
# Batch: 40, Loss: 0.13197460770606995
# Batch: 60, Loss: 0.1139644905924797
# Batch: 80, Loss: 0.18286539614200592
# Batch: 100, Loss: 0.1508958488702774
# Batch: 120, Loss: 0.1946871131658554
# Batch: 140, Loss: 0.11394482851028442
# Batch: 160, Loss: 0.14200377464294434
# Batch: 180, Loss: 0.10853420943021774
# Batch: 200, Loss: 0.130148783326149
#
# Average loss: 0.1231, Accuracy: 25023.0/26038 (96%)
#
#
# Average loss: 0.1467, Accuracy: 2812.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 96.10%
# Validation Accuracy: 95.65%
# Batch: 0, Loss: 0.08565475791692734
# Batch: 20, Loss: 0.25034478306770325
# Batch: 40, Loss: 0.26234427094459534
# Batch: 60, Loss: 0.1938643753528595
# Batch: 80, Loss: 0.12201464921236038
# Batch: 100, Loss: 0.15441633760929108
# Batch: 120, Loss: 0.0727829784154892
# Batch: 140, Loss: 0.15961799025535583
# Batch: 160, Loss: 0.21412669122219086
# Batch: 180, Loss: 0.12607735395431519
# Batch: 200, Loss: 0.11051120609045029
#
# Average loss: 0.1174, Accuracy: 25050.0/26038 (96%)
#
#
# Average loss: 0.1436, Accuracy: 2815.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 96.21%
# Validation Accuracy: 95.75%
# Batch: 0, Loss: 0.06499803066253662
# Batch: 20, Loss: 0.06987427920103073
# Batch: 40, Loss: 0.15321142971515656
# Batch: 60, Loss: 0.1498962938785553
# Batch: 80, Loss: 0.12708628177642822
# Batch: 100, Loss: 0.11225080490112305
# Batch: 120, Loss: 0.09742657840251923
# Batch: 140, Loss: 0.1325417309999466
# Batch: 160, Loss: 0.0887572318315506
# Batch: 180, Loss: 0.20411884784698486
# Batch: 200, Loss: 0.09248168021440506
#
# Average loss: 0.1130, Accuracy: 25106.0/26038 (96%)
#
#
# Average loss: 0.1428, Accuracy: 2814.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 96.42%
# Validation Accuracy: 95.71%
# Batch: 0, Loss: 0.11858509480953217
# Batch: 20, Loss: 0.08162683993577957
# Batch: 40, Loss: 0.13736847043037415
# Batch: 60, Loss: 0.13456237316131592
# Batch: 80, Loss: 0.06661924719810486
# Batch: 100, Loss: 0.17223380506038666
# Batch: 120, Loss: 0.06561679393053055
# Batch: 140, Loss: 0.08381187915802002
# Batch: 160, Loss: 0.1696983277797699
# Batch: 180, Loss: 0.08327342569828033
# Batch: 200, Loss: 0.09523551166057587
#
# Average loss: 0.1056, Accuracy: 25151.0/26038 (97%)
#
#
# Average loss: 0.1365, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 96.59%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.0454171821475029
# Batch: 20, Loss: 0.16529475152492523
# Batch: 40, Loss: 0.1098606288433075
# Batch: 60, Loss: 0.17237716913223267
# Batch: 80, Loss: 0.1431892216205597
# Batch: 100, Loss: 0.07650791108608246
# Batch: 120, Loss: 0.12044597417116165
# Batch: 140, Loss: 0.1804620921611786
# Batch: 160, Loss: 0.11169499903917313
# Batch: 180, Loss: 0.15751129388809204
# Batch: 200, Loss: 0.0739932581782341
#
# Average loss: 0.0997, Accuracy: 25206.0/26038 (97%)
#
#
# Average loss: 0.1306, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 96.80%
# Validation Accuracy: 96.22%
# Batch: 0, Loss: 0.07152078300714493
# Batch: 20, Loss: 0.08489827066659927
# Batch: 40, Loss: 0.1334076076745987
# Batch: 60, Loss: 0.13978104293346405
# Batch: 80, Loss: 0.1664084643125534
# Batch: 100, Loss: 0.045386750251054764
# Batch: 120, Loss: 0.1473713219165802
# Batch: 140, Loss: 0.14100848138332367
# Batch: 160, Loss: 0.04959605634212494
# Batch: 180, Loss: 0.08414572477340698
# Batch: 200, Loss: 0.16568928956985474
#
# Average loss: 0.1003, Accuracy: 25194.0/26038 (97%)
#
#
# Average loss: 0.1312, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 96.76%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.10929328203201294
# Batch: 20, Loss: 0.053771376609802246
# Batch: 40, Loss: 0.04925907403230667
# Batch: 60, Loss: 0.048292480409145355
# Batch: 80, Loss: 0.0651833713054657
# Batch: 100, Loss: 0.13343361020088196
# Batch: 120, Loss: 0.11799230426549911
# Batch: 140, Loss: 0.14263221621513367
# Batch: 160, Loss: 0.1255469173192978
# Batch: 180, Loss: 0.11958910524845123
# Batch: 200, Loss: 0.0873175859451294
#
# Average loss: 0.0908, Accuracy: 25296.0/26038 (97%)
#
#
# Average loss: 0.1238, Accuracy: 2840.0/2940 (97%)
#
# Epoch: 10 	Training Accuracy: 97.15%
# Validation Accuracy: 96.60%
# Batch: 0, Loss: 0.08733066916465759
# Batch: 20, Loss: 0.025530699640512466
# Batch: 40, Loss: 0.06974749267101288
# Batch: 60, Loss: 0.08340077102184296
# Batch: 80, Loss: 0.06213271617889404
# Batch: 100, Loss: 0.12354683876037598
# Batch: 120, Loss: 0.06373144686222076
# Batch: 140, Loss: 0.10733094066381454
# Batch: 160, Loss: 0.10844036191701889
# Batch: 180, Loss: 0.09985364973545074
# Batch: 200, Loss: 0.08013971149921417
#
# Average loss: 0.0906, Accuracy: 25296.0/26038 (97%)
#
#
# Average loss: 0.1232, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 11 	Training Accuracy: 97.15%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.09651875495910645
# Batch: 20, Loss: 0.12258048355579376
# Batch: 40, Loss: 0.115835040807724
# Batch: 60, Loss: 0.13989973068237305
# Batch: 80, Loss: 0.11107494682073593
# Batch: 100, Loss: 0.05496446415781975
# Batch: 120, Loss: 0.11782722920179367
# Batch: 140, Loss: 0.09811822324991226
# Batch: 160, Loss: 0.08774730563163757
# Batch: 180, Loss: 0.07643257081508636
# Batch: 200, Loss: 0.08751353621482849
#
# Average loss: 0.0953, Accuracy: 25263.0/26038 (97%)
#
#
# Average loss: 0.1287, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 97.02%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.07455158978700638
# Batch: 20, Loss: 0.14902696013450623
# Batch: 40, Loss: 0.04107688367366791
# Batch: 60, Loss: 0.073396235704422
# Batch: 80, Loss: 0.05835779756307602
# Batch: 100, Loss: 0.17853981256484985
# Batch: 120, Loss: 0.04284002631902695
# Batch: 140, Loss: 0.05508158355951309
# Batch: 160, Loss: 0.0932040810585022
# Batch: 180, Loss: 0.07191135734319687
# Batch: 200, Loss: 0.19129829108715057
#
# Average loss: 0.0874, Accuracy: 25308.0/26038 (97%)
#
#
# Average loss: 0.1199, Accuracy: 2841.0/2940 (97%)
#
# Epoch: 13 	Training Accuracy: 97.20%
# Validation Accuracy: 96.63%
# Batch: 0, Loss: 0.2928844094276428
# Batch: 20, Loss: 0.14002220332622528
# Batch: 40, Loss: 0.12586072087287903
# Batch: 60, Loss: 0.10193043947219849
# Batch: 80, Loss: 0.0418565571308136
# Batch: 100, Loss: 0.13054518401622772
# Batch: 120, Loss: 0.07833582162857056
# Batch: 140, Loss: 0.10566031187772751
# Batch: 160, Loss: 0.09152303636074066
# Batch: 180, Loss: 0.07556910812854767
# Batch: 200, Loss: 0.07043945044279099
#
# Average loss: 0.0895, Accuracy: 25320.0/26038 (97%)
#
#
# Average loss: 0.1255, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 97.24%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.1222669929265976
# Batch: 20, Loss: 0.11683206260204315
# Batch: 40, Loss: 0.07299243658781052
# Batch: 60, Loss: 0.07989206165075302
# Batch: 80, Loss: 0.17021231353282928
# Batch: 100, Loss: 0.091215118765831
# Batch: 120, Loss: 0.13269135355949402
# Batch: 140, Loss: 0.054987844079732895
# Batch: 160, Loss: 0.02978648990392685
# Batch: 180, Loss: 0.06380287557840347
# Batch: 200, Loss: 0.12391151487827301
#
# Average loss: 0.0938, Accuracy: 25196.0/26038 (97%)
#
#
# Average loss: 0.1319, Accuracy: 2815.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 96.77%
# Validation Accuracy: 95.75%
# Batch: 0, Loss: 0.06386673450469971
# Batch: 20, Loss: 0.10208816081285477
# Batch: 40, Loss: 0.09708304703235626
# Batch: 60, Loss: 0.061538152396678925
# Batch: 80, Loss: 0.06027689203619957
# Batch: 100, Loss: 0.08314768224954605
# Batch: 120, Loss: 0.11451756209135056
# Batch: 140, Loss: 0.0936044454574585
# Batch: 160, Loss: 0.06532831490039825
# Batch: 180, Loss: 0.06612245738506317
# Batch: 200, Loss: 0.05672410503029823
#
# Average loss: 0.0850, Accuracy: 25349.0/26038 (97%)
#
#
# Average loss: 0.1165, Accuracy: 2840.0/2940 (97%)
#
# Epoch: 16 	Training Accuracy: 97.35%
# Validation Accuracy: 96.60%
# Batch: 0, Loss: 0.15749575197696686
# Batch: 20, Loss: 0.08577252179384232
# Batch: 40, Loss: 0.13676804304122925
# Batch: 60, Loss: 0.044261686503887177
# Batch: 80, Loss: 0.09606188535690308
# Batch: 100, Loss: 0.03816895931959152
# Batch: 120, Loss: 0.040966276079416275
# Batch: 140, Loss: 0.04423011466860771
# Batch: 160, Loss: 0.1325511634349823
# Batch: 180, Loss: 0.05848165601491928
# Batch: 200, Loss: 0.18379755318164825
#
# Average loss: 0.0756, Accuracy: 25446.0/26038 (98%)
#
#
# Average loss: 0.1083, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 17 	Training Accuracy: 97.73%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.04191628471016884
# Batch: 20, Loss: 0.04810250177979469
# Batch: 40, Loss: 0.08739814162254333
# Batch: 60, Loss: 0.1776440590620041
# Batch: 80, Loss: 0.12338781356811523
# Batch: 100, Loss: 0.11430872976779938
# Batch: 120, Loss: 0.03810529410839081
# Batch: 140, Loss: 0.10499340295791626
# Batch: 160, Loss: 0.0728473886847496
# Batch: 180, Loss: 0.11265765130519867
# Batch: 200, Loss: 0.06347234547138214
#
# Average loss: 0.0752, Accuracy: 25426.0/26038 (98%)
#
#
# Average loss: 0.1125, Accuracy: 2844.0/2940 (97%)
#
# Epoch: 18 	Training Accuracy: 97.65%
# Validation Accuracy: 96.73%
# Batch: 0, Loss: 0.05813736096024513
# Batch: 20, Loss: 0.041501354426145554
# Batch: 40, Loss: 0.09644120186567307
# Batch: 60, Loss: 0.10283315926790237
# Batch: 80, Loss: 0.11576004326343536
# Batch: 100, Loss: 0.1142813041806221
# Batch: 120, Loss: 0.06262741982936859
# Batch: 140, Loss: 0.03723076358437538
# Batch: 160, Loss: 0.06611181050539017
# Batch: 180, Loss: 0.12118279933929443
# Batch: 200, Loss: 0.043744027614593506
#
# Average loss: 0.0721, Accuracy: 25447.0/26038 (98%)
#
#
# Average loss: 0.1097, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 19 	Training Accuracy: 97.73%
# Validation Accuracy: 96.90%
#
# Average loss: 0.0721, Accuracy: 25447.0/26038 (98%)
#
#
# Average loss: 0.0892, Accuracy: 4730.0/4861 (97%)
#
# Final Training Accuracy (New Data): 0.9773
# Final Test Accuracy (New Data): 0.9731
# Percentage: 0.01, Seed: 10, Epochs taken: 20
# Percentage: 0.01, Seed: 20, Epochs taken: 20
# Percentage: 0.01, Seed: 30, Epochs taken: 20
# Percentage: 0.01, Seed: 40, Epochs taken: 7
# Percentage: 0.01, Seed: 50, Epochs taken: 16
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 20
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 16
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 20
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 17
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 19
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 18
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 20
# Percentage: 1, Seed: 20, Epochs taken: 15
# Percentage: 1, Seed: 30, Epochs taken: 20
# Percentage: 1, Seed: 40, Epochs taken: 18
# Percentage: 1, Seed: 50, Epochs taken: 20

# %% [markdown]
# ## Only heads and data for new classes

# %% [markdown]
# now with balanced classes

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.0001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test_finetune = {}
results_train_finetune = {}
best_models = {}
data_loaders = {}
epochs_taken_finetune = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Processing percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []
    
    for seed in tqdm(seed_set, desc=f'Running seeds for {perc} data', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")

                # Copying model
        model_new = copy.deepcopy(model)

        # Calculate the output size from the pool layer dynamically
        # You would replace this with the actual size based on your model's architecture
        # model_new.fc_1 = nn.Linear(576, 128)
    
        # Reinitialize the second fully connected layer
        # model_new.fc_2 = nn.Linear(128, 5)
        
        # Ensure the softmax layer matches the number of classes (if used)
        model_new.softmax = nn.Softmax(dim=1)
        
        model_new.to(device)
        
        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)
        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test_finetune[perc] = test_accuracies
    results_train_finetune[perc] = train_accuracies
    epochs_taken_finetune[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken_finetune[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Running seeds for 0.01 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 42 =========================
# Batch: 0, Loss: 0.1538412868976593
#
# Average loss: 0.1117, Accuracy: 253.0/260 (97%)
#
#
# Average loss: 0.1278, Accuracy: 2815.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 97.31%
# Validation Accuracy: 95.75%
# Batch: 0, Loss: 0.09175896644592285
#
# Average loss: 0.1094, Accuracy: 254.0/260 (98%)
#
#
# Average loss: 0.1282, Accuracy: 2817.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 97.69%
# Validation Accuracy: 95.82%
# Batch: 0, Loss: 0.10135609656572342
#
# Average loss: 0.1071, Accuracy: 254.0/260 (98%)
#
#
# Average loss: 0.1283, Accuracy: 2816.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 97.69%
# Validation Accuracy: 95.78%
# Batch: 0, Loss: 0.04923499748110771
#
# Average loss: 0.1050, Accuracy: 254.0/260 (98%)
#
#
# Average loss: 0.1289, Accuracy: 2816.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 97.69%
# Validation Accuracy: 95.78%
# Batch: 0, Loss: 0.09029779583215714
#
# Average loss: 0.1028, Accuracy: 254.0/260 (98%)
#
#
# Average loss: 0.1290, Accuracy: 2814.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 97.69%
# Validation Accuracy: 95.71%
# Batch: 0, Loss: 0.13773222267627716
#
# Average loss: 0.1005, Accuracy: 255.0/260 (98%)
#
#
# Average loss: 0.1286, Accuracy: 2814.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 98.08%
# Validation Accuracy: 95.71%
# Batch: 0, Loss: 0.05455916002392769
#
# Average loss: 0.0983, Accuracy: 255.0/260 (98%)
#
#
# Average loss: 0.1285, Accuracy: 2814.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 98.08%
# Validation Accuracy: 95.71%
# Batch: 0, Loss: 0.13314807415008545
#
# Average loss: 0.0962, Accuracy: 255.0/260 (98%)
#
#
# Average loss: 0.1283, Accuracy: 2815.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 98.08%
# Validation Accuracy: 95.75%
# Early stopping invoked.
#
# Average loss: 0.1094, Accuracy: 254.0/260 (98%)
#
#
# Average loss: 0.1243, Accuracy: 4655.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 23 =========================
# Batch: 0, Loss: 0.16282323002815247
#
# Average loss: 0.1595, Accuracy: 247.0/260 (95%)
#
#
# Average loss: 0.1270, Accuracy: 2819.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 95.00%
# Validation Accuracy: 95.88%
# Batch: 0, Loss: 0.14601781964302063
#
# Average loss: 0.1521, Accuracy: 247.0/260 (95%)
#
#
# Average loss: 0.1261, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 95.00%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.11920104175806046
#
# Average loss: 0.1462, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1254, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 95.77%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.20293399691581726
#
# Average loss: 0.1420, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1248, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 95.77%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.12978675961494446
#
# Average loss: 0.1386, Accuracy: 250.0/260 (96%)
#
#
# Average loss: 0.1246, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 96.15%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.14658987522125244
#
# Average loss: 0.1355, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1246, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 95.77%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.11113820225000381
#
# Average loss: 0.1327, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1249, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 95.77%
# Validation Accuracy: 96.22%
# Batch: 0, Loss: 0.14989377558231354
#
# Average loss: 0.1302, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1252, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 95.77%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.1386166661977768
#
# Average loss: 0.1278, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1256, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 95.77%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.17372415959835052
#
# Average loss: 0.1255, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1259, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 95.77%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.08212536573410034
#
# Average loss: 0.1231, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1263, Accuracy: 2833.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 95.77%
# Validation Accuracy: 96.36%
# Batch: 0, Loss: 0.12102863192558289
#
# Average loss: 0.1202, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1266, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 11 	Training Accuracy: 95.77%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.10942807048559189
#
# Average loss: 0.1179, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1270, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 95.77%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.09328362345695496
#
# Average loss: 0.1157, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1273, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 95.77%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.13846373558044434
#
# Average loss: 0.1137, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1276, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 95.77%
# Validation Accuracy: 96.22%
# Batch: 0, Loss: 0.05605808645486832
#
# Average loss: 0.1117, Accuracy: 250.0/260 (96%)
#
#
# Average loss: 0.1276, Accuracy: 2828.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 96.15%
# Validation Accuracy: 96.19%
# Batch: 0, Loss: 0.14016416668891907
#
# Average loss: 0.1095, Accuracy: 250.0/260 (96%)
#
#
# Average loss: 0.1277, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 96.15%
# Validation Accuracy: 96.22%
# Early stopping invoked.
#
# Average loss: 0.1231, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1268, Accuracy: 4667.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 11 =========================
# Batch: 0, Loss: 0.12270422279834747
#
# Average loss: 0.1237, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1278, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 95.77%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.12149021774530411
#
# Average loss: 0.1211, Accuracy: 250.0/260 (96%)
#
#
# Average loss: 0.1280, Accuracy: 2819.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 96.15%
# Validation Accuracy: 95.88%
# Batch: 0, Loss: 0.1489131599664688
#
# Average loss: 0.1184, Accuracy: 250.0/260 (96%)
#
#
# Average loss: 0.1279, Accuracy: 2819.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 96.15%
# Validation Accuracy: 95.88%
# Batch: 0, Loss: 0.16263973712921143
#
# Average loss: 0.1158, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1277, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 96.54%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.1571086198091507
#
# Average loss: 0.1131, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1274, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 96.54%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.08994907885789871
#
# Average loss: 0.1106, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1271, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 96.92%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.0704871118068695
#
# Average loss: 0.1085, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1266, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 96.92%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.15962155163288116
#
# Average loss: 0.1065, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1264, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 96.92%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.15343113243579865
#
# Average loss: 0.1046, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1264, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 96.92%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.1062609851360321
#
# Average loss: 0.1028, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1264, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 96.92%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.026339061558246613
#
# Average loss: 0.1012, Accuracy: 253.0/260 (97%)
#
#
# Average loss: 0.1264, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 97.31%
# Validation Accuracy: 95.92%
# Early stopping invoked.
#
# Average loss: 0.1131, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1246, Accuracy: 4656.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 81 =========================
# Batch: 0, Loss: 0.10976951569318771
#
# Average loss: 0.1047, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1278, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 96.54%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.11769001930952072
#
# Average loss: 0.1003, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1274, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 96.54%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.12470921128988266
#
# Average loss: 0.0967, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1274, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 96.54%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.08066274970769882
#
# Average loss: 0.0938, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1276, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 96.54%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.07899253815412521
#
# Average loss: 0.0913, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1276, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 96.54%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.058575645089149475
#
# Average loss: 0.0888, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1277, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 96.54%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.05958017706871033
#
# Average loss: 0.0864, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1280, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 96.54%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.11836730688810349
#
# Average loss: 0.0841, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1283, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 96.54%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.08019562810659409
#
# Average loss: 0.0819, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1287, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 96.54%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.1281941682100296
#
# Average loss: 0.0797, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1291, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 96.92%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.07147926837205887
#
# Average loss: 0.0777, Accuracy: 252.0/260 (97%)
#
#
# Average loss: 0.1295, Accuracy: 2819.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 96.92%
# Validation Accuracy: 95.88%
# Early stopping invoked.
#
# Average loss: 0.0913, Accuracy: 251.0/260 (97%)
#
#
# Average loss: 0.1253, Accuracy: 4659.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 23 =========================
# Batch: 0, Loss: 0.16282323002815247
#
# Average loss: 0.1595, Accuracy: 247.0/260 (95%)
#
#
# Average loss: 0.1270, Accuracy: 2819.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 95.00%
# Validation Accuracy: 95.88%
# Batch: 0, Loss: 0.14601781964302063
#
# Average loss: 0.1521, Accuracy: 247.0/260 (95%)
#
#
# Average loss: 0.1261, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 95.00%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.11920104175806046
#
# Average loss: 0.1462, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1254, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 95.77%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.20293399691581726
#
# Average loss: 0.1420, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1248, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 95.77%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.12978675961494446
#
# Average loss: 0.1386, Accuracy: 250.0/260 (96%)
#
#
# Average loss: 0.1246, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 96.15%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.14658987522125244
#
# Average loss: 0.1355, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1246, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 95.77%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.11113820225000381
#
# Average loss: 0.1327, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1249, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 95.77%
# Validation Accuracy: 96.22%
# Batch: 0, Loss: 0.14989377558231354
#
# Average loss: 0.1302, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1252, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 95.77%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.1386166661977768
#
# Average loss: 0.1278, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1256, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 95.77%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.17372415959835052
#
# Average loss: 0.1255, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1259, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 95.77%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.08212536573410034
#
# Average loss: 0.1231, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1263, Accuracy: 2833.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 95.77%
# Validation Accuracy: 96.36%
# Batch: 0, Loss: 0.12102863192558289
#
# Average loss: 0.1202, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1266, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 11 	Training Accuracy: 95.77%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.10942807048559189
#
# Average loss: 0.1179, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1270, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 95.77%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.09328362345695496
#
# Average loss: 0.1157, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1273, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 95.77%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.13846373558044434
#
# Average loss: 0.1137, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1276, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 95.77%
# Validation Accuracy: 96.22%
# Batch: 0, Loss: 0.05605808645486832
#
# Average loss: 0.1117, Accuracy: 250.0/260 (96%)
#
#
# Average loss: 0.1276, Accuracy: 2828.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 96.15%
# Validation Accuracy: 96.19%
# Batch: 0, Loss: 0.14016416668891907
#
# Average loss: 0.1095, Accuracy: 250.0/260 (96%)
#
#
# Average loss: 0.1277, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 96.15%
# Validation Accuracy: 96.22%
# Early stopping invoked.
#
# Average loss: 0.1231, Accuracy: 249.0/260 (96%)
#
#
# Average loss: 0.1268, Accuracy: 4667.0/4861 (96%)
# Running seeds for 0.03 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 48 =========================
# Batch: 0, Loss: 0.05139961838722229
#
# Average loss: 0.0567, Accuracy: 776.0/790 (98%)
#
#
# Average loss: 0.1267, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 98.23%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.05495882034301758
#
# Average loss: 0.0542, Accuracy: 778.0/790 (98%)
#
#
# Average loss: 0.1267, Accuracy: 2828.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 98.48%
# Validation Accuracy: 96.19%
# Batch: 0, Loss: 0.05992681533098221
#
# Average loss: 0.0523, Accuracy: 778.0/790 (98%)
#
#
# Average loss: 0.1270, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 98.48%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.03312355652451515
#
# Average loss: 0.0506, Accuracy: 778.0/790 (98%)
#
#
# Average loss: 0.1272, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 98.48%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.061803288757801056
#
# Average loss: 0.0490, Accuracy: 779.0/790 (99%)
#
#
# Average loss: 0.1275, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 98.61%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.04167017713189125
#
# Average loss: 0.0475, Accuracy: 780.0/790 (99%)
#
#
# Average loss: 0.1278, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 98.73%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.06476812064647675
#
# Average loss: 0.0460, Accuracy: 780.0/790 (99%)
#
#
# Average loss: 0.1279, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 98.73%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.038041189312934875
#
# Average loss: 0.0447, Accuracy: 780.0/790 (99%)
#
#
# Average loss: 0.1279, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 98.73%
# Validation Accuracy: 95.95%
# Early stopping invoked.
#
# Average loss: 0.0542, Accuracy: 778.0/790 (98%)
#
#
# Average loss: 0.1236, Accuracy: 4664.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 45 =========================
# Batch: 0, Loss: 0.1659700870513916
#
# Average loss: 0.0736, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1272, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 97.72%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.03988103196024895
#
# Average loss: 0.0719, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1266, Accuracy: 2819.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 97.72%
# Validation Accuracy: 95.88%
# Batch: 0, Loss: 0.08545146882534027
#
# Average loss: 0.0703, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1265, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 97.72%
# Validation Accuracy: 95.85%
# Batch: 0, Loss: 0.057277895510196686
#
# Average loss: 0.0688, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1264, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 97.72%
# Validation Accuracy: 95.85%
# Batch: 0, Loss: 0.05392595753073692
#
# Average loss: 0.0676, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1264, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 97.72%
# Validation Accuracy: 95.85%
# Batch: 0, Loss: 0.0856708288192749
#
# Average loss: 0.0661, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1264, Accuracy: 2817.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 97.72%
# Validation Accuracy: 95.82%
# Batch: 0, Loss: 0.07860082387924194
#
# Average loss: 0.0647, Accuracy: 774.0/790 (98%)
#
#
# Average loss: 0.1264, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.97%
# Validation Accuracy: 95.85%
# Early stopping invoked.
#
# Average loss: 0.0736, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1245, Accuracy: 4661.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 1 =========================
# Batch: 0, Loss: 0.04175223410129547
#
# Average loss: 0.1067, Accuracy: 763.0/790 (97%)
#
#
# Average loss: 0.1272, Accuracy: 2816.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 96.58%
# Validation Accuracy: 95.78%
# Batch: 0, Loss: 0.12262069433927536
#
# Average loss: 0.1030, Accuracy: 763.0/790 (97%)
#
#
# Average loss: 0.1268, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 96.58%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.1538303941488266
#
# Average loss: 0.1001, Accuracy: 764.0/790 (97%)
#
#
# Average loss: 0.1268, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 96.71%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.11233232170343399
#
# Average loss: 0.0976, Accuracy: 766.0/790 (97%)
#
#
# Average loss: 0.1264, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 96.96%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.0906331017613411
#
# Average loss: 0.0953, Accuracy: 766.0/790 (97%)
#
#
# Average loss: 0.1264, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 96.96%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.10064096003770828
#
# Average loss: 0.0936, Accuracy: 766.0/790 (97%)
#
#
# Average loss: 0.1270, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 96.96%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.08196597546339035
#
# Average loss: 0.0918, Accuracy: 767.0/790 (97%)
#
#
# Average loss: 0.1264, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.09%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.07887475937604904
#
# Average loss: 0.0900, Accuracy: 770.0/790 (97%)
#
#
# Average loss: 0.1254, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 97.47%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.12711089849472046
#
# Average loss: 0.0884, Accuracy: 770.0/790 (97%)
#
#
# Average loss: 0.1254, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 97.47%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.08478657156229019
#
# Average loss: 0.0868, Accuracy: 769.0/790 (97%)
#
#
# Average loss: 0.1261, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 97.34%
# Validation Accuracy: 95.95%
# Early stopping invoked.
#
# Average loss: 0.0976, Accuracy: 766.0/790 (97%)
#
#
# Average loss: 0.1232, Accuracy: 4663.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 14 =========================
# Batch: 0, Loss: 0.0777498185634613
#
# Average loss: 0.0867, Accuracy: 771.0/790 (98%)
#
#
# Average loss: 0.1265, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 97.59%
# Validation Accuracy: 95.85%
# Batch: 0, Loss: 0.07170300930738449
#
# Average loss: 0.0815, Accuracy: 771.0/790 (98%)
#
#
# Average loss: 0.1265, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 97.59%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.05764278769493103
#
# Average loss: 0.0778, Accuracy: 775.0/790 (98%)
#
#
# Average loss: 0.1263, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 98.10%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.03231851011514664
#
# Average loss: 0.0753, Accuracy: 774.0/790 (98%)
#
#
# Average loss: 0.1269, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 97.97%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.09758269041776657
#
# Average loss: 0.0731, Accuracy: 774.0/790 (98%)
#
#
# Average loss: 0.1263, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 97.97%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.06590712815523148
#
# Average loss: 0.0712, Accuracy: 774.0/790 (98%)
#
#
# Average loss: 0.1262, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 97.97%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.11119208484888077
#
# Average loss: 0.0689, Accuracy: 777.0/790 (98%)
#
#
# Average loss: 0.1275, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 98.35%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.07362987101078033
#
# Average loss: 0.0671, Accuracy: 777.0/790 (98%)
#
#
# Average loss: 0.1276, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 98.35%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.09495134651660919
#
# Average loss: 0.0656, Accuracy: 776.0/790 (98%)
#
#
# Average loss: 0.1277, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 98.23%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.0656462237238884
#
# Average loss: 0.0643, Accuracy: 776.0/790 (98%)
#
#
# Average loss: 0.1277, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 98.23%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.07322043180465698
#
# Average loss: 0.0632, Accuracy: 776.0/790 (98%)
#
#
# Average loss: 0.1288, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 98.23%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.04027940332889557
#
# Average loss: 0.0618, Accuracy: 775.0/790 (98%)
#
#
# Average loss: 0.1287, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 11 	Training Accuracy: 98.10%
# Validation Accuracy: 95.85%
# Early stopping invoked.
#
# Average loss: 0.0712, Accuracy: 774.0/790 (98%)
#
#
# Average loss: 0.1235, Accuracy: 4661.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 39 =========================
# Batch: 0, Loss: 0.17245687544345856
#
# Average loss: 0.0983, Accuracy: 766.0/790 (97%)
#
#
# Average loss: 0.1277, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 96.96%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.1003105565905571
#
# Average loss: 0.0949, Accuracy: 767.0/790 (97%)
#
#
# Average loss: 0.1263, Accuracy: 2817.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 97.09%
# Validation Accuracy: 95.82%
# Batch: 0, Loss: 0.11717460304498672
#
# Average loss: 0.0920, Accuracy: 766.0/790 (97%)
#
#
# Average loss: 0.1258, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 96.96%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.06302943825721741
#
# Average loss: 0.0893, Accuracy: 767.0/790 (97%)
#
#
# Average loss: 0.1257, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 97.09%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.04297018051147461
#
# Average loss: 0.0870, Accuracy: 768.0/790 (97%)
#
#
# Average loss: 0.1258, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 97.22%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.09682988375425339
#
# Average loss: 0.0848, Accuracy: 770.0/790 (97%)
#
#
# Average loss: 0.1258, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 97.47%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.04811563715338707
#
# Average loss: 0.0829, Accuracy: 771.0/790 (98%)
#
#
# Average loss: 0.1259, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.59%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.11369755864143372
#
# Average loss: 0.0809, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1260, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 97.72%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.08689405024051666
#
# Average loss: 0.0792, Accuracy: 772.0/790 (98%)
#
#
# Average loss: 0.1263, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 97.72%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.16258271038532257
#
# Average loss: 0.0774, Accuracy: 771.0/790 (98%)
#
#
# Average loss: 0.1266, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 97.59%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.07994870096445084
#
# Average loss: 0.0761, Accuracy: 773.0/790 (98%)
#
#
# Average loss: 0.1261, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 97.85%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.10248442739248276
#
# Average loss: 0.0746, Accuracy: 773.0/790 (98%)
#
#
# Average loss: 0.1256, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 11 	Training Accuracy: 97.85%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.14298473298549652
#
# Average loss: 0.0730, Accuracy: 773.0/790 (98%)
#
#
# Average loss: 0.1255, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 97.85%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.10271930694580078
#
# Average loss: 0.0717, Accuracy: 775.0/790 (98%)
#
#
# Average loss: 0.1256, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 98.10%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.029740331694483757
#
# Average loss: 0.0704, Accuracy: 775.0/790 (98%)
#
#
# Average loss: 0.1255, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 98.10%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.0542260967195034
#
# Average loss: 0.0691, Accuracy: 774.0/790 (98%)
#
#
# Average loss: 0.1260, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 97.97%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.024257389828562737
#
# Average loss: 0.0680, Accuracy: 776.0/790 (98%)
#
#
# Average loss: 0.1265, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 98.23%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.03605717048048973
#
# Average loss: 0.0669, Accuracy: 776.0/790 (98%)
#
#
# Average loss: 0.1275, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 98.23%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.06327912956476212
#
# Average loss: 0.0658, Accuracy: 776.0/790 (98%)
#
#
# Average loss: 0.1279, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 18 	Training Accuracy: 98.23%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.05539408326148987
#
# Average loss: 0.0648, Accuracy: 776.0/790 (98%)
#
#
# Average loss: 0.1283, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 19 	Training Accuracy: 98.23%
# Validation Accuracy: 96.05%
#
# Average loss: 0.0648, Accuracy: 776.0/790 (98%)
#
#
# Average loss: 0.1314, Accuracy: 4636.0/4861 (95%)
# Running seeds for 0.05 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 4 =========================
# Batch: 0, Loss: 0.07561758160591125
#
# Average loss: 0.0847, Accuracy: 1278.0/1320 (97%)
#
#
# Average loss: 0.1257, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 96.82%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.053061410784721375
#
# Average loss: 0.0819, Accuracy: 1284.0/1320 (97%)
#
#
# Average loss: 0.1244, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 97.27%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.08550422638654709
#
# Average loss: 0.0795, Accuracy: 1285.0/1320 (97%)
#
#
# Average loss: 0.1238, Accuracy: 2828.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 97.35%
# Validation Accuracy: 96.19%
# Batch: 0, Loss: 0.043593570590019226
#
# Average loss: 0.0775, Accuracy: 1285.0/1320 (97%)
#
#
# Average loss: 0.1230, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 97.35%
# Validation Accuracy: 96.22%
# Batch: 0, Loss: 0.1194964051246643
#
# Average loss: 0.0757, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.1226, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 97.42%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.060974232852458954
#
# Average loss: 0.0742, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.1226, Accuracy: 2831.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 97.42%
# Validation Accuracy: 96.29%
# Batch: 0, Loss: 0.06882739812135696
#
# Average loss: 0.0728, Accuracy: 1288.0/1320 (98%)
#
#
# Average loss: 0.1227, Accuracy: 2831.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.58%
# Validation Accuracy: 96.29%
# Batch: 0, Loss: 0.07844346016645432
#
# Average loss: 0.0715, Accuracy: 1288.0/1320 (98%)
#
#
# Average loss: 0.1227, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 97.58%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.04206322878599167
#
# Average loss: 0.0704, Accuracy: 1288.0/1320 (98%)
#
#
# Average loss: 0.1228, Accuracy: 2831.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 97.58%
# Validation Accuracy: 96.29%
# Batch: 0, Loss: 0.06672041118144989
#
# Average loss: 0.0692, Accuracy: 1288.0/1320 (98%)
#
#
# Average loss: 0.1231, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 97.58%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.08847454935312271
#
# Average loss: 0.0680, Accuracy: 1288.0/1320 (98%)
#
#
# Average loss: 0.1233, Accuracy: 2833.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 97.58%
# Validation Accuracy: 96.36%
# Batch: 0, Loss: 0.10599729418754578
#
# Average loss: 0.0669, Accuracy: 1288.0/1320 (98%)
#
#
# Average loss: 0.1236, Accuracy: 2834.0/2940 (96%)
#
# Epoch: 11 	Training Accuracy: 97.58%
# Validation Accuracy: 96.39%
# Batch: 0, Loss: 0.08921761810779572
#
# Average loss: 0.0658, Accuracy: 1289.0/1320 (98%)
#
#
# Average loss: 0.1238, Accuracy: 2833.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 97.65%
# Validation Accuracy: 96.36%
# Batch: 0, Loss: 0.07457368075847626
#
# Average loss: 0.0647, Accuracy: 1290.0/1320 (98%)
#
#
# Average loss: 0.1241, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 97.73%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.05253899097442627
#
# Average loss: 0.0637, Accuracy: 1290.0/1320 (98%)
#
#
# Average loss: 0.1242, Accuracy: 2833.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 97.73%
# Validation Accuracy: 96.36%
# Batch: 0, Loss: 0.05548766255378723
#
# Average loss: 0.0627, Accuracy: 1292.0/1320 (98%)
#
#
# Average loss: 0.1246, Accuracy: 2833.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 97.88%
# Validation Accuracy: 96.36%
# Batch: 0, Loss: 0.06224018335342407
#
# Average loss: 0.0618, Accuracy: 1293.0/1320 (98%)
#
#
# Average loss: 0.1249, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 97.95%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.07869310677051544
#
# Average loss: 0.0611, Accuracy: 1293.0/1320 (98%)
#
#
# Average loss: 0.1254, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 97.95%
# Validation Accuracy: 96.26%
# Early stopping invoked.
#
# Average loss: 0.0669, Accuracy: 1288.0/1320 (98%)
#
#
# Average loss: 0.1236, Accuracy: 4659.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 91 =========================
# Batch: 0, Loss: 0.13719993829727173
#
# Average loss: 0.1003, Accuracy: 1276.0/1320 (97%)
#
#
# Average loss: 0.1264, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 96.67%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.15718333423137665
#
# Average loss: 0.0970, Accuracy: 1279.0/1320 (97%)
#
#
# Average loss: 0.1264, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 96.89%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.09696175158023834
#
# Average loss: 0.0942, Accuracy: 1280.0/1320 (97%)
#
#
# Average loss: 0.1257, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 96.97%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.1622924953699112
#
# Average loss: 0.0922, Accuracy: 1281.0/1320 (97%)
#
#
# Average loss: 0.1255, Accuracy: 2827.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 97.05%
# Validation Accuracy: 96.16%
# Batch: 0, Loss: 0.06990981101989746
#
# Average loss: 0.0901, Accuracy: 1282.0/1320 (97%)
#
#
# Average loss: 0.1253, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 97.12%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.09348655492067337
#
# Average loss: 0.0885, Accuracy: 1283.0/1320 (97%)
#
#
# Average loss: 0.1254, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 97.20%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.1061798632144928
#
# Average loss: 0.0867, Accuracy: 1284.0/1320 (97%)
#
#
# Average loss: 0.1253, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.27%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.09222623705863953
#
# Average loss: 0.0851, Accuracy: 1283.0/1320 (97%)
#
#
# Average loss: 0.1254, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 97.20%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.033211443573236465
#
# Average loss: 0.0837, Accuracy: 1284.0/1320 (97%)
#
#
# Average loss: 0.1251, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 97.27%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.0840650424361229
#
# Average loss: 0.0823, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.1261, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 97.42%
# Validation Accuracy: 96.09%
# Early stopping invoked.
#
# Average loss: 0.0922, Accuracy: 1281.0/1320 (97%)
#
#
# Average loss: 0.1230, Accuracy: 4670.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 77 =========================
# Batch: 0, Loss: 0.06530509889125824
#
# Average loss: 0.0952, Accuracy: 1287.0/1320 (98%)
#
#
# Average loss: 0.1259, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 97.50%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.07542364299297333
#
# Average loss: 0.0914, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.1244, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 97.42%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.11330731958150864
#
# Average loss: 0.0886, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.1240, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 97.42%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.08425389230251312
#
# Average loss: 0.0864, Accuracy: 1286.0/1320 (97%)
#
#
# Average loss: 0.1233, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 97.42%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.031999461352825165
#
# Average loss: 0.0845, Accuracy: 1287.0/1320 (98%)
#
#
# Average loss: 0.1234, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 97.50%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.07548678666353226
#
# Average loss: 0.0827, Accuracy: 1288.0/1320 (98%)
#
#
# Average loss: 0.1232, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 97.58%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.06201136112213135
#
# Average loss: 0.0810, Accuracy: 1289.0/1320 (98%)
#
#
# Average loss: 0.1231, Accuracy: 2827.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.65%
# Validation Accuracy: 96.16%
# Batch: 0, Loss: 0.2310662865638733
#
# Average loss: 0.0793, Accuracy: 1290.0/1320 (98%)
#
#
# Average loss: 0.1231, Accuracy: 2827.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 97.73%
# Validation Accuracy: 96.16%
# Batch: 0, Loss: 0.0747600644826889
#
# Average loss: 0.0780, Accuracy: 1292.0/1320 (98%)
#
#
# Average loss: 0.1231, Accuracy: 2827.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 97.88%
# Validation Accuracy: 96.16%
# Batch: 0, Loss: 0.03554576635360718
#
# Average loss: 0.0768, Accuracy: 1294.0/1320 (98%)
#
#
# Average loss: 0.1232, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 98.03%
# Validation Accuracy: 96.22%
# Batch: 0, Loss: 0.10337434709072113
#
# Average loss: 0.0755, Accuracy: 1290.0/1320 (98%)
#
#
# Average loss: 0.1232, Accuracy: 2828.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 97.73%
# Validation Accuracy: 96.19%
# Batch: 0, Loss: 0.04863627627491951
#
# Average loss: 0.0744, Accuracy: 1293.0/1320 (98%)
#
#
# Average loss: 0.1234, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 11 	Training Accuracy: 97.95%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.16510790586471558
#
# Average loss: 0.0732, Accuracy: 1292.0/1320 (98%)
#
#
# Average loss: 0.1242, Accuracy: 2827.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 97.88%
# Validation Accuracy: 96.16%
# Batch: 0, Loss: 0.0457318052649498
#
# Average loss: 0.0722, Accuracy: 1292.0/1320 (98%)
#
#
# Average loss: 0.1245, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 97.88%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.06108437106013298
#
# Average loss: 0.0712, Accuracy: 1293.0/1320 (98%)
#
#
# Average loss: 0.1246, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 97.95%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.1037827879190445
#
# Average loss: 0.0702, Accuracy: 1295.0/1320 (98%)
#
#
# Average loss: 0.1245, Accuracy: 2828.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 98.11%
# Validation Accuracy: 96.19%
# Batch: 0, Loss: 0.056341223418712616
#
# Average loss: 0.0692, Accuracy: 1294.0/1320 (98%)
#
#
# Average loss: 0.1250, Accuracy: 2825.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 98.03%
# Validation Accuracy: 96.09%
# Batch: 0, Loss: 0.09781036525964737
#
# Average loss: 0.0683, Accuracy: 1292.0/1320 (98%)
#
#
# Average loss: 0.1253, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 97.88%
# Validation Accuracy: 95.92%
# Early stopping invoked.
#
# Average loss: 0.0744, Accuracy: 1293.0/1320 (98%)
#
#
# Average loss: 0.1240, Accuracy: 4659.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 18 =========================
# Batch: 0, Loss: 0.08996439725160599
#
# Average loss: 0.0959, Accuracy: 1278.0/1320 (97%)
#
#
# Average loss: 0.1270, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 96.82%
# Validation Accuracy: 95.85%
# Batch: 0, Loss: 0.12344533205032349
#
# Average loss: 0.0938, Accuracy: 1277.0/1320 (97%)
#
#
# Average loss: 0.1264, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 96.74%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.14878714084625244
#
# Average loss: 0.0921, Accuracy: 1279.0/1320 (97%)
#
#
# Average loss: 0.1264, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 96.89%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.07674954831600189
#
# Average loss: 0.0906, Accuracy: 1279.0/1320 (97%)
#
#
# Average loss: 0.1262, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 96.89%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.07061149179935455
#
# Average loss: 0.0891, Accuracy: 1281.0/1320 (97%)
#
#
# Average loss: 0.1259, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 97.05%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.052912335842847824
#
# Average loss: 0.0878, Accuracy: 1281.0/1320 (97%)
#
#
# Average loss: 0.1260, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 97.05%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.1739238202571869
#
# Average loss: 0.0865, Accuracy: 1282.0/1320 (97%)
#
#
# Average loss: 0.1266, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.12%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.10928519070148468
#
# Average loss: 0.0852, Accuracy: 1283.0/1320 (97%)
#
#
# Average loss: 0.1261, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 97.20%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.04163923114538193
#
# Average loss: 0.0840, Accuracy: 1285.0/1320 (97%)
#
#
# Average loss: 0.1260, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 97.35%
# Validation Accuracy: 95.99%
# Early stopping invoked.
#
# Average loss: 0.0921, Accuracy: 1279.0/1320 (97%)
#
#
# Average loss: 0.1230, Accuracy: 4667.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 64 =========================
# Batch: 0, Loss: 0.05682510510087013
#
# Average loss: 0.0863, Accuracy: 1280.0/1320 (97%)
#
#
# Average loss: 0.1268, Accuracy: 2819.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 96.97%
# Validation Accuracy: 95.88%
# Batch: 0, Loss: 0.0723896473646164
#
# Average loss: 0.0836, Accuracy: 1279.0/1320 (97%)
#
#
# Average loss: 0.1268, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 96.89%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.05113067477941513
#
# Average loss: 0.0815, Accuracy: 1280.0/1320 (97%)
#
#
# Average loss: 0.1272, Accuracy: 2819.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 96.97%
# Validation Accuracy: 95.88%
# Batch: 0, Loss: 0.0336824394762516
#
# Average loss: 0.0794, Accuracy: 1280.0/1320 (97%)
#
#
# Average loss: 0.1269, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 96.97%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.053652748465538025
#
# Average loss: 0.0776, Accuracy: 1280.0/1320 (97%)
#
#
# Average loss: 0.1268, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 96.97%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.042040154337882996
#
# Average loss: 0.0760, Accuracy: 1282.0/1320 (97%)
#
#
# Average loss: 0.1270, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 97.12%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.1256302446126938
#
# Average loss: 0.0745, Accuracy: 1282.0/1320 (97%)
#
#
# Average loss: 0.1268, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.12%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.07486847043037415
#
# Average loss: 0.0731, Accuracy: 1283.0/1320 (97%)
#
#
# Average loss: 0.1268, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 97.20%
# Validation Accuracy: 95.99%
# Early stopping invoked.
#
# Average loss: 0.0836, Accuracy: 1279.0/1320 (97%)
#
#
# Average loss: 0.1245, Accuracy: 4661.0/4861 (96%)
# Running seeds for 0.1 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 13 =========================
# Batch: 0, Loss: 0.19284094870090485
# Batch: 20, Loss: 0.13844533264636993
#
# Average loss: 0.1065, Accuracy: 2563.0/2645 (97%)
#
#
# Average loss: 0.1256, Accuracy: 2824.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 96.90%
# Validation Accuracy: 96.05%
# Batch: 0, Loss: 0.07928416877985
# Batch: 20, Loss: 0.24133408069610596
#
# Average loss: 0.1034, Accuracy: 2563.0/2645 (97%)
#
#
# Average loss: 0.1239, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 96.90%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.04732947424054146
# Batch: 20, Loss: 0.10009358078241348
#
# Average loss: 0.1012, Accuracy: 2566.0/2645 (97%)
#
#
# Average loss: 0.1233, Accuracy: 2827.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 97.01%
# Validation Accuracy: 96.16%
# Batch: 0, Loss: 0.19493456184864044
# Batch: 20, Loss: 0.039386142045259476
#
# Average loss: 0.0991, Accuracy: 2572.0/2645 (97%)
#
#
# Average loss: 0.1234, Accuracy: 2827.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 97.24%
# Validation Accuracy: 96.16%
# Batch: 0, Loss: 0.12109452486038208
# Batch: 20, Loss: 0.03271057829260826
#
# Average loss: 0.0976, Accuracy: 2573.0/2645 (97%)
#
#
# Average loss: 0.1236, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 97.28%
# Validation Accuracy: 96.22%
# Batch: 0, Loss: 0.058707207441329956
# Batch: 20, Loss: 0.09271326661109924
#
# Average loss: 0.0960, Accuracy: 2573.0/2645 (97%)
#
#
# Average loss: 0.1240, Accuracy: 2827.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 97.28%
# Validation Accuracy: 96.16%
# Batch: 0, Loss: 0.14458563923835754
# Batch: 20, Loss: 0.03672272339463234
#
# Average loss: 0.0946, Accuracy: 2578.0/2645 (97%)
#
#
# Average loss: 0.1237, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.47%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.058180540800094604
# Batch: 20, Loss: 0.040632735937833786
#
# Average loss: 0.0933, Accuracy: 2578.0/2645 (97%)
#
#
# Average loss: 0.1240, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 97.47%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.05819324031472206
# Batch: 20, Loss: 0.13398444652557373
#
# ...
# Batch: 120, Loss: 0.27655887603759766
# Batch: 140, Loss: 0.10592835396528244
# Batch: 160, Loss: 0.16221216320991516
# Batch: 180, Loss: 0.06953894346952438
# Batch: 200, Loss: 0.06587323546409607
#
# Average loss: 0.0908, Accuracy: 25256.0/26038 (97%)
#
#
# Average loss: 0.1206, Accuracy: 2831.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 97.00%
# Validation Accuracy: 96.29%
# Batch: 0, Loss: 0.05967359244823456
# Batch: 20, Loss: 0.12236429750919342
# Batch: 40, Loss: 0.06287750601768494
# Batch: 60, Loss: 0.12467388063669205
# Batch: 80, Loss: 0.07433962821960449
# Batch: 100, Loss: 0.0382230319082737
# Batch: 120, Loss: 0.15792441368103027
# Batch: 140, Loss: 0.14826366305351257
# Batch: 160, Loss: 0.08027202636003494
# Batch: 180, Loss: 0.0808679610490799
# Batch: 200, Loss: 0.08861840516328812
#
# Average loss: 0.0906, Accuracy: 25263.0/26038 (97%)
#
#
# Average loss: 0.1212, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.02%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.20210592448711395
# Batch: 20, Loss: 0.08390218764543533
# Batch: 40, Loss: 0.09173046052455902
# Batch: 60, Loss: 0.09483598172664642
# Batch: 80, Loss: 0.050050169229507446
# Batch: 100, Loss: 0.06806571036577225
# Batch: 120, Loss: 0.1275077760219574
# Batch: 140, Loss: 0.11085551977157593
# Batch: 160, Loss: 0.16329598426818848
# Batch: 180, Loss: 0.086791031062603
# Batch: 200, Loss: 0.11811064183712006
#
# Average loss: 0.0908, Accuracy: 25257.0/26038 (97%)
#
#
# Average loss: 0.1214, Accuracy: 2832.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 97.00%
# Validation Accuracy: 96.33%
# Batch: 0, Loss: 0.10326533019542694
# Batch: 20, Loss: 0.12628856301307678
# Batch: 40, Loss: 0.14918209612369537
# Batch: 60, Loss: 0.18570822477340698
# Batch: 80, Loss: 0.04770781472325325
# Batch: 100, Loss: 0.06930643320083618
# Batch: 120, Loss: 0.13224075734615326
# Batch: 140, Loss: 0.1124088317155838
# Batch: 160, Loss: 0.06203574314713478
# Batch: 180, Loss: 0.062091726809740067
# Batch: 200, Loss: 0.12317421287298203
#
# Average loss: 0.0903, Accuracy: 25268.0/26038 (97%)
#
#
# Average loss: 0.1213, Accuracy: 2833.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 97.04%
# Validation Accuracy: 96.36%
# Batch: 0, Loss: 0.08829750120639801
# Batch: 20, Loss: 0.15574395656585693
# Batch: 40, Loss: 0.12092821300029755
# Batch: 60, Loss: 0.08634413033723831
# Batch: 80, Loss: 0.09120070934295654
# Batch: 100, Loss: 0.10653865337371826
# Batch: 120, Loss: 0.14314158260822296
# Batch: 140, Loss: 0.07812479883432388
# Batch: 160, Loss: 0.05924760922789574
# Batch: 180, Loss: 0.09664993733167648
# Batch: 200, Loss: 0.11678095161914825
#
# Average loss: 0.0905, Accuracy: 25251.0/26038 (97%)
#
#
# Average loss: 0.1221, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 96.98%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.08138523250818253
# Batch: 20, Loss: 0.09727603197097778
# Batch: 40, Loss: 0.0734994187951088
# Batch: 60, Loss: 0.07550343871116638
# Batch: 80, Loss: 0.036055803298950195
# Batch: 100, Loss: 0.22685466706752777
# Batch: 120, Loss: 0.03637205809354782
# Batch: 140, Loss: 0.051075227558612823
# Batch: 160, Loss: 0.05543235316872597
# Batch: 180, Loss: 0.19909082353115082
# Batch: 200, Loss: 0.038720373064279556
#
# Average loss: 0.0899, Accuracy: 25258.0/26038 (97%)
#
#
# Average loss: 0.1214, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 97.00%
# Validation Accuracy: 96.26%
# Early stopping invoked.
#
# Average loss: 0.0910, Accuracy: 25248.0/26038 (97%)
#
#
# Average loss: 0.1217, Accuracy: 4670.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 98 =========================
# Batch: 0, Loss: 0.11433591693639755
# Batch: 20, Loss: 0.1381278932094574
# Batch: 40, Loss: 0.07811208814382553
# Batch: 60, Loss: 0.0800895094871521
# Batch: 80, Loss: 0.034247465431690216
# Batch: 100, Loss: 0.1157820001244545
# Batch: 120, Loss: 0.21051955223083496
# Batch: 140, Loss: 0.10958389192819595
# Batch: 160, Loss: 0.11856302618980408
# Batch: 180, Loss: 0.07440488785505295
# Batch: 200, Loss: 0.09039194881916046
#
# Average loss: 0.0931, Accuracy: 25233.0/26038 (97%)
#
#
# Average loss: 0.1228, Accuracy: 2828.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 96.91%
# Validation Accuracy: 96.19%
# Batch: 0, Loss: 0.12698526680469513
# Batch: 20, Loss: 0.18468645215034485
# Batch: 40, Loss: 0.09517095983028412
# Batch: 60, Loss: 0.10915195941925049
# Batch: 80, Loss: 0.024809371680021286
# Batch: 100, Loss: 0.05997283011674881
# Batch: 120, Loss: 0.1026856079697609
# Batch: 140, Loss: 0.09988486021757126
# Batch: 160, Loss: 0.04251625016331673
# Batch: 180, Loss: 0.16065485775470734
# Batch: 200, Loss: 0.05972868204116821
#
# Average loss: 0.0918, Accuracy: 25245.0/26038 (97%)
#
#
# Average loss: 0.1221, Accuracy: 2835.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 96.95%
# Validation Accuracy: 96.43%
# Batch: 0, Loss: 0.18442752957344055
# Batch: 20, Loss: 0.14214693009853363
# Batch: 40, Loss: 0.036520570516586304
# Batch: 60, Loss: 0.15514732897281647
# Batch: 80, Loss: 0.06335734575986862
# Batch: 100, Loss: 0.09026598930358887
# Batch: 120, Loss: 0.0899878442287445
# Batch: 140, Loss: 0.07872588187456131
# Batch: 160, Loss: 0.11264470964670181
# Batch: 180, Loss: 0.08976993709802628
# Batch: 200, Loss: 0.06858611106872559
#
# Average loss: 0.0913, Accuracy: 25257.0/26038 (97%)
#
#
# Average loss: 0.1216, Accuracy: 2831.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 97.00%
# Validation Accuracy: 96.29%
# Batch: 0, Loss: 0.08428166061639786
# Batch: 20, Loss: 0.0910259336233139
# Batch: 40, Loss: 0.12625250220298767
# Batch: 60, Loss: 0.050625137984752655
# Batch: 80, Loss: 0.06758833676576614
# Batch: 100, Loss: 0.10259182751178741
# Batch: 120, Loss: 0.15210457146167755
# Batch: 140, Loss: 0.1580103188753128
# Batch: 160, Loss: 0.03684148192405701
# Batch: 180, Loss: 0.05785159394145012
# Batch: 200, Loss: 0.10796245187520981
#
# Average loss: 0.0909, Accuracy: 25261.0/26038 (97%)
#
#
# Average loss: 0.1218, Accuracy: 2833.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 97.02%
# Validation Accuracy: 96.36%
# Batch: 0, Loss: 0.08949990570545197
# Batch: 20, Loss: 0.04109114781022072
# Batch: 40, Loss: 0.07721118628978729
# Batch: 60, Loss: 0.07258929312229156
# Batch: 80, Loss: 0.14622852206230164
# Batch: 100, Loss: 0.08149362355470657
# Batch: 120, Loss: 0.06349506974220276
# Batch: 140, Loss: 0.04510868713259697
# Batch: 160, Loss: 0.04377944394946098
# Batch: 180, Loss: 0.0790998563170433
# Batch: 200, Loss: 0.19772958755493164
#
# Average loss: 0.0907, Accuracy: 25262.0/26038 (97%)
#
#
# Average loss: 0.1216, Accuracy: 2834.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 97.02%
# Validation Accuracy: 96.39%
# Batch: 0, Loss: 0.10351407527923584
# Batch: 20, Loss: 0.09521838277578354
# Batch: 40, Loss: 0.047539472579956055
# Batch: 60, Loss: 0.05058944225311279
# Batch: 80, Loss: 0.05482114106416702
# Batch: 100, Loss: 0.11413554102182388
# Batch: 120, Loss: 0.11768710613250732
# Batch: 140, Loss: 0.06319286674261093
# Batch: 160, Loss: 0.149847611784935
# Batch: 180, Loss: 0.09645083546638489
# Batch: 200, Loss: 0.039040714502334595
#
# Average loss: 0.0918, Accuracy: 25262.0/26038 (97%)
#
#
# Average loss: 0.1220, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 97.02%
# Validation Accuracy: 96.22%
# Batch: 0, Loss: 0.08451584726572037
# Batch: 20, Loss: 0.05928616598248482
# Batch: 40, Loss: 0.13393902778625488
# Batch: 60, Loss: 0.12849758565425873
# Batch: 80, Loss: 0.1241760104894638
# Batch: 100, Loss: 0.09951482713222504
# Batch: 120, Loss: 0.044334009289741516
# Batch: 140, Loss: 0.18103118240833282
# Batch: 160, Loss: 0.14788609743118286
# Batch: 180, Loss: 0.040175266563892365
# Batch: 200, Loss: 0.10205164551734924
#
# Average loss: 0.0920, Accuracy: 25264.0/26038 (97%)
#
#
# Average loss: 0.1235, Accuracy: 2833.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.03%
# Validation Accuracy: 96.36%
# Batch: 0, Loss: 0.04167316108942032
# Batch: 20, Loss: 0.10506404936313629
# Batch: 40, Loss: 0.028672978281974792
# Batch: 60, Loss: 0.033798739314079285
# Batch: 80, Loss: 0.08385282754898071
# Batch: 100, Loss: 0.08842551708221436
# Batch: 120, Loss: 0.10970517992973328
# Batch: 140, Loss: 0.062117356806993484
# Batch: 160, Loss: 0.13556191325187683
# Batch: 180, Loss: 0.07311702519655228
# Batch: 200, Loss: 0.11361199617385864
#
# Average loss: 0.0900, Accuracy: 25270.0/26038 (97%)
#
#
# Average loss: 0.1210, Accuracy: 2833.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 97.05%
# Validation Accuracy: 96.36%
# Early stopping invoked.
#
# Average loss: 0.0918, Accuracy: 25245.0/26038 (97%)
#
#
# Average loss: 0.1220, Accuracy: 4662.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 62 =========================
# Batch: 0, Loss: 0.07945526391267776
# Batch: 20, Loss: 0.11079864203929901
# Batch: 40, Loss: 0.23511245846748352
# Batch: 60, Loss: 0.05441656708717346
# Batch: 80, Loss: 0.154780775308609
# Batch: 100, Loss: 0.04775742068886757
# Batch: 120, Loss: 0.05128215253353119
# Batch: 140, Loss: 0.05004870891571045
# Batch: 160, Loss: 0.04479135572910309
# Batch: 180, Loss: 0.06140371039509773
# Batch: 200, Loss: 0.07847534865140915
#
# Average loss: 0.0926, Accuracy: 25244.0/26038 (97%)
#
#
# Average loss: 0.1230, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 0 	Training Accuracy: 96.95%
# Validation Accuracy: 96.12%
# Batch: 0, Loss: 0.05087867006659508
# Batch: 20, Loss: 0.08716977387666702
# Batch: 40, Loss: 0.05336632579565048
# Batch: 60, Loss: 0.11212915927171707
# Batch: 80, Loss: 0.10433956235647202
# Batch: 100, Loss: 0.033567484468221664
# Batch: 120, Loss: 0.05931786447763443
# Batch: 140, Loss: 0.03344854712486267
# Batch: 160, Loss: 0.09026865661144257
# Batch: 180, Loss: 0.08693818747997284
# Batch: 200, Loss: 0.05543489754199982
#
# Average loss: 0.0918, Accuracy: 25247.0/26038 (97%)
#
#
# Average loss: 0.1223, Accuracy: 2831.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 96.96%
# Validation Accuracy: 96.29%
# Batch: 0, Loss: 0.0847763791680336
# Batch: 20, Loss: 0.07966270297765732
# Batch: 40, Loss: 0.06357289850711823
# Batch: 60, Loss: 0.14668256044387817
# Batch: 80, Loss: 0.09303022921085358
# Batch: 100, Loss: 0.13042953610420227
# Batch: 120, Loss: 0.07539889216423035
# Batch: 140, Loss: 0.10105633735656738
# Batch: 160, Loss: 0.06267111003398895
# Batch: 180, Loss: 0.16148456931114197
# Batch: 200, Loss: 0.044706929475069046
#
# Average loss: 0.0919, Accuracy: 25242.0/26038 (97%)
#
#
# Average loss: 0.1229, Accuracy: 2831.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 96.94%
# Validation Accuracy: 96.29%
# Batch: 0, Loss: 0.09326492995023727
# Batch: 20, Loss: 0.12250255793333054
# Batch: 40, Loss: 0.08970900624990463
# Batch: 60, Loss: 0.15570370852947235
# Batch: 80, Loss: 0.03823681175708771
# Batch: 100, Loss: 0.13109324872493744
# Batch: 120, Loss: 0.10533098131418228
# Batch: 140, Loss: 0.20127150416374207
# Batch: 160, Loss: 0.10151347517967224
# Batch: 180, Loss: 0.05487099662423134
# Batch: 200, Loss: 0.06462323665618896
#
# Average loss: 0.0910, Accuracy: 25249.0/26038 (97%)
#
#
# Average loss: 0.1215, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 96.97%
# Validation Accuracy: 96.26%
# Batch: 0, Loss: 0.17656977474689484
# Batch: 20, Loss: 0.05786906182765961
# Batch: 40, Loss: 0.06189257279038429
# Batch: 60, Loss: 0.05515628308057785
# Batch: 80, Loss: 0.18897320330142975
# Batch: 100, Loss: 0.10856730490922928
# Batch: 120, Loss: 0.10932949930429459
# Batch: 140, Loss: 0.1433505266904831
# Batch: 160, Loss: 0.07760919630527496
# Batch: 180, Loss: 0.09587546437978745
# Batch: 200, Loss: 0.05261487141251564
#
# Average loss: 0.0911, Accuracy: 25252.0/26038 (97%)
#
#
# Average loss: 0.1216, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 96.98%
# Validation Accuracy: 96.22%
# Batch: 0, Loss: 0.06940100342035294
# Batch: 20, Loss: 0.1549716293811798
# Batch: 40, Loss: 0.14806462824344635
# Batch: 60, Loss: 0.1416810005903244
# Batch: 80, Loss: 0.0832647830247879
# Batch: 100, Loss: 0.061133645474910736
# Batch: 120, Loss: 0.14464253187179565
# Batch: 140, Loss: 0.07512590289115906
# Batch: 160, Loss: 0.09724296629428864
# Batch: 180, Loss: 0.0933743417263031
# Batch: 200, Loss: 0.05470520630478859
#
# Average loss: 0.0906, Accuracy: 25254.0/26038 (97%)
#
#
# Average loss: 0.1217, Accuracy: 2828.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 96.99%
# Validation Accuracy: 96.19%
# Batch: 0, Loss: 0.05253337696194649
# Batch: 20, Loss: 0.06701593101024628
# Batch: 40, Loss: 0.04316379874944687
# Batch: 60, Loss: 0.12560078501701355
# Batch: 80, Loss: 0.07424435764551163
# Batch: 100, Loss: 0.07052993774414062
# Batch: 120, Loss: 0.21501563489437103
# Batch: 140, Loss: 0.1022641658782959
# Batch: 160, Loss: 0.05980488285422325
# Batch: 180, Loss: 0.050851963460445404
# Batch: 200, Loss: 0.13042277097702026
#
# Average loss: 0.0907, Accuracy: 25258.0/26038 (97%)
#
#
# Average loss: 0.1221, Accuracy: 2829.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.00%
# Validation Accuracy: 96.22%
# Batch: 0, Loss: 0.05966613069176674
# Batch: 20, Loss: 0.10257894545793533
# Batch: 40, Loss: 0.06325274705886841
# Batch: 60, Loss: 0.20283764600753784
# Batch: 80, Loss: 0.04963904619216919
# Batch: 100, Loss: 0.06985301524400711
# Batch: 120, Loss: 0.061909932643175125
# Batch: 140, Loss: 0.08771214634180069
# Batch: 160, Loss: 0.05784080922603607
# Batch: 180, Loss: 0.08279459923505783
# Batch: 200, Loss: 0.15420237183570862
#
# Average loss: 0.0906, Accuracy: 25254.0/26038 (97%)
#
#
# Average loss: 0.1220, Accuracy: 2831.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 96.99%
# Validation Accuracy: 96.29%
# Early stopping invoked.
#
# Average loss: 0.0918, Accuracy: 25247.0/26038 (97%)
#
#
# Average loss: 0.1223, Accuracy: 4662.0/4861 (96%)
#
# Percentage: 0.01, Seed: 10, Epochs taken: 8
# Percentage: 0.01, Seed: 20, Epochs taken: 17
# Percentage: 0.01, Seed: 30, Epochs taken: 11
# Percentage: 0.01, Seed: 40, Epochs taken: 11
# Percentage: 0.01, Seed: 50, Epochs taken: 17
# Percentage: 0.03, Seed: 10, Epochs taken: 8
# Percentage: 0.03, Seed: 20, Epochs taken: 7
# Percentage: 0.03, Seed: 30, Epochs taken: 10
# Percentage: 0.03, Seed: 40, Epochs taken: 12
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 18
# Percentage: 0.05, Seed: 20, Epochs taken: 10
# Percentage: 0.05, Seed: 30, Epochs taken: 18
# Percentage: 0.05, Seed: 40, Epochs taken: 9
# Percentage: 0.05, Seed: 50, Epochs taken: 8
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 8
# Percentage: 0.1, Seed: 30, Epochs taken: 17
# Percentage: 0.1, Seed: 40, Epochs taken: 16
# Percentage: 0.1, Seed: 50, Epochs taken: 12
# Percentage: 0.15, Seed: 10, Epochs taken: 10
# Percentage: 0.15, Seed: 20, Epochs taken: 12
# Percentage: 0.15, Seed: 30, Epochs taken: 18
# Percentage: 0.15, Seed: 40, Epochs taken: 13
# Percentage: 0.15, Seed: 50, Epochs taken: 10
# Percentage: 0.2, Seed: 10, Epochs taken: 11
# Percentage: 0.2, Seed: 20, Epochs taken: 8
# Percentage: 0.2, Seed: 30, Epochs taken: 10
# Percentage: 0.2, Seed: 40, Epochs taken: 12
# Percentage: 0.2, Seed: 50, Epochs taken: 12
# Percentage: 0.4, Seed: 10, Epochs taken: 17
# Percentage: 0.4, Seed: 20, Epochs taken: 9
# Percentage: 0.4, Seed: 30, Epochs taken: 9
# Percentage: 0.4, Seed: 40, Epochs taken: 8
# Percentage: 0.4, Seed: 50, Epochs taken: 7
# Percentage: 0.6, Seed: 10, Epochs taken: 10
# Percentage: 0.6, Seed: 20, Epochs taken: 8
# Percentage: 0.6, Seed: 30, Epochs taken: 15
# Percentage: 0.6, Seed: 40, Epochs taken: 12
# Percentage: 0.6, Seed: 50, Epochs taken: 10
# Percentage: 0.8, Seed: 10, Epochs taken: 11
# Percentage: 0.8, Seed: 20, Epochs taken: 8
# Percentage: 0.8, Seed: 30, Epochs taken: 7
# Percentage: 0.8, Seed: 40, Epochs taken: 18
# Percentage: 0.8, Seed: 50, Epochs taken: 18
# Percentage: 1, Seed: 10, Epochs taken: 10
# Percentage: 1, Seed: 20, Epochs taken: 13
# Percentage: 1, Seed: 30, Epochs taken: 11
# Percentage: 1, Seed: 40, Epochs taken: 8
# Percentage: 1, Seed: 50, Epochs taken: 8

# %%
# End to End - Train Accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Train Accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Train Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Train Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
# End to End - Test Accuracies
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]

plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Test Accuracies
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Test Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Test Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
data_to_save = {
    "results_test_finetune": results_test_finetune,
    "results_train_finetune": results_train_finetune,
    "epochs_taken_finetune": epochs_taken_finetune,
    
    "results_test": results_test,
    "results_train": results_train,
    "epochs_taken": epochs_taken
}

# Assuming data_to_save from the previous code
with open("data.json", "w") as file:
    json.dump(data_to_save, file)

# %%
plt.figure(figsize=(10, 6))

for perc in percentages:
    plt.scatter(epochs_taken[perc], epochs_taken_finetune[perc], label=f'{perc} data')
plt.xlabel('Epochs (End to End)')
plt.ylabel('Epochs (Finetune)')
plt.title('Scatter Plot Comparing Epochs Taken for Convergence')
plt.legend()
plt.show()

# %%
# Given data
percentages = list(epochs_taken.keys())

all_epochs = []
labels = []

for perc in percentages:
    all_epochs.extend([epochs_taken[perc], epochs_taken_finetune[perc]])
    labels.extend([f'{perc} End to End', f'{perc} Finetune'])

# Plotting
plt.figure(figsize=(10, 6))
box = plt.boxplot(all_epochs, labels=labels, patch_artist=True)

# Coloring
colors = ['skyblue', 'lightgreen'] * len(percentages)
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

plt.ylabel('Epochs Taken')
plt.title('Box Plot of Epochs Taken for Each Percentage')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ***EXPERIMENT SETUP***

# %% [markdown]
# - percentages_set_1 = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
# - dataset: same as before MNIST 5 to 5
#
# - lr pretraining = 0.01
# - lr finetuning = 0.001
#
# - architecture:
#     - Conv 1 (5,5), channels=1
#     - Relu
#     - Conv 2 (5,5,), channels=1
#     - Relu
#     - Pooling: True
#     - dense( x, x) x=output shape of prev layer (128?)
#     - Relu
#     - dense(x, 5)
#     - softmax
#
# - Freezing: NO
#
# - Reinitializing CNN layers: No
# - Reinitializing CNN layers: Both
# - Reinitializing softmax layers: Yes
#
# - If we don’t save the best model, ES=6
#
# - num train = 20

# %% [markdown]
# ***IMPORTS***

# %%
import numpy as np
import random
import copy
import matplotlib.pyplot as plt
import json
from tqdm.auto import tqdm

# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from torchvision import datasets, transforms

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from types import SimpleNamespace
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ***UTILS***

# %%
def eval(model, device, dataset_loader, debug=False, classification_report_flag=False, is_cnn=True, logger=print):

    """
    Evaluates the model on the given dataset loader.

    Parameters:
    - model: the PyTorch model to evaluate.
    - device: the device to which tensors should be moved before computation.
    - dataset_loader: DataLoader for evaluation.
    - debug: whether to print debug info like loss and accuracy.
    - classification_report_flag: whether to print a classification report.
    - is_cnn: a flag indicating if the model is a CNN. If it's not, the input data will be reshaped.
    - logger: logging function for printing messages.

    Returns:
    - Accuracy of the model on the provided dataset loader.

    Usage:
    - accuracy = eval(model, device, dataset_loader, debug=False, is_cnn=False, classification_report_flag=False)
    """

    model.eval()
    test_loss, correct = 0., 0.
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data, target in dataset_loader:
            if is_cnn:
              data = data.view(data.size(0), 1, 28, 28)
            else:
              data = data.reshape([data.shape[0], -1])
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(target.cpu().numpy())

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data

    if debug:
        logger('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(test_loss, correct, num_data, 100. * acc))

    if classification_report_flag:
        unique_labels = np.unique(all_labels).tolist()
        logger(classification_report(all_labels, all_preds, labels=unique_labels, target_names=[f'Class {i}' for i in unique_labels]))

    return acc

# %%
class Trainer:

    """
    A class for training and evaluating a model with early stopping and best model saving functionalities.

    Attributes:
    - model: PyTorch model to be trained and evaluated.
    - dataloader: Contains data loaders (train, validation, test) for training and evaluation.
    - params: Dictionary containing various hyperparameters and settings.
    - device: the device to which tensors should be moved before computation.
    - optimizer: The optimizer for training.
    - best_model_state: State dictionary of the best model.
    - max_val_acc: The highest validation accuracy encountered during training.
    - no_improve_epochs: Number of epochs without improvement in validation accuracy.
    - is_cnn: Flag indicating if the model is a CNN.
    - is_debug: Flag indicating if debug information should be printed.
    - classification_report_flag: Flag indicating if a classification report should be generated.

    Methods:
    - train_epoch(): Runs a single epoch of training.
    - evaluate(loader): Evaluates the model on a given data loader.
    - save_best_model(): Saves the current state of the model as the best model.
    - save_checkpoint(epoch, train_acc, val_acc): Saves the current state of the model and other information as a checkpoint.
    - early_stopping_check(val_acc): Checks the stopping criterion and performs actions based on it.
    - train(): Runs the training process for a number of epochs, with early stopping functionality.

    Usage:
    params = {
      'device': 'cuda',
      'lr': 0.001,
      'num_train': 10,
      'early_stop_patience': 3,
      'save_best': True,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': True
    }

    trainer = Trainer(model, dataloader, params)
    train_acc, test_acc, effective_epochs, checkpoints = trainer.train()
    """


    def __init__(self, model, dataloader, params):
        self.model = model
        self.dataloader = dataloader
        self.params = params

        self.device = torch.device(params['device'])
        self.optimizer = optim.Adam(model.parameters(), lr=params['lr'])

        # Initialize best_model_state with the current model state
        self.best_model_state = copy.deepcopy(self.model.state_dict())
        self.max_val_acc = 0.
        self.no_improve_epochs = 0

        self.is_cnn = params.get('is_cnn', False)
        self.is_debug = params.get('is_debug', False)
        self.classification_report_flag = params.get('classification_report_flag', False)
        self.logger = params.get('logger', print)
        
    def train_epoch(self):
      self.model.train()
      for batch_idx, (data, target) in enumerate(self.dataloader.train_loader):

          # Print the size of the current batch
          if self.is_cnn:
            data = data.view(data.size(0), 1, 28, 28)
          else:
            data = data.reshape([data.shape[0], -1])

          data, target = data.to(self.device), target.to(self.device)
          self.optimizer.zero_grad()
          output = self.model(data)
          loss = F.nll_loss(output, target)
          loss.backward()
          self.optimizer.step()

          if self.is_debug and batch_idx % 20 == 0:
              self.logger(f"Batch: {batch_idx}, Loss: {loss.item()}")

    def evaluate(self, loader):
        return eval(self.model, self.device, loader, self.is_debug, self.classification_report_flag, self.is_cnn)

    def save_best_model(self):
        torch.save(self.model.state_dict(), 'best_model.pth')

    def save_checkpoint(self, epoch, train_acc, val_acc):
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'train_acc': train_acc,
            'val_acc': val_acc
        }
        torch.save(checkpoint, f'checkpoint_epoch_{epoch}.pth')
        return checkpoint

    def early_stopping_check(self, val_acc):
        if val_acc > self.max_val_acc:
            self.max_val_acc = val_acc
            self.no_improve_epochs = 0
            # Deep copy the model's state
            self.best_model_state = copy.deepcopy(self.model.state_dict())
            if self.params.get('save_best', False):
                self.save_best_model()
        else:
            self.no_improve_epochs += 1
            if self.no_improve_epochs >= self.params['early_stop_patience']:
                self.logger("Early stopping invoked.")
                # Only load if best_model_state has been set
                if self.best_model_state is not None:
                    self.model.load_state_dict(self.best_model_state)
                return True
        return False

    def train(self):
        effective_epochs = 0
        checkpoints = []

        for epoch in range(self.params['num_train']):
            effective_epochs += 1
            self.train_epoch()

            train_acc = self.evaluate(self.dataloader.train_loader)
            val_acc = self.evaluate(self.dataloader.val_loader)
            self.logger(f'Epoch: {epoch} \tTraining Accuracy: {train_acc*100:.2f}%')
            self.logger(f'Validation Accuracy: {val_acc*100:.2f}%')

            if self.params.get('early_stop_patience', None):
                if self.early_stopping_check(val_acc):
                    self.model.load_state_dict(self.best_model_state)
                    break

            if self.params.get('save_checkpoints', False):
                checkpoint = self.save_checkpoint(epoch, train_acc, val_acc)
                checkpoints.append(checkpoint)

        # Final evaluations
        train_acc = self.evaluate(self.dataloader.train_loader)
        test_acc = self.evaluate(self.dataloader.test_loader)

        return train_acc, test_acc, effective_epochs, checkpoints

# %%
def reduce_dataset(dataloader, percentage, balanced=True, seed=42):

    """
    Reduces the dataset to the given percentage. Can ensure class balance if needed.

    Parameters:
    - dataloader: PyTorch DataLoader object.
    - percentage: Desired percentage of the original dataset.
    - balanced: If True, ensures class balance. If False, reduces randomly.
    - seed: Seed for reproducibility.

    Returns:
    - reduced_dataloader: DataLoader with the reduced dataset.
    """
    # Extract the dataset from the dataloader
    dataset = dataloader.dataset

    # Extract all data and labels from the dataset
    X = [dataset[i][0] for i in range(len(dataset))]
    y = [dataset[i][1] for i in range(len(dataset))]

    # Set the seed for reproducibility
    torch.manual_seed(seed)

    if not balanced:
        # Determine the number of samples to keep
        num_samples = int(len(dataset) * percentage)

        # Randomly select indices without replacement
        indices = torch.randperm(len(dataset))[:num_samples].tolist()

    else:
        # Get unique classes and their counts
        classes, class_counts = torch.unique(torch.tensor(y), return_counts=True)

        # Determine the number of samples per class to keep
        num_samples_per_class = int(len(dataset) * percentage / len(classes))
        indices = []

        for class_label in classes:
            class_indices = [i for i, label in enumerate(y) if label == class_label]

            # Randomly select indices without replacement for each class
            class_selected_indices = torch.randperm(len(class_indices))[:num_samples_per_class].tolist()
            indices.extend([class_indices[i] for i in class_selected_indices])

    # Use a Subset of the original dataset to create a reduced dataset
    reduced_dataset = data.Subset(dataset, indices)

    # Create a DataLoader with the reduced dataset.
    reduced_dataloader = data.DataLoader(reduced_dataset, batch_size=dataloader.batch_size, shuffle=True)

    return reduced_dataloader

# %%
class RelabeledSubset(torch.utils.data.Dataset):
    def __init__(self, dataset, offset):
        self.dataset = dataset
        self.offset = offset

    def __getitem__(self, idx):
        data, label = self.dataset[idx]
        # Offset the label to start from 0
        label = label - self.offset
        return data, label

    def __len__(self):
        return len(self.dataset)

# %%
class TransferLearningMNIST(object):
    def __init__(self, batch_size, input_dim=28*28, val_split=0.1, num_workers=4):
        self.input_dim = input_dim
        self.output_dim = 10
        self.val_split = val_split

        def filter_dataset(dataset, classes):
            indices = [i for i, t in enumerate(dataset.targets) if t in classes]
            return torch.utils.data.Subset(dataset, indices)

        mnist_train_data = datasets.MNIST(
            '../data',
            train=True,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_train_data = filter_dataset(mnist_train_data, list(range(5)))
        finetune_train_data = filter_dataset(mnist_train_data, list(range(5, 10)))

        pretrain_len = len(pretrain_train_data)
        finetune_len = len(finetune_train_data)
        pretrain_val_len = int(val_split * pretrain_len)
        finetune_val_len = int(val_split * finetune_len)
        SEED = 42
        pretrain_train_set, pretrain_val_set = torch.utils.data.random_split(
            pretrain_train_data, [pretrain_len - pretrain_val_len, pretrain_val_len], generator=torch.Generator().manual_seed(SEED))
        finetune_train_set, finetune_val_set = torch.utils.data.random_split(
            finetune_train_data, [finetune_len - finetune_val_len, finetune_val_len], generator=torch.Generator().manual_seed(SEED))

        self.pretrain_train_loader = torch.utils.data.DataLoader(pretrain_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.pretrain_val_loader = torch.utils.data.DataLoader(pretrain_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning datasets
        finetune_train_set = RelabeledSubset(finetune_train_set, 5)
        finetune_val_set = RelabeledSubset(finetune_val_set, 5)

        self.finetune_train_loader = torch.utils.data.DataLoader(finetune_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.finetune_val_loader = torch.utils.data.DataLoader(finetune_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        mnist_test_data = datasets.MNIST(
            '../data',
            train=False,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_test_data = filter_dataset(mnist_test_data, list(range(5)))
        finetune_test_data = filter_dataset(mnist_test_data, list(range(5, 10)))

        self.pretrain_test_loader = torch.utils.data.DataLoader(pretrain_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning test datasets
        finetune_test_data = RelabeledSubset(finetune_test_data, 5)
        self.finetune_test_loader = torch.utils.data.DataLoader(finetune_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        # Complete test loader contains all test examples.
        self.complete_test_loader = torch.utils.data.DataLoader(mnist_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
class TransferLearningMNISTWrapper:
    """
    This wrapper class provides a convenient way to switch between pretraining and fine-tuning phases.

    It allows for changing the phase and accordingly updating the data loaders (train, val, test)
    to either pretraining or fine-tuning sets.
    """
    def __init__(self, transferLearningMNISTObj, phase):
        """
        Initializes the TransferLearningMNISTWrapper object.

        Parameters:
        - transferLearningMNISTObj: An instance of the TransferLearningMNIST class.
        - phase: String indicating the current phase ("pretrain" or "finetune").
        """
        self.transferLearningMNISTObj = transferLearningMNISTObj
        self.phase = phase
        self.input_dim = self.transferLearningMNISTObj.input_dim
        self.output_dim = self.transferLearningMNISTObj.output_dim
        self.update_phase(phase)

    def update_phase(self, phase):
        """
        Updates the phase and the corresponding data loaders.

        Parameters:
        - phase: String indicating the desired phase ("pretrain" or "finetune").

        Throws:
        - ValueError: If the phase is neither "pretrain" nor "finetune".
        """
        self.phase = phase
        if phase == 'pretrain':
            self.train_loader = self.transferLearningMNISTObj.pretrain_train_loader
            self.val_loader = self.transferLearningMNISTObj.pretrain_val_loader
            self.test_loader = self.transferLearningMNISTObj.pretrain_test_loader
        elif phase == 'finetune':
            self.train_loader = self.transferLearningMNISTObj.finetune_train_loader
            self.val_loader = self.transferLearningMNISTObj.finetune_val_loader
            self.test_loader = self.transferLearningMNISTObj.finetune_test_loader
        else:
            raise ValueError('Phase must be either "pretrain" or "finetune".')

    def get_current_phase(self):
      return self.phase

# %%
class CustomCNN(nn.Module):
    def __init__(self, input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling=True):
        super(CustomCNN, self).__init__()

        # Initial number of input channels, assuming grayscale images
        in_channels = 1

        # Dynamically add convolutional and activation layers based on the specified depth
        for i in range(depth):
            # Create a convolutional layer and add it to the model
            setattr(self, f"conv{i}", nn.Conv2d(in_channels, num_channels, kernel_size=kernel_size, padding=1))

            # Create an activation layer (e.g., ReLU) and add it to the model
            setattr(self, f"act{i}", activation_function())

            # Update the input dimensions after convolution
            input_dim = (input_dim - kernel_size + 2 * 1) + 1

            # Optionally add pooling layers to reduce spatial dimensions
            if use_pooling and i % 2 == 1:
                setattr(self, f"pool{i}", nn.MaxPool2d(2))
                input_dim = input_dim // 2

            # Update the input channels for the next convolutional layer
            in_channels = num_channels

        # Compute the size of the flattened features for the fully connected layer
        flattened_size = in_channels * input_dim * input_dim

        # Add two fully connected layers for classification
        self.fc_1 = nn.Linear(flattened_size, hidden_dim_lin)
        self.fc_2 = nn.Linear(hidden_dim_lin, output_dim)

        # Add log softmax layer for multi-class classification output
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
      # Iterate over each module in the CustomCNN class
      for layer_name, layer in self.named_children():
          # Process the input tensor through convolutional and activation layers
          if "conv" in layer_name or "act" in layer_name:
              x = layer(x)
          # Process the input tensor through pooling layers if they exist
          elif "pool" in layer_name:
              x = layer(x)
          # If reached fully connected layers, break the loop
          elif isinstance(layer, nn.Linear):
              break

      # Flatten the tensor to fit the input shape of the fully connected layers
      x = x.view(x.size(0), -1)
        
      # Save the flattened size for reinitializing layers later
      self.flattened_size = x.shape[1]

      # Pass the tensor through the fully connected layers
      x = self.fc_1(x)
      x = self.fc_2(x)

      # Return log softmax activated output
      return self.logsoftmax(x)

# %%
def generate_cnn(input_dim, output_dim, depth, num_channels, hidden_dim_lin, kernel_size, activation_function=nn.ReLU, use_pooling=True):
    model = CustomCNN(input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling)
    return model

# %% [markdown]
# ***PRE-TRAINING***

# %%
batch_size = 128

dataloader = TransferLearningMNIST(batch_size)
dataloader_wrapped = TransferLearningMNISTWrapper(dataloader, phase = 'pretrain')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 90542201.30it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 67560342.34it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 25061118.77it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 15928535.76it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw

# %%
a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        break

# %%
params = {
      'depth': 2,
      'width': 1,
      'hidden_dim_lin': 128,
      'activation_function': nn.ReLU,
      'kernel_size': 5,
      'device': device,
      'lr': 0.001,
      'num_train': 20,
      'early_stop_patience': 6,
      'save_best': True,
      'save_checkpoints': True,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': False
    }

# Create DNN model
model = generate_cnn(input_dim = 28, output_dim = 10, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
model
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
# Train and evaluate
trainer = Trainer(model, dataloader_wrapped, params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Batch: 0, Loss: 2.2988688945770264
# Batch: 20, Loss: 1.679621696472168
# Batch: 40, Loss: 1.281978726387024
# Batch: 60, Loss: 0.652273952960968
# Batch: 80, Loss: 0.4007314443588257
# Batch: 100, Loss: 0.3612010180950165
# Batch: 120, Loss: 0.24924878776073456
# Batch: 140, Loss: 0.11499082297086716
# Batch: 160, Loss: 0.18692833185195923
# Batch: 180, Loss: 0.23273912072181702
# Batch: 200, Loss: 0.10572396963834763
#
# Average loss: 0.1630, Accuracy: 26165.0/27537 (95%)
#
#
# Average loss: 0.1889, Accuracy: 2873.0/3059 (94%)
#
# Epoch: 0 	Training Accuracy: 95.02%
# Validation Accuracy: 93.92%
# Batch: 0, Loss: 0.12397367507219315
# Batch: 20, Loss: 0.13805925846099854
# Batch: 40, Loss: 0.10154307633638382
# Batch: 60, Loss: 0.10549850016832352
# Batch: 80, Loss: 0.1335236132144928
# Batch: 100, Loss: 0.1198328509926796
# Batch: 120, Loss: 0.13561998307704926
# Batch: 140, Loss: 0.11358091235160828
# Batch: 160, Loss: 0.21463091671466827
# Batch: 180, Loss: 0.2897544503211975
# Batch: 200, Loss: 0.11882569640874863
#
# Average loss: 0.1313, Accuracy: 26434.0/27537 (96%)
#
#
# Average loss: 0.1522, Accuracy: 2914.0/3059 (95%)
#
# Epoch: 1 	Training Accuracy: 95.99%
# Validation Accuracy: 95.26%
# Batch: 0, Loss: 0.17914660274982452
# Batch: 20, Loss: 0.11042699962854385
# Batch: 40, Loss: 0.1290302872657776
# Batch: 60, Loss: 0.17010615766048431
# Batch: 80, Loss: 0.11530875414609909
# Batch: 100, Loss: 0.10338769853115082
# Batch: 120, Loss: 0.21188177168369293
# Batch: 140, Loss: 0.08702447265386581
# Batch: 160, Loss: 0.05891643837094307
# Batch: 180, Loss: 0.11857347190380096
# Batch: 200, Loss: 0.05482298135757446
#
# Average loss: 0.1216, Accuracy: 26551.0/27537 (96%)
#
#
# Average loss: 0.1459, Accuracy: 2926.0/3059 (96%)
#
# Epoch: 2 	Training Accuracy: 96.42%
# Validation Accuracy: 95.65%
# Batch: 0, Loss: 0.06807523220777512
# Batch: 20, Loss: 0.047047510743141174
# Batch: 40, Loss: 0.0646245926618576
# Batch: 60, Loss: 0.10804817080497742
# Batch: 80, Loss: 0.18650735914707184
# Batch: 100, Loss: 0.0726330503821373
# Batch: 120, Loss: 0.22522510588169098
# Batch: 140, Loss: 0.10760195553302765
# Batch: 160, Loss: 0.1379537135362625
# Batch: 180, Loss: 0.1715620905160904
# Batch: 200, Loss: 0.09288569539785385
#
# Average loss: 0.1130, Accuracy: 26560.0/27537 (96%)
#
#
# Average loss: 0.1324, Accuracy: 2932.0/3059 (96%)
#
# Epoch: 3 	Training Accuracy: 96.45%
# Validation Accuracy: 95.85%
# Batch: 0, Loss: 0.16230666637420654
# Batch: 20, Loss: 0.17509464919567108
# Batch: 40, Loss: 0.07575910538434982
# Batch: 60, Loss: 0.11770512908697128
# Batch: 80, Loss: 0.08623920381069183
# Batch: 100, Loss: 0.1358530968427658
# Batch: 120, Loss: 0.11084301769733429
# Batch: 140, Loss: 0.19456107914447784
# Batch: 160, Loss: 0.08715575188398361
# Batch: 180, Loss: 0.15237784385681152
# Batch: 200, Loss: 0.1090095117688179
#
# Average loss: 0.1089, Accuracy: 26607.0/27537 (97%)
#
#
# Average loss: 0.1303, Accuracy: 2939.0/3059 (96%)
#
# Epoch: 4 	Training Accuracy: 96.62%
# Validation Accuracy: 96.08%
# Batch: 0, Loss: 0.0645514726638794
# Batch: 20, Loss: 0.052939850836992264
# Batch: 40, Loss: 0.10192319750785828
# Batch: 60, Loss: 0.07643113285303116
# Batch: 80, Loss: 0.16396093368530273
# Batch: 100, Loss: 0.07592286914587021
# Batch: 120, Loss: 0.15211221575737
# Batch: 140, Loss: 0.06646671891212463
# Batch: 160, Loss: 0.06190799921751022
# Batch: 180, Loss: 0.16001243889331818
# Batch: 200, Loss: 0.18138845264911652
#
# Average loss: 0.1064, Accuracy: 26619.0/27537 (97%)
#
#
# Average loss: 0.1237, Accuracy: 2939.0/3059 (96%)
#
# Epoch: 5 	Training Accuracy: 96.67%
# Validation Accuracy: 96.08%
# Batch: 0, Loss: 0.16301941871643066
# Batch: 20, Loss: 0.07754242420196533
# Batch: 40, Loss: 0.0938412994146347
# Batch: 60, Loss: 0.0618109330534935
# Batch: 80, Loss: 0.09467306733131409
# Batch: 100, Loss: 0.07077813148498535
# Batch: 120, Loss: 0.09200303256511688
# Batch: 140, Loss: 0.0890643373131752
# Batch: 160, Loss: 0.0457596629858017
# Batch: 180, Loss: 0.07192808389663696
# Batch: 200, Loss: 0.21189303696155548
#
# Average loss: 0.1041, Accuracy: 26670.0/27537 (97%)
#
#
# Average loss: 0.1252, Accuracy: 2942.0/3059 (96%)
#
# Epoch: 6 	Training Accuracy: 96.85%
# Validation Accuracy: 96.18%
# Batch: 0, Loss: 0.0753173679113388
# Batch: 20, Loss: 0.03607786074280739
# Batch: 40, Loss: 0.12542761862277985
# Batch: 60, Loss: 0.11696787923574448
# Batch: 80, Loss: 0.07491607218980789
# Batch: 100, Loss: 0.1674528419971466
# Batch: 120, Loss: 0.16409221291542053
# Batch: 140, Loss: 0.10931859165430069
# Batch: 160, Loss: 0.0803709551692009
# Batch: 180, Loss: 0.14957457780838013
# Batch: 200, Loss: 0.0571260005235672
#
# Average loss: 0.1001, Accuracy: 26707.0/27537 (97%)
#
#
# Average loss: 0.1221, Accuracy: 2947.0/3059 (96%)
#
# Epoch: 7 	Training Accuracy: 96.99%
# Validation Accuracy: 96.34%
# Batch: 0, Loss: 0.07897241413593292
# Batch: 20, Loss: 0.11418883502483368
# Batch: 40, Loss: 0.08971770852804184
# Batch: 60, Loss: 0.14124983549118042
# Batch: 80, Loss: 0.09663914144039154
# Batch: 100, Loss: 0.09482564777135849
# Batch: 120, Loss: 0.04493311047554016
# Batch: 140, Loss: 0.13312360644340515
# Batch: 160, Loss: 0.061985988169908524
# Batch: 180, Loss: 0.13120649755001068
# Batch: 200, Loss: 0.26733213663101196
#
# Average loss: 0.0996, Accuracy: 26697.0/27537 (97%)
#
#
# Average loss: 0.1195, Accuracy: 2948.0/3059 (96%)
#
# Epoch: 8 	Training Accuracy: 96.95%
# Validation Accuracy: 96.37%
# Batch: 0, Loss: 0.21713735163211823
# Batch: 20, Loss: 0.10176996886730194
# Batch: 40, Loss: 0.09712718427181244
# Batch: 60, Loss: 0.13321375846862793
# Batch: 80, Loss: 0.20279687643051147
# Batch: 100, Loss: 0.06776394695043564
# Batch: 120, Loss: 0.08270914107561111
# Batch: 140, Loss: 0.10257573425769806
# Batch: 160, Loss: 0.21805086731910706
# Batch: 180, Loss: 0.11008229106664658
# Batch: 200, Loss: 0.1281147301197052
#
# Average loss: 0.0950, Accuracy: 26736.0/27537 (97%)
#
#
# Average loss: 0.1151, Accuracy: 2951.0/3059 (96%)
#
# Epoch: 9 	Training Accuracy: 97.09%
# Validation Accuracy: 96.47%
# Batch: 0, Loss: 0.11835575848817825
# Batch: 20, Loss: 0.09565466642379761
# Batch: 40, Loss: 0.07529711723327637
# Batch: 60, Loss: 0.15317361056804657
# Batch: 80, Loss: 0.13811644911766052
# Batch: 100, Loss: 0.07597856968641281
# Batch: 120, Loss: 0.0692315399646759
# Batch: 140, Loss: 0.12298057228326797
# Batch: 160, Loss: 0.052661046385765076
# Batch: 180, Loss: 0.16463862359523773
# Batch: 200, Loss: 0.053962063044309616
#
# Average loss: 0.0906, Accuracy: 26771.0/27537 (97%)
#
#
# Average loss: 0.1132, Accuracy: 2956.0/3059 (97%)
#
# Epoch: 10 	Training Accuracy: 97.22%
# Validation Accuracy: 96.63%
# Batch: 0, Loss: 0.07580764591693878
# Batch: 20, Loss: 0.06987782567739487
# Batch: 40, Loss: 0.19474755227565765
# Batch: 60, Loss: 0.15088419616222382
# Batch: 80, Loss: 0.10622861236333847
# Batch: 100, Loss: 0.12208990752696991
# Batch: 120, Loss: 0.04019096866250038
# Batch: 140, Loss: 0.11625458300113678
# Batch: 160, Loss: 0.1311245858669281
# Batch: 180, Loss: 0.0788731798529625
# Batch: 200, Loss: 0.14942146837711334
#
# Average loss: 0.0863, Accuracy: 26821.0/27537 (97%)
#
#
# Average loss: 0.1098, Accuracy: 2956.0/3059 (97%)
#
# Epoch: 11 	Training Accuracy: 97.40%
# Validation Accuracy: 96.63%
# Batch: 0, Loss: 0.11771921068429947
# Batch: 20, Loss: 0.06696275621652603
# Batch: 40, Loss: 0.0585455484688282
# Batch: 60, Loss: 0.09374091029167175
# Batch: 80, Loss: 0.10177574306726456
# Batch: 100, Loss: 0.11459648609161377
# Batch: 120, Loss: 0.053995948284864426
# Batch: 140, Loss: 0.11910471320152283
# Batch: 160, Loss: 0.07379388809204102
# Batch: 180, Loss: 0.07180766016244888
# Batch: 200, Loss: 0.10447713732719421
#
# Average loss: 0.0864, Accuracy: 26790.0/27537 (97%)
#
#
# Average loss: 0.1143, Accuracy: 2945.0/3059 (96%)
#
# Epoch: 12 	Training Accuracy: 97.29%
# Validation Accuracy: 96.27%
# Batch: 0, Loss: 0.060210660099983215
# Batch: 20, Loss: 0.024641375988721848
# Batch: 40, Loss: 0.03277048468589783
# Batch: 60, Loss: 0.13447439670562744
# Batch: 80, Loss: 0.0803258940577507
# Batch: 100, Loss: 0.06550826132297516
# Batch: 120, Loss: 0.089510977268219
# Batch: 140, Loss: 0.1090121641755104
# Batch: 160, Loss: 0.05600595474243164
# Batch: 180, Loss: 0.049223143607378006
# Batch: 200, Loss: 0.04436999559402466
#
# Average loss: 0.0772, Accuracy: 26880.0/27537 (98%)
#
#
# Average loss: 0.1004, Accuracy: 2965.0/3059 (97%)
#
# Epoch: 13 	Training Accuracy: 97.61%
# Validation Accuracy: 96.93%
# Batch: 0, Loss: 0.048081956803798676
# Batch: 20, Loss: 0.05472777411341667
# Batch: 40, Loss: 0.1496487855911255
# Batch: 60, Loss: 0.027933713048696518
# Batch: 80, Loss: 0.05863472446799278
# Batch: 100, Loss: 0.06841991096735
# Batch: 120, Loss: 0.0736493170261383
# Batch: 140, Loss: 0.07363596558570862
# Batch: 160, Loss: 0.12718407809734344
# Batch: 180, Loss: 0.1134670078754425
# Batch: 200, Loss: 0.14696769416332245
#
# Average loss: 0.0732, Accuracy: 26934.0/27537 (98%)
#
#
# Average loss: 0.0951, Accuracy: 2964.0/3059 (97%)
#
# Epoch: 14 	Training Accuracy: 97.81%
# Validation Accuracy: 96.89%
# Batch: 0, Loss: 0.049793925136327744
# Batch: 20, Loss: 0.10449636727571487
# Batch: 40, Loss: 0.061721496284008026
# Batch: 60, Loss: 0.03546762093901634
# Batch: 80, Loss: 0.07160421460866928
# Batch: 100, Loss: 0.041371122002601624
# Batch: 120, Loss: 0.08020436763763428
# Batch: 140, Loss: 0.047606147825717926
# Batch: 160, Loss: 0.06037423759698868
# Batch: 180, Loss: 0.05669529736042023
# Batch: 200, Loss: 0.015753377228975296
#
# Average loss: 0.0739, Accuracy: 26908.0/27537 (98%)
#
#
# Average loss: 0.0937, Accuracy: 2963.0/3059 (97%)
#
# Epoch: 15 	Training Accuracy: 97.72%
# Validation Accuracy: 96.86%
# Batch: 0, Loss: 0.10268046706914902
# Batch: 20, Loss: 0.05661638453602791
# Batch: 40, Loss: 0.07588513940572739
# Batch: 60, Loss: 0.25221526622772217
# Batch: 80, Loss: 0.03917127475142479
# Batch: 100, Loss: 0.02932721935212612
# Batch: 120, Loss: 0.16506946086883545
# Batch: 140, Loss: 0.07755143940448761
# Batch: 160, Loss: 0.08415211737155914
# Batch: 180, Loss: 0.10273364186286926
# Batch: 200, Loss: 0.09331154823303223
#
# Average loss: 0.0646, Accuracy: 26987.0/27537 (98%)
#
#
# Average loss: 0.0834, Accuracy: 2974.0/3059 (97%)
#
# Epoch: 16 	Training Accuracy: 98.00%
# Validation Accuracy: 97.22%
# Batch: 0, Loss: 0.09481805562973022
# Batch: 20, Loss: 0.02938593178987503
# Batch: 40, Loss: 0.20047613978385925
# Batch: 60, Loss: 0.011157292872667313
# Batch: 80, Loss: 0.07245291769504547
# Batch: 100, Loss: 0.0588558092713356
# Batch: 120, Loss: 0.11203721165657043
# Batch: 140, Loss: 0.05924011394381523
# Batch: 160, Loss: 0.15193378925323486
# Batch: 180, Loss: 0.09300035983324051
# Batch: 200, Loss: 0.05482639744877815
#
# Average loss: 0.0610, Accuracy: 27030.0/27537 (98%)
#
#
# Average loss: 0.0780, Accuracy: 2974.0/3059 (97%)
#
# Epoch: 17 	Training Accuracy: 98.16%
# Validation Accuracy: 97.22%
# Batch: 0, Loss: 0.028893791139125824
# Batch: 20, Loss: 0.07209312915802002
# Batch: 40, Loss: 0.10151359438896179
# Batch: 60, Loss: 0.0873912051320076
# Batch: 80, Loss: 0.0646636039018631
# Batch: 100, Loss: 0.017068402841687202
# Batch: 120, Loss: 0.07602889835834503
# Batch: 140, Loss: 0.08499349653720856
# Batch: 160, Loss: 0.11083859205245972
# Batch: 180, Loss: 0.01767374388873577
# Batch: 200, Loss: 0.08444075286388397
#
# Average loss: 0.0608, Accuracy: 27021.0/27537 (98%)
#
#
# Average loss: 0.0781, Accuracy: 2979.0/3059 (97%)
#
# Epoch: 18 	Training Accuracy: 98.13%
# Validation Accuracy: 97.38%
# Batch: 0, Loss: 0.06263630837202072
# Batch: 20, Loss: 0.024966400116682053
# Batch: 40, Loss: 0.07475155591964722
# Batch: 60, Loss: 0.08899969607591629
# Batch: 80, Loss: 0.04566952586174011
# Batch: 100, Loss: 0.03720123693346977
# Batch: 120, Loss: 0.014478807337582111
# Batch: 140, Loss: 0.08775283396244049
# Batch: 160, Loss: 0.06971143186092377
# Batch: 180, Loss: 0.0697958767414093
# Batch: 200, Loss: 0.02310834266245365
#
# Average loss: 0.0587, Accuracy: 27033.0/27537 (98%)
#
#
# Average loss: 0.0757, Accuracy: 2979.0/3059 (97%)
#
# Epoch: 19 	Training Accuracy: 98.17%
# Validation Accuracy: 97.38%
#
# Average loss: 0.0587, Accuracy: 27033.0/27537 (98%)
#
#
# Average loss: 0.0509, Accuracy: 5060.0/5139 (98%)
#
# Final Training Accuracy: 0.9817
# Final Test Accuracy: 0.9846

# %%
accuracy = eval(model, device, dataloader_wrapped.test_loader, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
# Out:
# Average loss: 0.0509, Accuracy: 5060.0/5139 (98%)

# %%
def effective_rank(singular_values):
    normalized_singular_values = singular_values / np.sum(singular_values)
    entropy = -np.sum(normalized_singular_values * np.log(normalized_singular_values))
    eff_rank = np.exp(entropy)
    return eff_rank

def plot_layer_effective_ranks(model, print_ranks=True):
    effective_ranks = []
    layer_names = []

    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            singular_values = np.linalg.svd(weight_matrix, compute_uv=False)
            eff_rank = effective_rank(singular_values)
            effective_ranks.append(eff_rank)
            layer_names.append(name)

    if print_ranks:
        for layer_name, eff_rank in zip(layer_names, effective_ranks):
            print(f'{layer_name}: {eff_rank:.4f}')

    # Plotting
    plt.figure(figsize=(15, 5))
    plt.bar(layer_names, effective_ranks, color='green')
    plt.xlabel('Layer')
    plt.ylabel('Effective Rank')
    plt.title('Effective Rank of Weight Matrices for Each Layer')
    plt.grid(True)

    y_max = np.max(effective_ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(effective_ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(0, int(y_max)+2, step=2))  # Set yticks

    plt.show()

# Example usage
plot_layer_effective_ranks(model)  # Note: You'll need to define or load 'model' before calling this function
# Out:
# conv0.weight: 3.5016
# conv1.weight: 4.0647
# fc_1.weight: 75.4789
# fc_2.weight: 8.6079

# %% [markdown]
# ----

# %% [markdown]
# # Finetuning experiments

# %%
dataloader_wrapped.update_phase('finetune')

a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        print('-------------')
        break
# Out:
# -------------

# %% [markdown]
# ## Baseline model: end2end with the same architecture as the preatining model

# %%
# 2. Create a new model and copy weights from the original model, then adjust the final layer
print("Current dataloader phase: ", dataloader_wrapped.get_current_phase())

model_finetuning_baseline = generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
model_finetuning_baseline.to(device)

# dataloader_wrapped.update_phase('finetune')
# Train and evaluate the new model on the new data
# train_acc_new, test_acc_new, model_finetuning_baseline, _,_ = compute_training_acc_epochs_cnn(model_finetuning_baseline, dataloader_wrapped, params, debug=True)

trainer = Trainer(model, dataloader_wrapped, params)
train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
print(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")
# Out:
# Current dataloader phase:  finetune
# Batch: 0, Loss: 7.026913642883301
# Batch: 20, Loss: 2.1879594326019287
# Batch: 40, Loss: 1.0139694213867188
# Batch: 60, Loss: 0.9219241738319397
# Batch: 80, Loss: 0.8095496296882629
# Batch: 100, Loss: 0.6548382043838501
# Batch: 120, Loss: 0.41667303442955017
# Batch: 140, Loss: 0.4559692442417145
# Batch: 160, Loss: 0.5858278870582581
# Batch: 180, Loss: 0.5162555575370789
# Batch: 200, Loss: 0.26906803250312805
#
# Average loss: 0.3755, Accuracy: 23116.0/26464 (87%)
#
#
# Average loss: 0.3872, Accuracy: 2566.0/2940 (87%)
#
# Epoch: 0 	Training Accuracy: 87.35%
# Validation Accuracy: 87.28%
# Batch: 0, Loss: 0.30405551195144653
# Batch: 20, Loss: 0.3087233006954193
# Batch: 40, Loss: 0.25764238834381104
# Batch: 60, Loss: 0.4023982584476471
# Batch: 80, Loss: 0.2617571949958801
# Batch: 100, Loss: 0.27800893783569336
# Batch: 120, Loss: 0.21572662889957428
# Batch: 140, Loss: 0.23542916774749756
# Batch: 160, Loss: 0.25810080766677856
# Batch: 180, Loss: 0.265517920255661
# Batch: 200, Loss: 0.20391631126403809
#
# Average loss: 0.2352, Accuracy: 24437.0/26464 (92%)
#
#
# Average loss: 0.2500, Accuracy: 2708.0/2940 (92%)
#
# Epoch: 1 	Training Accuracy: 92.34%
# Validation Accuracy: 92.11%
# Batch: 0, Loss: 0.15962377190589905
# Batch: 20, Loss: 0.20747116208076477
# Batch: 40, Loss: 0.21435274183750153
# Batch: 60, Loss: 0.18685226142406464
# Batch: 80, Loss: 0.1649162322282791
# Batch: 100, Loss: 0.22315151989459991
# Batch: 120, Loss: 0.11270815879106522
# Batch: 140, Loss: 0.17181091010570526
# Batch: 160, Loss: 0.23470979928970337
# Batch: 180, Loss: 0.13421976566314697
# Batch: 200, Loss: 0.18493245542049408
#
# Average loss: 0.1931, Accuracy: 24794.0/26464 (94%)
#
#
# Average loss: 0.2102, Accuracy: 2739.0/2940 (93%)
#
# Epoch: 2 	Training Accuracy: 93.69%
# Validation Accuracy: 93.16%
# Batch: 0, Loss: 0.240094855427742
# Batch: 20, Loss: 0.21896275877952576
# Batch: 40, Loss: 0.19670432806015015
# Batch: 60, Loss: 0.10547801107168198
# Batch: 80, Loss: 0.23170167207717896
# Batch: 100, Loss: 0.14455491304397583
# Batch: 120, Loss: 0.14031130075454712
# Batch: 140, Loss: 0.19912941753864288
# Batch: 160, Loss: 0.23252947628498077
# Batch: 180, Loss: 0.1767311543226242
# Batch: 200, Loss: 0.16813217103481293
#
# Average loss: 0.1692, Accuracy: 24961.0/26464 (94%)
#
#
# Average loss: 0.1899, Accuracy: 2763.0/2940 (94%)
#
# Epoch: 3 	Training Accuracy: 94.32%
# Validation Accuracy: 93.98%
# Batch: 0, Loss: 0.17950905859470367
# Batch: 20, Loss: 0.18348382413387299
# Batch: 40, Loss: 0.07681814581155777
# Batch: 60, Loss: 0.1704682856798172
# Batch: 80, Loss: 0.17845013737678528
# Batch: 100, Loss: 0.2100292444229126
# Batch: 120, Loss: 0.14597506821155548
# Batch: 140, Loss: 0.27759838104248047
# Batch: 160, Loss: 0.1644452065229416
# Batch: 180, Loss: 0.07998517155647278
# Batch: 200, Loss: 0.13907797634601593
#
# Average loss: 0.1539, Accuracy: 25082.0/26464 (95%)
#
#
# Average loss: 0.1742, Accuracy: 2771.0/2940 (94%)
#
# Epoch: 4 	Training Accuracy: 94.78%
# Validation Accuracy: 94.25%
# Batch: 0, Loss: 0.1980673223733902
# Batch: 20, Loss: 0.23961415886878967
# Batch: 40, Loss: 0.13137473165988922
# Batch: 60, Loss: 0.15346015989780426
# Batch: 80, Loss: 0.15961101651191711
# Batch: 100, Loss: 0.1365361213684082
# Batch: 120, Loss: 0.17328225076198578
# Batch: 140, Loss: 0.16051624715328217
# Batch: 160, Loss: 0.10550890117883682
# Batch: 180, Loss: 0.19360686838626862
# Batch: 200, Loss: 0.2021147608757019
#
# Average loss: 0.1473, Accuracy: 25102.0/26464 (95%)
#
#
# Average loss: 0.1697, Accuracy: 2779.0/2940 (95%)
#
# Epoch: 5 	Training Accuracy: 94.85%
# Validation Accuracy: 94.52%
# Batch: 0, Loss: 0.09186853468418121
# Batch: 20, Loss: 0.14268632233142853
# Batch: 40, Loss: 0.13476108014583588
# Batch: 60, Loss: 0.11816353350877762
# Batch: 80, Loss: 0.1442863643169403
# Batch: 100, Loss: 0.1415693312883377
# Batch: 120, Loss: 0.15384729206562042
# Batch: 140, Loss: 0.2690386474132538
# Batch: 160, Loss: 0.21848870813846588
# Batch: 180, Loss: 0.19435851275920868
# Batch: 200, Loss: 0.06529994308948517
#
# Average loss: 0.1437, Accuracy: 25148.0/26464 (95%)
#
#
# Average loss: 0.1716, Accuracy: 2783.0/2940 (95%)
#
# Epoch: 6 	Training Accuracy: 95.03%
# Validation Accuracy: 94.66%
# Batch: 0, Loss: 0.07094582170248032
# Batch: 20, Loss: 0.17287147045135498
# Batch: 40, Loss: 0.11473909765481949
# Batch: 60, Loss: 0.14491596817970276
# Batch: 80, Loss: 0.17449899017810822
# Batch: 100, Loss: 0.23724159598350525
# Batch: 120, Loss: 0.14999662339687347
# Batch: 140, Loss: 0.09192141890525818
# Batch: 160, Loss: 0.16299200057983398
# Batch: 180, Loss: 0.13878904283046722
# Batch: 200, Loss: 0.1285845786333084
#
# Average loss: 0.1373, Accuracy: 25211.0/26464 (95%)
#
#
# Average loss: 0.1628, Accuracy: 2781.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 95.27%
# Validation Accuracy: 94.59%
# Batch: 0, Loss: 0.16424515843391418
# Batch: 20, Loss: 0.1981862634420395
# Batch: 40, Loss: 0.09875403344631195
# Batch: 60, Loss: 0.14563848078250885
# Batch: 80, Loss: 0.11432518064975739
# Batch: 100, Loss: 0.25809553265571594
# Batch: 120, Loss: 0.10137876868247986
# Batch: 140, Loss: 0.11766886711120605
# Batch: 160, Loss: 0.17839299142360687
# Batch: 180, Loss: 0.15922434628009796
# Batch: 200, Loss: 0.102325439453125
#
# Average loss: 0.1327, Accuracy: 25267.0/26464 (95%)
#
#
# Average loss: 0.1628, Accuracy: 2788.0/2940 (95%)
#
# Epoch: 8 	Training Accuracy: 95.48%
# Validation Accuracy: 94.83%
# Batch: 0, Loss: 0.1601434051990509
# Batch: 20, Loss: 0.12425451725721359
# Batch: 40, Loss: 0.15488336980342865
# Batch: 60, Loss: 0.09259849786758423
# Batch: 80, Loss: 0.1136707216501236
# Batch: 100, Loss: 0.14363230764865875
# Batch: 120, Loss: 0.1275189220905304
# Batch: 140, Loss: 0.14690162241458893
# Batch: 160, Loss: 0.11128762364387512
# Batch: 180, Loss: 0.15363624691963196
# Batch: 200, Loss: 0.13387788832187653
#
# Average loss: 0.1258, Accuracy: 25346.0/26464 (96%)
#
#
# Average loss: 0.1564, Accuracy: 2794.0/2940 (95%)
#
# Epoch: 9 	Training Accuracy: 95.78%
# Validation Accuracy: 95.03%
# Batch: 0, Loss: 0.22992175817489624
# Batch: 20, Loss: 0.1074146032333374
# Batch: 40, Loss: 0.11218471825122833
# Batch: 60, Loss: 0.12606850266456604
# Batch: 80, Loss: 0.16291993856430054
# Batch: 100, Loss: 0.14549176394939423
# Batch: 120, Loss: 0.24780184030532837
# Batch: 140, Loss: 0.1485559493303299
# Batch: 160, Loss: 0.07433262467384338
# Batch: 180, Loss: 0.17351122200489044
# Batch: 200, Loss: 0.09846542775630951
#
# Average loss: 0.1268, Accuracy: 25322.0/26464 (96%)
#
#
# Average loss: 0.1513, Accuracy: 2806.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 95.68%
# Validation Accuracy: 95.44%
# Batch: 0, Loss: 0.08063484728336334
# Batch: 20, Loss: 0.12765468657016754
# Batch: 40, Loss: 0.15321215987205505
# Batch: 60, Loss: 0.2168595790863037
# Batch: 80, Loss: 0.12763306498527527
# Batch: 100, Loss: 0.1773100048303604
# Batch: 120, Loss: 0.11066463589668274
# Batch: 140, Loss: 0.08515198528766632
# Batch: 160, Loss: 0.14841511845588684
# Batch: 180, Loss: 0.17765545845031738
# Batch: 200, Loss: 0.04530174285173416
#
# Average loss: 0.1278, Accuracy: 25313.0/26464 (96%)
#
#
# Average loss: 0.1596, Accuracy: 2791.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 95.65%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.1340968906879425
# Batch: 20, Loss: 0.12967827916145325
# Batch: 40, Loss: 0.055136874318122864
# Batch: 60, Loss: 0.15213648974895477
# Batch: 80, Loss: 0.20256736874580383
# Batch: 100, Loss: 0.15239909291267395
# Batch: 120, Loss: 0.2061372846364975
# Batch: 140, Loss: 0.1229582130908966
# Batch: 160, Loss: 0.13672983646392822
# Batch: 180, Loss: 0.20123326778411865
# Batch: 200, Loss: 0.07790450751781464
#
# Average loss: 0.1249, Accuracy: 25361.0/26464 (96%)
#
#
# Average loss: 0.1537, Accuracy: 2799.0/2940 (95%)
#
# Epoch: 12 	Training Accuracy: 95.83%
# Validation Accuracy: 95.20%
# Batch: 0, Loss: 0.1348424255847931
# Batch: 20, Loss: 0.1687707155942917
# Batch: 40, Loss: 0.08755910396575928
# Batch: 60, Loss: 0.1525661200284958
# Batch: 80, Loss: 0.15347883105278015
# Batch: 100, Loss: 0.0460800901055336
# Batch: 120, Loss: 0.2200668603181839
# Batch: 140, Loss: 0.12729905545711517
# Batch: 160, Loss: 0.1013188287615776
# Batch: 180, Loss: 0.13628004491329193
# Batch: 200, Loss: 0.10856274515390396
#
# Average loss: 0.1239, Accuracy: 25351.0/26464 (96%)
#
#
# Average loss: 0.1549, Accuracy: 2799.0/2940 (95%)
#
# Epoch: 13 	Training Accuracy: 95.79%
# Validation Accuracy: 95.20%
# Batch: 0, Loss: 0.14260798692703247
# Batch: 20, Loss: 0.06978942453861237
# Batch: 40, Loss: 0.24946074187755585
# Batch: 60, Loss: 0.1850208044052124
# Batch: 80, Loss: 0.1948302835226059
# Batch: 100, Loss: 0.128767192363739
# Batch: 120, Loss: 0.07504971325397491
# Batch: 140, Loss: 0.10961072891950607
# Batch: 160, Loss: 0.10476641356945038
# Batch: 180, Loss: 0.08957936614751816
# Batch: 200, Loss: 0.13797084987163544
#
# Average loss: 0.1175, Accuracy: 25411.0/26464 (96%)
#
#
# Average loss: 0.1458, Accuracy: 2805.0/2940 (95%)
#
# Epoch: 14 	Training Accuracy: 96.02%
# Validation Accuracy: 95.41%
# Batch: 0, Loss: 0.20480124652385712
# Batch: 20, Loss: 0.11172888427972794
# Batch: 40, Loss: 0.1606360375881195
# Batch: 60, Loss: 0.1644761562347412
# Batch: 80, Loss: 0.13894382119178772
# Batch: 100, Loss: 0.10649899393320084
# Batch: 120, Loss: 0.24451808631420135
# Batch: 140, Loss: 0.0775638148188591
# Batch: 160, Loss: 0.14366796612739563
# Batch: 180, Loss: 0.07535915076732635
# Batch: 200, Loss: 0.20131225883960724
#
# Average loss: 0.1155, Accuracy: 25438.0/26464 (96%)
#
#
# Average loss: 0.1436, Accuracy: 2807.0/2940 (95%)
#
# Epoch: 15 	Training Accuracy: 96.12%
# Validation Accuracy: 95.48%
# Batch: 0, Loss: 0.10852637887001038
# Batch: 20, Loss: 0.14154566824436188
# Batch: 40, Loss: 0.08848286420106888
# Batch: 60, Loss: 0.1362333595752716
# Batch: 80, Loss: 0.1081315279006958
# Batch: 100, Loss: 0.13821090757846832
# Batch: 120, Loss: 0.0849420428276062
# Batch: 140, Loss: 0.08923161774873734
# Batch: 160, Loss: 0.13108743727207184
# Batch: 180, Loss: 0.09560011327266693
# Batch: 200, Loss: 0.09221071749925613
#
# Average loss: 0.1152, Accuracy: 25405.0/26464 (96%)
#
#
# Average loss: 0.1398, Accuracy: 2808.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 96.00%
# Validation Accuracy: 95.51%
# Batch: 0, Loss: 0.09922610968351364
# Batch: 20, Loss: 0.15126267075538635
# Batch: 40, Loss: 0.17036911845207214
# Batch: 60, Loss: 0.11244663596153259
# Batch: 80, Loss: 0.22946318984031677
# Batch: 100, Loss: 0.11743829399347305
# Batch: 120, Loss: 0.178864985704422
# Batch: 140, Loss: 0.15674801170825958
# Batch: 160, Loss: 0.10768511146306992
# Batch: 180, Loss: 0.1992691606283188
# Batch: 200, Loss: 0.10682177543640137
#
# Average loss: 0.1173, Accuracy: 25411.0/26464 (96%)
#
#
# Average loss: 0.1497, Accuracy: 2808.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 96.02%
# Validation Accuracy: 95.51%
# Batch: 0, Loss: 0.07404735684394836
# Batch: 20, Loss: 0.10542798787355423
# Batch: 40, Loss: 0.08777284622192383
# Batch: 60, Loss: 0.14348845183849335
# Batch: 80, Loss: 0.04380781203508377
# Batch: 100, Loss: 0.15993089973926544
# Batch: 120, Loss: 0.15834274888038635
# Batch: 140, Loss: 0.08502547442913055
# Batch: 160, Loss: 0.09345834702253342
# Batch: 180, Loss: 0.07860098034143448
# Batch: 200, Loss: 0.20408648252487183
#
# Average loss: 0.1174, Accuracy: 25419.0/26464 (96%)
#
#
# Average loss: 0.1496, Accuracy: 2802.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 96.05%
# Validation Accuracy: 95.31%
# Batch: 0, Loss: 0.19049952924251556
# Batch: 20, Loss: 0.08925170451402664
# Batch: 40, Loss: 0.09835195541381836
# Batch: 60, Loss: 0.08213115483522415
# Batch: 80, Loss: 0.2667528986930847
# Batch: 100, Loss: 0.08730268478393555
# Batch: 120, Loss: 0.22149135172367096
# Batch: 140, Loss: 0.2951273024082184
# Batch: 160, Loss: 0.07766031473875046
# Batch: 180, Loss: 0.14707672595977783
# Batch: 200, Loss: 0.11831033229827881
#
# Average loss: 0.1223, Accuracy: 25364.0/26464 (96%)
#
#
# Average loss: 0.1479, Accuracy: 2803.0/2940 (95%)
#
# Epoch: 19 	Training Accuracy: 95.84%
# Validation Accuracy: 95.34%
#
# Average loss: 0.1223, Accuracy: 25364.0/26464 (96%)
#
#
# Average loss: 0.1326, Accuracy: 4652.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9584
# Final Test Accuracy (New Data): 0.9570

# %%
plot_layer_effective_ranks(model_finetuning_baseline)
# Out:
# conv0.weight: 3.8347
# conv1.weight: 4.5382
# fc_1.weight: 107.9744
# fc_2.weight: 4.9817

# %% [markdown]
# ***WITH BALANCED CLASSES***

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01]
percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]

seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test = {}
results_train = {}
best_models = {}
data_loaders = {}
epochs_taken = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Training with different data percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []

    for seed in tqdm(seed_set, desc=f'Training for data percentage: {perc}', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")
        
        model_new =  generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
        model_new.to(device)

        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)

        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        # Train and evaluate the new model on the new data
        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        # Add tqdm write method to prevent progress bar overlap
        tqdm.write(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
        tqdm.write(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test[perc] = test_accuracies
    results_train[perc] = train_accuracies
    epochs_taken[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Training with different data percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Training for data percentage: 0.01:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 60 =========================
# Batch: 0, Loss: 1.6152747869491577
#
# Average loss: 1.6120, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6125, Accuracy: 599.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6157612800598145
#
# Average loss: 1.6120, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6125, Accuracy: 599.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.609192132949829
#
# Average loss: 1.6120, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6124, Accuracy: 599.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6149650812149048
#
# Average loss: 1.6120, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6124, Accuracy: 599.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6110517978668213
#
# Average loss: 1.6120, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6124, Accuracy: 599.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6162196397781372
#
# Average loss: 1.6119, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6123, Accuracy: 599.0/2940 (20%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.612512230873108
#
# Average loss: 1.6119, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6123, Accuracy: 599.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Early stopping invoked.
#
# Average loss: 1.6120, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6144, Accuracy: 958.0/4861 (20%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.1971
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 1 =========================
# Batch: 0, Loss: 1.612808346748352
#
# Average loss: 1.6050, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.6025, Accuracy: 607.0/2940 (21%)
#
# Epoch: 0 	Training Accuracy: 20.38%
# Validation Accuracy: 20.65%
# Batch: 0, Loss: 1.6091012954711914
#
# Average loss: 1.6036, Accuracy: 60.0/260 (23%)
#
#
# Average loss: 1.6010, Accuracy: 702.0/2940 (24%)
#
# Epoch: 1 	Training Accuracy: 23.08%
# Validation Accuracy: 23.88%
# Batch: 0, Loss: 1.6068538427352905
#
# Average loss: 1.6025, Accuracy: 69.0/260 (27%)
#
#
# Average loss: 1.6001, Accuracy: 774.0/2940 (26%)
#
# Epoch: 2 	Training Accuracy: 26.54%
# Validation Accuracy: 26.33%
# Batch: 0, Loss: 1.6094624996185303
#
# Average loss: 1.6013, Accuracy: 75.0/260 (29%)
#
#
# Average loss: 1.5993, Accuracy: 847.0/2940 (29%)
#
# Epoch: 3 	Training Accuracy: 28.85%
# Validation Accuracy: 28.81%
# Batch: 0, Loss: 1.6030863523483276
#
# Average loss: 1.6001, Accuracy: 79.0/260 (30%)
#
#
# Average loss: 1.5985, Accuracy: 896.0/2940 (30%)
#
# Epoch: 4 	Training Accuracy: 30.38%
# Validation Accuracy: 30.48%
# Batch: 0, Loss: 1.594230055809021
#
# Average loss: 1.5992, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5978, Accuracy: 948.0/2940 (32%)
#
# Epoch: 5 	Training Accuracy: 32.31%
# Validation Accuracy: 32.24%
# Batch: 0, Loss: 1.5997133255004883
#
# Average loss: 1.5981, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5970, Accuracy: 960.0/2940 (33%)
#
# Epoch: 6 	Training Accuracy: 32.31%
# Validation Accuracy: 32.65%
# Batch: 0, Loss: 1.6030340194702148
#
# Average loss: 1.5971, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5963, Accuracy: 957.0/2940 (33%)
#
# Epoch: 7 	Training Accuracy: 32.31%
# Validation Accuracy: 32.55%
# Batch: 0, Loss: 1.6010403633117676
#
# Average loss: 1.5962, Accuracy: 85.0/260 (33%)
#
#
# Average loss: 1.5957, Accuracy: 947.0/2940 (32%)
#
# Epoch: 8 	Training Accuracy: 32.69%
# Validation Accuracy: 32.21%
# Batch: 0, Loss: 1.5988363027572632
#
# Average loss: 1.5952, Accuracy: 87.0/260 (33%)
#
#
# Average loss: 1.5949, Accuracy: 1018.0/2940 (35%)
#
# Epoch: 9 	Training Accuracy: 33.46%
# Validation Accuracy: 34.63%
# Batch: 0, Loss: 1.594072937965393
#
# Average loss: 1.5942, Accuracy: 96.0/260 (37%)
#
#
# Average loss: 1.5943, Accuracy: 1090.0/2940 (37%)
#
# Epoch: 10 	Training Accuracy: 36.92%
# Validation Accuracy: 37.07%
# Batch: 0, Loss: 1.594242811203003
#
# Average loss: 1.5931, Accuracy: 101.0/260 (39%)
#
#
# Average loss: 1.5937, Accuracy: 1133.0/2940 (39%)
#
# Epoch: 11 	Training Accuracy: 38.85%
# Validation Accuracy: 38.54%
# Batch: 0, Loss: 1.5904992818832397
#
# Average loss: 1.5920, Accuracy: 105.0/260 (40%)
#
#
# Average loss: 1.5931, Accuracy: 1185.0/2940 (40%)
#
# Epoch: 12 	Training Accuracy: 40.38%
# Validation Accuracy: 40.31%
# Batch: 0, Loss: 1.5925958156585693
#
# Average loss: 1.5912, Accuracy: 103.0/260 (40%)
#
#
# Average loss: 1.5925, Accuracy: 1136.0/2940 (39%)
#
# Epoch: 13 	Training Accuracy: 39.62%
# Validation Accuracy: 38.64%
# Batch: 0, Loss: 1.5897294282913208
#
# Average loss: 1.5905, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.5919, Accuracy: 1020.0/2940 (35%)
#
# Epoch: 14 	Training Accuracy: 35.00%
# Validation Accuracy: 34.69%
# Batch: 0, Loss: 1.58838951587677
#
# Average loss: 1.5897, Accuracy: 87.0/260 (33%)
#
#
# Average loss: 1.5914, Accuracy: 957.0/2940 (33%)
#
# Epoch: 15 	Training Accuracy: 33.46%
# Validation Accuracy: 32.55%
# Batch: 0, Loss: 1.5908374786376953
#
# Average loss: 1.5887, Accuracy: 92.0/260 (35%)
#
#
# Average loss: 1.5909, Accuracy: 940.0/2940 (32%)
#
# Epoch: 16 	Training Accuracy: 35.38%
# Validation Accuracy: 31.97%
# Batch: 0, Loss: 1.5884531736373901
#
# Average loss: 1.5877, Accuracy: 90.0/260 (35%)
#
#
# Average loss: 1.5901, Accuracy: 971.0/2940 (33%)
#
# Epoch: 17 	Training Accuracy: 34.62%
# Validation Accuracy: 33.03%
# Batch: 0, Loss: 1.5884112119674683
#
# Average loss: 1.5865, Accuracy: 90.0/260 (35%)
#
#
# Average loss: 1.5892, Accuracy: 980.0/2940 (33%)
#
# Epoch: 18 	Training Accuracy: 34.62%
# Validation Accuracy: 33.33%
# Early stopping invoked.
#
# Average loss: 1.5920, Accuracy: 105.0/260 (40%)
#
#
# Average loss: 1.5918, Accuracy: 2032.0/4861 (42%)
#
# Final Training Accuracy (New Data): 0.4038
# Final Test Accuracy (New Data): 0.4180
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 84 =========================
# Batch: 0, Loss: 1.615952730178833
#
# Average loss: 1.6121, Accuracy: 61.0/260 (23%)
#
#
# Average loss: 1.6097, Accuracy: 695.0/2940 (24%)
#
# Epoch: 0 	Training Accuracy: 23.46%
# Validation Accuracy: 23.64%
# Batch: 0, Loss: 1.6057419776916504
#
# Average loss: 1.6123, Accuracy: 55.0/260 (21%)
#
#
# Average loss: 1.6102, Accuracy: 582.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 21.15%
# Validation Accuracy: 19.80%
# Batch: 0, Loss: 1.6215769052505493
#
# Average loss: 1.6124, Accuracy: 55.0/260 (21%)
#
#
# Average loss: 1.6101, Accuracy: 602.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 21.15%
# Validation Accuracy: 20.48%
# Batch: 0, Loss: 1.6113439798355103
#
# Average loss: 1.6123, Accuracy: 67.0/260 (26%)
#
#
# Average loss: 1.6095, Accuracy: 742.0/2940 (25%)
#
# Epoch: 3 	Training Accuracy: 25.77%
# Validation Accuracy: 25.24%
# Batch: 0, Loss: 1.609537959098816
#
# Average loss: 1.6118, Accuracy: 54.0/260 (21%)
#
#
# Average loss: 1.6090, Accuracy: 681.0/2940 (23%)
#
# Epoch: 4 	Training Accuracy: 20.77%
# Validation Accuracy: 23.16%
# Batch: 0, Loss: 1.6155606508255005
#
# Average loss: 1.6114, Accuracy: 47.0/260 (18%)
#
#
# Average loss: 1.6086, Accuracy: 658.0/2940 (22%)
#
# Epoch: 5 	Training Accuracy: 18.08%
# Validation Accuracy: 22.38%
# Batch: 0, Loss: 1.6064833402633667
#
# Average loss: 1.6110, Accuracy: 47.0/260 (18%)
#
#
# Average loss: 1.6083, Accuracy: 661.0/2940 (22%)
#
# Epoch: 6 	Training Accuracy: 18.08%
# Validation Accuracy: 22.48%
# Batch: 0, Loss: 1.611234188079834
#
# Average loss: 1.6108, Accuracy: 48.0/260 (18%)
#
#
# Average loss: 1.6081, Accuracy: 664.0/2940 (23%)
#
# Epoch: 7 	Training Accuracy: 18.46%
# Validation Accuracy: 22.59%
# Batch: 0, Loss: 1.6161469221115112
#
# Average loss: 1.6104, Accuracy: 47.0/260 (18%)
#
#
# Average loss: 1.6078, Accuracy: 665.0/2940 (23%)
#
# Epoch: 8 	Training Accuracy: 18.08%
# Validation Accuracy: 22.62%
# Batch: 0, Loss: 1.6104228496551514
#
# Average loss: 1.6101, Accuracy: 49.0/260 (19%)
#
#
# Average loss: 1.6075, Accuracy: 665.0/2940 (23%)
#
# Epoch: 9 	Training Accuracy: 18.85%
# Validation Accuracy: 22.62%
# Early stopping invoked.
#
# Average loss: 1.6123, Accuracy: 67.0/260 (26%)
#
#
# Average loss: 1.6117, Accuracy: 1133.0/4861 (23%)
#
# Final Training Accuracy (New Data): 0.2577
# Final Test Accuracy (New Data): 0.2331
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 74 =========================
# Batch: 0, Loss: 1.6145062446594238
#
# Average loss: 1.6100, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6092, Accuracy: 658.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 22.38%
# Batch: 0, Loss: 1.6094692945480347
#
# Average loss: 1.6099, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6092, Accuracy: 657.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 22.35%
# Batch: 0, Loss: 1.6114782094955444
#
# Average loss: 1.6098, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6091, Accuracy: 656.0/2940 (22%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 22.31%
# Batch: 0, Loss: 1.6123104095458984
#
# Average loss: 1.6097, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6090, Accuracy: 657.0/2940 (22%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 22.35%
# Batch: 0, Loss: 1.6045763492584229
#
# Average loss: 1.6095, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6089, Accuracy: 658.0/2940 (22%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 22.38%
# Batch: 0, Loss: 1.6118625402450562
#
# Average loss: 1.6094, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6088, Accuracy: 659.0/2940 (22%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 22.41%
# Batch: 0, Loss: 1.6083147525787354
#
# Average loss: 1.6093, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6087, Accuracy: 660.0/2940 (22%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 22.45%
# Batch: 0, Loss: 1.6104929447174072
#
# Average loss: 1.6091, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6085, Accuracy: 660.0/2940 (22%)
#
# Epoch: 7 	Training Accuracy: 20.00%
# Validation Accuracy: 22.45%
# Batch: 0, Loss: 1.6098966598510742
#
# Average loss: 1.6089, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6084, Accuracy: 663.0/2940 (23%)
#
# Epoch: 8 	Training Accuracy: 20.00%
# Validation Accuracy: 22.55%
# Batch: 0, Loss: 1.6151783466339111
#
# Average loss: 1.6087, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6082, Accuracy: 665.0/2940 (23%)
#
# Epoch: 9 	Training Accuracy: 20.00%
# Validation Accuracy: 22.62%
# Batch: 0, Loss: 1.612136721611023
#
# Average loss: 1.6085, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.6080, Accuracy: 670.0/2940 (23%)
#
# Epoch: 10 	Training Accuracy: 20.38%
# Validation Accuracy: 22.79%
# Batch: 0, Loss: 1.6092437505722046
#
# Average loss: 1.6083, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.6079, Accuracy: 675.0/2940 (23%)
#
# Epoch: 11 	Training Accuracy: 20.38%
# Validation Accuracy: 22.96%
# Batch: 0, Loss: 1.6065245866775513
#
# Average loss: 1.6081, Accuracy: 55.0/260 (21%)
#
#
# Average loss: 1.6077, Accuracy: 685.0/2940 (23%)
#
# Epoch: 12 	Training Accuracy: 21.15%
# Validation Accuracy: 23.30%
# Batch: 0, Loss: 1.6086575984954834
#
# Average loss: 1.6078, Accuracy: 57.0/260 (22%)
#
#
# Average loss: 1.6074, Accuracy: 696.0/2940 (24%)
#
# Epoch: 13 	Training Accuracy: 21.92%
# Validation Accuracy: 23.67%
# Batch: 0, Loss: 1.6074316501617432
#
# Average loss: 1.6075, Accuracy: 57.0/260 (22%)
#
#
# Average loss: 1.6072, Accuracy: 701.0/2940 (24%)
#
# Epoch: 14 	Training Accuracy: 21.92%
# Validation Accuracy: 23.84%
# Batch: 0, Loss: 1.608500361442566
#
# Average loss: 1.6072, Accuracy: 57.0/260 (22%)
#
#
# Average loss: 1.6069, Accuracy: 699.0/2940 (24%)
#
# Epoch: 15 	Training Accuracy: 21.92%
# Validation Accuracy: 23.78%
# Batch: 0, Loss: 1.6018341779708862
#
# Average loss: 1.6068, Accuracy: 57.0/260 (22%)
#
#
# Average loss: 1.6066, Accuracy: 701.0/2940 (24%)
#
# Epoch: 16 	Training Accuracy: 21.92%
# Validation Accuracy: 23.84%
# Batch: 0, Loss: 1.605013370513916
#
# Average loss: 1.6064, Accuracy: 60.0/260 (23%)
#
#
# Average loss: 1.6062, Accuracy: 713.0/2940 (24%)
#
# Epoch: 17 	Training Accuracy: 23.08%
# Validation Accuracy: 24.25%
# Batch: 0, Loss: 1.6065305471420288
#
# Average loss: 1.6058, Accuracy: 62.0/260 (24%)
#
#
# Average loss: 1.6057, Accuracy: 733.0/2940 (25%)
#
# Epoch: 18 	Training Accuracy: 23.85%
# Validation Accuracy: 24.93%
# Batch: 0, Loss: 1.6061522960662842
#
# Average loss: 1.6052, Accuracy: 66.0/260 (25%)
#
#
# Average loss: 1.6051, Accuracy: 753.0/2940 (26%)
#
# Epoch: 19 	Training Accuracy: 25.38%
# Validation Accuracy: 25.61%
#
# Average loss: 1.6052, Accuracy: 66.0/260 (25%)
#
#
# Average loss: 1.6059, Accuracy: 1172.0/4861 (24%)
#
# Final Training Accuracy (New Data): 0.2538
# Final Test Accuracy (New Data): 0.2411
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 22 =========================
# Batch: 0, Loss: 1.6201728582382202
#
# Average loss: 1.6111, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6153, Accuracy: 551.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6129521131515503
#
# Average loss: 1.6111, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6150, Accuracy: 551.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6108739376068115
#
# Average loss: 1.6107, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6142, Accuracy: 551.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6175799369812012
#
# Average loss: 1.6101, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6131, Accuracy: 551.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6113072633743286
#
# Average loss: 1.6097, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6125, Accuracy: 551.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6031596660614014
#
# Average loss: 1.6095, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6122, Accuracy: 551.0/2940 (19%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.604440450668335
#
# Average loss: 1.6092, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6117, Accuracy: 551.0/2940 (19%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Early stopping invoked.
#
# Average loss: 1.6111, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6153, Accuracy: 892.0/4861 (18%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.1835
# Training for data percentage: 0.03:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 7 =========================
# Batch: 0, Loss: 1.614740014076233
#
# Average loss: 1.6068, Accuracy: 182.0/790 (23%)
#
#
# Average loss: 1.6043, Accuracy: 781.0/2940 (27%)
#
# Epoch: 0 	Training Accuracy: 23.04%
# Validation Accuracy: 26.56%
# Batch: 0, Loss: 1.6105784177780151
#
# Average loss: 1.6021, Accuracy: 218.0/790 (28%)
#
#
# Average loss: 1.6001, Accuracy: 910.0/2940 (31%)
#
# Epoch: 1 	Training Accuracy: 27.59%
# Validation Accuracy: 30.95%
# Batch: 0, Loss: 1.6004588603973389
#
# Average loss: 1.5976, Accuracy: 279.0/790 (35%)
#
#
# Average loss: 1.5959, Accuracy: 1063.0/2940 (36%)
#
# Epoch: 2 	Training Accuracy: 35.32%
# Validation Accuracy: 36.16%
# Batch: 0, Loss: 1.594132423400879
#
# Average loss: 1.5930, Accuracy: 320.0/790 (41%)
#
#
# Average loss: 1.5914, Accuracy: 1272.0/2940 (43%)
#
# Epoch: 3 	Training Accuracy: 40.51%
# Validation Accuracy: 43.27%
# Batch: 0, Loss: 1.5902355909347534
#
# Average loss: 1.5884, Accuracy: 317.0/790 (40%)
#
#
# Average loss: 1.5865, Accuracy: 1233.0/2940 (42%)
#
# Epoch: 4 	Training Accuracy: 40.13%
# Validation Accuracy: 41.94%
# Batch: 0, Loss: 1.5889331102371216
#
# Average loss: 1.5831, Accuracy: 346.0/790 (44%)
#
#
# Average loss: 1.5812, Accuracy: 1352.0/2940 (46%)
#
# Epoch: 5 	Training Accuracy: 43.80%
# Validation Accuracy: 45.99%
# Batch: 0, Loss: 1.5811208486557007
#
# Average loss: 1.5774, Accuracy: 404.0/790 (51%)
#
#
# Average loss: 1.5756, Accuracy: 1548.0/2940 (53%)
#
# Epoch: 6 	Training Accuracy: 51.14%
# Validation Accuracy: 52.65%
# Batch: 0, Loss: 1.5763678550720215
#
# Average loss: 1.5713, Accuracy: 389.0/790 (49%)
#
#
# Average loss: 1.5692, Accuracy: 1495.0/2940 (51%)
#
# Epoch: 7 	Training Accuracy: 49.24%
# Validation Accuracy: 50.85%
# Batch: 0, Loss: 1.567030668258667
#
# Average loss: 1.5646, Accuracy: 450.0/790 (57%)
#
#
# Average loss: 1.5627, Accuracy: 1692.0/2940 (58%)
#
# Epoch: 8 	Training Accuracy: 56.96%
# Validation Accuracy: 57.55%
# Batch: 0, Loss: 1.5623661279678345
#
# Average loss: 1.5574, Accuracy: 517.0/790 (65%)
#
#
# Average loss: 1.5558, Accuracy: 1919.0/2940 (65%)
#
# Epoch: 9 	Training Accuracy: 65.44%
# Validation Accuracy: 65.27%
# Batch: 0, Loss: 1.558490514755249
#
# Average loss: 1.5496, Accuracy: 544.0/790 (69%)
#
#
# Average loss: 1.5483, Accuracy: 1997.0/2940 (68%)
#
# Epoch: 10 	Training Accuracy: 68.86%
# Validation Accuracy: 67.93%
# Batch: 0, Loss: 1.5450561046600342
#
# Average loss: 1.5410, Accuracy: 550.0/790 (70%)
#
#
# Average loss: 1.5398, Accuracy: 2010.0/2940 (68%)
#
# Epoch: 11 	Training Accuracy: 69.62%
# Validation Accuracy: 68.37%
# Batch: 0, Loss: 1.531280279159546
#
# Average loss: 1.5318, Accuracy: 565.0/790 (72%)
#
#
# Average loss: 1.5306, Accuracy: 2060.0/2940 (70%)
#
# Epoch: 12 	Training Accuracy: 71.52%
# Validation Accuracy: 70.07%
# Batch: 0, Loss: 1.5353965759277344
#
# Average loss: 1.5219, Accuracy: 579.0/790 (73%)
#
#
# Average loss: 1.5204, Accuracy: 2110.0/2940 (72%)
#
# Epoch: 13 	Training Accuracy: 73.29%
# Validation Accuracy: 71.77%
# Batch: 0, Loss: 1.5127816200256348
#
# Average loss: 1.5114, Accuracy: 572.0/790 (72%)
#
#
# Average loss: 1.5097, Accuracy: 2126.0/2940 (72%)
#
# Epoch: 14 	Training Accuracy: 72.41%
# Validation Accuracy: 72.31%
# Batch: 0, Loss: 1.5080060958862305
#
# Average loss: 1.4998, Accuracy: 579.0/790 (73%)
#
#
# Average loss: 1.4977, Accuracy: 2096.0/2940 (71%)
#
# Epoch: 15 	Training Accuracy: 73.29%
# Validation Accuracy: 71.29%
# Batch: 0, Loss: 1.5023638010025024
#
# Average loss: 1.4876, Accuracy: 608.0/790 (77%)
#
#
# Average loss: 1.4858, Accuracy: 2185.0/2940 (74%)
#
# Epoch: 16 	Training Accuracy: 76.96%
# Validation Accuracy: 74.32%
# Batch: 0, Loss: 1.4927186965942383
#
# Average loss: 1.4747, Accuracy: 623.0/790 (79%)
#
#
# Average loss: 1.4733, Accuracy: 2221.0/2940 (76%)
#
# Epoch: 17 	Training Accuracy: 78.86%
# Validation Accuracy: 75.54%
# Batch: 0, Loss: 1.4687532186508179
#
# Average loss: 1.4608, Accuracy: 634.0/790 (80%)
#
#
# Average loss: 1.4603, Accuracy: 2265.0/2940 (77%)
#
# Epoch: 18 	Training Accuracy: 80.25%
# Validation Accuracy: 77.04%
# Batch: 0, Loss: 1.4556031227111816
#
# Average loss: 1.4457, Accuracy: 637.0/790 (81%)
#
#
# Average loss: 1.4457, Accuracy: 2290.0/2940 (78%)
#
# Epoch: 19 	Training Accuracy: 80.63%
# Validation Accuracy: 77.89%
#
# Average loss: 1.4457, Accuracy: 637.0/790 (81%)
#
#
# Average loss: 1.4457, Accuracy: 3810.0/4861 (78%)
#
# Final Training Accuracy (New Data): 0.8063
# Final Test Accuracy (New Data): 0.7838
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 91 =========================
# Batch: 0, Loss: 1.6189947128295898
#
# Average loss: 1.6116, Accuracy: 156.0/790 (20%)
#
#
# Average loss: 1.6087, Accuracy: 554.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 19.75%
# Validation Accuracy: 18.84%
# Batch: 0, Loss: 1.6047028303146362
#
# Average loss: 1.6094, Accuracy: 199.0/790 (25%)
#
#
# Average loss: 1.6067, Accuracy: 730.0/2940 (25%)
#
# Epoch: 1 	Training Accuracy: 25.19%
# Validation Accuracy: 24.83%
# Batch: 0, Loss: 1.6119240522384644
#
# Average loss: 1.6070, Accuracy: 225.0/790 (28%)
#
#
# Average loss: 1.6046, Accuracy: 856.0/2940 (29%)
#
# Epoch: 2 	Training Accuracy: 28.48%
# Validation Accuracy: 29.12%
# Batch: 0, Loss: 1.615663766860962
#
# Average loss: 1.6041, Accuracy: 259.0/790 (33%)
#
#
# Average loss: 1.6020, Accuracy: 977.0/2940 (33%)
#
# Epoch: 3 	Training Accuracy: 32.78%
# Validation Accuracy: 33.23%
# Batch: 0, Loss: 1.6041229963302612
#
# Average loss: 1.6005, Accuracy: 276.0/790 (35%)
#
#
# Average loss: 1.5988, Accuracy: 1064.0/2940 (36%)
#
# Epoch: 4 	Training Accuracy: 34.94%
# Validation Accuracy: 36.19%
# Batch: 0, Loss: 1.6055852174758911
#
# Average loss: 1.5962, Accuracy: 287.0/790 (36%)
#
#
# Average loss: 1.5949, Accuracy: 1121.0/2940 (38%)
#
# Epoch: 5 	Training Accuracy: 36.33%
# Validation Accuracy: 38.13%
# Batch: 0, Loss: 1.6052320003509521
#
# Average loss: 1.5912, Accuracy: 290.0/790 (37%)
#
#
# Average loss: 1.5902, Accuracy: 1155.0/2940 (39%)
#
# Epoch: 6 	Training Accuracy: 36.71%
# Validation Accuracy: 39.29%
# Batch: 0, Loss: 1.5841646194458008
#
# Average loss: 1.5852, Accuracy: 296.0/790 (37%)
#
#
# Average loss: 1.5847, Accuracy: 1171.0/2940 (40%)
#
# Epoch: 7 	Training Accuracy: 37.47%
# Validation Accuracy: 39.83%
# Batch: 0, Loss: 1.5833775997161865
#
# Average loss: 1.5785, Accuracy: 300.0/790 (38%)
#
#
# Average loss: 1.5785, Accuracy: 1194.0/2940 (41%)
#
# Epoch: 8 	Training Accuracy: 37.97%
# Validation Accuracy: 40.61%
# Batch: 0, Loss: 1.5749359130859375
#
# Average loss: 1.5712, Accuracy: 315.0/790 (40%)
#
#
# Average loss: 1.5716, Accuracy: 1240.0/2940 (42%)
#
# Epoch: 9 	Training Accuracy: 39.87%
# Validation Accuracy: 42.18%
# Batch: 0, Loss: 1.5698645114898682
#
# Average loss: 1.5630, Accuracy: 328.0/790 (42%)
#
#
# Average loss: 1.5639, Accuracy: 1297.0/2940 (44%)
#
# Epoch: 10 	Training Accuracy: 41.52%
# Validation Accuracy: 44.12%
# Batch: 0, Loss: 1.555405855178833
#
# Average loss: 1.5540, Accuracy: 340.0/790 (43%)
#
#
# Average loss: 1.5553, Accuracy: 1356.0/2940 (46%)
#
# Epoch: 11 	Training Accuracy: 43.04%
# Validation Accuracy: 46.12%
# Batch: 0, Loss: 1.5492732524871826
#
# Average loss: 1.5440, Accuracy: 380.0/790 (48%)
#
#
# Average loss: 1.5457, Accuracy: 1456.0/2940 (50%)
#
# Epoch: 12 	Training Accuracy: 48.10%
# Validation Accuracy: 49.52%
# Batch: 0, Loss: 1.5544861555099487
#
# Average loss: 1.5331, Accuracy: 442.0/790 (56%)
#
#
# Average loss: 1.5352, Accuracy: 1609.0/2940 (55%)
#
# Epoch: 13 	Training Accuracy: 55.95%
# Validation Accuracy: 54.73%
# Batch: 0, Loss: 1.540184497833252
#
# Average loss: 1.5211, Accuracy: 450.0/790 (57%)
#
#
# Average loss: 1.5235, Accuracy: 1645.0/2940 (56%)
#
# Epoch: 14 	Training Accuracy: 56.96%
# Validation Accuracy: 55.95%
# Batch: 0, Loss: 1.518298864364624
#
# Average loss: 1.5075, Accuracy: 486.0/790 (62%)
#
#
# Average loss: 1.5104, Accuracy: 1765.0/2940 (60%)
#
# Epoch: 15 	Training Accuracy: 61.52%
# Validation Accuracy: 60.03%
# Batch: 0, Loss: 1.5106556415557861
#
# Average loss: 1.4926, Accuracy: 530.0/790 (67%)
#
#
# Average loss: 1.4961, Accuracy: 1911.0/2940 (65%)
#
# Epoch: 16 	Training Accuracy: 67.09%
# Validation Accuracy: 65.00%
# Batch: 0, Loss: 1.4992679357528687
#
# Average loss: 1.4763, Accuracy: 568.0/790 (72%)
#
#
# Average loss: 1.4803, Accuracy: 2073.0/2940 (71%)
#
# Epoch: 17 	Training Accuracy: 71.90%
# Validation Accuracy: 70.51%
# Batch: 0, Loss: 1.4720131158828735
#
# Average loss: 1.4587, Accuracy: 603.0/790 (76%)
#
#
# Average loss: 1.4635, Accuracy: 2156.0/2940 (73%)
#
# Epoch: 18 	Training Accuracy: 76.33%
# Validation Accuracy: 73.33%
# Batch: 0, Loss: 1.465472936630249
#
# Average loss: 1.4399, Accuracy: 621.0/790 (79%)
#
#
# Average loss: 1.4457, Accuracy: 2189.0/2940 (74%)
#
# Epoch: 19 	Training Accuracy: 78.61%
# Validation Accuracy: 74.46%
#
# Average loss: 1.4399, Accuracy: 621.0/790 (79%)
#
#
# Average loss: 1.4503, Accuracy: 3649.0/4861 (75%)
#
# Final Training Accuracy (New Data): 0.7861
# Final Test Accuracy (New Data): 0.7507
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 96 =========================
# Batch: 0, Loss: 1.6066089868545532
#
# Average loss: 1.6105, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6086, Accuracy: 599.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.607717752456665
#
# Average loss: 1.6104, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6086, Accuracy: 599.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6147363185882568
#
# Average loss: 1.6104, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6087, Accuracy: 599.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.610691785812378
#
# Average loss: 1.6103, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6087, Accuracy: 599.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.615450143814087
#
# Average loss: 1.6102, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6087, Accuracy: 599.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6097934246063232
#
# Average loss: 1.6102, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6087, Accuracy: 599.0/2940 (20%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6165910959243774
#
# Average loss: 1.6101, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6087, Accuracy: 599.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Early stopping invoked.
#
# Average loss: 1.6105, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6105, Accuracy: 958.0/4861 (20%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.1971
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 6 =========================
# Batch: 0, Loss: 1.6060080528259277
#
# Average loss: 1.6054, Accuracy: 162.0/790 (21%)
#
#
# Average loss: 1.6058, Accuracy: 587.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.51%
# Validation Accuracy: 19.97%
# Batch: 0, Loss: 1.5990656614303589
#
# Average loss: 1.6008, Accuracy: 227.0/790 (29%)
#
#
# Average loss: 1.6013, Accuracy: 750.0/2940 (26%)
#
# Epoch: 1 	Training Accuracy: 28.73%
# Validation Accuracy: 25.51%
# Batch: 0, Loss: 1.6021997928619385
#
# Average loss: 1.5961, Accuracy: 263.0/790 (33%)
#
#
# Average loss: 1.5967, Accuracy: 964.0/2940 (33%)
#
# Epoch: 2 	Training Accuracy: 33.29%
# Validation Accuracy: 32.79%
# Batch: 0, Loss: 1.598773717880249
#
# Average loss: 1.5913, Accuracy: 297.0/790 (38%)
#
#
# Average loss: 1.5922, Accuracy: 1117.0/2940 (38%)
#
# Epoch: 3 	Training Accuracy: 37.59%
# Validation Accuracy: 37.99%
# Batch: 0, Loss: 1.5945606231689453
#
# Average loss: 1.5867, Accuracy: 326.0/790 (41%)
#
#
# Average loss: 1.5878, Accuracy: 1248.0/2940 (42%)
#
# Epoch: 4 	Training Accuracy: 41.27%
# Validation Accuracy: 42.45%
# Batch: 0, Loss: 1.5838611125946045
#
# Average loss: 1.5819, Accuracy: 360.0/790 (46%)
#
#
# Average loss: 1.5833, Accuracy: 1357.0/2940 (46%)
#
# Epoch: 5 	Training Accuracy: 45.57%
# Validation Accuracy: 46.16%
# Batch: 0, Loss: 1.5806068181991577
#
# Average loss: 1.5767, Accuracy: 393.0/790 (50%)
#
#
# Average loss: 1.5782, Accuracy: 1474.0/2940 (50%)
#
# Epoch: 6 	Training Accuracy: 49.75%
# Validation Accuracy: 50.14%
# Batch: 0, Loss: 1.5783863067626953
#
# Average loss: 1.5711, Accuracy: 403.0/790 (51%)
#
#
# Average loss: 1.5728, Accuracy: 1515.0/2940 (52%)
#
# Epoch: 7 	Training Accuracy: 51.01%
# Validation Accuracy: 51.53%
# Batch: 0, Loss: 1.5758424997329712
#
# Average loss: 1.5652, Accuracy: 413.0/790 (52%)
#
#
# Average loss: 1.5671, Accuracy: 1543.0/2940 (52%)
#
# Epoch: 8 	Training Accuracy: 52.28%
# Validation Accuracy: 52.48%
# Batch: 0, Loss: 1.5679669380187988
#
# Average loss: 1.5587, Accuracy: 439.0/790 (56%)
#
#
# Average loss: 1.5607, Accuracy: 1611.0/2940 (55%)
#
# Epoch: 9 	Training Accuracy: 55.57%
# Validation Accuracy: 54.80%
# Batch: 0, Loss: 1.556695818901062
#
# Average loss: 1.5515, Accuracy: 476.0/790 (60%)
#
#
# Average loss: 1.5537, Accuracy: 1765.0/2940 (60%)
#
# Epoch: 10 	Training Accuracy: 60.25%
# Validation Accuracy: 60.03%
# Batch: 0, Loss: 1.5490167140960693
#
# Average loss: 1.5438, Accuracy: 512.0/790 (65%)
#
#
# Average loss: 1.5460, Accuracy: 1875.0/2940 (64%)
#
# Epoch: 11 	Training Accuracy: 64.81%
# Validation Accuracy: 63.78%
# Batch: 0, Loss: 1.5415080785751343
#
# Average loss: 1.5353, Accuracy: 541.0/790 (68%)
#
#
# Average loss: 1.5376, Accuracy: 1982.0/2940 (67%)
#
# Epoch: 12 	Training Accuracy: 68.48%
# Validation Accuracy: 67.41%
# Batch: 0, Loss: 1.535884141921997
#
# Average loss: 1.5260, Accuracy: 552.0/790 (70%)
#
#
# Average loss: 1.5284, Accuracy: 2053.0/2940 (70%)
#
# Epoch: 13 	Training Accuracy: 69.87%
# Validation Accuracy: 69.83%
# Batch: 0, Loss: 1.5255298614501953
#
# Average loss: 1.5159, Accuracy: 571.0/790 (72%)
#
#
# Average loss: 1.5183, Accuracy: 2124.0/2940 (72%)
#
# Epoch: 14 	Training Accuracy: 72.28%
# Validation Accuracy: 72.24%
# Batch: 0, Loss: 1.5200831890106201
#
# Average loss: 1.5049, Accuracy: 595.0/790 (75%)
#
#
# Average loss: 1.5072, Accuracy: 2176.0/2940 (74%)
#
# Epoch: 15 	Training Accuracy: 75.32%
# Validation Accuracy: 74.01%
# Batch: 0, Loss: 1.5007905960083008
#
# Average loss: 1.4929, Accuracy: 610.0/790 (77%)
#
#
# Average loss: 1.4952, Accuracy: 2222.0/2940 (76%)
#
# Epoch: 16 	Training Accuracy: 77.22%
# Validation Accuracy: 75.58%
# Batch: 0, Loss: 1.4953327178955078
#
# Average loss: 1.4800, Accuracy: 621.0/790 (79%)
#
#
# Average loss: 1.4825, Accuracy: 2267.0/2940 (77%)
#
# Epoch: 17 	Training Accuracy: 78.61%
# Validation Accuracy: 77.11%
# Batch: 0, Loss: 1.4809703826904297
#
# Average loss: 1.4660, Accuracy: 631.0/790 (80%)
#
#
# Average loss: 1.4688, Accuracy: 2297.0/2940 (78%)
#
# Epoch: 18 	Training Accuracy: 79.87%
# Validation Accuracy: 78.13%
# Batch: 0, Loss: 1.4785412549972534
#
# Average loss: 1.4508, Accuracy: 638.0/790 (81%)
#
#
# Average loss: 1.4537, Accuracy: 2335.0/2940 (79%)
#
# Epoch: 19 	Training Accuracy: 80.76%
# Validation Accuracy: 79.42%
#
# Average loss: 1.4508, Accuracy: 638.0/790 (81%)
#
#
# Average loss: 1.4507, Accuracy: 3898.0/4861 (80%)
#
# Final Training Accuracy (New Data): 0.8076
# Final Test Accuracy (New Data): 0.8019
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 47 =========================
# Batch: 0, Loss: 1.6145148277282715
#
# Average loss: 1.6113, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6128, Accuracy: 550.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.612499713897705
#
# Average loss: 1.6081, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6093, Accuracy: 550.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.615756630897522
#
# Average loss: 1.6050, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6058, Accuracy: 550.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6074613332748413
#
# Average loss: 1.6019, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6025, Accuracy: 553.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 18.81%
# Batch: 0, Loss: 1.5998902320861816
#
# Average loss: 1.5985, Accuracy: 159.0/790 (20%)
#
#
# Average loss: 1.5992, Accuracy: 562.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.13%
# Validation Accuracy: 19.12%
# Batch: 0, Loss: 1.6017512083053589
#
# Average loss: 1.5947, Accuracy: 160.0/790 (20%)
#
#
# Average loss: 1.5957, Accuracy: 568.0/2940 (19%)
#
# Epoch: 5 	Training Accuracy: 20.25%
# Validation Accuracy: 19.32%
# Batch: 0, Loss: 1.5940806865692139
#
# Average loss: 1.5905, Accuracy: 167.0/790 (21%)
#
#
# Average loss: 1.5916, Accuracy: 597.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 21.14%
# Validation Accuracy: 20.31%
# Batch: 0, Loss: 1.5909779071807861
#
# Average loss: 1.5859, Accuracy: 188.0/790 (24%)
#
#
# Average loss: 1.5870, Accuracy: 684.0/2940 (23%)
#
# Epoch: 7 	Training Accuracy: 23.80%
# Validation Accuracy: 23.27%
# Batch: 0, Loss: 1.5833684206008911
#
# Average loss: 1.5807, Accuracy: 199.0/790 (25%)
#
#
# Average loss: 1.5820, Accuracy: 755.0/2940 (26%)
#
# Epoch: 8 	Training Accuracy: 25.19%
# Validation Accuracy: 25.68%
# Batch: 0, Loss: 1.5844306945800781
#
# Average loss: 1.5747, Accuracy: 232.0/790 (29%)
#
#
# Average loss: 1.5762, Accuracy: 873.0/2940 (30%)
#
# Epoch: 9 	Training Accuracy: 29.37%
# Validation Accuracy: 29.69%
# Batch: 0, Loss: 1.5748264789581299
#
# Average loss: 1.5685, Accuracy: 265.0/790 (34%)
#
#
# Average loss: 1.5702, Accuracy: 985.0/2940 (34%)
#
# Epoch: 10 	Training Accuracy: 33.54%
# Validation Accuracy: 33.50%
# Batch: 0, Loss: 1.5686331987380981
#
# Average loss: 1.5625, Accuracy: 287.0/790 (36%)
#
#
# Average loss: 1.5643, Accuracy: 1075.0/2940 (37%)
#
# Epoch: 11 	Training Accuracy: 36.33%
# Validation Accuracy: 36.56%
# Batch: 0, Loss: 1.5620588064193726
#
# Average loss: 1.5565, Accuracy: 317.0/790 (40%)
#
#
# Average loss: 1.5585, Accuracy: 1203.0/2940 (41%)
#
# Epoch: 12 	Training Accuracy: 40.13%
# Validation Accuracy: 40.92%
# Batch: 0, Loss: 1.561922311782837
#
# Average loss: 1.5502, Accuracy: 368.0/790 (47%)
#
#
# Average loss: 1.5522, Accuracy: 1377.0/2940 (47%)
#
# Epoch: 13 	Training Accuracy: 46.58%
# Validation Accuracy: 46.84%
# Batch: 0, Loss: 1.5473814010620117
#
# Average loss: 1.5436, Accuracy: 391.0/790 (49%)
#
#
# Average loss: 1.5458, Accuracy: 1455.0/2940 (49%)
#
# Epoch: 14 	Training Accuracy: 49.49%
# Validation Accuracy: 49.49%
# Batch: 0, Loss: 1.5456113815307617
#
# Average loss: 1.5366, Accuracy: 408.0/790 (52%)
#
#
# Average loss: 1.5391, Accuracy: 1537.0/2940 (52%)
#
# Epoch: 15 	Training Accuracy: 51.65%
# Validation Accuracy: 52.28%
# Batch: 0, Loss: 1.5389049053192139
#
# Average loss: 1.5293, Accuracy: 426.0/790 (54%)
#
#
# Average loss: 1.5320, Accuracy: 1594.0/2940 (54%)
#
# Epoch: 16 	Training Accuracy: 53.92%
# Validation Accuracy: 54.22%
# Batch: 0, Loss: 1.5275620222091675
#
# Average loss: 1.5214, Accuracy: 442.0/790 (56%)
#
#
# Average loss: 1.5243, Accuracy: 1658.0/2940 (56%)
#
# Epoch: 17 	Training Accuracy: 55.95%
# Validation Accuracy: 56.39%
# Batch: 0, Loss: 1.5151491165161133
#
# Average loss: 1.5131, Accuracy: 457.0/790 (58%)
#
#
# Average loss: 1.5161, Accuracy: 1709.0/2940 (58%)
#
# Epoch: 18 	Training Accuracy: 57.85%
# Validation Accuracy: 58.13%
# Batch: 0, Loss: 1.5172820091247559
#
# Average loss: 1.5043, Accuracy: 470.0/790 (59%)
#
#
# Average loss: 1.5074, Accuracy: 1752.0/2940 (60%)
#
# Epoch: 19 	Training Accuracy: 59.49%
# Validation Accuracy: 59.59%
#
# Average loss: 1.5043, Accuracy: 470.0/790 (59%)
#
#
# Average loss: 1.5041, Accuracy: 3083.0/4861 (63%)
#
# Final Training Accuracy (New Data): 0.5949
# Final Test Accuracy (New Data): 0.6342
# Training for data percentage: 0.05:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 55 =========================
# Batch: 0, Loss: 1.5985363721847534
#
# Average loss: 1.6038, Accuracy: 266.0/1320 (20%)
#
#
# Average loss: 1.6054, Accuracy: 601.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.15%
# Validation Accuracy: 20.44%
# Batch: 0, Loss: 1.603468656539917
#
# Average loss: 1.5977, Accuracy: 276.0/1320 (21%)
#
#
# Average loss: 1.5993, Accuracy: 620.0/2940 (21%)
#
# Epoch: 1 	Training Accuracy: 20.91%
# Validation Accuracy: 21.09%
# Batch: 0, Loss: 1.5924447774887085
#
# Average loss: 1.5898, Accuracy: 310.0/1320 (23%)
#
#
# Average loss: 1.5911, Accuracy: 682.0/2940 (23%)
#
# Epoch: 2 	Training Accuracy: 23.48%
# Validation Accuracy: 23.20%
# Batch: 0, Loss: 1.5799378156661987
#
# Average loss: 1.5794, Accuracy: 375.0/1320 (28%)
#
#
# Average loss: 1.5806, Accuracy: 805.0/2940 (27%)
#
# Epoch: 3 	Training Accuracy: 28.41%
# Validation Accuracy: 27.38%
# Batch: 0, Loss: 1.5745339393615723
#
# Average loss: 1.5655, Accuracy: 478.0/1320 (36%)
#
#
# Average loss: 1.5666, Accuracy: 1038.0/2940 (35%)
#
# Epoch: 4 	Training Accuracy: 36.21%
# Validation Accuracy: 35.31%
# Batch: 0, Loss: 1.5717616081237793
#
# Average loss: 1.5474, Accuracy: 608.0/1320 (46%)
#
#
# Average loss: 1.5482, Accuracy: 1362.0/2940 (46%)
#
# Epoch: 5 	Training Accuracy: 46.06%
# Validation Accuracy: 46.33%
# Batch: 0, Loss: 1.543745756149292
#
# Average loss: 1.5246, Accuracy: 730.0/1320 (55%)
#
#
# Average loss: 1.5252, Accuracy: 1647.0/2940 (56%)
#
# Epoch: 6 	Training Accuracy: 55.30%
# Validation Accuracy: 56.02%
# Batch: 0, Loss: 1.5172791481018066
#
# Average loss: 1.4983, Accuracy: 800.0/1320 (61%)
#
#
# Average loss: 1.4988, Accuracy: 1795.0/2940 (61%)
#
# Epoch: 7 	Training Accuracy: 60.61%
# Validation Accuracy: 61.05%
# Batch: 0, Loss: 1.4990977048873901
#
# Average loss: 1.4682, Accuracy: 869.0/1320 (66%)
#
#
# Average loss: 1.4685, Accuracy: 1934.0/2940 (66%)
#
# Epoch: 8 	Training Accuracy: 65.83%
# Validation Accuracy: 65.78%
# Batch: 0, Loss: 1.4752331972122192
#
# Average loss: 1.4344, Accuracy: 913.0/1320 (69%)
#
#
# Average loss: 1.4342, Accuracy: 2030.0/2940 (69%)
#
# Epoch: 9 	Training Accuracy: 69.17%
# Validation Accuracy: 69.05%
# Batch: 0, Loss: 1.4331203699111938
#
# Average loss: 1.3994, Accuracy: 963.0/1320 (73%)
#
#
# Average loss: 1.3988, Accuracy: 2129.0/2940 (72%)
#
# Epoch: 10 	Training Accuracy: 72.95%
# Validation Accuracy: 72.41%
# Batch: 0, Loss: 1.4077115058898926
#
# Average loss: 1.3611, Accuracy: 1007.0/1320 (76%)
#
#
# Average loss: 1.3597, Accuracy: 2218.0/2940 (75%)
#
# Epoch: 11 	Training Accuracy: 76.29%
# Validation Accuracy: 75.44%
# Batch: 0, Loss: 1.3788244724273682
#
# Average loss: 1.3197, Accuracy: 1048.0/1320 (79%)
#
#
# Average loss: 1.3171, Accuracy: 2295.0/2940 (78%)
#
# Epoch: 12 	Training Accuracy: 79.39%
# Validation Accuracy: 78.06%
# Batch: 0, Loss: 1.3313959836959839
#
# Average loss: 1.2746, Accuracy: 1086.0/1320 (82%)
#
#
# Average loss: 1.2708, Accuracy: 2366.0/2940 (80%)
#
# Epoch: 13 	Training Accuracy: 82.27%
# Validation Accuracy: 80.48%
# Batch: 0, Loss: 1.2537755966186523
#
# Average loss: 1.2256, Accuracy: 1123.0/1320 (85%)
#
#
# Average loss: 1.2207, Accuracy: 2442.0/2940 (83%)
#
# Epoch: 14 	Training Accuracy: 85.08%
# Validation Accuracy: 83.06%
# Batch: 0, Loss: 1.193041205406189
#
# Average loss: 1.1740, Accuracy: 1125.0/1320 (85%)
#
#
# Average loss: 1.1682, Accuracy: 2457.0/2940 (84%)
#
# Epoch: 15 	Training Accuracy: 85.23%
# Validation Accuracy: 83.57%
# Batch: 0, Loss: 1.1692692041397095
#
# Average loss: 1.1191, Accuracy: 1131.0/1320 (86%)
#
#
# Average loss: 1.1121, Accuracy: 2504.0/2940 (85%)
#
# Epoch: 16 	Training Accuracy: 85.68%
# Validation Accuracy: 85.17%
# Batch: 0, Loss: 1.1090549230575562
#
# Average loss: 1.0626, Accuracy: 1154.0/1320 (87%)
#
#
# Average loss: 1.0552, Accuracy: 2542.0/2940 (86%)
#
# Epoch: 17 	Training Accuracy: 87.42%
# Validation Accuracy: 86.46%
# Batch: 0, Loss: 1.0302027463912964
#
# Average loss: 1.0056, Accuracy: 1161.0/1320 (88%)
#
#
# Average loss: 0.9979, Accuracy: 2558.0/2940 (87%)
#
# Epoch: 18 	Training Accuracy: 87.95%
# Validation Accuracy: 87.01%
# Batch: 0, Loss: 0.9996054768562317
#
# Average loss: 0.9492, Accuracy: 1173.0/1320 (89%)
#
#
# Average loss: 0.9412, Accuracy: 2573.0/2940 (88%)
#
# Epoch: 19 	Training Accuracy: 88.86%
# Validation Accuracy: 87.52%
#
# Average loss: 0.9492, Accuracy: 1173.0/1320 (89%)
#
#
# Average loss: 0.9344, Accuracy: 4294.0/4861 (88%)
#
# Final Training Accuracy (New Data): 0.8886
# Final Test Accuracy (New Data): 0.8834
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 2 =========================
# Batch: 0, Loss: 1.6126625537872314
#
# Average loss: 1.6051, Accuracy: 338.0/1320 (26%)
#
#
# Average loss: 1.6047, Accuracy: 777.0/2940 (26%)
#
# Epoch: 0 	Training Accuracy: 25.61%
# Validation Accuracy: 26.43%
# Batch: 0, Loss: 1.603572964668274
#
# Average loss: 1.5996, Accuracy: 448.0/1320 (34%)
#
#
# Average loss: 1.5992, Accuracy: 932.0/2940 (32%)
#
# Epoch: 1 	Training Accuracy: 33.94%
# Validation Accuracy: 31.70%
# Batch: 0, Loss: 1.6019792556762695
#
# Average loss: 1.5938, Accuracy: 543.0/1320 (41%)
#
#
# Average loss: 1.5936, Accuracy: 1195.0/2940 (41%)
#
# Epoch: 2 	Training Accuracy: 41.14%
# Validation Accuracy: 40.65%
# Batch: 0, Loss: 1.5930280685424805
#
# Average loss: 1.5870, Accuracy: 662.0/1320 (50%)
#
#
# Average loss: 1.5870, Accuracy: 1438.0/2940 (49%)
#
# Epoch: 3 	Training Accuracy: 50.15%
# Validation Accuracy: 48.91%
# Batch: 0, Loss: 1.5874148607254028
#
# Average loss: 1.5791, Accuracy: 747.0/1320 (57%)
#
#
# Average loss: 1.5793, Accuracy: 1594.0/2940 (54%)
#
# Epoch: 4 	Training Accuracy: 56.59%
# Validation Accuracy: 54.22%
# Batch: 0, Loss: 1.5810117721557617
#
# Average loss: 1.5699, Accuracy: 805.0/1320 (61%)
#
#
# Average loss: 1.5704, Accuracy: 1692.0/2940 (58%)
#
# Epoch: 5 	Training Accuracy: 60.98%
# Validation Accuracy: 57.55%
# Batch: 0, Loss: 1.5679328441619873
#
# Average loss: 1.5591, Accuracy: 818.0/1320 (62%)
#
#
# Average loss: 1.5598, Accuracy: 1789.0/2940 (61%)
#
# Epoch: 6 	Training Accuracy: 61.97%
# Validation Accuracy: 60.85%
# Batch: 0, Loss: 1.5610759258270264
#
# Average loss: 1.5469, Accuracy: 864.0/1320 (65%)
#
#
# Average loss: 1.5476, Accuracy: 1894.0/2940 (64%)
#
# Epoch: 7 	Training Accuracy: 65.45%
# Validation Accuracy: 64.42%
# Batch: 0, Loss: 1.5467419624328613
#
# Average loss: 1.5324, Accuracy: 904.0/1320 (68%)
#
#
# Average loss: 1.5329, Accuracy: 1994.0/2940 (68%)
#
# Epoch: 8 	Training Accuracy: 68.48%
# Validation Accuracy: 67.82%
# Batch: 0, Loss: 1.5316087007522583
#
# Average loss: 1.5156, Accuracy: 933.0/1320 (71%)
#
#
# Average loss: 1.5161, Accuracy: 2080.0/2940 (71%)
#
# Epoch: 9 	Training Accuracy: 70.68%
# Validation Accuracy: 70.75%
# Batch: 0, Loss: 1.5154768228530884
#
# Average loss: 1.4961, Accuracy: 985.0/1320 (75%)
#
#
# Average loss: 1.4960, Accuracy: 2205.0/2940 (75%)
#
# Epoch: 10 	Training Accuracy: 74.62%
# Validation Accuracy: 75.00%
# Batch: 0, Loss: 1.4960966110229492
#
# Average loss: 1.4739, Accuracy: 1011.0/1320 (77%)
#
#
# Average loss: 1.4734, Accuracy: 2253.0/2940 (77%)
#
# Epoch: 11 	Training Accuracy: 76.59%
# Validation Accuracy: 76.63%
# Batch: 0, Loss: 1.4665114879608154
#
# Average loss: 1.4485, Accuracy: 1023.0/1320 (78%)
#
#
# Average loss: 1.4480, Accuracy: 2287.0/2940 (78%)
#
# Epoch: 12 	Training Accuracy: 77.50%
# Validation Accuracy: 77.79%
# Batch: 0, Loss: 1.4417966604232788
#
# Average loss: 1.4202, Accuracy: 1034.0/1320 (78%)
#
#
# Average loss: 1.4195, Accuracy: 2327.0/2940 (79%)
#
# Epoch: 13 	Training Accuracy: 78.33%
# Validation Accuracy: 79.15%
# Batch: 0, Loss: 1.4337308406829834
#
# Average loss: 1.3884, Accuracy: 1054.0/1320 (80%)
#
#
# Average loss: 1.3873, Accuracy: 2358.0/2940 (80%)
#
# Epoch: 14 	Training Accuracy: 79.85%
# Validation Accuracy: 80.20%
# Batch: 0, Loss: 1.3962547779083252
#
# Average loss: 1.3533, Accuracy: 1055.0/1320 (80%)
#
#
# Average loss: 1.3517, Accuracy: 2377.0/2940 (81%)
#
# Epoch: 15 	Training Accuracy: 79.92%
# Validation Accuracy: 80.85%
# Batch: 0, Loss: 1.3669496774673462
#
# Average loss: 1.3146, Accuracy: 1058.0/1320 (80%)
#
#
# Average loss: 1.3119, Accuracy: 2381.0/2940 (81%)
#
# Epoch: 16 	Training Accuracy: 80.15%
# Validation Accuracy: 80.99%
# Batch: 0, Loss: 1.3240526914596558
#
# Average loss: 1.2736, Accuracy: 1056.0/1320 (80%)
#
#
# Average loss: 1.2706, Accuracy: 2390.0/2940 (81%)
#
# Epoch: 17 	Training Accuracy: 80.00%
# Validation Accuracy: 81.29%
# Batch: 0, Loss: 1.2741672992706299
#
# Average loss: 1.2300, Accuracy: 1053.0/1320 (80%)
#
#
# Average loss: 1.2262, Accuracy: 2383.0/2940 (81%)
#
# Epoch: 18 	Training Accuracy: 79.77%
# Validation Accuracy: 81.05%
# Batch: 0, Loss: 1.2323368787765503
#
# Average loss: 1.1847, Accuracy: 1063.0/1320 (81%)
#
#
# Average loss: 1.1801, Accuracy: 2385.0/2940 (81%)
#
# Epoch: 19 	Training Accuracy: 80.53%
# Validation Accuracy: 81.12%
#
# Average loss: 1.1847, Accuracy: 1063.0/1320 (81%)
#
#
# Average loss: 1.1854, Accuracy: 3907.0/4861 (80%)
#
# Final Training Accuracy (New Data): 0.8053
# Final Test Accuracy (New Data): 0.8037
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 63 =========================
# Batch: 0, Loss: 1.6183911561965942
#
# Average loss: 1.6102, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6089, Accuracy: 655.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6036287546157837
#
# Average loss: 1.6089, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6081, Accuracy: 655.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6044154167175293
#
# Average loss: 1.6077, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6072, Accuracy: 655.0/2940 (22%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6099090576171875
#
# Average loss: 1.6064, Accuracy: 281.0/1320 (21%)
#
#
# Average loss: 1.6063, Accuracy: 692.0/2940 (24%)
#
# Epoch: 3 	Training Accuracy: 21.29%
# Validation Accuracy: 23.54%
# Batch: 0, Loss: 1.6079003810882568
#
# ...
# Batch: 200, Loss: 0.21727891266345978
#
# Average loss: 0.2001, Accuracy: 24349.0/26038 (94%)
#
#
# Average loss: 0.2217, Accuracy: 2737.0/2940 (93%)
#
# Epoch: 17 	Training Accuracy: 93.51%
# Validation Accuracy: 93.10%
# Batch: 0, Loss: 0.19455915689468384
# Batch: 20, Loss: 0.2247878611087799
# Batch: 40, Loss: 0.21822816133499146
# Batch: 60, Loss: 0.12969449162483215
# Batch: 80, Loss: 0.1694049835205078
# Batch: 100, Loss: 0.23941268026828766
# Batch: 120, Loss: 0.19853341579437256
# Batch: 140, Loss: 0.1135692372918129
# Batch: 160, Loss: 0.19876840710639954
# Batch: 180, Loss: 0.12642906606197357
# Batch: 200, Loss: 0.27569764852523804
#
# Average loss: 0.1977, Accuracy: 24383.0/26038 (94%)
#
#
# Average loss: 0.2208, Accuracy: 2738.0/2940 (93%)
#
# Epoch: 18 	Training Accuracy: 93.64%
# Validation Accuracy: 93.13%
# Batch: 0, Loss: 0.14673911035060883
# Batch: 20, Loss: 0.2411753237247467
# Batch: 40, Loss: 0.29889240860939026
# Batch: 60, Loss: 0.13995391130447388
# Batch: 80, Loss: 0.30705443024635315
# Batch: 100, Loss: 0.20949232578277588
# Batch: 120, Loss: 0.22659441828727722
# Batch: 140, Loss: 0.3033005893230438
# Batch: 160, Loss: 0.17244674265384674
# Batch: 180, Loss: 0.13973045349121094
# Batch: 200, Loss: 0.2511640787124634
#
# Average loss: 0.1951, Accuracy: 24391.0/26038 (94%)
#
#
# Average loss: 0.2167, Accuracy: 2733.0/2940 (93%)
#
# Epoch: 19 	Training Accuracy: 93.67%
# Validation Accuracy: 92.96%
#
# Average loss: 0.1951, Accuracy: 24391.0/26038 (94%)
#
#
# Average loss: 0.1978, Accuracy: 4564.0/4861 (94%)
#
# Final Training Accuracy (New Data): 0.9367
# Final Test Accuracy (New Data): 0.9389
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 60 =========================
# Batch: 0, Loss: 1.6122615337371826
# Batch: 20, Loss: 1.604518175125122
# Batch: 40, Loss: 1.601027011871338
# Batch: 60, Loss: 1.600940227508545
# Batch: 80, Loss: 1.598586082458496
# Batch: 100, Loss: 1.5899049043655396
# Batch: 120, Loss: 1.5662721395492554
# Batch: 140, Loss: 1.5487394332885742
# Batch: 160, Loss: 1.5275745391845703
# Batch: 180, Loss: 1.449610948562622
# Batch: 200, Loss: 1.4043889045715332
#
# Average loss: 1.3930, Accuracy: 16739.0/26038 (64%)
#
#
# Average loss: 1.3988, Accuracy: 1848.0/2940 (63%)
#
# Epoch: 0 	Training Accuracy: 64.29%
# Validation Accuracy: 62.86%
# Batch: 0, Loss: 1.4059242010116577
# Batch: 20, Loss: 1.3078653812408447
# Batch: 40, Loss: 1.192785382270813
# Batch: 60, Loss: 1.1303473711013794
# Batch: 80, Loss: 0.9832761287689209
# Batch: 100, Loss: 0.92742520570755
# Batch: 120, Loss: 0.7924748659133911
# Batch: 140, Loss: 0.7082165479660034
# Batch: 160, Loss: 0.7104263305664062
# Batch: 180, Loss: 0.5784552097320557
# Batch: 200, Loss: 0.6160919666290283
#
# Average loss: 0.5562, Accuracy: 22397.0/26038 (86%)
#
#
# Average loss: 0.5704, Accuracy: 2511.0/2940 (85%)
#
# Epoch: 1 	Training Accuracy: 86.02%
# Validation Accuracy: 85.41%
# Batch: 0, Loss: 0.4614807069301605
# Batch: 20, Loss: 0.4858980178833008
# Batch: 40, Loss: 0.42933398485183716
# Batch: 60, Loss: 0.44833457469940186
# Batch: 80, Loss: 0.4054393768310547
# Batch: 100, Loss: 0.484849750995636
# Batch: 120, Loss: 0.38550466299057007
# Batch: 140, Loss: 0.4228178858757019
# Batch: 160, Loss: 0.34152281284332275
# Batch: 180, Loss: 0.4056205749511719
# Batch: 200, Loss: 0.3080936372280121
#
# Average loss: 0.3792, Accuracy: 22957.0/26038 (88%)
#
#
# Average loss: 0.3969, Accuracy: 2585.0/2940 (88%)
#
# Epoch: 2 	Training Accuracy: 88.17%
# Validation Accuracy: 87.93%
# Batch: 0, Loss: 0.29464051127433777
# Batch: 20, Loss: 0.3511471450328827
# Batch: 40, Loss: 0.4268832802772522
# Batch: 60, Loss: 0.3456883430480957
# Batch: 80, Loss: 0.2900415062904358
# Batch: 100, Loss: 0.3547743260860443
# Batch: 120, Loss: 0.29294511675834656
# Batch: 140, Loss: 0.3708154857158661
# Batch: 160, Loss: 0.31925562024116516
# Batch: 180, Loss: 0.3358137309551239
# Batch: 200, Loss: 0.2591624855995178
#
# Average loss: 0.3249, Accuracy: 23278.0/26038 (89%)
#
#
# Average loss: 0.3429, Accuracy: 2624.0/2940 (89%)
#
# Epoch: 3 	Training Accuracy: 89.40%
# Validation Accuracy: 89.25%
# Batch: 0, Loss: 0.31636300683021545
# Batch: 20, Loss: 0.324607789516449
# Batch: 40, Loss: 0.2422604113817215
# Batch: 60, Loss: 0.33238333463668823
# Batch: 80, Loss: 0.3762427270412445
# Batch: 100, Loss: 0.29350993037223816
# Batch: 120, Loss: 0.2554986774921417
# Batch: 140, Loss: 0.2584902048110962
# Batch: 160, Loss: 0.1816180944442749
# Batch: 180, Loss: 0.21932047605514526
# Batch: 200, Loss: 0.41571328043937683
#
# Average loss: 0.2923, Accuracy: 23556.0/26038 (90%)
#
#
# Average loss: 0.3074, Accuracy: 2652.0/2940 (90%)
#
# Epoch: 4 	Training Accuracy: 90.47%
# Validation Accuracy: 90.20%
# Batch: 0, Loss: 0.2624128758907318
# Batch: 20, Loss: 0.216549813747406
# Batch: 40, Loss: 0.36810681223869324
# Batch: 60, Loss: 0.33625778555870056
# Batch: 80, Loss: 0.2587798237800598
# Batch: 100, Loss: 0.28935858607292175
# Batch: 120, Loss: 0.33980947732925415
# Batch: 140, Loss: 0.3038319945335388
# Batch: 160, Loss: 0.23056162893772125
# Batch: 180, Loss: 0.34771469235420227
# Batch: 200, Loss: 0.18844300508499146
#
# Average loss: 0.2717, Accuracy: 23695.0/26038 (91%)
#
#
# Average loss: 0.2858, Accuracy: 2668.0/2940 (91%)
#
# Epoch: 5 	Training Accuracy: 91.00%
# Validation Accuracy: 90.75%
# Batch: 0, Loss: 0.31960898637771606
# Batch: 20, Loss: 0.3073764145374298
# Batch: 40, Loss: 0.3267101049423218
# Batch: 60, Loss: 0.2276168167591095
# Batch: 80, Loss: 0.285783976316452
# Batch: 100, Loss: 0.20581553876399994
# Batch: 120, Loss: 0.23396605253219604
# Batch: 140, Loss: 0.277017205953598
# Batch: 160, Loss: 0.19275350868701935
# Batch: 180, Loss: 0.2794034481048584
# Batch: 200, Loss: 0.30231180787086487
#
# Average loss: 0.2547, Accuracy: 23835.0/26038 (92%)
#
#
# Average loss: 0.2676, Accuracy: 2682.0/2940 (91%)
#
# Epoch: 6 	Training Accuracy: 91.54%
# Validation Accuracy: 91.22%
# Batch: 0, Loss: 0.27809539437294006
# Batch: 20, Loss: 0.20952670276165009
# Batch: 40, Loss: 0.28566184639930725
# Batch: 60, Loss: 0.2035699039697647
# Batch: 80, Loss: 0.28520599007606506
# Batch: 100, Loss: 0.1982208639383316
# Batch: 120, Loss: 0.23498131334781647
# Batch: 140, Loss: 0.23853138089179993
# Batch: 160, Loss: 0.26901713013648987
# Batch: 180, Loss: 0.36112040281295776
# Batch: 200, Loss: 0.28684118390083313
#
# Average loss: 0.2425, Accuracy: 23943.0/26038 (92%)
#
#
# Average loss: 0.2556, Accuracy: 2682.0/2940 (91%)
#
# Epoch: 7 	Training Accuracy: 91.95%
# Validation Accuracy: 91.22%
# Batch: 0, Loss: 0.16918985545635223
# Batch: 20, Loss: 0.2758084237575531
# Batch: 40, Loss: 0.25570908188819885
# Batch: 60, Loss: 0.1557019054889679
# Batch: 80, Loss: 0.20175093412399292
# Batch: 100, Loss: 0.3082783818244934
# Batch: 120, Loss: 0.29705342650413513
# Batch: 140, Loss: 0.31768062710762024
# Batch: 160, Loss: 0.25154033303260803
# Batch: 180, Loss: 0.4336331784725189
# Batch: 200, Loss: 0.20725461840629578
#
# Average loss: 0.2316, Accuracy: 24053.0/26038 (92%)
#
#
# Average loss: 0.2452, Accuracy: 2696.0/2940 (92%)
#
# Epoch: 8 	Training Accuracy: 92.38%
# Validation Accuracy: 91.70%
# Batch: 0, Loss: 0.24796345829963684
# Batch: 20, Loss: 0.18079924583435059
# Batch: 40, Loss: 0.17766055464744568
# Batch: 60, Loss: 0.2275632619857788
# Batch: 80, Loss: 0.34375807642936707
# Batch: 100, Loss: 0.19169972836971283
# Batch: 120, Loss: 0.2342420518398285
# Batch: 140, Loss: 0.2866133749485016
# Batch: 160, Loss: 0.20237843692302704
# Batch: 180, Loss: 0.36369848251342773
# Batch: 200, Loss: 0.14219507575035095
#
# Average loss: 0.2250, Accuracy: 24099.0/26038 (93%)
#
#
# Average loss: 0.2386, Accuracy: 2704.0/2940 (92%)
#
# Epoch: 9 	Training Accuracy: 92.55%
# Validation Accuracy: 91.97%
# Batch: 0, Loss: 0.1778419464826584
# Batch: 20, Loss: 0.1677476167678833
# Batch: 40, Loss: 0.1793864518404007
# Batch: 60, Loss: 0.18297667801380157
# Batch: 80, Loss: 0.13057908415794373
# Batch: 100, Loss: 0.15866658091545105
# Batch: 120, Loss: 0.20112454891204834
# Batch: 140, Loss: 0.25867027044296265
# Batch: 160, Loss: 0.14629220962524414
# Batch: 180, Loss: 0.25958096981048584
# Batch: 200, Loss: 0.31217947602272034
#
# Average loss: 0.2175, Accuracy: 24131.0/26038 (93%)
#
#
# Average loss: 0.2315, Accuracy: 2715.0/2940 (92%)
#
# Epoch: 10 	Training Accuracy: 92.68%
# Validation Accuracy: 92.35%
# Batch: 0, Loss: 0.2247239351272583
# Batch: 20, Loss: 0.18550589680671692
# Batch: 40, Loss: 0.16069534420967102
# Batch: 60, Loss: 0.1760602742433548
# Batch: 80, Loss: 0.20070891082286835
# Batch: 100, Loss: 0.2409076988697052
# Batch: 120, Loss: 0.17484070360660553
# Batch: 140, Loss: 0.24366797506809235
# Batch: 160, Loss: 0.1883595734834671
# Batch: 180, Loss: 0.21998827159404755
# Batch: 200, Loss: 0.26810041069984436
#
# Average loss: 0.2112, Accuracy: 24197.0/26038 (93%)
#
#
# Average loss: 0.2265, Accuracy: 2719.0/2940 (92%)
#
# Epoch: 11 	Training Accuracy: 92.93%
# Validation Accuracy: 92.48%
# Batch: 0, Loss: 0.21297116577625275
# Batch: 20, Loss: 0.19199073314666748
# Batch: 40, Loss: 0.20748701691627502
# Batch: 60, Loss: 0.20108437538146973
# Batch: 80, Loss: 0.1806255280971527
# Batch: 100, Loss: 0.16121800243854523
# Batch: 120, Loss: 0.2066143900156021
# Batch: 140, Loss: 0.31197869777679443
# Batch: 160, Loss: 0.23534776270389557
# Batch: 180, Loss: 0.2900775074958801
# Batch: 200, Loss: 0.2376985251903534
#
# Average loss: 0.2046, Accuracy: 24238.0/26038 (93%)
#
#
# Average loss: 0.2186, Accuracy: 2726.0/2940 (93%)
#
# Epoch: 12 	Training Accuracy: 93.09%
# Validation Accuracy: 92.72%
# Batch: 0, Loss: 0.15795797109603882
# Batch: 20, Loss: 0.14176100492477417
# Batch: 40, Loss: 0.18111298978328705
# Batch: 60, Loss: 0.229224294424057
# Batch: 80, Loss: 0.09609901905059814
# Batch: 100, Loss: 0.2580440640449524
# Batch: 120, Loss: 0.21783685684204102
# Batch: 140, Loss: 0.2752280533313751
# Batch: 160, Loss: 0.11125632375478745
# Batch: 180, Loss: 0.2482798546552658
# Batch: 200, Loss: 0.19037111103534698
#
# Average loss: 0.2004, Accuracy: 24293.0/26038 (93%)
#
#
# Average loss: 0.2149, Accuracy: 2726.0/2940 (93%)
#
# Epoch: 13 	Training Accuracy: 93.30%
# Validation Accuracy: 92.72%
# Batch: 0, Loss: 0.18675021827220917
# Batch: 20, Loss: 0.2079228311777115
# Batch: 40, Loss: 0.17474040389060974
# Batch: 60, Loss: 0.16072964668273926
# Batch: 80, Loss: 0.2526169717311859
# Batch: 100, Loss: 0.1412540078163147
# Batch: 120, Loss: 0.2124263048171997
# Batch: 140, Loss: 0.1326400488615036
# Batch: 160, Loss: 0.20344416797161102
# Batch: 180, Loss: 0.11463242769241333
# Batch: 200, Loss: 0.1765439510345459
#
# Average loss: 0.1959, Accuracy: 24302.0/26038 (93%)
#
#
# Average loss: 0.2096, Accuracy: 2741.0/2940 (93%)
#
# Epoch: 14 	Training Accuracy: 93.33%
# Validation Accuracy: 93.23%
# Batch: 0, Loss: 0.1715301275253296
# Batch: 20, Loss: 0.1730353683233261
# Batch: 40, Loss: 0.11943603307008743
# Batch: 60, Loss: 0.22514547407627106
# Batch: 80, Loss: 0.18368881940841675
# Batch: 100, Loss: 0.276189923286438
# Batch: 120, Loss: 0.17128756642341614
# Batch: 140, Loss: 0.2581356465816498
# Batch: 160, Loss: 0.27268826961517334
# Batch: 180, Loss: 0.20214000344276428
# Batch: 200, Loss: 0.20072698593139648
#
# Average loss: 0.1919, Accuracy: 24355.0/26038 (94%)
#
#
# Average loss: 0.2068, Accuracy: 2743.0/2940 (93%)
#
# Epoch: 15 	Training Accuracy: 93.54%
# Validation Accuracy: 93.30%
# Batch: 0, Loss: 0.18492694199085236
# Batch: 20, Loss: 0.23046626150608063
# Batch: 40, Loss: 0.18162046372890472
# Batch: 60, Loss: 0.268379271030426
# Batch: 80, Loss: 0.12532995641231537
# Batch: 100, Loss: 0.13821040093898773
# Batch: 120, Loss: 0.10122700780630112
# Batch: 140, Loss: 0.14326579868793488
# Batch: 160, Loss: 0.219853475689888
# Batch: 180, Loss: 0.13244204223155975
# Batch: 200, Loss: 0.3127690255641937
#
# Average loss: 0.1891, Accuracy: 24366.0/26038 (94%)
#
#
# Average loss: 0.2031, Accuracy: 2748.0/2940 (93%)
#
# Epoch: 16 	Training Accuracy: 93.58%
# Validation Accuracy: 93.47%
# Batch: 0, Loss: 0.2390788346529007
# Batch: 20, Loss: 0.21067485213279724
# Batch: 40, Loss: 0.19536268711090088
# Batch: 60, Loss: 0.23735298216342926
# Batch: 80, Loss: 0.11784248054027557
# Batch: 100, Loss: 0.17412075400352478
# Batch: 120, Loss: 0.14622923731803894
# Batch: 140, Loss: 0.2646532952785492
# Batch: 160, Loss: 0.20087698101997375
# Batch: 180, Loss: 0.15179072320461273
# Batch: 200, Loss: 0.20094819366931915
#
# Average loss: 0.1868, Accuracy: 24397.0/26038 (94%)
#
#
# Average loss: 0.2006, Accuracy: 2754.0/2940 (94%)
#
# Epoch: 17 	Training Accuracy: 93.70%
# Validation Accuracy: 93.67%
# Batch: 0, Loss: 0.1819440871477127
# Batch: 20, Loss: 0.17881053686141968
# Batch: 40, Loss: 0.16878679394721985
# Batch: 60, Loss: 0.18444785475730896
# Batch: 80, Loss: 0.19933100044727325
# Batch: 100, Loss: 0.233106330037117
# Batch: 120, Loss: 0.18357469141483307
# Batch: 140, Loss: 0.2521054744720459
# Batch: 160, Loss: 0.16410841047763824
# Batch: 180, Loss: 0.08925154060125351
# Batch: 200, Loss: 0.09085039794445038
#
# Average loss: 0.1830, Accuracy: 24421.0/26038 (94%)
#
#
# Average loss: 0.1988, Accuracy: 2752.0/2940 (94%)
#
# Epoch: 18 	Training Accuracy: 93.79%
# Validation Accuracy: 93.61%
# Batch: 0, Loss: 0.20000571012496948
# Batch: 20, Loss: 0.23819130659103394
# Batch: 40, Loss: 0.20744676887989044
# Batch: 60, Loss: 0.214935764670372
# Batch: 80, Loss: 0.14657345414161682
# Batch: 100, Loss: 0.21914085745811462
# Batch: 120, Loss: 0.119048573076725
# Batch: 140, Loss: 0.10416387766599655
# Batch: 160, Loss: 0.24423670768737793
# Batch: 180, Loss: 0.13820359110832214
# Batch: 200, Loss: 0.14900103211402893
#
# Average loss: 0.1808, Accuracy: 24461.0/26038 (94%)
#
#
# Average loss: 0.1963, Accuracy: 2750.0/2940 (94%)
#
# Epoch: 19 	Training Accuracy: 93.94%
# Validation Accuracy: 93.54%
#
# Average loss: 0.1808, Accuracy: 24461.0/26038 (94%)
#
#
# Average loss: 0.1886, Accuracy: 4542.0/4861 (93%)
#
# Final Training Accuracy (New Data): 0.9394
# Final Test Accuracy (New Data): 0.9344
# Percentage: 0.01, Seed: 10, Epochs taken: 7
# Percentage: 0.01, Seed: 20, Epochs taken: 19
# Percentage: 0.01, Seed: 30, Epochs taken: 10
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 7
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 7
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 7
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 20
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 20
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 20
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 20
# Percentage: 1, Seed: 40, Epochs taken: 20
# Percentage: 1, Seed: 50, Epochs taken: 20

# %% [markdown]
# ## Only heads and data for new classes

# %% [markdown]
# now with balanced classes

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.0001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test_finetune = {}
results_train_finetune = {}
best_models = {}
data_loaders = {}
epochs_taken_finetune = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Processing percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []
    
    for seed in tqdm(seed_set, desc=f'Running seeds for {perc} data', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")

                # Copying model
        model_new = copy.deepcopy(model)

        # Calculate the output size from the pool layer dynamically
        # You would replace this with the actual size based on your model's architecture
        model_new.fc_1 = nn.Linear(144, 128)
    
        # Reinitialize the second fully connected layer
        model_new.fc_2 = nn.Linear(128, 5)
        
        # Ensure the softmax layer matches the number of classes (if used)
        model_new.softmax = nn.Softmax(dim=1)
        
        model_new.to(device)
        
        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)
        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test_finetune[perc] = test_accuracies
    results_train_finetune[perc] = train_accuracies
    epochs_taken_finetune[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken_finetune[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Running seeds for 0.01 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 84 =========================
# Batch: 0, Loss: 1.6115912199020386
#
# Average loss: 1.5905, Accuracy: 63.0/260 (24%)
#
#
# Average loss: 1.5893, Accuracy: 722.0/2940 (25%)
#
# Epoch: 0 	Training Accuracy: 24.23%
# Validation Accuracy: 24.56%
# Batch: 0, Loss: 1.5934184789657593
#
# Average loss: 1.5753, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.5749, Accuracy: 883.0/2940 (30%)
#
# Epoch: 1 	Training Accuracy: 28.46%
# Validation Accuracy: 30.03%
# Batch: 0, Loss: 1.584012508392334
#
# Average loss: 1.5621, Accuracy: 86.0/260 (33%)
#
#
# Average loss: 1.5619, Accuracy: 984.0/2940 (33%)
#
# Epoch: 2 	Training Accuracy: 33.08%
# Validation Accuracy: 33.47%
# Batch: 0, Loss: 1.5548474788665771
#
# Average loss: 1.5494, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.5494, Accuracy: 1063.0/2940 (36%)
#
# Epoch: 3 	Training Accuracy: 35.00%
# Validation Accuracy: 36.16%
# Batch: 0, Loss: 1.548466682434082
#
# Average loss: 1.5369, Accuracy: 100.0/260 (38%)
#
#
# Average loss: 1.5375, Accuracy: 1135.0/2940 (39%)
#
# Epoch: 4 	Training Accuracy: 38.46%
# Validation Accuracy: 38.61%
# Batch: 0, Loss: 1.5395265817642212
#
# Average loss: 1.5248, Accuracy: 111.0/260 (43%)
#
#
# Average loss: 1.5262, Accuracy: 1198.0/2940 (41%)
#
# Epoch: 5 	Training Accuracy: 42.69%
# Validation Accuracy: 40.75%
# Batch: 0, Loss: 1.5154643058776855
#
# Average loss: 1.5123, Accuracy: 117.0/260 (45%)
#
#
# Average loss: 1.5146, Accuracy: 1257.0/2940 (43%)
#
# Epoch: 6 	Training Accuracy: 45.00%
# Validation Accuracy: 42.76%
# Batch: 0, Loss: 1.53078293800354
#
# Average loss: 1.5001, Accuracy: 118.0/260 (45%)
#
#
# Average loss: 1.5032, Accuracy: 1312.0/2940 (45%)
#
# Epoch: 7 	Training Accuracy: 45.38%
# Validation Accuracy: 44.63%
# Batch: 0, Loss: 1.4970258474349976
#
# Average loss: 1.4878, Accuracy: 127.0/260 (49%)
#
#
# Average loss: 1.4919, Accuracy: 1371.0/2940 (47%)
#
# Epoch: 8 	Training Accuracy: 48.85%
# Validation Accuracy: 46.63%
# Batch: 0, Loss: 1.4914168119430542
#
# Average loss: 1.4754, Accuracy: 128.0/260 (49%)
#
#
# Average loss: 1.4805, Accuracy: 1428.0/2940 (49%)
#
# Epoch: 9 	Training Accuracy: 49.23%
# Validation Accuracy: 48.57%
# Batch: 0, Loss: 1.4715237617492676
#
# Average loss: 1.4628, Accuracy: 130.0/260 (50%)
#
#
# Average loss: 1.4689, Accuracy: 1491.0/2940 (51%)
#
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 50.71%
# Batch: 0, Loss: 1.4858055114746094
#
# Average loss: 1.4502, Accuracy: 137.0/260 (53%)
#
#
# Average loss: 1.4573, Accuracy: 1527.0/2940 (52%)
#
# Epoch: 11 	Training Accuracy: 52.69%
# Validation Accuracy: 51.94%
# Batch: 0, Loss: 1.413856863975525
#
# Average loss: 1.4378, Accuracy: 140.0/260 (54%)
#
#
# Average loss: 1.4456, Accuracy: 1557.0/2940 (53%)
#
# Epoch: 12 	Training Accuracy: 53.85%
# Validation Accuracy: 52.96%
# Batch: 0, Loss: 1.4325058460235596
#
# Average loss: 1.4256, Accuracy: 141.0/260 (54%)
#
#
# Average loss: 1.4341, Accuracy: 1589.0/2940 (54%)
#
# Epoch: 13 	Training Accuracy: 54.23%
# Validation Accuracy: 54.05%
# Batch: 0, Loss: 1.4322808980941772
#
# Average loss: 1.4137, Accuracy: 146.0/260 (56%)
#
#
# Average loss: 1.4230, Accuracy: 1629.0/2940 (55%)
#
# Epoch: 14 	Training Accuracy: 56.15%
# Validation Accuracy: 55.41%
# Batch: 0, Loss: 1.4082077741622925
#
# Average loss: 1.4022, Accuracy: 148.0/260 (57%)
#
#
# Average loss: 1.4121, Accuracy: 1664.0/2940 (57%)
#
# Epoch: 15 	Training Accuracy: 56.92%
# Validation Accuracy: 56.60%
# Batch: 0, Loss: 1.3961474895477295
#
# Average loss: 1.3905, Accuracy: 156.0/260 (60%)
#
#
# Average loss: 1.4012, Accuracy: 1705.0/2940 (58%)
#
# Epoch: 16 	Training Accuracy: 60.00%
# Validation Accuracy: 57.99%
# Batch: 0, Loss: 1.3719829320907593
#
# Average loss: 1.3785, Accuracy: 163.0/260 (63%)
#
#
# Average loss: 1.3900, Accuracy: 1742.0/2940 (59%)
#
# Epoch: 17 	Training Accuracy: 62.69%
# Validation Accuracy: 59.25%
# Batch: 0, Loss: 1.386561393737793
#
# Average loss: 1.3665, Accuracy: 167.0/260 (64%)
#
#
# Average loss: 1.3785, Accuracy: 1754.0/2940 (60%)
#
# Epoch: 18 	Training Accuracy: 64.23%
# Validation Accuracy: 59.66%
# Batch: 0, Loss: 1.3724638223648071
#
# Average loss: 1.3548, Accuracy: 167.0/260 (64%)
#
#
# Average loss: 1.3674, Accuracy: 1789.0/2940 (61%)
#
# Epoch: 19 	Training Accuracy: 64.23%
# Validation Accuracy: 60.85%
#
# Average loss: 1.3548, Accuracy: 167.0/260 (64%)
#
#
# Average loss: 1.3659, Accuracy: 2947.0/4861 (61%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 1 =========================
# Batch: 0, Loss: 1.620181918144226
#
# Average loss: 1.5982, Accuracy: 54.0/260 (21%)
#
#
# Average loss: 1.5994, Accuracy: 617.0/2940 (21%)
#
# Epoch: 0 	Training Accuracy: 20.77%
# Validation Accuracy: 20.99%
# Batch: 0, Loss: 1.5841165781021118
#
# Average loss: 1.5836, Accuracy: 61.0/260 (23%)
#
#
# Average loss: 1.5855, Accuracy: 703.0/2940 (24%)
#
# Epoch: 1 	Training Accuracy: 23.46%
# Validation Accuracy: 23.91%
# Batch: 0, Loss: 1.5980026721954346
#
# Average loss: 1.5702, Accuracy: 66.0/260 (25%)
#
#
# Average loss: 1.5730, Accuracy: 798.0/2940 (27%)
#
# Epoch: 2 	Training Accuracy: 25.38%
# Validation Accuracy: 27.14%
# Batch: 0, Loss: 1.5822808742523193
#
# Average loss: 1.5576, Accuracy: 73.0/260 (28%)
#
#
# Average loss: 1.5615, Accuracy: 877.0/2940 (30%)
#
# Epoch: 3 	Training Accuracy: 28.08%
# Validation Accuracy: 29.83%
# Batch: 0, Loss: 1.5582826137542725
#
# Average loss: 1.5451, Accuracy: 80.0/260 (31%)
#
#
# Average loss: 1.5500, Accuracy: 940.0/2940 (32%)
#
# Epoch: 4 	Training Accuracy: 30.77%
# Validation Accuracy: 31.97%
# Batch: 0, Loss: 1.5360023975372314
#
# Average loss: 1.5324, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.5378, Accuracy: 1015.0/2940 (35%)
#
# Epoch: 5 	Training Accuracy: 35.00%
# Validation Accuracy: 34.52%
# Batch: 0, Loss: 1.5167412757873535
#
# Average loss: 1.5198, Accuracy: 99.0/260 (38%)
#
#
# Average loss: 1.5262, Accuracy: 1092.0/2940 (37%)
#
# Epoch: 6 	Training Accuracy: 38.08%
# Validation Accuracy: 37.14%
# Batch: 0, Loss: 1.5218167304992676
#
# Average loss: 1.5075, Accuracy: 106.0/260 (41%)
#
#
# Average loss: 1.5149, Accuracy: 1173.0/2940 (40%)
#
# Epoch: 7 	Training Accuracy: 40.77%
# Validation Accuracy: 39.90%
# Batch: 0, Loss: 1.5265032052993774
#
# Average loss: 1.4952, Accuracy: 113.0/260 (43%)
#
#
# Average loss: 1.5037, Accuracy: 1249.0/2940 (42%)
#
# Epoch: 8 	Training Accuracy: 43.46%
# Validation Accuracy: 42.48%
# Batch: 0, Loss: 1.5002243518829346
#
# Average loss: 1.4831, Accuracy: 126.0/260 (48%)
#
#
# Average loss: 1.4925, Accuracy: 1301.0/2940 (44%)
#
# Epoch: 9 	Training Accuracy: 48.46%
# Validation Accuracy: 44.25%
# Batch: 0, Loss: 1.484087586402893
#
# Average loss: 1.4712, Accuracy: 128.0/260 (49%)
#
#
# Average loss: 1.4817, Accuracy: 1340.0/2940 (46%)
#
# Epoch: 10 	Training Accuracy: 49.23%
# Validation Accuracy: 45.58%
# Batch: 0, Loss: 1.4744361639022827
#
# Average loss: 1.4596, Accuracy: 128.0/260 (49%)
#
#
# Average loss: 1.4713, Accuracy: 1371.0/2940 (47%)
#
# Epoch: 11 	Training Accuracy: 49.23%
# Validation Accuracy: 46.63%
# Batch: 0, Loss: 1.4468796253204346
#
# Average loss: 1.4480, Accuracy: 130.0/260 (50%)
#
#
# Average loss: 1.4610, Accuracy: 1409.0/2940 (48%)
#
# Epoch: 12 	Training Accuracy: 50.00%
# Validation Accuracy: 47.93%
# Batch: 0, Loss: 1.4594547748565674
#
# Average loss: 1.4368, Accuracy: 135.0/260 (52%)
#
#
# Average loss: 1.4507, Accuracy: 1443.0/2940 (49%)
#
# Epoch: 13 	Training Accuracy: 51.92%
# Validation Accuracy: 49.08%
# Batch: 0, Loss: 1.432708978652954
#
# Average loss: 1.4256, Accuracy: 138.0/260 (53%)
#
#
# Average loss: 1.4404, Accuracy: 1457.0/2940 (50%)
#
# Epoch: 14 	Training Accuracy: 53.08%
# Validation Accuracy: 49.56%
# Batch: 0, Loss: 1.4292906522750854
#
# Average loss: 1.4142, Accuracy: 141.0/260 (54%)
#
#
# Average loss: 1.4300, Accuracy: 1484.0/2940 (50%)
#
# Epoch: 15 	Training Accuracy: 54.23%
# Validation Accuracy: 50.48%
# Batch: 0, Loss: 1.4164302349090576
#
# Average loss: 1.4022, Accuracy: 144.0/260 (55%)
#
#
# Average loss: 1.4190, Accuracy: 1525.0/2940 (52%)
#
# Epoch: 16 	Training Accuracy: 55.38%
# Validation Accuracy: 51.87%
# Batch: 0, Loss: 1.4002636671066284
#
# Average loss: 1.3898, Accuracy: 145.0/260 (56%)
#
#
# Average loss: 1.4073, Accuracy: 1569.0/2940 (53%)
#
# Epoch: 17 	Training Accuracy: 55.77%
# Validation Accuracy: 53.37%
# Batch: 0, Loss: 1.381251573562622
#
# Average loss: 1.3771, Accuracy: 148.0/260 (57%)
#
#
# Average loss: 1.3954, Accuracy: 1625.0/2940 (55%)
#
# Epoch: 18 	Training Accuracy: 56.92%
# Validation Accuracy: 55.27%
# Batch: 0, Loss: 1.3555150032043457
#
# Average loss: 1.3644, Accuracy: 154.0/260 (59%)
#
#
# Average loss: 1.3835, Accuracy: 1665.0/2940 (57%)
#
# Epoch: 19 	Training Accuracy: 59.23%
# Validation Accuracy: 56.63%
#
# Average loss: 1.3644, Accuracy: 154.0/260 (59%)
#
#
# Average loss: 1.3708, Accuracy: 2882.0/4861 (59%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 35 =========================
# Batch: 0, Loss: 1.6387220621109009
#
# Average loss: 1.6128, Accuracy: 60.0/260 (23%)
#
#
# Average loss: 1.5973, Accuracy: 711.0/2940 (24%)
#
# Epoch: 0 	Training Accuracy: 23.08%
# Validation Accuracy: 24.18%
# Batch: 0, Loss: 1.6142234802246094
#
# Average loss: 1.5993, Accuracy: 63.0/260 (24%)
#
#
# Average loss: 1.5829, Accuracy: 811.0/2940 (28%)
#
# Epoch: 1 	Training Accuracy: 24.23%
# Validation Accuracy: 27.59%
# Batch: 0, Loss: 1.6181021928787231
#
# Average loss: 1.5884, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.5715, Accuracy: 896.0/2940 (30%)
#
# Epoch: 2 	Training Accuracy: 28.46%
# Validation Accuracy: 30.48%
# Batch: 0, Loss: 1.5821541547775269
#
# Average loss: 1.5786, Accuracy: 80.0/260 (31%)
#
#
# Average loss: 1.5617, Accuracy: 968.0/2940 (33%)
#
# Epoch: 3 	Training Accuracy: 30.77%
# Validation Accuracy: 32.93%
# Batch: 0, Loss: 1.5952483415603638
#
# Average loss: 1.5686, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5518, Accuracy: 1051.0/2940 (36%)
#
# Epoch: 4 	Training Accuracy: 32.31%
# Validation Accuracy: 35.75%
# Batch: 0, Loss: 1.5656116008758545
#
# Average loss: 1.5588, Accuracy: 90.0/260 (35%)
#
#
# Average loss: 1.5420, Accuracy: 1125.0/2940 (38%)
#
# Epoch: 5 	Training Accuracy: 34.62%
# Validation Accuracy: 38.27%
# Batch: 0, Loss: 1.5785714387893677
#
# Average loss: 1.5490, Accuracy: 100.0/260 (38%)
#
#
# Average loss: 1.5325, Accuracy: 1191.0/2940 (41%)
#
# Epoch: 6 	Training Accuracy: 38.46%
# Validation Accuracy: 40.51%
# Batch: 0, Loss: 1.5503253936767578
#
# Average loss: 1.5396, Accuracy: 104.0/260 (40%)
#
#
# Average loss: 1.5232, Accuracy: 1251.0/2940 (43%)
#
# Epoch: 7 	Training Accuracy: 40.00%
# Validation Accuracy: 42.55%
# Batch: 0, Loss: 1.545360803604126
#
# Average loss: 1.5299, Accuracy: 106.0/260 (41%)
#
#
# Average loss: 1.5136, Accuracy: 1319.0/2940 (45%)
#
# Epoch: 8 	Training Accuracy: 40.77%
# Validation Accuracy: 44.86%
# Batch: 0, Loss: 1.555464267730713
#
# Average loss: 1.5201, Accuracy: 112.0/260 (43%)
#
#
# Average loss: 1.5035, Accuracy: 1377.0/2940 (47%)
#
# Epoch: 9 	Training Accuracy: 43.08%
# Validation Accuracy: 46.84%
# Batch: 0, Loss: 1.513219952583313
#
# Average loss: 1.5104, Accuracy: 115.0/260 (44%)
#
#
# Average loss: 1.4938, Accuracy: 1427.0/2940 (49%)
#
# Epoch: 10 	Training Accuracy: 44.23%
# Validation Accuracy: 48.54%
# Batch: 0, Loss: 1.4915956258773804
#
# Average loss: 1.5008, Accuracy: 119.0/260 (46%)
#
#
# Average loss: 1.4842, Accuracy: 1480.0/2940 (50%)
#
# Epoch: 11 	Training Accuracy: 45.77%
# Validation Accuracy: 50.34%
# Batch: 0, Loss: 1.5011121034622192
#
# Average loss: 1.4909, Accuracy: 126.0/260 (48%)
#
#
# Average loss: 1.4742, Accuracy: 1524.0/2940 (52%)
#
# Epoch: 12 	Training Accuracy: 48.46%
# Validation Accuracy: 51.84%
# Batch: 0, Loss: 1.49574613571167
#
# Average loss: 1.4807, Accuracy: 132.0/260 (51%)
#
#
# Average loss: 1.4643, Accuracy: 1582.0/2940 (54%)
#
# Epoch: 13 	Training Accuracy: 50.77%
# Validation Accuracy: 53.81%
# Batch: 0, Loss: 1.4863125085830688
#
# Average loss: 1.4705, Accuracy: 132.0/260 (51%)
#
#
# Average loss: 1.4545, Accuracy: 1616.0/2940 (55%)
#
# Epoch: 14 	Training Accuracy: 50.77%
# Validation Accuracy: 54.97%
# Batch: 0, Loss: 1.4710931777954102
#
# Average loss: 1.4605, Accuracy: 138.0/260 (53%)
#
#
# Average loss: 1.4449, Accuracy: 1650.0/2940 (56%)
#
# Epoch: 15 	Training Accuracy: 53.08%
# Validation Accuracy: 56.12%
# Batch: 0, Loss: 1.4797213077545166
#
# Average loss: 1.4505, Accuracy: 143.0/260 (55%)
#
#
# Average loss: 1.4350, Accuracy: 1683.0/2940 (57%)
#
# Epoch: 16 	Training Accuracy: 55.00%
# Validation Accuracy: 57.24%
# Batch: 0, Loss: 1.4465391635894775
#
# Average loss: 1.4406, Accuracy: 143.0/260 (55%)
#
#
# Average loss: 1.4250, Accuracy: 1721.0/2940 (59%)
#
# Epoch: 17 	Training Accuracy: 55.00%
# Validation Accuracy: 58.54%
# Batch: 0, Loss: 1.4478733539581299
#
# Average loss: 1.4306, Accuracy: 144.0/260 (55%)
#
#
# Average loss: 1.4148, Accuracy: 1749.0/2940 (59%)
#
# Epoch: 18 	Training Accuracy: 55.38%
# Validation Accuracy: 59.49%
# Batch: 0, Loss: 1.4391366243362427
#
# Average loss: 1.4205, Accuracy: 147.0/260 (57%)
#
#
# Average loss: 1.4043, Accuracy: 1772.0/2940 (60%)
#
# Epoch: 19 	Training Accuracy: 56.54%
# Validation Accuracy: 60.27%
#
# Average loss: 1.4205, Accuracy: 147.0/260 (57%)
#
#
# Average loss: 1.4073, Accuracy: 2894.0/4861 (60%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 46 =========================
# Batch: 0, Loss: 1.6310253143310547
#
# Average loss: 1.5984, Accuracy: 61.0/260 (23%)
#
#
# Average loss: 1.5918, Accuracy: 731.0/2940 (25%)
#
# Epoch: 0 	Training Accuracy: 23.46%
# Validation Accuracy: 24.86%
# Batch: 0, Loss: 1.5914279222488403
#
# Average loss: 1.5849, Accuracy: 71.0/260 (27%)
#
#
# Average loss: 1.5790, Accuracy: 807.0/2940 (27%)
#
# Epoch: 1 	Training Accuracy: 27.31%
# Validation Accuracy: 27.45%
# Batch: 0, Loss: 1.5994540452957153
#
# Average loss: 1.5721, Accuracy: 77.0/260 (30%)
#
#
# Average loss: 1.5667, Accuracy: 878.0/2940 (30%)
#
# Epoch: 2 	Training Accuracy: 29.62%
# Validation Accuracy: 29.86%
# Batch: 0, Loss: 1.578717827796936
#
# Average loss: 1.5596, Accuracy: 83.0/260 (32%)
#
#
# Average loss: 1.5548, Accuracy: 970.0/2940 (33%)
#
# Epoch: 3 	Training Accuracy: 31.92%
# Validation Accuracy: 32.99%
# Batch: 0, Loss: 1.5595285892486572
#
# Average loss: 1.5472, Accuracy: 97.0/260 (37%)
#
#
# Average loss: 1.5432, Accuracy: 1055.0/2940 (36%)
#
# Epoch: 4 	Training Accuracy: 37.31%
# Validation Accuracy: 35.88%
# Batch: 0, Loss: 1.544894814491272
#
# Average loss: 1.5353, Accuracy: 103.0/260 (40%)
#
#
# Average loss: 1.5319, Accuracy: 1156.0/2940 (39%)
#
# Epoch: 5 	Training Accuracy: 39.62%
# Validation Accuracy: 39.32%
# Batch: 0, Loss: 1.54469633102417
#
# Average loss: 1.5239, Accuracy: 110.0/260 (42%)
#
#
# Average loss: 1.5210, Accuracy: 1247.0/2940 (42%)
#
# Epoch: 6 	Training Accuracy: 42.31%
# Validation Accuracy: 42.41%
# Batch: 0, Loss: 1.5188829898834229
#
# Average loss: 1.5127, Accuracy: 113.0/260 (43%)
#
#
# Average loss: 1.5105, Accuracy: 1348.0/2940 (46%)
#
# Epoch: 7 	Training Accuracy: 43.46%
# Validation Accuracy: 45.85%
# Batch: 0, Loss: 1.512495756149292
#
# Average loss: 1.5018, Accuracy: 121.0/260 (47%)
#
#
# Average loss: 1.5004, Accuracy: 1438.0/2940 (49%)
#
# Epoch: 8 	Training Accuracy: 46.54%
# Validation Accuracy: 48.91%
# Batch: 0, Loss: 1.5033092498779297
#
# Average loss: 1.4909, Accuracy: 133.0/260 (51%)
#
#
# Average loss: 1.4904, Accuracy: 1516.0/2940 (52%)
#
# Epoch: 9 	Training Accuracy: 51.15%
# Validation Accuracy: 51.56%
# Batch: 0, Loss: 1.4807299375534058
#
# Average loss: 1.4803, Accuracy: 144.0/260 (55%)
#
#
# Average loss: 1.4808, Accuracy: 1572.0/2940 (53%)
#
# Epoch: 10 	Training Accuracy: 55.38%
# Validation Accuracy: 53.47%
# Batch: 0, Loss: 1.47148859500885
#
# Average loss: 1.4700, Accuracy: 148.0/260 (57%)
#
#
# Average loss: 1.4716, Accuracy: 1629.0/2940 (55%)
#
# Epoch: 11 	Training Accuracy: 56.92%
# Validation Accuracy: 55.41%
# Batch: 0, Loss: 1.462083339691162
#
# Average loss: 1.4598, Accuracy: 154.0/260 (59%)
#
#
# Average loss: 1.4624, Accuracy: 1661.0/2940 (56%)
#
# Epoch: 12 	Training Accuracy: 59.23%
# Validation Accuracy: 56.50%
# Batch: 0, Loss: 1.4525175094604492
#
# Average loss: 1.4493, Accuracy: 162.0/260 (62%)
#
#
# Average loss: 1.4527, Accuracy: 1704.0/2940 (58%)
#
# Epoch: 13 	Training Accuracy: 62.31%
# Validation Accuracy: 57.96%
# Batch: 0, Loss: 1.4420130252838135
#
# Average loss: 1.4387, Accuracy: 168.0/260 (65%)
#
#
# Average loss: 1.4426, Accuracy: 1734.0/2940 (59%)
#
# Epoch: 14 	Training Accuracy: 64.62%
# Validation Accuracy: 58.98%
# Batch: 0, Loss: 1.4455302953720093
#
# Average loss: 1.4280, Accuracy: 171.0/260 (66%)
#
#
# Average loss: 1.4324, Accuracy: 1772.0/2940 (60%)
#
# Epoch: 15 	Training Accuracy: 65.77%
# Validation Accuracy: 60.27%
# Batch: 0, Loss: 1.4376428127288818
#
# Average loss: 1.4173, Accuracy: 175.0/260 (67%)
#
#
# Average loss: 1.4221, Accuracy: 1810.0/2940 (62%)
#
# Epoch: 16 	Training Accuracy: 67.31%
# Validation Accuracy: 61.56%
# Batch: 0, Loss: 1.4130653142929077
#
# Average loss: 1.4062, Accuracy: 176.0/260 (68%)
#
#
# Average loss: 1.4114, Accuracy: 1855.0/2940 (63%)
#
# Epoch: 17 	Training Accuracy: 67.69%
# Validation Accuracy: 63.10%
# Batch: 0, Loss: 1.4024906158447266
#
# Average loss: 1.3949, Accuracy: 177.0/260 (68%)
#
#
# Average loss: 1.4004, Accuracy: 1886.0/2940 (64%)
#
# Epoch: 18 	Training Accuracy: 68.08%
# Validation Accuracy: 64.15%
# Batch: 0, Loss: 1.377845048904419
#
# Average loss: 1.3836, Accuracy: 180.0/260 (69%)
#
#
# Average loss: 1.3894, Accuracy: 1902.0/2940 (65%)
#
# Epoch: 19 	Training Accuracy: 69.23%
# Validation Accuracy: 64.69%
#
# Average loss: 1.3836, Accuracy: 180.0/260 (69%)
#
#
# Average loss: 1.3818, Accuracy: 3169.0/4861 (65%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 8 =========================
# Batch: 0, Loss: 1.6122816801071167
#
# Average loss: 1.5997, Accuracy: 49.0/260 (19%)
#
#
# Average loss: 1.5886, Accuracy: 662.0/2940 (23%)
#
# Epoch: 0 	Training Accuracy: 18.85%
# Validation Accuracy: 22.52%
# Batch: 0, Loss: 1.61324942111969
#
# Average loss: 1.5831, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.5726, Accuracy: 759.0/2940 (26%)
#
# Epoch: 1 	Training Accuracy: 22.31%
# Validation Accuracy: 25.82%
# Batch: 0, Loss: 1.5754754543304443
#
# Average loss: 1.5695, Accuracy: 66.0/260 (25%)
#
#
# Average loss: 1.5596, Accuracy: 832.0/2940 (28%)
#
# Epoch: 2 	Training Accuracy: 25.38%
# Validation Accuracy: 28.30%
# Batch: 0, Loss: 1.5656870603561401
#
# Average loss: 1.5574, Accuracy: 68.0/260 (26%)
#
#
# Average loss: 1.5481, Accuracy: 885.0/2940 (30%)
#
# Epoch: 3 	Training Accuracy: 26.15%
# Validation Accuracy: 30.10%
# Batch: 0, Loss: 1.5664458274841309
#
# Average loss: 1.5460, Accuracy: 71.0/260 (27%)
#
#
# Average loss: 1.5372, Accuracy: 913.0/2940 (31%)
#
# Epoch: 4 	Training Accuracy: 27.31%
# Validation Accuracy: 31.05%
# Batch: 0, Loss: 1.541621208190918
#
# Average loss: 1.5353, Accuracy: 75.0/260 (29%)
#
#
# Average loss: 1.5271, Accuracy: 960.0/2940 (33%)
#
# Epoch: 5 	Training Accuracy: 28.85%
# Validation Accuracy: 32.65%
# Batch: 0, Loss: 1.5246248245239258
#
# Average loss: 1.5246, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5168, Accuracy: 1017.0/2940 (35%)
#
# Epoch: 6 	Training Accuracy: 32.31%
# Validation Accuracy: 34.59%
# Batch: 0, Loss: 1.5104566812515259
#
# Average loss: 1.5138, Accuracy: 88.0/260 (34%)
#
#
# Average loss: 1.5065, Accuracy: 1085.0/2940 (37%)
#
# Epoch: 7 	Training Accuracy: 33.85%
# Validation Accuracy: 36.90%
# Batch: 0, Loss: 1.5224305391311646
#
# Average loss: 1.5033, Accuracy: 95.0/260 (37%)
#
#
# Average loss: 1.4964, Accuracy: 1142.0/2940 (39%)
#
# Epoch: 8 	Training Accuracy: 36.54%
# Validation Accuracy: 38.84%
# Batch: 0, Loss: 1.5157244205474854
#
# Average loss: 1.4925, Accuracy: 99.0/260 (38%)
#
#
# Average loss: 1.4861, Accuracy: 1209.0/2940 (41%)
#
# Epoch: 9 	Training Accuracy: 38.08%
# Validation Accuracy: 41.12%
# Batch: 0, Loss: 1.4984865188598633
#
# Average loss: 1.4817, Accuracy: 108.0/260 (42%)
#
#
# Average loss: 1.4759, Accuracy: 1277.0/2940 (43%)
#
# Epoch: 10 	Training Accuracy: 41.54%
# Validation Accuracy: 43.44%
# Batch: 0, Loss: 1.472457766532898
#
# Average loss: 1.4710, Accuracy: 113.0/260 (43%)
#
#
# Average loss: 1.4658, Accuracy: 1347.0/2940 (46%)
#
# Epoch: 11 	Training Accuracy: 43.46%
# Validation Accuracy: 45.82%
# Batch: 0, Loss: 1.477009654045105
#
# Average loss: 1.4604, Accuracy: 120.0/260 (46%)
#
#
# Average loss: 1.4559, Accuracy: 1410.0/2940 (48%)
#
# Epoch: 12 	Training Accuracy: 46.15%
# Validation Accuracy: 47.96%
# Batch: 0, Loss: 1.4804515838623047
#
# Average loss: 1.4496, Accuracy: 125.0/260 (48%)
#
#
# Average loss: 1.4459, Accuracy: 1497.0/2940 (51%)
#
# Epoch: 13 	Training Accuracy: 48.08%
# Validation Accuracy: 50.92%
# Batch: 0, Loss: 1.4487777948379517
#
# Average loss: 1.4390, Accuracy: 140.0/260 (54%)
#
#
# Average loss: 1.4362, Accuracy: 1551.0/2940 (53%)
#
# Epoch: 14 	Training Accuracy: 53.85%
# Validation Accuracy: 52.76%
# Batch: 0, Loss: 1.435499668121338
#
# Average loss: 1.4284, Accuracy: 144.0/260 (55%)
#
#
# Average loss: 1.4266, Accuracy: 1610.0/2940 (55%)
#
# Epoch: 15 	Training Accuracy: 55.38%
# Validation Accuracy: 54.76%
# Batch: 0, Loss: 1.412581443786621
#
# Average loss: 1.4175, Accuracy: 145.0/260 (56%)
#
#
# Average loss: 1.4167, Accuracy: 1653.0/2940 (56%)
#
# Epoch: 16 	Training Accuracy: 55.77%
# Validation Accuracy: 56.22%
# Batch: 0, Loss: 1.4146101474761963
#
# Average loss: 1.4068, Accuracy: 149.0/260 (57%)
#
#
# Average loss: 1.4067, Accuracy: 1680.0/2940 (57%)
#
# Epoch: 17 	Training Accuracy: 57.31%
# Validation Accuracy: 57.14%
# Batch: 0, Loss: 1.4229474067687988
#
# Average loss: 1.3963, Accuracy: 149.0/260 (57%)
#
#
# Average loss: 1.3971, Accuracy: 1703.0/2940 (58%)
#
# Epoch: 18 	Training Accuracy: 57.31%
# Validation Accuracy: 57.93%
# Batch: 0, Loss: 1.38690185546875
#
# Average loss: 1.3860, Accuracy: 155.0/260 (60%)
#
#
# Average loss: 1.3876, Accuracy: 1720.0/2940 (59%)
#
# Epoch: 19 	Training Accuracy: 59.62%
# Validation Accuracy: 58.50%
#
# Average loss: 1.3860, Accuracy: 155.0/260 (60%)
#
#
# Average loss: 1.3793, Accuracy: 2880.0/4861 (59%)
# Running seeds for 0.03 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 93 =========================
# Batch: 0, Loss: 1.6274831295013428
#
# Average loss: 1.5919, Accuracy: 160.0/790 (20%)
#
#
# Average loss: 1.5984, Accuracy: 574.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.25%
# Validation Accuracy: 19.52%
# Batch: 0, Loss: 1.601226568222046
#
# Average loss: 1.5539, Accuracy: 212.0/790 (27%)
#
#
# Average loss: 1.5607, Accuracy: 764.0/2940 (26%)
#
# Epoch: 1 	Training Accuracy: 26.84%
# Validation Accuracy: 25.99%
# Batch: 0, Loss: 1.5589700937271118
#
# Average loss: 1.5179, Accuracy: 268.0/790 (34%)
#
#
# Average loss: 1.5253, Accuracy: 988.0/2940 (34%)
#
# Epoch: 2 	Training Accuracy: 33.92%
# Validation Accuracy: 33.61%
# Batch: 0, Loss: 1.5101566314697266
#
# Average loss: 1.4824, Accuracy: 338.0/790 (43%)
#
#
# Average loss: 1.4901, Accuracy: 1241.0/2940 (42%)
#
# Epoch: 3 	Training Accuracy: 42.78%
# Validation Accuracy: 42.21%
# Batch: 0, Loss: 1.4974796772003174
#
# Average loss: 1.4465, Accuracy: 399.0/790 (51%)
#
#
# Average loss: 1.4545, Accuracy: 1441.0/2940 (49%)
#
# Epoch: 4 	Training Accuracy: 50.51%
# Validation Accuracy: 49.01%
# Batch: 0, Loss: 1.4521821737289429
#
# Average loss: 1.4102, Accuracy: 446.0/790 (56%)
#
#
# Average loss: 1.4189, Accuracy: 1591.0/2940 (54%)
#
# Epoch: 5 	Training Accuracy: 56.46%
# Validation Accuracy: 54.12%
# Batch: 0, Loss: 1.3965709209442139
#
# Average loss: 1.3738, Accuracy: 484.0/790 (61%)
#
#
# Average loss: 1.3837, Accuracy: 1711.0/2940 (58%)
#
# Epoch: 6 	Training Accuracy: 61.27%
# Validation Accuracy: 58.20%
# Batch: 0, Loss: 1.3806401491165161
#
# Average loss: 1.3371, Accuracy: 510.0/790 (65%)
#
#
# Average loss: 1.3483, Accuracy: 1822.0/2940 (62%)
#
# Epoch: 7 	Training Accuracy: 64.56%
# Validation Accuracy: 61.97%
# Batch: 0, Loss: 1.3373949527740479
#
# Average loss: 1.3002, Accuracy: 531.0/790 (67%)
#
#
# Average loss: 1.3128, Accuracy: 1897.0/2940 (65%)
#
# Epoch: 8 	Training Accuracy: 67.22%
# Validation Accuracy: 64.52%
# Batch: 0, Loss: 1.3060173988342285
#
# Average loss: 1.2628, Accuracy: 556.0/790 (70%)
#
#
# Average loss: 1.2764, Accuracy: 1977.0/2940 (67%)
#
# Epoch: 9 	Training Accuracy: 70.38%
# Validation Accuracy: 67.24%
# Batch: 0, Loss: 1.246567726135254
#
# Average loss: 1.2254, Accuracy: 573.0/790 (73%)
#
#
# Average loss: 1.2398, Accuracy: 2041.0/2940 (69%)
#
# Epoch: 10 	Training Accuracy: 72.53%
# Validation Accuracy: 69.42%
# Batch: 0, Loss: 1.214318037033081
#
# Average loss: 1.1884, Accuracy: 583.0/790 (74%)
#
#
# Average loss: 1.2039, Accuracy: 2099.0/2940 (71%)
#
# Epoch: 11 	Training Accuracy: 73.80%
# Validation Accuracy: 71.39%
# Batch: 0, Loss: 1.159695029258728
#
# Average loss: 1.1516, Accuracy: 602.0/790 (76%)
#
#
# Average loss: 1.1686, Accuracy: 2149.0/2940 (73%)
#
# Epoch: 12 	Training Accuracy: 76.20%
# Validation Accuracy: 73.10%
# Batch: 0, Loss: 1.1687264442443848
#
# Average loss: 1.1152, Accuracy: 614.0/790 (78%)
#
#
# Average loss: 1.1338, Accuracy: 2203.0/2940 (75%)
#
# Epoch: 13 	Training Accuracy: 77.72%
# Validation Accuracy: 74.93%
# Batch: 0, Loss: 1.1377813816070557
#
# Average loss: 1.0792, Accuracy: 626.0/790 (79%)
#
#
# Average loss: 1.0991, Accuracy: 2240.0/2940 (76%)
#
# Epoch: 14 	Training Accuracy: 79.24%
# Validation Accuracy: 76.19%
# Batch: 0, Loss: 1.102944016456604
#
# Average loss: 1.0436, Accuracy: 632.0/790 (80%)
#
#
# Average loss: 1.0650, Accuracy: 2269.0/2940 (77%)
#
# Epoch: 15 	Training Accuracy: 80.00%
# Validation Accuracy: 77.18%
# Batch: 0, Loss: 1.0150127410888672
#
# Average loss: 1.0090, Accuracy: 637.0/790 (81%)
#
#
# Average loss: 1.0315, Accuracy: 2297.0/2940 (78%)
#
# Epoch: 16 	Training Accuracy: 80.63%
# Validation Accuracy: 78.13%
# Batch: 0, Loss: 0.9905993938446045
#
# Average loss: 0.9753, Accuracy: 641.0/790 (81%)
#
#
# Average loss: 0.9989, Accuracy: 2317.0/2940 (79%)
#
# Epoch: 17 	Training Accuracy: 81.14%
# Validation Accuracy: 78.81%
# Batch: 0, Loss: 0.9059566259384155
#
# Average loss: 0.9421, Accuracy: 645.0/790 (82%)
#
#
# Average loss: 0.9675, Accuracy: 2331.0/2940 (79%)
#
# Epoch: 18 	Training Accuracy: 81.65%
# Validation Accuracy: 79.29%
# Batch: 0, Loss: 0.9340822696685791
#
# Average loss: 0.9097, Accuracy: 655.0/790 (83%)
#
#
# Average loss: 0.9371, Accuracy: 2357.0/2940 (80%)
#
# Epoch: 19 	Training Accuracy: 82.91%
# Validation Accuracy: 80.17%
#
# Average loss: 0.9097, Accuracy: 655.0/790 (83%)
#
#
# Average loss: 0.9319, Accuracy: 3912.0/4861 (80%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 89 =========================
# Batch: 0, Loss: 1.6010514497756958
#
# Average loss: 1.5700, Accuracy: 198.0/790 (25%)
#
#
# Average loss: 1.5769, Accuracy: 708.0/2940 (24%)
#
# Epoch: 0 	Training Accuracy: 25.06%
# Validation Accuracy: 24.08%
# Batch: 0, Loss: 1.573530673980713
#
# Average loss: 1.5322, Accuracy: 266.0/790 (34%)
#
#
# Average loss: 1.5395, Accuracy: 973.0/2940 (33%)
#
# Epoch: 1 	Training Accuracy: 33.67%
# Validation Accuracy: 33.10%
# Batch: 0, Loss: 1.5394890308380127
#
# Average loss: 1.4961, Accuracy: 316.0/790 (40%)
#
#
# Average loss: 1.5036, Accuracy: 1146.0/2940 (39%)
#
# Epoch: 2 	Training Accuracy: 40.00%
# Validation Accuracy: 38.98%
# Batch: 0, Loss: 1.4812535047531128
#
# Average loss: 1.4604, Accuracy: 377.0/790 (48%)
#
#
# Average loss: 1.4677, Accuracy: 1321.0/2940 (45%)
#
# Epoch: 3 	Training Accuracy: 47.72%
# Validation Accuracy: 44.93%
# Batch: 0, Loss: 1.483193278312683
#
# Average loss: 1.4256, Accuracy: 418.0/790 (53%)
#
#
# Average loss: 1.4327, Accuracy: 1470.0/2940 (50%)
#
# Epoch: 4 	Training Accuracy: 52.91%
# Validation Accuracy: 50.00%
# Batch: 0, Loss: 1.399358868598938
#
# Average loss: 1.3908, Accuracy: 452.0/790 (57%)
#
#
# Average loss: 1.3979, Accuracy: 1609.0/2940 (55%)
#
# Epoch: 5 	Training Accuracy: 57.22%
# Validation Accuracy: 54.73%
# Batch: 0, Loss: 1.3571758270263672
#
# Average loss: 1.3555, Accuracy: 474.0/790 (60%)
#
#
# Average loss: 1.3625, Accuracy: 1714.0/2940 (58%)
#
# Epoch: 6 	Training Accuracy: 60.00%
# Validation Accuracy: 58.30%
# Batch: 0, Loss: 1.3922460079193115
#
# Average loss: 1.3201, Accuracy: 489.0/790 (62%)
#
#
# Average loss: 1.3270, Accuracy: 1786.0/2940 (61%)
#
# Epoch: 7 	Training Accuracy: 61.90%
# Validation Accuracy: 60.75%
# Batch: 0, Loss: 1.3184332847595215
#
# Average loss: 1.2841, Accuracy: 509.0/790 (64%)
#
#
# Average loss: 1.2909, Accuracy: 1857.0/2940 (63%)
#
# Epoch: 8 	Training Accuracy: 64.43%
# Validation Accuracy: 63.16%
# Batch: 0, Loss: 1.2684723138809204
#
# Average loss: 1.2484, Accuracy: 518.0/790 (66%)
#
#
# Average loss: 1.2550, Accuracy: 1915.0/2940 (65%)
#
# Epoch: 9 	Training Accuracy: 65.57%
# Validation Accuracy: 65.14%
# Batch: 0, Loss: 1.2470219135284424
#
# Average loss: 1.2129, Accuracy: 536.0/790 (68%)
#
#
# Average loss: 1.2197, Accuracy: 1967.0/2940 (67%)
#
# Epoch: 10 	Training Accuracy: 67.85%
# Validation Accuracy: 66.90%
# Batch: 0, Loss: 1.2179508209228516
#
# Average loss: 1.1773, Accuracy: 553.0/790 (70%)
#
#
# Average loss: 1.1837, Accuracy: 2012.0/2940 (68%)
#
# Epoch: 11 	Training Accuracy: 70.00%
# Validation Accuracy: 68.44%
# Batch: 0, Loss: 1.1873747110366821
#
# Average loss: 1.1423, Accuracy: 559.0/790 (71%)
#
#
# Average loss: 1.1489, Accuracy: 2054.0/2940 (70%)
#
# Epoch: 12 	Training Accuracy: 70.76%
# Validation Accuracy: 69.86%
# Batch: 0, Loss: 1.116243839263916
#
# Average loss: 1.1071, Accuracy: 575.0/790 (73%)
#
#
# Average loss: 1.1140, Accuracy: 2103.0/2940 (72%)
#
# Epoch: 13 	Training Accuracy: 72.78%
# Validation Accuracy: 71.53%
# Batch: 0, Loss: 1.1092971563339233
#
# Average loss: 1.0726, Accuracy: 591.0/790 (75%)
#
#
# Average loss: 1.0804, Accuracy: 2151.0/2940 (73%)
#
# Epoch: 14 	Training Accuracy: 74.81%
# Validation Accuracy: 73.16%
# Batch: 0, Loss: 1.089853048324585
#
# Average loss: 1.0398, Accuracy: 610.0/790 (77%)
#
#
# Average loss: 1.0488, Accuracy: 2195.0/2940 (75%)
#
# Epoch: 15 	Training Accuracy: 77.22%
# Validation Accuracy: 74.66%
# Batch: 0, Loss: 1.0224177837371826
#
# Average loss: 1.0073, Accuracy: 623.0/790 (79%)
#
#
# Average loss: 1.0175, Accuracy: 2224.0/2940 (76%)
#
# Epoch: 16 	Training Accuracy: 78.86%
# Validation Accuracy: 75.65%
# Batch: 0, Loss: 1.0456379652023315
#
# Average loss: 0.9758, Accuracy: 625.0/790 (79%)
#
#
# Average loss: 0.9873, Accuracy: 2238.0/2940 (76%)
#
# Epoch: 17 	Training Accuracy: 79.11%
# Validation Accuracy: 76.12%
# Batch: 0, Loss: 0.9561968445777893
#
# Average loss: 0.9448, Accuracy: 631.0/790 (80%)
#
#
# Average loss: 0.9573, Accuracy: 2265.0/2940 (77%)
#
# Epoch: 18 	Training Accuracy: 79.87%
# Validation Accuracy: 77.04%
# Batch: 0, Loss: 0.9617838859558105
#
# Average loss: 0.9148, Accuracy: 637.0/790 (81%)
#
#
# Average loss: 0.9284, Accuracy: 2298.0/2940 (78%)
#
# Epoch: 19 	Training Accuracy: 80.63%
# Validation Accuracy: 78.16%
#
# Average loss: 0.9148, Accuracy: 637.0/790 (81%)
#
#
# Average loss: 0.9150, Accuracy: 3850.0/4861 (79%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 99 =========================
# Batch: 0, Loss: 1.6147129535675049
#
# Average loss: 1.5604, Accuracy: 236.0/790 (30%)
#
#
# Average loss: 1.5664, Accuracy: 857.0/2940 (29%)
#
# Epoch: 0 	Training Accuracy: 29.87%
# Validation Accuracy: 29.15%
# Batch: 0, Loss: 1.570494532585144
#
# Average loss: 1.5229, Accuracy: 277.0/790 (35%)
#
#
# Average loss: 1.5297, Accuracy: 1021.0/2940 (35%)
#
# Epoch: 1 	Training Accuracy: 35.06%
# Validation Accuracy: 34.73%
# Batch: 0, Loss: 1.5219806432724
#
# Average loss: 1.4856, Accuracy: 332.0/790 (42%)
#
#
# Average loss: 1.4935, Accuracy: 1220.0/2940 (41%)
#
# Epoch: 2 	Training Accuracy: 42.03%
# Validation Accuracy: 41.50%
# Batch: 0, Loss: 1.491869568824768
#
# Average loss: 1.4488, Accuracy: 378.0/790 (48%)
#
#
# Average loss: 1.4576, Accuracy: 1456.0/2940 (50%)
#
# Epoch: 3 	Training Accuracy: 47.85%
# Validation Accuracy: 49.52%
# Batch: 0, Loss: 1.473536729812622
#
# Average loss: 1.4120, Accuracy: 440.0/790 (56%)
#
#
# Average loss: 1.4216, Accuracy: 1655.0/2940 (56%)
#
# Epoch: 4 	Training Accuracy: 55.70%
# Validation Accuracy: 56.29%
# Batch: 0, Loss: 1.4163591861724854
#
# Average loss: 1.3749, Accuracy: 486.0/790 (62%)
#
#
# Average loss: 1.3855, Accuracy: 1798.0/2940 (61%)
#
# Epoch: 5 	Training Accuracy: 61.52%
# Validation Accuracy: 61.16%
# Batch: 0, Loss: 1.3884390592575073
#
# Average loss: 1.3380, Accuracy: 516.0/790 (65%)
#
#
# Average loss: 1.3496, Accuracy: 1918.0/2940 (65%)
#
# Epoch: 6 	Training Accuracy: 65.32%
# Validation Accuracy: 65.24%
# Batch: 0, Loss: 1.334438443183899
#
# Average loss: 1.3010, Accuracy: 542.0/790 (69%)
#
#
# Average loss: 1.3133, Accuracy: 2008.0/2940 (68%)
#
# Epoch: 7 	Training Accuracy: 68.61%
# Validation Accuracy: 68.30%
# Batch: 0, Loss: 1.3287522792816162
#
# Average loss: 1.2643, Accuracy: 572.0/790 (72%)
#
#
# Average loss: 1.2775, Accuracy: 2078.0/2940 (71%)
#
# Epoch: 8 	Training Accuracy: 72.41%
# Validation Accuracy: 70.68%
# Batch: 0, Loss: 1.2652833461761475
#
# Average loss: 1.2274, Accuracy: 586.0/790 (74%)
#
#
# Average loss: 1.2417, Accuracy: 2129.0/2940 (72%)
#
# Epoch: 9 	Training Accuracy: 74.18%
# Validation Accuracy: 72.41%
# Batch: 0, Loss: 1.2193732261657715
#
# Average loss: 1.1903, Accuracy: 593.0/790 (75%)
#
#
# Average loss: 1.2055, Accuracy: 2174.0/2940 (74%)
#
# Epoch: 10 	Training Accuracy: 75.06%
# Validation Accuracy: 73.95%
# Batch: 0, Loss: 1.143070101737976
#
# Average loss: 1.1536, Accuracy: 597.0/790 (76%)
#
#
# Average loss: 1.1698, Accuracy: 2204.0/2940 (75%)
#
# Epoch: 11 	Training Accuracy: 75.57%
# Validation Accuracy: 74.97%
# Batch: 0, Loss: 1.1514912843704224
#
# Average loss: 1.1179, Accuracy: 603.0/790 (76%)
#
#
# Average loss: 1.1351, Accuracy: 2241.0/2940 (76%)
#
# Epoch: 12 	Training Accuracy: 76.33%
# Validation Accuracy: 76.22%
# Batch: 0, Loss: 1.1234021186828613
#
# Average loss: 1.0829, Accuracy: 613.0/790 (78%)
#
#
# Average loss: 1.1006, Accuracy: 2263.0/2940 (77%)
#
# Epoch: 13 	Training Accuracy: 77.59%
# Validation Accuracy: 76.97%
# Batch: 0, Loss: 1.0704845190048218
#
# Average loss: 1.0487, Accuracy: 621.0/790 (79%)
#
#
# Average loss: 1.0674, Accuracy: 2277.0/2940 (77%)
#
# Epoch: 14 	Training Accuracy: 78.61%
# Validation Accuracy: 77.45%
# Batch: 0, Loss: 1.077804684638977
#
# Average loss: 1.0148, Accuracy: 626.0/790 (79%)
#
#
# Average loss: 1.0352, Accuracy: 2302.0/2940 (78%)
#
# Epoch: 15 	Training Accuracy: 79.24%
# Validation Accuracy: 78.30%
# Batch: 0, Loss: 0.9935734272003174
#
# Average loss: 0.9821, Accuracy: 635.0/790 (80%)
#
#
# Average loss: 1.0041, Accuracy: 2328.0/2940 (79%)
#
# Epoch: 16 	Training Accuracy: 80.38%
# Validation Accuracy: 79.18%
# Batch: 0, Loss: 0.8970154523849487
#
# Average loss: 0.9504, Accuracy: 637.0/790 (81%)
#
#
# Average loss: 0.9731, Accuracy: 2340.0/2940 (80%)
#
# Epoch: 17 	Training Accuracy: 80.63%
# Validation Accuracy: 79.59%
# Batch: 0, Loss: 0.9902832508087158
#
# Average loss: 0.9196, Accuracy: 639.0/790 (81%)
#
#
# Average loss: 0.9434, Accuracy: 2346.0/2940 (80%)
#
# Epoch: 18 	Training Accuracy: 80.89%
# Validation Accuracy: 79.80%
# Batch: 0, Loss: 0.9201235175132751
#
# Average loss: 0.8900, Accuracy: 640.0/790 (81%)
#
#
# Average loss: 0.9149, Accuracy: 2353.0/2940 (80%)
#
# Epoch: 19 	Training Accuracy: 81.01%
# Validation Accuracy: 80.03%
#
# Average loss: 0.8900, Accuracy: 640.0/790 (81%)
#
#
# Average loss: 0.9074, Accuracy: 3980.0/4861 (82%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 68 =========================
# Batch: 0, Loss: 1.6004278659820557
#
# Average loss: 1.5677, Accuracy: 264.0/790 (33%)
#
#
# Average loss: 1.5693, Accuracy: 911.0/2940 (31%)
#
# Epoch: 0 	Training Accuracy: 33.42%
# Validation Accuracy: 30.99%
# Batch: 0, Loss: 1.563444972038269
#
# Average loss: 1.5278, Accuracy: 305.0/790 (39%)
#
#
# Average loss: 1.5295, Accuracy: 1102.0/2940 (37%)
#
# Epoch: 1 	Training Accuracy: 38.61%
# Validation Accuracy: 37.48%
# Batch: 0, Loss: 1.5222347974777222
#
# Average loss: 1.4896, Accuracy: 348.0/790 (44%)
#
#
# Average loss: 1.4919, Accuracy: 1268.0/2940 (43%)
#
# Epoch: 2 	Training Accuracy: 44.05%
# Validation Accuracy: 43.13%
# Batch: 0, Loss: 1.4929529428482056
#
# Average loss: 1.4513, Accuracy: 404.0/790 (51%)
#
#
# Average loss: 1.4542, Accuracy: 1406.0/2940 (48%)
#
# Epoch: 3 	Training Accuracy: 51.14%
# Validation Accuracy: 47.82%
# Batch: 0, Loss: 1.4588935375213623
#
# Average loss: 1.4130, Accuracy: 456.0/790 (58%)
#
#
# Average loss: 1.4163, Accuracy: 1601.0/2940 (54%)
#
# Epoch: 4 	Training Accuracy: 57.72%
# Validation Accuracy: 54.46%
# Batch: 0, Loss: 1.4332423210144043
#
# Average loss: 1.3749, Accuracy: 490.0/790 (62%)
#
#
# Average loss: 1.3787, Accuracy: 1753.0/2940 (60%)
#
# Epoch: 5 	Training Accuracy: 62.03%
# Validation Accuracy: 59.63%
# Batch: 0, Loss: 1.4264914989471436
#
# Average loss: 1.3367, Accuracy: 527.0/790 (67%)
#
#
# Average loss: 1.3415, Accuracy: 1884.0/2940 (64%)
#
# Epoch: 6 	Training Accuracy: 66.71%
# Validation Accuracy: 64.08%
# Batch: 0, Loss: 1.351240634918213
#
# Average loss: 1.2988, Accuracy: 559.0/790 (71%)
#
#
# Average loss: 1.3046, Accuracy: 2003.0/2940 (68%)
#
# Epoch: 7 	Training Accuracy: 70.76%
# Validation Accuracy: 68.13%
# Batch: 0, Loss: 1.2980960607528687
#
# Average loss: 1.2614, Accuracy: 585.0/790 (74%)
#
#
# Average loss: 1.2687, Accuracy: 2091.0/2940 (71%)
#
# Epoch: 8 	Training Accuracy: 74.05%
# Validation Accuracy: 71.12%
# Batch: 0, Loss: 1.2904331684112549
#
# Average loss: 1.2236, Accuracy: 606.0/790 (77%)
#
#
# Average loss: 1.2322, Accuracy: 2147.0/2940 (73%)
#
# Epoch: 9 	Training Accuracy: 76.71%
# Validation Accuracy: 73.03%
# Batch: 0, Loss: 1.2449722290039062
#
# Average loss: 1.1865, Accuracy: 623.0/790 (79%)
#
#
# Average loss: 1.1965, Accuracy: 2191.0/2940 (75%)
#
# Epoch: 10 	Training Accuracy: 78.86%
# Validation Accuracy: 74.52%
# Batch: 0, Loss: 1.1566836833953857
#
# Average loss: 1.1500, Accuracy: 627.0/790 (79%)
#
#
# Average loss: 1.1609, Accuracy: 2228.0/2940 (76%)
#
# Epoch: 11 	Training Accuracy: 79.37%
# Validation Accuracy: 75.78%
# Batch: 0, Loss: 1.1631338596343994
#
# Average loss: 1.1137, Accuracy: 629.0/790 (80%)
#
#
# Average loss: 1.1258, Accuracy: 2251.0/2940 (77%)
#
# Epoch: 12 	Training Accuracy: 79.62%
# Validation Accuracy: 76.56%
# Batch: 0, Loss: 1.0683988332748413
#
# Average loss: 1.0776, Accuracy: 637.0/790 (81%)
#
#
# Average loss: 1.0906, Accuracy: 2278.0/2940 (77%)
#
# Epoch: 13 	Training Accuracy: 80.63%
# Validation Accuracy: 77.48%
# Batch: 0, Loss: 1.0957777500152588
#
# Average loss: 1.0425, Accuracy: 640.0/790 (81%)
#
#
# Average loss: 1.0564, Accuracy: 2289.0/2940 (78%)
#
# Epoch: 14 	Training Accuracy: 81.01%
# Validation Accuracy: 77.86%
# Batch: 0, Loss: 1.0465253591537476
#
# Average loss: 1.0079, Accuracy: 647.0/790 (82%)
#
#
# Average loss: 1.0231, Accuracy: 2308.0/2940 (79%)
#
# Epoch: 15 	Training Accuracy: 81.90%
# Validation Accuracy: 78.50%
# Batch: 0, Loss: 1.0347243547439575
#
# Average loss: 0.9741, Accuracy: 653.0/790 (83%)
#
#
# Average loss: 0.9905, Accuracy: 2330.0/2940 (79%)
#
# Epoch: 16 	Training Accuracy: 82.66%
# Validation Accuracy: 79.25%
# Batch: 0, Loss: 1.02504563331604
#
# Average loss: 0.9417, Accuracy: 655.0/790 (83%)
#
#
# Average loss: 0.9584, Accuracy: 2344.0/2940 (80%)
#
# Epoch: 17 	Training Accuracy: 82.91%
# Validation Accuracy: 79.73%
# Batch: 0, Loss: 0.9391558170318604
#
# Average loss: 0.9111, Accuracy: 658.0/790 (83%)
#
#
# Average loss: 0.9280, Accuracy: 2356.0/2940 (80%)
#
# Epoch: 18 	Training Accuracy: 83.29%
# Validation Accuracy: 80.14%
# Batch: 0, Loss: 0.9483197927474976
#
# Average loss: 0.8810, Accuracy: 663.0/790 (84%)
#
#
# Average loss: 0.8985, Accuracy: 2374.0/2940 (81%)
#
# Epoch: 19 	Training Accuracy: 83.92%
# Validation Accuracy: 80.75%
#
# Average loss: 0.8810, Accuracy: 663.0/790 (84%)
#
#
# Average loss: 0.8924, Accuracy: 3943.0/4861 (81%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 47 =========================
# Batch: 0, Loss: 1.5831879377365112
#
# Average loss: 1.5752, Accuracy: 244.0/790 (31%)
#
#
# Average loss: 1.5737, Accuracy: 911.0/2940 (31%)
#
# Epoch: 0 	Training Accuracy: 30.89%
# Validation Accuracy: 30.99%
# Batch: 0, Loss: 1.5895425081253052
#
# Average loss: 1.5360, Accuracy: 290.0/790 (37%)
#
#
# Average loss: 1.5348, Accuracy: 1135.0/2940 (39%)
#
# Epoch: 1 	Training Accuracy: 36.71%
# Validation Accuracy: 38.61%
# Batch: 0, Loss: 1.5425831079483032
#
# Average loss: 1.4978, Accuracy: 358.0/790 (45%)
#
#
# Average loss: 1.4966, Accuracy: 1363.0/2940 (46%)
#
# Epoch: 2 	Training Accuracy: 45.32%
# Validation Accuracy: 46.36%
# Batch: 0, Loss: 1.5222234725952148
#
# Average loss: 1.4602, Accuracy: 423.0/790 (54%)
#
#
# Average loss: 1.4594, Accuracy: 1608.0/2940 (55%)
#
# Epoch: 3 	Training Accuracy: 53.54%
# Validation Accuracy: 54.69%
# Batch: 0, Loss: 1.4477359056472778
#
# Average loss: 1.4224, Accuracy: 491.0/790 (62%)
#
#
# Average loss: 1.4220, Accuracy: 1791.0/2940 (61%)
#
# Epoch: 4 	Training Accuracy: 62.15%
# Validation Accuracy: 60.92%
# Batch: 0, Loss: 1.428511619567871
#
# Average loss: 1.3846, Accuracy: 531.0/790 (67%)
#
#
# Average loss: 1.3847, Accuracy: 1940.0/2940 (66%)
#
# Epoch: 5 	Training Accuracy: 67.22%
# Validation Accuracy: 65.99%
# Batch: 0, Loss: 1.39176344871521
#
# Average loss: 1.3464, Accuracy: 556.0/790 (70%)
#
#
# Average loss: 1.3469, Accuracy: 2038.0/2940 (69%)
#
# Epoch: 6 	Training Accuracy: 70.38%
# Validation Accuracy: 69.32%
# Batch: 0, Loss: 1.3349348306655884
#
# Average loss: 1.3085, Accuracy: 577.0/790 (73%)
#
#
# Average loss: 1.3094, Accuracy: 2074.0/2940 (71%)
#
# Epoch: 7 	Training Accuracy: 73.04%
# Validation Accuracy: 70.54%
# Batch: 0, Loss: 1.3079707622528076
#
# Average loss: 1.2708, Accuracy: 586.0/790 (74%)
#
#
# Average loss: 1.2724, Accuracy: 2124.0/2940 (72%)
#
# Epoch: 8 	Training Accuracy: 74.18%
# Validation Accuracy: 72.24%
# Batch: 0, Loss: 1.3028279542922974
#
# Average loss: 1.2328, Accuracy: 590.0/790 (75%)
#
#
# Average loss: 1.2350, Accuracy: 2173.0/2940 (74%)
#
# Epoch: 9 	Training Accuracy: 74.68%
# Validation Accuracy: 73.91%
# Batch: 0, Loss: 1.2252575159072876
#
# Average loss: 1.1954, Accuracy: 602.0/790 (76%)
#
#
# Average loss: 1.1984, Accuracy: 2202.0/2940 (75%)
#
# Epoch: 10 	Training Accuracy: 76.20%
# Validation Accuracy: 74.90%
# Batch: 0, Loss: 1.2018215656280518
#
# Average loss: 1.1585, Accuracy: 611.0/790 (77%)
#
#
# Average loss: 1.1624, Accuracy: 2236.0/2940 (76%)
#
# Epoch: 11 	Training Accuracy: 77.34%
# Validation Accuracy: 76.05%
# Batch: 0, Loss: 1.1656227111816406
#
# Average loss: 1.1219, Accuracy: 625.0/790 (79%)
#
#
# Average loss: 1.1268, Accuracy: 2259.0/2940 (77%)
#
# Epoch: 12 	Training Accuracy: 79.11%
# Validation Accuracy: 76.84%
# Batch: 0, Loss: 1.15373957157135
#
# Average loss: 1.0862, Accuracy: 633.0/790 (80%)
#
#
# Average loss: 1.0922, Accuracy: 2287.0/2940 (78%)
#
# Epoch: 13 	Training Accuracy: 80.13%
# Validation Accuracy: 77.79%
# Batch: 0, Loss: 1.0656358003616333
#
# Average loss: 1.0513, Accuracy: 642.0/790 (81%)
#
#
# Average loss: 1.0579, Accuracy: 2312.0/2940 (79%)
#
# Epoch: 14 	Training Accuracy: 81.27%
# Validation Accuracy: 78.64%
# Batch: 0, Loss: 1.0352052450180054
#
# Average loss: 1.0170, Accuracy: 649.0/790 (82%)
#
#
# Average loss: 1.0249, Accuracy: 2338.0/2940 (80%)
#
# Epoch: 15 	Training Accuracy: 82.15%
# Validation Accuracy: 79.52%
# Batch: 0, Loss: 1.048287272453308
#
# Average loss: 0.9838, Accuracy: 650.0/790 (82%)
#
#
# Average loss: 0.9929, Accuracy: 2359.0/2940 (80%)
#
# Epoch: 16 	Training Accuracy: 82.28%
# Validation Accuracy: 80.24%
# Batch: 0, Loss: 0.9999966025352478
#
# Average loss: 0.9511, Accuracy: 652.0/790 (83%)
#
#
# Average loss: 0.9610, Accuracy: 2368.0/2940 (81%)
#
# Epoch: 17 	Training Accuracy: 82.53%
# Validation Accuracy: 80.54%
# Batch: 0, Loss: 0.9483798742294312
#
# Average loss: 0.9193, Accuracy: 664.0/790 (84%)
#
#
# Average loss: 0.9303, Accuracy: 2387.0/2940 (81%)
#
# Epoch: 18 	Training Accuracy: 84.05%
# Validation Accuracy: 81.19%
# Batch: 0, Loss: 0.9337351322174072
#
# Average loss: 0.8885, Accuracy: 666.0/790 (84%)
#
#
# Average loss: 0.9000, Accuracy: 2396.0/2940 (81%)
#
# Epoch: 19 	Training Accuracy: 84.30%
# Validation Accuracy: 81.50%
#
# Average loss: 0.8885, Accuracy: 666.0/790 (84%)
#
#
# Average loss: 0.8919, Accuracy: 3994.0/4861 (82%)
# Running seeds for 0.05 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 68 =========================
# Batch: 0, Loss: 1.6534854173660278
#
# Average loss: 1.5288, Accuracy: 501.0/1320 (38%)
#
#
# Average loss: 1.5253, Accuracy: 1142.0/2940 (39%)
#
# Epoch: 0 	Training Accuracy: 37.95%
# Validation Accuracy: 38.84%
# Batch: 0, Loss: 1.5497254133224487
#
# Average loss: 1.4647, Accuracy: 644.0/1320 (49%)
#
#
# Average loss: 1.4632, Accuracy: 1450.0/2940 (49%)
#
# Epoch: 1 	Training Accuracy: 48.79%
# Validation Accuracy: 49.32%
# Batch: 0, Loss: 1.4645545482635498
#
# Average loss: 1.4023, Accuracy: 744.0/1320 (56%)
#
#
# Average loss: 1.4025, Accuracy: 1621.0/2940 (55%)
#
# Epoch: 2 	Training Accuracy: 56.36%
# Validation Accuracy: 55.14%
# Batch: 0, Loss: 1.374414086341858
#
# Average loss: 1.3403, Accuracy: 798.0/1320 (60%)
#
#
# Average loss: 1.3416, Accuracy: 1771.0/2940 (60%)
#
# Epoch: 3 	Training Accuracy: 60.45%
# Validation Accuracy: 60.24%
# Batch: 0, Loss: 1.3516650199890137
#
# Average loss: 1.2786, Accuracy: 851.0/1320 (64%)
#
#
# Average loss: 1.2803, Accuracy: 1882.0/2940 (64%)
#
# Epoch: 4 	Training Accuracy: 64.47%
# Validation Accuracy: 64.01%
# Batch: 0, Loss: 1.2900584936141968
#
# Average loss: 1.2176, Accuracy: 895.0/1320 (68%)
#
#
# Average loss: 1.2201, Accuracy: 1973.0/2940 (67%)
#
# ...
# Batch: 120, Loss: 0.1292545050382614
# Batch: 140, Loss: 0.09883090853691101
# Batch: 160, Loss: 0.11658069491386414
# Batch: 180, Loss: 0.1208408996462822
# Batch: 200, Loss: 0.19927191734313965
#
# Average loss: 0.1319, Accuracy: 24883.0/26038 (96%)
#
#
# Average loss: 0.1505, Accuracy: 2788.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 95.56%
# Validation Accuracy: 94.83%
# Batch: 0, Loss: 0.10954753309488297
# Batch: 20, Loss: 0.1105908751487732
# Batch: 40, Loss: 0.11128466576337814
# Batch: 60, Loss: 0.059017907828092575
# Batch: 80, Loss: 0.12530188262462616
# Batch: 100, Loss: 0.20973628759384155
# Batch: 120, Loss: 0.1278836578130722
# Batch: 140, Loss: 0.13389213383197784
# Batch: 160, Loss: 0.1581331044435501
# Batch: 180, Loss: 0.10286502540111542
# Batch: 200, Loss: 0.11246657371520996
#
# Average loss: 0.1315, Accuracy: 24881.0/26038 (96%)
#
#
# Average loss: 0.1508, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 95.56%
# Validation Accuracy: 95.10%
# Batch: 0, Loss: 0.15323223173618317
# Batch: 20, Loss: 0.08440352231264114
# Batch: 40, Loss: 0.09829167276620865
# Batch: 60, Loss: 0.07251385599374771
# Batch: 80, Loss: 0.27164316177368164
# Batch: 100, Loss: 0.12037550657987595
# Batch: 120, Loss: 0.13564297556877136
# Batch: 140, Loss: 0.09195537120103836
# Batch: 160, Loss: 0.2775680720806122
# Batch: 180, Loss: 0.1619238704442978
# Batch: 200, Loss: 0.1471288949251175
#
# Average loss: 0.1306, Accuracy: 24910.0/26038 (96%)
#
#
# Average loss: 0.1488, Accuracy: 2803.0/2940 (95%)
#
# Epoch: 19 	Training Accuracy: 95.67%
# Validation Accuracy: 95.34%
#
# Average loss: 0.1306, Accuracy: 24910.0/26038 (96%)
#
#
# Average loss: 0.1320, Accuracy: 4643.0/4861 (96%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc_1): Linear(in_features=144, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 57 =========================
# Batch: 0, Loss: 1.6402463912963867
# Batch: 20, Loss: 1.50469172000885
# Batch: 40, Loss: 1.4108922481536865
# Batch: 60, Loss: 1.2773693799972534
# Batch: 80, Loss: 1.1852283477783203
# Batch: 100, Loss: 1.087083339691162
# Batch: 120, Loss: 0.9948885440826416
# Batch: 140, Loss: 0.9257107973098755
# Batch: 160, Loss: 0.7924730181694031
# Batch: 180, Loss: 0.8002409338951111
# Batch: 200, Loss: 0.6111545562744141
#
# Average loss: 0.6639, Accuracy: 22301.0/26038 (86%)
#
#
# Average loss: 0.6706, Accuracy: 2518.0/2940 (86%)
#
# Epoch: 0 	Training Accuracy: 85.65%
# Validation Accuracy: 85.65%
# Batch: 0, Loss: 0.6732175946235657
# Batch: 20, Loss: 0.6206005215644836
# Batch: 40, Loss: 0.5418539047241211
# Batch: 60, Loss: 0.6665036082267761
# Batch: 80, Loss: 0.5234060883522034
# Batch: 100, Loss: 0.5136224031448364
# Batch: 120, Loss: 0.4639497399330139
# Batch: 140, Loss: 0.36990028619766235
# Batch: 160, Loss: 0.3725796341896057
# Batch: 180, Loss: 0.3277488350868225
# Batch: 200, Loss: 0.28243017196655273
#
# Average loss: 0.3794, Accuracy: 23329.0/26038 (90%)
#
#
# Average loss: 0.3917, Accuracy: 2619.0/2940 (89%)
#
# Epoch: 1 	Training Accuracy: 89.60%
# Validation Accuracy: 89.08%
# Batch: 0, Loss: 0.26576435565948486
# Batch: 20, Loss: 0.3422998785972595
# Batch: 40, Loss: 0.3336206376552582
# Batch: 60, Loss: 0.4186474680900574
# Batch: 80, Loss: 0.34983277320861816
# Batch: 100, Loss: 0.21383938193321228
# Batch: 120, Loss: 0.2409757524728775
# Batch: 140, Loss: 0.21664874255657196
# Batch: 160, Loss: 0.2707518935203552
# Batch: 180, Loss: 0.24944061040878296
# Batch: 200, Loss: 0.37043288350105286
#
# Average loss: 0.2877, Accuracy: 23836.0/26038 (92%)
#
#
# Average loss: 0.2989, Accuracy: 2681.0/2940 (91%)
#
# Epoch: 2 	Training Accuracy: 91.54%
# Validation Accuracy: 91.19%
# Batch: 0, Loss: 0.2550109922885895
# Batch: 20, Loss: 0.23265674710273743
# Batch: 40, Loss: 0.24414435029029846
# Batch: 60, Loss: 0.4238424599170685
# Batch: 80, Loss: 0.23770904541015625
# Batch: 100, Loss: 0.21884164214134216
# Batch: 120, Loss: 0.366193562746048
# Batch: 140, Loss: 0.2525924742221832
# Batch: 160, Loss: 0.24226993322372437
# Batch: 180, Loss: 0.23426245152950287
# Batch: 200, Loss: 0.20878392457962036
#
# Average loss: 0.2429, Accuracy: 24129.0/26038 (93%)
#
#
# Average loss: 0.2528, Accuracy: 2704.0/2940 (92%)
#
# Epoch: 3 	Training Accuracy: 92.67%
# Validation Accuracy: 91.97%
# Batch: 0, Loss: 0.29905667901039124
# Batch: 20, Loss: 0.22295765578746796
# Batch: 40, Loss: 0.25406980514526367
# Batch: 60, Loss: 0.23594501614570618
# Batch: 80, Loss: 0.25526922941207886
# Batch: 100, Loss: 0.19400160014629364
# Batch: 120, Loss: 0.2054949849843979
# Batch: 140, Loss: 0.1687822937965393
# Batch: 160, Loss: 0.2957720458507538
# Batch: 180, Loss: 0.18068483471870422
# Batch: 200, Loss: 0.23856502771377563
#
# Average loss: 0.2162, Accuracy: 24271.0/26038 (93%)
#
#
# Average loss: 0.2254, Accuracy: 2734.0/2940 (93%)
#
# Epoch: 4 	Training Accuracy: 93.21%
# Validation Accuracy: 92.99%
# Batch: 0, Loss: 0.15296894311904907
# Batch: 20, Loss: 0.23162412643432617
# Batch: 40, Loss: 0.19633641839027405
# Batch: 60, Loss: 0.18964065611362457
# Batch: 80, Loss: 0.13175061345100403
# Batch: 100, Loss: 0.21497777104377747
# Batch: 120, Loss: 0.18816302716732025
# Batch: 140, Loss: 0.14548617601394653
# Batch: 160, Loss: 0.19481267035007477
# Batch: 180, Loss: 0.18224307894706726
# Batch: 200, Loss: 0.1978532075881958
#
# Average loss: 0.1972, Accuracy: 24427.0/26038 (94%)
#
#
# Average loss: 0.2080, Accuracy: 2753.0/2940 (94%)
#
# Epoch: 5 	Training Accuracy: 93.81%
# Validation Accuracy: 93.64%
# Batch: 0, Loss: 0.15853989124298096
# Batch: 20, Loss: 0.22524137794971466
# Batch: 40, Loss: 0.2762696444988251
# Batch: 60, Loss: 0.2468792200088501
# Batch: 80, Loss: 0.2872202396392822
# Batch: 100, Loss: 0.24912932515144348
# Batch: 120, Loss: 0.13664862513542175
# Batch: 140, Loss: 0.28922238945961
# Batch: 160, Loss: 0.1353175938129425
# Batch: 180, Loss: 0.18160280585289001
# Batch: 200, Loss: 0.2401420772075653
#
# Average loss: 0.1841, Accuracy: 24533.0/26038 (94%)
#
#
# Average loss: 0.1944, Accuracy: 2758.0/2940 (94%)
#
# Epoch: 6 	Training Accuracy: 94.22%
# Validation Accuracy: 93.81%
# Batch: 0, Loss: 0.1389506608247757
# Batch: 20, Loss: 0.1979351043701172
# Batch: 40, Loss: 0.13108663260936737
# Batch: 60, Loss: 0.12870682775974274
# Batch: 80, Loss: 0.22549787163734436
# Batch: 100, Loss: 0.12021980434656143
# Batch: 120, Loss: 0.2778171896934509
# Batch: 140, Loss: 0.16662301123142242
# Batch: 160, Loss: 0.1653311550617218
# Batch: 180, Loss: 0.13566142320632935
# Batch: 200, Loss: 0.21105752885341644
#
# Average loss: 0.1739, Accuracy: 24601.0/26038 (94%)
#
#
# Average loss: 0.1846, Accuracy: 2767.0/2940 (94%)
#
# Epoch: 7 	Training Accuracy: 94.48%
# Validation Accuracy: 94.12%
# Batch: 0, Loss: 0.14227910339832306
# Batch: 20, Loss: 0.13474904000759125
# Batch: 40, Loss: 0.13999910652637482
# Batch: 60, Loss: 0.27157673239707947
# Batch: 80, Loss: 0.18257153034210205
# Batch: 100, Loss: 0.1926790028810501
# Batch: 120, Loss: 0.20397284626960754
# Batch: 140, Loss: 0.12350797653198242
# Batch: 160, Loss: 0.19372573494911194
# Batch: 180, Loss: 0.20201586186885834
# Batch: 200, Loss: 0.2311227172613144
#
# Average loss: 0.1654, Accuracy: 24630.0/26038 (95%)
#
#
# Average loss: 0.1763, Accuracy: 2772.0/2940 (94%)
#
# Epoch: 8 	Training Accuracy: 94.59%
# Validation Accuracy: 94.29%
# Batch: 0, Loss: 0.28530025482177734
# Batch: 20, Loss: 0.09725099802017212
# Batch: 40, Loss: 0.12496410310268402
# Batch: 60, Loss: 0.14274360239505768
# Batch: 80, Loss: 0.12173387408256531
# Batch: 100, Loss: 0.184987872838974
# Batch: 120, Loss: 0.24913905560970306
# Batch: 140, Loss: 0.13938085734844208
# Batch: 160, Loss: 0.16313618421554565
# Batch: 180, Loss: 0.18852923810482025
# Batch: 200, Loss: 0.1620108187198639
#
# Average loss: 0.1598, Accuracy: 24674.0/26038 (95%)
#
#
# Average loss: 0.1720, Accuracy: 2771.0/2940 (94%)
#
# Epoch: 9 	Training Accuracy: 94.76%
# Validation Accuracy: 94.25%
# Batch: 0, Loss: 0.10189492255449295
# Batch: 20, Loss: 0.15891540050506592
# Batch: 40, Loss: 0.164618581533432
# Batch: 60, Loss: 0.24583657085895538
# Batch: 80, Loss: 0.19294200837612152
# Batch: 100, Loss: 0.19174577295780182
# Batch: 120, Loss: 0.10471393167972565
# Batch: 140, Loss: 0.19685547053813934
# Batch: 160, Loss: 0.08064115047454834
# Batch: 180, Loss: 0.13090376555919647
# Batch: 200, Loss: 0.19539320468902588
#
# Average loss: 0.1539, Accuracy: 24701.0/26038 (95%)
#
#
# Average loss: 0.1677, Accuracy: 2773.0/2940 (94%)
#
# Epoch: 10 	Training Accuracy: 94.87%
# Validation Accuracy: 94.32%
# Batch: 0, Loss: 0.17580007016658783
# Batch: 20, Loss: 0.1252049058675766
# Batch: 40, Loss: 0.18281517922878265
# Batch: 60, Loss: 0.2045668661594391
# Batch: 80, Loss: 0.12230493128299713
# Batch: 100, Loss: 0.1205795481801033
# Batch: 120, Loss: 0.2427455186843872
# Batch: 140, Loss: 0.1698831021785736
# Batch: 160, Loss: 0.08690853416919708
# Batch: 180, Loss: 0.155687615275383
# Batch: 200, Loss: 0.14788088202476501
#
# Average loss: 0.1518, Accuracy: 24743.0/26038 (95%)
#
#
# Average loss: 0.1652, Accuracy: 2781.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 95.03%
# Validation Accuracy: 94.59%
# Batch: 0, Loss: 0.18079714477062225
# Batch: 20, Loss: 0.13178730010986328
# Batch: 40, Loss: 0.14136871695518494
# Batch: 60, Loss: 0.1554058939218521
# Batch: 80, Loss: 0.18339671194553375
# Batch: 100, Loss: 0.1501469910144806
# Batch: 120, Loss: 0.11254193633794785
# Batch: 140, Loss: 0.07333605736494064
# Batch: 160, Loss: 0.16130493581295013
# Batch: 180, Loss: 0.10460512340068817
# Batch: 200, Loss: 0.13291333615779877
#
# Average loss: 0.1456, Accuracy: 24766.0/26038 (95%)
#
#
# Average loss: 0.1599, Accuracy: 2783.0/2940 (95%)
#
# Epoch: 12 	Training Accuracy: 95.11%
# Validation Accuracy: 94.66%
# Batch: 0, Loss: 0.20020903646945953
# Batch: 20, Loss: 0.2156062126159668
# Batch: 40, Loss: 0.16371387243270874
# Batch: 60, Loss: 0.116531603038311
# Batch: 80, Loss: 0.2014387995004654
# Batch: 100, Loss: 0.12173484265804291
# Batch: 120, Loss: 0.11014710366725922
# Batch: 140, Loss: 0.13121692836284637
# Batch: 160, Loss: 0.17080166935920715
# Batch: 180, Loss: 0.13658535480499268
# Batch: 200, Loss: 0.1957000494003296
#
# Average loss: 0.1426, Accuracy: 24795.0/26038 (95%)
#
#
# Average loss: 0.1576, Accuracy: 2787.0/2940 (95%)
#
# Epoch: 13 	Training Accuracy: 95.23%
# Validation Accuracy: 94.80%
# Batch: 0, Loss: 0.14780506491661072
# Batch: 20, Loss: 0.08305387943983078
# Batch: 40, Loss: 0.186782106757164
# Batch: 60, Loss: 0.17848573625087738
# Batch: 80, Loss: 0.12059805542230606
# Batch: 100, Loss: 0.08809827268123627
# Batch: 120, Loss: 0.1565849930047989
# Batch: 140, Loss: 0.17294006049633026
# Batch: 160, Loss: 0.13564492762088776
# Batch: 180, Loss: 0.13584855198860168
# Batch: 200, Loss: 0.1557203233242035
#
# Average loss: 0.1422, Accuracy: 24767.0/26038 (95%)
#
#
# Average loss: 0.1587, Accuracy: 2793.0/2940 (95%)
#
# Epoch: 14 	Training Accuracy: 95.12%
# Validation Accuracy: 95.00%
# Batch: 0, Loss: 0.09700506180524826
# Batch: 20, Loss: 0.10655739903450012
# Batch: 40, Loss: 0.19636930525302887
# Batch: 60, Loss: 0.17613473534584045
# Batch: 80, Loss: 0.1301720142364502
# Batch: 100, Loss: 0.2129843533039093
# Batch: 120, Loss: 0.16776564717292786
# Batch: 140, Loss: 0.10971185564994812
# Batch: 160, Loss: 0.1025332361459732
# Batch: 180, Loss: 0.11399853229522705
# Batch: 200, Loss: 0.1088288277387619
#
# Average loss: 0.1388, Accuracy: 24839.0/26038 (95%)
#
#
# Average loss: 0.1561, Accuracy: 2785.0/2940 (95%)
#
# Epoch: 15 	Training Accuracy: 95.40%
# Validation Accuracy: 94.73%
# Batch: 0, Loss: 0.12962189316749573
# Batch: 20, Loss: 0.10629571229219437
# Batch: 40, Loss: 0.22503730654716492
# Batch: 60, Loss: 0.1274729073047638
# Batch: 80, Loss: 0.12920930981636047
# Batch: 100, Loss: 0.12332966923713684
# Batch: 120, Loss: 0.2100519984960556
# Batch: 140, Loss: 0.10368075221776962
# Batch: 160, Loss: 0.12898528575897217
# Batch: 180, Loss: 0.11211458593606949
# Batch: 200, Loss: 0.10559926182031631
#
# Average loss: 0.1379, Accuracy: 24795.0/26038 (95%)
#
#
# Average loss: 0.1546, Accuracy: 2790.0/2940 (95%)
#
# Epoch: 16 	Training Accuracy: 95.23%
# Validation Accuracy: 94.90%
# Batch: 0, Loss: 0.21666909754276276
# Batch: 20, Loss: 0.14058972895145416
# Batch: 40, Loss: 0.09445050358772278
# Batch: 60, Loss: 0.14175917208194733
# Batch: 80, Loss: 0.16243824362754822
# Batch: 100, Loss: 0.20862799882888794
# Batch: 120, Loss: 0.14312686026096344
# Batch: 140, Loss: 0.10441477596759796
# Batch: 160, Loss: 0.13747134804725647
# Batch: 180, Loss: 0.06750049442052841
# Batch: 200, Loss: 0.22556939721107483
#
# Average loss: 0.1329, Accuracy: 24889.0/26038 (96%)
#
#
# Average loss: 0.1512, Accuracy: 2793.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 95.59%
# Validation Accuracy: 95.00%
# Batch: 0, Loss: 0.17036546766757965
# Batch: 20, Loss: 0.14566703140735626
# Batch: 40, Loss: 0.1502181887626648
# Batch: 60, Loss: 0.11069980263710022
# Batch: 80, Loss: 0.08757366240024567
# Batch: 100, Loss: 0.10899181663990021
# Batch: 120, Loss: 0.11109529435634613
# Batch: 140, Loss: 0.08494655787944794
# Batch: 160, Loss: 0.10116619616746902
# Batch: 180, Loss: 0.09719795733690262
# Batch: 200, Loss: 0.11044973880052567
#
# Average loss: 0.1316, Accuracy: 24891.0/26038 (96%)
#
#
# Average loss: 0.1510, Accuracy: 2790.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 95.59%
# Validation Accuracy: 94.90%
# Batch: 0, Loss: 0.11432482302188873
# Batch: 20, Loss: 0.07277233898639679
# Batch: 40, Loss: 0.07496200501918793
# Batch: 60, Loss: 0.07202441245317459
# Batch: 80, Loss: 0.13158778846263885
# Batch: 100, Loss: 0.12677618861198425
# Batch: 120, Loss: 0.14552778005599976
# Batch: 140, Loss: 0.13437429070472717
# Batch: 160, Loss: 0.13069692254066467
# Batch: 180, Loss: 0.12993106245994568
# Batch: 200, Loss: 0.1428559571504593
#
# Average loss: 0.1300, Accuracy: 24888.0/26038 (96%)
#
#
# Average loss: 0.1476, Accuracy: 2798.0/2940 (95%)
#
# Epoch: 19 	Training Accuracy: 95.58%
# Validation Accuracy: 95.17%
#
# Average loss: 0.1300, Accuracy: 24888.0/26038 (96%)
#
#
# Average loss: 0.1300, Accuracy: 4648.0/4861 (96%)
#
# Percentage: 0.01, Seed: 10, Epochs taken: 20
# Percentage: 0.01, Seed: 20, Epochs taken: 20
# Percentage: 0.01, Seed: 30, Epochs taken: 20
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 20
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 20
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 20
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 20
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 20
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 20
# Percentage: 1, Seed: 40, Epochs taken: 20
# Percentage: 1, Seed: 50, Epochs taken: 20

# %%
# End to End - Train Accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Train Accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Train Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Train Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
# End to End - Test Accuracies
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]

plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Test Accuracies
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Test Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Test Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
data_to_save = {
    "results_test_finetune": results_test_finetune,
    "results_train_finetune": results_train_finetune,
    "epochs_taken_finetune": epochs_taken_finetune,
    
    "results_test": results_test,
    "results_train": results_train,
    "epochs_taken": epochs_taken
}

# Assuming data_to_save from the previous code
with open("data.json", "w") as file:
    json.dump(data_to_save, file)

# %%
plt.figure(figsize=(10, 6))

for perc in percentages:
    plt.scatter(epochs_taken[perc], epochs_taken_finetune[perc], label=f'{perc} data')
plt.xlabel('Epochs (End to End)')
plt.ylabel('Epochs (Finetune)')
plt.title('Scatter Plot Comparing Epochs Taken for Convergence')
plt.legend()
plt.show()

# %%
# Given data
percentages = list(epochs_taken.keys())

all_epochs = []
labels = []

for perc in percentages:
    all_epochs.extend([epochs_taken[perc], epochs_taken_finetune[perc]])
    labels.extend([f'{perc} End to End', f'{perc} Finetune'])

# Plotting
plt.figure(figsize=(10, 6))
box = plt.boxplot(all_epochs, labels=labels, patch_artist=True)

# Coloring
colors = ['skyblue', 'lightgreen'] * len(percentages)
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

plt.ylabel('Epochs Taken')
plt.title('Box Plot of Epochs Taken for Each Percentage')
plt.xticks(rotation=90)
plt.show()

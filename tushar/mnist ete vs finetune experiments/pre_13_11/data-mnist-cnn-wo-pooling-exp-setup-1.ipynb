# %% [markdown]
# ***EXPERIMENT SETUP***

# %% [markdown]
# - percentages_set_1 = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
# - dataset: same as before MNIST 5 to 5
#
# - lr pretraining = 0.001
# - lr finetuning = 0.0001
#
# - architecture:
#     - Conv 1 (5,5), channels=1
#     - Relu
#     - Conv 2 (5,5,), channels=1
#     - Relu
#     - Pooling: FALSE
#     - dense( x, x) x=output shape of prev layer (128?)
#     - Relu
#     - dense(x, 5)
#     - softmax
#
# - Freezing: NO
# - Reinitializing: NO for CNN layers. For dense, reinit last dense and softmax, but also try BOTH (time permitting)
#
# - If we don’t save the best model, ES=6
#
# - num train = 20

# %% [markdown]
# ***IMPORTS***

# %%
import numpy as np
import random
import copy
import matplotlib.pyplot as plt
import json

# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from torchvision import datasets, transforms

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from types import SimpleNamespace
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ***UTILS***

# %%
def eval(model, device, dataset_loader, debug=False, classification_report_flag=False, is_cnn=True, logger=print):

    """
    Evaluates the model on the given dataset loader.

    Parameters:
    - model: the PyTorch model to evaluate.
    - device: the device to which tensors should be moved before computation.
    - dataset_loader: DataLoader for evaluation.
    - debug: whether to print debug info like loss and accuracy.
    - classification_report_flag: whether to print a classification report.
    - is_cnn: a flag indicating if the model is a CNN. If it's not, the input data will be reshaped.
    - logger: logging function for printing messages.

    Returns:
    - Accuracy of the model on the provided dataset loader.

    Usage:
    - accuracy = eval(model, device, dataset_loader, debug=False, is_cnn=False, classification_report_flag=False)
    """

    model.eval()
    test_loss, correct = 0., 0.
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data, target in dataset_loader:
            if is_cnn:
              data = data.view(data.size(0), 1, 28, 28)
            else:
              data = data.reshape([data.shape[0], -1])
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(target.cpu().numpy())

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data

    if debug:
        logger('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(test_loss, correct, num_data, 100. * acc))

    if classification_report_flag:
        unique_labels = np.unique(all_labels).tolist()
        logger(classification_report(all_labels, all_preds, labels=unique_labels, target_names=[f'Class {i}' for i in unique_labels]))

    return acc

# %%
class Trainer:

    """
    A class for training and evaluating a model with early stopping and best model saving functionalities.

    Attributes:
    - model: PyTorch model to be trained and evaluated.
    - dataloader: Contains data loaders (train, validation, test) for training and evaluation.
    - params: Dictionary containing various hyperparameters and settings.
    - device: the device to which tensors should be moved before computation.
    - optimizer: The optimizer for training.
    - best_model_state: State dictionary of the best model.
    - max_val_acc: The highest validation accuracy encountered during training.
    - no_improve_epochs: Number of epochs without improvement in validation accuracy.
    - is_cnn: Flag indicating if the model is a CNN.
    - is_debug: Flag indicating if debug information should be printed.
    - classification_report_flag: Flag indicating if a classification report should be generated.

    Methods:
    - train_epoch(): Runs a single epoch of training.
    - evaluate(loader): Evaluates the model on a given data loader.
    - save_best_model(): Saves the current state of the model as the best model.
    - save_checkpoint(epoch, train_acc, val_acc): Saves the current state of the model and other information as a checkpoint.
    - early_stopping_check(val_acc): Checks the stopping criterion and performs actions based on it.
    - train(): Runs the training process for a number of epochs, with early stopping functionality.

    Usage:
    params = {
      'device': 'cuda',
      'lr': 0.001,
      'num_train': 10,
      'early_stop_patience': 3,
      'save_best': True,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': True
    }

    trainer = Trainer(model, dataloader, params)
    train_acc, test_acc, effective_epochs, checkpoints = trainer.train()
    """


    def __init__(self, model, dataloader, params):
        self.model = model
        self.dataloader = dataloader
        self.params = params

        self.device = torch.device(params['device'])
        self.optimizer = optim.Adam(model.parameters(), lr=params['lr'])

        # Initialize best_model_state with the current model state
        self.best_model_state = copy.deepcopy(self.model.state_dict())
        self.max_val_acc = 0.
        self.no_improve_epochs = 0

        self.is_cnn = params.get('is_cnn', False)
        self.is_debug = params.get('is_debug', False)
        self.classification_report_flag = params.get('classification_report_flag', False)
        self.logger = params.get('logger', print)
        
    def train_epoch(self):
      self.model.train()
      for batch_idx, (data, target) in enumerate(self.dataloader.train_loader):

          # Print the size of the current batch
          if self.is_cnn:
            data = data.view(data.size(0), 1, 28, 28)
          else:
            data = data.reshape([data.shape[0], -1])

          data, target = data.to(self.device), target.to(self.device)
          self.optimizer.zero_grad()
          output = self.model(data)
          loss = F.nll_loss(output, target)
          loss.backward()
          self.optimizer.step()

          if self.is_debug and batch_idx % 20 == 0:
              self.logger(f"Batch: {batch_idx}, Loss: {loss.item()}")

    def evaluate(self, loader):
        return eval(self.model, self.device, loader, self.is_debug, self.classification_report_flag, self.is_cnn)

    def save_best_model(self):
        torch.save(self.model.state_dict(), 'best_model.pth')

    def save_checkpoint(self, epoch, train_acc, val_acc):
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'train_acc': train_acc,
            'val_acc': val_acc
        }
        torch.save(checkpoint, f'checkpoint_epoch_{epoch}.pth')
        return checkpoint

    def early_stopping_check(self, val_acc):
        if val_acc > self.max_val_acc:
            self.max_val_acc = val_acc
            self.no_improve_epochs = 0
            # Deep copy the model's state
            self.best_model_state = copy.deepcopy(self.model.state_dict())
            if self.params.get('save_best', False):
                self.save_best_model()
        else:
            self.no_improve_epochs += 1
            if self.no_improve_epochs >= self.params['early_stop_patience']:
                self.logger("Early stopping invoked.")
                # Only load if best_model_state has been set
                if self.best_model_state is not None:
                    self.model.load_state_dict(self.best_model_state)
                return True
        return False

    def train(self):
        effective_epochs = 0
        checkpoints = []

        for epoch in range(self.params['num_train']):
            effective_epochs += 1
            self.train_epoch()

            train_acc = self.evaluate(self.dataloader.train_loader)
            val_acc = self.evaluate(self.dataloader.val_loader)
            self.logger(f'Epoch: {epoch} \tTraining Accuracy: {train_acc*100:.2f}%')
            self.logger(f'Validation Accuracy: {val_acc*100:.2f}%')

            if self.params.get('early_stop_patience', None):
                if self.early_stopping_check(val_acc):
                    self.model.load_state_dict(self.best_model_state)
                    break

            if self.params.get('save_checkpoints', False):
                checkpoint = self.save_checkpoint(epoch, train_acc, val_acc)
                checkpoints.append(checkpoint)

        # Final evaluations
        train_acc = self.evaluate(self.dataloader.train_loader)
        test_acc = self.evaluate(self.dataloader.test_loader)

        return train_acc, test_acc, effective_epochs, checkpoints

# %%
def reduce_dataset(dataloader, percentage, balanced=True, seed=42):

    """
    Reduces the dataset to the given percentage. Can ensure class balance if needed.

    Parameters:
    - dataloader: PyTorch DataLoader object.
    - percentage: Desired percentage of the original dataset.
    - balanced: If True, ensures class balance. If False, reduces randomly.
    - seed: Seed for reproducibility.

    Returns:
    - reduced_dataloader: DataLoader with the reduced dataset.
    """
    # Extract the dataset from the dataloader
    dataset = dataloader.dataset

    # Extract all data and labels from the dataset
    X = [dataset[i][0] for i in range(len(dataset))]
    y = [dataset[i][1] for i in range(len(dataset))]

    # Set the seed for reproducibility
    torch.manual_seed(seed)

    if not balanced:
        # Determine the number of samples to keep
        num_samples = int(len(dataset) * percentage)

        # Randomly select indices without replacement
        indices = torch.randperm(len(dataset))[:num_samples].tolist()

    else:
        # Get unique classes and their counts
        classes, class_counts = torch.unique(torch.tensor(y), return_counts=True)

        # Determine the number of samples per class to keep
        num_samples_per_class = int(len(dataset) * percentage / len(classes))
        indices = []

        for class_label in classes:
            class_indices = [i for i, label in enumerate(y) if label == class_label]

            # Randomly select indices without replacement for each class
            class_selected_indices = torch.randperm(len(class_indices))[:num_samples_per_class].tolist()
            indices.extend([class_indices[i] for i in class_selected_indices])

    # Use a Subset of the original dataset to create a reduced dataset
    reduced_dataset = data.Subset(dataset, indices)

    # Create a DataLoader with the reduced dataset.
    reduced_dataloader = data.DataLoader(reduced_dataset, batch_size=dataloader.batch_size, shuffle=True)

    return reduced_dataloader

# %%
class RelabeledSubset(torch.utils.data.Dataset):
    def __init__(self, dataset, offset):
        self.dataset = dataset
        self.offset = offset

    def __getitem__(self, idx):
        data, label = self.dataset[idx]
        # Offset the label to start from 0
        label = label - self.offset
        return data, label

    def __len__(self):
        return len(self.dataset)

# %%
class TransferLearningMNIST(object):
    def __init__(self, batch_size, input_dim=28*28, val_split=0.1, num_workers=4):
        self.input_dim = input_dim
        self.output_dim = 10
        self.val_split = val_split

        def filter_dataset(dataset, classes):
            indices = [i for i, t in enumerate(dataset.targets) if t in classes]
            return torch.utils.data.Subset(dataset, indices)

        mnist_train_data = datasets.MNIST(
            '../data',
            train=True,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_train_data = filter_dataset(mnist_train_data, list(range(5)))
        finetune_train_data = filter_dataset(mnist_train_data, list(range(5, 10)))

        pretrain_len = len(pretrain_train_data)
        finetune_len = len(finetune_train_data)
        pretrain_val_len = int(val_split * pretrain_len)
        finetune_val_len = int(val_split * finetune_len)
        SEED = 42
        pretrain_train_set, pretrain_val_set = torch.utils.data.random_split(
            pretrain_train_data, [pretrain_len - pretrain_val_len, pretrain_val_len], generator=torch.Generator().manual_seed(SEED))
        finetune_train_set, finetune_val_set = torch.utils.data.random_split(
            finetune_train_data, [finetune_len - finetune_val_len, finetune_val_len], generator=torch.Generator().manual_seed(SEED))

        self.pretrain_train_loader = torch.utils.data.DataLoader(pretrain_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.pretrain_val_loader = torch.utils.data.DataLoader(pretrain_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning datasets
        finetune_train_set = RelabeledSubset(finetune_train_set, 5)
        finetune_val_set = RelabeledSubset(finetune_val_set, 5)

        self.finetune_train_loader = torch.utils.data.DataLoader(finetune_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.finetune_val_loader = torch.utils.data.DataLoader(finetune_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        mnist_test_data = datasets.MNIST(
            '../data',
            train=False,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_test_data = filter_dataset(mnist_test_data, list(range(5)))
        finetune_test_data = filter_dataset(mnist_test_data, list(range(5, 10)))

        self.pretrain_test_loader = torch.utils.data.DataLoader(pretrain_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning test datasets
        finetune_test_data = RelabeledSubset(finetune_test_data, 5)
        self.finetune_test_loader = torch.utils.data.DataLoader(finetune_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        # Complete test loader contains all test examples.
        self.complete_test_loader = torch.utils.data.DataLoader(mnist_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
class TransferLearningMNISTWrapper:
    """
    This wrapper class provides a convenient way to switch between pretraining and fine-tuning phases.

    It allows for changing the phase and accordingly updating the data loaders (train, val, test)
    to either pretraining or fine-tuning sets.
    """
    def __init__(self, transferLearningMNISTObj, phase):
        """
        Initializes the TransferLearningMNISTWrapper object.

        Parameters:
        - transferLearningMNISTObj: An instance of the TransferLearningMNIST class.
        - phase: String indicating the current phase ("pretrain" or "finetune").
        """
        self.transferLearningMNISTObj = transferLearningMNISTObj
        self.phase = phase
        self.input_dim = self.transferLearningMNISTObj.input_dim
        self.output_dim = self.transferLearningMNISTObj.output_dim
        self.update_phase(phase)

    def update_phase(self, phase):
        """
        Updates the phase and the corresponding data loaders.

        Parameters:
        - phase: String indicating the desired phase ("pretrain" or "finetune").

        Throws:
        - ValueError: If the phase is neither "pretrain" nor "finetune".
        """
        self.phase = phase
        if phase == 'pretrain':
            self.train_loader = self.transferLearningMNISTObj.pretrain_train_loader
            self.val_loader = self.transferLearningMNISTObj.pretrain_val_loader
            self.test_loader = self.transferLearningMNISTObj.pretrain_test_loader
        elif phase == 'finetune':
            self.train_loader = self.transferLearningMNISTObj.finetune_train_loader
            self.val_loader = self.transferLearningMNISTObj.finetune_val_loader
            self.test_loader = self.transferLearningMNISTObj.finetune_test_loader
        else:
            raise ValueError('Phase must be either "pretrain" or "finetune".')

    def get_current_phase(self):
      return self.phase

# %%
class CustomCNN(nn.Module):
    def __init__(self, input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling=False):
        super(CustomCNN, self).__init__()

        # Initial number of input channels, assuming grayscale images
        in_channels = 1

        # Dynamically add convolutional and activation layers based on the specified depth
        for i in range(depth):
            # Create a convolutional layer and add it to the model
            setattr(self, f"conv{i}", nn.Conv2d(in_channels, num_channels, kernel_size=kernel_size, padding=1))

            # Create an activation layer (e.g., ReLU) and add it to the model
            setattr(self, f"act{i}", activation_function())

            # Update the input dimensions after convolution
            input_dim = (input_dim - kernel_size + 2 * 1) + 1

            # Optionally add pooling layers to reduce spatial dimensions
            if use_pooling and i % 2 == 0:
                setattr(self, f"pool{i}", nn.MaxPool2d(2))
                input_dim = input_dim // 2

            # Update the input channels for the next convolutional layer
            in_channels = num_channels

        # Compute the size of the flattened features for the fully connected layer
        flattened_size = in_channels * input_dim * input_dim

        # Add two fully connected layers for classification
        self.fc_1 = nn.Linear(flattened_size, hidden_dim_lin)
        self.fc_2 = nn.Linear(hidden_dim_lin, output_dim)

        # Add log softmax layer for multi-class classification output
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
      # Iterate over each module in the CustomCNN class
      for layer_name, layer in self.named_children():
          # Process the input tensor through convolutional and activation layers
          if "conv" in layer_name or "act" in layer_name:
              x = layer(x)
          # Process the input tensor through pooling layers if they exist
          elif "pool" in layer_name:
              x = layer(x)
          # If reached fully connected layers, break the loop
          elif isinstance(layer, nn.Linear):
              break

      # Flatten the tensor to fit the input shape of the fully connected layers
      x = x.view(x.size(0), -1)

      # Pass the tensor through the fully connected layers
      x = self.fc_1(x)
      x = self.fc_2(x)

      # Return log softmax activated output
      return self.logsoftmax(x)

# %%
def generate_cnn(input_dim, output_dim, depth, num_channels, hidden_dim_lin, kernel_size, activation_function=nn.ReLU, use_pooling=False):
    model = CustomCNN(input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling)
    return model

# %% [markdown]
# ***PRE-TRAINING***

# %%
batch_size = 128

dataloader = TransferLearningMNIST(batch_size)
dataloader_wrapped = TransferLearningMNISTWrapper(dataloader, phase = 'pretrain')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 100840206.47it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 48031599.45it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 26690741.44it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 22815004.51it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw

# %%
a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        break

# %%
params = {
      'depth': 2,
      'width': 1,
      'hidden_dim_lin': 128,
      'activation_function': nn.ReLU,
      'kernel_size': 5,
      'device': device,
      'lr': 0.001,
      'num_train': 20,
      'early_stop_patience': 6,
      'save_best': True,
      'save_checkpoints': True,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': False
    }

# Create DNN model
model = generate_cnn(input_dim = 28, output_dim = 10, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=False)
model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
# Train and evaluate
trainer = Trainer(model, dataloader_wrapped, params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Batch: 0, Loss: 2.3195724487304688
# Batch: 20, Loss: 1.5118052959442139
# Batch: 40, Loss: 1.148066759109497
# Batch: 60, Loss: 0.7694644927978516
# Batch: 80, Loss: 0.8376663327217102
# Batch: 100, Loss: 0.47078055143356323
# Batch: 120, Loss: 0.5356427431106567
# Batch: 140, Loss: 0.2543295621871948
# Batch: 160, Loss: 0.2486434429883957
# Batch: 180, Loss: 0.296596884727478
# Batch: 200, Loss: 0.26261380314826965
#
# Average loss: 0.2215, Accuracy: 25718.0/27537 (93%)
#
#
# Average loss: 0.2558, Accuracy: 2825.0/3059 (92%)
#
# Epoch: 0 	Training Accuracy: 93.39%
# Validation Accuracy: 92.35%
# Batch: 0, Loss: 0.1706545054912567
# Batch: 20, Loss: 0.2209516167640686
# Batch: 40, Loss: 0.21629339456558228
# Batch: 60, Loss: 0.15593411028385162
# Batch: 80, Loss: 0.15851759910583496
# Batch: 100, Loss: 0.19774112105369568
# Batch: 120, Loss: 0.14826051890850067
# Batch: 140, Loss: 0.10639920085668564
# Batch: 160, Loss: 0.07648249715566635
# Batch: 180, Loss: 0.13312485814094543
# Batch: 200, Loss: 0.09313280880451202
#
# Average loss: 0.1465, Accuracy: 26376.0/27537 (96%)
#
#
# Average loss: 0.1734, Accuracy: 2915.0/3059 (95%)
#
# Epoch: 1 	Training Accuracy: 95.78%
# Validation Accuracy: 95.29%
# Batch: 0, Loss: 0.15764914453029633
# Batch: 20, Loss: 0.21292626857757568
# Batch: 40, Loss: 0.05885311961174011
# Batch: 60, Loss: 0.07533296197652817
# Batch: 80, Loss: 0.09286343306303024
# Batch: 100, Loss: 0.08554797619581223
# Batch: 120, Loss: 0.10297413170337677
# Batch: 140, Loss: 0.08800116926431656
# Batch: 160, Loss: 0.1460975855588913
# Batch: 180, Loss: 0.29615822434425354
# Batch: 200, Loss: 0.26748061180114746
#
# Average loss: 0.1106, Accuracy: 26582.0/27537 (97%)
#
#
# Average loss: 0.1342, Accuracy: 2927.0/3059 (96%)
#
# Epoch: 2 	Training Accuracy: 96.53%
# Validation Accuracy: 95.68%
# Batch: 0, Loss: 0.13782230019569397
# Batch: 20, Loss: 0.06296385824680328
# Batch: 40, Loss: 0.07937084883451462
# Batch: 60, Loss: 0.08579172939062119
# Batch: 80, Loss: 0.12375642359256744
# Batch: 100, Loss: 0.2316984236240387
# Batch: 120, Loss: 0.09257130324840546
# Batch: 140, Loss: 0.1157459244132042
# Batch: 160, Loss: 0.10339891910552979
# Batch: 180, Loss: 0.09989364445209503
# Batch: 200, Loss: 0.03841905668377876
#
# Average loss: 0.1034, Accuracy: 26703.0/27537 (97%)
#
#
# Average loss: 0.1281, Accuracy: 2943.0/3059 (96%)
#
# Epoch: 3 	Training Accuracy: 96.97%
# Validation Accuracy: 96.21%
# Batch: 0, Loss: 0.06456756591796875
# Batch: 20, Loss: 0.09624528139829636
# Batch: 40, Loss: 0.13373249769210815
# Batch: 60, Loss: 0.07190058380365372
# Batch: 80, Loss: 0.048705894500017166
# Batch: 100, Loss: 0.12170635163784027
# Batch: 120, Loss: 0.019139321520924568
# Batch: 140, Loss: 0.10101784765720367
# Batch: 160, Loss: 0.19311244785785675
# Batch: 180, Loss: 0.1316976100206375
# Batch: 200, Loss: 0.09537582099437714
#
# Average loss: 0.0921, Accuracy: 26751.0/27537 (97%)
#
#
# Average loss: 0.1171, Accuracy: 2939.0/3059 (96%)
#
# Epoch: 4 	Training Accuracy: 97.15%
# Validation Accuracy: 96.08%
# Batch: 0, Loss: 0.08630736917257309
# Batch: 20, Loss: 0.08475573360919952
# Batch: 40, Loss: 0.12301816046237946
# Batch: 60, Loss: 0.044284604489803314
# Batch: 80, Loss: 0.060361359268426895
# Batch: 100, Loss: 0.09209483116865158
# Batch: 120, Loss: 0.11471416801214218
# Batch: 140, Loss: 0.09703467786312103
# Batch: 160, Loss: 0.1614210605621338
# Batch: 180, Loss: 0.10559247434139252
# Batch: 200, Loss: 0.07391136139631271
#
# Average loss: 0.0917, Accuracy: 26727.0/27537 (97%)
#
#
# Average loss: 0.1171, Accuracy: 2945.0/3059 (96%)
#
# Epoch: 5 	Training Accuracy: 97.06%
# Validation Accuracy: 96.27%
# Batch: 0, Loss: 0.0429874062538147
# Batch: 20, Loss: 0.06398939341306686
# Batch: 40, Loss: 0.1081589087843895
# Batch: 60, Loss: 0.07094752043485641
# Batch: 80, Loss: 0.025209510698914528
# Batch: 100, Loss: 0.10194072127342224
# Batch: 120, Loss: 0.1046881377696991
# Batch: 140, Loss: 0.029256366193294525
# Batch: 160, Loss: 0.09410092234611511
# Batch: 180, Loss: 0.013966674916446209
# Batch: 200, Loss: 0.11612515151500702
#
# Average loss: 0.0850, Accuracy: 26842.0/27537 (97%)
#
#
# Average loss: 0.1116, Accuracy: 2954.0/3059 (97%)
#
# Epoch: 6 	Training Accuracy: 97.48%
# Validation Accuracy: 96.57%
# Batch: 0, Loss: 0.11072754114866257
# Batch: 20, Loss: 0.15053458511829376
# Batch: 40, Loss: 0.12294207513332367
# Batch: 60, Loss: 0.03348080441355705
# Batch: 80, Loss: 0.09249572455883026
# Batch: 100, Loss: 0.11066213250160217
# Batch: 120, Loss: 0.03368149325251579
# Batch: 140, Loss: 0.12632738053798676
# Batch: 160, Loss: 0.05404968559741974
# Batch: 180, Loss: 0.06969983875751495
# Batch: 200, Loss: 0.022312387824058533
#
# Average loss: 0.0854, Accuracy: 26796.0/27537 (97%)
#
#
# Average loss: 0.1126, Accuracy: 2958.0/3059 (97%)
#
# Epoch: 7 	Training Accuracy: 97.31%
# Validation Accuracy: 96.70%
# Batch: 0, Loss: 0.04728413000702858
# Batch: 20, Loss: 0.11876681447029114
# Batch: 40, Loss: 0.11878475546836853
# Batch: 60, Loss: 0.0704931691288948
# Batch: 80, Loss: 0.13058310747146606
# Batch: 100, Loss: 0.19525475800037384
# Batch: 120, Loss: 0.03145146742463112
# Batch: 140, Loss: 0.09583597630262375
# Batch: 160, Loss: 0.08916115760803223
# Batch: 180, Loss: 0.061469580978155136
# Batch: 200, Loss: 0.14128151535987854
#
# Average loss: 0.0798, Accuracy: 26854.0/27537 (98%)
#
#
# Average loss: 0.1092, Accuracy: 2949.0/3059 (96%)
#
# Epoch: 8 	Training Accuracy: 97.52%
# Validation Accuracy: 96.40%
# Batch: 0, Loss: 0.16002647578716278
# Batch: 20, Loss: 0.2677799165248871
# Batch: 40, Loss: 0.10078694671392441
# Batch: 60, Loss: 0.09318989515304565
# Batch: 80, Loss: 0.04792031645774841
# Batch: 100, Loss: 0.015498396009206772
# Batch: 120, Loss: 0.03052263706922531
# Batch: 140, Loss: 0.06662116944789886
# Batch: 160, Loss: 0.05190172791481018
# Batch: 180, Loss: 0.10479333251714706
# Batch: 200, Loss: 0.05312404781579971
#
# Average loss: 0.0875, Accuracy: 26742.0/27537 (97%)
#
#
# Average loss: 0.1174, Accuracy: 2951.0/3059 (96%)
#
# Epoch: 9 	Training Accuracy: 97.11%
# Validation Accuracy: 96.47%
# Batch: 0, Loss: 0.11929350346326828
# Batch: 20, Loss: 0.09413474798202515
# Batch: 40, Loss: 0.15339922904968262
# Batch: 60, Loss: 0.18982240557670593
# Batch: 80, Loss: 0.047241467982530594
# Batch: 100, Loss: 0.12289080768823624
# Batch: 120, Loss: 0.04585397616028786
# Batch: 140, Loss: 0.10374992340803146
# Batch: 160, Loss: 0.06020479276776314
# Batch: 180, Loss: 0.07419170439243317
# Batch: 200, Loss: 0.06275004893541336
#
# Average loss: 0.0756, Accuracy: 26888.0/27537 (98%)
#
#
# Average loss: 0.1031, Accuracy: 2967.0/3059 (97%)
#
# Epoch: 10 	Training Accuracy: 97.64%
# Validation Accuracy: 96.99%
# Batch: 0, Loss: 0.03742586448788643
# Batch: 20, Loss: 0.1311511993408203
# Batch: 40, Loss: 0.04963255673646927
# Batch: 60, Loss: 0.06657829880714417
# Batch: 80, Loss: 0.039445508271455765
# Batch: 100, Loss: 0.06970188766717911
# Batch: 120, Loss: 0.1630837619304657
# Batch: 140, Loss: 0.1274755895137787
# Batch: 160, Loss: 0.08501195907592773
# Batch: 180, Loss: 0.016933025792241096
# Batch: 200, Loss: 0.05687674134969711
#
# Average loss: 0.0891, Accuracy: 26820.0/27537 (97%)
#
#
# Average loss: 0.1173, Accuracy: 2959.0/3059 (97%)
#
# Epoch: 11 	Training Accuracy: 97.40%
# Validation Accuracy: 96.73%
# Batch: 0, Loss: 0.032332662492990494
# Batch: 20, Loss: 0.12315703183412552
# Batch: 40, Loss: 0.12370063364505768
# Batch: 60, Loss: 0.10242606699466705
# Batch: 80, Loss: 0.10025613754987717
# Batch: 100, Loss: 0.06467204540967941
# Batch: 120, Loss: 0.058628976345062256
# Batch: 140, Loss: 0.041871290653944016
# Batch: 160, Loss: 0.06765109300613403
# Batch: 180, Loss: 0.15944497287273407
# Batch: 200, Loss: 0.08681480586528778
#
# Average loss: 0.0725, Accuracy: 26915.0/27537 (98%)
#
#
# Average loss: 0.1038, Accuracy: 2962.0/3059 (97%)
#
# Epoch: 12 	Training Accuracy: 97.74%
# Validation Accuracy: 96.83%
# Batch: 0, Loss: 0.050276074558496475
# Batch: 20, Loss: 0.07479659467935562
# Batch: 40, Loss: 0.05573001131415367
# Batch: 60, Loss: 0.07195807248353958
# Batch: 80, Loss: 0.060696594417095184
# Batch: 100, Loss: 0.08667250722646713
# Batch: 120, Loss: 0.12528198957443237
# Batch: 140, Loss: 0.122061587870121
# Batch: 160, Loss: 0.03203267976641655
# Batch: 180, Loss: 0.12486103177070618
# Batch: 200, Loss: 0.04032272472977638
#
# Average loss: 0.0707, Accuracy: 26920.0/27537 (98%)
#
#
# Average loss: 0.1041, Accuracy: 2967.0/3059 (97%)
#
# Epoch: 13 	Training Accuracy: 97.76%
# Validation Accuracy: 96.99%
# Batch: 0, Loss: 0.10123883932828903
# Batch: 20, Loss: 0.11251675337553024
# Batch: 40, Loss: 0.029410315677523613
# Batch: 60, Loss: 0.11815149337053299
# Batch: 80, Loss: 0.0550970733165741
# Batch: 100, Loss: 0.17313677072525024
# Batch: 120, Loss: 0.11062701791524887
# Batch: 140, Loss: 0.15097634494304657
# Batch: 160, Loss: 0.06246189773082733
# Batch: 180, Loss: 0.050952352583408356
# Batch: 200, Loss: 0.055753014981746674
#
# Average loss: 0.0770, Accuracy: 26836.0/27537 (97%)
#
#
# Average loss: 0.1130, Accuracy: 2962.0/3059 (97%)
#
# Epoch: 14 	Training Accuracy: 97.45%
# Validation Accuracy: 96.83%
# Batch: 0, Loss: 0.061385516077280045
# Batch: 20, Loss: 0.07447244971990585
# Batch: 40, Loss: 0.047014910727739334
# Batch: 60, Loss: 0.0597282350063324
# Batch: 80, Loss: 0.0747726783156395
# Batch: 100, Loss: 0.052711158990859985
# Batch: 120, Loss: 0.047655217349529266
# Batch: 140, Loss: 0.11091701686382294
# Batch: 160, Loss: 0.050083089619874954
# Batch: 180, Loss: 0.04938669130206108
# Batch: 200, Loss: 0.020670318976044655
#
# Average loss: 0.0691, Accuracy: 26928.0/27537 (98%)
#
#
# Average loss: 0.1016, Accuracy: 2964.0/3059 (97%)
#
# Epoch: 15 	Training Accuracy: 97.79%
# Validation Accuracy: 96.89%
# Batch: 0, Loss: 0.043346766382455826
# Batch: 20, Loss: 0.04195665940642357
# Batch: 40, Loss: 0.05976627767086029
# Batch: 60, Loss: 0.052648670971393585
# Batch: 80, Loss: 0.08737949281930923
# Batch: 100, Loss: 0.12428002059459686
# Batch: 120, Loss: 0.04627647250890732
# Batch: 140, Loss: 0.04386569932103157
# Batch: 160, Loss: 0.031205439940094948
# Batch: 180, Loss: 0.04459170997142792
# Batch: 200, Loss: 0.10398346185684204
#
# Average loss: 0.0669, Accuracy: 26945.0/27537 (98%)
#
#
# Average loss: 0.1002, Accuracy: 2970.0/3059 (97%)
#
# Epoch: 16 	Training Accuracy: 97.85%
# Validation Accuracy: 97.09%
# Batch: 0, Loss: 0.028783416375517845
# Batch: 20, Loss: 0.061673250049352646
# Batch: 40, Loss: 0.026917003095149994
# Batch: 60, Loss: 0.05553164705634117
# Batch: 80, Loss: 0.094733826816082
# Batch: 100, Loss: 0.08222014456987381
# Batch: 120, Loss: 0.11826864629983902
# Batch: 140, Loss: 0.06330040842294693
# Batch: 160, Loss: 0.03736948221921921
# Batch: 180, Loss: 0.0567173957824707
# Batch: 200, Loss: 0.049222223460674286
#
# Average loss: 0.0635, Accuracy: 26985.0/27537 (98%)
#
#
# Average loss: 0.1007, Accuracy: 2975.0/3059 (97%)
#
# Epoch: 17 	Training Accuracy: 98.00%
# Validation Accuracy: 97.25%
# Batch: 0, Loss: 0.044231295585632324
# Batch: 20, Loss: 0.025893336161971092
# Batch: 40, Loss: 0.09530497342348099
# Batch: 60, Loss: 0.02770078368484974
# Batch: 80, Loss: 0.011762143112719059
# Batch: 100, Loss: 0.021358594298362732
# Batch: 120, Loss: 0.025669969618320465
# Batch: 140, Loss: 0.041140004992485046
# Batch: 160, Loss: 0.0783504918217659
# Batch: 180, Loss: 0.07678964734077454
# Batch: 200, Loss: 0.11130359023809433
#
# Average loss: 0.0693, Accuracy: 26936.0/27537 (98%)
#
#
# Average loss: 0.1005, Accuracy: 2969.0/3059 (97%)
#
# Epoch: 18 	Training Accuracy: 97.82%
# Validation Accuracy: 97.06%
# Batch: 0, Loss: 0.06917497515678406
# Batch: 20, Loss: 0.03215174376964569
# Batch: 40, Loss: 0.06936367601156235
# Batch: 60, Loss: 0.029545124620199203
# Batch: 80, Loss: 0.04110638052225113
# Batch: 100, Loss: 0.061011627316474915
# Batch: 120, Loss: 0.0855751782655716
# Batch: 140, Loss: 0.09335698187351227
# Batch: 160, Loss: 0.11236274242401123
# Batch: 180, Loss: 0.020826430991292
# Batch: 200, Loss: 0.015192298218607903
#
# Average loss: 0.0634, Accuracy: 26987.0/27537 (98%)
#
#
# Average loss: 0.0961, Accuracy: 2974.0/3059 (97%)
#
# Epoch: 19 	Training Accuracy: 98.00%
# Validation Accuracy: 97.22%
#
# Average loss: 0.0634, Accuracy: 26987.0/27537 (98%)
#
#
# Average loss: 0.0717, Accuracy: 5030.0/5139 (98%)
#
# Final Training Accuracy: 0.9800
# Final Test Accuracy: 0.9788

# %%
accuracy = eval(model, device, dataloader_wrapped.test_loader, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
# Out:
# Average loss: 0.0717, Accuracy: 5030.0/5139 (98%)

# %%
def effective_rank(singular_values):
    normalized_singular_values = singular_values / np.sum(singular_values)
    entropy = -np.sum(normalized_singular_values * np.log(normalized_singular_values))
    eff_rank = np.exp(entropy)
    return eff_rank

def plot_layer_effective_ranks(model, print_ranks=True):
    effective_ranks = []
    layer_names = []

    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            singular_values = np.linalg.svd(weight_matrix, compute_uv=False)
            eff_rank = effective_rank(singular_values)
            effective_ranks.append(eff_rank)
            layer_names.append(name)

    if print_ranks:
        for layer_name, eff_rank in zip(layer_names, effective_ranks):
            print(f'{layer_name}: {eff_rank:.4f}')

    # Plotting
    plt.figure(figsize=(15, 5))
    plt.bar(layer_names, effective_ranks, color='green')
    plt.xlabel('Layer')
    plt.ylabel('Effective Rank')
    plt.title('Effective Rank of Weight Matrices for Each Layer')
    plt.grid(True)

    y_max = np.max(effective_ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(effective_ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(0, int(y_max)+2, step=2))  # Set yticks

    plt.show()

# Example usage
plot_layer_effective_ranks(model)  # Note: You'll need to define or load 'model' before calling this function
# Out:
# conv0.weight: 3.8276
# conv1.weight: 3.5931
# fc_1.weight: 74.5929
# fc_2.weight: 8.5340

# %% [markdown]
# ----

# %% [markdown]
# # Finetuning experiments

# %%
dataloader_wrapped.update_phase('finetune')

a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        print('-------------')
        break
# Out:
# -------------

# %% [markdown]
# ## Baseline model: end2end with the same architecture as the preatining model

# %%
# 2. Create a new model and copy weights from the original model, then adjust the final layer
print("Current dataloader phase: ", dataloader_wrapped.get_current_phase())

model_finetuning_baseline = generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=False)
model_finetuning_baseline.to(device)

# dataloader_wrapped.update_phase('finetune')
# Train and evaluate the new model on the new data
# train_acc_new, test_acc_new, model_finetuning_baseline, _,_ = compute_training_acc_epochs_cnn(model_finetuning_baseline, dataloader_wrapped, params, debug=True)

trainer = Trainer(model, dataloader_wrapped, params)
train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
print(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")
# Out:
# Current dataloader phase:  finetune
# Batch: 0, Loss: 4.701102256774902
# Batch: 20, Loss: 1.167060375213623
# Batch: 40, Loss: 0.8232892155647278
# Batch: 60, Loss: 0.5789087414741516
# Batch: 80, Loss: 0.5112910270690918
# Batch: 100, Loss: 0.35809800028800964
# Batch: 120, Loss: 0.3547667860984802
# Batch: 140, Loss: 0.3381081521511078
# Batch: 160, Loss: 0.3071092963218689
# Batch: 180, Loss: 0.40613943338394165
# Batch: 200, Loss: 0.22907514870166779
#
# Average loss: 0.2699, Accuracy: 24065.0/26464 (91%)
#
#
# Average loss: 0.2921, Accuracy: 2657.0/2940 (90%)
#
# Epoch: 0 	Training Accuracy: 90.93%
# Validation Accuracy: 90.37%
# Batch: 0, Loss: 0.2720005214214325
# Batch: 20, Loss: 0.25553178787231445
# Batch: 40, Loss: 0.293499231338501
# Batch: 60, Loss: 0.2103414535522461
# Batch: 80, Loss: 0.3182205259799957
# Batch: 100, Loss: 0.23739247024059296
# Batch: 120, Loss: 0.23499295115470886
# Batch: 140, Loss: 0.3002140522003174
# Batch: 160, Loss: 0.13583087921142578
# Batch: 180, Loss: 0.18022999167442322
# Batch: 200, Loss: 0.15633705258369446
#
# Average loss: 0.1946, Accuracy: 24732.0/26464 (93%)
#
#
# Average loss: 0.2119, Accuracy: 2731.0/2940 (93%)
#
# Epoch: 1 	Training Accuracy: 93.46%
# Validation Accuracy: 92.89%
# Batch: 0, Loss: 0.07615676522254944
# Batch: 20, Loss: 0.26871585845947266
# Batch: 40, Loss: 0.20084427297115326
# Batch: 60, Loss: 0.22894316911697388
# Batch: 80, Loss: 0.21618720889091492
# Batch: 100, Loss: 0.1247987374663353
# Batch: 120, Loss: 0.22179704904556274
# Batch: 140, Loss: 0.1615229696035385
# Batch: 160, Loss: 0.1418832540512085
# Batch: 180, Loss: 0.10952183604240417
# Batch: 200, Loss: 0.14855797588825226
#
# Average loss: 0.1716, Accuracy: 24910.0/26464 (94%)
#
#
# Average loss: 0.1950, Accuracy: 2739.0/2940 (93%)
#
# Epoch: 2 	Training Accuracy: 94.13%
# Validation Accuracy: 93.16%
# Batch: 0, Loss: 0.1751246452331543
# Batch: 20, Loss: 0.264248251914978
# Batch: 40, Loss: 0.2618848383426666
# Batch: 60, Loss: 0.1339118629693985
# Batch: 80, Loss: 0.13162168860435486
# Batch: 100, Loss: 0.11731722950935364
# Batch: 120, Loss: 0.1638781726360321
# Batch: 140, Loss: 0.12772555649280548
# Batch: 160, Loss: 0.21840469539165497
# Batch: 180, Loss: 0.15099923312664032
# Batch: 200, Loss: 0.22397968173027039
#
# Average loss: 0.1524, Accuracy: 25172.0/26464 (95%)
#
#
# Average loss: 0.1716, Accuracy: 2772.0/2940 (94%)
#
# Epoch: 3 	Training Accuracy: 95.12%
# Validation Accuracy: 94.29%
# Batch: 0, Loss: 0.17644281685352325
# Batch: 20, Loss: 0.15812401473522186
# Batch: 40, Loss: 0.16266438364982605
# Batch: 60, Loss: 0.25971096754074097
# Batch: 80, Loss: 0.11257567256689072
# Batch: 100, Loss: 0.08025406301021576
# Batch: 120, Loss: 0.10874588042497635
# Batch: 140, Loss: 0.10455641150474548
# Batch: 160, Loss: 0.10168798267841339
# Batch: 180, Loss: 0.16343548893928528
# Batch: 200, Loss: 0.27264702320098877
#
# Average loss: 0.1410, Accuracy: 25247.0/26464 (95%)
#
#
# Average loss: 0.1650, Accuracy: 2780.0/2940 (95%)
#
# Epoch: 4 	Training Accuracy: 95.40%
# Validation Accuracy: 94.56%
# Batch: 0, Loss: 0.10628463327884674
# Batch: 20, Loss: 0.17569613456726074
# Batch: 40, Loss: 0.16009677946567535
# Batch: 60, Loss: 0.1536300629377365
# Batch: 80, Loss: 0.15776091814041138
# Batch: 100, Loss: 0.07999423146247864
# Batch: 120, Loss: 0.13709208369255066
# Batch: 140, Loss: 0.09640832245349884
# Batch: 160, Loss: 0.06710869818925858
# Batch: 180, Loss: 0.16837403178215027
# Batch: 200, Loss: 0.14527198672294617
#
# Average loss: 0.1326, Accuracy: 25327.0/26464 (96%)
#
#
# Average loss: 0.1584, Accuracy: 2794.0/2940 (95%)
#
# Epoch: 5 	Training Accuracy: 95.70%
# Validation Accuracy: 95.03%
# Batch: 0, Loss: 0.21995675563812256
# Batch: 20, Loss: 0.11728925257921219
# Batch: 40, Loss: 0.05980256199836731
# Batch: 60, Loss: 0.12249977141618729
# Batch: 80, Loss: 0.08020954579114914
# Batch: 100, Loss: 0.15737448632717133
# Batch: 120, Loss: 0.09729278832674026
# Batch: 140, Loss: 0.04536368325352669
# Batch: 160, Loss: 0.09910912811756134
# Batch: 180, Loss: 0.1632021814584732
# Batch: 200, Loss: 0.21595372259616852
#
# Average loss: 0.1263, Accuracy: 25327.0/26464 (96%)
#
#
# Average loss: 0.1538, Accuracy: 2792.0/2940 (95%)
#
# Epoch: 6 	Training Accuracy: 95.70%
# Validation Accuracy: 94.97%
# Batch: 0, Loss: 0.12432077527046204
# Batch: 20, Loss: 0.08712811768054962
# Batch: 40, Loss: 0.059674523770809174
# Batch: 60, Loss: 0.15855303406715393
# Batch: 80, Loss: 0.12759719789028168
# Batch: 100, Loss: 0.2778860926628113
# Batch: 120, Loss: 0.11064077168703079
# Batch: 140, Loss: 0.12097012996673584
# Batch: 160, Loss: 0.10816575586795807
# Batch: 180, Loss: 0.19851326942443848
# Batch: 200, Loss: 0.1971925050020218
#
# Average loss: 0.1192, Accuracy: 25401.0/26464 (96%)
#
#
# Average loss: 0.1505, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 95.98%
# Validation Accuracy: 95.10%
# Batch: 0, Loss: 0.09479162096977234
# Batch: 20, Loss: 0.16806364059448242
# Batch: 40, Loss: 0.12802718579769135
# Batch: 60, Loss: 0.23405605554580688
# Batch: 80, Loss: 0.06990213692188263
# Batch: 100, Loss: 0.10758449882268906
# Batch: 120, Loss: 0.1293654888868332
# Batch: 140, Loss: 0.1631588637828827
# Batch: 160, Loss: 0.09220986068248749
# Batch: 180, Loss: 0.2084054946899414
# Batch: 200, Loss: 0.09621790051460266
#
# Average loss: 0.1130, Accuracy: 25471.0/26464 (96%)
#
#
# Average loss: 0.1463, Accuracy: 2812.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 96.25%
# Validation Accuracy: 95.65%
# Batch: 0, Loss: 0.09781958162784576
# Batch: 20, Loss: 0.061143018305301666
# Batch: 40, Loss: 0.09575902670621872
# Batch: 60, Loss: 0.08805637061595917
# Batch: 80, Loss: 0.08563835918903351
# Batch: 100, Loss: 0.128457710146904
# Batch: 120, Loss: 0.08090540021657944
# Batch: 140, Loss: 0.10365808010101318
# Batch: 160, Loss: 0.07986889779567719
# Batch: 180, Loss: 0.10118681937456131
# Batch: 200, Loss: 0.1415063738822937
#
# Average loss: 0.1095, Accuracy: 25509.0/26464 (96%)
#
#
# Average loss: 0.1414, Accuracy: 2808.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 96.39%
# Validation Accuracy: 95.51%
# Batch: 0, Loss: 0.0379318930208683
# Batch: 20, Loss: 0.08592792600393295
# Batch: 40, Loss: 0.07518088072538376
# Batch: 60, Loss: 0.043584417551755905
# Batch: 80, Loss: 0.1281418651342392
# Batch: 100, Loss: 0.06900002807378769
# Batch: 120, Loss: 0.1594104915857315
# Batch: 140, Loss: 0.10507150739431381
# Batch: 160, Loss: 0.07219595462083817
# Batch: 180, Loss: 0.06733578443527222
# Batch: 200, Loss: 0.13240274786949158
#
# Average loss: 0.0972, Accuracy: 25624.0/26464 (97%)
#
#
# Average loss: 0.1338, Accuracy: 2811.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 96.83%
# Validation Accuracy: 95.61%
# Batch: 0, Loss: 0.05248641222715378
# Batch: 20, Loss: 0.10586242377758026
# Batch: 40, Loss: 0.13269004225730896
# Batch: 60, Loss: 0.09400167316198349
# Batch: 80, Loss: 0.15487074851989746
# Batch: 100, Loss: 0.0702151283621788
# Batch: 120, Loss: 0.07087069004774094
# Batch: 140, Loss: 0.1268867701292038
# Batch: 160, Loss: 0.107979416847229
# Batch: 180, Loss: 0.10705750435590744
# Batch: 200, Loss: 0.029278939589858055
#
# Average loss: 0.0975, Accuracy: 25609.0/26464 (97%)
#
#
# Average loss: 0.1342, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 11 	Training Accuracy: 96.77%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.07876288145780563
# Batch: 20, Loss: 0.08318382501602173
# Batch: 40, Loss: 0.12939952313899994
# Batch: 60, Loss: 0.1428796797990799
# Batch: 80, Loss: 0.07288789749145508
# Batch: 100, Loss: 0.05444416031241417
# Batch: 120, Loss: 0.12860026955604553
# Batch: 140, Loss: 0.135128915309906
# Batch: 160, Loss: 0.055493760854005814
# Batch: 180, Loss: 0.07568369805812836
# Batch: 200, Loss: 0.06410828977823257
#
# Average loss: 0.0971, Accuracy: 25568.0/26464 (97%)
#
#
# Average loss: 0.1383, Accuracy: 2816.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 96.61%
# Validation Accuracy: 95.78%
# Batch: 0, Loss: 0.16673441231250763
# Batch: 20, Loss: 0.08041569590568542
# Batch: 40, Loss: 0.09779471158981323
# Batch: 60, Loss: 0.09359128773212433
# Batch: 80, Loss: 0.11076429486274719
# Batch: 100, Loss: 0.04371543228626251
# Batch: 120, Loss: 0.19569534063339233
# Batch: 140, Loss: 0.09184993803501129
# Batch: 160, Loss: 0.09381821751594543
# Batch: 180, Loss: 0.1254209578037262
# Batch: 200, Loss: 0.04021994024515152
#
# Average loss: 0.0911, Accuracy: 25679.0/26464 (97%)
#
#
# Average loss: 0.1360, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 97.03%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.05779951810836792
# Batch: 20, Loss: 0.06338681280612946
# Batch: 40, Loss: 0.12597215175628662
# Batch: 60, Loss: 0.16238895058631897
# Batch: 80, Loss: 0.1476440131664276
# Batch: 100, Loss: 0.18075233697891235
# Batch: 120, Loss: 0.04587152227759361
# Batch: 140, Loss: 0.048872966319322586
# Batch: 160, Loss: 0.07777901738882065
# Batch: 180, Loss: 0.08408128470182419
# Batch: 200, Loss: 0.2212764322757721
#
# Average loss: 0.0890, Accuracy: 25698.0/26464 (97%)
#
#
# Average loss: 0.1317, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 97.11%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.04352125898003578
# Batch: 20, Loss: 0.046404942870140076
# Batch: 40, Loss: 0.07938508689403534
# Batch: 60, Loss: 0.09698263555765152
# Batch: 80, Loss: 0.15522822737693787
# Batch: 100, Loss: 0.12471131980419159
# Batch: 120, Loss: 0.05398912727832794
# Batch: 140, Loss: 0.060299575328826904
# Batch: 160, Loss: 0.05789134278893471
# Batch: 180, Loss: 0.1683380901813507
# Batch: 200, Loss: 0.10230909287929535
#
# Average loss: 0.0877, Accuracy: 25700.0/26464 (97%)
#
#
# Average loss: 0.1366, Accuracy: 2816.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 97.11%
# Validation Accuracy: 95.78%
# Batch: 0, Loss: 0.0975140705704689
# Batch: 20, Loss: 0.05677395313978195
# Batch: 40, Loss: 0.08883152157068253
# Batch: 60, Loss: 0.09148654341697693
# Batch: 80, Loss: 0.13520218431949615
# Batch: 100, Loss: 0.07251513749361038
# Batch: 120, Loss: 0.053263723850250244
# Batch: 140, Loss: 0.14687134325504303
# Batch: 160, Loss: 0.09627407044172287
# Batch: 180, Loss: 0.07922649383544922
# Batch: 200, Loss: 0.05597073957324028
#
# Average loss: 0.0893, Accuracy: 25693.0/26464 (97%)
#
#
# Average loss: 0.1397, Accuracy: 2813.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 97.09%
# Validation Accuracy: 95.68%
# Batch: 0, Loss: 0.09715704619884491
# Batch: 20, Loss: 0.10276506841182709
# Batch: 40, Loss: 0.05384797975420952
# Batch: 60, Loss: 0.10351327806711197
# Batch: 80, Loss: 0.08982840925455093
# Batch: 100, Loss: 0.08658634126186371
# Batch: 120, Loss: 0.06337372213602066
# Batch: 140, Loss: 0.06583987921476364
# Batch: 160, Loss: 0.09191690385341644
# Batch: 180, Loss: 0.11816848814487457
# Batch: 200, Loss: 0.167570099234581
#
# Average loss: 0.0886, Accuracy: 25695.0/26464 (97%)
#
#
# Average loss: 0.1443, Accuracy: 2808.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 97.09%
# Validation Accuracy: 95.51%
# Early stopping invoked.
#
# Average loss: 0.0975, Accuracy: 25609.0/26464 (97%)
#
#
# Average loss: 0.1158, Accuracy: 4676.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9677
# Final Test Accuracy (New Data): 0.9619

# %%
plot_layer_effective_ranks(model_finetuning_baseline)
# Out:
# conv0.weight: 3.6755
# conv1.weight: 3.9790
# fc_1.weight: 124.1625
# fc_2.weight: 4.9765

# %% [markdown]
# ***WITH BALANCED CLASSES***

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01]
percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]

seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.0001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test = {}
results_train = {}
best_models = {}
data_loaders = {}
epochs_taken = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in percentages:
    print(f"Percentage: {perc}")
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []  # Store epochs for this percentage

    for _, temp_seed in enumerate(seed_set):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")
        model_new =  generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=True)
        model_new.to(device)

        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)

        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        # Train and evaluate the new model on the new data
        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        print(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
        print(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test[perc] = test_accuracies
    results_train[perc] = train_accuracies
    epochs_taken[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Percentage: 0.01
# Repeat: 0, with seed 64 =========================
# Batch: 0, Loss: 1.600923776626587
#
# Average loss: 1.6102, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6093, Accuracy: 585.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.623268723487854
#
# Average loss: 1.6098, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6090, Accuracy: 585.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.611096739768982
#
# Average loss: 1.6095, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6087, Accuracy: 585.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6035196781158447
#
# Average loss: 1.6092, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6085, Accuracy: 585.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6064708232879639
#
# Average loss: 1.6088, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6082, Accuracy: 585.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6054320335388184
#
# Average loss: 1.6085, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6079, Accuracy: 585.0/2940 (20%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.608551025390625
#
# Average loss: 1.6081, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6076, Accuracy: 585.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Early stopping invoked.
#
# Average loss: 1.6102, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6082, Accuracy: 1009.0/4861 (21%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.2076
# Repeat: 1, with seed 24 =========================
# Batch: 0, Loss: 1.6007912158966064
#
# Average loss: 1.5963, Accuracy: 62.0/260 (24%)
#
#
# Average loss: 1.5952, Accuracy: 751.0/2940 (26%)
#
# Epoch: 0 	Training Accuracy: 23.85%
# Validation Accuracy: 25.54%
# Batch: 0, Loss: 1.5956591367721558
#
# Average loss: 1.5929, Accuracy: 73.0/260 (28%)
#
#
# Average loss: 1.5919, Accuracy: 839.0/2940 (29%)
#
# Epoch: 1 	Training Accuracy: 28.08%
# Validation Accuracy: 28.54%
# Batch: 0, Loss: 1.5917128324508667
#
# Average loss: 1.5897, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5887, Accuracy: 950.0/2940 (32%)
#
# Epoch: 2 	Training Accuracy: 32.31%
# Validation Accuracy: 32.31%
# Batch: 0, Loss: 1.5903669595718384
#
# Average loss: 1.5864, Accuracy: 94.0/260 (36%)
#
#
# Average loss: 1.5856, Accuracy: 1035.0/2940 (35%)
#
# Epoch: 3 	Training Accuracy: 36.15%
# Validation Accuracy: 35.20%
# Batch: 0, Loss: 1.5871593952178955
#
# Average loss: 1.5833, Accuracy: 97.0/260 (37%)
#
#
# Average loss: 1.5825, Accuracy: 1120.0/2940 (38%)
#
# Epoch: 4 	Training Accuracy: 37.31%
# Validation Accuracy: 38.10%
# Batch: 0, Loss: 1.5800749063491821
#
# Average loss: 1.5801, Accuracy: 101.0/260 (39%)
#
#
# Average loss: 1.5795, Accuracy: 1180.0/2940 (40%)
#
# Epoch: 5 	Training Accuracy: 38.85%
# Validation Accuracy: 40.14%
# Batch: 0, Loss: 1.5810415744781494
#
# Average loss: 1.5769, Accuracy: 105.0/260 (40%)
#
#
# Average loss: 1.5765, Accuracy: 1235.0/2940 (42%)
#
# Epoch: 6 	Training Accuracy: 40.38%
# Validation Accuracy: 42.01%
# Batch: 0, Loss: 1.5777482986450195
#
# Average loss: 1.5737, Accuracy: 112.0/260 (43%)
#
#
# Average loss: 1.5734, Accuracy: 1366.0/2940 (46%)
#
# Epoch: 7 	Training Accuracy: 43.08%
# Validation Accuracy: 46.46%
# Batch: 0, Loss: 1.5705785751342773
#
# Average loss: 1.5703, Accuracy: 122.0/260 (47%)
#
#
# Average loss: 1.5701, Accuracy: 1478.0/2940 (50%)
#
# Epoch: 8 	Training Accuracy: 46.92%
# Validation Accuracy: 50.27%
# Batch: 0, Loss: 1.5704643726348877
#
# Average loss: 1.5670, Accuracy: 135.0/260 (52%)
#
#
# Average loss: 1.5669, Accuracy: 1567.0/2940 (53%)
#
# Epoch: 9 	Training Accuracy: 51.92%
# Validation Accuracy: 53.30%
# Batch: 0, Loss: 1.5670288801193237
#
# Average loss: 1.5637, Accuracy: 142.0/260 (55%)
#
#
# Average loss: 1.5636, Accuracy: 1635.0/2940 (56%)
#
# Epoch: 10 	Training Accuracy: 54.62%
# Validation Accuracy: 55.61%
# Batch: 0, Loss: 1.5665879249572754
#
# Average loss: 1.5603, Accuracy: 156.0/260 (60%)
#
#
# Average loss: 1.5603, Accuracy: 1680.0/2940 (57%)
#
# Epoch: 11 	Training Accuracy: 60.00%
# Validation Accuracy: 57.14%
# Batch: 0, Loss: 1.5596948862075806
#
# Average loss: 1.5568, Accuracy: 161.0/260 (62%)
#
#
# Average loss: 1.5570, Accuracy: 1728.0/2940 (59%)
#
# Epoch: 12 	Training Accuracy: 61.92%
# Validation Accuracy: 58.78%
# Batch: 0, Loss: 1.5594946146011353
#
# Average loss: 1.5532, Accuracy: 165.0/260 (63%)
#
#
# Average loss: 1.5536, Accuracy: 1790.0/2940 (61%)
#
# Epoch: 13 	Training Accuracy: 63.46%
# Validation Accuracy: 60.88%
# Batch: 0, Loss: 1.5570060014724731
#
# Average loss: 1.5496, Accuracy: 174.0/260 (67%)
#
#
# Average loss: 1.5500, Accuracy: 1843.0/2940 (63%)
#
# Epoch: 14 	Training Accuracy: 66.92%
# Validation Accuracy: 62.69%
# Batch: 0, Loss: 1.5506154298782349
#
# Average loss: 1.5459, Accuracy: 177.0/260 (68%)
#
#
# Average loss: 1.5464, Accuracy: 1887.0/2940 (64%)
#
# Epoch: 15 	Training Accuracy: 68.08%
# Validation Accuracy: 64.18%
# Batch: 0, Loss: 1.5437606573104858
#
# Average loss: 1.5422, Accuracy: 178.0/260 (68%)
#
#
# Average loss: 1.5429, Accuracy: 1919.0/2940 (65%)
#
# Epoch: 16 	Training Accuracy: 68.46%
# Validation Accuracy: 65.27%
# Batch: 0, Loss: 1.544925332069397
#
# Average loss: 1.5386, Accuracy: 182.0/260 (70%)
#
#
# Average loss: 1.5394, Accuracy: 1966.0/2940 (67%)
#
# Epoch: 17 	Training Accuracy: 70.00%
# Validation Accuracy: 66.87%
# Batch: 0, Loss: 1.536097526550293
#
# Average loss: 1.5350, Accuracy: 183.0/260 (70%)
#
#
# Average loss: 1.5360, Accuracy: 1985.0/2940 (68%)
#
# Epoch: 18 	Training Accuracy: 70.38%
# Validation Accuracy: 67.52%
# Batch: 0, Loss: 1.5382061004638672
#
# Average loss: 1.5313, Accuracy: 184.0/260 (71%)
#
#
# Average loss: 1.5324, Accuracy: 2016.0/2940 (69%)
#
# Epoch: 19 	Training Accuracy: 70.77%
# Validation Accuracy: 68.57%
#
# Average loss: 1.5313, Accuracy: 184.0/260 (71%)
#
#
# Average loss: 1.5292, Accuracy: 3397.0/4861 (70%)
#
# Final Training Accuracy (New Data): 0.7077
# Final Test Accuracy (New Data): 0.6988
# Repeat: 2, with seed 9 =========================
# Batch: 0, Loss: 1.6111743450164795
#
# Average loss: 1.6096, Accuracy: 39.0/260 (15%)
#
#
# Average loss: 1.6104, Accuracy: 390.0/2940 (13%)
#
# Epoch: 0 	Training Accuracy: 15.00%
# Validation Accuracy: 13.27%
# Batch: 0, Loss: 1.6114858388900757
#
# Average loss: 1.6091, Accuracy: 40.0/260 (15%)
#
#
# Average loss: 1.6100, Accuracy: 402.0/2940 (14%)
#
# Epoch: 1 	Training Accuracy: 15.38%
# Validation Accuracy: 13.67%
# Batch: 0, Loss: 1.6075876951217651
#
# Average loss: 1.6087, Accuracy: 41.0/260 (16%)
#
#
# Average loss: 1.6097, Accuracy: 394.0/2940 (13%)
#
# Epoch: 2 	Training Accuracy: 15.77%
# Validation Accuracy: 13.40%
# Batch: 0, Loss: 1.6080652475357056
#
# Average loss: 1.6083, Accuracy: 41.0/260 (16%)
#
#
# Average loss: 1.6094, Accuracy: 412.0/2940 (14%)
#
# Epoch: 3 	Training Accuracy: 15.77%
# Validation Accuracy: 14.01%
# Batch: 0, Loss: 1.6098554134368896
#
# Average loss: 1.6079, Accuracy: 44.0/260 (17%)
#
#
# Average loss: 1.6090, Accuracy: 425.0/2940 (14%)
#
# Epoch: 4 	Training Accuracy: 16.92%
# Validation Accuracy: 14.46%
# Batch: 0, Loss: 1.609147310256958
#
# Average loss: 1.6075, Accuracy: 46.0/260 (18%)
#
#
# Average loss: 1.6087, Accuracy: 440.0/2940 (15%)
#
# Epoch: 5 	Training Accuracy: 17.69%
# Validation Accuracy: 14.97%
# Batch: 0, Loss: 1.6086457967758179
#
# Average loss: 1.6071, Accuracy: 48.0/260 (18%)
#
#
# Average loss: 1.6083, Accuracy: 465.0/2940 (16%)
#
# Epoch: 6 	Training Accuracy: 18.46%
# Validation Accuracy: 15.82%
# Batch: 0, Loss: 1.6071664094924927
#
# Average loss: 1.6067, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.6079, Accuracy: 488.0/2940 (17%)
#
# Epoch: 7 	Training Accuracy: 20.38%
# Validation Accuracy: 16.60%
# Batch: 0, Loss: 1.608223557472229
#
# Average loss: 1.6062, Accuracy: 56.0/260 (22%)
#
#
# Average loss: 1.6075, Accuracy: 511.0/2940 (17%)
#
# Epoch: 8 	Training Accuracy: 21.54%
# Validation Accuracy: 17.38%
# Batch: 0, Loss: 1.6105092763900757
#
# Average loss: 1.6056, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.6070, Accuracy: 537.0/2940 (18%)
#
# Epoch: 9 	Training Accuracy: 22.31%
# Validation Accuracy: 18.27%
# Batch: 0, Loss: 1.6046072244644165
#
# Average loss: 1.6051, Accuracy: 66.0/260 (25%)
#
#
# Average loss: 1.6066, Accuracy: 548.0/2940 (19%)
#
# Epoch: 10 	Training Accuracy: 25.38%
# Validation Accuracy: 18.64%
# Batch: 0, Loss: 1.6071206331253052
#
# Average loss: 1.6046, Accuracy: 68.0/260 (26%)
#
#
# Average loss: 1.6061, Accuracy: 560.0/2940 (19%)
#
# Epoch: 11 	Training Accuracy: 26.15%
# Validation Accuracy: 19.05%
# Batch: 0, Loss: 1.60211980342865
#
# Average loss: 1.6040, Accuracy: 69.0/260 (27%)
#
#
# Average loss: 1.6056, Accuracy: 586.0/2940 (20%)
#
# Epoch: 12 	Training Accuracy: 26.54%
# Validation Accuracy: 19.93%
# Batch: 0, Loss: 1.6045515537261963
#
# Average loss: 1.6033, Accuracy: 71.0/260 (27%)
#
#
# Average loss: 1.6050, Accuracy: 600.0/2940 (20%)
#
# Epoch: 13 	Training Accuracy: 27.31%
# Validation Accuracy: 20.41%
# Batch: 0, Loss: 1.6064279079437256
#
# Average loss: 1.6027, Accuracy: 71.0/260 (27%)
#
#
# Average loss: 1.6044, Accuracy: 621.0/2940 (21%)
#
# Epoch: 14 	Training Accuracy: 27.31%
# Validation Accuracy: 21.12%
# Batch: 0, Loss: 1.606210470199585
#
# Average loss: 1.6020, Accuracy: 72.0/260 (28%)
#
#
# Average loss: 1.6038, Accuracy: 643.0/2940 (22%)
#
# Epoch: 15 	Training Accuracy: 27.69%
# Validation Accuracy: 21.87%
# Batch: 0, Loss: 1.604160189628601
#
# Average loss: 1.6012, Accuracy: 75.0/260 (29%)
#
#
# Average loss: 1.6031, Accuracy: 671.0/2940 (23%)
#
# Epoch: 16 	Training Accuracy: 28.85%
# Validation Accuracy: 22.82%
# Batch: 0, Loss: 1.6006051301956177
#
# Average loss: 1.6004, Accuracy: 78.0/260 (30%)
#
#
# Average loss: 1.6023, Accuracy: 701.0/2940 (24%)
#
# Epoch: 17 	Training Accuracy: 30.00%
# Validation Accuracy: 23.84%
# Batch: 0, Loss: 1.600090742111206
#
# Average loss: 1.5995, Accuracy: 80.0/260 (31%)
#
#
# Average loss: 1.6015, Accuracy: 726.0/2940 (25%)
#
# Epoch: 18 	Training Accuracy: 30.77%
# Validation Accuracy: 24.69%
# Batch: 0, Loss: 1.597488522529602
#
# Average loss: 1.5986, Accuracy: 82.0/260 (32%)
#
#
# Average loss: 1.6006, Accuracy: 758.0/2940 (26%)
#
# Epoch: 19 	Training Accuracy: 31.54%
# Validation Accuracy: 25.78%
#
# Average loss: 1.5986, Accuracy: 82.0/260 (32%)
#
#
# Average loss: 1.5996, Accuracy: 1359.0/4861 (28%)
#
# Final Training Accuracy (New Data): 0.3154
# Final Test Accuracy (New Data): 0.2796
# Repeat: 3, with seed 54 =========================
# Batch: 0, Loss: 1.6122392416000366
#
# Average loss: 1.6105, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6104, Accuracy: 585.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6094741821289062
#
# Average loss: 1.6105, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6103, Accuracy: 585.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6074001789093018
#
# Average loss: 1.6104, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6103, Accuracy: 585.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6102299690246582
#
# Average loss: 1.6104, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6103, Accuracy: 585.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6073150634765625
#
# Average loss: 1.6104, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6103, Accuracy: 585.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.606253743171692
#
# Average loss: 1.6104, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6102, Accuracy: 585.0/2940 (20%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6120710372924805
#
# Average loss: 1.6103, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6102, Accuracy: 585.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Early stopping invoked.
#
# Average loss: 1.6105, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6092, Accuracy: 1009.0/4861 (21%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.2076
# Repeat: 4, with seed 98 =========================
# Batch: 0, Loss: 1.6083935499191284
#
# Average loss: 1.6091, Accuracy: 54.0/260 (21%)
#
#
# Average loss: 1.6091, Accuracy: 562.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.77%
# Validation Accuracy: 19.12%
# Batch: 0, Loss: 1.6069366931915283
#
# Average loss: 1.6082, Accuracy: 56.0/260 (22%)
#
#
# Average loss: 1.6083, Accuracy: 582.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 21.54%
# Validation Accuracy: 19.80%
# Batch: 0, Loss: 1.6087716817855835
#
# Average loss: 1.6073, Accuracy: 59.0/260 (23%)
#
#
# Average loss: 1.6074, Accuracy: 623.0/2940 (21%)
#
# Epoch: 2 	Training Accuracy: 22.69%
# Validation Accuracy: 21.19%
# Batch: 0, Loss: 1.6082587242126465
#
# Average loss: 1.6064, Accuracy: 62.0/260 (24%)
#
#
# Average loss: 1.6066, Accuracy: 667.0/2940 (23%)
#
# Epoch: 3 	Training Accuracy: 23.85%
# Validation Accuracy: 22.69%
# Batch: 0, Loss: 1.609319806098938
#
# Average loss: 1.6055, Accuracy: 65.0/260 (25%)
#
#
# Average loss: 1.6058, Accuracy: 736.0/2940 (25%)
#
# Epoch: 4 	Training Accuracy: 25.00%
# Validation Accuracy: 25.03%
# Batch: 0, Loss: 1.6041711568832397
#
# Average loss: 1.6047, Accuracy: 71.0/260 (27%)
#
#
# Average loss: 1.6050, Accuracy: 775.0/2940 (26%)
#
# Epoch: 5 	Training Accuracy: 27.31%
# Validation Accuracy: 26.36%
# Batch: 0, Loss: 1.6068590879440308
#
# Average loss: 1.6039, Accuracy: 71.0/260 (27%)
#
#
# Average loss: 1.6044, Accuracy: 786.0/2940 (27%)
#
# Epoch: 6 	Training Accuracy: 27.31%
# Validation Accuracy: 26.73%
# Batch: 0, Loss: 1.6047031879425049
#
# Average loss: 1.6031, Accuracy: 71.0/260 (27%)
#
#
# Average loss: 1.6037, Accuracy: 791.0/2940 (27%)
#
# Epoch: 7 	Training Accuracy: 27.31%
# Validation Accuracy: 26.90%
# Batch: 0, Loss: 1.5998730659484863
#
# Average loss: 1.6023, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.6030, Accuracy: 817.0/2940 (28%)
#
# Epoch: 8 	Training Accuracy: 28.46%
# Validation Accuracy: 27.79%
# Batch: 0, Loss: 1.6064376831054688
#
# Average loss: 1.6015, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.6022, Accuracy: 838.0/2940 (29%)
#
# Epoch: 9 	Training Accuracy: 28.46%
# Validation Accuracy: 28.50%
# Batch: 0, Loss: 1.5994396209716797
#
# Average loss: 1.6008, Accuracy: 76.0/260 (29%)
#
#
# Average loss: 1.6014, Accuracy: 868.0/2940 (30%)
#
# Epoch: 10 	Training Accuracy: 29.23%
# Validation Accuracy: 29.52%
# Batch: 0, Loss: 1.6002650260925293
#
# Average loss: 1.6000, Accuracy: 77.0/260 (30%)
#
#
# Average loss: 1.6007, Accuracy: 878.0/2940 (30%)
#
# Epoch: 11 	Training Accuracy: 29.62%
# Validation Accuracy: 29.86%
# Batch: 0, Loss: 1.6014338731765747
#
# Average loss: 1.5992, Accuracy: 79.0/260 (30%)
#
#
# Average loss: 1.5999, Accuracy: 890.0/2940 (30%)
#
# Epoch: 12 	Training Accuracy: 30.38%
# Validation Accuracy: 30.27%
# Batch: 0, Loss: 1.5995427370071411
#
# Average loss: 1.5984, Accuracy: 82.0/260 (32%)
#
#
# Average loss: 1.5992, Accuracy: 916.0/2940 (31%)
#
# Epoch: 13 	Training Accuracy: 31.54%
# Validation Accuracy: 31.16%
# Batch: 0, Loss: 1.596756935119629
#
# Average loss: 1.5975, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5984, Accuracy: 928.0/2940 (32%)
#
# Epoch: 14 	Training Accuracy: 32.31%
# Validation Accuracy: 31.56%
# Batch: 0, Loss: 1.5952454805374146
#
# Average loss: 1.5967, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5976, Accuracy: 924.0/2940 (31%)
#
# Epoch: 15 	Training Accuracy: 32.31%
# Validation Accuracy: 31.43%
# Batch: 0, Loss: 1.5972304344177246
#
# Average loss: 1.5958, Accuracy: 83.0/260 (32%)
#
#
# Average loss: 1.5968, Accuracy: 914.0/2940 (31%)
#
# Epoch: 16 	Training Accuracy: 31.92%
# Validation Accuracy: 31.09%
# Batch: 0, Loss: 1.5935840606689453
#
# Average loss: 1.5949, Accuracy: 81.0/260 (31%)
#
#
# Average loss: 1.5960, Accuracy: 903.0/2940 (31%)
#
# Epoch: 17 	Training Accuracy: 31.15%
# Validation Accuracy: 30.71%
# Batch: 0, Loss: 1.5947836637496948
#
# Average loss: 1.5940, Accuracy: 80.0/260 (31%)
#
#
# Average loss: 1.5951, Accuracy: 896.0/2940 (30%)
#
# Epoch: 18 	Training Accuracy: 30.77%
# Validation Accuracy: 30.48%
# Batch: 0, Loss: 1.5959945917129517
#
# Average loss: 1.5930, Accuracy: 79.0/260 (30%)
#
#
# Average loss: 1.5943, Accuracy: 882.0/2940 (30%)
#
# Epoch: 19 	Training Accuracy: 30.38%
# Validation Accuracy: 30.00%
#
# Average loss: 1.5930, Accuracy: 79.0/260 (30%)
#
#
# Average loss: 1.5939, Accuracy: 1454.0/4861 (30%)
#
# Final Training Accuracy (New Data): 0.3038
# Final Test Accuracy (New Data): 0.2991
# Percentage: 0.03
# Repeat: 0, with seed 57 =========================
# Batch: 0, Loss: 1.6165759563446045
#
# Average loss: 1.6113, Accuracy: 160.0/790 (20%)
#
#
# Average loss: 1.6152, Accuracy: 561.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.25%
# Validation Accuracy: 19.08%
# Batch: 0, Loss: 1.6134793758392334
#
# Average loss: 1.6111, Accuracy: 163.0/790 (21%)
#
#
# Average loss: 1.6149, Accuracy: 571.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.63%
# Validation Accuracy: 19.42%
# Batch: 0, Loss: 1.6129347085952759
#
# Average loss: 1.6110, Accuracy: 155.0/790 (20%)
#
#
# Average loss: 1.6146, Accuracy: 565.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 19.62%
# Validation Accuracy: 19.22%
# Batch: 0, Loss: 1.6174752712249756
#
# Average loss: 1.6108, Accuracy: 168.0/790 (21%)
#
#
# Average loss: 1.6143, Accuracy: 564.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 21.27%
# Validation Accuracy: 19.18%
# Batch: 0, Loss: 1.6085920333862305
#
# Average loss: 1.6107, Accuracy: 165.0/790 (21%)
#
#
# Average loss: 1.6141, Accuracy: 561.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.89%
# Validation Accuracy: 19.08%
# Batch: 0, Loss: 1.6098953485488892
#
# Average loss: 1.6105, Accuracy: 166.0/790 (21%)
#
#
# Average loss: 1.6138, Accuracy: 563.0/2940 (19%)
#
# Epoch: 5 	Training Accuracy: 21.01%
# Validation Accuracy: 19.15%
# Batch: 0, Loss: 1.6119188070297241
#
# Average loss: 1.6104, Accuracy: 172.0/790 (22%)
#
#
# Average loss: 1.6135, Accuracy: 590.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 21.77%
# Validation Accuracy: 20.07%
# Batch: 0, Loss: 1.615951418876648
#
# Average loss: 1.6102, Accuracy: 168.0/790 (21%)
#
#
# Average loss: 1.6133, Accuracy: 573.0/2940 (19%)
#
# Epoch: 7 	Training Accuracy: 21.27%
# Validation Accuracy: 19.49%
# Batch: 0, Loss: 1.598487138748169
#
# Average loss: 1.6100, Accuracy: 164.0/790 (21%)
#
#
# Average loss: 1.6131, Accuracy: 561.0/2940 (19%)
#
# Epoch: 8 	Training Accuracy: 20.76%
# Validation Accuracy: 19.08%
# Batch: 0, Loss: 1.6075365543365479
#
# Average loss: 1.6097, Accuracy: 168.0/790 (21%)
#
#
# Average loss: 1.6127, Accuracy: 568.0/2940 (19%)
#
# Epoch: 9 	Training Accuracy: 21.27%
# Validation Accuracy: 19.32%
# Batch: 0, Loss: 1.604306697845459
#
# Average loss: 1.6093, Accuracy: 178.0/790 (23%)
#
#
# Average loss: 1.6123, Accuracy: 596.0/2940 (20%)
#
# Epoch: 10 	Training Accuracy: 22.53%
# Validation Accuracy: 20.27%
# Batch: 0, Loss: 1.6109012365341187
#
# Average loss: 1.6088, Accuracy: 190.0/790 (24%)
#
#
# Average loss: 1.6117, Accuracy: 630.0/2940 (21%)
#
# Epoch: 11 	Training Accuracy: 24.05%
# Validation Accuracy: 21.43%
# Batch: 0, Loss: 1.6109395027160645
#
# Average loss: 1.6080, Accuracy: 193.0/790 (24%)
#
#
# Average loss: 1.6110, Accuracy: 628.0/2940 (21%)
#
# Epoch: 12 	Training Accuracy: 24.43%
# Validation Accuracy: 21.36%
# Batch: 0, Loss: 1.6116139888763428
#
# Average loss: 1.6069, Accuracy: 190.0/790 (24%)
#
#
# Average loss: 1.6098, Accuracy: 638.0/2940 (22%)
#
# Epoch: 13 	Training Accuracy: 24.05%
# Validation Accuracy: 21.70%
# Batch: 0, Loss: 1.6066291332244873
#
# Average loss: 1.6053, Accuracy: 200.0/790 (25%)
#
#
# Average loss: 1.6083, Accuracy: 662.0/2940 (23%)
#
# Epoch: 14 	Training Accuracy: 25.32%
# Validation Accuracy: 22.52%
# Batch: 0, Loss: 1.6040459871292114
#
# Average loss: 1.6031, Accuracy: 220.0/790 (28%)
#
#
# Average loss: 1.6063, Accuracy: 717.0/2940 (24%)
#
# Epoch: 15 	Training Accuracy: 27.85%
# Validation Accuracy: 24.39%
# Batch: 0, Loss: 1.605799913406372
#
# Average loss: 1.6004, Accuracy: 244.0/790 (31%)
#
#
# Average loss: 1.6037, Accuracy: 809.0/2940 (28%)
#
# Epoch: 16 	Training Accuracy: 30.89%
# Validation Accuracy: 27.52%
# Batch: 0, Loss: 1.5994776487350464
#
# Average loss: 1.5971, Accuracy: 273.0/790 (35%)
#
#
# Average loss: 1.6007, Accuracy: 946.0/2940 (32%)
#
# Epoch: 17 	Training Accuracy: 34.56%
# Validation Accuracy: 32.18%
# Batch: 0, Loss: 1.5933704376220703
#
# Average loss: 1.5929, Accuracy: 292.0/790 (37%)
#
#
# Average loss: 1.5968, Accuracy: 1089.0/2940 (37%)
#
# Epoch: 18 	Training Accuracy: 36.96%
# Validation Accuracy: 37.04%
# Batch: 0, Loss: 1.590234637260437
#
# Average loss: 1.5879, Accuracy: 319.0/790 (40%)
#
#
# Average loss: 1.5920, Accuracy: 1163.0/2940 (40%)
#
# Epoch: 19 	Training Accuracy: 40.38%
# Validation Accuracy: 39.56%
#
# Average loss: 1.5879, Accuracy: 319.0/790 (40%)
#
#
# Average loss: 1.5908, Accuracy: 2007.0/4861 (41%)
#
# Final Training Accuracy (New Data): 0.4038
# Final Test Accuracy (New Data): 0.4129
# Repeat: 1, with seed 61 =========================
# Batch: 0, Loss: 1.6082819700241089
#
# Average loss: 1.6105, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6084, Accuracy: 599.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6169424057006836
#
# Average loss: 1.6100, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6079, Accuracy: 599.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6158543825149536
#
# Average loss: 1.6093, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6074, Accuracy: 599.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6080538034439087
#
# Average loss: 1.6087, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6069, Accuracy: 599.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6031333208084106
#
# Average loss: 1.6079, Accuracy: 161.0/790 (20%)
#
#
# Average loss: 1.6062, Accuracy: 617.0/2940 (21%)
#
# Epoch: 4 	Training Accuracy: 20.38%
# Validation Accuracy: 20.99%
# Batch: 0, Loss: 1.6077606678009033
#
# Average loss: 1.6070, Accuracy: 192.0/790 (24%)
#
#
# Average loss: 1.6053, Accuracy: 762.0/2940 (26%)
#
# Epoch: 5 	Training Accuracy: 24.30%
# Validation Accuracy: 25.92%
# Batch: 0, Loss: 1.6064696311950684
#
# Average loss: 1.6059, Accuracy: 241.0/790 (31%)
#
#
# Average loss: 1.6043, Accuracy: 909.0/2940 (31%)
#
# Epoch: 6 	Training Accuracy: 30.51%
# Validation Accuracy: 30.92%
# Batch: 0, Loss: 1.609688401222229
#
# Average loss: 1.6045, Accuracy: 262.0/790 (33%)
#
#
# Average loss: 1.6031, Accuracy: 996.0/2940 (34%)
#
# Epoch: 7 	Training Accuracy: 33.16%
# Validation Accuracy: 33.88%
# Batch: 0, Loss: 1.599687099456787
#
# Average loss: 1.6029, Accuracy: 273.0/790 (35%)
#
#
# Average loss: 1.6016, Accuracy: 1035.0/2940 (35%)
#
# Epoch: 8 	Training Accuracy: 34.56%
# Validation Accuracy: 35.20%
# Batch: 0, Loss: 1.6041573286056519
#
# Average loss: 1.6010, Accuracy: 282.0/790 (36%)
#
#
# Average loss: 1.5999, Accuracy: 1036.0/2940 (35%)
#
# Epoch: 9 	Training Accuracy: 35.70%
# Validation Accuracy: 35.24%
# Batch: 0, Loss: 1.6040712594985962
#
# Average loss: 1.5987, Accuracy: 278.0/790 (35%)
#
#
# Average loss: 1.5978, Accuracy: 1038.0/2940 (35%)
#
# Epoch: 10 	Training Accuracy: 35.19%
# Validation Accuracy: 35.31%
# Batch: 0, Loss: 1.5949496030807495
#
# Average loss: 1.5959, Accuracy: 295.0/790 (37%)
#
#
# Average loss: 1.5952, Accuracy: 1069.0/2940 (36%)
#
# Epoch: 11 	Training Accuracy: 37.34%
# Validation Accuracy: 36.36%
# Batch: 0, Loss: 1.5973691940307617
#
# Average loss: 1.5927, Accuracy: 305.0/790 (39%)
#
#
# Average loss: 1.5922, Accuracy: 1079.0/2940 (37%)
#
# Epoch: 12 	Training Accuracy: 38.61%
# Validation Accuracy: 36.70%
# Batch: 0, Loss: 1.5860815048217773
#
# Average loss: 1.5889, Accuracy: 313.0/790 (40%)
#
#
# Average loss: 1.5887, Accuracy: 1121.0/2940 (38%)
#
# Epoch: 13 	Training Accuracy: 39.62%
# Validation Accuracy: 38.13%
# Batch: 0, Loss: 1.5873864889144897
#
# Average loss: 1.5845, Accuracy: 346.0/790 (44%)
#
#
# Average loss: 1.5845, Accuracy: 1229.0/2940 (42%)
#
# Epoch: 14 	Training Accuracy: 43.80%
# Validation Accuracy: 41.80%
# Batch: 0, Loss: 1.5851798057556152
#
# Average loss: 1.5793, Accuracy: 372.0/790 (47%)
#
#
# Average loss: 1.5796, Accuracy: 1338.0/2940 (46%)
#
# Epoch: 15 	Training Accuracy: 47.09%
# Validation Accuracy: 45.51%
# Batch: 0, Loss: 1.5810530185699463
#
# Average loss: 1.5733, Accuracy: 408.0/790 (52%)
#
#
# Average loss: 1.5739, Accuracy: 1504.0/2940 (51%)
#
# Epoch: 16 	Training Accuracy: 51.65%
# Validation Accuracy: 51.16%
# Batch: 0, Loss: 1.5719585418701172
#
# Average loss: 1.5664, Accuracy: 441.0/790 (56%)
#
#
# Average loss: 1.5673, Accuracy: 1614.0/2940 (55%)
#
# Epoch: 17 	Training Accuracy: 55.82%
# Validation Accuracy: 54.90%
# Batch: 0, Loss: 1.565240502357483
#
# Average loss: 1.5585, Accuracy: 491.0/790 (62%)
#
#
# Average loss: 1.5599, Accuracy: 1760.0/2940 (60%)
#
# Epoch: 18 	Training Accuracy: 62.15%
# Validation Accuracy: 59.86%
# Batch: 0, Loss: 1.5627281665802002
#
# Average loss: 1.5496, Accuracy: 528.0/790 (67%)
#
#
# Average loss: 1.5515, Accuracy: 1912.0/2940 (65%)
#
# Epoch: 19 	Training Accuracy: 66.84%
# Validation Accuracy: 65.03%
#
# Average loss: 1.5496, Accuracy: 528.0/790 (67%)
#
#
# Average loss: 1.5511, Accuracy: 3166.0/4861 (65%)
#
# Final Training Accuracy (New Data): 0.6684
# Final Test Accuracy (New Data): 0.6513
# Repeat: 2, with seed 94 =========================
# Batch: 0, Loss: 1.6089789867401123
#
# Average loss: 1.6117, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6139, Accuracy: 599.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.606255292892456
#
# Average loss: 1.6110, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6132, Accuracy: 599.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6090489625930786
#
# Average loss: 1.6103, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6124, Accuracy: 599.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6061688661575317
#
# Average loss: 1.6093, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6114, Accuracy: 599.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6098740100860596
#
# Average loss: 1.6082, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6103, Accuracy: 599.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6043041944503784
#
# Average loss: 1.6067, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6088, Accuracy: 599.0/2940 (20%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.5995460748672485
#
# Average loss: 1.6048, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6069, Accuracy: 599.0/2940 (20%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Early stopping invoked.
#
# Average loss: 1.6117, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6138, Accuracy: 958.0/4861 (20%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.1971
# Repeat: 3, with seed 41 =========================
# Batch: 0, Loss: 1.6087594032287598
#
# Average loss: 1.6078, Accuracy: 169.0/790 (21%)
#
#
# Average loss: 1.6077, Accuracy: 596.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 21.39%
# Validation Accuracy: 20.27%
# Batch: 0, Loss: 1.6063117980957031
#
# Average loss: 1.6061, Accuracy: 195.0/790 (25%)
#
#
# Average loss: 1.6062, Accuracy: 692.0/2940 (24%)
#
# Epoch: 1 	Training Accuracy: 24.68%
# Validation Accuracy: 23.54%
# Batch: 0, Loss: 1.6062151193618774
#
# Average loss: 1.6043, Accuracy: 209.0/790 (26%)
#
#
# Average loss: 1.6047, Accuracy: 750.0/2940 (26%)
#
# Epoch: 2 	Training Accuracy: 26.46%
# Validation Accuracy: 25.51%
# Batch: 0, Loss: 1.609348177909851
#
# Average loss: 1.6025, Accuracy: 221.0/790 (28%)
#
#
# Average loss: 1.6031, Accuracy: 812.0/2940 (28%)
#
# Epoch: 3 	Training Accuracy: 27.97%
# Validation Accuracy: 27.62%
# Batch: 0, Loss: 1.6039191484451294
#
# Average loss: 1.6009, Accuracy: 222.0/790 (28%)
#
#
# Average loss: 1.6017, Accuracy: 770.0/2940 (26%)
#
# Epoch: 4 	Training Accuracy: 28.10%
# Validation Accuracy: 26.19%
# Batch: 0, Loss: 1.6021181344985962
#
# Average loss: 1.5991, Accuracy: 231.0/790 (29%)
#
#
# Average loss: 1.6000, Accuracy: 795.0/2940 (27%)
#
# Epoch: 5 	Training Accuracy: 29.24%
# Validation Accuracy: 27.04%
# Batch: 0, Loss: 1.5969170331954956
#
# Average loss: 1.5971, Accuracy: 243.0/790 (31%)
#
#
# Average loss: 1.5982, Accuracy: 873.0/2940 (30%)
#
# Epoch: 6 	Training Accuracy: 30.76%
# Validation Accuracy: 29.69%
# Batch: 0, Loss: 1.5977940559387207
#
# Average loss: 1.5950, Accuracy: 305.0/790 (39%)
#
#
# Average loss: 1.5961, Accuracy: 1087.0/2940 (37%)
#
# Epoch: 7 	Training Accuracy: 38.61%
# Validation Accuracy: 36.97%
# Batch: 0, Loss: 1.5948468446731567
#
# Average loss: 1.5928, Accuracy: 363.0/790 (46%)
#
#
# Average loss: 1.5939, Accuracy: 1282.0/2940 (44%)
#
# Epoch: 8 	Training Accuracy: 45.95%
# Validation Accuracy: 43.61%
# Batch: 0, Loss: 1.5931553840637207
#
# Average loss: 1.5903, Accuracy: 407.0/790 (52%)
#
#
# Average loss: 1.5913, Accuracy: 1495.0/2940 (51%)
#
# Epoch: 9 	Training Accuracy: 51.52%
# Validation Accuracy: 50.85%
# Batch: 0, Loss: 1.5898112058639526
#
# Average loss: 1.5877, Accuracy: 444.0/790 (56%)
#
#
# Average loss: 1.5888, Accuracy: 1651.0/2940 (56%)
#
# Epoch: 10 	Training Accuracy: 56.20%
# Validation Accuracy: 56.16%
# Batch: 0, Loss: 1.5883736610412598
#
# Average loss: 1.5849, Accuracy: 442.0/790 (56%)
#
#
# Average loss: 1.5859, Accuracy: 1562.0/2940 (53%)
#
# Epoch: 11 	Training Accuracy: 55.95%
# Validation Accuracy: 53.13%
# Batch: 0, Loss: 1.5855275392532349
#
# Average loss: 1.5818, Accuracy: 448.0/790 (57%)
#
#
# Average loss: 1.5828, Accuracy: 1606.0/2940 (55%)
#
# Epoch: 12 	Training Accuracy: 56.71%
# Validation Accuracy: 54.63%
# Batch: 0, Loss: 1.5818005800247192
#
# Average loss: 1.5785, Accuracy: 453.0/790 (57%)
#
#
# Average loss: 1.5795, Accuracy: 1613.0/2940 (55%)
#
# Epoch: 13 	Training Accuracy: 57.34%
# Validation Accuracy: 54.86%
# Batch: 0, Loss: 1.5789234638214111
#
# Average loss: 1.5748, Accuracy: 455.0/790 (58%)
#
#
# Average loss: 1.5760, Accuracy: 1633.0/2940 (56%)
#
# Epoch: 14 	Training Accuracy: 57.59%
# Validation Accuracy: 55.54%
# Batch: 0, Loss: 1.5753095149993896
#
# Average loss: 1.5708, Accuracy: 489.0/790 (62%)
#
#
# Average loss: 1.5721, Accuracy: 1764.0/2940 (60%)
#
# Epoch: 15 	Training Accuracy: 61.90%
# Validation Accuracy: 60.00%
# Batch: 0, Loss: 1.570387840270996
#
# Average loss: 1.5666, Accuracy: 511.0/790 (65%)
#
#
# Average loss: 1.5682, Accuracy: 1826.0/2940 (62%)
#
# Epoch: 16 	Training Accuracy: 64.68%
# Validation Accuracy: 62.11%
# Batch: 0, Loss: 1.5645993947982788
#
# Average loss: 1.5619, Accuracy: 519.0/790 (66%)
#
#
# Average loss: 1.5641, Accuracy: 1876.0/2940 (64%)
#
# Epoch: 17 	Training Accuracy: 65.70%
# Validation Accuracy: 63.81%
# Batch: 0, Loss: 1.5573740005493164
#
# Average loss: 1.5568, Accuracy: 549.0/790 (69%)
#
#
# Average loss: 1.5589, Accuracy: 2014.0/2940 (69%)
#
# Epoch: 18 	Training Accuracy: 69.49%
# Validation Accuracy: 68.50%
# Batch: 0, Loss: 1.5579380989074707
#
# Average loss: 1.5512, Accuracy: 566.0/790 (72%)
#
#
# Average loss: 1.5536, Accuracy: 2067.0/2940 (70%)
#
# Epoch: 19 	Training Accuracy: 71.65%
# Validation Accuracy: 70.31%
#
# Average loss: 1.5512, Accuracy: 566.0/790 (72%)
#
#
# Average loss: 1.5534, Accuracy: 3465.0/4861 (71%)
#
# Final Training Accuracy (New Data): 0.7165
# Final Test Accuracy (New Data): 0.7128
# Repeat: 4, with seed 52 =========================
# Batch: 0, Loss: 1.6186221837997437
#
# Average loss: 1.6087, Accuracy: 159.0/790 (20%)
#
#
# Average loss: 1.6075, Accuracy: 660.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 20.13%
# Validation Accuracy: 22.45%
# Batch: 0, Loss: 1.6100082397460938
#
# Average loss: 1.6067, Accuracy: 160.0/790 (20%)
#
#
# Average loss: 1.6056, Accuracy: 658.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 20.25%
# Validation Accuracy: 22.38%
# Batch: 0, Loss: 1.6047486066818237
#
# Average loss: 1.6048, Accuracy: 159.0/790 (20%)
#
#
# Average loss: 1.6036, Accuracy: 656.0/2940 (22%)
#
# Epoch: 2 	Training Accuracy: 20.13%
# Validation Accuracy: 22.31%
# Batch: 0, Loss: 1.6051137447357178
#
# Average loss: 1.6027, Accuracy: 160.0/790 (20%)
#
#
# Average loss: 1.6016, Accuracy: 655.0/2940 (22%)
#
# Epoch: 3 	Training Accuracy: 20.25%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6034870147705078
#
# Average loss: 1.6004, Accuracy: 162.0/790 (21%)
#
#
# Average loss: 1.5993, Accuracy: 659.0/2940 (22%)
#
# Epoch: 4 	Training Accuracy: 20.51%
# Validation Accuracy: 22.41%
# Batch: 0, Loss: 1.6013213396072388
#
# Average loss: 1.5978, Accuracy: 162.0/790 (21%)
#
#
# Average loss: 1.5968, Accuracy: 670.0/2940 (23%)
#
# Epoch: 5 	Training Accuracy: 20.51%
# Validation Accuracy: 22.79%
# Batch: 0, Loss: 1.596476674079895
#
# Average loss: 1.5950, Accuracy: 191.0/790 (24%)
#
#
# Average loss: 1.5941, Accuracy: 750.0/2940 (26%)
#
# Epoch: 6 	Training Accuracy: 24.18%
# Validation Accuracy: 25.51%
# Batch: 0, Loss: 1.5957661867141724
#
# Average loss: 1.5920, Accuracy: 311.0/790 (39%)
#
#
# Average loss: 1.5913, Accuracy: 1128.0/2940 (38%)
#
# Epoch: 7 	Training Accuracy: 39.37%
# Validation Accuracy: 38.37%
# Batch: 0, Loss: 1.5929011106491089
#
# Average loss: 1.5887, Accuracy: 398.0/790 (50%)
#
#
# Average loss: 1.5885, Accuracy: 1507.0/2940 (51%)
#
# Epoch: 8 	Training Accuracy: 50.38%
# Validation Accuracy: 51.26%
# Batch: 0, Loss: 1.5917240381240845
#
# Average loss: 1.5852, Accuracy: 422.0/790 (53%)
#
#
# Average loss: 1.5852, Accuracy: 1627.0/2940 (55%)
#
# Epoch: 9 	Training Accuracy: 53.42%
# Validation Accuracy: 55.34%
# Batch: 0, Loss: 1.5848300457000732
#
# Average loss: 1.5817, Accuracy: 447.0/790 (57%)
#
#
# Average loss: 1.5817, Accuracy: 1659.0/2940 (56%)
#
# Epoch: 10 	Training Accuracy: 56.58%
# Validation Accuracy: 56.43%
# Batch: 0, Loss: 1.5816466808319092
#
# Average loss: 1.5780, Accuracy: 468.0/790 (59%)
#
#
# Average loss: 1.5780, Accuracy: 1740.0/2940 (59%)
#
# Epoch: 11 	Training Accuracy: 59.24%
# Validation Accuracy: 59.18%
# Batch: 0, Loss: 1.5785419940948486
#
# Average loss: 1.5739, Accuracy: 454.0/790 (57%)
#
#
# Average loss: 1.5739, Accuracy: 1707.0/2940 (58%)
#
# Epoch: 12 	Training Accuracy: 57.47%
# Validation Accuracy: 58.06%
# Batch: 0, Loss: 1.573359727859497
#
# Average loss: 1.5696, Accuracy: 462.0/790 (58%)
#
#
# Average loss: 1.5694, Accuracy: 1770.0/2940 (60%)
#
# Epoch: 13 	Training Accuracy: 58.48%
# Validation Accuracy: 60.20%
# Batch: 0, Loss: 1.5709068775177002
#
# Average loss: 1.5650, Accuracy: 497.0/790 (63%)
#
#
# Average loss: 1.5650, Accuracy: 1900.0/2940 (65%)
#
# Epoch: 14 	Training Accuracy: 62.91%
# Validation Accuracy: 64.63%
# Batch: 0, Loss: 1.5644630193710327
#
# Average loss: 1.5602, Accuracy: 526.0/790 (67%)
#
#
# Average loss: 1.5604, Accuracy: 1995.0/2940 (68%)
#
# Epoch: 15 	Training Accuracy: 66.58%
# Validation Accuracy: 67.86%
# Batch: 0, Loss: 1.5614612102508545
#
# Average loss: 1.5550, Accuracy: 547.0/790 (69%)
#
#
# Average loss: 1.5555, Accuracy: 2054.0/2940 (70%)
#
# Epoch: 16 	Training Accuracy: 69.24%
# Validation Accuracy: 69.86%
# Batch: 0, Loss: 1.553031086921692
#
# Average loss: 1.5494, Accuracy: 576.0/790 (73%)
#
#
# Average loss: 1.5502, Accuracy: 2130.0/2940 (72%)
#
# Epoch: 17 	Training Accuracy: 72.91%
# Validation Accuracy: 72.45%
# Batch: 0, Loss: 1.5482630729675293
#
# Average loss: 1.5435, Accuracy: 594.0/790 (75%)
#
#
# Average loss: 1.5447, Accuracy: 2208.0/2940 (75%)
#
# Epoch: 18 	Training Accuracy: 75.19%
# Validation Accuracy: 75.10%
# Batch: 0, Loss: 1.549013376235962
#
# Average loss: 1.5372, Accuracy: 601.0/790 (76%)
#
#
# Average loss: 1.5387, Accuracy: 2212.0/2940 (75%)
#
# Epoch: 19 	Training Accuracy: 76.08%
# Validation Accuracy: 75.24%
#
# Average loss: 1.5372, Accuracy: 601.0/790 (76%)
#
#
# Average loss: 1.5382, Accuracy: 3651.0/4861 (75%)
#
# Final Training Accuracy (New Data): 0.7608
# Final Test Accuracy (New Data): 0.7511
# Percentage: 0.05
# Repeat: 0, with seed 73 =========================
# Batch: 0, Loss: 1.6020867824554443
#
# Average loss: 1.6109, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6111, Accuracy: 551.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6063874959945679
#
# Average loss: 1.6107, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6109, Accuracy: 551.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6061396598815918
#
# Average loss: 1.6106, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6109, Accuracy: 551.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.611802101135254
#
# Average loss: 1.6105, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6108, Accuracy: 551.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6135241985321045
#
# Average loss: 1.6104, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6107, Accuracy: 551.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6016565561294556
#
# Average loss: 1.6104, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6106, Accuracy: 551.0/2940 (19%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6097676753997803
#
# Average loss: 1.6102, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6105, Accuracy: 551.0/2940 (19%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Early stopping invoked.
#
# Average loss: 1.6109, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6127, Accuracy: 892.0/4861 (18%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.1835
# Repeat: 1, with seed 3 =========================
# Batch: 0, Loss: 1.6024494171142578
#
# Average loss: 1.6045, Accuracy: 275.0/1320 (21%)
#
#
# Average loss: 1.6046, Accuracy: 622.0/2940 (21%)
#
# Epoch: 0 	Training Accuracy: 20.83%
# Validation Accuracy: 21.16%
# Batch: 0, Loss: 1.6056104898452759
#
# Average loss: 1.6005, Accuracy: 309.0/1320 (23%)
#
#
# Average loss: 1.6006, Accuracy: 714.0/2940 (24%)
#
# Epoch: 1 	Training Accuracy: 23.41%
# Validation Accuracy: 24.29%
# Batch: 0, Loss: 1.599319338798523
#
# Average loss: 1.5958, Accuracy: 375.0/1320 (28%)
#
#
# Average loss: 1.5960, Accuracy: 847.0/2940 (29%)
#
# Epoch: 2 	Training Accuracy: 28.41%
# Validation Accuracy: 28.81%
# Batch: 0, Loss: 1.5993624925613403
#
# Average loss: 1.5900, Accuracy: 477.0/1320 (36%)
#
#
# Average loss: 1.5902, Accuracy: 1077.0/2940 (37%)
#
# Epoch: 3 	Training Accuracy: 36.14%
# Validation Accuracy: 36.63%
# Batch: 0, Loss: 1.586652398109436
#
# Average loss: 1.5830, Accuracy: 621.0/1320 (47%)
#
#
# Average loss: 1.5833, Accuracy: 1392.0/2940 (47%)
#
# Epoch: 4 	Training Accuracy: 47.05%
# Validation Accuracy: 47.35%
# Batch: 0, Loss: 1.5870040655136108
#
# Average loss: 1.5744, Accuracy: 711.0/1320 (54%)
#
#
# Average loss: 1.5748, Accuracy: 1595.0/2940 (54%)
#
# Epoch: 5 	Training Accuracy: 53.86%
# Validation Accuracy: 54.25%
# Batch: 0, Loss: 1.5738630294799805
#
# Average loss: 1.5637, Accuracy: 791.0/1320 (60%)
#
#
# Average loss: 1.5642, Accuracy: 1742.0/2940 (59%)
#
# Epoch: 6 	Training Accuracy: 59.92%
# Validation Accuracy: 59.25%
# Batch: 0, Loss: 1.5619120597839355
#
# Average loss: 1.5511, Accuracy: 867.0/1320 (66%)
#
#
# Average loss: 1.5515, Accuracy: 1941.0/2940 (66%)
#
# Epoch: 7 	Training Accuracy: 65.68%
# Validation Accuracy: 66.02%
# Batch: 0, Loss: 1.5492620468139648
#
# Average loss: 1.5361, Accuracy: 900.0/1320 (68%)
#
#
# Average loss: 1.5363, Accuracy: 2019.0/2940 (69%)
#
# Epoch: 8 	Training Accuracy: 68.18%
# Validation Accuracy: 68.67%
# Batch: 0, Loss: 1.5318458080291748
#
# Average loss: 1.5182, Accuracy: 976.0/1320 (74%)
#
#
# Average loss: 1.5178, Accuracy: 2182.0/2940 (74%)
#
# Epoch: 9 	Training Accuracy: 73.94%
# Validation Accuracy: 74.22%
# Batch: 0, Loss: 1.5190972089767456
#
# Average loss: 1.4976, Accuracy: 1004.0/1320 (76%)
#
#
# Average loss: 1.4969, Accuracy: 2259.0/2940 (77%)
#
# Epoch: 10 	Training Accuracy: 76.06%
# Validation Accuracy: 76.84%
# Batch: 0, Loss: 1.4973379373550415
#
# Average loss: 1.4741, Accuracy: 1023.0/1320 (78%)
#
#
# Average loss: 1.4730, Accuracy: 2274.0/2940 (77%)
#
# Epoch: 11 	Training Accuracy: 77.50%
# Validation Accuracy: 77.35%
# Batch: 0, Loss: 1.4756509065628052
#
# Average loss: 1.4474, Accuracy: 1033.0/1320 (78%)
#
#
# Average loss: 1.4454, Accuracy: 2292.0/2940 (78%)
#
# Epoch: 12 	Training Accuracy: 78.26%
# Validation Accuracy: 77.96%
# Batch: 0, Loss: 1.4369093179702759
#
# Average loss: 1.4178, Accuracy: 1005.0/1320 (76%)
#
#
# Average loss: 1.4146, Accuracy: 2258.0/2940 (77%)
#
# Epoch: 13 	Training Accuracy: 76.14%
# Validation Accuracy: 76.80%
# Batch: 0, Loss: 1.4014521837234497
#
# Average loss: 1.3852, Accuracy: 994.0/1320 (75%)
#
#
# Average loss: 1.3812, Accuracy: 2250.0/2940 (77%)
#
# Epoch: 14 	Training Accuracy: 75.30%
# Validation Accuracy: 76.53%
# Batch: 0, Loss: 1.400477647781372
#
# Average loss: 1.3503, Accuracy: 1018.0/1320 (77%)
#
#
# Average loss: 1.3460, Accuracy: 2307.0/2940 (78%)
#
# Epoch: 15 	Training Accuracy: 77.12%
# Validation Accuracy: 78.47%
# Batch: 0, Loss: 1.3603264093399048
#
# Average loss: 1.3121, Accuracy: 1011.0/1320 (77%)
#
#
# Average loss: 1.3070, Accuracy: 2299.0/2940 (78%)
#
# Epoch: 16 	Training Accuracy: 76.59%
# Validation Accuracy: 78.20%
# Batch: 0, Loss: 1.31133234500885
#
# Average loss: 1.2718, Accuracy: 1020.0/1320 (77%)
#
#
# Average loss: 1.2659, Accuracy: 2308.0/2940 (79%)
#
# Epoch: 17 	Training Accuracy: 77.27%
# Validation Accuracy: 78.50%
# Batch: 0, Loss: 1.2707403898239136
#
# Average loss: 1.2294, Accuracy: 1019.0/1320 (77%)
#
#
# Average loss: 1.2227, Accuracy: 2318.0/2940 (79%)
#
# Epoch: 18 	Training Accuracy: 77.20%
# Validation Accuracy: 78.84%
# Batch: 0, Loss: 1.2301679849624634
#
# Average loss: 1.1858, Accuracy: 1031.0/1320 (78%)
#
#
# Average loss: 1.1793, Accuracy: 2327.0/2940 (79%)
#
# Epoch: 19 	Training Accuracy: 78.11%
# Validation Accuracy: 79.15%
#
# Average loss: 1.1858, Accuracy: 1031.0/1320 (78%)
#
#
# Average loss: 1.1752, Accuracy: 3854.0/4861 (79%)
#
# Final Training Accuracy (New Data): 0.7811
# Final Test Accuracy (New Data): 0.7928
# Repeat: 2, with seed 27 =========================
# Batch: 0, Loss: 1.6171002388000488
#
# Average loss: 1.6089, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6072, Accuracy: 599.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6105542182922363
#
# Average loss: 1.6044, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6027, Accuracy: 599.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6048074960708618
#
# Average loss: 1.5997, Accuracy: 266.0/1320 (20%)
#
#
# Average loss: 1.5979, Accuracy: 603.0/2940 (21%)
#
# Epoch: 2 	Training Accuracy: 20.15%
# Validation Accuracy: 20.51%
# Batch: 0, Loss: 1.596989393234253
#
# Average loss: 1.5947, Accuracy: 276.0/1320 (21%)
#
#
# Average loss: 1.5929, Accuracy: 641.0/2940 (22%)
#
# Epoch: 3 	Training Accuracy: 20.91%
# Validation Accuracy: 21.80%
# Batch: 0, Loss: 1.5914664268493652
#
# Average loss: 1.5892, Accuracy: 354.0/1320 (27%)
#
#
# Average loss: 1.5870, Accuracy: 839.0/2940 (29%)
#
# Epoch: 4 	Training Accuracy: 26.82%
# Validation Accuracy: 28.54%
# Batch: 0, Loss: 1.5794618129730225
#
# Average loss: 1.5830, Accuracy: 457.0/1320 (35%)
#
#
# Average loss: 1.5805, Accuracy: 1100.0/2940 (37%)
#
# Epoch: 5 	Training Accuracy: 34.62%
# Validation Accuracy: 37.41%
# Batch: 0, Loss: 1.5866010189056396
#
# Average loss: 1.5762, Accuracy: 569.0/1320 (43%)
#
#
# Average loss: 1.5732, Accuracy: 1332.0/2940 (45%)
#
# Epoch: 6 	Training Accuracy: 43.11%
# Validation Accuracy: 45.31%
# Batch: 0, Loss: 1.5816670656204224
#
# Average loss: 1.5685, Accuracy: 646.0/1320 (49%)
#
#
# Average loss: 1.5653, Accuracy: 1493.0/2940 (51%)
#
# Epoch: 7 	Training Accuracy: 48.94%
# Validation Accuracy: 50.78%
# Batch: 0, Loss: 1.5706770420074463
#
# Average loss: 1.5598, Accuracy: 669.0/1320 (51%)
#
#
# Average loss: 1.5564, Accuracy: 1582.0/2940 (54%)
#
# Epoch: 8 	Training Accuracy: 50.68%
# Validation Accuracy: 53.81%
# Batch: 0, Loss: 1.5618256330490112
#
# Average loss: 1.5500, Accuracy: 712.0/1320 (54%)
#
#
# Average loss: 1.5460, Accuracy: 1664.0/2940 (57%)
#
# Epoch: 9 	Training Accuracy: 53.94%
# Validation Accuracy: 56.60%
# Batch: 0, Loss: 1.5546300411224365
#
# Average loss: 1.5390, Accuracy: 739.0/1320 (56%)
#
#
# Average loss: 1.5345, Accuracy: 1716.0/2940 (58%)
#
# Epoch: 10 	Training Accuracy: 55.98%
# Validation Accuracy: 58.37%
# Batch: 0, Loss: 1.53811776638031
#
# Average loss: 1.5264, Accuracy: 759.0/1320 (57%)
#
#
# Average loss: 1.5214, Accuracy: 1785.0/2940 (61%)
#
# Epoch: 11 	Training Accuracy: 57.50%
# Validation Accuracy: 60.71%
# Batch: 0, Loss: 1.5260400772094727
#
# Average loss: 1.5124, Accuracy: 778.0/1320 (59%)
#
#
# Average loss: 1.5067, Accuracy: 1833.0/2940 (62%)
#
# Epoch: 12 	Training Accuracy: 58.94%
# Validation Accuracy: 62.35%
# Batch: 0, Loss: 1.5067646503448486
#
# Average loss: 1.4966, Accuracy: 793.0/1320 (60%)
#
#
# Average loss: 1.4901, Accuracy: 1882.0/2940 (64%)
#
# Epoch: 13 	Training Accuracy: 60.08%
# Validation Accuracy: 64.01%
# Batch: 0, Loss: 1.4835673570632935
#
# Average loss: 1.4791, Accuracy: 811.0/1320 (61%)
#
#
# Average loss: 1.4717, Accuracy: 1908.0/2940 (65%)
#
# Epoch: 14 	Training Accuracy: 61.44%
# Validation Accuracy: 64.90%
# Batch: 0, Loss: 1.475473165512085
#
# Average loss: 1.4592, Accuracy: 851.0/1320 (64%)
#
#
# Average loss: 1.4511, Accuracy: 1959.0/2940 (67%)
#
# Epoch: 15 	Training Accuracy: 64.47%
# Validation Accuracy: 66.63%
# Batch: 0, Loss: 1.4771819114685059
#
# Average loss: 1.4371, Accuracy: 878.0/1320 (67%)
#
#
# Average loss: 1.4282, Accuracy: 2003.0/2940 (68%)
#
# Epoch: 16 	Training Accuracy: 66.52%
# Validation Accuracy: 68.13%
# Batch: 0, Loss: 1.4468228816986084
#
# Average loss: 1.4126, Accuracy: 892.0/1320 (68%)
#
#
# Average loss: 1.4028, Accuracy: 2044.0/2940 (70%)
#
# Epoch: 17 	Training Accuracy: 67.58%
# Validation Accuracy: 69.52%
# Batch: 0, Loss: 1.3834632635116577
#
# Average loss: 1.3856, Accuracy: 914.0/1320 (69%)
#
#
# Average loss: 1.3748, Accuracy: 2080.0/2940 (71%)
#
# Epoch: 18 	Training Accuracy: 69.24%
# Validation Accuracy: 70.75%
# Batch: 0, Loss: 1.3810584545135498
#
# Average loss: 1.3557, Accuracy: 931.0/1320 (71%)
#
#
# Average loss: 1.3441, Accuracy: 2127.0/2940 (72%)
#
# Epoch: 19 	Training Accuracy: 70.53%
# Validation Accuracy: 72.35%
#
# Average loss: 1.3557, Accuracy: 931.0/1320 (71%)
#
#
# Average loss: 1.3418, Accuracy: 3458.0/4861 (71%)
#
# Final Training Accuracy (New Data): 0.7053
# Final Test Accuracy (New Data): 0.7114
# Repeat: 3, with seed 62 =========================
# Batch: 0, Loss: 1.6121114492416382
#
# Average loss: 1.6111, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6105, Accuracy: 551.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6096317768096924
#
# Average loss: 1.6110, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6104, Accuracy: 551.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.60494863986969
#
# Average loss: 1.6108, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6103, Accuracy: 551.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6094034910202026
#
# Average loss: 1.6107, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6101, Accuracy: 551.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6108407974243164
#
# Average loss: 1.6105, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6100, Accuracy: 550.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6082699298858643
#
# Average loss: 1.6104, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6099, Accuracy: 551.0/2940 (19%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6132922172546387
#
# Average loss: 1.6103, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6099, Accuracy: 550.0/2940 (19%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Early stopping invoked.
#
# Average loss: 1.6111, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6128, Accuracy: 892.0/4861 (18%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.1835
# Repeat: 4, with seed 28 =========================
# Batch: 0, Loss: 1.6111536026000977
#
# Average loss: 1.6070, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6077, Accuracy: 585.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6069154739379883
#
# Average loss: 1.6033, Accuracy: 264.0/1320 (20%)
#
#
# Average loss: 1.6040, Accuracy: 585.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6009879112243652
#
# Average loss: 1.5983, Accuracy: 267.0/1320 (20%)
#
#
# Average loss: 1.5991, Accuracy: 602.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.23%
# Validation Accuracy: 20.48%
# Batch: 0, Loss: 1.601576566696167
#
# Average loss: 1.5919, Accuracy: 304.0/1320 (23%)
#
#
# Average loss: 1.5928, Accuracy: 684.0/2940 (23%)
#
# Epoch: 3 	Training Accuracy: 23.03%
# Validation Accuracy: 23.27%
# Batch: 0, Loss: 1.5918632745742798
#
# Average loss: 1.5840, Accuracy: 429.0/1320 (32%)
#
#
# Average loss: 1.5849, Accuracy: 938.0/2940 (32%)
#
# Epoch: 4 	Training Accuracy: 32.50%
# Validation Accuracy: 31.90%
# Batch: 0, Loss: 1.5838642120361328
#
# Average loss: 1.5759, Accuracy: 648.0/1320 (49%)
#
#
# Average loss: 1.5768, Accuracy: 1360.0/2940 (46%)
#
# Epoch: 5 	Training Accuracy: 49.09%
# Validation Accuracy: 46.26%
# Batch: 0, Loss: 1.571998119354248
#
# Average loss: 1.5673, Accuracy: 752.0/1320 (57%)
#
#
# Average loss: 1.5680, Accuracy: 1647.0/2940 (56%)
#
# ...
#
# Epoch: 16 	Training Accuracy: 94.74%
# Validation Accuracy: 94.39%
# Batch: 0, Loss: 0.13879959285259247
# Batch: 20, Loss: 0.14999625086784363
# Batch: 40, Loss: 0.14695289731025696
# Batch: 60, Loss: 0.1216316670179367
# Batch: 80, Loss: 0.24991212785243988
# Batch: 100, Loss: 0.1352095603942871
# Batch: 120, Loss: 0.1808987706899643
# Batch: 140, Loss: 0.20357538759708405
# Batch: 160, Loss: 0.14355731010437012
# Batch: 180, Loss: 0.12981641292572021
# Batch: 200, Loss: 0.16316235065460205
#
# Average loss: 0.1631, Accuracy: 24693.0/26038 (95%)
#
#
# Average loss: 0.1834, Accuracy: 2771.0/2940 (94%)
#
# Epoch: 17 	Training Accuracy: 94.83%
# Validation Accuracy: 94.25%
# Batch: 0, Loss: 0.1285182386636734
# Batch: 20, Loss: 0.20090948045253754
# Batch: 40, Loss: 0.15890802443027496
# Batch: 60, Loss: 0.15819889307022095
# Batch: 80, Loss: 0.108613520860672
# Batch: 100, Loss: 0.14885592460632324
# Batch: 120, Loss: 0.20443391799926758
# Batch: 140, Loss: 0.18910197913646698
# Batch: 160, Loss: 0.1287093311548233
# Batch: 180, Loss: 0.17705091834068298
# Batch: 200, Loss: 0.1412733495235443
#
# Average loss: 0.1584, Accuracy: 24713.0/26038 (95%)
#
#
# Average loss: 0.1811, Accuracy: 2779.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 94.91%
# Validation Accuracy: 94.52%
# Batch: 0, Loss: 0.20298360288143158
# Batch: 20, Loss: 0.20728309452533722
# Batch: 40, Loss: 0.12521575391292572
# Batch: 60, Loss: 0.14127621054649353
# Batch: 80, Loss: 0.14599420130252838
# Batch: 100, Loss: 0.1689261943101883
# Batch: 120, Loss: 0.1428040862083435
# Batch: 140, Loss: 0.24522559344768524
# Batch: 160, Loss: 0.20904195308685303
# Batch: 180, Loss: 0.15515148639678955
# Batch: 200, Loss: 0.10689415782690048
#
# Average loss: 0.1570, Accuracy: 24738.0/26038 (95%)
#
#
# Average loss: 0.1800, Accuracy: 2780.0/2940 (95%)
#
# Epoch: 19 	Training Accuracy: 95.01%
# Validation Accuracy: 94.56%
#
# Average loss: 0.1570, Accuracy: 24738.0/26038 (95%)
#
#
# Average loss: 0.1499, Accuracy: 4611.0/4861 (95%)
#
# Final Training Accuracy (New Data): 0.9501
# Final Test Accuracy (New Data): 0.9486
# Repeat: 4, with seed 82 =========================
# Batch: 0, Loss: 1.607431173324585
# Batch: 20, Loss: 1.60416841506958
# Batch: 40, Loss: 1.6037520170211792
# Batch: 60, Loss: 1.5942292213439941
# Batch: 80, Loss: 1.5881538391113281
# Batch: 100, Loss: 1.5780119895935059
# Batch: 120, Loss: 1.5422557592391968
# Batch: 140, Loss: 1.5057214498519897
# Batch: 160, Loss: 1.4637869596481323
# Batch: 180, Loss: 1.3963356018066406
# Batch: 200, Loss: 1.3650977611541748
#
# Average loss: 1.3440, Accuracy: 18509.0/26038 (71%)
#
#
# Average loss: 1.3457, Accuracy: 2068.0/2940 (70%)
#
# Epoch: 0 	Training Accuracy: 71.08%
# Validation Accuracy: 70.34%
# Batch: 0, Loss: 1.329711675643921
# Batch: 20, Loss: 1.2496803998947144
# Batch: 40, Loss: 1.1898592710494995
# Batch: 60, Loss: 1.139058232307434
# Batch: 80, Loss: 1.0616133213043213
# Batch: 100, Loss: 0.9235250353813171
# Batch: 120, Loss: 0.854530930519104
# Batch: 140, Loss: 0.8179818391799927
# Batch: 160, Loss: 0.7187722325325012
# Batch: 180, Loss: 0.6998221278190613
# Batch: 200, Loss: 0.6381857395172119
#
# Average loss: 0.6323, Accuracy: 22178.0/26038 (85%)
#
#
# Average loss: 0.6373, Accuracy: 2477.0/2940 (84%)
#
# Epoch: 1 	Training Accuracy: 85.18%
# Validation Accuracy: 84.25%
# Batch: 0, Loss: 0.6004344820976257
# Batch: 20, Loss: 0.5735393762588501
# Batch: 40, Loss: 0.45749855041503906
# Batch: 60, Loss: 0.584311842918396
# Batch: 80, Loss: 0.47205957770347595
# Batch: 100, Loss: 0.4353730082511902
# Batch: 120, Loss: 0.45706477761268616
# Batch: 140, Loss: 0.4694660007953644
# Batch: 160, Loss: 0.4546518325805664
# Batch: 180, Loss: 0.40179410576820374
# Batch: 200, Loss: 0.3333095610141754
#
# Average loss: 0.4016, Accuracy: 23019.0/26038 (88%)
#
#
# Average loss: 0.4091, Accuracy: 2579.0/2940 (88%)
#
# Epoch: 2 	Training Accuracy: 88.41%
# Validation Accuracy: 87.72%
# Batch: 0, Loss: 0.39673343300819397
# Batch: 20, Loss: 0.29360949993133545
# Batch: 40, Loss: 0.41802912950515747
# Batch: 60, Loss: 0.3988613188266754
# Batch: 80, Loss: 0.446469247341156
# Batch: 100, Loss: 0.3659212589263916
# Batch: 120, Loss: 0.3696008324623108
# Batch: 140, Loss: 0.4768369793891907
# Batch: 160, Loss: 0.29963403940200806
# Batch: 180, Loss: 0.3222252130508423
# Batch: 200, Loss: 0.3794310688972473
#
# Average loss: 0.3322, Accuracy: 23335.0/26038 (90%)
#
#
# Average loss: 0.3394, Accuracy: 2611.0/2940 (89%)
#
# Epoch: 3 	Training Accuracy: 89.62%
# Validation Accuracy: 88.81%
# Batch: 0, Loss: 0.34641093015670776
# Batch: 20, Loss: 0.35266533493995667
# Batch: 40, Loss: 0.26388439536094666
# Batch: 60, Loss: 0.298066645860672
# Batch: 80, Loss: 0.29592111706733704
# Batch: 100, Loss: 0.32358208298683167
# Batch: 120, Loss: 0.3225049376487732
# Batch: 140, Loss: 0.3281726539134979
# Batch: 160, Loss: 0.2946186661720276
# Batch: 180, Loss: 0.17349910736083984
# Batch: 200, Loss: 0.32068729400634766
#
# Average loss: 0.2980, Accuracy: 23529.0/26038 (90%)
#
#
# Average loss: 0.3054, Accuracy: 2628.0/2940 (89%)
#
# Epoch: 4 	Training Accuracy: 90.36%
# Validation Accuracy: 89.39%
# Batch: 0, Loss: 0.35010072588920593
# Batch: 20, Loss: 0.21754954755306244
# Batch: 40, Loss: 0.3849826455116272
# Batch: 60, Loss: 0.25096359848976135
# Batch: 80, Loss: 0.226695716381073
# Batch: 100, Loss: 0.27319198846817017
# Batch: 120, Loss: 0.2367476224899292
# Batch: 140, Loss: 0.27110007405281067
# Batch: 160, Loss: 0.34575793147087097
# Batch: 180, Loss: 0.3247406482696533
# Batch: 200, Loss: 0.23384395241737366
#
# Average loss: 0.2745, Accuracy: 23698.0/26038 (91%)
#
#
# Average loss: 0.2819, Accuracy: 2653.0/2940 (90%)
#
# Epoch: 5 	Training Accuracy: 91.01%
# Validation Accuracy: 90.24%
# Batch: 0, Loss: 0.23037327826023102
# Batch: 20, Loss: 0.2309575378894806
# Batch: 40, Loss: 0.23516201972961426
# Batch: 60, Loss: 0.24028737843036652
# Batch: 80, Loss: 0.30521732568740845
# Batch: 100, Loss: 0.3598572313785553
# Batch: 120, Loss: 0.2523782253265381
# Batch: 140, Loss: 0.24689851701259613
# Batch: 160, Loss: 0.16264799237251282
# Batch: 180, Loss: 0.2671046853065491
# Batch: 200, Loss: 0.18367761373519897
#
# Average loss: 0.2582, Accuracy: 23833.0/26038 (92%)
#
#
# Average loss: 0.2653, Accuracy: 2668.0/2940 (91%)
#
# Epoch: 6 	Training Accuracy: 91.53%
# Validation Accuracy: 90.75%
# Batch: 0, Loss: 0.3303506374359131
# Batch: 20, Loss: 0.22464600205421448
# Batch: 40, Loss: 0.3072131276130676
# Batch: 60, Loss: 0.2634153962135315
# Batch: 80, Loss: 0.26638343930244446
# Batch: 100, Loss: 0.249691441655159
# Batch: 120, Loss: 0.42979809641838074
# Batch: 140, Loss: 0.18207935988903046
# Batch: 160, Loss: 0.1525123119354248
# Batch: 180, Loss: 0.24640145897865295
# Batch: 200, Loss: 0.2776409089565277
#
# Average loss: 0.2455, Accuracy: 23924.0/26038 (92%)
#
#
# Average loss: 0.2527, Accuracy: 2686.0/2940 (91%)
#
# Epoch: 7 	Training Accuracy: 91.88%
# Validation Accuracy: 91.36%
# Batch: 0, Loss: 0.19800634682178497
# Batch: 20, Loss: 0.266368567943573
# Batch: 40, Loss: 0.2826080322265625
# Batch: 60, Loss: 0.23466278612613678
# Batch: 80, Loss: 0.2512460947036743
# Batch: 100, Loss: 0.23292690515518188
# Batch: 120, Loss: 0.25883248448371887
# Batch: 140, Loss: 0.21121524274349213
# Batch: 160, Loss: 0.2488013207912445
# Batch: 180, Loss: 0.27292031049728394
# Batch: 200, Loss: 0.2827149033546448
#
# Average loss: 0.2353, Accuracy: 24013.0/26038 (92%)
#
#
# Average loss: 0.2423, Accuracy: 2701.0/2940 (92%)
#
# Epoch: 8 	Training Accuracy: 92.22%
# Validation Accuracy: 91.87%
# Batch: 0, Loss: 0.3144630491733551
# Batch: 20, Loss: 0.13858935236930847
# Batch: 40, Loss: 0.3429446220397949
# Batch: 60, Loss: 0.16102132201194763
# Batch: 80, Loss: 0.1834111362695694
# Batch: 100, Loss: 0.2694464921951294
# Batch: 120, Loss: 0.24136567115783691
# Batch: 140, Loss: 0.12175939977169037
# Batch: 160, Loss: 0.2671850025653839
# Batch: 180, Loss: 0.23409610986709595
# Batch: 200, Loss: 0.24847285449504852
#
# Average loss: 0.2273, Accuracy: 24075.0/26038 (92%)
#
#
# Average loss: 0.2349, Accuracy: 2706.0/2940 (92%)
#
# Epoch: 9 	Training Accuracy: 92.46%
# Validation Accuracy: 92.04%
# Batch: 0, Loss: 0.24109503626823425
# Batch: 20, Loss: 0.30562692880630493
# Batch: 40, Loss: 0.2597506046295166
# Batch: 60, Loss: 0.2722195088863373
# Batch: 80, Loss: 0.18494969606399536
# Batch: 100, Loss: 0.23647570610046387
# Batch: 120, Loss: 0.20372934639453888
# Batch: 140, Loss: 0.21184806525707245
# Batch: 160, Loss: 0.22199073433876038
# Batch: 180, Loss: 0.3338111937046051
# Batch: 200, Loss: 0.25813359022140503
#
# Average loss: 0.2201, Accuracy: 24133.0/26038 (93%)
#
#
# Average loss: 0.2273, Accuracy: 2708.0/2940 (92%)
#
# Epoch: 10 	Training Accuracy: 92.68%
# Validation Accuracy: 92.11%
# Batch: 0, Loss: 0.35350045561790466
# Batch: 20, Loss: 0.36751827597618103
# Batch: 40, Loss: 0.2179233878850937
# Batch: 60, Loss: 0.25145453214645386
# Batch: 80, Loss: 0.27385905385017395
# Batch: 100, Loss: 0.26141926646232605
# Batch: 120, Loss: 0.2976526618003845
# Batch: 140, Loss: 0.21494685113430023
# Batch: 160, Loss: 0.21943169832229614
# Batch: 180, Loss: 0.14108487963676453
# Batch: 200, Loss: 0.1967533528804779
#
# Average loss: 0.2141, Accuracy: 24187.0/26038 (93%)
#
#
# Average loss: 0.2207, Accuracy: 2711.0/2940 (92%)
#
# Epoch: 11 	Training Accuracy: 92.89%
# Validation Accuracy: 92.21%
# Batch: 0, Loss: 0.2052534967660904
# Batch: 20, Loss: 0.18051837384700775
# Batch: 40, Loss: 0.28844359517097473
# Batch: 60, Loss: 0.17757192254066467
# Batch: 80, Loss: 0.19641728699207306
# Batch: 100, Loss: 0.11003733426332474
# Batch: 120, Loss: 0.21108445525169373
# Batch: 140, Loss: 0.13646429777145386
# Batch: 160, Loss: 0.2837422788143158
# Batch: 180, Loss: 0.15982167422771454
# Batch: 200, Loss: 0.21964918076992035
#
# Average loss: 0.2108, Accuracy: 24203.0/26038 (93%)
#
#
# Average loss: 0.2172, Accuracy: 2715.0/2940 (92%)
#
# Epoch: 12 	Training Accuracy: 92.95%
# Validation Accuracy: 92.35%
# Batch: 0, Loss: 0.24764995276927948
# Batch: 20, Loss: 0.1777210682630539
# Batch: 40, Loss: 0.11997830122709274
# Batch: 60, Loss: 0.15164153277873993
# Batch: 80, Loss: 0.12402202188968658
# Batch: 100, Loss: 0.20872654020786285
# Batch: 120, Loss: 0.14418759942054749
# Batch: 140, Loss: 0.16615009307861328
# Batch: 160, Loss: 0.27872583270072937
# Batch: 180, Loss: 0.1474544107913971
# Batch: 200, Loss: 0.24011045694351196
#
# Average loss: 0.2055, Accuracy: 24263.0/26038 (93%)
#
#
# Average loss: 0.2132, Accuracy: 2722.0/2940 (93%)
#
# Epoch: 13 	Training Accuracy: 93.18%
# Validation Accuracy: 92.59%
# Batch: 0, Loss: 0.20006854832172394
# Batch: 20, Loss: 0.17996469140052795
# Batch: 40, Loss: 0.21742118895053864
# Batch: 60, Loss: 0.21204756200313568
# Batch: 80, Loss: 0.20757946372032166
# Batch: 100, Loss: 0.12979266047477722
# Batch: 120, Loss: 0.20353366434574127
# Batch: 140, Loss: 0.26463979482650757
# Batch: 160, Loss: 0.24608226120471954
# Batch: 180, Loss: 0.197843536734581
# Batch: 200, Loss: 0.159145325422287
#
# Average loss: 0.2021, Accuracy: 24283.0/26038 (93%)
#
#
# Average loss: 0.2093, Accuracy: 2732.0/2940 (93%)
#
# Epoch: 14 	Training Accuracy: 93.26%
# Validation Accuracy: 92.93%
# Batch: 0, Loss: 0.2394736409187317
# Batch: 20, Loss: 0.25737419724464417
# Batch: 40, Loss: 0.16346623003482819
# Batch: 60, Loss: 0.20890973508358002
# Batch: 80, Loss: 0.11551525443792343
# Batch: 100, Loss: 0.1205638200044632
# Batch: 120, Loss: 0.1977362185716629
# Batch: 140, Loss: 0.18064142763614655
# Batch: 160, Loss: 0.20454776287078857
# Batch: 180, Loss: 0.18083682656288147
# Batch: 200, Loss: 0.1814793199300766
#
# Average loss: 0.1987, Accuracy: 24292.0/26038 (93%)
#
#
# Average loss: 0.2058, Accuracy: 2736.0/2940 (93%)
#
# Epoch: 15 	Training Accuracy: 93.29%
# Validation Accuracy: 93.06%
# Batch: 0, Loss: 0.2943856418132782
# Batch: 20, Loss: 0.15307120978832245
# Batch: 40, Loss: 0.12309154123067856
# Batch: 60, Loss: 0.23209534585475922
# Batch: 80, Loss: 0.17631739377975464
# Batch: 100, Loss: 0.3550085723400116
# Batch: 120, Loss: 0.23576416075229645
# Batch: 140, Loss: 0.13841287791728973
# Batch: 160, Loss: 0.2651767432689667
# Batch: 180, Loss: 0.2530403733253479
# Batch: 200, Loss: 0.20453312993049622
#
# Average loss: 0.1953, Accuracy: 24306.0/26038 (93%)
#
#
# Average loss: 0.2029, Accuracy: 2741.0/2940 (93%)
#
# Epoch: 16 	Training Accuracy: 93.35%
# Validation Accuracy: 93.23%
# Batch: 0, Loss: 0.19403350353240967
# Batch: 20, Loss: 0.1899469792842865
# Batch: 40, Loss: 0.1422852873802185
# Batch: 60, Loss: 0.16309364140033722
# Batch: 80, Loss: 0.18257689476013184
# Batch: 100, Loss: 0.30153992772102356
# Batch: 120, Loss: 0.12710413336753845
# Batch: 140, Loss: 0.21740388870239258
# Batch: 160, Loss: 0.13025037944316864
# Batch: 180, Loss: 0.14193642139434814
# Batch: 200, Loss: 0.2860185503959656
#
# Average loss: 0.1939, Accuracy: 24311.0/26038 (93%)
#
#
# Average loss: 0.1997, Accuracy: 2744.0/2940 (93%)
#
# Epoch: 17 	Training Accuracy: 93.37%
# Validation Accuracy: 93.33%
# Batch: 0, Loss: 0.1365782469511032
# Batch: 20, Loss: 0.14948324859142303
# Batch: 40, Loss: 0.19230793416500092
# Batch: 60, Loss: 0.13343623280525208
# Batch: 80, Loss: 0.10168638825416565
# Batch: 100, Loss: 0.2806078791618347
# Batch: 120, Loss: 0.13710275292396545
# Batch: 140, Loss: 0.1652596890926361
# Batch: 160, Loss: 0.1281435638666153
# Batch: 180, Loss: 0.1804438829421997
# Batch: 200, Loss: 0.19996419548988342
#
# Average loss: 0.1912, Accuracy: 24372.0/26038 (94%)
#
#
# Average loss: 0.1986, Accuracy: 2750.0/2940 (94%)
#
# Epoch: 18 	Training Accuracy: 93.60%
# Validation Accuracy: 93.54%
# Batch: 0, Loss: 0.20750242471694946
# Batch: 20, Loss: 0.1757804900407791
# Batch: 40, Loss: 0.27372443675994873
# Batch: 60, Loss: 0.1046963483095169
# Batch: 80, Loss: 0.2519547939300537
# Batch: 100, Loss: 0.1867612600326538
# Batch: 120, Loss: 0.15857085585594177
# Batch: 140, Loss: 0.14059698581695557
# Batch: 160, Loss: 0.17883357405662537
# Batch: 180, Loss: 0.22692479193210602
# Batch: 200, Loss: 0.19249391555786133
#
# Average loss: 0.1894, Accuracy: 24370.0/26038 (94%)
#
#
# Average loss: 0.1962, Accuracy: 2749.0/2940 (94%)
#
# Epoch: 19 	Training Accuracy: 93.59%
# Validation Accuracy: 93.50%
#
# Average loss: 0.1894, Accuracy: 24370.0/26038 (94%)
#
#
# Average loss: 0.1955, Accuracy: 4533.0/4861 (93%)
#
# Final Training Accuracy (New Data): 0.9359
# Final Test Accuracy (New Data): 0.9325
# Percentage: 0.01, Seed: 10, Epochs taken: 7
# Percentage: 0.01, Seed: 20, Epochs taken: 20
# Percentage: 0.01, Seed: 30, Epochs taken: 20
# Percentage: 0.01, Seed: 40, Epochs taken: 7
# Percentage: 0.01, Seed: 50, Epochs taken: 20
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 7
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 7
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 7
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 7
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 7
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 20
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 20
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 20
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 20
# Percentage: 1, Seed: 40, Epochs taken: 20
# Percentage: 1, Seed: 50, Epochs taken: 20

# %% [markdown]
# ## Only heads and data for new classes

# %% [markdown]
# now with balanced classes

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.0001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test_finetune = {}
results_train_finetune = {}
best_models = {}
data_loaders = {}
epochs_taken_finetune = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in percentages:
    print(f"Percentage: {perc}")
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []  # Store epochs for this percentage

    for _, temp_seed in enumerate(seed_set):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")

        # Copying model
        model_new = copy.deepcopy(model)

        in_features = model.fc_2.in_features
        out_features = 5

        # Reinitializing the second fcnn layer and softmax layer
        model_new.fc_2 = nn.Linear(in_features, out_features)  # Reinitialize with the same shape
        model_new.softmax = nn.Softmax(dim=1)
        
        model_new.to(device)

        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)
        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test_finetune[perc] = test_accuracies
    results_train_finetune[perc] = train_accuracies
    epochs_taken_finetune[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken_finetune[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Percentage: 0.01
# Repeat: 0, with seed 22 =========================
# Batch: 0, Loss: 1.7990567684173584
#
# Average loss: 1.7775, Accuracy: 39.0/260 (15%)
#
#
# Average loss: 1.8029, Accuracy: 357.0/2940 (12%)
#
# Epoch: 0 	Training Accuracy: 15.00%
# Validation Accuracy: 12.14%
# Batch: 0, Loss: 1.7924270629882812
#
# Average loss: 1.7373, Accuracy: 43.0/260 (17%)
#
#
# Average loss: 1.7629, Accuracy: 442.0/2940 (15%)
#
# Epoch: 1 	Training Accuracy: 16.54%
# Validation Accuracy: 15.03%
# Batch: 0, Loss: 1.7308027744293213
#
# Average loss: 1.6989, Accuracy: 49.0/260 (19%)
#
#
# Average loss: 1.7244, Accuracy: 526.0/2940 (18%)
#
# Epoch: 2 	Training Accuracy: 18.85%
# Validation Accuracy: 17.89%
# Batch: 0, Loss: 1.7194137573242188
#
# Average loss: 1.6627, Accuracy: 57.0/260 (22%)
#
#
# Average loss: 1.6880, Accuracy: 612.0/2940 (21%)
#
# Epoch: 3 	Training Accuracy: 21.92%
# Validation Accuracy: 20.82%
# Batch: 0, Loss: 1.695411205291748
#
# Average loss: 1.6286, Accuracy: 68.0/260 (26%)
#
#
# Average loss: 1.6540, Accuracy: 710.0/2940 (24%)
#
# Epoch: 4 	Training Accuracy: 26.15%
# Validation Accuracy: 24.15%
# Batch: 0, Loss: 1.6367162466049194
#
# Average loss: 1.5958, Accuracy: 69.0/260 (27%)
#
#
# Average loss: 1.6215, Accuracy: 787.0/2940 (27%)
#
# Epoch: 5 	Training Accuracy: 26.54%
# Validation Accuracy: 26.77%
# Batch: 0, Loss: 1.5960673093795776
#
# Average loss: 1.5638, Accuracy: 75.0/260 (29%)
#
#
# Average loss: 1.5898, Accuracy: 875.0/2940 (30%)
#
# Epoch: 6 	Training Accuracy: 28.85%
# Validation Accuracy: 29.76%
# Batch: 0, Loss: 1.5602680444717407
#
# Average loss: 1.5329, Accuracy: 92.0/260 (35%)
#
#
# Average loss: 1.5596, Accuracy: 993.0/2940 (34%)
#
# Epoch: 7 	Training Accuracy: 35.38%
# Validation Accuracy: 33.78%
# Batch: 0, Loss: 1.5726245641708374
#
# Average loss: 1.5031, Accuracy: 104.0/260 (40%)
#
#
# Average loss: 1.5306, Accuracy: 1120.0/2940 (38%)
#
# Epoch: 8 	Training Accuracy: 40.00%
# Validation Accuracy: 38.10%
# Batch: 0, Loss: 1.5349252223968506
#
# Average loss: 1.4746, Accuracy: 114.0/260 (44%)
#
#
# Average loss: 1.5030, Accuracy: 1242.0/2940 (42%)
#
# Epoch: 9 	Training Accuracy: 43.85%
# Validation Accuracy: 42.24%
# Batch: 0, Loss: 1.438538908958435
#
# Average loss: 1.4471, Accuracy: 123.0/260 (47%)
#
#
# Average loss: 1.4763, Accuracy: 1328.0/2940 (45%)
#
# Epoch: 10 	Training Accuracy: 47.31%
# Validation Accuracy: 45.17%
# Batch: 0, Loss: 1.4347748756408691
#
# Average loss: 1.4209, Accuracy: 129.0/260 (50%)
#
#
# Average loss: 1.4510, Accuracy: 1417.0/2940 (48%)
#
# Epoch: 11 	Training Accuracy: 49.62%
# Validation Accuracy: 48.20%
# Batch: 0, Loss: 1.4064466953277588
#
# Average loss: 1.3951, Accuracy: 137.0/260 (53%)
#
#
# Average loss: 1.4260, Accuracy: 1469.0/2940 (50%)
#
# Epoch: 12 	Training Accuracy: 52.69%
# Validation Accuracy: 49.97%
# Batch: 0, Loss: 1.3893707990646362
#
# Average loss: 1.3694, Accuracy: 138.0/260 (53%)
#
#
# Average loss: 1.4009, Accuracy: 1518.0/2940 (52%)
#
# Epoch: 13 	Training Accuracy: 53.08%
# Validation Accuracy: 51.63%
# Batch: 0, Loss: 1.3587956428527832
#
# Average loss: 1.3441, Accuracy: 140.0/260 (54%)
#
#
# Average loss: 1.3762, Accuracy: 1540.0/2940 (52%)
#
# Epoch: 14 	Training Accuracy: 53.85%
# Validation Accuracy: 52.38%
# Batch: 0, Loss: 1.404695749282837
#
# Average loss: 1.3199, Accuracy: 143.0/260 (55%)
#
#
# Average loss: 1.3525, Accuracy: 1569.0/2940 (53%)
#
# Epoch: 15 	Training Accuracy: 55.00%
# Validation Accuracy: 53.37%
# Batch: 0, Loss: 1.3177316188812256
#
# Average loss: 1.2971, Accuracy: 148.0/260 (57%)
#
#
# Average loss: 1.3302, Accuracy: 1598.0/2940 (54%)
#
# Epoch: 16 	Training Accuracy: 56.92%
# Validation Accuracy: 54.35%
# Batch: 0, Loss: 1.2596375942230225
#
# Average loss: 1.2754, Accuracy: 150.0/260 (58%)
#
#
# Average loss: 1.3090, Accuracy: 1611.0/2940 (55%)
#
# Epoch: 17 	Training Accuracy: 57.69%
# Validation Accuracy: 54.80%
# Batch: 0, Loss: 1.2737245559692383
#
# Average loss: 1.2539, Accuracy: 152.0/260 (58%)
#
#
# Average loss: 1.2881, Accuracy: 1628.0/2940 (55%)
#
# Epoch: 18 	Training Accuracy: 58.46%
# Validation Accuracy: 55.37%
# Batch: 0, Loss: 1.2520723342895508
#
# Average loss: 1.2320, Accuracy: 153.0/260 (59%)
#
#
# Average loss: 1.2666, Accuracy: 1643.0/2940 (56%)
#
# Epoch: 19 	Training Accuracy: 58.85%
# Validation Accuracy: 55.88%
#
# Average loss: 1.2320, Accuracy: 153.0/260 (59%)
#
#
# Average loss: 1.2509, Accuracy: 2777.0/4861 (57%)
#
# Repeat: 1, with seed 66 =========================
# Batch: 0, Loss: 1.6663190126419067
#
# Average loss: 1.6282, Accuracy: 48.0/260 (18%)
#
#
# Average loss: 1.5878, Accuracy: 710.0/2940 (24%)
#
# Epoch: 0 	Training Accuracy: 18.46%
# Validation Accuracy: 24.15%
# Batch: 0, Loss: 1.5892112255096436
#
# Average loss: 1.5880, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.5506, Accuracy: 811.0/2940 (28%)
#
# Epoch: 1 	Training Accuracy: 22.31%
# Validation Accuracy: 27.59%
# Batch: 0, Loss: 1.586591362953186
#
# Average loss: 1.5511, Accuracy: 68.0/260 (26%)
#
#
# Average loss: 1.5162, Accuracy: 929.0/2940 (32%)
#
# Epoch: 2 	Training Accuracy: 26.15%
# Validation Accuracy: 31.60%
# Batch: 0, Loss: 1.5191200971603394
#
# Average loss: 1.5173, Accuracy: 80.0/260 (31%)
#
#
# Average loss: 1.4849, Accuracy: 1025.0/2940 (35%)
#
# Epoch: 3 	Training Accuracy: 30.77%
# Validation Accuracy: 34.86%
# Batch: 0, Loss: 1.5080914497375488
#
# Average loss: 1.4871, Accuracy: 86.0/260 (33%)
#
#
# Average loss: 1.4571, Accuracy: 1102.0/2940 (37%)
#
# Epoch: 4 	Training Accuracy: 33.08%
# Validation Accuracy: 37.48%
# Batch: 0, Loss: 1.4650877714157104
#
# Average loss: 1.4576, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.4300, Accuracy: 1175.0/2940 (40%)
#
# Epoch: 5 	Training Accuracy: 35.00%
# Validation Accuracy: 39.97%
# Batch: 0, Loss: 1.478522777557373
#
# Average loss: 1.4289, Accuracy: 94.0/260 (36%)
#
#
# Average loss: 1.4032, Accuracy: 1239.0/2940 (42%)
#
# Epoch: 6 	Training Accuracy: 36.15%
# Validation Accuracy: 42.14%
# Batch: 0, Loss: 1.4614061117172241
#
# Average loss: 1.4005, Accuracy: 101.0/260 (39%)
#
#
# Average loss: 1.3764, Accuracy: 1290.0/2940 (44%)
#
# Epoch: 7 	Training Accuracy: 38.85%
# Validation Accuracy: 43.88%
# Batch: 0, Loss: 1.4120073318481445
#
# Average loss: 1.3720, Accuracy: 108.0/260 (42%)
#
#
# Average loss: 1.3491, Accuracy: 1363.0/2940 (46%)
#
# Epoch: 8 	Training Accuracy: 41.54%
# Validation Accuracy: 46.36%
# Batch: 0, Loss: 1.3890784978866577
#
# Average loss: 1.3436, Accuracy: 112.0/260 (43%)
#
#
# Average loss: 1.3218, Accuracy: 1424.0/2940 (48%)
#
# Epoch: 9 	Training Accuracy: 43.08%
# Validation Accuracy: 48.44%
# Batch: 0, Loss: 1.3177947998046875
#
# Average loss: 1.3157, Accuracy: 120.0/260 (46%)
#
#
# Average loss: 1.2951, Accuracy: 1486.0/2940 (51%)
#
# Epoch: 10 	Training Accuracy: 46.15%
# Validation Accuracy: 50.54%
# Batch: 0, Loss: 1.329380750656128
#
# Average loss: 1.2888, Accuracy: 131.0/260 (50%)
#
#
# Average loss: 1.2693, Accuracy: 1557.0/2940 (53%)
#
# Epoch: 11 	Training Accuracy: 50.38%
# Validation Accuracy: 52.96%
# Batch: 0, Loss: 1.3247857093811035
#
# Average loss: 1.2627, Accuracy: 136.0/260 (52%)
#
#
# Average loss: 1.2444, Accuracy: 1626.0/2940 (55%)
#
# Epoch: 12 	Training Accuracy: 52.31%
# Validation Accuracy: 55.31%
# Batch: 0, Loss: 1.2611390352249146
#
# Average loss: 1.2376, Accuracy: 141.0/260 (54%)
#
#
# Average loss: 1.2204, Accuracy: 1688.0/2940 (57%)
#
# Epoch: 13 	Training Accuracy: 54.23%
# Validation Accuracy: 57.41%
# Batch: 0, Loss: 1.2419087886810303
#
# Average loss: 1.2137, Accuracy: 150.0/260 (58%)
#
#
# Average loss: 1.1973, Accuracy: 1749.0/2940 (59%)
#
# Epoch: 14 	Training Accuracy: 57.69%
# Validation Accuracy: 59.49%
# Batch: 0, Loss: 1.2130950689315796
#
# Average loss: 1.1903, Accuracy: 153.0/260 (59%)
#
#
# Average loss: 1.1747, Accuracy: 1805.0/2940 (61%)
#
# Epoch: 15 	Training Accuracy: 58.85%
# Validation Accuracy: 61.39%
# Batch: 0, Loss: 1.175101399421692
#
# Average loss: 1.1671, Accuracy: 155.0/260 (60%)
#
#
# Average loss: 1.1526, Accuracy: 1875.0/2940 (64%)
#
# Epoch: 16 	Training Accuracy: 59.62%
# Validation Accuracy: 63.78%
# Batch: 0, Loss: 1.1622662544250488
#
# Average loss: 1.1439, Accuracy: 164.0/260 (63%)
#
#
# Average loss: 1.1306, Accuracy: 1929.0/2940 (66%)
#
# Epoch: 17 	Training Accuracy: 63.08%
# Validation Accuracy: 65.61%
# Batch: 0, Loss: 1.1261441707611084
#
# Average loss: 1.1206, Accuracy: 172.0/260 (66%)
#
#
# Average loss: 1.1086, Accuracy: 1997.0/2940 (68%)
#
# Epoch: 18 	Training Accuracy: 66.15%
# Validation Accuracy: 67.93%
# Batch: 0, Loss: 1.095263957977295
#
# Average loss: 1.0972, Accuracy: 182.0/260 (70%)
#
#
# Average loss: 1.0868, Accuracy: 2081.0/2940 (71%)
#
# Epoch: 19 	Training Accuracy: 70.00%
# Validation Accuracy: 70.78%
#
# Average loss: 1.0972, Accuracy: 182.0/260 (70%)
#
#
# Average loss: 1.0831, Accuracy: 3468.0/4861 (71%)
#
# Repeat: 2, with seed 93 =========================
# Batch: 0, Loss: 1.6468292474746704
#
# Average loss: 1.6216, Accuracy: 70.0/260 (27%)
#
#
# Average loss: 1.6233, Accuracy: 781.0/2940 (27%)
#
# Epoch: 0 	Training Accuracy: 26.92%
# Validation Accuracy: 26.56%
# Batch: 0, Loss: 1.6315847635269165
#
# Average loss: 1.5793, Accuracy: 77.0/260 (30%)
#
#
# Average loss: 1.5831, Accuracy: 886.0/2940 (30%)
#
# Epoch: 1 	Training Accuracy: 29.62%
# Validation Accuracy: 30.14%
# Batch: 0, Loss: 1.5551260709762573
#
# Average loss: 1.5404, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5462, Accuracy: 946.0/2940 (32%)
#
# Epoch: 2 	Training Accuracy: 32.31%
# Validation Accuracy: 32.18%
# Batch: 0, Loss: 1.5345180034637451
#
# Average loss: 1.5055, Accuracy: 83.0/260 (32%)
#
#
# Average loss: 1.5127, Accuracy: 977.0/2940 (33%)
#
# Epoch: 3 	Training Accuracy: 31.92%
# Validation Accuracy: 33.23%
# Batch: 0, Loss: 1.459754467010498
#
# Average loss: 1.4733, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.4820, Accuracy: 1033.0/2940 (35%)
#
# Epoch: 4 	Training Accuracy: 35.00%
# Validation Accuracy: 35.14%
# Batch: 0, Loss: 1.4728484153747559
#
# Average loss: 1.4435, Accuracy: 97.0/260 (37%)
#
#
# Average loss: 1.4532, Accuracy: 1059.0/2940 (36%)
#
# Epoch: 5 	Training Accuracy: 37.31%
# Validation Accuracy: 36.02%
# Batch: 0, Loss: 1.4551963806152344
#
# Average loss: 1.4144, Accuracy: 100.0/260 (38%)
#
#
# Average loss: 1.4256, Accuracy: 1089.0/2940 (37%)
#
# Epoch: 6 	Training Accuracy: 38.46%
# Validation Accuracy: 37.04%
# Batch: 0, Loss: 1.4196239709854126
#
# Average loss: 1.3860, Accuracy: 103.0/260 (40%)
#
#
# Average loss: 1.3990, Accuracy: 1141.0/2940 (39%)
#
# Epoch: 7 	Training Accuracy: 39.62%
# Validation Accuracy: 38.81%
# Batch: 0, Loss: 1.4061541557312012
#
# Average loss: 1.3585, Accuracy: 110.0/260 (42%)
#
#
# Average loss: 1.3733, Accuracy: 1215.0/2940 (41%)
#
# Epoch: 8 	Training Accuracy: 42.31%
# Validation Accuracy: 41.33%
# Batch: 0, Loss: 1.3480032682418823
#
# Average loss: 1.3323, Accuracy: 115.0/260 (44%)
#
#
# Average loss: 1.3487, Accuracy: 1279.0/2940 (44%)
#
# Epoch: 9 	Training Accuracy: 44.23%
# Validation Accuracy: 43.50%
# Batch: 0, Loss: 1.3504184484481812
#
# Average loss: 1.3071, Accuracy: 119.0/260 (46%)
#
#
# Average loss: 1.3247, Accuracy: 1345.0/2940 (46%)
#
# Epoch: 10 	Training Accuracy: 45.77%
# Validation Accuracy: 45.75%
# Batch: 0, Loss: 1.2789214849472046
#
# Average loss: 1.2824, Accuracy: 124.0/260 (48%)
#
#
# Average loss: 1.3013, Accuracy: 1389.0/2940 (47%)
#
# Epoch: 11 	Training Accuracy: 47.69%
# Validation Accuracy: 47.24%
# Batch: 0, Loss: 1.2853862047195435
#
# Average loss: 1.2581, Accuracy: 129.0/260 (50%)
#
#
# Average loss: 1.2783, Accuracy: 1445.0/2940 (49%)
#
# Epoch: 12 	Training Accuracy: 49.62%
# Validation Accuracy: 49.15%
# Batch: 0, Loss: 1.2449853420257568
#
# Average loss: 1.2342, Accuracy: 139.0/260 (53%)
#
#
# Average loss: 1.2559, Accuracy: 1527.0/2940 (52%)
#
# Epoch: 13 	Training Accuracy: 53.46%
# Validation Accuracy: 51.94%
# Batch: 0, Loss: 1.2601783275604248
#
# Average loss: 1.2108, Accuracy: 145.0/260 (56%)
#
#
# Average loss: 1.2340, Accuracy: 1573.0/2940 (54%)
#
# Epoch: 14 	Training Accuracy: 55.77%
# Validation Accuracy: 53.50%
# Batch: 0, Loss: 1.208398699760437
#
# Average loss: 1.1884, Accuracy: 151.0/260 (58%)
#
#
# Average loss: 1.2132, Accuracy: 1632.0/2940 (56%)
#
# Epoch: 15 	Training Accuracy: 58.08%
# Validation Accuracy: 55.51%
# Batch: 0, Loss: 1.181309700012207
#
# Average loss: 1.1661, Accuracy: 160.0/260 (62%)
#
#
# Average loss: 1.1925, Accuracy: 1692.0/2940 (58%)
#
# Epoch: 16 	Training Accuracy: 61.54%
# Validation Accuracy: 57.55%
# Batch: 0, Loss: 1.1578329801559448
#
# Average loss: 1.1441, Accuracy: 167.0/260 (64%)
#
#
# Average loss: 1.1717, Accuracy: 1753.0/2940 (60%)
#
# Epoch: 17 	Training Accuracy: 64.23%
# Validation Accuracy: 59.63%
# Batch: 0, Loss: 1.1365429162979126
#
# Average loss: 1.1224, Accuracy: 168.0/260 (65%)
#
#
# Average loss: 1.1509, Accuracy: 1819.0/2940 (62%)
#
# Epoch: 18 	Training Accuracy: 64.62%
# Validation Accuracy: 61.87%
# Batch: 0, Loss: 1.1657832860946655
#
# Average loss: 1.1008, Accuracy: 175.0/260 (67%)
#
#
# Average loss: 1.1301, Accuracy: 1867.0/2940 (64%)
#
# Epoch: 19 	Training Accuracy: 67.31%
# Validation Accuracy: 63.50%
#
# Average loss: 1.1008, Accuracy: 175.0/260 (67%)
#
#
# Average loss: 1.1309, Accuracy: 3084.0/4861 (63%)
#
# Repeat: 3, with seed 12 =========================
# Batch: 0, Loss: 1.7565892934799194
#
# Average loss: 1.7231, Accuracy: 16.0/260 (6%)
#
#
# Average loss: 1.7283, Accuracy: 204.0/2940 (7%)
#
# Epoch: 0 	Training Accuracy: 6.15%
# Validation Accuracy: 6.94%
# Batch: 0, Loss: 1.700624704360962
#
# Average loss: 1.6855, Accuracy: 26.0/260 (10%)
#
#
# Average loss: 1.6917, Accuracy: 275.0/2940 (9%)
#
# Epoch: 1 	Training Accuracy: 10.00%
# Validation Accuracy: 9.35%
# Batch: 0, Loss: 1.659973382949829
#
# Average loss: 1.6492, Accuracy: 31.0/260 (12%)
#
#
# Average loss: 1.6565, Accuracy: 365.0/2940 (12%)
#
# Epoch: 2 	Training Accuracy: 11.92%
# Validation Accuracy: 12.41%
# Batch: 0, Loss: 1.6176503896713257
#
# Average loss: 1.6133, Accuracy: 39.0/260 (15%)
#
#
# Average loss: 1.6212, Accuracy: 460.0/2940 (16%)
#
# Epoch: 3 	Training Accuracy: 15.00%
# Validation Accuracy: 15.65%
# Batch: 0, Loss: 1.6065412759780884
#
# Average loss: 1.5789, Accuracy: 54.0/260 (21%)
#
#
# Average loss: 1.5870, Accuracy: 589.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.77%
# Validation Accuracy: 20.03%
# Batch: 0, Loss: 1.5678681135177612
#
# Average loss: 1.5466, Accuracy: 64.0/260 (25%)
#
#
# Average loss: 1.5550, Accuracy: 735.0/2940 (25%)
#
# Epoch: 5 	Training Accuracy: 24.62%
# Validation Accuracy: 25.00%
# Batch: 0, Loss: 1.5419865846633911
#
# Average loss: 1.5150, Accuracy: 75.0/260 (29%)
#
#
# Average loss: 1.5239, Accuracy: 897.0/2940 (31%)
#
# Epoch: 6 	Training Accuracy: 28.85%
# Validation Accuracy: 30.51%
# Batch: 0, Loss: 1.5195964574813843
#
# Average loss: 1.4840, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.4933, Accuracy: 1047.0/2940 (36%)
#
# Epoch: 7 	Training Accuracy: 35.00%
# Validation Accuracy: 35.61%
# Batch: 0, Loss: 1.5011200904846191
#
# Average loss: 1.4537, Accuracy: 111.0/260 (43%)
#
#
# Average loss: 1.4632, Accuracy: 1217.0/2940 (41%)
#
# Epoch: 8 	Training Accuracy: 42.69%
# Validation Accuracy: 41.39%
# Batch: 0, Loss: 1.4624844789505005
#
# Average loss: 1.4248, Accuracy: 130.0/260 (50%)
#
#
# Average loss: 1.4342, Accuracy: 1380.0/2940 (47%)
#
# Epoch: 9 	Training Accuracy: 50.00%
# Validation Accuracy: 46.94%
# Batch: 0, Loss: 1.4608770608901978
#
# Average loss: 1.3968, Accuracy: 142.0/260 (55%)
#
#
# Average loss: 1.4065, Accuracy: 1532.0/2940 (52%)
#
# Epoch: 10 	Training Accuracy: 54.62%
# Validation Accuracy: 52.11%
# Batch: 0, Loss: 1.4113117456436157
#
# Average loss: 1.3697, Accuracy: 157.0/260 (60%)
#
#
# Average loss: 1.3797, Accuracy: 1657.0/2940 (56%)
#
# Epoch: 11 	Training Accuracy: 60.38%
# Validation Accuracy: 56.36%
# Batch: 0, Loss: 1.3561899662017822
#
# Average loss: 1.3435, Accuracy: 165.0/260 (63%)
#
#
# Average loss: 1.3535, Accuracy: 1770.0/2940 (60%)
#
# Epoch: 12 	Training Accuracy: 63.46%
# Validation Accuracy: 60.20%
# Batch: 0, Loss: 1.3456741571426392
#
# Average loss: 1.3180, Accuracy: 174.0/260 (67%)
#
#
# Average loss: 1.3281, Accuracy: 1861.0/2940 (63%)
#
# Epoch: 13 	Training Accuracy: 66.92%
# Validation Accuracy: 63.30%
# Batch: 0, Loss: 1.3119275569915771
#
# Average loss: 1.2930, Accuracy: 179.0/260 (69%)
#
#
# Average loss: 1.3035, Accuracy: 1925.0/2940 (65%)
#
# Epoch: 14 	Training Accuracy: 68.85%
# Validation Accuracy: 65.48%
# Batch: 0, Loss: 1.302422046661377
#
# Average loss: 1.2679, Accuracy: 184.0/260 (71%)
#
#
# Average loss: 1.2787, Accuracy: 1972.0/2940 (67%)
#
# Epoch: 15 	Training Accuracy: 70.77%
# Validation Accuracy: 67.07%
# Batch: 0, Loss: 1.292323350906372
#
# Average loss: 1.2426, Accuracy: 187.0/260 (72%)
#
#
# Average loss: 1.2538, Accuracy: 2036.0/2940 (69%)
#
# Epoch: 16 	Training Accuracy: 71.92%
# Validation Accuracy: 69.25%
# Batch: 0, Loss: 1.2259011268615723
#
# Average loss: 1.2177, Accuracy: 192.0/260 (74%)
#
#
# Average loss: 1.2293, Accuracy: 2095.0/2940 (71%)
#
# Epoch: 17 	Training Accuracy: 73.85%
# Validation Accuracy: 71.26%
# Batch: 0, Loss: 1.2325928211212158
#
# Average loss: 1.1934, Accuracy: 197.0/260 (76%)
#
#
# Average loss: 1.2056, Accuracy: 2147.0/2940 (73%)
#
# Epoch: 18 	Training Accuracy: 75.77%
# Validation Accuracy: 73.03%
# Batch: 0, Loss: 1.183605670928955
#
# Average loss: 1.1697, Accuracy: 203.0/260 (78%)
#
#
# Average loss: 1.1826, Accuracy: 2179.0/2940 (74%)
#
# Epoch: 19 	Training Accuracy: 78.08%
# Validation Accuracy: 74.12%
#
# Average loss: 1.1697, Accuracy: 203.0/260 (78%)
#
#
# Average loss: 1.1788, Accuracy: 3654.0/4861 (75%)
#
# Repeat: 4, with seed 77 =========================
# Batch: 0, Loss: 1.5634196996688843
#
# Average loss: 1.5477, Accuracy: 62.0/260 (24%)
#
#
# Average loss: 1.5505, Accuracy: 723.0/2940 (25%)
#
# Epoch: 0 	Training Accuracy: 23.85%
# Validation Accuracy: 24.59%
# Batch: 0, Loss: 1.5294468402862549
#
# Average loss: 1.5098, Accuracy: 66.0/260 (25%)
#
#
# Average loss: 1.5142, Accuracy: 793.0/2940 (27%)
#
# Epoch: 1 	Training Accuracy: 25.38%
# Validation Accuracy: 26.97%
# Batch: 0, Loss: 1.5028481483459473
#
# Average loss: 1.4764, Accuracy: 72.0/260 (28%)
#
#
# Average loss: 1.4819, Accuracy: 855.0/2940 (29%)
#
# Epoch: 2 	Training Accuracy: 27.69%
# Validation Accuracy: 29.08%
# Batch: 0, Loss: 1.4560946226119995
#
# Average loss: 1.4444, Accuracy: 81.0/260 (31%)
#
#
# Average loss: 1.4510, Accuracy: 922.0/2940 (31%)
#
# Epoch: 3 	Training Accuracy: 31.15%
# Validation Accuracy: 31.36%
# Batch: 0, Loss: 1.4513086080551147
#
# Average loss: 1.4136, Accuracy: 90.0/260 (35%)
#
#
# Average loss: 1.4213, Accuracy: 1008.0/2940 (34%)
#
# Epoch: 4 	Training Accuracy: 34.62%
# Validation Accuracy: 34.29%
# Batch: 0, Loss: 1.3899686336517334
#
# Average loss: 1.3844, Accuracy: 100.0/260 (38%)
#
#
# Average loss: 1.3931, Accuracy: 1095.0/2940 (37%)
#
# Epoch: 5 	Training Accuracy: 38.46%
# Validation Accuracy: 37.24%
# Batch: 0, Loss: 1.3961776494979858
#
# Average loss: 1.3559, Accuracy: 114.0/260 (44%)
#
#
# Average loss: 1.3654, Accuracy: 1198.0/2940 (41%)
#
# Epoch: 6 	Training Accuracy: 43.85%
# Validation Accuracy: 40.75%
# Batch: 0, Loss: 1.3317437171936035
#
# Average loss: 1.3283, Accuracy: 125.0/260 (48%)
#
#
# Average loss: 1.3387, Accuracy: 1326.0/2940 (45%)
#
# Epoch: 7 	Training Accuracy: 48.08%
# Validation Accuracy: 45.10%
# Batch: 0, Loss: 1.3255599737167358
#
# Average loss: 1.3012, Accuracy: 132.0/260 (51%)
#
#
# Average loss: 1.3124, Accuracy: 1417.0/2940 (48%)
#
# Epoch: 8 	Training Accuracy: 50.77%
# Validation Accuracy: 48.20%
# Batch: 0, Loss: 1.2932294607162476
#
# Average loss: 1.2747, Accuracy: 141.0/260 (54%)
#
#
# Average loss: 1.2868, Accuracy: 1533.0/2940 (52%)
#
# Epoch: 9 	Training Accuracy: 54.23%
# Validation Accuracy: 52.14%
# Batch: 0, Loss: 1.256020426750183
#
# Average loss: 1.2486, Accuracy: 148.0/260 (57%)
#
#
# Average loss: 1.2615, Accuracy: 1616.0/2940 (55%)
#
# Epoch: 10 	Training Accuracy: 56.92%
# Validation Accuracy: 54.97%
# Batch: 0, Loss: 1.1832786798477173
#
# Average loss: 1.2228, Accuracy: 158.0/260 (61%)
#
#
# Average loss: 1.2366, Accuracy: 1700.0/2940 (58%)
#
# Epoch: 11 	Training Accuracy: 60.77%
# Validation Accuracy: 57.82%
# Batch: 0, Loss: 1.2724508047103882
#
# Average loss: 1.1972, Accuracy: 166.0/260 (64%)
#
#
# Average loss: 1.2118, Accuracy: 1780.0/2940 (61%)
#
# Epoch: 12 	Training Accuracy: 63.85%
# Validation Accuracy: 60.54%
# Batch: 0, Loss: 1.2348886728286743
#
# Average loss: 1.1720, Accuracy: 170.0/260 (65%)
#
#
# Average loss: 1.1874, Accuracy: 1828.0/2940 (62%)
#
# Epoch: 13 	Training Accuracy: 65.38%
# Validation Accuracy: 62.18%
# Batch: 0, Loss: 1.1624864339828491
#
# Average loss: 1.1474, Accuracy: 174.0/260 (67%)
#
#
# Average loss: 1.1636, Accuracy: 1911.0/2940 (65%)
#
# Epoch: 14 	Training Accuracy: 66.92%
# Validation Accuracy: 65.00%
# Batch: 0, Loss: 1.1531586647033691
#
# Average loss: 1.1233, Accuracy: 181.0/260 (70%)
#
#
# Average loss: 1.1401, Accuracy: 1974.0/2940 (67%)
#
# Epoch: 15 	Training Accuracy: 69.62%
# Validation Accuracy: 67.14%
# Batch: 0, Loss: 1.1230894327163696
#
# Average loss: 1.0996, Accuracy: 187.0/260 (72%)
#
#
# Average loss: 1.1173, Accuracy: 2030.0/2940 (69%)
#
# Epoch: 16 	Training Accuracy: 71.92%
# Validation Accuracy: 69.05%
# Batch: 0, Loss: 1.1071863174438477
#
# Average loss: 1.0768, Accuracy: 190.0/260 (73%)
#
#
# Average loss: 1.0953, Accuracy: 2098.0/2940 (71%)
#
# Epoch: 17 	Training Accuracy: 73.08%
# Validation Accuracy: 71.36%
# Batch: 0, Loss: 1.0783090591430664
#
# Average loss: 1.0547, Accuracy: 193.0/260 (74%)
#
#
# Average loss: 1.0741, Accuracy: 2151.0/2940 (73%)
#
# Epoch: 18 	Training Accuracy: 74.23%
# Validation Accuracy: 73.16%
# Batch: 0, Loss: 1.0317379236221313
#
# Average loss: 1.0329, Accuracy: 198.0/260 (76%)
#
#
# Average loss: 1.0529, Accuracy: 2186.0/2940 (74%)
#
# Epoch: 19 	Training Accuracy: 76.15%
# Validation Accuracy: 74.35%
#
# Average loss: 1.0329, Accuracy: 198.0/260 (76%)
#
#
# Average loss: 1.0516, Accuracy: 3608.0/4861 (74%)
#
# Percentage: 0.03
# Repeat: 0, with seed 24 =========================
# Batch: 0, Loss: 1.7639751434326172
#
# Average loss: 1.6429, Accuracy: 283.0/790 (36%)
#
#
# Average loss: 1.6602, Accuracy: 1048.0/2940 (36%)
#
# Epoch: 0 	Training Accuracy: 35.82%
# Validation Accuracy: 35.65%
# Batch: 0, Loss: 1.6121532917022705
#
# Average loss: 1.5459, Accuracy: 331.0/790 (42%)
#
#
# Average loss: 1.5642, Accuracy: 1215.0/2940 (41%)
#
# Epoch: 1 	Training Accuracy: 41.90%
# Validation Accuracy: 41.33%
# Batch: 0, Loss: 1.5448954105377197
#
# Average loss: 1.4562, Accuracy: 376.0/790 (48%)
#
#
# Average loss: 1.4749, Accuracy: 1355.0/2940 (46%)
#
# Epoch: 2 	Training Accuracy: 47.59%
# Validation Accuracy: 46.09%
# Batch: 0, Loss: 1.4292824268341064
#
# Average loss: 1.3717, Accuracy: 415.0/790 (53%)
#
#
# Average loss: 1.3908, Accuracy: 1486.0/2940 (51%)
#
# Epoch: 3 	Training Accuracy: 52.53%
# Validation Accuracy: 50.54%
# Batch: 0, Loss: 1.385299563407898
#
# Average loss: 1.2916, Accuracy: 452.0/790 (57%)
#
#
# Average loss: 1.3108, Accuracy: 1607.0/2940 (55%)
#
# Epoch: 4 	Training Accuracy: 57.22%
# Validation Accuracy: 54.66%
# Batch: 0, Loss: 1.273437261581421
#
# Average loss: 1.2156, Accuracy: 510.0/790 (65%)
#
#
# Average loss: 1.2351, Accuracy: 1787.0/2940 (61%)
#
# Epoch: 5 	Training Accuracy: 64.56%
# Validation Accuracy: 60.78%
# Batch: 0, Loss: 1.221660852432251
#
# Average loss: 1.1433, Accuracy: 563.0/790 (71%)
#
#
# Average loss: 1.1632, Accuracy: 2018.0/2940 (69%)
#
# Epoch: 6 	Training Accuracy: 71.27%
# Validation Accuracy: 68.64%
# Batch: 0, Loss: 1.166067361831665
#
# Average loss: 1.0745, Accuracy: 608.0/790 (77%)
#
#
# Average loss: 1.0945, Accuracy: 2198.0/2940 (75%)
#
# Epoch: 7 	Training Accuracy: 76.96%
# Validation Accuracy: 74.76%
# Batch: 0, Loss: 1.0551040172576904
#
# Average loss: 1.0085, Accuracy: 649.0/790 (82%)
#
#
# Average loss: 1.0286, Accuracy: 2333.0/2940 (79%)
#
# Epoch: 8 	Training Accuracy: 82.15%
# Validation Accuracy: 79.35%
# Batch: 0, Loss: 1.0392805337905884
#
# Average loss: 0.9464, Accuracy: 666.0/790 (84%)
#
#
# Average loss: 0.9668, Accuracy: 2401.0/2940 (82%)
#
# Epoch: 9 	Training Accuracy: 84.30%
# Validation Accuracy: 81.67%
# Batch: 0, Loss: 0.9534467458724976
#
# Average loss: 0.8874, Accuracy: 683.0/790 (86%)
#
#
# Average loss: 0.9077, Accuracy: 2461.0/2940 (84%)
#
# Epoch: 10 	Training Accuracy: 86.46%
# Validation Accuracy: 83.71%
# Batch: 0, Loss: 0.8717238903045654
#
# Average loss: 0.8325, Accuracy: 693.0/790 (88%)
#
#
# Average loss: 0.8529, Accuracy: 2515.0/2940 (86%)
#
# Epoch: 11 	Training Accuracy: 87.72%
# Validation Accuracy: 85.54%
# Batch: 0, Loss: 0.8906478881835938
#
# Average loss: 0.7809, Accuracy: 702.0/790 (89%)
#
#
# Average loss: 0.8013, Accuracy: 2544.0/2940 (87%)
#
# Epoch: 12 	Training Accuracy: 88.86%
# Validation Accuracy: 86.53%
# Batch: 0, Loss: 0.7489243745803833
#
# Average loss: 0.7334, Accuracy: 712.0/790 (90%)
#
#
# Average loss: 0.7537, Accuracy: 2584.0/2940 (88%)
#
# Epoch: 13 	Training Accuracy: 90.13%
# Validation Accuracy: 87.89%
# Batch: 0, Loss: 0.734500527381897
#
# Average loss: 0.6894, Accuracy: 716.0/790 (91%)
#
#
# Average loss: 0.7098, Accuracy: 2610.0/2940 (89%)
#
# Epoch: 14 	Training Accuracy: 90.63%
# Validation Accuracy: 88.78%
# Batch: 0, Loss: 0.6866297125816345
#
# Average loss: 0.6489, Accuracy: 721.0/790 (91%)
#
#
# Average loss: 0.6700, Accuracy: 2634.0/2940 (90%)
#
# Epoch: 15 	Training Accuracy: 91.27%
# Validation Accuracy: 89.59%
# Batch: 0, Loss: 0.7303327918052673
#
# Average loss: 0.6116, Accuracy: 724.0/790 (92%)
#
#
# Average loss: 0.6338, Accuracy: 2646.0/2940 (90%)
#
# Epoch: 16 	Training Accuracy: 91.65%
# Validation Accuracy: 90.00%
# Batch: 0, Loss: 0.59293133020401
#
# Average loss: 0.5774, Accuracy: 727.0/790 (92%)
#
#
# Average loss: 0.6003, Accuracy: 2660.0/2940 (90%)
#
# Epoch: 17 	Training Accuracy: 92.03%
# Validation Accuracy: 90.48%
# Batch: 0, Loss: 0.5747758746147156
#
# Average loss: 0.5466, Accuracy: 734.0/790 (93%)
#
#
# Average loss: 0.5696, Accuracy: 2671.0/2940 (91%)
#
# Epoch: 18 	Training Accuracy: 92.91%
# Validation Accuracy: 90.85%
# Batch: 0, Loss: 0.6089599132537842
#
# Average loss: 0.5183, Accuracy: 735.0/790 (93%)
#
#
# Average loss: 0.5417, Accuracy: 2688.0/2940 (91%)
#
# Epoch: 19 	Training Accuracy: 93.04%
# Validation Accuracy: 91.43%
#
# Average loss: 0.5183, Accuracy: 735.0/790 (93%)
#
#
# Average loss: 0.5218, Accuracy: 4476.0/4861 (92%)
#
# Repeat: 1, with seed 56 =========================
# Batch: 0, Loss: 1.7908704280853271
#
# Average loss: 1.6349, Accuracy: 109.0/790 (14%)
#
#
# Average loss: 1.6235, Accuracy: 375.0/2940 (13%)
#
# Epoch: 0 	Training Accuracy: 13.80%
# Validation Accuracy: 12.76%
# Batch: 0, Loss: 1.6222985982894897
#
# Average loss: 1.5300, Accuracy: 166.0/790 (21%)
#
#
# Average loss: 1.5215, Accuracy: 592.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 21.01%
# Validation Accuracy: 20.14%
# Batch: 0, Loss: 1.524354100227356
#
# Average loss: 1.4348, Accuracy: 241.0/790 (31%)
#
#
# Average loss: 1.4285, Accuracy: 925.0/2940 (31%)
#
# Epoch: 2 	Training Accuracy: 30.51%
# Validation Accuracy: 31.46%
# Batch: 0, Loss: 1.4434115886688232
#
# Average loss: 1.3481, Accuracy: 343.0/790 (43%)
#
#
# Average loss: 1.3438, Accuracy: 1306.0/2940 (44%)
#
# Epoch: 3 	Training Accuracy: 43.42%
# Validation Accuracy: 44.42%
# Batch: 0, Loss: 1.3446711301803589
#
# Average loss: 1.2683, Accuracy: 445.0/790 (56%)
#
#
# Average loss: 1.2663, Accuracy: 1695.0/2940 (58%)
#
# Epoch: 4 	Training Accuracy: 56.33%
# Validation Accuracy: 57.65%
# Batch: 0, Loss: 1.302970290184021
#
# Average loss: 1.1945, Accuracy: 508.0/790 (64%)
#
#
# Average loss: 1.1945, Accuracy: 1884.0/2940 (64%)
#
# Epoch: 5 	Training Accuracy: 64.30%
# Validation Accuracy: 64.08%
# Batch: 0, Loss: 1.2025431394577026
#
# Average loss: 1.1248, Accuracy: 552.0/790 (70%)
#
#
# Average loss: 1.1252, Accuracy: 2024.0/2940 (69%)
#
# Epoch: 6 	Training Accuracy: 69.87%
# Validation Accuracy: 68.84%
# Batch: 0, Loss: 1.143096923828125
#
# Average loss: 1.0596, Accuracy: 575.0/790 (73%)
#
#
# Average loss: 1.0605, Accuracy: 2124.0/2940 (72%)
#
# Epoch: 7 	Training Accuracy: 72.78%
# Validation Accuracy: 72.24%
# Batch: 0, Loss: 1.09621000289917
#
# Average loss: 0.9976, Accuracy: 592.0/790 (75%)
#
#
# Average loss: 0.9992, Accuracy: 2219.0/2940 (75%)
#
# Epoch: 8 	Training Accuracy: 74.94%
# Validation Accuracy: 75.48%
# Batch: 0, Loss: 1.008410930633545
#
# Average loss: 0.9390, Accuracy: 615.0/790 (78%)
#
#
# Average loss: 0.9410, Accuracy: 2296.0/2940 (78%)
#
# Epoch: 9 	Training Accuracy: 77.85%
# Validation Accuracy: 78.10%
# Batch: 0, Loss: 0.9175567030906677
#
# Average loss: 0.8838, Accuracy: 635.0/790 (80%)
#
#
# Average loss: 0.8863, Accuracy: 2359.0/2940 (80%)
#
# Epoch: 10 	Training Accuracy: 80.38%
# Validation Accuracy: 80.24%
# Batch: 0, Loss: 0.9512885212898254
#
# Average loss: 0.8324, Accuracy: 643.0/790 (81%)
#
#
# Average loss: 0.8356, Accuracy: 2416.0/2940 (82%)
#
# Epoch: 11 	Training Accuracy: 81.39%
# Validation Accuracy: 82.18%
# Batch: 0, Loss: 0.8196700215339661
#
# Average loss: 0.7843, Accuracy: 660.0/790 (84%)
#
#
# Average loss: 0.7885, Accuracy: 2469.0/2940 (84%)
#
# Epoch: 12 	Training Accuracy: 83.54%
# Validation Accuracy: 83.98%
# Batch: 0, Loss: 0.7516400814056396
#
# Average loss: 0.7392, Accuracy: 678.0/790 (86%)
#
#
# Average loss: 0.7436, Accuracy: 2528.0/2940 (86%)
#
# Epoch: 13 	Training Accuracy: 85.82%
# Validation Accuracy: 85.99%
# Batch: 0, Loss: 0.7364752292633057
#
# Average loss: 0.6976, Accuracy: 688.0/790 (87%)
#
#
# Average loss: 0.7030, Accuracy: 2555.0/2940 (87%)
#
# Epoch: 14 	Training Accuracy: 87.09%
# Validation Accuracy: 86.90%
# Batch: 0, Loss: 0.7148736715316772
#
# Average loss: 0.6596, Accuracy: 696.0/790 (88%)
#
#
# Average loss: 0.6655, Accuracy: 2582.0/2940 (88%)
#
# Epoch: 15 	Training Accuracy: 88.10%
# Validation Accuracy: 87.82%
# Batch: 0, Loss: 0.6391306519508362
#
# Average loss: 0.6242, Accuracy: 704.0/790 (89%)
#
#
# Average loss: 0.6309, Accuracy: 2600.0/2940 (88%)
#
# Epoch: 16 	Training Accuracy: 89.11%
# Validation Accuracy: 88.44%
# Batch: 0, Loss: 0.6552714705467224
#
# Average loss: 0.5916, Accuracy: 713.0/790 (90%)
#
#
# Average loss: 0.5984, Accuracy: 2629.0/2940 (89%)
#
# Epoch: 17 	Training Accuracy: 90.25%
# Validation Accuracy: 89.42%
# Batch: 0, Loss: 0.5857776403427124
#
# Average loss: 0.5618, Accuracy: 718.0/790 (91%)
#
#
# Average loss: 0.5692, Accuracy: 2642.0/2940 (90%)
#
# Epoch: 18 	Training Accuracy: 90.89%
# Validation Accuracy: 89.86%
# Batch: 0, Loss: 0.525364339351654
#
# Average loss: 0.5343, Accuracy: 723.0/790 (92%)
#
#
# Average loss: 0.5424, Accuracy: 2648.0/2940 (90%)
#
# Epoch: 19 	Training Accuracy: 91.52%
# Validation Accuracy: 90.07%
#
# Average loss: 0.5343, Accuracy: 723.0/790 (92%)
#
#
# Average loss: 0.5252, Accuracy: 4431.0/4861 (91%)
#
# Repeat: 2, with seed 41 =========================
# Batch: 0, Loss: 1.791585922241211
#
# Average loss: 1.6817, Accuracy: 79.0/790 (10%)
#
#
# Average loss: 1.6877, Accuracy: 302.0/2940 (10%)
#
# Epoch: 0 	Training Accuracy: 10.00%
# Validation Accuracy: 10.27%
# Batch: 0, Loss: 1.6455192565917969
#
# Average loss: 1.5835, Accuracy: 132.0/790 (17%)
#
#
# Average loss: 1.5894, Accuracy: 534.0/2940 (18%)
#
# Epoch: 1 	Training Accuracy: 16.71%
# Validation Accuracy: 18.16%
# Batch: 0, Loss: 1.5670173168182373
#
# Average loss: 1.4926, Accuracy: 195.0/790 (25%)
#
#
# Average loss: 1.4988, Accuracy: 765.0/2940 (26%)
#
# Epoch: 2 	Training Accuracy: 24.68%
# Validation Accuracy: 26.02%
# Batch: 0, Loss: 1.5071240663528442
#
# Average loss: 1.4092, Accuracy: 273.0/790 (35%)
#
#
# Average loss: 1.4157, Accuracy: 1034.0/2940 (35%)
#
# Epoch: 3 	Training Accuracy: 34.56%
# Validation Accuracy: 35.17%
# Batch: 0, Loss: 1.4260954856872559
#
# Average loss: 1.3330, Accuracy: 365.0/790 (46%)
#
#
# Average loss: 1.3403, Accuracy: 1334.0/2940 (45%)
#
# Epoch: 4 	Training Accuracy: 46.20%
# Validation Accuracy: 45.37%
# Batch: 0, Loss: 1.3073945045471191
#
# Average loss: 1.2600, Accuracy: 461.0/790 (58%)
#
#
# Average loss: 1.2678, Accuracy: 1649.0/2940 (56%)
#
# Epoch: 5 	Training Accuracy: 58.35%
# Validation Accuracy: 56.09%
# Batch: 0, Loss: 1.2456843852996826
#
# Average loss: 1.1901, Accuracy: 523.0/790 (66%)
#
#
# Average loss: 1.1983, Accuracy: 1899.0/2940 (65%)
#
# Epoch: 6 	Training Accuracy: 66.20%
# Validation Accuracy: 64.59%
# Batch: 0, Loss: 1.213285207748413
#
# Average loss: 1.1235, Accuracy: 570.0/790 (72%)
#
#
# Average loss: 1.1321, Accuracy: 2059.0/2940 (70%)
#
# Epoch: 7 	Training Accuracy: 72.15%
# Validation Accuracy: 70.03%
# Batch: 0, Loss: 1.0972813367843628
#
# Average loss: 1.0599, Accuracy: 608.0/790 (77%)
#
#
# Average loss: 1.0689, Accuracy: 2164.0/2940 (74%)
#
# Epoch: 8 	Training Accuracy: 76.96%
# Validation Accuracy: 73.61%
# Batch: 0, Loss: 1.0616188049316406
#
# Average loss: 0.9988, Accuracy: 639.0/790 (81%)
#
#
# Average loss: 1.0086, Accuracy: 2289.0/2940 (78%)
#
# Epoch: 9 	Training Accuracy: 80.89%
# Validation Accuracy: 77.86%
# Batch: 0, Loss: 1.022607445716858
#
# Average loss: 0.9406, Accuracy: 659.0/790 (83%)
#
#
# Average loss: 0.9513, Accuracy: 2365.0/2940 (80%)
#
# Epoch: 10 	Training Accuracy: 83.42%
# Validation Accuracy: 80.44%
# Batch: 0, Loss: 0.9333140254020691
#
# Average loss: 0.8860, Accuracy: 672.0/790 (85%)
#
#
# Average loss: 0.8977, Accuracy: 2426.0/2940 (83%)
#
# Epoch: 11 	Training Accuracy: 85.06%
# Validation Accuracy: 82.52%
# Batch: 0, Loss: 0.9062891602516174
#
# Average loss: 0.8342, Accuracy: 686.0/790 (87%)
#
#
# Average loss: 0.8466, Accuracy: 2486.0/2940 (85%)
#
# Epoch: 12 	Training Accuracy: 86.84%
# Validation Accuracy: 84.56%
# Batch: 0, Loss: 0.8077993988990784
#
# Average loss: 0.7854, Accuracy: 695.0/790 (88%)
#
#
# Average loss: 0.7988, Accuracy: 2524.0/2940 (86%)
#
# Epoch: 13 	Training Accuracy: 87.97%
# Validation Accuracy: 85.85%
# Batch: 0, Loss: 0.8145411014556885
#
# Average loss: 0.7398, Accuracy: 697.0/790 (88%)
#
#
# Average loss: 0.7543, Accuracy: 2561.0/2940 (87%)
#
# Epoch: 14 	Training Accuracy: 88.23%
# Validation Accuracy: 87.11%
# Batch: 0, Loss: 0.7151903510093689
#
# Average loss: 0.6971, Accuracy: 703.0/790 (89%)
#
#
# Average loss: 0.7127, Accuracy: 2588.0/2940 (88%)
#
# Epoch: 15 	Training Accuracy: 88.99%
# Validation Accuracy: 88.03%
# Batch: 0, Loss: 0.6996727585792542
#
# Average loss: 0.6574, Accuracy: 705.0/790 (89%)
#
#
# Average loss: 0.6741, Accuracy: 2611.0/2940 (89%)
#
# Epoch: 16 	Training Accuracy: 89.24%
# Validation Accuracy: 88.81%
# Batch: 0, Loss: 0.6626078486442566
#
# Average loss: 0.6203, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.6381, Accuracy: 2629.0/2940 (89%)
#
# Epoch: 17 	Training Accuracy: 90.38%
# Validation Accuracy: 89.42%
# Batch: 0, Loss: 0.6598580479621887
#
# Average loss: 0.5864, Accuracy: 720.0/790 (91%)
#
#
# Average loss: 0.6049, Accuracy: 2640.0/2940 (90%)
#
# Epoch: 18 	Training Accuracy: 91.14%
# Validation Accuracy: 89.80%
# Batch: 0, Loss: 0.5888665914535522
#
# Average loss: 0.5550, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.5745, Accuracy: 2641.0/2940 (90%)
#
# Epoch: 19 	Training Accuracy: 91.39%
# Validation Accuracy: 89.83%
#
# Average loss: 0.5550, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.5620, Accuracy: 4391.0/4861 (90%)
#
# Repeat: 3, with seed 13 =========================
# Batch: 0, Loss: 1.537432074546814
#
# Average loss: 1.4383, Accuracy: 310.0/790 (39%)
#
#
# Average loss: 1.4580, Accuracy: 1072.0/2940 (36%)
#
# Epoch: 0 	Training Accuracy: 39.24%
# Validation Accuracy: 36.46%
# Batch: 0, Loss: 1.4424021244049072
#
# Average loss: 1.3523, Accuracy: 364.0/790 (46%)
#
#
# Average loss: 1.3731, Accuracy: 1271.0/2940 (43%)
#
# Epoch: 1 	Training Accuracy: 46.08%
# Validation Accuracy: 43.23%
# Batch: 0, Loss: 1.3734079599380493
#
# Average loss: 1.2709, Accuracy: 417.0/790 (53%)
#
#
# Average loss: 1.2921, Accuracy: 1448.0/2940 (49%)
#
# Epoch: 2 	Training Accuracy: 52.78%
# Validation Accuracy: 49.25%
# Batch: 0, Loss: 1.2740637063980103
#
# Average loss: 1.1940, Accuracy: 462.0/790 (58%)
#
#
# Average loss: 1.2158, Accuracy: 1625.0/2940 (55%)
#
# Epoch: 3 	Training Accuracy: 58.48%
# Validation Accuracy: 55.27%
# Batch: 0, Loss: 1.1839543581008911
#
# Average loss: 1.1212, Accuracy: 505.0/790 (64%)
#
#
# Average loss: 1.1435, Accuracy: 1790.0/2940 (61%)
#
# Epoch: 4 	Training Accuracy: 63.92%
# Validation Accuracy: 60.88%
# Batch: 0, Loss: 1.1297842264175415
#
# Average loss: 1.0528, Accuracy: 559.0/790 (71%)
#
#
# Average loss: 1.0758, Accuracy: 1991.0/2940 (68%)
#
# Epoch: 5 	Training Accuracy: 70.76%
# Validation Accuracy: 67.72%
# Batch: 0, Loss: 1.0248665809631348
#
# Average loss: 0.9873, Accuracy: 597.0/790 (76%)
#
#
# Average loss: 1.0100, Accuracy: 2152.0/2940 (73%)
#
# Epoch: 6 	Training Accuracy: 75.57%
# Validation Accuracy: 73.20%
# Batch: 0, Loss: 1.0263019800186157
#
# Average loss: 0.9249, Accuracy: 635.0/790 (80%)
#
#
# Average loss: 0.9464, Accuracy: 2294.0/2940 (78%)
#
# Epoch: 7 	Training Accuracy: 80.38%
# Validation Accuracy: 78.03%
# Batch: 0, Loss: 0.9457852840423584
#
# Average loss: 0.8671, Accuracy: 655.0/790 (83%)
#
#
# Average loss: 0.8878, Accuracy: 2396.0/2940 (81%)
#
# Epoch: 8 	Training Accuracy: 82.91%
# Validation Accuracy: 81.50%
# Batch: 0, Loss: 0.8694881200790405
#
# Average loss: 0.8133, Accuracy: 667.0/790 (84%)
#
#
# Average loss: 0.8337, Accuracy: 2449.0/2940 (83%)
#
# Epoch: 9 	Training Accuracy: 84.43%
# Validation Accuracy: 83.30%
# Batch: 0, Loss: 0.863365888595581
#
# Average loss: 0.7635, Accuracy: 679.0/790 (86%)
#
#
# Average loss: 0.7839, Accuracy: 2491.0/2940 (85%)
#
# Epoch: 10 	Training Accuracy: 85.95%
# Validation Accuracy: 84.73%
# Batch: 0, Loss: 0.7545993328094482
#
# Average loss: 0.7174, Accuracy: 684.0/790 (87%)
#
#
# Average loss: 0.7384, Accuracy: 2533.0/2940 (86%)
#
# Epoch: 11 	Training Accuracy: 86.58%
# Validation Accuracy: 86.16%
# Batch: 0, Loss: 0.7281506061553955
#
# Average loss: 0.6742, Accuracy: 700.0/790 (89%)
#
#
# Average loss: 0.6950, Accuracy: 2583.0/2940 (88%)
#
# Epoch: 12 	Training Accuracy: 88.61%
# Validation Accuracy: 87.86%
# Batch: 0, Loss: 0.6929978132247925
#
# Average loss: 0.6349, Accuracy: 705.0/790 (89%)
#
#
# Average loss: 0.6559, Accuracy: 2603.0/2940 (89%)
#
# Epoch: 13 	Training Accuracy: 89.24%
# Validation Accuracy: 88.54%
# Batch: 0, Loss: 0.6490496397018433
#
# Average loss: 0.5990, Accuracy: 706.0/790 (89%)
#
#
# Average loss: 0.6209, Accuracy: 2619.0/2940 (89%)
#
# Epoch: 14 	Training Accuracy: 89.37%
# Validation Accuracy: 89.08%
# Batch: 0, Loss: 0.5904475450515747
#
# Average loss: 0.5660, Accuracy: 709.0/790 (90%)
#
#
# Average loss: 0.5886, Accuracy: 2636.0/2940 (90%)
#
# Epoch: 15 	Training Accuracy: 89.75%
# Validation Accuracy: 89.66%
# Batch: 0, Loss: 0.5606598854064941
#
# Average loss: 0.5360, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.5593, Accuracy: 2650.0/2940 (90%)
#
# Epoch: 16 	Training Accuracy: 90.38%
# Validation Accuracy: 90.14%
# Batch: 0, Loss: 0.49294283986091614
#
# Average loss: 0.5085, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.5315, Accuracy: 2661.0/2940 (91%)
#
# Epoch: 17 	Training Accuracy: 90.76%
# Validation Accuracy: 90.51%
# Batch: 0, Loss: 0.5352302193641663
#
# Average loss: 0.4835, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.5065, Accuracy: 2676.0/2940 (91%)
#
# Epoch: 18 	Training Accuracy: 91.39%
# Validation Accuracy: 91.02%
# Batch: 0, Loss: 0.4580914378166199
#
# Average loss: 0.4605, Accuracy: 723.0/790 (92%)
#
#
# Average loss: 0.4842, Accuracy: 2685.0/2940 (91%)
#
# Epoch: 19 	Training Accuracy: 91.52%
# Validation Accuracy: 91.33%
#
# Average loss: 0.4605, Accuracy: 723.0/790 (92%)
#
#
# Average loss: 0.4648, Accuracy: 4481.0/4861 (92%)
#
# Repeat: 4, with seed 65 =========================
# Batch: 0, Loss: 1.7530689239501953
#
# Average loss: 1.6835, Accuracy: 203.0/790 (26%)
#
#
# Average loss: 1.6916, Accuracy: 705.0/2940 (24%)
#
# Epoch: 0 	Training Accuracy: 25.70%
# Validation Accuracy: 23.98%
# Batch: 0, Loss: 1.6440839767456055
#
# Average loss: 1.5651, Accuracy: 230.0/790 (29%)
#
#
# Average loss: 1.5748, Accuracy: 805.0/2940 (27%)
#
# Epoch: 1 	Training Accuracy: 29.11%
# Validation Accuracy: 27.38%
# Batch: 0, Loss: 1.573731780052185
#
# Average loss: 1.4599, Accuracy: 267.0/790 (34%)
#
#
# Average loss: 1.4712, Accuracy: 950.0/2940 (32%)
#
# Epoch: 2 	Training Accuracy: 33.80%
# Validation Accuracy: 32.31%
# Batch: 0, Loss: 1.4716284275054932
#
# Average loss: 1.3667, Accuracy: 344.0/790 (44%)
#
#
# Average loss: 1.3793, Accuracy: 1214.0/2940 (41%)
#
# Epoch: 3 	Training Accuracy: 43.54%
# Validation Accuracy: 41.29%
# Batch: 0, Loss: 1.3767743110656738
#
# Average loss: 1.2818, Accuracy: 426.0/790 (54%)
#
#
# Average loss: 1.2954, Accuracy: 1518.0/2940 (52%)
#
# Epoch: 4 	Training Accuracy: 53.92%
# Validation Accuracy: 51.63%
# Batch: 0, Loss: 1.3292760848999023
#
# Average loss: 1.2024, Accuracy: 496.0/790 (63%)
#
#
# Average loss: 1.2173, Accuracy: 1791.0/2940 (61%)
#
# Epoch: 5 	Training Accuracy: 62.78%
# Validation Accuracy: 60.92%
# Batch: 0, Loss: 1.200791358947754
#
# Average loss: 1.1277, Accuracy: 540.0/790 (68%)
#
#
# Average loss: 1.1439, Accuracy: 2009.0/2940 (68%)
#
# Epoch: 6 	Training Accuracy: 68.35%
# Validation Accuracy: 68.33%
# Batch: 0, Loss: 1.1922688484191895
#
# Average loss: 1.0579, Accuracy: 582.0/790 (74%)
#
#
# Average loss: 1.0753, Accuracy: 2147.0/2940 (73%)
#
# Epoch: 7 	Training Accuracy: 73.67%
# Validation Accuracy: 73.03%
# Batch: 0, Loss: 1.0782679319381714
#
# Average loss: 0.9924, Accuracy: 618.0/790 (78%)
#
#
# Average loss: 1.0109, Accuracy: 2273.0/2940 (77%)
#
# Epoch: 8 	Training Accuracy: 78.23%
# Validation Accuracy: 77.31%
# Batch: 0, Loss: 0.9399492144584656
#
# Average loss: 0.9303, Accuracy: 643.0/790 (81%)
#
#
# Average loss: 0.9502, Accuracy: 2380.0/2940 (81%)
#
# Epoch: 9 	Training Accuracy: 81.39%
# Validation Accuracy: 80.95%
# Batch: 0, Loss: 0.9490565657615662
#
# Average loss: 0.8724, Accuracy: 667.0/790 (84%)
#
#
# Average loss: 0.8936, Accuracy: 2467.0/2940 (84%)
#
# Epoch: 10 	Training Accuracy: 84.43%
# Validation Accuracy: 83.91%
# Batch: 0, Loss: 0.8889139890670776
#
# Average loss: 0.8189, Accuracy: 684.0/790 (87%)
#
#
# Average loss: 0.8412, Accuracy: 2518.0/2940 (86%)
#
# Epoch: 11 	Training Accuracy: 86.58%
# Validation Accuracy: 85.65%
# Batch: 0, Loss: 0.7725540399551392
#
# Average loss: 0.7694, Accuracy: 696.0/790 (88%)
#
#
# Average loss: 0.7927, Accuracy: 2543.0/2940 (86%)
#
# Epoch: 12 	Training Accuracy: 88.10%
# Validation Accuracy: 86.50%
# Batch: 0, Loss: 0.7655831575393677
#
# Average loss: 0.7234, Accuracy: 702.0/790 (89%)
#
#
# Average loss: 0.7478, Accuracy: 2570.0/2940 (87%)
#
# Epoch: 13 	Training Accuracy: 88.86%
# Validation Accuracy: 87.41%
# Batch: 0, Loss: 0.7116503119468689
#
# Average loss: 0.6818, Accuracy: 707.0/790 (89%)
#
#
# Average loss: 0.7071, Accuracy: 2585.0/2940 (88%)
#
# Epoch: 14 	Training Accuracy: 89.49%
# Validation Accuracy: 87.93%
# Batch: 0, Loss: 0.6865882873535156
#
# Average loss: 0.6436, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.6700, Accuracy: 2608.0/2940 (89%)
#
# Epoch: 15 	Training Accuracy: 90.76%
# Validation Accuracy: 88.71%
# Batch: 0, Loss: 0.5988793969154358
#
# Average loss: 0.6079, Accuracy: 718.0/790 (91%)
#
#
# Average loss: 0.6356, Accuracy: 2607.0/2940 (89%)
#
# Epoch: 16 	Training Accuracy: 90.89%
# Validation Accuracy: 88.67%
# Batch: 0, Loss: 0.5881623029708862
#
# Average loss: 0.5748, Accuracy: 727.0/790 (92%)
#
#
# Average loss: 0.6039, Accuracy: 2622.0/2940 (89%)
#
# Epoch: 17 	Training Accuracy: 92.03%
# Validation Accuracy: 89.18%
# Batch: 0, Loss: 0.5827623009681702
#
# Average loss: 0.5452, Accuracy: 724.0/790 (92%)
#
#
# Average loss: 0.5755, Accuracy: 2621.0/2940 (89%)
#
# Epoch: 18 	Training Accuracy: 91.65%
# Validation Accuracy: 89.15%
# Batch: 0, Loss: 0.5792086124420166
#
# Average loss: 0.5186, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.5498, Accuracy: 2630.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 92.15%
# Validation Accuracy: 89.46%
#
# Average loss: 0.5186, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.5434, Accuracy: 4417.0/4861 (91%)
#
# Percentage: 0.05
# Repeat: 0, with seed 95 =========================
# Batch: 0, Loss: 1.853084683418274
#
# Average loss: 1.7059, Accuracy: 431.0/1320 (33%)
#
#
# Average loss: 1.6924, Accuracy: 959.0/2940 (33%)
#
# Epoch: 0 	Training Accuracy: 32.65%
# Validation Accuracy: 32.62%
# Batch: 0, Loss: 1.693860650062561
#
# Average loss: 1.5539, Accuracy: 506.0/1320 (38%)
#
#
# Average loss: 1.5439, Accuracy: 1170.0/2940 (40%)
#
# Epoch: 1 	Training Accuracy: 38.33%
# Validation Accuracy: 39.80%
# Batch: 0, Loss: 1.521589994430542
#
# Average loss: 1.4216, Accuracy: 616.0/1320 (47%)
#
#
# Average loss: 1.4144, Accuracy: 1406.0/2940 (48%)
#
# Epoch: 2 	Training Accuracy: 46.67%
# Validation Accuracy: 47.82%
# Batch: 0, Loss: 1.4089621305465698
#
# Average loss: 1.2997, Accuracy: 807.0/1320 (61%)
#
#
# Average loss: 1.2951, Accuracy: 1822.0/2940 (62%)
#
# Epoch: 3 	Training Accuracy: 61.14%
# Validation Accuracy: 61.97%
# Batch: 0, Loss: 1.2784161567687988
#
# Average loss: 1.1870, Accuracy: 1005.0/1320 (76%)
#
#
# Average loss: 1.1845, Accuracy: 2239.0/2940 (76%)
#
# Epoch: 4 	Training Accuracy: 76.14%
# Validation Accuracy: 76.16%
# Batch: 0, Loss: 1.196533441543579
#
# Average loss: 1.0812, Accuracy: 1106.0/1320 (84%)
#
#
# Average loss: 1.0806, Accuracy: 2442.0/2940 (83%)
#
# Epoch: 5 	Training Accuracy: 83.79%
# Validation Accuracy: 83.06%
# Batch: 0, Loss: 1.0879061222076416
#
# Average loss: 0.9831, Accuracy: 1146.0/1320 (87%)
#
#
# Average loss: 0.9843, Accuracy: 2541.0/2940 (86%)
#
# Epoch: 6 	Training Accuracy: 86.82%
# Validation Accuracy: 86.43%
# Batch: 0, Loss: 1.003274917602539
#
# Average loss: 0.8920, Accuracy: 1154.0/1320 (87%)
#
#
# Average loss: 0.8953, Accuracy: 2584.0/2940 (88%)
#
# Epoch: 7 	Training Accuracy: 87.42%
# Validation Accuracy: 87.89%
# Batch: 0, Loss: 0.8873090147972107
#
# Average loss: 0.8099, Accuracy: 1179.0/1320 (89%)
#
#
# Average loss: 0.8148, Accuracy: 2623.0/2940 (89%)
#
# Epoch: 8 	Training Accuracy: 89.32%
# Validation Accuracy: 89.22%
# Batch: 0, Loss: 0.8360864520072937
#
# Average loss: 0.7362, Accuracy: 1190.0/1320 (90%)
#
#
# Average loss: 0.7423, Accuracy: 2637.0/2940 (90%)
#
# Epoch: 9 	Training Accuracy: 90.15%
# Validation Accuracy: 89.69%
# Batch: 0, Loss: 0.7331708073616028
#
# Average loss: 0.6708, Accuracy: 1192.0/1320 (90%)
#
#
# Average loss: 0.6782, Accuracy: 2647.0/2940 (90%)
#
# Epoch: 10 	Training Accuracy: 90.30%
# Validation Accuracy: 90.03%
# Batch: 0, Loss: 0.6326964497566223
#
# Average loss: 0.6138, Accuracy: 1195.0/1320 (91%)
#
#
# Average loss: 0.6226, Accuracy: 2658.0/2940 (90%)
#
# Epoch: 11 	Training Accuracy: 90.53%
# Validation Accuracy: 90.41%
# Batch: 0, Loss: 0.6394389867782593
#
# Average loss: 0.5634, Accuracy: 1203.0/1320 (91%)
#
#
# Average loss: 0.5739, Accuracy: 2675.0/2940 (91%)
#
# Epoch: 12 	Training Accuracy: 91.14%
# Validation Accuracy: 90.99%
# Batch: 0, Loss: 0.5883310437202454
#
# Average loss: 0.5195, Accuracy: 1205.0/1320 (91%)
#
#
# Average loss: 0.5314, Accuracy: 2681.0/2940 (91%)
#
# Epoch: 13 	Training Accuracy: 91.29%
# Validation Accuracy: 91.19%
# Batch: 0, Loss: 0.5131461024284363
#
# Average loss: 0.4815, Accuracy: 1210.0/1320 (92%)
#
#
# Average loss: 0.4943, Accuracy: 2687.0/2940 (91%)
#
# Epoch: 14 	Training Accuracy: 91.67%
# Validation Accuracy: 91.39%
# Batch: 0, Loss: 0.4862072467803955
#
# Average loss: 0.4485, Accuracy: 1214.0/1320 (92%)
#
#
# Average loss: 0.4625, Accuracy: 2690.0/2940 (91%)
#
# Epoch: 15 	Training Accuracy: 91.97%
# Validation Accuracy: 91.50%
# Batch: 0, Loss: 0.4810431897640228
#
# Average loss: 0.4194, Accuracy: 1221.0/1320 (92%)
#
#
# Average loss: 0.4347, Accuracy: 2689.0/2940 (91%)
#
# Epoch: 16 	Training Accuracy: 92.50%
# Validation Accuracy: 91.46%
# Batch: 0, Loss: 0.41417449712753296
#
# Average loss: 0.3940, Accuracy: 1223.0/1320 (93%)
#
#
# Average loss: 0.4104, Accuracy: 2691.0/2940 (92%)
#
# Epoch: 17 	Training Accuracy: 92.65%
# Validation Accuracy: 91.53%
# Batch: 0, Loss: 0.37986740469932556
#
# Average loss: 0.3718, Accuracy: 1226.0/1320 (93%)
#
#
# Average loss: 0.3895, Accuracy: 2694.0/2940 (92%)
#
# Epoch: 18 	Training Accuracy: 92.88%
# Validation Accuracy: 91.63%
# Batch: 0, Loss: 0.39050766825675964
#
# Average loss: 0.3523, Accuracy: 1223.0/1320 (93%)
#
#
# Average loss: 0.3710, Accuracy: 2699.0/2940 (92%)
#
# Epoch: 19 	Training Accuracy: 92.65%
# Validation Accuracy: 91.80%
#
# Average loss: 0.3523, Accuracy: 1223.0/1320 (93%)
#
#
# Average loss: 0.3524, Accuracy: 4526.0/4861 (93%)
#
# Repeat: 1, with seed 87 =========================
# Batch: 0, Loss: 1.7728791236877441
#
# Average loss: 1.6904, Accuracy: 333.0/1320 (25%)
#
#
# Average loss: 1.6889, Accuracy: 738.0/2940 (25%)
#
# Epoch: 0 	Training Accuracy: 25.23%
# Validation Accuracy: 25.10%
# Batch: 0, Loss: 1.6436623334884644
#
# Average loss: 1.5361, Accuracy: 470.0/1320 (36%)
#
#
# Average loss: 1.5339, Accuracy: 1037.0/2940 (35%)
#
# Epoch: 1 	Training Accuracy: 35.61%
# Validation Accuracy: 35.27%
# Batch: 0, Loss: 1.4929876327514648
#
# Average loss: 1.4028, Accuracy: 575.0/1320 (44%)
#
#
# Average loss: 1.4006, Accuracy: 1249.0/2940 (42%)
#
# Epoch: 2 	Training Accuracy: 43.56%
# Validation Accuracy: 42.48%
# Batch: 0, Loss: 1.417919635772705
#
# Average loss: 1.2842, Accuracy: 701.0/1320 (53%)
#
#
# Average loss: 1.2829, Accuracy: 1492.0/2940 (51%)
#
# Epoch: 3 	Training Accuracy: 53.11%
# Validation Accuracy: 50.75%
# Batch: 0, Loss: 1.2668911218643188
#
# Average loss: 1.1773, Accuracy: 809.0/1320 (61%)
#
#
# Average loss: 1.1761, Accuracy: 1780.0/2940 (61%)
#
# Epoch: 4 	Training Accuracy: 61.29%
# Validation Accuracy: 60.54%
# Batch: 0, Loss: 1.240849256515503
#
# Average loss: 1.0794, Accuracy: 881.0/1320 (67%)
#
#
# Average loss: 1.0789, Accuracy: 1970.0/2940 (67%)
#
# Epoch: 5 	Training Accuracy: 66.74%
# Validation Accuracy: 67.01%
# Batch: 0, Loss: 1.0900294780731201
#
# Average loss: 0.9883, Accuracy: 956.0/1320 (72%)
#
#
# Average loss: 0.9886, Accuracy: 2145.0/2940 (73%)
#
# Epoch: 6 	Training Accuracy: 72.42%
# Validation Accuracy: 72.96%
# Batch: 0, Loss: 0.9954385757446289
#
# Average loss: 0.9052, Accuracy: 1010.0/1320 (77%)
#
#
# Average loss: 0.9055, Accuracy: 2263.0/2940 (77%)
#
# Epoch: 7 	Training Accuracy: 76.52%
# Validation Accuracy: 76.97%
# Batch: 0, Loss: 0.8768244385719299
#
# Average loss: 0.8287, Accuracy: 1058.0/1320 (80%)
#
#
# Average loss: 0.8294, Accuracy: 2373.0/2940 (81%)
#
# Epoch: 8 	Training Accuracy: 80.15%
# Validation Accuracy: 80.71%
# Batch: 0, Loss: 0.7951067686080933
#
# Average loss: 0.7593, Accuracy: 1089.0/1320 (82%)
#
#
# Average loss: 0.7608, Accuracy: 2461.0/2940 (84%)
#
# ...
#
# Average loss: 0.1046, Accuracy: 25157.0/26038 (97%)
#
#
# Average loss: 0.1315, Accuracy: 2816.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 96.62%
# Validation Accuracy: 95.78%
# Batch: 0, Loss: 0.10733848810195923
# Batch: 20, Loss: 0.04997808486223221
# Batch: 40, Loss: 0.13122937083244324
# Batch: 60, Loss: 0.10534973442554474
# Batch: 80, Loss: 0.05382722243666649
# Batch: 100, Loss: 0.07896842062473297
# Batch: 120, Loss: 0.09392619132995605
# Batch: 140, Loss: 0.12038218230009079
# Batch: 160, Loss: 0.11202526837587357
# Batch: 180, Loss: 0.07627005130052567
# Batch: 200, Loss: 0.16853992640972137
#
# Average loss: 0.1031, Accuracy: 25151.0/26038 (97%)
#
#
# Average loss: 0.1306, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 96.59%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.055581286549568176
# Batch: 20, Loss: 0.08785451948642731
# Batch: 40, Loss: 0.09320325404405594
# Batch: 60, Loss: 0.07140464335680008
# Batch: 80, Loss: 0.11323826760053635
# Batch: 100, Loss: 0.09170891344547272
# Batch: 120, Loss: 0.05854835361242294
# Batch: 140, Loss: 0.05910581350326538
# Batch: 160, Loss: 0.09173200279474258
# Batch: 180, Loss: 0.04033007100224495
# Batch: 200, Loss: 0.091855987906456
#
# Average loss: 0.1017, Accuracy: 25174.0/26038 (97%)
#
#
# Average loss: 0.1306, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 18 	Training Accuracy: 96.68%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.11427236348390579
# Batch: 20, Loss: 0.08714602142572403
# Batch: 40, Loss: 0.19091258943080902
# Batch: 60, Loss: 0.11484925448894501
# Batch: 80, Loss: 0.11040844768285751
# Batch: 100, Loss: 0.0748913586139679
# Batch: 120, Loss: 0.07766667008399963
# Batch: 140, Loss: 0.08165598660707474
# Batch: 160, Loss: 0.13788311183452606
# Batch: 180, Loss: 0.0952407494187355
# Batch: 200, Loss: 0.12499655783176422
#
# Average loss: 0.1009, Accuracy: 25204.0/26038 (97%)
#
#
# Average loss: 0.1304, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 19 	Training Accuracy: 96.80%
# Validation Accuracy: 95.85%
#
# Average loss: 0.1009, Accuracy: 25204.0/26038 (97%)
#
#
# Average loss: 0.1138, Accuracy: 4675.0/4861 (96%)
#
# Repeat: 4, with seed 99 =========================
# Batch: 0, Loss: 1.4429686069488525
# Batch: 20, Loss: 1.2403849363327026
# Batch: 40, Loss: 1.0427554845809937
# Batch: 60, Loss: 0.8800111413002014
# Batch: 80, Loss: 0.7068580985069275
# Batch: 100, Loss: 0.5455560088157654
# Batch: 120, Loss: 0.5127108097076416
# Batch: 140, Loss: 0.46528926491737366
# Batch: 160, Loss: 0.3864802122116089
# Batch: 180, Loss: 0.36830225586891174
# Batch: 200, Loss: 0.30033302307128906
#
# Average loss: 0.3131, Accuracy: 24296.0/26038 (93%)
#
#
# Average loss: 0.3260, Accuracy: 2715.0/2940 (92%)
#
# Epoch: 0 	Training Accuracy: 93.31%
# Validation Accuracy: 92.35%
# Batch: 0, Loss: 0.3442777097225189
# Batch: 20, Loss: 0.2804337739944458
# Batch: 40, Loss: 0.27515900135040283
# Batch: 60, Loss: 0.29155901074409485
# Batch: 80, Loss: 0.2142285257577896
# Batch: 100, Loss: 0.24472768604755402
# Batch: 120, Loss: 0.19952356815338135
# Batch: 140, Loss: 0.1967039555311203
# Batch: 160, Loss: 0.15245503187179565
# Batch: 180, Loss: 0.20153848826885223
# Batch: 200, Loss: 0.22107477486133575
#
# Average loss: 0.1944, Accuracy: 24630.0/26038 (95%)
#
#
# Average loss: 0.2090, Accuracy: 2766.0/2940 (94%)
#
# Epoch: 1 	Training Accuracy: 94.59%
# Validation Accuracy: 94.08%
# Batch: 0, Loss: 0.19893662631511688
# Batch: 20, Loss: 0.283746600151062
# Batch: 40, Loss: 0.19388553500175476
# Batch: 60, Loss: 0.18266287446022034
# Batch: 80, Loss: 0.10587790608406067
# Batch: 100, Loss: 0.11228982359170914
# Batch: 120, Loss: 0.1457500457763672
# Batch: 140, Loss: 0.14027617871761322
# Batch: 160, Loss: 0.09620332717895508
# Batch: 180, Loss: 0.13833053410053253
# Batch: 200, Loss: 0.17526808381080627
#
# Average loss: 0.1604, Accuracy: 24769.0/26038 (95%)
#
#
# Average loss: 0.1759, Accuracy: 2779.0/2940 (95%)
#
# Epoch: 2 	Training Accuracy: 95.13%
# Validation Accuracy: 94.52%
# Batch: 0, Loss: 0.14972184598445892
# Batch: 20, Loss: 0.15082642436027527
# Batch: 40, Loss: 0.1425933986902237
# Batch: 60, Loss: 0.12843157351016998
# Batch: 80, Loss: 0.17051628232002258
# Batch: 100, Loss: 0.11220474541187286
# Batch: 120, Loss: 0.1076897382736206
# Batch: 140, Loss: 0.11873465031385422
# Batch: 160, Loss: 0.14986641705036163
# Batch: 180, Loss: 0.09919893741607666
# Batch: 200, Loss: 0.16559654474258423
#
# Average loss: 0.1442, Accuracy: 24887.0/26038 (96%)
#
#
# Average loss: 0.1609, Accuracy: 2788.0/2940 (95%)
#
# Epoch: 3 	Training Accuracy: 95.58%
# Validation Accuracy: 94.83%
# Batch: 0, Loss: 0.13260866701602936
# Batch: 20, Loss: 0.23255200684070587
# Batch: 40, Loss: 0.08474413305521011
# Batch: 60, Loss: 0.1386709064245224
# Batch: 80, Loss: 0.14855624735355377
# Batch: 100, Loss: 0.11462368816137314
# Batch: 120, Loss: 0.13965973258018494
# Batch: 140, Loss: 0.15291453897953033
# Batch: 160, Loss: 0.1695067584514618
# Batch: 180, Loss: 0.1317155957221985
# Batch: 200, Loss: 0.23501676321029663
#
# Average loss: 0.1346, Accuracy: 24921.0/26038 (96%)
#
#
# Average loss: 0.1523, Accuracy: 2791.0/2940 (95%)
#
# Epoch: 4 	Training Accuracy: 95.71%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.17987486720085144
# Batch: 20, Loss: 0.11561370640993118
# Batch: 40, Loss: 0.14699336886405945
# Batch: 60, Loss: 0.12555693089962006
# Batch: 80, Loss: 0.13265901803970337
# Batch: 100, Loss: 0.07154481112957001
# Batch: 120, Loss: 0.12253269553184509
# Batch: 140, Loss: 0.09621653705835342
# Batch: 160, Loss: 0.09743098169565201
# Batch: 180, Loss: 0.08106417208909988
# Batch: 200, Loss: 0.10256171971559525
#
# Average loss: 0.1280, Accuracy: 24957.0/26038 (96%)
#
#
# Average loss: 0.1464, Accuracy: 2792.0/2940 (95%)
#
# Epoch: 5 	Training Accuracy: 95.85%
# Validation Accuracy: 94.97%
# Batch: 0, Loss: 0.14935635030269623
# Batch: 20, Loss: 0.23242460191249847
# Batch: 40, Loss: 0.15404997766017914
# Batch: 60, Loss: 0.11957661062479019
# Batch: 80, Loss: 0.12858322262763977
# Batch: 100, Loss: 0.1665142923593521
# Batch: 120, Loss: 0.07863228768110275
# Batch: 140, Loss: 0.16565150022506714
# Batch: 160, Loss: 0.14609061181545258
# Batch: 180, Loss: 0.1092943549156189
# Batch: 200, Loss: 0.15531238913536072
#
# Average loss: 0.1231, Accuracy: 24996.0/26038 (96%)
#
#
# Average loss: 0.1425, Accuracy: 2798.0/2940 (95%)
#
# Epoch: 6 	Training Accuracy: 96.00%
# Validation Accuracy: 95.17%
# Batch: 0, Loss: 0.19311898946762085
# Batch: 20, Loss: 0.16687732934951782
# Batch: 40, Loss: 0.08647460490465164
# Batch: 60, Loss: 0.13572318851947784
# Batch: 80, Loss: 0.10808048397302628
# Batch: 100, Loss: 0.10828132182359695
# Batch: 120, Loss: 0.11943218857049942
# Batch: 140, Loss: 0.04617954418063164
# Batch: 160, Loss: 0.08354390412569046
# Batch: 180, Loss: 0.08967535197734833
# Batch: 200, Loss: 0.13529546558856964
#
# Average loss: 0.1194, Accuracy: 25025.0/26038 (96%)
#
#
# Average loss: 0.1399, Accuracy: 2800.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 96.11%
# Validation Accuracy: 95.24%
# Batch: 0, Loss: 0.08414438366889954
# Batch: 20, Loss: 0.1504429131746292
# Batch: 40, Loss: 0.07106401771306992
# Batch: 60, Loss: 0.09127090126276016
# Batch: 80, Loss: 0.06702949106693268
# Batch: 100, Loss: 0.0937938317656517
# Batch: 120, Loss: 0.10961582511663437
# Batch: 140, Loss: 0.16717523336410522
# Batch: 160, Loss: 0.16365964710712433
# Batch: 180, Loss: 0.06533513963222504
# Batch: 200, Loss: 0.08572301268577576
#
# Average loss: 0.1166, Accuracy: 25049.0/26038 (96%)
#
#
# Average loss: 0.1382, Accuracy: 2808.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 96.20%
# Validation Accuracy: 95.51%
# Batch: 0, Loss: 0.1367378979921341
# Batch: 20, Loss: 0.08739400655031204
# Batch: 40, Loss: 0.09848928451538086
# Batch: 60, Loss: 0.0876157358288765
# Batch: 80, Loss: 0.08983150869607925
# Batch: 100, Loss: 0.15843115746974945
# Batch: 120, Loss: 0.05614370107650757
# Batch: 140, Loss: 0.20052345097064972
# Batch: 160, Loss: 0.19253963232040405
# Batch: 180, Loss: 0.22301624715328217
# Batch: 200, Loss: 0.08899357169866562
#
# Average loss: 0.1136, Accuracy: 25072.0/26038 (96%)
#
#
# Average loss: 0.1359, Accuracy: 2809.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 96.29%
# Validation Accuracy: 95.54%
# Batch: 0, Loss: 0.07578644156455994
# Batch: 20, Loss: 0.05294933170080185
# Batch: 40, Loss: 0.09138163179159164
# Batch: 60, Loss: 0.048892926424741745
# Batch: 80, Loss: 0.12423673272132874
# Batch: 100, Loss: 0.10256554186344147
# Batch: 120, Loss: 0.0696575865149498
# Batch: 140, Loss: 0.0721578523516655
# Batch: 160, Loss: 0.11249399185180664
# Batch: 180, Loss: 0.07111752033233643
# Batch: 200, Loss: 0.09444651007652283
#
# Average loss: 0.1128, Accuracy: 25093.0/26038 (96%)
#
#
# Average loss: 0.1361, Accuracy: 2814.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 96.37%
# Validation Accuracy: 95.71%
# Batch: 0, Loss: 0.1656056046485901
# Batch: 20, Loss: 0.10808400064706802
# Batch: 40, Loss: 0.1693640649318695
# Batch: 60, Loss: 0.09057912975549698
# Batch: 80, Loss: 0.08534650504589081
# Batch: 100, Loss: 0.10707496106624603
# Batch: 120, Loss: 0.1717091053724289
# Batch: 140, Loss: 0.17743423581123352
# Batch: 160, Loss: 0.12885522842407227
# Batch: 180, Loss: 0.10889149457216263
# Batch: 200, Loss: 0.08067452162504196
#
# Average loss: 0.1091, Accuracy: 25111.0/26038 (96%)
#
#
# Average loss: 0.1335, Accuracy: 2813.0/2940 (96%)
#
# Epoch: 11 	Training Accuracy: 96.44%
# Validation Accuracy: 95.68%
# Batch: 0, Loss: 0.059084296226501465
# Batch: 20, Loss: 0.09767311066389084
# Batch: 40, Loss: 0.129941925406456
# Batch: 60, Loss: 0.11777355521917343
# Batch: 80, Loss: 0.17252123355865479
# Batch: 100, Loss: 0.12832607328891754
# Batch: 120, Loss: 0.09538434445858002
# Batch: 140, Loss: 0.09236114472150803
# Batch: 160, Loss: 0.1305573284626007
# Batch: 180, Loss: 0.07263517379760742
# Batch: 200, Loss: 0.11255455017089844
#
# Average loss: 0.1088, Accuracy: 25125.0/26038 (96%)
#
#
# Average loss: 0.1343, Accuracy: 2813.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 96.49%
# Validation Accuracy: 95.68%
# Batch: 0, Loss: 0.2075098752975464
# Batch: 20, Loss: 0.16138246655464172
# Batch: 40, Loss: 0.0787503644824028
# Batch: 60, Loss: 0.152273491024971
# Batch: 80, Loss: 0.10985888540744781
# Batch: 100, Loss: 0.17074131965637207
# Batch: 120, Loss: 0.04684225097298622
# Batch: 140, Loss: 0.14972466230392456
# Batch: 160, Loss: 0.05268939584493637
# Batch: 180, Loss: 0.09776914864778519
# Batch: 200, Loss: 0.1146811693906784
#
# Average loss: 0.1060, Accuracy: 25128.0/26038 (97%)
#
#
# Average loss: 0.1324, Accuracy: 2817.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 96.51%
# Validation Accuracy: 95.82%
# Batch: 0, Loss: 0.13226334750652313
# Batch: 20, Loss: 0.11239918321371078
# Batch: 40, Loss: 0.09367120265960693
# Batch: 60, Loss: 0.07740184664726257
# Batch: 80, Loss: 0.0898577868938446
# Batch: 100, Loss: 0.0703464224934578
# Batch: 120, Loss: 0.08761292695999146
# Batch: 140, Loss: 0.12249691039323807
# Batch: 160, Loss: 0.1417015641927719
# Batch: 180, Loss: 0.09382377564907074
# Batch: 200, Loss: 0.19202148914337158
#
# Average loss: 0.1050, Accuracy: 25149.0/26038 (97%)
#
#
# Average loss: 0.1329, Accuracy: 2818.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 96.59%
# Validation Accuracy: 95.85%
# Batch: 0, Loss: 0.11723519116640091
# Batch: 20, Loss: 0.15802045166492462
# Batch: 40, Loss: 0.11102358996868134
# Batch: 60, Loss: 0.13387252390384674
# Batch: 80, Loss: 0.16462881863117218
# Batch: 100, Loss: 0.07863682508468628
# Batch: 120, Loss: 0.05865796282887459
# Batch: 140, Loss: 0.10320890694856644
# Batch: 160, Loss: 0.2023800015449524
# Batch: 180, Loss: 0.11905018985271454
# Batch: 200, Loss: 0.11617155373096466
#
# Average loss: 0.1048, Accuracy: 25151.0/26038 (97%)
#
#
# Average loss: 0.1317, Accuracy: 2815.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 96.59%
# Validation Accuracy: 95.75%
# Batch: 0, Loss: 0.06294509023427963
# Batch: 20, Loss: 0.13885828852653503
# Batch: 40, Loss: 0.12144409120082855
# Batch: 60, Loss: 0.13844121992588043
# Batch: 80, Loss: 0.10396014153957367
# Batch: 100, Loss: 0.04607963189482689
# Batch: 120, Loss: 0.14988139271736145
# Batch: 140, Loss: 0.04768558591604233
# Batch: 160, Loss: 0.07816047966480255
# Batch: 180, Loss: 0.038195013999938965
# Batch: 200, Loss: 0.09680239111185074
#
# Average loss: 0.1026, Accuracy: 25181.0/26038 (97%)
#
#
# Average loss: 0.1315, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 96.71%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.09050671756267548
# Batch: 20, Loss: 0.12442544847726822
# Batch: 40, Loss: 0.15873752534389496
# Batch: 60, Loss: 0.1027078926563263
# Batch: 80, Loss: 0.11184872686862946
# Batch: 100, Loss: 0.15698730945587158
# Batch: 120, Loss: 0.14509998261928558
# Batch: 140, Loss: 0.11888383328914642
# Batch: 160, Loss: 0.13461534678936005
# Batch: 180, Loss: 0.1522657871246338
# Batch: 200, Loss: 0.11437620222568512
#
# Average loss: 0.1016, Accuracy: 25189.0/26038 (97%)
#
#
# Average loss: 0.1310, Accuracy: 2820.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 96.74%
# Validation Accuracy: 95.92%
# Batch: 0, Loss: 0.060711782425642014
# Batch: 20, Loss: 0.08520781993865967
# Batch: 40, Loss: 0.11980247497558594
# Batch: 60, Loss: 0.04733150452375412
# Batch: 80, Loss: 0.07942274212837219
# Batch: 100, Loss: 0.09294556081295013
# Batch: 120, Loss: 0.1272846758365631
# Batch: 140, Loss: 0.04050265997648239
# Batch: 160, Loss: 0.04845922067761421
# Batch: 180, Loss: 0.10736890882253647
# Batch: 200, Loss: 0.18633459508419037
#
# Average loss: 0.1008, Accuracy: 25182.0/26038 (97%)
#
#
# Average loss: 0.1306, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 18 	Training Accuracy: 96.71%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.07457605004310608
# Batch: 20, Loss: 0.0782829150557518
# Batch: 40, Loss: 0.09678603708744049
# Batch: 60, Loss: 0.09122581779956818
# Batch: 80, Loss: 0.07122315466403961
# Batch: 100, Loss: 0.053934019058942795
# Batch: 120, Loss: 0.13011543452739716
# Batch: 140, Loss: 0.16218620538711548
# Batch: 160, Loss: 0.07759348303079605
# Batch: 180, Loss: 0.08773723989725113
# Batch: 200, Loss: 0.16123385727405548
#
# Average loss: 0.1009, Accuracy: 25185.0/26038 (97%)
#
#
# Average loss: 0.1316, Accuracy: 2819.0/2940 (96%)
#
# Epoch: 19 	Training Accuracy: 96.72%
# Validation Accuracy: 95.88%
#
# Average loss: 0.1009, Accuracy: 25185.0/26038 (97%)
#
#
# Average loss: 0.1146, Accuracy: 4680.0/4861 (96%)
#
# Percentage: 0.01, Seed: 10, Epochs taken: 20
# Percentage: 0.01, Seed: 20, Epochs taken: 20
# Percentage: 0.01, Seed: 30, Epochs taken: 20
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 20
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 20
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 19
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 20
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 20
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 20
# Percentage: 1, Seed: 40, Epochs taken: 20
# Percentage: 1, Seed: 50, Epochs taken: 20

# %%
# End to End - Train Accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Train Accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Train Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Train Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
# End to End - Test Accuracies
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]

plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Test Accuracies
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Test Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Test Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
data_to_save = {
    "results_test_finetune": results_test_finetune,
    "results_train_finetune": results_train_finetune,
    "epochs_taken_finetune": epochs_taken_finetune,
    
    "results_test": results_test,
    "results_train": results_train,
    "epochs_taken": epochs_taken
}

# Assuming data_to_save from the previous code
with open("data.json", "w") as file:
    json.dump(data_to_save, file)

# %%
plt.figure(figsize=(10, 6))

for perc in percentages:
    plt.scatter(epochs_taken[perc], epochs_taken_finetune[perc], label=f'{perc} data')
plt.xlabel('Epochs (End to End)')
plt.ylabel('Epochs (Finetune)')
plt.title('Scatter Plot Comparing Epochs Taken for Convergence')
plt.legend()
plt.show()

# %%
# Given data
percentages = list(epochs_taken.keys())

all_epochs = []
labels = []

for perc in percentages:
    all_epochs.extend([epochs_taken[perc], epochs_taken_finetune[perc]])
    labels.extend([f'{perc} End to End', f'{perc} Finetune'])

# Plotting
plt.figure(figsize=(10, 6))
box = plt.boxplot(all_epochs, labels=labels, patch_artist=True)

# Coloring
colors = ['skyblue', 'lightgreen'] * len(percentages)
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

plt.ylabel('Epochs Taken')
plt.title('Box Plot of Epochs Taken for Each Percentage')
plt.xticks(rotation=90)
plt.show()

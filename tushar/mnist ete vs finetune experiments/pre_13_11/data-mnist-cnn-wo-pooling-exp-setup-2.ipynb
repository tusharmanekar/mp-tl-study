# %% [markdown]
# ***EXPERIMENT SETUP***

# %% [markdown]
# - percentages_set_1 = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
# - dataset: same as before MNIST 5 to 5
#
# - lr pretraining = 0.01
# - lr finetuning = 0.001
#
# - architecture:
#     - Conv 1 (5,5), channels=1
#     - Relu
#     - Conv 2 (5,5,), channels=1
#     - Relu
#     - Pooling: False
#     - dense( x, x) x=output shape of prev layer (128?)
#     - Relu
#     - dense(x, 5)
#     - softmax
#
# - Freezing: NO
#
# - Reinitializing CNN layers: No
# - Reinitializing CNN layers: Both
# - Reinitializing softmax layers: Yes
#
# - If we don’t save the best model, ES=6
#
# - num train = 20

# %% [markdown]
# ***IMPORTS***

# %%
import numpy as np
import random
import copy
import matplotlib.pyplot as plt
import json
from tqdm.auto import tqdm

# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from torchvision import datasets, transforms

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from types import SimpleNamespace

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ***UTILS***

# %%
def eval(model, device, dataset_loader, debug=False, classification_report_flag=False, is_cnn=True, logger=print):

    """
    Evaluates the model on the given dataset loader.

    Parameters:
    - model: the PyTorch model to evaluate.
    - device: the device to which tensors should be moved before computation.
    - dataset_loader: DataLoader for evaluation.
    - debug: whether to print debug info like loss and accuracy.
    - classification_report_flag: whether to print a classification report.
    - is_cnn: a flag indicating if the model is a CNN. If it's not, the input data will be reshaped.
    - logger: logging function for printing messages.

    Returns:
    - Accuracy of the model on the provided dataset loader.

    Usage:
    - accuracy = eval(model, device, dataset_loader, debug=False, is_cnn=False, classification_report_flag=False)
    """

    model.eval()
    test_loss, correct = 0., 0.
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data, target in dataset_loader:
            if is_cnn:
              data = data.view(data.size(0), 1, 28, 28)
            else:
              data = data.reshape([data.shape[0], -1])
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(target.cpu().numpy())

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data

    if debug:
        logger('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(test_loss, correct, num_data, 100. * acc))

    if classification_report_flag:
        unique_labels = np.unique(all_labels).tolist()
        logger(classification_report(all_labels, all_preds, labels=unique_labels, target_names=[f'Class {i}' for i in unique_labels]))

    return acc

# %%
class Trainer:

    """
    A class for training and evaluating a model with early stopping and best model saving functionalities.

    Attributes:
    - model: PyTorch model to be trained and evaluated.
    - dataloader: Contains data loaders (train, validation, test) for training and evaluation.
    - params: Dictionary containing various hyperparameters and settings.
    - device: the device to which tensors should be moved before computation.
    - optimizer: The optimizer for training.
    - best_model_state: State dictionary of the best model.
    - max_val_acc: The highest validation accuracy encountered during training.
    - no_improve_epochs: Number of epochs without improvement in validation accuracy.
    - is_cnn: Flag indicating if the model is a CNN.
    - is_debug: Flag indicating if debug information should be printed.
    - classification_report_flag: Flag indicating if a classification report should be generated.

    Methods:
    - train_epoch(): Runs a single epoch of training.
    - evaluate(loader): Evaluates the model on a given data loader.
    - save_best_model(): Saves the current state of the model as the best model.
    - save_checkpoint(epoch, train_acc, val_acc): Saves the current state of the model and other information as a checkpoint.
    - early_stopping_check(val_acc): Checks the stopping criterion and performs actions based on it.
    - train(): Runs the training process for a number of epochs, with early stopping functionality.

    Usage:
    params = {
      'device': 'cuda',
      'lr': 0.001,
      'num_train': 10,
      'early_stop_patience': 3,
      'save_best': True,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': True
    }

    trainer = Trainer(model, dataloader, params)
    train_acc, test_acc, effective_epochs, checkpoints = trainer.train()
    """


    def __init__(self, model, dataloader, params):
        self.model = model
        self.dataloader = dataloader
        self.params = params

        self.device = torch.device(params['device'])
        self.optimizer = optim.Adam(model.parameters(), lr=params['lr'])

        # Initialize best_model_state with the current model state
        self.best_model_state = copy.deepcopy(self.model.state_dict())
        self.max_val_acc = 0.
        self.no_improve_epochs = 0

        self.is_cnn = params.get('is_cnn', False)
        self.is_debug = params.get('is_debug', False)
        self.classification_report_flag = params.get('classification_report_flag', False)
        self.logger = params.get('logger', print)
        
    def train_epoch(self):
      self.model.train()
      for batch_idx, (data, target) in enumerate(self.dataloader.train_loader):

          # Print the size of the current batch
          if self.is_cnn:
            data = data.view(data.size(0), 1, 28, 28)
          else:
            data = data.reshape([data.shape[0], -1])

          data, target = data.to(self.device), target.to(self.device)
          self.optimizer.zero_grad()
          output = self.model(data)
          loss = F.nll_loss(output, target)
          loss.backward()
          self.optimizer.step()

          if self.is_debug and batch_idx % 20 == 0:
              self.logger(f"Batch: {batch_idx}, Loss: {loss.item()}")

    def evaluate(self, loader):
        return eval(self.model, self.device, loader, self.is_debug, self.classification_report_flag, self.is_cnn)

    def save_best_model(self):
        torch.save(self.model.state_dict(), 'best_model.pth')

    def save_checkpoint(self, epoch, train_acc, val_acc):
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'train_acc': train_acc,
            'val_acc': val_acc
        }
        torch.save(checkpoint, f'checkpoint_epoch_{epoch}.pth')
        return checkpoint

    def early_stopping_check(self, val_acc):
        if val_acc > self.max_val_acc:
            self.max_val_acc = val_acc
            self.no_improve_epochs = 0
            # Deep copy the model's state
            self.best_model_state = copy.deepcopy(self.model.state_dict())
            if self.params.get('save_best', False):
                self.save_best_model()
        else:
            self.no_improve_epochs += 1
            if self.no_improve_epochs >= self.params['early_stop_patience']:
                self.logger("Early stopping invoked.")
                # Only load if best_model_state has been set
                if self.best_model_state is not None:
                    self.model.load_state_dict(self.best_model_state)
                return True
        return False

    def train(self):
        effective_epochs = 0
        checkpoints = []

        for epoch in range(self.params['num_train']):
            effective_epochs += 1
            self.train_epoch()

            train_acc = self.evaluate(self.dataloader.train_loader)
            val_acc = self.evaluate(self.dataloader.val_loader)
            self.logger(f'Epoch: {epoch} \tTraining Accuracy: {train_acc*100:.2f}%')
            self.logger(f'Validation Accuracy: {val_acc*100:.2f}%')

            if self.params.get('early_stop_patience', None):
                if self.early_stopping_check(val_acc):
                    self.model.load_state_dict(self.best_model_state)
                    break

            if self.params.get('save_checkpoints', False):
                checkpoint = self.save_checkpoint(epoch, train_acc, val_acc)
                checkpoints.append(checkpoint)

        # Final evaluations
        train_acc = self.evaluate(self.dataloader.train_loader)
        test_acc = self.evaluate(self.dataloader.test_loader)

        return train_acc, test_acc, effective_epochs, checkpoints

# %%
def reduce_dataset(dataloader, percentage, balanced=True, seed=42):

    """
    Reduces the dataset to the given percentage. Can ensure class balance if needed.

    Parameters:
    - dataloader: PyTorch DataLoader object.
    - percentage: Desired percentage of the original dataset.
    - balanced: If True, ensures class balance. If False, reduces randomly.
    - seed: Seed for reproducibility.

    Returns:
    - reduced_dataloader: DataLoader with the reduced dataset.
    """
    # Extract the dataset from the dataloader
    dataset = dataloader.dataset

    # Extract all data and labels from the dataset
    X = [dataset[i][0] for i in range(len(dataset))]
    y = [dataset[i][1] for i in range(len(dataset))]

    # Set the seed for reproducibility
    torch.manual_seed(seed)

    if not balanced:
        # Determine the number of samples to keep
        num_samples = int(len(dataset) * percentage)

        # Randomly select indices without replacement
        indices = torch.randperm(len(dataset))[:num_samples].tolist()

    else:
        # Get unique classes and their counts
        classes, class_counts = torch.unique(torch.tensor(y), return_counts=True)

        # Determine the number of samples per class to keep
        num_samples_per_class = int(len(dataset) * percentage / len(classes))
        indices = []

        for class_label in classes:
            class_indices = [i for i, label in enumerate(y) if label == class_label]

            # Randomly select indices without replacement for each class
            class_selected_indices = torch.randperm(len(class_indices))[:num_samples_per_class].tolist()
            indices.extend([class_indices[i] for i in class_selected_indices])

    # Use a Subset of the original dataset to create a reduced dataset
    reduced_dataset = data.Subset(dataset, indices)

    # Create a DataLoader with the reduced dataset.
    reduced_dataloader = data.DataLoader(reduced_dataset, batch_size=dataloader.batch_size, shuffle=True)

    return reduced_dataloader

# %%
class RelabeledSubset(torch.utils.data.Dataset):
    def __init__(self, dataset, offset):
        self.dataset = dataset
        self.offset = offset

    def __getitem__(self, idx):
        data, label = self.dataset[idx]
        # Offset the label to start from 0
        label = label - self.offset
        return data, label

    def __len__(self):
        return len(self.dataset)

# %%
class TransferLearningMNIST(object):
    def __init__(self, batch_size, input_dim=28*28, val_split=0.1, num_workers=4):
        self.input_dim = input_dim
        self.output_dim = 10
        self.val_split = val_split

        def filter_dataset(dataset, classes):
            indices = [i for i, t in enumerate(dataset.targets) if t in classes]
            return torch.utils.data.Subset(dataset, indices)

        mnist_train_data = datasets.MNIST(
            '../data',
            train=True,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_train_data = filter_dataset(mnist_train_data, list(range(5)))
        finetune_train_data = filter_dataset(mnist_train_data, list(range(5, 10)))

        pretrain_len = len(pretrain_train_data)
        finetune_len = len(finetune_train_data)
        pretrain_val_len = int(val_split * pretrain_len)
        finetune_val_len = int(val_split * finetune_len)
        SEED = 42
        pretrain_train_set, pretrain_val_set = torch.utils.data.random_split(
            pretrain_train_data, [pretrain_len - pretrain_val_len, pretrain_val_len], generator=torch.Generator().manual_seed(SEED))
        finetune_train_set, finetune_val_set = torch.utils.data.random_split(
            finetune_train_data, [finetune_len - finetune_val_len, finetune_val_len], generator=torch.Generator().manual_seed(SEED))

        self.pretrain_train_loader = torch.utils.data.DataLoader(pretrain_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.pretrain_val_loader = torch.utils.data.DataLoader(pretrain_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning datasets
        finetune_train_set = RelabeledSubset(finetune_train_set, 5)
        finetune_val_set = RelabeledSubset(finetune_val_set, 5)

        self.finetune_train_loader = torch.utils.data.DataLoader(finetune_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.finetune_val_loader = torch.utils.data.DataLoader(finetune_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        mnist_test_data = datasets.MNIST(
            '../data',
            train=False,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_test_data = filter_dataset(mnist_test_data, list(range(5)))
        finetune_test_data = filter_dataset(mnist_test_data, list(range(5, 10)))

        self.pretrain_test_loader = torch.utils.data.DataLoader(pretrain_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning test datasets
        finetune_test_data = RelabeledSubset(finetune_test_data, 5)
        self.finetune_test_loader = torch.utils.data.DataLoader(finetune_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        # Complete test loader contains all test examples.
        self.complete_test_loader = torch.utils.data.DataLoader(mnist_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
class TransferLearningMNISTWrapper:
    """
    This wrapper class provides a convenient way to switch between pretraining and fine-tuning phases.

    It allows for changing the phase and accordingly updating the data loaders (train, val, test)
    to either pretraining or fine-tuning sets.
    """
    def __init__(self, transferLearningMNISTObj, phase):
        """
        Initializes the TransferLearningMNISTWrapper object.

        Parameters:
        - transferLearningMNISTObj: An instance of the TransferLearningMNIST class.
        - phase: String indicating the current phase ("pretrain" or "finetune").
        """
        self.transferLearningMNISTObj = transferLearningMNISTObj
        self.phase = phase
        self.input_dim = self.transferLearningMNISTObj.input_dim
        self.output_dim = self.transferLearningMNISTObj.output_dim
        self.update_phase(phase)

    def update_phase(self, phase):
        """
        Updates the phase and the corresponding data loaders.

        Parameters:
        - phase: String indicating the desired phase ("pretrain" or "finetune").

        Throws:
        - ValueError: If the phase is neither "pretrain" nor "finetune".
        """
        self.phase = phase
        if phase == 'pretrain':
            self.train_loader = self.transferLearningMNISTObj.pretrain_train_loader
            self.val_loader = self.transferLearningMNISTObj.pretrain_val_loader
            self.test_loader = self.transferLearningMNISTObj.pretrain_test_loader
        elif phase == 'finetune':
            self.train_loader = self.transferLearningMNISTObj.finetune_train_loader
            self.val_loader = self.transferLearningMNISTObj.finetune_val_loader
            self.test_loader = self.transferLearningMNISTObj.finetune_test_loader
        else:
            raise ValueError('Phase must be either "pretrain" or "finetune".')

    def get_current_phase(self):
      return self.phase

# %%
class CustomCNN(nn.Module):
    def __init__(self, input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling=False):
        super(CustomCNN, self).__init__()

        # Initial number of input channels, assuming grayscale images
        in_channels = 1

        # Dynamically add convolutional and activation layers based on the specified depth
        for i in range(depth):
            # Create a convolutional layer and add it to the model
            setattr(self, f"conv{i}", nn.Conv2d(in_channels, num_channels, kernel_size=kernel_size, padding=1))

            # Create an activation layer (e.g., ReLU) and add it to the model
            setattr(self, f"act{i}", activation_function())

            # Update the input dimensions after convolution
            input_dim = (input_dim - kernel_size + 2 * 1) + 1

            # Optionally add pooling layers to reduce spatial dimensions
            if use_pooling and i % 2 == 1:
                setattr(self, f"pool{i}", nn.MaxPool2d(2))
                input_dim = input_dim // 2

            # Update the input channels for the next convolutional layer
            in_channels = num_channels

        # Compute the size of the flattened features for the fully connected layer
        flattened_size = in_channels * input_dim * input_dim

        # Add two fully connected layers for classification
        self.fc_1 = nn.Linear(flattened_size, hidden_dim_lin)
        self.fc_2 = nn.Linear(hidden_dim_lin, output_dim)

        # Add log softmax layer for multi-class classification output
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
      # Iterate over each module in the CustomCNN class
      for layer_name, layer in self.named_children():
          # Process the input tensor through convolutional and activation layers
          if "conv" in layer_name or "act" in layer_name:
              x = layer(x)
          # Process the input tensor through pooling layers if they exist
          elif "pool" in layer_name:
              x = layer(x)
          # If reached fully connected layers, break the loop
          elif isinstance(layer, nn.Linear):
              break

      # Flatten the tensor to fit the input shape of the fully connected layers
      x = x.view(x.size(0), -1)
        
      # Save the flattened size for reinitializing layers later
      self.flattened_size = x.shape[1]

      # Pass the tensor through the fully connected layers
      x = self.fc_1(x)
      x = self.fc_2(x)

      # Return log softmax activated output
      return self.logsoftmax(x)

# %%
def generate_cnn(input_dim, output_dim, depth, num_channels, hidden_dim_lin, kernel_size, activation_function=nn.ReLU, use_pooling=False):
    model = CustomCNN(input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling)
    return model

# %% [markdown]
# ***PRE-TRAINING***

# %%
batch_size = 128

dataloader = TransferLearningMNIST(batch_size)
dataloader_wrapped = TransferLearningMNISTWrapper(dataloader, phase = 'pretrain')

# %%
a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        break

# %%
params = {
      'depth': 2,
      'width': 1,
      'hidden_dim_lin': 128,
      'activation_function': nn.ReLU,
      'kernel_size': 5,
      'device': device,
      'lr': 0.001,
      'num_train': 20,
      'early_stop_patience': 6,
      'save_best': True,
      'save_checkpoints': True,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': False
    }

# Create DNN model
model = generate_cnn(input_dim = 28, output_dim = 10, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=False)
model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
model
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
# Train and evaluate
trainer = Trainer(model, dataloader_wrapped, params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Batch: 0, Loss: 2.3219573497772217
# Batch: 20, Loss: 1.287878394126892
# Batch: 40, Loss: 0.43129879236221313
# Batch: 60, Loss: 0.190947026014328
# Batch: 80, Loss: 0.2724006474018097
# Batch: 100, Loss: 0.09783657640218735
# Batch: 120, Loss: 0.12667039036750793
# Batch: 140, Loss: 0.10790370404720306
# Batch: 160, Loss: 0.17736266553401947
# Batch: 180, Loss: 0.20533007383346558
# Batch: 200, Loss: 0.1855286955833435
#
# Average loss: 0.1420, Accuracy: 26352.0/27537 (96%)
#
#
# Average loss: 0.1670, Accuracy: 2900.0/3059 (95%)
#
# Epoch: 0 	Training Accuracy: 95.70%
# Validation Accuracy: 94.80%
# Batch: 0, Loss: 0.1347295194864273
# Batch: 20, Loss: 0.09360337257385254
# Batch: 40, Loss: 0.11007742583751678
# Batch: 60, Loss: 0.20858410000801086
# Batch: 80, Loss: 0.15436355769634247
# Batch: 100, Loss: 0.1163041964173317
# Batch: 120, Loss: 0.15751662850379944
# Batch: 140, Loss: 0.10946296900510788
# Batch: 160, Loss: 0.11063562333583832
# Batch: 180, Loss: 0.11089970171451569
# Batch: 200, Loss: 0.08668238669633865
#
# Average loss: 0.1324, Accuracy: 26380.0/27537 (96%)
#
#
# Average loss: 0.1556, Accuracy: 2906.0/3059 (95%)
#
# Epoch: 1 	Training Accuracy: 95.80%
# Validation Accuracy: 95.00%
# Batch: 0, Loss: 0.14935551583766937
# Batch: 20, Loss: 0.12771567702293396
# Batch: 40, Loss: 0.13622449338436127
# Batch: 60, Loss: 0.13529559969902039
# Batch: 80, Loss: 0.07808475196361542
# Batch: 100, Loss: 0.17137013375759125
# Batch: 120, Loss: 0.11879231780767441
# Batch: 140, Loss: 0.07166334241628647
# Batch: 160, Loss: 0.06823239475488663
# Batch: 180, Loss: 0.1730005145072937
# Batch: 200, Loss: 0.1327836811542511
#
# Average loss: 0.1170, Accuracy: 26596.0/27537 (97%)
#
#
# Average loss: 0.1387, Accuracy: 2929.0/3059 (96%)
#
# Epoch: 2 	Training Accuracy: 96.58%
# Validation Accuracy: 95.75%
# Batch: 0, Loss: 0.06424958258867264
# Batch: 20, Loss: 0.15469366312026978
# Batch: 40, Loss: 0.07424231618642807
# Batch: 60, Loss: 0.2033240795135498
# Batch: 80, Loss: 0.1319190114736557
# Batch: 100, Loss: 0.19366401433944702
# Batch: 120, Loss: 0.19698473811149597
# Batch: 140, Loss: 0.15115101635456085
# Batch: 160, Loss: 0.08531634509563446
# Batch: 180, Loss: 0.17651496827602386
# Batch: 200, Loss: 0.19905972480773926
#
# Average loss: 0.1272, Accuracy: 26413.0/27537 (96%)
#
#
# Average loss: 0.1500, Accuracy: 2915.0/3059 (95%)
#
# Epoch: 3 	Training Accuracy: 95.92%
# Validation Accuracy: 95.29%
# Batch: 0, Loss: 0.08853176981210709
# Batch: 20, Loss: 0.13214892148971558
# Batch: 40, Loss: 0.09979871660470963
# Batch: 60, Loss: 0.07347779721021652
# Batch: 80, Loss: 0.061865903437137604
# Batch: 100, Loss: 0.11984827369451523
# Batch: 120, Loss: 0.24717949330806732
# Batch: 140, Loss: 0.06702564656734467
# Batch: 160, Loss: 0.09731654077768326
# Batch: 180, Loss: 0.0901087149977684
# Batch: 200, Loss: 0.10362304747104645
#
# Average loss: 0.1008, Accuracy: 26672.0/27537 (97%)
#
#
# Average loss: 0.1223, Accuracy: 2949.0/3059 (96%)
#
# Epoch: 4 	Training Accuracy: 96.86%
# Validation Accuracy: 96.40%
# Batch: 0, Loss: 0.052384838461875916
# Batch: 20, Loss: 0.06544945389032364
# Batch: 40, Loss: 0.14218707382678986
# Batch: 60, Loss: 0.11422717571258545
# Batch: 80, Loss: 0.13332149386405945
# Batch: 100, Loss: 0.12019152194261551
# Batch: 120, Loss: 0.049373261630535126
# Batch: 140, Loss: 0.09392630308866501
# Batch: 160, Loss: 0.08494805544614792
# Batch: 180, Loss: 0.09842423349618912
# Batch: 200, Loss: 0.059204328805208206
#
# Average loss: 0.1018, Accuracy: 26711.0/27537 (97%)
#
#
# Average loss: 0.1246, Accuracy: 2946.0/3059 (96%)
#
# Epoch: 5 	Training Accuracy: 97.00%
# Validation Accuracy: 96.31%
# Batch: 0, Loss: 0.1328367292881012
# Batch: 20, Loss: 0.1518002152442932
# Batch: 40, Loss: 0.17830604314804077
# Batch: 60, Loss: 0.0913173109292984
# Batch: 80, Loss: 0.11062247306108475
# Batch: 100, Loss: 0.08323371410369873
# Batch: 120, Loss: 0.12485522031784058
# Batch: 140, Loss: 0.07390139997005463
# Batch: 160, Loss: 0.09236762672662735
# Batch: 180, Loss: 0.19816997647285461
# Batch: 200, Loss: 0.026126589626073837
#
# Average loss: 0.1001, Accuracy: 26687.0/27537 (97%)
#
#
# Average loss: 0.1224, Accuracy: 2938.0/3059 (96%)
#
# Epoch: 6 	Training Accuracy: 96.91%
# Validation Accuracy: 96.04%
# Batch: 0, Loss: 0.06775155663490295
# Batch: 20, Loss: 0.08343780040740967
# Batch: 40, Loss: 0.061802659183740616
# Batch: 60, Loss: 0.11416679620742798
# Batch: 80, Loss: 0.08841861039400101
# Batch: 100, Loss: 0.0371745340526104
# Batch: 120, Loss: 0.06465250998735428
# Batch: 140, Loss: 0.043216902762651443
# Batch: 160, Loss: 0.05455069988965988
# Batch: 180, Loss: 0.05896895006299019
# Batch: 200, Loss: 0.09691543132066727
#
# Average loss: 0.0979, Accuracy: 26729.0/27537 (97%)
#
#
# Average loss: 0.1229, Accuracy: 2941.0/3059 (96%)
#
# Epoch: 7 	Training Accuracy: 97.07%
# Validation Accuracy: 96.14%
# Batch: 0, Loss: 0.051057908684015274
# Batch: 20, Loss: 0.07998079061508179
# Batch: 40, Loss: 0.17011086642742157
# Batch: 60, Loss: 0.1810283660888672
# Batch: 80, Loss: 0.06311599910259247
# Batch: 100, Loss: 0.06166169419884682
# Batch: 120, Loss: 0.1257655769586563
# Batch: 140, Loss: 0.047904763370752335
# Batch: 160, Loss: 0.13250774145126343
# Batch: 180, Loss: 0.06811291724443436
# Batch: 200, Loss: 0.1050538718700409
#
# Average loss: 0.1024, Accuracy: 26691.0/27537 (97%)
#
#
# Average loss: 0.1282, Accuracy: 2942.0/3059 (96%)
#
# Epoch: 8 	Training Accuracy: 96.93%
# Validation Accuracy: 96.18%
# Batch: 0, Loss: 0.1380149871110916
# Batch: 20, Loss: 0.1176438257098198
# Batch: 40, Loss: 0.04671350121498108
# Batch: 60, Loss: 0.041220929473638535
# Batch: 80, Loss: 0.06613042205572128
# Batch: 100, Loss: 0.06907735764980316
# Batch: 120, Loss: 0.1427779495716095
# Batch: 140, Loss: 0.13020232319831848
# Batch: 160, Loss: 0.04868781939148903
# Batch: 180, Loss: 0.12286056578159332
# Batch: 200, Loss: 0.03204395994544029
#
# Average loss: 0.0919, Accuracy: 26782.0/27537 (97%)
#
#
# Average loss: 0.1208, Accuracy: 2948.0/3059 (96%)
#
# Epoch: 9 	Training Accuracy: 97.26%
# Validation Accuracy: 96.37%
# Batch: 0, Loss: 0.10591568052768707
# Batch: 20, Loss: 0.05255143716931343
# Batch: 40, Loss: 0.07208754867315292
# Batch: 60, Loss: 0.050823014229536057
# Batch: 80, Loss: 0.09748971462249756
# Batch: 100, Loss: 0.14553727209568024
# Batch: 120, Loss: 0.13313856720924377
# Batch: 140, Loss: 0.08259965479373932
# Batch: 160, Loss: 0.08133725076913834
# Batch: 180, Loss: 0.07451635599136353
# Batch: 200, Loss: 0.04606165736913681
#
# Average loss: 0.0959, Accuracy: 26745.0/27537 (97%)
#
#
# Average loss: 0.1237, Accuracy: 2944.0/3059 (96%)
#
# Epoch: 10 	Training Accuracy: 97.12%
# Validation Accuracy: 96.24%
# Early stopping invoked.
#
# Average loss: 0.1008, Accuracy: 26672.0/27537 (97%)
#
#
# Average loss: 0.0866, Accuracy: 5010.0/5139 (97%)
#
# Final Training Accuracy: 0.9686
# Final Test Accuracy: 0.9749

# %%
accuracy = eval(model, device, dataloader_wrapped.test_loader, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
# Out:
# Average loss: 0.0866, Accuracy: 5010.0/5139 (97%)

# %%
def effective_rank(singular_values):
    normalized_singular_values = singular_values / np.sum(singular_values)
    entropy = -np.sum(normalized_singular_values * np.log(normalized_singular_values))
    eff_rank = np.exp(entropy)
    return eff_rank

def plot_layer_effective_ranks(model, print_ranks=True):
    effective_ranks = []
    layer_names = []

    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            singular_values = np.linalg.svd(weight_matrix, compute_uv=False)
            eff_rank = effective_rank(singular_values)
            effective_ranks.append(eff_rank)
            layer_names.append(name)

    if print_ranks:
        for layer_name, eff_rank in zip(layer_names, effective_ranks):
            print(f'{layer_name}: {eff_rank:.4f}')

    # Plotting
    plt.figure(figsize=(15, 5))
    plt.bar(layer_names, effective_ranks, color='green')
    plt.xlabel('Layer')
    plt.ylabel('Effective Rank')
    plt.title('Effective Rank of Weight Matrices for Each Layer')
    plt.grid(True)

    y_max = np.max(effective_ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(effective_ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(0, int(y_max)+2, step=2))  # Set yticks

    plt.show()

# Example usage
plot_layer_effective_ranks(model)  # Note: You'll need to define or load 'model' before calling this function
# Out:
# conv0.weight: 3.8875
# conv1.weight: 3.9582
# fc_1.weight: 97.2927
# fc_2.weight: 9.4978

# %% [markdown]
# ----

# %% [markdown]
# # Finetuning experiments

# %%
dataloader_wrapped.update_phase('finetune')

a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        print('-------------')
        break
# Out:
# -------------

# %% [markdown]
# ## Baseline model: end2end with the same architecture as the preatining model

# %%
# 2. Create a new model and copy weights from the original model, then adjust the final layer
print("Current dataloader phase: ", dataloader_wrapped.get_current_phase())

model_finetuning_baseline = generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=False)
model_finetuning_baseline.to(device)

# dataloader_wrapped.update_phase('finetune')
# Train and evaluate the new model on the new data
# train_acc_new, test_acc_new, model_finetuning_baseline, _,_ = compute_training_acc_epochs_cnn(model_finetuning_baseline, dataloader_wrapped, params, debug=True)

trainer = Trainer(model, dataloader_wrapped, params)
train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
print(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")
# Out:
# Current dataloader phase:  finetune
# Batch: 0, Loss: 4.584918975830078
# Batch: 20, Loss: 1.3195247650146484
# Batch: 40, Loss: 0.9921354651451111
# Batch: 60, Loss: 0.7039961218833923
# Batch: 80, Loss: 0.6020423769950867
# Batch: 100, Loss: 0.4417096674442291
# Batch: 120, Loss: 0.3949466943740845
# Batch: 140, Loss: 0.3588717579841614
# Batch: 160, Loss: 0.2161933332681656
# Batch: 180, Loss: 0.2533576190471649
# Batch: 200, Loss: 0.22301582992076874
#
# Average loss: 0.2657, Accuracy: 24166.0/26464 (91%)
#
#
# Average loss: 0.2850, Accuracy: 2671.0/2940 (91%)
#
# Epoch: 0 	Training Accuracy: 91.32%
# Validation Accuracy: 90.85%
# Batch: 0, Loss: 0.29162442684173584
# Batch: 20, Loss: 0.2400335818529129
# Batch: 40, Loss: 0.2543697953224182
# Batch: 60, Loss: 0.27579647302627563
# Batch: 80, Loss: 0.27850306034088135
# Batch: 100, Loss: 0.20663395524024963
# Batch: 120, Loss: 0.13089729845523834
# Batch: 140, Loss: 0.14954610168933868
# Batch: 160, Loss: 0.19710581004619598
# Batch: 180, Loss: 0.1306239813566208
# Batch: 200, Loss: 0.20062805712223053
#
# Average loss: 0.1852, Accuracy: 24853.0/26464 (94%)
#
#
# Average loss: 0.2068, Accuracy: 2743.0/2940 (93%)
#
# Epoch: 1 	Training Accuracy: 93.91%
# Validation Accuracy: 93.30%
# Batch: 0, Loss: 0.11844325810670853
# Batch: 20, Loss: 0.22409625351428986
# Batch: 40, Loss: 0.1735614836215973
# Batch: 60, Loss: 0.22272351384162903
# Batch: 80, Loss: 0.2547028958797455
# Batch: 100, Loss: 0.16277718544006348
# Batch: 120, Loss: 0.13696572184562683
# Batch: 140, Loss: 0.14296437799930573
# Batch: 160, Loss: 0.1860598921775818
# Batch: 180, Loss: 0.15333789587020874
# Batch: 200, Loss: 0.15498466789722443
#
# Average loss: 0.1580, Accuracy: 25121.0/26464 (95%)
#
#
# Average loss: 0.1847, Accuracy: 2774.0/2940 (94%)
#
# Epoch: 2 	Training Accuracy: 94.93%
# Validation Accuracy: 94.35%
# Batch: 0, Loss: 0.1686430126428604
# Batch: 20, Loss: 0.06605558842420578
# Batch: 40, Loss: 0.18103283643722534
# Batch: 60, Loss: 0.09880192577838898
# Batch: 80, Loss: 0.11642097681760788
# Batch: 100, Loss: 0.21219143271446228
# Batch: 120, Loss: 0.22733426094055176
# Batch: 140, Loss: 0.13866589963436127
# Batch: 160, Loss: 0.11445396393537521
# Batch: 180, Loss: 0.08689954876899719
# Batch: 200, Loss: 0.12053576111793518
#
# Average loss: 0.1493, Accuracy: 25200.0/26464 (95%)
#
#
# Average loss: 0.1742, Accuracy: 2783.0/2940 (95%)
#
# Epoch: 3 	Training Accuracy: 95.22%
# Validation Accuracy: 94.66%
# Batch: 0, Loss: 0.12194831669330597
# Batch: 20, Loss: 0.1169426366686821
# Batch: 40, Loss: 0.11995533853769302
# Batch: 60, Loss: 0.22395120561122894
# Batch: 80, Loss: 0.21465127170085907
# Batch: 100, Loss: 0.14516189694404602
# Batch: 120, Loss: 0.10608071833848953
# Batch: 140, Loss: 0.12107343226671219
# Batch: 160, Loss: 0.051621995866298676
# Batch: 180, Loss: 0.11199856549501419
# Batch: 200, Loss: 0.1750933825969696
#
# Average loss: 0.1363, Accuracy: 25340.0/26464 (96%)
#
#
# Average loss: 0.1601, Accuracy: 2793.0/2940 (95%)
#
# Epoch: 4 	Training Accuracy: 95.75%
# Validation Accuracy: 95.00%
# Batch: 0, Loss: 0.12332998216152191
# Batch: 20, Loss: 0.13780228793621063
# Batch: 40, Loss: 0.08382833749055862
# Batch: 60, Loss: 0.0744611844420433
# Batch: 80, Loss: 0.20128270983695984
# Batch: 100, Loss: 0.08915384858846664
# Batch: 120, Loss: 0.12171141803264618
# Batch: 140, Loss: 0.04168609157204628
# Batch: 160, Loss: 0.15368859469890594
# Batch: 180, Loss: 0.15482228994369507
# Batch: 200, Loss: 0.1444852501153946
#
# Average loss: 0.1300, Accuracy: 25400.0/26464 (96%)
#
#
# Average loss: 0.1575, Accuracy: 2795.0/2940 (95%)
#
# Epoch: 5 	Training Accuracy: 95.98%
# Validation Accuracy: 95.07%
# Batch: 0, Loss: 0.12364907562732697
# Batch: 20, Loss: 0.06404387205839157
# Batch: 40, Loss: 0.10678134858608246
# Batch: 60, Loss: 0.051692813634872437
# Batch: 80, Loss: 0.06284860521554947
# Batch: 100, Loss: 0.12962715327739716
# Batch: 120, Loss: 0.12716560065746307
# Batch: 140, Loss: 0.18448472023010254
# Batch: 160, Loss: 0.14372000098228455
# Batch: 180, Loss: 0.1392345428466797
# Batch: 200, Loss: 0.17246346175670624
#
# Average loss: 0.1233, Accuracy: 25465.0/26464 (96%)
#
#
# Average loss: 0.1534, Accuracy: 2797.0/2940 (95%)
#
# Epoch: 6 	Training Accuracy: 96.23%
# Validation Accuracy: 95.14%
# Batch: 0, Loss: 0.10208307951688766
# Batch: 20, Loss: 0.21620948612689972
# Batch: 40, Loss: 0.24305054545402527
# Batch: 60, Loss: 0.10916697978973389
# Batch: 80, Loss: 0.18493658304214478
# Batch: 100, Loss: 0.1070922464132309
# Batch: 120, Loss: 0.18385377526283264
# Batch: 140, Loss: 0.18425211310386658
# Batch: 160, Loss: 0.11072061955928802
# Batch: 180, Loss: 0.17934216558933258
# Batch: 200, Loss: 0.24933242797851562
#
# Average loss: 0.1250, Accuracy: 25455.0/26464 (96%)
#
#
# Average loss: 0.1544, Accuracy: 2795.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 96.19%
# Validation Accuracy: 95.07%
# Batch: 0, Loss: 0.14475852251052856
# Batch: 20, Loss: 0.053998757153749466
# Batch: 40, Loss: 0.10902301967144012
# Batch: 60, Loss: 0.10650547593832016
# Batch: 80, Loss: 0.07731274515390396
# Batch: 100, Loss: 0.14741839468479156
# Batch: 120, Loss: 0.08697991818189621
# Batch: 140, Loss: 0.1286185085773468
# Batch: 160, Loss: 0.1424972116947174
# Batch: 180, Loss: 0.10200249403715134
# Batch: 200, Loss: 0.09350509196519852
#
# Average loss: 0.1217, Accuracy: 25431.0/26464 (96%)
#
#
# Average loss: 0.1507, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 8 	Training Accuracy: 96.10%
# Validation Accuracy: 95.10%
# Batch: 0, Loss: 0.13185130059719086
# Batch: 20, Loss: 0.10550917685031891
# Batch: 40, Loss: 0.13213768601417542
# Batch: 60, Loss: 0.0819225087761879
# Batch: 80, Loss: 0.24796022474765778
# Batch: 100, Loss: 0.19156987965106964
# Batch: 120, Loss: 0.13046492636203766
# Batch: 140, Loss: 0.15750905871391296
# Batch: 160, Loss: 0.0781932845711708
# Batch: 180, Loss: 0.1095656305551529
# Batch: 200, Loss: 0.12405413389205933
#
# Average loss: 0.1168, Accuracy: 25537.0/26464 (96%)
#
#
# Average loss: 0.1494, Accuracy: 2799.0/2940 (95%)
#
# Epoch: 9 	Training Accuracy: 96.50%
# Validation Accuracy: 95.20%
# Batch: 0, Loss: 0.09417323023080826
# Batch: 20, Loss: 0.06323814392089844
# Batch: 40, Loss: 0.15120510756969452
# Batch: 60, Loss: 0.12973129749298096
# Batch: 80, Loss: 0.14205637574195862
# Batch: 100, Loss: 0.054180651903152466
# Batch: 120, Loss: 0.0770743265748024
# Batch: 140, Loss: 0.09407205879688263
# Batch: 160, Loss: 0.19114305078983307
# Batch: 180, Loss: 0.07912085205316544
# Batch: 200, Loss: 0.1106315404176712
#
# Average loss: 0.1193, Accuracy: 25474.0/26464 (96%)
#
#
# Average loss: 0.1482, Accuracy: 2804.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 96.26%
# Validation Accuracy: 95.37%
# Batch: 0, Loss: 0.1269824206829071
# Batch: 20, Loss: 0.13769684731960297
# Batch: 40, Loss: 0.11260673403739929
# Batch: 60, Loss: 0.09889711439609528
# Batch: 80, Loss: 0.12151379883289337
# Batch: 100, Loss: 0.15070109069347382
# Batch: 120, Loss: 0.18643583357334137
# Batch: 140, Loss: 0.05615293234586716
# Batch: 160, Loss: 0.12343638390302658
# Batch: 180, Loss: 0.09138746559619904
# Batch: 200, Loss: 0.11444415152072906
#
# Average loss: 0.1117, Accuracy: 25584.0/26464 (97%)
#
#
# Average loss: 0.1438, Accuracy: 2809.0/2940 (96%)
#
# Epoch: 11 	Training Accuracy: 96.67%
# Validation Accuracy: 95.54%
# Batch: 0, Loss: 0.15601401031017303
# Batch: 20, Loss: 0.11247334629297256
# Batch: 40, Loss: 0.08087997138500214
# Batch: 60, Loss: 0.13126680254936218
# Batch: 80, Loss: 0.06646531075239182
# Batch: 100, Loss: 0.2058389037847519
# Batch: 120, Loss: 0.11042274534702301
# Batch: 140, Loss: 0.11038509756326675
# Batch: 160, Loss: 0.15902607142925262
# Batch: 180, Loss: 0.12693904340267181
# Batch: 200, Loss: 0.0973515436053276
#
# Average loss: 0.1086, Accuracy: 25591.0/26464 (97%)
#
#
# Average loss: 0.1402, Accuracy: 2816.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 96.70%
# Validation Accuracy: 95.78%
# Batch: 0, Loss: 0.08201450109481812
# Batch: 20, Loss: 0.0916869193315506
# Batch: 40, Loss: 0.09256594628095627
# Batch: 60, Loss: 0.12250617146492004
# Batch: 80, Loss: 0.03514823317527771
# Batch: 100, Loss: 0.10418710857629776
# Batch: 120, Loss: 0.1314961463212967
# Batch: 140, Loss: 0.06893256306648254
# Batch: 160, Loss: 0.1686374396085739
# Batch: 180, Loss: 0.0388159453868866
# Batch: 200, Loss: 0.21485131978988647
#
# Average loss: 0.1160, Accuracy: 25556.0/26464 (97%)
#
#
# Average loss: 0.1456, Accuracy: 2808.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 96.57%
# Validation Accuracy: 95.51%
# Batch: 0, Loss: 0.08566352725028992
# Batch: 20, Loss: 0.13338078558444977
# Batch: 40, Loss: 0.07631932944059372
# Batch: 60, Loss: 0.16474220156669617
# Batch: 80, Loss: 0.16256432235240936
# Batch: 100, Loss: 0.048657771199941635
# Batch: 120, Loss: 0.11038628965616226
# Batch: 140, Loss: 0.08964855223894119
# Batch: 160, Loss: 0.14229872822761536
# Batch: 180, Loss: 0.09620657563209534
# Batch: 200, Loss: 0.11400109529495239
#
# Average loss: 0.1097, Accuracy: 25594.0/26464 (97%)
#
#
# Average loss: 0.1363, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 96.71%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.10425140708684921
# Batch: 20, Loss: 0.10124850273132324
# Batch: 40, Loss: 0.05948327109217644
# Batch: 60, Loss: 0.08395528793334961
# Batch: 80, Loss: 0.22235022485256195
# Batch: 100, Loss: 0.14136821031570435
# Batch: 120, Loss: 0.14962515234947205
# Batch: 140, Loss: 0.0699744001030922
# Batch: 160, Loss: 0.09168392419815063
# Batch: 180, Loss: 0.12025494873523712
# Batch: 200, Loss: 0.13996821641921997
#
# Average loss: 0.1106, Accuracy: 25559.0/26464 (97%)
#
#
# Average loss: 0.1430, Accuracy: 2813.0/2940 (96%)
#
# Epoch: 15 	Training Accuracy: 96.58%
# Validation Accuracy: 95.68%
# Batch: 0, Loss: 0.18565374612808228
# Batch: 20, Loss: 0.04718248173594475
# Batch: 40, Loss: 0.1208082064986229
# Batch: 60, Loss: 0.043432313948869705
# Batch: 80, Loss: 0.1483394056558609
# Batch: 100, Loss: 0.10211986303329468
# Batch: 120, Loss: 0.05775263532996178
# Batch: 140, Loss: 0.17699353396892548
# Batch: 160, Loss: 0.10067770630121231
# Batch: 180, Loss: 0.1449085772037506
# Batch: 200, Loss: 0.10534153133630753
#
# Average loss: 0.1029, Accuracy: 25625.0/26464 (97%)
#
#
# Average loss: 0.1430, Accuracy: 2814.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 96.83%
# Validation Accuracy: 95.71%
# Batch: 0, Loss: 0.08589546382427216
# Batch: 20, Loss: 0.1117316335439682
# Batch: 40, Loss: 0.1616586297750473
# Batch: 60, Loss: 0.12970906496047974
# Batch: 80, Loss: 0.13937145471572876
# Batch: 100, Loss: 0.17617958784103394
# Batch: 120, Loss: 0.1108345240354538
# Batch: 140, Loss: 0.09650993347167969
# Batch: 160, Loss: 0.13292284309864044
# Batch: 180, Loss: 0.07590129971504211
# Batch: 200, Loss: 0.05349631980061531
#
# Average loss: 0.1266, Accuracy: 25406.0/26464 (96%)
#
#
# Average loss: 0.1609, Accuracy: 2790.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 96.00%
# Validation Accuracy: 94.90%
# Batch: 0, Loss: 0.12381456792354584
# Batch: 20, Loss: 0.12170878052711487
# Batch: 40, Loss: 0.06102032586932182
# Batch: 60, Loss: 0.08203643560409546
# Batch: 80, Loss: 0.039139434695243835
# Batch: 100, Loss: 0.08415345847606659
# Batch: 120, Loss: 0.05358861759305
# Batch: 140, Loss: 0.07519957423210144
# Batch: 160, Loss: 0.07098118215799332
# Batch: 180, Loss: 0.1093628779053688
# Batch: 200, Loss: 0.02731839008629322
#
# Average loss: 0.0953, Accuracy: 25681.0/26464 (97%)
#
#
# Average loss: 0.1321, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 18 	Training Accuracy: 97.04%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.061702486127614975
# Batch: 20, Loss: 0.1308295577764511
# Batch: 40, Loss: 0.059130776673555374
# Batch: 60, Loss: 0.14018912613391876
# Batch: 80, Loss: 0.16496622562408447
# Batch: 100, Loss: 0.0824211835861206
# Batch: 120, Loss: 0.11262574046850204
# Batch: 140, Loss: 0.11006978899240494
# Batch: 160, Loss: 0.08425214141607285
# Batch: 180, Loss: 0.1126604676246643
# Batch: 200, Loss: 0.08405269682407379
#
# Average loss: 0.1064, Accuracy: 25626.0/26464 (97%)
#
#
# Average loss: 0.1369, Accuracy: 2830.0/2940 (96%)
#
# Epoch: 19 	Training Accuracy: 96.83%
# Validation Accuracy: 96.26%
#
# Average loss: 0.1064, Accuracy: 25626.0/26464 (97%)
#
#
# Average loss: 0.1209, Accuracy: 4682.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9683
# Final Test Accuracy (New Data): 0.9632

# %%
plot_layer_effective_ranks(model_finetuning_baseline)
# Out:
# conv0.weight: 4.5751
# conv1.weight: 4.2635
# fc_1.weight: 124.1947
# fc_2.weight: 4.9832

# %% [markdown]
# ***WITH BALANCED CLASSES***

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01]
percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]

seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test = {}
results_train = {}
best_models = {}
data_loaders = {}
epochs_taken = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Training with different data percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []

    for seed in tqdm(seed_set, desc=f'Training for data percentage: {perc}', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")
        
        model_new =  generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=False)
        model_new.to(device)

        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)

        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        # Train and evaluate the new model on the new data
        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        # Add tqdm write method to prevent progress bar overlap
        tqdm.write(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
        tqdm.write(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test[perc] = test_accuracies
    results_train[perc] = train_accuracies
    epochs_taken[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Training with different data percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Training for data percentage: 0.01:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 20 =========================
# Batch: 0, Loss: 1.6081303358078003
#
# Average loss: 1.6128, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6099, Accuracy: 655.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6132346391677856
#
# Average loss: 1.6365, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6360, Accuracy: 551.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.64191734790802
#
# Average loss: 1.6150, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6183, Accuracy: 551.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6106324195861816
#
# Average loss: 1.5992, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6019, Accuracy: 550.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.5935125350952148
#
# Average loss: 1.6049, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6057, Accuracy: 550.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6170973777770996
#
# Average loss: 1.6136, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6123, Accuracy: 550.0/2940 (19%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.5901427268981934
#
# Average loss: 1.6187, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6182, Accuracy: 550.0/2940 (19%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Early stopping invoked.
#
# Average loss: 1.6128, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6129, Accuracy: 1028.0/4861 (21%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.2115
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 72 =========================
# Batch: 0, Loss: 1.6126229763031006
#
# Average loss: 1.6041, Accuracy: 69.0/260 (27%)
#
#
# Average loss: 1.6052, Accuracy: 715.0/2940 (24%)
#
# Epoch: 0 	Training Accuracy: 26.54%
# Validation Accuracy: 24.32%
# Batch: 0, Loss: 1.605027437210083
#
# Average loss: 1.6126, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6217, Accuracy: 550.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6021345853805542
#
# Average loss: 1.6121, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6211, Accuracy: 585.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.605203628540039
#
# Average loss: 1.6113, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6202, Accuracy: 585.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.613586664199829
#
# Average loss: 1.5990, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6101, Accuracy: 585.0/2940 (20%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6069753170013428
#
# Average loss: 1.5876, Accuracy: 81.0/260 (31%)
#
#
# Average loss: 1.5994, Accuracy: 802.0/2940 (27%)
#
# Epoch: 5 	Training Accuracy: 31.15%
# Validation Accuracy: 27.28%
# Batch: 0, Loss: 1.595375657081604
#
# Average loss: 1.5779, Accuracy: 71.0/260 (27%)
#
#
# Average loss: 1.5894, Accuracy: 671.0/2940 (23%)
#
# Epoch: 6 	Training Accuracy: 27.31%
# Validation Accuracy: 22.82%
# Batch: 0, Loss: 1.5847060680389404
#
# Average loss: 1.5675, Accuracy: 67.0/260 (26%)
#
#
# Average loss: 1.5794, Accuracy: 652.0/2940 (22%)
#
# Epoch: 7 	Training Accuracy: 25.77%
# Validation Accuracy: 22.18%
# Batch: 0, Loss: 1.5628242492675781
#
# Average loss: 1.5541, Accuracy: 76.0/260 (29%)
#
#
# Average loss: 1.5678, Accuracy: 719.0/2940 (24%)
#
# Epoch: 8 	Training Accuracy: 29.23%
# Validation Accuracy: 24.46%
# Batch: 0, Loss: 1.5595167875289917
#
# Average loss: 1.5390, Accuracy: 90.0/260 (35%)
#
#
# Average loss: 1.5548, Accuracy: 828.0/2940 (28%)
#
# Epoch: 9 	Training Accuracy: 34.62%
# Validation Accuracy: 28.16%
# Batch: 0, Loss: 1.5385146141052246
#
# Average loss: 1.5232, Accuracy: 105.0/260 (40%)
#
#
# Average loss: 1.5407, Accuracy: 1103.0/2940 (38%)
#
# Epoch: 10 	Training Accuracy: 40.38%
# Validation Accuracy: 37.52%
# Batch: 0, Loss: 1.5105116367340088
#
# Average loss: 1.5042, Accuracy: 152.0/260 (58%)
#
#
# Average loss: 1.5221, Accuracy: 1597.0/2940 (54%)
#
# Epoch: 11 	Training Accuracy: 58.46%
# Validation Accuracy: 54.32%
# Batch: 0, Loss: 1.4988009929656982
#
# Average loss: 1.4833, Accuracy: 166.0/260 (64%)
#
#
# Average loss: 1.5026, Accuracy: 1697.0/2940 (58%)
#
# Epoch: 12 	Training Accuracy: 63.85%
# Validation Accuracy: 57.72%
# Batch: 0, Loss: 1.491255760192871
#
# Average loss: 1.4579, Accuracy: 162.0/260 (62%)
#
#
# Average loss: 1.4793, Accuracy: 1590.0/2940 (54%)
#
# Epoch: 13 	Training Accuracy: 62.31%
# Validation Accuracy: 54.08%
# Batch: 0, Loss: 1.455939769744873
#
# Average loss: 1.4266, Accuracy: 166.0/260 (64%)
#
#
# Average loss: 1.4501, Accuracy: 1684.0/2940 (57%)
#
# Epoch: 14 	Training Accuracy: 63.85%
# Validation Accuracy: 57.28%
# Batch: 0, Loss: 1.4273771047592163
#
# Average loss: 1.3901, Accuracy: 182.0/260 (70%)
#
#
# Average loss: 1.4162, Accuracy: 1847.0/2940 (63%)
#
# Epoch: 15 	Training Accuracy: 70.00%
# Validation Accuracy: 62.82%
# Batch: 0, Loss: 1.3935168981552124
#
# Average loss: 1.3485, Accuracy: 184.0/260 (71%)
#
#
# Average loss: 1.3770, Accuracy: 1922.0/2940 (65%)
#
# Epoch: 16 	Training Accuracy: 70.77%
# Validation Accuracy: 65.37%
# Batch: 0, Loss: 1.359235405921936
#
# Average loss: 1.3036, Accuracy: 181.0/260 (70%)
#
#
# Average loss: 1.3342, Accuracy: 1884.0/2940 (64%)
#
# Epoch: 17 	Training Accuracy: 69.62%
# Validation Accuracy: 64.08%
# Batch: 0, Loss: 1.343324899673462
#
# Average loss: 1.2587, Accuracy: 162.0/260 (62%)
#
#
# Average loss: 1.2931, Accuracy: 1778.0/2940 (60%)
#
# Epoch: 18 	Training Accuracy: 62.31%
# Validation Accuracy: 60.48%
# Batch: 0, Loss: 1.2411258220672607
#
# Average loss: 1.2002, Accuracy: 174.0/260 (67%)
#
#
# Average loss: 1.2395, Accuracy: 1842.0/2940 (63%)
#
# Epoch: 19 	Training Accuracy: 66.92%
# Validation Accuracy: 62.65%
#
# Average loss: 1.2002, Accuracy: 174.0/260 (67%)
#
#
# Average loss: 1.2358, Accuracy: 2973.0/4861 (61%)
#
# Final Training Accuracy (New Data): 0.6692
# Final Test Accuracy (New Data): 0.6116
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 13 =========================
# Batch: 0, Loss: 1.6068090200424194
#
# Average loss: 1.6072, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6083, Accuracy: 599.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.6085611581802368
#
# Average loss: 1.6001, Accuracy: 127.0/260 (49%)
#
#
# Average loss: 1.6030, Accuracy: 1346.0/2940 (46%)
#
# Epoch: 1 	Training Accuracy: 48.85%
# Validation Accuracy: 45.78%
# Batch: 0, Loss: 1.5962116718292236
#
# Average loss: 1.5858, Accuracy: 105.0/260 (40%)
#
#
# Average loss: 1.5916, Accuracy: 1089.0/2940 (37%)
#
# Epoch: 2 	Training Accuracy: 40.38%
# Validation Accuracy: 37.04%
# Batch: 0, Loss: 1.5834646224975586
#
# Average loss: 1.5613, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.5703, Accuracy: 555.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 20.38%
# Validation Accuracy: 18.88%
# Batch: 0, Loss: 1.5746501684188843
#
# Average loss: 1.5384, Accuracy: 57.0/260 (22%)
#
#
# Average loss: 1.5501, Accuracy: 569.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 21.92%
# Validation Accuracy: 19.35%
# Batch: 0, Loss: 1.5363038778305054
#
# Average loss: 1.5266, Accuracy: 60.0/260 (23%)
#
#
# Average loss: 1.5405, Accuracy: 622.0/2940 (21%)
#
# Epoch: 5 	Training Accuracy: 23.08%
# Validation Accuracy: 21.16%
# Batch: 0, Loss: 1.508965015411377
#
# Average loss: 1.4595, Accuracy: 87.0/260 (33%)
#
#
# Average loss: 1.4737, Accuracy: 1032.0/2940 (35%)
#
# Epoch: 6 	Training Accuracy: 33.46%
# Validation Accuracy: 35.10%
# Batch: 0, Loss: 1.4714531898498535
#
# Average loss: 1.3565, Accuracy: 142.0/260 (55%)
#
#
# Average loss: 1.3686, Accuracy: 1593.0/2940 (54%)
#
# Epoch: 7 	Training Accuracy: 54.62%
# Validation Accuracy: 54.18%
# Batch: 0, Loss: 1.3825454711914062
#
# Average loss: 1.2394, Accuracy: 142.0/260 (55%)
#
#
# Average loss: 1.2545, Accuracy: 1620.0/2940 (55%)
#
# Epoch: 8 	Training Accuracy: 54.62%
# Validation Accuracy: 55.10%
# Batch: 0, Loss: 1.2077643871307373
#
# Average loss: 1.0892, Accuracy: 188.0/260 (72%)
#
#
# Average loss: 1.1148, Accuracy: 2061.0/2940 (70%)
#
# Epoch: 9 	Training Accuracy: 72.31%
# Validation Accuracy: 70.10%
# Batch: 0, Loss: 1.1058076620101929
#
# Average loss: 0.9333, Accuracy: 206.0/260 (79%)
#
#
# Average loss: 0.9658, Accuracy: 2285.0/2940 (78%)
#
# Epoch: 10 	Training Accuracy: 79.23%
# Validation Accuracy: 77.72%
# Batch: 0, Loss: 0.9844322204589844
#
# Average loss: 0.7975, Accuracy: 194.0/260 (75%)
#
#
# Average loss: 0.8383, Accuracy: 2167.0/2940 (74%)
#
# Epoch: 11 	Training Accuracy: 74.62%
# Validation Accuracy: 73.71%
# Batch: 0, Loss: 0.7295457124710083
#
# Average loss: 0.6370, Accuracy: 222.0/260 (85%)
#
#
# Average loss: 0.7032, Accuracy: 2305.0/2940 (78%)
#
# Epoch: 12 	Training Accuracy: 85.38%
# Validation Accuracy: 78.40%
# Batch: 0, Loss: 0.6845803260803223
#
# Average loss: 0.4932, Accuracy: 231.0/260 (89%)
#
#
# Average loss: 0.5768, Accuracy: 2460.0/2940 (84%)
#
# Epoch: 13 	Training Accuracy: 88.85%
# Validation Accuracy: 83.67%
# Batch: 0, Loss: 0.49012285470962524
#
# Average loss: 0.4248, Accuracy: 235.0/260 (90%)
#
#
# Average loss: 0.5146, Accuracy: 2469.0/2940 (84%)
#
# Epoch: 14 	Training Accuracy: 90.38%
# Validation Accuracy: 83.98%
# Batch: 0, Loss: 0.42660754919052124
#
# Average loss: 0.3716, Accuracy: 234.0/260 (90%)
#
#
# Average loss: 0.4838, Accuracy: 2457.0/2940 (84%)
#
# Epoch: 15 	Training Accuracy: 90.00%
# Validation Accuracy: 83.57%
# Batch: 0, Loss: 0.4248088002204895
#
# Average loss: 0.3820, Accuracy: 233.0/260 (90%)
#
#
# Average loss: 0.4903, Accuracy: 2463.0/2940 (84%)
#
# Epoch: 16 	Training Accuracy: 89.62%
# Validation Accuracy: 83.78%
# Batch: 0, Loss: 0.31741973757743835
#
# Average loss: 0.3386, Accuracy: 233.0/260 (90%)
#
#
# Average loss: 0.4601, Accuracy: 2482.0/2940 (84%)
#
# Epoch: 17 	Training Accuracy: 89.62%
# Validation Accuracy: 84.42%
# Batch: 0, Loss: 0.34060561656951904
#
# Average loss: 0.2858, Accuracy: 234.0/260 (90%)
#
#
# Average loss: 0.4323, Accuracy: 2499.0/2940 (85%)
#
# Epoch: 18 	Training Accuracy: 90.00%
# Validation Accuracy: 85.00%
# Batch: 0, Loss: 0.24225977063179016
#
# Average loss: 0.3833, Accuracy: 214.0/260 (82%)
#
#
# Average loss: 0.5690, Accuracy: 2372.0/2940 (81%)
#
# Epoch: 19 	Training Accuracy: 82.31%
# Validation Accuracy: 80.68%
#
# Average loss: 0.3833, Accuracy: 214.0/260 (82%)
#
#
# Average loss: 0.5073, Accuracy: 4031.0/4861 (83%)
#
# Final Training Accuracy (New Data): 0.8231
# Final Test Accuracy (New Data): 0.8293
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 95 =========================
# Batch: 0, Loss: 1.6090911626815796
#
# Average loss: 1.6112, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6198, Accuracy: 550.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6164501905441284
#
# Average loss: 1.6658, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6869, Accuracy: 550.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6760907173156738
#
# Average loss: 1.6534, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6767, Accuracy: 550.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6314365863800049
#
# Average loss: 1.6465, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6651, Accuracy: 551.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6694941520690918
#
# Average loss: 1.6075, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6112, Accuracy: 551.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.61797034740448
#
# Average loss: 1.5971, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5881, Accuracy: 655.0/2940 (22%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.5885530710220337
#
# Average loss: 1.6068, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5926, Accuracy: 655.0/2940 (22%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.5823811292648315
#
# Average loss: 1.5800, Accuracy: 64.0/260 (25%)
#
#
# Average loss: 1.5718, Accuracy: 773.0/2940 (26%)
#
# Epoch: 7 	Training Accuracy: 24.62%
# Validation Accuracy: 26.29%
# Batch: 0, Loss: 1.611066222190857
#
# Average loss: 1.5625, Accuracy: 67.0/260 (26%)
#
#
# Average loss: 1.5665, Accuracy: 615.0/2940 (21%)
#
# Epoch: 8 	Training Accuracy: 25.77%
# Validation Accuracy: 20.92%
# Batch: 0, Loss: 1.5430186986923218
#
# Average loss: 1.5547, Accuracy: 102.0/260 (39%)
#
#
# Average loss: 1.5698, Accuracy: 1076.0/2940 (37%)
#
# Epoch: 9 	Training Accuracy: 39.23%
# Validation Accuracy: 36.60%
# Batch: 0, Loss: 1.6011648178100586
#
# Average loss: 1.5365, Accuracy: 91.0/260 (35%)
#
#
# Average loss: 1.5584, Accuracy: 947.0/2940 (32%)
#
# Epoch: 10 	Training Accuracy: 35.00%
# Validation Accuracy: 32.21%
# Batch: 0, Loss: 1.5632233619689941
#
# Average loss: 1.4461, Accuracy: 103.0/260 (40%)
#
#
# Average loss: 1.4698, Accuracy: 1121.0/2940 (38%)
#
# Epoch: 11 	Training Accuracy: 39.62%
# Validation Accuracy: 38.13%
# Batch: 0, Loss: 1.4281108379364014
#
# Average loss: 1.3663, Accuracy: 125.0/260 (48%)
#
#
# Average loss: 1.3894, Accuracy: 1312.0/2940 (45%)
#
# Epoch: 12 	Training Accuracy: 48.08%
# Validation Accuracy: 44.63%
# Batch: 0, Loss: 1.3508381843566895
#
# Average loss: 1.3151, Accuracy: 110.0/260 (42%)
#
#
# Average loss: 1.3361, Accuracy: 1204.0/2940 (41%)
#
# Epoch: 13 	Training Accuracy: 42.31%
# Validation Accuracy: 40.95%
# Batch: 0, Loss: 1.334271788597107
#
# Average loss: 1.2351, Accuracy: 129.0/260 (50%)
#
#
# Average loss: 1.2528, Accuracy: 1507.0/2940 (51%)
#
# Epoch: 14 	Training Accuracy: 49.62%
# Validation Accuracy: 51.26%
# Batch: 0, Loss: 1.1961413621902466
#
# Average loss: 1.1521, Accuracy: 163.0/260 (63%)
#
#
# Average loss: 1.1679, Accuracy: 1725.0/2940 (59%)
#
# Epoch: 15 	Training Accuracy: 62.69%
# Validation Accuracy: 58.67%
# Batch: 0, Loss: 1.1131055355072021
#
# Average loss: 1.0687, Accuracy: 149.0/260 (57%)
#
#
# Average loss: 1.0883, Accuracy: 1664.0/2940 (57%)
#
# Epoch: 16 	Training Accuracy: 57.31%
# Validation Accuracy: 56.60%
# Batch: 0, Loss: 1.057757019996643
#
# Average loss: 0.9986, Accuracy: 171.0/260 (66%)
#
#
# Average loss: 1.0303, Accuracy: 1941.0/2940 (66%)
#
# Epoch: 17 	Training Accuracy: 65.77%
# Validation Accuracy: 66.02%
# Batch: 0, Loss: 1.0172175168991089
#
# Average loss: 0.9389, Accuracy: 171.0/260 (66%)
#
#
# Average loss: 0.9813, Accuracy: 1969.0/2940 (67%)
#
# Epoch: 18 	Training Accuracy: 65.77%
# Validation Accuracy: 66.97%
# Batch: 0, Loss: 0.8821257948875427
#
# Average loss: 0.8705, Accuracy: 170.0/260 (65%)
#
#
# Average loss: 0.9143, Accuracy: 1959.0/2940 (67%)
#
# Epoch: 19 	Training Accuracy: 65.38%
# Validation Accuracy: 66.63%
#
# Average loss: 0.8705, Accuracy: 170.0/260 (65%)
#
#
# Average loss: 0.9193, Accuracy: 3188.0/4861 (66%)
#
# Final Training Accuracy (New Data): 0.6538
# Final Test Accuracy (New Data): 0.6558
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 4 =========================
# Batch: 0, Loss: 1.6135334968566895
#
# Average loss: 1.5835, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5822, Accuracy: 554.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.84%
# Batch: 0, Loss: 1.5806931257247925
#
# Average loss: 1.6169, Accuracy: 60.0/260 (23%)
#
#
# Average loss: 1.6229, Accuracy: 633.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 23.08%
# Validation Accuracy: 21.53%
# Batch: 0, Loss: 1.614994764328003
#
# Average loss: 1.5915, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.6016, Accuracy: 597.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 22.31%
# Validation Accuracy: 20.31%
# Batch: 0, Loss: 1.5743801593780518
#
# Average loss: 1.5607, Accuracy: 85.0/260 (33%)
#
#
# Average loss: 1.5685, Accuracy: 976.0/2940 (33%)
#
# Epoch: 3 	Training Accuracy: 32.69%
# Validation Accuracy: 33.20%
# Batch: 0, Loss: 1.5424996614456177
#
# Average loss: 1.5440, Accuracy: 152.0/260 (58%)
#
#
# Average loss: 1.5479, Accuracy: 1640.0/2940 (56%)
#
# Epoch: 4 	Training Accuracy: 58.46%
# Validation Accuracy: 55.78%
# Batch: 0, Loss: 1.546661376953125
#
# Average loss: 1.5301, Accuracy: 115.0/260 (44%)
#
#
# Average loss: 1.5324, Accuracy: 1253.0/2940 (43%)
#
# Epoch: 5 	Training Accuracy: 44.23%
# Validation Accuracy: 42.62%
# Batch: 0, Loss: 1.5318931341171265
#
# Average loss: 1.5126, Accuracy: 82.0/260 (32%)
#
#
# Average loss: 1.5148, Accuracy: 983.0/2940 (33%)
#
# Epoch: 6 	Training Accuracy: 31.54%
# Validation Accuracy: 33.44%
# Batch: 0, Loss: 1.509246587753296
#
# Average loss: 1.4963, Accuracy: 73.0/260 (28%)
#
#
# Average loss: 1.5001, Accuracy: 824.0/2940 (28%)
#
# Epoch: 7 	Training Accuracy: 28.08%
# Validation Accuracy: 28.03%
# Batch: 0, Loss: 1.4986066818237305
#
# Average loss: 1.4659, Accuracy: 98.0/260 (38%)
#
#
# Average loss: 1.4701, Accuracy: 1156.0/2940 (39%)
#
# Epoch: 8 	Training Accuracy: 37.69%
# Validation Accuracy: 39.32%
# Batch: 0, Loss: 1.4245356321334839
#
# Average loss: 1.4322, Accuracy: 125.0/260 (48%)
#
#
# Average loss: 1.4382, Accuracy: 1385.0/2940 (47%)
#
# Epoch: 9 	Training Accuracy: 48.08%
# Validation Accuracy: 47.11%
# Batch: 0, Loss: 1.4561352729797363
#
# Average loss: 1.3728, Accuracy: 124.0/260 (48%)
#
#
# Average loss: 1.3786, Accuracy: 1483.0/2940 (50%)
#
# Epoch: 10 	Training Accuracy: 47.69%
# Validation Accuracy: 50.44%
# Early stopping invoked.
#
# Average loss: 1.5440, Accuracy: 152.0/260 (58%)
#
#
# Average loss: 1.5463, Accuracy: 2708.0/4861 (56%)
#
# Final Training Accuracy (New Data): 0.5846
# Final Test Accuracy (New Data): 0.5571
# Training for data percentage: 0.03:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 76 =========================
# Batch: 0, Loss: 1.605858325958252
#
# Average loss: 1.5699, Accuracy: 466.0/790 (59%)
#
#
# Average loss: 1.5733, Accuracy: 1696.0/2940 (58%)
#
# Epoch: 0 	Training Accuracy: 58.99%
# Validation Accuracy: 57.69%
# Batch: 0, Loss: 1.5708907842636108
#
# Average loss: 1.4672, Accuracy: 596.0/790 (75%)
#
#
# Average loss: 1.4756, Accuracy: 2151.0/2940 (73%)
#
# Epoch: 1 	Training Accuracy: 75.44%
# Validation Accuracy: 73.16%
# Batch: 0, Loss: 1.4625141620635986
#
# Average loss: 1.2580, Accuracy: 623.0/790 (79%)
#
#
# Average loss: 1.2703, Accuracy: 2280.0/2940 (78%)
#
# Epoch: 2 	Training Accuracy: 78.86%
# Validation Accuracy: 77.55%
# Batch: 0, Loss: 1.271803855895996
#
# Average loss: 0.9548, Accuracy: 617.0/790 (78%)
#
#
# Average loss: 0.9694, Accuracy: 2280.0/2940 (78%)
#
# Epoch: 3 	Training Accuracy: 78.10%
# Validation Accuracy: 77.55%
# Batch: 0, Loss: 0.9290869235992432
#
# Average loss: 0.6967, Accuracy: 628.0/790 (79%)
#
#
# Average loss: 0.7053, Accuracy: 2330.0/2940 (79%)
#
# Epoch: 4 	Training Accuracy: 79.49%
# Validation Accuracy: 79.25%
# Batch: 0, Loss: 0.626916229724884
#
# Average loss: 0.5586, Accuracy: 642.0/790 (81%)
#
#
# Average loss: 0.5682, Accuracy: 2410.0/2940 (82%)
#
# Epoch: 5 	Training Accuracy: 81.27%
# Validation Accuracy: 81.97%
# Batch: 0, Loss: 0.5765042901039124
#
# Average loss: 0.4822, Accuracy: 660.0/790 (84%)
#
#
# Average loss: 0.4997, Accuracy: 2464.0/2940 (84%)
#
# Epoch: 6 	Training Accuracy: 83.54%
# Validation Accuracy: 83.81%
# Batch: 0, Loss: 0.431951105594635
#
# Average loss: 0.4282, Accuracy: 675.0/790 (85%)
#
#
# Average loss: 0.4570, Accuracy: 2517.0/2940 (86%)
#
# Epoch: 7 	Training Accuracy: 85.44%
# Validation Accuracy: 85.61%
# Batch: 0, Loss: 0.4761378765106201
#
# Average loss: 0.3882, Accuracy: 693.0/790 (88%)
#
#
# Average loss: 0.4279, Accuracy: 2562.0/2940 (87%)
#
# Epoch: 8 	Training Accuracy: 87.72%
# Validation Accuracy: 87.14%
# Batch: 0, Loss: 0.34100833535194397
#
# Average loss: 0.3581, Accuracy: 705.0/790 (89%)
#
#
# Average loss: 0.4094, Accuracy: 2575.0/2940 (88%)
#
# Epoch: 9 	Training Accuracy: 89.24%
# Validation Accuracy: 87.59%
# Batch: 0, Loss: 0.33314475417137146
#
# Average loss: 0.3342, Accuracy: 707.0/790 (89%)
#
#
# Average loss: 0.3976, Accuracy: 2574.0/2940 (88%)
#
# Epoch: 10 	Training Accuracy: 89.49%
# Validation Accuracy: 87.55%
# Batch: 0, Loss: 0.2958310842514038
#
# Average loss: 0.3127, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.3844, Accuracy: 2590.0/2940 (88%)
#
# Epoch: 11 	Training Accuracy: 90.38%
# Validation Accuracy: 88.10%
# Batch: 0, Loss: 0.479549765586853
#
# Average loss: 0.2941, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.3768, Accuracy: 2597.0/2940 (88%)
#
# Epoch: 12 	Training Accuracy: 90.76%
# Validation Accuracy: 88.33%
# Batch: 0, Loss: 0.37067827582359314
#
# Average loss: 0.2780, Accuracy: 721.0/790 (91%)
#
#
# Average loss: 0.3678, Accuracy: 2593.0/2940 (88%)
#
# Epoch: 13 	Training Accuracy: 91.27%
# Validation Accuracy: 88.20%
# Batch: 0, Loss: 0.29177433252334595
#
# Average loss: 0.2627, Accuracy: 730.0/790 (92%)
#
#
# Average loss: 0.3611, Accuracy: 2606.0/2940 (89%)
#
# Epoch: 14 	Training Accuracy: 92.41%
# Validation Accuracy: 88.64%
# Batch: 0, Loss: 0.32506346702575684
#
# Average loss: 0.2493, Accuracy: 731.0/790 (93%)
#
#
# Average loss: 0.3523, Accuracy: 2606.0/2940 (89%)
#
# Epoch: 15 	Training Accuracy: 92.53%
# Validation Accuracy: 88.64%
# Batch: 0, Loss: 0.24555544555187225
#
# Average loss: 0.2381, Accuracy: 731.0/790 (93%)
#
#
# Average loss: 0.3448, Accuracy: 2612.0/2940 (89%)
#
# Epoch: 16 	Training Accuracy: 92.53%
# Validation Accuracy: 88.84%
# Batch: 0, Loss: 0.2770041823387146
#
# Average loss: 0.2273, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.3389, Accuracy: 2621.0/2940 (89%)
#
# Epoch: 17 	Training Accuracy: 93.42%
# Validation Accuracy: 89.15%
# Batch: 0, Loss: 0.2111240029335022
#
# Average loss: 0.2142, Accuracy: 742.0/790 (94%)
#
#
# Average loss: 0.3318, Accuracy: 2627.0/2940 (89%)
#
# Epoch: 18 	Training Accuracy: 93.92%
# Validation Accuracy: 89.35%
# Batch: 0, Loss: 0.31465086340904236
#
# Average loss: 0.2121, Accuracy: 735.0/790 (93%)
#
#
# Average loss: 0.3352, Accuracy: 2615.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 93.04%
# Validation Accuracy: 88.95%
#
# Average loss: 0.2121, Accuracy: 735.0/790 (93%)
#
#
# Average loss: 0.3224, Accuracy: 4319.0/4861 (89%)
#
# Final Training Accuracy (New Data): 0.9304
# Final Test Accuracy (New Data): 0.8885
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 57 =========================
# Batch: 0, Loss: 1.6169837713241577
#
# Average loss: 1.6077, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6078, Accuracy: 585.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6108256578445435
#
# Average loss: 1.5972, Accuracy: 163.0/790 (21%)
#
#
# Average loss: 1.5988, Accuracy: 600.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.63%
# Validation Accuracy: 20.41%
# Batch: 0, Loss: 1.5950658321380615
#
# Average loss: 1.5629, Accuracy: 526.0/790 (67%)
#
#
# Average loss: 1.5675, Accuracy: 1840.0/2940 (63%)
#
# Epoch: 2 	Training Accuracy: 66.58%
# Validation Accuracy: 62.59%
# Batch: 0, Loss: 1.5618293285369873
#
# Average loss: 1.4692, Accuracy: 557.0/790 (71%)
#
#
# Average loss: 1.4795, Accuracy: 1910.0/2940 (65%)
#
# Epoch: 3 	Training Accuracy: 70.51%
# Validation Accuracy: 64.97%
# Batch: 0, Loss: 1.4763602018356323
#
# Average loss: 1.2842, Accuracy: 519.0/790 (66%)
#
#
# Average loss: 1.3042, Accuracy: 1805.0/2940 (61%)
#
# Epoch: 4 	Training Accuracy: 65.70%
# Validation Accuracy: 61.39%
# Batch: 0, Loss: 1.278235673904419
#
# Average loss: 1.0027, Accuracy: 579.0/790 (73%)
#
#
# Average loss: 1.0299, Accuracy: 2094.0/2940 (71%)
#
# Epoch: 5 	Training Accuracy: 73.29%
# Validation Accuracy: 71.22%
# Batch: 0, Loss: 1.0666446685791016
#
# Average loss: 0.7236, Accuracy: 614.0/790 (78%)
#
#
# Average loss: 0.7607, Accuracy: 2277.0/2940 (77%)
#
# Epoch: 6 	Training Accuracy: 77.72%
# Validation Accuracy: 77.45%
# Batch: 0, Loss: 0.7255683541297913
#
# Average loss: 0.5512, Accuracy: 635.0/790 (80%)
#
#
# Average loss: 0.5991, Accuracy: 2378.0/2940 (81%)
#
# Epoch: 7 	Training Accuracy: 80.38%
# Validation Accuracy: 80.88%
# Batch: 0, Loss: 0.6533480882644653
#
# Average loss: 0.4664, Accuracy: 657.0/790 (83%)
#
#
# Average loss: 0.5258, Accuracy: 2418.0/2940 (82%)
#
# Epoch: 8 	Training Accuracy: 83.16%
# Validation Accuracy: 82.24%
# Batch: 0, Loss: 0.48413369059562683
#
# Average loss: 0.4070, Accuracy: 672.0/790 (85%)
#
#
# Average loss: 0.4764, Accuracy: 2465.0/2940 (84%)
#
# Epoch: 9 	Training Accuracy: 85.06%
# Validation Accuracy: 83.84%
# Batch: 0, Loss: 0.42401134967803955
#
# Average loss: 0.3499, Accuracy: 690.0/790 (87%)
#
#
# Average loss: 0.4228, Accuracy: 2529.0/2940 (86%)
#
# Epoch: 10 	Training Accuracy: 87.34%
# Validation Accuracy: 86.02%
# Batch: 0, Loss: 0.3813568949699402
#
# Average loss: 0.3108, Accuracy: 704.0/790 (89%)
#
#
# Average loss: 0.3958, Accuracy: 2549.0/2940 (87%)
#
# Epoch: 11 	Training Accuracy: 89.11%
# Validation Accuracy: 86.70%
# Batch: 0, Loss: 0.34967416524887085
#
# Average loss: 0.2774, Accuracy: 705.0/790 (89%)
#
#
# Average loss: 0.3770, Accuracy: 2590.0/2940 (88%)
#
# Epoch: 12 	Training Accuracy: 89.24%
# Validation Accuracy: 88.10%
# Batch: 0, Loss: 0.2252911627292633
#
# Average loss: 0.2509, Accuracy: 713.0/790 (90%)
#
#
# Average loss: 0.3624, Accuracy: 2598.0/2940 (88%)
#
# Epoch: 13 	Training Accuracy: 90.25%
# Validation Accuracy: 88.37%
# Batch: 0, Loss: 0.22403369843959808
#
# Average loss: 0.2293, Accuracy: 718.0/790 (91%)
#
#
# Average loss: 0.3510, Accuracy: 2614.0/2940 (89%)
#
# Epoch: 14 	Training Accuracy: 90.89%
# Validation Accuracy: 88.91%
# Batch: 0, Loss: 0.2194495052099228
#
# Average loss: 0.2144, Accuracy: 727.0/790 (92%)
#
#
# Average loss: 0.3419, Accuracy: 2607.0/2940 (89%)
#
# Epoch: 15 	Training Accuracy: 92.03%
# Validation Accuracy: 88.67%
# Batch: 0, Loss: 0.2543133497238159
#
# Average loss: 0.1983, Accuracy: 735.0/790 (93%)
#
#
# Average loss: 0.3332, Accuracy: 2629.0/2940 (89%)
#
# Epoch: 16 	Training Accuracy: 93.04%
# Validation Accuracy: 89.42%
# Batch: 0, Loss: 0.1717327982187271
#
# Average loss: 0.1821, Accuracy: 741.0/790 (94%)
#
#
# Average loss: 0.3213, Accuracy: 2634.0/2940 (90%)
#
# Epoch: 17 	Training Accuracy: 93.80%
# Validation Accuracy: 89.59%
# Batch: 0, Loss: 0.1503782570362091
#
# Average loss: 0.1703, Accuracy: 748.0/790 (95%)
#
#
# Average loss: 0.3148, Accuracy: 2654.0/2940 (90%)
#
# Epoch: 18 	Training Accuracy: 94.68%
# Validation Accuracy: 90.27%
# Batch: 0, Loss: 0.22467398643493652
#
# Average loss: 0.1597, Accuracy: 747.0/790 (95%)
#
#
# Average loss: 0.3088, Accuracy: 2657.0/2940 (90%)
#
# Epoch: 19 	Training Accuracy: 94.56%
# Validation Accuracy: 90.37%
#
# Average loss: 0.1597, Accuracy: 747.0/790 (95%)
#
#
# Average loss: 0.3043, Accuracy: 4397.0/4861 (90%)
#
# Final Training Accuracy (New Data): 0.9456
# Final Test Accuracy (New Data): 0.9045
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 67 =========================
# Batch: 0, Loss: 1.610611915588379
#
# Average loss: 1.5987, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6008, Accuracy: 585.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.597214937210083
#
# Average loss: 1.5550, Accuracy: 630.0/790 (80%)
#
#
# Average loss: 1.5609, Accuracy: 2222.0/2940 (76%)
#
# Epoch: 1 	Training Accuracy: 79.75%
# Validation Accuracy: 75.58%
# Batch: 0, Loss: 1.5574342012405396
#
# Average loss: 1.4147, Accuracy: 647.0/790 (82%)
#
#
# Average loss: 1.4295, Accuracy: 2304.0/2940 (78%)
#
# Epoch: 2 	Training Accuracy: 81.90%
# Validation Accuracy: 78.37%
# Batch: 0, Loss: 1.410000205039978
#
# Average loss: 1.1150, Accuracy: 646.0/790 (82%)
#
#
# Average loss: 1.1405, Accuracy: 2278.0/2940 (77%)
#
# Epoch: 3 	Training Accuracy: 81.77%
# Validation Accuracy: 77.48%
# Batch: 0, Loss: 1.122656226158142
#
# Average loss: 0.7571, Accuracy: 654.0/790 (83%)
#
#
# Average loss: 0.7984, Accuracy: 2329.0/2940 (79%)
#
# Epoch: 4 	Training Accuracy: 82.78%
# Validation Accuracy: 79.22%
# Batch: 0, Loss: 0.6935291886329651
#
# Average loss: 0.5340, Accuracy: 661.0/790 (84%)
#
#
# Average loss: 0.6039, Accuracy: 2363.0/2940 (80%)
#
# Epoch: 5 	Training Accuracy: 83.67%
# Validation Accuracy: 80.37%
# Batch: 0, Loss: 0.5764669179916382
#
# Average loss: 0.4260, Accuracy: 677.0/790 (86%)
#
#
# Average loss: 0.5182, Accuracy: 2410.0/2940 (82%)
#
# Epoch: 6 	Training Accuracy: 85.70%
# Validation Accuracy: 81.97%
# Batch: 0, Loss: 0.27539747953414917
#
# Average loss: 0.3805, Accuracy: 684.0/790 (87%)
#
#
# Average loss: 0.4863, Accuracy: 2438.0/2940 (83%)
#
# Epoch: 7 	Training Accuracy: 86.58%
# Validation Accuracy: 82.93%
# Batch: 0, Loss: 0.3821047842502594
#
# Average loss: 0.3283, Accuracy: 696.0/790 (88%)
#
#
# Average loss: 0.4429, Accuracy: 2507.0/2940 (85%)
#
# Epoch: 8 	Training Accuracy: 88.10%
# Validation Accuracy: 85.27%
# Batch: 0, Loss: 0.3633372485637665
#
# Average loss: 0.3018, Accuracy: 700.0/790 (89%)
#
#
# Average loss: 0.4233, Accuracy: 2521.0/2940 (86%)
#
# Epoch: 9 	Training Accuracy: 88.61%
# Validation Accuracy: 85.75%
# Batch: 0, Loss: 0.23780477046966553
#
# Average loss: 0.2852, Accuracy: 707.0/790 (89%)
#
#
# Average loss: 0.4119, Accuracy: 2541.0/2940 (86%)
#
# Epoch: 10 	Training Accuracy: 89.49%
# Validation Accuracy: 86.43%
# Batch: 0, Loss: 0.3155229985713959
#
# Average loss: 0.2704, Accuracy: 711.0/790 (90%)
#
#
# Average loss: 0.4132, Accuracy: 2549.0/2940 (87%)
#
# Epoch: 11 	Training Accuracy: 90.00%
# Validation Accuracy: 86.70%
# Batch: 0, Loss: 0.29430729150772095
#
# Average loss: 0.2479, Accuracy: 718.0/790 (91%)
#
#
# Average loss: 0.3995, Accuracy: 2557.0/2940 (87%)
#
# Epoch: 12 	Training Accuracy: 90.89%
# Validation Accuracy: 86.97%
# Batch: 0, Loss: 0.18171164393424988
#
# Average loss: 0.2281, Accuracy: 730.0/790 (92%)
#
#
# Average loss: 0.3878, Accuracy: 2580.0/2940 (88%)
#
# Epoch: 13 	Training Accuracy: 92.41%
# Validation Accuracy: 87.76%
# Batch: 0, Loss: 0.19557812809944153
#
# Average loss: 0.2163, Accuracy: 732.0/790 (93%)
#
#
# Average loss: 0.3774, Accuracy: 2589.0/2940 (88%)
#
# Epoch: 14 	Training Accuracy: 92.66%
# Validation Accuracy: 88.06%
# Batch: 0, Loss: 0.23175743222236633
#
# Average loss: 0.2014, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.3758, Accuracy: 2595.0/2940 (88%)
#
# Epoch: 15 	Training Accuracy: 93.16%
# Validation Accuracy: 88.27%
# Batch: 0, Loss: 0.16040156781673431
#
# Average loss: 0.1897, Accuracy: 739.0/790 (94%)
#
#
# Average loss: 0.3749, Accuracy: 2594.0/2940 (88%)
#
# Epoch: 16 	Training Accuracy: 93.54%
# Validation Accuracy: 88.23%
# Batch: 0, Loss: 0.18454499542713165
#
# Average loss: 0.1803, Accuracy: 746.0/790 (94%)
#
#
# Average loss: 0.3703, Accuracy: 2603.0/2940 (89%)
#
# Epoch: 17 	Training Accuracy: 94.43%
# Validation Accuracy: 88.54%
# Batch: 0, Loss: 0.20501892268657684
#
# Average loss: 0.1734, Accuracy: 742.0/790 (94%)
#
#
# Average loss: 0.3746, Accuracy: 2606.0/2940 (89%)
#
# Epoch: 18 	Training Accuracy: 93.92%
# Validation Accuracy: 88.64%
# Batch: 0, Loss: 0.21868592500686646
#
# Average loss: 0.1608, Accuracy: 751.0/790 (95%)
#
#
# Average loss: 0.3671, Accuracy: 2610.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 95.06%
# Validation Accuracy: 88.78%
#
# Average loss: 0.1608, Accuracy: 751.0/790 (95%)
#
#
# Average loss: 0.3566, Accuracy: 4362.0/4861 (90%)
#
# Final Training Accuracy (New Data): 0.9506
# Final Test Accuracy (New Data): 0.8973
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 88 =========================
# Batch: 0, Loss: 1.6129659414291382
#
# Average loss: 1.6094, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6093, Accuracy: 655.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6095932722091675
#
# Average loss: 1.6074, Accuracy: 177.0/790 (22%)
#
#
# Average loss: 1.6082, Accuracy: 571.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 22.41%
# Validation Accuracy: 19.42%
# Batch: 0, Loss: 1.6057722568511963
#
# Average loss: 1.5849, Accuracy: 165.0/790 (21%)
#
#
# Average loss: 1.5883, Accuracy: 577.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.89%
# Validation Accuracy: 19.63%
# Batch: 0, Loss: 1.5841902494430542
#
# Average loss: 1.4446, Accuracy: 337.0/790 (43%)
#
#
# Average loss: 1.4365, Accuracy: 1271.0/2940 (43%)
#
# Epoch: 3 	Training Accuracy: 42.66%
# Validation Accuracy: 43.23%
# Batch: 0, Loss: 1.4450969696044922
#
# Average loss: 1.0318, Accuracy: 526.0/790 (67%)
#
#
# Average loss: 1.0399, Accuracy: 1939.0/2940 (66%)
#
# Epoch: 4 	Training Accuracy: 66.58%
# Validation Accuracy: 65.95%
# Batch: 0, Loss: 1.0486366748809814
#
# Average loss: 0.7076, Accuracy: 589.0/790 (75%)
#
#
# Average loss: 0.7378, Accuracy: 2158.0/2940 (73%)
#
# Epoch: 5 	Training Accuracy: 74.56%
# Validation Accuracy: 73.40%
# Batch: 0, Loss: 0.7110806107521057
#
# Average loss: 0.4910, Accuracy: 651.0/790 (82%)
#
#
# Average loss: 0.5209, Accuracy: 2359.0/2940 (80%)
#
# Epoch: 6 	Training Accuracy: 82.41%
# Validation Accuracy: 80.24%
# Batch: 0, Loss: 0.49874937534332275
#
# Average loss: 0.3468, Accuracy: 694.0/790 (88%)
#
#
# Average loss: 0.4004, Accuracy: 2531.0/2940 (86%)
#
# Epoch: 7 	Training Accuracy: 87.85%
# Validation Accuracy: 86.09%
# Batch: 0, Loss: 0.2693609893321991
#
# Average loss: 0.3483, Accuracy: 701.0/790 (89%)
#
#
# Average loss: 0.4074, Accuracy: 2532.0/2940 (86%)
#
# Epoch: 8 	Training Accuracy: 88.73%
# Validation Accuracy: 86.12%
# Batch: 0, Loss: 0.40849024057388306
#
# Average loss: 0.2881, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.3594, Accuracy: 2573.0/2940 (88%)
#
# Epoch: 9 	Training Accuracy: 90.38%
# Validation Accuracy: 87.52%
# Batch: 0, Loss: 0.3143276572227478
#
# Average loss: 0.2935, Accuracy: 715.0/790 (91%)
#
#
# Average loss: 0.3670, Accuracy: 2583.0/2940 (88%)
#
# Epoch: 10 	Training Accuracy: 90.51%
# Validation Accuracy: 87.86%
# Batch: 0, Loss: 0.37557506561279297
#
# Average loss: 0.2722, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.3541, Accuracy: 2591.0/2940 (88%)
#
# Epoch: 11 	Training Accuracy: 91.39%
# Validation Accuracy: 88.13%
# Batch: 0, Loss: 0.23855642974376678
#
# Average loss: 0.2992, Accuracy: 707.0/790 (89%)
#
#
# Average loss: 0.3794, Accuracy: 2556.0/2940 (87%)
#
# Epoch: 12 	Training Accuracy: 89.49%
# Validation Accuracy: 86.94%
# Batch: 0, Loss: 0.3838270306587219
#
# Average loss: 0.2320, Accuracy: 723.0/790 (92%)
#
#
# Average loss: 0.3093, Accuracy: 2650.0/2940 (90%)
#
# Epoch: 13 	Training Accuracy: 91.52%
# Validation Accuracy: 90.14%
# Batch: 0, Loss: 0.2644812762737274
#
# Average loss: 0.2288, Accuracy: 729.0/790 (92%)
#
#
# Average loss: 0.3182, Accuracy: 2624.0/2940 (89%)
#
# Epoch: 14 	Training Accuracy: 92.28%
# Validation Accuracy: 89.25%
# Batch: 0, Loss: 0.19387921690940857
#
# Average loss: 0.2198, Accuracy: 733.0/790 (93%)
#
#
# Average loss: 0.2949, Accuracy: 2649.0/2940 (90%)
#
# Epoch: 15 	Training Accuracy: 92.78%
# Validation Accuracy: 90.10%
# Batch: 0, Loss: 0.24643126130104065
#
# Average loss: 0.2124, Accuracy: 731.0/790 (93%)
#
#
# Average loss: 0.3053, Accuracy: 2640.0/2940 (90%)
#
# Epoch: 16 	Training Accuracy: 92.53%
# Validation Accuracy: 89.80%
# Batch: 0, Loss: 0.178031787276268
#
# Average loss: 0.2086, Accuracy: 734.0/790 (93%)
#
#
# Average loss: 0.2881, Accuracy: 2659.0/2940 (90%)
#
# Epoch: 17 	Training Accuracy: 92.91%
# Validation Accuracy: 90.44%
# Batch: 0, Loss: 0.1573442667722702
#
# Average loss: 0.2039, Accuracy: 734.0/790 (93%)
#
#
# Average loss: 0.3016, Accuracy: 2640.0/2940 (90%)
#
# Epoch: 18 	Training Accuracy: 92.91%
# Validation Accuracy: 89.80%
# Batch: 0, Loss: 0.205754354596138
#
# Average loss: 0.2012, Accuracy: 740.0/790 (94%)
#
#
# Average loss: 0.2978, Accuracy: 2657.0/2940 (90%)
#
# Epoch: 19 	Training Accuracy: 93.67%
# Validation Accuracy: 90.37%
#
# Average loss: 0.2012, Accuracy: 740.0/790 (94%)
#
#
# Average loss: 0.2896, Accuracy: 4402.0/4861 (91%)
#
# Final Training Accuracy (New Data): 0.9367
# Final Test Accuracy (New Data): 0.9056
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 100 =========================
# Batch: 0, Loss: 1.6084284782409668
#
# Average loss: 1.6010, Accuracy: 287.0/790 (36%)
#
#
# Average loss: 1.6009, Accuracy: 1036.0/2940 (35%)
#
# Epoch: 0 	Training Accuracy: 36.33%
# Validation Accuracy: 35.24%
# Batch: 0, Loss: 1.5958014726638794
#
# Average loss: 1.5527, Accuracy: 442.0/790 (56%)
#
#
# Average loss: 1.5533, Accuracy: 1628.0/2940 (55%)
#
# Epoch: 1 	Training Accuracy: 55.95%
# Validation Accuracy: 55.37%
# Batch: 0, Loss: 1.546555757522583
#
# Average loss: 1.4025, Accuracy: 509.0/790 (64%)
#
#
# Average loss: 1.4039, Accuracy: 1875.0/2940 (64%)
#
# Epoch: 2 	Training Accuracy: 64.43%
# Validation Accuracy: 63.78%
# Batch: 0, Loss: 1.3820823431015015
#
# Average loss: 1.1094, Accuracy: 515.0/790 (65%)
#
#
# Average loss: 1.1106, Accuracy: 1904.0/2940 (65%)
#
# Epoch: 3 	Training Accuracy: 65.19%
# Validation Accuracy: 64.76%
# Batch: 0, Loss: 1.065682291984558
#
# Average loss: 0.8122, Accuracy: 569.0/790 (72%)
#
#
# Average loss: 0.8230, Accuracy: 2044.0/2940 (70%)
#
# Epoch: 4 	Training Accuracy: 72.03%
# Validation Accuracy: 69.52%
# Batch: 0, Loss: 0.8167938590049744
#
# Average loss: 0.5884, Accuracy: 644.0/790 (82%)
#
#
# Average loss: 0.6133, Accuracy: 2370.0/2940 (81%)
#
# Epoch: 5 	Training Accuracy: 81.52%
# Validation Accuracy: 80.61%
# Batch: 0, Loss: 0.6643615961074829
#
# Average loss: 0.4757, Accuracy: 664.0/790 (84%)
#
#
# Average loss: 0.5020, Accuracy: 2460.0/2940 (84%)
#
# Epoch: 6 	Training Accuracy: 84.05%
# Validation Accuracy: 83.67%
# Batch: 0, Loss: 0.4573025703430176
#
# Average loss: 0.3957, Accuracy: 687.0/790 (87%)
#
#
# Average loss: 0.4226, Accuracy: 2520.0/2940 (86%)
#
# Epoch: 7 	Training Accuracy: 86.96%
# Validation Accuracy: 85.71%
# Batch: 0, Loss: 0.39470621943473816
#
# Average loss: 0.3413, Accuracy: 700.0/790 (89%)
#
#
# Average loss: 0.3733, Accuracy: 2581.0/2940 (88%)
#
# Epoch: 8 	Training Accuracy: 88.61%
# Validation Accuracy: 87.79%
# Batch: 0, Loss: 0.3110957145690918
#
# Average loss: 0.3045, Accuracy: 706.0/790 (89%)
#
#
# Average loss: 0.3456, Accuracy: 2608.0/2940 (89%)
#
# Epoch: 9 	Training Accuracy: 89.37%
# Validation Accuracy: 88.71%
# Batch: 0, Loss: 0.31254690885543823
#
# Average loss: 0.2827, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.3250, Accuracy: 2622.0/2940 (89%)
#
# Epoch: 10 	Training Accuracy: 90.38%
# Validation Accuracy: 89.18%
# Batch: 0, Loss: 0.2614350914955139
#
# Average loss: 0.2578, Accuracy: 726.0/790 (92%)
#
#
# Average loss: 0.3063, Accuracy: 2634.0/2940 (90%)
#
# Epoch: 11 	Training Accuracy: 91.90%
# Validation Accuracy: 89.59%
# Batch: 0, Loss: 0.3237742483615875
#
# Average loss: 0.2338, Accuracy: 720.0/790 (91%)
#
#
# Average loss: 0.2909, Accuracy: 2663.0/2940 (91%)
#
# Epoch: 12 	Training Accuracy: 91.14%
# Validation Accuracy: 90.58%
# Batch: 0, Loss: 0.19332626461982727
#
# Average loss: 0.2218, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.2851, Accuracy: 2672.0/2940 (91%)
#
# Epoch: 13 	Training Accuracy: 92.15%
# Validation Accuracy: 90.88%
# Batch: 0, Loss: 0.25255531072616577
#
# Average loss: 0.2127, Accuracy: 730.0/790 (92%)
#
#
# Average loss: 0.2822, Accuracy: 2659.0/2940 (90%)
#
# Epoch: 14 	Training Accuracy: 92.41%
# Validation Accuracy: 90.44%
# Batch: 0, Loss: 0.2011331468820572
#
# Average loss: 0.1959, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.2701, Accuracy: 2686.0/2940 (91%)
#
# Epoch: 15 	Training Accuracy: 93.16%
# Validation Accuracy: 91.36%
# Batch: 0, Loss: 0.15923286974430084
#
# Average loss: 0.1800, Accuracy: 741.0/790 (94%)
#
#
# Average loss: 0.2582, Accuracy: 2702.0/2940 (92%)
#
# Epoch: 16 	Training Accuracy: 93.80%
# Validation Accuracy: 91.90%
# Batch: 0, Loss: 0.19147871434688568
#
# Average loss: 0.1712, Accuracy: 742.0/790 (94%)
#
#
# Average loss: 0.2556, Accuracy: 2699.0/2940 (92%)
#
# Epoch: 17 	Training Accuracy: 93.92%
# Validation Accuracy: 91.80%
# Batch: 0, Loss: 0.1589299440383911
#
# Average loss: 0.1615, Accuracy: 747.0/790 (95%)
#
#
# Average loss: 0.2519, Accuracy: 2707.0/2940 (92%)
#
# Epoch: 18 	Training Accuracy: 94.56%
# Validation Accuracy: 92.07%
# Batch: 0, Loss: 0.16816723346710205
#
# Average loss: 0.1536, Accuracy: 749.0/790 (95%)
#
#
# Average loss: 0.2526, Accuracy: 2703.0/2940 (92%)
#
# Epoch: 19 	Training Accuracy: 94.81%
# Validation Accuracy: 91.94%
#
# Average loss: 0.1536, Accuracy: 749.0/790 (95%)
#
#
# Average loss: 0.2460, Accuracy: 4441.0/4861 (91%)
#
# Final Training Accuracy (New Data): 0.9481
# Final Test Accuracy (New Data): 0.9136
# Training for data percentage: 0.05:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 1 =========================
# Batch: 0, Loss: 1.6112076044082642
#
# Average loss: 1.5852, Accuracy: 473.0/1320 (36%)
#
#
# Average loss: 1.5855, Accuracy: 1084.0/2940 (37%)
#
# Epoch: 0 	Training Accuracy: 35.83%
# Validation Accuracy: 36.87%
# Batch: 0, Loss: 1.5849957466125488
#
# Average loss: 1.4650, Accuracy: 830.0/1320 (63%)
#
#
# Average loss: 1.4733, Accuracy: 1760.0/2940 (60%)
#
# Epoch: 1 	Training Accuracy: 62.88%
# Validation Accuracy: 59.86%
# Batch: 0, Loss: 1.4820582866668701
#
# Average loss: 1.0946, Accuracy: 930.0/1320 (70%)
#
#
# Average loss: 1.1125, Accuracy: 2048.0/2940 (70%)
#
# Epoch: 2 	Training Accuracy: 70.45%
# Validation Accuracy: 69.66%
# Batch: 0, Loss: 1.0996798276901245
#
# Average loss: 0.5820, Accuracy: 1120.0/1320 (85%)
#
#
# Average loss: 0.5895, Accuracy: 2482.0/2940 (84%)
#
# Epoch: 3 	Training Accuracy: 84.85%
# Validation Accuracy: 84.42%
# Batch: 0, Loss: 0.5728371739387512
#
# Average loss: 0.3925, Accuracy: 1154.0/1320 (87%)
#
#
# Average loss: 0.4239, Accuracy: 2561.0/2940 (87%)
#
# Epoch: 4 	Training Accuracy: 87.42%
# Validation Accuracy: 87.11%
# Batch: 0, Loss: 0.553673267364502
#
# Average loss: 0.3211, Accuracy: 1170.0/1320 (89%)
#
#
# Average loss: 0.3771, Accuracy: 2613.0/2940 (89%)
#
# Epoch: 5 	Training Accuracy: 88.64%
# Validation Accuracy: 88.88%
# Batch: 0, Loss: 0.40510979294776917
#
# Average loss: 0.2940, Accuracy: 1198.0/1320 (91%)
#
#
# Average loss: 0.3589, Accuracy: 2636.0/2940 (90%)
#
# Epoch: 6 	Training Accuracy: 90.76%
# Validation Accuracy: 89.66%
# Batch: 0, Loss: 0.3506483733654022
#
# Average loss: 0.2513, Accuracy: 1213.0/1320 (92%)
#
#
# Average loss: 0.3239, Accuracy: 2654.0/2940 (90%)
#
# Epoch: 7 	Training Accuracy: 91.89%
# Validation Accuracy: 90.27%
# Batch: 0, Loss: 0.22544685006141663
#
# Average loss: 0.2313, Accuracy: 1229.0/1320 (93%)
#
#
# Average loss: 0.3096, Accuracy: 2667.0/2940 (91%)
#
# Epoch: 8 	Training Accuracy: 93.11%
# Validation Accuracy: 90.71%
# Batch: 0, Loss: 0.16970431804656982
#
# Average loss: 0.2216, Accuracy: 1228.0/1320 (93%)
#
#
# Average loss: 0.3105, Accuracy: 2649.0/2940 (90%)
#
# Epoch: 9 	Training Accuracy: 93.03%
# Validation Accuracy: 90.10%
# Batch: 0, Loss: 0.32410889863967896
#
# Average loss: 0.2089, Accuracy: 1230.0/1320 (93%)
#
#
# Average loss: 0.3090, Accuracy: 2653.0/2940 (90%)
#
# Epoch: 10 	Training Accuracy: 93.18%
# Validation Accuracy: 90.24%
# Batch: 0, Loss: 0.25309351086616516
#
# Average loss: 0.1953, Accuracy: 1249.0/1320 (95%)
#
#
# Average loss: 0.2956, Accuracy: 2679.0/2940 (91%)
#
# Epoch: 11 	Training Accuracy: 94.62%
# Validation Accuracy: 91.12%
# Batch: 0, Loss: 0.15868887305259705
#
# Average loss: 0.1762, Accuracy: 1253.0/1320 (95%)
#
#
# Average loss: 0.2880, Accuracy: 2672.0/2940 (91%)
#
# Epoch: 12 	Training Accuracy: 94.92%
# Validation Accuracy: 90.88%
# Batch: 0, Loss: 0.15426090359687805
#
# Average loss: 0.1761, Accuracy: 1251.0/1320 (95%)
#
#
# Average loss: 0.2990, Accuracy: 2666.0/2940 (91%)
#
# Epoch: 13 	Training Accuracy: 94.77%
# Validation Accuracy: 90.68%
# Batch: 0, Loss: 0.16324542462825775
#
# Average loss: 0.1617, Accuracy: 1258.0/1320 (95%)
#
#
# Average loss: 0.2879, Accuracy: 2671.0/2940 (91%)
#
# Epoch: 14 	Training Accuracy: 95.30%
# Validation Accuracy: 90.85%
# Batch: 0, Loss: 0.15895849466323853
#
# Average loss: 0.1506, Accuracy: 1266.0/1320 (96%)
#
#
# Average loss: 0.2887, Accuracy: 2668.0/2940 (91%)
#
# Epoch: 15 	Training Accuracy: 95.91%
# Validation Accuracy: 90.75%
# Batch: 0, Loss: 0.17160305380821228
#
# Average loss: 0.1410, Accuracy: 1273.0/1320 (96%)
#
#
# Average loss: 0.2803, Accuracy: 2679.0/2940 (91%)
#
# Epoch: 16 	Training Accuracy: 96.44%
# Validation Accuracy: 91.12%
# Batch: 0, Loss: 0.11988665908575058
#
# Average loss: 0.1568, Accuracy: 1251.0/1320 (95%)
#
#
# Average loss: 0.3078, Accuracy: 2653.0/2940 (90%)
#
# Epoch: 17 	Training Accuracy: 94.77%
# Validation Accuracy: 90.24%
# Early stopping invoked.
#
# Average loss: 0.1953, Accuracy: 1249.0/1320 (95%)
#
#
# Average loss: 0.3258, Accuracy: 4398.0/4861 (90%)
#
# Final Training Accuracy (New Data): 0.9462
# Final Test Accuracy (New Data): 0.9048
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 62 =========================
# Batch: 0, Loss: 1.6149358749389648
#
# Average loss: 1.3838, Accuracy: 921.0/1320 (70%)
#
#
# Average loss: 1.3850, Accuracy: 2019.0/2940 (69%)
#
# Epoch: 0 	Training Accuracy: 69.77%
# Validation Accuracy: 68.67%
# Batch: 0, Loss: 1.3852065801620483
#
# Average loss: 1.0325, Accuracy: 1069.0/1320 (81%)
#
#
# Average loss: 1.0257, Accuracy: 2389.0/2940 (81%)
#
# Epoch: 1 	Training Accuracy: 80.98%
# Validation Accuracy: 81.26%
# Batch: 0, Loss: 1.0374259948730469
#
# Average loss: 0.6602, Accuracy: 1099.0/1320 (83%)
#
#
# Average loss: 0.6575, Accuracy: 2448.0/2940 (83%)
#
# Epoch: 2 	Training Accuracy: 83.26%
# Validation Accuracy: 83.27%
# Batch: 0, Loss: 0.6563579440116882
#
# Average loss: 0.4528, Accuracy: 1137.0/1320 (86%)
#
#
# Average loss: 0.4686, Accuracy: 2499.0/2940 (85%)
#
# Epoch: 3 	Training Accuracy: 86.14%
# Validation Accuracy: 85.00%
# Batch: 0, Loss: 0.49739208817481995
#
# Average loss: 0.3764, Accuracy: 1165.0/1320 (88%)
#
#
# Average loss: 0.4151, Accuracy: 2546.0/2940 (87%)
#
# Epoch: 4 	Training Accuracy: 88.26%
# Validation Accuracy: 86.60%
# Batch: 0, Loss: 0.33490970730781555
#
# Average loss: 0.3111, Accuracy: 1176.0/1320 (89%)
#
#
# Average loss: 0.3566, Accuracy: 2596.0/2940 (88%)
#
# Epoch: 5 	Training Accuracy: 89.09%
# Validation Accuracy: 88.30%
# Batch: 0, Loss: 0.35686805844306946
#
# ...
# Batch: 180, Loss: 0.06276261806488037
# Batch: 200, Loss: 0.04565902799367905
#
# Average loss: 0.0635, Accuracy: 25522.0/26038 (98%)
#
#
# Average loss: 0.1013, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 17 	Training Accuracy: 98.02%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.025305667892098427
# Batch: 20, Loss: 0.04159962013363838
# Batch: 40, Loss: 0.05019647255539894
# Batch: 60, Loss: 0.024779081344604492
# Batch: 80, Loss: 0.08141758292913437
# Batch: 100, Loss: 0.0467776283621788
# Batch: 120, Loss: 0.08435741811990738
# Batch: 140, Loss: 0.12605062127113342
# Batch: 160, Loss: 0.026605922728776932
# Batch: 180, Loss: 0.10519073158502579
# Batch: 200, Loss: 0.060862742364406586
#
# Average loss: 0.0643, Accuracy: 25472.0/26038 (98%)
#
#
# Average loss: 0.1069, Accuracy: 2843.0/2940 (97%)
#
# Epoch: 18 	Training Accuracy: 97.83%
# Validation Accuracy: 96.70%
# Batch: 0, Loss: 0.06672053784132004
# Batch: 20, Loss: 0.1260940283536911
# Batch: 40, Loss: 0.05320551618933678
# Batch: 60, Loss: 0.09886994957923889
# Batch: 80, Loss: 0.10468169301748276
# Batch: 100, Loss: 0.03780915215611458
# Batch: 120, Loss: 0.11400571465492249
# Batch: 140, Loss: 0.06976300477981567
# Batch: 160, Loss: 0.05395800247788429
# Batch: 180, Loss: 0.03558598458766937
# Batch: 200, Loss: 0.012128062546253204
#
# Average loss: 0.0574, Accuracy: 25562.0/26038 (98%)
#
#
# Average loss: 0.0963, Accuracy: 2844.0/2940 (97%)
#
# Epoch: 19 	Training Accuracy: 98.17%
# Validation Accuracy: 96.73%
#
# Average loss: 0.0574, Accuracy: 25562.0/26038 (98%)
#
#
# Average loss: 0.0950, Accuracy: 4717.0/4861 (97%)
#
# Final Training Accuracy (New Data): 0.9817
# Final Test Accuracy (New Data): 0.9704
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 32 =========================
# Batch: 0, Loss: 1.6085184812545776
# Batch: 20, Loss: 1.4101073741912842
# Batch: 40, Loss: 0.5575510263442993
# Batch: 60, Loss: 0.3359542489051819
# Batch: 80, Loss: 0.18625520169734955
# Batch: 100, Loss: 0.200934499502182
# Batch: 120, Loss: 0.1806326061487198
# Batch: 140, Loss: 0.2434435933828354
# Batch: 160, Loss: 0.1660340279340744
# Batch: 180, Loss: 0.21109579503536224
# Batch: 200, Loss: 0.3785773813724518
#
# Average loss: 0.2052, Accuracy: 24320.0/26038 (93%)
#
#
# Average loss: 0.2240, Accuracy: 2738.0/2940 (93%)
#
# Epoch: 0 	Training Accuracy: 93.40%
# Validation Accuracy: 93.13%
# Batch: 0, Loss: 0.21199552714824677
# Batch: 20, Loss: 0.28155145049095154
# Batch: 40, Loss: 0.2259311079978943
# Batch: 60, Loss: 0.19034536182880402
# Batch: 80, Loss: 0.260397732257843
# Batch: 100, Loss: 0.25554582476615906
# Batch: 120, Loss: 0.2428271323442459
# Batch: 140, Loss: 0.09620171785354614
# Batch: 160, Loss: 0.19666635990142822
# Batch: 180, Loss: 0.2094346582889557
# Batch: 200, Loss: 0.269513875246048
#
# Average loss: 0.1799, Accuracy: 24531.0/26038 (94%)
#
#
# Average loss: 0.1974, Accuracy: 2762.0/2940 (94%)
#
# Epoch: 1 	Training Accuracy: 94.21%
# Validation Accuracy: 93.95%
# Batch: 0, Loss: 0.22516945004463196
# Batch: 20, Loss: 0.1917821168899536
# Batch: 40, Loss: 0.1411954015493393
# Batch: 60, Loss: 0.25912266969680786
# Batch: 80, Loss: 0.11152326315641403
# Batch: 100, Loss: 0.10088787972927094
# Batch: 120, Loss: 0.23115038871765137
# Batch: 140, Loss: 0.1176234781742096
# Batch: 160, Loss: 0.11031503975391388
# Batch: 180, Loss: 0.16773907840251923
# Batch: 200, Loss: 0.13360115885734558
#
# Average loss: 0.1778, Accuracy: 24538.0/26038 (94%)
#
#
# Average loss: 0.2030, Accuracy: 2764.0/2940 (94%)
#
# Epoch: 2 	Training Accuracy: 94.24%
# Validation Accuracy: 94.01%
# Batch: 0, Loss: 0.11366750299930573
# Batch: 20, Loss: 0.2545672655105591
# Batch: 40, Loss: 0.1583239585161209
# Batch: 60, Loss: 0.12644559144973755
# Batch: 80, Loss: 0.12919630110263824
# Batch: 100, Loss: 0.19322142004966736
# Batch: 120, Loss: 0.1699073314666748
# Batch: 140, Loss: 0.1146138533949852
# Batch: 160, Loss: 0.1778625249862671
# Batch: 180, Loss: 0.1181642934679985
# Batch: 200, Loss: 0.15369755029678345
#
# Average loss: 0.1619, Accuracy: 24696.0/26038 (95%)
#
#
# Average loss: 0.1873, Accuracy: 2779.0/2940 (95%)
#
# Epoch: 3 	Training Accuracy: 94.85%
# Validation Accuracy: 94.52%
# Batch: 0, Loss: 0.08833964914083481
# Batch: 20, Loss: 0.12774714827537537
# Batch: 40, Loss: 0.20837727189064026
# Batch: 60, Loss: 0.1673944890499115
# Batch: 80, Loss: 0.1604040563106537
# Batch: 100, Loss: 0.08285117894411087
# Batch: 120, Loss: 0.15764573216438293
# Batch: 140, Loss: 0.15579013526439667
# Batch: 160, Loss: 0.20651885867118835
# Batch: 180, Loss: 0.10783422738313675
# Batch: 200, Loss: 0.10458064079284668
#
# Average loss: 0.1513, Accuracy: 24786.0/26038 (95%)
#
#
# Average loss: 0.1779, Accuracy: 2784.0/2940 (95%)
#
# Epoch: 4 	Training Accuracy: 95.19%
# Validation Accuracy: 94.69%
# Batch: 0, Loss: 0.10615342855453491
# Batch: 20, Loss: 0.09286024421453476
# Batch: 40, Loss: 0.15457333624362946
# Batch: 60, Loss: 0.13773976266384125
# Batch: 80, Loss: 0.16850608587265015
# Batch: 100, Loss: 0.2114296853542328
# Batch: 120, Loss: 0.06775373965501785
# Batch: 140, Loss: 0.1571171134710312
# Batch: 160, Loss: 0.15311972796916962
# Batch: 180, Loss: 0.09858817607164383
# Batch: 200, Loss: 0.21778322756290436
#
# Average loss: 0.1491, Accuracy: 24812.0/26038 (95%)
#
#
# Average loss: 0.1766, Accuracy: 2786.0/2940 (95%)
#
# Epoch: 5 	Training Accuracy: 95.29%
# Validation Accuracy: 94.76%
# Batch: 0, Loss: 0.14078858494758606
# Batch: 20, Loss: 0.14930298924446106
# Batch: 40, Loss: 0.14991670846939087
# Batch: 60, Loss: 0.12668174505233765
# Batch: 80, Loss: 0.16659830510616302
# Batch: 100, Loss: 0.09533772617578506
# Batch: 120, Loss: 0.22319018840789795
# Batch: 140, Loss: 0.13487397134304047
# Batch: 160, Loss: 0.17228536307811737
# Batch: 180, Loss: 0.1667069047689438
# Batch: 200, Loss: 0.19675834476947784
#
# Average loss: 0.1518, Accuracy: 24754.0/26038 (95%)
#
#
# Average loss: 0.1828, Accuracy: 2775.0/2940 (94%)
#
# Epoch: 6 	Training Accuracy: 95.07%
# Validation Accuracy: 94.39%
# Batch: 0, Loss: 0.18301266431808472
# Batch: 20, Loss: 0.18811339139938354
# Batch: 40, Loss: 0.1750502586364746
# Batch: 60, Loss: 0.13120263814926147
# Batch: 80, Loss: 0.1024472713470459
# Batch: 100, Loss: 0.09565861523151398
# Batch: 120, Loss: 0.10853138566017151
# Batch: 140, Loss: 0.1074594259262085
# Batch: 160, Loss: 0.2176685482263565
# Batch: 180, Loss: 0.08848638087511063
# Batch: 200, Loss: 0.10457485914230347
#
# Average loss: 0.1358, Accuracy: 24945.0/26038 (96%)
#
#
# Average loss: 0.1680, Accuracy: 2792.0/2940 (95%)
#
# Epoch: 7 	Training Accuracy: 95.80%
# Validation Accuracy: 94.97%
# Batch: 0, Loss: 0.1314111351966858
# Batch: 20, Loss: 0.1026427149772644
# Batch: 40, Loss: 0.1481204479932785
# Batch: 60, Loss: 0.13564008474349976
# Batch: 80, Loss: 0.17294012010097504
# Batch: 100, Loss: 0.09140893816947937
# Batch: 120, Loss: 0.17135204374790192
# Batch: 140, Loss: 0.07562568783760071
# Batch: 160, Loss: 0.09793763607740402
# Batch: 180, Loss: 0.10994095355272293
# Batch: 200, Loss: 0.13291524350643158
#
# Average loss: 0.1380, Accuracy: 24927.0/26038 (96%)
#
#
# Average loss: 0.1741, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 8 	Training Accuracy: 95.73%
# Validation Accuracy: 95.10%
# Batch: 0, Loss: 0.156504824757576
# Batch: 20, Loss: 0.17534077167510986
# Batch: 40, Loss: 0.021639786660671234
# Batch: 60, Loss: 0.08902671188116074
# Batch: 80, Loss: 0.1653582900762558
# Batch: 100, Loss: 0.11876358091831207
# Batch: 120, Loss: 0.09063233435153961
# Batch: 140, Loss: 0.16173914074897766
# Batch: 160, Loss: 0.0911671444773674
# Batch: 180, Loss: 0.1381007879972458
# Batch: 200, Loss: 0.1477392464876175
#
# Average loss: 0.1423, Accuracy: 24884.0/26038 (96%)
#
#
# Average loss: 0.1791, Accuracy: 2772.0/2940 (94%)
#
# Epoch: 9 	Training Accuracy: 95.57%
# Validation Accuracy: 94.29%
# Batch: 0, Loss: 0.11751377582550049
# Batch: 20, Loss: 0.1309944987297058
# Batch: 40, Loss: 0.18264423310756683
# Batch: 60, Loss: 0.1255161464214325
# Batch: 80, Loss: 0.161676287651062
# Batch: 100, Loss: 0.24821199476718903
# Batch: 120, Loss: 0.18323661386966705
# Batch: 140, Loss: 0.17170079052448273
# Batch: 160, Loss: 0.24772405624389648
# Batch: 180, Loss: 0.12442953884601593
# Batch: 200, Loss: 0.14427810907363892
#
# Average loss: 0.1316, Accuracy: 24963.0/26038 (96%)
#
#
# Average loss: 0.1725, Accuracy: 2790.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 95.87%
# Validation Accuracy: 94.90%
# Batch: 0, Loss: 0.1620069146156311
# Batch: 20, Loss: 0.10922367870807648
# Batch: 40, Loss: 0.1950606256723404
# Batch: 60, Loss: 0.17317476868629456
# Batch: 80, Loss: 0.1738642007112503
# Batch: 100, Loss: 0.21863938868045807
# Batch: 120, Loss: 0.10774048417806625
# Batch: 140, Loss: 0.09624827653169632
# Batch: 160, Loss: 0.17597486078739166
# Batch: 180, Loss: 0.10330358892679214
# Batch: 200, Loss: 0.1363016664981842
#
# Average loss: 0.1250, Accuracy: 25023.0/26038 (96%)
#
#
# Average loss: 0.1673, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 96.10%
# Validation Accuracy: 95.10%
# Batch: 0, Loss: 0.11535833030939102
# Batch: 20, Loss: 0.08356219530105591
# Batch: 40, Loss: 0.0961654931306839
# Batch: 60, Loss: 0.26374611258506775
# Batch: 80, Loss: 0.2962192893028259
# Batch: 100, Loss: 0.16181540489196777
# Batch: 120, Loss: 0.042073339223861694
# Batch: 140, Loss: 0.050837114453315735
# Batch: 160, Loss: 0.21064908802509308
# Batch: 180, Loss: 0.13818207383155823
# Batch: 200, Loss: 0.0928480327129364
#
# Average loss: 0.1359, Accuracy: 24906.0/26038 (96%)
#
#
# Average loss: 0.1699, Accuracy: 2787.0/2940 (95%)
#
# Epoch: 12 	Training Accuracy: 95.65%
# Validation Accuracy: 94.80%
# Batch: 0, Loss: 0.11472112685441971
# Batch: 20, Loss: 0.12888437509536743
# Batch: 40, Loss: 0.1606656312942505
# Batch: 60, Loss: 0.12175661325454712
# Batch: 80, Loss: 0.2326691746711731
# Batch: 100, Loss: 0.12956289947032928
# Batch: 120, Loss: 0.19446544349193573
# Batch: 140, Loss: 0.09815751761198044
# Batch: 160, Loss: 0.07983259111642838
# Batch: 180, Loss: 0.20673871040344238
# Batch: 200, Loss: 0.3633854389190674
#
# Average loss: 0.1228, Accuracy: 25050.0/26038 (96%)
#
#
# Average loss: 0.1647, Accuracy: 2791.0/2940 (95%)
#
# Epoch: 13 	Training Accuracy: 96.21%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.20684416592121124
# Batch: 20, Loss: 0.09416504204273224
# Batch: 40, Loss: 0.15631097555160522
# Batch: 60, Loss: 0.18509039282798767
# Batch: 80, Loss: 0.13955816626548767
# Batch: 100, Loss: 0.0964299663901329
# Batch: 120, Loss: 0.11352861672639847
# Batch: 140, Loss: 0.14111968874931335
# Batch: 160, Loss: 0.11385522782802582
# Batch: 180, Loss: 0.170089989900589
# Batch: 200, Loss: 0.19432832300662994
#
# Average loss: 0.1237, Accuracy: 25030.0/26038 (96%)
#
#
# Average loss: 0.1651, Accuracy: 2798.0/2940 (95%)
#
# Epoch: 14 	Training Accuracy: 96.13%
# Validation Accuracy: 95.17%
# Batch: 0, Loss: 0.11067449301481247
# Batch: 20, Loss: 0.3019532561302185
# Batch: 40, Loss: 0.06417669355869293
# Batch: 60, Loss: 0.07982752472162247
# Batch: 80, Loss: 0.11597472429275513
# Batch: 100, Loss: 0.11354179680347443
# Batch: 120, Loss: 0.07786910980939865
# Batch: 140, Loss: 0.12307366728782654
# Batch: 160, Loss: 0.14942416548728943
# Batch: 180, Loss: 0.1123955249786377
# Batch: 200, Loss: 0.09446918219327927
#
# Average loss: 0.1231, Accuracy: 25019.0/26038 (96%)
#
#
# Average loss: 0.1659, Accuracy: 2794.0/2940 (95%)
#
# Epoch: 15 	Training Accuracy: 96.09%
# Validation Accuracy: 95.03%
# Batch: 0, Loss: 0.07908059656620026
# Batch: 20, Loss: 0.08809816837310791
# Batch: 40, Loss: 0.13756026327610016
# Batch: 60, Loss: 0.08860258758068085
# Batch: 80, Loss: 0.167733296751976
# Batch: 100, Loss: 0.16226835548877716
# Batch: 120, Loss: 0.14122432470321655
# Batch: 140, Loss: 0.07511788606643677
# Batch: 160, Loss: 0.15650871396064758
# Batch: 180, Loss: 0.07007977366447449
# Batch: 200, Loss: 0.12520912289619446
#
# Average loss: 0.1177, Accuracy: 25093.0/26038 (96%)
#
#
# Average loss: 0.1600, Accuracy: 2808.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 96.37%
# Validation Accuracy: 95.51%
# Batch: 0, Loss: 0.0891624465584755
# Batch: 20, Loss: 0.09379458427429199
# Batch: 40, Loss: 0.19545292854309082
# Batch: 60, Loss: 0.13486754894256592
# Batch: 80, Loss: 0.15366940200328827
# Batch: 100, Loss: 0.20894518494606018
# Batch: 120, Loss: 0.09984520822763443
# Batch: 140, Loss: 0.08588100224733353
# Batch: 160, Loss: 0.10399093478918076
# Batch: 180, Loss: 0.13010716438293457
# Batch: 200, Loss: 0.28516656160354614
#
# Average loss: 0.1290, Accuracy: 24991.0/26038 (96%)
#
#
# Average loss: 0.1758, Accuracy: 2779.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 95.98%
# Validation Accuracy: 94.52%
# Batch: 0, Loss: 0.23527558147907257
# Batch: 20, Loss: 0.1481315642595291
# Batch: 40, Loss: 0.09866210073232651
# Batch: 60, Loss: 0.11557536572217941
# Batch: 80, Loss: 0.07806305587291718
# Batch: 100, Loss: 0.20432426035404205
# Batch: 120, Loss: 0.14336733520030975
# Batch: 140, Loss: 0.2808850109577179
# Batch: 160, Loss: 0.21655461192131042
# Batch: 180, Loss: 0.08308281749486923
# Batch: 200, Loss: 0.13299371302127838
#
# Average loss: 0.1247, Accuracy: 24997.0/26038 (96%)
#
#
# Average loss: 0.1763, Accuracy: 2782.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 96.00%
# Validation Accuracy: 94.63%
# Batch: 0, Loss: 0.16393280029296875
# Batch: 20, Loss: 0.05803656205534935
# Batch: 40, Loss: 0.17579181492328644
# Batch: 60, Loss: 0.0796259194612503
# Batch: 80, Loss: 0.1495843082666397
# Batch: 100, Loss: 0.16628539562225342
# Batch: 120, Loss: 0.07169858366250992
# Batch: 140, Loss: 0.08136509358882904
# Batch: 160, Loss: 0.09153078496456146
# Batch: 180, Loss: 0.08115898072719574
# Batch: 200, Loss: 0.155315563082695
#
# Average loss: 0.1190, Accuracy: 25063.0/26038 (96%)
#
#
# Average loss: 0.1668, Accuracy: 2802.0/2940 (95%)
#
# Epoch: 19 	Training Accuracy: 96.26%
# Validation Accuracy: 95.31%
#
# Average loss: 0.1190, Accuracy: 25063.0/26038 (96%)
#
#
# Average loss: 0.1644, Accuracy: 4610.0/4861 (95%)
#
# Final Training Accuracy (New Data): 0.9626
# Final Test Accuracy (New Data): 0.9484
# Percentage: 0.01, Seed: 10, Epochs taken: 7
# Percentage: 0.01, Seed: 20, Epochs taken: 20
# Percentage: 0.01, Seed: 30, Epochs taken: 20
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 11
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 20
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 18
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 20
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 20
# Percentage: 0.6, Seed: 10, Epochs taken: 8
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 16
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 20
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 18
# Percentage: 1, Seed: 40, Epochs taken: 20
# Percentage: 1, Seed: 50, Epochs taken: 20

# %% [markdown]
# ## Only heads and data for new classes

# %% [markdown]
# now with balanced classes

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.0001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test_finetune = {}
results_train_finetune = {}
best_models = {}
data_loaders = {}
epochs_taken_finetune = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Processing percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []
    
    for seed in tqdm(seed_set, desc=f'Running seeds for {perc} data', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")

                # Copying model
        model_new = copy.deepcopy(model)

        # Calculate the output size from the pool layer dynamically
        # You would replace this with the actual size based on your model's architecture
        model_new.fc_1 = nn.Linear(576, 128)
    
        # Reinitialize the second fully connected layer
        model_new.fc_2 = nn.Linear(128, 5)
        
        # Ensure the softmax layer matches the number of classes (if used)
        model_new.softmax = nn.Softmax(dim=1)
        
        model_new.to(device)
        
        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)
        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test_finetune[perc] = test_accuracies
    results_train_finetune[perc] = train_accuracies
    epochs_taken_finetune[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken_finetune[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Running seeds for 0.01 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 79 =========================
# Batch: 0, Loss: 1.6109973192214966
#
# Average loss: 1.5885, Accuracy: 103.0/260 (40%)
#
#
# Average loss: 1.5917, Accuracy: 1041.0/2940 (35%)
#
# Epoch: 0 	Training Accuracy: 39.62%
# Validation Accuracy: 35.41%
# Batch: 0, Loss: 1.5875240564346313
#
# Average loss: 1.5740, Accuracy: 114.0/260 (44%)
#
#
# Average loss: 1.5792, Accuracy: 1183.0/2940 (40%)
#
# Epoch: 1 	Training Accuracy: 43.85%
# Validation Accuracy: 40.24%
# Batch: 0, Loss: 1.5733520984649658
#
# Average loss: 1.5607, Accuracy: 117.0/260 (45%)
#
#
# Average loss: 1.5675, Accuracy: 1181.0/2940 (40%)
#
# Epoch: 2 	Training Accuracy: 45.00%
# Validation Accuracy: 40.17%
# Batch: 0, Loss: 1.5595545768737793
#
# Average loss: 1.5476, Accuracy: 124.0/260 (48%)
#
#
# Average loss: 1.5558, Accuracy: 1226.0/2940 (42%)
#
# Epoch: 3 	Training Accuracy: 47.69%
# Validation Accuracy: 41.70%
# Batch: 0, Loss: 1.5449891090393066
#
# Average loss: 1.5343, Accuracy: 131.0/260 (50%)
#
#
# Average loss: 1.5436, Accuracy: 1297.0/2940 (44%)
#
# Epoch: 4 	Training Accuracy: 50.38%
# Validation Accuracy: 44.12%
# Batch: 0, Loss: 1.5366119146347046
#
# Average loss: 1.5205, Accuracy: 144.0/260 (55%)
#
#
# Average loss: 1.5308, Accuracy: 1407.0/2940 (48%)
#
# Epoch: 5 	Training Accuracy: 55.38%
# Validation Accuracy: 47.86%
# Batch: 0, Loss: 1.5155929327011108
#
# Average loss: 1.5064, Accuracy: 156.0/260 (60%)
#
#
# Average loss: 1.5174, Accuracy: 1628.0/2940 (55%)
#
# Epoch: 6 	Training Accuracy: 60.00%
# Validation Accuracy: 55.37%
# Batch: 0, Loss: 1.505075216293335
#
# Average loss: 1.4922, Accuracy: 161.0/260 (62%)
#
#
# Average loss: 1.5035, Accuracy: 1734.0/2940 (59%)
#
# Epoch: 7 	Training Accuracy: 61.92%
# Validation Accuracy: 58.98%
# Batch: 0, Loss: 1.4939420223236084
#
# Average loss: 1.4774, Accuracy: 166.0/260 (64%)
#
#
# Average loss: 1.4893, Accuracy: 1777.0/2940 (60%)
#
# Epoch: 8 	Training Accuracy: 63.85%
# Validation Accuracy: 60.44%
# Batch: 0, Loss: 1.473830223083496
#
# Average loss: 1.4616, Accuracy: 175.0/260 (67%)
#
#
# Average loss: 1.4735, Accuracy: 1829.0/2940 (62%)
#
# Epoch: 9 	Training Accuracy: 67.31%
# Validation Accuracy: 62.21%
# Batch: 0, Loss: 1.4600780010223389
#
# Average loss: 1.4453, Accuracy: 182.0/260 (70%)
#
#
# Average loss: 1.4574, Accuracy: 1874.0/2940 (64%)
#
# Epoch: 10 	Training Accuracy: 70.00%
# Validation Accuracy: 63.74%
# Batch: 0, Loss: 1.445716381072998
#
# Average loss: 1.4287, Accuracy: 180.0/260 (69%)
#
#
# Average loss: 1.4412, Accuracy: 1904.0/2940 (65%)
#
# Epoch: 11 	Training Accuracy: 69.23%
# Validation Accuracy: 64.76%
# Batch: 0, Loss: 1.4180232286453247
#
# Average loss: 1.4121, Accuracy: 193.0/260 (74%)
#
#
# Average loss: 1.4243, Accuracy: 2005.0/2940 (68%)
#
# Epoch: 12 	Training Accuracy: 74.23%
# Validation Accuracy: 68.20%
# Batch: 0, Loss: 1.398794174194336
#
# Average loss: 1.3960, Accuracy: 199.0/260 (77%)
#
#
# Average loss: 1.4075, Accuracy: 2076.0/2940 (71%)
#
# Epoch: 13 	Training Accuracy: 76.54%
# Validation Accuracy: 70.61%
# Batch: 0, Loss: 1.4017062187194824
#
# Average loss: 1.3802, Accuracy: 197.0/260 (76%)
#
#
# Average loss: 1.3911, Accuracy: 2077.0/2940 (71%)
#
# Epoch: 14 	Training Accuracy: 75.77%
# Validation Accuracy: 70.65%
# Batch: 0, Loss: 1.3684842586517334
#
# Average loss: 1.3656, Accuracy: 181.0/260 (70%)
#
#
# Average loss: 1.3762, Accuracy: 1970.0/2940 (67%)
#
# Epoch: 15 	Training Accuracy: 69.62%
# Validation Accuracy: 67.01%
# Batch: 0, Loss: 1.373544692993164
#
# Average loss: 1.3513, Accuracy: 173.0/260 (67%)
#
#
# Average loss: 1.3620, Accuracy: 1895.0/2940 (64%)
#
# Epoch: 16 	Training Accuracy: 66.54%
# Validation Accuracy: 64.46%
# Batch: 0, Loss: 1.3745238780975342
#
# Average loss: 1.3346, Accuracy: 171.0/260 (66%)
#
#
# Average loss: 1.3454, Accuracy: 1868.0/2940 (64%)
#
# Epoch: 17 	Training Accuracy: 65.77%
# Validation Accuracy: 63.54%
# Batch: 0, Loss: 1.3634880781173706
#
# Average loss: 1.3145, Accuracy: 177.0/260 (68%)
#
#
# Average loss: 1.3262, Accuracy: 1923.0/2940 (65%)
#
# Epoch: 18 	Training Accuracy: 68.08%
# Validation Accuracy: 65.41%
# Batch: 0, Loss: 1.3066824674606323
#
# Average loss: 1.2948, Accuracy: 176.0/260 (68%)
#
#
# Average loss: 1.3067, Accuracy: 1918.0/2940 (65%)
#
# Epoch: 19 	Training Accuracy: 67.69%
# Validation Accuracy: 65.24%
#
# Average loss: 1.2948, Accuracy: 176.0/260 (68%)
#
#
# Average loss: 1.3099, Accuracy: 3136.0/4861 (65%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 72 =========================
# Batch: 0, Loss: 1.6172029972076416
#
# Average loss: 1.5994, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.5972, Accuracy: 823.0/2940 (28%)
#
# Epoch: 0 	Training Accuracy: 28.46%
# Validation Accuracy: 27.99%
# Batch: 0, Loss: 1.6009565591812134
#
# Average loss: 1.5829, Accuracy: 90.0/260 (35%)
#
#
# Average loss: 1.5832, Accuracy: 1006.0/2940 (34%)
#
# Epoch: 1 	Training Accuracy: 34.62%
# Validation Accuracy: 34.22%
# Batch: 0, Loss: 1.5747246742248535
#
# Average loss: 1.5679, Accuracy: 83.0/260 (32%)
#
#
# Average loss: 1.5698, Accuracy: 921.0/2940 (31%)
#
# Epoch: 2 	Training Accuracy: 31.92%
# Validation Accuracy: 31.33%
# Batch: 0, Loss: 1.5561854839324951
#
# Average loss: 1.5540, Accuracy: 81.0/260 (31%)
#
#
# Average loss: 1.5574, Accuracy: 880.0/2940 (30%)
#
# Epoch: 3 	Training Accuracy: 31.15%
# Validation Accuracy: 29.93%
# Batch: 0, Loss: 1.5567033290863037
#
# Average loss: 1.5393, Accuracy: 80.0/260 (31%)
#
#
# Average loss: 1.5446, Accuracy: 879.0/2940 (30%)
#
# Epoch: 4 	Training Accuracy: 30.77%
# Validation Accuracy: 29.90%
# Batch: 0, Loss: 1.542341947555542
#
# Average loss: 1.5237, Accuracy: 87.0/260 (33%)
#
#
# Average loss: 1.5305, Accuracy: 956.0/2940 (33%)
#
# Epoch: 5 	Training Accuracy: 33.46%
# Validation Accuracy: 32.52%
# Batch: 0, Loss: 1.528628945350647
#
# Average loss: 1.5075, Accuracy: 104.0/260 (40%)
#
#
# Average loss: 1.5154, Accuracy: 1168.0/2940 (40%)
#
# Epoch: 6 	Training Accuracy: 40.00%
# Validation Accuracy: 39.73%
# Batch: 0, Loss: 1.5134739875793457
#
# Average loss: 1.4913, Accuracy: 126.0/260 (48%)
#
#
# Average loss: 1.4999, Accuracy: 1374.0/2940 (47%)
#
# Epoch: 7 	Training Accuracy: 48.46%
# Validation Accuracy: 46.73%
# Batch: 0, Loss: 1.503124713897705
#
# Average loss: 1.4762, Accuracy: 135.0/260 (52%)
#
#
# Average loss: 1.4858, Accuracy: 1455.0/2940 (49%)
#
# Epoch: 8 	Training Accuracy: 51.92%
# Validation Accuracy: 49.49%
# Batch: 0, Loss: 1.4687705039978027
#
# Average loss: 1.4611, Accuracy: 145.0/260 (56%)
#
#
# Average loss: 1.4717, Accuracy: 1602.0/2940 (54%)
#
# Epoch: 9 	Training Accuracy: 55.77%
# Validation Accuracy: 54.49%
# Batch: 0, Loss: 1.4604438543319702
#
# Average loss: 1.4450, Accuracy: 177.0/260 (68%)
#
#
# Average loss: 1.4560, Accuracy: 1911.0/2940 (65%)
#
# Epoch: 10 	Training Accuracy: 68.08%
# Validation Accuracy: 65.00%
# Batch: 0, Loss: 1.4427733421325684
#
# Average loss: 1.4280, Accuracy: 193.0/260 (74%)
#
#
# Average loss: 1.4384, Accuracy: 2157.0/2940 (73%)
#
# Epoch: 11 	Training Accuracy: 74.23%
# Validation Accuracy: 73.37%
# Batch: 0, Loss: 1.4297668933868408
#
# Average loss: 1.4112, Accuracy: 200.0/260 (77%)
#
#
# Average loss: 1.4214, Accuracy: 2216.0/2940 (75%)
#
# Epoch: 12 	Training Accuracy: 76.92%
# Validation Accuracy: 75.37%
# Batch: 0, Loss: 1.4071720838546753
#
# Average loss: 1.3944, Accuracy: 198.0/260 (76%)
#
#
# Average loss: 1.4045, Accuracy: 2176.0/2940 (74%)
#
# Epoch: 13 	Training Accuracy: 76.15%
# Validation Accuracy: 74.01%
# Batch: 0, Loss: 1.400070309638977
#
# Average loss: 1.3776, Accuracy: 188.0/260 (72%)
#
#
# Average loss: 1.3870, Accuracy: 2088.0/2940 (71%)
#
# Epoch: 14 	Training Accuracy: 72.31%
# Validation Accuracy: 71.02%
# Batch: 0, Loss: 1.3769757747650146
#
# Average loss: 1.3606, Accuracy: 185.0/260 (71%)
#
#
# Average loss: 1.3697, Accuracy: 2078.0/2940 (71%)
#
# Epoch: 15 	Training Accuracy: 71.15%
# Validation Accuracy: 70.68%
# Batch: 0, Loss: 1.3607035875320435
#
# Average loss: 1.3421, Accuracy: 182.0/260 (70%)
#
#
# Average loss: 1.3513, Accuracy: 2068.0/2940 (70%)
#
# Epoch: 16 	Training Accuracy: 70.00%
# Validation Accuracy: 70.34%
# Batch: 0, Loss: 1.3475143909454346
#
# Average loss: 1.3247, Accuracy: 178.0/260 (68%)
#
#
# Average loss: 1.3334, Accuracy: 2054.0/2940 (70%)
#
# Epoch: 17 	Training Accuracy: 68.46%
# Validation Accuracy: 69.86%
# Batch: 0, Loss: 1.3479410409927368
#
# Average loss: 1.3078, Accuracy: 180.0/260 (69%)
#
#
# Average loss: 1.3170, Accuracy: 2025.0/2940 (69%)
#
# Epoch: 18 	Training Accuracy: 69.23%
# Validation Accuracy: 68.88%
# Early stopping invoked.
#
# Average loss: 1.4112, Accuracy: 200.0/260 (77%)
#
#
# Average loss: 1.4216, Accuracy: 3738.0/4861 (77%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 0 =========================
# Batch: 0, Loss: 1.6170378923416138
#
# Average loss: 1.5951, Accuracy: 77.0/260 (30%)
#
#
# Average loss: 1.5971, Accuracy: 753.0/2940 (26%)
#
# Epoch: 0 	Training Accuracy: 29.62%
# Validation Accuracy: 25.61%
# Batch: 0, Loss: 1.595143437385559
#
# Average loss: 1.5798, Accuracy: 108.0/260 (42%)
#
#
# Average loss: 1.5838, Accuracy: 1081.0/2940 (37%)
#
# Epoch: 1 	Training Accuracy: 41.54%
# Validation Accuracy: 36.77%
# Batch: 0, Loss: 1.5791864395141602
#
# Average loss: 1.5665, Accuracy: 118.0/260 (45%)
#
#
# Average loss: 1.5728, Accuracy: 1181.0/2940 (40%)
#
# Epoch: 2 	Training Accuracy: 45.38%
# Validation Accuracy: 40.17%
# Batch: 0, Loss: 1.5671546459197998
#
# Average loss: 1.5538, Accuracy: 99.0/260 (38%)
#
#
# Average loss: 1.5617, Accuracy: 989.0/2940 (34%)
#
# Epoch: 3 	Training Accuracy: 38.08%
# Validation Accuracy: 33.64%
# Batch: 0, Loss: 1.556077003479004
#
# Average loss: 1.5412, Accuracy: 85.0/260 (33%)
#
#
# Average loss: 1.5500, Accuracy: 903.0/2940 (31%)
#
# Epoch: 4 	Training Accuracy: 32.69%
# Validation Accuracy: 30.71%
# Batch: 0, Loss: 1.542467713356018
#
# Average loss: 1.5272, Accuracy: 94.0/260 (36%)
#
#
# Average loss: 1.5373, Accuracy: 995.0/2940 (34%)
#
# Epoch: 5 	Training Accuracy: 36.15%
# Validation Accuracy: 33.84%
# Batch: 0, Loss: 1.5231430530548096
#
# Average loss: 1.5129, Accuracy: 100.0/260 (38%)
#
#
# Average loss: 1.5250, Accuracy: 1053.0/2940 (36%)
#
# Epoch: 6 	Training Accuracy: 38.46%
# Validation Accuracy: 35.82%
# Batch: 0, Loss: 1.5089144706726074
#
# Average loss: 1.4991, Accuracy: 102.0/260 (39%)
#
#
# Average loss: 1.5129, Accuracy: 1121.0/2940 (38%)
#
# Epoch: 7 	Training Accuracy: 39.23%
# Validation Accuracy: 38.13%
# Batch: 0, Loss: 1.4933770895004272
#
# Average loss: 1.4846, Accuracy: 120.0/260 (46%)
#
#
# Average loss: 1.4989, Accuracy: 1340.0/2940 (46%)
#
# Epoch: 8 	Training Accuracy: 46.15%
# Validation Accuracy: 45.58%
# Batch: 0, Loss: 1.4876147508621216
#
# Average loss: 1.4687, Accuracy: 153.0/260 (59%)
#
#
# Average loss: 1.4833, Accuracy: 1620.0/2940 (55%)
#
# Epoch: 9 	Training Accuracy: 58.85%
# Validation Accuracy: 55.10%
# Batch: 0, Loss: 1.4722644090652466
#
# Average loss: 1.4527, Accuracy: 169.0/260 (65%)
#
#
# Average loss: 1.4674, Accuracy: 1814.0/2940 (62%)
#
# Epoch: 10 	Training Accuracy: 65.00%
# Validation Accuracy: 61.70%
# Batch: 0, Loss: 1.4553391933441162
#
# Average loss: 1.4365, Accuracy: 172.0/260 (66%)
#
#
# Average loss: 1.4514, Accuracy: 1889.0/2940 (64%)
#
# Epoch: 11 	Training Accuracy: 66.15%
# Validation Accuracy: 64.25%
# Batch: 0, Loss: 1.4442306756973267
#
# Average loss: 1.4206, Accuracy: 175.0/260 (67%)
#
#
# Average loss: 1.4357, Accuracy: 1879.0/2940 (64%)
#
# Epoch: 12 	Training Accuracy: 67.31%
# Validation Accuracy: 63.91%
# Batch: 0, Loss: 1.4241302013397217
#
# Average loss: 1.4047, Accuracy: 172.0/260 (66%)
#
#
# Average loss: 1.4206, Accuracy: 1857.0/2940 (63%)
#
# Epoch: 13 	Training Accuracy: 66.15%
# Validation Accuracy: 63.16%
# Batch: 0, Loss: 1.4029357433319092
#
# Average loss: 1.3878, Accuracy: 178.0/260 (68%)
#
#
# Average loss: 1.4055, Accuracy: 1884.0/2940 (64%)
#
# Epoch: 14 	Training Accuracy: 68.46%
# Validation Accuracy: 64.08%
# Batch: 0, Loss: 1.3955556154251099
#
# Average loss: 1.3696, Accuracy: 189.0/260 (73%)
#
#
# Average loss: 1.3896, Accuracy: 2011.0/2940 (68%)
#
# Epoch: 15 	Training Accuracy: 72.69%
# Validation Accuracy: 68.40%
# Batch: 0, Loss: 1.350623369216919
#
# Average loss: 1.3513, Accuracy: 198.0/260 (76%)
#
#
# Average loss: 1.3738, Accuracy: 2130.0/2940 (72%)
#
# Epoch: 16 	Training Accuracy: 76.15%
# Validation Accuracy: 72.45%
# Batch: 0, Loss: 1.3503464460372925
#
# Average loss: 1.3328, Accuracy: 205.0/260 (79%)
#
#
# Average loss: 1.3577, Accuracy: 2189.0/2940 (74%)
#
# Epoch: 17 	Training Accuracy: 78.85%
# Validation Accuracy: 74.46%
# Batch: 0, Loss: 1.3177918195724487
#
# Average loss: 1.3138, Accuracy: 213.0/260 (82%)
#
#
# Average loss: 1.3420, Accuracy: 2233.0/2940 (76%)
#
# Epoch: 18 	Training Accuracy: 81.92%
# Validation Accuracy: 75.95%
# Batch: 0, Loss: 1.3215224742889404
#
# Average loss: 1.2942, Accuracy: 209.0/260 (80%)
#
#
# Average loss: 1.3259, Accuracy: 2228.0/2940 (76%)
#
# Epoch: 19 	Training Accuracy: 80.38%
# Validation Accuracy: 75.78%
#
# Average loss: 1.2942, Accuracy: 209.0/260 (80%)
#
#
# Average loss: 1.3346, Accuracy: 3611.0/4861 (74%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 97 =========================
# Batch: 0, Loss: 1.6079871654510498
#
# Average loss: 1.5980, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.6021, Accuracy: 605.0/2940 (21%)
#
# Epoch: 0 	Training Accuracy: 22.31%
# Validation Accuracy: 20.58%
# Batch: 0, Loss: 1.6019889116287231
#
# Average loss: 1.5796, Accuracy: 76.0/260 (29%)
#
#
# Average loss: 1.5844, Accuracy: 777.0/2940 (26%)
#
# Epoch: 1 	Training Accuracy: 29.23%
# Validation Accuracy: 26.43%
# Batch: 0, Loss: 1.5808234214782715
#
# Average loss: 1.5632, Accuracy: 113.0/260 (43%)
#
#
# Average loss: 1.5690, Accuracy: 1184.0/2940 (40%)
#
# Epoch: 2 	Training Accuracy: 43.46%
# Validation Accuracy: 40.27%
# Batch: 0, Loss: 1.560307264328003
#
# Average loss: 1.5478, Accuracy: 135.0/260 (52%)
#
#
# Average loss: 1.5551, Accuracy: 1450.0/2940 (49%)
#
# Epoch: 3 	Training Accuracy: 51.92%
# Validation Accuracy: 49.32%
# Batch: 0, Loss: 1.5502955913543701
#
# Average loss: 1.5331, Accuracy: 137.0/260 (53%)
#
#
# Average loss: 1.5419, Accuracy: 1489.0/2940 (51%)
#
# Epoch: 4 	Training Accuracy: 52.69%
# Validation Accuracy: 50.65%
# Batch: 0, Loss: 1.5349441766738892
#
# Average loss: 1.5185, Accuracy: 142.0/260 (55%)
#
#
# Average loss: 1.5284, Accuracy: 1465.0/2940 (50%)
#
# Epoch: 5 	Training Accuracy: 54.62%
# Validation Accuracy: 49.83%
# Batch: 0, Loss: 1.5246713161468506
#
# Average loss: 1.5038, Accuracy: 154.0/260 (59%)
#
#
# Average loss: 1.5142, Accuracy: 1568.0/2940 (53%)
#
# Epoch: 6 	Training Accuracy: 59.23%
# Validation Accuracy: 53.33%
# Batch: 0, Loss: 1.505468487739563
#
# Average loss: 1.4894, Accuracy: 166.0/260 (64%)
#
#
# Average loss: 1.4994, Accuracy: 1669.0/2940 (57%)
#
# Epoch: 7 	Training Accuracy: 63.85%
# Validation Accuracy: 56.77%
# Batch: 0, Loss: 1.4893466234207153
#
# Average loss: 1.4754, Accuracy: 164.0/260 (63%)
#
#
# Average loss: 1.4857, Accuracy: 1678.0/2940 (57%)
#
# Epoch: 8 	Training Accuracy: 63.08%
# Validation Accuracy: 57.07%
# Batch: 0, Loss: 1.486608862876892
#
# Average loss: 1.4615, Accuracy: 161.0/260 (62%)
#
#
# Average loss: 1.4720, Accuracy: 1698.0/2940 (58%)
#
# Epoch: 9 	Training Accuracy: 61.92%
# Validation Accuracy: 57.76%
# Batch: 0, Loss: 1.4566450119018555
#
# Average loss: 1.4470, Accuracy: 159.0/260 (61%)
#
#
# Average loss: 1.4572, Accuracy: 1674.0/2940 (57%)
#
# Epoch: 10 	Training Accuracy: 61.15%
# Validation Accuracy: 56.94%
# Batch: 0, Loss: 1.4373853206634521
#
# Average loss: 1.4325, Accuracy: 149.0/260 (57%)
#
#
# Average loss: 1.4426, Accuracy: 1631.0/2940 (55%)
#
# Epoch: 11 	Training Accuracy: 57.31%
# Validation Accuracy: 55.48%
# Batch: 0, Loss: 1.4394184350967407
#
# Average loss: 1.4160, Accuracy: 157.0/260 (60%)
#
#
# Average loss: 1.4265, Accuracy: 1668.0/2940 (57%)
#
# Epoch: 12 	Training Accuracy: 60.38%
# Validation Accuracy: 56.73%
# Batch: 0, Loss: 1.4089553356170654
#
# Average loss: 1.3977, Accuracy: 173.0/260 (67%)
#
#
# Average loss: 1.4094, Accuracy: 1803.0/2940 (61%)
#
# Epoch: 13 	Training Accuracy: 66.54%
# Validation Accuracy: 61.33%
# Batch: 0, Loss: 1.4144607782363892
#
# Average loss: 1.3801, Accuracy: 181.0/260 (70%)
#
#
# Average loss: 1.3930, Accuracy: 1846.0/2940 (63%)
#
# Epoch: 14 	Training Accuracy: 69.62%
# Validation Accuracy: 62.79%
# Batch: 0, Loss: 1.3756742477416992
#
# Average loss: 1.3617, Accuracy: 178.0/260 (68%)
#
#
# Average loss: 1.3750, Accuracy: 1852.0/2940 (63%)
#
# Epoch: 15 	Training Accuracy: 68.46%
# Validation Accuracy: 62.99%
# Batch: 0, Loss: 1.3725919723510742
#
# Average loss: 1.3410, Accuracy: 186.0/260 (72%)
#
#
# Average loss: 1.3546, Accuracy: 1959.0/2940 (67%)
#
# Epoch: 16 	Training Accuracy: 71.54%
# Validation Accuracy: 66.63%
# Batch: 0, Loss: 1.3302336931228638
#
# Average loss: 1.3196, Accuracy: 193.0/260 (74%)
#
#
# Average loss: 1.3342, Accuracy: 2094.0/2940 (71%)
#
# Epoch: 17 	Training Accuracy: 74.23%
# Validation Accuracy: 71.22%
# Batch: 0, Loss: 1.3079127073287964
#
# Average loss: 1.2982, Accuracy: 199.0/260 (77%)
#
#
# Average loss: 1.3136, Accuracy: 2141.0/2940 (73%)
#
# Epoch: 18 	Training Accuracy: 76.54%
# Validation Accuracy: 72.82%
# Batch: 0, Loss: 1.2911760807037354
#
# Average loss: 1.2775, Accuracy: 194.0/260 (75%)
#
#
# Average loss: 1.2938, Accuracy: 2107.0/2940 (72%)
#
# Epoch: 19 	Training Accuracy: 74.62%
# Validation Accuracy: 71.67%
#
# Average loss: 1.2775, Accuracy: 194.0/260 (75%)
#
#
# Average loss: 1.2989, Accuracy: 3450.0/4861 (71%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 46 =========================
# Batch: 0, Loss: 1.6172460317611694
#
# Average loss: 1.5921, Accuracy: 59.0/260 (23%)
#
#
# Average loss: 1.5911, Accuracy: 667.0/2940 (23%)
#
# Epoch: 0 	Training Accuracy: 22.69%
# Validation Accuracy: 22.69%
# Batch: 0, Loss: 1.595343828201294
#
# Average loss: 1.5759, Accuracy: 64.0/260 (25%)
#
#
# Average loss: 1.5755, Accuracy: 808.0/2940 (27%)
#
# Epoch: 1 	Training Accuracy: 24.62%
# Validation Accuracy: 27.48%
# Batch: 0, Loss: 1.567875623703003
#
# Average loss: 1.5610, Accuracy: 100.0/260 (38%)
#
#
# Average loss: 1.5609, Accuracy: 1215.0/2940 (41%)
#
# Epoch: 2 	Training Accuracy: 38.46%
# Validation Accuracy: 41.33%
# Batch: 0, Loss: 1.5659065246582031
#
# Average loss: 1.5466, Accuracy: 131.0/260 (50%)
#
#
# Average loss: 1.5473, Accuracy: 1487.0/2940 (51%)
#
# Epoch: 3 	Training Accuracy: 50.38%
# Validation Accuracy: 50.58%
# Batch: 0, Loss: 1.5442990064620972
#
# Average loss: 1.5321, Accuracy: 141.0/260 (54%)
#
#
# Average loss: 1.5339, Accuracy: 1569.0/2940 (53%)
#
# Epoch: 4 	Training Accuracy: 54.23%
# Validation Accuracy: 53.37%
# Batch: 0, Loss: 1.5287421941757202
#
# Average loss: 1.5173, Accuracy: 155.0/260 (60%)
#
#
# Average loss: 1.5201, Accuracy: 1715.0/2940 (58%)
#
# Epoch: 5 	Training Accuracy: 59.62%
# Validation Accuracy: 58.33%
# Batch: 0, Loss: 1.5231143236160278
#
# Average loss: 1.5021, Accuracy: 169.0/260 (65%)
#
#
# Average loss: 1.5057, Accuracy: 1847.0/2940 (63%)
#
# Epoch: 6 	Training Accuracy: 65.00%
# Validation Accuracy: 62.82%
# Batch: 0, Loss: 1.4916901588439941
#
# Average loss: 1.4867, Accuracy: 186.0/260 (72%)
#
#
# Average loss: 1.4917, Accuracy: 1976.0/2940 (67%)
#
# Epoch: 7 	Training Accuracy: 71.54%
# Validation Accuracy: 67.21%
# Batch: 0, Loss: 1.482663869857788
#
# Average loss: 1.4715, Accuracy: 191.0/260 (73%)
#
#
# Average loss: 1.4779, Accuracy: 2073.0/2940 (71%)
#
# Epoch: 8 	Training Accuracy: 73.46%
# Validation Accuracy: 70.51%
# Batch: 0, Loss: 1.466637134552002
#
# Average loss: 1.4561, Accuracy: 195.0/260 (75%)
#
#
# Average loss: 1.4639, Accuracy: 2073.0/2940 (71%)
#
# Epoch: 9 	Training Accuracy: 75.00%
# Validation Accuracy: 70.51%
# Batch: 0, Loss: 1.4568276405334473
#
# Average loss: 1.4417, Accuracy: 194.0/260 (75%)
#
#
# Average loss: 1.4515, Accuracy: 1933.0/2940 (66%)
#
# Epoch: 10 	Training Accuracy: 74.62%
# Validation Accuracy: 65.75%
# Batch: 0, Loss: 1.43089759349823
#
# Average loss: 1.4275, Accuracy: 186.0/260 (72%)
#
#
# Average loss: 1.4394, Accuracy: 1790.0/2940 (61%)
#
# Epoch: 11 	Training Accuracy: 71.54%
# Validation Accuracy: 60.88%
# Batch: 0, Loss: 1.4210444688796997
#
# Average loss: 1.4129, Accuracy: 175.0/260 (67%)
#
#
# Average loss: 1.4264, Accuracy: 1678.0/2940 (57%)
#
# Epoch: 12 	Training Accuracy: 67.31%
# Validation Accuracy: 57.07%
# Batch: 0, Loss: 1.4090226888656616
#
# Average loss: 1.3961, Accuracy: 183.0/260 (70%)
#
#
# Average loss: 1.4103, Accuracy: 1752.0/2940 (60%)
#
# Epoch: 13 	Training Accuracy: 70.38%
# Validation Accuracy: 59.59%
# Batch: 0, Loss: 1.3959494829177856
#
# Average loss: 1.3782, Accuracy: 189.0/260 (73%)
#
#
# Average loss: 1.3925, Accuracy: 1829.0/2940 (62%)
#
# Epoch: 14 	Training Accuracy: 72.69%
# Validation Accuracy: 62.21%
# Early stopping invoked.
#
# Average loss: 1.4715, Accuracy: 191.0/260 (73%)
#
#
# Average loss: 1.4778, Accuracy: 3386.0/4861 (70%)
# Running seeds for 0.03 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 75 =========================
# Batch: 0, Loss: 1.6185619831085205
#
# Average loss: 1.5650, Accuracy: 387.0/790 (49%)
#
#
# Average loss: 1.5670, Accuracy: 1390.0/2940 (47%)
#
# Epoch: 0 	Training Accuracy: 48.99%
# Validation Accuracy: 47.28%
# Batch: 0, Loss: 1.5671781301498413
#
# Average loss: 1.5150, Accuracy: 573.0/790 (73%)
#
#
# Average loss: 1.5176, Accuracy: 2069.0/2940 (70%)
#
# Epoch: 1 	Training Accuracy: 72.53%
# Validation Accuracy: 70.37%
# Batch: 0, Loss: 1.5095911026000977
#
# Average loss: 1.4627, Accuracy: 597.0/790 (76%)
#
#
# Average loss: 1.4639, Accuracy: 2170.0/2940 (74%)
#
# Epoch: 2 	Training Accuracy: 75.57%
# Validation Accuracy: 73.81%
# Batch: 0, Loss: 1.463940978050232
#
# Average loss: 1.4075, Accuracy: 622.0/790 (79%)
#
#
# Average loss: 1.4082, Accuracy: 2287.0/2940 (78%)
#
# Epoch: 3 	Training Accuracy: 78.73%
# Validation Accuracy: 77.79%
# Batch: 0, Loss: 1.4033766984939575
#
# Average loss: 1.3480, Accuracy: 654.0/790 (83%)
#
#
# Average loss: 1.3498, Accuracy: 2419.0/2940 (82%)
#
# Epoch: 4 	Training Accuracy: 82.78%
# Validation Accuracy: 82.28%
# Batch: 0, Loss: 1.347385287284851
#
# Average loss: 1.2861, Accuracy: 679.0/790 (86%)
#
#
# Average loss: 1.2899, Accuracy: 2456.0/2940 (84%)
#
# Epoch: 5 	Training Accuracy: 85.95%
# Validation Accuracy: 83.54%
# Batch: 0, Loss: 1.2830076217651367
#
# Average loss: 1.2209, Accuracy: 682.0/790 (86%)
#
#
# Average loss: 1.2251, Accuracy: 2471.0/2940 (84%)
#
# Epoch: 6 	Training Accuracy: 86.33%
# Validation Accuracy: 84.05%
# Batch: 0, Loss: 1.1939668655395508
#
# Average loss: 1.1551, Accuracy: 682.0/790 (86%)
#
#
# Average loss: 1.1593, Accuracy: 2490.0/2940 (85%)
#
# Epoch: 7 	Training Accuracy: 86.33%
# Validation Accuracy: 84.69%
# Batch: 0, Loss: 1.1369781494140625
#
# Average loss: 1.0875, Accuracy: 708.0/790 (90%)
#
#
# Average loss: 1.0939, Accuracy: 2535.0/2940 (86%)
#
# Epoch: 8 	Training Accuracy: 89.62%
# Validation Accuracy: 86.22%
# Batch: 0, Loss: 1.0686447620391846
#
# Average loss: 1.0201, Accuracy: 729.0/790 (92%)
#
#
# Average loss: 1.0299, Accuracy: 2574.0/2940 (88%)
#
# Epoch: 9 	Training Accuracy: 92.28%
# Validation Accuracy: 87.55%
# Batch: 0, Loss: 1.0390806198120117
#
# Average loss: 0.9526, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.9642, Accuracy: 2565.0/2940 (87%)
#
# Epoch: 10 	Training Accuracy: 91.01%
# Validation Accuracy: 87.24%
# Batch: 0, Loss: 0.9444391131401062
#
# Average loss: 0.8870, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.8994, Accuracy: 2565.0/2940 (87%)
#
# Epoch: 11 	Training Accuracy: 90.76%
# Validation Accuracy: 87.24%
# Batch: 0, Loss: 0.8878703117370605
#
# Average loss: 0.8255, Accuracy: 703.0/790 (89%)
#
#
# Average loss: 0.8393, Accuracy: 2531.0/2940 (86%)
#
# Epoch: 12 	Training Accuracy: 88.99%
# Validation Accuracy: 86.09%
# Batch: 0, Loss: 0.8320732116699219
#
# Average loss: 0.7661, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.7845, Accuracy: 2568.0/2940 (87%)
#
# Epoch: 13 	Training Accuracy: 91.39%
# Validation Accuracy: 87.35%
# Batch: 0, Loss: 0.7560806274414062
#
# Average loss: 0.7117, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.7344, Accuracy: 2605.0/2940 (89%)
#
# Epoch: 14 	Training Accuracy: 93.42%
# Validation Accuracy: 88.61%
# Batch: 0, Loss: 0.7136668562889099
#
# Average loss: 0.6592, Accuracy: 730.0/790 (92%)
#
#
# Average loss: 0.6829, Accuracy: 2584.0/2940 (88%)
#
# Epoch: 15 	Training Accuracy: 92.41%
# Validation Accuracy: 87.89%
# Batch: 0, Loss: 0.6808153986930847
#
# Average loss: 0.6146, Accuracy: 732.0/790 (93%)
#
#
# Average loss: 0.6414, Accuracy: 2598.0/2940 (88%)
#
# Epoch: 16 	Training Accuracy: 92.66%
# Validation Accuracy: 88.37%
# Batch: 0, Loss: 0.627640426158905
#
# Average loss: 0.5715, Accuracy: 730.0/790 (92%)
#
#
# Average loss: 0.6021, Accuracy: 2605.0/2940 (89%)
#
# Epoch: 17 	Training Accuracy: 92.41%
# Validation Accuracy: 88.61%
# Batch: 0, Loss: 0.5342341661453247
#
# Average loss: 0.5333, Accuracy: 733.0/790 (93%)
#
#
# Average loss: 0.5664, Accuracy: 2602.0/2940 (89%)
#
# Epoch: 18 	Training Accuracy: 92.78%
# Validation Accuracy: 88.50%
# Batch: 0, Loss: 0.5322084426879883
#
# Average loss: 0.5000, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.5349, Accuracy: 2608.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 93.16%
# Validation Accuracy: 88.71%
#
# Average loss: 0.5000, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.5274, Accuracy: 4362.0/4861 (90%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 61 =========================
# Batch: 0, Loss: 1.6105479001998901
#
# Average loss: 1.5572, Accuracy: 421.0/790 (53%)
#
#
# Average loss: 1.5567, Accuracy: 1607.0/2940 (55%)
#
# Epoch: 0 	Training Accuracy: 53.29%
# Validation Accuracy: 54.66%
# Batch: 0, Loss: 1.557733416557312
#
# Average loss: 1.5073, Accuracy: 587.0/790 (74%)
#
#
# Average loss: 1.5088, Accuracy: 2178.0/2940 (74%)
#
# Epoch: 1 	Training Accuracy: 74.30%
# Validation Accuracy: 74.08%
# Batch: 0, Loss: 1.5124824047088623
#
# Average loss: 1.4556, Accuracy: 643.0/790 (81%)
#
#
# Average loss: 1.4596, Accuracy: 2380.0/2940 (81%)
#
# Epoch: 2 	Training Accuracy: 81.39%
# Validation Accuracy: 80.95%
# Batch: 0, Loss: 1.4542009830474854
#
# Average loss: 1.4016, Accuracy: 669.0/790 (85%)
#
#
# Average loss: 1.4073, Accuracy: 2446.0/2940 (83%)
#
# Epoch: 3 	Training Accuracy: 84.68%
# Validation Accuracy: 83.20%
# Batch: 0, Loss: 1.3914527893066406
#
# Average loss: 1.3434, Accuracy: 667.0/790 (84%)
#
#
# Average loss: 1.3496, Accuracy: 2429.0/2940 (83%)
#
# Epoch: 4 	Training Accuracy: 84.43%
# Validation Accuracy: 82.62%
# Batch: 0, Loss: 1.3405510187149048
#
# Average loss: 1.2836, Accuracy: 647.0/790 (82%)
#
#
# Average loss: 1.2907, Accuracy: 2367.0/2940 (81%)
#
# Epoch: 5 	Training Accuracy: 81.90%
# Validation Accuracy: 80.51%
# Batch: 0, Loss: 1.2739429473876953
#
# Average loss: 1.2189, Accuracy: 674.0/790 (85%)
#
#
# Average loss: 1.2301, Accuracy: 2460.0/2940 (84%)
#
# Epoch: 6 	Training Accuracy: 85.32%
# Validation Accuracy: 83.67%
# Batch: 0, Loss: 1.2216439247131348
#
# Average loss: 1.1534, Accuracy: 691.0/790 (87%)
#
#
# Average loss: 1.1689, Accuracy: 2517.0/2940 (86%)
#
# Epoch: 7 	Training Accuracy: 87.47%
# Validation Accuracy: 85.61%
# Batch: 0, Loss: 1.1414328813552856
#
# Average loss: 1.0856, Accuracy: 694.0/790 (88%)
#
#
# Average loss: 1.1028, Accuracy: 2515.0/2940 (86%)
#
# Epoch: 8 	Training Accuracy: 87.85%
# Validation Accuracy: 85.54%
# Batch: 0, Loss: 1.0786070823669434
#
# Average loss: 1.0182, Accuracy: 696.0/790 (88%)
#
#
# Average loss: 1.0381, Accuracy: 2502.0/2940 (85%)
#
# Epoch: 9 	Training Accuracy: 88.10%
# Validation Accuracy: 85.10%
# Batch: 0, Loss: 1.0297772884368896
#
# Average loss: 0.9512, Accuracy: 697.0/790 (88%)
#
#
# Average loss: 0.9736, Accuracy: 2503.0/2940 (85%)
#
# Epoch: 10 	Training Accuracy: 88.23%
# Validation Accuracy: 85.14%
# Batch: 0, Loss: 0.925361156463623
#
# Average loss: 0.8855, Accuracy: 705.0/790 (89%)
#
#
# Average loss: 0.9124, Accuracy: 2532.0/2940 (86%)
#
# Epoch: 11 	Training Accuracy: 89.24%
# Validation Accuracy: 86.12%
# Batch: 0, Loss: 0.9038314819335938
#
# Average loss: 0.8233, Accuracy: 712.0/790 (90%)
#
#
# Average loss: 0.8542, Accuracy: 2562.0/2940 (87%)
#
# Epoch: 12 	Training Accuracy: 90.13%
# Validation Accuracy: 87.14%
# Batch: 0, Loss: 0.8027291893959045
#
# Average loss: 0.7649, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.7982, Accuracy: 2562.0/2940 (87%)
#
# Epoch: 13 	Training Accuracy: 91.01%
# Validation Accuracy: 87.14%
# Batch: 0, Loss: 0.753662645816803
#
# Average loss: 0.7076, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.7431, Accuracy: 2573.0/2940 (88%)
#
# Epoch: 14 	Training Accuracy: 91.01%
# Validation Accuracy: 87.52%
# Batch: 0, Loss: 0.7506216764450073
#
# Average loss: 0.6571, Accuracy: 711.0/790 (90%)
#
#
# Average loss: 0.6936, Accuracy: 2570.0/2940 (87%)
#
# Epoch: 15 	Training Accuracy: 90.00%
# Validation Accuracy: 87.41%
# Batch: 0, Loss: 0.6827090978622437
#
# Average loss: 0.6096, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.6508, Accuracy: 2580.0/2940 (88%)
#
# Epoch: 16 	Training Accuracy: 90.76%
# Validation Accuracy: 87.76%
# Batch: 0, Loss: 0.6042945981025696
#
# Average loss: 0.5703, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.6139, Accuracy: 2580.0/2940 (88%)
#
# Epoch: 17 	Training Accuracy: 91.39%
# Validation Accuracy: 87.76%
# Batch: 0, Loss: 0.5553081035614014
#
# Average loss: 0.5309, Accuracy: 720.0/790 (91%)
#
#
# Average loss: 0.5783, Accuracy: 2586.0/2940 (88%)
#
# Epoch: 18 	Training Accuracy: 91.14%
# Validation Accuracy: 87.96%
# Batch: 0, Loss: 0.5177491307258606
#
# Average loss: 0.4975, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.5431, Accuracy: 2596.0/2940 (88%)
#
# Epoch: 19 	Training Accuracy: 90.76%
# Validation Accuracy: 88.30%
#
# Average loss: 0.4975, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.5369, Accuracy: 4341.0/4861 (89%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 96 =========================
# Batch: 0, Loss: 1.596567153930664
#
# Average loss: 1.5529, Accuracy: 404.0/790 (51%)
#
#
# Average loss: 1.5499, Accuracy: 1484.0/2940 (50%)
#
# Epoch: 0 	Training Accuracy: 51.14%
# Validation Accuracy: 50.48%
# Batch: 0, Loss: 1.5397412776947021
#
# Average loss: 1.5045, Accuracy: 523.0/790 (66%)
#
#
# Average loss: 1.5048, Accuracy: 1968.0/2940 (67%)
#
# Epoch: 1 	Training Accuracy: 66.20%
# Validation Accuracy: 66.94%
# Batch: 0, Loss: 1.5025335550308228
#
# Average loss: 1.4540, Accuracy: 619.0/790 (78%)
#
#
# Average loss: 1.4569, Accuracy: 2288.0/2940 (78%)
#
# Epoch: 2 	Training Accuracy: 78.35%
# Validation Accuracy: 77.82%
# Batch: 0, Loss: 1.4503480195999146
#
# Average loss: 1.3998, Accuracy: 659.0/790 (83%)
#
#
# Average loss: 1.4038, Accuracy: 2450.0/2940 (83%)
#
# Epoch: 3 	Training Accuracy: 83.42%
# Validation Accuracy: 83.33%
# Batch: 0, Loss: 1.4032701253890991
#
# Average loss: 1.3426, Accuracy: 673.0/790 (85%)
#
#
# Average loss: 1.3471, Accuracy: 2451.0/2940 (83%)
#
# Epoch: 4 	Training Accuracy: 85.19%
# Validation Accuracy: 83.37%
# Batch: 0, Loss: 1.3327596187591553
#
# Average loss: 1.2825, Accuracy: 677.0/790 (86%)
#
#
# Average loss: 1.2884, Accuracy: 2467.0/2940 (84%)
#
# Epoch: 5 	Training Accuracy: 85.70%
# Validation Accuracy: 83.91%
# Batch: 0, Loss: 1.2906211614608765
#
# Average loss: 1.2183, Accuracy: 692.0/790 (88%)
#
#
# Average loss: 1.2252, Accuracy: 2496.0/2940 (85%)
#
# Epoch: 6 	Training Accuracy: 87.59%
# Validation Accuracy: 84.90%
# Batch: 0, Loss: 1.2130279541015625
#
# Average loss: 1.1526, Accuracy: 676.0/790 (86%)
#
#
# Average loss: 1.1612, Accuracy: 2448.0/2940 (83%)
#
# Epoch: 7 	Training Accuracy: 85.57%
# Validation Accuracy: 83.27%
# Batch: 0, Loss: 1.1695942878723145
#
# Average loss: 1.0848, Accuracy: 692.0/790 (88%)
#
#
# Average loss: 1.0974, Accuracy: 2517.0/2940 (86%)
#
# Epoch: 8 	Training Accuracy: 87.59%
# Validation Accuracy: 85.61%
# Batch: 0, Loss: 1.0555312633514404
#
# Average loss: 1.0171, Accuracy: 707.0/790 (89%)
#
#
# Average loss: 1.0332, Accuracy: 2545.0/2940 (87%)
#
# Epoch: 9 	Training Accuracy: 89.49%
# Validation Accuracy: 86.56%
# Batch: 0, Loss: 0.9969230890274048
#
# Average loss: 0.9500, Accuracy: 715.0/790 (91%)
#
#
# Average loss: 0.9709, Accuracy: 2559.0/2940 (87%)
#
# Epoch: 10 	Training Accuracy: 90.51%
# Validation Accuracy: 87.04%
# Batch: 0, Loss: 0.9690559506416321
#
# Average loss: 0.8849, Accuracy: 721.0/790 (91%)
#
#
# Average loss: 0.9082, Accuracy: 2559.0/2940 (87%)
#
# Epoch: 11 	Training Accuracy: 91.27%
# Validation Accuracy: 87.04%
# Batch: 0, Loss: 0.905539333820343
#
# Average loss: 0.8213, Accuracy: 715.0/790 (91%)
#
#
# Average loss: 0.8453, Accuracy: 2556.0/2940 (87%)
#
# Epoch: 12 	Training Accuracy: 90.51%
# Validation Accuracy: 86.94%
# Batch: 0, Loss: 0.8573600649833679
#
# Average loss: 0.7628, Accuracy: 708.0/790 (90%)
#
#
# Average loss: 0.7890, Accuracy: 2557.0/2940 (87%)
#
# Epoch: 13 	Training Accuracy: 89.62%
# Validation Accuracy: 86.97%
# Batch: 0, Loss: 0.7655611634254456
#
# Average loss: 0.7071, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.7371, Accuracy: 2567.0/2940 (87%)
#
# Epoch: 14 	Training Accuracy: 91.01%
# Validation Accuracy: 87.31%
# Batch: 0, Loss: 0.7117751240730286
#
# Average loss: 0.6562, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.6937, Accuracy: 2580.0/2940 (88%)
#
# Epoch: 15 	Training Accuracy: 91.39%
# Validation Accuracy: 87.76%
# Batch: 0, Loss: 0.6599302291870117
#
# Average loss: 0.6136, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.6560, Accuracy: 2579.0/2940 (88%)
#
# Epoch: 16 	Training Accuracy: 90.76%
# Validation Accuracy: 87.72%
# Batch: 0, Loss: 0.6002156734466553
#
# Average loss: 0.5657, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.6073, Accuracy: 2592.0/2940 (88%)
#
# Epoch: 17 	Training Accuracy: 92.15%
# Validation Accuracy: 88.16%
# Batch: 0, Loss: 0.6108959317207336
#
# Average loss: 0.5371, Accuracy: 724.0/790 (92%)
#
#
# Average loss: 0.5793, Accuracy: 2567.0/2940 (87%)
#
# Epoch: 18 	Training Accuracy: 91.65%
# Validation Accuracy: 87.31%
# Batch: 0, Loss: 0.5484676957130432
#
# Average loss: 0.4950, Accuracy: 729.0/790 (92%)
#
#
# Average loss: 0.5414, Accuracy: 2596.0/2940 (88%)
#
# Epoch: 19 	Training Accuracy: 92.28%
# Validation Accuracy: 88.30%
#
# Average loss: 0.4950, Accuracy: 729.0/790 (92%)
#
#
# Average loss: 0.5349, Accuracy: 4342.0/4861 (89%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 32 =========================
# Batch: 0, Loss: 1.6022249460220337
#
# Average loss: 1.5573, Accuracy: 323.0/790 (41%)
#
#
# Average loss: 1.5594, Accuracy: 1140.0/2940 (39%)
#
# Epoch: 0 	Training Accuracy: 40.89%
# Validation Accuracy: 38.78%
# Batch: 0, Loss: 1.5531028509140015
#
# Average loss: 1.5097, Accuracy: 463.0/790 (59%)
#
#
# Average loss: 1.5124, Accuracy: 1707.0/2940 (58%)
#
# Epoch: 1 	Training Accuracy: 58.61%
# Validation Accuracy: 58.06%
# Batch: 0, Loss: 1.510843276977539
#
# Average loss: 1.4576, Accuracy: 621.0/790 (79%)
#
#
# Average loss: 1.4618, Accuracy: 2273.0/2940 (77%)
#
# Epoch: 2 	Training Accuracy: 78.61%
# Validation Accuracy: 77.31%
# Batch: 0, Loss: 1.4478079080581665
#
# Average loss: 1.4027, Accuracy: 632.0/790 (80%)
#
#
# Average loss: 1.4076, Accuracy: 2316.0/2940 (79%)
#
# Epoch: 3 	Training Accuracy: 80.00%
# Validation Accuracy: 78.78%
# Batch: 0, Loss: 1.4152108430862427
#
# Average loss: 1.3450, Accuracy: 650.0/790 (82%)
#
#
# Average loss: 1.3521, Accuracy: 2368.0/2940 (81%)
#
# Epoch: 4 	Training Accuracy: 82.28%
# Validation Accuracy: 80.54%
# Batch: 0, Loss: 1.344700813293457
#
# Average loss: 1.2840, Accuracy: 679.0/790 (86%)
#
#
# Average loss: 1.2935, Accuracy: 2466.0/2940 (84%)
#
# Epoch: 5 	Training Accuracy: 85.95%
# Validation Accuracy: 83.88%
# Batch: 0, Loss: 1.2830629348754883
#
# Average loss: 1.2206, Accuracy: 676.0/790 (86%)
#
#
# Average loss: 1.2318, Accuracy: 2472.0/2940 (84%)
#
# Epoch: 6 	Training Accuracy: 85.57%
# Validation Accuracy: 84.08%
# Batch: 0, Loss: 1.1995604038238525
#
# Average loss: 1.1535, Accuracy: 691.0/790 (87%)
#
#
# Average loss: 1.1682, Accuracy: 2510.0/2940 (85%)
#
# Epoch: 7 	Training Accuracy: 87.47%
# Validation Accuracy: 85.37%
# Batch: 0, Loss: 1.126076579093933
#
# Average loss: 1.0861, Accuracy: 692.0/790 (88%)
#
#
# Average loss: 1.1028, Accuracy: 2515.0/2940 (86%)
#
# Epoch: 8 	Training Accuracy: 87.59%
# Validation Accuracy: 85.54%
# Batch: 0, Loss: 1.0893946886062622
#
# Average loss: 1.0190, Accuracy: 685.0/790 (87%)
#
#
# Average loss: 1.0364, Accuracy: 2508.0/2940 (85%)
#
# Epoch: 9 	Training Accuracy: 86.71%
# Validation Accuracy: 85.31%
# Batch: 0, Loss: 0.9783273935317993
#
# Average loss: 0.9514, Accuracy: 702.0/790 (89%)
#
#
# Average loss: 0.9734, Accuracy: 2552.0/2940 (87%)
#
# Epoch: 10 	Training Accuracy: 88.86%
# Validation Accuracy: 86.80%
# Batch: 0, Loss: 0.9978633522987366
#
# Average loss: 0.8882, Accuracy: 705.0/790 (89%)
#
#
# Average loss: 0.9175, Accuracy: 2555.0/2940 (87%)
#
# Epoch: 11 	Training Accuracy: 89.24%
# Validation Accuracy: 86.90%
# Batch: 0, Loss: 0.8528450727462769
#
# Average loss: 0.8243, Accuracy: 702.0/790 (89%)
#
#
# Average loss: 0.8534, Accuracy: 2558.0/2940 (87%)
#
# Epoch: 12 	Training Accuracy: 88.86%
# Validation Accuracy: 87.01%
# Batch: 0, Loss: 0.8069901466369629
#
# Average loss: 0.7631, Accuracy: 711.0/790 (90%)
#
#
# Average loss: 0.7950, Accuracy: 2580.0/2940 (88%)
#
# Epoch: 13 	Training Accuracy: 90.00%
# Validation Accuracy: 87.76%
# Batch: 0, Loss: 0.7723184823989868
#
# Average loss: 0.7072, Accuracy: 723.0/790 (92%)
#
#
# Average loss: 0.7421, Accuracy: 2590.0/2940 (88%)
#
# Epoch: 14 	Training Accuracy: 91.52%
# Validation Accuracy: 88.10%
# Batch: 0, Loss: 0.7141080498695374
#
# Average loss: 0.6551, Accuracy: 716.0/790 (91%)
#
#
# Average loss: 0.6943, Accuracy: 2578.0/2940 (88%)
#
# Epoch: 15 	Training Accuracy: 90.63%
# Validation Accuracy: 87.69%
# Batch: 0, Loss: 0.6535929441452026
#
# Average loss: 0.6086, Accuracy: 711.0/790 (90%)
#
#
# Average loss: 0.6515, Accuracy: 2581.0/2940 (88%)
#
# Epoch: 16 	Training Accuracy: 90.00%
# Validation Accuracy: 87.79%
# Batch: 0, Loss: 0.6358212828636169
#
# Average loss: 0.5680, Accuracy: 723.0/790 (92%)
#
#
# Average loss: 0.6145, Accuracy: 2585.0/2940 (88%)
#
# Epoch: 17 	Training Accuracy: 91.52%
# Validation Accuracy: 87.93%
# Batch: 0, Loss: 0.5689636468887329
#
# Average loss: 0.5298, Accuracy: 734.0/790 (93%)
#
#
# Average loss: 0.5785, Accuracy: 2604.0/2940 (89%)
#
# Epoch: 18 	Training Accuracy: 92.91%
# Validation Accuracy: 88.57%
# Batch: 0, Loss: 0.5799583792686462
#
# Average loss: 0.4936, Accuracy: 729.0/790 (92%)
#
#
# Average loss: 0.5436, Accuracy: 2608.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 92.28%
# Validation Accuracy: 88.71%
#
# Average loss: 0.4936, Accuracy: 729.0/790 (92%)
#
#
# Average loss: 0.5391, Accuracy: 4359.0/4861 (90%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 63 =========================
# Batch: 0, Loss: 1.5894054174423218
#
# Average loss: 1.5380, Accuracy: 516.0/790 (65%)
#
#
# Average loss: 1.5383, Accuracy: 1891.0/2940 (64%)
#
# Epoch: 0 	Training Accuracy: 65.32%
# Validation Accuracy: 64.32%
# Batch: 0, Loss: 1.5312440395355225
#
# Average loss: 1.4862, Accuracy: 631.0/790 (80%)
#
#
# Average loss: 1.4874, Accuracy: 2331.0/2940 (79%)
#
# Epoch: 1 	Training Accuracy: 79.87%
# Validation Accuracy: 79.29%
# Batch: 0, Loss: 1.479237675666809
#
# Average loss: 1.4321, Accuracy: 671.0/790 (85%)
#
#
# Average loss: 1.4339, Accuracy: 2487.0/2940 (85%)
#
# Epoch: 2 	Training Accuracy: 84.94%
# Validation Accuracy: 84.59%
# Batch: 0, Loss: 1.4262456893920898
#
# Average loss: 1.3747, Accuracy: 668.0/790 (85%)
#
#
# Average loss: 1.3758, Accuracy: 2468.0/2940 (84%)
#
# Epoch: 3 	Training Accuracy: 84.56%
# Validation Accuracy: 83.95%
# Batch: 0, Loss: 1.3691911697387695
#
# Average loss: 1.3157, Accuracy: 677.0/790 (86%)
#
#
# Average loss: 1.3190, Accuracy: 2485.0/2940 (85%)
#
# Epoch: 4 	Training Accuracy: 85.70%
# Validation Accuracy: 84.52%
# Batch: 0, Loss: 1.3238660097122192
#
# Average loss: 1.2533, Accuracy: 703.0/790 (89%)
#
#
# Average loss: 1.2571, Accuracy: 2542.0/2940 (86%)
#
# Epoch: 5 	Training Accuracy: 88.99%
# Validation Accuracy: 86.46%
# Batch: 0, Loss: 1.2497055530548096
#
# Average loss: 1.1882, Accuracy: 698.0/790 (88%)
#
#
# Average loss: 1.1936, Accuracy: 2543.0/2940 (86%)
#
# Epoch: 6 	Training Accuracy: 88.35%
# Validation Accuracy: 86.50%
# Batch: 0, Loss: 1.1829930543899536
#
# Average loss: 1.1210, Accuracy: 702.0/790 (89%)
#
#
# Average loss: 1.1279, Accuracy: 2571.0/2940 (87%)
#
# Epoch: 7 	Training Accuracy: 88.86%
# Validation Accuracy: 87.45%
# Batch: 0, Loss: 1.103301763534546
#
# Average loss: 1.0534, Accuracy: 705.0/790 (89%)
#
#
# Average loss: 1.0615, Accuracy: 2548.0/2940 (87%)
#
# Epoch: 8 	Training Accuracy: 89.24%
# Validation Accuracy: 86.67%
# Batch: 0, Loss: 1.0642566680908203
#
# Average loss: 0.9857, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.9962, Accuracy: 2570.0/2940 (87%)
#
# Epoch: 9 	Training Accuracy: 90.38%
# Validation Accuracy: 87.41%
# Batch: 0, Loss: 0.9770307540893555
#
# Average loss: 0.9217, Accuracy: 701.0/790 (89%)
#
#
# Average loss: 0.9327, Accuracy: 2518.0/2940 (86%)
#
# Epoch: 10 	Training Accuracy: 88.73%
# Validation Accuracy: 85.65%
# Batch: 0, Loss: 0.9157284498214722
#
# Average loss: 0.8587, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.8734, Accuracy: 2575.0/2940 (88%)
#
# Epoch: 11 	Training Accuracy: 90.76%
# Validation Accuracy: 87.59%
# Batch: 0, Loss: 0.8625633716583252
#
# Average loss: 0.8038, Accuracy: 702.0/790 (89%)
#
#
# Average loss: 0.8214, Accuracy: 2538.0/2940 (86%)
#
# Epoch: 12 	Training Accuracy: 88.86%
# Validation Accuracy: 86.33%
# Batch: 0, Loss: 0.8557590246200562
#
# Average loss: 0.7411, Accuracy: 724.0/790 (92%)
#
#
# Average loss: 0.7635, Accuracy: 2594.0/2940 (88%)
#
# Epoch: 13 	Training Accuracy: 91.65%
# Validation Accuracy: 88.23%
# Batch: 0, Loss: 0.7825731635093689
#
# Average loss: 0.6937, Accuracy: 722.0/790 (91%)
#
#
# Average loss: 0.7211, Accuracy: 2585.0/2940 (88%)
#
# Epoch: 14 	Training Accuracy: 91.39%
# Validation Accuracy: 87.93%
# Batch: 0, Loss: 0.6686687469482422
#
# Average loss: 0.6402, Accuracy: 726.0/790 (92%)
#
#
# Average loss: 0.6686, Accuracy: 2614.0/2940 (89%)
#
# Epoch: 15 	Training Accuracy: 91.90%
# Validation Accuracy: 88.91%
# Batch: 0, Loss: 0.5783528685569763
#
# Average loss: 0.5976, Accuracy: 721.0/790 (91%)
#
#
# Average loss: 0.6272, Accuracy: 2608.0/2940 (89%)
#
# Epoch: 16 	Training Accuracy: 91.27%
# Validation Accuracy: 88.71%
# Batch: 0, Loss: 0.581004798412323
#
# Average loss: 0.5552, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.5884, Accuracy: 2619.0/2940 (89%)
#
# Epoch: 17 	Training Accuracy: 92.15%
# Validation Accuracy: 89.08%
# Batch: 0, Loss: 0.5368618965148926
#
# Average loss: 0.5193, Accuracy: 725.0/790 (92%)
#
#
# Average loss: 0.5572, Accuracy: 2625.0/2940 (89%)
#
# Epoch: 18 	Training Accuracy: 91.77%
# Validation Accuracy: 89.29%
# Batch: 0, Loss: 0.5521190166473389
#
# Average loss: 0.4864, Accuracy: 731.0/790 (93%)
#
#
# Average loss: 0.5271, Accuracy: 2614.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 92.53%
# Validation Accuracy: 88.91%
#
# Average loss: 0.4864, Accuracy: 731.0/790 (93%)
#
#
# Average loss: 0.5248, Accuracy: 4358.0/4861 (90%)
# Running seeds for 0.05 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 94 =========================
# Batch: 0, Loss: 1.6008843183517456
#
# Average loss: 1.5366, Accuracy: 821.0/1320 (62%)
#
#
# Average loss: 1.5359, Accuracy: 1796.0/2940 (61%)
#
# Epoch: 0 	Training Accuracy: 62.20%
# Validation Accuracy: 61.09%
# Batch: 0, Loss: 1.535815715789795
#
# Average loss: 1.4608, Accuracy: 1086.0/1320 (82%)
#
#
# Average loss: 1.4615, Accuracy: 2353.0/2940 (80%)
#
# Epoch: 1 	Training Accuracy: 82.27%
# Validation Accuracy: 80.03%
# Batch: 0, Loss: 1.4658429622650146
#
# Average loss: 1.3758, Accuracy: 1133.0/1320 (86%)
#
#
# Average loss: 1.3780, Accuracy: 2467.0/2940 (84%)
#
# Epoch: 2 	Training Accuracy: 85.83%
# Validation Accuracy: 83.91%
# Batch: 0, Loss: 1.3774404525756836
#
# Average loss: 1.2816, Accuracy: 1129.0/1320 (86%)
#
#
# Average loss: 1.2827, Accuracy: 2454.0/2940 (83%)
#
# Epoch: 3 	Training Accuracy: 85.53%
# Validation Accuracy: 83.47%
# Batch: 0, Loss: 1.2862107753753662
#
# Average loss: 1.1799, Accuracy: 1143.0/1320 (87%)
#
#
# Average loss: 1.1823, Accuracy: 2482.0/2940 (84%)
#
# Epoch: 4 	Training Accuracy: 86.59%
# Validation Accuracy: 84.42%
# Batch: 0, Loss: 1.1688276529312134
#
# Average loss: 1.0731, Accuracy: 1159.0/1320 (88%)
#
#
# Average loss: 1.0781, Accuracy: 2524.0/2940 (86%)
#
# Epoch: 5 	Training Accuracy: 87.80%
# Validation Accuracy: 85.85%
# Batch: 0, Loss: 1.0530128479003906
#
# Average loss: 0.9658, Accuracy: 1190.0/1320 (90%)
#
#
# Average loss: 0.9732, Accuracy: 2573.0/2940 (88%)
#
# Epoch: 6 	Training Accuracy: 90.15%
# Validation Accuracy: 87.52%
# Batch: 0, Loss: 0.9437286853790283
#
# Average loss: 0.8624, Accuracy: 1185.0/1320 (90%)
#
#
# Average loss: 0.8735, Accuracy: 2569.0/2940 (87%)
#
# Epoch: 7 	Training Accuracy: 89.77%
# Validation Accuracy: 87.38%
# Batch: 0, Loss: 0.826438844203949
#
# Average loss: 0.7670, Accuracy: 1193.0/1320 (90%)
#
#
# Average loss: 0.7802, Accuracy: 2573.0/2940 (88%)
#
# Epoch: 8 	Training Accuracy: 90.38%
# Validation Accuracy: 87.52%
# Batch: 0, Loss: 0.8204498887062073
#
# Average loss: 0.6803, Accuracy: 1206.0/1320 (91%)
#
#
# Average loss: 0.6979, Accuracy: 2605.0/2940 (89%)
#
# Epoch: 9 	Training Accuracy: 91.36%
# Validation Accuracy: 88.61%
# Batch: 0, Loss: 0.7096592783927917
#
# Average loss: 0.6070, Accuracy: 1206.0/1320 (91%)
#
#
# Average loss: 0.6269, Accuracy: 2602.0/2940 (89%)
#
# Epoch: 10 	Training Accuracy: 91.36%
# Validation Accuracy: 88.50%
# Batch: 0, Loss: 0.6032847762107849
#
# Average loss: 0.5426, Accuracy: 1216.0/1320 (92%)
#
#
# Average loss: 0.5652, Accuracy: 2622.0/2940 (89%)
#
# Epoch: 11 	Training Accuracy: 92.12%
# Validation Accuracy: 89.18%
# Batch: 0, Loss: 0.6152256727218628
#
# Average loss: 0.4904, Accuracy: 1217.0/1320 (92%)
#
#
# Average loss: 0.5172, Accuracy: 2631.0/2940 (89%)
#
# Epoch: 12 	Training Accuracy: 92.20%
# Validation Accuracy: 89.49%
# Batch: 0, Loss: 0.5056917667388916
#
# Average loss: 0.4471, Accuracy: 1223.0/1320 (93%)
#
#
# Average loss: 0.4738, Accuracy: 2637.0/2940 (90%)
#
# Epoch: 13 	Training Accuracy: 92.65%
# Validation Accuracy: 89.69%
# Batch: 0, Loss: 0.43431299924850464
#
# Average loss: 0.4109, Accuracy: 1222.0/1320 (93%)
#
#
# Average loss: 0.4423, Accuracy: 2641.0/2940 (90%)
#
# Epoch: 14 	Training Accuracy: 92.58%
# Validation Accuracy: 89.83%
# Batch: 0, Loss: 0.44196537137031555
#
# Average loss: 0.3815, Accuracy: 1226.0/1320 (93%)
#
#
# Average loss: 0.4113, Accuracy: 2656.0/2940 (90%)
#
# ...
# Batch: 80, Loss: 0.1191670224070549
# Batch: 100, Loss: 0.1848442107439041
# Batch: 120, Loss: 0.1512962132692337
# Batch: 140, Loss: 0.15163519978523254
# Batch: 160, Loss: 0.0903431698679924
# Batch: 180, Loss: 0.18863555788993835
# Batch: 200, Loss: 0.28676116466522217
#
# Average loss: 0.1340, Accuracy: 24924.0/26038 (96%)
#
#
# Average loss: 0.1613, Accuracy: 2794.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 95.72%
# Validation Accuracy: 95.03%
# Batch: 0, Loss: 0.06532894819974899
# Batch: 20, Loss: 0.10160116851329803
# Batch: 40, Loss: 0.13654974102973938
# Batch: 60, Loss: 0.1257036030292511
# Batch: 80, Loss: 0.15065982937812805
# Batch: 100, Loss: 0.08204704523086548
# Batch: 120, Loss: 0.176621213555336
# Batch: 140, Loss: 0.17922838032245636
# Batch: 160, Loss: 0.12232916802167892
# Batch: 180, Loss: 0.14535333216190338
# Batch: 200, Loss: 0.12483180314302444
#
# Average loss: 0.1400, Accuracy: 24898.0/26038 (96%)
#
#
# Average loss: 0.1687, Accuracy: 2791.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 95.62%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.16481339931488037
# Batch: 20, Loss: 0.13691796362400055
# Batch: 40, Loss: 0.16752664744853973
# Batch: 60, Loss: 0.08131273835897446
# Batch: 80, Loss: 0.1334565281867981
# Batch: 100, Loss: 0.1907617598772049
# Batch: 120, Loss: 0.19480761885643005
# Batch: 140, Loss: 0.07436934858560562
# Batch: 160, Loss: 0.05194040760397911
# Batch: 180, Loss: 0.07828427851200104
# Batch: 200, Loss: 0.1561635434627533
#
# Average loss: 0.1312, Accuracy: 24927.0/26038 (96%)
#
#
# Average loss: 0.1573, Accuracy: 2797.0/2940 (95%)
#
# Epoch: 19 	Training Accuracy: 95.73%
# Validation Accuracy: 95.14%
#
# Average loss: 0.1312, Accuracy: 24927.0/26038 (96%)
#
#
# Average loss: 0.1453, Accuracy: 4637.0/4861 (95%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 90 =========================
# Batch: 0, Loss: 1.5904626846313477
# Batch: 20, Loss: 1.4556984901428223
# Batch: 40, Loss: 1.3366936445236206
# Batch: 60, Loss: 1.0840542316436768
# Batch: 80, Loss: 0.9150453209877014
# Batch: 100, Loss: 0.6819129586219788
# Batch: 120, Loss: 0.5914487242698669
# Batch: 140, Loss: 0.45960694551467896
# Batch: 160, Loss: 0.41799789667129517
# Batch: 180, Loss: 0.3496243357658386
# Batch: 200, Loss: 0.2976202070713043
#
# Average loss: 0.3314, Accuracy: 23904.0/26038 (92%)
#
#
# Average loss: 0.3483, Accuracy: 2659.0/2940 (90%)
#
# Epoch: 0 	Training Accuracy: 91.80%
# Validation Accuracy: 90.44%
# Batch: 0, Loss: 0.30483540892601013
# Batch: 20, Loss: 0.3230201303958893
# Batch: 40, Loss: 0.31398308277130127
# Batch: 60, Loss: 0.20443004369735718
# Batch: 80, Loss: 0.32903990149497986
# Batch: 100, Loss: 0.23446162045001984
# Batch: 120, Loss: 0.2267254889011383
# Batch: 140, Loss: 0.2064647227525711
# Batch: 160, Loss: 0.1592196822166443
# Batch: 180, Loss: 0.2844087779521942
# Batch: 200, Loss: 0.22445513308048248
#
# Average loss: 0.2281, Accuracy: 24141.0/26038 (93%)
#
#
# Average loss: 0.2491, Accuracy: 2701.0/2940 (92%)
#
# Epoch: 1 	Training Accuracy: 92.71%
# Validation Accuracy: 91.87%
# Batch: 0, Loss: 0.15995663404464722
# Batch: 20, Loss: 0.23419977724552155
# Batch: 40, Loss: 0.22208233177661896
# Batch: 60, Loss: 0.2524144947528839
# Batch: 80, Loss: 0.24348048865795135
# Batch: 100, Loss: 0.19984816014766693
# Batch: 120, Loss: 0.20553945004940033
# Batch: 140, Loss: 0.19232118129730225
# Batch: 160, Loss: 0.18228749930858612
# Batch: 180, Loss: 0.24012413620948792
# Batch: 200, Loss: 0.15807031095027924
#
# Average loss: 0.1931, Accuracy: 24406.0/26038 (94%)
#
#
# Average loss: 0.2161, Accuracy: 2731.0/2940 (93%)
#
# Epoch: 2 	Training Accuracy: 93.73%
# Validation Accuracy: 92.89%
# Batch: 0, Loss: 0.10912084579467773
# Batch: 20, Loss: 0.18773651123046875
# Batch: 40, Loss: 0.12523895502090454
# Batch: 60, Loss: 0.19220823049545288
# Batch: 80, Loss: 0.1947193741798401
# Batch: 100, Loss: 0.2822355628013611
# Batch: 120, Loss: 0.20503973960876465
# Batch: 140, Loss: 0.22454647719860077
# Batch: 160, Loss: 0.23089562356472015
# Batch: 180, Loss: 0.3173265755176544
# Batch: 200, Loss: 0.17067688703536987
#
# Average loss: 0.1802, Accuracy: 24547.0/26038 (94%)
#
#
# Average loss: 0.2050, Accuracy: 2748.0/2940 (93%)
#
# Epoch: 3 	Training Accuracy: 94.27%
# Validation Accuracy: 93.47%
# Batch: 0, Loss: 0.20467787981033325
# Batch: 20, Loss: 0.18555615842342377
# Batch: 40, Loss: 0.15778130292892456
# Batch: 60, Loss: 0.1469143182039261
# Batch: 80, Loss: 0.18880686163902283
# Batch: 100, Loss: 0.21552300453186035
# Batch: 120, Loss: 0.08710210770368576
# Batch: 140, Loss: 0.1836874783039093
# Batch: 160, Loss: 0.1978588104248047
# Batch: 180, Loss: 0.1088411808013916
# Batch: 200, Loss: 0.18184097111225128
#
# Average loss: 0.1719, Accuracy: 24556.0/26038 (94%)
#
#
# Average loss: 0.1954, Accuracy: 2747.0/2940 (93%)
#
# Epoch: 4 	Training Accuracy: 94.31%
# Validation Accuracy: 93.44%
# Batch: 0, Loss: 0.11208660900592804
# Batch: 20, Loss: 0.20200252532958984
# Batch: 40, Loss: 0.1900893896818161
# Batch: 60, Loss: 0.14583410322666168
# Batch: 80, Loss: 0.14566659927368164
# Batch: 100, Loss: 0.06168903037905693
# Batch: 120, Loss: 0.3059685528278351
# Batch: 140, Loss: 0.13851773738861084
# Batch: 160, Loss: 0.1280634105205536
# Batch: 180, Loss: 0.22941584885120392
# Batch: 200, Loss: 0.20114609599113464
#
# Average loss: 0.1672, Accuracy: 24615.0/26038 (95%)
#
#
# Average loss: 0.1931, Accuracy: 2757.0/2940 (94%)
#
# Epoch: 5 	Training Accuracy: 94.53%
# Validation Accuracy: 93.78%
# Batch: 0, Loss: 0.22480760514736176
# Batch: 20, Loss: 0.22081097960472107
# Batch: 40, Loss: 0.22115769982337952
# Batch: 60, Loss: 0.15960854291915894
# Batch: 80, Loss: 0.07629649341106415
# Batch: 100, Loss: 0.193923681974411
# Batch: 120, Loss: 0.1610693633556366
# Batch: 140, Loss: 0.15231283009052277
# Batch: 160, Loss: 0.2019921988248825
# Batch: 180, Loss: 0.13661059737205505
# Batch: 200, Loss: 0.23198767006397247
#
# Average loss: 0.1617, Accuracy: 24660.0/26038 (95%)
#
#
# Average loss: 0.1848, Accuracy: 2763.0/2940 (94%)
#
# Epoch: 6 	Training Accuracy: 94.71%
# Validation Accuracy: 93.98%
# Batch: 0, Loss: 0.10526479035615921
# Batch: 20, Loss: 0.1229449212551117
# Batch: 40, Loss: 0.19286209344863892
# Batch: 60, Loss: 0.18691454827785492
# Batch: 80, Loss: 0.17487885057926178
# Batch: 100, Loss: 0.12453702092170715
# Batch: 120, Loss: 0.1461213231086731
# Batch: 140, Loss: 0.1309993714094162
# Batch: 160, Loss: 0.0642673671245575
# Batch: 180, Loss: 0.1165771335363388
# Batch: 200, Loss: 0.1283886730670929
#
# Average loss: 0.1575, Accuracy: 24706.0/26038 (95%)
#
#
# Average loss: 0.1816, Accuracy: 2765.0/2940 (94%)
#
# Epoch: 7 	Training Accuracy: 94.88%
# Validation Accuracy: 94.05%
# Batch: 0, Loss: 0.2044406682252884
# Batch: 20, Loss: 0.18070442974567413
# Batch: 40, Loss: 0.13609908521175385
# Batch: 60, Loss: 0.09248722344636917
# Batch: 80, Loss: 0.05364316701889038
# Batch: 100, Loss: 0.150955468416214
# Batch: 120, Loss: 0.11362162977457047
# Batch: 140, Loss: 0.17682448029518127
# Batch: 160, Loss: 0.20127911865711212
# Batch: 180, Loss: 0.2530417740345001
# Batch: 200, Loss: 0.17186668515205383
#
# Average loss: 0.1578, Accuracy: 24673.0/26038 (95%)
#
#
# Average loss: 0.1819, Accuracy: 2762.0/2940 (94%)
#
# Epoch: 8 	Training Accuracy: 94.76%
# Validation Accuracy: 93.95%
# Batch: 0, Loss: 0.2494352012872696
# Batch: 20, Loss: 0.17737865447998047
# Batch: 40, Loss: 0.04319251328706741
# Batch: 60, Loss: 0.11771129071712494
# Batch: 80, Loss: 0.13930320739746094
# Batch: 100, Loss: 0.19184105098247528
# Batch: 120, Loss: 0.18473124504089355
# Batch: 140, Loss: 0.18442028760910034
# Batch: 160, Loss: 0.13923002779483795
# Batch: 180, Loss: 0.14225085079669952
# Batch: 200, Loss: 0.1295674741268158
#
# Average loss: 0.1511, Accuracy: 24750.0/26038 (95%)
#
#
# Average loss: 0.1755, Accuracy: 2773.0/2940 (94%)
#
# Epoch: 9 	Training Accuracy: 95.05%
# Validation Accuracy: 94.32%
# Batch: 0, Loss: 0.09636195749044418
# Batch: 20, Loss: 0.13329117000102997
# Batch: 40, Loss: 0.18188147246837616
# Batch: 60, Loss: 0.19059661030769348
# Batch: 80, Loss: 0.1987883746623993
# Batch: 100, Loss: 0.19246050715446472
# Batch: 120, Loss: 0.11972492933273315
# Batch: 140, Loss: 0.13080516457557678
# Batch: 160, Loss: 0.16255110502243042
# Batch: 180, Loss: 0.09201669692993164
# Batch: 200, Loss: 0.23136980831623077
#
# Average loss: 0.1476, Accuracy: 24803.0/26038 (95%)
#
#
# Average loss: 0.1741, Accuracy: 2783.0/2940 (95%)
#
# Epoch: 10 	Training Accuracy: 95.26%
# Validation Accuracy: 94.66%
# Batch: 0, Loss: 0.18409191071987152
# Batch: 20, Loss: 0.11350436508655548
# Batch: 40, Loss: 0.0870128646492958
# Batch: 60, Loss: 0.12386598438024521
# Batch: 80, Loss: 0.08459850400686264
# Batch: 100, Loss: 0.17490313947200775
# Batch: 120, Loss: 0.08905214816331863
# Batch: 140, Loss: 0.07842504978179932
# Batch: 160, Loss: 0.16914181411266327
# Batch: 180, Loss: 0.2152850478887558
# Batch: 200, Loss: 0.1280348151922226
#
# Average loss: 0.1436, Accuracy: 24821.0/26038 (95%)
#
#
# Average loss: 0.1700, Accuracy: 2784.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 95.33%
# Validation Accuracy: 94.69%
# Batch: 0, Loss: 0.15680639445781708
# Batch: 20, Loss: 0.10828401148319244
# Batch: 40, Loss: 0.09627231955528259
# Batch: 60, Loss: 0.14870014786720276
# Batch: 80, Loss: 0.1429613083600998
# Batch: 100, Loss: 0.07046745717525482
# Batch: 120, Loss: 0.08452513068914413
# Batch: 140, Loss: 0.08842942863702774
# Batch: 160, Loss: 0.09428094327449799
# Batch: 180, Loss: 0.16107413172721863
# Batch: 200, Loss: 0.14981241524219513
#
# Average loss: 0.1440, Accuracy: 24845.0/26038 (95%)
#
#
# Average loss: 0.1713, Accuracy: 2785.0/2940 (95%)
#
# Epoch: 12 	Training Accuracy: 95.42%
# Validation Accuracy: 94.73%
# Batch: 0, Loss: 0.1748504638671875
# Batch: 20, Loss: 0.13026399910449982
# Batch: 40, Loss: 0.11260803043842316
# Batch: 60, Loss: 0.10417477786540985
# Batch: 80, Loss: 0.2423287183046341
# Batch: 100, Loss: 0.215539813041687
# Batch: 120, Loss: 0.12285702675580978
# Batch: 140, Loss: 0.11182543635368347
# Batch: 160, Loss: 0.16797615587711334
# Batch: 180, Loss: 0.1541702002286911
# Batch: 200, Loss: 0.25783705711364746
#
# Average loss: 0.1414, Accuracy: 24825.0/26038 (95%)
#
#
# Average loss: 0.1663, Accuracy: 2791.0/2940 (95%)
#
# Epoch: 13 	Training Accuracy: 95.34%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.22855092585086823
# Batch: 20, Loss: 0.1789158582687378
# Batch: 40, Loss: 0.12606947124004364
# Batch: 60, Loss: 0.09520123153924942
# Batch: 80, Loss: 0.21362774074077606
# Batch: 100, Loss: 0.09594021737575531
# Batch: 120, Loss: 0.12055031955242157
# Batch: 140, Loss: 0.11003337800502777
# Batch: 160, Loss: 0.2172963172197342
# Batch: 180, Loss: 0.222659170627594
# Batch: 200, Loss: 0.1946238875389099
#
# Average loss: 0.1383, Accuracy: 24877.0/26038 (96%)
#
#
# Average loss: 0.1654, Accuracy: 2791.0/2940 (95%)
#
# Epoch: 14 	Training Accuracy: 95.54%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.1290586292743683
# Batch: 20, Loss: 0.06258593499660492
# Batch: 40, Loss: 0.04252781718969345
# Batch: 60, Loss: 0.15228645503520966
# Batch: 80, Loss: 0.11860869079828262
# Batch: 100, Loss: 0.12489937990903854
# Batch: 120, Loss: 0.16969656944274902
# Batch: 140, Loss: 0.1800869107246399
# Batch: 160, Loss: 0.117882639169693
# Batch: 180, Loss: 0.27066510915756226
# Batch: 200, Loss: 0.14178940653800964
#
# Average loss: 0.1409, Accuracy: 24881.0/26038 (96%)
#
#
# Average loss: 0.1686, Accuracy: 2783.0/2940 (95%)
#
# Epoch: 15 	Training Accuracy: 95.56%
# Validation Accuracy: 94.66%
# Batch: 0, Loss: 0.12425972521305084
# Batch: 20, Loss: 0.04841789975762367
# Batch: 40, Loss: 0.35591474175453186
# Batch: 60, Loss: 0.26289883255958557
# Batch: 80, Loss: 0.15521591901779175
# Batch: 100, Loss: 0.10951048135757446
# Batch: 120, Loss: 0.155981183052063
# Batch: 140, Loss: 0.2401762157678604
# Batch: 160, Loss: 0.13680124282836914
# Batch: 180, Loss: 0.18808425962924957
# Batch: 200, Loss: 0.12782537937164307
#
# Average loss: 0.1353, Accuracy: 24927.0/26038 (96%)
#
#
# Average loss: 0.1637, Accuracy: 2789.0/2940 (95%)
#
# Epoch: 16 	Training Accuracy: 95.73%
# Validation Accuracy: 94.86%
# Batch: 0, Loss: 0.11729365587234497
# Batch: 20, Loss: 0.2941889762878418
# Batch: 40, Loss: 0.09275773167610168
# Batch: 60, Loss: 0.15074293315410614
# Batch: 80, Loss: 0.08573730289936066
# Batch: 100, Loss: 0.19017061591148376
# Batch: 120, Loss: 0.15435338020324707
# Batch: 140, Loss: 0.11493366956710815
# Batch: 160, Loss: 0.1776023805141449
# Batch: 180, Loss: 0.09540161490440369
# Batch: 200, Loss: 0.10223213583230972
#
# Average loss: 0.1351, Accuracy: 24914.0/26038 (96%)
#
#
# Average loss: 0.1613, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 17 	Training Accuracy: 95.68%
# Validation Accuracy: 95.10%
# Batch: 0, Loss: 0.14438983798027039
# Batch: 20, Loss: 0.17452886700630188
# Batch: 40, Loss: 0.09891974925994873
# Batch: 60, Loss: 0.11556454002857208
# Batch: 80, Loss: 0.09630753099918365
# Batch: 100, Loss: 0.14060217142105103
# Batch: 120, Loss: 0.1529202163219452
# Batch: 140, Loss: 0.1443692296743393
# Batch: 160, Loss: 0.11267698556184769
# Batch: 180, Loss: 0.16132241487503052
# Batch: 200, Loss: 0.12883783876895905
#
# Average loss: 0.1378, Accuracy: 24873.0/26038 (96%)
#
#
# Average loss: 0.1636, Accuracy: 2788.0/2940 (95%)
#
# Epoch: 18 	Training Accuracy: 95.53%
# Validation Accuracy: 94.83%
# Batch: 0, Loss: 0.17668738961219788
# Batch: 20, Loss: 0.07505488395690918
# Batch: 40, Loss: 0.1398436278104782
# Batch: 60, Loss: 0.16136378049850464
# Batch: 80, Loss: 0.08514702320098877
# Batch: 100, Loss: 0.16053767502307892
# Batch: 120, Loss: 0.15234000980854034
# Batch: 140, Loss: 0.09179481118917465
# Batch: 160, Loss: 0.05161488801240921
# Batch: 180, Loss: 0.12356723845005035
# Batch: 200, Loss: 0.15161100029945374
#
# Average loss: 0.1303, Accuracy: 24951.0/26038 (96%)
#
#
# Average loss: 0.1573, Accuracy: 2796.0/2940 (95%)
#
# Epoch: 19 	Training Accuracy: 95.83%
# Validation Accuracy: 95.10%
#
# Average loss: 0.1303, Accuracy: 24951.0/26038 (96%)
#
#
# Average loss: 0.1451, Accuracy: 4637.0/4861 (95%)
#
# Percentage: 0.01, Seed: 10, Epochs taken: 20
# Percentage: 0.01, Seed: 20, Epochs taken: 19
# Percentage: 0.01, Seed: 30, Epochs taken: 20
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 15
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 20
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 20
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 20
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 20
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 20
# Percentage: 1, Seed: 40, Epochs taken: 20
# Percentage: 1, Seed: 50, Epochs taken: 20

# %%
# End to End - Train Accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Train Accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Train Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Train Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
# End to End - Test Accuracies
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]

plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Test Accuracies
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Test Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Test Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
data_to_save = {
    "results_test_finetune": results_test_finetune,
    "results_train_finetune": results_train_finetune,
    "epochs_taken_finetune": epochs_taken_finetune,
    
    "results_test": results_test,
    "results_train": results_train,
    "epochs_taken": epochs_taken
}

# Assuming data_to_save from the previous code
with open("data.json", "w") as file:
    json.dump(data_to_save, file)

# %%
plt.figure(figsize=(10, 6))

for perc in percentages:
    plt.scatter(epochs_taken[perc], epochs_taken_finetune[perc], label=f'{perc} data')
plt.xlabel('Epochs (End to End)')
plt.ylabel('Epochs (Finetune)')
plt.title('Scatter Plot Comparing Epochs Taken for Convergence')
plt.legend()
plt.show()

# %%
# Given data
percentages = list(epochs_taken.keys())

all_epochs = []
labels = []

for perc in percentages:
    all_epochs.extend([epochs_taken[perc], epochs_taken_finetune[perc]])
    labels.extend([f'{perc} End to End', f'{perc} Finetune'])

# Plotting
plt.figure(figsize=(10, 6))
box = plt.boxplot(all_epochs, labels=labels, patch_artist=True)

# Coloring
colors = ['skyblue', 'lightgreen'] * len(percentages)
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

plt.ylabel('Epochs Taken')
plt.title('Box Plot of Epochs Taken for Each Percentage')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ***EXPERIMENT SETUP***

# %% [markdown]
# - percentages_set_1 = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
# - dataset: same as before MNIST 5 to 5
#
# - lr pretraining = 0.001
# - lr finetuning = 0.0001
#
# - architecture:
#     - Conv 1 (5,5), channels=1
#     - Relu
#     - Conv 2 (5,5,), channels=1
#     - Relu
#     - Pooling: False
#     - dense( x, x) x=output shape of prev layer (128?)
#     - Relu
#     - dense(x, 5)
#     - softmax
#
# - Freezing: NO
#
# - Reinitializing CNN layers: No
# - Reinitializing Dense layers: Only last
# - Reinitializing softmax layers: Yes
#
# - If we don’t save the best model, ES=6
#
# - num train = 20

# %% [markdown]
# ***IMPORTS***

# %%
import numpy as np
import random
import copy
import matplotlib.pyplot as plt
import json
from tqdm.auto import tqdm

# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from torchvision import datasets, transforms

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from types import SimpleNamespace
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ***UTILS***

# %%
def eval(model, device, dataset_loader, debug=False, classification_report_flag=False, is_cnn=True, logger=print):

    """
    Evaluates the model on the given dataset loader.

    Parameters:
    - model: the PyTorch model to evaluate.
    - device: the device to which tensors should be moved before computation.
    - dataset_loader: DataLoader for evaluation.
    - debug: whether to print debug info like loss and accuracy.
    - classification_report_flag: whether to print a classification report.
    - is_cnn: a flag indicating if the model is a CNN. If it's not, the input data will be reshaped.
    - logger: logging function for printing messages.

    Returns:
    - Accuracy of the model on the provided dataset loader.

    Usage:
    - accuracy = eval(model, device, dataset_loader, debug=False, is_cnn=False, classification_report_flag=False)
    """

    model.eval()
    test_loss, correct = 0., 0.
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data, target in dataset_loader:
            if is_cnn:
              data = data.view(data.size(0), 1, 28, 28)
            else:
              data = data.reshape([data.shape[0], -1])
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(target.cpu().numpy())

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data

    if debug:
        logger('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(test_loss, correct, num_data, 100. * acc))

    if classification_report_flag:
        unique_labels = np.unique(all_labels).tolist()
        logger(classification_report(all_labels, all_preds, labels=unique_labels, target_names=[f'Class {i}' for i in unique_labels]))

    return acc

# %%
class Trainer:

    """
    A class for training and evaluating a model with early stopping and best model saving functionalities.

    Attributes:
    - model: PyTorch model to be trained and evaluated.
    - dataloader: Contains data loaders (train, validation, test) for training and evaluation.
    - params: Dictionary containing various hyperparameters and settings.
    - device: the device to which tensors should be moved before computation.
    - optimizer: The optimizer for training.
    - best_model_state: State dictionary of the best model.
    - max_val_acc: The highest validation accuracy encountered during training.
    - no_improve_epochs: Number of epochs without improvement in validation accuracy.
    - is_cnn: Flag indicating if the model is a CNN.
    - is_debug: Flag indicating if debug information should be printed.
    - classification_report_flag: Flag indicating if a classification report should be generated.

    Methods:
    - train_epoch(): Runs a single epoch of training.
    - evaluate(loader): Evaluates the model on a given data loader.
    - save_best_model(): Saves the current state of the model as the best model.
    - save_checkpoint(epoch, train_acc, val_acc): Saves the current state of the model and other information as a checkpoint.
    - early_stopping_check(val_acc): Checks the stopping criterion and performs actions based on it.
    - train(): Runs the training process for a number of epochs, with early stopping functionality.

    Usage:
    params = {
      'device': 'cuda',
      'lr': 0.001,
      'num_train': 10,
      'early_stop_patience': 3,
      'save_best': True,
      'save_checkpoints': False,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': True
    }

    trainer = Trainer(model, dataloader, params)
    train_acc, test_acc, effective_epochs, checkpoints = trainer.train()
    """


    def __init__(self, model, dataloader, params):
        self.model = model
        self.dataloader = dataloader
        self.params = params

        self.device = torch.device(params['device'])
        self.optimizer = optim.Adam(model.parameters(), lr=params['lr'])

        # Initialize best_model_state with the current model state
        self.best_model_state = copy.deepcopy(self.model.state_dict())
        self.max_val_acc = 0.
        self.no_improve_epochs = 0

        self.is_cnn = params.get('is_cnn', False)
        self.is_debug = params.get('is_debug', False)
        self.classification_report_flag = params.get('classification_report_flag', False)
        self.logger = params.get('logger', print)
        
    def train_epoch(self):
      self.model.train()
      for batch_idx, (data, target) in enumerate(self.dataloader.train_loader):

          # Print the size of the current batch
          if self.is_cnn:
            data = data.view(data.size(0), 1, 28, 28)
          else:
            data = data.reshape([data.shape[0], -1])

          data, target = data.to(self.device), target.to(self.device)
          self.optimizer.zero_grad()
          output = self.model(data)
          loss = F.nll_loss(output, target)
          loss.backward()
          self.optimizer.step()

          if self.is_debug and batch_idx % 20 == 0:
              self.logger(f"Batch: {batch_idx}, Loss: {loss.item()}")

    def evaluate(self, loader):
        return eval(self.model, self.device, loader, self.is_debug, self.classification_report_flag, self.is_cnn)

    def save_best_model(self):
        torch.save(self.model.state_dict(), 'best_model.pth')

    def save_checkpoint(self, epoch, train_acc, val_acc):
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'train_acc': train_acc,
            'val_acc': val_acc
        }
        torch.save(checkpoint, f'checkpoint_epoch_{epoch}.pth')
        return checkpoint

    def early_stopping_check(self, val_acc):
        if val_acc > self.max_val_acc:
            self.max_val_acc = val_acc
            self.no_improve_epochs = 0
            # Deep copy the model's state
            self.best_model_state = copy.deepcopy(self.model.state_dict())
            if self.params.get('save_best', False):
                self.save_best_model()
        else:
            self.no_improve_epochs += 1
            if self.no_improve_epochs >= self.params['early_stop_patience']:
                self.logger("Early stopping invoked.")
                # Only load if best_model_state has been set
                if self.best_model_state is not None:
                    self.model.load_state_dict(self.best_model_state)
                return True
        return False

    def train(self):
        effective_epochs = 0
        checkpoints = []

        for epoch in range(self.params['num_train']):
            effective_epochs += 1
            self.train_epoch()

            train_acc = self.evaluate(self.dataloader.train_loader)
            val_acc = self.evaluate(self.dataloader.val_loader)
            self.logger(f'Epoch: {epoch} \tTraining Accuracy: {train_acc*100:.2f}%')
            self.logger(f'Validation Accuracy: {val_acc*100:.2f}%')

            if self.params.get('early_stop_patience', None):
                if self.early_stopping_check(val_acc):
                    self.model.load_state_dict(self.best_model_state)
                    break

            if self.params.get('save_checkpoints', False):
                checkpoint = self.save_checkpoint(epoch, train_acc, val_acc)
                checkpoints.append(checkpoint)

        # Final evaluations
        train_acc = self.evaluate(self.dataloader.train_loader)
        test_acc = self.evaluate(self.dataloader.test_loader)

        return train_acc, test_acc, effective_epochs, checkpoints

# %%
def reduce_dataset(dataloader, percentage, balanced=True, seed=42):

    """
    Reduces the dataset to the given percentage. Can ensure class balance if needed.

    Parameters:
    - dataloader: PyTorch DataLoader object.
    - percentage: Desired percentage of the original dataset.
    - balanced: If True, ensures class balance. If False, reduces randomly.
    - seed: Seed for reproducibility.

    Returns:
    - reduced_dataloader: DataLoader with the reduced dataset.
    """
    # Extract the dataset from the dataloader
    dataset = dataloader.dataset

    # Extract all data and labels from the dataset
    X = [dataset[i][0] for i in range(len(dataset))]
    y = [dataset[i][1] for i in range(len(dataset))]

    # Set the seed for reproducibility
    torch.manual_seed(seed)

    if not balanced:
        # Determine the number of samples to keep
        num_samples = int(len(dataset) * percentage)

        # Randomly select indices without replacement
        indices = torch.randperm(len(dataset))[:num_samples].tolist()

    else:
        # Get unique classes and their counts
        classes, class_counts = torch.unique(torch.tensor(y), return_counts=True)

        # Determine the number of samples per class to keep
        num_samples_per_class = int(len(dataset) * percentage / len(classes))
        indices = []

        for class_label in classes:
            class_indices = [i for i, label in enumerate(y) if label == class_label]

            # Randomly select indices without replacement for each class
            class_selected_indices = torch.randperm(len(class_indices))[:num_samples_per_class].tolist()
            indices.extend([class_indices[i] for i in class_selected_indices])

    # Use a Subset of the original dataset to create a reduced dataset
    reduced_dataset = data.Subset(dataset, indices)

    # Create a DataLoader with the reduced dataset.
    reduced_dataloader = data.DataLoader(reduced_dataset, batch_size=dataloader.batch_size, shuffle=True)

    return reduced_dataloader

# %%
class RelabeledSubset(torch.utils.data.Dataset):
    def __init__(self, dataset, offset):
        self.dataset = dataset
        self.offset = offset

    def __getitem__(self, idx):
        data, label = self.dataset[idx]
        # Offset the label to start from 0
        label = label - self.offset
        return data, label

    def __len__(self):
        return len(self.dataset)

# %%
class TransferLearningMNIST(object):
    def __init__(self, batch_size, input_dim=28*28, val_split=0.1, num_workers=4):
        self.input_dim = input_dim
        self.output_dim = 10
        self.val_split = val_split

        def filter_dataset(dataset, classes):
            indices = [i for i, t in enumerate(dataset.targets) if t in classes]
            return torch.utils.data.Subset(dataset, indices)

        mnist_train_data = datasets.MNIST(
            '../data',
            train=True,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_train_data = filter_dataset(mnist_train_data, list(range(5)))
        finetune_train_data = filter_dataset(mnist_train_data, list(range(5, 10)))

        pretrain_len = len(pretrain_train_data)
        finetune_len = len(finetune_train_data)
        pretrain_val_len = int(val_split * pretrain_len)
        finetune_val_len = int(val_split * finetune_len)
        SEED = 42
        pretrain_train_set, pretrain_val_set = torch.utils.data.random_split(
            pretrain_train_data, [pretrain_len - pretrain_val_len, pretrain_val_len], generator=torch.Generator().manual_seed(SEED))
        finetune_train_set, finetune_val_set = torch.utils.data.random_split(
            finetune_train_data, [finetune_len - finetune_val_len, finetune_val_len], generator=torch.Generator().manual_seed(SEED))

        self.pretrain_train_loader = torch.utils.data.DataLoader(pretrain_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.pretrain_val_loader = torch.utils.data.DataLoader(pretrain_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning datasets
        finetune_train_set = RelabeledSubset(finetune_train_set, 5)
        finetune_val_set = RelabeledSubset(finetune_val_set, 5)

        self.finetune_train_loader = torch.utils.data.DataLoader(finetune_train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.finetune_val_loader = torch.utils.data.DataLoader(finetune_val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        mnist_test_data = datasets.MNIST(
            '../data',
            train=False,
            download=True,
            transform=transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: (x * 2 - 1) * 0.5),
            ]))

        pretrain_test_data = filter_dataset(mnist_test_data, list(range(5)))
        finetune_test_data = filter_dataset(mnist_test_data, list(range(5, 10)))

        self.pretrain_test_loader = torch.utils.data.DataLoader(pretrain_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)
        
        # Use the RelabeledSubset for fine-tuning test datasets
        finetune_test_data = RelabeledSubset(finetune_test_data, 5)
        self.finetune_test_loader = torch.utils.data.DataLoader(finetune_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

        # Complete test loader contains all test examples.
        self.complete_test_loader = torch.utils.data.DataLoader(mnist_test_data, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
class TransferLearningMNISTWrapper:
    """
    This wrapper class provides a convenient way to switch between pretraining and fine-tuning phases.

    It allows for changing the phase and accordingly updating the data loaders (train, val, test)
    to either pretraining or fine-tuning sets.
    """
    def __init__(self, transferLearningMNISTObj, phase):
        """
        Initializes the TransferLearningMNISTWrapper object.

        Parameters:
        - transferLearningMNISTObj: An instance of the TransferLearningMNIST class.
        - phase: String indicating the current phase ("pretrain" or "finetune").
        """
        self.transferLearningMNISTObj = transferLearningMNISTObj
        self.phase = phase
        self.input_dim = self.transferLearningMNISTObj.input_dim
        self.output_dim = self.transferLearningMNISTObj.output_dim
        self.update_phase(phase)

    def update_phase(self, phase):
        """
        Updates the phase and the corresponding data loaders.

        Parameters:
        - phase: String indicating the desired phase ("pretrain" or "finetune").

        Throws:
        - ValueError: If the phase is neither "pretrain" nor "finetune".
        """
        self.phase = phase
        if phase == 'pretrain':
            self.train_loader = self.transferLearningMNISTObj.pretrain_train_loader
            self.val_loader = self.transferLearningMNISTObj.pretrain_val_loader
            self.test_loader = self.transferLearningMNISTObj.pretrain_test_loader
        elif phase == 'finetune':
            self.train_loader = self.transferLearningMNISTObj.finetune_train_loader
            self.val_loader = self.transferLearningMNISTObj.finetune_val_loader
            self.test_loader = self.transferLearningMNISTObj.finetune_test_loader
        else:
            raise ValueError('Phase must be either "pretrain" or "finetune".')

    def get_current_phase(self):
      return self.phase

# %%
class CustomCNN(nn.Module):
    def __init__(self, input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling=False):
        super(CustomCNN, self).__init__()

        # Initial number of input channels, assuming grayscale images
        in_channels = 1

        # Dynamically add convolutional and activation layers based on the specified depth
        for i in range(depth):
            # Create a convolutional layer and add it to the model
            setattr(self, f"conv{i}", nn.Conv2d(in_channels, num_channels, kernel_size=kernel_size, padding=1))

            # Create an activation layer (e.g., ReLU) and add it to the model
            setattr(self, f"act{i}", activation_function())

            # Update the input dimensions after convolution
            input_dim = (input_dim - kernel_size + 2 * 1) + 1

            # Optionally add pooling layers to reduce spatial dimensions
            if use_pooling and i % 2 == 1:
                setattr(self, f"pool{i}", nn.MaxPool2d(2))
                input_dim = input_dim // 2

            # Update the input channels for the next convolutional layer
            in_channels = num_channels

        # Compute the size of the flattened features for the fully connected layer
        flattened_size = in_channels * input_dim * input_dim

        # Add two fully connected layers for classification
        self.fc_1 = nn.Linear(flattened_size, hidden_dim_lin)
        self.fc_2 = nn.Linear(hidden_dim_lin, output_dim)

        # Add log softmax layer for multi-class classification output
        self.logsoftmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
      # Iterate over each module in the CustomCNN class
      for layer_name, layer in self.named_children():
          # Process the input tensor through convolutional and activation layers
          if "conv" in layer_name or "act" in layer_name:
              x = layer(x)
          # Process the input tensor through pooling layers if they exist
          elif "pool" in layer_name:
              x = layer(x)
          # If reached fully connected layers, break the loop
          elif isinstance(layer, nn.Linear):
              break

      # Flatten the tensor to fit the input shape of the fully connected layers
      x = x.view(x.size(0), -1)
        
      # Save the flattened size for reinitializing layers later
      self.flattened_size = x.shape[1]

      # Pass the tensor through the fully connected layers
      x = self.fc_1(x)
      x = self.fc_2(x)

      # Return log softmax activated output
      return self.logsoftmax(x)

# %%
def generate_cnn(input_dim, output_dim, depth, num_channels, hidden_dim_lin, kernel_size, activation_function=nn.ReLU, use_pooling=False):
    model = CustomCNN(input_dim, output_dim, depth, num_channels, hidden_dim_lin, activation_function, kernel_size, use_pooling)
    return model

# %% [markdown]
# ***PRE-TRAINING***

# %%
batch_size = 128

dataloader = TransferLearningMNIST(batch_size)
dataloader_wrapped = TransferLearningMNISTWrapper(dataloader, phase = 'pretrain')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 161955316.46it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 52690601.92it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 30300695.74it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 7273970.51it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw

# %%
a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        break

# %%
params = {
      'depth': 2,
      'width': 1,
      'hidden_dim_lin': 128,
      'activation_function': nn.ReLU,
      'kernel_size': 5,
      'device': device,
      'lr': 0.001,
      'num_train': 20,
      'early_stop_patience': 6,
      'save_best': True,
      'save_checkpoints': True,
      'is_cnn': True,
      'is_debug': True,
      'classification_report_flag': False
    }

# Create DNN model
model = generate_cnn(input_dim = 28, output_dim = 10, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=False)
model.to(device)
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
model
# Out:
# CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
# Train and evaluate
trainer = Trainer(model, dataloader_wrapped, params)
train_acc, test_acc, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Batch: 0, Loss: 2.321122169494629
# Batch: 20, Loss: 0.9580217599868774
# Batch: 40, Loss: 0.3368486762046814
# Batch: 60, Loss: 0.24965354800224304
# Batch: 80, Loss: 0.14581593871116638
# Batch: 100, Loss: 0.1955774873495102
# Batch: 120, Loss: 0.19066007435321808
# Batch: 140, Loss: 0.17112337052822113
# Batch: 160, Loss: 0.15544380247592926
# Batch: 180, Loss: 0.22958073019981384
# Batch: 200, Loss: 0.2781550884246826
#
# Average loss: 0.1601, Accuracy: 26189.0/27537 (95%)
#
#
# Average loss: 0.1857, Accuracy: 2892.0/3059 (95%)
#
# Epoch: 0 	Training Accuracy: 95.10%
# Validation Accuracy: 94.54%
# Batch: 0, Loss: 0.08693250268697739
# Batch: 20, Loss: 0.17423047125339508
# Batch: 40, Loss: 0.10684534907341003
# Batch: 60, Loss: 0.22538743913173676
# Batch: 80, Loss: 0.11042643338441849
# Batch: 100, Loss: 0.0655040293931961
# Batch: 120, Loss: 0.1325475573539734
# Batch: 140, Loss: 0.10501155257225037
# Batch: 160, Loss: 0.1138734444975853
# Batch: 180, Loss: 0.11440719664096832
# Batch: 200, Loss: 0.24052323400974274
#
# Average loss: 0.1397, Accuracy: 26333.0/27537 (96%)
#
#
# Average loss: 0.1599, Accuracy: 2904.0/3059 (95%)
#
# Epoch: 1 	Training Accuracy: 95.63%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.13579919934272766
# Batch: 20, Loss: 0.09607798606157303
# Batch: 40, Loss: 0.1386425793170929
# Batch: 60, Loss: 0.1127946749329567
# Batch: 80, Loss: 0.1161935105919838
# Batch: 100, Loss: 0.2401069700717926
# Batch: 120, Loss: 0.20252962410449982
# Batch: 140, Loss: 0.1770460307598114
# Batch: 160, Loss: 0.06304863095283508
# Batch: 180, Loss: 0.12939536571502686
# Batch: 200, Loss: 0.13078655302524567
#
# Average loss: 0.1137, Accuracy: 26566.0/27537 (96%)
#
#
# Average loss: 0.1354, Accuracy: 2927.0/3059 (96%)
#
# Epoch: 2 	Training Accuracy: 96.47%
# Validation Accuracy: 95.68%
# Batch: 0, Loss: 0.10057329386472702
# Batch: 20, Loss: 0.1180511862039566
# Batch: 40, Loss: 0.13093210756778717
# Batch: 60, Loss: 0.07699679583311081
# Batch: 80, Loss: 0.1115545704960823
# Batch: 100, Loss: 0.05319049209356308
# Batch: 120, Loss: 0.11891357600688934
# Batch: 140, Loss: 0.12344693392515182
# Batch: 160, Loss: 0.10135877877473831
# Batch: 180, Loss: 0.147891566157341
# Batch: 200, Loss: 0.0510886125266552
#
# Average loss: 0.1026, Accuracy: 26656.0/27537 (97%)
#
#
# Average loss: 0.1224, Accuracy: 2941.0/3059 (96%)
#
# Epoch: 3 	Training Accuracy: 96.80%
# Validation Accuracy: 96.14%
# Batch: 0, Loss: 0.14363686740398407
# Batch: 20, Loss: 0.06441094726324081
# Batch: 40, Loss: 0.07078088074922562
# Batch: 60, Loss: 0.08465934544801712
# Batch: 80, Loss: 0.05259031429886818
# Batch: 100, Loss: 0.07253995537757874
# Batch: 120, Loss: 0.08665338158607483
# Batch: 140, Loss: 0.112846739590168
# Batch: 160, Loss: 0.07310960441827774
# Batch: 180, Loss: 0.036314159631729126
# Batch: 200, Loss: 0.1357286274433136
#
# Average loss: 0.1060, Accuracy: 26583.0/27537 (97%)
#
#
# Average loss: 0.1244, Accuracy: 2937.0/3059 (96%)
#
# Epoch: 4 	Training Accuracy: 96.54%
# Validation Accuracy: 96.01%
# Batch: 0, Loss: 0.1416173130273819
# Batch: 20, Loss: 0.1388252079486847
# Batch: 40, Loss: 0.09654086828231812
# Batch: 60, Loss: 0.12644541263580322
# Batch: 80, Loss: 0.09645126014947891
# Batch: 100, Loss: 0.04316464066505432
# Batch: 120, Loss: 0.06372275948524475
# Batch: 140, Loss: 0.1606214940547943
# Batch: 160, Loss: 0.09025689214468002
# Batch: 180, Loss: 0.15332676470279694
# Batch: 200, Loss: 0.13447019457817078
#
# Average loss: 0.0861, Accuracy: 26854.0/27537 (98%)
#
#
# Average loss: 0.1114, Accuracy: 2965.0/3059 (97%)
#
# Epoch: 5 	Training Accuracy: 97.52%
# Validation Accuracy: 96.93%
# Batch: 0, Loss: 0.05710897594690323
# Batch: 20, Loss: 0.14526362717151642
# Batch: 40, Loss: 0.06519880890846252
# Batch: 60, Loss: 0.18273285031318665
# Batch: 80, Loss: 0.06869543343782425
# Batch: 100, Loss: 0.10700824856758118
# Batch: 120, Loss: 0.09943286329507828
# Batch: 140, Loss: 0.039996419101953506
# Batch: 160, Loss: 0.07117608934640884
# Batch: 180, Loss: 0.0675610676407814
# Batch: 200, Loss: 0.059207484126091
#
# Average loss: 0.0877, Accuracy: 26851.0/27537 (98%)
#
#
# Average loss: 0.1092, Accuracy: 2961.0/3059 (97%)
#
# Epoch: 6 	Training Accuracy: 97.51%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.030111009255051613
# Batch: 20, Loss: 0.06504416465759277
# Batch: 40, Loss: 0.15975990891456604
# Batch: 60, Loss: 0.028796127066016197
# Batch: 80, Loss: 0.14355061948299408
# Batch: 100, Loss: 0.10950836539268494
# Batch: 120, Loss: 0.031000079587101936
# Batch: 140, Loss: 0.02614770643413067
# Batch: 160, Loss: 0.04411788284778595
# Batch: 180, Loss: 0.07960044592618942
# Batch: 200, Loss: 0.10783909261226654
#
# Average loss: 0.0740, Accuracy: 26971.0/27537 (98%)
#
#
# Average loss: 0.0996, Accuracy: 2974.0/3059 (97%)
#
# Epoch: 7 	Training Accuracy: 97.94%
# Validation Accuracy: 97.22%
# Batch: 0, Loss: 0.09873927384614944
# Batch: 20, Loss: 0.08257463574409485
# Batch: 40, Loss: 0.030445121228694916
# Batch: 60, Loss: 0.07865037024021149
# Batch: 80, Loss: 0.08567920327186584
# Batch: 100, Loss: 0.07259415090084076
# Batch: 120, Loss: 0.031639739871025085
# Batch: 140, Loss: 0.13555344939231873
# Batch: 160, Loss: 0.061745837330818176
# Batch: 180, Loss: 0.10292033851146698
# Batch: 200, Loss: 0.044976960867643356
#
# Average loss: 0.0665, Accuracy: 27006.0/27537 (98%)
#
#
# Average loss: 0.0902, Accuracy: 2983.0/3059 (98%)
#
# Epoch: 8 	Training Accuracy: 98.07%
# Validation Accuracy: 97.52%
# Batch: 0, Loss: 0.06595657020807266
# Batch: 20, Loss: 0.03161317855119705
# Batch: 40, Loss: 0.06753156334161758
# Batch: 60, Loss: 0.04457644000649452
# Batch: 80, Loss: 0.0726916491985321
# Batch: 100, Loss: 0.13036687672138214
# Batch: 120, Loss: 0.07244237512350082
# Batch: 140, Loss: 0.10008049756288528
# Batch: 160, Loss: 0.05820930004119873
# Batch: 180, Loss: 0.05161018669605255
# Batch: 200, Loss: 0.039752047508955
#
# Average loss: 0.0621, Accuracy: 26982.0/27537 (98%)
#
#
# Average loss: 0.0888, Accuracy: 2972.0/3059 (97%)
#
# Epoch: 9 	Training Accuracy: 97.98%
# Validation Accuracy: 97.16%
# Batch: 0, Loss: 0.027392158284783363
# Batch: 20, Loss: 0.06297950446605682
# Batch: 40, Loss: 0.10130628198385239
# Batch: 60, Loss: 0.07752753049135208
# Batch: 80, Loss: 0.0931287556886673
# Batch: 100, Loss: 0.04464513808488846
# Batch: 120, Loss: 0.08322212845087051
# Batch: 140, Loss: 0.057168204337358475
# Batch: 160, Loss: 0.07311204820871353
# Batch: 180, Loss: 0.06890568882226944
# Batch: 200, Loss: 0.04210938885807991
#
# Average loss: 0.0560, Accuracy: 27060.0/27537 (98%)
#
#
# Average loss: 0.0818, Accuracy: 2978.0/3059 (97%)
#
# Epoch: 10 	Training Accuracy: 98.27%
# Validation Accuracy: 97.35%
# Batch: 0, Loss: 0.044010262936353683
# Batch: 20, Loss: 0.10608115047216415
# Batch: 40, Loss: 0.046249665319919586
# Batch: 60, Loss: 0.03654339537024498
# Batch: 80, Loss: 0.05518653243780136
# Batch: 100, Loss: 0.02496175467967987
# Batch: 120, Loss: 0.061973027884960175
# Batch: 140, Loss: 0.051728371530771255
# Batch: 160, Loss: 0.01009404193609953
# Batch: 180, Loss: 0.040696851909160614
# Batch: 200, Loss: 0.07983613014221191
#
# Average loss: 0.0522, Accuracy: 27149.0/27537 (99%)
#
#
# Average loss: 0.0799, Accuracy: 2991.0/3059 (98%)
#
# Epoch: 11 	Training Accuracy: 98.59%
# Validation Accuracy: 97.78%
# Batch: 0, Loss: 0.04487914964556694
# Batch: 20, Loss: 0.06007741019129753
# Batch: 40, Loss: 0.07439498603343964
# Batch: 60, Loss: 0.024792544543743134
# Batch: 80, Loss: 0.12873485684394836
# Batch: 100, Loss: 0.0218706876039505
# Batch: 120, Loss: 0.11226751655340195
# Batch: 140, Loss: 0.1861421763896942
# Batch: 160, Loss: 0.031114112585783005
# Batch: 180, Loss: 0.0887250155210495
# Batch: 200, Loss: 0.013320638798177242
#
# Average loss: 0.0477, Accuracy: 27164.0/27537 (99%)
#
#
# Average loss: 0.0720, Accuracy: 2995.0/3059 (98%)
#
# Epoch: 12 	Training Accuracy: 98.65%
# Validation Accuracy: 97.91%
# Batch: 0, Loss: 0.09430932253599167
# Batch: 20, Loss: 0.0213556420058012
# Batch: 40, Loss: 0.14970234036445618
# Batch: 60, Loss: 0.0317036509513855
# Batch: 80, Loss: 0.007609682623296976
# Batch: 100, Loss: 0.0802193358540535
# Batch: 120, Loss: 0.027471937239170074
# Batch: 140, Loss: 0.11442005634307861
# Batch: 160, Loss: 0.01332258339971304
# Batch: 180, Loss: 0.02485532872378826
# Batch: 200, Loss: 0.09089145809412003
#
# Average loss: 0.0486, Accuracy: 27164.0/27537 (99%)
#
#
# Average loss: 0.0745, Accuracy: 2988.0/3059 (98%)
#
# Epoch: 13 	Training Accuracy: 98.65%
# Validation Accuracy: 97.68%
# Batch: 0, Loss: 0.016699129715561867
# Batch: 20, Loss: 0.05364217981696129
# Batch: 40, Loss: 0.033721741288900375
# Batch: 60, Loss: 0.04868081584572792
# Batch: 80, Loss: 0.02219943329691887
# Batch: 100, Loss: 0.050085119903087616
# Batch: 120, Loss: 0.00986587442457676
# Batch: 140, Loss: 0.03225557506084442
# Batch: 160, Loss: 0.05314084142446518
# Batch: 180, Loss: 0.01084992103278637
# Batch: 200, Loss: 0.08986304700374603
#
# Average loss: 0.0449, Accuracy: 27162.0/27537 (99%)
#
#
# Average loss: 0.0709, Accuracy: 2987.0/3059 (98%)
#
# Epoch: 14 	Training Accuracy: 98.64%
# Validation Accuracy: 97.65%
# Batch: 0, Loss: 0.060398783534765244
# Batch: 20, Loss: 0.019083786755800247
# Batch: 40, Loss: 0.03878641501069069
# Batch: 60, Loss: 0.0286403875797987
# Batch: 80, Loss: 0.06834006309509277
# Batch: 100, Loss: 0.029308926314115524
# Batch: 120, Loss: 0.006177531089633703
# Batch: 140, Loss: 0.08189882338047028
# Batch: 160, Loss: 0.02059728093445301
# Batch: 180, Loss: 0.047681547701358795
# Batch: 200, Loss: 0.03310806304216385
#
# Average loss: 0.0439, Accuracy: 27189.0/27537 (99%)
#
#
# Average loss: 0.0685, Accuracy: 2993.0/3059 (98%)
#
# Epoch: 15 	Training Accuracy: 98.74%
# Validation Accuracy: 97.84%
# Batch: 0, Loss: 0.04294952377676964
# Batch: 20, Loss: 0.026712004095315933
# Batch: 40, Loss: 0.14567936956882477
# Batch: 60, Loss: 0.06840971857309341
# Batch: 80, Loss: 0.02437625639140606
# Batch: 100, Loss: 0.040037769824266434
# Batch: 120, Loss: 0.09057910740375519
# Batch: 140, Loss: 0.04535165801644325
# Batch: 160, Loss: 0.07044096291065216
# Batch: 180, Loss: 0.034396518021821976
# Batch: 200, Loss: 0.03913767635822296
#
# Average loss: 0.0427, Accuracy: 27177.0/27537 (99%)
#
#
# Average loss: 0.0721, Accuracy: 2994.0/3059 (98%)
#
# Epoch: 16 	Training Accuracy: 98.69%
# Validation Accuracy: 97.88%
# Batch: 0, Loss: 0.027681497856974602
# Batch: 20, Loss: 0.009787095710635185
# Batch: 40, Loss: 0.06843975931406021
# Batch: 60, Loss: 0.012880584225058556
# Batch: 80, Loss: 0.04089304804801941
# Batch: 100, Loss: 0.028325943276286125
# Batch: 120, Loss: 0.022658461704850197
# Batch: 140, Loss: 0.09941989183425903
# Batch: 160, Loss: 0.03574773296713829
# Batch: 180, Loss: 0.03308892995119095
# Batch: 200, Loss: 0.06335273385047913
#
# Average loss: 0.0425, Accuracy: 27205.0/27537 (99%)
#
#
# Average loss: 0.0706, Accuracy: 2995.0/3059 (98%)
#
# Epoch: 17 	Training Accuracy: 98.79%
# Validation Accuracy: 97.91%
# Batch: 0, Loss: 0.012716401368379593
# Batch: 20, Loss: 0.060914259403944016
# Batch: 40, Loss: 0.05099394917488098
# Batch: 60, Loss: 0.03980572894215584
# Batch: 80, Loss: 0.12713174521923065
# Batch: 100, Loss: 0.008568950928747654
# Batch: 120, Loss: 0.026742542162537575
# Batch: 140, Loss: 0.026455916464328766
# Batch: 160, Loss: 0.0873831957578659
# Batch: 180, Loss: 0.08487223833799362
# Batch: 200, Loss: 0.16846370697021484
#
# Average loss: 0.0522, Accuracy: 27101.0/27537 (98%)
#
#
# Average loss: 0.0782, Accuracy: 2980.0/3059 (97%)
#
# Epoch: 18 	Training Accuracy: 98.42%
# Validation Accuracy: 97.42%
# Early stopping invoked.
#
# Average loss: 0.0477, Accuracy: 27164.0/27537 (99%)
#
#
# Average loss: 0.0420, Accuracy: 5071.0/5139 (99%)
#
# Final Training Accuracy: 0.9865
# Final Test Accuracy: 0.9868

# %%
accuracy = eval(model, device, dataloader_wrapped.test_loader, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
# Out:
# Average loss: 0.0420, Accuracy: 5071.0/5139 (99%)

# %%
def effective_rank(singular_values):
    normalized_singular_values = singular_values / np.sum(singular_values)
    entropy = -np.sum(normalized_singular_values * np.log(normalized_singular_values))
    eff_rank = np.exp(entropy)
    return eff_rank

def plot_layer_effective_ranks(model, print_ranks=True):
    effective_ranks = []
    layer_names = []

    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            singular_values = np.linalg.svd(weight_matrix, compute_uv=False)
            eff_rank = effective_rank(singular_values)
            effective_ranks.append(eff_rank)
            layer_names.append(name)

    if print_ranks:
        for layer_name, eff_rank in zip(layer_names, effective_ranks):
            print(f'{layer_name}: {eff_rank:.4f}')

    # Plotting
    plt.figure(figsize=(15, 5))
    plt.bar(layer_names, effective_ranks, color='green')
    plt.xlabel('Layer')
    plt.ylabel('Effective Rank')
    plt.title('Effective Rank of Weight Matrices for Each Layer')
    plt.grid(True)

    y_max = np.max(effective_ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(effective_ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(0, int(y_max)+2, step=2))  # Set yticks

    plt.show()

# Example usage
plot_layer_effective_ranks(model)  # Note: You'll need to define or load 'model' before calling this function
# Out:
# conv0.weight: 4.0247
# conv1.weight: 3.6045
# fc_1.weight: 90.0800
# fc_2.weight: 9.3957

# %% [markdown]
# ----

# %% [markdown]
# # Finetuning experiments

# %%
dataloader_wrapped.update_phase('finetune')

a = dataloader_wrapped.test_loader
b = dataloader_wrapped.train_loader

#check if the content of the two loaders are the same, and print the respective mnist images, use zip
for i, (data_a, data_b) in enumerate(zip(a, b)):
        plt.imshow(data_a[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        plt.imshow(data_b[0][0].reshape([28,28]), cmap='gray')
        plt.show()
        print('-------------')
        break
# Out:
# -------------

# %% [markdown]
# ## Baseline model: end2end with the same architecture as the preatining model

# %%
# 2. Create a new model and copy weights from the original model, then adjust the final layer
print("Current dataloader phase: ", dataloader_wrapped.get_current_phase())

model_finetuning_baseline = generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=False)
model_finetuning_baseline.to(device)

# dataloader_wrapped.update_phase('finetune')
# Train and evaluate the new model on the new data
# train_acc_new, test_acc_new, model_finetuning_baseline, _,_ = compute_training_acc_epochs_cnn(model_finetuning_baseline, dataloader_wrapped, params, debug=True)

trainer = Trainer(model, dataloader_wrapped, params)
train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

print(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
print(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")
# Out:
# Current dataloader phase:  finetune
# Batch: 0, Loss: 5.84702205657959
# Batch: 20, Loss: 1.0467031002044678
# Batch: 40, Loss: 0.6837326884269714
# Batch: 60, Loss: 0.40909749269485474
# Batch: 80, Loss: 0.21890224516391754
# Batch: 100, Loss: 0.2858143746852875
# Batch: 120, Loss: 0.2843706011772156
# Batch: 140, Loss: 0.1291598677635193
# Batch: 160, Loss: 0.1999272257089615
# Batch: 180, Loss: 0.2833150327205658
# Batch: 200, Loss: 0.15626442432403564
#
# Average loss: 0.1746, Accuracy: 24951.0/26464 (94%)
#
#
# Average loss: 0.2030, Accuracy: 2750.0/2940 (94%)
#
# Epoch: 0 	Training Accuracy: 94.28%
# Validation Accuracy: 93.54%
# Batch: 0, Loss: 0.17684705555438995
# Batch: 20, Loss: 0.1960609257221222
# Batch: 40, Loss: 0.11509590595960617
# Batch: 60, Loss: 0.16715888679027557
# Batch: 80, Loss: 0.16328077018260956
# Batch: 100, Loss: 0.11115166544914246
# Batch: 120, Loss: 0.057483166456222534
# Batch: 140, Loss: 0.19009463489055634
# Batch: 160, Loss: 0.09568160027265549
# Batch: 180, Loss: 0.1732243448495865
# Batch: 200, Loss: 0.17581547796726227
#
# Average loss: 0.1213, Accuracy: 25418.0/26464 (96%)
#
#
# Average loss: 0.1415, Accuracy: 2814.0/2940 (96%)
#
# Epoch: 1 	Training Accuracy: 96.05%
# Validation Accuracy: 95.71%
# Batch: 0, Loss: 0.08716731518507004
# Batch: 20, Loss: 0.03498746082186699
# Batch: 40, Loss: 0.12812180817127228
# Batch: 60, Loss: 0.1454240381717682
# Batch: 80, Loss: 0.10909545421600342
# Batch: 100, Loss: 0.1784980297088623
# Batch: 120, Loss: 0.08665280044078827
# Batch: 140, Loss: 0.11451943218708038
# Batch: 160, Loss: 0.13333475589752197
# Batch: 180, Loss: 0.10691731423139572
# Batch: 200, Loss: 0.08807780593633652
#
# Average loss: 0.0997, Accuracy: 25641.0/26464 (97%)
#
#
# Average loss: 0.1251, Accuracy: 2828.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 96.89%
# Validation Accuracy: 96.19%
# Batch: 0, Loss: 0.06949671357870102
# Batch: 20, Loss: 0.11753815412521362
# Batch: 40, Loss: 0.0685959905385971
# Batch: 60, Loss: 0.051088057458400726
# Batch: 80, Loss: 0.21727977693080902
# Batch: 100, Loss: 0.07567327469587326
# Batch: 120, Loss: 0.1344575583934784
# Batch: 140, Loss: 0.10619661957025528
# Batch: 160, Loss: 0.07516563683748245
# Batch: 180, Loss: 0.05497738718986511
# Batch: 200, Loss: 0.05534352362155914
#
# Average loss: 0.0917, Accuracy: 25704.0/26464 (97%)
#
#
# Average loss: 0.1171, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 3 	Training Accuracy: 97.13%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.09888342767953873
# Batch: 20, Loss: 0.15160582959651947
# Batch: 40, Loss: 0.08353259414434433
# Batch: 60, Loss: 0.09929146617650986
# Batch: 80, Loss: 0.11869043111801147
# Batch: 100, Loss: 0.17867892980575562
# Batch: 120, Loss: 0.08813579380512238
# Batch: 140, Loss: 0.04432304948568344
# Batch: 160, Loss: 0.08898965269327164
# Batch: 180, Loss: 0.05915830656886101
# Batch: 200, Loss: 0.05920235812664032
#
# Average loss: 0.0890, Accuracy: 25712.0/26464 (97%)
#
#
# Average loss: 0.1191, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 4 	Training Accuracy: 97.16%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.08700033277273178
# Batch: 20, Loss: 0.07345618307590485
# Batch: 40, Loss: 0.06477520614862442
# Batch: 60, Loss: 0.10044895112514496
# Batch: 80, Loss: 0.19784954190254211
# Batch: 100, Loss: 0.05944575369358063
# Batch: 120, Loss: 0.11777950078248978
# Batch: 140, Loss: 0.10101588815450668
# Batch: 160, Loss: 0.05078252777457237
# Batch: 180, Loss: 0.07518619298934937
# Batch: 200, Loss: 0.06755983829498291
#
# Average loss: 0.0859, Accuracy: 25732.0/26464 (97%)
#
#
# Average loss: 0.1138, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 5 	Training Accuracy: 97.23%
# Validation Accuracy: 96.97%
# Batch: 0, Loss: 0.020885076373815536
# Batch: 20, Loss: 0.052841827273368835
# Batch: 40, Loss: 0.06389880925416946
# Batch: 60, Loss: 0.05640052631497383
# Batch: 80, Loss: 0.0793236494064331
# Batch: 100, Loss: 0.07464215159416199
# Batch: 120, Loss: 0.08638076484203339
# Batch: 140, Loss: 0.022381283342838287
# Batch: 160, Loss: 0.08171102404594421
# Batch: 180, Loss: 0.05370393395423889
# Batch: 200, Loss: 0.04888126626610756
#
# Average loss: 0.0858, Accuracy: 25758.0/26464 (97%)
#
#
# Average loss: 0.1192, Accuracy: 2840.0/2940 (97%)
#
# Epoch: 6 	Training Accuracy: 97.33%
# Validation Accuracy: 96.60%
# Batch: 0, Loss: 0.1730642318725586
# Batch: 20, Loss: 0.05571409687399864
# Batch: 40, Loss: 0.04165200889110565
# Batch: 60, Loss: 0.15139999985694885
# Batch: 80, Loss: 0.05103364959359169
# Batch: 100, Loss: 0.11357954144477844
# Batch: 120, Loss: 0.05736482888460159
# Batch: 140, Loss: 0.08203039318323135
# Batch: 160, Loss: 0.0694967582821846
# Batch: 180, Loss: 0.060407862067222595
# Batch: 200, Loss: 0.030254874378442764
#
# Average loss: 0.0797, Accuracy: 25810.0/26464 (98%)
#
#
# Average loss: 0.1133, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 97.53%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.101985864341259
# Batch: 20, Loss: 0.05695735663175583
# Batch: 40, Loss: 0.05267865210771561
# Batch: 60, Loss: 0.08057823777198792
# Batch: 80, Loss: 0.02562866359949112
# Batch: 100, Loss: 0.0219905823469162
# Batch: 120, Loss: 0.018484920263290405
# Batch: 140, Loss: 0.12494557350873947
# Batch: 160, Loss: 0.08188202232122421
# Batch: 180, Loss: 0.03469238802790642
# Batch: 200, Loss: 0.11607686430215836
#
# Average loss: 0.0767, Accuracy: 25820.0/26464 (98%)
#
#
# Average loss: 0.1106, Accuracy: 2846.0/2940 (97%)
#
# Epoch: 8 	Training Accuracy: 97.57%
# Validation Accuracy: 96.80%
# Batch: 0, Loss: 0.11284082382917404
# Batch: 20, Loss: 0.104390449821949
# Batch: 40, Loss: 0.05050923675298691
# Batch: 60, Loss: 0.1713327169418335
# Batch: 80, Loss: 0.05614751577377319
# Batch: 100, Loss: 0.18815955519676208
# Batch: 120, Loss: 0.027760108932852745
# Batch: 140, Loss: 0.05435940995812416
# Batch: 160, Loss: 0.055431120097637177
# Batch: 180, Loss: 0.05040288716554642
# Batch: 200, Loss: 0.10687267780303955
#
# Average loss: 0.0748, Accuracy: 25823.0/26464 (98%)
#
#
# Average loss: 0.1094, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 9 	Training Accuracy: 97.58%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.0583944097161293
# Batch: 20, Loss: 0.1302054226398468
# Batch: 40, Loss: 0.01918771304190159
# Batch: 60, Loss: 0.07058409601449966
# Batch: 80, Loss: 0.023757414892315865
# Batch: 100, Loss: 0.068610779941082
# Batch: 120, Loss: 0.07261420786380768
# Batch: 140, Loss: 0.03172631934285164
# Batch: 160, Loss: 0.19345098733901978
# Batch: 180, Loss: 0.02599695511162281
# Batch: 200, Loss: 0.07315018028020859
#
# Average loss: 0.0744, Accuracy: 25848.0/26464 (98%)
#
#
# Average loss: 0.1075, Accuracy: 2845.0/2940 (97%)
#
# Epoch: 10 	Training Accuracy: 97.67%
# Validation Accuracy: 96.77%
# Batch: 0, Loss: 0.03511781617999077
# Batch: 20, Loss: 0.06687845289707184
# Batch: 40, Loss: 0.10281374305486679
# Batch: 60, Loss: 0.10187999904155731
# Batch: 80, Loss: 0.10179278999567032
# Batch: 100, Loss: 0.0675157904624939
# Batch: 120, Loss: 0.06284444034099579
# Batch: 140, Loss: 0.125559002161026
# Batch: 160, Loss: 0.09004726260900497
# Batch: 180, Loss: 0.043209098279476166
# Batch: 200, Loss: 0.05319015309214592
#
# Average loss: 0.0679, Accuracy: 25900.0/26464 (98%)
#
#
# Average loss: 0.1038, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 11 	Training Accuracy: 97.87%
# Validation Accuracy: 96.97%
# Early stopping invoked.
#
# Average loss: 0.0859, Accuracy: 25732.0/26464 (97%)
#
#
# Average loss: 0.0763, Accuracy: 4746.0/4861 (98%)
#
# Final Training Accuracy (New Data): 0.9723
# Final Test Accuracy (New Data): 0.9763

# %%
plot_layer_effective_ranks(model_finetuning_baseline)
# Out:
# conv0.weight: 4.0725
# conv1.weight: 3.4554
# fc_1.weight: 124.2384
# fc_2.weight: 4.9706

# %% [markdown]
# ***WITH BALANCED CLASSES***

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01]
percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]

seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test = {}
results_train = {}
best_models = {}
data_loaders = {}
epochs_taken = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Training with different data percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []

    for seed in tqdm(seed_set, desc=f'Training for data percentage: {perc}', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")
        
        model_new =  generate_cnn(input_dim = 28, output_dim = 5, depth = params['depth'], num_channels = params['width'],
                     hidden_dim_lin = params['hidden_dim_lin'], kernel_size = params['kernel_size'], activation_function = params["activation_function"], use_pooling=False)
        model_new.to(device)

        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)

        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        # Train and evaluate the new model on the new data
        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        # Add tqdm write method to prevent progress bar overlap
        tqdm.write(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
        tqdm.write(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test[perc] = test_accuracies
    results_train[perc] = train_accuracies
    epochs_taken[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Training with different data percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Training for data percentage: 0.01:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 80 =========================
# Batch: 0, Loss: 1.6097885370254517
#
# Average loss: 1.5976, Accuracy: 55.0/260 (21%)
#
#
# Average loss: 1.5942, Accuracy: 694.0/2940 (24%)
#
# Epoch: 0 	Training Accuracy: 21.15%
# Validation Accuracy: 23.61%
# Batch: 0, Loss: 1.590161681175232
#
# Average loss: 1.5944, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5913, Accuracy: 600.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 20.41%
# Batch: 0, Loss: 1.5932879447937012
#
# Average loss: 1.5889, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5853, Accuracy: 599.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.5987969636917114
#
# Average loss: 1.5697, Accuracy: 103.0/260 (40%)
#
#
# Average loss: 1.5661, Accuracy: 1200.0/2940 (41%)
#
# Epoch: 3 	Training Accuracy: 39.62%
# Validation Accuracy: 40.82%
# Batch: 0, Loss: 1.5487436056137085
#
# Average loss: 1.5470, Accuracy: 65.0/260 (25%)
#
#
# Average loss: 1.5485, Accuracy: 782.0/2940 (27%)
#
# Epoch: 4 	Training Accuracy: 25.00%
# Validation Accuracy: 26.60%
# Batch: 0, Loss: 1.5405519008636475
#
# Average loss: 1.5359, Accuracy: 97.0/260 (37%)
#
#
# Average loss: 1.5426, Accuracy: 1089.0/2940 (37%)
#
# Epoch: 5 	Training Accuracy: 37.31%
# Validation Accuracy: 37.04%
# Batch: 0, Loss: 1.5495609045028687
#
# Average loss: 1.5218, Accuracy: 56.0/260 (22%)
#
#
# Average loss: 1.5327, Accuracy: 572.0/2940 (19%)
#
# Epoch: 6 	Training Accuracy: 21.54%
# Validation Accuracy: 19.46%
# Batch: 0, Loss: 1.519034504890442
#
# Average loss: 1.5027, Accuracy: 60.0/260 (23%)
#
#
# Average loss: 1.5182, Accuracy: 596.0/2940 (20%)
#
# Epoch: 7 	Training Accuracy: 23.08%
# Validation Accuracy: 20.27%
# Batch: 0, Loss: 1.495504379272461
#
# Average loss: 1.4796, Accuracy: 72.0/260 (28%)
#
#
# Average loss: 1.4980, Accuracy: 697.0/2940 (24%)
#
# Epoch: 8 	Training Accuracy: 27.69%
# Validation Accuracy: 23.71%
# Batch: 0, Loss: 1.4761273860931396
#
# Average loss: 1.4566, Accuracy: 77.0/260 (30%)
#
#
# Average loss: 1.4786, Accuracy: 750.0/2940 (26%)
#
# Epoch: 9 	Training Accuracy: 29.62%
# Validation Accuracy: 25.51%
# Early stopping invoked.
#
# Average loss: 1.5697, Accuracy: 103.0/260 (40%)
#
#
# Average loss: 1.5700, Accuracy: 1890.0/4861 (39%)
#
# Final Training Accuracy (New Data): 0.3962
# Final Test Accuracy (New Data): 0.3888
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 55 =========================
# Batch: 0, Loss: 1.6099586486816406
#
# Average loss: 1.6015, Accuracy: 86.0/260 (33%)
#
#
# Average loss: 1.6031, Accuracy: 1019.0/2940 (35%)
#
# Epoch: 0 	Training Accuracy: 33.08%
# Validation Accuracy: 34.66%
# Batch: 0, Loss: 1.6099233627319336
#
# Average loss: 1.5975, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6059, Accuracy: 550.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.5939996242523193
#
# Average loss: 1.5881, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6009, Accuracy: 552.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 18.78%
# Batch: 0, Loss: 1.5844759941101074
#
# Average loss: 1.5693, Accuracy: 72.0/260 (28%)
#
#
# Average loss: 1.5835, Accuracy: 711.0/2940 (24%)
#
# Epoch: 3 	Training Accuracy: 27.69%
# Validation Accuracy: 24.18%
# Batch: 0, Loss: 1.5828572511672974
#
# Average loss: 1.5574, Accuracy: 76.0/260 (29%)
#
#
# Average loss: 1.5715, Accuracy: 752.0/2940 (26%)
#
# Epoch: 4 	Training Accuracy: 29.23%
# Validation Accuracy: 25.58%
# Batch: 0, Loss: 1.5600205659866333
#
# Average loss: 1.5430, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.5529, Accuracy: 600.0/2940 (20%)
#
# Epoch: 5 	Training Accuracy: 20.38%
# Validation Accuracy: 20.41%
# Batch: 0, Loss: 1.552350640296936
#
# Average loss: 1.5289, Accuracy: 79.0/260 (30%)
#
#
# Average loss: 1.5323, Accuracy: 954.0/2940 (32%)
#
# Epoch: 6 	Training Accuracy: 30.38%
# Validation Accuracy: 32.45%
# Early stopping invoked.
#
# Average loss: 1.6015, Accuracy: 86.0/260 (33%)
#
#
# Average loss: 1.6030, Accuracy: 1721.0/4861 (35%)
#
# Final Training Accuracy (New Data): 0.3308
# Final Test Accuracy (New Data): 0.3540
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 23 =========================
# Batch: 0, Loss: 1.6109755039215088
#
# Average loss: 1.6046, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6062, Accuracy: 585.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6094363927841187
#
# Average loss: 1.6057, Accuracy: 78.0/260 (30%)
#
#
# Average loss: 1.6160, Accuracy: 808.0/2940 (27%)
#
# Epoch: 1 	Training Accuracy: 30.00%
# Validation Accuracy: 27.48%
# Batch: 0, Loss: 1.5852839946746826
#
# Average loss: 1.6118, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6263, Accuracy: 551.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.587726354598999
#
# Average loss: 1.6121, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6258, Accuracy: 551.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.5905481576919556
#
# Average loss: 1.6092, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6208, Accuracy: 551.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.5993096828460693
#
# Average loss: 1.6021, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6132, Accuracy: 551.0/2940 (19%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6259320974349976
#
# Average loss: 1.5813, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5920, Accuracy: 551.0/2940 (19%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.5921056270599365
#
# Average loss: 1.5616, Accuracy: 115.0/260 (44%)
#
#
# Average loss: 1.5705, Accuracy: 1252.0/2940 (43%)
#
# Epoch: 7 	Training Accuracy: 44.23%
# Validation Accuracy: 42.59%
# Batch: 0, Loss: 1.5485265254974365
#
# Average loss: 1.5508, Accuracy: 55.0/260 (21%)
#
#
# Average loss: 1.5577, Accuracy: 574.0/2940 (20%)
#
# Epoch: 8 	Training Accuracy: 21.15%
# Validation Accuracy: 19.52%
# Batch: 0, Loss: 1.5545941591262817
#
# Average loss: 1.5387, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.5452, Accuracy: 578.0/2940 (20%)
#
# Epoch: 9 	Training Accuracy: 20.38%
# Validation Accuracy: 19.66%
# Batch: 0, Loss: 1.5312113761901855
#
# Average loss: 1.5228, Accuracy: 96.0/260 (37%)
#
#
# Average loss: 1.5297, Accuracy: 1025.0/2940 (35%)
#
# Epoch: 10 	Training Accuracy: 36.92%
# Validation Accuracy: 34.86%
# Batch: 0, Loss: 1.5264595746994019
#
# Average loss: 1.5050, Accuracy: 145.0/260 (56%)
#
#
# Average loss: 1.5128, Accuracy: 1643.0/2940 (56%)
#
# Epoch: 11 	Training Accuracy: 55.77%
# Validation Accuracy: 55.88%
# Batch: 0, Loss: 1.5165761709213257
#
# Average loss: 1.4911, Accuracy: 133.0/260 (51%)
#
#
# Average loss: 1.4986, Accuracy: 1462.0/2940 (50%)
#
# Epoch: 12 	Training Accuracy: 51.15%
# Validation Accuracy: 49.73%
# Batch: 0, Loss: 1.4688767194747925
#
# Average loss: 1.4755, Accuracy: 123.0/260 (47%)
#
#
# Average loss: 1.4809, Accuracy: 1452.0/2940 (49%)
#
# Epoch: 13 	Training Accuracy: 47.31%
# Validation Accuracy: 49.39%
# Batch: 0, Loss: 1.4886631965637207
#
# Average loss: 1.4525, Accuracy: 134.0/260 (52%)
#
#
# Average loss: 1.4551, Accuracy: 1596.0/2940 (54%)
#
# Epoch: 14 	Training Accuracy: 51.54%
# Validation Accuracy: 54.29%
# Batch: 0, Loss: 1.4668335914611816
#
# Average loss: 1.4180, Accuracy: 128.0/260 (49%)
#
#
# Average loss: 1.4206, Accuracy: 1580.0/2940 (54%)
#
# Epoch: 15 	Training Accuracy: 49.23%
# Validation Accuracy: 53.74%
# Batch: 0, Loss: 1.4017492532730103
#
# Average loss: 1.3794, Accuracy: 168.0/260 (65%)
#
#
# Average loss: 1.3858, Accuracy: 1907.0/2940 (65%)
#
# Epoch: 16 	Training Accuracy: 64.62%
# Validation Accuracy: 64.86%
# Batch: 0, Loss: 1.3506547212600708
#
# Average loss: 1.3440, Accuracy: 202.0/260 (78%)
#
#
# Average loss: 1.3566, Accuracy: 2166.0/2940 (74%)
#
# Epoch: 17 	Training Accuracy: 77.69%
# Validation Accuracy: 73.67%
# Batch: 0, Loss: 1.342842936515808
#
# Average loss: 1.3134, Accuracy: 169.0/260 (65%)
#
#
# Average loss: 1.3323, Accuracy: 1801.0/2940 (61%)
#
# Epoch: 18 	Training Accuracy: 65.00%
# Validation Accuracy: 61.26%
# Batch: 0, Loss: 1.3084553480148315
#
# Average loss: 1.2774, Accuracy: 158.0/260 (61%)
#
#
# Average loss: 1.3011, Accuracy: 1715.0/2940 (58%)
#
# Epoch: 19 	Training Accuracy: 60.77%
# Validation Accuracy: 58.33%
#
# Average loss: 1.2774, Accuracy: 158.0/260 (61%)
#
#
# Average loss: 1.2935, Accuracy: 2886.0/4861 (59%)
#
# Final Training Accuracy (New Data): 0.6077
# Final Test Accuracy (New Data): 0.5937
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 1 =========================
# Batch: 0, Loss: 1.6133092641830444
#
# Average loss: 1.6110, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6115, Accuracy: 550.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.6081714630126953
#
# Average loss: 1.6110, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6113, Accuracy: 550.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.609613060951233
#
# Average loss: 1.6108, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6111, Accuracy: 550.0/2940 (19%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.608978509902954
#
# Average loss: 1.6101, Accuracy: 60.0/260 (23%)
#
#
# Average loss: 1.6107, Accuracy: 567.0/2940 (19%)
#
# Epoch: 3 	Training Accuracy: 23.08%
# Validation Accuracy: 19.29%
# Batch: 0, Loss: 1.6142778396606445
#
# Average loss: 1.6069, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.6081, Accuracy: 703.0/2940 (24%)
#
# Epoch: 4 	Training Accuracy: 28.46%
# Validation Accuracy: 23.91%
# Batch: 0, Loss: 1.6072747707366943
#
# Average loss: 1.5963, Accuracy: 95.0/260 (37%)
#
#
# Average loss: 1.5982, Accuracy: 913.0/2940 (31%)
#
# Epoch: 5 	Training Accuracy: 36.54%
# Validation Accuracy: 31.05%
# Batch: 0, Loss: 1.5898878574371338
#
# Average loss: 1.5723, Accuracy: 136.0/260 (52%)
#
#
# Average loss: 1.5750, Accuracy: 1442.0/2940 (49%)
#
# Epoch: 6 	Training Accuracy: 52.31%
# Validation Accuracy: 49.05%
# Batch: 0, Loss: 1.5776525735855103
#
# Average loss: 1.5379, Accuracy: 171.0/260 (66%)
#
#
# Average loss: 1.5420, Accuracy: 1800.0/2940 (61%)
#
# Epoch: 7 	Training Accuracy: 65.77%
# Validation Accuracy: 61.22%
# Batch: 0, Loss: 1.5391347408294678
#
# Average loss: 1.4990, Accuracy: 154.0/260 (59%)
#
#
# Average loss: 1.5048, Accuracy: 1598.0/2940 (54%)
#
# Epoch: 8 	Training Accuracy: 59.23%
# Validation Accuracy: 54.35%
# Batch: 0, Loss: 1.4975875616073608
#
# Average loss: 1.4395, Accuracy: 135.0/260 (52%)
#
#
# Average loss: 1.4474, Accuracy: 1447.0/2940 (49%)
#
# Epoch: 9 	Training Accuracy: 51.92%
# Validation Accuracy: 49.22%
# Batch: 0, Loss: 1.4313796758651733
#
# Average loss: 1.3581, Accuracy: 163.0/260 (63%)
#
#
# Average loss: 1.3705, Accuracy: 1708.0/2940 (58%)
#
# Epoch: 10 	Training Accuracy: 62.69%
# Validation Accuracy: 58.10%
# Batch: 0, Loss: 1.3509137630462646
#
# Average loss: 1.2512, Accuracy: 184.0/260 (71%)
#
#
# Average loss: 1.2720, Accuracy: 1897.0/2940 (65%)
#
# Epoch: 11 	Training Accuracy: 70.77%
# Validation Accuracy: 64.52%
# Batch: 0, Loss: 1.2629667520523071
#
# Average loss: 1.1250, Accuracy: 186.0/260 (72%)
#
#
# Average loss: 1.1587, Accuracy: 1825.0/2940 (62%)
#
# Epoch: 12 	Training Accuracy: 71.54%
# Validation Accuracy: 62.07%
# Batch: 0, Loss: 1.141459584236145
#
# Average loss: 1.0051, Accuracy: 180.0/260 (69%)
#
#
# Average loss: 1.0533, Accuracy: 1802.0/2940 (61%)
#
# Epoch: 13 	Training Accuracy: 69.23%
# Validation Accuracy: 61.29%
# Batch: 0, Loss: 1.011605143547058
#
# Average loss: 0.9160, Accuracy: 181.0/260 (70%)
#
#
# Average loss: 0.9776, Accuracy: 1852.0/2940 (63%)
#
# Epoch: 14 	Training Accuracy: 69.62%
# Validation Accuracy: 62.99%
# Batch: 0, Loss: 0.9209057092666626
#
# Average loss: 0.7463, Accuracy: 209.0/260 (80%)
#
#
# Average loss: 0.8132, Accuracy: 2169.0/2940 (74%)
#
# Epoch: 15 	Training Accuracy: 80.38%
# Validation Accuracy: 73.78%
# Batch: 0, Loss: 0.7818334698677063
#
# Average loss: 0.6853, Accuracy: 207.0/260 (80%)
#
#
# Average loss: 0.7649, Accuracy: 2233.0/2940 (76%)
#
# Epoch: 16 	Training Accuracy: 79.62%
# Validation Accuracy: 75.95%
# Batch: 0, Loss: 0.65096515417099
#
# Average loss: 0.6602, Accuracy: 211.0/260 (81%)
#
#
# Average loss: 0.7531, Accuracy: 2224.0/2940 (76%)
#
# Epoch: 17 	Training Accuracy: 81.15%
# Validation Accuracy: 75.65%
# Batch: 0, Loss: 0.5239293575286865
#
# Average loss: 0.5434, Accuracy: 222.0/260 (85%)
#
#
# Average loss: 0.6582, Accuracy: 2270.0/2940 (77%)
#
# Epoch: 18 	Training Accuracy: 85.38%
# Validation Accuracy: 77.21%
# Batch: 0, Loss: 0.4469161927700043
#
# Average loss: 0.4965, Accuracy: 221.0/260 (85%)
#
#
# Average loss: 0.6335, Accuracy: 2227.0/2940 (76%)
#
# Epoch: 19 	Training Accuracy: 85.00%
# Validation Accuracy: 75.75%
#
# Average loss: 0.4965, Accuracy: 221.0/260 (85%)
#
#
# Average loss: 0.5941, Accuracy: 3751.0/4861 (77%)
#
# Final Training Accuracy (New Data): 0.8500
# Final Test Accuracy (New Data): 0.7717
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 40 =========================
# Batch: 0, Loss: 1.6130478382110596
#
# Average loss: 1.5888, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5948, Accuracy: 550.0/2940 (19%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.5944297313690186
#
# Average loss: 1.5764, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.5799, Accuracy: 550.0/2940 (19%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 18.71%
# Batch: 0, Loss: 1.5688426494598389
#
# Average loss: 1.5344, Accuracy: 53.0/260 (20%)
#
#
# Average loss: 1.5283, Accuracy: 667.0/2940 (23%)
#
# Epoch: 2 	Training Accuracy: 20.38%
# Validation Accuracy: 22.69%
# Batch: 0, Loss: 1.5360231399536133
#
# Average loss: 1.5066, Accuracy: 165.0/260 (63%)
#
#
# Average loss: 1.5081, Accuracy: 1734.0/2940 (59%)
#
# Epoch: 3 	Training Accuracy: 63.46%
# Validation Accuracy: 58.98%
# Batch: 0, Loss: 1.4971842765808105
#
# Average loss: 1.5084, Accuracy: 98.0/260 (38%)
#
#
# Average loss: 1.5097, Accuracy: 1103.0/2940 (38%)
#
# Epoch: 4 	Training Accuracy: 37.69%
# Validation Accuracy: 37.52%
# Batch: 0, Loss: 1.4951751232147217
#
# Average loss: 1.5187, Accuracy: 76.0/260 (29%)
#
#
# Average loss: 1.5144, Accuracy: 829.0/2940 (28%)
#
# Epoch: 5 	Training Accuracy: 29.23%
# Validation Accuracy: 28.20%
# Batch: 0, Loss: 1.512939453125
#
# Average loss: 1.4565, Accuracy: 89.0/260 (34%)
#
#
# Average loss: 1.4515, Accuracy: 1050.0/2940 (36%)
#
# Epoch: 6 	Training Accuracy: 34.23%
# Validation Accuracy: 35.71%
# Batch: 0, Loss: 1.4809929132461548
#
# Average loss: 1.3675, Accuracy: 168.0/260 (65%)
#
#
# Average loss: 1.3717, Accuracy: 1789.0/2940 (61%)
#
# Epoch: 7 	Training Accuracy: 64.62%
# Validation Accuracy: 60.85%
# Batch: 0, Loss: 1.3951961994171143
#
# Average loss: 1.3525, Accuracy: 149.0/260 (57%)
#
#
# Average loss: 1.3639, Accuracy: 1576.0/2940 (54%)
#
# Epoch: 8 	Training Accuracy: 57.31%
# Validation Accuracy: 53.61%
# Batch: 0, Loss: 1.37623929977417
#
# Average loss: 1.2817, Accuracy: 133.0/260 (51%)
#
#
# Average loss: 1.2973, Accuracy: 1341.0/2940 (46%)
#
# Epoch: 9 	Training Accuracy: 51.15%
# Validation Accuracy: 45.61%
# Batch: 0, Loss: 1.2678700685501099
#
# Average loss: 1.1669, Accuracy: 199.0/260 (77%)
#
#
# Average loss: 1.1870, Accuracy: 2118.0/2940 (72%)
#
# Epoch: 10 	Training Accuracy: 76.54%
# Validation Accuracy: 72.04%
# Batch: 0, Loss: 1.1628592014312744
#
# Average loss: 1.1640, Accuracy: 146.0/260 (56%)
#
#
# Average loss: 1.1833, Accuracy: 1712.0/2940 (58%)
#
# Epoch: 11 	Training Accuracy: 56.15%
# Validation Accuracy: 58.23%
# Batch: 0, Loss: 1.1664143800735474
#
# Average loss: 1.0492, Accuracy: 174.0/260 (67%)
#
#
# Average loss: 1.0684, Accuracy: 1944.0/2940 (66%)
#
# Epoch: 12 	Training Accuracy: 66.92%
# Validation Accuracy: 66.12%
# Batch: 0, Loss: 1.0447497367858887
#
# Average loss: 0.9100, Accuracy: 197.0/260 (76%)
#
#
# Average loss: 0.9311, Accuracy: 2193.0/2940 (75%)
#
# Epoch: 13 	Training Accuracy: 75.77%
# Validation Accuracy: 74.59%
# Batch: 0, Loss: 0.9179003238677979
#
# Average loss: 0.9115, Accuracy: 179.0/260 (69%)
#
#
# Average loss: 0.9263, Accuracy: 1942.0/2940 (66%)
#
# Epoch: 14 	Training Accuracy: 68.85%
# Validation Accuracy: 66.05%
# Batch: 0, Loss: 0.8808359503746033
#
# Average loss: 0.7817, Accuracy: 191.0/260 (73%)
#
#
# Average loss: 0.8072, Accuracy: 2179.0/2940 (74%)
#
# Epoch: 15 	Training Accuracy: 73.46%
# Validation Accuracy: 74.12%
# Batch: 0, Loss: 0.8317846059799194
#
# Average loss: 0.8616, Accuracy: 166.0/260 (64%)
#
#
# Average loss: 0.9033, Accuracy: 1870.0/2940 (64%)
#
# Epoch: 16 	Training Accuracy: 63.85%
# Validation Accuracy: 63.61%
# Batch: 0, Loss: 0.8639895915985107
#
# Average loss: 0.6813, Accuracy: 197.0/260 (76%)
#
#
# Average loss: 0.7352, Accuracy: 2147.0/2940 (73%)
#
# Epoch: 17 	Training Accuracy: 75.77%
# Validation Accuracy: 73.03%
# Batch: 0, Loss: 0.7232446074485779
#
# Average loss: 0.6575, Accuracy: 193.0/260 (74%)
#
#
# Average loss: 0.7099, Accuracy: 2163.0/2940 (74%)
#
# Epoch: 18 	Training Accuracy: 74.23%
# Validation Accuracy: 73.57%
# Batch: 0, Loss: 0.6435360908508301
#
# Average loss: 0.6127, Accuracy: 201.0/260 (77%)
#
#
# Average loss: 0.6719, Accuracy: 2194.0/2940 (75%)
#
# Epoch: 19 	Training Accuracy: 77.31%
# Validation Accuracy: 74.63%
#
# Average loss: 0.6127, Accuracy: 201.0/260 (77%)
#
#
# Average loss: 0.6911, Accuracy: 3585.0/4861 (74%)
#
# Final Training Accuracy (New Data): 0.7731
# Final Test Accuracy (New Data): 0.7375
# Training for data percentage: 0.03:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 58 =========================
# Batch: 0, Loss: 1.6229106187820435
#
# Average loss: 1.4887, Accuracy: 478.0/790 (61%)
#
#
# Average loss: 1.4952, Accuracy: 1692.0/2940 (58%)
#
# Epoch: 0 	Training Accuracy: 60.51%
# Validation Accuracy: 57.55%
# Batch: 0, Loss: 1.4967371225357056
#
# Average loss: 1.3160, Accuracy: 441.0/790 (56%)
#
#
# Average loss: 1.3308, Accuracy: 1606.0/2940 (55%)
#
# Epoch: 1 	Training Accuracy: 55.82%
# Validation Accuracy: 54.63%
# Batch: 0, Loss: 1.3323051929473877
#
# Average loss: 1.0810, Accuracy: 567.0/790 (72%)
#
#
# Average loss: 1.1180, Accuracy: 2049.0/2940 (70%)
#
# Epoch: 2 	Training Accuracy: 71.77%
# Validation Accuracy: 69.69%
# Batch: 0, Loss: 1.0934255123138428
#
# Average loss: 0.8530, Accuracy: 637.0/790 (81%)
#
#
# Average loss: 0.9029, Accuracy: 2213.0/2940 (75%)
#
# Epoch: 3 	Training Accuracy: 80.63%
# Validation Accuracy: 75.27%
# Batch: 0, Loss: 0.7940393686294556
#
# Average loss: 0.6802, Accuracy: 642.0/790 (81%)
#
#
# Average loss: 0.7393, Accuracy: 2298.0/2940 (78%)
#
# Epoch: 4 	Training Accuracy: 81.27%
# Validation Accuracy: 78.16%
# Batch: 0, Loss: 0.6882915496826172
#
# Average loss: 0.5521, Accuracy: 662.0/790 (84%)
#
#
# Average loss: 0.6214, Accuracy: 2368.0/2940 (81%)
#
# Epoch: 5 	Training Accuracy: 83.80%
# Validation Accuracy: 80.54%
# Batch: 0, Loss: 0.49302172660827637
#
# Average loss: 0.4580, Accuracy: 680.0/790 (86%)
#
#
# Average loss: 0.5412, Accuracy: 2422.0/2940 (82%)
#
# Epoch: 6 	Training Accuracy: 86.08%
# Validation Accuracy: 82.38%
# Batch: 0, Loss: 0.4322604537010193
#
# Average loss: 0.3939, Accuracy: 688.0/790 (87%)
#
#
# Average loss: 0.4933, Accuracy: 2448.0/2940 (83%)
#
# Epoch: 7 	Training Accuracy: 87.09%
# Validation Accuracy: 83.27%
# Batch: 0, Loss: 0.38789102435112
#
# Average loss: 0.3463, Accuracy: 697.0/790 (88%)
#
#
# Average loss: 0.4576, Accuracy: 2495.0/2940 (85%)
#
# Epoch: 8 	Training Accuracy: 88.23%
# Validation Accuracy: 84.86%
# Batch: 0, Loss: 0.40368399024009705
#
# Average loss: 0.3095, Accuracy: 706.0/790 (89%)
#
#
# Average loss: 0.4269, Accuracy: 2517.0/2940 (86%)
#
# Epoch: 9 	Training Accuracy: 89.37%
# Validation Accuracy: 85.61%
# Batch: 0, Loss: 0.2590625286102295
#
# Average loss: 0.2878, Accuracy: 718.0/790 (91%)
#
#
# Average loss: 0.4241, Accuracy: 2524.0/2940 (86%)
#
# Epoch: 10 	Training Accuracy: 90.89%
# Validation Accuracy: 85.85%
# Batch: 0, Loss: 0.2416718602180481
#
# Average loss: 0.2636, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.4022, Accuracy: 2542.0/2940 (86%)
#
# Epoch: 11 	Training Accuracy: 90.38%
# Validation Accuracy: 86.46%
# Batch: 0, Loss: 0.22476179897785187
#
# Average loss: 0.2451, Accuracy: 727.0/790 (92%)
#
#
# Average loss: 0.3988, Accuracy: 2555.0/2940 (87%)
#
# Epoch: 12 	Training Accuracy: 92.03%
# Validation Accuracy: 86.90%
# Batch: 0, Loss: 0.307830274105072
#
# Average loss: 0.2232, Accuracy: 731.0/790 (93%)
#
#
# Average loss: 0.3818, Accuracy: 2576.0/2940 (88%)
#
# Epoch: 13 	Training Accuracy: 92.53%
# Validation Accuracy: 87.62%
# Batch: 0, Loss: 0.19288210570812225
#
# Average loss: 0.2066, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.3811, Accuracy: 2591.0/2940 (88%)
#
# Epoch: 14 	Training Accuracy: 93.42%
# Validation Accuracy: 88.13%
# Batch: 0, Loss: 0.21193258464336395
#
# Average loss: 0.1973, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.3773, Accuracy: 2591.0/2940 (88%)
#
# Epoch: 15 	Training Accuracy: 93.16%
# Validation Accuracy: 88.13%
# Batch: 0, Loss: 0.21540221571922302
#
# Average loss: 0.1878, Accuracy: 737.0/790 (93%)
#
#
# Average loss: 0.3749, Accuracy: 2593.0/2940 (88%)
#
# Epoch: 16 	Training Accuracy: 93.29%
# Validation Accuracy: 88.20%
# Batch: 0, Loss: 0.18318617343902588
#
# Average loss: 0.1711, Accuracy: 748.0/790 (95%)
#
#
# Average loss: 0.3726, Accuracy: 2600.0/2940 (88%)
#
# Epoch: 17 	Training Accuracy: 94.68%
# Validation Accuracy: 88.44%
# Batch: 0, Loss: 0.2444402128458023
#
# Average loss: 0.1681, Accuracy: 743.0/790 (94%)
#
#
# Average loss: 0.3707, Accuracy: 2605.0/2940 (89%)
#
# Epoch: 18 	Training Accuracy: 94.05%
# Validation Accuracy: 88.61%
# Batch: 0, Loss: 0.21792368590831757
#
# Average loss: 0.1556, Accuracy: 747.0/790 (95%)
#
#
# Average loss: 0.3704, Accuracy: 2610.0/2940 (89%)
#
# Epoch: 19 	Training Accuracy: 94.56%
# Validation Accuracy: 88.78%
#
# Average loss: 0.1556, Accuracy: 747.0/790 (95%)
#
#
# Average loss: 0.3756, Accuracy: 4312.0/4861 (89%)
#
# Final Training Accuracy (New Data): 0.9456
# Final Test Accuracy (New Data): 0.8871
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 15 =========================
# Batch: 0, Loss: 1.6153119802474976
#
# Average loss: 1.5951, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.5972, Accuracy: 599.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 20.37%
# Batch: 0, Loss: 1.604842185974121
#
# Average loss: 1.4981, Accuracy: 262.0/790 (33%)
#
#
# Average loss: 1.5032, Accuracy: 949.0/2940 (32%)
#
# Epoch: 1 	Training Accuracy: 33.16%
# Validation Accuracy: 32.28%
# Batch: 0, Loss: 1.4938918352127075
#
# Average loss: 1.3830, Accuracy: 473.0/790 (60%)
#
#
# Average loss: 1.3902, Accuracy: 1738.0/2940 (59%)
#
# Epoch: 2 	Training Accuracy: 59.87%
# Validation Accuracy: 59.12%
# Batch: 0, Loss: 1.3754034042358398
#
# Average loss: 1.2145, Accuracy: 554.0/790 (70%)
#
#
# Average loss: 1.2272, Accuracy: 1946.0/2940 (66%)
#
# Epoch: 3 	Training Accuracy: 70.13%
# Validation Accuracy: 66.19%
# Batch: 0, Loss: 1.2701008319854736
#
# Average loss: 0.9988, Accuracy: 602.0/790 (76%)
#
#
# Average loss: 1.0155, Accuracy: 2174.0/2940 (74%)
#
# Epoch: 4 	Training Accuracy: 76.20%
# Validation Accuracy: 73.95%
# Batch: 0, Loss: 1.081785798072815
#
# Average loss: 0.7911, Accuracy: 622.0/790 (79%)
#
#
# Average loss: 0.8149, Accuracy: 2304.0/2940 (78%)
#
# Epoch: 5 	Training Accuracy: 78.73%
# Validation Accuracy: 78.37%
# Batch: 0, Loss: 0.7651776671409607
#
# Average loss: 0.6311, Accuracy: 645.0/790 (82%)
#
#
# Average loss: 0.6668, Accuracy: 2379.0/2940 (81%)
#
# Epoch: 6 	Training Accuracy: 81.65%
# Validation Accuracy: 80.92%
# Batch: 0, Loss: 0.6367277503013611
#
# Average loss: 0.5223, Accuracy: 654.0/790 (83%)
#
#
# Average loss: 0.5725, Accuracy: 2421.0/2940 (82%)
#
# Epoch: 7 	Training Accuracy: 82.78%
# Validation Accuracy: 82.35%
# Batch: 0, Loss: 0.5823194980621338
#
# Average loss: 0.4492, Accuracy: 677.0/790 (86%)
#
#
# Average loss: 0.5169, Accuracy: 2469.0/2940 (84%)
#
# Epoch: 8 	Training Accuracy: 85.70%
# Validation Accuracy: 83.98%
# Batch: 0, Loss: 0.5354219079017639
#
# Average loss: 0.4026, Accuracy: 689.0/790 (87%)
#
#
# Average loss: 0.4840, Accuracy: 2497.0/2940 (85%)
#
# Epoch: 9 	Training Accuracy: 87.22%
# Validation Accuracy: 84.93%
# Batch: 0, Loss: 0.36719149351119995
#
# Average loss: 0.3608, Accuracy: 703.0/790 (89%)
#
#
# Average loss: 0.4535, Accuracy: 2526.0/2940 (86%)
#
# Epoch: 10 	Training Accuracy: 88.99%
# Validation Accuracy: 85.92%
# Batch: 0, Loss: 0.417813777923584
#
# Average loss: 0.3303, Accuracy: 711.0/790 (90%)
#
#
# Average loss: 0.4334, Accuracy: 2546.0/2940 (87%)
#
# Epoch: 11 	Training Accuracy: 90.00%
# Validation Accuracy: 86.60%
# Batch: 0, Loss: 0.24797110259532928
#
# Average loss: 0.3067, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.4222, Accuracy: 2547.0/2940 (87%)
#
# Epoch: 12 	Training Accuracy: 90.38%
# Validation Accuracy: 86.63%
# Batch: 0, Loss: 0.26229676604270935
#
# Average loss: 0.2851, Accuracy: 724.0/790 (92%)
#
#
# Average loss: 0.4068, Accuracy: 2569.0/2940 (87%)
#
# Epoch: 13 	Training Accuracy: 91.65%
# Validation Accuracy: 87.38%
# Batch: 0, Loss: 0.25272536277770996
#
# Average loss: 0.2731, Accuracy: 726.0/790 (92%)
#
#
# Average loss: 0.4080, Accuracy: 2564.0/2940 (87%)
#
# Epoch: 14 	Training Accuracy: 91.90%
# Validation Accuracy: 87.21%
# Batch: 0, Loss: 0.18867313861846924
#
# Average loss: 0.2605, Accuracy: 727.0/790 (92%)
#
#
# Average loss: 0.4109, Accuracy: 2564.0/2940 (87%)
#
# Epoch: 15 	Training Accuracy: 92.03%
# Validation Accuracy: 87.21%
# Batch: 0, Loss: 0.26104414463043213
#
# Average loss: 0.2413, Accuracy: 734.0/790 (93%)
#
#
# Average loss: 0.3886, Accuracy: 2586.0/2940 (88%)
#
# Epoch: 16 	Training Accuracy: 92.91%
# Validation Accuracy: 87.96%
# Batch: 0, Loss: 0.2845350503921509
#
# Average loss: 0.2300, Accuracy: 741.0/790 (94%)
#
#
# Average loss: 0.3818, Accuracy: 2580.0/2940 (88%)
#
# Epoch: 17 	Training Accuracy: 93.80%
# Validation Accuracy: 87.76%
# Batch: 0, Loss: 0.23350441455841064
#
# Average loss: 0.2155, Accuracy: 739.0/790 (94%)
#
#
# Average loss: 0.3798, Accuracy: 2584.0/2940 (88%)
#
# Epoch: 18 	Training Accuracy: 93.54%
# Validation Accuracy: 87.89%
# Batch: 0, Loss: 0.166411891579628
#
# Average loss: 0.2050, Accuracy: 742.0/790 (94%)
#
#
# Average loss: 0.3721, Accuracy: 2594.0/2940 (88%)
#
# Epoch: 19 	Training Accuracy: 93.92%
# Validation Accuracy: 88.23%
#
# Average loss: 0.2050, Accuracy: 742.0/790 (94%)
#
#
# Average loss: 0.3566, Accuracy: 4347.0/4861 (89%)
#
# Final Training Accuracy (New Data): 0.9392
# Final Test Accuracy (New Data): 0.8943
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 45 =========================
# Batch: 0, Loss: 1.6090716123580933
#
# Average loss: 1.5973, Accuracy: 171.0/790 (22%)
#
#
# Average loss: 1.5981, Accuracy: 661.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 21.65%
# Validation Accuracy: 22.48%
# Batch: 0, Loss: 1.5977474451065063
#
# Average loss: 1.5435, Accuracy: 621.0/790 (79%)
#
#
# Average loss: 1.5484, Accuracy: 2125.0/2940 (72%)
#
# Epoch: 1 	Training Accuracy: 78.61%
# Validation Accuracy: 72.28%
# Batch: 0, Loss: 1.5419552326202393
#
# Average loss: 1.3894, Accuracy: 658.0/790 (83%)
#
#
# Average loss: 1.4028, Accuracy: 2297.0/2940 (78%)
#
# Epoch: 2 	Training Accuracy: 83.29%
# Validation Accuracy: 78.13%
# Batch: 0, Loss: 1.3895838260650635
#
# Average loss: 1.1094, Accuracy: 682.0/790 (86%)
#
#
# Average loss: 1.1349, Accuracy: 2394.0/2940 (81%)
#
# Epoch: 3 	Training Accuracy: 86.33%
# Validation Accuracy: 81.43%
# Batch: 0, Loss: 1.1194090843200684
#
# Average loss: 0.7497, Accuracy: 690.0/790 (87%)
#
#
# Average loss: 0.7854, Accuracy: 2462.0/2940 (84%)
#
# Epoch: 4 	Training Accuracy: 87.34%
# Validation Accuracy: 83.74%
# Batch: 0, Loss: 0.7975338101387024
#
# Average loss: 0.4757, Accuracy: 706.0/790 (89%)
#
#
# Average loss: 0.5318, Accuracy: 2530.0/2940 (86%)
#
# Epoch: 5 	Training Accuracy: 89.37%
# Validation Accuracy: 86.05%
# Batch: 0, Loss: 0.4662790894508362
#
# Average loss: 0.3347, Accuracy: 713.0/790 (90%)
#
#
# Average loss: 0.4103, Accuracy: 2543.0/2940 (86%)
#
# Epoch: 6 	Training Accuracy: 90.25%
# Validation Accuracy: 86.50%
# Batch: 0, Loss: 0.2315753847360611
#
# Average loss: 0.2652, Accuracy: 723.0/790 (92%)
#
#
# Average loss: 0.3633, Accuracy: 2583.0/2940 (88%)
#
# Epoch: 7 	Training Accuracy: 91.52%
# Validation Accuracy: 87.86%
# Batch: 0, Loss: 0.27615365386009216
#
# Average loss: 0.2298, Accuracy: 734.0/790 (93%)
#
#
# Average loss: 0.3451, Accuracy: 2611.0/2940 (89%)
#
# Epoch: 8 	Training Accuracy: 92.91%
# Validation Accuracy: 88.81%
# Batch: 0, Loss: 0.20081445574760437
#
# Average loss: 0.2041, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.3256, Accuracy: 2610.0/2940 (89%)
#
# Epoch: 9 	Training Accuracy: 93.42%
# Validation Accuracy: 88.78%
# Batch: 0, Loss: 0.21708443760871887
#
# Average loss: 0.1828, Accuracy: 751.0/790 (95%)
#
#
# Average loss: 0.3164, Accuracy: 2628.0/2940 (89%)
#
# Epoch: 10 	Training Accuracy: 95.06%
# Validation Accuracy: 89.39%
# Batch: 0, Loss: 0.20977188646793365
#
# Average loss: 0.1687, Accuracy: 753.0/790 (95%)
#
#
# Average loss: 0.3107, Accuracy: 2642.0/2940 (90%)
#
# Epoch: 11 	Training Accuracy: 95.32%
# Validation Accuracy: 89.86%
# Batch: 0, Loss: 0.18598008155822754
#
# Average loss: 0.1593, Accuracy: 753.0/790 (95%)
#
#
# Average loss: 0.3044, Accuracy: 2644.0/2940 (90%)
#
# Epoch: 12 	Training Accuracy: 95.32%
# Validation Accuracy: 89.93%
# Batch: 0, Loss: 0.23203825950622559
#
# Average loss: 0.1466, Accuracy: 754.0/790 (95%)
#
#
# Average loss: 0.3046, Accuracy: 2648.0/2940 (90%)
#
# Epoch: 13 	Training Accuracy: 95.44%
# Validation Accuracy: 90.07%
# Batch: 0, Loss: 0.1720842719078064
#
# Average loss: 0.1382, Accuracy: 758.0/790 (96%)
#
#
# Average loss: 0.2993, Accuracy: 2651.0/2940 (90%)
#
# Epoch: 14 	Training Accuracy: 95.95%
# Validation Accuracy: 90.17%
# Batch: 0, Loss: 0.16109013557434082
#
# Average loss: 0.1330, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.3111, Accuracy: 2656.0/2940 (90%)
#
# Epoch: 15 	Training Accuracy: 96.33%
# Validation Accuracy: 90.34%
# Batch: 0, Loss: 0.11659683287143707
#
# Average loss: 0.1273, Accuracy: 758.0/790 (96%)
#
#
# Average loss: 0.2958, Accuracy: 2656.0/2940 (90%)
#
# Epoch: 16 	Training Accuracy: 95.95%
# Validation Accuracy: 90.34%
# Batch: 0, Loss: 0.17034728825092316
#
# Average loss: 0.1172, Accuracy: 764.0/790 (97%)
#
#
# Average loss: 0.3004, Accuracy: 2659.0/2940 (90%)
#
# Epoch: 17 	Training Accuracy: 96.71%
# Validation Accuracy: 90.44%
# Batch: 0, Loss: 0.07394701987504959
#
# Average loss: 0.1158, Accuracy: 761.0/790 (96%)
#
#
# Average loss: 0.2982, Accuracy: 2672.0/2940 (91%)
#
# Epoch: 18 	Training Accuracy: 96.33%
# Validation Accuracy: 90.88%
# Batch: 0, Loss: 0.16057445108890533
#
# Average loss: 0.1104, Accuracy: 766.0/790 (97%)
#
#
# Average loss: 0.3038, Accuracy: 2652.0/2940 (90%)
#
# Epoch: 19 	Training Accuracy: 96.96%
# Validation Accuracy: 90.20%
#
# Average loss: 0.1104, Accuracy: 766.0/790 (97%)
#
#
# Average loss: 0.2802, Accuracy: 4427.0/4861 (91%)
#
# Final Training Accuracy (New Data): 0.9696
# Final Test Accuracy (New Data): 0.9107
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 7 =========================
# Batch: 0, Loss: 1.6120083332061768
#
# Average loss: 1.6100, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6109, Accuracy: 585.0/2940 (20%)
#
# Epoch: 0 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6110267639160156
#
# Average loss: 1.6097, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6103, Accuracy: 585.0/2940 (20%)
#
# Epoch: 1 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6103780269622803
#
# Average loss: 1.6096, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6100, Accuracy: 585.0/2940 (20%)
#
# Epoch: 2 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.6107168197631836
#
# Average loss: 1.6095, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6097, Accuracy: 585.0/2940 (20%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 19.90%
# Batch: 0, Loss: 1.610198736190796
#
# Average loss: 1.6095, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6093, Accuracy: 551.0/2940 (19%)
#
# Epoch: 4 	Training Accuracy: 20.00%
# Validation Accuracy: 18.74%
# Batch: 0, Loss: 1.6098742485046387
#
# Average loss: 1.6095, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6091, Accuracy: 655.0/2940 (22%)
#
# Epoch: 5 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6098346710205078
#
# Average loss: 1.6095, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6090, Accuracy: 655.0/2940 (22%)
#
# Epoch: 6 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6073845624923706
#
# Average loss: 1.6095, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6088, Accuracy: 655.0/2940 (22%)
#
# Epoch: 7 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6078815460205078
#
# Average loss: 1.6095, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6088, Accuracy: 655.0/2940 (22%)
#
# Epoch: 8 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6080598831176758
#
# Average loss: 1.6095, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6088, Accuracy: 655.0/2940 (22%)
#
# Epoch: 9 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.608744740486145
#
# Average loss: 1.6095, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6090, Accuracy: 655.0/2940 (22%)
#
# Epoch: 10 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Batch: 0, Loss: 1.6086102724075317
#
# Average loss: 1.6095, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6091, Accuracy: 655.0/2940 (22%)
#
# Epoch: 11 	Training Accuracy: 20.00%
# Validation Accuracy: 22.28%
# Early stopping invoked.
#
# Average loss: 1.6095, Accuracy: 158.0/790 (20%)
#
#
# Average loss: 1.6094, Accuracy: 1028.0/4861 (21%)
#
# Final Training Accuracy (New Data): 0.2000
# Final Test Accuracy (New Data): 0.2115
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 83 =========================
# Batch: 0, Loss: 1.611331820487976
#
# Average loss: 1.5845, Accuracy: 326.0/790 (41%)
#
#
# Average loss: 1.5843, Accuracy: 1220.0/2940 (41%)
#
# Epoch: 0 	Training Accuracy: 41.27%
# Validation Accuracy: 41.50%
# Batch: 0, Loss: 1.591011881828308
#
# Average loss: 1.4964, Accuracy: 539.0/790 (68%)
#
#
# Average loss: 1.4968, Accuracy: 1994.0/2940 (68%)
#
# Epoch: 1 	Training Accuracy: 68.23%
# Validation Accuracy: 67.82%
# Batch: 0, Loss: 1.5047485828399658
#
# Average loss: 1.2914, Accuracy: 586.0/790 (74%)
#
#
# Average loss: 1.2948, Accuracy: 2161.0/2940 (74%)
#
# Epoch: 2 	Training Accuracy: 74.18%
# Validation Accuracy: 73.50%
# Batch: 0, Loss: 1.3338338136672974
#
# Average loss: 0.9802, Accuracy: 612.0/790 (77%)
#
#
# Average loss: 0.9915, Accuracy: 2253.0/2940 (77%)
#
# Epoch: 3 	Training Accuracy: 77.47%
# Validation Accuracy: 76.63%
# Batch: 0, Loss: 1.0075078010559082
#
# Average loss: 0.6852, Accuracy: 653.0/790 (83%)
#
#
# Average loss: 0.7151, Accuracy: 2392.0/2940 (81%)
#
# Epoch: 4 	Training Accuracy: 82.66%
# Validation Accuracy: 81.36%
# Batch: 0, Loss: 0.6714708805084229
#
# Average loss: 0.4833, Accuracy: 681.0/790 (86%)
#
#
# Average loss: 0.5416, Accuracy: 2497.0/2940 (85%)
#
# Epoch: 5 	Training Accuracy: 86.20%
# Validation Accuracy: 84.93%
# Batch: 0, Loss: 0.44540393352508545
#
# Average loss: 0.3738, Accuracy: 702.0/790 (89%)
#
#
# Average loss: 0.4673, Accuracy: 2543.0/2940 (86%)
#
# Epoch: 6 	Training Accuracy: 88.86%
# Validation Accuracy: 86.50%
# Batch: 0, Loss: 0.33189186453819275
#
# Average loss: 0.3113, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.4360, Accuracy: 2573.0/2940 (88%)
#
# Epoch: 7 	Training Accuracy: 90.38%
# Validation Accuracy: 87.52%
# Batch: 0, Loss: 0.26211026310920715
#
# Average loss: 0.2737, Accuracy: 723.0/790 (92%)
#
#
# Average loss: 0.4235, Accuracy: 2576.0/2940 (88%)
#
# Epoch: 8 	Training Accuracy: 91.52%
# Validation Accuracy: 87.62%
# Batch: 0, Loss: 0.3844195008277893
#
# Average loss: 0.2468, Accuracy: 731.0/790 (93%)
#
#
# Average loss: 0.4022, Accuracy: 2592.0/2940 (88%)
#
# Epoch: 9 	Training Accuracy: 92.53%
# Validation Accuracy: 88.16%
# Batch: 0, Loss: 0.20374880731105804
#
# Average loss: 0.2318, Accuracy: 734.0/790 (93%)
#
#
# Average loss: 0.3861, Accuracy: 2627.0/2940 (89%)
#
# Epoch: 10 	Training Accuracy: 92.91%
# Validation Accuracy: 89.35%
# Batch: 0, Loss: 0.24879062175750732
#
# Average loss: 0.2154, Accuracy: 740.0/790 (94%)
#
#
# Average loss: 0.3712, Accuracy: 2634.0/2940 (90%)
#
# Epoch: 11 	Training Accuracy: 93.67%
# Validation Accuracy: 89.59%
# Batch: 0, Loss: 0.2549145221710205
#
# Average loss: 0.2024, Accuracy: 740.0/790 (94%)
#
#
# Average loss: 0.3657, Accuracy: 2629.0/2940 (89%)
#
# Epoch: 12 	Training Accuracy: 93.67%
# Validation Accuracy: 89.42%
# Batch: 0, Loss: 0.2476557344198227
#
# Average loss: 0.1941, Accuracy: 746.0/790 (94%)
#
#
# Average loss: 0.3629, Accuracy: 2644.0/2940 (90%)
#
# Epoch: 13 	Training Accuracy: 94.43%
# Validation Accuracy: 89.93%
# Batch: 0, Loss: 0.19841966032981873
#
# Average loss: 0.1799, Accuracy: 747.0/790 (95%)
#
#
# Average loss: 0.3508, Accuracy: 2641.0/2940 (90%)
#
# Epoch: 14 	Training Accuracy: 94.56%
# Validation Accuracy: 89.83%
# Batch: 0, Loss: 0.20628733932971954
#
# Average loss: 0.1711, Accuracy: 752.0/790 (95%)
#
#
# Average loss: 0.3399, Accuracy: 2649.0/2940 (90%)
#
# Epoch: 15 	Training Accuracy: 95.19%
# Validation Accuracy: 90.10%
# Batch: 0, Loss: 0.14328981935977936
#
# Average loss: 0.1616, Accuracy: 754.0/790 (95%)
#
#
# Average loss: 0.3351, Accuracy: 2656.0/2940 (90%)
#
# Epoch: 16 	Training Accuracy: 95.44%
# Validation Accuracy: 90.34%
# Batch: 0, Loss: 0.08341154456138611
#
# Average loss: 0.1525, Accuracy: 756.0/790 (96%)
#
#
# Average loss: 0.3279, Accuracy: 2663.0/2940 (91%)
#
# Epoch: 17 	Training Accuracy: 95.70%
# Validation Accuracy: 90.58%
# Batch: 0, Loss: 0.16238395869731903
#
# Average loss: 0.1451, Accuracy: 757.0/790 (96%)
#
#
# Average loss: 0.3240, Accuracy: 2670.0/2940 (91%)
#
# Epoch: 18 	Training Accuracy: 95.82%
# Validation Accuracy: 90.82%
# Batch: 0, Loss: 0.1437903493642807
#
# Average loss: 0.1391, Accuracy: 758.0/790 (96%)
#
#
# Average loss: 0.3175, Accuracy: 2682.0/2940 (91%)
#
# Epoch: 19 	Training Accuracy: 95.95%
# Validation Accuracy: 91.22%
#
# Average loss: 0.1391, Accuracy: 758.0/790 (96%)
#
#
# Average loss: 0.2723, Accuracy: 4452.0/4861 (92%)
#
# Final Training Accuracy (New Data): 0.9595
# Final Test Accuracy (New Data): 0.9159
# Training for data percentage: 0.05:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 100 =========================
# Batch: 0, Loss: 1.60702383518219
#
# Average loss: 1.6083, Accuracy: 288.0/1320 (22%)
#
#
# Average loss: 1.6070, Accuracy: 704.0/2940 (24%)
#
# Epoch: 0 	Training Accuracy: 21.82%
# Validation Accuracy: 23.95%
# Batch: 0, Loss: 1.6038705110549927
#
# Average loss: 1.5861, Accuracy: 436.0/1320 (33%)
#
#
# Average loss: 1.5861, Accuracy: 1053.0/2940 (36%)
#
# Epoch: 1 	Training Accuracy: 33.03%
# Validation Accuracy: 35.82%
# Batch: 0, Loss: 1.582734227180481
#
# Average loss: 1.4700, Accuracy: 436.0/1320 (33%)
#
#
# Average loss: 1.4707, Accuracy: 1031.0/2940 (35%)
#
# Epoch: 2 	Training Accuracy: 33.03%
# Validation Accuracy: 35.07%
# Batch: 0, Loss: 1.4403340816497803
#
# Average loss: 1.1853, Accuracy: 780.0/1320 (59%)
#
#
# Average loss: 1.1984, Accuracy: 1707.0/2940 (58%)
#
# Epoch: 3 	Training Accuracy: 59.09%
# Validation Accuracy: 58.06%
# Batch: 0, Loss: 1.1852998733520508
#
# Average loss: 0.6966, Accuracy: 1008.0/1320 (76%)
#
#
# Average loss: 0.7366, Accuracy: 2175.0/2940 (74%)
#
# Epoch: 4 	Training Accuracy: 76.36%
# Validation Accuracy: 73.98%
# Batch: 0, Loss: 0.7734188437461853
#
# Average loss: 0.4497, Accuracy: 1135.0/1320 (86%)
#
#
# Average loss: 0.5176, Accuracy: 2400.0/2940 (82%)
#
# Epoch: 5 	Training Accuracy: 85.98%
# Validation Accuracy: 81.63%
# Batch: 0, Loss: 0.39977318048477173
#
# Average loss: 0.3460, Accuracy: 1168.0/1320 (88%)
#
#
# Average loss: 0.4258, Accuracy: 2498.0/2940 (85%)
#
# Epoch: 6 	Training Accuracy: 88.48%
# Validation Accuracy: 84.97%
# Batch: 0, Loss: 0.3302965760231018
#
# Average loss: 0.2837, Accuracy: 1209.0/1320 (92%)
#
#
# Average loss: 0.3619, Accuracy: 2558.0/2940 (87%)
#
# Epoch: 7 	Training Accuracy: 91.59%
# Validation Accuracy: 87.01%
# Batch: 0, Loss: 0.35444557666778564
#
# Average loss: 0.2423, Accuracy: 1223.0/1320 (93%)
#
#
# Average loss: 0.3269, Accuracy: 2603.0/2940 (89%)
#
# Epoch: 8 	Training Accuracy: 92.65%
# Validation Accuracy: 88.54%
# Batch: 0, Loss: 0.2852901220321655
#
# Average loss: 0.2102, Accuracy: 1232.0/1320 (93%)
#
#
# Average loss: 0.3018, Accuracy: 2647.0/2940 (90%)
#
# Epoch: 9 	Training Accuracy: 93.33%
# Validation Accuracy: 90.03%
# Batch: 0, Loss: 0.23948398232460022
#
# Average loss: 0.2070, Accuracy: 1230.0/1320 (93%)
#
#
# Average loss: 0.2984, Accuracy: 2648.0/2940 (90%)
#
# Epoch: 10 	Training Accuracy: 93.18%
# Validation Accuracy: 90.07%
# Batch: 0, Loss: 0.26628249883651733
#
# Average loss: 0.1709, Accuracy: 1240.0/1320 (94%)
#
#
# Average loss: 0.2663, Accuracy: 2674.0/2940 (91%)
#
# Epoch: 11 	Training Accuracy: 93.94%
# Validation Accuracy: 90.95%
# Batch: 0, Loss: 0.14508973062038422
#
# Average loss: 0.1524, Accuracy: 1254.0/1320 (95%)
#
#
# Average loss: 0.2548, Accuracy: 2675.0/2940 (91%)
#
# Epoch: 12 	Training Accuracy: 95.00%
# Validation Accuracy: 90.99%
# Batch: 0, Loss: 0.1314704269170761
#
# Average loss: 0.1419, Accuracy: 1267.0/1320 (96%)
#
#
# Average loss: 0.2522, Accuracy: 2687.0/2940 (91%)
#
# Epoch: 13 	Training Accuracy: 95.98%
# Validation Accuracy: 91.39%
# Batch: 0, Loss: 0.09850198030471802
#
# Average loss: 0.1366, Accuracy: 1259.0/1320 (95%)
#
#
# Average loss: 0.2486, Accuracy: 2703.0/2940 (92%)
#
# Epoch: 14 	Training Accuracy: 95.38%
# Validation Accuracy: 91.94%
# Batch: 0, Loss: 0.18174009025096893
#
# Average loss: 0.1281, Accuracy: 1263.0/1320 (96%)
#
#
# Average loss: 0.2416, Accuracy: 2698.0/2940 (92%)
#
# Epoch: 15 	Training Accuracy: 95.68%
# Validation Accuracy: 91.77%
# Batch: 0, Loss: 0.11775945872068405
#
# Average loss: 0.1162, Accuracy: 1278.0/1320 (97%)
#
#
# Average loss: 0.2351, Accuracy: 2723.0/2940 (93%)
#
# Epoch: 16 	Training Accuracy: 96.82%
# Validation Accuracy: 92.62%
# Batch: 0, Loss: 0.17403168976306915
#
# Average loss: 0.1155, Accuracy: 1274.0/1320 (97%)
#
#
# Average loss: 0.2419, Accuracy: 2709.0/2940 (92%)
#
# Epoch: 17 	Training Accuracy: 96.52%
# Validation Accuracy: 92.14%
# Batch: 0, Loss: 0.1839405745267868
#
# Average loss: 0.1251, Accuracy: 1266.0/1320 (96%)
#
#
# Average loss: 0.2586, Accuracy: 2703.0/2940 (92%)
#
# Epoch: 18 	Training Accuracy: 95.91%
# Validation Accuracy: 91.94%
# Batch: 0, Loss: 0.14408913254737854
#
# Average loss: 0.1089, Accuracy: 1277.0/1320 (97%)
#
#
# Average loss: 0.2481, Accuracy: 2706.0/2940 (92%)
#
# Epoch: 19 	Training Accuracy: 96.74%
# Validation Accuracy: 92.04%
#
# Average loss: 0.1089, Accuracy: 1277.0/1320 (97%)
#
#
# Average loss: 0.2197, Accuracy: 4518.0/4861 (93%)
#
# Final Training Accuracy (New Data): 0.9674
# Final Test Accuracy (New Data): 0.9294
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 75 =========================
# Batch: 0, Loss: 1.608686089515686
#
# Average loss: 1.5897, Accuracy: 399.0/1320 (30%)
#
#
# Average loss: 1.5891, Accuracy: 930.0/2940 (32%)
#
# Epoch: 0 	Training Accuracy: 30.23%
# Validation Accuracy: 31.63%
# Batch: 0, Loss: 1.5904783010482788
#
# Average loss: 1.4858, Accuracy: 841.0/1320 (64%)
#
#
# Average loss: 1.4936, Accuracy: 1767.0/2940 (60%)
#
# Epoch: 1 	Training Accuracy: 63.71%
# Validation Accuracy: 60.10%
# Batch: 0, Loss: 1.467814564704895
#
# Average loss: 1.1390, Accuracy: 907.0/1320 (69%)
#
#
# Average loss: 1.1616, Accuracy: 2006.0/2940 (68%)
#
# Epoch: 2 	Training Accuracy: 68.71%
# Validation Accuracy: 68.23%
# Batch: 0, Loss: 1.1743953227996826
#
# Average loss: 0.5827, Accuracy: 1140.0/1320 (86%)
#
#
# Average loss: 0.6097, Accuracy: 2489.0/2940 (85%)
#
# Epoch: 3 	Training Accuracy: 86.36%
# Validation Accuracy: 84.66%
# Batch: 0, Loss: 0.6066210269927979
#
# Average loss: 0.3635, Accuracy: 1178.0/1320 (89%)
#
#
# Average loss: 0.4291, Accuracy: 2570.0/2940 (87%)
#
# Epoch: 4 	Training Accuracy: 89.24%
# Validation Accuracy: 87.41%
# Batch: 0, Loss: 0.37962809205055237
#
# Average loss: 0.2949, Accuracy: 1203.0/1320 (91%)
#
#
# Average loss: 0.3877, Accuracy: 2617.0/2940 (89%)
#
# Epoch: 5 	Training Accuracy: 91.14%
# Validation Accuracy: 89.01%
# Batch: 0, Loss: 0.3841891884803772
#
# Average loss: 0.2551, Accuracy: 1214.0/1320 (92%)
#
#
# Average loss: 0.3603, Accuracy: 2638.0/2940 (90%)
#
# Epoch: 6 	Training Accuracy: 91.97%
# Validation Accuracy: 89.73%
# Batch: 0, Loss: 0.3422619104385376
#
# Average loss: 0.2310, Accuracy: 1220.0/1320 (92%)
#
#
# Average loss: 0.3468, Accuracy: 2625.0/2940 (89%)
#
# Epoch: 7 	Training Accuracy: 92.42%
# Validation Accuracy: 89.29%
# Batch: 0, Loss: 0.18974784016609192
#
# Average loss: 0.2078, Accuracy: 1242.0/1320 (94%)
#
#
# Average loss: 0.3359, Accuracy: 2643.0/2940 (90%)
#
# Epoch: 8 	Training Accuracy: 94.09%
# Validation Accuracy: 89.90%
# Batch: 0, Loss: 0.2718264162540436
#
# Average loss: 0.1964, Accuracy: 1241.0/1320 (94%)
#
#
# Average loss: 0.3371, Accuracy: 2637.0/2940 (90%)
#
# Epoch: 9 	Training Accuracy: 94.02%
# Validation Accuracy: 89.69%
# Batch: 0, Loss: 0.22313594818115234
#
# Average loss: 0.1793, Accuracy: 1249.0/1320 (95%)
#
#
# Average loss: 0.3202, Accuracy: 2663.0/2940 (91%)
#
# Epoch: 10 	Training Accuracy: 94.62%
# Validation Accuracy: 90.58%
# Batch: 0, Loss: 0.11836347728967667
#
# Average loss: 0.1653, Accuracy: 1252.0/1320 (95%)
#
#
# Average loss: 0.3146, Accuracy: 2661.0/2940 (91%)
#
# Epoch: 11 	Training Accuracy: 94.85%
# Validation Accuracy: 90.51%
# Batch: 0, Loss: 0.09877221286296844
#
# Average loss: 0.1534, Accuracy: 1264.0/1320 (96%)
#
#
# Average loss: 0.3134, Accuracy: 2673.0/2940 (91%)
#
# Epoch: 12 	Training Accuracy: 95.76%
# Validation Accuracy: 90.92%
# Batch: 0, Loss: 0.12007956206798553
#
# ...
# Batch: 200, Loss: 0.04551693797111511
#
# Average loss: 0.0818, Accuracy: 25387.0/26038 (97%)
#
#
# Average loss: 0.1184, Accuracy: 2844.0/2940 (97%)
#
# Epoch: 13 	Training Accuracy: 97.50%
# Validation Accuracy: 96.73%
# Batch: 0, Loss: 0.16602763533592224
# Batch: 20, Loss: 0.028671011328697205
# Batch: 40, Loss: 0.19264169037342072
# Batch: 60, Loss: 0.07545589655637741
# Batch: 80, Loss: 0.1298525035381317
# Batch: 100, Loss: 0.10490257292985916
# Batch: 120, Loss: 0.03708760440349579
# Batch: 140, Loss: 0.047096963971853256
# Batch: 160, Loss: 0.036846041679382324
# Batch: 180, Loss: 0.10689494758844376
# Batch: 200, Loss: 0.13927854597568512
#
# Average loss: 0.0774, Accuracy: 25432.0/26038 (98%)
#
#
# Average loss: 0.1169, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 14 	Training Accuracy: 97.67%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.017084386199712753
# Batch: 20, Loss: 0.091512531042099
# Batch: 40, Loss: 0.16036967933177948
# Batch: 60, Loss: 0.0949699878692627
# Batch: 80, Loss: 0.049203258007764816
# Batch: 100, Loss: 0.14018160104751587
# Batch: 120, Loss: 0.07421761751174927
# Batch: 140, Loss: 0.03294789046049118
# Batch: 160, Loss: 0.042470186948776245
# Batch: 180, Loss: 0.09288225322961807
# Batch: 200, Loss: 0.0987059697508812
#
# Average loss: 0.0877, Accuracy: 25320.0/26038 (97%)
#
#
# Average loss: 0.1177, Accuracy: 2842.0/2940 (97%)
#
# Epoch: 15 	Training Accuracy: 97.24%
# Validation Accuracy: 96.67%
# Early stopping invoked.
#
# Average loss: 0.0889, Accuracy: 25329.0/26038 (97%)
#
#
# Average loss: 0.0933, Accuracy: 4716.0/4861 (97%)
#
# Final Training Accuracy (New Data): 0.9728
# Final Test Accuracy (New Data): 0.9702
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 87 =========================
# Batch: 0, Loss: 1.6066235303878784
# Batch: 20, Loss: 1.4531439542770386
# Batch: 40, Loss: 0.9731965065002441
# Batch: 60, Loss: 0.5333880186080933
# Batch: 80, Loss: 0.5668694972991943
# Batch: 100, Loss: 0.4569624364376068
# Batch: 120, Loss: 0.4506117105484009
# Batch: 140, Loss: 0.31174102425575256
# Batch: 160, Loss: 0.17342796921730042
# Batch: 180, Loss: 0.26581019163131714
# Batch: 200, Loss: 0.28628966212272644
#
# Average loss: 0.2600, Accuracy: 23743.0/26038 (91%)
#
#
# Average loss: 0.2879, Accuracy: 2658.0/2940 (90%)
#
# Epoch: 0 	Training Accuracy: 91.19%
# Validation Accuracy: 90.41%
# Batch: 0, Loss: 0.1623205542564392
# Batch: 20, Loss: 0.16828683018684387
# Batch: 40, Loss: 0.16877318918704987
# Batch: 60, Loss: 0.1805262714624405
# Batch: 80, Loss: 0.19751952588558197
# Batch: 100, Loss: 0.17808932065963745
# Batch: 120, Loss: 0.44527584314346313
# Batch: 140, Loss: 0.07067292183637619
# Batch: 160, Loss: 0.19978860020637512
# Batch: 180, Loss: 0.22984714806079865
# Batch: 200, Loss: 0.13665585219860077
#
# Average loss: 0.1813, Accuracy: 24486.0/26038 (94%)
#
#
# Average loss: 0.1972, Accuracy: 2751.0/2940 (94%)
#
# Epoch: 1 	Training Accuracy: 94.04%
# Validation Accuracy: 93.57%
# Batch: 0, Loss: 0.1673153042793274
# Batch: 20, Loss: 0.17172643542289734
# Batch: 40, Loss: 0.28552791476249695
# Batch: 60, Loss: 0.24333004653453827
# Batch: 80, Loss: 0.1430519074201584
# Batch: 100, Loss: 0.3289642035961151
# Batch: 120, Loss: 0.15876024961471558
# Batch: 140, Loss: 0.2177131325006485
# Batch: 160, Loss: 0.12855951488018036
# Batch: 180, Loss: 0.10826078802347183
# Batch: 200, Loss: 0.14833861589431763
#
# Average loss: 0.1612, Accuracy: 24689.0/26038 (95%)
#
#
# Average loss: 0.1765, Accuracy: 2781.0/2940 (95%)
#
# Epoch: 2 	Training Accuracy: 94.82%
# Validation Accuracy: 94.59%
# Batch: 0, Loss: 0.12654413282871246
# Batch: 20, Loss: 0.08251345902681351
# Batch: 40, Loss: 0.21671244502067566
# Batch: 60, Loss: 0.15564300119876862
# Batch: 80, Loss: 0.1385955959558487
# Batch: 100, Loss: 0.16964825987815857
# Batch: 120, Loss: 0.22133682668209076
# Batch: 140, Loss: 0.1796473115682602
# Batch: 160, Loss: 0.1789597123861313
# Batch: 180, Loss: 0.2146771252155304
# Batch: 200, Loss: 0.05736270919442177
#
# Average loss: 0.1586, Accuracy: 24666.0/26038 (95%)
#
#
# Average loss: 0.1661, Accuracy: 2800.0/2940 (95%)
#
# Epoch: 3 	Training Accuracy: 94.73%
# Validation Accuracy: 95.24%
# Batch: 0, Loss: 0.1983650177717209
# Batch: 20, Loss: 0.1266731172800064
# Batch: 40, Loss: 0.2002960741519928
# Batch: 60, Loss: 0.08661216497421265
# Batch: 80, Loss: 0.09695985168218613
# Batch: 100, Loss: 0.13240715861320496
# Batch: 120, Loss: 0.11575333774089813
# Batch: 140, Loss: 0.10886818170547485
# Batch: 160, Loss: 0.06611400842666626
# Batch: 180, Loss: 0.11913472414016724
# Batch: 200, Loss: 0.2078980952501297
#
# Average loss: 0.1485, Accuracy: 24790.0/26038 (95%)
#
#
# Average loss: 0.1566, Accuracy: 2794.0/2940 (95%)
#
# Epoch: 4 	Training Accuracy: 95.21%
# Validation Accuracy: 95.03%
# Batch: 0, Loss: 0.12089590728282928
# Batch: 20, Loss: 0.113420769572258
# Batch: 40, Loss: 0.09253039956092834
# Batch: 60, Loss: 0.1177780032157898
# Batch: 80, Loss: 0.09522028267383575
# Batch: 100, Loss: 0.25052955746650696
# Batch: 120, Loss: 0.12309097498655319
# Batch: 140, Loss: 0.08348768949508667
# Batch: 160, Loss: 0.11563845723867416
# Batch: 180, Loss: 0.23715996742248535
# Batch: 200, Loss: 0.2346448302268982
#
# Average loss: 0.1398, Accuracy: 24849.0/26038 (95%)
#
#
# Average loss: 0.1510, Accuracy: 2791.0/2940 (95%)
#
# Epoch: 5 	Training Accuracy: 95.43%
# Validation Accuracy: 94.93%
# Batch: 0, Loss: 0.15588165819644928
# Batch: 20, Loss: 0.06445004045963287
# Batch: 40, Loss: 0.16935200989246368
# Batch: 60, Loss: 0.09395654499530792
# Batch: 80, Loss: 0.13198532164096832
# Batch: 100, Loss: 0.20335283875465393
# Batch: 120, Loss: 0.09567975997924805
# Batch: 140, Loss: 0.12414435297250748
# Batch: 160, Loss: 0.11006225645542145
# Batch: 180, Loss: 0.08546200394630432
# Batch: 200, Loss: 0.2788199484348297
#
# Average loss: 0.1341, Accuracy: 24879.0/26038 (96%)
#
#
# Average loss: 0.1487, Accuracy: 2792.0/2940 (95%)
#
# Epoch: 6 	Training Accuracy: 95.55%
# Validation Accuracy: 94.97%
# Batch: 0, Loss: 0.06004485860466957
# Batch: 20, Loss: 0.1853974461555481
# Batch: 40, Loss: 0.09029940515756607
# Batch: 60, Loss: 0.15900075435638428
# Batch: 80, Loss: 0.14274390041828156
# Batch: 100, Loss: 0.10824689269065857
# Batch: 120, Loss: 0.07054080069065094
# Batch: 140, Loss: 0.1776544600725174
# Batch: 160, Loss: 0.19613268971443176
# Batch: 180, Loss: 0.12594187259674072
# Batch: 200, Loss: 0.10079433768987656
#
# Average loss: 0.1261, Accuracy: 24976.0/26038 (96%)
#
#
# Average loss: 0.1453, Accuracy: 2812.0/2940 (96%)
#
# Epoch: 7 	Training Accuracy: 95.92%
# Validation Accuracy: 95.65%
# Batch: 0, Loss: 0.04503927379846573
# Batch: 20, Loss: 0.06532607972621918
# Batch: 40, Loss: 0.13354122638702393
# Batch: 60, Loss: 0.10035405308008194
# Batch: 80, Loss: 0.2429128885269165
# Batch: 100, Loss: 0.14728744328022003
# Batch: 120, Loss: 0.11484874039888382
# Batch: 140, Loss: 0.11501340568065643
# Batch: 160, Loss: 0.16379016637802124
# Batch: 180, Loss: 0.10769039392471313
# Batch: 200, Loss: 0.18069979548454285
#
# Average loss: 0.1325, Accuracy: 24919.0/26038 (96%)
#
#
# Average loss: 0.1496, Accuracy: 2810.0/2940 (96%)
#
# Epoch: 8 	Training Accuracy: 95.70%
# Validation Accuracy: 95.58%
# Batch: 0, Loss: 0.0898640975356102
# Batch: 20, Loss: 0.08934814482927322
# Batch: 40, Loss: 0.19082973897457123
# Batch: 60, Loss: 0.16504767537117004
# Batch: 80, Loss: 0.0687185749411583
# Batch: 100, Loss: 0.23415909707546234
# Batch: 120, Loss: 0.1562286615371704
# Batch: 140, Loss: 0.1746375858783722
# Batch: 160, Loss: 0.12082609534263611
# Batch: 180, Loss: 0.09448742121458054
# Batch: 200, Loss: 0.18558967113494873
#
# Average loss: 0.1244, Accuracy: 24988.0/26038 (96%)
#
#
# Average loss: 0.1415, Accuracy: 2810.0/2940 (96%)
#
# Epoch: 9 	Training Accuracy: 95.97%
# Validation Accuracy: 95.58%
# Batch: 0, Loss: 0.172671377658844
# Batch: 20, Loss: 0.06559980660676956
# Batch: 40, Loss: 0.12924115359783173
# Batch: 60, Loss: 0.09541358798742294
# Batch: 80, Loss: 0.11361293494701385
# Batch: 100, Loss: 0.14130401611328125
# Batch: 120, Loss: 0.17902648448944092
# Batch: 140, Loss: 0.09480807930231094
# Batch: 160, Loss: 0.1610853374004364
# Batch: 180, Loss: 0.16292013227939606
# Batch: 200, Loss: 0.1269514560699463
#
# Average loss: 0.1217, Accuracy: 25041.0/26038 (96%)
#
#
# Average loss: 0.1440, Accuracy: 2815.0/2940 (96%)
#
# Epoch: 10 	Training Accuracy: 96.17%
# Validation Accuracy: 95.75%
# Batch: 0, Loss: 0.07816702127456665
# Batch: 20, Loss: 0.10816822946071625
# Batch: 40, Loss: 0.10527190566062927
# Batch: 60, Loss: 0.0449545681476593
# Batch: 80, Loss: 0.052891746163368225
# Batch: 100, Loss: 0.09562390297651291
# Batch: 120, Loss: 0.0840706005692482
# Batch: 140, Loss: 0.21535028517246246
# Batch: 160, Loss: 0.08130591362714767
# Batch: 180, Loss: 0.12157431244850159
# Batch: 200, Loss: 0.07881435006856918
#
# Average loss: 0.1187, Accuracy: 25002.0/26038 (96%)
#
#
# Average loss: 0.1428, Accuracy: 2806.0/2940 (95%)
#
# Epoch: 11 	Training Accuracy: 96.02%
# Validation Accuracy: 95.44%
# Batch: 0, Loss: 0.10232928395271301
# Batch: 20, Loss: 0.09488344937562943
# Batch: 40, Loss: 0.14251957833766937
# Batch: 60, Loss: 0.12113159894943237
# Batch: 80, Loss: 0.09646205604076385
# Batch: 100, Loss: 0.09336062520742416
# Batch: 120, Loss: 0.03839533403515816
# Batch: 140, Loss: 0.14180371165275574
# Batch: 160, Loss: 0.12661270797252655
# Batch: 180, Loss: 0.11634843051433563
# Batch: 200, Loss: 0.3168846666812897
#
# Average loss: 0.1145, Accuracy: 25060.0/26038 (96%)
#
#
# Average loss: 0.1389, Accuracy: 2815.0/2940 (96%)
#
# Epoch: 12 	Training Accuracy: 96.24%
# Validation Accuracy: 95.75%
# Batch: 0, Loss: 0.07049428671598434
# Batch: 20, Loss: 0.1649944931268692
# Batch: 40, Loss: 0.13242091238498688
# Batch: 60, Loss: 0.08269120752811432
# Batch: 80, Loss: 0.11853191256523132
# Batch: 100, Loss: 0.11084245890378952
# Batch: 120, Loss: 0.24254721403121948
# Batch: 140, Loss: 0.2102569192647934
# Batch: 160, Loss: 0.14063850045204163
# Batch: 180, Loss: 0.10262157022953033
# Batch: 200, Loss: 0.08787069469690323
#
# Average loss: 0.1088, Accuracy: 25152.0/26038 (97%)
#
#
# Average loss: 0.1375, Accuracy: 2823.0/2940 (96%)
#
# Epoch: 13 	Training Accuracy: 96.60%
# Validation Accuracy: 96.02%
# Batch: 0, Loss: 0.06086527556180954
# Batch: 20, Loss: 0.1808401346206665
# Batch: 40, Loss: 0.0751931294798851
# Batch: 60, Loss: 0.0671243891119957
# Batch: 80, Loss: 0.0537392795085907
# Batch: 100, Loss: 0.10323702543973923
# Batch: 120, Loss: 0.12167671322822571
# Batch: 140, Loss: 0.15931667387485504
# Batch: 160, Loss: 0.062007833272218704
# Batch: 180, Loss: 0.087247334420681
# Batch: 200, Loss: 0.1276116967201233
#
# Average loss: 0.1061, Accuracy: 25168.0/26038 (97%)
#
#
# Average loss: 0.1379, Accuracy: 2822.0/2940 (96%)
#
# Epoch: 14 	Training Accuracy: 96.66%
# Validation Accuracy: 95.99%
# Batch: 0, Loss: 0.06040456146001816
# Batch: 20, Loss: 0.203470379114151
# Batch: 40, Loss: 0.1081852838397026
# Batch: 60, Loss: 0.13517753779888153
# Batch: 80, Loss: 0.11188563704490662
# Batch: 100, Loss: 0.07910560816526413
# Batch: 120, Loss: 0.06231653690338135
# Batch: 140, Loss: 0.08637881278991699
# Batch: 160, Loss: 0.09383723139762878
# Batch: 180, Loss: 0.09901998937129974
# Batch: 200, Loss: 0.12683185935020447
#
# Average loss: 0.1198, Accuracy: 25004.0/26038 (96%)
#
#
# Average loss: 0.1499, Accuracy: 2802.0/2940 (95%)
#
# Epoch: 15 	Training Accuracy: 96.03%
# Validation Accuracy: 95.31%
# Batch: 0, Loss: 0.11355412006378174
# Batch: 20, Loss: 0.09486806392669678
# Batch: 40, Loss: 0.10425615310668945
# Batch: 60, Loss: 0.11724492162466049
# Batch: 80, Loss: 0.08171860128641129
# Batch: 100, Loss: 0.087974414229393
# Batch: 120, Loss: 0.15997661650180817
# Batch: 140, Loss: 0.05507645010948181
# Batch: 160, Loss: 0.12396398186683655
# Batch: 180, Loss: 0.13008159399032593
# Batch: 200, Loss: 0.050149306654930115
#
# Average loss: 0.1052, Accuracy: 25178.0/26038 (97%)
#
#
# Average loss: 0.1414, Accuracy: 2815.0/2940 (96%)
#
# Epoch: 16 	Training Accuracy: 96.70%
# Validation Accuracy: 95.75%
# Batch: 0, Loss: 0.08289940655231476
# Batch: 20, Loss: 0.057921700179576874
# Batch: 40, Loss: 0.07191617786884308
# Batch: 60, Loss: 0.1438426375389099
# Batch: 80, Loss: 0.13985683023929596
# Batch: 100, Loss: 0.06279373914003372
# Batch: 120, Loss: 0.11611133813858032
# Batch: 140, Loss: 0.12419074028730392
# Batch: 160, Loss: 0.09461082518100739
# Batch: 180, Loss: 0.07860051840543747
# Batch: 200, Loss: 0.07322809845209122
#
# Average loss: 0.1095, Accuracy: 25091.0/26038 (96%)
#
#
# Average loss: 0.1434, Accuracy: 2810.0/2940 (96%)
#
# Epoch: 17 	Training Accuracy: 96.36%
# Validation Accuracy: 95.58%
# Batch: 0, Loss: 0.0989273265004158
# Batch: 20, Loss: 0.10360606014728546
# Batch: 40, Loss: 0.1458440124988556
# Batch: 60, Loss: 0.046687494963407516
# Batch: 80, Loss: 0.08964136987924576
# Batch: 100, Loss: 0.128414124250412
# Batch: 120, Loss: 0.03230913728475571
# Batch: 140, Loss: 0.038991402834653854
# Batch: 160, Loss: 0.06618605554103851
# Batch: 180, Loss: 0.12154600024223328
# Batch: 200, Loss: 0.09707771986722946
#
# Average loss: 0.0929, Accuracy: 25231.0/26038 (97%)
#
#
# Average loss: 0.1280, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 18 	Training Accuracy: 96.90%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.0631457194685936
# Batch: 20, Loss: 0.08535643666982651
# Batch: 40, Loss: 0.08611705899238586
# Batch: 60, Loss: 0.0739160105586052
# Batch: 80, Loss: 0.12284458428621292
# Batch: 100, Loss: 0.06732498109340668
# Batch: 120, Loss: 0.11679954826831818
# Batch: 140, Loss: 0.10270395129919052
# Batch: 160, Loss: 0.15576529502868652
# Batch: 180, Loss: 0.1394820511341095
# Batch: 200, Loss: 0.06649935245513916
#
# Average loss: 0.0904, Accuracy: 25278.0/26038 (97%)
#
#
# Average loss: 0.1323, Accuracy: 2826.0/2940 (96%)
#
# Epoch: 19 	Training Accuracy: 97.08%
# Validation Accuracy: 96.12%
#
# Average loss: 0.0904, Accuracy: 25278.0/26038 (97%)
#
#
# Average loss: 0.1291, Accuracy: 4670.0/4861 (96%)
#
# Final Training Accuracy (New Data): 0.9708
# Final Test Accuracy (New Data): 0.9607
# Percentage: 0.01, Seed: 10, Epochs taken: 10
# Percentage: 0.01, Seed: 20, Epochs taken: 7
# Percentage: 0.01, Seed: 30, Epochs taken: 20
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 20
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 20
# Percentage: 0.03, Seed: 40, Epochs taken: 12
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 7
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 16
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 9
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 9
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 20
# Percentage: 0.4, Seed: 40, Epochs taken: 18
# Percentage: 0.4, Seed: 50, Epochs taken: 20
# Percentage: 0.6, Seed: 10, Epochs taken: 19
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 17
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 19
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 18
# Percentage: 1, Seed: 40, Epochs taken: 16
# Percentage: 1, Seed: 50, Epochs taken: 20

# %% [markdown]
# ## Only heads and data for new classes

# %% [markdown]
# now with balanced classes

# %%
dataloader_wrapped.update_phase('finetune')

percentages = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1]
seed_set = [10, 20, 30, 40, 50]
repeats = 1

params['lr'] = 0.0001
params['num_train'] = 20
params['early_stop_patience'] = 6

# Store results for each percentage
results_test_finetune = {}
results_train_finetune = {}
best_models = {}
data_loaders = {}
epochs_taken_finetune = {}  # Dictionary to store the number of epochs for each (perc, seed) tuple

for perc in tqdm(percentages, desc='Processing percentages'):
    test_accuracies = []
    train_accuracies = []
    epochs_for_this_percentage = []
    
    for seed in tqdm(seed_set, desc=f'Running seeds for {perc} data', leave=False):
        #temp_seed as a random seed
        temp_seed  = random.randint(0, 100)
        print(f"Repeat: {_}, with seed {temp_seed} =========================")

                # Copying model
        model_new = copy.deepcopy(model)

        # Calculate the output size from the pool layer dynamically
        # You would replace this with the actual size based on your model's architecture
        # model_new.fc_1 = nn.Linear(576, 128)
    
        # Reinitialize the second fully connected layer
        model_new.fc_2 = nn.Linear(128, 5)
        
        # Ensure the softmax layer matches the number of classes (if used)
        model_new.softmax = nn.Softmax(dim=1)
        
        model_new.to(device)
        
        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset(dataloader_wrapped.train_loader, perc, balanced = True, seed=temp_seed)
        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = dataloader_wrapped.test_loader
        val_loader_transfer_reduced = dataloader_wrapped.val_loader

        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)

        trainer = Trainer(model_new, dataset_namespace_new, params)
        train_acc_new, test_acc_new, effective_epochs, checkpoints = trainer.train()

        test_accuracies.append(test_acc_new)
        train_accuracies.append(train_acc_new)
        epochs_for_this_percentage.append(effective_epochs)

#         print('eval on reduced train set')
#         accuracy = eval(model_new, device, train_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])
        
#         print('eval on full test set')
#         accuracy = eval(model_new, device, test_loader_transfer_reduced, debug = params["is_debug"], is_cnn = params["is_cnn"], classification_report_flag = params["classification_report_flag"])

    results_test_finetune[perc] = test_accuracies
    results_train_finetune[perc] = train_accuracies
    epochs_taken_finetune[perc] = epochs_for_this_percentage

# Now, you can print or store the number of epochs for each (percentage, seed) tuple:
for perc in percentages:
    for seed, epoch_num in zip(seed_set, epochs_taken_finetune[perc]):
        print(f"Percentage: {perc}, Seed: {seed}, Epochs taken: {epoch_num}")

# Plot the results
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing percentages:   0%|          | 0/10 [00:00<?, ?it/s]
# Running seeds for 0.01 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 55 =========================
# Batch: 0, Loss: 1.9302641153335571
#
# Average loss: 1.8284, Accuracy: 18.0/260 (7%)
#
#
# Average loss: 1.8262, Accuracy: 272.0/2940 (9%)
#
# Epoch: 0 	Training Accuracy: 6.92%
# Validation Accuracy: 9.25%
# Batch: 0, Loss: 1.8462458848953247
#
# Average loss: 1.7336, Accuracy: 36.0/260 (14%)
#
#
# Average loss: 1.7341, Accuracy: 496.0/2940 (17%)
#
# Epoch: 1 	Training Accuracy: 13.85%
# Validation Accuracy: 16.87%
# Batch: 0, Loss: 1.749348759651184
#
# Average loss: 1.6536, Accuracy: 62.0/260 (24%)
#
#
# Average loss: 1.6564, Accuracy: 709.0/2940 (24%)
#
# Epoch: 2 	Training Accuracy: 23.85%
# Validation Accuracy: 24.12%
# Batch: 0, Loss: 1.6547117233276367
#
# Average loss: 1.5849, Accuracy: 81.0/260 (31%)
#
#
# Average loss: 1.5897, Accuracy: 893.0/2940 (30%)
#
# Epoch: 3 	Training Accuracy: 31.15%
# Validation Accuracy: 30.37%
# Batch: 0, Loss: 1.5822430849075317
#
# Average loss: 1.5229, Accuracy: 97.0/260 (37%)
#
#
# Average loss: 1.5292, Accuracy: 1045.0/2940 (36%)
#
# Epoch: 4 	Training Accuracy: 37.31%
# Validation Accuracy: 35.54%
# Batch: 0, Loss: 1.4581310749053955
#
# Average loss: 1.4651, Accuracy: 103.0/260 (40%)
#
#
# Average loss: 1.4710, Accuracy: 1119.0/2940 (38%)
#
# Epoch: 5 	Training Accuracy: 39.62%
# Validation Accuracy: 38.06%
# Batch: 0, Loss: 1.47822105884552
#
# Average loss: 1.4099, Accuracy: 112.0/260 (43%)
#
#
# Average loss: 1.4139, Accuracy: 1221.0/2940 (42%)
#
# Epoch: 6 	Training Accuracy: 43.08%
# Validation Accuracy: 41.53%
# Batch: 0, Loss: 1.426514983177185
#
# Average loss: 1.3591, Accuracy: 127.0/260 (49%)
#
#
# Average loss: 1.3619, Accuracy: 1438.0/2940 (49%)
#
# Epoch: 7 	Training Accuracy: 48.85%
# Validation Accuracy: 48.91%
# Batch: 0, Loss: 1.3820489645004272
#
# Average loss: 1.3125, Accuracy: 141.0/260 (54%)
#
#
# Average loss: 1.3148, Accuracy: 1561.0/2940 (53%)
#
# Epoch: 8 	Training Accuracy: 54.23%
# Validation Accuracy: 53.10%
# Batch: 0, Loss: 1.3781739473342896
#
# Average loss: 1.2685, Accuracy: 147.0/260 (57%)
#
#
# Average loss: 1.2701, Accuracy: 1656.0/2940 (56%)
#
# Epoch: 9 	Training Accuracy: 56.54%
# Validation Accuracy: 56.33%
# Batch: 0, Loss: 1.2758952379226685
#
# Average loss: 1.2279, Accuracy: 154.0/260 (59%)
#
#
# Average loss: 1.2306, Accuracy: 1706.0/2940 (58%)
#
# Epoch: 10 	Training Accuracy: 59.23%
# Validation Accuracy: 58.03%
# Batch: 0, Loss: 1.2281057834625244
#
# Average loss: 1.1882, Accuracy: 158.0/260 (61%)
#
#
# Average loss: 1.1923, Accuracy: 1749.0/2940 (59%)
#
# Epoch: 11 	Training Accuracy: 60.77%
# Validation Accuracy: 59.49%
# Batch: 0, Loss: 1.1590956449508667
#
# Average loss: 1.1491, Accuracy: 166.0/260 (64%)
#
#
# Average loss: 1.1534, Accuracy: 1794.0/2940 (61%)
#
# Epoch: 12 	Training Accuracy: 63.85%
# Validation Accuracy: 61.02%
# Batch: 0, Loss: 1.091538906097412
#
# Average loss: 1.1107, Accuracy: 172.0/260 (66%)
#
#
# Average loss: 1.1150, Accuracy: 1843.0/2940 (63%)
#
# Epoch: 13 	Training Accuracy: 66.15%
# Validation Accuracy: 62.69%
# Batch: 0, Loss: 1.1078705787658691
#
# Average loss: 1.0709, Accuracy: 176.0/260 (68%)
#
#
# Average loss: 1.0751, Accuracy: 1916.0/2940 (65%)
#
# Epoch: 14 	Training Accuracy: 67.69%
# Validation Accuracy: 65.17%
# Batch: 0, Loss: 1.0224688053131104
#
# Average loss: 1.0328, Accuracy: 177.0/260 (68%)
#
#
# Average loss: 1.0371, Accuracy: 1978.0/2940 (67%)
#
# Epoch: 15 	Training Accuracy: 68.08%
# Validation Accuracy: 67.28%
# Batch: 0, Loss: 1.032476544380188
#
# Average loss: 0.9974, Accuracy: 179.0/260 (69%)
#
#
# Average loss: 1.0016, Accuracy: 2032.0/2940 (69%)
#
# Epoch: 16 	Training Accuracy: 68.85%
# Validation Accuracy: 69.12%
# Batch: 0, Loss: 1.0410274267196655
#
# Average loss: 0.9642, Accuracy: 184.0/260 (71%)
#
#
# Average loss: 0.9673, Accuracy: 2090.0/2940 (71%)
#
# Epoch: 17 	Training Accuracy: 70.77%
# Validation Accuracy: 71.09%
# Batch: 0, Loss: 0.9675959348678589
#
# Average loss: 0.9321, Accuracy: 188.0/260 (72%)
#
#
# Average loss: 0.9341, Accuracy: 2128.0/2940 (72%)
#
# Epoch: 18 	Training Accuracy: 72.31%
# Validation Accuracy: 72.38%
# Batch: 0, Loss: 0.9304552674293518
#
# Average loss: 0.9017, Accuracy: 197.0/260 (76%)
#
#
# Average loss: 0.9025, Accuracy: 2194.0/2940 (75%)
#
# Epoch: 19 	Training Accuracy: 75.77%
# Validation Accuracy: 74.63%
#
# Average loss: 0.9017, Accuracy: 197.0/260 (76%)
#
#
# Average loss: 0.9071, Accuracy: 3596.0/4861 (74%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 72 =========================
# Batch: 0, Loss: 1.8635330200195312
#
# Average loss: 1.7365, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.7831, Accuracy: 716.0/2940 (24%)
#
# Epoch: 0 	Training Accuracy: 28.46%
# Validation Accuracy: 24.35%
# Batch: 0, Loss: 1.7167714834213257
#
# Average loss: 1.6609, Accuracy: 86.0/260 (33%)
#
#
# Average loss: 1.7090, Accuracy: 793.0/2940 (27%)
#
# Epoch: 1 	Training Accuracy: 33.08%
# Validation Accuracy: 26.97%
# Batch: 0, Loss: 1.6167088747024536
#
# Average loss: 1.5930, Accuracy: 94.0/260 (36%)
#
#
# Average loss: 1.6405, Accuracy: 893.0/2940 (30%)
#
# Epoch: 2 	Training Accuracy: 36.15%
# Validation Accuracy: 30.37%
# Batch: 0, Loss: 1.6362004280090332
#
# Average loss: 1.5316, Accuracy: 98.0/260 (38%)
#
#
# Average loss: 1.5781, Accuracy: 1012.0/2940 (34%)
#
# Epoch: 3 	Training Accuracy: 37.69%
# Validation Accuracy: 34.42%
# Batch: 0, Loss: 1.5526072978973389
#
# Average loss: 1.4745, Accuracy: 106.0/260 (41%)
#
#
# Average loss: 1.5206, Accuracy: 1142.0/2940 (39%)
#
# Epoch: 4 	Training Accuracy: 40.77%
# Validation Accuracy: 38.84%
# Batch: 0, Loss: 1.4291263818740845
#
# Average loss: 1.4184, Accuracy: 115.0/260 (44%)
#
#
# Average loss: 1.4636, Accuracy: 1248.0/2940 (42%)
#
# Epoch: 5 	Training Accuracy: 44.23%
# Validation Accuracy: 42.45%
# Batch: 0, Loss: 1.4982850551605225
#
# Average loss: 1.3634, Accuracy: 123.0/260 (47%)
#
#
# Average loss: 1.4073, Accuracy: 1358.0/2940 (46%)
#
# Epoch: 6 	Training Accuracy: 47.31%
# Validation Accuracy: 46.19%
# Batch: 0, Loss: 1.395938754081726
#
# Average loss: 1.3119, Accuracy: 131.0/260 (50%)
#
#
# Average loss: 1.3537, Accuracy: 1458.0/2940 (50%)
#
# Epoch: 7 	Training Accuracy: 50.38%
# Validation Accuracy: 49.59%
# Batch: 0, Loss: 1.302613377571106
#
# Average loss: 1.2652, Accuracy: 146.0/260 (56%)
#
#
# Average loss: 1.3060, Accuracy: 1561.0/2940 (53%)
#
# Epoch: 8 	Training Accuracy: 56.15%
# Validation Accuracy: 53.10%
# Batch: 0, Loss: 1.249414086341858
#
# Average loss: 1.2220, Accuracy: 157.0/260 (60%)
#
#
# Average loss: 1.2617, Accuracy: 1661.0/2940 (56%)
#
# Epoch: 9 	Training Accuracy: 60.38%
# Validation Accuracy: 56.50%
# Batch: 0, Loss: 1.208277940750122
#
# Average loss: 1.1795, Accuracy: 165.0/260 (63%)
#
#
# Average loss: 1.2179, Accuracy: 1749.0/2940 (59%)
#
# Epoch: 10 	Training Accuracy: 63.46%
# Validation Accuracy: 59.49%
# Batch: 0, Loss: 1.147733449935913
#
# Average loss: 1.1369, Accuracy: 172.0/260 (66%)
#
#
# Average loss: 1.1732, Accuracy: 1835.0/2940 (62%)
#
# Epoch: 11 	Training Accuracy: 66.15%
# Validation Accuracy: 62.41%
# Batch: 0, Loss: 1.1130763292312622
#
# Average loss: 1.0967, Accuracy: 180.0/260 (69%)
#
#
# Average loss: 1.1315, Accuracy: 1923.0/2940 (65%)
#
# Epoch: 12 	Training Accuracy: 69.23%
# Validation Accuracy: 65.41%
# Batch: 0, Loss: 1.0921893119812012
#
# Average loss: 1.0594, Accuracy: 184.0/260 (71%)
#
#
# Average loss: 1.0930, Accuracy: 2007.0/2940 (68%)
#
# Epoch: 13 	Training Accuracy: 70.77%
# Validation Accuracy: 68.27%
# Batch: 0, Loss: 1.0588666200637817
#
# Average loss: 1.0241, Accuracy: 192.0/260 (74%)
#
#
# Average loss: 1.0558, Accuracy: 2085.0/2940 (71%)
#
# Epoch: 14 	Training Accuracy: 73.85%
# Validation Accuracy: 70.92%
# Batch: 0, Loss: 1.0136264562606812
#
# Average loss: 0.9899, Accuracy: 199.0/260 (77%)
#
#
# Average loss: 1.0201, Accuracy: 2176.0/2940 (74%)
#
# Epoch: 15 	Training Accuracy: 76.54%
# Validation Accuracy: 74.01%
# Batch: 0, Loss: 0.9928757548332214
#
# Average loss: 0.9573, Accuracy: 203.0/260 (78%)
#
#
# Average loss: 0.9860, Accuracy: 2254.0/2940 (77%)
#
# Epoch: 16 	Training Accuracy: 78.08%
# Validation Accuracy: 76.67%
# Batch: 0, Loss: 0.9855237007141113
#
# Average loss: 0.9267, Accuracy: 210.0/260 (81%)
#
#
# Average loss: 0.9535, Accuracy: 2321.0/2940 (79%)
#
# Epoch: 17 	Training Accuracy: 80.77%
# Validation Accuracy: 78.95%
# Batch: 0, Loss: 0.9480257630348206
#
# Average loss: 0.8986, Accuracy: 211.0/260 (81%)
#
#
# Average loss: 0.9244, Accuracy: 2357.0/2940 (80%)
#
# Epoch: 18 	Training Accuracy: 81.15%
# Validation Accuracy: 80.17%
# Batch: 0, Loss: 0.9034258723258972
#
# Average loss: 0.8717, Accuracy: 213.0/260 (82%)
#
#
# Average loss: 0.8970, Accuracy: 2411.0/2940 (82%)
#
# Epoch: 19 	Training Accuracy: 81.92%
# Validation Accuracy: 82.01%
#
# Average loss: 0.8717, Accuracy: 213.0/260 (82%)
#
#
# Average loss: 0.8845, Accuracy: 3970.0/4861 (82%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 85 =========================
# Batch: 0, Loss: 1.6080477237701416
#
# Average loss: 1.4919, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.5196, Accuracy: 1007.0/2940 (34%)
#
# Epoch: 0 	Training Accuracy: 32.31%
# Validation Accuracy: 34.25%
# Batch: 0, Loss: 1.5169885158538818
#
# Average loss: 1.4197, Accuracy: 99.0/260 (38%)
#
#
# Average loss: 1.4462, Accuracy: 1150.0/2940 (39%)
#
# Epoch: 1 	Training Accuracy: 38.08%
# Validation Accuracy: 39.12%
# Batch: 0, Loss: 1.4280632734298706
#
# Average loss: 1.3561, Accuracy: 106.0/260 (41%)
#
#
# Average loss: 1.3829, Accuracy: 1260.0/2940 (43%)
#
# Epoch: 2 	Training Accuracy: 40.77%
# Validation Accuracy: 42.86%
# Batch: 0, Loss: 1.3627269268035889
#
# Average loss: 1.2976, Accuracy: 116.0/260 (45%)
#
#
# Average loss: 1.3260, Accuracy: 1366.0/2940 (46%)
#
# Epoch: 3 	Training Accuracy: 44.62%
# Validation Accuracy: 46.46%
# Batch: 0, Loss: 1.270071029663086
#
# Average loss: 1.2426, Accuracy: 129.0/260 (50%)
#
#
# Average loss: 1.2723, Accuracy: 1485.0/2940 (51%)
#
# Epoch: 4 	Training Accuracy: 49.62%
# Validation Accuracy: 50.51%
# Batch: 0, Loss: 1.2472879886627197
#
# Average loss: 1.1905, Accuracy: 143.0/260 (55%)
#
#
# Average loss: 1.2217, Accuracy: 1587.0/2940 (54%)
#
# Epoch: 5 	Training Accuracy: 55.00%
# Validation Accuracy: 53.98%
# Batch: 0, Loss: 1.1970466375350952
#
# Average loss: 1.1404, Accuracy: 158.0/260 (61%)
#
#
# Average loss: 1.1741, Accuracy: 1676.0/2940 (57%)
#
# Epoch: 6 	Training Accuracy: 60.77%
# Validation Accuracy: 57.01%
# Batch: 0, Loss: 1.1252046823501587
#
# Average loss: 1.0914, Accuracy: 172.0/260 (66%)
#
#
# Average loss: 1.1285, Accuracy: 1810.0/2940 (62%)
#
# Epoch: 7 	Training Accuracy: 66.15%
# Validation Accuracy: 61.56%
# Batch: 0, Loss: 1.0806223154067993
#
# Average loss: 1.0450, Accuracy: 177.0/260 (68%)
#
#
# Average loss: 1.0854, Accuracy: 1934.0/2940 (66%)
#
# Epoch: 8 	Training Accuracy: 68.08%
# Validation Accuracy: 65.78%
# Batch: 0, Loss: 1.060051679611206
#
# Average loss: 1.0003, Accuracy: 193.0/260 (74%)
#
#
# Average loss: 1.0447, Accuracy: 2032.0/2940 (69%)
#
# Epoch: 9 	Training Accuracy: 74.23%
# Validation Accuracy: 69.12%
# Batch: 0, Loss: 0.9749512672424316
#
# Average loss: 0.9578, Accuracy: 204.0/260 (78%)
#
#
# Average loss: 1.0068, Accuracy: 2126.0/2940 (72%)
#
# Epoch: 10 	Training Accuracy: 78.46%
# Validation Accuracy: 72.31%
# Batch: 0, Loss: 0.9573653936386108
#
# Average loss: 0.9192, Accuracy: 208.0/260 (80%)
#
#
# Average loss: 0.9724, Accuracy: 2192.0/2940 (75%)
#
# Epoch: 11 	Training Accuracy: 80.00%
# Validation Accuracy: 74.56%
# Batch: 0, Loss: 0.9317545890808105
#
# Average loss: 0.8827, Accuracy: 213.0/260 (82%)
#
#
# Average loss: 0.9392, Accuracy: 2238.0/2940 (76%)
#
# Epoch: 12 	Training Accuracy: 81.92%
# Validation Accuracy: 76.12%
# Batch: 0, Loss: 0.8495588302612305
#
# Average loss: 0.8483, Accuracy: 216.0/260 (83%)
#
#
# Average loss: 0.9072, Accuracy: 2293.0/2940 (78%)
#
# Epoch: 13 	Training Accuracy: 83.08%
# Validation Accuracy: 77.99%
# Batch: 0, Loss: 0.836435079574585
#
# Average loss: 0.8169, Accuracy: 220.0/260 (85%)
#
#
# Average loss: 0.8780, Accuracy: 2335.0/2940 (79%)
#
# Epoch: 14 	Training Accuracy: 84.62%
# Validation Accuracy: 79.42%
# Batch: 0, Loss: 0.7883191704750061
#
# Average loss: 0.7878, Accuracy: 222.0/260 (85%)
#
#
# Average loss: 0.8507, Accuracy: 2355.0/2940 (80%)
#
# Epoch: 15 	Training Accuracy: 85.38%
# Validation Accuracy: 80.10%
# Batch: 0, Loss: 0.7530820965766907
#
# Average loss: 0.7595, Accuracy: 226.0/260 (87%)
#
#
# Average loss: 0.8240, Accuracy: 2387.0/2940 (81%)
#
# Epoch: 16 	Training Accuracy: 86.92%
# Validation Accuracy: 81.19%
# Batch: 0, Loss: 0.7487407922744751
#
# Average loss: 0.7326, Accuracy: 227.0/260 (87%)
#
#
# Average loss: 0.7986, Accuracy: 2408.0/2940 (82%)
#
# Epoch: 17 	Training Accuracy: 87.31%
# Validation Accuracy: 81.90%
# Batch: 0, Loss: 0.7494908571243286
#
# Average loss: 0.7075, Accuracy: 226.0/260 (87%)
#
#
# Average loss: 0.7751, Accuracy: 2426.0/2940 (83%)
#
# Epoch: 18 	Training Accuracy: 86.92%
# Validation Accuracy: 82.52%
# Batch: 0, Loss: 0.6929293274879456
#
# Average loss: 0.6864, Accuracy: 228.0/260 (88%)
#
#
# Average loss: 0.7554, Accuracy: 2425.0/2940 (82%)
#
# Epoch: 19 	Training Accuracy: 87.69%
# Validation Accuracy: 82.48%
#
# Average loss: 0.6864, Accuracy: 228.0/260 (88%)
#
#
# Average loss: 0.7406, Accuracy: 4092.0/4861 (84%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 40 =========================
# Batch: 0, Loss: 1.9191936254501343
#
# Average loss: 1.8229, Accuracy: 35.0/260 (13%)
#
#
# Average loss: 1.8449, Accuracy: 347.0/2940 (12%)
#
# Epoch: 0 	Training Accuracy: 13.46%
# Validation Accuracy: 11.80%
# Batch: 0, Loss: 1.7890822887420654
#
# Average loss: 1.7473, Accuracy: 39.0/260 (15%)
#
#
# Average loss: 1.7664, Accuracy: 390.0/2940 (13%)
#
# Epoch: 1 	Training Accuracy: 15.00%
# Validation Accuracy: 13.27%
# Batch: 0, Loss: 1.7140837907791138
#
# Average loss: 1.6809, Accuracy: 48.0/260 (18%)
#
#
# Average loss: 1.6972, Accuracy: 447.0/2940 (15%)
#
# Epoch: 2 	Training Accuracy: 18.46%
# Validation Accuracy: 15.20%
# Batch: 0, Loss: 1.6186614036560059
#
# Average loss: 1.6199, Accuracy: 61.0/260 (23%)
#
#
# Average loss: 1.6349, Accuracy: 538.0/2940 (18%)
#
# Epoch: 3 	Training Accuracy: 23.46%
# Validation Accuracy: 18.30%
# Batch: 0, Loss: 1.6148053407669067
#
# Average loss: 1.5621, Accuracy: 71.0/260 (27%)
#
#
# Average loss: 1.5751, Accuracy: 693.0/2940 (24%)
#
# Epoch: 4 	Training Accuracy: 27.31%
# Validation Accuracy: 23.57%
# Batch: 0, Loss: 1.5736926794052124
#
# Average loss: 1.5078, Accuracy: 87.0/260 (33%)
#
#
# Average loss: 1.5184, Accuracy: 906.0/2940 (31%)
#
# Epoch: 5 	Training Accuracy: 33.46%
# Validation Accuracy: 30.82%
# Batch: 0, Loss: 1.50914466381073
#
# Average loss: 1.4571, Accuracy: 101.0/260 (39%)
#
#
# Average loss: 1.4656, Accuracy: 1103.0/2940 (38%)
#
# Epoch: 6 	Training Accuracy: 38.85%
# Validation Accuracy: 37.52%
# Batch: 0, Loss: 1.4927008152008057
#
# Average loss: 1.4089, Accuracy: 111.0/260 (43%)
#
#
# Average loss: 1.4161, Accuracy: 1274.0/2940 (43%)
#
# Epoch: 7 	Training Accuracy: 42.69%
# Validation Accuracy: 43.33%
# Batch: 0, Loss: 1.42728590965271
#
# Average loss: 1.3634, Accuracy: 128.0/260 (49%)
#
#
# Average loss: 1.3696, Accuracy: 1384.0/2940 (47%)
#
# Epoch: 8 	Training Accuracy: 49.23%
# Validation Accuracy: 47.07%
# Batch: 0, Loss: 1.3397245407104492
#
# Average loss: 1.3202, Accuracy: 134.0/260 (52%)
#
#
# Average loss: 1.3259, Accuracy: 1521.0/2940 (52%)
#
# Epoch: 9 	Training Accuracy: 51.54%
# Validation Accuracy: 51.73%
# Batch: 0, Loss: 1.3066680431365967
#
# Average loss: 1.2771, Accuracy: 146.0/260 (56%)
#
#
# Average loss: 1.2830, Accuracy: 1619.0/2940 (55%)
#
# Epoch: 10 	Training Accuracy: 56.15%
# Validation Accuracy: 55.07%
# Batch: 0, Loss: 1.249351978302002
#
# Average loss: 1.2331, Accuracy: 157.0/260 (60%)
#
#
# Average loss: 1.2393, Accuracy: 1709.0/2940 (58%)
#
# Epoch: 11 	Training Accuracy: 60.38%
# Validation Accuracy: 58.13%
# Batch: 0, Loss: 1.2700207233428955
#
# Average loss: 1.1902, Accuracy: 166.0/260 (64%)
#
#
# Average loss: 1.1966, Accuracy: 1816.0/2940 (62%)
#
# Epoch: 12 	Training Accuracy: 63.85%
# Validation Accuracy: 61.77%
# Batch: 0, Loss: 1.1960268020629883
#
# Average loss: 1.1493, Accuracy: 174.0/260 (67%)
#
#
# Average loss: 1.1560, Accuracy: 1903.0/2940 (65%)
#
# Epoch: 13 	Training Accuracy: 66.92%
# Validation Accuracy: 64.73%
# Batch: 0, Loss: 1.1740416288375854
#
# Average loss: 1.1113, Accuracy: 177.0/260 (68%)
#
#
# Average loss: 1.1177, Accuracy: 1965.0/2940 (67%)
#
# Epoch: 14 	Training Accuracy: 68.08%
# Validation Accuracy: 66.84%
# Batch: 0, Loss: 1.1030982732772827
#
# Average loss: 1.0748, Accuracy: 182.0/260 (70%)
#
#
# Average loss: 1.0810, Accuracy: 2007.0/2940 (68%)
#
# Epoch: 15 	Training Accuracy: 70.00%
# Validation Accuracy: 68.27%
# Batch: 0, Loss: 1.0828481912612915
#
# Average loss: 1.0383, Accuracy: 187.0/260 (72%)
#
#
# Average loss: 1.0451, Accuracy: 2065.0/2940 (70%)
#
# Epoch: 16 	Training Accuracy: 71.92%
# Validation Accuracy: 70.24%
# Batch: 0, Loss: 0.9811459183692932
#
# Average loss: 1.0036, Accuracy: 193.0/260 (74%)
#
#
# Average loss: 1.0115, Accuracy: 2135.0/2940 (73%)
#
# Epoch: 17 	Training Accuracy: 74.23%
# Validation Accuracy: 72.62%
# Batch: 0, Loss: 1.0115151405334473
#
# Average loss: 0.9705, Accuracy: 199.0/260 (77%)
#
#
# Average loss: 0.9799, Accuracy: 2206.0/2940 (75%)
#
# Epoch: 18 	Training Accuracy: 76.54%
# Validation Accuracy: 75.03%
# Batch: 0, Loss: 0.9676221609115601
#
# Average loss: 0.9385, Accuracy: 204.0/260 (78%)
#
#
# Average loss: 0.9495, Accuracy: 2254.0/2940 (77%)
#
# Epoch: 19 	Training Accuracy: 78.46%
# Validation Accuracy: 76.67%
#
# Average loss: 0.9385, Accuracy: 204.0/260 (78%)
#
#
# Average loss: 0.9459, Accuracy: 3733.0/4861 (77%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 19 =========================
# Batch: 0, Loss: 2.0078587532043457
#
# Average loss: 1.9521, Accuracy: 47.0/260 (18%)
#
#
# Average loss: 1.8867, Accuracy: 641.0/2940 (22%)
#
# Epoch: 0 	Training Accuracy: 18.08%
# Validation Accuracy: 21.80%
# Batch: 0, Loss: 1.9637835025787354
#
# Average loss: 1.8722, Accuracy: 49.0/260 (19%)
#
#
# Average loss: 1.8127, Accuracy: 649.0/2940 (22%)
#
# Epoch: 1 	Training Accuracy: 18.85%
# Validation Accuracy: 22.07%
# Batch: 0, Loss: 1.9709280729293823
#
# Average loss: 1.8001, Accuracy: 51.0/260 (20%)
#
#
# Average loss: 1.7463, Accuracy: 667.0/2940 (23%)
#
# Epoch: 2 	Training Accuracy: 19.62%
# Validation Accuracy: 22.69%
# Batch: 0, Loss: 1.800636887550354
#
# Average loss: 1.7322, Accuracy: 52.0/260 (20%)
#
#
# Average loss: 1.6840, Accuracy: 692.0/2940 (24%)
#
# Epoch: 3 	Training Accuracy: 20.00%
# Validation Accuracy: 23.54%
# Batch: 0, Loss: 1.8291383981704712
#
# Average loss: 1.6693, Accuracy: 54.0/260 (21%)
#
#
# Average loss: 1.6264, Accuracy: 724.0/2940 (25%)
#
# Epoch: 4 	Training Accuracy: 20.77%
# Validation Accuracy: 24.63%
# Batch: 0, Loss: 1.6537750959396362
#
# Average loss: 1.6104, Accuracy: 58.0/260 (22%)
#
#
# Average loss: 1.5720, Accuracy: 754.0/2940 (26%)
#
# Epoch: 5 	Training Accuracy: 22.31%
# Validation Accuracy: 25.65%
# Batch: 0, Loss: 1.668173909187317
#
# Average loss: 1.5558, Accuracy: 59.0/260 (23%)
#
#
# Average loss: 1.5217, Accuracy: 781.0/2940 (27%)
#
# Epoch: 6 	Training Accuracy: 22.69%
# Validation Accuracy: 26.56%
# Batch: 0, Loss: 1.5228774547576904
#
# Average loss: 1.5045, Accuracy: 66.0/260 (25%)
#
#
# Average loss: 1.4739, Accuracy: 819.0/2940 (28%)
#
# Epoch: 7 	Training Accuracy: 25.38%
# Validation Accuracy: 27.86%
# Batch: 0, Loss: 1.496622085571289
#
# Average loss: 1.4525, Accuracy: 69.0/260 (27%)
#
#
# Average loss: 1.4244, Accuracy: 845.0/2940 (29%)
#
# Epoch: 8 	Training Accuracy: 26.54%
# Validation Accuracy: 28.74%
# Batch: 0, Loss: 1.433212161064148
#
# Average loss: 1.3992, Accuracy: 74.0/260 (28%)
#
#
# Average loss: 1.3734, Accuracy: 860.0/2940 (29%)
#
# Epoch: 9 	Training Accuracy: 28.46%
# Validation Accuracy: 29.25%
# Batch: 0, Loss: 1.387355923652649
#
# Average loss: 1.3469, Accuracy: 84.0/260 (32%)
#
#
# Average loss: 1.3235, Accuracy: 929.0/2940 (32%)
#
# Epoch: 10 	Training Accuracy: 32.31%
# Validation Accuracy: 31.60%
# Batch: 0, Loss: 1.3077110052108765
#
# Average loss: 1.2968, Accuracy: 93.0/260 (36%)
#
#
# Average loss: 1.2755, Accuracy: 1052.0/2940 (36%)
#
# Epoch: 11 	Training Accuracy: 35.77%
# Validation Accuracy: 35.78%
# Batch: 0, Loss: 1.3329308032989502
#
# Average loss: 1.2492, Accuracy: 109.0/260 (42%)
#
#
# Average loss: 1.2305, Accuracy: 1205.0/2940 (41%)
#
# Epoch: 12 	Training Accuracy: 41.92%
# Validation Accuracy: 40.99%
# Batch: 0, Loss: 1.238445520401001
#
# Average loss: 1.2047, Accuracy: 132.0/260 (51%)
#
#
# Average loss: 1.1891, Accuracy: 1361.0/2940 (46%)
#
# Epoch: 13 	Training Accuracy: 50.77%
# Validation Accuracy: 46.29%
# Batch: 0, Loss: 1.1943145990371704
#
# Average loss: 1.1627, Accuracy: 137.0/260 (53%)
#
#
# Average loss: 1.1505, Accuracy: 1487.0/2940 (51%)
#
# Epoch: 14 	Training Accuracy: 52.69%
# Validation Accuracy: 50.58%
# Batch: 0, Loss: 1.1307405233383179
#
# Average loss: 1.1224, Accuracy: 143.0/260 (55%)
#
#
# Average loss: 1.1129, Accuracy: 1560.0/2940 (53%)
#
# Epoch: 15 	Training Accuracy: 55.00%
# Validation Accuracy: 53.06%
# Batch: 0, Loss: 1.1239848136901855
#
# Average loss: 1.0838, Accuracy: 150.0/260 (58%)
#
#
# Average loss: 1.0771, Accuracy: 1598.0/2940 (54%)
#
# Epoch: 16 	Training Accuracy: 57.69%
# Validation Accuracy: 54.35%
# Batch: 0, Loss: 1.096606731414795
#
# Average loss: 1.0467, Accuracy: 152.0/260 (58%)
#
#
# Average loss: 1.0430, Accuracy: 1652.0/2940 (56%)
#
# Epoch: 17 	Training Accuracy: 58.46%
# Validation Accuracy: 56.19%
# Batch: 0, Loss: 1.0067534446716309
#
# Average loss: 1.0119, Accuracy: 156.0/260 (60%)
#
#
# Average loss: 1.0116, Accuracy: 1704.0/2940 (58%)
#
# Epoch: 18 	Training Accuracy: 60.00%
# Validation Accuracy: 57.96%
# Batch: 0, Loss: 1.0078505277633667
#
# Average loss: 0.9783, Accuracy: 163.0/260 (63%)
#
#
# Average loss: 0.9812, Accuracy: 1800.0/2940 (61%)
#
# Epoch: 19 	Training Accuracy: 62.69%
# Validation Accuracy: 61.22%
#
# Average loss: 0.9783, Accuracy: 163.0/260 (63%)
#
#
# Average loss: 0.9867, Accuracy: 2927.0/4861 (60%)
# Running seeds for 0.03 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 23 =========================
# Batch: 0, Loss: 2.3058524131774902
#
# Average loss: 1.7591, Accuracy: 264.0/790 (33%)
#
#
# Average loss: 1.7679, Accuracy: 996.0/2940 (34%)
#
# Epoch: 0 	Training Accuracy: 33.42%
# Validation Accuracy: 33.88%
# Batch: 0, Loss: 1.746269702911377
#
# Average loss: 1.5587, Accuracy: 377.0/790 (48%)
#
#
# Average loss: 1.5579, Accuracy: 1373.0/2940 (47%)
#
# Epoch: 1 	Training Accuracy: 47.72%
# Validation Accuracy: 46.70%
# Batch: 0, Loss: 1.4906073808670044
#
# Average loss: 1.3939, Accuracy: 419.0/790 (53%)
#
#
# Average loss: 1.3891, Accuracy: 1517.0/2940 (52%)
#
# Epoch: 2 	Training Accuracy: 53.04%
# Validation Accuracy: 51.60%
# Batch: 0, Loss: 1.3721842765808105
#
# Average loss: 1.2505, Accuracy: 439.0/790 (56%)
#
#
# Average loss: 1.2445, Accuracy: 1595.0/2940 (54%)
#
# Epoch: 3 	Training Accuracy: 55.57%
# Validation Accuracy: 54.25%
# Batch: 0, Loss: 1.272936224937439
#
# Average loss: 1.1236, Accuracy: 493.0/790 (62%)
#
#
# Average loss: 1.1197, Accuracy: 1795.0/2940 (61%)
#
# Epoch: 4 	Training Accuracy: 62.41%
# Validation Accuracy: 61.05%
# Batch: 0, Loss: 1.0401792526245117
#
# Average loss: 1.0080, Accuracy: 559.0/790 (71%)
#
#
# Average loss: 1.0084, Accuracy: 2030.0/2940 (69%)
#
# Epoch: 5 	Training Accuracy: 70.76%
# Validation Accuracy: 69.05%
# Batch: 0, Loss: 0.9832456707954407
#
# Average loss: 0.9033, Accuracy: 593.0/790 (75%)
#
#
# Average loss: 0.9098, Accuracy: 2180.0/2940 (74%)
#
# Epoch: 6 	Training Accuracy: 75.06%
# Validation Accuracy: 74.15%
# Batch: 0, Loss: 0.9307309985160828
#
# Average loss: 0.8122, Accuracy: 640.0/790 (81%)
#
#
# Average loss: 0.8223, Accuracy: 2348.0/2940 (80%)
#
# Epoch: 7 	Training Accuracy: 81.01%
# Validation Accuracy: 79.86%
# Batch: 0, Loss: 0.8361234664916992
#
# Average loss: 0.7324, Accuracy: 666.0/790 (84%)
#
#
# Average loss: 0.7447, Accuracy: 2478.0/2940 (84%)
#
# Epoch: 8 	Training Accuracy: 84.30%
# Validation Accuracy: 84.29%
# Batch: 0, Loss: 0.722385585308075
#
# Average loss: 0.6632, Accuracy: 684.0/790 (87%)
#
#
# Average loss: 0.6768, Accuracy: 2537.0/2940 (86%)
#
# Epoch: 9 	Training Accuracy: 86.58%
# Validation Accuracy: 86.29%
# Batch: 0, Loss: 0.6537204384803772
#
# Average loss: 0.6047, Accuracy: 697.0/790 (88%)
#
#
# Average loss: 0.6196, Accuracy: 2586.0/2940 (88%)
#
# Epoch: 10 	Training Accuracy: 88.23%
# Validation Accuracy: 87.96%
# Batch: 0, Loss: 0.5676338076591492
#
# Average loss: 0.5526, Accuracy: 712.0/790 (90%)
#
#
# Average loss: 0.5685, Accuracy: 2628.0/2940 (89%)
#
# Epoch: 11 	Training Accuracy: 90.13%
# Validation Accuracy: 89.39%
# Batch: 0, Loss: 0.5890821814537048
#
# Average loss: 0.5077, Accuracy: 719.0/790 (91%)
#
#
# Average loss: 0.5234, Accuracy: 2662.0/2940 (91%)
#
# Epoch: 12 	Training Accuracy: 91.01%
# Validation Accuracy: 90.54%
# Batch: 0, Loss: 0.4946693778038025
#
# Average loss: 0.4699, Accuracy: 725.0/790 (92%)
#
#
# Average loss: 0.4859, Accuracy: 2683.0/2940 (91%)
#
# Epoch: 13 	Training Accuracy: 91.77%
# Validation Accuracy: 91.26%
# Batch: 0, Loss: 0.4647233486175537
#
# Average loss: 0.4382, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.4541, Accuracy: 2695.0/2940 (92%)
#
# Epoch: 14 	Training Accuracy: 92.15%
# Validation Accuracy: 91.67%
# Batch: 0, Loss: 0.4189556837081909
#
# Average loss: 0.4107, Accuracy: 732.0/790 (93%)
#
#
# Average loss: 0.4267, Accuracy: 2712.0/2940 (92%)
#
# Epoch: 15 	Training Accuracy: 92.66%
# Validation Accuracy: 92.24%
# Batch: 0, Loss: 0.42254921793937683
#
# Average loss: 0.3853, Accuracy: 729.0/790 (92%)
#
#
# Average loss: 0.4013, Accuracy: 2714.0/2940 (92%)
#
# Epoch: 16 	Training Accuracy: 92.28%
# Validation Accuracy: 92.31%
# Batch: 0, Loss: 0.38018420338630676
#
# Average loss: 0.3636, Accuracy: 732.0/790 (93%)
#
#
# Average loss: 0.3797, Accuracy: 2726.0/2940 (93%)
#
# Epoch: 17 	Training Accuracy: 92.66%
# Validation Accuracy: 92.72%
# Batch: 0, Loss: 0.28912150859832764
#
# Average loss: 0.3446, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.3609, Accuracy: 2730.0/2940 (93%)
#
# Epoch: 18 	Training Accuracy: 93.16%
# Validation Accuracy: 92.86%
# Batch: 0, Loss: 0.3548562824726105
#
# Average loss: 0.3277, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.3444, Accuracy: 2739.0/2940 (93%)
#
# Epoch: 19 	Training Accuracy: 93.16%
# Validation Accuracy: 93.16%
#
# Average loss: 0.3277, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.3312, Accuracy: 4535.0/4861 (93%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 86 =========================
# Batch: 0, Loss: 1.2680763006210327
#
# Average loss: 1.1205, Accuracy: 415.0/790 (53%)
#
#
# Average loss: 1.1312, Accuracy: 1533.0/2940 (52%)
#
# Epoch: 0 	Training Accuracy: 52.53%
# Validation Accuracy: 52.14%
# Batch: 0, Loss: 1.1329424381256104
#
# Average loss: 0.9827, Accuracy: 570.0/790 (72%)
#
#
# Average loss: 0.9938, Accuracy: 2131.0/2940 (72%)
#
# Epoch: 1 	Training Accuracy: 72.15%
# Validation Accuracy: 72.48%
# Batch: 0, Loss: 0.9806821346282959
#
# Average loss: 0.8670, Accuracy: 658.0/790 (83%)
#
#
# Average loss: 0.8806, Accuracy: 2411.0/2940 (82%)
#
# Epoch: 2 	Training Accuracy: 83.29%
# Validation Accuracy: 82.01%
# Batch: 0, Loss: 0.876018762588501
#
# Average loss: 0.7648, Accuracy: 707.0/790 (89%)
#
#
# Average loss: 0.7805, Accuracy: 2573.0/2940 (88%)
#
# Epoch: 3 	Training Accuracy: 89.49%
# Validation Accuracy: 87.52%
# Batch: 0, Loss: 0.7586405873298645
#
# Average loss: 0.6773, Accuracy: 714.0/790 (90%)
#
#
# Average loss: 0.6947, Accuracy: 2614.0/2940 (89%)
#
# Epoch: 4 	Training Accuracy: 90.38%
# Validation Accuracy: 88.91%
# Batch: 0, Loss: 0.6916340589523315
#
# Average loss: 0.6037, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.6206, Accuracy: 2688.0/2940 (91%)
#
# Epoch: 5 	Training Accuracy: 92.15%
# Validation Accuracy: 91.43%
# Batch: 0, Loss: 0.5948120355606079
#
# Average loss: 0.5424, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.5593, Accuracy: 2723.0/2940 (93%)
#
# Epoch: 6 	Training Accuracy: 93.16%
# Validation Accuracy: 92.62%
# Batch: 0, Loss: 0.5613372325897217
#
# Average loss: 0.4921, Accuracy: 743.0/790 (94%)
#
#
# Average loss: 0.5089, Accuracy: 2751.0/2940 (94%)
#
# Epoch: 7 	Training Accuracy: 94.05%
# Validation Accuracy: 93.57%
# Batch: 0, Loss: 0.4800127148628235
#
# Average loss: 0.4485, Accuracy: 748.0/790 (95%)
#
#
# Average loss: 0.4669, Accuracy: 2764.0/2940 (94%)
#
# Epoch: 8 	Training Accuracy: 94.68%
# Validation Accuracy: 94.01%
# Batch: 0, Loss: 0.45157381892204285
#
# Average loss: 0.4118, Accuracy: 746.0/790 (94%)
#
#
# Average loss: 0.4331, Accuracy: 2745.0/2940 (93%)
#
# Epoch: 9 	Training Accuracy: 94.43%
# Validation Accuracy: 93.37%
# Batch: 0, Loss: 0.388908326625824
#
# Average loss: 0.3806, Accuracy: 751.0/790 (95%)
#
#
# Average loss: 0.4035, Accuracy: 2756.0/2940 (94%)
#
# Epoch: 10 	Training Accuracy: 95.06%
# Validation Accuracy: 93.74%
# Batch: 0, Loss: 0.3607631027698517
#
# Average loss: 0.3536, Accuracy: 753.0/790 (95%)
#
#
# Average loss: 0.3786, Accuracy: 2763.0/2940 (94%)
#
# Epoch: 11 	Training Accuracy: 95.32%
# Validation Accuracy: 93.98%
# Batch: 0, Loss: 0.40829119086265564
#
# Average loss: 0.3313, Accuracy: 754.0/790 (95%)
#
#
# Average loss: 0.3572, Accuracy: 2770.0/2940 (94%)
#
# Epoch: 12 	Training Accuracy: 95.44%
# Validation Accuracy: 94.22%
# Batch: 0, Loss: 0.3278713524341583
#
# Average loss: 0.3107, Accuracy: 755.0/790 (96%)
#
#
# Average loss: 0.3381, Accuracy: 2773.0/2940 (94%)
#
# Epoch: 13 	Training Accuracy: 95.57%
# Validation Accuracy: 94.32%
# Batch: 0, Loss: 0.3318901062011719
#
# Average loss: 0.2929, Accuracy: 754.0/790 (95%)
#
#
# Average loss: 0.3209, Accuracy: 2767.0/2940 (94%)
#
# Epoch: 14 	Training Accuracy: 95.44%
# Validation Accuracy: 94.12%
# Batch: 0, Loss: 0.28220731019973755
#
# Average loss: 0.2773, Accuracy: 755.0/790 (96%)
#
#
# Average loss: 0.3066, Accuracy: 2768.0/2940 (94%)
#
# Epoch: 15 	Training Accuracy: 95.57%
# Validation Accuracy: 94.15%
# Batch: 0, Loss: 0.282536119222641
#
# Average loss: 0.2640, Accuracy: 755.0/790 (96%)
#
#
# Average loss: 0.2948, Accuracy: 2770.0/2940 (94%)
#
# Epoch: 16 	Training Accuracy: 95.57%
# Validation Accuracy: 94.22%
# Batch: 0, Loss: 0.2617848515510559
#
# Average loss: 0.2514, Accuracy: 756.0/790 (96%)
#
#
# Average loss: 0.2831, Accuracy: 2772.0/2940 (94%)
#
# Epoch: 17 	Training Accuracy: 95.70%
# Validation Accuracy: 94.29%
# Batch: 0, Loss: 0.27524271607398987
#
# Average loss: 0.2405, Accuracy: 754.0/790 (95%)
#
#
# Average loss: 0.2734, Accuracy: 2777.0/2940 (94%)
#
# Epoch: 18 	Training Accuracy: 95.44%
# Validation Accuracy: 94.46%
# Batch: 0, Loss: 0.2603527903556824
#
# Average loss: 0.2314, Accuracy: 755.0/790 (96%)
#
#
# Average loss: 0.2668, Accuracy: 2778.0/2940 (94%)
#
# Epoch: 19 	Training Accuracy: 95.57%
# Validation Accuracy: 94.49%
#
# Average loss: 0.2314, Accuracy: 755.0/790 (96%)
#
#
# Average loss: 0.2531, Accuracy: 4594.0/4861 (95%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 66 =========================
# Batch: 0, Loss: 2.3403406143188477
#
# Average loss: 2.0249, Accuracy: 98.0/790 (12%)
#
#
# Average loss: 2.0159, Accuracy: 390.0/2940 (13%)
#
# Epoch: 0 	Training Accuracy: 12.41%
# Validation Accuracy: 13.27%
# Batch: 0, Loss: 1.8944793939590454
#
# Average loss: 1.8234, Accuracy: 211.0/790 (27%)
#
#
# Average loss: 1.8104, Accuracy: 817.0/2940 (28%)
#
# Epoch: 1 	Training Accuracy: 26.71%
# Validation Accuracy: 27.79%
# Batch: 0, Loss: 1.9002336263656616
#
# Average loss: 1.6506, Accuracy: 249.0/790 (32%)
#
#
# Average loss: 1.6364, Accuracy: 954.0/2940 (32%)
#
# Epoch: 2 	Training Accuracy: 31.52%
# Validation Accuracy: 32.45%
# Batch: 0, Loss: 1.6556496620178223
#
# Average loss: 1.4967, Accuracy: 284.0/790 (36%)
#
#
# Average loss: 1.4831, Accuracy: 1060.0/2940 (36%)
#
# Epoch: 3 	Training Accuracy: 35.95%
# Validation Accuracy: 36.05%
# Batch: 0, Loss: 1.5078315734863281
#
# Average loss: 1.3586, Accuracy: 319.0/790 (40%)
#
#
# Average loss: 1.3469, Accuracy: 1202.0/2940 (41%)
#
# Epoch: 4 	Training Accuracy: 40.38%
# Validation Accuracy: 40.88%
# Batch: 0, Loss: 1.3703367710113525
#
# Average loss: 1.2338, Accuracy: 357.0/790 (45%)
#
#
# Average loss: 1.2230, Accuracy: 1341.0/2940 (46%)
#
# Epoch: 5 	Training Accuracy: 45.19%
# Validation Accuracy: 45.61%
# Batch: 0, Loss: 1.2591285705566406
#
# Average loss: 1.1229, Accuracy: 443.0/790 (56%)
#
#
# Average loss: 1.1137, Accuracy: 1655.0/2940 (56%)
#
# Epoch: 6 	Training Accuracy: 56.08%
# Validation Accuracy: 56.29%
# Batch: 0, Loss: 1.1207799911499023
#
# Average loss: 1.0243, Accuracy: 532.0/790 (67%)
#
#
# Average loss: 1.0169, Accuracy: 1957.0/2940 (67%)
#
# Epoch: 7 	Training Accuracy: 67.34%
# Validation Accuracy: 66.56%
# Batch: 0, Loss: 1.0602165460586548
#
# Average loss: 0.9358, Accuracy: 586.0/790 (74%)
#
#
# Average loss: 0.9308, Accuracy: 2141.0/2940 (73%)
#
# Epoch: 8 	Training Accuracy: 74.18%
# Validation Accuracy: 72.82%
# Batch: 0, Loss: 0.9579936861991882
#
# Average loss: 0.8570, Accuracy: 628.0/790 (79%)
#
#
# Average loss: 0.8544, Accuracy: 2276.0/2940 (77%)
#
# Epoch: 9 	Training Accuracy: 79.49%
# Validation Accuracy: 77.41%
# Batch: 0, Loss: 0.8311434984207153
#
# Average loss: 0.7864, Accuracy: 662.0/790 (84%)
#
#
# Average loss: 0.7864, Accuracy: 2383.0/2940 (81%)
#
# Epoch: 10 	Training Accuracy: 83.80%
# Validation Accuracy: 81.05%
# Batch: 0, Loss: 0.823424756526947
#
# Average loss: 0.7236, Accuracy: 680.0/790 (86%)
#
#
# Average loss: 0.7261, Accuracy: 2476.0/2940 (84%)
#
# Epoch: 11 	Training Accuracy: 86.08%
# Validation Accuracy: 84.22%
# Batch: 0, Loss: 0.7090973854064941
#
# Average loss: 0.6670, Accuracy: 699.0/790 (88%)
#
#
# Average loss: 0.6725, Accuracy: 2541.0/2940 (86%)
#
# Epoch: 12 	Training Accuracy: 88.48%
# Validation Accuracy: 86.43%
# Batch: 0, Loss: 0.6896181106567383
#
# Average loss: 0.6158, Accuracy: 711.0/790 (90%)
#
#
# Average loss: 0.6247, Accuracy: 2588.0/2940 (88%)
#
# Epoch: 13 	Training Accuracy: 90.00%
# Validation Accuracy: 88.03%
# Batch: 0, Loss: 0.6472082138061523
#
# Average loss: 0.5705, Accuracy: 720.0/790 (91%)
#
#
# Average loss: 0.5828, Accuracy: 2622.0/2940 (89%)
#
# Epoch: 14 	Training Accuracy: 91.14%
# Validation Accuracy: 89.18%
# Batch: 0, Loss: 0.6053239107131958
#
# Average loss: 0.5298, Accuracy: 724.0/790 (92%)
#
#
# Average loss: 0.5451, Accuracy: 2653.0/2940 (90%)
#
# Epoch: 15 	Training Accuracy: 91.65%
# Validation Accuracy: 90.24%
# Batch: 0, Loss: 0.5325172543525696
#
# Average loss: 0.4934, Accuracy: 728.0/790 (92%)
#
#
# Average loss: 0.5114, Accuracy: 2662.0/2940 (91%)
#
# Epoch: 16 	Training Accuracy: 92.15%
# Validation Accuracy: 90.54%
# Batch: 0, Loss: 0.4686441123485565
#
# Average loss: 0.4606, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.4812, Accuracy: 2685.0/2940 (91%)
#
# Epoch: 17 	Training Accuracy: 93.16%
# Validation Accuracy: 91.33%
# Batch: 0, Loss: 0.4886210858821869
#
# Average loss: 0.4319, Accuracy: 737.0/790 (93%)
#
#
# Average loss: 0.4544, Accuracy: 2700.0/2940 (92%)
#
# Epoch: 18 	Training Accuracy: 93.29%
# Validation Accuracy: 91.84%
# Batch: 0, Loss: 0.41448187828063965
#
# Average loss: 0.4060, Accuracy: 737.0/790 (93%)
#
#
# Average loss: 0.4307, Accuracy: 2710.0/2940 (92%)
#
# Epoch: 19 	Training Accuracy: 93.29%
# Validation Accuracy: 92.18%
#
# Average loss: 0.4060, Accuracy: 737.0/790 (93%)
#
#
# Average loss: 0.4172, Accuracy: 4473.0/4861 (92%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 12 =========================
# Batch: 0, Loss: 1.7860790491104126
#
# Average loss: 1.5625, Accuracy: 184.0/790 (23%)
#
#
# Average loss: 1.5676, Accuracy: 621.0/2940 (21%)
#
# Epoch: 0 	Training Accuracy: 23.29%
# Validation Accuracy: 21.12%
# Batch: 0, Loss: 1.5661662817001343
#
# Average loss: 1.3978, Accuracy: 245.0/790 (31%)
#
#
# Average loss: 1.4032, Accuracy: 916.0/2940 (31%)
#
# Epoch: 1 	Training Accuracy: 31.01%
# Validation Accuracy: 31.16%
# Batch: 0, Loss: 1.4217305183410645
#
# Average loss: 1.2539, Accuracy: 379.0/790 (48%)
#
#
# Average loss: 1.2613, Accuracy: 1361.0/2940 (46%)
#
# Epoch: 2 	Training Accuracy: 47.97%
# Validation Accuracy: 46.29%
# Batch: 0, Loss: 1.2947757244110107
#
# Average loss: 1.1261, Accuracy: 477.0/790 (60%)
#
#
# Average loss: 1.1352, Accuracy: 1727.0/2940 (59%)
#
# Epoch: 3 	Training Accuracy: 60.38%
# Validation Accuracy: 58.74%
# Batch: 0, Loss: 1.1249336004257202
#
# Average loss: 1.0125, Accuracy: 524.0/790 (66%)
#
#
# Average loss: 1.0222, Accuracy: 1939.0/2940 (66%)
#
# Epoch: 4 	Training Accuracy: 66.33%
# Validation Accuracy: 65.95%
# Batch: 0, Loss: 0.9955085515975952
#
# Average loss: 0.9115, Accuracy: 573.0/790 (73%)
#
#
# Average loss: 0.9238, Accuracy: 2092.0/2940 (71%)
#
# Epoch: 5 	Training Accuracy: 72.53%
# Validation Accuracy: 71.16%
# Batch: 0, Loss: 0.9256292581558228
#
# Average loss: 0.8228, Accuracy: 606.0/790 (77%)
#
#
# Average loss: 0.8382, Accuracy: 2235.0/2940 (76%)
#
# Epoch: 6 	Training Accuracy: 76.71%
# Validation Accuracy: 76.02%
# Batch: 0, Loss: 0.8342356085777283
#
# Average loss: 0.7445, Accuracy: 644.0/790 (82%)
#
#
# Average loss: 0.7623, Accuracy: 2363.0/2940 (80%)
#
# Epoch: 7 	Training Accuracy: 81.52%
# Validation Accuracy: 80.37%
# Batch: 0, Loss: 0.7554782629013062
#
# Average loss: 0.6749, Accuracy: 675.0/790 (85%)
#
#
# Average loss: 0.6952, Accuracy: 2449.0/2940 (83%)
#
# Epoch: 8 	Training Accuracy: 85.44%
# Validation Accuracy: 83.30%
# Batch: 0, Loss: 0.6881441473960876
#
# Average loss: 0.6148, Accuracy: 701.0/790 (89%)
#
#
# Average loss: 0.6368, Accuracy: 2535.0/2940 (86%)
#
# Epoch: 9 	Training Accuracy: 88.73%
# Validation Accuracy: 86.22%
# Batch: 0, Loss: 0.6398622393608093
#
# Average loss: 0.5618, Accuracy: 717.0/790 (91%)
#
#
# Average loss: 0.5851, Accuracy: 2588.0/2940 (88%)
#
# Epoch: 10 	Training Accuracy: 90.76%
# Validation Accuracy: 88.03%
# Batch: 0, Loss: 0.5449498295783997
#
# Average loss: 0.5170, Accuracy: 726.0/790 (92%)
#
#
# Average loss: 0.5421, Accuracy: 2619.0/2940 (89%)
#
# Epoch: 11 	Training Accuracy: 91.90%
# Validation Accuracy: 89.08%
# Batch: 0, Loss: 0.5303176641464233
#
# Average loss: 0.4765, Accuracy: 730.0/790 (92%)
#
#
# Average loss: 0.5033, Accuracy: 2639.0/2940 (90%)
#
# Epoch: 12 	Training Accuracy: 92.41%
# Validation Accuracy: 89.76%
# Batch: 0, Loss: 0.4836276173591614
#
# Average loss: 0.4414, Accuracy: 730.0/790 (92%)
#
#
# Average loss: 0.4699, Accuracy: 2656.0/2940 (90%)
#
# Epoch: 13 	Training Accuracy: 92.41%
# Validation Accuracy: 90.34%
# Batch: 0, Loss: 0.403906911611557
#
# Average loss: 0.4110, Accuracy: 734.0/790 (93%)
#
#
# Average loss: 0.4409, Accuracy: 2676.0/2940 (91%)
#
# Epoch: 14 	Training Accuracy: 92.91%
# Validation Accuracy: 91.02%
# Batch: 0, Loss: 0.39161017537117004
#
# Average loss: 0.3856, Accuracy: 738.0/790 (93%)
#
#
# Average loss: 0.4164, Accuracy: 2693.0/2940 (92%)
#
# Epoch: 15 	Training Accuracy: 93.42%
# Validation Accuracy: 91.60%
# Batch: 0, Loss: 0.3420562148094177
#
# Average loss: 0.3610, Accuracy: 740.0/790 (94%)
#
#
# Average loss: 0.3930, Accuracy: 2694.0/2940 (92%)
#
# Epoch: 16 	Training Accuracy: 93.67%
# Validation Accuracy: 91.63%
# Batch: 0, Loss: 0.33788177371025085
#
# Average loss: 0.3402, Accuracy: 739.0/790 (94%)
#
#
# Average loss: 0.3735, Accuracy: 2700.0/2940 (92%)
#
# Epoch: 17 	Training Accuracy: 93.54%
# Validation Accuracy: 91.84%
# Batch: 0, Loss: 0.28796765208244324
#
# Average loss: 0.3216, Accuracy: 747.0/790 (95%)
#
#
# Average loss: 0.3560, Accuracy: 2705.0/2940 (92%)
#
# Epoch: 18 	Training Accuracy: 94.56%
# Validation Accuracy: 92.01%
# Batch: 0, Loss: 0.2901739776134491
#
# Average loss: 0.3045, Accuracy: 750.0/790 (95%)
#
#
# Average loss: 0.3401, Accuracy: 2715.0/2940 (92%)
#
# Epoch: 19 	Training Accuracy: 94.94%
# Validation Accuracy: 92.35%
#
# Average loss: 0.3045, Accuracy: 750.0/790 (95%)
#
#
# Average loss: 0.3241, Accuracy: 4523.0/4861 (93%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 19 =========================
# Batch: 0, Loss: 1.5375922918319702
#
# Average loss: 1.3792, Accuracy: 262.0/790 (33%)
#
#
# Average loss: 1.3627, Accuracy: 1065.0/2940 (36%)
#
# Epoch: 0 	Training Accuracy: 33.16%
# Validation Accuracy: 36.22%
# Batch: 0, Loss: 1.3340805768966675
#
# Average loss: 1.2351, Accuracy: 342.0/790 (43%)
#
#
# Average loss: 1.2180, Accuracy: 1384.0/2940 (47%)
#
# Epoch: 1 	Training Accuracy: 43.29%
# Validation Accuracy: 47.07%
# Batch: 0, Loss: 1.2824796438217163
#
# Average loss: 1.1089, Accuracy: 416.0/790 (53%)
#
#
# Average loss: 1.0925, Accuracy: 1631.0/2940 (55%)
#
# Epoch: 2 	Training Accuracy: 52.66%
# Validation Accuracy: 55.48%
# Batch: 0, Loss: 1.0920302867889404
#
# Average loss: 0.9960, Accuracy: 500.0/790 (63%)
#
#
# Average loss: 0.9819, Accuracy: 1918.0/2940 (65%)
#
# Epoch: 3 	Training Accuracy: 63.29%
# Validation Accuracy: 65.24%
# Batch: 0, Loss: 0.9961261749267578
#
# Average loss: 0.8959, Accuracy: 582.0/790 (74%)
#
#
# Average loss: 0.8843, Accuracy: 2163.0/2940 (74%)
#
# Epoch: 4 	Training Accuracy: 73.67%
# Validation Accuracy: 73.57%
# Batch: 0, Loss: 0.8937247395515442
#
# Average loss: 0.8077, Accuracy: 630.0/790 (80%)
#
#
# Average loss: 0.7985, Accuracy: 2346.0/2940 (80%)
#
# Epoch: 5 	Training Accuracy: 79.75%
# Validation Accuracy: 79.80%
# Batch: 0, Loss: 0.8109949827194214
#
# Average loss: 0.7282, Accuracy: 670.0/790 (85%)
#
#
# Average loss: 0.7214, Accuracy: 2485.0/2940 (85%)
#
# Epoch: 6 	Training Accuracy: 84.81%
# Validation Accuracy: 84.52%
# Batch: 0, Loss: 0.6810792684555054
#
# Average loss: 0.6601, Accuracy: 694.0/790 (88%)
#
#
# Average loss: 0.6565, Accuracy: 2573.0/2940 (88%)
#
# Epoch: 7 	Training Accuracy: 87.85%
# Validation Accuracy: 87.52%
# Batch: 0, Loss: 0.6505423784255981
#
# Average loss: 0.6002, Accuracy: 716.0/790 (91%)
#
#
# Average loss: 0.5992, Accuracy: 2628.0/2940 (89%)
#
# Epoch: 8 	Training Accuracy: 90.63%
# Validation Accuracy: 89.39%
# Batch: 0, Loss: 0.5563163757324219
#
# Average loss: 0.5484, Accuracy: 726.0/790 (92%)
#
#
# Average loss: 0.5497, Accuracy: 2678.0/2940 (91%)
#
# Epoch: 9 	Training Accuracy: 91.90%
# Validation Accuracy: 91.09%
# Batch: 0, Loss: 0.5187208652496338
#
# Average loss: 0.5034, Accuracy: 732.0/790 (93%)
#
#
# Average loss: 0.5067, Accuracy: 2703.0/2940 (92%)
#
# Epoch: 10 	Training Accuracy: 92.66%
# Validation Accuracy: 91.94%
# Batch: 0, Loss: 0.4822266697883606
#
# Average loss: 0.4644, Accuracy: 734.0/790 (93%)
#
#
# Average loss: 0.4697, Accuracy: 2712.0/2940 (92%)
#
# Epoch: 11 	Training Accuracy: 92.91%
# Validation Accuracy: 92.24%
# Batch: 0, Loss: 0.44744259119033813
#
# Average loss: 0.4306, Accuracy: 736.0/790 (93%)
#
#
# Average loss: 0.4378, Accuracy: 2726.0/2940 (93%)
#
# Epoch: 12 	Training Accuracy: 93.16%
# Validation Accuracy: 92.72%
# Batch: 0, Loss: 0.43730443716049194
#
# Average loss: 0.4015, Accuracy: 739.0/790 (94%)
#
#
# Average loss: 0.4104, Accuracy: 2739.0/2940 (93%)
#
# Epoch: 13 	Training Accuracy: 93.54%
# Validation Accuracy: 93.16%
# Batch: 0, Loss: 0.3921530246734619
#
# Average loss: 0.3758, Accuracy: 741.0/790 (94%)
#
#
# Average loss: 0.3867, Accuracy: 2745.0/2940 (93%)
#
# Epoch: 14 	Training Accuracy: 93.80%
# Validation Accuracy: 93.37%
# Batch: 0, Loss: 0.34032055735588074
#
# Average loss: 0.3530, Accuracy: 743.0/790 (94%)
#
#
# Average loss: 0.3657, Accuracy: 2753.0/2940 (94%)
#
# Epoch: 15 	Training Accuracy: 94.05%
# Validation Accuracy: 93.64%
# Batch: 0, Loss: 0.3199656903743744
#
# Average loss: 0.3328, Accuracy: 743.0/790 (94%)
#
#
# Average loss: 0.3474, Accuracy: 2758.0/2940 (94%)
#
# Epoch: 16 	Training Accuracy: 94.05%
# Validation Accuracy: 93.81%
# Batch: 0, Loss: 0.32552435994148254
#
# Average loss: 0.3151, Accuracy: 743.0/790 (94%)
#
#
# Average loss: 0.3314, Accuracy: 2754.0/2940 (94%)
#
# Epoch: 17 	Training Accuracy: 94.05%
# Validation Accuracy: 93.67%
# Batch: 0, Loss: 0.3376446068286896
#
# Average loss: 0.2989, Accuracy: 745.0/790 (94%)
#
#
# Average loss: 0.3167, Accuracy: 2761.0/2940 (94%)
#
# Epoch: 18 	Training Accuracy: 94.30%
# Validation Accuracy: 93.91%
# Batch: 0, Loss: 0.33366912603378296
#
# Average loss: 0.2846, Accuracy: 749.0/790 (95%)
#
#
# Average loss: 0.3041, Accuracy: 2761.0/2940 (94%)
#
# Epoch: 19 	Training Accuracy: 94.81%
# Validation Accuracy: 93.91%
#
# Average loss: 0.2846, Accuracy: 749.0/790 (95%)
#
#
# Average loss: 0.2794, Accuracy: 4601.0/4861 (95%)
# Running seeds for 0.05 data:   0%|          | 0/5 [00:00<?, ?it/s]
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 63 =========================
# Batch: 0, Loss: 1.938523769378662
#
# Average loss: 1.6204, Accuracy: 567.0/1320 (43%)
#
#
# Average loss: 1.6389, Accuracy: 1272.0/2940 (43%)
#
# Epoch: 0 	Training Accuracy: 42.95%
# Validation Accuracy: 43.27%
# Batch: 0, Loss: 1.7655084133148193
#
# Average loss: 1.3580, Accuracy: 686.0/1320 (52%)
#
#
# Average loss: 1.3629, Accuracy: 1504.0/2940 (51%)
#
# Epoch: 1 	Training Accuracy: 51.97%
# Validation Accuracy: 51.16%
# Batch: 0, Loss: 1.3429845571517944
#
# Average loss: 1.1476, Accuracy: 765.0/1320 (58%)
#
#
# Average loss: 1.1474, Accuracy: 1679.0/2940 (57%)
#
# Epoch: 2 	Training Accuracy: 57.95%
# Validation Accuracy: 57.11%
# Batch: 0, Loss: 1.1528211832046509
#
# Average loss: 0.9663, Accuracy: 904.0/1320 (68%)
#
#
# Average loss: 0.9681, Accuracy: 2027.0/2940 (69%)
#
# Epoch: 3 	Training Accuracy: 68.48%
# Validation Accuracy: 68.95%
# Batch: 0, Loss: 0.9397203922271729
#
# Average loss: 0.8160, Accuracy: 1041.0/1320 (79%)
#
#
# Average loss: 0.8207, Accuracy: 2332.0/2940 (79%)
#
# Epoch: 4 	Training Accuracy: 78.86%
# Validation Accuracy: 79.32%
# Batch: 0, Loss: 0.7599220871925354
#
# Average loss: 0.6918, Accuracy: 1141.0/1320 (86%)
#
#
# Average loss: 0.6996, Accuracy: 2510.0/2940 (85%)
#
# Epoch: 5 	Training Accuracy: 86.44%
# Validation Accuracy: 85.37%
# Batch: 0, Loss: 0.7323116064071655
#
# Average loss: 0.5911, Accuracy: 1190.0/1320 (90%)
#
#
# Average loss: 0.6016, Accuracy: 2607.0/2940 (89%)
#
# Epoch: 6 	Training Accuracy: 90.15%
# Validation Accuracy: 88.67%
# Batch: 0, Loss: 0.5826106667518616
#
# Average loss: 0.5115, Accuracy: 1213.0/1320 (92%)
#
#
# Average loss: 0.5253, Accuracy: 2650.0/2940 (90%)
#
# Epoch: 7 	Training Accuracy: 91.89%
# Validation Accuracy: 90.14%
# Batch: 0, Loss: 0.48664116859436035
#
# Average loss: 0.4483, Accuracy: 1230.0/1320 (93%)
#
#
# Average loss: 0.4647, Accuracy: 2691.0/2940 (92%)
#
# Epoch: 8 	Training Accuracy: 93.18%
# Validation Accuracy: 91.53%
# Batch: 0, Loss: 0.3818269670009613
#
# Average loss: 0.3994, Accuracy: 1240.0/1320 (94%)
#
#
# Average loss: 0.4166, Accuracy: 2710.0/2940 (92%)
#
# Epoch: 9 	Training Accuracy: 93.94%
# Validation Accuracy: 92.18%
# ...
# Batch: 140, Loss: 0.053718600422143936
# Batch: 160, Loss: 0.12822332978248596
# Batch: 180, Loss: 0.1763957291841507
# Batch: 200, Loss: 0.034399598836898804
#
# Average loss: 0.0784, Accuracy: 25396.0/26038 (98%)
#
#
# Average loss: 0.1057, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 14 	Training Accuracy: 97.53%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.056594811379909515
# Batch: 20, Loss: 0.03173598647117615
# Batch: 40, Loss: 0.1585807055234909
# Batch: 60, Loss: 0.06167089566588402
# Batch: 80, Loss: 0.09147553890943527
# Batch: 100, Loss: 0.12183286249637604
# Batch: 120, Loss: 0.0868116170167923
# Batch: 140, Loss: 0.15249189734458923
# Batch: 160, Loss: 0.09026388078927994
# Batch: 180, Loss: 0.10623007267713547
# Batch: 200, Loss: 0.06661439687013626
#
# Average loss: 0.0785, Accuracy: 25391.0/26038 (98%)
#
#
# Average loss: 0.1042, Accuracy: 2854.0/2940 (97%)
#
# Epoch: 15 	Training Accuracy: 97.52%
# Validation Accuracy: 97.07%
# Batch: 0, Loss: 0.043902572244405746
# Batch: 20, Loss: 0.07904739677906036
# Batch: 40, Loss: 0.035292740911245346
# Batch: 60, Loss: 0.047569114714860916
# Batch: 80, Loss: 0.05554936081171036
# Batch: 100, Loss: 0.06741231679916382
# Batch: 120, Loss: 0.05822770297527313
# Batch: 140, Loss: 0.09560824930667877
# Batch: 160, Loss: 0.15339191257953644
# Batch: 180, Loss: 0.016272295266389847
# Batch: 200, Loss: 0.01783277653157711
#
# Average loss: 0.0783, Accuracy: 25418.0/26038 (98%)
#
#
# Average loss: 0.1071, Accuracy: 2851.0/2940 (97%)
#
# Epoch: 16 	Training Accuracy: 97.62%
# Validation Accuracy: 96.97%
# Early stopping invoked.
#
# Average loss: 0.0835, Accuracy: 25363.0/26038 (97%)
#
#
# Average loss: 0.0753, Accuracy: 4736.0/4861 (97%)
#
# Repeat: CustomCNN(
#   (conv0): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act0): ReLU()
#   (conv1): Conv2d(1, 1, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (fc_1): Linear(in_features=576, out_features=128, bias=True)
#   (fc_2): Linear(in_features=128, out_features=10, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# ), with seed 59 =========================
# Batch: 0, Loss: 2.0395662784576416
# Batch: 20, Loss: 1.3590885400772095
# Batch: 40, Loss: 1.0280286073684692
# Batch: 60, Loss: 0.6481610536575317
# Batch: 80, Loss: 0.6044263243675232
# Batch: 100, Loss: 0.45233672857284546
# Batch: 120, Loss: 0.30880579352378845
# Batch: 140, Loss: 0.33092382550239563
# Batch: 160, Loss: 0.3342990577220917
# Batch: 180, Loss: 0.196071058511734
# Batch: 200, Loss: 0.23227152228355408
#
# Average loss: 0.2357, Accuracy: 24704.0/26038 (95%)
#
#
# Average loss: 0.2562, Accuracy: 2748.0/2940 (93%)
#
# Epoch: 0 	Training Accuracy: 94.88%
# Validation Accuracy: 93.47%
# Batch: 0, Loss: 0.21212361752986908
# Batch: 20, Loss: 0.2696664333343506
# Batch: 40, Loss: 0.24772575497627258
# Batch: 60, Loss: 0.19344429671764374
# Batch: 80, Loss: 0.16916100680828094
# Batch: 100, Loss: 0.19447262585163116
# Batch: 120, Loss: 0.17588062584400177
# Batch: 140, Loss: 0.19719791412353516
# Batch: 160, Loss: 0.16602493822574615
# Batch: 180, Loss: 0.17093150317668915
# Batch: 200, Loss: 0.25832241773605347
#
# Average loss: 0.1528, Accuracy: 24960.0/26038 (96%)
#
#
# Average loss: 0.1735, Accuracy: 2804.0/2940 (95%)
#
# Epoch: 1 	Training Accuracy: 95.86%
# Validation Accuracy: 95.37%
# Batch: 0, Loss: 0.11550576239824295
# Batch: 20, Loss: 0.17728452384471893
# Batch: 40, Loss: 0.17434559762477875
# Batch: 60, Loss: 0.15058299899101257
# Batch: 80, Loss: 0.17423410713672638
# Batch: 100, Loss: 0.12314676493406296
# Batch: 120, Loss: 0.09967165440320969
# Batch: 140, Loss: 0.13347680866718292
# Batch: 160, Loss: 0.09681455045938492
# Batch: 180, Loss: 0.1576836258172989
# Batch: 200, Loss: 0.13026180863380432
#
# Average loss: 0.1267, Accuracy: 25083.0/26038 (96%)
#
#
# Average loss: 0.1490, Accuracy: 2810.0/2940 (96%)
#
# Epoch: 2 	Training Accuracy: 96.33%
# Validation Accuracy: 95.58%
# Batch: 0, Loss: 0.2513980269432068
# Batch: 20, Loss: 0.1671091765165329
# Batch: 40, Loss: 0.06240643933415413
# Batch: 60, Loss: 0.15144465863704681
# Batch: 80, Loss: 0.09662705659866333
# Batch: 100, Loss: 0.11482672393321991
# Batch: 120, Loss: 0.0808502733707428
# Batch: 140, Loss: 0.12329331040382385
# Batch: 160, Loss: 0.07299713790416718
# Batch: 180, Loss: 0.11961352825164795
# Batch: 200, Loss: 0.09735724329948425
#
# Average loss: 0.1142, Accuracy: 25157.0/26038 (97%)
#
#
# Average loss: 0.1367, Accuracy: 2817.0/2940 (96%)
#
# Epoch: 3 	Training Accuracy: 96.62%
# Validation Accuracy: 95.82%
# Batch: 0, Loss: 0.14275331795215607
# Batch: 20, Loss: 0.08372696489095688
# Batch: 40, Loss: 0.07676752656698227
# Batch: 60, Loss: 0.09755703806877136
# Batch: 80, Loss: 0.09136220067739487
# Batch: 100, Loss: 0.21488413214683533
# Batch: 120, Loss: 0.13920141756534576
# Batch: 140, Loss: 0.11441651731729507
# Batch: 160, Loss: 0.1339365839958191
# Batch: 180, Loss: 0.07961016148328781
# Batch: 200, Loss: 0.1274709850549698
#
# Average loss: 0.1076, Accuracy: 25188.0/26038 (97%)
#
#
# Average loss: 0.1311, Accuracy: 2821.0/2940 (96%)
#
# Epoch: 4 	Training Accuracy: 96.74%
# Validation Accuracy: 95.95%
# Batch: 0, Loss: 0.09936640411615372
# Batch: 20, Loss: 0.12861019372940063
# Batch: 40, Loss: 0.10139884054660797
# Batch: 60, Loss: 0.05423787236213684
# Batch: 80, Loss: 0.17035849392414093
# Batch: 100, Loss: 0.05602577328681946
# Batch: 120, Loss: 0.10942097753286362
# Batch: 140, Loss: 0.09814182668924332
# Batch: 160, Loss: 0.06908552348613739
# Batch: 180, Loss: 0.10598795861005783
# Batch: 200, Loss: 0.08904597908258438
#
# Average loss: 0.1005, Accuracy: 25253.0/26038 (97%)
#
#
# Average loss: 0.1235, Accuracy: 2834.0/2940 (96%)
#
# Epoch: 5 	Training Accuracy: 96.99%
# Validation Accuracy: 96.39%
# Batch: 0, Loss: 0.08576814830303192
# Batch: 20, Loss: 0.07284503430128098
# Batch: 40, Loss: 0.0887053906917572
# Batch: 60, Loss: 0.0575469546020031
# Batch: 80, Loss: 0.16546042263507843
# Batch: 100, Loss: 0.15546439588069916
# Batch: 120, Loss: 0.048574041575193405
# Batch: 140, Loss: 0.08051029592752457
# Batch: 160, Loss: 0.1133749932050705
# Batch: 180, Loss: 0.09935682266950607
# Batch: 200, Loss: 0.06011991947889328
#
# Average loss: 0.0958, Accuracy: 25281.0/26038 (97%)
#
#
# Average loss: 0.1181, Accuracy: 2837.0/2940 (96%)
#
# Epoch: 6 	Training Accuracy: 97.09%
# Validation Accuracy: 96.50%
# Batch: 0, Loss: 0.07465356588363647
# Batch: 20, Loss: 0.0929977297782898
# Batch: 40, Loss: 0.10255955904722214
# Batch: 60, Loss: 0.06301016360521317
# Batch: 80, Loss: 0.1137600839138031
# Batch: 100, Loss: 0.08097320795059204
# Batch: 120, Loss: 0.09725688397884369
# Batch: 140, Loss: 0.10386138409376144
# Batch: 160, Loss: 0.1282729059457779
# Batch: 180, Loss: 0.11369185894727707
# Batch: 200, Loss: 0.09060876071453094
#
# Average loss: 0.0921, Accuracy: 25307.0/26038 (97%)
#
#
# Average loss: 0.1150, Accuracy: 2842.0/2940 (97%)
#
# Epoch: 7 	Training Accuracy: 97.19%
# Validation Accuracy: 96.67%
# Batch: 0, Loss: 0.05593087524175644
# Batch: 20, Loss: 0.11931397765874863
# Batch: 40, Loss: 0.041405968368053436
# Batch: 60, Loss: 0.10364430397748947
# Batch: 80, Loss: 0.11863655596971512
# Batch: 100, Loss: 0.06627961993217468
# Batch: 120, Loss: 0.11701000481843948
# Batch: 140, Loss: 0.07001198828220367
# Batch: 160, Loss: 0.07199583947658539
# Batch: 180, Loss: 0.07095547020435333
# Batch: 200, Loss: 0.15171103179454803
#
# Average loss: 0.0894, Accuracy: 25339.0/26038 (97%)
#
#
# Average loss: 0.1137, Accuracy: 2838.0/2940 (97%)
#
# Epoch: 8 	Training Accuracy: 97.32%
# Validation Accuracy: 96.53%
# Batch: 0, Loss: 0.06520451605319977
# Batch: 20, Loss: 0.04303937405347824
# Batch: 40, Loss: 0.0513266995549202
# Batch: 60, Loss: 0.09461846202611923
# Batch: 80, Loss: 0.08650652319192886
# Batch: 100, Loss: 0.07932873070240021
# Batch: 120, Loss: 0.039217572659254074
# Batch: 140, Loss: 0.10260767489671707
# Batch: 160, Loss: 0.17662304639816284
# Batch: 180, Loss: 0.15758758783340454
# Batch: 200, Loss: 0.06878841668367386
#
# Average loss: 0.0871, Accuracy: 25344.0/26038 (97%)
#
#
# Average loss: 0.1109, Accuracy: 2843.0/2940 (97%)
#
# Epoch: 9 	Training Accuracy: 97.33%
# Validation Accuracy: 96.70%
# Batch: 0, Loss: 0.06607741117477417
# Batch: 20, Loss: 0.05372728407382965
# Batch: 40, Loss: 0.10356754064559937
# Batch: 60, Loss: 0.13089026510715485
# Batch: 80, Loss: 0.08482272922992706
# Batch: 100, Loss: 0.04764050245285034
# Batch: 120, Loss: 0.12063347548246384
# Batch: 140, Loss: 0.10886126011610031
# Batch: 160, Loss: 0.144461527466774
# Batch: 180, Loss: 0.03961633890867233
# Batch: 200, Loss: 0.04632321372628212
#
# Average loss: 0.0847, Accuracy: 25383.0/26038 (97%)
#
#
# Average loss: 0.1094, Accuracy: 2847.0/2940 (97%)
#
# Epoch: 10 	Training Accuracy: 97.48%
# Validation Accuracy: 96.84%
# Batch: 0, Loss: 0.06376950442790985
# Batch: 20, Loss: 0.096164770424366
# Batch: 40, Loss: 0.09242453426122665
# Batch: 60, Loss: 0.05351056903600693
# Batch: 80, Loss: 0.04838060960173607
# Batch: 100, Loss: 0.06886573880910873
# Batch: 120, Loss: 0.07452893257141113
# Batch: 140, Loss: 0.037095729261636734
# Batch: 160, Loss: 0.03627656400203705
# Batch: 180, Loss: 0.1726795881986618
# Batch: 200, Loss: 0.04869769886136055
#
# Average loss: 0.0831, Accuracy: 25380.0/26038 (97%)
#
#
# Average loss: 0.1083, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 11 	Training Accuracy: 97.47%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.146030992269516
# Batch: 20, Loss: 0.06923458725214005
# Batch: 40, Loss: 0.04414188489317894
# Batch: 60, Loss: 0.05061517655849457
# Batch: 80, Loss: 0.07182054221630096
# Batch: 100, Loss: 0.04002084210515022
# Batch: 120, Loss: 0.02757791057229042
# Batch: 140, Loss: 0.06827268749475479
# Batch: 160, Loss: 0.08327707648277283
# Batch: 180, Loss: 0.07380356639623642
# Batch: 200, Loss: 0.06944922357797623
#
# Average loss: 0.0813, Accuracy: 25385.0/26038 (97%)
#
#
# Average loss: 0.1059, Accuracy: 2848.0/2940 (97%)
#
# Epoch: 12 	Training Accuracy: 97.49%
# Validation Accuracy: 96.87%
# Batch: 0, Loss: 0.03481054678559303
# Batch: 20, Loss: 0.12179180979728699
# Batch: 40, Loss: 0.08805368095636368
# Batch: 60, Loss: 0.04002322256565094
# Batch: 80, Loss: 0.08013319224119186
# Batch: 100, Loss: 0.04670540243387222
# Batch: 120, Loss: 0.05388747528195381
# Batch: 140, Loss: 0.1330360323190689
# Batch: 160, Loss: 0.09719273447990417
# Batch: 180, Loss: 0.10924003273248672
# Batch: 200, Loss: 0.05350267142057419
#
# Average loss: 0.0802, Accuracy: 25385.0/26038 (97%)
#
#
# Average loss: 0.1055, Accuracy: 2852.0/2940 (97%)
#
# Epoch: 13 	Training Accuracy: 97.49%
# Validation Accuracy: 97.01%
# Batch: 0, Loss: 0.03340157866477966
# Batch: 20, Loss: 0.08494143933057785
# Batch: 40, Loss: 0.15224549174308777
# Batch: 60, Loss: 0.07656718045473099
# Batch: 80, Loss: 0.1359236240386963
# Batch: 100, Loss: 0.04973553121089935
# Batch: 120, Loss: 0.04144265875220299
# Batch: 140, Loss: 0.08970029652118683
# Batch: 160, Loss: 0.02731119468808174
# Batch: 180, Loss: 0.16123542189598083
# Batch: 200, Loss: 0.06964893639087677
#
# Average loss: 0.0792, Accuracy: 25396.0/26038 (98%)
#
#
# Average loss: 0.1050, Accuracy: 2849.0/2940 (97%)
#
# Epoch: 14 	Training Accuracy: 97.53%
# Validation Accuracy: 96.90%
# Batch: 0, Loss: 0.0367872379720211
# Batch: 20, Loss: 0.0797688290476799
# Batch: 40, Loss: 0.03320610523223877
# Batch: 60, Loss: 0.04518218711018562
# Batch: 80, Loss: 0.19031617045402527
# Batch: 100, Loss: 0.05989343300461769
# Batch: 120, Loss: 0.04252466559410095
# Batch: 140, Loss: 0.12153536081314087
# Batch: 160, Loss: 0.12261536717414856
# Batch: 180, Loss: 0.13796570897102356
# Batch: 200, Loss: 0.033214617520570755
#
# Average loss: 0.0794, Accuracy: 25417.0/26038 (98%)
#
#
# Average loss: 0.1062, Accuracy: 2856.0/2940 (97%)
#
# Epoch: 15 	Training Accuracy: 97.62%
# Validation Accuracy: 97.14%
# Batch: 0, Loss: 0.06622369587421417
# Batch: 20, Loss: 0.10959819704294205
# Batch: 40, Loss: 0.06341183185577393
# Batch: 60, Loss: 0.045323263853788376
# Batch: 80, Loss: 0.05202319845557213
# Batch: 100, Loss: 0.13291963934898376
# Batch: 120, Loss: 0.038120534271001816
# Batch: 140, Loss: 0.01991383358836174
# Batch: 160, Loss: 0.08671454340219498
# Batch: 180, Loss: 0.15123184025287628
# Batch: 200, Loss: 0.10728021711111069
#
# Average loss: 0.0772, Accuracy: 25442.0/26038 (98%)
#
#
# Average loss: 0.1049, Accuracy: 2854.0/2940 (97%)
#
# Epoch: 16 	Training Accuracy: 97.71%
# Validation Accuracy: 97.07%
# Batch: 0, Loss: 0.05057121813297272
# Batch: 20, Loss: 0.14220276474952698
# Batch: 40, Loss: 0.05323898047208786
# Batch: 60, Loss: 0.14779315888881683
# Batch: 80, Loss: 0.10662734508514404
# Batch: 100, Loss: 0.0576869435608387
# Batch: 120, Loss: 0.1076439768075943
# Batch: 140, Loss: 0.06065311282873154
# Batch: 160, Loss: 0.15429407358169556
# Batch: 180, Loss: 0.11392126232385635
# Batch: 200, Loss: 0.07259237766265869
#
# Average loss: 0.0758, Accuracy: 25453.0/26038 (98%)
#
#
# Average loss: 0.1033, Accuracy: 2855.0/2940 (97%)
#
# Epoch: 17 	Training Accuracy: 97.75%
# Validation Accuracy: 97.11%
# Batch: 0, Loss: 0.0679130107164383
# Batch: 20, Loss: 0.08680815994739532
# Batch: 40, Loss: 0.08780193328857422
# Batch: 60, Loss: 0.06017483398318291
# Batch: 80, Loss: 0.04555755853652954
# Batch: 100, Loss: 0.1639523059129715
# Batch: 120, Loss: 0.07007726281881332
# Batch: 140, Loss: 0.09505806118249893
# Batch: 160, Loss: 0.08240385353565216
# Batch: 180, Loss: 0.03555070236325264
# Batch: 200, Loss: 0.08586620539426804
#
# Average loss: 0.0769, Accuracy: 25439.0/26038 (98%)
#
#
# Average loss: 0.1051, Accuracy: 2858.0/2940 (97%)
#
# Epoch: 18 	Training Accuracy: 97.70%
# Validation Accuracy: 97.21%
# Batch: 0, Loss: 0.04615214094519615
# Batch: 20, Loss: 0.08591636270284653
# Batch: 40, Loss: 0.10357937961816788
# Batch: 60, Loss: 0.22447384893894196
# Batch: 80, Loss: 0.05467601865530014
# Batch: 100, Loss: 0.0798770934343338
# Batch: 120, Loss: 0.029064690694212914
# Batch: 140, Loss: 0.0674763172864914
# Batch: 160, Loss: 0.036278605461120605
# Batch: 180, Loss: 0.05611192062497139
# Batch: 200, Loss: 0.06046764925122261
#
# Average loss: 0.0747, Accuracy: 25447.0/26038 (98%)
#
#
# Average loss: 0.1033, Accuracy: 2855.0/2940 (97%)
#
# Epoch: 19 	Training Accuracy: 97.73%
# Validation Accuracy: 97.11%
#
# Average loss: 0.0747, Accuracy: 25447.0/26038 (98%)
#
#
# Average loss: 0.0695, Accuracy: 4746.0/4861 (98%)
#
# Percentage: 0.01, Seed: 10, Epochs taken: 20
# Percentage: 0.01, Seed: 20, Epochs taken: 20
# Percentage: 0.01, Seed: 30, Epochs taken: 20
# Percentage: 0.01, Seed: 40, Epochs taken: 20
# Percentage: 0.01, Seed: 50, Epochs taken: 20
# Percentage: 0.03, Seed: 10, Epochs taken: 20
# Percentage: 0.03, Seed: 20, Epochs taken: 20
# Percentage: 0.03, Seed: 30, Epochs taken: 20
# Percentage: 0.03, Seed: 40, Epochs taken: 20
# Percentage: 0.03, Seed: 50, Epochs taken: 20
# Percentage: 0.05, Seed: 10, Epochs taken: 20
# Percentage: 0.05, Seed: 20, Epochs taken: 20
# Percentage: 0.05, Seed: 30, Epochs taken: 20
# Percentage: 0.05, Seed: 40, Epochs taken: 20
# Percentage: 0.05, Seed: 50, Epochs taken: 20
# Percentage: 0.1, Seed: 10, Epochs taken: 20
# Percentage: 0.1, Seed: 20, Epochs taken: 20
# Percentage: 0.1, Seed: 30, Epochs taken: 20
# Percentage: 0.1, Seed: 40, Epochs taken: 20
# Percentage: 0.1, Seed: 50, Epochs taken: 20
# Percentage: 0.15, Seed: 10, Epochs taken: 20
# Percentage: 0.15, Seed: 20, Epochs taken: 20
# Percentage: 0.15, Seed: 30, Epochs taken: 20
# Percentage: 0.15, Seed: 40, Epochs taken: 20
# Percentage: 0.15, Seed: 50, Epochs taken: 20
# Percentage: 0.2, Seed: 10, Epochs taken: 20
# Percentage: 0.2, Seed: 20, Epochs taken: 20
# Percentage: 0.2, Seed: 30, Epochs taken: 20
# Percentage: 0.2, Seed: 40, Epochs taken: 20
# Percentage: 0.2, Seed: 50, Epochs taken: 20
# Percentage: 0.4, Seed: 10, Epochs taken: 20
# Percentage: 0.4, Seed: 20, Epochs taken: 20
# Percentage: 0.4, Seed: 30, Epochs taken: 20
# Percentage: 0.4, Seed: 40, Epochs taken: 20
# Percentage: 0.4, Seed: 50, Epochs taken: 19
# Percentage: 0.6, Seed: 10, Epochs taken: 20
# Percentage: 0.6, Seed: 20, Epochs taken: 20
# Percentage: 0.6, Seed: 30, Epochs taken: 20
# Percentage: 0.6, Seed: 40, Epochs taken: 20
# Percentage: 0.6, Seed: 50, Epochs taken: 20
# Percentage: 0.8, Seed: 10, Epochs taken: 20
# Percentage: 0.8, Seed: 20, Epochs taken: 20
# Percentage: 0.8, Seed: 30, Epochs taken: 20
# Percentage: 0.8, Seed: 40, Epochs taken: 20
# Percentage: 0.8, Seed: 50, Epochs taken: 20
# Percentage: 1, Seed: 10, Epochs taken: 20
# Percentage: 1, Seed: 20, Epochs taken: 20
# Percentage: 1, Seed: 30, Epochs taken: 20
# Percentage: 1, Seed: 40, Epochs taken: 17
# Percentage: 1, Seed: 50, Epochs taken: 20

# %%
# End to End - Train Accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Train Accuracies
means = [np.mean(results_train_finetune[perc]) for perc in percentages]
stds = [np.std(results_train_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Train Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Train Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
# End to End - Test Accuracies
means = [np.mean(results_test[perc]) for perc in percentages]
stds = [np.std(results_test[perc]) for perc in percentages]

plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="End-to-End Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

# Finetune - Test Accuracies
means = [np.mean(results_test_finetune[perc]) for perc in percentages]
stds = [np.std(results_test_finetune[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Finetune Test Accuracies", color='r')
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='r', alpha=0.1)

# Displaying the Test Accuracies plot
plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

# %%
data_to_save = {
    "results_test_finetune": results_test_finetune,
    "results_train_finetune": results_train_finetune,
    "epochs_taken_finetune": epochs_taken_finetune,
    
    "results_test": results_test,
    "results_train": results_train,
    "epochs_taken": epochs_taken
}

# Assuming data_to_save from the previous code
with open("data.json", "w") as file:
    json.dump(data_to_save, file)

# %%
plt.figure(figsize=(10, 6))

for perc in percentages:
    plt.scatter(epochs_taken[perc], epochs_taken_finetune[perc], label=f'{perc} data')
plt.xlabel('Epochs (End to End)')
plt.ylabel('Epochs (Finetune)')
plt.title('Scatter Plot Comparing Epochs Taken for Convergence')
plt.legend()
plt.show()

# %%
# Given data
percentages = list(epochs_taken.keys())

all_epochs = []
labels = []

for perc in percentages:
    all_epochs.extend([epochs_taken[perc], epochs_taken_finetune[perc]])
    labels.extend([f'{perc} End to End', f'{perc} Finetune'])

# Plotting
plt.figure(figsize=(10, 6))
box = plt.boxplot(all_epochs, labels=labels, patch_artist=True)

# Coloring
colors = ['skyblue', 'lightgreen'] * len(percentages)
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

plt.ylabel('Epochs Taken')
plt.title('Box Plot of Epochs Taken for Each Percentage')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ***IMPORTS***

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import DataLoader, random_split, Dataset
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ***GENERATE 6 DIMENSIONAL DATA***

# %%
def rotation_matrix_6D(theta, dim1, dim2):
    """
    Create a 6D rotation matrix to rotate by angle theta in the plane defined by dim1 and dim2.
    
    Parameters:
    - theta: Rotation angle in radians.
    - dim1, dim2: Dimensions (0-5) in which rotation should occur.
    
    Returns:
    - 6x6 rotation matrix.
    """
    R2 = np.array([[np.cos(theta), -np.sin(theta)],
                   [np.sin(theta), np.cos(theta)]])
    
    R6 = np.eye(6) # create identity matrix of 6*6
    R6[dim1, dim1], R6[dim1, dim2], R6[dim2, dim1], R6[dim2, dim2] = R2.flatten()
    
    return R6

# %%
def generate_data_6D(n_samples_per_class=100, n_classes=5):
    """
    Generate data for n_classes in a 6D space.

    Parameters:
    - n_samples_per_class: Number of samples per class.
    - n_classes: Number of classes.

    Returns:
    - X: Data points.
    - y: Class targets.
    """
    
    # Define means for the classes in 6D space
    means = [tuple(i*2 for _ in range(6)) for i in range(n_classes)]

    # Define a covariance matrix for 6D
    # Base covariance defines how spread out the data is in that dimension
    base_covariance = np.array([[0.2, 0, 0, 0, 0, 0], 
                                [0, 5, 0, 0, 0, 0],
                                [0, 0, 0.2, 0, 0, 0],
                                [0, 0, 0, 5, 0, 0],
                                [0, 0, 0, 0, 0.2, 0],
                                [0, 0, 0, 0, 0, 5]])
    
    theta = np.pi / 4  # or any other desired angle
    # R = rotation_matrix_6D(theta, 0, 1)  # for rotation in the plane of the first two dimensions
    
    R1 = rotation_matrix_6D(theta, 0, 1)
    R2 = rotation_matrix_6D(theta, 2, 3)
    R3 = rotation_matrix_6D(theta, 4, 5)
    covariance = R1 @ R2 @ R3 @ base_covariance @ R3.T @ R2.T @ R1.T
    
    X = np.empty((0, 6))
    y = np.empty((0,))

    for idx, mean in enumerate(means):
        class_data = np.random.multivariate_normal(mean, covariance, n_samples_per_class)
        X = np.vstack([X, class_data])
        y = np.hstack([y, [idx]*n_samples_per_class])

    return X, y

# %%
# Generate and plot the data
n_classes = 5
X, y = generate_data_6D(n_samples_per_class = 400, n_classes=n_classes)

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
# Split the data into primary (even classes) and transfer (odd classes) datasets
X_primary = X[np.isin(y, [0, 2, 4])]
y_primary = y[np.isin(y, [0, 2, 4])]


# Assuming X_primary and y_primary are numpy arrays
X_primary = torch.tensor(X_primary, dtype=torch.float32)
y_primary = torch.tensor(y_primary, dtype=torch.int64)

primary_dataset = CustomDataset(X_primary, y_primary)

X_transfer = X[np.isin(y, [1, 3])]
y_transfer = y[np.isin(y, [1, 3])]

transfer_dataset = CustomDataset(X_transfer, y_transfer)

# Assuming X_primary and y_primary are numpy arrays
X_transfer = torch.tensor(X_transfer, dtype=torch.float32)
y_transfer = torch.tensor(y_transfer, dtype=torch.int64)


# Splitting ratios
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Calculate sizes for primary dataset split
primary_train_size = int(train_ratio * len(primary_dataset))
primary_val_size = int(val_ratio * len(primary_dataset))
primary_test_size = len(primary_dataset) - primary_train_size - primary_val_size

# Split the primary dataset into training, validation, and test sets
primary_train_dataset, primary_val_dataset, primary_test_dataset = random_split(primary_dataset, [primary_train_size, primary_val_size, primary_test_size])

# Calculate sizes for transfer dataset split
transfer_train_size = int(train_ratio * len(transfer_dataset))
transfer_val_size = int(val_ratio * len(transfer_dataset))
transfer_test_size = len(transfer_dataset) - transfer_train_size - transfer_val_size

# Split the transfer dataset into training, validation, and test sets
transfer_train_dataset, transfer_val_dataset, transfer_test_dataset = random_split(transfer_dataset, [transfer_train_size, transfer_val_size, transfer_test_size])

# Create DataLoader objects
batch_size = 32

primary_train_loader = DataLoader(primary_train_dataset, batch_size=batch_size, shuffle=True)
primary_val_loader = DataLoader(primary_val_dataset, batch_size=batch_size, shuffle=False)
primary_test_loader = DataLoader(primary_test_dataset, batch_size=batch_size, shuffle=False)

transfer_train_loader = DataLoader(transfer_train_dataset, batch_size=batch_size, shuffle=True)
transfer_val_loader = DataLoader(transfer_val_dataset, batch_size=batch_size, shuffle=False)
transfer_test_loader = DataLoader(transfer_test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Define the network architecture
class DenseNet(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout_prob = 0.15):
        super(DenseNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc4 = nn.Linear(hidden_dim, hidden_dim)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc5 = nn.Linear(hidden_dim, hidden_dim)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc6 = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = F.relu(self.fc3(x))
        x = self.dropout(x)
        x = F.relu(self.fc4(x))
        x = self.dropout(x)
        x = F.relu(self.fc5(x))
        x = self.dropout(x)
        x = self.fc6(x)
        return x

# %%
# Hyperparameters
input_dim = 6
hidden_dim = 128
output_dim = 5
output_dim_trnsfr = 5

# %%
# Initialize the network and optimizer
model = DenseNet(input_dim, hidden_dim, output_dim)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# %%
# Training loop
epochs = 50
patience = 5  # Number of epochs to wait before stopping
wait = 0
best_loss = float('inf')

for epoch in range(epochs):
    # Training phase
    model.train()
    train_loss = 0.0
    for data, target in primary_train_loader:
        optimizer.zero_grad()
        output = model(data.to(device))
        loss = criterion(output.to(device), target.to(device))
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    
    train_loss /= len(primary_train_loader)
    
    # Validation phase
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for data, target in primary_val_loader:
            output = model(data.to(device))
            loss = criterion(output.to(device), target.to(device))
            val_loss += loss.item()
    
    val_loss /= len(primary_val_loader)
    print(f"Epoch {epoch+1}/{epochs} - Training Loss: {train_loss}, Validation Loss: {val_loss}")
    
    # Check early stopping condition
    if val_loss < best_loss:
        best_loss = val_loss
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            print("Early stopping!")
            break
# Out:
# Epoch 1/50 - Training Loss: 1.0212677739284657, Validation Loss: 0.4999668796857198
# Epoch 2/50 - Training Loss: 0.462572470859245, Validation Loss: 0.30311032632986706
# Epoch 3/50 - Training Loss: 0.3233858992656072, Validation Loss: 0.16625078146656355
# Epoch 4/50 - Training Loss: 0.23936856344894128, Validation Loss: 0.10227527096867561
# Epoch 5/50 - Training Loss: 0.1772726975657322, Validation Loss: 0.08754480071365833
# Epoch 6/50 - Training Loss: 0.13768492031980445, Validation Loss: 0.08644431084394455
# Epoch 7/50 - Training Loss: 0.1399601939375754, Validation Loss: 0.07298677352567513
# Epoch 8/50 - Training Loss: 0.08649039068431766, Validation Loss: 0.030614261360218126
# Epoch 9/50 - Training Loss: 0.0679895911814162, Validation Loss: 0.029137626057490706
# Epoch 10/50 - Training Loss: 0.057420522802405886, Validation Loss: 0.015215820089603463
# Epoch 11/50 - Training Loss: 0.03354192271621691, Validation Loss: 0.011264036254336437
# Epoch 12/50 - Training Loss: 0.07394281973096507, Validation Loss: 0.006980613960574071
# Epoch 13/50 - Training Loss: 0.02685603172156132, Validation Loss: 0.0015234362023572128
# Epoch 14/50 - Training Loss: 0.013859989849152043, Validation Loss: 0.029673416703493178
# Epoch 15/50 - Training Loss: 0.033917254837298835, Validation Loss: 0.0023286915966309607
# Epoch 16/50 - Training Loss: 0.0152167539097179, Validation Loss: 0.001133252711345752
# Epoch 17/50 - Training Loss: 0.01438638990253417, Validation Loss: 0.0006970269023440778
# Epoch 18/50 - Training Loss: 0.013932535195231644, Validation Loss: 0.0005920627299929038
# Epoch 19/50 - Training Loss: 0.039680664371526626, Validation Loss: 0.03250757425363796
# Epoch 20/50 - Training Loss: 0.013134050120478842, Validation Loss: 0.0008415843864592413
# Epoch 21/50 - Training Loss: 0.005314621279938836, Validation Loss: 0.0004187813926061305
# Epoch 22/50 - Training Loss: 0.011967970733099652, Validation Loss: 0.0005882526262818525
# Epoch 23/50 - Training Loss: 0.015500899723351554, Validation Loss: 0.0034818890465733907
# Epoch 24/50 - Training Loss: 0.007226309114937774, Validation Loss: 0.00031314896477852017
# Epoch 25/50 - Training Loss: 0.00974884933222913, Validation Loss: 0.00037224031014678377
# Epoch 26/50 - Training Loss: 0.006147121862913655, Validation Loss: 0.00581386886551627
# Epoch 27/50 - Training Loss: 0.0033801572518078267, Validation Loss: 0.0007218814995818926
# Epoch 28/50 - Training Loss: 0.0035833226181609832, Validation Loss: 0.00022104118033894338
# Epoch 29/50 - Training Loss: 0.009785859196132084, Validation Loss: 0.00014939023033851603
# Epoch 30/50 - Training Loss: 0.022031752512298733, Validation Loss: 0.0006438907051536565
# Epoch 31/50 - Training Loss: 0.02749006364805003, Validation Loss: 0.005899255144565056
# Epoch 32/50 - Training Loss: 0.00900025794248062, Validation Loss: 0.0005545357174317663
# Epoch 33/50 - Training Loss: 0.014351825096161553, Validation Loss: 0.0007069104467518628
# Epoch 34/50 - Training Loss: 0.02016133851968873, Validation Loss: 0.0006867471238365397
# Early stopping!

# %%
class TransferModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim_transfer, dropout_prob=0.15):
        super(TransferModel, self).__init__()
        # Copy the layers from the pretrained model
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, hidden_dim)
        self.fc5 = nn.Linear(hidden_dim, hidden_dim)
        
        # Add the new final layer
        self.fc_final = nn.Linear(hidden_dim, output_dim_transfer)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x = self.fc_final(x)
        return x

# %%
# Assuming pretrained_model is an instance of DenseNet that has been trained
pretrained_model = DenseNet(input_dim, hidden_dim, output_dim)

# %%
# Create the transfer model
transfer_model = TransferModel(input_dim, hidden_dim, output_dim_trnsfr)
transfer_model.to(device)

# Copy weights from the pretrained model
with torch.no_grad():
    transfer_model.fc1.weight.copy_(pretrained_model.fc1.weight)
    transfer_model.fc1.bias.copy_(pretrained_model.fc1.bias)
    transfer_model.fc2.weight.copy_(pretrained_model.fc2.weight)
    transfer_model.fc2.bias.copy_(pretrained_model.fc2.bias)
    transfer_model.fc3.weight.copy_(pretrained_model.fc3.weight)
    transfer_model.fc3.bias.copy_(pretrained_model.fc3.bias)
    transfer_model.fc4.weight.copy_(pretrained_model.fc4.weight)
    transfer_model.fc4.bias.copy_(pretrained_model.fc4.bias)
    transfer_model.fc5.weight.copy_(pretrained_model.fc5.weight)
    transfer_model.fc5.bias.copy_(pretrained_model.fc5.bias)

# The final layer (fc_final) will be randomly initialized by default

# %%
# Initialize the network and optimize

optimizer = optim.Adam(transfer_model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# %%
# Training loop
epochs = 50
patience = 5  # Number of epochs to wait before stopping
wait = 0
best_loss = float('inf')

for epoch in range(epochs):
    # Training phase
    transfer_model.train()
    train_loss = 0.0
    for data, target in transfer_train_loader:
        optimizer.zero_grad()
        output = transfer_model(data.float().to(device))
        loss = criterion(output.float().to(device), target.long().to(device))
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    
    train_loss /= len(transfer_train_loader)
    
    # Validation phase
    transfer_model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for data, target in transfer_val_loader:
            output = transfer_model(data.float().to(device))
            loss = criterion(output.float().to(device), target.long().to(device))
            val_loss += loss.item()
    
    val_loss /= len(transfer_val_loader)
    print(f"Epoch {epoch+1}/{epochs} - Training Loss: {train_loss}, Validation Loss: {val_loss}")
    
    # Check early stopping condition
    if val_loss < best_loss:
        best_loss = val_loss
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            print("Early stopping!")
            break
# Out:
# Epoch 1/200 - Training Loss: 1.0878548986381955, Validation Loss: 0.6431633681058884
# Epoch 2/200 - Training Loss: 0.5192563136418661, Validation Loss: 0.3546052426099777
# Epoch 3/200 - Training Loss: 0.21002500131726265, Validation Loss: 0.09400339983403683
# Epoch 4/200 - Training Loss: 0.07645487904341684, Validation Loss: 0.06693738931789994
# Epoch 5/200 - Training Loss: 0.08184411134829538, Validation Loss: 0.022570077562704682
# Epoch 6/200 - Training Loss: 0.024185269573030785, Validation Loss: 0.009710656013339758
# Epoch 7/200 - Training Loss: 0.006573067850291004, Validation Loss: 0.002504124218830839
# Epoch 8/200 - Training Loss: 0.006757996282734287, Validation Loss: 0.0013563911925302818
# Epoch 9/200 - Training Loss: 0.004063306699713899, Validation Loss: 0.0010105907203978859
# Epoch 10/200 - Training Loss: 0.0011167156654765778, Validation Loss: 0.0007625091056979727
# Epoch 11/200 - Training Loss: 0.0006338393072332514, Validation Loss: 0.00029867679586459417
# Epoch 12/200 - Training Loss: 0.00038946006902228366, Validation Loss: 0.0002510858412279049
# Epoch 13/200 - Training Loss: 0.00030401247285125364, Validation Loss: 0.00020241661150066648
# Epoch 14/200 - Training Loss: 0.00024387343506128268, Validation Loss: 0.00015644477934984025
# Epoch 15/200 - Training Loss: 0.00021946131124018898, Validation Loss: 0.00015092430203367257
# Epoch 16/200 - Training Loss: 0.0001866871610521533, Validation Loss: 0.00012830043760914123
# Epoch 17/200 - Training Loss: 0.00016341244413019417, Validation Loss: 0.00010005745662056142
# Epoch 18/200 - Training Loss: 0.00014158092709395633, Validation Loss: 0.00010208065032202285
# Epoch 19/200 - Training Loss: 0.00012250010341732478, Validation Loss: 8.249185430031503e-05
# Epoch 20/200 - Training Loss: 0.00010967493830725693, Validation Loss: 6.883633386678412e-05
# Epoch 21/200 - Training Loss: 9.774651226103338e-05, Validation Loss: 6.420082627300872e-05
# Epoch 22/200 - Training Loss: 8.846736909617903e-05, Validation Loss: 6.304396902123699e-05
# Epoch 23/200 - Training Loss: 7.999114960613143e-05, Validation Loss: 5.426219286164269e-05
# Epoch 24/200 - Training Loss: 7.663809136223183e-05, Validation Loss: 4.716210582955682e-05
# Epoch 25/200 - Training Loss: 6.88215088505078e-05, Validation Loss: 4.3264164560241625e-05
# Epoch 26/200 - Training Loss: 6.20456770421798e-05, Validation Loss: 4.3350283021936775e-05
# Epoch 27/200 - Training Loss: 5.764978691836909e-05, Validation Loss: 3.8221725617404445e-05
# Epoch 28/200 - Training Loss: 5.327464873516874e-05, Validation Loss: 3.2569994573350414e-05
# Epoch 29/200 - Training Loss: 4.96494032202261e-05, Validation Loss: 3.161584936606232e-05
# Epoch 30/200 - Training Loss: 4.6951307025564245e-05, Validation Loss: 2.981916600219847e-05
# Epoch 31/200 - Training Loss: 4.193949580945223e-05, Validation Loss: 2.6530348236519785e-05
# Epoch 32/200 - Training Loss: 4.101024465954753e-05, Validation Loss: 2.4588674818915024e-05
# Epoch 33/200 - Training Loss: 3.553976843148929e-05, Validation Loss: 2.5691218866086274e-05
# Epoch 34/200 - Training Loss: 3.540565563121668e-05, Validation Loss: 2.193277725837106e-05
# Epoch 35/200 - Training Loss: 3.1274593639965235e-05, Validation Loss: 2.1451942757266806e-05
# Epoch 36/200 - Training Loss: 3.4464657523535104e-05, Validation Loss: 1.915301220378751e-05
# Epoch 37/200 - Training Loss: 2.7629437504906997e-05, Validation Loss: 1.71892164644305e-05
# Epoch 38/200 - Training Loss: 2.5564593487261947e-05, Validation Loss: 1.6415713162132306e-05
# Epoch 39/200 - Training Loss: 2.4571504468440253e-05, Validation Loss: 1.547987119465688e-05
# Epoch 40/200 - Training Loss: 2.3026458090195472e-05, Validation Loss: 1.572720412923445e-05
# Epoch 41/200 - Training Loss: 2.2776450536967888e-05, Validation Loss: 1.4385388624305051e-05
# Epoch 42/200 - Training Loss: 2.062049586331543e-05, Validation Loss: 1.297464905292145e-05
# Epoch 43/200 - Training Loss: 1.9714460203582956e-05, Validation Loss: 1.2672924128764862e-05
# Epoch 44/200 - Training Loss: 1.9090494599064794e-05, Validation Loss: 1.162191182402239e-05
# Epoch 45/200 - Training Loss: 1.7774920662658486e-05, Validation Loss: 1.1251896864905575e-05
# Epoch 46/200 - Training Loss: 1.7726708209566925e-05, Validation Loss: 1.082104972738307e-05
# Epoch 47/200 - Training Loss: 1.717285248206382e-05, Validation Loss: 1.0156158282370598e-05
# Epoch 48/200 - Training Loss: 1.5212935484972453e-05, Validation Loss: 1.03681429095559e-05
# Epoch 49/200 - Training Loss: 1.5145133261285082e-05, Validation Loss: 9.370193197355547e-06
# Epoch 50/200 - Training Loss: 1.3832272827585257e-05, Validation Loss: 9.10820108401822e-06
# Epoch 51/200 - Training Loss: 1.3633370612195802e-05, Validation Loss: 8.560016112824087e-06
# Epoch 52/200 - Training Loss: 1.3068794039049357e-05, Validation Loss: 7.949745906898897e-06
# Epoch 53/200 - Training Loss: 1.2091524038421792e-05, Validation Loss: 8.039753879529599e-06
# Epoch 54/200 - Training Loss: 1.1618334522406965e-05, Validation Loss: 7.436933941562529e-06
# Epoch 55/200 - Training Loss: 1.1062229071335929e-05, Validation Loss: 7.1330354955989606e-06
# Epoch 56/200 - Training Loss: 1.062236866763063e-05, Validation Loss: 6.8278941682820005e-06
# Epoch 57/200 - Training Loss: 1.0364207270185943e-05, Validation Loss: 6.475568994801506e-06
# Epoch 58/200 - Training Loss: 9.908956201343244e-06, Validation Loss: 6.369712735931898e-06
# Epoch 59/200 - Training Loss: 9.470535840389655e-06, Validation Loss: 5.9869668120882125e-06
# Epoch 60/200 - Training Loss: 9.698799080600414e-06, Validation Loss: 5.808162796938632e-06
# Epoch 61/200 - Training Loss: 8.720283940672542e-06, Validation Loss: 5.425415139370671e-06
# Epoch 62/200 - Training Loss: 8.471406001970334e-06, Validation Loss: 5.290069111651974e-06
# Epoch 63/200 - Training Loss: 8.22849606960416e-06, Validation Loss: 5.013792616637147e-06
# Epoch 64/200 - Training Loss: 7.856838281996817e-06, Validation Loss: 5.065008537030735e-06
# Epoch 65/200 - Training Loss: 7.900737131194546e-06, Validation Loss: 4.8020806104887015e-06
# Epoch 66/200 - Training Loss: 7.452333190056177e-06, Validation Loss: 4.492278293355412e-06
# Epoch 67/200 - Training Loss: 7.171972678558329e-06, Validation Loss: 4.410013417555092e-06
# Epoch 68/200 - Training Loss: 6.815806977379503e-06, Validation Loss: 4.331474627861098e-06
# Epoch 69/200 - Training Loss: 6.51700538077825e-06, Validation Loss: 3.994664325546182e-06
# Epoch 70/200 - Training Loss: 6.30741598683926e-06, Validation Loss: 3.939407122288685e-06
# Epoch 71/200 - Training Loss: 6.299572349790752e-06, Validation Loss: 3.831998697023664e-06
# Epoch 72/200 - Training Loss: 6.252990841757209e-06, Validation Loss: 3.726142651316877e-06
# Epoch 73/200 - Training Loss: 5.672969045633636e-06, Validation Loss: 3.5613054478744743e-06
# Epoch 74/200 - Training Loss: 5.539506007481678e-06, Validation Loss: 3.3688403249243493e-06
# Epoch 75/200 - Training Loss: 5.350168442595936e-06, Validation Loss: 3.321654290289189e-06
# Epoch 76/200 - Training Loss: 5.141986880137968e-06, Validation Loss: 3.2083475929312044e-06
# Epoch 77/200 - Training Loss: 5.039336667462319e-06, Validation Loss: 3.158678126169434e-06
# Epoch 78/200 - Training Loss: 4.822483729090739e-06, Validation Loss: 2.990115191892073e-06
# Epoch 79/200 - Training Loss: 4.686113307962438e-06, Validation Loss: 2.950690074499107e-06
# Epoch 80/200 - Training Loss: 4.899050133467932e-06, Validation Loss: 2.8951225203854847e-06
# Epoch 81/200 - Training Loss: 4.465307582456211e-06, Validation Loss: 2.7172463745728237e-06
# Epoch 82/200 - Training Loss: 4.301009871217805e-06, Validation Loss: 2.623806480528401e-06
# Epoch 83/200 - Training Loss: 4.1803655395571896e-06, Validation Loss: 2.568859898133269e-06
# Epoch 84/200 - Training Loss: 4.075439153755016e-06, Validation Loss: 2.566686134741758e-06
# Epoch 85/200 - Training Loss: 4.222593774885455e-06, Validation Loss: 2.435373929188245e-06
# Epoch 86/200 - Training Loss: 3.8351869228058095e-06, Validation Loss: 2.3968801201590395e-06
# Epoch 87/200 - Training Loss: 3.845540059425427e-06, Validation Loss: 2.3751493216650488e-06
# Epoch 88/200 - Training Loss: 3.64604355714467e-06, Validation Loss: 2.2727069222128193e-06
# Epoch 89/200 - Training Loss: 3.6023838624209425e-06, Validation Loss: 2.2168290172430716e-06
# Epoch 90/200 - Training Loss: 3.690552015693053e-06, Validation Loss: 2.097623195140841e-06
# Epoch 91/200 - Training Loss: 3.5069919653728398e-06, Validation Loss: 2.117490026876112e-06
# Epoch 92/200 - Training Loss: 3.5123718033800187e-06, Validation Loss: 2.0315002942083993e-06
# Epoch 93/200 - Training Loss: 3.163042484920374e-06, Validation Loss: 1.9874185355206464e-06
# Epoch 94/200 - Training Loss: 3.099305243065626e-06, Validation Loss: 1.9380596256723948e-06
# Epoch 95/200 - Training Loss: 3.1022080146196154e-06, Validation Loss: 1.887458957128274e-06
# Epoch 96/200 - Training Loss: 3.0610277548248632e-06, Validation Loss: 1.8290972860768306e-06
# Epoch 97/200 - Training Loss: 2.9610735212928476e-06, Validation Loss: 1.790293005399235e-06
# Epoch 98/200 - Training Loss: 2.7903359457089514e-06, Validation Loss: 1.7688727496079082e-06
# Epoch 99/200 - Training Loss: 2.72101030576424e-06, Validation Loss: 1.6968521023841276e-06
# Epoch 100/200 - Training Loss: 2.7427472228206775e-06, Validation Loss: 1.642836586768226e-06
# Epoch 101/200 - Training Loss: 2.589809900952231e-06, Validation Loss: 1.5897521663532643e-06
# Epoch 102/200 - Training Loss: 2.520275300652328e-06, Validation Loss: 1.5674007372012966e-06
# Epoch 103/200 - Training Loss: 2.6471359820195376e-06, Validation Loss: 1.546912038463688e-06
# Epoch 104/200 - Training Loss: 2.432323147634937e-06, Validation Loss: 1.4680617397289097e-06
# Epoch 105/200 - Training Loss: 2.4641979455471605e-06, Validation Loss: 1.450987603845988e-06
# Epoch 106/200 - Training Loss: 2.634705023436052e-06, Validation Loss: 1.4590586729923416e-06
# Epoch 107/200 - Training Loss: 2.240690333918691e-06, Validation Loss: 1.3687222164548984e-06
# Epoch 108/200 - Training Loss: 2.192679616936428e-06, Validation Loss: 1.3311594742049238e-06
# Epoch 109/200 - Training Loss: 2.2427643836901248e-06, Validation Loss: 1.2942176113028836e-06
# Epoch 110/200 - Training Loss: 2.080098475687464e-06, Validation Loss: 1.3081869241204913e-06
# Epoch 111/200 - Training Loss: 2.1138329905233554e-06, Validation Loss: 1.2923546250931395e-06
# Epoch 112/200 - Training Loss: 2.0171858542047025e-06, Validation Loss: 1.2383388678927076e-06
# Epoch 113/200 - Training Loss: 1.9412351494175873e-06, Validation Loss: 1.2190917786369937e-06
# Epoch 114/200 - Training Loss: 1.923230978522699e-06, Validation Loss: 1.192704715435866e-06
# Epoch 115/200 - Training Loss: 1.868388885976439e-06, Validation Loss: 1.160108784148406e-06
# Epoch 116/200 - Training Loss: 1.9279928596836903e-06, Validation Loss: 1.14551827934406e-06
# Epoch 117/200 - Training Loss: 1.7893334446720626e-06, Validation Loss: 1.1126119865423334e-06
# Epoch 118/200 - Training Loss: 1.8267940477853826e-06, Validation Loss: 1.0880874583563127e-06
# Epoch 119/200 - Training Loss: 1.7498081000945199e-06, Validation Loss: 1.0672882773121728e-06
# Epoch 120/200 - Training Loss: 1.6879284048501277e-06, Validation Loss: 1.065425575319523e-06
# Epoch 121/200 - Training Loss: 1.6960005879695927e-06, Validation Loss: 1.0213436283379451e-06
# Epoch 122/200 - Training Loss: 1.649230065304942e-06, Validation Loss: 1.0135826151724814e-06
# Epoch 123/200 - Training Loss: 1.5838319124365323e-06, Validation Loss: 9.96198075142729e-07
# Epoch 124/200 - Training Loss: 1.6465402686726015e-06, Validation Loss: 9.552204431884093e-07
# Epoch 125/200 - Training Loss: 1.5548604434595998e-06, Validation Loss: 9.567725847148267e-07
# Epoch 126/200 - Training Loss: 1.5103645169113456e-06, Validation Loss: 9.452864162540209e-07
# Epoch 127/200 - Training Loss: 1.4495196902528405e-06, Validation Loss: 9.170366261912477e-07
# Epoch 128/200 - Training Loss: 1.4391734533979338e-06, Validation Loss: 8.850615778044357e-07
# Epoch 129/200 - Training Loss: 1.5078823254713016e-06, Validation Loss: 8.692292929879386e-07
# Epoch 130/200 - Training Loss: 1.3741898076741816e-06, Validation Loss: 8.636414285945193e-07
# Epoch 131/200 - Training Loss: 1.4106152911431814e-06, Validation Loss: 8.208011159638318e-07
# Epoch 132/200 - Training Loss: 1.3222455851212721e-06, Validation Loss: 8.149027941328768e-07
# Epoch 133/200 - Training Loss: 1.3330075094112697e-06, Validation Loss: 8.133505353669079e-07
# Epoch 134/200 - Training Loss: 1.3388031183423109e-06, Validation Loss: 7.89446861659826e-07
# Epoch 135/200 - Training Loss: 1.2746467221960402e-06, Validation Loss: 7.720623038665053e-07
# Epoch 136/200 - Training Loss: 1.2717501801281135e-06, Validation Loss: 7.562299906282988e-07
# Epoch 137/200 - Training Loss: 1.2806482077268001e-06, Validation Loss: 7.403976560738101e-07
# Epoch 138/200 - Training Loss: 1.2357404963994313e-06, Validation Loss: 7.133895927324829e-07
# Epoch 139/200 - Training Loss: 1.1479906715609427e-06, Validation Loss: 7.093538876290495e-07
# Epoch 140/200 - Training Loss: 1.1231555391412308e-06, Validation Loss: 7.121477700877676e-07
# Epoch 141/200 - Training Loss: 1.1111521822155307e-06, Validation Loss: 7.022137200607403e-07
# Epoch 142/200 - Training Loss: 1.0970796001035726e-06, Validation Loss: 6.702386965429241e-07
# Epoch 143/200 - Training Loss: 1.0683131675095738e-06, Validation Loss: 6.683760513936932e-07
# Epoch 144/200 - Training Loss: 1.0598284533437486e-06, Validation Loss: 6.52543745260914e-07
# Epoch 145/200 - Training Loss: 1.0503083487378717e-06, Validation Loss: 6.450931717694175e-07
# Epoch 146/200 - Training Loss: 1.0122284687478593e-06, Validation Loss: 6.236730367703558e-07
# Epoch 147/200 - Training Loss: 9.869802658120836e-07, Validation Loss: 6.056675587728932e-07
# Epoch 148/200 - Training Loss: 9.838763403990924e-07, Validation Loss: 6.038049136236623e-07
# Epoch 149/200 - Training Loss: 1.010574156307737e-06, Validation Loss: 5.879725790691737e-07
# Epoch 150/200 - Training Loss: 1.0085048058883217e-06, Validation Loss: 5.786594101664377e-07
# Epoch 151/200 - Training Loss: 9.366901001012845e-07, Validation Loss: 5.904559809977172e-07
# Epoch 152/200 - Training Loss: 9.068881939732087e-07, Validation Loss: 5.764862986978869e-07
# Epoch 153/200 - Training Loss: 9.391739439479352e-07, Validation Loss: 5.569286738449364e-07
# Epoch 154/200 - Training Loss: 8.762593542617955e-07, Validation Loss: 5.38923249138179e-07
# Epoch 155/200 - Training Loss: 8.584613255319734e-07, Validation Loss: 5.237117779444134e-07
# Epoch 156/200 - Training Loss: 8.483206875729998e-07, Validation Loss: 5.153299493798613e-07
# Epoch 157/200 - Training Loss: 8.526667575460401e-07, Validation Loss: 5.190551934930454e-07
# Epoch 158/200 - Training Loss: 8.129307277214714e-07, Validation Loss: 5.088107482009718e-07
# Epoch 159/200 - Training Loss: 8.646710373878047e-07, Validation Loss: 4.892531055844529e-07
# Epoch 160/200 - Training Loss: 7.820944800427141e-07, Validation Loss: 4.92978339039496e-07
# Epoch 161/200 - Training Loss: 7.738162093318124e-07, Validation Loss: 4.790086176598152e-07
# Epoch 162/200 - Training Loss: 7.616059044658464e-07, Validation Loss: 4.805607805025147e-07
# Epoch 163/200 - Training Loss: 7.705053503867829e-07, Validation Loss: 4.7031631744687274e-07
# Epoch 164/200 - Training Loss: 7.551906483863983e-07, Validation Loss: 4.541734810459275e-07
# Epoch 165/200 - Training Loss: 7.375993544340215e-07, Validation Loss: 4.4020373124453727e-07
# Epoch 166/200 - Training Loss: 7.876832432726941e-07, Validation Loss: 4.389619672195977e-07
# Epoch 167/200 - Training Loss: 6.947591280553272e-07, Validation Loss: 4.2964881608043015e-07
# Epoch 168/200 - Training Loss: 6.945524108440774e-07, Validation Loss: 4.2219827811607047e-07
# Epoch 169/200 - Training Loss: 6.719939595396024e-07, Validation Loss: 4.1257465888122624e-07
# Epoch 170/200 - Training Loss: 7.011751558631355e-07, Validation Loss: 4.113328824217888e-07
# Epoch 171/200 - Training Loss: 6.469521821964955e-07, Validation Loss: 4.038823444574291e-07
# Epoch 172/200 - Training Loss: 6.374321809153748e-07, Validation Loss: 3.964318100457831e-07
# Epoch 173/200 - Training Loss: 6.289470054888902e-07, Validation Loss: 3.871186553539019e-07
# Epoch 174/200 - Training Loss: 6.426064990621643e-07, Validation Loss: 3.8525602441552564e-07
# Epoch 175/200 - Training Loss: 6.624741801057136e-07, Validation Loss: 3.824620566916792e-07
# Epoch 176/200 - Training Loss: 7.535350046655114e-07, Validation Loss: 3.709758011893882e-07
# Epoch 177/200 - Training Loss: 6.078378089253217e-07, Validation Loss: 3.545225535361851e-07
# Epoch 178/200 - Training Loss: 5.832097167670883e-07, Validation Loss: 3.5203901216362965e-07
# Epoch 179/200 - Training Loss: 5.749314652013659e-07, Validation Loss: 3.4645113355935564e-07
# Epoch 180/200 - Training Loss: 5.699645770660153e-07, Validation Loss: 3.427258610244621e-07
# Epoch 181/200 - Training Loss: 5.498895229531323e-07, Validation Loss: 3.3434397206377753e-07
# Epoch 182/200 - Training Loss: 5.784498935154955e-07, Validation Loss: 3.31239562889607e-07
# Epoch 183/200 - Training Loss: 5.329190108464369e-07, Validation Loss: 3.247203474998628e-07
# Epoch 184/200 - Training Loss: 6.144596410943374e-07, Validation Loss: 3.247203474998628e-07
# Epoch 185/200 - Training Loss: 5.451297787494191e-07, Validation Loss: 3.1168188829866494e-07
# Epoch 186/200 - Training Loss: 5.076702825037829e-07, Validation Loss: 3.0981924670214767e-07
# Epoch 187/200 - Training Loss: 5.027033038975917e-07, Validation Loss: 3.060939848253952e-07
# Epoch 188/200 - Training Loss: 4.962876106616598e-07, Validation Loss: 3.0423135388701894e-07
# Epoch 189/200 - Training Loss: 5.020825541003483e-07, Validation Loss: 2.977121100755653e-07
# Epoch 190/200 - Training Loss: 4.789031616701955e-07, Validation Loss: 2.893302530893038e-07
# Epoch 191/200 - Training Loss: 4.697970062355555e-07, Validation Loss: 2.893302530893038e-07
# Epoch 192/200 - Training Loss: 4.7124579458410506e-07, Validation Loss: 2.8560496989626927e-07
# Epoch 193/200 - Training Loss: 4.6545099374739607e-07, Validation Loss: 2.828110234887049e-07
# Epoch 194/200 - Training Loss: 4.509638955596529e-07, Validation Loss: 2.7784399847519126e-07
# Epoch 195/200 - Training Loss: 4.6048408932877453e-07, Validation Loss: 2.731873998129686e-07
# Epoch 196/200 - Training Loss: 4.3999514530589244e-07, Validation Loss: 2.6977255096483077e-07
# Epoch 197/200 - Training Loss: 4.3088893855427716e-07, Validation Loss: 2.6418463683341997e-07
# Epoch 198/200 - Training Loss: 4.22610623138395e-07, Validation Loss: 2.62321991684189e-07
# Epoch 199/200 - Training Loss: 4.1929931359084725e-07, Validation Loss: 2.554923161923739e-07
# Epoch 200/200 - Training Loss: 4.743497138785339e-07, Validation Loss: 2.5456099539411525e-07

# %%
# Test loop
transfer_model.eval()  # Set the model to evaluation mode
test_loss = 0.0
correct = 0
total = 0

with torch.no_grad():  # No gradients required during testing
    for data, target in transfer_test_loader:
        data, target = data.float().to(device), target.long().to(device)
        output = transfer_model(data)
        loss = criterion(output, target)
        
        test_loss += loss.item()
        
        _, predicted = output.max(1)  # Get index of the max value for each sample
        total += target.size(0)  # Increment the total count
        correct += predicted.eq(target).sum().item()  # Increment the correct count

test_loss /= len(transfer_test_loader)
accuracy = 100. * correct / total

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# Test Loss: 0.0001
# Test Accuracy: 100.00%

# %%
# Your percentage list
percentages = [0.005, 0.01, 0.015, 0.02, 0.03, 0.07, 0.1]

# Storage for models and their training curves
trained_models = []
training_curves = []

for percentage in percentages:
    # Sample the data
    sample_size = int(percentage * len(transfer_dataset))
    sampled_data, _ = torch.utils.data.random_split(transfer_dataset, [sample_size, len(transfer_dataset) - sample_size])

    # Splitting the sampled_data further into train, validation, and test sets
    transfer_train_size = int(train_ratio * len(sampled_data))
    transfer_val_size = int(val_ratio * len(sampled_data))
    transfer_test_size = len(sampled_data) - transfer_train_size - transfer_val_size
    
    # Ensure each split has at least one sample
    while transfer_train_size < 1:
        transfer_train_size += 1
        transfer_val_size -= 1
        
    while transfer_val_size < 1:
        transfer_val_size += 1
        transfer_train_size -= 1
    
    transfer_train_dataset, transfer_val_dataset, _ = random_split(sampled_data, [transfer_train_size, transfer_val_size, transfer_test_size])
    
    # Create dataloaders
    transfer_train_loader = torch.utils.data.DataLoader(transfer_train_dataset, batch_size=batch_size, shuffle=True)
    transfer_val_loader = torch.utils.data.DataLoader(transfer_val_dataset, batch_size=batch_size, shuffle=True)
    
    # Create a new model for transfer learning
    transfer_model = TransferModel(input_dim, hidden_dim, output_dim_trnsfr)
    transfer_model.to(device)
    
    # Freeze or Unfreeze layers from the pretrained model as discussed earlier
    for name, param in transfer_model.named_parameters():
        if 'fc_out' not in name:
            param.requires_grad = True

    # Define optimizer only for the unfrozen layer
    optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, transfer_model.parameters()), lr=0.001)
    
    # Lists to store losses for this model
    train_losses = []
    val_losses = []
    
    # Training loop
    epochs = 50
    patience = 5  # Number of epochs to wait before stopping
    wait = 0
    best_loss = float('inf')

    for epoch in range(epochs):
        # Training phase
        transfer_model.train()
        train_loss = 0.0
        for data, target in transfer_train_loader:
            optimizer.zero_grad()
            output = transfer_model(data.float().to(device))
            loss = criterion(output.float().to(device), target.long().to(device))
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(transfer_train_loader)

        # Validation phase
        transfer_model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for data, target in transfer_val_loader:
                output = transfer_model(data.float().to(device))
                loss = criterion(output.float().to(device), target.long().to(device))
                val_loss += loss.item()

        val_loss /= len(transfer_val_loader)
        print(f"Epoch {epoch+1}/{epochs} - Training Loss: {train_loss}, Validation Loss: {val_loss}")
        
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        
        # Check early stopping condition
        if val_loss < best_loss:
            best_loss = val_loss
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                print("Early stopping!")
                break

    # Append the trained model to the list
    trained_models.append(transfer_model)
    training_curves.append((train_losses, val_losses))
# Out:
# Epoch 1/50 - Training Loss: 1.5942054986953735, Validation Loss: 1.4722844362258911
# Epoch 2/50 - Training Loss: 1.4849581718444824, Validation Loss: 1.3436640501022339
# Epoch 3/50 - Training Loss: 1.3696666955947876, Validation Loss: 1.1941449642181396
# Epoch 4/50 - Training Loss: 1.234230637550354, Validation Loss: 1.0105562210083008
# Epoch 5/50 - Training Loss: 1.061637043952942, Validation Loss: 0.7958436608314514
# Epoch 6/50 - Training Loss: 0.8578861355781555, Validation Loss: 0.565563440322876
# Epoch 7/50 - Training Loss: 0.6335399150848389, Validation Loss: 0.34761252999305725
# Epoch 8/50 - Training Loss: 0.41027000546455383, Validation Loss: 0.1759248822927475
# Epoch 9/50 - Training Loss: 0.22251373529434204, Validation Loss: 0.07012639939785004
# Epoch 10/50 - Training Loss: 0.09669629484415054, Validation Loss: 0.022445792332291603
# Epoch 11/50 - Training Loss: 0.033984363079071045, Validation Loss: 0.006013988982886076
# Epoch 12/50 - Training Loss: 0.010049697011709213, Validation Loss: 0.0014218707801774144
# Epoch 13/50 - Training Loss: 0.002633201191201806, Validation Loss: 0.0003094194398727268
# Epoch 14/50 - Training Loss: 0.0006349454633891582, Validation Loss: 6.365573790390044e-05
# Epoch 15/50 - Training Loss: 0.00014506718434859067, Validation Loss: 1.2636104656849056e-05
# Epoch 16/50 - Training Loss: 3.2066785934148356e-05, Validation Loss: 2.3841830625315197e-06
# Epoch 17/50 - Training Loss: 6.9141146923357155e-06, Validation Loss: 4.768370445162873e-07
# Epoch 18/50 - Training Loss: 1.4305104514278355e-06, Validation Loss: 1.1920928244535389e-07
# Epoch 19/50 - Training Loss: 3.576278118089249e-07, Validation Loss: 0.0
# Epoch 20/50 - Training Loss: 0.0, Validation Loss: 0.0
# Epoch 21/50 - Training Loss: 0.0, Validation Loss: 0.0
# Epoch 22/50 - Training Loss: 0.0, Validation Loss: 0.0
# Epoch 23/50 - Training Loss: 0.0, Validation Loss: 0.0
# Epoch 24/50 - Training Loss: 0.0, Validation Loss: 0.0
# Early stopping!
# Epoch 1/50 - Training Loss: 1.6202913522720337, Validation Loss: 1.6366150379180908
# Epoch 2/50 - Training Loss: 1.5665525197982788, Validation Loss: 1.5844614505767822
# Epoch 3/50 - Training Loss: 1.5186851024627686, Validation Loss: 1.5301357507705688
# Epoch 4/50 - Training Loss: 1.4675648212432861, Validation Loss: 1.4724210500717163
# Epoch 5/50 - Training Loss: 1.4077832698822021, Validation Loss: 1.4067087173461914
# Epoch 6/50 - Training Loss: 1.336270809173584, Validation Loss: 1.344436764717102
# Epoch 7/50 - Training Loss: 1.2485239505767822, Validation Loss: 1.3009470701217651
# Epoch 8/50 - Training Loss: 1.1456928253173828, Validation Loss: 1.2969943284988403
# Epoch 9/50 - Training Loss: 1.030551791191101, Validation Loss: 1.3522233963012695
# Epoch 10/50 - Training Loss: 0.9100667238235474, Validation Loss: 1.4849553108215332
# Epoch 11/50 - Training Loss: 0.792061984539032, Validation Loss: 1.6604639291763306
# Epoch 12/50 - Training Loss: 0.6827373504638672, Validation Loss: 1.8113534450531006
# Epoch 13/50 - Training Loss: 0.5839546918869019, Validation Loss: 1.8281606435775757
# Early stopping!
# Epoch 1/50 - Training Loss: 1.595746636390686, Validation Loss: 1.5481480360031128
# Epoch 2/50 - Training Loss: 1.5267536640167236, Validation Loss: 1.5388070344924927
# Epoch 3/50 - Training Loss: 1.4549552202224731, Validation Loss: 1.5334306955337524
# Epoch 4/50 - Training Loss: 1.3739322423934937, Validation Loss: 1.52815842628479
# Epoch 5/50 - Training Loss: 1.2790321111679077, Validation Loss: 1.5226244926452637
# Epoch 6/50 - Training Loss: 1.1702669858932495, Validation Loss: 1.51728093624115
# Epoch 7/50 - Training Loss: 1.0529953241348267, Validation Loss: 1.5150127410888672
# Epoch 8/50 - Training Loss: 0.9379104971885681, Validation Loss: 1.5128121376037598
# Epoch 9/50 - Training Loss: 0.8380473256111145, Validation Loss: 1.5095958709716797
# Epoch 10/50 - Training Loss: 0.7612229585647583, Validation Loss: 1.4933216571807861
# Epoch 11/50 - Training Loss: 0.6998453140258789, Validation Loss: 1.4519920349121094
# Epoch 12/50 - Training Loss: 0.6391932368278503, Validation Loss: 1.3689287900924683
# Epoch 13/50 - Training Loss: 0.5717931985855103, Validation Loss: 1.2405338287353516
# Epoch 14/50 - Training Loss: 0.5029130578041077, Validation Loss: 1.0854021310806274
# Epoch 15/50 - Training Loss: 0.4591389000415802, Validation Loss: 0.9751006364822388
# Epoch 16/50 - Training Loss: 0.44878941774368286, Validation Loss: 0.9949802756309509
# Epoch 17/50 - Training Loss: 0.4076581299304962, Validation Loss: 1.1383075714111328
# Epoch 18/50 - Training Loss: 0.34671807289123535, Validation Loss: 1.3576316833496094
# Epoch 19/50 - Training Loss: 0.3210296332836151, Validation Loss: 1.5414412021636963
# Epoch 20/50 - Training Loss: 0.3094829320907593, Validation Loss: 1.6072895526885986
# Early stopping!
# Epoch 1/50 - Training Loss: 1.532973051071167, Validation Loss: 1.4740405082702637
# Epoch 2/50 - Training Loss: 1.475353717803955, Validation Loss: 1.344735860824585
# Epoch 3/50 - Training Loss: 1.413597822189331, Validation Loss: 1.1914923191070557
# Epoch 4/50 - Training Loss: 1.3417526483535767, Validation Loss: 1.010225534439087
# Epoch 5/50 - Training Loss: 1.2567721605300903, Validation Loss: 0.8090360760688782
# Epoch 6/50 - Training Loss: 1.1588218212127686, Validation Loss: 0.6033821105957031
# Epoch 7/50 - Training Loss: 1.0532971620559692, Validation Loss: 0.42061862349510193
# Epoch 8/50 - Training Loss: 0.9524631500244141, Validation Loss: 0.28521907329559326
# Epoch 9/50 - Training Loss: 0.865492045879364, Validation Loss: 0.21219761669635773
# Epoch 10/50 - Training Loss: 0.7946242690086365, Validation Loss: 0.19843368232250214
# Epoch 11/50 - Training Loss: 0.7319223284721375, Validation Loss: 0.2410511076450348
# Epoch 12/50 - Training Loss: 0.672309160232544, Validation Loss: 0.3553861975669861
# Epoch 13/50 - Training Loss: 0.6233676075935364, Validation Loss: 0.5391103625297546
# Epoch 14/50 - Training Loss: 0.6063106060028076, Validation Loss: 0.6108583211898804
# Epoch 15/50 - Training Loss: 0.5954281091690063, Validation Loss: 0.4671369194984436
# Early stopping!
# Epoch 1/50 - Training Loss: 1.6588300466537476, Validation Loss: 1.5996508598327637
# Epoch 2/50 - Training Loss: 1.6013916730880737, Validation Loss: 1.5402512550354004
# Epoch 3/50 - Training Loss: 1.552184820175171, Validation Loss: 1.4828299283981323
# Epoch 4/50 - Training Loss: 1.5031697750091553, Validation Loss: 1.4168704748153687
# Epoch 5/50 - Training Loss: 1.447281837463379, Validation Loss: 1.3330708742141724
# Epoch 6/50 - Training Loss: 1.3777790069580078, Validation Loss: 1.2288492918014526
# Epoch 7/50 - Training Loss: 1.2906287908554077, Validation Loss: 1.1038702726364136
# Epoch 8/50 - Training Loss: 1.1861509084701538, Validation Loss: 0.9626167416572571
# Epoch 9/50 - Training Loss: 1.0674848556518555, Validation Loss: 0.8160836100578308
# Epoch 10/50 - Training Loss: 0.9426203370094299, Validation Loss: 0.6778621673583984
# Epoch 11/50 - Training Loss: 0.8221070766448975, Validation Loss: 0.5612754821777344
# Epoch 12/50 - Training Loss: 0.7176169157028198, Validation Loss: 0.4728951156139374
# Epoch 13/50 - Training Loss: 0.6337551474571228, Validation Loss: 0.40372827649116516
# Epoch 14/50 - Training Loss: 0.5625502467155457, Validation Loss: 0.34435832500457764
# Epoch 15/50 - Training Loss: 0.49488720297813416, Validation Loss: 0.3040391504764557
# Epoch 16/50 - Training Loss: 0.4402817487716675, Validation Loss: 0.2853618860244751
# Epoch 17/50 - Training Loss: 0.41312089562416077, Validation Loss: 0.23111385107040405
# Epoch 18/50 - Training Loss: 0.3659825623035431, Validation Loss: 0.18337519466876984
# Epoch 19/50 - Training Loss: 0.33025696873664856, Validation Loss: 0.15867671370506287
# Epoch 20/50 - Training Loss: 0.3143750727176666, Validation Loss: 0.12779627740383148
# Epoch 21/50 - Training Loss: 0.2827304005622864, Validation Loss: 0.10882618278265
# Epoch 22/50 - Training Loss: 0.2602318227291107, Validation Loss: 0.09709630161523819
# Epoch 23/50 - Training Loss: 0.24569490551948547, Validation Loss: 0.07488938421010971
# Epoch 24/50 - Training Loss: 0.21674418449401855, Validation Loss: 0.06697721034288406
# Epoch 25/50 - Training Loss: 0.20507657527923584, Validation Loss: 0.05626808479428291
# Epoch 26/50 - Training Loss: 0.17918899655342102, Validation Loss: 0.05671393498778343
# Epoch 27/50 - Training Loss: 0.16267317533493042, Validation Loss: 0.048538755625486374
# Epoch 28/50 - Training Loss: 0.14234521985054016, Validation Loss: 0.0359717421233654
# Epoch 29/50 - Training Loss: 0.12410303950309753, Validation Loss: 0.030256090685725212
# Epoch 30/50 - Training Loss: 0.10996761173009872, Validation Loss: 0.02629563957452774
# Epoch 31/50 - Training Loss: 0.09090467542409897, Validation Loss: 0.02639162354171276
# Epoch 32/50 - Training Loss: 0.08207085728645325, Validation Loss: 0.017122086137533188
# Epoch 33/50 - Training Loss: 0.06485823541879654, Validation Loss: 0.012935184873640537
# Epoch 34/50 - Training Loss: 0.05642728507518768, Validation Loss: 0.009942405857145786
# Epoch 35/50 - Training Loss: 0.04522161930799484, Validation Loss: 0.008467775769531727
# Epoch 36/50 - Training Loss: 0.03597984090447426, Validation Loss: 0.007326467428356409
# Epoch 37/50 - Training Loss: 0.031010951846837997, Validation Loss: 0.00422524381428957
# Epoch 38/50 - Training Loss: 0.022746266797184944, Validation Loss: 0.0027286952827125788
# Epoch 39/50 - Training Loss: 0.018509486690163612, Validation Loss: 0.0019109583226963878
# Epoch 40/50 - Training Loss: 0.015053662471473217, Validation Loss: 0.0012928068172186613
# Epoch 41/50 - Training Loss: 0.011182893998920918, Validation Loss: 0.0009125732467509806
# Epoch 42/50 - Training Loss: 0.008268912322819233, Validation Loss: 0.0007127683493308723
# Epoch 43/50 - Training Loss: 0.0066865552216768265, Validation Loss: 0.0005263008060865104
# Epoch 44/50 - Training Loss: 0.005496392957866192, Validation Loss: 0.00032807819661684334
# Epoch 45/50 - Training Loss: 0.004028964322060347, Validation Loss: 0.00019520026398822665
# Epoch 46/50 - Training Loss: 0.002905244240537286, Validation Loss: 0.00012444244930520654
# Epoch 47/50 - Training Loss: 0.002254801569506526, Validation Loss: 8.582392911193892e-05
# Epoch 48/50 - Training Loss: 0.0018318481743335724, Validation Loss: 6.166707316879183e-05
# Epoch 49/50 - Training Loss: 0.0014936142833903432, Validation Loss: 4.521791197475977e-05
# Epoch 50/50 - Training Loss: 0.0012016959954053164, Validation Loss: 3.3297976187895983e-05
# Epoch 1/50 - Training Loss: 1.5772932767868042, Validation Loss: 1.5081455707550049
# Epoch 2/50 - Training Loss: 1.4767822623252869, Validation Loss: 1.3688814640045166
# Epoch 3/50 - Training Loss: 1.2350144386291504, Validation Loss: 1.1944488286972046
# Epoch 4/50 - Training Loss: 1.1609633564949036, Validation Loss: 1.034172773361206
# Epoch 5/50 - Training Loss: 1.0588994026184082, Validation Loss: 0.9049999117851257
# Epoch 6/50 - Training Loss: 0.7909855544567108, Validation Loss: 0.7641211748123169
# Epoch 7/50 - Training Loss: 0.6220629066228867, Validation Loss: 0.6643458604812622
# Epoch 8/50 - Training Loss: 0.5831855535507202, Validation Loss: 0.6116805076599121
# Epoch 9/50 - Training Loss: 0.6684167385101318, Validation Loss: 0.5426454544067383
# Epoch 10/50 - Training Loss: 0.5284566730260849, Validation Loss: 0.5023117661476135
# Epoch 11/50 - Training Loss: 0.49090319871902466, Validation Loss: 0.5106778144836426
# Epoch 12/50 - Training Loss: 0.5234119892120361, Validation Loss: 0.4338429868221283
# Epoch 13/50 - Training Loss: 0.3990938067436218, Validation Loss: 0.46488937735557556
# Epoch 14/50 - Training Loss: 0.4604918360710144, Validation Loss: 0.36455416679382324
# Epoch 15/50 - Training Loss: 0.3939329832792282, Validation Loss: 0.4515801668167114
# Epoch 16/50 - Training Loss: 0.5760476291179657, Validation Loss: 0.2649593651294708
# Epoch 17/50 - Training Loss: 0.3279747813940048, Validation Loss: 0.37208089232444763
# Epoch 18/50 - Training Loss: 0.33729299157857895, Validation Loss: 0.2014451026916504
# Epoch 19/50 - Training Loss: 0.40331263095140457, Validation Loss: 0.2511124014854431
# Epoch 20/50 - Training Loss: 0.3075485825538635, Validation Loss: 0.15939365327358246
# Epoch 21/50 - Training Loss: 0.23407768458127975, Validation Loss: 0.13918247818946838
# Epoch 22/50 - Training Loss: 0.17444848641753197, Validation Loss: 0.19565345346927643
# Epoch 23/50 - Training Loss: 0.23793073743581772, Validation Loss: 0.06854571402072906
# Epoch 24/50 - Training Loss: 0.13139310851693153, Validation Loss: 0.07000032067298889
# Epoch 25/50 - Training Loss: 0.1403549574315548, Validation Loss: 0.05337842181324959
# Epoch 26/50 - Training Loss: 0.1534806452691555, Validation Loss: 0.03080771677196026
# Epoch 27/50 - Training Loss: 0.11508970335125923, Validation Loss: 0.053397659212350845
# Epoch 28/50 - Training Loss: 0.11030170693993568, Validation Loss: 0.02424365095794201
# Epoch 29/50 - Training Loss: 0.11831912025809288, Validation Loss: 0.013459011912345886
# Epoch 30/50 - Training Loss: 0.05133688822388649, Validation Loss: 0.009853584691882133
# Epoch 31/50 - Training Loss: 0.033453114330768585, Validation Loss: 0.007436586543917656
# Epoch 32/50 - Training Loss: 0.05708264373242855, Validation Loss: 0.009051447734236717
# Epoch 33/50 - Training Loss: 0.0441853292286396, Validation Loss: 0.006179243326187134
# Epoch 34/50 - Training Loss: 0.02302676811814308, Validation Loss: 0.0031010336242616177
# Epoch 35/50 - Training Loss: 0.014579522423446178, Validation Loss: 0.002767333062365651
# Epoch 36/50 - Training Loss: 0.06474459683522582, Validation Loss: 0.0020305339712649584
# Epoch 37/50 - Training Loss: 0.0261870757676661, Validation Loss: 0.0017068525776267052
# Epoch 38/50 - Training Loss: 0.014664753805845976, Validation Loss: 0.004287717863917351
# Epoch 39/50 - Training Loss: 0.015290713403373957, Validation Loss: 0.0017284149071201682
# Epoch 40/50 - Training Loss: 0.007263435749337077, Validation Loss: 0.0008150067296810448
# Epoch 41/50 - Training Loss: 0.004848476150073111, Validation Loss: 0.000643276609480381
# Epoch 42/50 - Training Loss: 0.005679152440279722, Validation Loss: 0.0005489782779477537
# Epoch 43/50 - Training Loss: 0.0038267287891358137, Validation Loss: 0.0004577225190587342
# Epoch 44/50 - Training Loss: 0.004122708342038095, Validation Loss: 0.00037770593189634383
# Epoch 45/50 - Training Loss: 0.004332667333073914, Validation Loss: 0.0003204959793947637
# Epoch 46/50 - Training Loss: 0.00249845051439479, Validation Loss: 0.00031136328470893204
# Epoch 47/50 - Training Loss: 0.003516678640153259, Validation Loss: 0.0003723280387930572
# Epoch 48/50 - Training Loss: 0.0017469529120717198, Validation Loss: 0.0004521739901974797
# Epoch 49/50 - Training Loss: 0.0022682726266793907, Validation Loss: 0.0003502705949358642
# Epoch 50/50 - Training Loss: 0.0021818845998495817, Validation Loss: 0.00022715686645824462
# Epoch 1/50 - Training Loss: 1.554013431072235, Validation Loss: 1.492993712425232
# Epoch 2/50 - Training Loss: 1.4470206499099731, Validation Loss: 1.3834763765335083
# Epoch 3/50 - Training Loss: 1.3121057748794556, Validation Loss: 1.2245453596115112
# Epoch 4/50 - Training Loss: 1.1184442639350891, Validation Loss: 1.0238827466964722
# Epoch 5/50 - Training Loss: 0.9056409001350403, Validation Loss: 0.8463197350502014
# Epoch 6/50 - Training Loss: 0.7426937222480774, Validation Loss: 0.7106875777244568
# Epoch 7/50 - Training Loss: 0.6282689869403839, Validation Loss: 0.6042351126670837
# Epoch 8/50 - Training Loss: 0.5598399341106415, Validation Loss: 0.580474317073822
# Epoch 9/50 - Training Loss: 0.5230458527803421, Validation Loss: 0.5226091742515564
# Epoch 10/50 - Training Loss: 0.4800664782524109, Validation Loss: 0.4575822055339813
# Epoch 11/50 - Training Loss: 0.434693843126297, Validation Loss: 0.4133358299732208
# Epoch 12/50 - Training Loss: 0.3990746885538101, Validation Loss: 0.33960413932800293
# Epoch 13/50 - Training Loss: 0.3517661392688751, Validation Loss: 0.30503204464912415
# Epoch 14/50 - Training Loss: 0.29016663134098053, Validation Loss: 0.23900020122528076
# Epoch 15/50 - Training Loss: 0.23424885421991348, Validation Loss: 0.22116000950336456
# Epoch 16/50 - Training Loss: 0.20358650386333466, Validation Loss: 0.15630978345870972
# Epoch 17/50 - Training Loss: 0.22254478186368942, Validation Loss: 0.205170676112175
# Epoch 18/50 - Training Loss: 0.2786198705434799, Validation Loss: 0.29193994402885437
# Epoch 19/50 - Training Loss: 0.1870180070400238, Validation Loss: 0.08429417014122009
# Epoch 20/50 - Training Loss: 0.3208426982164383, Validation Loss: 0.09129414707422256
# Epoch 21/50 - Training Loss: 0.12832686677575111, Validation Loss: 0.32670512795448303
# Epoch 22/50 - Training Loss: 0.25254159420728683, Validation Loss: 0.31888547539711
# Epoch 23/50 - Training Loss: 0.19933489710092545, Validation Loss: 0.137680783867836
# Epoch 24/50 - Training Loss: 0.07500613294541836, Validation Loss: 0.04676533117890358
# Epoch 25/50 - Training Loss: 0.15411009266972542, Validation Loss: 0.042689770460128784
# Epoch 26/50 - Training Loss: 0.057504281401634216, Validation Loss: 0.10201576352119446
# Epoch 27/50 - Training Loss: 0.07126476801931858, Validation Loss: 0.16316436231136322
# Epoch 28/50 - Training Loss: 0.08531759679317474, Validation Loss: 0.1372394561767578
# Epoch 29/50 - Training Loss: 0.06308121606707573, Validation Loss: 0.07513441890478134
# Epoch 30/50 - Training Loss: 0.031033207662403584, Validation Loss: 0.027556560933589935
# Epoch 31/50 - Training Loss: 0.04574016574770212, Validation Loss: 0.019912397488951683
# Epoch 32/50 - Training Loss: 0.0338759021833539, Validation Loss: 0.03369663655757904
# Epoch 33/50 - Training Loss: 0.018646547570824623, Validation Loss: 0.05295717343688011
# Epoch 34/50 - Training Loss: 0.022860766388475895, Validation Loss: 0.05988827347755432
# Epoch 35/50 - Training Loss: 0.023782077245414257, Validation Loss: 0.04974149540066719
# Epoch 36/50 - Training Loss: 0.018443638458848, Validation Loss: 0.03245134279131889
# Early stopping!

# %%
# Plotting the Training Curves
plt.figure(figsize=(12, 6))
for i, (train_losses, val_losses) in enumerate(training_curves):
    plt.plot(train_losses, label=f"{percentages[i]*100}% Data - Training Loss", linestyle='--')
    plt.plot(val_losses, label=f"{percentages[i]*100}% Data - Validation Loss")
    
plt.title("Training Curves for Different Data Percentages")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
class ETETransferModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim_transfer, dropout_prob=0.15):
        super(ETETransferModel, self).__init__()
        # Copy the layers from the pretrained model
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, hidden_dim)
        self.fc5 = nn.Linear(hidden_dim, hidden_dim)
        self.fc6 = nn.Linear(hidden_dim, output_dim_trnsfr)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x = self.fc6(x)
        return x

# %%
# Your percentage list
percentages = [0.005, 0.01, 0.015, 0.02, 0.03, 0.07, 0.1]

# Storage for models and their training curves
trained_models_ete = []
training_curves_ete = []

for percentage in percentages:
    # Sample the data
    sample_size = int(percentage * len(transfer_dataset))
    sampled_data, _ = torch.utils.data.random_split(transfer_dataset, [sample_size, len(transfer_dataset) - sample_size])

    # Splitting the sampled_data further into train, validation, and test sets
    transfer_train_size = int(train_ratio * len(sampled_data))
    transfer_val_size = int(val_ratio * len(sampled_data))
    transfer_test_size = len(sampled_data) - transfer_train_size - transfer_val_size
    
    # Ensure each split has at least one sample
    while transfer_train_size < 1:
        transfer_train_size += 1
        transfer_val_size -= 1
        
    while transfer_val_size < 1:
        transfer_val_size += 1
        transfer_train_size -= 1
    
    transfer_train_dataset, transfer_val_dataset, _ = random_split(sampled_data, [transfer_train_size, transfer_val_size, transfer_test_size])
    
    # Create dataloaders
    transfer_train_loader = torch.utils.data.DataLoader(transfer_train_dataset, batch_size=batch_size, shuffle=True)
    transfer_val_loader = torch.utils.data.DataLoader(transfer_val_dataset, batch_size=batch_size, shuffle=True)
    
    # Create a new model for transfer learning
    transfer_model_ete = ETETransferModel(input_dim, hidden_dim, output_dim_trnsfr)
    transfer_model_ete.to(device)

    # Define optimizer only for the unfrozen layer
    optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, transfer_model.parameters()), lr=0.001)
    
    # Lists to store losses for this model
    train_losses = []
    val_losses = []
    
    # Training loop
    epochs = 50
    patience = 5  # Number of epochs to wait before stopping
    wait = 0
    best_loss = float('inf')

    for epoch in range(epochs):
        # Training phase
        transfer_model.train()
        train_loss = 0.0
        for data, target in transfer_train_loader:
            optimizer.zero_grad()
            output = transfer_model_ete(data.float().to(device))
            loss = criterion(output.float().to(device), target.long().to(device))
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(transfer_train_loader)

        # Validation phase
        transfer_model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for data, target in transfer_val_loader:
                output = transfer_model_ete(data.float().to(device))
                loss = criterion(output.float().to(device), target.long().to(device))
                val_loss += loss.item()

        val_loss /= len(transfer_val_loader)
        print(f"Epoch {epoch+1}/{epochs} - Training Loss: {train_loss}, Validation Loss: {val_loss}")
        
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        
        # Check early stopping condition
        if val_loss < best_loss:
            best_loss = val_loss
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                print("Early stopping!")
                break

    # Append the trained model to the list
    trained_models_ete.append(transfer_model)
    training_curves_ete.append((train_losses, val_losses))
# Out:
# Epoch 1/50 - Training Loss: 1.6718404293060303, Validation Loss: 1.6577197313308716
# Epoch 2/50 - Training Loss: 1.6718404293060303, Validation Loss: 1.6577197313308716
# Epoch 3/50 - Training Loss: 1.6718404293060303, Validation Loss: 1.6577197313308716
# Epoch 4/50 - Training Loss: 1.6718404293060303, Validation Loss: 1.6577197313308716
# Epoch 5/50 - Training Loss: 1.6718404293060303, Validation Loss: 1.6577197313308716
# Epoch 6/50 - Training Loss: 1.6718404293060303, Validation Loss: 1.6577197313308716
# Early stopping!
# Epoch 1/50 - Training Loss: 1.5821983814239502, Validation Loss: 1.6008845567703247
# Epoch 2/50 - Training Loss: 1.5821983814239502, Validation Loss: 1.6008845567703247
# Epoch 3/50 - Training Loss: 1.5821983814239502, Validation Loss: 1.6008845567703247
# Epoch 4/50 - Training Loss: 1.5821983814239502, Validation Loss: 1.6008845567703247
# Epoch 5/50 - Training Loss: 1.5821983814239502, Validation Loss: 1.6008845567703247
# Epoch 6/50 - Training Loss: 1.5821983814239502, Validation Loss: 1.6008845567703247
# Early stopping!
# Epoch 1/50 - Training Loss: 1.602843999862671, Validation Loss: 1.6116905212402344
# Epoch 2/50 - Training Loss: 1.602843999862671, Validation Loss: 1.6116905212402344
# Epoch 3/50 - Training Loss: 1.60284423828125, Validation Loss: 1.6116905212402344
# Epoch 4/50 - Training Loss: 1.602843999862671, Validation Loss: 1.6116905212402344
# Epoch 5/50 - Training Loss: 1.602843999862671, Validation Loss: 1.6116905212402344
# Epoch 6/50 - Training Loss: 1.6028441190719604, Validation Loss: 1.6116905212402344
# Early stopping!
# Epoch 1/50 - Training Loss: 1.6403172016143799, Validation Loss: 1.6310336589813232
# Epoch 2/50 - Training Loss: 1.6403170824050903, Validation Loss: 1.6310336589813232
# Epoch 3/50 - Training Loss: 1.6403170824050903, Validation Loss: 1.6310336589813232
# Epoch 4/50 - Training Loss: 1.6403170824050903, Validation Loss: 1.6310336589813232
# Epoch 5/50 - Training Loss: 1.6403170824050903, Validation Loss: 1.6310336589813232
# Epoch 6/50 - Training Loss: 1.6403170824050903, Validation Loss: 1.6310336589813232
# Early stopping!
# Epoch 1/50 - Training Loss: 1.6332932710647583, Validation Loss: 1.6240845918655396
# Epoch 2/50 - Training Loss: 1.6332932710647583, Validation Loss: 1.6240845918655396
# Epoch 3/50 - Training Loss: 1.6332931518554688, Validation Loss: 1.6240845918655396
# Epoch 4/50 - Training Loss: 1.6332931518554688, Validation Loss: 1.6240845918655396
# Epoch 5/50 - Training Loss: 1.6332933902740479, Validation Loss: 1.6240845918655396
# Epoch 6/50 - Training Loss: 1.6332931518554688, Validation Loss: 1.6240845918655396
# Early stopping!
# Epoch 1/50 - Training Loss: 1.6191424131393433, Validation Loss: 1.650865077972412
# Epoch 2/50 - Training Loss: 1.6197718977928162, Validation Loss: 1.650865077972412
# Epoch 3/50 - Training Loss: 1.6187819242477417, Validation Loss: 1.650865077972412
# Epoch 4/50 - Training Loss: 1.628256618976593, Validation Loss: 1.650865077972412
# Epoch 5/50 - Training Loss: 1.655499279499054, Validation Loss: 1.6508649587631226
# Epoch 6/50 - Training Loss: 1.6366865038871765, Validation Loss: 1.650865077972412
# Epoch 7/50 - Training Loss: 1.6197295784950256, Validation Loss: 1.6508649587631226
# Epoch 8/50 - Training Loss: 1.6267672181129456, Validation Loss: 1.6508651971817017
# Epoch 9/50 - Training Loss: 1.6283623576164246, Validation Loss: 1.6508649587631226
# Epoch 10/50 - Training Loss: 1.6466196179389954, Validation Loss: 1.650865077972412
# Early stopping!
# Epoch 1/50 - Training Loss: 1.5627391338348389, Validation Loss: 1.5619505643844604
# Epoch 2/50 - Training Loss: 1.562962830066681, Validation Loss: 1.5619503259658813
# Epoch 3/50 - Training Loss: 1.5627820491790771, Validation Loss: 1.5619505643844604
# Epoch 4/50 - Training Loss: 1.5628328919410706, Validation Loss: 1.5619505643844604
# Epoch 5/50 - Training Loss: 1.5625650882720947, Validation Loss: 1.5619505643844604
# Epoch 6/50 - Training Loss: 1.56265389919281, Validation Loss: 1.5619503259658813
# Epoch 7/50 - Training Loss: 1.562982439994812, Validation Loss: 1.5619503259658813
# Early stopping!

# %%
# Plotting the Training Curves
plt.figure(figsize=(12, 6))
for i, (train_losses, val_losses) in enumerate(training_curves_ete):
    plt.plot(train_losses, label=f"{percentages[i]*100}% Data - Training Loss", linestyle='--')
    plt.plot(val_losses, label=f"{percentages[i]*100}% Data - Validation Loss")
    
plt.title("Training Curves for Different Data Percentages")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
test_loaders = []

for percentage in percentages:
    sample_size = int(percentage * len(transfer_dataset))
    _, remaining = torch.utils.data.random_split(transfer_dataset, [sample_size, len(transfer_dataset) - sample_size])
    
    _, _, transfer_test_dataset = random_split(remaining, [transfer_train_size, transfer_val_size, len(remaining) - transfer_train_size - transfer_val_size])

    transfer_test_loader = torch.utils.data.DataLoader(transfer_test_dataset, batch_size=batch_size, shuffle=False)
    test_loaders.append(transfer_test_loader)

# %%
def evaluate(model, test_loader, criterion, device):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.float().to(device), target.long().to(device)
            outputs = model(data)
            loss = criterion(outputs, target)
            
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += target.size(0)
            correct += predicted.eq(target).sum().item()
    
    accuracy = 100. * correct / total
    test_loss /= len(test_loader)
    return test_loss, accuracy

# %%
test_results = []
test_results_ete = []

criterion = nn.CrossEntropyLoss()

for i in range(len(percentages)):
    loss, accuracy = evaluate(trained_models[i], test_loaders[i], criterion, device)
    test_results.append((loss, accuracy))

    loss_ete, accuracy_ete = evaluate(trained_models_ete[i], test_loaders[i], criterion, device)
    test_results_ete.append((loss_ete, accuracy_ete))

# %%
import matplotlib.pyplot as plt

accuracies = [x[1] for x in test_results]
accuracies_ete = [x[1] for x in test_results_ete]

plt.figure(figsize=(12, 6))
plt.plot(percentages, accuracies, marker='o', label='trained_models')
plt.plot(percentages, accuracies_ete, marker='x', label='trained_models_ete', linestyle='--')
plt.xlabel('Sample Percentage')
plt.ylabel('Accuracy')
plt.title('Comparison between trained_models and trained_models_ete')
plt.legend()
plt.grid(True)
plt.show()

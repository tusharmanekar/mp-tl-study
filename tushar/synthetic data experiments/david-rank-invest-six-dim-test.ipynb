# %% [markdown]
# ToDo
#
# [] reduce size of finetuning dataset
#
# [] see how performance changes as a function of the % of the finetuning dataset used
#
# [x] create an end2end baseline
#
# [] change to 1 layer
#
# [x] update early stopping
#
# [] investigate SGD
#
# [] other stuff on slack
#
# [] randomsearch with wandb

# %%
import sys
sys.path.append('..')

from utils import *
from data_utils import *
from metrics import *
from plots import *

import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# ## Testing dataset generation

# %%
def eval(model, device, dataset_loader, debug, classification_report_flag = False):
    model.eval()
    test_loss, correct = 0., 0.
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for data, target in dataset_loader:
            data, target = data.reshape([data.shape[0], -1]).to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(
                output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(
                dim=1,
                keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(target.cpu().numpy())

    num_data = len(dataset_loader.dataset)
    test_loss /= num_data
    acc = correct / num_data
    if debug:
        print('\nAverage loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.
              format(test_loss, correct, num_data, 100. * acc))

    if classification_report_flag:
        print(classification_report(all_labels, all_preds, target_names=[f'Class {i}' for i in range(len(set(all_labels)))]))

    return acc

# %%
def rotation_matrix_6D(theta, dim1, dim2):
    """
    Create a 6D rotation matrix to rotate by angle theta in the plane defined by dim1 and dim2.
    
    Parameters:
    - theta: Rotation angle in radians.
    - dim1, dim2: Dimensions (0-5) in which rotation should occur.
    
    Returns:
    - 6x6 rotation matrix.
    """
    R2 = np.array([[np.cos(theta), -np.sin(theta)],
                   [np.sin(theta), np.cos(theta)]])
    
    R6 = np.eye(6) # create identity matrix of 6*6
    R6[dim1, dim1], R6[dim1, dim2], R6[dim2, dim1], R6[dim2, dim2] = R2.flatten()
    
    return R6

# %%
def generate_data_6D(n_samples_per_class=100, n_classes=5):
    """
    Generate data for n_classes in a 6D space.

    Parameters:
    - n_samples_per_class: Number of samples per class.
    - n_classes: Number of classes.

    Returns:
    - X: Data points.
    - y: Class targets.
    """
    
    # Define means for the classes in 6D space
    means = [tuple(i*2 for _ in range(6)) for i in range(n_classes)]

    # Define a covariance matrix for 6D
    # Base covariance defines how spread out the data is in that dimension
    base_covariance = np.array([[0.2, 0, 0, 0, 0, 0], 
                                [0, 5, 0, 0, 0, 0],
                                [0, 0, 0.2, 0, 0, 0],
                                [0, 0, 0, 5, 0, 0],
                                [0, 0, 0, 0, 0.2, 0],
                                [0, 0, 0, 0, 0, 5]])
    
    theta = np.pi / 4  # or any other desired angle
    # R = rotation_matrix_6D(theta, 0, 1)  # for rotation in the plane of the first two dimensions
    
    R1 = rotation_matrix_6D(theta, 0, 1)
    R2 = rotation_matrix_6D(theta, 2, 3)
    R3 = rotation_matrix_6D(theta, 4, 5)
    covariance = R1 @ R2 @ R3 @ base_covariance @ R3.T @ R2.T @ R1.T
    
    X = np.empty((0, 6))
    y = np.empty((0,))

    for idx, mean in enumerate(means):
        class_data = np.random.multivariate_normal(mean, covariance, n_samples_per_class)
        X = np.vstack([X, class_data])
        y = np.hstack([y, [idx]*n_samples_per_class])

    return X, y

# %%
# Generate and plot the data
n_classes = 5
X, y = generate_data_6D(n_samples_per_class = 400, n_classes=n_classes)

for idx in range(5):
    plt.scatter(X[y == idx][:, 0], X[y == idx][:, 1], label=f'Class {idx}')

plt.title("Five Classes in 2D Space")
plt.legend()
plt.show()

# %%
# Split the data into primary (even classes) and transfer (odd classes) datasets
X_primary = X[np.isin(y, [0, 2, 4])]
y_primary = y[np.isin(y, [0, 2, 4])]

X_transfer = X[np.isin(y, [1, 3])]
y_transfer = y[np.isin(y, [1, 3])]

# Splitting ratios
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Primary dataset: Split into train, validation, and test sets
X_primary_train, X_primary_temp, y_primary_train, y_primary_temp = train_test_split(X_primary, y_primary, test_size=(1-train_ratio))
X_primary_val, X_primary_test, y_primary_val, y_primary_test = train_test_split(X_primary_temp, y_primary_temp, test_size=test_ratio/(test_ratio+val_ratio))

# Transfer dataset: Split into train, validation, and test sets
X_transfer_train, X_transfer_temp, y_transfer_train, y_transfer_temp = train_test_split(X_transfer, y_transfer, test_size=(1-train_ratio))
X_transfer_val, X_transfer_test, y_transfer_val, y_transfer_test = train_test_split(X_transfer_temp, y_transfer_temp, test_size=test_ratio/(test_ratio+val_ratio))

# Plotting
# For brevity, I'm only plotting the training datasets for primary and transfer.
plt.figure(figsize=(12, 5))

# Primary training dataset
plt.subplot(1, 2, 1)
colors = ['red', 'blue', 'green', 'purple', 'orange']
for i in [0, 2, 4]:
    plt.scatter(X_primary_train[y_primary_train==i][:, 0], X_primary_train[y_primary_train==i][:, 1], color=colors[i % len(colors)], label=f'Class {i}')
plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Primary Training Dataset (Even Classes)')
plt.grid(True)

# Transfer training dataset
plt.subplot(1, 2, 2)
for i in [1, 3]:
    plt.scatter(X_transfer_train[y_transfer_train==i][:, 0], X_transfer_train[y_transfer_train==i][:, 1], color=colors[i % len(colors)], label=f'Class {i}')
plt.legend()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Transfer Training Dataset (Odd Classes)')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ADAM IS THE KEY

# %%
# like previous function, but run for given number of epochs determined by params['num_train']
def compute_training_acc_epochs(model, dataset, params, debug=False, save_checkpoints=False):
    device = torch.device(params['device'])
    optimizer = optim.Adam(model.parameters(), lr=params['lr'])   
    # if debug: print(model, optimizer)

    if params['early_stop_patience']:
        no_improve_epochs = 0
        max_val_acc = 0.

    train_acc = 0.0
    model.train()
    checkpoints = []

    # Loop over epochs
    for epoch in range(params['num_train']):
        for batch_idx, (data, target) in enumerate(dataset.train_loader):
            data, target = data.reshape([data.shape[0], -1]).to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = F.nll_loss(output, target)
            loss.backward()
            optimizer.step()

            if debug and batch_idx % 20 == 0:
                #print('Epoch: {} Train step: {} \tLoss: {:.6f}'.format(epoch, batch_idx, loss.item()))
                pass

        # Evaluate after each epoch
        if debug:
            train_acc = eval(model, device, dataset.train_loader, debug=False)
            print('Epoch: {} \tTraining Accuracy: {:.2f}%'.format(epoch, train_acc*100))
            # if debug and (epoch+1) % 1 == 0:
            val_acc = eval(model, device, dataset.val_loader, debug=False)
            print('Validation Accuracy: {:.2f}%'.format(val_acc*100))

            if params['early_stop_patience']:
                if val_acc > max_val_acc:
                    max_val_acc = val_acc
                    no_improve_epochs = 0
                else:
                    no_improve_epochs += 1
                    print("val_acc: {}, max_val_acc: {}, no_improve_epochs: {}".format(val_acc, max_val_acc, no_improve_epochs))
                    if no_improve_epochs >= params['early_stop_patience']:
                        print("Early stopping invoked.")
                        break
        
        if save_checkpoints:
            # Save checkpoint after each epoch
            checkpoint = {
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'train_acc': train_acc,
                'val_acc': val_acc
            }
            torch.save(checkpoint, 'checkpoint_epoch_{}.pth'.format(epoch))
            checkpoints.append(checkpoint)

    # Final evaluation after all epochs are completed
    train_acc = eval(model, device, dataset.train_loader, debug=False)
    test_acc = eval(model, device, dataset.test_loader, debug=False)
    if save_checkpoints:
        return train_acc, test_acc, model, checkpoints
    else:
        return train_acc, test_acc, model, []

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

def plot_decision_boundary(model, X, y, n_classes):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1))

    with torch.no_grad():
        model.eval()
        Z = model(torch.FloatTensor(np.c_[xx.ravel(), yy.ravel()])).numpy()
        Z = np.argmax(Z, axis=1)

    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, alpha=0.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o', linewidth=1)
    plt.title("Decision Boundary")
    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")

    for i in range(n_classes):
        plt.scatter([], [], c='k', alpha=0.8, s=20, label=f"Class {i}")
    plt.legend(loc='upper left')

    plt.show()

def plot_decision_boundary_dataloader(model, dataloader, n_classes, percentage = None, Seed = None):
    # Extract data from dataloader
    X_list = []
    y_list = []
    for data, target in dataloader:
        X_list.append(data.numpy())
        y_list.append(target.numpy())
    
    # Concatenate all the data points
    X = np.vstack(X_list)
    y = np.hstack(y_list)
    
    # Rest is similar to the original function
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1))

    with torch.no_grad():
        model.eval()
        Z = model(torch.FloatTensor(np.c_[xx.ravel(), yy.ravel()])).numpy()
        Z = np.argmax(Z, axis=1)

    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, alpha=0.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o', linewidth=1)
    if percentage and Seed:
        plt.title(f"Decision Boundary (percentage {percentage:.2f}%, Seed: {Seed})")
    elif percentage:
        plt.title(f"Decision Boundary (percentage {percentage:.2f}%)")
    else:
        plt.title("Decision Boundary")
    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")

    for i in range(n_classes):
        plt.scatter([], [], c='k', alpha=0.8, s=20, label=f"Class {i}")
    plt.legend(loc='upper left')

    plt.show()

# Usage
# plot_decision_boundary_dataloader(model, dataloader, n_classes=2)

# %%
def compute_training_acc_epochs(model, dataset, params, debug=False, save_checkpoints=False, plot_boundary=False):
    device = torch.device(params['device'])
    optimizer = optim.Adam(model.parameters(), lr=params['lr'])   

    best_model_state = None  # To save the best model weights/state
    if params['early_stop_patience']:
        no_improve_epochs = 0
        max_val_acc = 0.

    train_acc = 0.0
    model.train()
    checkpoints = []

    # Loop over epochs
    for epoch in range(params['num_train']):
        for batch_idx, (data, target) in enumerate(dataset.train_loader):
            data, target = data.reshape([data.shape[0], -1]).to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = F.nll_loss(output, target)
            loss.backward()
            optimizer.step()

        # Evaluate after each epoch
        if debug:
            train_acc = eval(model, device, dataset.train_loader, debug=False)
            val_acc = eval(model, device, dataset.val_loader, debug=False)
            print('Epoch: {} \tTraining Accuracy: {:.2f}%'.format(epoch, train_acc*100))
            print('Validation Accuracy: {:.2f}%'.format(val_acc*100))
        if plot_boundary:
            plot_decision_boundary_dataloader(model, dataset.train_loader,  n_classes=2)

        if params['early_stop_patience']:
            if val_acc > max_val_acc:
                max_val_acc = val_acc
                best_model_state = model.state_dict().copy() # This line saves the best model state.
                no_improve_epochs = 0
                best_model_state = model.state_dict()  # Save the best model state
            else:
                no_improve_epochs += 1
                print("val_acc: {}, max_val_acc: {}, no_improve_epochs: {}".format(val_acc, max_val_acc, no_improve_epochs))
                if no_improve_epochs >= params['early_stop_patience']:
                    print("Early stopping invoked.")
                    if best_model_state is not None:
                        model.load_state_dict(best_model_state)  # Load the best model weights
                    break
        
        if save_checkpoints:
            checkpoint = {
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'train_acc': train_acc,
                'val_acc': val_acc
            }
            torch.save(checkpoint, 'checkpoint_epoch_{}.pth'.format(epoch))
            checkpoints.append(checkpoint)

    # At the end of training, load the best weights if early stopping wasn't invoked 
    # (in case the final epochs did not improve performance)
    if params['early_stop_patience']:
        if not params['early_stop_patience'] or no_improve_epochs < params['early_stop_patience']:
            model.load_state_dict(best_model_state)

    train_acc = eval(model, device, dataset.train_loader, debug=False)
    test_acc = eval(model, device, dataset.test_loader, debug=False)
    if save_checkpoints:
        return train_acc, test_acc, model, checkpoints
    else:
        return train_acc, test_acc, model, []

# %%
import torch.utils.data as data

def reduce_dataset(dataloader, percentage, seed=42):
    """
    Reduces the dataset to the given percentage.

    Parameters:
    - dataloader: PyTorch DataLoader object.
    - percentage: Desired percentage of the original dataset.
    - seed: Seed for reproducibility.

    Returns:
    - reduced_dataloader: DataLoader with the reduced dataset.
    """
    # Extract the dataset from the dataloader
    dataset = dataloader.dataset
    
    # Extract all data and labels from the dataset
    X = [dataset[i][0] for i in range(len(dataset))]
    y = [dataset[i][1] for i in range(len(dataset))]

    # Set the seed for reproducibility
    torch.manual_seed(seed)

    # Determine the number of samples to keep
    num_samples = int(len(dataset) * percentage)
    
    # Randomly select indices without replacement
    indices = torch.randperm(len(dataset))[:num_samples]

    # Use a Subset of the original dataset to create a reduced dataset
    reduced_dataset = data.Subset(dataset, indices)

    # Create a DataLoader with the reduced dataset. 
    # You may want to copy other settings from the original DataLoader (like batch_size).
    reduced_dataloader = data.DataLoader(reduced_dataset, batch_size=dataloader.batch_size, shuffle=True)

    return reduced_dataloader

import torch
from torch.utils import data

def reduce_dataset_balanced(dataloader, percentage, seed=42):
    """
    Reduces the dataset to the given percentage ensuring class balance.

    Parameters:
    - dataloader: PyTorch DataLoader object.
    - percentage: Desired percentage of the original dataset.
    - seed: Seed for reproducibility.

    Returns:
    - reduced_dataloader: DataLoader with the reduced dataset.
    """
    # Extract the dataset from the dataloader
    dataset = dataloader.dataset
    
    # Extract all data and labels from the dataset
    X = [dataset[i][0] for i in range(len(dataset))]
    y = [dataset[i][1] for i in range(len(dataset))]

    # Set the seed for reproducibility
    torch.manual_seed(seed)

    # Get unique classes and their counts
    classes, class_counts = torch.unique(torch.tensor(y), return_counts=True)
    
    # Determine the number of samples per class to keep
    num_samples_per_class = int(len(dataset) * percentage / len(classes))
    selected_indices = []

    for class_label in classes:
        class_indices = [i for i, label in enumerate(y) if label == class_label]
        
        # Randomly select indices without replacement for each class
        class_selected_indices = torch.randperm(len(class_indices))[:num_samples_per_class].tolist()
        selected_indices.extend([class_indices[i] for i in class_selected_indices])

    # Use a Subset of the original dataset to create a reduced dataset
    reduced_dataset = data.Subset(dataset, selected_indices)

    # Create a DataLoader with the reduced dataset. 
    # You may want to copy other settings from the original DataLoader (like batch_size).
    reduced_dataloader = data.DataLoader(reduced_dataset, batch_size=dataloader.batch_size, shuffle=True)

    return reduced_dataloader

# %% [markdown]
# ## Pretraining

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
device = 'cpu'

depth = 5

params = dict(device=device,
                width=128, lr=0.0001, num_train=100,
                sb=0.05, depth= depth, sw=1.7346938775510203, early_stop_patience = 10, activation_function='tanh')

import torch
from torch.utils.data import TensorDataset, DataLoader

#relable the data
mapping = {0: 0, 2: 1, 4: 2}

y_primary_train_pretain = torch.LongTensor([mapping[c] for c in y_primary_train])
y_primary_val_pretain = torch.LongTensor([mapping[c] for c in y_primary_val])
y_primary_test_pretain = torch.LongTensor([mapping[c] for c in y_primary_test])

# Convert primary training data to PyTorch tensors
X_primary_train_tensor = torch.FloatTensor(X_primary_train)
y_primary_train_tensor = torch.LongTensor(y_primary_train_pretain)

# Convert primary validation data to PyTorch tensors
X_primary_val_tensor = torch.FloatTensor(X_primary_val)
y_primary_val_tensor = torch.LongTensor(y_primary_val_pretain)

# Convert primary test data to PyTorch tensors
X_primary_test_tensor = torch.FloatTensor(X_primary_test)
y_primary_test_tensor = torch.LongTensor(y_primary_test_pretain)


# Create DataLoaders for primary datasets
train_dataset = TensorDataset(X_primary_train_tensor, y_primary_train_tensor)
val_dataset = TensorDataset(X_primary_val_tensor, y_primary_val_tensor)
test_dataset = TensorDataset(X_primary_test_tensor, y_primary_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Create DNN model
input_dim = 6  # 6D data points
output_dim = n_classes  # Number of classes
model = generate_fc_dnn(input_dim, output_dim-2, params, gaussian_init=False, activation_function = nn.ReLU)

# Create a 'Namespace' to supply to the training function (to comply with your function's requirements)
from types import SimpleNamespace
dataset_namespace = SimpleNamespace(train_loader=train_loader, val_loader=val_loader, test_loader=test_loader)

# Train and evaluate
train_acc, test_acc, model, _ = compute_training_acc_epochs(model, dataset_namespace, params, debug=True)

print(f"Final Training Accuracy: {train_acc:.4f}")
print(f"Final Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 34.68%
# Validation Accuracy: 35.56%
# Epoch: 1 	Training Accuracy: 64.96%
# Validation Accuracy: 68.33%
# Epoch: 2 	Training Accuracy: 68.65%
# Validation Accuracy: 71.11%
# Epoch: 3 	Training Accuracy: 79.14%
# Validation Accuracy: 82.22%
# Epoch: 4 	Training Accuracy: 83.55%
# Validation Accuracy: 85.00%
# Epoch: 5 	Training Accuracy: 90.94%
# Validation Accuracy: 93.33%
# Epoch: 6 	Training Accuracy: 90.82%
# Validation Accuracy: 93.89%
# Epoch: 7 	Training Accuracy: 90.94%
# Validation Accuracy: 93.33%
# val_acc: 0.9333333333333333, max_val_acc: 0.9388888888888889, no_improve_epochs: 1
# Epoch: 8 	Training Accuracy: 95.35%
# Validation Accuracy: 95.56%
# Epoch: 9 	Training Accuracy: 90.82%
# Validation Accuracy: 93.89%
# val_acc: 0.9388888888888889, max_val_acc: 0.9555555555555556, no_improve_epochs: 1
# Epoch: 10 	Training Accuracy: 96.42%
# Validation Accuracy: 97.78%
# Epoch: 11 	Training Accuracy: 95.59%
# Validation Accuracy: 96.11%
# val_acc: 0.9611111111111111, max_val_acc: 0.9777777777777777, no_improve_epochs: 1
# Epoch: 12 	Training Accuracy: 97.50%
# Validation Accuracy: 98.33%
# Epoch: 13 	Training Accuracy: 98.57%
# Validation Accuracy: 98.33%
# val_acc: 0.9833333333333333, max_val_acc: 0.9833333333333333, no_improve_epochs: 1
# Epoch: 14 	Training Accuracy: 98.21%
# Validation Accuracy: 97.22%
# val_acc: 0.9722222222222222, max_val_acc: 0.9833333333333333, no_improve_epochs: 2
# Epoch: 15 	Training Accuracy: 99.52%
# Validation Accuracy: 100.00%
# Epoch: 16 	Training Accuracy: 98.45%
# Validation Accuracy: 99.44%
# val_acc: 0.9944444444444445, max_val_acc: 1.0, no_improve_epochs: 1
# Epoch: 17 	Training Accuracy: 99.76%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 2
# Epoch: 18 	Training Accuracy: 99.64%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 3
# Epoch: 19 	Training Accuracy: 99.88%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 4
# Epoch: 20 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 5
# Epoch: 21 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 6
# Epoch: 22 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 7
# Epoch: 23 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 8
# Epoch: 24 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 9
# Epoch: 25 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 10
# Early stopping invoked.
# Final Training Accuracy: 1.0000
# Final Test Accuracy: 1.0000

# %%
print(model)
# Out:
# Sequential(
#   (linear0): Linear(in_features=6, out_features=128, bias=True)
#   (activation0): ReLU()
#   (linear1): Linear(in_features=128, out_features=128, bias=True)
#   (activation1): ReLU()
#   (linear2): Linear(in_features=128, out_features=128, bias=True)
#   (activation2): ReLU()
#   (linear3): Linear(in_features=128, out_features=128, bias=True)
#   (activation3): ReLU()
#   (linear4): Linear(in_features=128, out_features=3, bias=True)
#   (activation4): LogSoftmax(dim=1)
# )

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# After training
# plot_decision_boundary(model, X_primary_train, y_primary_train, n_classes)
# plot_decision_boundary(model, X_primary_val, y_primary_val, n_classes)
# plot_decision_boundary(model, X_primary_test, y_primary_test, n_classes)

# %%
import matplotlib.pyplot as plt

def plot_layer_transformations(model, X, y, layer_indices):
    n_classes = len(np.unique(y))
    X_transformed = torch.FloatTensor(X)
    
    for i, layer_index in enumerate(layer_indices):
        layer = model[layer_index]
        
        with torch.no_grad():
            X_transformed = layer(X_transformed)
            
        if isinstance(layer, nn.Linear) or isinstance(layer, nn.Tanh) or isinstance(layer, nn.LogSoftmax):
            X_transformed_numpy = X_transformed.detach().cpu().numpy()
            
            plt.figure()
            for class_idx in range(n_classes):
                idxs = np.where(y == class_idx)[0]
                plt.scatter(X_transformed_numpy[idxs, 0], X_transformed_numpy[idxs, 1], label=f"Class {class_idx}")
            
            layer_type = type(layer).__name__
            plt.title(f'Transformation after layer {layer_index} ({layer_type})')
            plt.xlabel('Dimension 1')
            plt.ylabel('Dimension 2')
            plt.legend()

# Indicate which layers you are interested in (by index).
layer_indices = list(range(depth*2))

# X should be your original data and y should be the labels.
plot_layer_transformations(model, X_primary_train, y_primary_train, layer_indices)

plt.show()

# %%
eval(model, device, test_loader, debug=True, classification_report_flag = True)
# Out:
# Average loss: 0.0172, Accuracy: 181.0/181 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00        60
#      Class 1       1.00      1.00      1.00        63
#      Class 2       1.00      1.00      1.00        58
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
# 1.0

# %%
#save model
# torch.save(model, f"model_{depth}_synthetic_data_against_overfitting.pt")

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_layer_ranks(model):
    ranks = []
    layer_names = []
    
    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            rank = np.linalg.matrix_rank(weight_matrix)
            ranks.append(rank)
            layer_names.append(name)
    
    # Plotting
    plt.figure(figsize=(15, 6))
    plt.bar(layer_names, ranks, color='blue')
    plt.xlabel('Layer')
    plt.ylabel('Rank')
    plt.title('Rank of Weight Matrices for Each Layer')
    plt.grid(True)
    
    y_max = np.max(ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(y_min, y_max, step=2))  # Set yticks

    plt.show()

# Example usage
plot_layer_ranks(model)  # Note: You'll need to define or load 'model' before calling this function

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

'''def effective_rank(singular_values):
    sigma_max = np.max(singular_values)
    sigma_min = singular_values[-1] if singular_values[-1] > 0 else np.min(singular_values[singular_values > 0])
    # print(sigma_max, sigma_min)
    print(np.sqrt(sigma_max / sigma_min))
    print('----')
    return np.sqrt(sigma_max / sigma_min)'''

def effective_rank(singular_values):
    normalized_singular_values = singular_values / np.sum(singular_values)
    entropy = -np.sum(normalized_singular_values * np.log(normalized_singular_values))
    eff_rank = np.exp(entropy)
    return eff_rank

def plot_layer_effective_ranks(model, print_ranks=True):
    effective_ranks = []
    layer_names = []
    
    for name, param in model.named_parameters():
        if 'weight' in name:  # We are only interested in weight matrices
            weight_matrix = param.detach().cpu().numpy()
            singular_values = np.linalg.svd(weight_matrix, compute_uv=False)
            eff_rank = effective_rank(singular_values)
            effective_ranks.append(eff_rank)
            layer_names.append(name)

    if print_ranks:
        for layer_name, eff_rank in zip(layer_names, effective_ranks):
            print(f'{layer_name}: {eff_rank:.4f}')
    
    # Plotting
    plt.figure(figsize=(15, 5))
    plt.bar(layer_names, effective_ranks, color='green')
    plt.xlabel('Layer')
    plt.ylabel('Effective Rank')
    plt.title('Effective Rank of Weight Matrices for Each Layer')
    plt.grid(True)
    
    y_max = np.max(effective_ranks) + 1  # Get maximum rank and add 1 for better visualization
    y_min = np.min(effective_ranks) - 1  # Get minimum rank and subtract 1 for better visualization
    plt.yticks(np.arange(0, int(y_max)+2, step=2))  # Set yticks

    plt.show()

# Example usage
plot_layer_effective_ranks(model)  # Note: You'll need to define or load 'model' before calling this function
# Out:
# linear0.weight: 5.9787
# linear1.weight: 101.3271
# linear2.weight: 100.6868
# linear3.weight: 99.9056
# linear4.weight: 2.9768

# %% [markdown]
# ----

# %% [markdown]
# # Finetuning experiments

# %% [markdown]
# ## Baseline model: end2end with the same architecture as the preatining model

# %%
#relabeling 

mapping = {1: 0, 3: 1}

y_transfer_train_v1 = np.array([mapping[label] for label in y_transfer_train])
y_transfer_val_v1 = np.array([mapping[label] for label in y_transfer_val])
y_transfer_test_v1 = np.array([mapping[label] for label in y_transfer_test])

# %%
# Convert transfer training data to PyTorch tensors
X_transfer_train_tensor = torch.FloatTensor(X_transfer_train)
y_transfer_train_tensor = torch.LongTensor(y_transfer_train_v1)

# Convert trasnfer validation data to PyTorch tensors
X_transfer_val_tensor = torch.FloatTensor(X_transfer_val)
y_transfer_val_tensor = torch.LongTensor(y_transfer_val_v1)

# Convert trasnfer test data to PyTorch tensors
X_transfer_test_tensor = torch.FloatTensor(X_transfer_test)
y_transfer_test_tensor = torch.LongTensor(y_transfer_test_v1)

# Create DataLoaders for transfer datasets
train_dataset_transfer = TensorDataset(X_transfer_train_tensor, y_transfer_train_tensor)
val_dataset_transfer = TensorDataset(X_transfer_val_tensor, y_transfer_val_tensor)
test_dataset_transfer = TensorDataset(X_transfer_test_tensor, y_transfer_test_tensor)

train_loader_transfer = DataLoader(train_dataset_transfer, batch_size=32, shuffle=True)
val_loader_transfer = DataLoader(val_dataset_transfer, batch_size=32, shuffle=False)
test_loader_transfer = DataLoader(test_dataset_transfer, batch_size=32, shuffle=False)

# %%
# 2. Create a new model and copy weights from the original model, then adjust the final layer
new_n_classes = 2  # Number of classes in the new dataset
model_finetuning_baseline = generate_fc_dnn(input_dim, new_n_classes, params,gaussian_init=False, activation_function = nn.ReLU)

# 3. Fine-tune on the new data

dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer, test_loader=test_loader_transfer, val_loader=test_loader_transfer)

# Train and evaluate the new model on the new data
train_acc_new, test_acc_new, model_finetuning_baseline, _ = compute_training_acc_epochs(model_finetuning_baseline, dataset_namespace_new, params, debug=True)

print(f"Final Training Accuracy (New Data): {train_acc_new:.4f}")
print(f"Final Test Accuracy (New Data): {test_acc_new:.4f}")
# Out:
# Epoch: 0 	Training Accuracy: 50.81%
# Validation Accuracy: 49.59%
# Epoch: 1 	Training Accuracy: 50.81%
# Validation Accuracy: 49.59%
# val_acc: 0.49586776859504134, max_val_acc: 0.49586776859504134, no_improve_epochs: 1
# Epoch: 2 	Training Accuracy: 54.20%
# Validation Accuracy: 52.07%
# Epoch: 3 	Training Accuracy: 67.26%
# Validation Accuracy: 67.77%
# Epoch: 4 	Training Accuracy: 84.26%
# Validation Accuracy: 82.64%
# Epoch: 5 	Training Accuracy: 90.70%
# Validation Accuracy: 88.43%
# Epoch: 6 	Training Accuracy: 92.49%
# Validation Accuracy: 94.21%
# Epoch: 7 	Training Accuracy: 92.49%
# Validation Accuracy: 92.56%
# val_acc: 0.9256198347107438, max_val_acc: 0.9421487603305785, no_improve_epochs: 1
# Epoch: 8 	Training Accuracy: 97.85%
# Validation Accuracy: 97.52%
# Epoch: 9 	Training Accuracy: 98.03%
# Validation Accuracy: 97.52%
# val_acc: 0.9752066115702479, max_val_acc: 0.9752066115702479, no_improve_epochs: 1
# Epoch: 10 	Training Accuracy: 98.03%
# Validation Accuracy: 97.52%
# val_acc: 0.9752066115702479, max_val_acc: 0.9752066115702479, no_improve_epochs: 2
# Epoch: 11 	Training Accuracy: 98.75%
# Validation Accuracy: 99.17%
# Epoch: 12 	Training Accuracy: 99.64%
# Validation Accuracy: 100.00%
# Epoch: 13 	Training Accuracy: 99.82%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 1
# Epoch: 14 	Training Accuracy: 99.64%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 2
# Epoch: 15 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 3
# Epoch: 16 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 4
# Epoch: 17 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 5
# Epoch: 18 	Training Accuracy: 99.82%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 6
# Epoch: 19 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 7
# Epoch: 20 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 8
# Epoch: 21 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 9
# Epoch: 22 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 10
# Early stopping invoked.
# Final Training Accuracy (New Data): 1.0000
# Final Test Accuracy (New Data): 1.0000

# %%
# plot_decision_boundary(model_finetuning_baseline, X_transfer_train, y_transfer_train, n_classes=2)
# plot_decision_boundary(model_finetuning_baseline, X_transfer_val, y_transfer_val, n_classes=2)
# plot_decision_boundary(model_finetuning_baseline, X_transfer_test, y_transfer_test, n_classes=2)

# %%
eval(model_finetuning_baseline, device, test_loader_transfer, debug=True, classification_report_flag = True)
plot_layer_effective_ranks(model_finetuning_baseline)
# results, variances = compute_layer_variances_dense(model_finetuning_baseline, test_loader_transfer, device = 'cpu',cnn=False)
# plot_variances_by_layer_type(variances, results, cnn = False, ignore_final_layer=True, std_of_variance = True )
# Out:
# Average loss: 0.0138, Accuracy: 121.0/121 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00        61
#      Class 1       1.00      1.00      1.00        60
#
#     accuracy                           1.00       121
#    macro avg       1.00      1.00      1.00       121
# weighted avg       1.00      1.00      1.00       121
#
# linear0.weight: 5.9530
# linear1.weight: 102.4813
# linear2.weight: 101.8368
# linear3.weight: 101.3540
# linear4.weight: 1.9690

# %% [markdown]
# now with balanced classes

# %%
import numpy as np
import matplotlib.pyplot as plt

#percentages = np.linspace(0.1, 1.0, 10)  # from 10% to 100%
percentages = [0.005, 0.01, 0.015, 0.02, 0.03, 0.07,0.1]
seed_set = [10, 20, 30]
repeats = 3

params['lr'] = 0.1  
params['num_train'] = 50
params['early_stop_patience'] = 10

# Store results for each percentage
results = {}
results_train = {}
best_models = {}
data_loaders = {}

for perc in percentages:
    print(f"Percentage: {perc}")
    test_accuracies = []
    train_accurecies = []
    best_accuracy = 0.0
    for _ , temp_seed in enumerate(seed_set):
        print(f"Repeat: {_}, with seed {temp_seed} =========================")
        model_new = generate_fc_dnn(input_dim, new_n_classes, params, gaussian_init=False, activation_function = nn.ReLU)
        
        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset_balanced(train_loader_transfer, perc, seed=temp_seed)
        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = test_loader_transfer
        val_loader_transfer_reduced = val_loader_transfer
        
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)
        
        train_acc_new, test_acc_new, _, _ = compute_training_acc_epochs(model_new, dataset_namespace_new, params, debug=True, plot_boundary=False)
        
        test_accuracies.append(test_acc_new)
        train_accurecies.append(train_acc_new)

        print('eval on reduced train set')
        eval(model_new, device, train_loader_transfer_reduced, debug=True, classification_report_flag = True)
        print('eval on full test set')
        eval(model_new, device, test_loader_transfer_reduced, debug=True, classification_report_flag = True)
        # plot_decision_boundary_dataloader(model_new, train_loader_transfer_reduced, n_classes=2, percentage = perc, Seed = temp_seed)

        '''# Check if this model is the best-performing for this percentage
        if train_acc_new > best_accuracy:
            best_accuracy = train_acc_new
            best_models[perc] = model_new.state_dict()  # Save only the model's parameters (state_dict)\
         '''   
    
    results[perc] = test_accuracies
    results_train[perc] = train_accurecies

# Save the best models
# for perc in best_models:
#     torch.save(best_models[perc], f"best_model_{int(perc*100)}_percent.pth")

# Plot the results
means = [np.mean(results[perc]) for perc in percentages]
stds = [np.std(results[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Percentage: 0.005
# Repeat: 0, with seed 10 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 5 	Training Accuracy: 100.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 6 	Training Accuracy: 100.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 5
# Epoch: 7 	Training Accuracy: 100.00%
# Validation Accuracy: 90.00%
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.9, no_improve_epochs: 1
# Epoch: 9 	Training Accuracy: 100.00%
# Validation Accuracy: 55.00%
# val_acc: 0.55, max_val_acc: 0.9, no_improve_epochs: 2
# Epoch: 10 	Training Accuracy: 100.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.9, no_improve_epochs: 3
# Epoch: 11 	Training Accuracy: 100.00%
# Validation Accuracy: 55.00%
# val_acc: 0.55, max_val_acc: 0.9, no_improve_epochs: 4
# Epoch: 12 	Training Accuracy: 100.00%
# Validation Accuracy: 57.50%
# val_acc: 0.575, max_val_acc: 0.9, no_improve_epochs: 5
# Epoch: 13 	Training Accuracy: 100.00%
# Validation Accuracy: 60.00%
# val_acc: 0.6, max_val_acc: 0.9, no_improve_epochs: 6
# Epoch: 14 	Training Accuracy: 100.00%
# Validation Accuracy: 63.33%
# val_acc: 0.6333333333333333, max_val_acc: 0.9, no_improve_epochs: 7
# Epoch: 15 	Training Accuracy: 100.00%
# Validation Accuracy: 64.17%
# val_acc: 0.6416666666666667, max_val_acc: 0.9, no_improve_epochs: 8
# Epoch: 16 	Training Accuracy: 50.00%
# Validation Accuracy: 60.00%
# val_acc: 0.6, max_val_acc: 0.9, no_improve_epochs: 9
# Epoch: 17 	Training Accuracy: 50.00%
# Validation Accuracy: 55.83%
# val_acc: 0.5583333333333333, max_val_acc: 0.9, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.7639, Accuracy: 1.0/2 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      1.00      0.67         1
#      Class 1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
# eval on full test set
#
# Average loss: 155.6621, Accuracy: 70.0/121 (58%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.60      0.48      0.53        61
#      Class 1       0.56      0.68      0.62        60
#
#     accuracy                           0.58       121
#    macro avg       0.58      0.58      0.57       121
# weighted avg       0.58      0.58      0.57       121
#
# Repeat: 1, with seed 20 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 47.50%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 57.50%
# Epoch: 6 	Training Accuracy: 0.00%
# Validation Accuracy: 31.67%
# val_acc: 0.31666666666666665, max_val_acc: 0.575, no_improve_epochs: 1
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.575, no_improve_epochs: 2
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.575, no_improve_epochs: 3
# Epoch: 9 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.575, no_improve_epochs: 4
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.575, no_improve_epochs: 5
# Epoch: 11 	Training Accuracy: 100.00%
# Validation Accuracy: 62.50%
# Epoch: 12 	Training Accuracy: 50.00%
# Validation Accuracy: 65.00%
# Epoch: 13 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.65, no_improve_epochs: 1
# Epoch: 14 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.65, no_improve_epochs: 2
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 15 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.65, no_improve_epochs: 3
# Epoch: 16 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.65, no_improve_epochs: 4
# Epoch: 17 	Training Accuracy: 100.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.65, no_improve_epochs: 5
# Epoch: 18 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.65, no_improve_epochs: 6
# Epoch: 19 	Training Accuracy: 100.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.65, no_improve_epochs: 7
# Epoch: 20 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.65, no_improve_epochs: 8
# Epoch: 21 	Training Accuracy: 100.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.65, no_improve_epochs: 9
# Epoch: 22 	Training Accuracy: 100.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.65, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.1177, Accuracy: 2.0/2 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00         1
#      Class 1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
# eval on full test set
#
# Average loss: 437.5110, Accuracy: 66.0/121 (55%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.10      0.18        61
#      Class 1       0.52      1.00      0.69        60
#
#     accuracy                           0.55       121
#    macro avg       0.76      0.55      0.43       121
# weighted avg       0.76      0.55      0.43       121
#
# Repeat: 2, with seed 30 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 100.00%
# Validation Accuracy: 55.83%
# Epoch: 5 	Training Accuracy: 100.00%
# Validation Accuracy: 56.67%
# Epoch: 6 	Training Accuracy: 100.00%
# Validation Accuracy: 61.67%
# Epoch: 7 	Training Accuracy: 100.00%
# Validation Accuracy: 60.00%
# val_acc: 0.6, max_val_acc: 0.6166666666666667, no_improve_epochs: 1
# Epoch: 8 	Training Accuracy: 100.00%
# Validation Accuracy: 57.50%
# val_acc: 0.575, max_val_acc: 0.6166666666666667, no_improve_epochs: 2
# Epoch: 9 	Training Accuracy: 100.00%
# Validation Accuracy: 54.17%
# val_acc: 0.5416666666666666, max_val_acc: 0.6166666666666667, no_improve_epochs: 3
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.6166666666666667, no_improve_epochs: 4
# Epoch: 11 	Training Accuracy: 100.00%
# Validation Accuracy: 59.17%
# val_acc: 0.5916666666666667, max_val_acc: 0.6166666666666667, no_improve_epochs: 5
# Epoch: 12 	Training Accuracy: 100.00%
# Validation Accuracy: 55.83%
# val_acc: 0.5583333333333333, max_val_acc: 0.6166666666666667, no_improve_epochs: 6
# Epoch: 13 	Training Accuracy: 100.00%
# Validation Accuracy: 55.00%
# val_acc: 0.55, max_val_acc: 0.6166666666666667, no_improve_epochs: 7
# Epoch: 14 	Training Accuracy: 100.00%
# Validation Accuracy: 51.67%
# val_acc: 0.5166666666666667, max_val_acc: 0.6166666666666667, no_improve_epochs: 8
# Epoch: 15 	Training Accuracy: 100.00%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.6166666666666667, no_improve_epochs: 9
# Epoch: 16 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.6166666666666667, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 55.8075, Accuracy: 1.0/2 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.00      0.00      0.00         1
#      Class 1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
# eval on full test set
#
# Average loss: 4420.0872, Accuracy: 62.0/121 (51%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.03      0.06        61
#      Class 1       0.50      1.00      0.67        60
#
#     accuracy                           0.51       121
#    macro avg       0.75      0.52      0.37       121
# weighted avg       0.75      0.51      0.36       121
#
# Percentage: 0.01
# Repeat: 0, with seed 10 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 75.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 6 	Training Accuracy: 75.00%
# Validation Accuracy: 54.17%
# Epoch: 7 	Training Accuracy: 75.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.5416666666666666, no_improve_epochs: 1
# Epoch: 8 	Training Accuracy: 75.00%
# Validation Accuracy: 49.17%
# val_acc: 0.49166666666666664, max_val_acc: 0.5416666666666666, no_improve_epochs: 2
# Epoch: 9 	Training Accuracy: 75.00%
# Validation Accuracy: 49.17%
# val_acc: 0.49166666666666664, max_val_acc: 0.5416666666666666, no_improve_epochs: 3
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 48.33%
# val_acc: 0.48333333333333334, max_val_acc: 0.5416666666666666, no_improve_epochs: 4
# Epoch: 11 	Training Accuracy: 50.00%
# Validation Accuracy: 49.17%
# val_acc: 0.49166666666666664, max_val_acc: 0.5416666666666666, no_improve_epochs: 5
# Epoch: 12 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5416666666666666, no_improve_epochs: 6
# Epoch: 13 	Training Accuracy: 50.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.5416666666666666, no_improve_epochs: 7
# Epoch: 14 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5416666666666666, no_improve_epochs: 8
# Epoch: 15 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5416666666666666, no_improve_epochs: 9
# Epoch: 16 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5416666666666666, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.8037, Accuracy: 2.0/4 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.00      0.00      0.00         2
#      Class 1       0.50      1.00      0.67         2
#
#     accuracy                           0.50         4
#    macro avg       0.25      0.50      0.33         4
# weighted avg       0.25      0.50      0.33         4
#
# eval on full test set
#
# Average loss: 0.9679, Accuracy: 60.0/121 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.00      0.00      0.00        61
#      Class 1       0.50      1.00      0.66        60
#
#     accuracy                           0.50       121
#    macro avg       0.25      0.50      0.33       121
# weighted avg       0.25      0.50      0.33       121
#
# Repeat: 1, with seed 20 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 75.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 6 	Training Accuracy: 100.00%
# Validation Accuracy: 70.83%
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.7083333333333334, no_improve_epochs: 1
# Epoch: 8 	Training Accuracy: 75.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.7083333333333334, no_improve_epochs: 2
# Epoch: 9 	Training Accuracy: 75.00%
# Validation Accuracy: 51.67%
# val_acc: 0.5166666666666667, max_val_acc: 0.7083333333333334, no_improve_epochs: 3
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.7083333333333334, no_improve_epochs: 4
# Epoch: 11 	Training Accuracy: 75.00%
# Validation Accuracy: 51.67%
# val_acc: 0.5166666666666667, max_val_acc: 0.7083333333333334, no_improve_epochs: 5
# Epoch: 12 	Training Accuracy: 75.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.7083333333333334, no_improve_epochs: 6
# Epoch: 13 	Training Accuracy: 75.00%
# Validation Accuracy: 60.00%
# val_acc: 0.6, max_val_acc: 0.7083333333333334, no_improve_epochs: 7
# Epoch: 14 	Training Accuracy: 75.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.7083333333333334, no_improve_epochs: 8
# Epoch: 15 	Training Accuracy: 75.00%
# Validation Accuracy: 45.83%
# val_acc: 0.4583333333333333, max_val_acc: 0.7083333333333334, no_improve_epochs: 9
# Epoch: 16 	Training Accuracy: 75.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.7083333333333334, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.4775, Accuracy: 3.0/4 (75%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.50      0.67         2
#      Class 1       0.67      1.00      0.80         2
#
#     accuracy                           0.75         4
#    macro avg       0.83      0.75      0.73         4
# weighted avg       0.83      0.75      0.73         4
#
# eval on full test set
#
# Average loss: 2.9794, Accuracy: 57.0/121 (47%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.46      0.28      0.35        61
#      Class 1       0.48      0.67      0.56        60
#
#     accuracy                           0.47       121
#    macro avg       0.47      0.47      0.45       121
# weighted avg       0.47      0.47      0.45       121
#
# Repeat: 2, with seed 30 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 5 	Training Accuracy: 75.00%
# Validation Accuracy: 54.17%
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.5416666666666666, no_improve_epochs: 1
# Epoch: 7 	Training Accuracy: 100.00%
# Validation Accuracy: 65.83%
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 60.83%
# val_acc: 0.6083333333333333, max_val_acc: 0.6583333333333333, no_improve_epochs: 1
# Epoch: 9 	Training Accuracy: 75.00%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.6583333333333333, no_improve_epochs: 2
# Epoch: 10 	Training Accuracy: 100.00%
# Validation Accuracy: 63.33%
# val_acc: 0.6333333333333333, max_val_acc: 0.6583333333333333, no_improve_epochs: 3
# Epoch: 11 	Training Accuracy: 100.00%
# Validation Accuracy: 60.83%
# val_acc: 0.6083333333333333, max_val_acc: 0.6583333333333333, no_improve_epochs: 4
# Epoch: 12 	Training Accuracy: 100.00%
# Validation Accuracy: 55.00%
# val_acc: 0.55, max_val_acc: 0.6583333333333333, no_improve_epochs: 5
# Epoch: 13 	Training Accuracy: 75.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.6583333333333333, no_improve_epochs: 6
# Epoch: 14 	Training Accuracy: 100.00%
# Validation Accuracy: 63.33%
# val_acc: 0.6333333333333333, max_val_acc: 0.6583333333333333, no_improve_epochs: 7
# Epoch: 15 	Training Accuracy: 100.00%
# Validation Accuracy: 65.00%
# val_acc: 0.65, max_val_acc: 0.6583333333333333, no_improve_epochs: 8
# Epoch: 16 	Training Accuracy: 100.00%
# Validation Accuracy: 55.83%
# val_acc: 0.5583333333333333, max_val_acc: 0.6583333333333333, no_improve_epochs: 9
# Epoch: 17 	Training Accuracy: 100.00%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.6583333333333333, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.1542, Accuracy: 4.0/4 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00         2
#      Class 1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
# eval on full test set
#
# Average loss: 63.0542, Accuracy: 69.0/121 (57%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.15      0.26        61
#      Class 1       0.54      1.00      0.70        60
#
#     accuracy                           0.57       121
#    macro avg       0.77      0.57      0.48       121
# weighted avg       0.77      0.57      0.48       121
#
# Percentage: 0.015
# Repeat: 0, with seed 10 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 62.50%
# Validation Accuracy: 55.83%
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5583333333333333, no_improve_epochs: 1
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5583333333333333, no_improve_epochs: 2
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5583333333333333, no_improve_epochs: 3
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 41.67%
# val_acc: 0.4166666666666667, max_val_acc: 0.5583333333333333, no_improve_epochs: 4
# Epoch: 9 	Training Accuracy: 50.00%
# Validation Accuracy: 48.33%
# val_acc: 0.48333333333333334, max_val_acc: 0.5583333333333333, no_improve_epochs: 5
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 45.83%
# val_acc: 0.4583333333333333, max_val_acc: 0.5583333333333333, no_improve_epochs: 6
# Epoch: 11 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5583333333333333, no_improve_epochs: 7
# Epoch: 12 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5583333333333333, no_improve_epochs: 8
# Epoch: 13 	Training Accuracy: 50.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.5583333333333333, no_improve_epochs: 9
# Epoch: 14 	Training Accuracy: 50.00%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.5583333333333333, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.7008, Accuracy: 4.0/8 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      1.00      0.67         4
#      Class 1       0.00      0.00      0.00         4
#
#     accuracy                           0.50         8
#    macro avg       0.25      0.50      0.33         8
# weighted avg       0.25      0.50      0.33         8
#
# eval on full test set
#
# Average loss: 0.7163, Accuracy: 55.0/121 (45%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.48      0.90      0.62        61
#      Class 1       0.00      0.00      0.00        60
#
#     accuracy                           0.45       121
#    macro avg       0.24      0.45      0.31       121
# weighted avg       0.24      0.45      0.32       121
#
# Repeat: 1, with seed 20 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 62.50%
# Validation Accuracy: 54.17%
# Epoch: 3 	Training Accuracy: 37.50%
# Validation Accuracy: 44.17%
# val_acc: 0.44166666666666665, max_val_acc: 0.5416666666666666, no_improve_epochs: 1
# Epoch: 4 	Training Accuracy: 75.00%
# Validation Accuracy: 65.83%
# Epoch: 5 	Training Accuracy: 100.00%
# Validation Accuracy: 96.67%
# Epoch: 6 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.9916666666666667, no_improve_epochs: 1
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 2
# Epoch: 9 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 3
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 4
# Epoch: 11 	Training Accuracy: 75.00%
# Validation Accuracy: 64.17%
# val_acc: 0.6416666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 5
# Epoch: 12 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.9916666666666667, no_improve_epochs: 6
# Epoch: 13 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 7
# Epoch: 14 	Training Accuracy: 50.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.9916666666666667, no_improve_epochs: 8
# Epoch: 15 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.9916666666666667, no_improve_epochs: 9
# Epoch: 16 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.9916666666666667, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 1.4642, Accuracy: 4.0/8 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      1.00      0.67         4
#      Class 1       0.00      0.00      0.00         4
#
#     accuracy                           0.50         8
#    macro avg       0.25      0.50      0.33         8
# weighted avg       0.25      0.50      0.33         8
#
# eval on full test set
#
# Average loss: 1.2013, Accuracy: 58.0/121 (48%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.49      0.92      0.64        61
#      Class 1       0.29      0.03      0.06        60
#
#     accuracy                           0.48       121
#    macro avg       0.39      0.48      0.35       121
# weighted avg       0.39      0.48      0.35       121
#
# Repeat: 2, with seed 30 =========================
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 5
# Epoch: 6 	Training Accuracy: 37.50%
# Validation Accuracy: 70.00%
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 48.33%
# val_acc: 0.48333333333333334, max_val_acc: 0.7, no_improve_epochs: 1
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.7, no_improve_epochs: 2
# Epoch: 9 	Training Accuracy: 100.00%
# Validation Accuracy: 85.83%
# Epoch: 10 	Training Accuracy: 87.50%
# Validation Accuracy: 60.83%
# val_acc: 0.6083333333333333, max_val_acc: 0.8583333333333333, no_improve_epochs: 1
# Epoch: 11 	Training Accuracy: 87.50%
# Validation Accuracy: 63.33%
# val_acc: 0.6333333333333333, max_val_acc: 0.8583333333333333, no_improve_epochs: 2
# Epoch: 12 	Training Accuracy: 100.00%
# Validation Accuracy: 69.17%
# val_acc: 0.6916666666666667, max_val_acc: 0.8583333333333333, no_improve_epochs: 3
# Epoch: 13 	Training Accuracy: 100.00%
# Validation Accuracy: 74.17%
# val_acc: 0.7416666666666667, max_val_acc: 0.8583333333333333, no_improve_epochs: 4
# Epoch: 14 	Training Accuracy: 100.00%
# Validation Accuracy: 70.83%
# val_acc: 0.7083333333333334, max_val_acc: 0.8583333333333333, no_improve_epochs: 5
# Epoch: 15 	Training Accuracy: 100.00%
# Validation Accuracy: 65.83%
# val_acc: 0.6583333333333333, max_val_acc: 0.8583333333333333, no_improve_epochs: 6
# Epoch: 16 	Training Accuracy: 100.00%
# Validation Accuracy: 60.83%
# val_acc: 0.6083333333333333, max_val_acc: 0.8583333333333333, no_improve_epochs: 7
# Epoch: 17 	Training Accuracy: 100.00%
# Validation Accuracy: 65.00%
# val_acc: 0.65, max_val_acc: 0.8583333333333333, no_improve_epochs: 8
# Epoch: 18 	Training Accuracy: 100.00%
# Validation Accuracy: 60.83%
# val_acc: 0.6083333333333333, max_val_acc: 0.8583333333333333, no_improve_epochs: 9
# Epoch: 19 	Training Accuracy: 100.00%
# Validation Accuracy: 62.50%
# val_acc: 0.625, max_val_acc: 0.8583333333333333, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0000, Accuracy: 8.0/8 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00         4
#      Class 1       1.00      1.00      1.00         4
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
# eval on full test set
#
# Average loss: 38.7418, Accuracy: 82.0/121 (68%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.76      0.52      0.62        61
#      Class 1       0.63      0.83      0.72        60
#
#     accuracy                           0.68       121
#    macro avg       0.70      0.68      0.67       121
# weighted avg       0.70      0.68      0.67       121
#
# Percentage: 0.02
# Repeat: 0, with seed 10 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 5 	Training Accuracy: 40.00%
# Validation Accuracy: 49.17%
# val_acc: 0.49166666666666664, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 6 	Training Accuracy: 40.00%
# Validation Accuracy: 33.33%
# val_acc: 0.3333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 5
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 49.17%
# val_acc: 0.49166666666666664, max_val_acc: 0.5333333333333333, no_improve_epochs: 6
# Epoch: 8 	Training Accuracy: 90.00%
# Validation Accuracy: 75.83%
# Epoch: 9 	Training Accuracy: 80.00%
# Validation Accuracy: 80.00%
# Epoch: 10 	Training Accuracy: 60.00%
# Validation Accuracy: 69.17%
# val_acc: 0.6916666666666667, max_val_acc: 0.8, no_improve_epochs: 1
# Epoch: 11 	Training Accuracy: 100.00%
# Validation Accuracy: 91.67%
# Epoch: 12 	Training Accuracy: 60.00%
# Validation Accuracy: 73.33%
# val_acc: 0.7333333333333333, max_val_acc: 0.9166666666666666, no_improve_epochs: 1
# Epoch: 13 	Training Accuracy: 90.00%
# Validation Accuracy: 70.83%
# val_acc: 0.7083333333333334, max_val_acc: 0.9166666666666666, no_improve_epochs: 2
# Epoch: 14 	Training Accuracy: 60.00%
# Validation Accuracy: 64.17%
# val_acc: 0.6416666666666667, max_val_acc: 0.9166666666666666, no_improve_epochs: 3
# Epoch: 15 	Training Accuracy: 90.00%
# Validation Accuracy: 84.17%
# val_acc: 0.8416666666666667, max_val_acc: 0.9166666666666666, no_improve_epochs: 4
# Epoch: 16 	Training Accuracy: 80.00%
# Validation Accuracy: 80.83%
# val_acc: 0.8083333333333333, max_val_acc: 0.9166666666666666, no_improve_epochs: 5
# Epoch: 17 	Training Accuracy: 80.00%
# Validation Accuracy: 74.17%
# val_acc: 0.7416666666666667, max_val_acc: 0.9166666666666666, no_improve_epochs: 6
# Epoch: 18 	Training Accuracy: 100.00%
# Validation Accuracy: 86.67%
# val_acc: 0.8666666666666667, max_val_acc: 0.9166666666666666, no_improve_epochs: 7
# Epoch: 19 	Training Accuracy: 100.00%
# Validation Accuracy: 85.83%
# val_acc: 0.8583333333333333, max_val_acc: 0.9166666666666666, no_improve_epochs: 8
# Epoch: 20 	Training Accuracy: 100.00%
# Validation Accuracy: 84.17%
# val_acc: 0.8416666666666667, max_val_acc: 0.9166666666666666, no_improve_epochs: 9
# Epoch: 21 	Training Accuracy: 100.00%
# Validation Accuracy: 82.50%
# val_acc: 0.825, max_val_acc: 0.9166666666666666, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0379, Accuracy: 10.0/10 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00         5
#      Class 1       1.00      1.00      1.00         5
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10
#
# eval on full test set
#
# Average loss: 1.4112, Accuracy: 98.0/121 (81%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.74      0.97      0.84        61
#      Class 1       0.95      0.65      0.77        60
#
#     accuracy                           0.81       121
#    macro avg       0.84      0.81      0.80       121
# weighted avg       0.84      0.81      0.80       121
#
# Repeat: 1, with seed 20 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 49.17%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.49166666666666664, no_improve_epochs: 1
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.49166666666666664, no_improve_epochs: 2
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.49166666666666664, no_improve_epochs: 3
# Epoch: 4 	Training Accuracy: 70.00%
# Validation Accuracy: 77.50%
# Epoch: 5 	Training Accuracy: 80.00%
# Validation Accuracy: 45.83%
# val_acc: 0.4583333333333333, max_val_acc: 0.775, no_improve_epochs: 1
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.775, no_improve_epochs: 2
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.775, no_improve_epochs: 3
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.775, no_improve_epochs: 4
# Epoch: 9 	Training Accuracy: 70.00%
# Validation Accuracy: 51.67%
# val_acc: 0.5166666666666667, max_val_acc: 0.775, no_improve_epochs: 5
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.775, no_improve_epochs: 6
# Epoch: 11 	Training Accuracy: 50.00%
# Validation Accuracy: 55.83%
# val_acc: 0.5583333333333333, max_val_acc: 0.775, no_improve_epochs: 7
# Epoch: 12 	Training Accuracy: 70.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.775, no_improve_epochs: 8
# Epoch: 13 	Training Accuracy: 70.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.775, no_improve_epochs: 9
# Epoch: 14 	Training Accuracy: 80.00%
# Validation Accuracy: 56.67%
# val_acc: 0.5666666666666667, max_val_acc: 0.775, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.4324, Accuracy: 8.0/10 (80%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.60      0.75         5
#      Class 1       0.71      1.00      0.83         5
#
#     accuracy                           0.80        10
#    macro avg       0.86      0.80      0.79        10
# weighted avg       0.86      0.80      0.79        10
#
# eval on full test set
#
# Average loss: 4.5176, Accuracy: 76.0/121 (63%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.70      0.46      0.55        61
#      Class 1       0.59      0.80      0.68        60
#
#     accuracy                           0.63       121
#    macro avg       0.65      0.63      0.62       121
# weighted avg       0.65      0.63      0.62       121
#
# Repeat: 2, with seed 30 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 100.00%
# Validation Accuracy: 76.67%
# Epoch: 5 	Training Accuracy: 60.00%
# Validation Accuracy: 64.17%
# val_acc: 0.6416666666666667, max_val_acc: 0.7666666666666667, no_improve_epochs: 1
# Epoch: 6 	Training Accuracy: 40.00%
# Validation Accuracy: 43.33%
# val_acc: 0.43333333333333335, max_val_acc: 0.7666666666666667, no_improve_epochs: 2
# Epoch: 7 	Training Accuracy: 80.00%
# Validation Accuracy: 67.50%
# val_acc: 0.675, max_val_acc: 0.7666666666666667, no_improve_epochs: 3
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.7666666666666667, no_improve_epochs: 4
# Epoch: 9 	Training Accuracy: 90.00%
# Validation Accuracy: 75.00%
# val_acc: 0.75, max_val_acc: 0.7666666666666667, no_improve_epochs: 5
# Epoch: 10 	Training Accuracy: 80.00%
# Validation Accuracy: 56.67%
# val_acc: 0.5666666666666667, max_val_acc: 0.7666666666666667, no_improve_epochs: 6
# Epoch: 11 	Training Accuracy: 80.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.7666666666666667, no_improve_epochs: 7
# Epoch: 12 	Training Accuracy: 60.00%
# Validation Accuracy: 51.67%
# val_acc: 0.5166666666666667, max_val_acc: 0.7666666666666667, no_improve_epochs: 8
# Epoch: 13 	Training Accuracy: 60.00%
# Validation Accuracy: 58.33%
# val_acc: 0.5833333333333334, max_val_acc: 0.7666666666666667, no_improve_epochs: 9
# Epoch: 14 	Training Accuracy: 60.00%
# Validation Accuracy: 60.83%
# val_acc: 0.6083333333333333, max_val_acc: 0.7666666666666667, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.6607, Accuracy: 6.0/10 (60%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.20      0.33         5
#      Class 1       0.56      1.00      0.71         5
#
#     accuracy                           0.60        10
#    macro avg       0.78      0.60      0.52        10
# weighted avg       0.78      0.60      0.52        10
#
# eval on full test set
#
# Average loss: 1.7212, Accuracy: 72.0/121 (60%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.25      0.38        61
#      Class 1       0.55      0.95      0.70        60
#
#     accuracy                           0.60       121
#    macro avg       0.69      0.60      0.54       121
# weighted avg       0.69      0.60      0.54       121
#
# Percentage: 0.03
# Repeat: 0, with seed 10 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 56.25%
# Validation Accuracy: 57.50%
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.575, no_improve_epochs: 1
# Epoch: 6 	Training Accuracy: 56.25%
# Validation Accuracy: 54.17%
# val_acc: 0.5416666666666666, max_val_acc: 0.575, no_improve_epochs: 2
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.575, no_improve_epochs: 3
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.575, no_improve_epochs: 4
# Epoch: 9 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.575, no_improve_epochs: 5
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 49.17%
# val_acc: 0.49166666666666664, max_val_acc: 0.575, no_improve_epochs: 6
# Epoch: 11 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.575, no_improve_epochs: 7
# Epoch: 12 	Training Accuracy: 50.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.575, no_improve_epochs: 8
# Epoch: 13 	Training Accuracy: 50.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.575, no_improve_epochs: 9
# Epoch: 14 	Training Accuracy: 50.00%
# Validation Accuracy: 45.00%
# val_acc: 0.45, max_val_acc: 0.575, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.6932, Accuracy: 8.0/16 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      1.00      0.67         8
#      Class 1       0.00      0.00      0.00         8
#
#     accuracy                           0.50        16
#    macro avg       0.25      0.50      0.33        16
# weighted avg       0.25      0.50      0.33        16
#
# eval on full test set
#
# Average loss: 0.6881, Accuracy: 57.0/121 (47%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.49      0.93      0.64        61
#      Class 1       0.00      0.00      0.00        60
#
#     accuracy                           0.47       121
#    macro avg       0.24      0.47      0.32       121
# weighted avg       0.25      0.47      0.32       121
#
# Repeat: 1, with seed 20 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 62.50%
# Validation Accuracy: 48.33%
# val_acc: 0.48333333333333334, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 50.00%
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 15 	Training Accuracy: 96.30%
# Validation Accuracy: 98.33%
# val_acc: 0.9833333333333333, max_val_acc: 0.9916666666666667, no_improve_epochs: 1
# Epoch: 16 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 2
# Epoch: 17 	Training Accuracy: 94.44%
# Validation Accuracy: 95.00%
# val_acc: 0.95, max_val_acc: 0.9916666666666667, no_improve_epochs: 3
# Epoch: 18 	Training Accuracy: 98.15%
# Validation Accuracy: 97.50%
# val_acc: 0.975, max_val_acc: 0.9916666666666667, no_improve_epochs: 4
# Epoch: 19 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# Epoch: 20 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 1
# Epoch: 21 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 2
# Epoch: 22 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 3
# Epoch: 23 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 4
# Epoch: 24 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 5
# Epoch: 25 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 6
# Epoch: 26 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 7
# Epoch: 27 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 8
# Epoch: 28 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 9
# Epoch: 29 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0023, Accuracy: 54.0/54 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00        27
#      Class 1       1.00      1.00      1.00        27
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54
#
# eval on full test set
#
# Average loss: 0.0027, Accuracy: 121.0/121 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00        61
#      Class 1       1.00      1.00      1.00        60
#
#     accuracy                           1.00       121
#    macro avg       1.00      1.00      1.00       121
# weighted avg       1.00      1.00      1.00       121
#
# Repeat: 1, with seed 20 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 1 	Training Accuracy: 44.44%
# Validation Accuracy: 43.33%
# val_acc: 0.43333333333333335, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 5
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 6
# Epoch: 7 	Training Accuracy: 48.15%
# Validation Accuracy: 55.00%
# Epoch: 8 	Training Accuracy: 42.59%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.55, no_improve_epochs: 1
# Epoch: 9 	Training Accuracy: 46.30%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.55, no_improve_epochs: 2
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.55, no_improve_epochs: 3
# Epoch: 11 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.55, no_improve_epochs: 4
# Epoch: 12 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.55, no_improve_epochs: 5
# Epoch: 13 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.55, no_improve_epochs: 6
# Epoch: 14 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.55, no_improve_epochs: 7
# Epoch: 15 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.55, no_improve_epochs: 8
# Epoch: 16 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.55, no_improve_epochs: 9
# Epoch: 17 	Training Accuracy: 59.26%
# Validation Accuracy: 55.83%
# Epoch: 18 	Training Accuracy: 59.26%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.5583333333333333, no_improve_epochs: 1
# Epoch: 19 	Training Accuracy: 59.26%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.5583333333333333, no_improve_epochs: 2
# Epoch: 20 	Training Accuracy: 59.26%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.5583333333333333, no_improve_epochs: 3
# Epoch: 21 	Training Accuracy: 59.26%
# Validation Accuracy: 55.00%
# val_acc: 0.55, max_val_acc: 0.5583333333333333, no_improve_epochs: 4
# Epoch: 22 	Training Accuracy: 59.26%
# Validation Accuracy: 63.33%
# Epoch: 23 	Training Accuracy: 61.11%
# Validation Accuracy: 65.83%
# Epoch: 24 	Training Accuracy: 83.33%
# Validation Accuracy: 94.17%
# Epoch: 25 	Training Accuracy: 83.33%
# Validation Accuracy: 94.17%
# val_acc: 0.9416666666666667, max_val_acc: 0.9416666666666667, no_improve_epochs: 1
# Epoch: 26 	Training Accuracy: 57.41%
# Validation Accuracy: 48.33%
# val_acc: 0.48333333333333334, max_val_acc: 0.9416666666666667, no_improve_epochs: 2
# Epoch: 27 	Training Accuracy: 51.85%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.9416666666666667, no_improve_epochs: 3
# Epoch: 28 	Training Accuracy: 51.85%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.9416666666666667, no_improve_epochs: 4
# Epoch: 29 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.9416666666666667, no_improve_epochs: 5
# Epoch: 30 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.9416666666666667, no_improve_epochs: 6
# Epoch: 31 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.9416666666666667, no_improve_epochs: 7
# Epoch: 32 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.9416666666666667, no_improve_epochs: 8
# Epoch: 33 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.9416666666666667, no_improve_epochs: 9
# Epoch: 34 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.9416666666666667, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.6931, Accuracy: 27.0/54 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      1.00      0.67        27
#      Class 1       0.00      0.00      0.00        27
#
#     accuracy                           0.50        54
#    macro avg       0.25      0.50      0.33        54
# weighted avg       0.25      0.50      0.33        54
#
# eval on full test set
#
# Average loss: 0.6931, Accuracy: 61.0/121 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      1.00      0.67        61
#      Class 1       0.00      0.00      0.00        60
#
#     accuracy                           0.50       121
#    macro avg       0.25      0.50      0.34       121
# weighted avg       0.25      0.50      0.34       121
#
# Repeat: 2, with seed 30 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.4666666666666667, no_improve_epochs: 1
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.4666666666666667, no_improve_epochs: 2
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 4 	Training Accuracy: 94.44%
# Validation Accuracy: 95.83%
# Epoch: 5 	Training Accuracy: 85.19%
# Validation Accuracy: 90.00%
# val_acc: 0.9, max_val_acc: 0.9583333333333334, no_improve_epochs: 1
# Epoch: 6 	Training Accuracy: 96.30%
# Validation Accuracy: 97.50%
# Epoch: 7 	Training Accuracy: 94.44%
# Validation Accuracy: 90.00%
# val_acc: 0.9, max_val_acc: 0.975, no_improve_epochs: 1
# Epoch: 8 	Training Accuracy: 87.04%
# Validation Accuracy: 68.33%
# val_acc: 0.6833333333333333, max_val_acc: 0.975, no_improve_epochs: 2
# Epoch: 9 	Training Accuracy: 96.30%
# Validation Accuracy: 95.83%
# val_acc: 0.9583333333333334, max_val_acc: 0.975, no_improve_epochs: 3
# Epoch: 10 	Training Accuracy: 64.81%
# Validation Accuracy: 70.00%
# val_acc: 0.7, max_val_acc: 0.975, no_improve_epochs: 4
# Epoch: 11 	Training Accuracy: 94.44%
# Validation Accuracy: 92.50%
# val_acc: 0.925, max_val_acc: 0.975, no_improve_epochs: 5
# Epoch: 12 	Training Accuracy: 88.89%
# Validation Accuracy: 73.33%
# val_acc: 0.7333333333333333, max_val_acc: 0.975, no_improve_epochs: 6
# Epoch: 13 	Training Accuracy: 96.30%
# Validation Accuracy: 90.83%
# val_acc: 0.9083333333333333, max_val_acc: 0.975, no_improve_epochs: 7
# Epoch: 14 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# Epoch: 15 	Training Accuracy: 94.44%
# Validation Accuracy: 95.00%
# val_acc: 0.95, max_val_acc: 0.9916666666666667, no_improve_epochs: 1
# Epoch: 16 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# Epoch: 17 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 1
# Epoch: 18 	Training Accuracy: 96.30%
# Validation Accuracy: 93.33%
# val_acc: 0.9333333333333333, max_val_acc: 1.0, no_improve_epochs: 2
# Epoch: 19 	Training Accuracy: 96.30%
# Validation Accuracy: 94.17%
# val_acc: 0.9416666666666667, max_val_acc: 1.0, no_improve_epochs: 3
# Epoch: 20 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 4
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 21 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 5
# Epoch: 22 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 6
# Epoch: 23 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 7
# Epoch: 24 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 8
# Epoch: 25 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 9
# Epoch: 26 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0000, Accuracy: 54.0/54 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00        27
#      Class 1       1.00      1.00      1.00        27
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54
#
# eval on full test set
#
# Average loss: 0.0000, Accuracy: 121.0/121 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00        61
#      Class 1       1.00      1.00      1.00        60
#
#     accuracy                           1.00       121
#    macro avg       1.00      1.00      1.00       121
# weighted avg       1.00      1.00      1.00       121

# %% [markdown]
# ## Only heads and data for new classes

# %% [markdown]
# now with balanced classes

# %%
import numpy as np
import matplotlib.pyplot as plt

#percentages = np.linspace(0.1, 1.0, 10)  # from 10% to 100%
percentages = [0.005, 0.01, 0.015, 0.02, 0.03, 0.07,0.1]
seed_set = [10, 20, 30]
repeats = 3

params['lr'] = 0.1  
params['num_train'] = 50
params['early_stop_patience'] = 10

# Store results for each percentage
results = {}
results_train = {}
best_models = {}
data_loaders = {}

for perc in percentages:
    print(f"Percentage: {perc}")
    test_accuracies = []
    train_accurecies = []
    best_accuracy = 0.0
    for _ , temp_seed in enumerate(seed_set):
        print(f"Repeat: {_}, with seed {temp_seed} =========================")
        model_new = generate_fc_dnn(input_dim, new_n_classes, params, gaussian_init=False, activation_function = nn.ReLU)

        # Copy weights
        for name, param in model.named_parameters():
            if "linear" + str(depth-1) not in name:
                model_new._parameters[name] = param
        
        # Reduce datasets
        train_loader_transfer_reduced = reduce_dataset_balanced(train_loader_transfer, perc, seed=temp_seed)
        if _ == 0:
            data_loaders[perc] = train_loader_transfer_reduced
        test_loader_transfer_reduced = test_loader_transfer
        val_loader_transfer_reduced = val_loader_transfer
        
        dataset_namespace_new = SimpleNamespace(train_loader=train_loader_transfer_reduced, test_loader=test_loader_transfer_reduced, val_loader=val_loader_transfer_reduced)
        
        train_acc_new, test_acc_new, _, _ = compute_training_acc_epochs(model_new, dataset_namespace_new, params, debug=True, plot_boundary=False)
        
        test_accuracies.append(test_acc_new)
        train_accurecies.append(train_acc_new)

        print('eval on reduced train set')
        eval(model_new, device, train_loader_transfer_reduced, debug=True, classification_report_flag = True)
        print('eval on full test set')
        eval(model_new, device, test_loader_transfer_reduced, debug=True, classification_report_flag = True)
        # plot_decision_boundary_dataloader(model_new, train_loader_transfer_reduced, n_classes=2, percentage = perc, Seed = temp_seed)

        '''# Check if this model is the best-performing for this percentage
        if train_acc_new > best_accuracy:
            best_accuracy = train_acc_new
            best_models[perc] = model_new.state_dict()  # Save only the model's parameters (state_dict)\
         '''   
    
    results[perc] = test_accuracies
    results_train[perc] = train_accurecies

# Save the best models
# for perc in best_models:
#     torch.save(best_models[perc], f"best_model_{int(perc*100)}_percent.pth")

# Plot the results
means = [np.mean(results[perc]) for perc in percentages]
stds = [np.std(results[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Test Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Test Accuracy")
plt.title("Test Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()

#plot the training accuracies
means = [np.mean(results_train[perc]) for perc in percentages]
stds = [np.std(results_train[perc]) for perc in percentages]
plt.errorbar(percentages, means, yerr=stds, fmt='-o', capsize=5, label="Train Accuracies")
plt.fill_between(percentages, np.subtract(means, stds), np.add(means, stds), color='b', alpha=0.1)

plt.xlabel("Percentage of Data")
plt.ylabel("Train Accuracy")
plt.title("Train Accuracy vs Percentage of Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Percentage: 0.005
# Repeat: 0, with seed 10 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 100.00%
# Validation Accuracy: 54.17%
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.5416666666666666, no_improve_epochs: 1
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.5416666666666666, no_improve_epochs: 2
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5416666666666666, no_improve_epochs: 3
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5416666666666666, no_improve_epochs: 4
# Epoch: 7 	Training Accuracy: 100.00%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.5416666666666666, no_improve_epochs: 5
# Epoch: 8 	Training Accuracy: 100.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5416666666666666, no_improve_epochs: 6
# Epoch: 9 	Training Accuracy: 100.00%
# Validation Accuracy: 57.50%
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 58.33%
# Epoch: 11 	Training Accuracy: 100.00%
# Validation Accuracy: 56.67%
# val_acc: 0.5666666666666667, max_val_acc: 0.5833333333333334, no_improve_epochs: 1
# Epoch: 12 	Training Accuracy: 100.00%
# Validation Accuracy: 56.67%
# val_acc: 0.5666666666666667, max_val_acc: 0.5833333333333334, no_improve_epochs: 2
# Epoch: 13 	Training Accuracy: 100.00%
# Validation Accuracy: 54.17%
# val_acc: 0.5416666666666666, max_val_acc: 0.5833333333333334, no_improve_epochs: 3
# Epoch: 14 	Training Accuracy: 100.00%
# Validation Accuracy: 54.17%
# val_acc: 0.5416666666666666, max_val_acc: 0.5833333333333334, no_improve_epochs: 4
# Epoch: 15 	Training Accuracy: 100.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5833333333333334, no_improve_epochs: 5
# Epoch: 16 	Training Accuracy: 100.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5833333333333334, no_improve_epochs: 6
# Epoch: 17 	Training Accuracy: 100.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5833333333333334, no_improve_epochs: 7
# Epoch: 18 	Training Accuracy: 100.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5833333333333334, no_improve_epochs: 8
# Epoch: 19 	Training Accuracy: 100.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.5833333333333334, no_improve_epochs: 9
# Epoch: 20 	Training Accuracy: 100.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.5833333333333334, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0000, Accuracy: 2.0/2 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00         1
#      Class 1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
# eval on full test set
#
# Average loss: 54.6371, Accuracy: 68.0/121 (56%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.13      0.23        61
#      Class 1       0.53      1.00      0.69        60
#
#     accuracy                           0.56       121
#    macro avg       0.77      0.57      0.46       121
# weighted avg       0.77      0.56      0.46       121
#
# Repeat: 1, with seed 20 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 5 	Training Accuracy: 100.00%
# Validation Accuracy: 55.83%
# Epoch: 6 	Training Accuracy: 100.00%
# Validation Accuracy: 64.17%
# Epoch: 7 	Training Accuracy: 100.00%
# Validation Accuracy: 67.50%
# Epoch: 8 	Training Accuracy: 100.00%
# Validation Accuracy: 67.50%
# val_acc: 0.675, max_val_acc: 0.675, no_improve_epochs: 1
# Epoch: 9 	Training Accuracy: 100.00%
# Validation Accuracy: 70.00%
# Epoch: 10 	Training Accuracy: 100.00%
# Validation Accuracy: 71.67%
# Epoch: 11 	Training Accuracy: 100.00%
# Validation Accuracy: 71.67%
# val_acc: 0.7166666666666667, max_val_acc: 0.7166666666666667, no_improve_epochs: 1
# Epoch: 12 	Training Accuracy: 100.00%
# Validation Accuracy: 70.83%
# val_acc: 0.7083333333333334, max_val_acc: 0.7166666666666667, no_improve_epochs: 2
# Epoch: 13 	Training Accuracy: 100.00%
# Validation Accuracy: 72.50%
# Epoch: 14 	Training Accuracy: 100.00%
# Validation Accuracy: 74.17%
# Epoch: 15 	Training Accuracy: 100.00%
# Validation Accuracy: 75.00%
# Epoch: 16 	Training Accuracy: 100.00%
# Validation Accuracy: 76.67%
# Epoch: 17 	Training Accuracy: 100.00%
# Validation Accuracy: 77.50%
# Epoch: 18 	Training Accuracy: 100.00%
# Validation Accuracy: 76.67%
# val_acc: 0.7666666666666667, max_val_acc: 0.775, no_improve_epochs: 1
# Epoch: 19 	Training Accuracy: 100.00%
# Validation Accuracy: 75.83%
# val_acc: 0.7583333333333333, max_val_acc: 0.775, no_improve_epochs: 2
# Epoch: 20 	Training Accuracy: 100.00%
# Validation Accuracy: 74.17%
# val_acc: 0.7416666666666667, max_val_acc: 0.775, no_improve_epochs: 3
# Epoch: 21 	Training Accuracy: 100.00%
# Validation Accuracy: 75.83%
# val_acc: 0.7583333333333333, max_val_acc: 0.775, no_improve_epochs: 4
# Epoch: 22 	Training Accuracy: 100.00%
# Validation Accuracy: 71.67%
# val_acc: 0.7166666666666667, max_val_acc: 0.775, no_improve_epochs: 5
# Epoch: 23 	Training Accuracy: 100.00%
# Validation Accuracy: 70.00%
# val_acc: 0.7, max_val_acc: 0.775, no_improve_epochs: 6
# Epoch: 24 	Training Accuracy: 100.00%
# Validation Accuracy: 68.33%
# val_acc: 0.6833333333333333, max_val_acc: 0.775, no_improve_epochs: 7
# Epoch: 25 	Training Accuracy: 100.00%
# Validation Accuracy: 68.33%
# val_acc: 0.6833333333333333, max_val_acc: 0.775, no_improve_epochs: 8
# Epoch: 26 	Training Accuracy: 100.00%
# Validation Accuracy: 69.17%
# val_acc: 0.6916666666666667, max_val_acc: 0.775, no_improve_epochs: 9
# Epoch: 27 	Training Accuracy: 100.00%
# Validation Accuracy: 70.00%
# val_acc: 0.7, max_val_acc: 0.775, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0000, Accuracy: 2.0/2 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00         1
#      Class 1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
# eval on full test set
#
# Average loss: 212.6145, Accuracy: 85.0/121 (70%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.51      0.63        61
#      Class 1       0.64      0.90      0.75        60
#
#     accuracy                           0.70       121
#    macro avg       0.74      0.70      0.69       121
# weighted avg       0.74      0.70      0.69       121
#
# Repeat: 2, with seed 30 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 100.00%
# Validation Accuracy: 56.67%
# Epoch: 4 	Training Accuracy: 100.00%
# Validation Accuracy: 57.50%
# Epoch: 5 	Training Accuracy: 100.00%
# Validation Accuracy: 55.83%
# val_acc: 0.5583333333333333, max_val_acc: 0.575, no_improve_epochs: 1
# Epoch: 6 	Training Accuracy: 100.00%
# Validation Accuracy: 54.17%
# val_acc: 0.5416666666666666, max_val_acc: 0.575, no_improve_epochs: 2
# Epoch: 7 	Training Accuracy: 100.00%
# Validation Accuracy: 55.83%
# val_acc: 0.5583333333333333, max_val_acc: 0.575, no_improve_epochs: 3
# Epoch: 8 	Training Accuracy: 100.00%
# Validation Accuracy: 71.67%
# Epoch: 9 	Training Accuracy: 50.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.7166666666666667, no_improve_epochs: 1
# Epoch: 10 	Training Accuracy: 100.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.7166666666666667, no_improve_epochs: 2
# Epoch: 11 	Training Accuracy: 100.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.7166666666666667, no_improve_epochs: 3
# Epoch: 12 	Training Accuracy: 100.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.7166666666666667, no_improve_epochs: 4
# Epoch: 13 	Training Accuracy: 100.00%
# Validation Accuracy: 51.67%
# val_acc: 0.5166666666666667, max_val_acc: 0.7166666666666667, no_improve_epochs: 5
# Epoch: 14 	Training Accuracy: 100.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.7166666666666667, no_improve_epochs: 6
# Epoch: 15 	Training Accuracy: 100.00%
# Validation Accuracy: 49.17%
# val_acc: 0.49166666666666664, max_val_acc: 0.7166666666666667, no_improve_epochs: 7
# Epoch: 16 	Training Accuracy: 100.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.7166666666666667, no_improve_epochs: 8
# Epoch: 17 	Training Accuracy: 100.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.7166666666666667, no_improve_epochs: 9
# Epoch: 18 	Training Accuracy: 100.00%
# Validation Accuracy: 54.17%
# val_acc: 0.5416666666666666, max_val_acc: 0.7166666666666667, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0000, Accuracy: 2.0/2 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00         1
#      Class 1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
# eval on full test set
#
# Average loss: 823.5324, Accuracy: 74.0/121 (61%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.23      0.37        61
#      Class 1       0.56      1.00      0.72        60
#
#     accuracy                           0.61       121
#    macro avg       0.78      0.61      0.55       121
# weighted avg       0.78      0.61      0.54       121
#
# Percentage: 0.01
# Repeat: 0, with seed 10 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 75.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 48.33%
# val_acc: 0.48333333333333334, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 51.67%
# val_acc: 0.5166666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 5
# Epoch: 7 	Training Accuracy: 75.00%
# Validation Accuracy: 55.83%
# Epoch: 8 	Training Accuracy: 100.00%
# Validation Accuracy: 70.83%
# Epoch: 9 	Training Accuracy: 100.00%
# Validation Accuracy: 88.33%
# Epoch: 10 	Training Accuracy: 100.00%
# Validation Accuracy: 97.50%
# Epoch: 11 	Training Accuracy: 75.00%
# Validation Accuracy: 81.67%
# val_acc: 0.8166666666666667, max_val_acc: 0.975, no_improve_epochs: 1
# Epoch: 12 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.975, no_improve_epochs: 2
# Epoch: 13 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.975, no_improve_epochs: 3
# Epoch: 14 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.975, no_improve_epochs: 4
# Epoch: 15 	Training Accuracy: 50.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.975, no_improve_epochs: 5
# Epoch: 16 	Training Accuracy: 100.00%
# Validation Accuracy: 83.33%
# val_acc: 0.8333333333333334, max_val_acc: 0.975, no_improve_epochs: 6
# Epoch: 17 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.975, no_improve_epochs: 7
# Epoch: 18 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.975, no_improve_epochs: 8
# Epoch: 19 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.975, no_improve_epochs: 9
# Epoch: 20 	Training Accuracy: 100.00%
# Validation Accuracy: 94.17%
# val_acc: 0.9416666666666667, max_val_acc: 0.975, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.3428, Accuracy: 4.0/4 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00         2
#      Class 1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
# eval on full test set
#
# Average loss: 0.3689, Accuracy: 115.0/121 (95%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.91      1.00      0.95        61
#      Class 1       1.00      0.90      0.95        60
#
#     accuracy                           0.95       121
#    macro avg       0.96      0.95      0.95       121
# weighted avg       0.95      0.95      0.95       121
#
# Repeat: 1, with seed 20 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 5
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 6
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 7
# Epoch: 9 	Training Accuracy: 50.00%
# Validation Accuracy: 33.33%
# val_acc: 0.3333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 8
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 9
# Epoch: 11 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.7271, Accuracy: 2.0/4 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.00      0.00      0.00         2
#      Class 1       0.50      1.00      0.67         2
#
#     accuracy                           0.50         4
#    macro avg       0.25      0.50      0.33         4
# weighted avg       0.25      0.50      0.33         4
#
# eval on full test set
#
# Average loss: 1.4005, Accuracy: 60.0/121 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.00      0.00      0.00        61
#      Class 1       0.50      1.00      0.66        60
#
#     accuracy                           0.50       121
#    macro avg       0.25      0.50      0.33       121
# weighted avg       0.25      0.50      0.33       121
#
# Repeat: 2, with seed 30 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 100.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 5 	Training Accuracy: 75.00%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 6 	Training Accuracy: 100.00%
# Validation Accuracy: 60.83%
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.6083333333333333, no_improve_epochs: 1
# Epoch: 8 	Training Accuracy: 100.00%
# Validation Accuracy: 59.17%
# val_acc: 0.5916666666666667, max_val_acc: 0.6083333333333333, no_improve_epochs: 2
# Epoch: 9 	Training Accuracy: 100.00%
# Validation Accuracy: 58.33%
# val_acc: 0.5833333333333334, max_val_acc: 0.6083333333333333, no_improve_epochs: 3
# Epoch: 10 	Training Accuracy: 100.00%
# Validation Accuracy: 59.17%
# val_acc: 0.5916666666666667, max_val_acc: 0.6083333333333333, no_improve_epochs: 4
# Epoch: 11 	Training Accuracy: 100.00%
# Validation Accuracy: 58.33%
# val_acc: 0.5833333333333334, max_val_acc: 0.6083333333333333, no_improve_epochs: 5
# Epoch: 12 	Training Accuracy: 100.00%
# Validation Accuracy: 58.33%
# val_acc: 0.5833333333333334, max_val_acc: 0.6083333333333333, no_improve_epochs: 6
# Epoch: 13 	Training Accuracy: 100.00%
# Validation Accuracy: 57.50%
# val_acc: 0.575, max_val_acc: 0.6083333333333333, no_improve_epochs: 7
# Epoch: 14 	Training Accuracy: 100.00%
# Validation Accuracy: 56.67%
# val_acc: 0.5666666666666667, max_val_acc: 0.6083333333333333, no_improve_epochs: 8
# Epoch: 15 	Training Accuracy: 100.00%
# Validation Accuracy: 56.67%
# val_acc: 0.5666666666666667, max_val_acc: 0.6083333333333333, no_improve_epochs: 9
# Epoch: 16 	Training Accuracy: 100.00%
# Validation Accuracy: 56.67%
# val_acc: 0.5666666666666667, max_val_acc: 0.6083333333333333, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0000, Accuracy: 4.0/4 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00         2
#      Class 1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
# eval on full test set
#
# Average loss: 389.7151, Accuracy: 75.0/121 (62%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.25      0.39        61
#      Class 1       0.57      1.00      0.72        60
#
#     accuracy                           0.62       121
#    macro avg       0.78      0.62      0.56       121
# weighted avg       0.78      0.62      0.56       121
#
# Percentage: 0.015
# Repeat: 0, with seed 10 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 6 	Training Accuracy: 25.00%
# Validation Accuracy: 35.00%
# val_acc: 0.35, max_val_acc: 0.5333333333333333, no_improve_epochs: 5
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 6
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 7
# Epoch: 9 	Training Accuracy: 50.00%
# Validation Accuracy: 51.67%
# val_acc: 0.5166666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 8
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.5333333333333333, no_improve_epochs: 9
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 11 	Training Accuracy: 50.00%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.5333333333333333, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.6967, Accuracy: 4.0/8 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      1.00      0.67         4
#      Class 1       0.00      0.00      0.00         4
#
#     accuracy                           0.50         8
#    macro avg       0.25      0.50      0.33         8
# weighted avg       0.25      0.50      0.33         8
#
# eval on full test set
#
# Average loss: 0.7118, Accuracy: 52.0/121 (43%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.46      0.84      0.60        61
#      Class 1       0.09      0.02      0.03        60
#
#     accuracy                           0.43       121
#    macro avg       0.28      0.43      0.31       121
# weighted avg       0.28      0.43      0.31       121
#
# Repeat: 1, with seed 20 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 75.00%
# Validation Accuracy: 57.50%
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.575, no_improve_epochs: 1
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.575, no_improve_epochs: 2
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.575, no_improve_epochs: 3
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.575, no_improve_epochs: 4
# Epoch: 9 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.575, no_improve_epochs: 5
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.575, no_improve_epochs: 6
# Epoch: 11 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.575, no_improve_epochs: 7
# Epoch: 12 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.575, no_improve_epochs: 8
# Epoch: 13 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.575, no_improve_epochs: 9
# Epoch: 14 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.575, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.7861, Accuracy: 4.0/8 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.00      0.00      0.00         4
#      Class 1       0.50      1.00      0.67         4
#
#     accuracy                           0.50         8
#    macro avg       0.25      0.50      0.33         8
# weighted avg       0.25      0.50      0.33         8
#
# eval on full test set
#
# Average loss: 0.7935, Accuracy: 60.0/121 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.00      0.00      0.00        61
#      Class 1       0.50      1.00      0.66        60
#
#     accuracy                           0.50       121
#    macro avg       0.25      0.50      0.33       121
# weighted avg       0.25      0.50      0.33       121
#
# Repeat: 2, with seed 30 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 100.00%
# Validation Accuracy: 64.17%
# Epoch: 5 	Training Accuracy: 100.00%
# Validation Accuracy: 70.00%
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.7, no_improve_epochs: 1
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.7, no_improve_epochs: 2
# Epoch: 8 	Training Accuracy: 75.00%
# Validation Accuracy: 58.33%
# val_acc: 0.5833333333333334, max_val_acc: 0.7, no_improve_epochs: 3
# Epoch: 9 	Training Accuracy: 62.50%
# Validation Accuracy: 54.17%
# val_acc: 0.5416666666666666, max_val_acc: 0.7, no_improve_epochs: 4
# Epoch: 10 	Training Accuracy: 50.00%
# Validation Accuracy: 39.17%
# val_acc: 0.39166666666666666, max_val_acc: 0.7, no_improve_epochs: 5
# Epoch: 11 	Training Accuracy: 50.00%
# Validation Accuracy: 43.33%
# val_acc: 0.43333333333333335, max_val_acc: 0.7, no_improve_epochs: 6
# Epoch: 12 	Training Accuracy: 75.00%
# Validation Accuracy: 54.17%
# val_acc: 0.5416666666666666, max_val_acc: 0.7, no_improve_epochs: 7
# Epoch: 13 	Training Accuracy: 75.00%
# Validation Accuracy: 55.00%
# val_acc: 0.55, max_val_acc: 0.7, no_improve_epochs: 8
# Epoch: 14 	Training Accuracy: 75.00%
# Validation Accuracy: 55.00%
# val_acc: 0.55, max_val_acc: 0.7, no_improve_epochs: 9
# Epoch: 15 	Training Accuracy: 50.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.7, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.5757, Accuracy: 4.0/8 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      1.00      0.67         4
#      Class 1       0.00      0.00      0.00         4
#
#     accuracy                           0.50         8
#    macro avg       0.25      0.50      0.33         8
# weighted avg       0.25      0.50      0.33         8
#
# eval on full test set
#
# Average loss: 0.6759, Accuracy: 53.0/121 (44%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.47      0.87      0.61        61
#      Class 1       0.00      0.00      0.00        60
#
#     accuracy                           0.44       121
#    macro avg       0.23      0.43      0.30       121
# weighted avg       0.24      0.44      0.31       121
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Percentage: 0.02
# Repeat: 0, with seed 10 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 60.00%
# Validation Accuracy: 58.33%
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5833333333333334, no_improve_epochs: 1
# Epoch: 5 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5833333333333334, no_improve_epochs: 2
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5833333333333334, no_improve_epochs: 3
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.5833333333333334, no_improve_epochs: 4
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 49.17%
# val_acc: 0.49166666666666664, max_val_acc: 0.5833333333333334, no_improve_epochs: 5
# Epoch: 9 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5833333333333334, no_improve_epochs: 6
# Epoch: 10 	Training Accuracy: 40.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5833333333333334, no_improve_epochs: 7
# Epoch: 11 	Training Accuracy: 50.00%
# Validation Accuracy: 49.17%
# val_acc: 0.49166666666666664, max_val_acc: 0.5833333333333334, no_improve_epochs: 8
# Epoch: 12 	Training Accuracy: 50.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.5833333333333334, no_improve_epochs: 9
# Epoch: 13 	Training Accuracy: 50.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.5833333333333334, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.7862, Accuracy: 5.0/10 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      1.00      0.67         5
#      Class 1       0.00      0.00      0.00         5
#
#     accuracy                           0.50        10
#    macro avg       0.25      0.50      0.33        10
# weighted avg       0.25      0.50      0.33        10
#
# eval on full test set
#
# Average loss: 0.8052, Accuracy: 60.0/121 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      0.98      0.66        61
#      Class 1       0.00      0.00      0.00        60
#
#     accuracy                           0.50       121
#    macro avg       0.25      0.49      0.33       121
# weighted avg       0.25      0.50      0.33       121
#
# Repeat: 1, with seed 20 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 40.00%
# Validation Accuracy: 41.67%
# val_acc: 0.4166666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 5 	Training Accuracy: 40.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 4
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 5
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 6
# Epoch: 8 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 7
# Epoch: 9 	Training Accuracy: 70.00%
# Validation Accuracy: 70.83%
# Epoch: 10 	Training Accuracy: 70.00%
# Validation Accuracy: 60.00%
# val_acc: 0.6, max_val_acc: 0.7083333333333334, no_improve_epochs: 1
# Epoch: 11 	Training Accuracy: 70.00%
# Validation Accuracy: 60.00%
# val_acc: 0.6, max_val_acc: 0.7083333333333334, no_improve_epochs: 2
# Epoch: 12 	Training Accuracy: 70.00%
# Validation Accuracy: 60.00%
# val_acc: 0.6, max_val_acc: 0.7083333333333334, no_improve_epochs: 3
# Epoch: 13 	Training Accuracy: 70.00%
# Validation Accuracy: 62.50%
# val_acc: 0.625, max_val_acc: 0.7083333333333334, no_improve_epochs: 4
# Epoch: 14 	Training Accuracy: 70.00%
# Validation Accuracy: 64.17%
# val_acc: 0.6416666666666667, max_val_acc: 0.7083333333333334, no_improve_epochs: 5
# Epoch: 15 	Training Accuracy: 70.00%
# Validation Accuracy: 60.00%
# val_acc: 0.6, max_val_acc: 0.7083333333333334, no_improve_epochs: 6
# Epoch: 16 	Training Accuracy: 70.00%
# Validation Accuracy: 59.17%
# val_acc: 0.5916666666666667, max_val_acc: 0.7083333333333334, no_improve_epochs: 7
# Epoch: 17 	Training Accuracy: 70.00%
# Validation Accuracy: 60.00%
# val_acc: 0.6, max_val_acc: 0.7083333333333334, no_improve_epochs: 8
# Epoch: 18 	Training Accuracy: 70.00%
# Validation Accuracy: 60.83%
# val_acc: 0.6083333333333333, max_val_acc: 0.7083333333333334, no_improve_epochs: 9
# Epoch: 19 	Training Accuracy: 70.00%
# Validation Accuracy: 61.67%
# val_acc: 0.6166666666666667, max_val_acc: 0.7083333333333334, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.5296, Accuracy: 7.0/10 (70%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.40      0.57         5
#      Class 1       0.62      1.00      0.77         5
#
#     accuracy                           0.70        10
#    macro avg       0.81      0.70      0.67        10
# weighted avg       0.81      0.70      0.67        10
#
# eval on full test set
#
# Average loss: 3.6047, Accuracy: 78.0/121 (64%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.88      0.34      0.49        61
#      Class 1       0.59      0.95      0.73        60
#
#     accuracy                           0.64       121
#    macro avg       0.73      0.65      0.61       121
# weighted avg       0.73      0.64      0.61       121
#
# Repeat: 2, with seed 30 =========================
# Epoch: 0 	Training Accuracy: 60.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 50.83%
# val_acc: 0.5083333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 3
# Epoch: 5 	Training Accuracy: 60.00%
# Validation Accuracy: 54.17%
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5416666666666666, no_improve_epochs: 1
# Epoch: 7 	Training Accuracy: 90.00%
# Validation Accuracy: 59.17%
# Epoch: 8 	Training Accuracy: 90.00%
# Validation Accuracy: 58.33%
# val_acc: 0.5833333333333334, max_val_acc: 0.5916666666666667, no_improve_epochs: 1
# Epoch: 9 	Training Accuracy: 50.00%
# Validation Accuracy: 59.17%
# val_acc: 0.5916666666666667, max_val_acc: 0.5916666666666667, no_improve_epochs: 2
# Epoch: 10 	Training Accuracy: 90.00%
# Validation Accuracy: 45.00%
# val_acc: 0.45, max_val_acc: 0.5916666666666667, no_improve_epochs: 3
# Epoch: 11 	Training Accuracy: 90.00%
# Validation Accuracy: 40.83%
# val_acc: 0.4083333333333333, max_val_acc: 0.5916666666666667, no_improve_epochs: 4
# Epoch: 12 	Training Accuracy: 90.00%
# Validation Accuracy: 38.33%
# val_acc: 0.38333333333333336, max_val_acc: 0.5916666666666667, no_improve_epochs: 5
# Epoch: 13 	Training Accuracy: 70.00%
# Validation Accuracy: 40.83%
# val_acc: 0.4083333333333333, max_val_acc: 0.5916666666666667, no_improve_epochs: 6
# Epoch: 14 	Training Accuracy: 90.00%
# Validation Accuracy: 47.50%
# val_acc: 0.475, max_val_acc: 0.5916666666666667, no_improve_epochs: 7
# Epoch: 15 	Training Accuracy: 90.00%
# Validation Accuracy: 63.33%
# Epoch: 16 	Training Accuracy: 80.00%
# Validation Accuracy: 57.50%
# val_acc: 0.575, max_val_acc: 0.6333333333333333, no_improve_epochs: 1
# Epoch: 17 	Training Accuracy: 90.00%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.6333333333333333, no_improve_epochs: 2
# Epoch: 18 	Training Accuracy: 70.00%
# Validation Accuracy: 61.67%
# val_acc: 0.6166666666666667, max_val_acc: 0.6333333333333333, no_improve_epochs: 3
# Epoch: 19 	Training Accuracy: 80.00%
# Validation Accuracy: 69.17%
# Epoch: 20 	Training Accuracy: 80.00%
# Validation Accuracy: 75.83%
# Epoch: 21 	Training Accuracy: 90.00%
# Validation Accuracy: 78.33%
# Epoch: 22 	Training Accuracy: 100.00%
# Validation Accuracy: 86.67%
# Epoch: 23 	Training Accuracy: 100.00%
# Validation Accuracy: 90.83%
# Epoch: 24 	Training Accuracy: 100.00%
# Validation Accuracy: 92.50%
# Epoch: 25 	Training Accuracy: 100.00%
# Validation Accuracy: 95.83%
# Epoch: 26 	Training Accuracy: 100.00%
# Validation Accuracy: 96.67%
# Epoch: 27 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# Epoch: 28 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 1
# Epoch: 29 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 2
# Epoch: 30 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 3
# Epoch: 31 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 4
# Epoch: 32 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 5
# Epoch: 33 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 6
# Epoch: 34 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 7
# Epoch: 35 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# Epoch: 36 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 1
# Epoch: 37 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 2
# Epoch: 38 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 3
# Epoch: 39 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 4
# Epoch: 40 	Training Accuracy: 100.00%
# Validation Accuracy: 98.33%
# val_acc: 0.9833333333333333, max_val_acc: 1.0, no_improve_epochs: 5
# Epoch: 41 	Training Accuracy: 100.00%
# Validation Accuracy: 98.33%
# val_acc: 0.9833333333333333, max_val_acc: 1.0, no_improve_epochs: 6
# Epoch: 42 	Training Accuracy: 100.00%
# Validation Accuracy: 98.33%
# val_acc: 0.9833333333333333, max_val_acc: 1.0, no_improve_epochs: 7
# Epoch: 43 	Training Accuracy: 100.00%
# Validation Accuracy: 98.33%
# val_acc: 0.9833333333333333, max_val_acc: 1.0, no_improve_epochs: 8
# Epoch: 44 	Training Accuracy: 100.00%
# Validation Accuracy: 98.33%
# val_acc: 0.9833333333333333, max_val_acc: 1.0, no_improve_epochs: 9
# Epoch: 45 	Training Accuracy: 100.00%
# Validation Accuracy: 98.33%
# val_acc: 0.9833333333333333, max_val_acc: 1.0, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0000, Accuracy: 10.0/10 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00         5
#      Class 1       1.00      1.00      1.00         5
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# ...
# Epoch: 17 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5583333333333333, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.6068, Accuracy: 19.0/38 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      1.00      0.67        19
#      Class 1       0.00      0.00      0.00        19
#
#     accuracy                           0.50        38
#    macro avg       0.25      0.50      0.33        38
# weighted avg       0.25      0.50      0.33        38
#
# eval on full test set
#
# Average loss: 0.6661, Accuracy: 61.0/121 (50%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.50      1.00      0.67        61
#      Class 1       0.00      0.00      0.00        60
#
#     accuracy                           0.50       121
#    macro avg       0.25      0.50      0.34       121
# weighted avg       0.25      0.50      0.34       121
#
# Percentage: 0.1
# Repeat: 0, with seed 10 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 1 	Training Accuracy: 51.85%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 3 	Training Accuracy: 92.59%
# Validation Accuracy: 94.17%
# Epoch: 4 	Training Accuracy: 16.67%
# Validation Accuracy: 14.17%
# val_acc: 0.14166666666666666, max_val_acc: 0.9416666666666667, no_improve_epochs: 1
# Epoch: 5 	Training Accuracy: 64.81%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.9416666666666667, no_improve_epochs: 2
# Epoch: 6 	Training Accuracy: 68.52%
# Validation Accuracy: 59.17%
# val_acc: 0.5916666666666667, max_val_acc: 0.9416666666666667, no_improve_epochs: 3
# Epoch: 7 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.9416666666666667, no_improve_epochs: 4
# Epoch: 8 	Training Accuracy: 70.37%
# Validation Accuracy: 68.33%
# val_acc: 0.6833333333333333, max_val_acc: 0.9416666666666667, no_improve_epochs: 5
# Epoch: 9 	Training Accuracy: 74.07%
# Validation Accuracy: 76.67%
# val_acc: 0.7666666666666667, max_val_acc: 0.9416666666666667, no_improve_epochs: 6
# Epoch: 10 	Training Accuracy: 88.89%
# Validation Accuracy: 90.00%
# val_acc: 0.9, max_val_acc: 0.9416666666666667, no_improve_epochs: 7
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tusha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 11 	Training Accuracy: 85.19%
# Validation Accuracy: 90.83%
# val_acc: 0.9083333333333333, max_val_acc: 0.9416666666666667, no_improve_epochs: 8
# Epoch: 12 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# Epoch: 13 	Training Accuracy: 88.89%
# Validation Accuracy: 87.50%
# val_acc: 0.875, max_val_acc: 0.9916666666666667, no_improve_epochs: 1
# Epoch: 14 	Training Accuracy: 92.59%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 2
# Epoch: 15 	Training Accuracy: 96.30%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 0.9916666666666667, no_improve_epochs: 3
# Epoch: 16 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# Epoch: 17 	Training Accuracy: 77.78%
# Validation Accuracy: 80.00%
# val_acc: 0.8, max_val_acc: 1.0, no_improve_epochs: 1
# Epoch: 18 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 2
# Epoch: 19 	Training Accuracy: 98.15%
# Validation Accuracy: 96.67%
# val_acc: 0.9666666666666667, max_val_acc: 1.0, no_improve_epochs: 3
# Epoch: 20 	Training Accuracy: 100.00%
# Validation Accuracy: 97.50%
# val_acc: 0.975, max_val_acc: 1.0, no_improve_epochs: 4
# Epoch: 21 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 5
# Epoch: 22 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 6
# Epoch: 23 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 7
# Epoch: 24 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 8
# Epoch: 25 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 9
# Epoch: 26 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0001, Accuracy: 54.0/54 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00        27
#      Class 1       1.00      1.00      1.00        27
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54
#
# eval on full test set
#
# Average loss: 0.4067, Accuracy: 118.0/121 (98%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.95      1.00      0.98        61
#      Class 1       1.00      0.95      0.97        60
#
#     accuracy                           0.98       121
#    macro avg       0.98      0.97      0.98       121
# weighted avg       0.98      0.98      0.98       121
#
# Repeat: 1, with seed 20 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# Epoch: 1 	Training Accuracy: 50.00%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.4666666666666667, no_improve_epochs: 1
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 3 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 4 	Training Accuracy: 50.00%
# Validation Accuracy: 50.00%
# val_acc: 0.5, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 5 	Training Accuracy: 62.96%
# Validation Accuracy: 81.67%
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.8166666666666667, no_improve_epochs: 1
# Epoch: 7 	Training Accuracy: 70.37%
# Validation Accuracy: 77.50%
# val_acc: 0.775, max_val_acc: 0.8166666666666667, no_improve_epochs: 2
# Epoch: 8 	Training Accuracy: 96.30%
# Validation Accuracy: 97.50%
# Epoch: 9 	Training Accuracy: 98.15%
# Validation Accuracy: 100.00%
# Epoch: 10 	Training Accuracy: 100.00%
# Validation Accuracy: 95.00%
# val_acc: 0.95, max_val_acc: 1.0, no_improve_epochs: 1
# Epoch: 11 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 2
# Epoch: 12 	Training Accuracy: 98.15%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 3
# Epoch: 13 	Training Accuracy: 87.04%
# Validation Accuracy: 90.00%
# val_acc: 0.9, max_val_acc: 1.0, no_improve_epochs: 4
# Epoch: 14 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 5
# Epoch: 15 	Training Accuracy: 100.00%
# Validation Accuracy: 95.00%
# val_acc: 0.95, max_val_acc: 1.0, no_improve_epochs: 6
# Epoch: 16 	Training Accuracy: 92.59%
# Validation Accuracy: 90.83%
# val_acc: 0.9083333333333333, max_val_acc: 1.0, no_improve_epochs: 7
# Epoch: 17 	Training Accuracy: 66.67%
# Validation Accuracy: 74.17%
# val_acc: 0.7416666666666667, max_val_acc: 1.0, no_improve_epochs: 8
# Epoch: 18 	Training Accuracy: 64.81%
# Validation Accuracy: 56.67%
# val_acc: 0.5666666666666667, max_val_acc: 1.0, no_improve_epochs: 9
# Epoch: 19 	Training Accuracy: 96.30%
# Validation Accuracy: 94.17%
# val_acc: 0.9416666666666667, max_val_acc: 1.0, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0505, Accuracy: 52.0/54 (96%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.93      0.96        27
#      Class 1       0.93      1.00      0.96        27
#
#     accuracy                           0.96        54
#    macro avg       0.97      0.96      0.96        54
# weighted avg       0.97      0.96      0.96        54
#
# eval on full test set
#
# Average loss: 0.3392, Accuracy: 114.0/121 (94%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.89      0.94        61
#      Class 1       0.90      1.00      0.94        60
#
#     accuracy                           0.94       121
#    macro avg       0.95      0.94      0.94       121
# weighted avg       0.95      0.94      0.94       121
#
# Repeat: 2, with seed 30 =========================
# Epoch: 0 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# Epoch: 1 	Training Accuracy: 53.70%
# Validation Accuracy: 46.67%
# val_acc: 0.4666666666666667, max_val_acc: 0.5333333333333333, no_improve_epochs: 1
# Epoch: 2 	Training Accuracy: 50.00%
# Validation Accuracy: 53.33%
# val_acc: 0.5333333333333333, max_val_acc: 0.5333333333333333, no_improve_epochs: 2
# Epoch: 3 	Training Accuracy: 79.63%
# Validation Accuracy: 70.00%
# Epoch: 4 	Training Accuracy: 48.15%
# Validation Accuracy: 49.17%
# val_acc: 0.49166666666666664, max_val_acc: 0.7, no_improve_epochs: 1
# Epoch: 5 	Training Accuracy: 79.63%
# Validation Accuracy: 52.50%
# val_acc: 0.525, max_val_acc: 0.7, no_improve_epochs: 2
# Epoch: 6 	Training Accuracy: 50.00%
# Validation Accuracy: 55.83%
# val_acc: 0.5583333333333333, max_val_acc: 0.7, no_improve_epochs: 3
# Epoch: 7 	Training Accuracy: 79.63%
# Validation Accuracy: 60.00%
# val_acc: 0.6, max_val_acc: 0.7, no_improve_epochs: 4
# Epoch: 8 	Training Accuracy: 75.93%
# Validation Accuracy: 64.17%
# val_acc: 0.6416666666666667, max_val_acc: 0.7, no_improve_epochs: 5
# Epoch: 9 	Training Accuracy: 81.48%
# Validation Accuracy: 64.17%
# val_acc: 0.6416666666666667, max_val_acc: 0.7, no_improve_epochs: 6
# Epoch: 10 	Training Accuracy: 77.78%
# Validation Accuracy: 63.33%
# val_acc: 0.6333333333333333, max_val_acc: 0.7, no_improve_epochs: 7
# Epoch: 11 	Training Accuracy: 64.81%
# Validation Accuracy: 58.33%
# val_acc: 0.5833333333333334, max_val_acc: 0.7, no_improve_epochs: 8
# Epoch: 12 	Training Accuracy: 83.33%
# Validation Accuracy: 75.00%
# Epoch: 13 	Training Accuracy: 87.04%
# Validation Accuracy: 74.17%
# val_acc: 0.7416666666666667, max_val_acc: 0.75, no_improve_epochs: 1
# Epoch: 14 	Training Accuracy: 94.44%
# Validation Accuracy: 89.17%
# Epoch: 15 	Training Accuracy: 96.30%
# Validation Accuracy: 85.00%
# val_acc: 0.85, max_val_acc: 0.8916666666666667, no_improve_epochs: 1
# Epoch: 16 	Training Accuracy: 87.04%
# Validation Accuracy: 83.33%
# val_acc: 0.8333333333333334, max_val_acc: 0.8916666666666667, no_improve_epochs: 2
# Epoch: 17 	Training Accuracy: 79.63%
# Validation Accuracy: 71.67%
# val_acc: 0.7166666666666667, max_val_acc: 0.8916666666666667, no_improve_epochs: 3
# Epoch: 18 	Training Accuracy: 100.00%
# Validation Accuracy: 96.67%
# Epoch: 19 	Training Accuracy: 90.74%
# Validation Accuracy: 75.83%
# val_acc: 0.7583333333333333, max_val_acc: 0.9666666666666667, no_improve_epochs: 1
# Epoch: 20 	Training Accuracy: 83.33%
# Validation Accuracy: 65.83%
# val_acc: 0.6583333333333333, max_val_acc: 0.9666666666666667, no_improve_epochs: 2
# Epoch: 21 	Training Accuracy: 100.00%
# Validation Accuracy: 95.83%
# val_acc: 0.9583333333333334, max_val_acc: 0.9666666666666667, no_improve_epochs: 3
# Epoch: 22 	Training Accuracy: 94.44%
# Validation Accuracy: 86.67%
# val_acc: 0.8666666666666667, max_val_acc: 0.9666666666666667, no_improve_epochs: 4
# Epoch: 23 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# Epoch: 24 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# Epoch: 25 	Training Accuracy: 96.30%
# Validation Accuracy: 91.67%
# val_acc: 0.9166666666666666, max_val_acc: 1.0, no_improve_epochs: 1
# Epoch: 26 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 2
# Epoch: 27 	Training Accuracy: 100.00%
# Validation Accuracy: 97.50%
# val_acc: 0.975, max_val_acc: 1.0, no_improve_epochs: 3
# Epoch: 28 	Training Accuracy: 98.15%
# Validation Accuracy: 97.50%
# val_acc: 0.975, max_val_acc: 1.0, no_improve_epochs: 4
# Epoch: 29 	Training Accuracy: 100.00%
# Validation Accuracy: 98.33%
# val_acc: 0.9833333333333333, max_val_acc: 1.0, no_improve_epochs: 5
# Epoch: 30 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 6
# Epoch: 31 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 7
# Epoch: 32 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 8
# Epoch: 33 	Training Accuracy: 100.00%
# Validation Accuracy: 99.17%
# val_acc: 0.9916666666666667, max_val_acc: 1.0, no_improve_epochs: 9
# Epoch: 34 	Training Accuracy: 100.00%
# Validation Accuracy: 100.00%
# val_acc: 1.0, max_val_acc: 1.0, no_improve_epochs: 10
# Early stopping invoked.
# eval on reduced train set
#
# Average loss: 0.0016, Accuracy: 54.0/54 (100%)
#
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00        27
#      Class 1       1.00      1.00      1.00        27
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54
#
# eval on full test set
#
# Average loss: 0.0243, Accuracy: 120.0/121 (99%)
#
#               precision    recall  f1-score   support
#
#      Class 0       0.98      1.00      0.99        61
#      Class 1       1.00      0.98      0.99        60
#
#     accuracy                           0.99       121
#    macro avg       0.99      0.99      0.99       121
# weighted avg       0.99      0.99      0.99       121

# %%
print(model_new)
# Out:
# Sequential(
#   (linear0): Linear(in_features=6, out_features=128, bias=True)
#   (activation0): ReLU()
#   (linear1): Linear(in_features=128, out_features=128, bias=True)
#   (activation1): ReLU()
#   (linear2): Linear(in_features=128, out_features=128, bias=True)
#   (activation2): ReLU()
#   (linear3): Linear(in_features=128, out_features=128, bias=True)
#   (activation3): ReLU()
#   (linear4): Linear(in_features=128, out_features=2, bias=True)
#   (activation4): LogSoftmax(dim=1)
# )

# %%
for name, param in model.named_parameters():
    if "linear" + str(depth-1) not in name:
        #model_new._parameters[name] = param
        print('layer name: ', name)
# Out:
# layer name:  linear0.weight
# layer name:  linear0.bias
# layer name:  linear1.weight
# layer name:  linear1.bias
# layer name:  linear2.weight
# layer name:  linear2.bias
# layer name:  linear3.weight
# layer name:  linear3.bias
